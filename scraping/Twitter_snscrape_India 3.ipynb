# %% [markdown]
# snscrape
#
# Ref: https://github.com/JustAnotherArchivist/snscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# Scraping tweets from a text search query
#
# Using the code below, we are scraping 100 tweets between June 14, 2020, and August 31, 2021,
# with the keywords 'SSR Bollywood'.
#
# I then pulled attributes DateTime, tweet id, text, and username from the tweet objects.

# %%
# Creating list to append tweet data to
tweets_list2 = []

# search terms
search_terms = 'mandated vaccine'

# Using TwitterSearchScraper to scrape data and append tweets to list
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(search_terms + ' since:2020-12-01 until:2022-02-11 near:"India" within:1000km').get_items()):
    if i > 100000:
        break
    #declare the attributes to be returned
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username',])

# %%
tweets_df2
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-02-10 18:29:21+00:00  1491841735944777734
# 1  2022-02-10 16:36:15+00:00  1491813274006220800
# 2  2022-02-10 04:08:12+00:00  1491625021961351170
# 3  2022-02-09 23:38:22+00:00  1491557112819986434
# 4  2022-02-09 19:16:38+00:00  1491491247609225217
# 5  2022-02-09 08:56:42+00:00  1491335237267345408
# 6  2022-02-09 08:01:01+00:00  1491321224198516736
# 7  2022-02-09 05:01:04+00:00  1491275934775001091
# 8  2022-02-08 16:24:53+00:00  1491085636815978501
# 9  2022-02-07 21:41:17+00:00  1490802873835274240
# 10 2022-02-07 06:21:45+00:00  1490571466718466049
# 11 2022-02-06 13:48:13+00:00  1490321434132074496
# 12 2022-02-06 12:49:27+00:00  1490306643628027904
# 13 2022-02-06 12:49:26+00:00  1490306640834449412
# 14 2022-02-04 21:42:10+00:00  1489715932091928577
# 15 2022-01-16 14:26:18+00:00  1482720871840387084
# 16 2022-01-13 06:39:13+00:00  1481516162819440642
# 17 2021-11-25 06:08:03+00:00  1463751314844700682
# 18 2021-11-25 04:58:52+00:00  1463733904947363842
# 19 2021-10-29 01:53:28+00:00  1453902774979096576
# 20 2021-10-18 03:00:02+00:00  1449933261795315725
# 21 2021-10-04 04:05:35+00:00  1444876328004558849
#
#                                                  Text         Username
# 0   @noonienoodie @John_outWest I was waiting for ...  Sunnyda04530056
# 1   Is this what you want to be mandated? Shouldn'...          zulkey8
# 2   @JustinTrudeau @fordnation Well undoing the ma...     connect2riaz
# 3   @AriMelber @MichaelSteele \nThe idea of unmask...   TheAvgBlackMan
# 4   @UnivofDelhi has not mandated the covid vaccin...  nainakwal_sahil
# 5   Alberta Will End Mandated Vaccine Passports at...      thegoogle93
# 6   Great business idea for lawyers-\nSince local ...    saikatghosh90
# 7   Who are the protesters?\n\nThis all started ou...          dn_rath
# 8   Lessons learnt-\n1. Look after your health\n2....  ArvindK26905698
# 9   I never made this point, in fact i am against ...     AidilIqmal99
# 10  @Kawanatanga1 @NZedAUS You said they were mand...       Sam___Issa
# 11  Costa Rica mandated Covid-19 vaccines for chil...    sociallykeeda
# 12  Costa Rica mandated Covid-19 vaccines for chil...          hs47641
# 13  Costa Rica mandated Covid-19 vaccines for chil...  Harpree09398061
# 14  @ninanotready Pfff nope its mandated to fly an...     DrewInSeAsia
# 15  @sardesairajdeep @Milan_reports Could it be be...      deeepakkher
# 16  So how do #strandedaussies UNVAXED get on a pl...     DrewInSeAsia
# 17  Today I learnt that there are willfully vaccin...     terrencedass
# 18  @BrotherAdr1an @tiotheo01 If the vaccine was m...     terrencedass
# 19  @ULucq Comparing life saving vaccines to self ...     terrencedass
# 20  @AJEnglish When I was growing up in Port Harco...   OsloCouncilman
# 21  @defendlife2a @pollyannathibo1 @laurenboebert ...    maddogberlin1

# %%
tweets_df2.to_csv("../data/India/vaccination/mandated-vaccine.csv", index = False)
