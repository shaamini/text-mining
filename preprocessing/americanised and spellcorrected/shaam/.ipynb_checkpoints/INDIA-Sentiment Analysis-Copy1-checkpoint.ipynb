# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS 
from textwrap import wrap
import ast
import itertools
import collections
import seaborn as sns

# %% [markdown]
# ### Simple EDA

# %%
df = pd.read_csv("india-v1-preprocessed-19000-38000.csv")

# %%
df
# Out:
#        Unnamed: 0                                               Text  \
# 0           19000  well this is no surprise, i spoke about this j...
# 1           19001                        faqs about #covid #vaccines
# 2           19002  4 dose vaccine against covid thanks doctor tha...
# 3           19003  india's fight against covid-19 is getting stro...
# 4           19004  #justasking #covid #precautiondose is there an...
# ...           ...                                                ...
# 18995       37995  i am afraid that infection will not spread whi...
# 18996       37996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997       37997  i think, modi ji k paas issbar 26 january pr d...
# 18998       37998  first #consignment #covid-19 vaccine, #covishi...
# 18999       37999  very good news assam finally covid vaccine is ...
#
#                                                 new_text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                      languages  \
# 0                      ENGLISH
# 1                      Unknown
# 2               ENGLISH, KHMER
# 3                      ENGLISH
# 4                      ENGLISH
# ...                        ...
# 18995                  ENGLISH
# 18996                  ENGLISH
# 18997  Unknown, HINDI, Unknown
# 18998                  ENGLISH
# 18999                  ENGLISH
#
#                                               translated  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                  new_languages  \
# 0                      ENGLISH
# 1                      Unknown
# 2                      ENGLISH
# 3                      ENGLISH
# 4                      ENGLISH
# ...                        ...
# 18995                  ENGLISH
# 18996                  ENGLISH
# 18997  Unknown, HINDI, Unknown
# 18998                  ENGLISH
# 18999                  ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                      words_processed_all  \
# 0      ['well', 'surprise', 'speak', 'journalist', 'b...
# 1                            ['fan', 'couid', 'vaccine']
# 2      ['four', 'dose', 'vaccine', 'couid', 'thank', ...
# 3      ['india', 'fight', 'couid', 'nineteen', 'get',...
# 4      ['justjoke', 'couid', 'precautiondose', 'scien...
# ...                                                  ...
# 18995  ['afraid', 'infection', 'not', 'spread', 'appl...
# 18996  ['wait', 'delhi', 'gujaratis', 'tamil_nada', '...
# 18997  ['think', 'modi', 'pass', 'disbar', 'january',...
# 18998  ['first', 'consignment', 'couid', 'nineteen', ...
# 18999  ['good', 'news', 'assay', 'finally', 'couid', ...
#
#                        words_processed_noun_adj_verb_adv  \
# 0      ['surprise', 'speak', 'journalist', 'come', 'n...
# 1                            ['fan', 'couid', 'vaccine']
# 2      ['dose', 'vaccine', 'couid', 'thank', 'doctor'...
# 3      ['fight', 'couid', 'get', 'strong', 'crore', '...
# 4      ['justjoke', 'couid', 'precautiondose', 'scien...
# ...                                                  ...
# 18995  ['afraid', 'infection', 'spread', 'apply', 'co...
# 18996  ['wait', 'receive', 'est', 'consignment', 'cov...
# 18997  ['think', 'modi', 'speech', 'content', 'modi',...
# 18998  ['vaccine', 'covishield', 'arrive', 'delhi', '...
# 18999   ['assay', 'finally', 'couid', 'vaccine', 'come']
#
#                                     words_processed_noun
# 0      ['surprise', 'journalist', 'number', 'other', ...
# 1                                     ['fan', 'vaccine']
# 2      ['dose', 'vaccine', 'thank', 'doctor', 'thank'...
# 3      ['fight', 'warrior', 'est', 'dose', 'vaccine',...
# 4      ['confirmation', 'evidence', 'ord', 'booster',...
# ...                                                  ...
# 18995  ['infection', 'vaccine', 'coronavirusvaccine',...
# 18996  ['est', 'consignment', 'covishield', 'couid', ...
# 18997  ['speech', 'content', 'vaccine', 'taani', 'spe...
# 18998                  ['vaccine', 'covishield', 'pune']
# 18999                                        ['vaccine']
#
# [19000 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19000 entries, 0 to 18999
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         19000 non-null  int64
#  1   Text                               19000 non-null  object
#  2   new_text                           19000 non-null  object
#  3   languages                          19000 non-null  object
#  4   translated                         19000 non-null  object
#  5   new_languages                      19000 non-null  object
#  6   pos_tagged_words                   19000 non-null  object
#  7   words_processed_all                19000 non-null  object
#  8   words_processed_noun_adj_verb_adv  19000 non-null  object
#  9   words_processed_noun               19000 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.4+ MB

# %%
df[df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Text, new_text, languages, translated, new_languages, pos_tagged_words, words_processed_all, words_processed_noun_adj_verb_adv, words_processed_noun]
# Index: []

# %%
df.describe()
# Out:
#          Unnamed: 0
# count  19000.000000
# mean   28499.500000
# std     5484.971893
# min    19000.000000
# 25%    23749.750000
# 50%    28499.500000
# 75%    33249.250000
# max    37999.000000

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# Text                                 object
# new_text                             object
# languages                            object
# translated                           object
# new_languages                        object
# pos_tagged_words                     object
# words_processed_all                  object
# words_processed_noun_adj_verb_adv    object
# words_processed_noun                 object
# dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0                                               Text  \
# 0       19000  well this is no surprise, i spoke about this j...
# 1       19001                        faqs about #covid #vaccines
# 2       19002  4 dose vaccine against covid thanks doctor tha...
# 3       19003  india's fight against covid-19 is getting stro...
# 4       19004  #justasking #covid #precautiondose is there an...
#
#                                             new_text       languages  \
# 0  well this is no surprise, i spoke about this j...         ENGLISH
# 1                        faqs about #covid #vaccines         Unknown
# 2  4 dose vaccine against covid thanks doctor tha...  ENGLISH, KHMER
# 3  india's fight against covid-19 is getting stro...         ENGLISH
# 4  #justasking #covid #precautiondose is there an...         ENGLISH
#
#                                           translated new_languages  \
# 0  well this is no surprise, i spoke about this j...       ENGLISH
# 1                        faqs about #covid #vaccines       Unknown
# 2  4 dose vaccine against covid thanks doctor tha...       ENGLISH
# 3  india's fight against covid-19 is getting stro...       ENGLISH
# 4  #justasking #covid #precautiondose is there an...       ENGLISH
#
#                                     pos_tagged_words  \
# 0  [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1  [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2  [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3  [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4  [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
#
#                                  words_processed_all  \
# 0  ['well', 'surprise', 'speak', 'journalist', 'b...
# 1                        ['fan', 'couid', 'vaccine']
# 2  ['four', 'dose', 'vaccine', 'couid', 'thank', ...
# 3  ['india', 'fight', 'couid', 'nineteen', 'get',...
# 4  ['justjoke', 'couid', 'precautiondose', 'scien...
#
#                    words_processed_noun_adj_verb_adv  \
# 0  ['surprise', 'speak', 'journalist', 'come', 'n...
# 1                        ['fan', 'couid', 'vaccine']
# 2  ['dose', 'vaccine', 'couid', 'thank', 'doctor'...
# 3  ['fight', 'couid', 'get', 'strong', 'crore', '...
# 4  ['justjoke', 'couid', 'precautiondose', 'scien...
#
#                                 words_processed_noun
# 0  ['surprise', 'journalist', 'number', 'other', ...
# 1                                 ['fan', 'vaccine']
# 2  ['dose', 'vaccine', 'thank', 'doctor', 'thank'...
# 3  ['fight', 'warrior', 'est', 'dose', 'vaccine',...
# 4  ['confirmation', 'evidence', 'ord', 'booster',...

# %% [markdown]
# ### Sentence Length Distribution

# %%
sns.set(rc = {'figure.figsize':(6,6)})

# %%
#sentence length distribution
print('Max length: {}, Min length: {}, Average Length :  {}'.format(max(df['Text'].str.len()),min(df['Text'].str.len()),df['Text'].str.len().mean()))
df['Text'].str.len().hist()
# Out:
# Max length: 939, Min length: 9, Average Length :  198.3247894736842
# <AxesSubplot:>

# %% [markdown]
# ### Word Count

# %%
#Review word count: Just to get a simple sensing of the word count in the reviews
word_count = []
for each in df["pos_tagged_words"]:
    words_list = each.split(" ")
    word_count.append(len(words_list))
df["word_count"] = word_count

# %%
df.head()
# Out:
#                                                 Text  \
# 0  vaccinated, rainbow, #, vaccinated, #, covidva...
# 1  very, unfortunate, situation, ., following, st...
# 2  statement, by, stating, all, australians, can,...
# 3  true, dat, ., but, also, chances, that, many, ...
# 4  before, :, couid, -, nineteen, vaccines, got, ...
#
#                                     pos_tagged_words  \
# 0  [('vaccinated', 'VBN'), ('rainbow', 'NN'), ('v...
# 1  [('very', 'RB'), ('unfortunate', 'JJ'), ('situ...
# 2  [('statement', 'NN'), ('by', 'IN'), ('stating'...
# 3  [('true', 'JJ'), ('dat', 'NN'), ('but', 'CC'),...
# 4  [('before', 'IN'), ('couid', 'NN'), ('nineteen...
#
#                                  words_processed_all  \
# 0  ['vaccinated', 'rainbow', 'vaccinated', 'covid...
# 1  ['unfortunate', 'situation', 'following', 'sto...
# 2  ['statement', 'stating', 'australian', 'vaccin...
# 3  ['true', 'dat', 'also', 'chance', 'many', 'peo...
# 4  ['couid', 'nineteen', 'vaccine', 'got', 'micro...
#
#                    words_processed_noun_adj_verb_adv  \
# 0        ['vaccinated', 'vaccinate', 'covidvaccine']
# 1  ['unfortunate', 'situation', 'follow', 'stop',...
# 2  ['statement', 'state', 'australian', 'vaccinat...
# 3  ['true', 'also', 'chance', 'many', 'people', '...
# 4  ['couid', 'vaccine', 'get', 'microchip', 'iver...
#
#                                 words_processed_noun  word_count
# 0                                   ['covidvaccine']           8
# 1  ['situation', 'stop', 'shipment', 'bangladesh'...          30
# 2  ['statement', 'australian', 'government', 'vac...          72
# 3  ['people', 'vaccine', 'disease', 'vaccine', 'm...          74
# 4             ['vaccine', 'microchip', 'ivermectin']          16

# %%
df["word_count"].describe()
# Out:
# count    19000.000000
# mean        46.014316
# std         24.380774
# min          1.000000
# 25%         26.000000
# 50%         42.000000
# 75%         66.000000
# max        194.000000
# Name: word_count, dtype: float64

# %%
#word length distribution
df['word_count'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## VADER Sentiment

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shaaminig/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Test
sid.polarity_scores("This is an excellent car with great mileage")
# Out:
# {'neg': 0.0, 'neu': 0.435, 'pos': 0.565, 'compound': 0.8316}

# %%
words_processed_all = df['words_processed_all'].to_list()
print(words_processed_all[0])
words_processed_all[0][0]
# Out:
# ['well', 'surprise', 'speak', 'journalist', 'back', 'september', 'come', 'number', 'other', 'go', 'well', 'result', 'poor', 'pay', 'condition', 'brexit', 'couid', 'stress', 'vaccine', 'issue', 'diversion', 'though', 'doubt', 'impact']
# '['

# %%
import ast
new_list = []
for str_list in words_processed_all:
    a_list = ast.literal_eval(str_list)
    new_list.append(a_list)

# %%
len(new_list)
# Out:
# 19000

# %%
new_list[0]
# Out:
# ['well',
#  'surprise',
#  'speak',
#  'journalist',
#  'back',
#  'september',
#  'come',
#  'number',
#  'other',
#  'go',
#  'well',
#  'result',
#  'poor',
#  'pay',
#  'condition',
#  'brexit',
#  'couid',
#  'stress',
#  'vaccine',
#  'issue',
#  'diversion',
#  'though',
#  'doubt',
#  'impact']

# %%
new_list[0][0]
# Out:
# 'well'

# %%
all_words_df = df[['Text', 'pos_tagged_words', 'words_processed_all']].copy()

# %%
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                      words_processed_all
# 0      ['well', 'surprise', 'speak', 'journalist', 'b...
# 1                            ['fan', 'couid', 'vaccine']
# 2      ['four', 'dose', 'vaccine', 'couid', 'thank', ...
# 3      ['india', 'fight', 'couid', 'nineteen', 'get',...
# 4      ['justjoke', 'couid', 'precautiondose', 'scien...
# ...                                                  ...
# 18995  ['afraid', 'infection', 'not', 'spread', 'appl...
# 18996  ['wait', 'delhi', 'gujaratis', 'tamil_nada', '...
# 18997  ['think', 'modi', 'pass', 'disbar', 'january',...
# 18998  ['first', 'consignment', 'couid', 'nineteen', ...
# 18999  ['good', 'news', 'assay', 'finally', 'couid', ...
#
# [19000 rows x 3 columns]

# %%
all_words_df['words_list'] = new_list

# %%
all_words_df.drop(columns = "words_processed_all", inplace = True)
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                               words_list
# 0      [well, surprise, speak, journalist, back, sept...
# 1                                  [fan, couid, vaccine]
# 2      [four, dose, vaccine, couid, thank, doctor, th...
# 3      [india, fight, couid, nineteen, get, strong, i...
# 4      [justjoke, couid, precautiondose, scientific, ...
# ...                                                  ...
# 18995  [afraid, infection, not, spread, apply, couid,...
# 18996  [wait, delhi, gujaratis, tamil_nada, receive, ...
# 18997  [think, modi, pass, disbar, january, dene, lik...
# 18998  [first, consignment, couid, nineteen, vaccine,...
# 18999  [good, news, assay, finally, couid, vaccine, c...
#
# [19000 rows x 3 columns]

# %%
all_words_df['words_list'][0]
# Out:
# ['well',
#  'surprise',
#  'speak',
#  'journalist',
#  'back',
#  'september',
#  'come',
#  'number',
#  'other',
#  'go',
#  'well',
#  'result',
#  'poor',
#  'pay',
#  'condition',
#  'brexit',
#  'couid',
#  'stress',
#  'vaccine',
#  'issue',
#  'diversion',
#  'though',
#  'doubt',
#  'impact']

# %%
' '.join(all_words_df['words_list'][0])
# Out:
# 'well surprise speak journalist back september come number other go well result poor pay condition brexit couid stress vaccine issue diversion though doubt impact'

# %%
new_col = []
all_lists = all_words_df['words_list']
for a_list in all_lists:
    new_text = ' '.join(a_list)
    new_col.append(new_text)

# %%
new_col
# Out:
# ['well surprise speak journalist back september come number other go well result poor pay condition brexit couid stress vaccine issue diversion though doubt impact',
#  'fan couid vaccine',
#  'four dose vaccine couid thank doctor thank development partner cassette hospital general five',
#  'india fight couid nineteen get strong india four crore young warrior fifteen seventeen age_group administer est dose couid nineteen vaccine indiafightscorona',
#  'justjoke couid precautiondose scientific confirmation evidence ord booster dose covidvaccine effective omicron couid variant modify new vaccine formulate prevent new couid variant',
#  'take third dose couid nineteen vaccine center_riya',
#  'valid point voluntarily inject vaccine lead myocarditis choose avoid surely pale possibility contracting couid risk mitigate one personal habit surely ability choose trump else',
#  'medicine pill treat couid vaccine way stimulate inner defense',
#  'couid nineteen vaccine athlete reluctant get jab',
#  'one crore people country not take single dose vaccine crore people not take second dose vaccine reminder send government also not affect vaccine coronavirusupdate coronaupdate breakingnews sonusharmajournalist news',
#  'government double engine work fast certificate get dose give get single dose vaccine couid development peak',
#  'way spread cough fever cold headache light note couid nineteen virus come vaccinesideeffect vaccine madness village spread like fire even though not deadly people experience',
#  'almost two year pandemic must know mask work save_live vaccine work not get one kill child get open less crowded_place low risk long couid exist media article not reference',
#  'take sputnik dose yet positive omicron covidvaccine indiafightscorona',
#  'covidteste covishield covidvaccine omicronvarient',
#  'marry five year two child trust live life similar isolation big difference covidteste couid covidvaccine',
#  'new india new record crore vaccine administer far india take yet another leap fight couid nineteen indiafightscorona largestvaccinedrive',
#  'wife resident dubai take couid nineteen vaccine covisheild two dose india take pfizer booster dose dubai',
#  'true cac america recommend world health_organization not object cac recommend everyone age five year old get couid nineteen vaccine help protect couid nineteen',
#  'not government alone deal sad situation society also responsibility much dedication make video could not explain dedication government society fail covidvaccine',
#  'couid nineteen vaccine',
#  'kerala become thirteenth state administer five crore couid nineteen vaccine dose',
#  'right pocket couid vaccine certificate leave pocket paracetamol caller_tune india complete one cry vac',
#  'dog faridabad commit wellbee parent student community get vaccinate stay dpsgschool wearedpsg getvaccinatedtobeprotecte vaccinatedandhappy vaccinesbringuscloser couid covidvaccine healthcare healthcareworker',
#  'swiss researcher launch trial couid nineteen patch vaccine',
#  'not sure other not think vaccine prevent couid infection transmission prevent severity may lead hospitalization bad',
#  'vaccines era datum defi make transparent public also third_wave breakthrough_infection covidvaccine still qualify vaccine drug low severity couid infection',
#  'logic people become healthy immune couid without vaccine expect',
#  'total number govt nineteen vaccine installments_paid till seven nineteen one covidvaccine largestvaccinedrive vaccineforall',
#  'detail govt nineteen vaccine installments_paid till seven nineteen one today covidvaccine largestvaccinedrive vaccineforall',
#  'well do young india fifty teen fifteen seventeen year receive first dose couid nineteen vaccine let_u practice covidappropriatebehavior defeat pandemic indiafightscorona',
#  'question would take cure vaccine prevent couid would take pill cure',
#  'alhamdulillah may allah benefit couid nineteen vaccine center_riya',
#  'convince save world make vaccine couid would already go premierleague breman',
#  'coronavirus announce miracle healing without vaccine medicine imam nasser muhammad_al yemeni',
#  'humanist gentleman invest find treatment unlike zionist invest vaccine use weapon mass destruction like couid vaccine',
#  'pleasure treat nareshchand agarras ret go ong ahmedabad_visit ahmedabad one step_dental solution_dentist orthodontist couid vaccine ahmedabad_chandkheda braces_aligne ong trend',
#  'break subject expert_committee sec central drug regulatory authority recommend upgrade status couid nineteen vaccine covishield restrict emergency_use full marketing authorisation cisco breakingnew covidvaccine',
#  'develop medical treatment couid nineteen not take vaccine confuse know world need novak antivaxxer djokovic',
#  'hybrid situation couid nineteen vaccine center al latif',
#  'first period couid vaccine drain shit much reading assignment leave brain fog',
#  'read post couid vaccine hairball thing',
#  'mega drive couid nineteen vaccine site one',
#  'blood donation require preferred couid past month vaccine last fourteen day alcohol hour diabete hypertension major surgery dental work last year woman thyroid med menstrual cycle since last seven day aster mi herbal',
#  'jammy_kashmir become twentieth state ut administer two crore couid nineteen vaccine dose',
#  'couid nineteen vaccine center_hammam',
#  'one five year since announce cares_fund make covidvaccine rti reveal confirm fund not pay single penny icer pro policy commission keep dumb ed put blinker',
#  'two year since start pandemic amp dozen effective vaccine new improved treatment still close two zero people daily die we due couid nineteen problem',
#  'till except vip citizen can not choose covidvaccine choice vaccine available vaccine make available addition covishield',
#  'true alot people argue context alot people credit wisdom proof not get couid suffer mildly people refuse look carefully realize freak vaccine save force coerce upon govt strongly',
#  'couid crash omicron increasingly act natural vaccine',
#  'dear praveen yoga congratulations_successfully administrate est dose couid nineteen vaccine rajouri sixteen one vaccination uma devi case query post vaccination contact help line coin',
#  'audio statement english assure brief news pfizer vaccine entire vaccine human physicians imam mardi_nasser mohammed al yemeni ten armada one ad',
#  'thank god certain financial loss indonesian state god willing future lot vaccine donation indonesia eyesmenke vain couid nineteen yang kedaluwarsa merupakan vain donsai',
#  'not good administer unapproved couid nineteen vaccine could unsafe',
#  'bharatbiotech healthcare_worker request ensure administer individual fifteen eighteen age_group follow report unapprove couid vaccine give fifteen eighteen year age_group coronavirusupdate coronaupdate breaking',
#  'bill_gate e microsoft software please donate accordingly net profit anti couid nineteen vaccine investment poor amp needy country world thank much bill_gates blak balkan soul invest vain two',
#  'vaccine taravatha couid china bantha severe strong undadatla anta bro vaccine cheinchukokapothe effective undo anta well get vaccinated mild untuned',
#  'mild_symptom omicronvariant still work keep charge workingfromhome booster boosterdose covidvaccine news',
#  'dahsak jumbo couid center available precaution dose vaccine senior_citizen',
#  'india pharmacy world save crore live supply medicine couid vaccine modi davos summit',
#  'even we face dearth couid vaccine medicine fate poor downtrodden country despite we wherewithal affluence',
#  'boostervaccinatie dose vaccine corona booster dose couid nineteen vaccine corona',
#  'one year corona vaccination far target first dose could not meet',
#  'couid nineteen vaccine ord dose complete srinagar jammy_kashmir',
#  'india continue make achievement pay crore govt nineteen vaccine installment far covidvaccine largestvaccinedrive vaccineforall',
#  'substance poison none not poison right dose differentiate poison remedy drug covidvaccine',
#  'jai ho sharath jai ho covidvaccine',
#  'take booster dose couid vaccine exactly one year first dose request take vaccine dose together fight chinese evil boosterjab vaccine covidvaccine',
#  'please not take omicron lightly suffer couid assure not take two dose vaccine would dead long time ago january sixteen morning catch couid still fight',
#  'please not take omicron lightly suffer couid assure not take two dose vaccine would dead long time ago january sixteen morning catch couid still fight',
#  'country war couid nineteen still go responsibility take precaution avoid virus also make people around aware wearyourmask staysail vaccine socialdistance',
#  'covidvaccine vaccinecertificate couid arrest supreme_court',
#  'look corona aur pharmacy know provide we vaccine effort since today work hard study everything couid go destroy remedy find',
#  'not go find fatal flaw math probability conspiracy sneaky math go couid killer maim vaccine respirator mask good defense not cia conspiracy',
#  'india pharmacy world save crore live supply medicine couid vaccine modi davos summit via_name app',
#  'keep couid strategic development nation ummm china china vaccine syringe effectively go immediately send one billion dose sale african kill people land area lot diamond gemstone rare land',
#  'dengue danger couid nineteen kododa vaccine dengue annum illa',
#  'masterpiece joke current relevance must read south indian punjabi gujaratis hardcore bengali reluctant take couid nineteen vaccine doctor call one one one',
#  'mammoth effort make take vaccine everyone remote area even drone use transport couid vaccine vaccine drive example new india win',
#  'modi hai pumkin_hai seva hi sangathan world large vaccine drive couid free india bop telangana senior leader mir firasath ali bari express congratulation hon_ble india shri modi',
#  'australian open without legitimacy not not allow play participant shud boycotted game solidarity truth truth vaccine amp couid fully discredit even french open must boycott djokovis not allow vaccine issue djokovic',
#  'couid along daughter wife thank god lucky bunch people infect omicron_variant take double dose vaccine ord_wave pray speedy_recovery',
#  'expect doctor doctor issue fake vaccine certificate covidvaccine',
#  'praise_god couid nineteen vaccine center_hammam',
#  'solve math covidteste covidvaccine covidvariant',
#  'take additional ord dose vaccine couid nineteen two dose get certificate believe three dose get diploma four dose degree not stop pod doctorate thank',
#  'great news tea approve russia_sputnik couid nineteen vaccine travel purpose read',
#  'dear sir request please share case ferment person already take dose vaccine still get couid',
#  'covidvaccine covidtesting',
#  'couid though not mandatory believe exist couid vaccine go lot research get approval concerned authority thus always advisable get vaccinate please not misuse word forceful negligence',
#  'faff god today get booster vaccinate stay protect couid nineteen vaccine safe effective save_live world pfizer_biotech vaccine vaccine booster authorize individual age sixteen seventeen boosterdose pfizer',
#  'bill_gate demand couid nineteen vaccine withdraw alternate universe',
#  'take ord precautionary dose covidvaccine today four hold',
#  'phenomenal achievement indeed discipline vaccination amp digital documentation unique world covidvaccine india india',
#  'government nepal seem able distribute vaccine reduce corona epidemic',
#  'thank god god willing natural medicine anti couid nineteen vaccine reduce severity disease indonesian people excite',
#  'case covidvaccine fightagainstcovid india prove global superpower',
#  'modi diligent decisive leadershiphelped allocate massive resource work enormous logistic untiring effort health care worker result administer crore dose couid vaccine',
#  'andyouknow india manufacturing five make india couid vaccine high world',
#  'one yr since first dose vaccine volunteered vaccine day many friend doc hesitant amp want set example closely follow science couid nineteen amp vaccine amp feel interest large good',
#  'know blue collar labor mumbai say fire we want not get vaccinated villager tell die become impotent due couid vaccine still live illiterate time',
#  'alhamdulillah do booster vaccine couid nineteen',
#  'interview fully worth listening vaccine efficacy rapid test treatment long couid prevalence disinformation datum availability school',
#  'dear pooja suggest spend thirty_minute couid ward drop vaccine mask mandate feel not miss life time opportunity date virus',
#  'one dose couid vaccine effective_prevente death second dose five govt datum',
#  'crore couid nineteen vaccine dose administer india far',
#  'circulate_video religious_leader tackle couid vaccine rumor modi',
#  'sunday good evening cold winter snowflake sun snowflake snowflake pass away omicron active around world hope save natural disaster hopefully take vaccine relate couid nineteen pandemic use mask maintain_social distance amp use sanitizer',
#  'success story aatmanirbhar_bharat cheap couid nineteen vaccine vaccine maker laud modi',
#  'couid vaccine crore dose administer india far',
#  'india milestone couid vaccine export establishe pharmacy world',
#  'couid nineteen india administer one crore vaccine dose one day',
#  'couid vaccine dose administer far say government',
#  'first anniversary life_save covidvaccine first center president patel minister look second well half press_conference benefit vaccine come long way since',
#  'not skeptical believe man paralyze cure take couid vaccine first one state vaccine promote muscle regeneration amp attenuate muscle atrophy',
#  'eligible group vaccine one citizen attain majority two child fifteen seventeen year age booster dose give citizen sixty year age co_morbiditie indiafightscorona boosterdose couid nineteen',
#  'sometimes wonder couid thing come maybe group people want kill people world slowly slowly use couid vaccine let_u overthink',
#  'largestvaccinedrive covidvaccine',
#  'one year couid nineteen not end outbreak omicron really happen world try sometimes overthink group people maybe want eliminate like everyone use couid vaccine kindly overthink',
#  'take additional ord dose vaccine couid nineteen two dose get certificate believe three dose get diploma four dose degree not stop pod doctorate',
#  'couid nineteen vaccine center_hammam',
#  'sixteen year_old take vaccine couid positive long wait second dose',
#  'everyone must get covidvaccine vaccine',
#  'absolutely nothing wrong podcast bet part say thing like get vaccine gey couid prove wrong knowledgeable guest take chin fan club would',
#  'make correction couid vaccine certificate chandigarh india',
#  'lot people not realize do great job couid immunization masse get vaccine free booster jab free well eligible go get please',
#  'vaccine work reduce risk serious_illness prevent hospitalization also couid case rise mask people stop wearing_mask mask help limit spread',
#  'remember modi defeat corona twentynine day march defeat corona without vaccines april india not manage beat couid nineteen crisis also help country process jan twentynine davos',
#  'country close border last two year country even make three dose vaccine couid nineteen interesting fact make vaccine country still allow student long still go close',
#  'important movement entry people yet take couid vaccine would restricted place today assay bongaigaontime',
#  'reuters news headline get correct rich nation deny man couid nineteen vaccine dose underprivileged country many near expiry',
#  'sudah ke nine fourteen hai bure want pe sarkar ki find sarkar kalahari age nazi hai yogiadityanath molto covidvaccine',
#  'tom may not know next variant new vaccine tab aware us president obama warn couid virus vaccine know pre plan activity keep eye rule mind set',
#  'come india show many get couid time serious symptom jab even young unfortunately pharma not pay hide suffer market vaccine fool like get vaccine due mandate',
#  'initiate door_door vaccination woman monday health worker district central get positive response people covidvaccine',
#  'recently take kid vaccine not couid vaccine government hospital addanki response govt hospital authority side_effect compensation kid condition critical coma',
#  'take different couid vaccine invent class',
#  'couid ka vaccine gay ravine aur para ka form nai',
#  'secondary infection go high immune_system compromise couid compromise immune_response stimulating thereby increase risk secondary infection vaccine give immune_system edge thus reduce chance secondary infection',
#  'covidvaccine eligible teen get couid nineteen shot first eleven day',
#  'someone test positive couid suffer symptom last thing want hear false positive due vaccine blah blah etc not actually couid trust insensitive people',
#  'newsreel universal vaccine adult child goal develop global vaccine couid nineteen achieve product development license bharat_biotech',
#  'not everyone icu couid would admit due couid prof bennett icu case e serious ailment also present proper study vaccine efficacy',
#  'think awareness campaign work nobody wear mask vaccinate nobody willing understand vaccine alone not eliminate chance contract couid',
#  'disappointed govt response offer advice give strandedaussie need lot onshoreaussie auspol message ask live couid yr still not home rage hotspot not word vaccine',
#  'offer advice give strandedaussie need lot onshoreaussie auspol message ask yes live couid yr nearly still not home rage hotspot not word vaccine',
#  'trend covidvaccine',
#  'salt packet bear photo paper india',
#  'couid nineteen vaccine center hoar_ash',
#  'universal vaccine adult child goal develop global vaccine couid nineteen achieve product development license bharat_biotech covidvaccine',
#  'take booster dose recently fever child fifteen eighteen take covidvaccine recently fever boosterdose vaccination boosterjab covidvariant',
#  'universal vaccine adult child goal develop global vaccine couid nineteen achieve product development license bharat_biotech',
#  'mask vaccine mandate europe start consider couid nineteen flu ask people live vaccination omicron flu',
#  'universal vaccine adult child goal develop global vaccine couid nineteen achieve product development license coronavirus',
#  'implant placement do today ahmedabad help get well support tooth help chew well visit we one step_dental solution_dentist orthodontist ahmedabad_chandkheda braces_aligne implant couid vaccine',
#  'next ten year never do vaccine poor country couid nineteen live people save planet pollution climate_change',
#  'everyone world get couid nineteen omicron whether vaccinated boost vaccinated omicron like live attenuate vaccine',
#  'couid vaccine ke dose lo sec advice not put amp safety risk always wear_mask go house always maintain proper social_distancing measure amp keep proper hand hygiene assure amp family safety time pandemic',
#  'administration deal strictly disobey rule love protocol vaccination strong protective shield prevent spread corona infection covidvaccine',
#  'telangana become twelfth state administer five crore couid nineteen vaccine dose',
#  'example couid myocarditis could label simple mi yes intrinsic ability fight individual vaccine promote factor fight also every wave may different case load know case load',
#  'free vaccination eye saudiarabia covidvaccine',
#  'booster dose do take early complete nine month since second dose covidvaccine boosterjab boosterdose boosted covishield',
#  'couid vaccine ord dose',
#  'man die two week pfizer couid vaccine injection suffer myocarditis vaccine',
#  'headline news around world item japan not discriminate vaccine hesitant put myocarditis couid van label list serious side_effect',
#  'think hospital specialize doctor bad luck tweet wrong entity u please help person rheumatoidarthritis take couid vaccine',
#  'china provide one million couid nineteen vaccine dose myanmar hong kongers opt sinovac couid nineteen vaccine one sinopharm sinovac vaccine prevent severe hospitalization omicron report view_article',
#  'couid nineteen vaccine est do complete alhamdulillah',
#  'covidvaccine not citizen allow choice vaccine suppose person give two dose covishield take booster covishield booster equally effective omicron variant',
#  'total number govt nineteen vaccine installments_paid till seven twelve one far covidvaccine largestvaccinedrive vaccineforall',
#  'detail nineteen vaccine installments_paid till twelve one today one day till seven covidvaccine largestvaccinedrive vaccineforall',
#  'call receive ask take two dose couid vaccine fraudster convince register ord dose top come phone share enable fraudster siphon money account remember top rakshakavach',
#  'watch two wave frightening news death hyderabad witness every fifteen min one ambulance line blackmarketing med ray development due anti couid vaccine omicron',
#  'hopefully future booster sell import couid nineteen vaccine quite burn family_member four',
#  'get booster shot sinovac couid nineteen vaccine today triple jabbed',
#  'child fifteen eighteen age_group wait turn first couid vaccine shoot center near jama old quarter wednesday january twelve covidvaccine vaccine jamamasjid',
#  'become immune second time thank god couid nineteen vaccine center hoar_ash',
#  'mask vaccine mandate europe start consider couid nineteen flu ask people live close hindu temple pongal hurt many badly hope god teach lesson declare automatically vested interest',
#  'lucknow report maximum case last_twentyfour hour active case total couid case thirteen amp total active case maskupindia markup covidvaccine',
#  'vaccine may need update well protection couid nineteen variant include omicron say',
#  'conventional ceramic crown ready get fit inside mouth ahmedabad_visit we one step_dental solution_dentist orthodontist braces_aligne couid vaccine trend india ahmedabad_chandkheda implant crown',
#  'parent vaccinate kolkata india father get cancer within less six_month symptom not side_effect vaccine get couid positive going',
#  'message precaution dose couid nineteen vaccine',
#  'two vaxicron carrier feel vaccine human race find reason sun convince other not get vaccinated carrier dangerous lead spread physical couid virus covidvariant',
#  'site precautionary dose couid nineteen vaccine town',
#  'person chronic rheumatoid arthritis take couid vaccine not please let know rheumatoidarthritis covidvaccine',
#  'coin vaccine takevaccien covidvaccine',
#  'around one five individual age sixty not take dose covidvaccine people sixty estimate thirteen number twelve twentyfive take vaccine ok_paul member health nit_mayor coronaupdate',
#  'suggestion invent couid nineteen vaccine act slow release vape cigarette sure smoke excuse not halal',
#  'india continue make achievement pay crore govt nineteen vaccine installment far covidvaccine largestvaccinedrive vaccineforall',
#  'difference infection disease must understand even vaccine give infection transmit incidence chronic disease low treatment determined severity symptom couid',
#  'visit goa urgently day official work two dose vaccine complete couid test mandatory return',
#  'indiafightscorona covidvaccine',
#  'covidvaccine gocoronago iam fifteen years_old iam say happily iam vaccinated thank modi free vaccination drive go corona go corona go go stay away country indiaindia',
#  'get covishield booster dose short three nine month get vaccine boosterdose covishield covidvaccine two fu amp instagram',
#  'delhicovid stats delhi india coronaupdate coronavirus covidvariant note low fatality seem covidvaccine help',
#  'good couid positive mom take dose vaccine',
#  'usa record around one three million case today busy report senseless story india first check burn backyard lecture india covidvaccine',
#  'mask well good mask build american not standard filter droplet fitting accurate corona markup covidvaccine covidisairborne',
#  'high strength even high accuracy precision zirconia crown visit we ahmedabad one step_dental solution_dentist orthodontist couid vaccine ahmedabad india zirconia trend braces_aligned',
#  'lakshadweep ut three child age_group fifteen eighteen_years spread across ten inhabited island complete vaccinate est dose eligible child est territory state lakshadweep covidvaccine',
#  'strickly_follow sop couid nineteen take vaccine time amp save_life',
#  'new corona case jammy corona case confirm jammy_kashmir within twentyfour_hour covidvaccine coronavirusupdate coronaviruspandemic',
#  'inner india begin new vaccine phase couid nineteen fight precautionary dose frontline health worker prepare inoculate woman dose covishield ok_paul head india couid nineteen task_force say',
#  'good news amid spurt couid case omicron vaccine expect ready march not',
#  'new video like comment share covidvaccine trading',
#  'couid vaccine effective watch find',
#  'today amp admit bahadurpura mla take precaution booster dose couid vaccine area hospital nasally request eligible person immediately take booster vaccine amp save amp family new variant coronavirus',
#  'turn seventeen years_old come know damon madly_grade child fifteen eighteen vaccinate kindly tell register online center near covidvaccine covidcenter',
#  'die couid jan five nine delhi vaccinated vaccine prevent death get shoot',
#  'omicronvariant covidvaccine many change last two year constant',
#  'covidvariant protect orr family wash hand properly get authorize couid nineteen vaccine help protect couid nineteen avoid crowd poorly ventilated space monitor health daily',
#  'couid happen even take vaccine test confuse',
#  'india continue make achievement pay crore govt nineteen vaccine installment far covidvaccine largestvaccinedrive vaccineforall',
#  'number govt nineteen vaccine installments_paid india till eight today eleven one covidvaccine largestvaccinedrive vaccineforall',
#  'markup covidvaccine stanhope',
#  'confidence level take ord dose couid vaccine',
#  'tiki talk paro lago wa die java mark many vela vaccineswork vaccinated vaccination covidvaccine nathdwara jaipur rajasthan bharat mead mead',
#  'booster dose take syringe covidvaccine',
#  'can not move anus kumar dey years_old cerebral palsy dose couid nineteen schedule last jun amp could not take vaccine could not walk want help',
#  'covidvaccine fightagainstcoronavirus',
#  'humanity still scare communist want talk real trust evidence quit group aunt uncle understand couid vaccine cheat lie thousand kid sick go china china vaccine vietnam vietnam china cheat vietnam',
#  'happiness return noise sorrow careful period examination covidvaccine coronaguideline coronabhagao',
#  'pretty sure sarang clinic not one fake vaccine cert apparently sell imagine many anti_baxter van rate genuine wonder struggle badly couid',
#  'certificate vaccination require everywhere present save number mobile get certificate open whatsapp type certificate immediately receive certificate couid vaccinated covidvaccine',
#  'couid nineteen vaccine booster',
#  'good fight fight not take vaccine fight couid not see happen last two year someone popular doko not take vaccine not spare thought poor hospitality suffer due lockdown',
#  'small suggestion courage not take couid vaccine almost crore already passed_away one tennis moral responsibility encourage_other know do grave mistake not take vaccine god save well',
#  'modern man accept science whole world fight battle together kind society live shall people need vaccine support overcome couid stop spread disease get vaccine',
#  'not believe speculation amp myth lot case post booster pfizer couid vaccine myalgias fever colleague face reason behind not know shit real still look answer boosterdose',
#  'detail nineteen vaccine installments_paid till ten ten one today covidvaccine largestvaccinedrive vaccineforall',
#  'first day inside couid ward lot less severe last wave reassure see vaccine work vaccinate admit question science word',
#  'highly accurate crown place ahmedabad_visit we one step_dental solution_dentist orthodontist ahmedabad gujaratis couid vaccine braces_aligne implant zirconia',
#  'bill_gate billionaire microsoft co founder demand withdrawal couid nineteen vaccine market harm good according',
#  'alarm strongly believe interested take booster shot allow irrespective pre medic condition age govt not put boundary get ord jab booster covidvaccine booster',
#  'get vaccinated prevent spread couid nineteen covidvaccine covidvariant',
#  'call number give get thata patti appa booster dose covidvaccine boosterdose call log website get help get loved_one vaccinate acc',
#  'breakingnew amidst rise case city report one death surgeon aryan covidindia boosterdose give today covidvaccine covidteste',
#  'pass covidvaccine',
#  'view increase infection couid nineteen take fast dose vaccine also take vaccine follow couid nineteen compliant practice every day time inspire other stay_safe couid',
#  'vaccine booster do india incidence couid nineteen variant omicron increase day day government make arrangement provide booster dose already vaccinate twice booster dose help control spread virus',
#  'pminauguratescancercenter eleven crore dose couid vaccine provide free cost west_bengal government ventilator new oxygen_cylinders also give state psa new oxygen_plant also start fun',
#  'covidvaccine boosterjab boosterdose covidbooster',
#  'depend couid vaccine booster friend harry week flabby',
#  'another big day world largestvaccinedrive india begin administer precautionary booster dose couid nineteen vaccine healthcare frontline_worker amp senior_citizen co_morbiditie book_appointment today indiafightscorona',
#  'novak djokovic win court battle australia australia federal court overturn australian government move cancel novak djokovic visa follow couid nineteen vaccine status read novakdjokovic follow short news sixty word',
#  'strict violation couid guideline give booster dose senior_citizen one police bac assist people register online face problem take vaccine simply mismanagement',
#  'fake couid vaccine',
#  'doctor get booster also senior_citizen get booster covidvaccine covidbooster',
#  'opening ceremony precaution dose couid vaccine inaugurate honorable sir try kamp ten one',
#  'ask stand equal fair couid vaccine distribution around world',
#  'today frontline_worker include healthy personnel police give pre prescription dose vaccine fight corona frontline_worker include police personal get precautionary couid nineteen vaccine dose phi jaipur',
#  'couid vaccine precaution dose thank government india covidvaccine',
#  'couid nineteen fresh spike health department start administer booster vaccine dose frontline_worker',
#  'booster est go get shield covidvaccine boostershot supercarehospital shilling meghalaya',
#  'pa adolescent aged fifteen eighteen_years administer first dose couid vaccine within seven day pro',
#  'wrong day layering boost covidbooster covidvaccine',
#  'hon_ble chief_minister tamil_nada covidvaccine',
#  'telangana launch drive precautiondose covidvaccine healthcare_worker amp senior_citizen co_morbiditie join citizen hyderabad govt unni hospital charming fresh drive begin turn get vaccinate',
#  'today launch precautionary dose vaccine health care frontline_worker citizen comorbiditie aged sixty year amid rise couid nineteen case across state one three largestvaccinedrive',
#  'seamless process get first precautionarydose booster dose parent chennai thank arrangement coin covidvaccine',
#  'precautionary booster dose couid warrior health care professional experience smooth india true capital record mobile hassle vaccine give date place batch past detail log coin cert add passport easy',
#  'syringephizer booster jab boost three needle already please not bad tonight tomorrow boosterjab covidvaccine',
#  'boot say get couid vaccine hand hurt can not move bestie lemme tell wannabe ruin shoulder move watch pain meet jap building skull tell experience get covaxinindia boosterjab',
#  'couid vaccine two crore teen fifteen eighteen age_group vaccinate first dose',
#  'india begin administer couid nineteen vaccine precautiondose healthcare_worker frontline_workers people aged sixty comorbiditie today gujaratis vaccine',
#  'delhi begin administer couid nineteen vaccine precautionary dose frontline_workers amp senior_citizen sixty yr age co_morbiditie',
#  'arm epi vaccine use increase couid epithelium child',
#  'simian take kenangan axis quarantine ad ironman law polar testimony sinovac vaccine without booster weak couid nineteen mom ne bukan pregnant symptom dead flu baton hang aeria rasa amp bau',
#  'need vaccine die china make need fake degree chemical need true alive couid doctor couid vaccine china kill humanity true medium delete post victim',
#  'couid vaccine two crore teen fifteen eighteen age_group vaccinate first dose via_name app',
#  'india begin administer couid nineteen vaccine precaution dose sixty age_group healthcare frontline_worker today',
#  'present india brand ambassador couid vaccine amp walk live proof vaccination truly safe else bihar someone cheat get additional nine mark mean dose',
#  'vaccine medicine scare couid eradication like hold election new corona wave newtonendra modi',
#  'consultant rheumatologist work people high_risk infection due immune system suppress take three dose couid vaccine protect patient getvaccinatednow vaccineswork',
#  'bihar man book take twelve dose couid nineteen vaccine',
#  'tac become part dirty game crony capitalist coterie depopulate world thru virus mask amp vaccine couid fear psychosis create dirty game play omicron nothing common_cold open school let child live kill',
#  'brahamdev manual award must declare brand ambassador vaccination country people vested interest run campaign covidvaccine year_old establish vaccine safe good health',
#  'precautiondose covidvaccine ut chandigarh tomorrow ten one sixty year plus person precaucionvial dose give preference person est dose adult vaccination center ut chandigarh',
#  'modi call adequate health infrastructure district boost couid vaccine drive adolescent mission mode pro',
#  'instead actively campaign vaccine people do responsible thing play part government fight couid get vaccinated',
#  'medical infra already thinly spread compare population loose doc avoidable couid illness like massive double whammy last time delay import vaccine time delay offer booster dose',
#  'bharat_mata ki jai couid vaccine two crore teen fifteen eighteen age_group vaccinate first dose via_name app',
#  'eligible precaution ord dose couid vaccine check list',
#  'full lockdown need tamilnadu covidvaccine corona coronavirus coronaupdate stalin',
#  'couid vaccine two crore teen fifteen eighteen age_group vaccinate first dose via_name app',
#  'virus deadly virus call couid not exist scam omicron microvirus omicronindia omicronvariant omicron coronavirus llorona sars covidvaccine covidiot',
#  'get est dose couid nineteen vaccine covishield turn vaccinated',
#  'bihar fir octogenarian take twelve dose couid vaccine',
#  'couid nineteen vaccine ith needle sinovac sinovac pfizer modern modern nakornthon hospital',
#  'solution lockdown central state_government eradicate corona couid couid nineteen vaccine make eradicate itching',
#  'protest pfizer covidvaccine still pop viagra make pfizer make hypocrite happy new year',
#  'anything rather take actual couid vaccine know completely free safe effective vaccine literally save countless life tell we take pill accidentally amp survive please',
#  'congratulation young india india achieve yet another_milestone administer two crore couid nineteen vaccine dose age_group fifteen seventeen paul',
#  'highly accurate precise zirconia crown ready rock roll inside mouth ahmedabad_visit we one step_dental solution_dentist orthodontist couid vaccine ahmedabad ahmedabad trend braces_aligned implant zirconia',
#  'couid vaccine children twenty million child age_group fifteen eighteen receive first dose whether child get not childrenvaccination',
#  'go symptom not need hospitalization vaccinate couid appropriate_behavior prevent couid infection vaccine save_life get couid',
#  'report case nepal couid community level already symptom please test isolate happen travel please cautious not vaccine please asap thirdwave couid',
#  'scientific agency need put science political compulsion let_u not mess anymore vaccine not anti couid medicine mask not vaccine substitute',
#  'ord dose hah couid nineteen vaccine center al_mubarak',
#  'get do est dose covidvaccine',
#  'precautionary dose couid nineteen vaccine session site',
#  'great congratulation appreciate contribute wonderful milestone not able efficiently ensure good number indian company develop right drug vaccine protect people attack couid family one brand four child',
#  'sabia saith sabia visas sabia visas one addition slogan sabia pray india achieve crore vaccination congratulation india amp thank hon indiafightscorona covidvaccine',
#  'jury efficacy lack vaccine probably meaningless debate thing guarantee protection stay masked amp practice couid safety protocol also agree booster see ongoing need cap pricing',
#  'crore youngster age fifteen eighteen_years receive est dose couid nineteen vaccine less week india fight pandemic double enthusiasm amp energy proactive measure govt active participation frontline_worker',
#  'vaccine equity mind today everyday even misinformation surround result antivaxx two opposite side pandemic two vulnerable side one choice another result injustice vaccineequity antivaxx couid',
#  'sake saith sake visa pminauguratescancercenter eleven crore dose couid vaccine provide free cost west_bengal government ventilator new oxygen_cylinders also give state',
#  'important avoid third_wave couid take care follow couid appropriate_behavior eligible difficult get vaccine everyone face together stay_safe keep other safe staysafestayhealthy',
#  'well not work tell not get formula right vaccine people still get couid',
#  'important another proof vaccine work couid patient need bed mumbai vaccinate not take even single dose vaccine datum',
#  'look first couid vaccine avoid get throw housing society novaccinemandate',
#  'congratulation india crore vaccine dose administer together india defeat couid nineteen largestvaccinedrive',
#  'british opinion live couid relevant virus may not go wash away we near future hurriedly prepare vaccine also become mostly ineffective goat earmark special fund unravel effective vaccine anti couid permanently erase',
#  'dose effective symptomatic reinfectionsin health worker aim study vaccine',
#  'good shot offhand covidiot covidvaccine nojabnowork',
#  'say take vaccine still get couid like say carry umbrella still get drench imagine would without umbrella getvaccinatednow omicron',
#  'high strength computer make zirconia crown ahmedabad_visit we one step_dental solution_dentist orthodontist chandkheda ahmedabad braces_aligned zirconia implant couid vaccine trend',
#  'india achieve historical feat administer one five billion couid vaccine dose today modi',
#  'pminauguratescancercenter eleven crore dose couid vaccine provide free cost west_bengal government ventilator new oxygen_cylinders also give state ipsa new oxygen_plant also start',
#  'proud_moment india administer crore vaccine less year let continue fight amp encourage_other get vaccinated follow couid appropriate_behavior indiafightscorona largestvaccinedrive',
#  'couid vaccine student administer today presence parent',
#  'another_milestone crore couid nineteen vaccine dose administer less year let_us follow couid appropriate behavior strengthen fight corona paul',
#  'covidvaccine',
#  'covidvaccine doctor',
#  'still go take year find one vaccine tackle couid whole flu jab not make year take alto advancement tech think shall get soon think',
#  'crore covidvaccine dose administer india coin',
#  'bop couid vaccine indian',
#  'proud_moment india india administer crore vaccine less year let continue fight amp encourage_other get vaccinated follow couid appropriate_behavior indiafightscorona largestvaccinedrive',
#  'german international footballer joseph gimmick say catch couid damage lung regret not take vaccine',
#  'thank boss crown theme couid vaccine brand',
#  'meanwhile year_old poster boy uncle poster grandpa couid vaccine fine hope stay strong comment side unique radar coin app etc etc',
#  'weird doc noisy couid vaccine amid time flu shot get every end year vaccine',
#  'first dose complete couid vaccine',
#  'police know category really stupid la police must not believe couid vaccine also want talk scam fool next time perm please hire wise police ye',
#  'hero survey result seventy india already affect couid nineteen wave two still proper datum prove natural_immunity vaccine induce immunity reduce omicron severity',
#  'name enter guinnessworldrecord administrate number couid vaccine livinglegend',
#  'forty lakh child get couid nineteen vaccine first day parent say big relief via_name app',
#  'get pfizer couid nineteen vaccine booster shot get pfizer west sport building two bangkok thai japanese youth center din dang',
#  'already know world heh tank vaccine juga not want couid not want people especially family follow anything long not get hit maybe everyone else thought smart think',
#  'couid exist someone want go overseas two three week go must someone get vaccine near clinic amid vaccine sub worried place want go disease also know forgot name vaccine',
#  'instead not able go ummah je vaccine prevent couid infection vaccine free afford pay thousand not want vaccine go ummah come back disease jon kau ken couid crap jian kulak ea padawan dirt send selfish',
#  'couid nineteen vaccine center hoar_ash',
#  'right couid microvirus staysail vaccine vaccinessavelive',
#  'addition paper datum component vaccine available blank',
#  'highly accurate computer make crown ready ahmedabad_visit we one step_dental solution_dentist orthodontist couid vaccine ahmedabad braces_aligne implant chandkheda',
#  'couid complete last sem exam come ith sem sem year already complete top rank kill many people sem fail top ranker vaccine come covidvariant omicron vaccine',
#  'inner couid vaccine not trigger pre term birth accord large cac study conduct study researcher look record woman across eight healthcare organization expect give birth view',
#  'give eleven dose couid vaccine',
#  'ap forefront state rapidly vaccinate young people age fifteen eighteen vaccine covidvaccine',
#  'brahamdev give title appoint brand ambassador india',
#  'yet take booster srilankaarmy incredible job vicar maha devi park registration jab ten min schedule get jab take vaccine card head getvaccinate',
#  'vaccine safe coronavirus omicron',
#  'seconddose vaccine indiafightscorona indiafightscorona testing',
#  'ord dosesyringe couid nineteen vaccine center al_hoar',
#  'look forward next quad leader meet year drive forward coordinated response couid vaccine say australia japan joint statement scott kishida virtual summit',
#  'need constantly high antibody_level prevent infection thus also prevent long couid way keep antibody_level constantly high three monthly dose monthly dose variant specific vaccine',
#  'new record couid nineteen vaccine',
#  'doctor booster shot third dose additional dose couid nineteen vaccine need know shut fuck want',
#  'disruption vaccine certificate verification crowd jam outside certificate verification outside mamlatdar office messala applicant security personnel see without mask vaccine memsaab',
#  'today couid nineteen vaccine two dose complete chi dewar dewar',
#  'hope side_effect couid vaccine booster mild none',
#  'iran feel like separate universe everything payment system visa mastercard everybody pay credit card car size even several couid vaccine hell even calendar',
#  'ar ese kyo kite ho couid time vaccine se kama cha lo bacchae ko dra',
#  'hindu muslim fight start near anger near hannah ko bane de ta lanai hot nazi secr job ki beat main job rate well modi ke time main couid maya hai vest alone vaccine li',
#  'eleven dose far couid induce anxiety disorder pal taking vaccine like energy pill sick minded fellow',
#  'get third pfizer booster jab eligible get couid nineteen vaccine stay_safe keep safe getvaccienate',
#  'jealousy among human always crush humanity man make couid nineteen converted variants human mutation start access animal like dear report state usa new variant mean new vaccine sound like scientist control global economy',
#  'ayushmanbharathwc amleshwar vaccine drive fifteen eighteen year school child get vaccine fight couid nineteen',
#  'go get booster jab couid vaccine today',
#  'vaccine authorize december use india may help solve one vexing problem global public health supply low income country couid nineteen vaccine safe effective affordable',
#  'two dose couid nineteen vaccine must employee work industry factory industry',
#  'ever wonder still two yr since start pandemic amp dozen effective vaccine struggle omicron hard find epidemiologist publichealth professional direct advise couid control anywhere drive',
#  'public not wearing_mask police also not work properly challah person sometimes also not wearing_mask check second dose couid vaccine take pocket not challah',
#  'let_us not believe sensational news page financial website not good source vaccine information trust science saves_live vaccinessavelive covidvaccine',
#  'another couid nineteen vaccine corbevax potential booster shoot future',
#  'fortunate treat devendra singh general manager ong chem gentle cheer person time appreciate charisma visit one step_dental solution_dentist orthodontist couid vaccine india ahmedabad braces_aligned',
#  'thankyou start couid vaccine center ward',
#  'couid action first dose covidvaccine nce',
#  'couid nineteen first dose complete syringe map log jo fifteen se eighteen sall ke ho vaccine jar lagga le',
#  'ply stay_safe dna ignore omicron say mild hai vaccine ki sarah kam area not black case expect per day wid speed medtwitter mend',
#  'precautionary dose couid vaccine healthcare frontline_worker sixty comorbiditie first two dose govt',
#  'forty lakh child get couid nineteen vaccine first day parent say big relief',
#  'hong_kong vaccine bubble roll restaurant leisure venue school hong_kong plan bar not vaccinate couid nineteen restaurant leisure venue school postpone view',
#  'wonderful people covidvaccine take manual take vaccine twelve time',
#  'gay brain paan mein money couid vaccine',
#  'fifteen eighteen year age_group eligible receive couid vaccine request get vaccinate safe couid vaccine available fifteen eighteen_years age_group surya nagar government hospital mallapur',
#  'biotech gets_nod conduct phase three booster dose intranasal couid vaccine',
#  'india not even fully face ord_wave omicron france already get case new variant pi seem virulent amp vaccine resistant couid not go anywhere amp learn live',
#  'bharat_biotech gets_nod conduct phase three amp booster trial intranasal couid nineteen vaccine',
#  'bharat_biotech gets_nod conduct phase three booster dose trial intranasal couid nineteen vaccine',
#  'india back chart new case new death twentyfour_hour let not fall trap omicron mild flu work like vaccine true color still unfold',
#  'thank informative view unbiased comparative research study various couid vaccine bring pro con efficacy vaccine may help people make informed choice future',
#  'see number death couid vaccine fine vaccine',
#  'year world large vaccine drive crore couid vaccine dose administer make india vaccine ninety first dose coverage fully vaccinate',
#  'two year state pandemic not improve go bad even though we moneybag good brain pie couid vaccine hospital amp one million case day zero death usa must not feel shameful seek help aim end pandemic amp save',
#  'couid nineteen vaccine information child india register effective vaccine give child',
#  'couid nineteen vaccine information child india',
#  'basic math number op hav vaccine administer one year way less couid vaccine administer billion dose',
#  'transfer online education sir employee gathering less fifty capacity anywhere even bus train fifty capacity everyone follow couid app behave also pfizer sputnik vaccine available country child vaccination',
# ...
#  'couid vaccine first dose sixteen july ko tha chi se mera first dose kiss wrong number register ho_gay hai mai karnataka state hun much second dose lene mein baht pareshani ho hai help thank',
#  'high time save maharashtrian mumbai dread omicron_variant couid nineteen hence essential time gap day vaccine dose covishield reduce thirty day',
#  'time booster shoot covidvaccine omicronindia medtwitter medicine',
#  'know china kill human couid virus microbe vaccine syringe sit ask charge pressure',
#  'point year half everyone around world understand travel restriction lockdown not solution couid get vaccine cautious lockdown around world destroy live billion people',
#  'game kill human couid vaccine china china stop shoot one nation go map save nation not die like rex angry',
#  'get second dose couid nineteen vaccine hand today',
#  'himachal_grade become first state fully vaccinate adult_population country covidvaccine',
#  'body loose function easy inflection couid people not jet take vaccine happen quickly one night',
#  'seem vietnam vietnam bring army go ho chi minh couid carry barbed wire gun bring medicine food extra expire vaccine syringe like expire visa',
#  'couid vaccine administer today touch one crore dose long gap still fifteen eligible population not administer even first dose worry require cross check people intentionally stay away vaccine',
#  'find high pay freelance copywrite job bandh survey dhathuru nukurevey gory heyhey not find look ask kawaku vaccine ahi f vaccine nudhevey',
#  'job bengal couid vaccine jab pakistan difficult find',
#  'case omicron travel people form country government allow travel fully vaccinated person role vaccine couid nineteen pmoindia',
#  'difficulty face sonapurcircle officer convince people vaccinate able vaccinate many people covidvaccine waragainstcovid',
#  'first datum analysis omicron',
#  'live telecast program hold aims bilaspur december show lead screen five place sirmaur covidvaccine vaccineswork ledscreen livestream',
#  'couid coronavirus covidvaccine',
#  'shot never fun kid meet kimball elementary know important couid nineteen vaccine keep family community safe check make save information vaccine make appointment',
#  'vaccine certificate make compulsory mall make sure carry couid vaccine certification go covidvaccine',
#  'omicron omicronvarient omicronawarness vaccination covidvaccine chennai schoolstudent',
#  'today camp love nineteen vaccination organize ward not vaccinate please vaccinate camp go outta bas school ten morning biker covidvaccine',
#  'goi plan make vaccination mandatory india union home minister say make van mandatory would lead dispute covidvaccine',
#  'feet five time day also go come home please give we guarantee take two vaccine three vaccine chance couid omicron give we write law body',
#  'omicron transmissible variant omicronvarient omicroninindia covidvaccine',
#  'india india consider covidvaccine booster shot immunocompromise patient omicroninindia',
#  'ith december vaccination maha order make vaccination campaign successful bella panchayat panchayat resident must get vaccination do location harper maheshpur time ten covidvaccine',
#  'vaccine inequity prolong pandemic raise_voice raise concern even light feather mount together sink ship together_let we fight win how s can not go another round couid build back well',
#  'vaccine couid visit like two person yesterday vietnam understand treatment te well',
#  'victim vaccine couid',
#  'slooooooooooomo covidvaccine omicron stayhomestaysafe',
#  'return back home next_week abroad next friday allow go couid booster vaccine two day self isolation',
#  'omicron covidvaccine get vaccinate already',
#  'die couid china china die vaccine couid china devil communist essence communist change face',
#  'die much china vaccine couid communist government extra one thing agreement maybe heart_attack brainbrain attack terrible say two take shoot not virus microbe frozen boldface china china vaccine man vaccine',
#  'miramar camp nod scan hwa mahobatpara porbandar covidvaccine nod',
#  'booster dose couid vaccine safe increase immunity show study lancet oxford_astrazeneca pfizer_biotech novavax jansen modern valera curebat vaccine covishield',
#  'link apply mobile friendly application launch revenue department state gujaratis help heir person die couid nineteen home url gujaratis covidvariant omicronvarient covidvaccine',
#  'day twenty everyday twitter someone explain need keep use mask stage virus not stop virus expert say virus mutate stay we along time mask thirty year omicronvarient covidvaccine fer science',
#  'inner million frontline couid worker demand india boost forty salary woman frontline india vaccine drive demand hike paltry salary call accredit social health activist asha hindi word view_article',
#  'corona new variant come please take care safe rho yr pray god country india coronavirus corona vaccine jour lga le ap maid rhe ki ap safe hai jai_hind india covidvaccine',
#  'ac secretariat conduct price checking monitor status couid nineteen vaccine check unauthorized use polythene bag overall hygiene fruit vegetable restaurant general store etc violator fine warn per law gala',
#  'corona vaccination permit crowded_place madurai certificate district collector anish sugar order covidvaccine omicronvarient',
#  'always go area hang look forward ginny cara faraway berkempen masa covidvaccine sarawakelection sarawakdecide sarawaktok',
#  'public debate amp discussion malaysia even element longcovid brain problem find one hospitalize couid nineteen patient real world datum show modern vaccine highly_effective reuter',
#  'vaccination campaign go full swing assay har gear datak vaccination campaign health worker give vaccine people door_door campaign run till december five state photo bongaigaon district covidvaccine harghardastak coronavirus',
#  'india administer crore vaccine strengthen fight couid get vaccinated contribute nation fight pandemic indiafightscorona',
#  'couid vaccine center sec fourteen dark near metro station',
#  'family ke like iso shirt two couid vaccine hai',
#  'complement vaccine know mean mean say receive another vaccine brand couid complement pfizer vaccine friend get couid free maybe stick bahasa minister say',
#  'covidvaccine late observe many delivery associate partially vaccinate first van tomato ensure fully vaccinate',
#  'right couid nineteen variant end collective effort main streamline block beneficiary vaccine manufacturer not charity program benefit keep distribute free world',
#  'spread word like share comment subscribe bell support hem omicron world new update couid vaccine effect lockdown india via',
#  'shot never fun kid meet kimball elementary know important couid nineteen vaccine keep family amp community safe',
#  'couid vaccine dose complete today layaway',
#  'establishment hire two people must consolidate covidvaccine certificate staff keep ready verification also display vaccinated subsequent vaccination',
#  'right wakeup planet well wakeup heaven shall much people die immediately couid vaccine case heart_attack brain brain attack ten milion citizen city red warn emergency',
#  'india achieve yet another historic landmark fight vaccine strong weapon couid nineteen strengthen fight get vaccinated indiafightscorona largestvaccinedrive',
#  'virus evolve moment know genetic sequence often two month old point need understand corona go atleast three yr couid appropriate_behavior amp vaccine save name strain change not protective strategy',
#  'congratulation achieve another_milestone administer crore couid vaccine dose india within short time hat vaccine manufacturer doctors_nurse health care worker achievement',
#  'well safe sorry follow strictly omicronvarient covidisairborne omicron universe covidvaccine covidvariant',
#  'corona new variant omicron risk omicron confirm india covidvaccine',
#  'strengthen fight india administer crore vaccine get vaccinated contribute country fight pandemic indiafightscorona india administer crore vaccine strengthen fight couid',
#  'proud_moment friend talk fearlessly couid parliament today covidvaccine omicronvarient',
#  'omicronvarient ready waste also human please god let good one china world still alive vaccinate omicronvarient newvariant covidvaccine indian bigbreaking',
#  'let_us get vaccinated let_u put mask let_us corona country rather recurrence testament patriotism let get second dose vaccine keep mask keep couid control cost nothing covidvacccination',
#  'abba day sleep minister congress ysjaganwithfloodvictim syrup tdptwitter visakhaptnam covidvaccine covidbooster',
#  'country ruin hack software hack people use day co part house money mansi',
#  'life get reduce ten year take two dose vaccine plus many side_effect not know medical_fraternity part not much vaccinate still not much spread couid',
#  'forefront vaccination five crore people get dose covidvaccine',
#  'government far spend billion import type couid nineteen vaccine adaderana la_srilanka',
#  'day india india couid vaccine administer',
#  'congratulation india another moment pride indians covidvaccine couid',
#  'four year ago export cover forty import bill go meager take couid vaccine arrive',
#  'wear_mask prevent omicronvariant also prevent people worldaidsday coronavirus covidvaccine covidvariant omicronvariant mask maskupindia wearamask hakimabanooali',
#  'large vaccine campaign world deliver crore vaccine largestvaccinationdrive covidvaccine indiafightscorona',
#  'electricity employee not pay two installment vaccine dec seven december pay suspend covidvaccine',
#  'status booster shoot india covidvaccine vaccination',
#  'repeat know healthy people like perish couid foolish think immune safe protect regardless vaccine one neighbor die vaccine',
#  'record vaccination india soon vaccine dose figure cross crore break coronavirus covidvaccine',
#  'couid nineteen vaccine probably still protect severe disease people infect omicron_variant biotech se ceo uour satin say freak plan remain speed administration third booster shot say',
#  'covidvaccine sometimes wonder use get fully vaccinate status remain vaccination happen idea vaccinepassport seamless travel without need roper quarantine etc vaccination travel',
#  'hope not wait modus next birthday sep get booster dose couid vaccine',
#  'travel fully vaccinated traveler ask take roper test not covidpassport issue person take two dose covidvaccine',
#  'couid virus demand strong vaccine',
#  'serum_institute india sit manufacturer couid nineteen vaccine covishield november resume export low middle_income country framework news omicron covidvariant airportgoodbye sit adarpoonawalla omicron breakingnews',
#  'serum_institute india send dose couid nineteen vaccine indonesia first export novavax shoot network indian government say wednesday seruminstitute adarpoonawalla vaccinemandate vaccinated news breakingnew',
#  'break warn toxic global level low couid vaccine coverage testing rate',
#  'couid nineteen omicron case mild evidence suggest vaccine may less effective variant say official',
#  'couid nineteen omicron case mild evidence suggest vaccine may less effective variant say official',
#  'class one two associate side_effects couid vaccine effect size not large',
#  'many many month research discussion family friend finally get first dose couid nineteen vaccine yesterday new variant emerge protect loved_one consider get vaccine already',
#  'people reluctant take couid vaccine sorghum borgia nayapar utter frangipani amp chenimara village hard reach area nagareru epic motivated team one twelve twentynine kamp',
#  'seorang anthrax call husband talk couid vaccine amp lockdown',
#  'couid nineteen vaccine ashram vaccine name venice shag molly',
#  'word enough thank son receive couid vaccine pfizer use covidvaccine',
#  'couid tracking entrez app suck can not get work try ten time keep get stop transportation amp enter games show vaccine card speak police past day ever arabcup fifarabcup',
#  'hon_ble cheif minster sir consider head new variant couid nineteen well non_availability child vaccine parent request please review school opening schedule',
#  'ounce prevention worth pound cure let extra careful regard aids aids couid dentist vaccine doctor ahmedabad_chandkheda mothra_newcgroad align brace',
#  'also get first dose couid nineteen vaccine covishield',
#  'wine wineglass natural fruit nineteen degree cool anti heart_attack vaccine syringe couid one two glass day perfectly not aspirin',
#  'still see datum people always interesting people reference causation around vaccine timely death correlation around couid death without vaccine convenient',
#  'not believe couid vaccine start follow unfortunately link provide bullshit crappy tabloid media site one put article five ten atleast check level publication post',
#  'case heart_attack day city ten milion eighty enough one two shot die much warning coventry emergency mean vaccine ability anti couid',
#  'case heart_attack day ho chi minh ten milion person number want see try understand vaccine couid stupid kill people quick couid',
#  'merit tweet couid vaccine folate na nishapata double dose ya covishield get scare bana think time mute maka saturday ya class',
#  'take couid nineteen vaccine jab not dhekiajuli lac assay harghardastak',
#  'not panic take dose vaccine couid nineteen',
#  'process change dna dna right faci need two four week see maybe seem delta vaccine run need take shot take much shot make blood stop run die immediately quickly couid',
#  'shareholder ki kismet hai raise uth pe bathe ko dog kat jaane kadam se inka couid nasal_spray maya hi tha visa variant maya safari vaccine ki credibility hi doubtful ho_gay chaljaitc',
#  'follower antisocial stupid fellow continue believe vaccine set free nonsense measure death toll come policy vaccine number far great couid actually',
#  'tooth waiting brace apply visit we one step_dental solution couid vaccine doctor dentist chandkheda ahmedabad mothra_newcgroad align brace implant',
#  'vaccine company spend lot money research never leave couid game easily keep try well keep fear always active around world keep churn money fear selling vaccine four year',
#  'lonavala couid vaccine center news tomorrow one twelve amp hospital railway vaccine center stop provide vaccine vaccine available mandala municipal hospital sankheskar center lonavala market lonavala',
#  'supreme_court government can not force people take vaccine govt fail prove vaccine stop couid government two dose compulsory travel purchasing stuff live live common_man start ask question rather afraid justifying',
#  'couid nineteen vaccine lene baby omicron fly rehab anti vaccine antibody hi bana sake',
#  'pure politic u not even understand lockdown not solution vaccine fiscal deficit much pre couid level u actually super brain election focused country ya tal lene',
#  'country vaccine not give protection story immunity lot turn wrong booster vaccine life virus always mutate not freedom choose couid stay start not destroy come virus',
#  'coward west ally vaccine supremacist pull washing hand expect instead lend thank india omicron covidiot couid',
#  'harghardastak skim eastsikkim healthcareworker hero publichealth covidvaccine vaccinationobligatoire work',
#  'finally second dose complete couid nineteen vaccinesyringe alhundhalila ogawa sada',
#  'thing modi afraid discuss parliament farm_law farm_law repeal chinese intrusion inflation unemployment rise crime fuel loot indian hunger index rank couid mismanagement vaccine target shortage',
#  'four india eighteen population take least one dose one eighteen population fully vaccinated coronavirusvaccination covidvaccine',
#  'whatever omicronvariant go jan end surge feb end whether u use mask sanitizer social_distance get covidvaccine presume hope',
#  'couid nineteen vaccine center ward',
#  'looks_like bandit rob everyone freedom speech freedom convey truth lead series death couid vaccine say goodbye high tech silicon valley jack busy investigation prepare go jail',
#  ...]

# %%
all_words_df['new_text'] = new_col
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                               words_list  \
# 0      [well, surprise, speak, journalist, back, sept...
# 1                                  [fan, couid, vaccine]
# 2      [four, dose, vaccine, couid, thank, doctor, th...
# 3      [india, fight, couid, nineteen, get, strong, i...
# 4      [justjoke, couid, precautiondose, scientific, ...
# ...                                                  ...
# 18995  [afraid, infection, not, spread, apply, couid,...
# 18996  [wait, delhi, gujaratis, tamil_nada, receive, ...
# 18997  [think, modi, pass, disbar, january, dene, lik...
# 18998  [first, consignment, couid, nineteen, vaccine,...
# 18999  [good, news, assay, finally, couid, vaccine, c...
#
#                                                 new_text
# 0      well surprise speak journalist back september ...
# 1                                      fan couid vaccine
# 2      four dose vaccine couid thank doctor thank dev...
# 3      india fight couid nineteen get strong india fo...
# 4      justjoke couid precautiondose scientific confi...
# ...                                                  ...
# 18995  afraid infection not spread apply couid vaccin...
# 18996  wait delhi gujaratis tamil_nada receive est co...
# 18997  think modi pass disbar january dene like koi s...
# 18998  first consignment couid nineteen vaccine covis...
# 18999         good news assay finally couid vaccine come
#
# [19000 rows x 4 columns]

# %%
all_words_df['scores'] = df['new_text'].apply(lambda tweet: sid.polarity_scores(tweet))
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                               words_list  \
# 0      [well, surprise, speak, journalist, back, sept...
# 1                                  [fan, couid, vaccine]
# 2      [four, dose, vaccine, couid, thank, doctor, th...
# 3      [india, fight, couid, nineteen, get, strong, i...
# 4      [justjoke, couid, precautiondose, scientific, ...
# ...                                                  ...
# 18995  [afraid, infection, not, spread, apply, couid,...
# 18996  [wait, delhi, gujaratis, tamil_nada, receive, ...
# 18997  [think, modi, pass, disbar, january, dene, lik...
# 18998  [first, consignment, couid, nineteen, vaccine,...
# 18999  [good, news, assay, finally, couid, vaccine, c...
#
#                                                 new_text  \
# 0      well surprise speak journalist back september ...
# 1                                      fan couid vaccine
# 2      four dose vaccine couid thank doctor thank dev...
# 3      india fight couid nineteen get strong india fo...
# 4      justjoke couid precautiondose scientific confi...
# ...                                                  ...
# 18995  afraid infection not spread apply couid vaccin...
# 18996  wait delhi gujaratis tamil_nada receive est co...
# 18997  think modi pass disbar january dene like koi s...
# 18998  first consignment couid nineteen vaccine covis...
# 18999         good news assay finally couid vaccine come
#
#                                                   scores
# 0      {'neg': 0.269, 'neu': 0.587, 'pos': 0.144, 'co...
# 1      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2      {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'comp...
# 3      {'neg': 0.086, 'neu': 0.828, 'pos': 0.086, 'co...
# 4      {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...
# ...                                                  ...
# 18995  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18997  {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'comp...
# 18998  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18999  {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'comp...
#
# [19000 rows x 5 columns]

# %%
all_words_df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                               words_list  \
# 0      [well, surprise, speak, journalist, back, sept...
# 1                                  [fan, couid, vaccine]
# 2      [four, dose, vaccine, couid, thank, doctor, th...
# 3      [india, fight, couid, nineteen, get, strong, i...
# 4      [justjoke, couid, precautiondose, scientific, ...
# ...                                                  ...
# 18995  [afraid, infection, not, spread, apply, couid,...
# 18996  [wait, delhi, gujaratis, tamil_nada, receive, ...
# 18997  [think, modi, pass, disbar, january, dene, lik...
# 18998  [first, consignment, couid, nineteen, vaccine,...
# 18999  [good, news, assay, finally, couid, vaccine, c...
#
#                                                 new_text  \
# 0      well surprise speak journalist back september ...
# 1                                      fan couid vaccine
# 2      four dose vaccine couid thank doctor thank dev...
# 3      india fight couid nineteen get strong india fo...
# 4      justjoke couid precautiondose scientific confi...
# ...                                                  ...
# 18995  afraid infection not spread apply couid vaccin...
# 18996  wait delhi gujaratis tamil_nada receive est co...
# 18997  think modi pass disbar january dene like koi s...
# 18998  first consignment couid nineteen vaccine covis...
# 18999         good news assay finally couid vaccine come
#
#                                                   scores  compound
# 0      {'neg': 0.269, 'neu': 0.587, 'pos': 0.144, 'co...   -0.7650
# 1      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2      {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'comp...    0.7003
# 3      {'neg': 0.086, 'neu': 0.828, 'pos': 0.086, 'co...    0.0000
# 4      {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...    0.4939
# ...                                                  ...       ...
# 18995  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18997  {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'comp...    0.4767
# 18998  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18999  {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'comp...    0.4927
#
# [19000 rows x 6 columns]

# %%
all_words_df["compound"].value_counts()
# Out:
#  0.0000    7528
#  0.4404     382
#  0.5106     258
#  0.4019     256
#  0.3612     244
#            ...
# -0.5233       1
#  0.6692       1
#  0.2212       1
#  0.8006       1
#  0.4289       1
# Name: compound, Length: 1825, dtype: int64

# %%
sentiment_vader = []
for each in all_words_df["compound"]:
    if each == 0:
        sentiment_vader.append("neutral")
    elif each > 0:
        sentiment_vader.append("positive")
    else:
        sentiment_vader.append("negative")

# %%
all_words_df["sentiment_vader"] = sentiment_vader

# %%
sns.countplot(x="sentiment_vader", data=all_words_df)
normalise_count = all_words_df['sentiment_vader'].value_counts(normalize = True)
ax = plt.title('Percentage \n {};'.format(normalise_count*100))

# %%
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                               words_list  \
# 0      [well, surprise, speak, journalist, back, sept...
# 1                                  [fan, couid, vaccine]
# 2      [four, dose, vaccine, couid, thank, doctor, th...
# 3      [india, fight, couid, nineteen, get, strong, i...
# 4      [justjoke, couid, precautiondose, scientific, ...
# ...                                                  ...
# 18995  [afraid, infection, not, spread, apply, couid,...
# 18996  [wait, delhi, gujaratis, tamil_nada, receive, ...
# 18997  [think, modi, pass, disbar, january, dene, lik...
# 18998  [first, consignment, couid, nineteen, vaccine,...
# 18999  [good, news, assay, finally, couid, vaccine, c...
#
#                                                 new_text  \
# 0      well surprise speak journalist back september ...
# 1                                      fan couid vaccine
# 2      four dose vaccine couid thank doctor thank dev...
# 3      india fight couid nineteen get strong india fo...
# 4      justjoke couid precautiondose scientific confi...
# ...                                                  ...
# 18995  afraid infection not spread apply couid vaccin...
# 18996  wait delhi gujaratis tamil_nada receive est co...
# 18997  think modi pass disbar january dene like koi s...
# 18998  first consignment couid nineteen vaccine covis...
# 18999         good news assay finally couid vaccine come
#
#                                                   scores  compound  \
# 0      {'neg': 0.269, 'neu': 0.587, 'pos': 0.144, 'co...   -0.7650
# 1      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2      {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'comp...    0.7003
# 3      {'neg': 0.086, 'neu': 0.828, 'pos': 0.086, 'co...    0.0000
# 4      {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...    0.4939
# ...                                                  ...       ...
# 18995  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18997  {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'comp...    0.4767
# 18998  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18999  {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'comp...    0.4927
#
#       sentiment_vader
# 0            negative
# 1             neutral
# 2            positive
# 3             neutral
# 4            positive
# ...               ...
# 18995         neutral
# 18996         neutral
# 18997        positive
# 18998         neutral
# 18999        positive
#
# [19000 rows x 7 columns]

# %%
pos = all_words_df[all_words_df["sentiment_vader"] == "positive"]
neg = all_words_df[all_words_df["sentiment_vader"] == "negative"]
neu = all_words_df[all_words_df["sentiment_vader"] == "neutral"]

# %%
for each in pos.sample(n=3)["Text"]:
    print("Tweet: " + each)
    print(" ")
# Out:
# Tweet: it was successful covid-19 vaccine campaign 👍👍
#
# Tweet: covid-19 #vaccinated today by personnel programme which helps reduce pressure national vaccine rollout. big thank you scientists, researchers healthcare professionals around world who worked tirelessly make this possible — we are grateful #vaccineswork
#
# Tweet: yeah alhamdulillah 💉#pfizer-biontech #covid-19 vaccines has arrived malaysia. 1st batch 312,390 💕

# %%
for each in neu.sample(n=3)["Text"]:
    print("Tweet: " + each)
    print(" ")
# Out:
# Tweet: jb 2 1947: india received 93 cases penicillin canada. 2021: canada received 5 lakh doses covid-19 vaccines india, 15 lakh more doses be supplied soon. #ourvaccineourpride
#
# Tweet: pandemic baby 👼. baby thinks everything is sanitizer 😁. see her reactions. #covid19 #covidvaccine
#
# Tweet: aiims director dr. randeep guleria receives covid-19 #vaccine at aiims, delhi. #largestvaccinedrive #vaccineforindia

# %%
for each in neg.sample(n=3)["Text"]:
    print("Tweet: " + each)
    print(" ")
# Out:
# Tweet: #indiafightscorona: 📍symptomatic pregnant women are at increased risk severe diseases it might affect foetus too. hence, covid-19 vaccine is recommended pregnant women. ✅ continue following #covidappropriatebehaviour #we4vaccine #unite2fightcorona
#
# Tweet: new zealand has reported what it believes be its first death linked pfizer covid-19 vaccine. #newzealand #covid19 #pfizer
#
# Tweet: this time no need discuss opnion poll now time show actual news related covid government guidelines also they need do awareness about vaccine as well. those who all are discussing election they are useless.

# %%
all_words_df
# Out:
#                                                     Text  \
# 0      well this is no surprise, i spoke about this j...
# 1                            faqs about #covid #vaccines
# 2      4 dose vaccine against covid thanks doctor tha...
# 3      india's fight against covid-19 is getting stro...
# 4      #justasking #covid #precautiondose is there an...
# ...                                                  ...
# 18995  i am afraid that infection will not spread whi...
# 18996  wait is now over: delhi, gujarat, tamil nadu r...
# 18997  i think, modi ji k paas issbar 26 january pr d...
# 18998  first #consignment #covid-19 vaccine, #covishi...
# 18999  very good news assam finally covid vaccine is ...
#
#                                         pos_tagged_words  \
# 0      [('well', 'RB'), ('this', 'DT'), ('is', 'VBZ')...
# 1      [('fans', 'NNS'), ('about', 'IN'), ('couid', '...
# 2      [('four', 'CD'), ('dose', 'JJ'), ('vaccine', '...
# 3      [('india', 'NN'), ('i', 'NN'), ('fight', 'NN')...
# 4      [('justjoking', 'VBG'), ('couid', 'NN'), ('pre...
# ...                                                  ...
# 18995  [('i', 'NN'), ('am', 'VBP'), ('afraid', 'JJ'),...
# 18996  [('wait', 'NN'), ('is', 'VBZ'), ('now', 'RB'),...
# 18997  [('i', 'NN'), ('think', 'VBP'), ('modi', 'IN')...
# 18998  [('first', 'RB'), ('consignment', 'JJ'), ('cou...
# 18999  [('very', 'RB'), ('good', 'JJ'), ('news', 'NN'...
#
#                                               words_list  \
# 0      [well, surprise, speak, journalist, back, sept...
# 1                                  [fan, couid, vaccine]
# 2      [four, dose, vaccine, couid, thank, doctor, th...
# 3      [india, fight, couid, nineteen, get, strong, i...
# 4      [justjoke, couid, precautiondose, scientific, ...
# ...                                                  ...
# 18995  [afraid, infection, not, spread, apply, couid,...
# 18996  [wait, delhi, gujaratis, tamil_nada, receive, ...
# 18997  [think, modi, pass, disbar, january, dene, lik...
# 18998  [first, consignment, couid, nineteen, vaccine,...
# 18999  [good, news, assay, finally, couid, vaccine, c...
#
#                                                 new_text  \
# 0      well surprise speak journalist back september ...
# 1                                      fan couid vaccine
# 2      four dose vaccine couid thank doctor thank dev...
# 3      india fight couid nineteen get strong india fo...
# 4      justjoke couid precautiondose scientific confi...
# ...                                                  ...
# 18995  afraid infection not spread apply couid vaccin...
# 18996  wait delhi gujaratis tamil_nada receive est co...
# 18997  think modi pass disbar january dene like koi s...
# 18998  first consignment couid nineteen vaccine covis...
# 18999         good news assay finally couid vaccine come
#
#                                                   scores  compound  \
# 0      {'neg': 0.269, 'neu': 0.587, 'pos': 0.144, 'co...   -0.7650
# 1      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2      {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'comp...    0.7003
# 3      {'neg': 0.086, 'neu': 0.828, 'pos': 0.086, 'co...    0.0000
# 4      {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...    0.4939
# ...                                                  ...       ...
# 18995  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18996  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18997  {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'comp...    0.4767
# 18998  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 18999  {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'comp...    0.4927
#
#       sentiment_vader
# 0            negative
# 1             neutral
# 2            positive
# 3             neutral
# 4            positive
# ...               ...
# 18995         neutral
# 18996         neutral
# 18997        positive
# 18998         neutral
# 18999        positive
#
# [19000 rows x 7 columns]

# %%
all_words_df.to_csv("labelled_india.csv", index = False)
