# %%
# !pip install emot
# !pip install symspellpy
# !pip install setuptools wheel
# !pip install spacy
# !pip install pyspellchecker
# !pip install spellchecker
# !pip install inflect
# !pip install langdetect
# !pip install google_trans_new
# !pip install deep-translator
# !pip install ekphrasis
# !pip install cdifflib
# !pip install gensim
# !pip install wordninja

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
import re, string, json

from symspellpy.symspellpy import SymSpell, Verbosity
import pkg_resources
import spacy
from tqdm.notebook import tqdm
from spellchecker import SpellChecker
import inflect

import difflib
import gensim

import pandas as pd

# %%
df = pd.read_csv("../data/usa_combined_corrected.csv")
df
# Out:
#                                                      Text
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       juste se rappeler m. leblanc la pression que l...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 423590  do it others.... üí™üéâüíâü§ô #vaccinesave...
# 423591  got my first pfizer shot today. feeling well g...
# 423592  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 423593  yay üôåüèª congrats dr. j being fully vaccin...
# 423594  we all have do our part end this pandemic‚Äî g...
#
# [423595 rows x 1 columns]

# %% [markdown]
# ## Used hashtags

# %%
text = df['Text']
hashtag_list = []
for tweet in text:
#     print(tweet)
    hashtags = re.findall("#[A-Za-z0-9_]+", tweet)
    if len(hashtags) > 0:
        for tag in hashtags:
            hashtag_list.append(tag)

# %%
hashtag_list
# Out:
# ['#covidvaccineconfidence',
#  '#vanguardvaccinationproject',
#  '#populationcontrol',
#  '#omicron',
#  '#vaccination',
#  '#mentalhealth',
#  '#psychtwitter',
#  '#cdnpoli',
#  '#onpoli',
#  '#covid19',
#  '#l',
#  '#polqc',
#  '#getvaccinated',
#  '#vaccineswork',
#  '#canada',
#  '#superbowlmusicfest',
#  '#socal',
#  '#superbowlexperience',
#  '#sblvi',
#  '#hiringphenomenaltalent',
#  '#security',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#legaultmustresign',
#  '#legault',
#  '#covid19',
#  '#localnews',
#  '#newsbreak',
#  '#covid',
#  '#defundcbc',
#  '#defundbbc',
#  '#nyc',
#  '#godblessamerica',
#  '#nonads',
#  '#votehelenkicknadlerny10',
#  '#dyk',
#  '#fightflu',
#  '#heartmonth',
#  '#nowplaying',
#  '#nowspinning',
#  '#np',
#  '#nowstreaming',
#  '#subgenius',
#  '#joerogan',
#  '#antivaxxers',
#  '#nowplaying',
#  '#nowspinning',
#  '#np',
#  '#nowstreaming',
#  '#subgenius',
#  '#joerogan',
#  '#antivaxxers',
#  '#covidab',
#  '#covid19',
#  '#repnotrip',
#  '#ableg',
#  '#ciuss_mcq',
#  '#covid19',
#  '#ambulance',
#  '#inacceptable',
#  '#k',
#  '#jdq',
#  '#covid19',
#  '#mybodymychoice',
#  '#rosiebartonappreciationday',
#  '#ohio',
#  '#abpoli',
#  '#covid19ab',
#  '#thankyoukyrie',
#  '#indonesia',
#  '#covid19',
#  '#sblvi',
#  '#world',
#  '#kingstonmines',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#bcpoli',
#  '#covid19',
#  '#brightonco',
#  '#covid19',
#  '#cdnpoli',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#abpoli',
#  '#ableg',
#  '#abhealth',
#  '#maskshelp',
#  '#clownvoy',
#  '#covid19',
#  '#vaccine',
#  '#vaccinated',
#  '#vaccination',
#  '#covid',
#  '#edafeokporo',
#  '#blackhistorymonth',
#  '#rosiebartonappreciationday',
#  '#covid19',
#  '#polqc',
#  '#earthlings',
#  '#thankful',
#  '#fullyvaxxed',
#  '#msriverproject',
#  '#swag',
#  '#antivaxers',
#  '#joerogan',
#  '#subgenius',
#  '#covid19vaccine',
#  '#vhcon',
#  '#antivaxers',
#  '#joerogan',
#  '#subgenius',
#  '#teamtoronto',
#  '#cityofto',
#  '#covid19',
#  '#vaccination',
#  '#publichealth',
#  '#weyburn',
#  '#polcan',
#  '#biometrics',
#  '#healthcare',
#  '#data',
#  '#vaccination',
#  '#privacy',
#  '#privacy',
#  '#vaccination',
#  '#vaccinemandates',
#  '#vaccinated',
#  '#data',
#  '#coronavirus',
#  '#vaccine',
#  '#vaccination',
#  '#pandemic',
#  '#buckscounty',
#  '#buckscountynews',
#  '#pennsylvania',
#  '#doh',
#  '#covid19news',
#  '#covidupdate',
#  '#nyctestandtrace',
#  '#covid19',
#  '#covid19',
#  '#covidvaccineboosters',
#  '#covidtesting',
#  '#sjcountyclinics',
#  '#visionaryhomebuilders_ca',
#  '#lesswrong',
#  '#covid19',
#  '#queensu',
#  '#queensu',
#  '#camden',
#  '#covid19',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#maskmandate',
#  '#nyc',
#  '#covid19',
#  '#asksavanity',
#  '#uftny',
#  '#2',
#  '#cdc',
#  '#vaccination',
#  '#endthemandates',
#  '#picphysicians',
#  '#informedconsent',
#  '#1stdonoharm',
#  '#vaccines',
#  '#vaccination',
#  '#physicians4informedconsent',
#  '#science',
#  '#statistics',
#  '#texas',
#  '#mediafreeamerica',
#  '#vaxupcuny',
#  '#vaccination',
#  '#covid',
#  '#jasonkenney',
#  '#covid19',
#  '#newyork',
#  '#vaccination',
#  '#mask',
#  '#illinois',
#  '#maskmandate',
#  '#covid19',
#  '#covidrestrictions',
#  '#daytonabeachpoker',
#  '#washtimesoped',
#  '#tga',
#  '#pfizer',
#  '#cpacpoli',
#  '#commonsense',
#  '#vaxupphilly',
#  '#cdnmedia',
#  '#cdnpoli',
#  '#justiceforcolten',
#  '#coronavirus',
#  '#skpoli',
#  '#cdnpoli',
#  '#deeperissues',
#  '#endmandatesnow',
#  '#vaccination',
#  '#covidvaccine',
#  '#covid19',
#  '#houston',
#  '#covid19',
#  '#hounews',
#  '#covid19',
#  '#vaccination',
#  '#downtownwindsor',
#  '#windsorontario',
#  '#yqg',
#  '#urgencyofequity',
#  '#covid19',
#  '#veterans',
#  '#seattlemedium',
#  '#castro',
#  '#cheguevara',
#  '#rino',
#  '#rinosalazar',
#  '#healthyelon',
#  '#myocarditis',
#  '#truckerconvoy',
#  '#vaxup',
#  '#maskup',
#  '#firetheucp',
#  '#gostanford',
#  '#covid',
#  '#vaccination',
#  '#delta',
#  '#essexfellsnj',
#  '#truckersconvoy',
#  '#freedomconvoycanada2022',
#  '#endthemandatesnow',
#  '#truckersforfreedom2020',
#  '#trudeaumustresign',
#  '#trudeaunationaldisgrace',
#  '#endmandates',
#  '#wpunj',
#  '#covid19',
#  '#cdnpoli',
#  '#covid19',
#  '#covid19',
#  '#medicine',
#  '#markmywords',
#  '#cdnpoli',
#  '#onpoli',
#  '#nfl',
#  '#walgreens',
#  '#vaccination',
#  '#superbowl',
#  '#nflalumnihealth',
#  '#trudeauhasgottogo',
#  '#trudeaumustresign',
#  '#gojohnnies',
#  '#covid19',
#  '#utpol',
#  '#utah',
#  '#covid19',
#  '#atthecoreofcare',
#  '#covid19',
#  '#covid19',
#  '#freedumbconvoy',
#  '#covid19',
#  '#ststephen',
#  '#chile',
#  '#covid',
#  '#aldianews',
#  '#getvaxxed',
#  '#utsa',
#  '#doyourpart',
#  '#denmark',
#  '#arts',
#  '#artsnews',
#  '#8217',
#  '#cdnpoli',
#  '#covid19',
#  '#toronto',
#  '#masks',
#  '#socialdistancing',
#  '#vaccination',
#  '#vaccinated',
#  '#vaccine',
#  '#vaccination',
#  '#coronavirus',
#  '#vaccinezvous',
#  '#vaccin',
#  '#vaccin',
#  '#vaccinationobligatoire',
#  '#vaccination',
#  '#vaccinatieschade',
#  '#vaccinezvousbordel',
#  '#covid19',
#  '#covid_19',
#  '#covid',
#  '#cdnpolitics',
#  '#cdnpoli',
#  '#fyi',
#  '#news',
#  '#feedly',
#  '#lockhimup',
#  '#ldnont',
#  '#lockhimup',
#  '#ableg',
#  '#abpoli',
#  '#alberta',
#  '#vaers',
#  '#flylgb',
#  '#news',
#  '#election2020',
#  '#airsuvidha',
#  '#califonia',
#  '#onevaxtwolives',
#  '#vaers',
#  '#covid19',
#  '#vaers',
#  '#vaers',
#  '#pushforthevaccine',
#  '#getvaccinated',
#  '#netsareunfair',
#  '#vaers',
#  '#cdnpoli',
#  '#ny21',
#  '#jazz',
#  '#calgary',
#  '#castro',
#  '#cheguevara',
#  '#rino',
#  '#rinosalazar',
#  '#masks',
#  '#vaccination',
#  '#stemeducation',
#  '#covid19',
#  '#occovid19',
#  '#othena',
#  '#thisisourshot',
#  '#ableg',
#  '#abpoli',
#  '#abpse',
#  '#masks',
#  '#mandates',
#  '#tennessee',
#  '#tnleg',
#  '#gopcoup',
#  '#masks',
#  '#vaccination',
#  '#covid19',
#  '#adulting',
#  '#responsibilities',
#  '#studentloans',
#  '#canada',
#  '#qu',
#  '#covid',
#  '#volunteers',
#  '#cannedgoods',
#  '#vaccine',
#  '#trucker',
#  '#ottawa',
#  '#hcm',
#  '#solution',
#  '#covid19',
#  '#automation',
#  '#coronavirus',
#  '#vaccination',
#  '#wakeup',
#  '#covid19',
#  '#teamniagara',
#  '#saveourkids',
#  '#vaccination',
#  '#parents',
#  '#covid19',
#  '#kids',
#  '#novaccinemandate',
#  '#covidsummit',
#  '#ridehigh',
#  '#ridetogether',
#  '#bettzedekgala2022',
#  '#bettzedek',
#  '#vaccination',
#  '#crackpipe',
#  '#healthinsurance',
#  '#covid',
#  '#americans',
#  '#covidvaccine',
#  '#covid19',
#  '#medhat',
#  '#covid19ab',
#  '#conception',
#  '#standwiththecoaches',
#  '#covid19',
#  '#tonga',
#  '#covid19',
#  '#outbreak',
#  '#vaccination',
#  '#98',
#  '#ri',
#  '#rhodeisland',
#  '#ripoli',
#  '#rhodyreport',
#  '#truckers',
#  '#trudeau',
#  '#ems',
#  '#covid19',
#  '#mno',
#  '#unvaccinated',
#  '#freedom',
#  '#endthemandates',
#  '#covid19',
#  '#3',
#  '#covid19',
#  '#ausummit',
#  '#covid19',
#  '#vaccination',
#  '#timbitterrorists',
#  '#ottawa',
#  '#ottawaoccupied',
#  '#convoidelahonte',
#  '#mbpoli',
#  '#covid19mb',
#  '#amarillo',
#  '#coronavirus',
#  '#protest',
#  '#world',
#  '#inquiringminds',
#  '#covid19',
#  '#nchealth',
#  '#ncpol',
#  '#covid19',
#  '#maskmandates',
#  '#hospitalizations',
#  '#deaths',
#  '#infections',
#  '#children',
#  '#vaccination',
#  '#parents',
#  '#teachers',
#  '#mandates',
#  '#responsibility',
#  '#vaccinate',
#  '#newbedford',
#  '#trustthefacts',
#  '#getthevax',
#  '#csu',
#  '#covid19',
#  '#sciencecommunication',
#  '#covid',
#  '#covidvaccine',
#  '#abpse',
#  '#ableg',
#  '#abpse',
#  '#ableg',
#  '#abpse',
#  '#ableg',
#  '#covid19',
#  '#covid19sk',
#  '#tuproposesquoiduhaime',
#  '#sarscov2',
#  '#tcellimmuneresponses',
#  '#omicron',
#  '#boostervaccines',
#  '#informyourchoice',
#  '#medtrademonday',
#  '#covid19',
#  '#vaccination',
#  '#dme',
#  '#hme',
#  '#freetraining',
#  '#covid',
#  '#yqr',
#  '#sk',
#  '#internetpluss',
#  '#vaccinated',
#  '#covid19',
#  '#vaccination',
#  '#restrictions',
#  '#pand',
#  '#togo',
#  '#news',
#  '#abhealth',
#  '#covid19ab',
#  '#cdnpoli',
#  '#covid19',
#  '#canada',
#  '#covid19',
#  '#covid19sk',
#  '#saskatchewan',
#  '#covid19',
#  '#truckersforfreedom2022',
#  '#honkhonk',
#  '#freedomconvoy',
#  '#sask',
#  '#covid19',
#  '#pregnancy',
#  '#srsu',
#  '#yegcc',
#  '#covid19qc',
#  '#novaxdjocovid',
#  '#hwdd22',
#  '#covid19france',
#  '#vaccination',
#  '#dhswi',
#  '#yql',
#  '#yqlcc',
#  '#tonga',
#  '#first',
#  '#covid',
#  '#98',
#  '#arstechnica',
#  '#covid',
#  '#vaxcard',
#  '#test',
#  '#mandate',
#  '#restaurants',
#  '#omicronvarient',
#  '#umboosted',
#  '#umboosted',
#  '#umflint',
#  '#sgumflint',
#  '#goblue',
#  '#vaccination',
#  '#vaccinationclinic',
#  '#booster',
#  '#boosterclinic',
#  '#covid',
#  '#southafrica',
#  '#superbowl',
#  '#nflasocal',
#  '#nflalumnihealth',
#  '#community',
#  '#vaccination',
#  '#nfl',
#  '#inglewood',
#  '#ldnont',
#  '#sasked',
#  '#covid19',
#  '#maskup',
#  '#vaxupnova',
#  '#classwarfare',
#  '#aacon2022',
#  '#truckersconvoy',
#  '#blackdehem22',
#  '#staystrongdc',
#  '#endallmandates',
#  '#trudeaumustresign',
#  '#canpoli',
#  '#honkhonk',
#  '#democrats',
#  '#uspolitics',
#  '#naturalimmunity',
#  '#cdnpoli',
#  '#booster',
#  '#zerflin',
#  '#covid19',
#  '#india',
#  '#covid',
#  '#vaccination',
#  '#covid19',
#  '#kippmemphis',
#  '#staysafe',
#  '#getvaxxed',
#  '#covidvaccine',
#  '#covid19',
#  '#covidvaccine',
#  '#covid',
#  '#vaccineswork',
#  '#getvaccinated',
#  '#caq',
#  '#polqc',
#  '#assnat',
#  '#govlove',
#  '#breaking',
#  '#covid19',
#  '#blues',
#  '#chicagoblues',
#  '#liveblues',
#  '#livemusic',
#  '#shopsmall',
#  '#choosechicago',
#  '#latenightkitchen',
#  '#covid19',
#  '#vaccineswork',
#  '#hypocrisy',
#  '#abortionishealthcare',
#  '#hollywood',
#  '#hypocrisy',
#  '#hypocrites',
#  '#covidontario',
#  '#vaccination',
#  '#covid19',
#  '#vaccinepassort',
#  '#coronavirus',
#  '#onpoli',
#  '#snrtg',
#  '#covid19',
#  '#pivot',
#  '#covid19',
#  '#covid19',
#  '#nurses',
#  '#covid19',
#  '#vaccination',
#  '#notlogical',
#  '#tcell',
#  '#sarscov2',
#  '#icymi',
#  '#accessible',
#  '#icymi',
#  '#accessible',
#  '#blackhistorymonth',
#  '#bhm',
#  '#primarycare',
#  '#covid19',
#  '#vaccination',
#  '#vaccines',
#  '#vaccination',
#  '#throwbackthursday',
#  '#nflalumnihealth',
#  '#cervicalcancer',
#  '#cancer',
#  '#screening',
#  '#vaccination',
#  '#freedomconvoycanada2022',
#  '#truckersconvoy',
#  '#vaccination',
#  '#ottawa',
#  '#getvaccinatedandboosted',
#  '#physicians4informedconsent',
#  '#1stdonoharm',
#  '#vaccines',
#  '#vaccination',
#  '#informedconsent',
#  '#science',
#  '#statistics',
#  '#covid19',
#  '#vaccination',
#  '#covid19',
#  '#vaccinatepasadena',
#  '#vacunacion',
#  '#vaccination',
#  '#coronavirus',
#  '#covid19',
#  '#stgeorge',
#  '#covid19',
#  '#vaccination',
#  '#strongertogether',
#  '#strong',
#  '#hope',
#  '#canada',
#  '#ottawa',
#  '#ottawaoccupied',
#  '#ottawaconvoy',
#  '#covid19',
#  '#omicron',
#  '#vaccination',
#  '#covid19',
#  '#netde',
#  '#coronavirus',
#  '#quarantine',
#  '#india',
#  '#canada',
#  '#pcrtest',
#  '#vaccination',
#  '#airsuvidha',
#  '#vaccination',
#  '#free',
#  '#webinar',
#  '#njbusiness',
#  '#businesstips',
#  '#rally',
#  '#antivaxxers',
#  '#protesters',
#  '#windsorblockade',
#  '#medicareforall',
#  '#vaccinatingsomerset',
#  '#everyvaccinematters',
#  '#beyondtheguidelines',
#  '#ruralhealth',
#  '#didyouknow',
#  '#residentdoctorappreciation2022',
#  '#macresidentsrock',
#  '#scotus',
#  '#capi',
#  '#covid19',
#  '#scgcon',
#  '#covid19',
#  '#vaccination',
#  '#canada',
#  '#canadian',
#  '#vaccination',
#  '#unvaccinated',
#  '#vaccineswork',
#  '#placebo',
#  '#cdc',
#  '#allopathetic',
#  '#drugs',
#  '#doesyourdoctordriveateslaorchangedigitalscriptstosavetrees',
#  '#hospital',
#  '#vaccines',
#  '#vaccination',
#  '#vaccine',
#  '#nurse',
#  '#hamont',
#  '#joescrackheads',
#  '#vaccination',
#  '#crackpipe',
#  '#covid_19',
#  '#maroc',
#  '#vaccination',
#  '#maskssavelives',
#  '#vaccineswork',
#  '#getvaccinated',
#  '#getvaccinatednow',
#  '#getvaccinatedandboosted',
#  '#getvaxxed',
#  '#wearamask',
#  '#maskup',
#  '#covid19',
#  '#bamako',
#  '#vaccination',
#  '#covid19',
#  '#darwin',
#  '#vaccineswork',
#  '#vaccine',
#  '#science',
#  '#god',
#  '#allopathetic',
#  '#hospital',
#  '#drugs',
#  '#money',
#  '#health',
#  '#cdc',
#  '#covid19',
#  '#vaccination',
#  '#drugs',
#  '#medicine',
#  '#doctor',
#  '#omicron',
#  '#vaccine',
#  '#california',
#  '#nomaskmandates',
#  '#cdc',
#  '#vaccination',
#  '#covid19',
#  '#vaccines',
#  '#vaccineswork',
#  '#hospitals',
#  '#drugs',
#  '#money',
#  '#news',
#  '#vaccination',
#  '#vaccines',
#  '#canada',
#  '#endmandates',
#  '#mandatefreedom',
#  '#cdnpoli',
#  '#bcpoli',
#  '#nffc',
#  '#coyr',
#  '#forestallovertheworld',
#  '#blackfuturemonth',
#  '#blm',
#  '#covid19',
#  '#cove',
#  '#covid19',
#  '#vaccination',
#  '#hmelsahly',
#  '#fightflu',
#  '#heartmonth',
#  '#harmreduction',
#  '#cdc',
#  '#vaccineswork',
#  '#doctor',
#  '#nurses',
#  '#hospitals',
#  '#frontlineworkers',
#  '#covid',
#  '#vaccines',
#  '#vaccination',
#  '#vaccine',
#  '#rensa22',
#  '#1',
#  '#2',
#  '#3',
#  '#vaccination',
#  '#cdc',
#  '#virus',
#  '#vaccination',
#  '#vaccineswork',
#  '#vaccines',
#  '#covid19',
#  '#covid',
#  '#drugs',
#  '#interoperability',
#  '#healthcareit',
#  '#digitalhealth',
#  '#myocarditis',
#  '#pathologist',
#  '#hart',
#  '#covid19',
#  '#covidvaccine',
#  '#propaganda',
#  '#cdc',
#  '#covidiots',
#  '#covid19',
#  '#covid',
#  '#vaccination',
#  '#vaccine',
#  '#vaccines',
#  '#vaccinessavelives',
#  '#antivaxxer',
#  '#2',
#  '#1',
#  '#vaccination',
#  '#covidvaccines',
#  '#pregnancy',
#  '#vaccinedata',
#  '#vaccinesafety',
#  '#medicine',
#  '#cdnpoli',
#  '#icd10',
#  '#leominster',
#  '#trustthefacts',
#  '#getthevax',
#  '#covid19canada',
#  '#cdnhealth',
#  '#covid19',
#  '#covid19',
#  '#skpoli',
#  '#canada',
#  '#endthemandatesnow',
#  '#covid19',
#  '#vaccines',
#  '#primarycare',
#  '#publichealth',
#  '#medtwitter',
#  '#sanfrancisco',
#  '#mask',
#  '#vaccination',
#  '#omicron',
#  '#covid19',
#  '#globalhealth',
#  '#covid19ma',
#  '#theearlyedition',
#  '#thursdaymotivation',
#  '#hrsa',
#  '#covax',
#  '#covax',
#  '#breakcovid',
#  '#ibaabackinthesaddle',
#  '#wearelha',
#  '#andalequeesperas',
#  '#covidtesting',
#  '#covidvaccine',
#  '#covid19',
#  '#doitforthem',
#  '#uvso',
#  '#ambassadorbridge',
#  '#truckersforfreedom2020',
#  '#covaxin',
#  '#maskmandates',
#  '#bcpoli',
#  '#endthemandates',
#  '#bigpharma',
#  '#naturalhealth',
#  '#health',
#  '#homeopathy',
#  '#homeopathicmedicin',
#  '#naturalmedicine',
#  '#vaccines',
#  '#freecrackpipes',
#  '#bidenisalaughingstock',
#  '#trump2024tosaveamerica',
#  '#wearesouthern',
#  '#teamsu',
#  '#alabama',
#  '#covid19',
#  '#vaccination',
#  '#omicronvariant',
#  '#covidnyc',
#  '#coronavirusnyc',
#  '#covid',
#  '#coronavirus',
#  '#wecandothis',
#  '#minkwoncenter',
#  '#vaxoutreach',
#  '#icymi',
#  '#publichealthagencyofcanada',
#  '#vaccineforall',
#  '#worldofreasons',
#  '#themcc',
#  '#phac',
#  '#canada',
#  '#justgotmyshot',
#  '#polqc',
#  '#nosd',
#  '#covid19',
#  '#superbowl',
#  '#covid19',
#  '#covid19',
#  '#vaccine',
#  '#vaccination',
#  '#healthcare',
#  '#healthcarestaff',
#  '#cms',
#  '#omnibus',
#  '#skpoli',
#  '#hhr',
#  '#ltc',
#  '#ontario',
#  '#onlab',
#  '#mandatoryvaccination',
#  '#covid19',
#  '#followthemoney',
#  '#covid19',
#  '#corrupt',
#  '#coronavirus',
#  '#nyctestandtrace',
#  '#covid19',
#  '#wearecruise',
#  '#fightcorona',
#  '#covidsafety',
#  '#vaccination',
#  '#covid19',
#  '#niagara',
#  '#vaccination',
#  '#covid19',
#  '#covid19',
#  '#alhambrahighschool',
#  '#ahs',
#  '#biden',
#  '#federal',
#  '#covid',
#  '#vaccination',
#  '#covid19ab',
#  '#rep',
#  '#vaccination',
#  '#calgarychamber',
#  '#vaccines',
#  '#publichealth',
#  '#covid19',
#  '#vaccination',
#  '#flutruxklan',
#  '#covid19',
#  '#azerbaijan',
#  '#covid',
#  '#swagideas',
#  '#vaccinecardholder',
#  '#swagidea',
#  '#swagideas',
#  '#vaccinecardholder',
#  '#swagidea',
#  '#vaccinehesitancy',
#  '#canvaxres',
#  '#science',
#  '#pfecolleague',
#  '#covid19vaccine',
#  '#covid19ncancer',
#  '#ccc19',
#  '#mandela',
#  '#blackhistorymonth',
#  '#bhm',
#  '#health',
#  '#covid',
#  '#highriskcovid19',
#  '#vaccination',
#  '#nvac',
#  '#covid19',
#  '#letsdoitforlancashire',
#  '#covid19',
#  '#sarscov2',
#  '#nhhealthy',
#  '#innhfornh',
#  '#polqc',
#  '#covid19',
#  '#covid19',
#  '#polqc',
#  '#freedomconvoy2022',
#  '#vaccination',
#  '#privilege',
#  '#mandated',
#  '#covid19',
#  '#adjuvants',
#  '#naturalinfection',
#  '#precisionvaccines',
#  '#vitapamps',
#  '#immunity',
#  '#vaccination',
#  '#prevention',
#  '#nextgenvaccines',
#  '#keytonyc',
#  '#warriorsnation',
#  ...]

# %%
seen = set()
dupes = []

for x in hashtag_list:
    if x in seen:
        dupes.append(x)
    else:
        seen.add(x)

# %%
len(hashtag_list)
# Out:
# 140497

# %%
len(seen)
# Out:
# 27840

# %%
hashtags_list = list(seen)

# %%
hashtags_list
# Out:
# ['#oposicionmiserableymezquina',
#  '#moralmonsters',
#  '#headline',
#  '#year',
#  '#pittsburgh',
#  '#sciencefiction',
#  '#vaxto',
#  '#flyers',
#  '#believeinahealthynewark',
#  '#stupidpeople',
#  '#scienceoverpseudoscience',
#  '#fultoncountyga',
#  '#organized',
#  '#lovehummingbirds',
#  '#onedownonemoretogo',
#  '#suenonevax',
#  '#classic',
#  '#photo',
#  '#cyclones',
#  '#santacruzatoyac',
#  '#cancelericclapton',
#  '#revolutionary',
#  '#drugdiscovery',
#  '#covidnazi',
#  '#poliopioneer',
#  '#thedublindifference',
#  '#urgenttherapyalert',
#  '#felizjueves',
#  '#listentoexperts',
#  '#losdeporteros',
#  '#bing',
#  '#trumps',
#  '#yamtits',
#  '#geek',
#  '#mutantabilities',
#  '#letsbesafe',
#  '#wmtw',
#  '#madeinusa',
#  '#lawncare',
#  '#stopthepandemic',
#  '#powerturbines',
#  '#hasdonaldtrumpbeenindictedyet',
#  '#counselorsnotcops',
#  '#amigoprogre',
#  '#icp',
#  '#crushedit',
#  '#huntingtonbeachca',
#  '#wheresmyfreedonut',
#  '#americorps',
#  '#animalclinic',
#  '#instagood',
#  '#hounews',
#  '#austinblackout',
#  '#postvaccinesymptoms',
#  '#recyclerater',
#  '#google',
#  '#superexcited',
#  '#princeharry',
#  '#vaccinechallenge',
#  '#usaolympics',
#  '#tnceal',
#  '#bothsides',
#  '#amillionlittlethings',
#  '#trudeauvaccinefail',
#  '#opentheborder',
#  '#arquitectura',
#  '#juggalos',
#  '#lrt',
#  '#law',
#  '#socialismworks',
#  '#spotifypodcasts',
#  '#getvaccinatednow',
#  '#saturdayvibes',
#  '#vocescovid19',
#  '#randyhillierisarussianasset',
#  '#honkhonkhonk',
#  '#stillsinkingin',
#  '#conservativesout',
#  '#teamred',
#  '#goofballs',
#  '#waukee',
#  '#marriedatfirstsight',
#  '#newyorkstate',
#  '#michaelflynn',
#  '#hwdd22',
#  '#gotowardstjelight',
#  '#teacher',
#  '#3edose',
#  '#federalelection2021',
#  '#orgy',
#  '#maskeup',
#  '#iamwonderwoman',
#  '#corona',
#  '#ipo',
#  '#trumpworstpresidentever',
#  '#vaxmandateswork',
#  '#bookstagram',
#  '#holiday',
#  '#covidispublichealthissue',
#  '#deschutescountyfairgrounds',
#  '#criminallaw',
#  '#patriot',
#  '#fightingcovid',
#  '#russians',
#  '#suitupnews',
#  '#fcked',
#  '#covid19utah',
#  '#cumbremonterrey',
#  '#yabuddy',
#  '#navarro',
#  '#nothingisfree',
#  '#antichrist',
#  '#shotone',
#  '#verona',
#  '#rogersville',
#  '#increase',
#  '#aap',
#  '#whereshan',
#  '#ibdwarrior',
#  '#sickness',
#  '#ppe',
#  '#southcoast',
#  '#urgencyofcapitalism',
#  '#madate',
#  '#throwbackthursday',
#  '#sundaybrunch',
#  '#fuckthevaccine',
#  '#formyteam',
#  '#planespotting',
#  '#stopspreadingthedisease',
#  '#osmium',
#  '#abrohilo',
#  '#esdeinfieles',
#  '#universalstudios',
#  '#riendexcuses',
#  '#djabilities',
#  '#gtranslators_1',
#  '#xoxo',
#  '#gunfail',
#  '#canadianmediafailed',
#  '#covidmandate',
#  '#usecommonsense',
#  '#vaccinatedlife',
#  '#trailrunning',
#  '#papers',
#  '#gopterrorists',
#  '#thanksalottrump',
#  '#alemania',
#  '#numbersdontlie',
#  '#manifesters',
#  '#44pfizer',
#  '#waytogojoe',
#  '#bucketlistchecked',
#  '#mattritter',
#  '#vaccinatenewyork',
#  '#yourbodyyourchoice',
#  '#pharmajobs',
#  '#nuevafotodeperfil',
#  '#abstracthiphop',
#  '#umsl',
#  '#getvaccinatedyouidiots',
#  '#testosteroneron',
#  '#blackandwhitephotography',
#  '#igotmysuperpower',
#  '#biontech',
#  '#tcell',
#  '#stoprxgreed',
#  '#ncaachampionship',
#  '#accesspointonjane',
#  '#singh',
#  '#herdimminity',
#  '#crohnswarrior',
#  '#covered',
#  '#guiltyverdict',
#  '#thankyouscientists',
#  '#iw',
#  '#lalaguna',
#  '#getmyshots',
#  '#readyfornormal',
#  '#makebettetchoices',
#  '#antioxidantes',
#  '#notmygopleader',
#  '#israel',
#  '#dglolz',
#  '#saveamericafromstupidpeople',
#  '#military',
#  '#horn',
#  '#ilovefood',
#  '#brachygrqphy',
#  '#fundstudentsnotsystems',
#  '#onemoresteptowardsnormalcy',
#  '#conservatives',
#  '#vaccineorventilator',
#  '#tellmewhatimissed',
#  '#afton',
#  '#beagreatmatadortoday',
#  '#milpaalta',
#  '#thrilled',
#  '#princessmargaret',
#  '#spacecamp',
#  '#mdnews',
#  '#americansaregoingtoeffaroundandfindout',
#  '#highschool',
#  '#bringontheroaring20s',
#  '#litchfieldcounty',
#  '#luchabros',
#  '#freethevaccine',
#  '#covidvaccine2',
#  '#nursesrock',
#  '#rockofjello',
#  '#bcphd',
#  '#cevarenotexpendable',
#  '#appreciationpost',
#  '#edafeokporo',
#  '#captainamerica',
#  '#technewscanada',
#  '#somosuaem',
#  '#vr',
#  '#whackamole',
#  '#allvaxedup',
#  '#palmbeach',
#  '#cluelessbutcautious',
#  '#clinicaltrialsandobservations',
#  '#blackdisabledlivesmatter',
#  '#someonewarnmyuncles',
#  '#edudatedvaccination',
#  '#vacunascovid',
#  '#younghowze',
#  '#marineswearmasks',
#  '#almostayear',
#  '#disability',
#  '#ghostbustersafterlife',
#  '#avoid3cs',
#  '#bostaff',
#  '#turbovax',
#  '#wlcsd',
#  '#badlook',
#  '#focusonallies',
#  '#teammoderna',
#  '#vaccinationstreet',
#  '#monterey',
#  '#passports',
#  '#fireselke',
#  '#spinout',
#  '#022f1a',
#  '#benitoju',
#  '#nhs',
#  '#thankyoujesus',
#  '#madridistasdc',
#  '#howvaccineswork',
#  '#workfamily',
#  '#dadjokes',
#  '#fascists',
#  '#seconddoses',
#  '#crees',
#  '#talibangelical',
#  '#southlakestrong',
#  '#imatrooper',
#  '#chesco',
#  '#bellevue',
#  '#dose3',
#  '#gobills',
#  '#insidertraitors',
#  '#illinoistro',
#  '#swiu',
#  '#notpassingoutthistime',
#  '#nevada',
#  '#huskypride',
#  '#wearthemask',
#  '#notawitchhunt',
#  '#avoidgroupsofpeople',
#  '#lostcreators',
#  '#wilfullyignorant',
#  '#spectator',
#  '#21octubre',
#  '#susd',
#  '#veterinarian',
#  '#yesung',
#  '#scienceupfirst',
#  '#covaxinapproval',
#  '#relax',
#  '#whospink',
#  '#onestepcloser',
#  '#watchroh',
#  '#dumbass',
#  '#humanupgrades',
#  '#wearereeling',
#  '#lizzieg',
#  '#thecoviddiaries',
#  '#janssenvaccine',
#  '#famfam',
#  '#hypocrite',
#  '#postcovidshot',
#  '#sjkids',
#  '#unvaccinatedunpreparedunderground',
#  '#sarcasmo',
#  '#fremont',
#  '#highriskcovid',
#  '#addamsfamily',
#  '#seniorliving',
#  '#dga',
#  '#mers',
#  '#2kperday',
#  '#internships',
#  '#aapi',
#  '#birmingham',
#  '#pleasedontwaitvaccinated',
#  '#clean',
#  '#gohomedjokovic',
#  '#fed',
#  '#mountainofbusch',
#  '#secondshot',
#  '#oneutah',
#  '#fasciste',
#  '#iamthechange',
#  '#vaccinelife',
#  '#docslead',
#  '#occupycityhall',
#  '#americamatters',
#  '#idweek2021',
#  '#denzel',
#  '#idpol',
#  '#cancerpaitent',
#  '#chief',
#  '#openupamericanow',
#  '#tulum',
#  '#johnssonjohnsson',
#  '#woohoo',
#  '#todoorizaba',
#  '#themoredeaththeyseebytheunvaccinatedthemoretheydontwanttogetvaccinated',
#  '#careaboutothers',
#  '#thankyouusa',
#  '#kuwk',
#  '#premarket',
#  '#jazzinchicago',
#  '#sciencesaveslives',
#  '#febrero',
#  '#getthefrickinvaccine',
#  '#hivvaccinetrials',
#  '#normalpeople',
#  '#vaccinesplus',
#  '#guatafac',
#  '#xboxseriesx',
#  '#indianews',
#  '#notinmycity',
#  '#covidshots',
#  '#protector',
#  '#pfizerx3',
#  '#revokeeua',
#  '#idemo',
#  '#frightening',
#  '#fans4life',
#  '#andlightsabers',
#  '#travellosangeles',
#  '#daddygotpoked',
#  '#gotmine',
#  '#freebritneynow',
#  '#vaccinessaveslives',
#  '#abelg',
#  '#theagenda',
#  '#stopsmoking',
#  '#cruise',
#  '#entitled',
#  '#wearthedamnmasks',
#  '#yessss',
#  '#vacinaparatodos',
#  '#fueralopezhablador',
#  '#casino',
#  '#hazloporsanantonio',
#  '#exemption',
#  '#lanecounty',
#  '#theaugustapress',
#  '#nelly',
#  '#destiny2',
#  '#soonitwillbetoolate',
#  '#ncaab',
#  '#chemjobs',
#  '#epipen',
#  '#okhealth',
#  '#iamrare',
#  '#jerkoftheday',
#  '#beautyqueen',
#  '#thefaulknerfocus',
#  '#publicgood',
#  '#ivig',
#  '#morgans',
#  '#frogs',
#  '#businesses',
#  '#herpeszoster',
#  '#buendia',
#  '#iwillnotfear',
#  '#fakespotifyfacts',
#  '#wearyourdamnmask',
#  '#vacunasanticovid',
#  '#aledchat',
#  '#wearebsfstrong',
#  '#bioanalytics',
#  '#stories',
#  '#100reasonstodumpdougford',
#  '#extraboost',
#  '#foodlikeitshouldbe',
#  '#gramercypark',
#  '#gottheshot',
#  '#plantdaddy',
#  '#pleaseboost',
#  '#notgonnamissmyshot',
#  '#swagideas',
#  '#scienceisgood',
#  '#physicalactivity',
#  '#mckinsey',
#  '#bam',
#  '#gobuckeyes',
#  '#richmondbc',
#  '#jeffco',
#  '#spreadtruth',
#  '#shitlib',
#  '#vaccineinjured',
#  '#vaxforkids',
#  '#ottawaprotests',
#  '#gohometruckers',
#  '#bigbrothernlbe',
#  '#cryaboutit',
#  '#vacinasim',
#  '#cdumobilevaccines',
#  '#sturgisrally',
#  '#covidsafe',
#  '#sugarpill',
#  '#xaebor',
#  '#covidfunny',
#  '#riseandshine',
#  '#oxygenshortage',
#  '#notomandate',
#  '#albertacovid19',
#  '#2022election',
#  '#failedstate',
#  '#coldchainlogistics',
#  '#antitrudeau',
#  '#wcvb',
#  '#miraculous',
#  '#modernaboosted',
#  '#makehaste',
#  '#slavery',
#  '#420day',
#  '#publichealthforall',
#  '#urbanconservative',
#  '#integralroasting',
#  '#onedownonetogo',
#  '#bananarepublicofpakistan',
#  '#covidcult',
#  '#wordle232',
#  '#welldone',
#  '#unitedstatesofamerica',
#  '#like4like',
#  '#manflu',
#  '#september1st',
#  '#elpeorgobiernodelahistoria',
#  '#deltahasdelta',
#  '#kks',
#  '#survive',
#  '#munaca',
#  '#ruvaccinated',
#  '#kyderby148',
#  '#vidasparalelas',
#  '#beachlife',
#  '#cytotoxictcells',
#  '#thankadoctor',
#  '#49ersfaithful',
#  '#900kdead',
#  '#excited',
#  '#apartheid',
#  '#nadal',
#  '#fightingthe4thwave',
#  '#breastmilkbegood',
#  '#stayhome',
#  '#covidrules',
#  '#elongate',
#  '#hivvaccine',
#  '#northriverside',
#  '#maskdenying',
#  '#palestine',
#  '#anavsdet',
#  '#cuartopiso',
#  '#vaccineselfie',
#  '#latimes',
#  '#dkjob',
#  '#stickittoem',
#  '#safety1st',
#  '#fsusd',
#  '#bankruptgofundme',
#  '#newyorkers',
#  '#vvsdproud',
#  '#boom',
#  '#notocovid19',
#  '#scienceislife',
#  '#tulare',
#  '#ouchiefauci',
#  '#oppression',
#  '#andatua_votar',
#  '#moneymakesthisworldgoround',
#  '#covidvacccine',
#  '#dnaspecial',
#  '#omicron_is_a_global_calamity',
#  '#crackpipevaxpass',
#  '#fvd',
#  '#gemba',
#  '#craftbeer',
#  '#cpfc',
#  '#barbs',
#  '#nevercon',
#  '#raping',
#  '#dcaboveall',
#  '#thriftshop',
#  '#sttr',
#  '#gaylife',
#  '#etobicoke',
#  '#economics',
#  '#frauds',
#  '#bccovid',
#  '#naci',
#  '#bribery',
#  '#ml',
#  '#bassetti',
#  '#uberpromo',
#  '#standtogether',
#  '#holdon',
#  '#virus',
#  '#gloryhallelujah',
#  '#indpoli',
#  '#capacitylimits',
#  '#puertom',
#  '#foryouandforus',
#  '#dentoncounty',
#  '#endcovidtogether',
#  '#sanadistancia',
#  '#premierleague',
#  '#vaxedandboosted',
#  '#johnsonnjohnson',
#  '#notleysucks',
#  '#batman',
#  '#vaxupil',
#  '#physicaldistancing',
#  '#newsrelease',
#  '#iworkinhealthcare',
#  '#lakecountrybc',
#  '#sinovac',
#  '#saludp',
#  '#refuerzo',
#  '#doseofinfo',
#  '#infantes',
#  '#freeourchildren',
#  '#dittaturanazisanitaria',
#  '#production',
#  '#our',
#  '#sciencediplomacy',
#  '#jimmycarter',
#  '#greenbelt',
#  '#stimuluscheck',
#  '#kareemabduljabbar',
#  '#doingmypartco',
#  '#ubcp',
#  '#chocolateday',
#  '#maskson',
#  '#vaccinesaresafe',
#  '#suffolkcounty',
#  '#patheads',
#  '#gardenvisitors',
#  '#putitinmebaby',
#  '#defeatthevirus',
#  '#covidsecondwave',
#  '#illinoisgovernor',
#  '#bootiemashup',
#  '#saludparatodos',
#  '#amerks',
#  '#50ymas',
#  '#westernunion',
#  '#rippleeffect',
#  '#creepy',
#  '#accountability',
#  '#olimpiadastokio2020',
#  '#tuesdaymotivation',
#  '#cdcvaccinationcard',
#  '#loveit',
#  '#multiculturalism',
#  '#bbk8',
#  '#planetaryspeciesextinction',
#  '#medsafety',
#  '#keeping',
#  '#lovefl',
#  '#oilers',
#  '#ahy',
#  '#endthemandatesnow',
#  '#endthemandate',
#  '#baritonejoe',
#  '#vacina',
#  '#realperson',
#  '#superweek',
#  '#telegram',
#  '#weed',
#  '#leon',
#  '#etobicokelakeshore',
#  '#nyfw',
#  '#youshouldfeelbad',
#  '#ibm',
#  '#usarmy',
#  '#qrcodes',
#  '#stockstotrade',
#  '#coloniestrong',
#  '#101stlegislature',
#  '#kodakhawkeyeplant',
#  '#policy',
#  '#freshoutoffucks',
#  '#slowaf',
#  '#zapdesk',
#  '#wineandwhiskey',
#  '#livewithit',
#  '#usveterans',
#  '#rescatemosjalisco',
#  '#phish',
#  '#whole',
#  '#trump2024',
#  '#walkingaround',
#  '#peacefulprotesters',
#  '#freedomoverfear',
#  '#inoculation',
#  '#itsourshothoosiers',
#  '#thisgirlisonpfizer',
#  '#teamplacebo',
#  '#globalcitizenshipeducation',
#  '#unmask',
#  '#monderna',
#  '#native',
#  '#cruelsummer',
#  '#ps5',
#  '#avileshurtado',
#  '#mariacollege',
#  '#madisoncawthorn',
#  '#globalstudies150',
#  '#varianteomicron',
#  '#smithsonian',
#  '#rotyourbrain',
#  '#saturdaymotivation',
#  '#hardpassfornow',
#  '#fairhousing',
#  '#recomendamos',
#  '#futureofworkingwell',
#  '#geraldorivera',
#  '#psychtwitter',
#  '#fordfailedthepeople',
#  '#governmentshutdown',
#  '#survivalofthefittest',
#  '#booklover',
#  '#notvax',
#  '#boostersnow',
#  '#altmiddle',
#  '#hepatoblastoma',
#  '#attorney',
#  '#fire',
#  '#walmartcanada',
#  '#contaminate',
#  '#professora',
#  '#nye2021',
#  '#sundaymorning',
#  '#news13covid19',
#  '#protectthepack',
#  '#shesvaccinated',
#  '#return',
#  '#inmate',
#  '#ligamx',
#  '#nfid',
#  '#cdvictoria',
#  '#magaa',
#  '#shotta',
#  '#opiod',
#  '#arn',
#  '#chainchainlogistics',
#  '#tacosdoradosdepapa',
#  '#everychildmatters',
#  '#vaccinated',
#  '#aav',
#  '#trumppropagandaspewing',
#  '#koolaid',
#  '#bayside',
#  '#woocommerce',
#  '#trumpisacriminal',
#  '#shoeho',
#  '#almostthere',
#  '#alltheunvaccinatedshouldgetvaccinatedandthengotoozandgetabrain',
#  '#vaxupphillyfamilies',
#  '#coronabedrog',
#  '#cdcstudy',
#  '#weared34',
#  '#bch',
#  '#leagueofgarmin',
#  '#candaceowens',
#  '#thread',
#  '#teaching',
#  '#arabs',
#  '#staar',
#  '#takenyquil',
#  '#mafia',
#  '#hesitancy',
#  '#yass',
#  '#vons',
#  '#session',
#  '#indiananews',
#  '#beautiful',
#  '#unvacs',
#  '#limitlessinsanity',
#  '#polarbearstrong',
#  '#stayhomestaysafe',
#  '#turbines',
#  '#ivermectinsaveslives',
#  '#covidvaccination2021',
#  '#wthr',
#  '#yougogirl',
#  '#aum',
#  '#maythe4th',
#  '#happybellystrong',
#  '#protecthospitalstaff',
#  '#freetherats',
#  '#tubmanhealth',
#  '#republicanlogic',
#  '#teenvaccines',
#  '#dough',
#  '#notantivaccine',
#  '#classrooms',
#  '#wearyourmask',
#  '#asiapacific',
#  '#habitualoffender',
#  '#ripcity',
#  '#2ndcovidvaccine',
#  '#hepb',
#  '#phoenixarizona',
#  '#lowermanhattan',
#  '#april16th',
#  '#vaccinateannearundel',
#  '#keephavingagoodday',
#  '#arteaga',
#  '#ei',
#  '#mtcarmelgrovecity',
#  '#ausdoc',
#  '#clinicaltrialparticipant',
#  '#theresnopointtodienow',
#  '#friendsdontletfriendsdoitalone',
#  '#mash4077',
#  '#radtwitter',
#  '#yuresearch',
#  '#ourlittlemanpan',
#  '#governors',
#  '#4thofjuly',
#  '#gobigred',
#  '#1dosis',
#  '#gamergate',
#  '#felizmiercoles',
#  '#protecttheolds',
#  '#oakbluffs',
#  '#republicansarenazis',
#  '#praisebetoscience',
#  '#passvacinal',
#  '#campora',
#  '#acim',
#  '#otzolotepec',
#  '#minimizecontacts',
#  '#vayacondios',
#  '#peaktv',
#  '#guantanamobay',
#  '#isntitironic',
#  '#dontthrowawayyourshot',
#  '#pharmaciaupjohncompany',
#  '#basisratefallacy',
#  '#covidvax',
#  '#songbyfilter',
#  '#rhodemap',
#  '#neilyoung',
#  '#notl',
#  '#potus45',
#  '#quack',
#  '#franciscoimadero',
#  '#flatearth',
#  '#cinnamoms_',
#  '#constipatedfaceforthewin',
#  '#omicon',
#  '#babypenguin',
#  '#failedcoup',
#  '#cfs',
#  '#bernedoodle',
#  '#mumps',
#  '#5defebrero',
#  '#covid_19vacccine',
#  '#publichealthmatters',
#  '#alergia',
#  '#tdfg',
#  '#ontariosucks',
#  '#solution',
#  '#12ways',
#  '#ucpfail',
#  '#covid19bc',
#  '#gomammoths',
#  '#pfizerposse',
#  '#limitedpartnerships',
#  '#ididntanticipate',
#  '#therock',
#  '#2021islookingup',
#  '#nolaed',
#  '#bahrain',
#  '#pf4',
#  '#peoplematter',
#  '#bigyikes',
#  '#hellcat',
#  '#theantivirus',
#  '#mrnatechnology',
#  '#sask',
#  '#dontlookup',
#  '#capsulepharmacy',
#  '#vtpoli',
#  '#senatedemocrat',
#  '#getvaxmemphis',
#  '#egot',
#  '#deadly',
#  '#giveaway',
#  '#mexicounido',
#  '#needle',
#  '#krausecares',
#  '#boostedtoprotect',
#  '#vaccineapproval',
#  '#sasked',
#  '#whoisjohngalt',
#  '#zerohypocrisy',
#  '#canadianimmigration',
#  '#oneus_flashmob',
#  '#campingworldsuperbowl',
#  '#whatdotheyknow',
#  '#freehugs',
#  '#christmasspirit',
#  '#ant1news',
#  '#iheartawards',
#  '#ba2variant',
#  '#thankyouhealthcareworkers',
#  '#tedxnishtiman',
#  '#conspiracytheories',
#  '#didntgetsalinesolution',
#  '#wereinthistogether',
#  '#pmpeepee',
#  '#travelawesome',
#  '#getadamnshot',
#  '#chsld',
#  '#brianwilliams',
#  '#triplejabbed',
#  '#gallardo',
#  '#woke',
#  '#2ndshotforme',
#  '#cscmpedge',
#  '#safeair',
#  '#itsawonderfullife',
#  '#flip',
#  '#excelsiorpass',
#  '#milton',
#  '#empathy',
#  '#goodtimes',
#  '#doublevaxsummer',
#  '#onemoreway',
#  '#gousa',
#  '#pierrepoilievresupportsnazis',
#  '#isthehardestpart',
#  '#pcosawareness',
#  '#broadcaster',
#  '#escobedo',
#  '#vaccinatenewyorkaqueduct',
#  '#itsadeathsentence',
#  '#payitforward',
#  '#nothappy',
#  '#usatoday',
#  '#govmikedewine',
#  '#insurrectionhunters',
#  '#lasalle',
#  '#artshare',
#  '#communitycare',
#  '#insurrectionjanuary6th',
#  '#load',
#  '#instagramdown',
#  '#plague',
#  '#oltramiranda',
#  '#herstory',
#  '#consent',
#  '#starlink',
#  '#sarcoidosiswarriors',
#  '#clowns',
#  '#medicaltwitter',
#  '#republikkan',
#  '#365grilling',
#  '#billandmelindagatesfoundationhassaved120millionlivessinceitsinception',
#  '#leecounty',
#  '#truckersforfreedom2022',
#  '#approves',
#  '#roneycenter',
#  '#havesymptoms',
#  '#valentines',
#  '#covid19shot',
#  '#trumpbump',
#  '#salisbury',
#  '#enlightenmentmovement',
#  '#jaumave',
#  '#deltaplus',
#  '#nycbus',
#  '#relaxed',
#  '#heartfailure',
#  '#pipeline',
#  '#rootedswe',
#  '#founder',
#  '#getvax',
#  '#ingoodhealth',
#  '#hopeforthefuture',
#  '#cambma',
#  '#america',
#  '#betterdaysahead',
#  '#sofarsogood',
#  '#guycode',
#  '#factvsfiction',
#  '#sunday',
#  '#isaidplease',
#  '#newreport',
#  '#california',
#  '#nwphilly',
#  '#hadenoughyet',
#  '#23',
#  '#wishmeluck',
#  '#firstvaccineshot',
#  '#sosiran',
#  '#dothework',
#  '#cutedog',
#  '#fuckkenney',
#  '#washtenawcountyhealthdepartment',
#  '#longhaulers',
#  '#livelaughlove',
#  '#stupid',
#  '#awsgameday',
#  '#gript',
#  '#thanksdollyparton',
#  '#january6thanniversary',
#  '#bncjm',
#  '#taxco',
#  '#caitlynjenner',
#  '#misleading',
#  '#branchcovidians',
#  '#backpain',
#  '#wheresamericas',
#  '#okwx',
#  '#republicanhypocrisy',
#  '#jefaisvaccinermesparents',
#  '#yeahaight',
#  '#byecanada',
#  '#enforcing',
#  '#republicancovideconomy',
#  '#justincausedthis',
#  '#hotels',
#  '#franchi',
#  '#wrc',
#  '#houstonproud',
#  '#fracking',
#  '#moreshitsneeded',
#  '#scienceisnotpolitical',
#  '#worcester',
#  '#eluniversalplus',
#  '#msmacares',
#  '#roganmustgo',
#  '#pornografia',
#  '#civilwarsurgeons',
#  '#couriernews',
#  '#supervaxer',
#  '#leadershipmatters',
#  '#astrazeneka',
#  '#decovid',
#  '#getfuckxngvaccinated',
#  '#ultimomomento',
#  '#hediedspeakingthetruth',
#  '#racistjoe',
#  '#pediatricianmom',
#  '#sumemosesfuerzos',
#  '#letsendcovid19',
#  '#jpm2021',
#  '#covidanniversary',
#  '#pfizershot',
#  '#freadomfighters',
#  '#powerofmany',
#  '#scugogarena',
#  '#extraviada',
#  '#50a',
#  '#hermitlife',
#  '#gotti',
#  '#who',
#  '#boostimmunity',
#  '#turnonaliberal',
#  '#hpvvaxnow',
#  '#bcvaccinecard',
#  '#foleycity',
#  '#arresttrudeauf',
#  '#pfizersideeffects',
#  '#canonphotography',
#  '#faucism',
#  '#prweek',
#  ...]

# %%
hdf = pd.DataFrame(hashtags_list)
hdf
# Out:
#                                   0
# 0      #oposicionmiserableymezquina
# 1                    #moralmonsters
# 2                         #headline
# 3                             #year
# 4                       #pittsburgh
# ...                             ...
# 27835                 #pandemiclife
# 27836                  #neverforget
# 27837                 #newyorktough
# 27838                    #2021goals
# 27839                  #staydistant
#
# [27840 rows x 1 columns]

# %%
hdf.to_csv('usa_hashtags.csv')

# %% [markdown]
# ## Detecting Languages

# %%
import pycld2 as cld2

tweets = df['Text']
language = []

for each in tweets:
    text_content = str(each)
    _, _, _, detected_language = cld2.detect(text_content, returnVectors=True)
    language.append(detected_language)

# %%
len(language)
# Out:
# 423595

# %%
langs = []

for each in language:
    lang_detected = ""
    for i in range(0,len(each)):
        lang_extracted = each[i][2]
        if i != (len(each) - 1):
            lang_detected += lang_extracted + ", "
        else:
            lang_detected += lang_extracted
    langs.append(lang_detected)

# %%
len(langs)
# Out:
# 423595

# %%
df['languages'] = langs
df
# Out:
#                                                      Text languages
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 423590  do it others.... üí™üéâüíâü§ô #vaccinesave...   ENGLISH
# 423591  got my first pfizer shot today. feeling well g...   ENGLISH
# 423592  #fauciouchie #2 #vaccinated #vaccinesaveslives...   Unknown
# 423593  yay üôåüèª congrats dr. j being fully vaccin...   ENGLISH
# 423594  we all have do our part end this pandemic‚Äî g...   ENGLISH
#
# [423595 rows x 2 columns]

# %%
df[df['languages'] != 'ENGLISH'].head()
# Out:
#                                                  Text languages
# 2   juste se rappeler m. leblanc la pression que l...    FRENCH
# 13                                        vaccination   Unknown
# 15  1-je comprends exactement ce qui doit √™tre co...    FRENCH
# 35  environ 500 m√©decins sp√©cialistes participai...   Unknown
# 38  c'est bien dommage que ce soit un droit, leur ...    FRENCH

# %% [markdown]
# ## Language Translation

# %%
from deep_translator import GoogleTranslator

non_english = df[df['languages'] != 'ENGLISH']['Text']

translated = []

for each in non_english:
    translate = GoogleTranslator(source='auto', target='en').translate(each)
    translated.append(translate)

# %%
translated

# %%
#creating new_text column
df['new_text'] = df['Text']

# %%
non_english = df[df['languages'] != 'ENGLISH']

# %%
non_english.head()

# %%
indexes_list = non_english.index

# %%
indexes_list

# %%
len(indexes_list)

# %%
# range_firstNum = start_range + start_batch

# new_indexes_list = []

# for num in indexes_list:
#     new = num - range_firstNum
#     new_indexes_list.append(new)

# %%
for i in range(0,len(indexes_list)):
    index = new_indexes_list[i]
    df.iloc[index]['new_text'] = translated[i]

# %%
#check that the new_text col to see to check that the initial non-english rows have been translated
df[df['languages'] != 'ENGLISH']

# %% [markdown]
# ## Language Detection Part 2

# %%
import pycld2 as cld2

reviews = df['new_text']
language2 = []

for each in reviews:
    text_content = each
    _, _, _, detected_language = cld2.detect(text_content, returnVectors=True)
    language2.append(detected_language)

# %%
langs2 = []

for each in language2:
    lang_detected = ""
    for i in range(0,len(each)):
        lang_extracted = each[i][2]
        if i != (len(each) - 1):
            lang_detected += lang_extracted + ", "
        else:
            lang_detected += lang_extracted
    langs2.append(lang_detected)

# %%
langs2

# %%
df['new_languages'] = langs2

# %%
df

# %%
non_english2 = df[df['new_languages'] != 'ENGLISH']
non_english2

# %%
#see how many still detected as non-english, brieflcheck is it rly non english
non_english2.info()

# %%
# non_english2.to_csv('non_english2.csv')

# %% [markdown]
# ## Emoji Processing

# %%
import pickle
from emot.emo_unicode import UNICODE_EMOJI, EMOTICONS_EMO

# %%
# # 'Emoji_Dict.p'- download link https://drive.google.com/open?id=1G1vIkkbqPBYPKHcQ8qy0G2zkoab2Qv4v
with open('./Emoji_Dict.p', 'rb') as fp:
    Emoji_Dict = pickle.load(fp)
Emoji_Dict = {v: k for k, v in Emoji_Dict.items()}

# # Function for converting emojis into word
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
    return text

# %%
# TEST: line of text before emoji processing
df["Text"][32]
# Out:
# '💩trudeau 💩wants 100% vaccination 💉**new video*** via'

# %%
# TEST: convert_emoji function
convert_emojis("🍫 🤩")
# Out:
# 'chocolate_bar star-struck'

# %%
# emoji processing on df["text"] column

df["new_text"] = df["new_text"].apply(convert_emojis)
df["new_text"][32]

# %% [markdown]
# ## Emoticon Processing

# %%
# 'Emoticon_Dict.p'- download link https://drive.google.com/open?id=1HDpafp97gCl9xZTQWMgP2kKK_NuhENlE
with open('./Emoticon_Dict.p', 'rb') as fp:
    Emoticon_Dict = pickle.load(fp)
    
# Function for converting emoticons into word
def convert_emoticons(text):
    for emot in EMOTICONS_EMO:
        text = text.replace(emot, "_".join(EMOTICONS_EMO[emot].replace(",","").replace(":","").split()))
    return text

# %%
# TEST: convert_emoticons function
sentence_listtext = "Hello :-) :-)"
convert_emoticons(sentence_listtext)
# Out:
# 'Hello Happy_face_smiley Happy_face_smiley'

# %%
df["new_text"] = df["new_text"].apply(convert_emoticons)

# %% [markdown]
# ## Text File & Corpus Creation

# %%
# create txt file for each text review

# def CreateCorpusFromDataFrame(corpusfolder, df):
#     for index, r in df.iterrows():
#     # print (r['text'])
#     # print (str(index) + '.txt')
#         text = r['new_text']
#         fname = str(index)+'.txt'
#         corpusfile = open(corpusfolder+'/'+fname, "w", encoding="utf-8")
#         corpusfile.write(str(text))
#         corpusfile.close()

# CreateCorpusFromDataFrame('../text-corpus-usa', df)

# reference: https://stackoverflow.com/questions/49088978/how-to-create-corpus-from-pandas-data-frame-to-operate-with-nltk/49104725

# %%
file_directory = '../text-corpus-usa'
filename_pattern = '.+\.txt'

my_corpus = PlaintextCorpusReader(file_directory, filename_pattern)

#Print some words in specific file
test = my_corpus.words('0.txt')
print(test)
print(len(test))

# %%
#Total number of text files i.e. total number of reviews
print(len(my_corpus.fileids()))

# %%
fdist = nltk.FreqDist(test)
print(fdist.most_common(10))

# %%
# word distribution across all files
fdist_all_files = nltk.FreqDist(my_corpus.words())
print(fdist_all_files.most_common(10))

# %%
#total number of words
total_words = my_corpus.words()
print(total_words)
print(len(total_words))

# %% [markdown]
# ## Tokenization

# %%
#Creating a sorted list of texts since my_corpus.fileids() does not read texts consecutively
#EDIT RANGE
sorted_list = [f'{i}.txt' for i in range(0, 81041)]

# %%
tokenised_words = [my_corpus.words(each) for each in sorted_list]
tokenised_words

# %%
print(len(tokenised_words))
