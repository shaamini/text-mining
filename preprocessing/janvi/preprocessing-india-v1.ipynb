# %%
# !pip install emot
# !pip install symspellpy
# !pip install setuptools wheel
# !pip install spacy
# !pip install pyspellchecker
# !pip install spellchecker
# !pip install inflect
# !pip install langdetect
# !pip install google_trans_new
# !pip install deep-translator
# !pip install ekphrasis
# !pip install cdifflib
# !pip install gensim
# !pip install wordninja

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
import re, string, json

from symspellpy.symspellpy import SymSpell, Verbosity
import pkg_resources
import spacy
from tqdm.notebook import tqdm
from spellchecker import SpellChecker
import inflect

import difflib
import gensim

import pandas as pd

# %% [markdown]
# ## Text File & Corpus Creation

# %%
# create txt file for each text review

# def CreateCorpusFromDataFrame(corpusfolder, df):
#     for index, r in df.iterrows():
#     # print (r['text'])
#     # print (str(index) + '.txt')
#         text = r['translated']
#         fname = str(index)+'.txt'
#         corpusfile = open(corpusfolder+'/'+fname, "w", encoding="utf-8")
#         corpusfile.write(str(text))
#         corpusfile.close()

# CreateCorpusFromDataFrame('../text-corpus-india-v1', df)

# reference: https://stackoverflow.com/questions/49088978/how-to-create-corpus-from-pandas-data-frame-to-operate-with-nltk/49104725

# %%
file_directory = '../../text-corpus-india-v1'
filename_pattern = '.+\.txt'

my_corpus = PlaintextCorpusReader(file_directory, filename_pattern)

#Print some words in specific file
test = my_corpus.words('0.txt')
print(test)
print(len(test))
# Out:
# ['soniya', 'mummy', 'hoti', 'toh', 'covid', 'me', ...]
# 26

# %%
#Total number of text files i.e. total number of reviews
print(len(my_corpus.fileids()))
# Out:
# 95188

# %%
fdist = nltk.FreqDist(test)
print(fdist.most_common(10))
# Out:
# [('soniya', 1), ('mummy', 1), ('hoti', 1), ('toh', 1), ('covid', 1), ('me', 1), ('magic', 1), ('stick', 1), ('ghuma', 1), ('ke', 1)]

# %% [markdown]
# ## Tokenization

# %%
#Creating a sorted list of texts since my_corpus.fileids() does not read texts consecutively
sorted_list = [f'{i}.txt' for i in range(38000, 41000)]

# %%
tokenised_words = [my_corpus.words(each) for each in sorted_list]
tokenised_words
# Out:
# [['finally', 'covid', '19', 'vaccine'],
#  ['assam', 't', 'covid', 'r', 'vaccine', 'ahi', ...],
#  ['first', 'batch', '#', 'covidvaccine', 'ne', ...],
#  ['state', 'task', 'force', 'stf', 'held', 'it', 'is', ...],
#  ['strengthening', 'efforts', 'health', 'counselors', ...],
#  ['covid', 'vaccine', 'arrive', 'at', '20', 'cartons', ...],
#  ['#', 'new_video_in_hindi', 'The', 'government', ...],
#  ['Corona', 'vaccine', '#', 'covidvaccine', '#', ...],
#  ['this', 'is', 'what', 'entire', 'country', 'India', ...],
#  ['lowest', 'case', '#', 'vaccine', 'is', 'ready', '#', ...],
#  ['I', 'want', 'to', 'avoid', 'children', 'getting', ...],
#  ['if', 'bjp', 'will', 'come', 'power', ',', 'every', ...],
#  ['#', '4newstrains', '...', 'is', 'new', 'challenge', ...],
#  ['Something', 'happy', 'every', 'time', 'I', 'visit', ...],
#  ['beware', 'indian', 'cargo', 'planes', 'with', ...],
#  ['live', 'update', 'out', '6', '#', 'covidvaccine', ...],
#  ['yes', ',', 'students', 'can', 'go', 'attend', ...],
#  ['great', 'effort', 'eradicate', '#', 'covid19', '.', ...],
#  ['has', 'updated', 'info', 'now', ':', 'sg', '493', ...],
#  ['#', 'vaccinestrategy', 'green', 'corridor', 'made', ...],
#  ['welcome', '#', 'bengaluru', ',', '#', 'covid', '#', ...],
#  ['wait', 'is', 'finally', 'over', '.', 'first', ...],
#  ['#', 'covidvaccine', 'bengaluru', ':', 'spicejet', ...],
#  ['Congratulations', 'Delhi', 'The', 'first', ...],
#  ['scoop', '1st', 'look', 'it', 'suggests', 'it', '’', ...],
#  ['preparatory', 'meeting', 'regarding', 'covid', ...],
#  ['nepal', 'desert_island', '️', 'desert_island', '️', ...],
#  ['#', 'seruminstituteofindia', '#', 'covidvaccine', ...],
#  ['#', 'ahmedabad', ':', 'first', 'consignment', ...],
#  ['am', 'waiting', 'take', 'covid', 'vaccine', 'head', ...],
#  ['covid', 'vaccine', 'mi', 'mahu', 'libeyne', '.'],
#  ['"', 'Survey', 'Bhavantu', 'Sukhin', ':', 'Survey', ...],
#  ['#', 'covidvaccine', 'If', 'someone', 'is', 'taking', ...],
#  ['boom', 'rolling_on_the_floor_laughingrolling_on_the_floor_laughingrolling_on_the_floor_laughing', ...],
#  ['boom', 'rolling_on_the_floor_laughingrolling_on_the_floor_laughingrolling_on_the_floor_laughing', ...],
#  ['blo', 'at', 'vasant', 'kunj', 'sector', 'c', ...],
#  ['When', 'the', 'car', 'carrying', 'the', 'Kovid', ...],
#  ['good', 'bm', 'story', 'tracking', 'covid', 'vaccine', ...],
#  ['first', 'batch', 'covid', '-', '19', 'vaccine', 'at', ...],
#  ['so', 'when', 'is', 'our', 'hardworking', 'pm', ...],
#  ['#', 'delhi', '|', 'first', 'consignment', '#', ...],
#  ['proud', 'moment', 'pune', '.', 'trucks', 'carrying', ...],
#  ['why', 'is', 'spicejet', 'still', 'flying', 'under', ...],
#  ['we', 'need', 'debunk', 'myths', 'about', 'covid', ...],
#  ['first', 'consignment', '#', 'covid19', '#', ...],
#  ['just', 'in', ':', 'lands', 'with', '#', ...],
#  ['#', 'covidvaccine', 'started', 'it', 'is', 'journey', ...],
#  ['#', 'श', 'ु', 'भ', 'ा', 'र', 'ं', 'भ_श', 'ु', 'भ', ...],
#  ['covid19', '|', 'carried', 'india', '’', 's', 'first', ...],
#  ['wow', 'wel', 'come', 'hyd', 'covid', 'vaccine'],
#  ['what', 'positive', 'news', 'start', 'day', '1st', ...],
#  ['how', 'can', 'saying', '#', 'covid', 'vaccines', ...],
#  ['covid', '-', '19', 'vaccine', 'starts', 'it', 'is', ...],
#  ['aam', 'aadmi', 'party', 'jammu', 'jk', 'demands', ...],
#  ['this', 'is', 'first', 'lot', 'covid', '-', '19', ...],
#  ['spicejet', 'has', 'carried', 'india', '’', 's', ...],
#  ['#', 'breaking', ':', 'first', 'lot', 'covid', '-', ...],
#  ['अच', '्', 'छ', 'े', 'द', 'ि', 'न', 'serum', ...],
#  ['india', 'wants', 'serum', 'institute', 'lower', ...],
#  ['will', 'pfizer', 'covid', '-', '19', 'vaccine', ...],
#  ['last', '-', 'mile', 'covid', 'vaccine', 'delivery', ...],
#  ['health', 'minister', 'assures', 'transparency', ...],
#  ['thermometersyringe', 'aussies', 'will', 'be', ...],
#  ['hopefully', 'johor', 'does', 'same', 'as', 'well', ...],
#  ['so', 'i', '’', 've', 'had', 'first', 'dose', ...],
#  ['pm', 'shri', 'narendra', 'modi', "'", 's', 'closing', ...],
#  ['tamil', 'nadu', 'govt', 'doctors', 'are', ...],
#  ['new', 'sources', 'found', 'that', 'vitamin', 'd', ...],
#  ['govt', 'india', 'will', 'pay', 'gst', 'covid', '-', ...],
#  ['covid', 'vaccine', 'se', 'jyada', 'we', 'need', ...],
#  ['#', 'vaccine', 'first', 'batch', '/', 'consignment', ...],
#  ['yes', 'index_pointing_upcheck_mark_button', 'also', ...],
#  ['upside', '-', 'down_face', '#', 'russia', 'try', ...],
#  ['no', 'injection', 'are', 'available', 'due', 'covid', ...],
#  ['vaccine', 'rolled', 'out', 'not', 'lobbies', 'nd', ...],
#  ['times', 'covid', ',', 'when', 'our', 'indian', ...],
#  ['was', 'so', 'focused', 'steering', 'discussion', ...],
#  ['Finally', 'covid', '-', '19', 'vaccine', 'God', 'is', ...],
#  ['agar', 'corona', 'ke', 'sath', 'ye', 'food', 'waste', ...],
#  ['pm', 'modi', "'", 's', 'closing', 'remarks', 'at', ...],
#  ['*', 'Vaccines', 'are', 'still', 'in', 'trial', ...],
#  ['our', 'vaccine', 'may', 'have', 'taken', 'time', ',', ...],
#  ['we', '’', 've', 'made', '#', 'covidvaccine', 'less', ...],
#  ['raj', 'ji', ',', 'young', 'dynast', 'raga', 'has', ...],
#  ['over', 'million', 'people', 'beijing', 'have', ...],
#  ['uae', 'has', 'administered', '1', ',', '167', ',', ...],
#  ['#', 'cooperativefedralism', 'at', 'work', '.', 'pm', ...],
#  ['live', ':', 'pm', 'shri', 'is', 'closing', 'remarks', ...],
#  ['by', 'way', 'how', 'is', 'your', 'region', 'doing', ...],
#  ['it', 'is', 'ironic', 'that', 'same', 'person', 'who', ...],
#  ['now', 'it', 'is', 'impossible', 'ec', 'win', 'even', ...],
#  ['big', 'breaking', ':', 'reports', 'that', 'cost', ...],
#  ['The', 'main', 'reason', 'for', 'the', 'end', 'of', ...],
#  ['pm', 'shri', 'is', 'closing', 'remarks', 'at', ...],
#  ['follow', 'us', '-', 'serum', "'", 's', "'", ...],
#  ['pm', 'modi', "'", 's', 'closing', 'remarks', 'at', ...],
#  ['india', 'is', 'working', '4', 'other', 'covid', ...],
#  ['#', 'covidvaccine', '#', 'nomo_lacke_crank'],
#  ['first', 'purchase', 'order', '#', 'covidvaccine', ...],
#  ['centre', 'says', 'that', 'there', 'will', 'be', ...],
#  ['Corona', 'vaccine', ':', 'Government', 'of', 'India', ...],
#  ['covid', 'vaccines', 'likely', 'reach', 'gujarat', ...],
#  ['indian', 'pm', 'modi', "'", 's', 'meet', 'with', ...],
#  ['because', 'as', 'i', 'know', 'pfizer', 'vaccine', ...],
#  ['nice', 'see', 'mahindra', 'supro', 'is', 'taking', ...],
#  ['i', 'take', '1', 'hour', 'looking', 'at', ...],
#  ['bahana', '14th', 'feb', '2021', 'two_hearts', '#', ...],
#  ['26th', 'jan', 'would', 'have', 'been', 'better', ...],
#  ['date', 'arrival', 'covid', 'vaccine', 'quantity', ...],
#  ['th', 'heat', 'parliamentary', 'dissolution', 'covid', ...],
#  ['rt', ':', 'importing', 'vaccines', 'made', 'us', ...],
#  ['pope', 'francis', 'calls', 'opposition', 'covid', ...],
#  ['nepal', 'fm', "'", 's', 'india', 'visit', ':', 'key', ...],
#  ['covid', '-', '19', ':', 'brazil', 'president', ...],
#  ['west', 'bengal', 'cm', 'mamata', 'banerjee', ...],
#  ['grateful', '#', 'mamatabanerjee', 'who', 'promised', ...],
#  ['at', 'present', 'there', 'is', 'no', 'application', ...],
#  ['delhi', '’', 's', 'blu', 'print', 'introduce', ...],
#  ['india', 'ready', 'save', 'humanity', 'with', 'two', ...],
#  ['last', 'night', "'", 's', 'weird', 'dream', ':', ...],
#  ['another', 'india', '#', 'covidvaccine', 'success', ...],
#  ['promoting', 'confidence', 'covid', '-', '19', ...],
#  ['since', 'modi', 'govt', 'has', 'approved', 'bharat', ...],
#  ['there', 'should', 'be', 'no', 'politics', 'covid', ...],
#  ['i', 'doubt', ',', 'covid', 'warriors', 'are', ...],
#  ['they', 'spent', '12', 'years', 'solving', 'puzzle', ...],
#  ['mamata', 'ji', 'announced', 'free', 'vaccine', ...],
#  ['india', 'under', 'takes', 'lead', 'introducing', ...],
#  ['great', 'news', 'people', 'bengal', '.', 'mamata', ...],
#  ['enjoyed', 'this', 'quick', 'video', 'debunking', ...],
#  ['Alhamdulillah', 'today', 'I', 'took', 'corona', ...],
#  ['has', 'india', 'India', 'made', 'vaccine', 'syringe', ...],
#  ['covid', 'vaccine', 'facts', 'vs', 'fiction'],
#  ['got', 'himself', 'vaccinated', 'prove', 'his', ...],
#  ['Have', 'heard', 'that', '#', 'covidvaccine', 'is', ...],
#  ['#', 'chinese', 'doctor', 'claims', 'that', ...],
#  ['it', 'is', 'astonishing', 'see', 'west', 'bengal', ...],
#  ['#', 'covid19', '#', 'covidvaccine', '#', ...],
#  ['what', 'extraordinary', 'start', '2021', 'wishing', ...],
#  ['humanity', 'inventing', 'vaccine', 'deal', 'with', ...],
#  ['there', 'was', 'no', 'hurry', 'do', 'this', 'trial', ...],
#  ['free', '#', 'covidvaccine', 'everyone', 'bengal', ...],
#  ['before', 'covid', 'vaccine', 'roll', 'out', '16th', ...],
#  ['The', 'word', '#', 'India', 'India', 'written', 'on', ...],
#  ['i', 'was', 'among', 'more', 'than', '70', ',', '000', ...],
#  ['done', 'with', 'first', 'dose', 'covid', '-', '19', ...],
#  ['Is', 'the', 'covid', 'vaccine', 'safe', '?'],
#  ['so', 'nigerian', 'govt', 'can', 'meet', 'world', ...],
#  ['Good', 'evening', 'everyone', 'from', 'Al', 'Bateen', ...],
#  ['i', '’', 'll', 'be', 'taking', 'test', 'as', 'i', ...],
#  ['Myanmar_', '(', 'Burma', ')', 'myanmar', 'has', ...],
#  ['nigerian', 'govt', 'is', 'failure', '...', 'we', ...],
#  ['new', 'covid', 'strain', 'south', 'african', 'one', ...],
#  ['Trust', 'me', 'Mamata', 'Sarkar', 'is', 'by', 'your', ...],
#  ['india', '”', 's', 'covid', 'recovery', 'rate', '96', ...],
#  ['jaiho', 'modi', 'g', 'india', 'ready', 'save', ...],
#  ['In', 'Delhi', ',', '89', 'hospitals', 'have', 'been', ...],
#  ['myanmar', 'has', 'ordered', '30', 'million', 'covid', ...],
#  ['india', 'ready', 'save', 'humanity', 'with', 'two', ...],
#  ['was', 'not', 'there', 'clear', 'indication', 'that', ...],
#  ['In', 'Delhi', ',', '89', 'hospitals', 'have', 'been', ...],
#  ['dr', 'saheer', 'sainalabdeen', ',', 'specialist', ...],
#  ['letter', 'frontline', 'workers', ',', 'west', ...],
#  ['just', 'took', 'first', 'dose', 'covid', '-', '19', ...],
#  ['india', 'ready', 'save', 'humanity', 'with', 'two', ...],
#  ['covid', 'number', ':', '19', 'date', ':', '16', ...],
#  ['It', 'is', 'a', 'matter', 'of', 'great', 'happiness', ...],
#  ['#', 'Delhi', 'Prime', 'Minister', 'Narendra', 'Modi', ...],
#  ['your', 'questions', 'about', 'covid', '-', '19', ...],
#  ['pfizer', ',', 'moderna', 'vaccines', 'may', ...],
#  ['be', 'prepared', 'receive', 'first', 'supply', ...],
#  ['wartime', 'manner', 'govt', 'should', 'give', ...],
#  ['4', 'challenges', 'fir', 'india', '’', 's', 'covid', ...],
#  ['give', 'covid', 'vaccine', '&', 'amp', ';', 'we', ...],
#  ['days', 'after', 'participating', 'covid', '-', '19', ...],
#  ['queen', 'duke', 'edinburgh', 'have', 'received', ...],
#  ['#', 'jaihonamo', 'india', '&', 'amp', ';', 'indian', ...],
#  ['sir', ',', 'smooth', 'seamless', 'vaccine', 'access', ...],
#  ['finally', 'got', 'my', '1st', 'dose', 'covid', '-', ...],
#  ['mongolia', 'has', 'requested', 'india', 'covid', ...],
#  ['#', 'nepal', 'request', 'india', 'procure', ...],
#  ['whenever', 'person', 'tweet', 'he', '/', 'she', ...],
#  ['covaxin', 'phase', '-', '3', 'trial', ':', 'covid', ...],
#  ['india', '&', 'amp', ';', 'covid', 'vaccine', ...],
#  ['#', 'bjpsupporters', 'tharpozhudhu', 'munnindru', ...],
#  ['it', 'is', 'really', 'great', 'moment', '.', 'no', ...],
#  ['new', 'study', 'provides', 'early', 'evidence', ...],
#  ['salute', 'all', 'scientist', ',', 'doctors', ...],
#  ['vaccine', 'french', 'relief', 'covid', '.'],
#  ['priority', 'will', 'be', 'given', 'healthcare', ...],
#  ['Kovid', 'vaccination', 'campaign', 'will', 'start', ...],
#  ['indian', 'vaccines', 'would', 'be', 'safer', ...],
#  ['we', 'all', 'are', 'proud', 'your', 'leadership', ...],
#  ['but', 'aadar', 'poonawala', 'had', 'confirmed', ...],
#  ['pan', 'india', 'roll', 'out', '#', 'covidvaccine', ...],
#  ['#', 'covid', '#', 'vaccine', 'leading', 'by', ...],
#  ['surreal', 'think', 'that', 'one', 'week', 'now', ',', ...],
#  ['The', 'moment', 'the', 'nation', 'was', 'waiting', ...],
#  ['Kovid', 'vaccination', 'campaign', 'will', 'start', ...],
#  ['covid', '-', '19', 'vaccine', 'free', 'all', 'uae', ...],
#  ['less', 'than', 'year', ',', 'after', 'first', 'case', ...],
#  ['brazilian', 'president', 'writes', 'indian', 'pm', ...],
#  ['followed', 'by', 'those', 'above', '50', 'years', ...],
#  ['breaking', 'news', ':', 'covid', 'vaccine', 'roll', ...],
#  ['mere', 'do', 'anmol', 'ratan', 'musical_notes', '#', ...],
#  ['one', 'is', '#', 'coronil', 'other', 'is', '#', ...],
#  ['we', 'do', 'not', 'have', 'data', 'how', 'pandemic', ...],
#  ['do', 'you', 'think', '#', 'covid_19', 'vaccine', ...],
#  ['efficacy', 'bharat', 'biotech', 'icmr', "'", 's', ...],
#  ['what', 'is', 'this', 'new', 'strain', 'covid', ...],
#  ['no', 'covid', 'no', 'vaccine', 'drama', 'fr', 'loot'],
#  ['experts', 'unsure', 'how', 'long', 'covid', ...],
#  ['my', 'first', 'yes', ',', '#', 'covid19', '#', ...],
#  ['do', 'watch', '#', 'watch', '#', 'twitchstreamer', ...],
#  ['just', 'train', 'amazon', 'delivery', 'guys', 'give', ...],
#  ['First', 'of', 'all', ',', 'Modi', 'himself', ...],
#  ['school', 'fail', 'scoundrel', 'modi', '&', 'amp', ...],
#  ['allergic', 'reactions', 'covid', '-', '19', ...],
#  ['us', 'reports', 'more', 'severe', '"', 'exceedingly', ...],
#  ['pm', 'lee', 'hsien', 'loong', 'received', 'his', ...],
#  ['king', 'salman', 'received', 'his', 'first', 'dose', ...],
#  ['iran', 'leader', 'bans', 'import', 'u', '.', 's', ...],
#  ['#', 'saudiarabia', '’', 's', 'king', 'salman', 'bin', ...],
#  ['take', 'look', 'know', 'all', 'about', 'phased', ...],
#  ['syringe', '@', 'vaccine', 'center', 'covid', '-', ...],
#  ['4000', 'people', 'us', '&', 'amp', ';', '1325', ...],
#  ['why', 'not', 'another', 'political', 'party', ...],
#  ['3k', 'patient', 'covid', 'vaccine', 'was', ...],
#  ['#', 'newsupdate', '#', 'dryrun', '#', 'bhadrak', '#', ...],
#  ['"', 'on', 'sunday', 'at', '5pm', ',', 'we', ...],
#  ['Today', ',', 'the', 'dry', 'run', 'of', ...],
#  ['Number', 'of', 'corona', 'testing', 'in', 'Gujarat', ...],
#  ['covid', 'vaccine', 'breaking', ':', 'pm', 'modi', ...],
#  ['china', "'", 's', 'sinopharm', 'covid', 'vaccine', ...],
#  ['Talk', 'about', 'your', 'intention', ',', 'Rahul', ...],
#  ['provide', 'covid', 'vaccines', 'indian', 'open', ...],
#  ['glad', 'volunteer', 'testing', 'covid', 'vaccine', ...],
#  ['provide', 'covid', 'vaccines', 'indian', 'open', ...],
#  ['provide', 'covid', 'vaccines', 'indian', 'open', ...],
#  ['"', 'so', 'we', 'have', 'now', 'tested', '16', ...],
#  ['covid', '-', '19', 'vaccine', 'test_tubednamicrobe'],
#  ['so', 'fact', 'check', 'says', ':', 'nurse', 'was', ...],
#  ['israel', "'", 's', 'covid', 'vaccine', 'rollout', ...],
#  ['There', 'is', 'no', 'law', 'to', 'force', 'the', ...],
#  ['thinking', 'take', 'covid', 'vaccine', 'already', ...],
#  ['who', ',', 'billgates', '&', 'amp', ';', 'many', ...],
#  ['covaxin', 'might', 'be', 'atleast', '60', '%', ...],
#  ['#', 'covid19', '#', 'covidsecondwave', '#', ...],
#  ['whoa', 'check', 'this', 'out', '.', 'pm', 'lee', ...],
#  ['dgca', 'releases', 'guidelines', 'transportation', ...],
#  ['will', 'bed', 'ridden', 'old', 'people', '/', ...],
#  ['no', 'problem', 'tp', 'yadav', 'do', 'not', 'take', ...],
#  ['pfizer', 'n', 'biontech', 'assert', 'that', ...],
#  ['meeting', '#', 'covidvaccine', 'between', 'pm', ...],
#  ['first', 'shot', 'covid', 'vaccine', 'done', ...],
#  ['Today', 'pm', 'lee', 'got', 'covid', 'vaccine', ...],
#  ['kudos', 'indian', 'scientists', '&', 'amp', ';', ...],
#  ['if', 'you', 'don', '’', 't', 'want', 'covid', ...],
#  ['what', 'if', '#', 'covidvaccine', 'is', 'beginning', ...],
#  ['wrt', 'travel', 'uk', 'covid', '-', '19', 'test', ...],
#  ['covid', 'vaccine', '...'],
#  ['victory', 'covid', 'warriors', 'n', 'covid', ...],
#  ['Corona', 'vaccination', 'will', 'be', 'given', 'the', ...],
#  ['covid', '-', '19', 'vaccine', 'dry', 'run', 'be', ...],
#  ['have', 'you', 'had', 'covid', 'vaccine', 'yet', 'is', ...],
#  ['ingmt', '—', 'india', 'oks', 'astrazeneca', ...],
#  ['kashmiri', 'girls', 'making', 'snow', 'sculpture', ...],
#  ['you', 'deserve', '1st', 'vaccine', 'because', 'your', ...],
#  ['1st', 'vaccine', 'against', 'covid', '-', '19', ...],
#  ['watch', ':', '2nd', 'round', '#', 'covidvaccine', ...],
#  ['portuguese', 'nurse', 'aged', '41', ',', 'without', ...],
#  ['breaking', ':', 'prime', 'minister', 'lee', 'hsien', ...],
#  ['heard', 'some', 'leading', 'health', 'organization', ...],
#  ['india', 'could', 'get', 'nasal', 'vaccine', ...],
#  ['india', "'", 's', 'second', 'dry', 'run', 'covid', ...],
#  ['why', 'who', 'is', 'trillianis', 'to', 'follow', ...],
#  ['trump', 'is', 'gone', ',', 'covid', 'vaccine', 'is', ...],
#  ['ask', 'yourself', 'why', 'more', 'money', 'was', ...],
#  ['it', 'is', 'only', '#', 'india', 'who', 'can', ...],
#  ['tomorrow', 'flight', 'airplane', '️', 'will', ...],
#  ['"', 'its', 'is', 'very', 'safe', 'us', '",', 'says', ...],
#  ['The', 'organization', 'is', 'more', 'than', ...],
#  ['how', 'has', '#', 'covid_19', 'pandemic', 'impacted', ...],
#  ['"', 'very', 'trustful', 'indian', 'pharma', ...],
#  ['i', 'take', 'look', 'back', 'at', 'last', '10', ...],
#  ['world', 'health', 'organization', 'has', 'announced', ...],
#  ['#', 'Riyadh_Lan', '#', 'health_passport', '#', ...],
#  ['#', 'saudi', 'ministry', 'health', 'cooperation', ...],
#  ['no', '.', 'he', 'may', 'advice', 'government', ...],
#  ['this', 'service', 'aims', 'confirm', 'that', ...],
#  ['The', 'spoons', 'we', 'are', 'saying', '"', 'the', ...],
#  ['may', 'i', 'know', 'what', 'is', 'procedure', 'get', ...],
#  ['nasal', 'covid', '-', '19', 'vaccine', 'could', 'be', ...],
#  ['i', 'think', 'only', 'way', 'combat', 'covid', 'is', ...],
#  ['Tukde', 'tukde', 'gang', 'was', 'saying', '"', 'The', ...],
#  ['co', '-', 'win', 'app', ':', 'how', 'register', ...],
#  ['replugging', 'webinar', '#', 'covidvaccine', 'ask', ...],
#  ['dr', '.', 'john', 'still', 'arguing', '#', ...],
#  ['Sub', '-', 'Divisional', 'Officer', 'should', ...],
#  ['but', 'covid', 'vaccine', 'has', 'a', 'chip', 'to', ...],
#  ['few', 'days', 'ago', ',', 'india', 'approved', 'two', ...],
#  ['vaccines', 'are', 'safer', 'disease', 'prevention', ...],
#  ['#', 'hospital', '#', 'medicalstaff', 'while', '#', ...],
#  ['confused', 'about', 'covid', '-', '19', 'vaccines', ...],
#  ['right_arrow', '️', 'Two', 'doses', 'of', 'trial', ...],
#  ['covid', '-', '19', ':', 'single', 'vaccine', 'dose', ...],
#  ['this', 'needs', 'proper', 'investigation', ',', ...],
#  ['just', 'in', ':', 'line', 'with', 'our', 'business', ...],
#  ['#', 'multibaggers', '#', 'cadila', 'hav', 'got', '#', ...],
#  ['so', 'my', 'company', 'just', 'required', 'us', ...],
#  ['#', 'unite2fightcorona', '#', 'indiafightscorona', ...],
#  ['today', 'covid', '-', '19', 'india', ':', '10', '.', ...],
#  ['few', 'days', 'ago', ',', 'india', 'approved', 'two', ...],
#  ['my', 'my', 'friends', 'reaction', 'over', 'covid', ...],
#  ['few', 'days', 'ago', ',', 'india', 'approved', 'it', ...],
#  ['"#', 'covid_19', '#', 'vaccine', 'tracker', ...],
#  ['these', 'are', 'my', 'recovery', 'scores', 'hrv', ...],
#  ['pfizer', '-', 'biontech', 'moderna', 'vaccines', ',', ...],
#  ['do', 'you', 'know', 'what', 'documents', 'are', ...],
#  ['"', 'india', 'becomes', 'vaccination', '"', '-', ...],
#  ['i', 'miss', 'japan', 'so', 'muchcrying_face', ...],
#  ['our', 'special', '1hr', 'edition', 'heart', 'matter', ...],
#  ['moderna', '’', 's', 'covid', '-', '19', 'vaccine', ...],
#  ['india', "'", 's', '4states', 'himachal', ',', 'mp', ...],
#  ['it', 'is', 'time', 'some', ...],
#  ['#', 'vaccine', '#', 'beer', '#', 'covidvaccine', '#', ...],
#  ['vaccine', 'free', 'mein', 'lagwa', 'lo', '.', ...],
#  ['new', 'arrival', 'guidelines', '#', 'uk', ...],
#  ['mihringte', 'khawsak', 'nunphung', 'tibuaitu', ...],
#  ['ex', 'abvp', 'leader', 'current', 'rss', 'member', ...],
#  ['incidents', 'shaheen', 'baghdad', ',', 'jnu', ',', ...],
#  ['incidents', 'shaheen', 'baghdad', ',', 'jnu', ',', ...],
#  ['german', 'readout', 'is', 'much', 'shorter', '.', ...],
#  ['co', '-', 'win', 'app', ':', 'how', 'register', 'co', ...],
#  ['#', 'india', "'", 's', 'prime', 'minister', 'held', ...],
#  ['did', 'not', 'india', 'express', 'interest', ...],
#  ['which', 'covid', 'vaccine', 'will', 'you', 'opt'],
#  ['uk', 'parliament', ':', '2nd', 'covid', 'vaccine', ...],
#  ['covid', 'vaccine', 'is', 'not', 'available', 'as', ...],
#  ['#', 'covid19', '#', 'covidvaccineindia', '#', ...],
#  ['I', 'am', 'at', 'vaccine', 'center', 'covid', '-', ...],
#  ['is', 'pleased', 'invite', 'you', 'webinar', '*', ...],
#  ['hasty', 'approval', 'has', 'raised', 'questions', ...],
#  ['"', 'we', 'are', 'now', 'looking', 'at', 'post', '-', ...],
#  ['covid', '/', 'corona', '/', 'made', 'india', ...],
#  ['h', '.', 'e', '.', 'minister', 'dr', '.', 'abdul', ...],
#  ['faqs', 'covid', '-', '19', 'vaccine'],
#  ['loudly_crying_faceloudly_crying_faceloudly_crying_face', 'not', ...],
#  ['due', 'apprehension', 'associated', 'with', 'covid', ...],
#  ['sir', 'mubarak', 'ho', 'i', 'lost', 'family', ...],
#  ["'", 'will', 'help', 'intensify', 'fight', "':", ...],
#  ['wondering', 'if', 'process', 'making', '#', ...],
#  ['covid', 'vaccine', 'rollout', 'set', 'begin', 'next', ...],
#  ['do', 'you', 'know', 'what', 'documents', 'are', ...],
#  ['india', "'", 's', 'first', '#', 'covidvaccine', ...],
#  ['14', 'million', 'covid', 'vaccine', 'doses', 'have', ...],
#  ['vaccine', 'or', 'no', 'vaccine', ',', 'coronavirus', ...],
#  ['when', 'country', 'is', 'having', 'over', 'thousand', ...],
#  ['covid', 'vaccine', 'reach', 'delhi', 'next', 'week', ...],
#  ['threat', 'mutant', 'covid', 'strain', 'prompted', ...],
#  ['new', 'video', '#', 'delhiguest', '#', ...],
#  ['covid', 'vaccine', '‘', 'developed', '’', 'by', ...],
#  ['covid', '-', '19', 'vaccine', 'who', 'chief', ...],
#  ['covid', 'vaccine', 'trials', 'being', 'conducted', ...],
#  ['brainless', ',', 'the', 'country', 'is', 'declared', ...],
#  ['i', 'just', 'had', 'my', 'covid', '-', '19', ...],
#  ['3', 'people', 'vaccinated', 'from', 'covid', 'died', ...],
#  ['england', 'enter', 'toughest', 'covid', 'lockdown', ...],
#  ['The', 'Chief', 'Minister', "'", 's', 'big', ...],
#  ['africa', 'loses', 'estimated', '$', '50', 'billion', ...],
#  ['good', 'news', '#', 'kingdomofsaudiarabia', ':', '1', ...],
#  ['ecuador', 'ambassador', 'india', 'hector', 'cueva', ...],
#  ['team', 'falconn', ',', 'is', 'definitely', 'working', ...],
#  ['serum', 'institute', ',', 'bharat', 'biotech', ...],
#  ['AustraliaUnited_KingdomLiberia', ':', 'we', 'need', ...],
#  ['wonderful', '...', 'next', 'they', 'shall', 'send', ...],
#  ['#', 'doctors', 'who', 'are', 'being', 'given', ...],
#  ['got', 'my', '1st', '#', 'pfizer', 'covid', '#', ...],
#  ['your', 'thinking', 'about', 'covid', 'vaccine', ...],
#  ['kind', 'request', 'ji', 'please', 'administer', ...],
#  ['we', '&', 'amp', ';', 'scientific', 'community', ',', ...],
#  ['13th', 'january', '1', '.#', 'covidvaccine', ...],
#  ['What', 'should', 'be', 'done', 'to', 'the', 'poor', ...],
#  ['good', 'evening', '.', 'some', 'politicians', 'are', ...],
#  ['hurry', 'do', 'not', 'download', 'any', 'app', ...],
#  ['it', 'is', 'great', 'see', 'india', 'leadership', ...],
#  ['#', 'vaccine', 'registration', '#', ...],
#  ['covid', '19', '...', 'vaccine', 'our', 'doctors', ...],
#  ['opposition', 'india', 'fears', 'that', 'covid', ...],
#  ['good', 'counter', 'brainless', 'leaders', 'seeram', ...],
#  ['‘', 'india', 'must', 'develop', 'own', 'standards', ...],
#  ['anupam', 'kher', "'", 's', 'mother', 'dulari', ...],
#  ['india', 'may', 'take', 'time', ',', 'but', 'hard', ...],
#  ['despite', 'being', 'doctor', ',', 'i', 'am', 'not', ...],
#  ['jaiho', 'modi', 'g', 'anupam', 'kher', "'", 's', ...],
#  ['there', 'are', 'currently', '52', 'covid', '-', '19', ...],
#  ['based', 'feedback', 'dry', 'run', ',', 'health', ...],
#  ['covid', '-', '19', 'vaccine', '|', 'first', ...],
#  ['serum', 'institute', ',', 'bharat', 'biotech', ...],
#  ['team', 'schoollog', 'bid', 'adieu', 'eventful', ...],
#  ['requirement', 'covid', '-', '19', 'vaccine', 'is', ...],
#  ['spirit', 'igwebuike', 'strength', 'community', ',', ...],
#  ['makar', 'sankrati', 'k', 'din', 'aa', 'p', 'leave', ...],
#  ['serum', 'institute', 'india', 'bharat', 'biotech', ...],
#  ['There', 'is', 'no', 'vaccine', ',', 'the', ...],
#  ['bjp', 'government', 'has', 'politically', 'misused', ...],
#  ['flatterers', 'do', 'you', 'need', 'burnol', ...],
#  ['it', 'implies', 'vips', 'not', 'believe', ...],
#  ['doubting', 'covid', '-', '19', 'vaccines', ',', 'is', ...],
#  ['serum', 'institute', 'india', 'bharat', 'biotech', ...],
#  ['"', 'swipe', 'up', 'get', 'your', 'covid', 'vaccine', ...],
#  ['what', 'has', 'possibility', '#', 'halal', '#', ...],
#  ['Have', 'come', 'out', 'on', 'the', 'path', 'of', ...],
#  ['aside', ':', 'i', 'think', 'almost', 'all', ...],
#  ['anything', 'over', '50', '-', '60', '%', 'is', ...],
#  ['covid', 'vaccine', 'doses', 'secured', 'by', 'india', ...],
#  ['The', 'initial', 'studies', 'we', 'are', 'done', ...],
#  ['Salute', 'to', 'the', 'world', ',', 'then', 'why', ...],
#  ['just', 'like', '#', 'falsepositive', 'australia', ...],
#  ['vaccine', 'cure', 'covid', '-', '19', 'developing', ...],
#  ['very', 'sorry', 'say', 'congress', 'has', 'stoop', ...],
#  ['new', 'covid', 'mutant', 'south', 'africa', '“', ...],
#  ['i', '’', 've', 'done', 'enough', 'covid', 'tests', ...],
#  ['now', ',', 'office', ',', 'debate', 'going', '-', ...],
#  ['#', 'master', 'movie', 'is', 'covid', '-', '19', ...],
#  ['cpm', 'govt', 'kerala', 'started', 'grabbing', ...],
#  ['there', 'is', 'high', 'possibility', 'that', 'those', ...],
#  ['gives', 'thumbs', 'up', 'india', '’', 's', '‘', ...],
#  ['United_States', ':', 'qualification', 'required', ...],
#  ['as', 'african', ',', 'i', 'am', 'disappointed', 'at', ...],
#  ['cabinet', 'approves', 'proposal', 'by', 'health', ...],
#  ['cabinet', 'ministers', 'grants', 'approval', ...],
#  ['if', 'dcgi', 'says', 'that', 'approved', 'covid', ...],
#  ['The', 'point', 'is', ',', '"', 'alcohol', 'can', ...],
#  ['register', ',', 'eat', 'good', 'meal', ',', 'take', ...],
#  ['anupam', 'kher', "'", 's', 'mother', 'dulari', ...],
#  ['A', 'decisive', 'achievement', 'in', 'India', "'", ...],
#  ['thinking', 'wait', 'little', 'more', 'before', 'i', ...],
#  ['oh', 'covid', 'covid', 'vaccine', 'kayo', 'diyan', ...],
#  ['may', 'be', 'he', 'is', 'busy', 'italy', ',', ...],
#  ['yes', 'sir', 'there', 'is', 'always', 'two', 'views', ...],
#  ['you', 'cannot', 'just', 'say', 'your', 'life', ...],
#  ['do', 'not', 'propagate', 'false', 'news', '#', ...],
#  ['bharat', 'biotech', "'", 's', 'covaxin', 'is', 'not', ...],
#  ['indian', 'national', 'congress', 'indian', ...],
#  ['vaccines', 'now', 'coming', 'back', 'inject', 'life', ...],
#  ['U', '.', 'S', '.', '_Outlying_Islands', 'covid', ...],
#  ['brazil', '’', 's', 'push', 'obtain', 'covid', ...],
#  ['Trustmayfolded_hands', '#', 'Allopathy', 'is', 'not', ...],
#  ['america', "'", 's', 'president', 'elect', 'joe', ...],
#  ['global', 'market', 'update', ':', 'steep', 'fall', ...],
#  ['statistically', 'speaking', 'every', '1', 'person', ...],
#  ['will', 'this', 'vaccine', 'be', 'acceptable', ...],
#  ['covaxin', 'is', 'world', 'no', 'covid', 'vaccine', ...],
#  ['pm', 'sammaan', 'nidhi', 'ya', 'anya', 'koi', 'bhi', ...],
#  ['husband', 'takes', 'vaccine', 'his', 'wife', 'too', ...],
#  ['covid', '-', '19', 'vaccines', 'are', 'acceptable', ...],
#  ['our', 'future', 'doctors', 'staying', 'up', 'date', ...],
#  ['my', 'boss', 'bring', 'up', 'why', 'they', 'did', ...],
#  ['new', 'more', 'infectious', 'covid', 'mutations', ...],
#  ['It', 'has', 'nothing', 'to', 'do', 'with', 'G', "'", ...],
#  ['wear', 'your', 'mask', 'please', ...],
#  ['no', ',', 'most', 'people', 'who', 'got', 'vaccine', ...],
#  ['flash', ':', 'bangladesh', "'", 's', 'drugs', ...],
#  ['needless', 'say', 'it', 'will', 'work', 'wonders', ...],
#  ['india', 'tv', 'editor', '-', 'in', '-', 'chief', ...],
#  ['at', 'same', 'time', 'how', 'many', 'other', ...],
#  ["'", 'covaxin', 'is', '200', 'per', 'cent', 'safe', ...],
#  ['indian', 'pharama', 'companies', 'should', 'have', ...],
#  ['historically', 'process', 'approval', 'any', 'drug', ...],
#  ['pharma', 'is', 'big', 'business', '.', 'indian', ...],
#  ['by', 'trying', 'do', 'politics', 'by', 'taking', ...],
#  ['The', 'first', 'right', 'on', 'covid', 'vaccine', ...],
#  ['‘', 'will', 'help', 'intensify', 'fight', '‘:', ...],
#  ['maharashtra', 'cm', 'holds', 'meeting', 'corona', ...],
#  ['sequence', 'events', '#', 'covid', 'vaccine', ...],
#  ['he', 'get', 'covid', 'vaccine', 'made', 'safai'],
#  ['hard', 'hitting', 'fact', 'based', 'presentation', ...],
#  ['covid', '19', 'vaccine', ':', '1', '.', 'must', ...],
#  ['india', 'approves', 'serum', '-', 'oxford', ',', ...],
#  ['more', 'they', 'oppose', ',', 'more', 'they', 'are', ...],
#  ['‘', 'more', 'they', 'oppose', ',', 'more', 'they', ...],
#  ['worlds', '1st', 'countryIndia', '...', 'made', 'not', ...],
#  ['egyptian', 'drug', 'authority', 'eda', 'has', ...],
#  ['he', '’', 's', 'right', 'u', 'knw', '.', 'we', ...],
#  ['respected', 'sir', ',', 'made', 'india', 'will', ...],
#  ['covid', '-', '19', 'vaccinesyringecheck_mark_button'],
#  ["'", 'will', 'help', 'intensify', 'fight', "':", ...],
#  ['no', ',', 'big', 'no', ',', 'these', 'vaccines', ...],
#  ['coronavirus', 'extends', 'support', 'samajwadi', ...],
#  ['Important', 'questions', 'related', 'to', '#', ...],
#  ['good', 'morning', 'sir', '.', 'great', 'job', 'has', ...],
#  ['my', 'feedback', 'covishield', 'covaxin', 'vaccine', ...],
#  ['if', 'either', 'mr', '.', 'or', 'mr', '.', 'does', ...],
#  ['i', 'did', 'receive', 'yesterday', 'first', 'shot', ...],
#  ['covaxin', ':', 'india', "'", 's', 'first', ...],
#  ['china', 'just', 'approved', 'it', 'is', 'first', ...],
#  ['two', 'vaccines', 'india', 'got', 'approval', ...],
#  ['More', 'than', '14', 'thousand', 'trained', ...],
#  ['#', 'indiafightscorona', ':', 'round_pushpinfaqs', ...],
#  ['mr', '.', 'akhlesh', 'yadav', ',', 'we', 'now', ...],
#  ['#', 'covid19', '#', 'covidvaccine', 'dr', ...],
#  ['india', 'near', 'inventing', '4', '-', '5', '+', ...],
#  ['Hello', 'Honorable', 'India', '.', 'Today', 'whole', ...],
#  ['two', 'covid', 'vaccines', ',', 'made', 'india', ...],
#  ['new', 'year', 'has', 'brought', 'with', 'it', 'new', ...],
#  ['good', 'thought', ',', 'but', 'this', 'is', 'being', ...],
#  ['Today', 'my', 'son', 'Nirbhay', 'got', '#', ...],
#  ['india', "'", 's', 'effort', 'towards', 'defeating', ...],
#  ['covid', 'vaccine', 'is', 'be', 'proved', 'raffale', ...],
#  ['I', 'am', 'west', 'ghaziabad', 'public', 'outreach', ...],
#  ['will', 'help', 'intensify', 'fight', "':", 'who', ...],
#  ['dcgi', 'approves', 'two', 'covid', '-', '19', ...],
#  ['good', 'morning', 'folded_hands', ',', 'first', ...],
#  ['"', '44', '.', '2', '%', 'adverse', 'events', ...],
#  ['let', 'bjp', 'leaders', 'first', 'take', 'covid', ...],
#  ['international', 'news', ':', 'nbc', 'nightly', ...],
#  ['arvind', 'kejriwal', 'lauds', 'scientists', ...],
#  ['#', 'pmcbankcrisis', 'even', 'covid', '19', ',', ...],
#  ['#', 'Bhadohi', ':-', '#', 'Corona_Vaccine', ':', ...],
#  ['finally', ',', '#', 'newyear2021', 'brought', 'much', ...],
#  ['Questions', 'should', 'be', 'raised', 'on', 'the', ...],
#  ['bjp', 'has', 'approved', 'two', 'indian', 'vaccines', ...],
#  ['good', 'time', 'catch', 'criminals', 'evading', ...],
#  ['discovery', 'vaccine', 'by', 'indian', 'scientists', ...],
#  ['this', 'is', 'surely', 'positive', 'beginning', ...],
#  ['dispel', 'fear', 'ppl', 'about', 'covid', 'vaccine', ...],
#  ['covid', '-', '19', 'who', 'welcomes', 'india', 'is', ...],
#  ['"', 'serum', 'institute', 'india', 'bharat', ...],
#  ['take', 'it', '@', 'own', 'risk', '.', 'without', ...],
#  ['u', '.', 's', '.', 'could', 'ramp', 'up', 'slow', ...],
#  ['aiims', 'could', 'not', 'recruit', 'enough', ...],
#  ['expect', 'vaccine', 'misinformation', 'spread', ...],
#  ['chief', 'executive', 'serum', 'institute', 'india', ...],
#  ["'", 'a', 'decisive', 'turning', 'point', ",'", ...],
#  ['yes', '.', 'it', 'has', 'shown', 'world', 'we', ...],
#  ['i', 'will', 'take', 'oxford', 'astra', 'vaccine', ...],
#  ['#', 'aashaherbals', '#', 'covid19', '#', ...],
#  ['We', 'are', 'proud', 'India', 'two', '#', ...],
#  ['momentous', 'achievement', 'india', 'dcgi', 'has', ...],
#  ['this', 'is', 'real', 'reason', 'why', 'i', 'suspect', ...],
#  ['when', 'r', 'we', 'going', 'see', 'protest', ...],
#  ['owaisi', 'may', 'also', 'suggest', 'govt', 'allow', ...],
#  ['first', '-', 'i', 'didn', '’', 't', 'wanted', 'get', ...],
#  ['ascertain', 'proper', 'efficacy', 'vaccine', '‘', ...],
#  ['i', 'hope', 'prey', 'that', 'covid', 'vaccine', 'is', ...],
#  ['listen', 'tottichor', 'this', 'is', 'not', 'bjp', ...],
#  ['#', 'aashaherbals', '#', 'covid19', '#', ...],
#  ['gst', 'should', 'collect', 'member', 'if', 'any', ...],
#  ['heartiest', 'congratulations', 'our', 'scientists', ...],
#  ['#', 'covid19', '#', 'covidvaccine', '#', ...],
#  ['all', 'efforts', 'eliminate', 'covid19', 'initiated', ...],
#  ['now', 'u', 'will', 'see', 'halal', 'certified', ...],
#  ['#', 'indoriyuvakumbh', '#', 'vaccinations', '#', ...],
#  ['covid', 'vaccine', 'is', 'not', 'first', 'thing', ...],
#  ['who', 'they', 'are', 'not', 'citizens', 'this', ...],
#  ['dcgi', 'gives', 'licensing', 'permission', 'bharat', ...],
#  ['as', 'prof', 'head', 'dermatology', 'cnmc', 'having', ...],
#  ['regarding', 'covid', 'vaccine'],
#  ['badhai', 'ho', ',', 'doston', '#', 'covidvaccine'],
#  ['coviTongue_sticking_out_cheeky_playful_or_blowing_a_raspberry', 'india', ...],
#  ['i', 'offer', 'my', 'thanks', 'gratitude', ...],
#  ['“', 'disgraceful', 'anyone', 'politicise', 'such', ...],
#  ['where', 'is', 'pink', 'diamond', 'covid', '-', '19', ...],
#  ['coronavirus', 'extends', 'support', 'samajwadi', ...],
#  ['now', 'reading', '𝘂𝗻𝗽𝗼𝗽𝘂𝗹𝗮𝗿', '𝗯𝗼𝗼𝗸', ',', '#', ...],
#  ['as', 'long', 'as', 'vaccine', 'is', 'choice', 'then', ...],
#  ['sudden', 'rise', 'covid', 'vaccine', 'experts', ...],
#  ['two', 'indian', 'vaccines', 'approved', 'emergency', ...],
#  ["'", 'completely', 'unaware', 'any', 'data', ...],
#  ['momentous', 'achievement', 'india', 'dcgi', 'has', ...],
#  ['We', 'are', 'proud', 'India', 'two', '#', ...],
#  ['politicisation', 'covid', 'vaccine', 'by', 'some', ...],
#  ['publication', 'phase', 'ii', 'trial', 'data', 'is', ...],
#  ['shashi', 'tharoor', 'is', 'more', 'expert', 'than', ...],
#  ['born', 'tamil', 'nadu', ',', 'india', ',', 'dr', '.', ...],
#  ['dcgi', 'approves', 'vaccine', '&', 'amp', ';', ...],
#  ['shame', 'liberals', '&', 'amp', ';', 'dynastic', ...],
#  ['no', 'need', 'do', 'politics', 'over', 'covid', '-', ...],
#  ['i', 'do', 'not', 'believe', 'skin', 'doctor', ...],
#  ['india', 'is', 'following', 'path', 'being', 'self', ...],
#  ['zee', 'guj', 'executive', 'director', '&', 'amp', ...],
#  ['prime', 'minister', 'narendra', 'modi', 'today', ...],
#  ['covid', 'cases', 'are', 'at', 'their', 'lowest', ...],
#  ['Proud', 'moment', 'for', '#', 'atmanirbharbharat', ...],
#  ['india', "'", 's', 'approval', 'homegrown', 'covid', ...],
#  ['#', 'etiholidays', '#', 'hcgmice', '#', ...],
#  ['indian', 'developed', 'covid', 'vaccine', 'has', ...],
#  ['no', 'body', 'expected', 'this', 'but', 'scotts', ...],
#  ['Today', 'media', 'panelists', 'will', 'become', ...],
#  ['i', 'have', 'taken', 'first', 'dose', 'covid', ...],
#  ['In', 'our', 'opinion', ',', 'your', 'education', ...],
#  ['congress', 'opposition', 'is', 'not', 'proud', ...],
#  ['....', 'to', 'fill', 'the', 'form', 'then', 'the', ...],
#  ['congratulations', 'india', 'folded_hands', '#', ...],
#  ['covid', 'vaccine', 'has', 'been', 'finalized', ...],
#  ['Country', 'has', 'to', 'think', 'very', 'seriously', ...],
#  ['within', 'year', 'covid', '-', '19', 'pandemic', ...],
#  ['kash', 'covid', 'ke', 'sath', 'tujh', 'jaise', ...],
#  ['good', 'idea', ',', 'however', 'those', 'who', 'can', ...],
#  ['coronavirus', 'extends', 'support', 'samajwadi', ...],
#  ['those', 'not', 'interested', 'vaccine', 'will', ...],
#  ['akileshji', 'i', 'condemn', 'ur', 'comment', 'covid', ...],
#  ['now', 'that', '#', 'covidvaccine', 'have', 'begun', ...],
#  ['balbir', 'sidhu', 'says', ',', 'centre', 'must', ...],
#  ['akileshji', 'few', 'days', 'back', 'u', 'we', 'are', ...],
#  ['breaking', ':', 'coronavirus', 'extends', 'support', ...],
#  ['my', 'big', 'big', 'big', 'salute', 'our', 'great', ...],
#  ['emergency', 'usage', 'authorization', 'means', ...],
#  ['PM', 'congratulates', 'nation', 'on', 'approval', ...],
#  ['this', 'vaccine', 'seems', 'be', 'more', 'lethal', ...],
#  ['#', 'bjp', 'ki', '#', 'vaccine', 'hum', 'nhi', ...],
#  ['icymi', ':', 'here', '’', 's', 'timeline', 'what', ...],
#  ['there', 'seems', 'be', 'smear', ',', 'insidious', ...],
#  ['covid', 'vaccine', 'already', 'administered', '-', ...],
#  ['nobody', 'wll', 'trust', 'foolish', 'fear', '-', ...],
#  ['#', 'covidvaccine', '#', 'coronavirusstrain', '#', ...],
#  ['where', 'is', 'safety', '&', 'amp', ';', 'efficacy', ...],
#  ['#', 'covidvaccine', 'likes', 'akhilesh', 'yadav', ...],
#  ['indigenous', 'covid', 'vaccine', 'is', 'purest', ...],
#  ['Akhilesh', 'Yadav', ',', 'AAP', 'does', 'not', ...],
#  ['congress', 'leaders', 'raise', 'concern', 'over', ...],
#  ['such', 'proud', 'moment', '..', 'well', 'done', ...],
#  ['happy', 'new', 'year', ',', 'everyone', 'all', ...],
#  ['#', 'Covidvaccine', 'for', 'free', 'all', 'over', ...],
#  ['two', 'reasons', 'be', 'wearing', 'masks', ',', ...],
#  ['On', 'questioning', 'the', '#', 'covidvaccine', 'of', ...],
#  ['ppl', 'india', 'are', 'congratulating', 'our', ...],
#  ['congratulations', 'we', 'final', 'have', '#', ...],
#  ['#', 'india', 'unveils', 'two', '#', 'vaccines', ...],
#  ['just', 'imagine', 'how', 'much', 'money', 'netas', ...],
#  ['sabse', 'pehle', 'covid', '-', '19', 'ki', 'vaccine', ...],
#  ['oxford', 'russia', 'se', 'kitna', 'khaaney', 'ko', ...],
#  ['#', 'madeinindia', '#', 'coronavaccine', '#', ...],
#  ['wait', ',', 'what', 'bolosonaro', 'says', 'covid', ...],
#  ['as', 'part', 'general', 'awareness', 'public', 'my', ...],
#  ['about', 'covid', '-', '19', 'vaccine'],
#  ['"', 'fact', 'check', ':', 'nurse', 'fainting', ...],
#  ['decisive', 'turning', 'point', 'strengthen', ...],
#  ['#', 'covidvaccine', 'which', '#', 'india', 'is', ...],
#  ['After', 'all', ',', '#', 'Corona_Vaccine', 'got', ...],
#  ['it', 'is', 'time', 'vaccinate', 'yourself', 'with', ...],
#  ['indian', 'government', "'", 's', 'promise', ...],
#  ['ashok', 'gehlot', ':', 'desh', 'me', 'nirmit', ...],
#  ['talk', 'with', '#', 'farmers', 'resolve', 'their', ...],
#  ['#', 'mainbhivaccineexpert', 'bjp', 'has', 'approved', ...],
#  ['Sankranti', 'moment', 'for', 'vaccination', '...', ...],
#  ['indeed', 'proud', 'moment', 'every', 'individual', ...],
#  ['congratulating', 'both', '&', 'amp', ';', 'formally', ...],
#  ['decisive', 'turning', 'point', 'strengthen', ...],
#  ['great', 'news', 'congratulations', 'india', 'we', ...],
#  ['nd', 'finally', '.', 'smiling_face_with_heart', '-', ...],
#  ['any', 'more', 'questions', 'regarding', 'covid', '-', ...],
#  ['thank', 'you', 'sir', ',', 'proud', 'be', 'indian', ...],
#  ['it', 'is', 'pity', 'that', 'dynastic', 'leaders', ...],
#  ['decisive', 'turning', 'point', 'strengthen', ...],
#  ['good', 'news', 'everyone', 'especially', 'all', ...],
#  ['here', 'is', 'point', 'public', 'only', 'few', ',', ...],
#  ['congratulations', 'india', 'we', 'thank', '&', 'amp', ...],
#  ['respected', 'sir', ',', 'i', 'am', 'very', 'much', ...],
#  ['pm', 'had', 'highest', 'approval', 'ratings', ...],
#  ['covid', '-', '19', 'vaccine', ':', 'serum', ...],
#  ['thanks', ',', 'great', 'achievement', 'launched', ...],
#  ['covaxin', 'covishield', 'vaccines', 'are', '110', ...],
#  ['finally', '#', 'covid19', 'made', 'india', 'vaccine', ...],
#  ['proud', 'moment', 'cdsco', 'breakthrough', 'covid', ...],
#  ['many', 'times', 'bjp', 'govt', 'was', 'rushing2', ...],
#  ['decisive', 'turning', 'point', 'strengthen', ...],
#  ['do', 'watch', '#', 'baekhyunbeyondlive', '#', ...],
#  ['#', 'breaking', 'dcgi', 'approval', 'for', ...],
#  ['backs', 'india', "'", 's', '#', 'vaccine', ...],
#  ['finally', '#', 'india', 'approved', '#', ...],
#  ['decisive', 'turning', 'point', 'strengthen', ...],
#  ['competition', 'towards', 'vaccine', 'coverage', ...],
#  ['may', 'this', 'be', 'one', 'most', 'effective', '&', ...],
#  ['thanks', 'you', 'sir', 'ji', 'constantly', 'keeping', ...],
#  ['happy', 'new', 'year', 'everyone', 'all', 'risks', ...],
#  ['Corona', 'vaccine', '#', 'official', 'announcement', ...],
#  ['The', 'medicine', 'has', 'arrived', '.', 'But', 'do', ...],
#  ['#', 'harshvardhan', 'promise', 'provide', 'covid', ...],
#  ['We', 'Indians', 'are', 'fortunate', 'to', 'have', ...],
#  ['thanks', 'once', 'again', 'our', 'sciencentists', ...],
#  ['.....', 'and', 'today', 'finally', 'DGHS', 'has', ...],
#  ['detailed', 'statement', 'by', '#', 'covid', ...],
#  ['congratulations', 'indiasmiling_face', '#', ...],
#  ['#', 'goodnews', 'bharat', 'biotech', '&', 'amp', ';', ...],
#  ['covid', '-', '19', ':', 'oxford', 'covishield', ',', ...],
#  ['great', 'news', '*', 'india', '’', 's', 'drug', ...],
#  ['#', 'dcgi', '-', 'vaccines', 'serum', 'institue', ...],
#  ['#', 'breakingnews', '2', 'covid', '-', '19', ...],
#  ['breaking', ':', 'india', 'approves', 'oxford', ...],
#  ['breaking', ':', 'india', "'", 's', 'drug', ...],
#  ['dcgi', 'approves', 'serum', 'institute', 'bharat', ...],
#  ['tomorrow', 'we', 'will', 'say', '"', 'we', 'are', ...],
#  ['all', 'those', 'taxpayers', 'who', 'wants', 'pay', ...],
#  ['saw', 'your', 'morning', 'show', 'with', 'respected', ...],
#  ['main', 'opponent', 'india', 'is', 'chinaChina', ',', ...],
#  ['akhlesh', 'yadav', 'sp', 'rashid', 'alvi', 'cong', ...],
#  ['uttar', 'pradesh', 'chief', 'minister', 'ji', ...],
#  ['india', 'likely', 'approve', 'two', '-', 'dose', ...],
#  ['#', 'bjp_covidvaccine', 'flexed_biceps'],
#  ['#', 'dcga', '-', 'drugs', 'controller', 'general', ...],
#  ['drugs', 'controller', 'general', 'india', 'dcgi', ...],
#  ['i', 'feel', 'covid', 'vaccine', 'should', 'already', ...],
#  ['can', 'covid', '-', '19', 'vaccine', 'communication', ...],
#  ['discrimination', 'equitable', 'distribution', ...],
#  ['"', 'finland', 'confirms', 'first', 'adverse', ...],
#  ['fact', 'by', 'giving', 'stupid', 'statement', ...],
#  ['covid', 'vaccine', 'check_mark_button', '#', ...],
#  ['covid', 'vaccine', 'will', 'be', 'provided', 'free', ...],
#  ['covid', '19', 'vaccine', 'be', 'innoculated', 'free', ...],
#  ['har', 'har', 'modi', 'ji', 'dikhenge', '.', 'aise', ...],
#  ['come', 'join', 'world', "'", 's', 'first', 'virtual', ...],
#  ['when', 'everyone', 'asks', 'why', 'is', 'it', ...],
#  ['our', 'doctors', 'scientists', 'have', 'made', 'it', ...],
#  ['could', 'khda', 'please', 'explain', 'why', 'it', ...],
#  ['ex', 'up', 'cm', 'akhiles', 'yadav', 'said', 'that', ...],
#  ['please', 'help', 'foreigner', 'residents', ...],
#  ['definitely', 'great', 'achievement', 'such', 'short', ...],
#  ['earlier', 'it', 'was', 'polio', 'drops', 'now', ...],
#  ['usa', 'has', 'researchers', ',', 'institutions', ',', ...],
#  ['hum', 'bjp', 'ka', 'vaccine', 'nahi', ...],
#  ['india', "'", 's', 'second', 'covid', 'vaccine', ...],
#  ['U', '.', 'S', '.', '_Outlying_Islands', ':', 'covid', ...],
#  ['india', "'", 's', 'first', 'indigenous', 'covid', ...],
#  ['i', 'wish', '2021', 'safe', 'everyone', 'covid', ...],
#  ['Follow', 'us', '#', 'rajasthani', '#', 'rajasthan', ...],
#  ['what', 'happened', '1st', 'covid', 'vaccine', ...],
#  ['playing', 'politics', 'with', 'successful', 'bane', ...],
#  ['quoted', 'story', 'both', 'trust', 'building', ...],
#  ['mislead', 'is', 'fraud', 'under', 'ipc', '.', ...],
#  ['covid', 'vaccines', 'approved', 'india', ',', ...],
#  ['pakistan', 'has', '3', 'options', 'get', 'covid', ...],
#  ['#', 'breaking', 'drug', 'controller', 'general', ...],
#  ['india', "'", 's', 'drug', 'controller', 'general', ...],
#  ['expert', 'panel', 'recommends', 'bharat', 'biotech', ...],
#  ['second', '#', 'covidvaccine', 'receives', 'approval', ...],
#  ['just', 'like', 'america', ',', 'it', 'would', 'be', ...],
#  ['thank', 'you', 'honorable', 'pm', 'ji', '&', 'amp', ...],
#  ['great', 'article', 'highlighting', 'scientific', ...],
#  ['announces', 'free', 'covid', '19', 'vaccine', 'all', ...],
#  ['any', 'vaccine', 'available', 'covid', 'brain'],
#  ['can', 'you', 'believe', ',', 'akhilesh', 'yadav', ...],
#  ['i', 'hope', 'covid', 'vaccine', 'has', 'microchip', ...],
#  ['covaxin', ',', 'india', "'", 's', 'indigenously', ...],
#  ['bharat', 'biotech', '’', 's', '#', 'covaxin', 'gets', ...],
#  ['india', 'statement', 'covid', 'vaccine', ':'],
#  ['The', 'Deputy', 'Commissioner', 'reached', 'rvs', ...],
#  ['cdsco', 'panel', 'recommends', 'granting', ...],
#  ['we', 'had', 'term', '"', 'covidiot', '"', 'those', ...],
#  ['what', 'do', 'i', 'do', 'by', 'covid', 'vaccine', ...],
#  ['covid', '-', '19', 'vaccine', 'will', 'be', ...],
#  ['Dry', 'run', 'at', 'two', 'places', 'of', 'Palamu', ...],
#  ['argentina', ',', 'south', 'africa', ',', 'brazil', ...],
#  ['Opposition', ':', 'Thought', 'that', 'the', 'farmer', ...],
#  ['dry', 'run', 'covid', '-', '19', 'vaccine', ...],
#  ['covid', '-', '19', 'vaccine', 'will', 'be', ...],
#  ['Hey', 'Tipu', 'Bhaiya', ',', 'a', 'scientist', 'is', ...],
#  ['kindly', 'take', 'action', 'against', 'all', '&', ...],
#  ['absurd', ',', 'mediocre', 'senseless', 'statement', ...],
#  ['as', 'we', 'wait', 'covid', 'vaccine', ',', 'ex', ...],
#  ['dry', 'run', '#', 'covid19vaccine', 'conducted', ...],
#  ['how', 'much', 'are', 'we', 'going', 'wait', 'see', ...],
#  ['must', 'relook', 'into', 'restrictions', 'air', ...],
#  ['40', 'minutes', ',', '3', 'centres', ',', 'medical', ...],
#  ['how', 'does', 'astrazeneca', "'", 's', 'covid', '-', ...],
#  ['#', 'covidvaccine', 'not', 'just', 'delhi', ',', ...],
#  ['new', 'year', '2021', ',', 'world', 'awaits', ...],
#  ['sp', 'under', 'akhilesh', 'yadav', 'are', ...],
#  ['now', 'it', 'should', 'be', 'made', 'sure', 'that', ...],
#  ['Thank', 'God', 'I', 'took', 'the', 'first', 'dose', ...],
#  ['covid', 'vaccine', ':', 'dry', 'runs', 'held', ...],
#  ['Modi', 'government', 'withdrew', 'the', ...],
#  ['vaccine', 'is', 'not', 'idiots', ';', 'let', ...],
#  ['irresponsible', 'should', 'understand', 'that', '#', ...],
#  ['if', 'ever', 'i', 'feel', '/', 'need', 'get', ...],
#  ['great', 'news', 'covid', '-', '19', 'vaccine', 'be', ...],
#  ['#', 'covidvaccine', 'will', 'be', 'provided', 'free', ...],
#  ['akhilesh', 'yadav', 'sparks', 'row', ',', 'says', ...],
#  ['other', 'countries', 'getting', 'cases', 'new', ...],
#  ['If', 'corona', 'vaccine', 'is', 'available', ',', ...],
#  ['covid', '-', '19', 'vaccine', 'dry', 'run', ...],
#  ['my', 'bucket', 'list', '2021', ':', 'tangerinehv', ...],
#  ['aaple', 'आय', 'ु', 'क', '्', 'त', 'taking', 'stock', ...],
#  ['vaccine', 'is', 'covid', 'virus', 'not', 'corrupt', ...],
#  ['If', 'no', 'one', 'asks', 'them', 'now', ',', 'then', ...],
#  ['addition', 'healthcare', 'workers', ',', 'all', '#', ...],
#  ['can', 'anyone', 'say', 'that', 'when', '#', ...],
#  ['every', "'", 'legal', "'", 'indian', 'will', 'get', ...],
#  ['*', 'good', 'news', ':', 'covid', '-', '19', ...],
#  ['as', 'per', 'union', 'health', 'ministry', 'affairs', ...],
#  ['big', 'announcement', '#', 'covid', '-', '19', ...],
#  ['different', 'efficacy', 'data', 'chinese', 'covid', ...],
#  ['union', 'health', 'minister', 'harsh', 'vardhan', ...],
#  ['not', 'male', 'nurse', 'took', 'pfizer', 'vaccine', ...],
#  ['big', 'announcement', '.#', 'covid', '-', '19', ...],
#  ['Modi', 'government', 'announced', 'free', 'covid', ...],
#  ['moderna', 'covid', '-', '19', 'vaccine', 'shows', ...],
#  ['thank', 'you', 'pm', 'sh', '.', 'ji', '&', 'amp', ...],
#  ['Maintain', 'health', 'with', 'european', ...],
#  ['sir', ',', 'is', 'there', 'mechanism', 'place', ...],
#  ['this', 'is', 'true', 'example', 'government', ...],
#  ['#', 'delhi', 'it', 'will', 'be', 'given', 'free', ...],
#  ['here', '’', 's', 'everything', 'you', 'need', 'know', ...],
#  ['Ignore', 'the', 'rumours', ',', 'my', 'appeal', 'to', ...],
#  ['india', "'", 's', 'health', 'minister', 'says', ...],
#  ['#', 'covid19india', '-', 'covid19', 'vaccine', 'be', ...],
#  ['covid', '-', '19', 'vaccine', 'will', 'be', 'free', ...],
#  ['covid', '-', '19', 'vaccine', 'will', 'be', 'free', ...],
#  ['.....', 'and', 'another', 'big', 'news', 'in', ...],
#  ['દ', 'ે', 'શભરમ', 'ાં', 'ફ', '્', 'ર', 'ી', 'વ', 'ે', ...],
#  ['good', 'news', '#', 'covid19', 'vaccine', ':', 'not', ...],
#  ['modi', 'government', 'announces', 'free', 'covid', ...],
#  ['.....', 'and', 'trial', 'run', 'of', '#', ...],
#  ['sindh', 'get', 'covid', '-', '19', 'vaccine', 'by', ...],
#  ['dry', 'run', '#', 'covid19', 'vaccine', ...],
#  ['Vaccine', 'Dry', 'Run', ...],
#  ['dry', 'run', '#', 'covid', 'vaccine', 'begins', '#', ...],
#  ['research', 'report', 'covid', '-', '19', '19', ...],
#  ['good', 'morning', 'n', 'hn', 'year', ',', 'kerala', ...],
#  ['do', 'maths', '...', 'at', '2', 'million', 'doses', ...],
#  ['expert', 'panel', 'clears', '#', 'covishvaccine', ...],
#  ['wish', 'you', 'family', 'happy', 'new', 'year', '.', ...],
#  ['"', 'world', 'faces', 'covid', '-', '19', '“', ...],
#  ['"', 'serum', 'institute', '’', 's', 'covid', '-', ...],
#  ['"', 'covid', '-', '19', 'vaccine', 'dry', 'run', ...],
#  ['when', 'covid', '-', '19', 'pandemic', 'is', 'over', ...],
#  ['pan', '#', 'india', 'dry', 'run', 'tomorrow', '#', ...],
#  ['not', 'only', 'vaccine', 'investor', 'but', 'also', ...],
#  ['india', 'drug', 'regulator', 'approves', ...],
#  ['sources', 'we', 'are', 'right', '.', 'historical', ...],
#  ['oxford', '-', 'astrazeneca', 'covid', 'vaccine', '.', ...],
#  ['expert', 'panel', 'covid', '-', '19', 'cdsco', '01', ...],
#  ['breaking', 'news', '2021', ':', '#', 'covidvaccine', ...],
#  ['covid', 'vaccine', 'syringe', 'is', 'first', 'big', ...],
#  ['frustration', 'is', 'building', 'with', '#', 'trump', ...],
#  ['2021', 'has', 'come', 'with', 'the', 'hope', 'of', ...],
#  ['let', '’', 's', 'go', '2021', '#', 'covidvaccine'],
#  ['corona', 'ko', 'humtak', 'pohochne', 'me', '4', '-', ...],
#  ['covid', '-', '19', ':', 'astrazeneca', '-', 'oxford', ...],
#  ['here', 'comes', 'first', '#', 'covidvaccine', ...],
#  ['india', 'got', 'it', 'is', 'first', 'covid', ...],
#  ['covid', '-', '19', 'vaccine', '|', 'panel', ...],
#  ['The', '#', 'covishield', 'vaccine', ',', 'developed', ...],
#  ['#', 'eisamay', '#', 'kolkata', ',', 'expart', ...],
#  ['#', 'covid19', '#', 'covidvaccine', '#', ...],
#  ['india', 'vaccine', 'update', '-', 'dry', 'run', ...],
#  ['my', 'bucket', 'list', '2021', ':', 'tangerinehv', ...],
#  ['internal', 'meeting', 'with', 'officials', 'is', ...],
#  ['happy', 'new', 'year', 'everyone', 'collision', '.', ...],
#  ['i', 'would', 'have', 'said', 'so', ',', 'but', ...],
#  ['modiji', 'happy', 'new', 'year', ',', 'as', 'senior', ...],
#  ['let', 'us', 'take', 'moment', 'condole', 'all', ...],
#  ['#', 'goodbye2020', '#', 'goodmorning', '#', ...],
#  ['india', 'will', 'have', 'covid', '-', '19', ...],
#  ['toi', 'editorials', ':', '2021', '’', 's', 'best', ...],
#  ['who', 'lists', 'pfizer', '-', 'biontech', '’', 's', ...],
#  ['what', '’', 's', 'going', 'with', '#', 'vaccination', ...],
#  ['why', 'even', 'one', 'shot', 'is', 'better', 'than', ...],
#  ['covid', 'vaccines', 'will', 'soon', 'be', ...],
#  ['world', 'faces', 'covid', '-', '19', '“', 'vaccine', ...],
#  ['it', 'is', '#', 'lastdayof2020', '#', 'covid19', ...],
#  ['happy', 'new', 'year', 'you', 'your', 'loved', ...],
#  ['let', 'us', 'have', 'back', 'all', 'happiness', ...],
#  ['pandamic', 'situation', 'we', 'have', 'lost', 'all', ...],
#  ['me', '&', 'amp', ';', ...],
#  ['not', 'break', 'news', 'you', 'but', 'tomorrow', ...],
#  ['well', 'done', 'india', '.', 'we', 'have', 'handled', ...],
#  ['1', 'january', '2021', 'today', '--', 'pm', 'modi', ...],
#  ['100', '%', 'personal', 'account', 'akah', 'jamaa', ...],
#  ['great', '...', 'thankyou', '..', 'but', 'now', ...],
#  ['my', 'wife', 'sangita', 'i', 'had', 'inspiring', ...],
#  ['as', 'mass', 'vaccine', 'campaigns', 'begin', ',', ...],
#  ['#', 'aashaherbals', '#', 'covid19', '#', 'thoughts', ...],
#  ['#', 'rushivarji', '#', 'covidvaccine', '#', ...],
#  ['#', 'eisamay', '#', 'kolkata', ',', 'dry', 'run', ...],
#  ['good', 'news', 'covid', 'vaccine', 'dry', 'run', ...],
#  ['just', 'coming', 'in', ':', 'covid', '-', '19', ...],
#  ['"', 'covid', '-', '19', 'vaccine', 'dry', 'run', ...],
#  ['at', 'this', 'rate', 'lebanon', ',', 'we', 'will', ...],
#  ["'", 'it', 'does', 'not', 'make', 'any', 'sense', ...],
#  ['today', 'last', 'day', 'year', '2020', 'view', ...],
#  ['sensex', ',', 'nifty', 'end', 'at', 'fresh', ...],
#  ['i', 'agree', 'with', 'you', 'because', 'had', ...],
#  ['jai', 'shri', 'ram', '.', 'seeking', 'blessings', ...],
#  ['serum', 'institute', 'india', 'have', '100', ...],
#  ['covid', 'vaccine', 'dry', 'run', 'take', 'place', ...],
#  ['my', 'prediction', ':', 'trim', 'his', 'beard', ...],
#  ['#', 'india', 'will', 'have', '#', 'covid', '-', '19', ...],
#  ['necessary', 'preparations', 'are', 'going', ...],
#  ['new', 'covid', '-', '19', 'vaccine', 'strain', ...],
#  ['when', 'can', 'children', 'get', 'covid', '-', '19', ...],
#  ['major', 'lesson', '2020', ...],
#  ['india', 'will', 'have', 'covid', '-', '19', ...],
#  ['contingent', 'assessment', 'covid', '-', '19', ...],
#  ['as', 'teacher', 'abu', 'dhabi', ',', 'i', 'my', ...],
#  ['this', 'govt', 'has', 'failed', 'provide', 'testing', ...],
#  ['india', 'will', 'get', '#', 'covidvaccine', 'within', ...],
#  ['yes', ',', 'we', 'need', 'be', 'optimistic', 'that', ...],
#  ['serum', "'", 's', 'chances', 'covishield', 'nod', ...],
#  ['wockhardt', 'will', 'be', 'today', 'focus', '.', ...],
#  ['would', 'i', 'take', '#', 'covidvaccine', 'at', ...],
#  ['heartening', 'news', '#', 'indians', 'who', 'await', ...],
#  ['international', 'news', ':', 'nbc', 'nightly', ...],
#  ['countdown', '1', 'day', 'go', 'rip', 'microbe', ...],
#  ['covid', '-', '19', 'vaccine', 'akan', 'launch', ...],
#  ['covid', '-', '19', 'vaccine', 'complete', 'stay', ...],
#  ['covid', '-', '19', 'vaccine', 'complete', '@', 'abu', ...],
#  ['"', 'let', 'this', 'be', 'last', 'year', 'you', ...],
#  ['i', 'wish', 'people', 'had', '30', 'seconds', ...],
#  ['new', 'covid', 'strain', ':', 'how', 'dangerous', ...],
#  ['"', 'kamala', 'harris', 'receives', 'first', 'dose', ...],
#  ['#', 'eisamay', '#', 'kolkata', ',', 'new', 'years', ...],
#  ['would', 'you', 'take', 'covid', 'vaccine', 'if', ...],
#  ['"', 'oxford', '/', 'astrazeneca', 'covid', '-', '19', ...],
#  ['beware', 'covid', 'vaccine', 'registration', 'fraud', ...],
#  ['covid', '-', '19', 'vaccine', 'already', 'come', ...],
#  ['nurse', 'tests', 'positive', 'sars', '-', 'cov', '-', ...],
#  ['#', '2020wrapped', 'bahrain', 'covid', 'edition', ...],
#  ['य', 'े', 'भ', 'ी', 'ठ', 'ी', 'क', 'ह', 'ै', ...],
#  ['dear', 'bestie', ',', 'irritating', 'you', 'is', ...],
#  ['#', 'dilemma', 'over', 'pfizer', 'vaccine', ...],
#  ['even', 'though', 'people', 'get', 'selfish', ...],
#  ['picture', 'year', '2020', '...', '#', 'covidvaccine', ...],
#  ['Will', 'have', 'to', 'wait', 'a', 'while', '#', ...],
#  ['covid', 'cannot', 'read', 'calender', '.', 'nothing', ...],
#  ['india', "'", 's', 'top', 'body', 'give', 'go', ...],
#  ['disrespect', 'comment', 'section', 'ncid', 'nurse', ...],
#  ['covid', '#', 'covidvaccine'],
#  ['tw', '-', '764', 'how', 'you', 'going', 'to', ...],
#  ['arcturus', 'believes', 'cellular', 'responses', ...],
#  ['#', 'legend', ',', '#', 'icon', ',', '#', 'genius', ...],
#  ['The', 'epidemic', 'of', 'covid', '-', '19', 'has', ...],
#  ['california', 'nurse', 'tests', 'positive', 'over', ...],
#  ['look', ',', 'covid', '19', 'is', 'not', 'going', ...],
#  ['covid', '-', '19', 'vaccines', 'compare'],
#  ['yes', '.', 'vaccine', 'takes', '2', 'shots', '21', ...],
#  ['i', 'want', 'volenteer', 'covid', '-', '19', ...],
#  ['#', 'hilarious', 'if', 'you', 'really', 'think', ...],
#  ['#', 'exclusive', 'pic', 'developed', 'covid', '-', ...],
#  ['congrats', 'approval', 'their', 'covid', 'vaccine', ...],
#  ['oxford', '/', 'astrazeneca', 'covid', '-', '19', ...],
#  ['uk', 'approves', 'oxford', '-', 'astrazeneca', ...],
#  ['second', 'trial', 'covid', 'vaccine', 'at', 'niced', ...],
#  ['subject', 'expert', 'committee', 'drugs', ...],
#  ['subject', 'expert', 'committee', 'cdsco', 'meet', ...],
#  ['britain', 'approves', 'astrazeneca', '-', 'oxford', ...],
#  ['"', 'oxford', '/', 'astrazeneca', 'covid', '-', '19', ...],
#  ['"', 'oxford', '/', 'astrazeneca', 'covid', '-', '19', ...],
#  ['kab', 'milega', 'yeh', 'vaccine', 'yahan', '"', ...],
#  ['good', 'news', ',', 'now', 'our', 'government', ...],
#  ['check', 'this', 'out', 'times', 'india', 'live', ':', ...],
#  ['covid', '-', '19', ':', '#', 'oxford', '-', ...],
#  ['uk', 'regulator', 'approves', 'oxford', '/', ...],
#  ['it', '’', 's', 'test', '/', 'trial', 'covid', '19', ...],
#  ['#', 'breaking', 'uk', 'approves', 'oxford', '-', ...],
#  ['astrazeneca', '’', 's', 'covid', '-', '19', ...],
#  ['who', 'say', '2020', 'was', 'tuff', 'i', 'mean', ...],
#  ['huge', 'moment', '#', 'covid', '#', 'vaccine'],
#  ['big', 'boost', '.', 'uk', 'clears', 'oxford', ...],
#  ['oxford', '-', 'astra', 'zeneca', 'get', 'uk', ...],
#  ['good', 'news', 'bbc', 'news', '-', 'covid', '-', ...],
#  ['great', 'news', 'hope', 'this', 'can', 'be', ...],
#  ['as', 'covid', 'vaccine', 'has', 'started', 'rolling', ...],
#  ['volunteered', 'covid', '-', '19', 'vaccine', 'trial', ...],
#  ['let', 'me', 'remind', 'you', 'all', '.', 'if', 'you', ...],
#  ['I', 'am', 'tired', 'of', 'waiting', '#', ...],
#  ['#', 'india', 'is', '#', 'covid19', 'status', '.', ...],
#  ['china', ',', 'india', 'both', 'front', 'pages', ...],
#  ['iran', "'", 's', 'purpose', 'doing', 'it', 'is', ...],
#  ['you', 'can', '’', 't', 'let', 'your', 'guard', ...],
#  ['2', '.', '1', 'million', 'covid', 'vaccine', 'doses', ...],
#  ['#', 'kamalaharris', '#', 'us', '#', 'joebiden', '#', ...],
#  ['#', 'mydubai', 'receives', 'first', 'batch', ...],
#  ['wth', 'arrival', 'f', 'new', 'uk', 'strain', 'covid', ...],
#  ['union', 'minister', 'ramdas', 'athawale', ',', ...],
#  ['Now', 'another', 'new', 'tension', 'has', 'started', ...],
#  ['first', 'covid', 'vaccine', 'does', 'blue_heart', ...],
#  ['we', '’', 're', 'not', 'going', 'get', 'rid', ...],
#  ['lots', 'negativity', 'surrounding', 'arcturus', ...],
#  ['We', 'trust', 'in', 'God', 'blue_heart', '@', ...],
#  ['all', 'vaccinated', 'people', 'against', 'covid', ...],
#  ['got', 'health', 'card', 'number', 'now', '"', 'book', ...],
#  ['correct', '.', 'covidiots', 'bark', 'without', ...],
#  ['india', 'do', 'not', 'need', 'dose', 'covid', '19', ...],
#  ['#', 'indiabeginsdryrun', 'india', 'which', 'is', ...],
#  ['flash', ':', 'vaccines', 'will', 'work', 'against', ...],
#  ['yes', 'i', 'got', '#', 'jab', 'done', '#', ...],
#  ['wear', 'mask', 'even', 'after', 'getting', 'covid', ...],
#  ['breaking', ':', 'india', 'says', 'it', 'has', ...],
#  ['Information', 'is', 'constantly', 'evolving', 'and', ...],
#  ['#', 'information', 'fraudsters', 'are', 'calling', ...],
#  ['do', 'not', 'share', 'aadhaar', 'card', ',', 'banks', ...],
#  ['new', 'covid', '-', '19', 'strain', 'reaches', ...],
#  ['new', 'covid', '-', '19', 'strain', 'reaches', ...],
#  ['big', 'task', 'ahead', 'india', '.', 'covid', '-', ...],
#  ['covid', 'vaccine', 'has', 'been', 'used', 'by', ...],
#  ['important', 'msg', ...],
#  ['whatsapp', 'backhand_index_pointing_rightlight_skin_tone', ...],
#  ['we', 'had', '15k', 'people', 'confirmed', 'with', ...],
#  ...]

# %%
print(len(tokenised_words))
# Out:
# 3000

# %%
tokenised_words[-1]
# Out:
# ['party_popper', 'will', 'get', 'it', 'now', '.', ...]

# %% [markdown]
# ## Converting British to American English

# %%
#https://stackoverflow.com/questions/42329766/python-nlp-british-english-vs-american-english

import requests

def americanize(word):
    url ="https://raw.githubusercontent.com/hyperreality/American-British-English-Translator/master/data/british_spellings.json"
    british_to_american_dict = requests.get(url).json()

    for british_spelling, american_spelling in british_to_american_dict.items():
        word = word.replace(british_spelling, american_spelling)
  
    return word

# %%
# import requests

# def britishize(string):
#     url ="https://raw.githubusercontent.com/hyperreality/American-British-English-Translator/master/data/american_spellings.json"
#     american_to_british_dict = requests.get(url).json()    

#     for american_spelling, british_spelling in american_to_british_dict.items():
#         string = string.replace(american_spelling, british_spelling)
  
#     return string

# %%
test_americanize = [['flavor', 'color'], ['apologize', 'traveled']]
test_americanize = [[americanize(w) for w in each] for each in test_americanize]
test_americanize
# Out:
# [['flavor', 'color'], ['apologize', 'traveled']]

# %%
# test_britishize = [['flavor', 'color'], ['apologize', 'traveled']]
# test_britishize = [[britishize(w) for w in each] for each in test_britishize]
# test_britishize

# %%
# len(tokenised_removed_campaigns)

# %%
tokenised_amer = [[americanize(w) for w in each] for each in tokenised_words]
tokenised_amer
# Out:
# [['finally', 'covid', '19', 'vaccine'],
#  ['assam', 't', 'covid', 'r', 'vaccine', 'ahi', 'golslightly_smiling_face'],
#  ['first',
#   'batch',
#   '#',
#   'covidvaccine',
#   'ne',
#   'reached',
#   'lgbi',
#   'airport',
#   ',',
#   '#',
#   'guwahati',
#   '.',
#   'around',
#   '20',
#   'boxes',
#   'vaccines',
#   'received',
#   'today',
#   'at',
#   'guwahati',
#   ',',
#   'out',
#   'which',
#   '17',
#   'are',
#   'assam',
#   '3',
#   'are',
#   'meghalaya',
#   '.'],
#  ['state',
#   'task',
#   'force',
#   'stf',
#   'held',
#   'it',
#   'is',
#   'second',
#   'meeting',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   '.',
#   '#',
#   'nagaland',
#   'read',
#   '-'],
#  ['strengthening',
#   'efforts',
#   'health',
#   'counselors',
#   'effective',
#   'roll',
#   'out',
#   'covid',
#   'vaccine'],
#  ['covid',
#   'vaccine',
#   'arrive',
#   'at',
#   '20',
#   'cartons',
#   'vaccines',
#   'arrive',
#   'at'],
#  ['#',
#   'new_video_in_hindi',
#   'The',
#   'government',
#   'should',
#   'rethink',
#   'again',
#   '#',
#   'covidvaccine',
#   ',',
#   'do',
#   'not',
#   'take',
#   'any',
#   'step',
#   'in',
#   'haste',
#   'folded_handsfolded_hands'],
#  ['Corona',
#   'vaccine',
#   '#',
#   'covidvaccine',
#   '#',
#   'covisheeld',
#   'came',
#   'to',
#   'the',
#   'state'],
#  ['this',
#   'is',
#   'what',
#   'entire',
#   'country',
#   'India',
#   'has',
#   'been',
#   'waiting',
#   'since',
#   'march',
#   '2020',
#   '.',
#   'green',
#   'corridors',
#   'being',
#   'created',
#   'by',
#   'police',
#   'multiple',
#   'India',
#   'cities',
#   '.',
#   'visuals',
#   'first',
#   'consignment',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   '#',
#   'covishield',
#   'arrives',
#   'at',
#   'telangana',
#   "'",
#   's',
#   'immunization',
#   'complex',
#   'koti',
#   '#',
#   'hyderabad',
#   '#',
#   'covidvaccine'],
#  ['lowest',
#   'case',
#   '#',
#   'vaccine',
#   'is',
#   'ready',
#   '#',
#   'india',
#   '.',
#   '#',
#   'indiafightscorona',
#   '#',
#   'covid19',
#   '#',
#   'covidiots',
#   '#',
#   'covidvaccine',
#   '#',
#   'healthcare',
#   '#',
#   'safety',
#   '#',
#   'stayhome',
#   '#',
#   'world',
#   '#',
#   'peoople',
#   '#',
#   '302pendinginssrcase',
#   '#',
#   'trumpcoupattempt',
#   '#',
#   'trumpbanned',
#   '#',
#   'biden',
#   '#',
#   'university',
#   '#',
#   'masterfilm',
#   '#',
#   'masterpongal'],
#  ['I',
#   'want',
#   'to',
#   'avoid',
#   'children',
#   'getting',
#   'covid',
#   '.',
#   'installl',
#   'antivirus',
#   '.',
#   'I',
#   'do',
#   'not',
#   'need',
#   'an',
#   'ambiguous',
#   'vaccine',
#   '.'],
#  ['if',
#   'bjp',
#   'will',
#   'come',
#   'power',
#   ',',
#   'every',
#   'person',
#   'will',
#   'get',
#   'free',
#   'vaccine',
#   'covid',
#   'meanwhile',
#   'bihari',
#   '-'],
#  ['#',
#   '4newstrains',
#   '...',
#   'is',
#   'new',
#   'challenge',
#   '...',
#   'testing',
#   'these',
#   'rampantly',
#   ',',
#   'only',
#   'way',
#   'out',
#   '...',
#   'we',
#   'cannt',
#   'let',
#   'it',
#   'beat',
#   'our',
#   '#',
#   'covidvaccine',
#   'initiatives',
#   '...#',
#   'covid19',
#   'challenging',
#   'science',
#   'even',
#   'more'],
#  ['Something',
#   'happy',
#   'every',
#   'time',
#   'I',
#   'visit',
#   'I',
#   'am',
#   'impressed',
#   'and',
#   'proud',
#   '🇸',
#   'American_SamoaAmerican_Samoa',
#   '🇦',
#   'white_heartwhite_heartwhite_heart',
#   '@',
#   'Corona',
#   '-',
#   'covid',
#   '-',
#   '19',
#   'Vaccine',
#   'Center',
#   'Riyadh'],
#  ['beware',
#   'indian',
#   'cargo',
#   'planes',
#   'with',
#   'loads',
#   'covid',
#   'vaccine',
#   'may',
#   'be',
#   'hijacked',
#   '#',
#   'pakistan'],
#  ['live',
#   'update',
#   'out',
#   '6',
#   '#',
#   'covidvaccine',
#   'centers',
#   '#',
#   'telangana',
#   ',',
#   'area',
#   'hospital',
#   '#',
#   'nampally',
#   'has',
#   'been',
#   'selected',
#   'as',
#   'center',
#   '#',
#   'covid19',
#   'vaccination',
#   'program',
#   ',',
#   'i',
#   'inspected',
#   'hospital',
#   'preparations',
#   '.',
#   '#',
#   'covidvaccine2021',
#   '#',
#   'covidvaccinations',
#   '#',
#   'covidvaccinefacts',
#   '#',
#   'hyderabad'],
#  ['yes',
#   ',',
#   'students',
#   'can',
#   'go',
#   'attend',
#   'their',
#   'xams',
#   'covid',
#   'when',
#   'there',
#   'was',
#   'not',
#   'even',
#   'any',
#   'signal',
#   'success',
#   'vaccine',
#   'but',
#   'u',
#   'should',
#   'not',
#   'do',
#   'ur',
#   'work',
#   'also',
#   'do',
#   'not',
#   'forget',
#   'there',
#   'r',
#   'doctors',
#   'nurses',
#   'n',
#   'many',
#   'others',
#   'who',
#   'r',
#   'constantly',
#   'doing',
#   'thr',
#   'jobs',
#   'amid',
#   'covid',
#   'risking',
#   'thr',
#   'lyf',
#   'real',
#   'but',
#   'u',
#   'should',
#   'not',
#   'work',
#   'ri8'],
#  ['great',
#   'effort',
#   'eradicate',
#   '#',
#   'covid19',
#   '.',
#   '#',
#   'india',
#   '#',
#   'healthcare',
#   '#',
#   'covidvaccine',
#   '#',
#   'covid',
#   '#',
#   'stateofemergency',
#   '#',
#   'staysafe',
#   '#',
#   'swamivivekanandjayanti',
#   '#',
#   'aatmanirbharbharat',
#   '#',
#   'listen',
#   '#',
#   'vivekananda',
#   '#',
#   'priyankagandhi',
#   '#',
#   'homeoffice',
#   '#',
#   'whatsappprivacy',
#   '#',
#   'trumpbegged',
#   '#',
#   'biden',
#   '#',
#   'masterfilm',
#   '#',
#   'masterpongal',
#   '#',
#   'homeschooling'],
#  ['has',
#   'updated',
#   'info',
#   'now',
#   ':',
#   'sg',
#   '493',
#   'has',
#   'delivered',
#   'all',
#   '6',
#   '.',
#   '4',
#   'lakh',
#   'doses',
#   '#',
#   'covidvaccine',
#   'scheduled',
#   'be',
#   'delivered',
#   'today',
#   'bengaluru',
#   '.',
#   'pics',
#   'at',
#   'vaccines',
#   'unloading'],
#  ['#',
#   'vaccinestrategy',
#   'green',
#   'corridor',
#   'made',
#   'truck',
#   'carrying',
#   'covid',
#   'vaccines',
#   ',',
#   'truck',
#   'currently',
#   'enroute',
#   'rajiv',
#   'gandhi',
#   'hospital',
#   '.'],
#  ['welcome',
#   '#',
#   'bengaluru',
#   ',',
#   '#',
#   'covid',
#   '#',
#   'vaccine',
#   'have',
#   'great',
#   'time',
#   '.',
#   '#',
#   'vaccinations'],
#  ['wait',
#   'is',
#   'finally',
#   'over',
#   '.',
#   'first',
#   'consignment',
#   '#',
#   'covidvaccine',
#   'vials',
#   'have',
#   'arrived',
#   'at',
#   'storage',
#   'center',
#   'bengaluru',
#   '.'],
#  ['#',
#   'covidvaccine',
#   'bengaluru',
#   ':',
#   'spicejet',
#   '2day',
#   'sent',
#   'it',
#   'is',
#   '1st',
#   'batch',
#   'vacc',
#   'doses',
#   'b',
#   "'",
#   'luru',
#   'frm',
#   'pune',
#   '.',
#   'sg',
#   '493',
#   'rchd',
#   'kia',
#   '@',
#   '12',
#   '.',
#   '15',
#   'pm',
#   ',',
#   'said',
#   'spokesperson',
#   'qty',
#   'not',
#   'yet',
#   'clear',
#   '.',
#   'deliv',
#   '6',
#   ',',
#   '48',
#   ',',
#   '000',
#   'doses',
#   'b',
#   "'",
#   'lur',
#   'tue',
#   '&',
#   'amp',
#   ';',
#   '4',
#   'mn',
#   'doses',
#   '4',
#   'india',
#   '.',
#   'rep',
#   'pic'],
#  ['Congratulations',
#   'Delhi',
#   'The',
#   'first',
#   'consignment',
#   'of',
#   'Corona',
#   'Vaccine',
#   'reached',
#   'Delhi',
#   '.',
#   '#',
#   'covidvaccine',
#   '#',
#   'delhi'],
#  ['scoop',
#   '1st',
#   'look',
#   'it',
#   'suggests',
#   'it',
#   '’',
#   's',
#   'multi',
#   '-',
#   'dose',
#   'vial',
#   '.',
#   'expiry',
#   'april',
#   '2021',
#   'indicates',
#   'limited',
#   'shelf',
#   'life',
#   '.',
#   '2',
#   'doses',
#   'per',
#   'person',
#   'will',
#   'consume',
#   'most',
#   'them',
#   '.',
#   'storage',
#   'course',
#   'at',
#   '2',
#   '-',
#   '8',
#   '’',
#   'c',
#   '.',
#   '#',
#   'covidvaccine',
#   '#',
#   'indiafightscorona',
#   '#',
#   'vaccineswork'],
#  ['preparatory',
#   'meeting',
#   'regarding',
#   'covid',
#   'vaccine',
#   '16',
#   'Jan',
#   'mro',
#   'ameerpet',
#   'chandrakal',
#   ',',
#   'dmo',
#   'revathi',
#   ',',
#   'dr',
#   'sridhar',
#   'nodal',
#   'office',
#   '#',
#   'bjp',
#   '#',
#   'bjpforindia'],
#  ['nepal',
#   'desert_island',
#   '️',
#   'desert_island',
#   '️',
#   'prefers',
#   'indian',
#   'vaccines',
#   'over',
#   'chinese',
#   'as',
#   'fm',
#   'gyawali',
#   'visits',
#   'india',
#   'procurement',
#   'half',
#   'million',
#   'doses',
#   'covid',
#   '-',
#   '19',
#   'thermometer',
#   '️',
#   'thermometer',
#   '️',
#   'vaccine',
#   'india',
#   'tops',
#   'agenda',
#   'nepalese',
#   'foreign',
#   'minister',
#   'pradeep',
#   'gyawali',
#   'who',
#   'arrives',
#   'new',
#   'delhi',
#   'january',
#   '14',
#   '.',
#   '#',
#   'newyear2021',
#   '#',
#   'censorship',
#   'flying_saucerflying_saucer'],
#  ['#',
#   'seruminstituteofindia',
#   '#',
#   'covidvaccine',
#   '#',
#   'aatmanirbharbharat'],
#  ['#',
#   'ahmedabad',
#   ':',
#   'first',
#   'consignment',
#   'coronavirus',
#   'vaccine',
#   'arrived',
#   'at',
#   'ahmedabad',
#   "'",
#   's',
#   'sardar',
#   'vallabhbhai',
#   'patel',
#   'international',
#   'airport',
#   'deputy',
#   'cm',
#   'nitin',
#   'patel',
#   'was',
#   'present',
#   'at',
#   'airport',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'covidvaccine',
#   '#',
#   '506',
#   '#',
#   '1201',
#   '#',
#   'ourvapii'],
#  ['am',
#   'waiting',
#   'take',
#   'covid',
#   'vaccine',
#   'head',
#   'out',
#   'world',
#   'that',
#   'we',
#   'are',
#   'so',
#   'used',
#   '..',
#   'shows',
#   ',',
#   'recordings',
#   ',',
#   'shoots',
#   'et',
#   'al',
#   '..',
#   'some',
#   'people',
#   'ask',
#   'if',
#   'vaccine',
#   'is',
#   'safe',
#   'or',
#   'without',
#   'side',
#   'effects',
#   '..',
#   'my',
#   'answer',
#   'is',
#   'any',
#   'side',
#   'effect',
#   'is',
#   'benign',
#   'compared',
#   'dreaded',
#   'covid',
#   ',',
#   'especially',
#   'my',
#   'age'],
#  ['covid', 'vaccine', 'mi', 'mahu', 'libeyne', '.'],
#  ['"',
#   'Survey',
#   'Bhavantu',
#   'Sukhin',
#   ':',
#   'Survey',
#   'Santu',
#   'Niramaya',
#   '.',
#   'May',
#   'everyone',
#   'be',
#   'free',
#   'disease',
#   '"',
#   'this',
#   'is',
#   'stamp',
#   'marked',
#   'every',
#   'box',
#   '#',
#   'covidvaccine',
#   'transported',
#   'various',
#   'parts',
#   'country',
#   '....'],
#  ['#',
#   'covidvaccine',
#   'If',
#   'someone',
#   'is',
#   'taking',
#   'medicine',
#   'for',
#   'diseases',
#   'like',
#   'cancer',
#   ',',
#   'diabetes',
#   ',',
#   'high',
#   'blood',
#   'pressure',
#   'etc',
#   ',',
#   'can',
#   'he',
#   'take',
#   'corona',
#   'vaccine',
#   '#',
#   'indiafightscorona',
#   '#',
#   'coronavaccine'],
#  ['boom',
#   'rolling_on_the_floor_laughingrolling_on_the_floor_laughingrolling_on_the_floor_laughing',
#   '.',
#   'that',
#   'is',
#   '#',
#   'rocketshot',
#   'rocket',
#   'son',
#   'face_with_tears_of_joyface_with_tears_of_joyperson_facepalminglight_skin_tone',
#   '\u200d',
#   'male_sign',
#   '.',
#   '#',
#   'retweet',
#   '#',
#   'twitch',
#   '#',
#   'twitter',
#   '#',
#   'india',
#   '#',
#   'mumbai',
#   '#',
#   'memes',
#   '#',
#   'funnyvideo',
#   '#',
#   'onlybreath',
#   '#',
#   'covidvaccine',
#   '#',
#   'donaldtrump',
#   '#',
#   'goodmorning',
#   '#',
#   'goodmorningtwitterworld',
#   '#',
#   'boom',
#   '#',
#   'maharashtra',
#   '#',
#   'instagram',
#   '#',
#   'quoteoftheday',
#   '#',
#   'positivevibes'],
#  ['boom',
#   'rolling_on_the_floor_laughingrolling_on_the_floor_laughingrolling_on_the_floor_laughing',
#   '.',
#   'that',
#   'is',
#   '#',
#   'rocketshot',
#   'rocket',
#   'son',
#   'face_with_tears_of_joyface_with_tears_of_joyperson_facepalminglight_skin_tone',
#   '\u200d',
#   'male_sign',
#   '.',
#   '#',
#   'retweet',
#   '#',
#   'twitch',
#   '#',
#   'twitter',
#   '#',
#   'india',
#   '#',
#   'mumbai',
#   '#',
#   'memes',
#   '#',
#   'funnyvideo',
#   '#',
#   'onlybreath',
#   '#',
#   'covidvaccine',
#   '#',
#   'donaldtrump',
#   '#',
#   'goodmorning',
#   '#',
#   'goodmorningtwitterworld',
#   '#',
#   'boom',
#   '#',
#   'maharashtra',
#   '#',
#   'instagram'],
#  ['blo',
#   'at',
#   'vasant',
#   'kunj',
#   'sector',
#   'c',
#   'pocket',
#   '-',
#   '1',
#   'is',
#   'supposed',
#   'reach',
#   'by',
#   '12',
#   '.',
#   '00',
#   'noon',
#   'distribute',
#   'forms',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'till',
#   'now',
#   'there',
#   'is',
#   'no',
#   'sign',
#   '.',
#   'senior',
#   'citizens',
#   'are',
#   'waiting',
#   'but',
#   'no',
#   'sign',
#   'her',
#   'coming',
#   '.',
#   'is',
#   'this',
#   'way'],
#  ['When',
#   'the',
#   'car',
#   'carrying',
#   'the',
#   'Kovid',
#   'vaccine',
#   'from',
#   'the',
#   'Serum',
#   'Institute',
#   'in',
#   'Pune',
#   ',',
#   'was',
#   'worshiped',
#   '.',
#   'Why',
#   'do',
#   'you',
#   'know',
#   'that',
#   'before',
#   'taking',
#   'the',
#   'vaccine',
#   ',',
#   'you',
#   'should',
#   'also',
#   'worship',
#   '...',
#   'why',
#   'do',
#   'you',
#   'know',
#   '#',
#   'covidvaccine'],
#  ['good',
#   'bm',
#   'story',
#   'tracking',
#   'covid',
#   'vaccine',
#   '’',
#   's',
#   'transportation',
#   'bengaluru'],
#  ['first',
#   'batch',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'at',
#   'igi',
#   'airport',
#   '.',
#   '#',
#   '9news'],
#  ['so',
#   'when',
#   'is',
#   'our',
#   'hardworking',
#   'pm',
#   'modi',
#   'taking',
#   'covid',
#   'vaccine',
#   'live',
#   'tv',
#   'then',
#   'he',
#   'cannot',
#   'miss',
#   'that',
#   'glorious',
#   'pr',
#   'moment',
#   ',',
#   'can',
#   'he',
#   'if',
#   'he',
#   'is',
#   'not',
#   'seen',
#   'taking',
#   'one',
#   'live',
#   'feed',
#   ',',
#   'what',
#   'does',
#   'it',
#   'tell',
#   'about',
#   'vaccines',
#   '#',
#   'vaccine',
#   '#',
#   'vaccinestrategy',
#   '#',
#   'seruminstituteofindia'],
#  ['#',
#   'delhi',
#   '|',
#   'first',
#   'consignment',
#   '#',
#   'covishield',
#   'covid',
#   '#',
#   'vaccine',
#   'arrives',
#   'pune',
#   "'",
#   's',
#   'serum',
#   'institute',
#   'india',
#   'delhi',
#   '.',
#   'pics',
#   'delhi',
#   'airport',
#   "'",
#   's',
#   'cargo',
#   'terminal',
#   '.'],
#  ['proud',
#   'moment',
#   'pune',
#   '.',
#   'trucks',
#   'carrying',
#   'covid',
#   'vaccines',
#   'their',
#   'way',
#   'airport',
#   'be',
#   'shipped',
#   'all',
#   'over',
#   'country',
#   '.',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'indiafightscorona',
#   '#',
#   'covishield',
#   '#',
#   'seruminstituteofindia',
#   '#',
#   'aatmanirbharbharat',
#   '#',
#   'pune',
#   '#',
#   'corona'],
#  ['why',
#   'is',
#   'spicejet',
#   'still',
#   'flying',
#   'under',
#   'jet',
#   'airways',
#   'colors',
#   'carrying',
#   'covid',
#   'vaccine',
#   '..',
#   'wolf',
#   'sheep',
#   '’',
#   's',
#   'clothing',
#   'or',
#   'vice',
#   'versa'],
#  ['we',
#   'need',
#   'debunk',
#   'myths',
#   'about',
#   'covid',
#   'vaccine',
#   '.',
#   'great',
#   'interview',
#   'by',
#   'dr',
#   'nk',
#   'arora',
#   '.'],
#  ['first',
#   'consignment',
#   '#',
#   'covid19',
#   '#',
#   'vaccine',
#   "'",
#   'covishield',
#   "'",
#   'arrives',
#   'at',
#   'delhi',
#   'airport',
#   'pune',
#   '.',
#   'first',
#   'phase',
#   '#',
#   'vaccination',
#   'india',
#   'starts',
#   'january',
#   '16',
#   '.',
#   '#',
#   'covidvaccine'],
#  ['just', 'in', ':', 'lands', 'with', '#', 'covidvaccine'],
#  ['#',
#   'covidvaccine',
#   'started',
#   'it',
#   'is',
#   'journey',
#   '#',
#   'seruminstituteofindia',
#   '#',
#   'pune',
#   'early',
#   'this',
#   'morning',
#   'different',
#   'locations',
#   '#',
#   'india',
#   '#',
#   'health',
#   '#',
#   'frontlineworkers'],
#  ['#',
#   'श',
#   'ु',
#   'भ',
#   'ा',
#   'र',
#   'ं',
#   'भ_श',
#   'ु',
#   'भ',
#   'ा',
#   'र',
#   'ं',
#   'भ',
#   'thumbs_upsyringeclapping_handsclapping_handsspicejet',
#   'has',
#   'carried',
#   'india',
#   '’',
#   's',
#   'first',
#   'consignment',
#   '#',
#   'covid',
#   'vaccine',
#   'today',
#   '.',
#   '#',
#   'first',
#   'consignment',
#   "'#",
#   'covishield',
#   "'",
#   'consisting',
#   '34',
#   'boxes',
#   'weighing',
#   '1088',
#   'kg',
#   'was',
#   'carried',
#   '#',
#   'pune',
#   '#',
#   'delhi',
#   '#',
#   'vaccine',
#   '#',
#   'covid19'],
#  ['covid19',
#   '|',
#   'carried',
#   'india',
#   '’',
#   's',
#   'first',
#   'consignment',
#   'covid',
#   'vaccine',
#   'today',
#   '.',
#   'consignment',
#   "'",
#   'covishield',
#   "'",
#   'constitutes',
#   '34',
#   'boxes',
#   'weights',
#   '1088',
#   'kg',
#   'is',
#   'being',
#   'carried',
#   '#',
#   'pune',
#   '#',
#   'delhi',
#   ':',
#   'ajay',
#   'singh',
#   ',',
#   'chairman',
#   '&',
#   'amp',
#   ';',
#   'm',
#   'd',
#   ',',
#   'spicejet',
#   '#',
#   'covishield',
#   '#',
#   'vaccine',
#   '#',
#   'indian',
#   '#',
#   'thecpdaily'],
#  ['wow', 'wel', 'come', 'hyd', 'covid', 'vaccine'],
#  ['what',
#   'positive',
#   'news',
#   'start',
#   'day',
#   '1st',
#   'consignment',
#   '#',
#   'covishield',
#   'vaccines',
#   'left',
#   '#',
#   'seruminstituteofindia',
#   'nationwide',
#   'vaccination',
#   'drive',
#   '#',
#   'covidvaccine',
#   '#',
#   'tuesdayvibe'],
#  ['how',
#   'can',
#   'saying',
#   '#',
#   'covid',
#   'vaccines',
#   'made',
#   'india',
#   'are',
#   'not',
#   'worth',
#   'just',
#   'before',
#   'vaccines',
#   'availablepersevering_facepouting_face',
#   'highly',
#   'irresponsible',
#   'act',
#   'n',
#   'seeding',
#   'fear',
#   'viewers',
#   'mindconfounded_face',
#   'pls',
#   'look',
#   'into',
#   'it'],
#  ['covid', '-', '19', 'vaccine', 'starts', 'it', 'is', 'journey', 'pune'],
#  ['aam',
#   'aadmi',
#   'party',
#   'jammu',
#   'jk',
#   'demands',
#   'free',
#   'cost',
#   'vaccine',
#   'against',
#   'covid',
#   '-',
#   '19',
#   'all',
#   'citizens',
#   '.'],
#  ['this',
#   'is',
#   'first',
#   'lot',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   ',',
#   'all',
#   'set',
#   'arrive',
#   'pune',
#   'flight',
#   '.',
#   'later',
#   'day',
#   ',',
#   'air',
#   'india',
#   'flight',
#   'is',
#   'expected',
#   'fly',
#   'another',
#   'consignment',
#   'vaccines',
#   'delhi',
#   ',',
#   'pune',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'vaccine'],
#  ['spicejet',
#   'has',
#   'carried',
#   'india',
#   '’',
#   's',
#   'first',
#   'consignment',
#   'covid',
#   'vaccine',
#   'today',
#   '.',
#   'first',
#   'consignment',
#   "'",
#   'covishield',
#   "'",
#   'consisting',
#   '34',
#   'boxes',
#   'weighing',
#   '1088',
#   'kg',
#   'was',
#   'carried',
#   '#',
#   'pune',
#   '#',
#   'delhi'],
#  ['#',
#   'breaking',
#   ':',
#   'first',
#   'lot',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   'that',
#   'will',
#   'come',
#   'delhi',
#   ',',
#   'being',
#   'loaded',
#   'flight',
#   'tuesday',
#   'morning',
#   'at',
#   'pune',
#   'airport',
#   '.'],
#  ['अच',
#   '्',
#   'छ',
#   'े',
#   'द',
#   'ि',
#   'न',
#   'serum',
#   'institute',
#   'india',
#   "'",
#   's',
#   'covid19',
#   'vaccine',
#   "'",
#   'covishield',
#   "'",
#   'will',
#   'be',
#   'shipped',
#   'different',
#   'locations',
#   'country',
#   'pune',
#   'airport',
#   ',',
#   'ahead',
#   'january',
#   '16',
#   'vaccine',
#   'rollout',
#   '.',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'covidvaccine'],
#  ['india',
#   'wants',
#   'serum',
#   'institute',
#   'lower',
#   'price',
#   'astrazeneca',
#   "'",
#   's',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'download',
#   'economic',
#   'times',
#   'app',
#   'stay',
#   'updated',
#   'with',
#   'business',
#   'news',
#   '-'],
#  ['will',
#   'pfizer',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'come',
#   'india',
#   'pfizer',
#   'had',
#   'applied',
#   'eua',
#   'india',
#   'december',
#   ',',
#   '2020',
#   ',',
#   'but',
#   'they',
#   'have',
#   'not',
#   'attended',
#   'any',
#   'three',
#   'sec',
#   'meetings',
#   'held',
#   'since',
#   'then',
#   '.'],
#  ['last',
#   '-',
#   'mile',
#   'covid',
#   'vaccine',
#   'delivery',
#   'far',
#   'perfect',
#   'sabah',
#   ',',
#   'sarawak',
#   'pfizer',
#   'moderna',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   'are',
#   'not',
#   'suitable',
#   'sabah',
#   'sarawak',
#   ',',
#   'says',
#   'federation',
#   'malaysian',
#   'freight',
#   'forwarders',
#   '.'],
#  ['health',
#   'minister',
#   'assures',
#   'transparency',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'purchase'],
#  ['thermometersyringe',
#   'aussies',
#   'will',
#   'be',
#   'vaccinated',
#   'against',
#   'covid',
#   '-',
#   '19',
#   'from',
#   'February',
#   ',',
#   'is',
#   'it',
#   'true',
#   'round_pushpinAustralia',
#   'according',
#   'to',
#   'new',
#   'information',
#   'from',
#   'health',
#   'experts',
#   'and',
#   'regulators',
#   ',',
#   'aussies',
#   'will',
#   'be',
#   'vaccinated',
#   'against',
#   'coronavirus',
#   'in',
#   'February',
#   '.',
#   'globe_with_meridians'],
#  ['hopefully',
#   'johor',
#   'does',
#   'same',
#   'as',
#   'well',
#   '.',
#   'that',
#   'might',
#   'help',
#   'open',
#   'up',
#   'causeway',
#   'again',
#   'report',
#   ':',
#   'selangor',
#   'buy',
#   'up',
#   '5',
#   'million',
#   'doses',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   'state',
#   'residents',
#   '|'],
#  ['so',
#   'i',
#   '’',
#   've',
#   'had',
#   'first',
#   'dose',
#   'sinopharm',
#   'covid',
#   'vaccine',
#   'i',
#   '’',
#   've',
#   'had',
#   'no',
#   'symptoms',
#   'at',
#   'all',
#   ',',
#   'nothing',
#   'after',
#   '30',
#   'hours',
#   'counting',
#   'now',
#   '.',
#   'how',
#   'strange',
#   'this',
#   'whole',
#   'pandemic',
#   'is'],
#  ['pm',
#   'shri',
#   'narendra',
#   'modi',
#   "'",
#   's',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cms',
#   'roll',
#   '-',
#   'out',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   '.',
#   '#',
#   'indiafightscorona'],
#  ['tamil',
#   'nadu',
#   'govt',
#   'doctors',
#   'are',
#   'reluctant',
#   'accept',
#   'covid',
#   'vaccine',
#   'shot',
#   '.',
#   'nurses',
#   'too',
#   'may',
#   'follow',
#   '.',
#   'read'],
#  ['new',
#   'sources',
#   'found',
#   'that',
#   'vitamin',
#   'd',
#   'is',
#   'good',
#   'stopping',
#   'covid',
#   '19',
#   'disease',
#   '.',
#   'sunlight',
#   'is',
#   'good',
#   'source',
#   'gaining',
#   'vitamin',
#   'd',
#   '.',
#   'drink',
#   'cow',
#   "'",
#   's',
#   'milk',
#   'orange',
#   'juice',
#   '.',
#   'you',
#   'can',
#   'take',
#   'vitamin',
#   'd',
#   'suppliment',
#   'tablets',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'coronavirusstrain',
#   '#',
#   'vitamind',
#   '#',
#   'vaccine'],
#  ['govt',
#   'india',
#   'will',
#   'pay',
#   'gst',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   '.',
#   'govt',
#   'india',
#   'will',
#   'give',
#   'this',
#   'vaccine',
#   'free',
#   '.',
#   'govt',
#   'india',
#   'will',
#   'earn',
#   'gst',
#   'returns',
#   'this',
#   '.',
#   'it',
#   'requires',
#   '"',
#   'extra',
#   '"',
#   'ordinary',
#   'use',
#   'brain',
#   'extraordinary',
#   'times',
#   'collect',
#   'gst',
#   'covid',
#   'vaccine',
#   'that',
#   'goi',
#   'will',
#   'purchase',
#   '&',
#   'amp',
#   ';',
#   'giveaway',
#   'free'],
#  ['covid', 'vaccine', 'se', 'jyada', 'we', 'need', 'develop', 'spine'],
#  ['#',
#   'vaccine',
#   'first',
#   'batch',
#   '/',
#   'consignment',
#   '#',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'likely',
#   'reach',
#   'jammu',
#   'kashmir',
#   'tomorrow',
#   'or',
#   'wednesday',
#   '.',
#   'health',
#   'workers',
#   'will',
#   'be',
#   'covered',
#   'first',
#   '.'],
#  ['yes',
#   'index_pointing_upcheck_mark_button',
#   'also',
#   'cm',
#   'maharashtra',
#   'must',
#   'be',
#   'requested',
#   'declare',
#   'that',
#   'covid',
#   '19',
#   'vaccine',
#   'will',
#   'be',
#   'free',
#   'all',
#   '.',
#   'tulipfolded_handsrosetriangular_flagtriangular_flagIndiaIndia'],
#  ['upside',
#   '-',
#   'down_face',
#   '#',
#   'russia',
#   'try',
#   'out',
#   "'",
#   'sputnik',
#   '-',
#   'light',
#   "'",
#   'covid',
#   'vaccine',
#   'make',
#   'it',
#   'go',
#   'further'],
#  ['no',
#   'injection',
#   'are',
#   'available',
#   'due',
#   'covid',
#   '-',
#   '19',
#   ',',
#   'only',
#   'vaccines',
#   'are',
#   'stock',
#   ',',
#   'which',
#   'are',
#   'real',
#   '/',
#   'water',
#   "'",
#   'namo',
#   "'",
#   'only',
#   'knows',
#   '.',
#   'by',
#   'way',
#   'recent',
#   'excitement',
#   'indian',
#   'economy',
#   'are',
#   'case',
#   'study',
#   'eminent',
#   'economists',
#   'as',
#   'promised',
#   'by',
#   'him',
#   '.'],
#  ['vaccine',
#   'rolled',
#   'out',
#   'not',
#   'lobbies',
#   'nd',
#   'corrupt',
#   'politician',
#   ',',
#   'let',
#   'their',
#   'turn',
#   'come',
#   'decide',
#   'take',
#   'or',
#   'die',
#   'infected',
#   'with',
#   'covid'],
#  ['times',
#   'covid',
#   ',',
#   'when',
#   'our',
#   'indian',
#   'scientific',
#   'community',
#   'is',
#   'working',
#   'selflessly',
#   'covishield',
#   'covaxin',
#   'vaccines',
#   ',',
#   'there',
#   'are',
#   'pieces',
#   'information',
#   'that',
#   'are',
#   'defaming',
#   'their',
#   'great',
#   'work',
#   "'",
#   's',
#   'integrity',
#   '.',
#   'we',
#   ',',
#   'as',
#   'organizatiom',
#   'request',
#   'everyone',
#   'not',
#   'fall',
#   'pit',
#   'politicization'],
#  ['was',
#   'so',
#   'focused',
#   'steering',
#   'diskussion',
#   'against',
#   'covidvaccine',
#   'that',
#   'it',
#   'took',
#   'babu',
#   'among',
#   'politicos',
#   '--',
#   'tn',
#   'health',
#   'secy',
#   'get',
#   'anchor',
#   'drop',
#   'his',
#   'campaign',
#   'against',
#   'indigenous',
#   'vaccine',
#   '.',
#   'anchor',
#   'even',
#   'cross',
#   'checked',
#   'with',
#   'tmc',
#   'minister',
#   'if',
#   'modi',
#   'ever',
#   'let',
#   'us',
#   'state',
#   'leaders',
#   'speak',
#   'meeting',
#   '.'],
#  ['Finally',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'God',
#   'is',
#   'dear',
#   'to',
#   'our',
#   'country',
#   'and',
#   'is',
#   'not',
#   'dear',
#   'to',
#   'it',
#   '#',
#   'Corona_vaccine',
#   '#',
#   'Kingdom_Saudi_Arabia'],
#  ['agar',
#   'corona',
#   'ke',
#   'sath',
#   'ye',
#   'food',
#   'waste',
#   'bhi',
#   'khatam',
#   'ho',
#   'jaye',
#   'ganga',
#   'naha',
#   'lena',
#   'he',
#   'humne',
#   '#',
#   'khaanashah',
#   '#',
#   'indore',
#   '#',
#   'food',
#   '#',
#   'foodwaste',
#   '#',
#   'wastemanagement',
#   '#',
#   'zerocovid',
#   '#',
#   'zerowaste',
#   '#',
#   'covid19',
#   '#',
#   'trending',
#   '#',
#   'coronavirusstrain',
#   '#',
#   'coronavirus',
#   '#',
#   'vaccine',
#   '#',
#   'covid',
#   '#',
#   'sustainability',
#   '#',
#   'foodsecurity',
#   '#',
#   'indiathoughts'],
#  ['pm',
#   'modi',
#   "'",
#   's',
#   'closing',
#   'remarks',
#   'at',
#   'interaction',
#   'with',
#   'chief',
#   'ministers',
#   'all',
#   'states',
#   'covid',
#   'vaccine',
#   'rollout'],
#  ['*',
#   'Vaccines',
#   'are',
#   'still',
#   'in',
#   'trial',
#   'phase',
#   ',',
#   'then',
#   'how',
#   'crores',
#   'of',
#   'doses',
#   'we',
#   'are',
#   'prepared',
#   'for',
#   'vaccination',
#   '*',
#   'thinking_face',
#   '#',
#   'covidvaccine'],
#  ['our',
#   'vaccine',
#   'may',
#   'have',
#   'taken',
#   'time',
#   ',',
#   'but',
#   'it',
#   'is',
#   'very',
#   'likely',
#   'be',
#   'most',
#   'effective',
#   'masses',
#   '.',
#   'keep',
#   'rumors',
#   'aside',
#   ',',
#   'see',
#   'well',
#   'managed',
#   '#',
#   'vaccine',
#   'mahakumbh',
#   'now',
#   '.',
#   'we',
#   'will',
#   'overcome',
#   '#',
#   'covid'],
#  ['we',
#   '’',
#   've',
#   'made',
#   '#',
#   'covidvaccine',
#   'less',
#   'than',
#   'year',
#   ',',
#   'but',
#   'we',
#   '’',
#   've',
#   'not',
#   'been',
#   'able',
#   'make',
#   'fucking',
#   'mask',
#   'that',
#   'doesn',
#   '’',
#   't',
#   'slip',
#   'down',
#   'your',
#   'nose',
#   'person_facepalmingmedium_skin_tone',
#   '\u200d',
#   'male_sign',
#   '️',
#   '#',
#   'covid19'],
#  ['raj',
#   'ji',
#   ',',
#   'young',
#   'dynast',
#   'raga',
#   'has',
#   'come',
#   'back',
#   'after',
#   'his',
#   'long',
#   'new',
#   'yr',
#   'blast',
#   'mysterious',
#   'forgn',
#   'destination',
#   '.',
#   'plz',
#   'ask',
#   'him',
#   'take',
#   'covid',
#   'vaccines',
#   'bfr',
#   'hia',
#   'next',
#   'trip',
#   '.'],
#  ['over',
#   'million',
#   'people',
#   'beijing',
#   'have',
#   'received',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   '.'],
#  ['uae',
#   'has',
#   'administered',
#   '1',
#   ',',
#   '167',
#   ',',
#   '251',
#   'doses',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   ',',
#   'that',
#   '’',
#   's',
#   'average',
#   '11',
#   '.',
#   '8',
#   'doses',
#   'per',
#   '100',
#   'people',
#   '.',
#   '#',
#   'uae',
#   'syringe'],
#  ['#',
#   'cooperativefedralism',
#   'at',
#   'work',
#   '.',
#   'pm',
#   'modi',
#   "'",
#   's',
#   'closing',
#   'remarks',
#   'at',
#   'interaction',
#   'with',
#   'chief',
#   'ministers',
#   'all',
#   'states',
#   'covid',
#   'vaccine',
#   'rollout',
#   'proud',
#   'moment',
#   'india',
#   '.',
#   'health',
#   'safety',
#   'indian',
#   'people',
#   'at',
#   'stake'],
#  ['live',
#   ':',
#   'pm',
#   'shri',
#   'is',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cms',
#   'roll',
#   '-',
#   'out',
#   'covid',
#   '-',
#   '19',
#   'vaccine'],
#  ['by',
#   'way',
#   'how',
#   'is',
#   'your',
#   'region',
#   'doing',
#   'wrt',
#   'covid',
#   'numbers',
#   'we',
#   ',',
#   'our',
#   'family',
#   ',',
#   'too',
#   'contracted',
#   'it',
#   'are',
#   'out',
#   'quarantine',
#   '..',
#   'vaccines',
#   'should',
#   'be',
#   'out',
#   'there',
#   'right'],
#  ['it',
#   'is',
#   'ironic',
#   'that',
#   'same',
#   'person',
#   'who',
#   'said',
#   'we',
#   'do',
#   'not',
#   'need',
#   'vaccinessyringe',
#   'right',
#   'now',
#   'got',
#   'infected',
#   'with',
#   '#',
#   'covid19',
#   '.',
#   'maybe',
#   'at',
#   'least',
#   'now',
#   'gosl',
#   'understands',
#   'that',
#   'we',
#   'have',
#   'bring',
#   'down',
#   '#',
#   'covidvaccine',
#   '.',
#   '#',
#   'lka',
#   '#',
#   'srilanka',
#   '#',
#   'covid19sl',
#   '#',
#   'covid19lk'],
#  ['now',
#   'it',
#   'is',
#   'impossible',
#   'ec',
#   'win',
#   'even',
#   'if',
#   'he',
#   'goes',
#   'another',
#   'appeal',
#   'divisional',
#   'bench',
#   'high',
#   'court',
#   'advice',
#   'naidu',
#   '&',
#   'amp',
#   ';',
#   'co',
#   '.',
#   'it',
#   'would',
#   'be',
#   'foolish',
#   'thing',
#   ',',
#   'if',
#   'he',
#   'takes',
#   'any',
#   'further',
#   'wrong',
#   'step',
#   '.',
#   'now',
#   'he',
#   'should',
#   'realize',
#   'importance',
#   'covid',
#   '#',
#   'covid19',
#   '#',
#   'covidvaccine'],
#  ['big',
#   'breaking',
#   ':',
#   'reports',
#   'that',
#   'cost',
#   'free',
#   'vaccine',
#   '3cr',
#   'frontline',
#   'workers',
#   'will',
#   'be',
#   'borne',
#   'by',
#   'pm',
#   '-',
#   'cares',
#   '#',
#   'covidvaccine',
#   'file',
#   'pic'],
#  ['The',
#   'main',
#   'reason',
#   'for',
#   'the',
#   'end',
#   'of',
#   '#',
#   'corana',
#   '#',
#   'covid19',
#   'has',
#   'spread',
#   '#',
#   'covidvaccine',
#   'in',
#   'the',
#   'air'],
#  ['pm',
#   'shri',
#   'is',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cms',
#   'roll',
#   '-',
#   'out',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   '.',
#   '#',
#   'indiafightscorona'],
#  ['follow',
#   'us',
#   '-',
#   'serum',
#   "'",
#   's',
#   "'",
#   'covishield',
#   "'",
#   'vaccine',
#   'would',
#   'be',
#   'available',
#   'at',
#   'price',
#   '₹',
#   '200',
#   'per',
#   'vial',
#   ',',
#   'said',
#   'officials',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'coronavirusstrain',
#   '#',
#   'covid19',
#   '#',
#   'vaccine',
#   '#',
#   'covid_19',
#   '#',
#   'covid',
#   '#',
#   'covid2020',
#   '#',
#   'covishield',
#   '#',
#   'covidvacccine',
#   '#',
#   'covidtesting',
#   '#',
#   'covishieldlatestnews'],
#  ['pm',
#   'modi',
#   "'",
#   's',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cms',
#   'roll',
#   '-',
#   'out',
#   'covid',
#   '-',
#   '19',
#   'vaccine'],
#  ['india',
#   'is',
#   'working',
#   '4',
#   'other',
#   'covid',
#   'vaccines',
#   'says',
#   'pm',
#   'modi'],
#  ['#', 'covidvaccine', '#', 'nomo_lacke_crank'],
#  ['first',
#   'purchase',
#   'order',
#   '#',
#   'covidvaccine',
#   'was',
#   'registered',
#   'with',
#   'by',
#   'central',
#   'govt',
#   '.#',
#   'pune',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'coronavirusupdates'],
#  ['center',
#   'says',
#   'that',
#   'there',
#   'will',
#   'be',
#   'single',
#   'purchase',
#   'covid',
#   'vaccine',
#   'do',
#   'we',
#   'see',
#   'another',
#   'cess',
#   'adding',
#   'our',
#   'taxs',
#   'now'],
#  ['Corona',
#   'vaccine',
#   ':',
#   'Government',
#   'of',
#   'India',
#   'signs',
#   '11',
#   'million',
#   'dose',
#   'agreement',
#   'with',
#   'Serum',
#   'Institute',
#   'Dispatch',
#   'process',
#   'will',
#   'start',
#   'from',
#   'this',
#   'evening',
#   '#',
#   'coronavaccine',
#   '#',
#   'vaccine',
#   '#',
#   'corona',
#   '#',
#   'coronavirus',
#   '#',
#   'covid',
#   '#',
#   'aapnusanjeli',
#   '#',
#   'dahod'],
#  ['covid',
#   'vaccines',
#   'likely',
#   'reach',
#   'gujarat',
#   'today',
#   '.',
#   '#',
#   'coronavirusupdates'],
#  ['indian',
#   'pm',
#   'modi',
#   "'",
#   's',
#   'meet',
#   'with',
#   'cms',
#   'covid',
#   'vaccine',
#   'begins'],
#  ['because',
#   'as',
#   'i',
#   'know',
#   'pfizer',
#   'vaccine',
#   'has',
#   'been',
#   'clinical',
#   'trial',
#   'phase',
#   '3',
#   'usa'],
#  ['nice',
#   'see',
#   'mahindra',
#   'supro',
#   'is',
#   'taking',
#   'lead',
#   'role',
#   'covid',
#   'vaccine',
#   'distribution',
#   'far',
#   'off',
#   'places',
#   'clapping_handsclapping_handsclapping_hands'],
#  ['i',
#   'take',
#   '1',
#   'hour',
#   'looking',
#   'at',
#   'macdonalds',
#   'menu',
#   'even',
#   'tho',
#   'i',
#   'always',
#   'order',
#   'same',
#   'thing',
#   '.',
#   'i',
#   'had',
#   'decide',
#   'if',
#   'i',
#   'want',
#   'get',
#   'covid',
#   'vaccine',
#   'day',
#   '.',
#   'now',
#   'I',
#   'am',
#   'scheduled',
#   'one',
#   ',',
#   'but',
#   'I',
#   'am',
#   'still',
#   'unsure',
#   '.',
#   'confounded_face'],
#  ['bahana',
#   '14th',
#   'feb',
#   '2021',
#   'two_hearts',
#   '#',
#   'valentinesday',
#   'mummy',
#   'covid',
#   '19',
#   'ki',
#   'vaccine',
#   'lagwane',
#   'jana',
#   'h',
#   'face_with_tears_of_joyface_with_tears_of_joyface_with_tears_of_joy'],
#  ['26th',
#   'jan',
#   'would',
#   'have',
#   'been',
#   'better',
#   'date',
#   'start',
#   'covid',
#   'vaccine',
#   'india',
#   '.',
#   'something',
#   'would',
#   'have',
#   'worked',
#   'that',
#   'was',
#   'done',
#   '26th',
#   'jan',
#   '.',
#   '#',
#   'covid19india',
#   '#',
#   'covid19vaccine',
#   '#',
#   'india',
#   '#',
#   'republicday'],
#  ['date',
#   'arrival',
#   'covid',
#   'vaccine',
#   'quantity',
#   'vaccine',
#   'be',
#   'allotted',
#   '#',
#   'odisha',
#   'is',
#   'yet',
#   'be',
#   'intimated',
#   'by',
#   'center'],
#  ['th',
#   'heat',
#   'parliamentary',
#   'dissolution',
#   'covid',
#   'has',
#   'become',
#   'non',
#   'issue',
#   '.',
#   'i',
#   'reqst',
#   'govt',
#   'machinery',
#   'nd',
#   'health',
#   'ministry',
#   'not',
#   'forget',
#   'covid',
#   'menace',
#   'nd',
#   'urgently',
#   'make',
#   'availble',
#   'vaccines',
#   'frm',
#   'next',
#   'fortnight'],
#  ['rt',
#   ':',
#   'importing',
#   'vaccines',
#   'made',
#   'us',
#   'or',
#   'uk',
#   'is',
#   'prohibited',
#   '.',
#   'they',
#   'are',
#   'completely',
#   'untrustworthy',
#   '.',
#   'it',
#   'is',
#   'not',
#   'unlikely',
#   'they',
#   'would',
#   'want',
#   'contaminate',
#   'other',
#   'nations',
#   '.#',
#   'covidvaccine'],
#  ['pope',
#   'francis',
#   'calls',
#   'opposition',
#   'covid',
#   'vaccine',
#   '‘',
#   'suicidal',
#   'denial',
#   '’',
#   'says',
#   'he',
#   '’',
#   'll',
#   'get',
#   'jab'],
#  ['nepal',
#   'fm',
#   "'",
#   's',
#   'india',
#   'visit',
#   ':',
#   'key',
#   'focus',
#   'covid',
#   'vaccine',
#   'procurement',
#   '.'],
#  ['covid',
#   '-',
#   '19',
#   ':',
#   'brazil',
#   'president',
#   'bolsonaro',
#   'urges',
#   'pm',
#   'narendra',
#   'modi',
#   '2',
#   'million',
#   'covishield',
#   'vaccine',
#   'doses',
#   'urgently'],
#  ['west',
#   'bengal',
#   'cm',
#   'mamata',
#   'banerjee',
#   'promises',
#   'free',
#   'covid',
#   'vaccine',
#   ',',
#   'opposition',
#   'calls',
#   'it',
#   'poll',
#   'sop'],
#  ['grateful',
#   '#',
#   'mamatabanerjee',
#   'who',
#   'promised',
#   'provide',
#   'free',
#   'covid',
#   'vaccine',
#   'everyone',
#   'bengal',
#   'by',
#   'selling',
#   'her',
#   'paintings',
#   'poetry',
#   '.',
#   'rolling_on_the_floor_laughingrolling_on_the_floor_laughing'],
#  ['at',
#   'present',
#   'there',
#   'is',
#   'no',
#   'application',
#   'available',
#   'registration',
#   'getting',
#   'vaccine',
#   'covid',
#   '19',
#   ',',
#   'available',
#   'app',
#   'play',
#   'store',
#   'are',
#   'all',
#   'fake',
#   ',',
#   'do',
#   'not',
#   'reveal',
#   'ur',
#   'info',
#   'them',
#   ',',
#   'when',
#   'app',
#   'is',
#   'ready',
#   'govt',
#   'will',
#   'advertise',
#   'it'],
#  ['delhi',
#   '’',
#   's',
#   'blu',
#   'print',
#   'introduce',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'immunize',
#   'people',
#   '...'],
#  ['india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   ':',
#   'pm',
#   'modi',
#   'via',
#   'namo',
#   'app'],
#  ['last',
#   'night',
#   "'",
#   's',
#   'weird',
#   'dream',
#   ':',
#   'about',
#   'getting',
#   'vaccine',
#   'covid',
#   'that',
#   'i',
#   'bought',
#   'street',
#   'food',
#   'vendor',
#   ',',
#   'had',
#   'administer',
#   'it',
#   'myself',
#   'right',
#   'there',
#   '.'],
#  ['another', 'india', '#', 'covidvaccine', 'success', 'story'],
#  ['promoting', 'confidence', 'covid', '-', '19', 'vaccines'],
#  ['since',
#   'modi',
#   'govt',
#   'has',
#   'approved',
#   'bharat',
#   'biotech',
#   'vaccine',
#   'without',
#   'results',
#   '3rd',
#   'phase',
#   'trial',
#   ',',
#   'modi',
#   'should',
#   'be',
#   'first',
#   'get',
#   'vaccinated',
#   'instilll',
#   'confidence',
#   'nation',
#   '#',
#   'bharatbiotech',
#   '#',
#   'indiafightscorona',
#   '#',
#   'covidvaccine',
#   '#',
#   'idiotpmmodi'],
#  ['there',
#   'should',
#   'be',
#   'no',
#   'politics',
#   'covid',
#   '19',
#   'vaccine',
#   '.',
#   'it',
#   'should',
#   'provide',
#   'at',
#   'affordable',
#   'cost',
#   '.'],
#  ['i',
#   'doubt',
#   ',',
#   'covid',
#   'warriors',
#   'are',
#   'being',
#   'targeted',
#   'as',
#   'guinea',
#   'pig',
#   '/',
#   'rats',
#   'by',
#   'corona',
#   'vaccine',
#   'companies',
#   '.',
#   'stop',
#   'humiliating',
#   'humanity',
#   '.',
#   '#',
#   'coronavirusvaccine'],
#  ['they',
#   'spent',
#   '12',
#   'years',
#   'solving',
#   'puzzle',
#   '.',
#   'it',
#   'yielded',
#   'first',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   '.',
#   'via'],
#  ['mamata',
#   'ji',
#   'announced',
#   'free',
#   'vaccine',
#   'west',
#   'bengal',
#   'heart_suit',
#   'but',
#   'during',
#   'lock',
#   'down',
#   'see',
#   'was',
#   'blaming',
#   'that',
#   'covid19',
#   '/',
#   'lock',
#   'down',
#   'is',
#   'strategy',
#   'make',
#   'fool',
#   'india',
#   'people',
#   ',',
#   'friends',
#   'just',
#   'think',
#   ',',
#   'free',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'is',
#   'just',
#   'lollipop',
#   '.',
#   '#',
#   'namo',
#   '#',
#   'narendramodi',
#   '#',
#   'amitshah',
#   '#',
#   'mamatabanerjee',
#   '#',
#   'aajtak'],
#  ['india',
#   'under',
#   'takes',
#   'lead',
#   'introducing',
#   'vaccines',
#   'counter',
#   'covid',
#   '-',
#   '19',
#   'virus',
#   '.',
#   'even',
#   'prior',
#   'vaccine',
#   'india',
#   'has',
#   'gotten',
#   'number',
#   'cases',
#   'dramatically',
#   'reduce',
#   'as',
#   'these',
#   'rapidly',
#   'increase',
#   'europe',
#   'america',
#   '.',
#   '#',
#   'म',
#   'े',
#   'र',
#   'ा',
#   '_प',
#   'ी',
#   'एम_म',
#   'े',
#   'र',
#   'ा',
#   '_अभ',
#   'ि',
#   'म',
#   'ा',
#   'न'],
#  ['great',
#   'news',
#   'people',
#   'bengal',
#   '.',
#   'mamata',
#   'has',
#   'promised',
#   'free',
#   'covid',
#   'vaccine',
#   'everyone',
#   'bengal',
#   '.',
#   'she',
#   'plans',
#   'sell',
#   'all',
#   'her',
#   'properties',
#   'harish',
#   'chatterjee',
#   'road',
#   'get',
#   'money',
#   '.'],
#  ['enjoyed',
#   'this',
#   'quick',
#   'video',
#   'debunking',
#   'conspiracies',
#   'surrounding',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'interviewers',
#   ':',
#   'try',
#   'guys',
#   '7',
#   '.',
#   '5m',
#   'subs',
#   'youtube',
#   'interviewee',
#   ':',
#   'dr',
#   'anthony',
#   'fauci',
#   '.',
#   'never',
#   'seen',
#   'him',
#   'have',
#   'more',
#   'fun',
#   'interview'],
#  ['Alhamdulillah',
#   'today',
#   'I',
#   'took',
#   'corona',
#   'vaccine',
#   'thanks',
#   'dubai',
#   'uae',
#   'health',
#   'authorities',
#   'uae',
#   'have',
#   'vaccinated',
#   'over',
#   'million',
#   'residents',
#   'against',
#   'covid',
#   '-',
#   '19',
#   '.',
#   '10',
#   '.',
#   '01',
#   '.',
#   '2021'],
#  ['has',
#   'india',
#   'India',
#   'made',
#   'vaccine',
#   'syringe',
#   'passed',
#   'all',
#   'tests',
#   'secure',
#   'people',
#   'against',
#   'covid',
#   '-',
#   '19',
#   'or',
#   'is',
#   'it',
#   'another',
#   'political',
#   'gimmick',
#   'lure',
#   'voters',
#   'or',
#   'fool',
#   'people',
#   'remember',
#   'this',
#   'issue',
#   'is',
#   'very',
#   'serious',
#   'government',
#   'must',
#   'ensure',
#   'safety',
#   'security',
#   'india',
#   'India',
#   'citizens',
#   'no',
#   'trials'],
#  ['covid', 'vaccine', 'facts', 'vs', 'fiction'],
#  ['got',
#   'himself',
#   'vaccinated',
#   'prove',
#   'his',
#   'covid',
#   'vaccine',
#   'is',
#   'absolutely',
#   'safe',
#   '.',
#   'must',
#   'do',
#   'same',
#   '.',
#   'if',
#   'he',
#   'shies',
#   'away',
#   'his',
#   'personal',
#   'participation',
#   ',',
#   'nation',
#   'must',
#   'question',
#   'his',
#   'leadership',
#   '.'],
#  ['Have',
#   'heard',
#   'that',
#   '#',
#   'covidvaccine',
#   'is',
#   'coming',
#   'on',
#   '16th',
#   'January',
#   ',',
#   'who',
#   'is',
#   'getting',
#   'it',
#   'installled',
#   '?'],
#  ['#',
#   'chinese',
#   'doctor',
#   'claims',
#   'that',
#   'sinopharm',
#   'vaccine',
#   'is',
#   'more',
#   'lethal',
#   'than',
#   'covid',
#   'itself',
#   'with',
#   '73',
#   'side',
#   'effects',
#   'posted',
#   'sarcastically',
#   'or',
#   'truth',
#   'chinese',
#   'nevar',
#   'fails',
#   'amaze',
#   'surprise',
#   'us',
#   'flushed_faceface_with_tears_of_joy'],
#  ['it',
#   'is',
#   'astonishing',
#   'see',
#   'west',
#   'bengal',
#   'nearly',
#   '10',
#   'crore',
#   'population',
#   'will',
#   'get',
#   'health',
#   'cover',
#   'free',
#   'cost',
#   'now',
#   'covid',
#   'vaccine',
#   ',',
#   'all',
#   'being',
#   'offered',
#   'with',
#   'elections',
#   'round',
#   'corner',
#   'but',
#   'my',
#   'concern',
#   'is',
#   'how',
#   'will',
#   'government',
#   'foot',
#   'bill',
#   'with',
#   'already',
#   '4',
#   '.',
#   '5',
#   'lakh',
#   'crore',
#   'loan',
#   'our',
#   'head'],
#  ['#',
#   'covid19',
#   '#',
#   'covidvaccine',
#   '#',
#   'vaccinestrategy',
#   '#',
#   'vaccinesideeffects'],
#  ['what',
#   'extraordinary',
#   'start',
#   '2021',
#   'wishing',
#   'all',
#   'our',
#   'friends',
#   'followers',
#   'happy',
#   'safe',
#   'new',
#   'year',
#   '.',
#   '#',
#   'theperioclinic',
#   '#',
#   'gums',
#   '#',
#   'implants',
#   '#',
#   'dental',
#   '#',
#   'periodontology',
#   '#',
#   'periodontist',
#   '#',
#   'dentist',
#   '#',
#   'dubaidentist',
#   '#',
#   'dhcc',
#   '#',
#   'dubai',
#   '#',
#   'mydubai',
#   '#',
#   'dubailife',
#   '#',
#   'dxb',
#   '#',
#   'covid19',
#   '#',
#   'coronavirus',
#   '#',
#   'covidvaccine',
#   '#',
#   'vaccine'],
#  ['humanity',
#   'inventing',
#   'vaccine',
#   'deal',
#   'with',
#   'covid',
#   '19',
#   '.',
#   'covid',
#   '19',
#   ':'],
#  ['there',
#   'was',
#   'no',
#   'hurry',
#   'do',
#   'this',
#   'trial',
#   'at',
#   'such',
#   'breakneck',
#   'pace',
#   '.',
#   'usually',
#   'vaccine',
#   'trials',
#   'take',
#   'year',
#   'recruit',
#   '.',
#   'who',
#   'will',
#   'blame',
#   'cheerleaders',
#   'now',
#   '.',
#   'covid',
#   'vaccine',
#   'is',
#   'not',
#   'magic',
#   'wand',
#   'which',
#   'can',
#   'hum',
#   'up',
#   'our',
#   'economy',
#   'few',
#   'months',
#   '.'],
#  ['free',
#   '#',
#   'covidvaccine',
#   'everyone',
#   'bengal',
#   'announces',
#   'cm',
#   'mamata',
#   'banerjee',
#   '....',
#   'wonder',
#   'what',
#   'those',
#   'who',
#   'criticized',
#   'parties',
#   'during',
#   'bihar',
#   'polls',
#   'now',
#   'have',
#   'say',
#   '...',
#   '#',
#   'vaccinepolitics'],
#  ['before',
#   'covid',
#   'vaccine',
#   'roll',
#   'out',
#   '16th',
#   'jan',
#   ',',
#   'union',
#   'health',
#   'ministry',
#   'holds',
#   'important',
#   'meeting',
#   'with',
#   'all',
#   'state',
#   '/',
#   'uts',
#   'administrators',
#   'review',
#   'examine',
#   'co',
#   '-',
#   'win',
#   'cowin',
#   'is',
#   'digital',
#   'platform',
#   'monitor',
#   '&',
#   'amp',
#   ';',
#   'share',
#   'covid',
#   'vaccine',
#   '.',
#   'my',
#   'report',
#   '#',
#   'indiafightscorona',
#   '#',
#   'vaccine',
#   '#',
#   'cowin'],
#  ['The',
#   'word',
#   '#',
#   'India',
#   'India',
#   'written',
#   'on',
#   'this',
#   'bottle',
#   'of',
#   'Corona',
#   'vaccine',
#   'is',
#   'enough',
#   'for',
#   'me',
#   'to',
#   'be',
#   'proud',
#   '.',
#   'I',
#   'have',
#   'faith',
#   'in',
#   'my',
#   'country',
#   "'",
#   's',
#   'scientists',
#   'on',
#   'my',
#   'country',
#   "'",
#   's',
#   'capabilities',
#   '#',
#   'Jai_Hind',
#   '#',
#   'Vande',
#   'Mataram',
#   '#',
#   'bharatbiotech',
#   '#',
#   'covidvaccine',
#   'syringeambulance',
#   '#',
#   'india',
#   '#',
#   'sundaymotivation'],
#  ['i',
#   'was',
#   'among',
#   'more',
#   'than',
#   '70',
#   ',',
#   '000',
#   'uae',
#   'citizens',
#   'residents',
#   'receive',
#   'their',
#   'first',
#   'dose',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'yesterday',
#   ',',
#   'with',
#   'well',
#   'over',
#   '10',
#   '%',
#   'population',
#   'already',
#   'vaccinated',
#   '.',
#   'it',
#   '’',
#   's',
#   'well',
#   '-',
#   'run',
#   'roll',
#   '-',
#   'out',
#   'my',
#   'perspective',
#   'well',
#   'it',
#   'is',
#   'way',
#   'achieving',
#   '50',
#   '%',
#   'vaccinated',
#   'q1',
#   '.'],
#  ['done',
#   'with',
#   'first',
#   'dose',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'check_mark_button'],
#  ['Is', 'the', 'covid', 'vaccine', 'safe', '?'],
#  ['so',
#   'nigerian',
#   'govt',
#   'can',
#   'meet',
#   'world',
#   'health',
#   'organization',
#   'meet',
#   'there',
#   'needs',
#   'get',
#   'covid',
#   '19',
#   'vaccine',
#   'i',
#   'don',
#   '’',
#   't',
#   'blame',
#   'you',
#   'nigerian',
#   'govt',
#   '.',
#   'world',
#   'did',
#   'not',
#   'recognized',
#   'you',
#   'nigerian',
#   'govt',
#   '..',
#   'you',
#   'all',
#   'are',
#   'disgrace',
#   'africa',
#   '..',
#   'thieves',
#   'that',
#   'is',
#   'what',
#   'you',
#   'all',
#   'are',
#   '.',
#   'awon',
#   'oloshi',
#   'ijoba'],
#  ['Good',
#   'evening',
#   'everyone',
#   'from',
#   'Al',
#   'Bateen',
#   'Council',
#   'in',
#   'Abu',
#   'Dhabi',
#   'United_Arab_Emirates',
#   'al',
#   'batten',
#   'majlis',
#   ',',
#   'taking',
#   'first',
#   'shot',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'syringe'],
#  ['i',
#   '’',
#   'll',
#   'be',
#   'taking',
#   'test',
#   'as',
#   'i',
#   '’',
#   've',
#   'done',
#   'every',
#   'time',
#   'still',
#   'isolating',
#   '2',
#   'weeks',
#   'when',
#   'i',
#   'get',
#   'back',
#   'uk',
#   'end',
#   'month',
#   'dubai',
#   '.',
#   'i',
#   '’',
#   've',
#   'even',
#   'had',
#   'my',
#   'covid',
#   'vaccine',
#   '.',
#   'i',
#   '’',
#   'm',
#   'at',
#   'greater',
#   'risk',
#   'catching',
#   'it',
#   'uk',
#   'then',
#   'you',
#   'are',
#   'me',
#   'bringing',
#   'it',
#   'in',
#   '.'],
#  ['Myanmar_',
#   '(',
#   'Burma',
#   ')',
#   'myanmar',
#   'has',
#   'ordered',
#   '30',
#   'million',
#   'doses',
#   '#',
#   'covidvaccine',
#   'india',
#   'India'],
#  ['nigerian',
#   'govt',
#   'is',
#   'failure',
#   '...',
#   'we',
#   'have',
#   'vaccine',
#   'covid',
#   '19',
#   'united',
#   'arab',
#   'emirate',
#   ',',
#   'mostly',
#   'everybody',
#   'has',
#   'been',
#   'vaccinated',
#   '...',
#   'you',
#   'people',
#   'govt',
#   'only',
#   'know',
#   'how',
#   'lie',
#   'citizens',
#   ',',
#   'embezzling',
#   'our',
#   'money',
#   'thousands',
#   'nigerian',
#   'are',
#   'dying',
#   'day',
#   'by',
#   'day',
#   'becos',
#   'you',
#   'bad',
#   'leaders'],
#  ['new',
#   'covid',
#   'strain',
#   'south',
#   'african',
#   'one',
#   'potentially',
#   'resisting',
#   'vaccine',
#   'whewwww',
#   'chileeee',
#   'anxiety'],
#  ['Trust',
#   'me',
#   'Mamata',
#   'Sarkar',
#   'is',
#   'by',
#   'your',
#   'side',
#   'green_heartgreen_heartgreen_heart',
#   'smiling_face_with_smiling_eyes',
#   '#',
#   'mamatabanerjee',
#   '#',
#   'covid_vaccine'],
#  ['india',
#   '”',
#   's',
#   'covid',
#   'recovery',
#   'rate',
#   '96',
#   '.',
#   '36',
#   '%',
#   'is',
#   'amongst',
#   'highest',
#   'world',
#   '.',
#   'we',
#   'did',
#   'ok',
#   'despite',
#   'our',
#   'huge',
#   'population',
#   'other',
#   'challenges',
#   '...',
#   'makes',
#   'one',
#   'hopeful',
#   'about',
#   'it',
#   'is',
#   'vaccine',
#   'coverage',
#   'too',
#   'this',
#   'year'],
#  ['jaiho',
#   'modi',
#   'g',
#   'india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   ':',
#   'pm',
#   'modi',
#   'via',
#   'namo',
#   'app'],
#  ['In',
#   'Delhi',
#   ',',
#   '89',
#   'hospitals',
#   'have',
#   'been',
#   'identified',
#   'for',
#   'Phase',
#   'I',
#   'vaccination',
#   ',',
#   'red_triangle_pointed_up',
#   ',',
#   'of',
#   'which',
#   '36',
#   'are',
#   'government',
#   'and',
#   '53',
#   'private',
#   'hospitals',
#   '.',
#   'red_triangle_pointed_up',
#   'In',
#   'the',
#   'first',
#   'phase',
#   ',',
#   'the',
#   'vaccine',
#   'will',
#   'be',
#   'given',
#   'to',
#   'healthcare',
#   'workers',
#   '.',
#   'red_triangle_pointed_up12',
#   '-',
#   '13',
#   'By',
#   'January',
#   'the',
#   'vaccine',
#   'will',
#   'come',
#   ',',
#   'we',
#   'have',
#   'enough',
#   'storage',
#   '.',
#   '#',
#   'covidvaccine'],
#  ['myanmar',
#   'has',
#   'ordered',
#   '30',
#   'million',
#   'covid',
#   'vaccine',
#   'india',
#   ',',
#   'country',
#   "'",
#   's',
#   'president',
#   'office',
#   'has',
#   'announced'],
#  ['india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   ':',
#   'pm',
#   'modi',
#   'ji',
#   'via',
#   'namo',
#   'app'],
#  ['was',
#   'not',
#   'there',
#   'clear',
#   'indication',
#   'that',
#   'vaccine',
#   'was',
#   'not',
#   'complete',
#   'protection',
#   ',',
#   'but',
#   'just',
#   'ensured',
#   'lighter',
#   'case',
#   'covid'],
#  ['In',
#   'Delhi',
#   ',',
#   '89',
#   'hospitals',
#   'have',
#   'been',
#   'identified',
#   'for',
#   'the',
#   'first',
#   'phase',
#   'of',
#   'vaccination',
#   ',',
#   'red_triangle_pointed_up',
#   ',',
#   'of',
#   'which',
#   '36',
#   'are',
#   'government',
#   'and',
#   '53',
#   'private',
#   'hospitals',
#   '.',
#   'red_triangle_pointed_up',
#   'In',
#   'the',
#   'first',
#   'phase',
#   ',',
#   'the',
#   'vaccine',
#   'will',
#   'be',
#   'given',
#   'to',
#   'healthcare',
#   'workers',
#   '.',
#   'red_triangle_pointed_up12',
#   '-',
#   '13',
#   'By',
#   'January',
#   'the',
#   'vaccine',
#   'will',
#   'come',
#   ',',
#   'we',
#   'have',
#   'enough',
#   'storage',
#   '.',
#   '#',
#   'covidvaccine'],
#  ['dr',
#   'saheer',
#   'sainalabdeen',
#   ',',
#   'specialist',
#   'respiratory',
#   'medicine',
#   ':',
#   '“',
#   'during',
#   'trials',
#   'currently',
#   'available',
#   'vaccines',
#   ',',
#   'tracking',
#   'has',
#   'been',
#   'done',
#   'pertaining',
#   'how',
#   'many',
#   'vaccinated',
#   'people',
#   'contract',
#   'covid',
#   '-',
#   '19',
#   'despite',
#   'inoculation',
#   '."'],
#  ['letter',
#   'frontline',
#   'workers',
#   ',',
#   'west',
#   'bengal',
#   'chief',
#   'minister',
#   'mamata',
#   'banerjee',
#   'says',
#   'that',
#   'her',
#   'govt',
#   'will',
#   'ensure',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'reaches',
#   'free',
#   'cost',
#   'everyone',
#   'state',
#   '.',
#   '“',
#   'i',
#   '’',
#   'm',
#   'happy',
#   'share',
#   'that',
#   'our',
#   'govt',
#   'will',
#   'ensure',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'reaches',
#   'everyone',
#   'state',
#   'free',
#   'cost',
#   '.”'],
#  ['just', 'took', 'first', 'dose', 'covid', '-', '19', 'vaccine', '..'],
#  ['india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   ':',
#   'pm',
#   'via',
#   'namo',
#   'app'],
#  ['covid',
#   'number',
#   ':',
#   '19',
#   'date',
#   ':',
#   '16',
#   'year',
#   ':',
#   '21',
#   'total',
#   'ho',
#   'gaya',
#   ':',
#   '56',
#   'vaccine',
#   'launch',
#   'drive',
#   '-',
#   'grahan',
#   'ka',
#   'khatra',
#   'number',
#   'mata',
#   'rani',
#   'kripa',
#   'karna',
#   '#',
#   'vaccinestrategy'],
#  ['It',
#   'is',
#   'a',
#   'matter',
#   'of',
#   'great',
#   'happiness',
#   'that',
#   'the',
#   'vaccine',
#   'of',
#   'covid_19',
#   'has',
#   'been',
#   'made',
#   ',',
#   'but',
#   'even',
#   'more',
#   'happiness',
#   'will',
#   'be',
#   'there',
#   'when',
#   'Indian',
#   'scientists',
#   'will',
#   'be',
#   'able',
#   'to',
#   'find',
#   'a',
#   'very',
#   'excellent',
#   'treatment',
#   'for',
#   '#',
#   'cancer',
#   ',',
#   'for',
#   'this',
#   'the',
#   'Government',
#   'of',
#   'India',
#   'should',
#   'think',
#   'deeply',
#   '.',
#   'g',
#   'folded_hands'],
#  ['#',
#   'Delhi',
#   'Prime',
#   'Minister',
#   'Narendra',
#   'Modi',
#   'can',
#   'hold',
#   'a',
#   'big',
#   'meeting',
#   'on',
#   'Monday',
#   'with',
#   'the',
#   'Chief',
#   'Ministers',
# ...
#   'covid',
#   '#',
#   'vaccine',
#   '#',
#   'vaccinatiestrategie'],
#  ['subject',
#   'expert',
#   'committee',
#   'cdsco',
#   'meet',
#   'shortly',
#   'consider',
#   'application',
#   'serum',
#   'institute',
#   'covid',
#   'vaccine',
#   '.',
#   'meeting',
#   'scheduled',
#   'minutes',
#   'after',
#   'uk',
#   'regulator',
#   'approved',
#   'vaccine',
#   '.',
#   '“',
#   'only',
#   'sii',
#   '’',
#   's',
#   'application',
#   'agenda',
#   '”',
#   'sources'],
#  ['britain',
#   'approves',
#   'astrazeneca',
#   '-',
#   'oxford',
#   'covid',
#   '-',
#   '19',
#   'vaccine'],
#  ['"',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'covid',
#   '-',
#   '19',
#   '#',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '"'],
#  ['"',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '"'],
#  ['kab',
#   'milega',
#   'yeh',
#   'vaccine',
#   'yahan',
#   '"',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '"'],
#  ['good',
#   'news',
#   ',',
#   'now',
#   'our',
#   'government',
#   'can',
#   'accelerate',
#   'roll',
#   'out',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '#',
#   'covidindia',
#   '#',
#   'covid19',
#   '#',
#   'coviduk'],
#  ['check',
#   'this',
#   'out',
#   'times',
#   'india',
#   'live',
#   ':',
#   'astrazeneca',
#   '-',
#   'oxford',
#   'covid',
#   'vaccine',
#   'approved',
#   'use',
#   'uk',
#   'download',
#   'toi',
#   'app',
#   'now',
#   ':',
#   'aab',
#   'approve',
#   'karo',
#   '...',
#   'daro',
#   'maat',
#   '...',
#   'aaji',
#   'kardo',
#   'approve',
#   '..'],
#  ['covid',
#   '-',
#   '19',
#   ':',
#   '#',
#   'oxford',
#   '-',
#   'astrazeneca',
#   'coronavirus',
#   'vaccine',
#   'approved',
#   'use',
#   '#',
#   'uk',
#   '.',
#   'serum',
#   'institute',
#   'india',
#   'has',
#   'already',
#   'produced',
#   '40',
#   '-',
#   '50',
#   'million',
#   'doses',
#   'this',
#   'vaccine',
#   'may',
#   'be',
#   '#',
#   'india',
#   'can',
#   'also',
#   'approve',
#   'it',
#   'soon',
#   '.'],
#  ['uk',
#   'regulator',
#   'approves',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'covid',
#   '-',
#   '19',
#   'vaccine'],
#  ['it', '’', 's', 'test', '/', 'trial', 'covid', '19', 'vaccine', '.'],
#  ['#',
#   'breaking',
#   'uk',
#   'approves',
#   'oxford',
#   '-',
#   'astra',
#   'zeneca',
#   'vaccine',
#   '#',
#   'covidvaccine',
#   '#',
#   'oxfordvaccine'],
#  ['astrazeneca',
#   '’',
#   's',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'has',
#   'been',
#   'approved',
#   'emergency',
#   'supply',
#   'uk'],
#  ['who',
#   'say',
#   '2020',
#   'was',
#   'tuff',
#   'i',
#   'mean',
#   'many',
#   'people',
#   'lost',
#   'there',
#   'loved',
#   'ones',
#   'most',
#   ',',
#   'doctors',
#   'they',
#   'served',
#   'much',
#   'far',
#   'than',
#   'any',
#   'ordinary',
#   'person',
#   'i',
#   'mean',
#   'they',
#   'had',
#   'more',
#   'pain',
#   'than',
#   'us',
#   'may',
#   'this',
#   'year',
#   'be',
#   'year',
#   'cureslightly_smiling_face',
#   '#',
#   'happynewyear',
#   '#',
#   'happynewyear2021',
#   '#',
#   'coronavirus',
#   '#',
#   'covidvaccine',
#   '#',
#   'newyear2021'],
#  ['huge', 'moment', '#', 'covid', '#', 'vaccine'],
#  ['big',
#   'boost',
#   '.',
#   'uk',
#   'clears',
#   'oxford',
#   'astrazeneca',
#   'covid',
#   'vaccine',
#   '.',
#   'regulatory',
#   'approval',
#   'india',
#   'can',
#   'be',
#   'next',
#   'step',
#   '.',
#   '#',
#   'coronavirus',
#   '#',
#   'coronavirusupdates',
#   '#',
#   'coronavirusstrain'],
#  ['oxford',
#   '-',
#   'astra',
#   'zeneca',
#   'get',
#   'uk',
#   'regulator',
#   '’',
#   's',
#   'approval',
#   '#',
#   'covidvaccine'],
#  ['good',
#   'news',
#   'bbc',
#   'news',
#   '-',
#   'covid',
#   '-',
#   '19',
#   ':',
#   'oxford',
#   '-',
#   'astrazeneca',
#   'coronavirus',
#   'vaccine',
#   'approved',
#   'use',
#   'uk'],
#  ['great',
#   'news',
#   'hope',
#   'this',
#   'can',
#   'be',
#   'rolled',
#   'out',
#   'developing',
#   'countries',
#   'asap',
#   '|',
#   'covid',
#   '-',
#   '19',
#   ':',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'vaccine',
#   'approved',
#   'use',
#   'uk'],
#  ['as',
#   'covid',
#   'vaccine',
#   'has',
#   'started',
#   'rolling',
#   'out',
#   'cross',
#   'countries',
#   ',',
#   '#',
#   'tilwiththeprint',
#   'revathi',
#   'krishnan',
#   'explains',
#   'what',
#   "'",
#   'vaccine',
#   'passport',
#   "'",
#   'is',
#   ',',
#   'why',
#   'one',
#   'might',
#   'need',
#   'it',
#   'travel',
#   '.'],
#  ['volunteered',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'trial',
#   'today',
#   '.',
#   'inshaallah',
#   'if',
#   'all',
#   'goes',
#   'well',
#   'trial',
#   'results',
#   'are',
#   'positive',
#   'we',
#   'can',
#   'make',
#   'pakistan',
#   'safe',
#   '.',
#   'palms_up_togethermedium',
#   '-',
#   'light_skin_tonepalms_up_togethermedium',
#   '-',
#   'light_skin_tonepalms_up_togethermedium',
#   '-',
#   'light_skin_tone'],
#  ['let',
#   'me',
#   'remind',
#   'you',
#   'all',
#   '.',
#   'if',
#   'you',
#   '’',
#   're',
#   'planning',
#   'get',
#   'covid',
#   'vaccine',
#   ',',
#   'syringe',
#   'make',
#   'sure',
#   'you',
#   'have',
#   'enough',
#   'sleep',
#   ',',
#   'rest',
#   '&',
#   'amp',
#   ';',
#   'no',
#   'history',
#   'allergy',
#   '.'],
#  ['I', 'am', 'tired', 'of', 'waiting', '#', 'covidvaccine'],
#  ['#',
#   'india',
#   'is',
#   '#',
#   'covid19',
#   'status',
#   '.',
#   '#',
#   'breaking',
#   '#',
#   'healthy',
#   '#',
#   'covidiot',
#   '#',
#   'covidindia',
#   '#',
#   'mastercheftuerkiye',
#   '#',
#   'maskup',
#   '#',
#   'socialdistancing',
#   '#',
#   'covidvaccine',
#   '#',
#   'uklockdown',
#   '#',
#   'coronaupdatesinindia',
#   '#',
#   'america',
#   '#',
#   'dhoni',
#   '#',
#   'vday',
#   '#',
#   'trending',
#   '#',
#   'coronanewstrain'],
#  ['china',
#   ',',
#   'india',
#   'both',
#   'front',
#   'pages',
#   'nepali',
#   'daily',
#   '.',
#   'india',
#   'covid',
#   'vaccine',
#   'procurement',
#   ',',
#   'china',
#   'it',
#   'is',
#   'vice',
#   'minister',
#   "'",
#   's',
#   '"',
#   'whirlwind',
#   'tour',
#   '"',
#   'over',
#   'political',
#   'crisis',
#   '.'],
#  ['iran',
#   "'",
#   's',
#   'purpose',
#   'doing',
#   'it',
#   'is',
#   'own',
#   '#',
#   'covid',
#   'vaccine',
#   'is',
#   'solely',
#   'set',
#   'humanity',
#   'serving',
#   'precedent',
#   'worth',
#   'mentioning',
#   'that',
#   'we',
#   'are',
#   'not',
#   'trifling',
#   'with',
#   'people',
#   'lives',
#   '.',
#   'any',
#   'new',
#   '#',
#   'sanctions',
#   'flourish',
#   'new',
#   'field',
#   'science',
#   '#',
#   'iran',
#   '.'],
#  ['you',
#   'can',
#   '’',
#   't',
#   'let',
#   'your',
#   'guard',
#   'down',
#   'again',
#   'covid',
#   'at',
#   'all',
#   ',',
#   'it',
#   '’',
#   's',
#   'pretty',
#   'evident',
#   'that',
#   'before',
#   'everybody',
#   'gets',
#   'vaccine',
#   'life',
#   'cannot',
#   'should',
#   'not',
#   'get',
#   'normalcy',
#   'unless',
#   'there',
#   '’',
#   's',
#   'strain',
#   'that',
#   'all',
#   'tha',
#   'vaccines',
#   'are',
#   'unsuccessful',
#   'against',
#   'it',
#   '#',
#   'stayhome',
#   '#',
#   'staysafe',
#   '#',
#   'covid19uk'],
#  ['2',
#   '.',
#   '1',
#   'million',
#   'covid',
#   'vaccine',
#   'doses',
#   'given',
#   'u',
#   '.',
#   's',
#   '.',
#   'sent',
#   'using',
#   'medscape',
#   'app',
#   'androidtrade_mark'],
#  ['#', 'kamalaharris', '#', 'us', '#', 'joebiden', '#', 'covidvaccine'],
#  ['#',
#   'mydubai',
#   'receives',
#   'first',
#   'batch',
#   'pfizer',
#   '-',
#   'biontech',
#   "'",
#   's',
#   'covid',
#   '-',
#   '19',
#   'vaccines',
#   'via'],
#  ['wth',
#   'arrival',
#   'f',
#   'new',
#   'uk',
#   'strain',
#   'covid',
#   'india',
#   ',',
#   'rwe',
#   'prepared',
#   'fr',
#   'this',
#   '70',
#   '%',
#   'more',
#   'contagious',
#   'variant',
#   'covid',
#   'we',
#   '’',
#   're',
#   'told',
#   'existing',
#   'vaccines',
#   'wl',
#   'work',
#   'this',
#   'new',
#   'variant',
#   ',',
#   'but',
#   'what',
#   '’',
#   's',
#   '=',
#   'lly',
#   'clear',
#   '’',
#   's',
#   'that',
#   'battle',
#   'is',
#   'far',
#   'frm',
#   'over',
#   '.',
#   'we',
#   'must',
#   'hence',
#   ',',
#   'strictly',
#   'follow',
#   'prevention',
#   'protocols',
#   '.'],
#  ['union',
#   'minister',
#   'ramdas',
#   'athawale',
#   ',',
#   'whose',
#   '"',
#   'go',
#   'corona',
#   ',',
#   'go',
#   '"',
#   'chant',
#   'became',
#   'national',
#   'sensation',
#   ',',
#   'sunday',
#   'came',
#   'out',
#   'with',
#   'new',
#   'slogan',
#   ',',
#   "''",
#   'no',
#   'corona',
#   "'',",
#   'saying',
#   'it',
#   'was',
#   'response',
#   'new',
#   'strain',
#   'novel',
#   'coronavirus',
#   '.',
#   '#',
#   'coronavirus',
#   '#',
#   'covid19',
#   '#',
#   'covidvaccine',
#   '#',
#   'vaccine',
#   '#',
#   'vaccination',
#   '#',
#   'bjp'],
#  ['Now',
#   'another',
#   'new',
#   'tension',
#   'has',
#   'started',
#   'for',
#   'all',
#   'those',
#   'who',
#   'came',
#   'to',
#   '#',
#   'corona',
#   '.',
#   'It',
#   'has',
#   'come',
#   'to',
#   'be',
#   'known',
#   'as',
#   'the',
#   '#',
#   'chineese',
#   'virus',
#   'or',
#   'the',
#   '#',
#   'english',
#   'virus',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'covid',
#   '#',
#   'covidvaccine'],
#  ['first',
#   'covid',
#   'vaccine',
#   'does',
#   'blue_heart',
#   'Saudi',
#   'Arabia',
#   'From',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'crisis',
#   ',',
#   'it',
#   'was',
#   'and',
#   'still',
#   'is',
#   'the',
#   'best',
#   '.'],
#  ['we',
#   '’',
#   're',
#   'not',
#   'going',
#   'get',
#   'rid',
#   'covid',
#   ',',
#   'no',
#   'clinician',
#   'i',
#   '’',
#   'm',
#   'aware',
#   'even',
#   'suggests',
#   'possibility',
#   'this',
#   '.',
#   'all',
#   'we',
#   '’',
#   're',
#   'trying',
#   'do',
#   'is',
#   'control',
#   'it',
#   'by',
#   'limiting',
#   'it',
#   'is',
#   'spread',
#   ',',
#   'one',
#   'most',
#   'effective',
#   'way',
#   'achieving',
#   'this',
#   'is',
#   'through',
#   'vaccines',
#   '.',
#   'this',
#   'isn',
#   '’',
#   't',
#   'going',
#   'disappear',
#   'anytime',
#   'soon',
#   '.'],
#  ['lots',
#   'negativity',
#   'surrounding',
#   'arcturus',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'data',
#   '.',
#   'low',
#   'neutralizing',
#   'titers',
#   'may',
#   'look',
#   'disappointing',
#   'but',
#   'response',
#   'cd4',
#   'cd8',
#   't',
#   'cells',
#   'are',
#   'very',
#   'good',
#   'could',
#   'prevent',
#   'covid',
#   '-',
#   '19',
#   'infection',
#   '.',
#   'immunity',
#   'is',
#   'more',
#   'than',
#   'just',
#   'antibodies',
#   '.'],
#  ['We',
#   'trust',
#   'in',
#   'God',
#   'blue_heart',
#   '@',
#   'Corona',
#   '-',
#   'covid',
#   '-',
#   '19',
#   'Vaccine',
#   'Center',
#   'Riyadh'],
#  ['all',
#   'vaccinated',
#   'people',
#   'against',
#   'covid',
#   '-',
#   '19',
#   'will',
#   'still',
#   'need',
#   '14',
#   'day',
#   'quarantine',
#   'until',
#   'more',
#   'study',
#   'is',
#   'done',
#   'vaccines',
#   'effects',
#   'stopping',
#   'infection',
#   'spread',
#   'says',
#   'thai',
#   'ministry',
#   'public',
#   'health',
#   '.'],
#  ['got',
#   'health',
#   'card',
#   'number',
#   'now',
#   '"',
#   'book',
#   'covid',
#   '19',
#   'vaccine',
#   '"',
#   'button',
#   'app',
#   'does',
#   'not',
#   'work',
#   'person_facepalmingperson_facepalming',
#   'hope',
#   'there',
#   'has',
#   'update'],
#  ['correct',
#   '.',
#   'covidiots',
#   'bark',
#   'without',
#   'knowledge',
#   'vaccine',
#   '"',
#   'might',
#   '"',
#   'help',
#   'with',
#   'covid',
#   '19',
#   '.',
#   'here',
#   'matter',
#   'is',
#   'new',
#   'covid',
#   '.',
#   'blanket',
#   'ban',
#   'all',
#   'international',
#   'flights',
#   '.'],
#  ['india',
#   'do',
#   'not',
#   'need',
#   'dose',
#   'covid',
#   '19',
#   'vaccine',
#   '.',
#   'man',
#   'ki',
#   'bat',
#   'is',
#   'enough',
#   '.'],
#  ['#',
#   'indiabeginsdryrun',
#   'india',
#   'which',
#   'is',
#   'doing',
#   'well',
#   'covid',
#   '19',
#   'war',
#   'is',
#   'now',
#   'ready',
#   'roll',
#   'out',
#   'it',
#   'is',
#   'vaccine',
#   'program',
#   'as',
#   'per',
#   'plan',
#   '.'],
#  ['flash',
#   ':',
#   'vaccines',
#   'will',
#   'work',
#   'against',
#   'new',
#   'variant',
#   'covid',
#   'virus',
#   'says',
#   'india',
#   "'",
#   's',
#   'principal',
#   'scientific',
#   'advisor'],
#  ['yes',
#   'i',
#   'got',
#   '#',
#   'jab',
#   'done',
#   '#',
#   'freevaccine',
#   '#',
#   'pfizer',
#   '#',
#   'covidvaccine',
#   '#',
#   'dubai',
#   '@',
#   'nadd',
#   'al',
#   'hammar',
#   'health',
#   'center'],
#  ['wear',
#   'mask',
#   'even',
#   'after',
#   'getting',
#   'covid',
#   '-',
#   '19',
#   'or',
#   'vaccine',
#   '1',
#   '.',
#   'vaccine',
#   'may',
#   'not',
#   'give',
#   'you',
#   'full',
#   'protection',
#   'vaccinated',
#   '2',
#   '.',
#   'you',
#   'could',
#   'still',
#   'spread',
#   'covid',
#   '-',
#   '19',
#   ',',
#   'even',
#   'after',
#   'getting',
#   'vaccinated',
#   '3',
#   '.',
#   'unvaccinated',
#   'people',
#   'might',
#   'think',
#   'it',
#   'is',
#   'okay',
#   'stop',
#   'wearing',
#   'mask',
#   '#',
#   'covid19'],
#  ['breaking',
#   ':',
#   'india',
#   'says',
#   'it',
#   'has',
#   'successfully',
#   'conducted',
#   'dry',
#   'run',
#   'covid',
#   'vaccine',
#   '4',
#   'states',
#   '--',
#   'four',
#   'states',
#   'assam',
#   ',',
#   'andhra',
#   'pradesh',
#   ',',
#   'punjab',
#   '&',
#   'amp',
#   ';',
#   'gujarat',
#   '28th',
#   '29th',
#   'december',
#   '.'],
#  ['Information',
#   'is',
#   'constantly',
#   'evolving',
#   'and',
#   'changing',
#   '..',
#   '#',
#   'vaccination',
#   '#',
#   'arthritis',
#   '#',
#   'corona',
#   '#',
#   'pfizer',
#   '#',
#   'kuwait',
#   '#',
#   'corona',
#   '#',
#   'vaccine',
#   '#',
#   'covid_19',
#   '#',
#   'rheumatology',
#   '#',
#   'rheumatologist'],
#  ['#',
#   'information',
#   'fraudsters',
#   'are',
#   'calling',
#   'asking',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'registration',
#   '.',
#   'they',
#   'ask',
#   'aadhar',
#   ',',
#   'email',
#   'id',
#   'etc',
#   '.',
#   'subsequently',
#   'authenticate',
#   'aadhar',
#   ',',
#   'they',
#   'ask',
#   'otp',
#   '.',
#   'moment',
#   'otp',
#   'is',
#   'given',
#   ',',
#   'money',
#   'is',
#   'siphoned',
#   'off',
#   'aadhar',
#   'linked',
#   'bank',
#   'account',
#   '.'],
#  ['do',
#   'not',
#   'share',
#   'aadhaar',
#   'card',
#   ',',
#   'banks',
#   ',',
#   'debit',
#   '/',
#   'credit',
#   'card',
#   ',',
#   'otp',
#   ',',
#   'address',
#   ',',
#   'pan',
#   'card',
#   'details',
#   'phone',
#   '/',
#   'email',
#   '/',
#   'whatsapp',
#   'do',
#   'not',
#   'pay',
#   'money',
#   'anyone',
#   'registration',
#   'covid',
#   'vaccine',
#   '.',
#   'your',
#   'local',
#   'government',
#   'will',
#   'inform',
#   'you',
#   'procedure',
#   '-',
#   'silver',
#   'innings'],
#  ['new',
#   'covid',
#   '-',
#   '19',
#   'strain',
#   'reaches',
#   'india',
#   ':',
#   'does',
#   'it',
#   'spread',
#   'easily',
#   'vaccines',
#   'will',
#   'not',
#   'work',
#   'here',
#   'are',
#   'all',
#   'your',
#   'questions',
#   'answered'],
#  ['new',
#   'covid',
#   '-',
#   '19',
#   'strain',
#   'reaches',
#   'india',
#   ':',
#   'does',
#   'it',
#   'spread',
#   'easily',
#   'vaccines',
#   'won',
#   '’',
#   't',
#   'work',
#   'here',
#   'are',
#   'all',
#   'your',
#   'questions',
#   'answered'],
#  ['big',
#   'task',
#   'ahead',
#   'india',
#   '.',
#   'covid',
#   '-',
#   '19',
#   'hasn',
#   '’',
#   't',
#   'ended',
#   'yet',
#   '.',
#   'it',
#   'is',
#   'getting',
#   'stronger',
#   'we',
#   'need',
#   'combat',
#   'it',
#   '.',
#   'wear',
#   'your',
#   'mask',
#   '.',
#   'face_with_medical_mask',
#   'wash',
#   'your',
#   'hands',
#   '.',
#   'all',
#   'hopes',
#   'covid',
#   'vaccine',
#   '.',
#   'crossed_fingerslight_skin_tone'],
#  ['covid',
#   'vaccine',
#   'has',
#   'been',
#   'used',
#   'by',
#   'more',
#   'than',
#   '23',
#   'million',
#   'people',
#   'worldwide',
#   '.',
#   'when',
#   'will',
#   'india',
#   'use',
#   'can',
#   'person',
#   'who',
#   'told',
#   'me',
#   'hit',
#   'plates',
#   ',',
#   'flower',
#   'light',
#   'fire',
#   'say',
#   'something'],
#  ['important',
#   'msg',
#   'backhand_index_pointing_downfolded_handsbackhand_index_pointing_down',
#   'fraudsters',
#   'are',
#   'calling',
#   'asking',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'registration',
#   '.',
#   'they',
#   'ask',
#   'aadhar',
#   ',',
#   'email',
#   'id',
#   'etc',
#   '.',
#   'subsequently',
#   ',',
#   'authenticate',
#   'aadhar',
#   ',',
#   'they',
#   'ask',
#   'otp',
#   '.',
#   'moment',
#   'otp',
#   'is',
#   'given',
#   ',',
#   'money',
#   'is',
#   'siphoned',
#   'off',
#   'aadhar',
#   'linked',
#   'bank',
#   'account',
#   '.'],
#  ['whatsapp',
#   'backhand_index_pointing_rightlight_skin_tone',
#   'beware',
#   'new',
#   'way',
#   'cyber',
#   'crime',
#   '.',
#   'fraudsters',
#   'are',
#   'calling',
#   'asking',
#   'covid',
#   '-',
#   '19',
#   'vaccine',
#   'registration',
#   '.',
#   'they',
#   'ask',
#   'aadhar',
#   ',',
#   'email',
#   'id',
#   'etc',
#   '.',
#   'then',
#   'authenticate',
#   'aadhar',
#   ',',
#   'they',
#   'ask',
#   'otp',
#   '.',
#   'once',
#   'otp',
#   'is',
#   'given',
#   ',',
#   'money',
#   'is',
#   'siphoned',
#   'off',
#   'aadhar',
#   'linked',
#   'bank',
#   'account',
#   '.'],
#  ['we',
#   'had',
#   '15k',
#   'people',
#   'confirmed',
#   'with',
#   'covid',
#   'india',
#   'yesterday',
#   '.',
#   'with',
#   '60',
#   '%',
#   'coverage',
#   'population',
#   'with',
#   '95',
#   '%',
#   'effective',
#   'vaccine',
#   'this',
#   'number',
#   'would',
#   'have',
#   'been',
#   '750',
#   '.',
#   'deaths',
#   'we',
#   'are',
#   '400',
#   'they',
#   'will',
#   'now',
#   'be',
#   'down',
#   'less',
#   'than',
#   '10',
#   '.'],
#  ...]

# %%
convert_to_str = []

for each in tokenised_amer:
    converted_str = ""
    for i in range(0,len(each)):
        if i == (len(each) - 1):
            converted_str += each[i]
        else:
            converted_str += each[i] + ", "
    convert_to_str.append(converted_str)
    
converted_df = pd.DataFrame(convert_to_str)

converted_df.to_csv('american-38k-41k.csv')

# %% [markdown]
# ## Conversion of Numerals

# %%
# new_df = pd.read_csv("american-2000-4000.csv")

# %%
# new_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# thelist = []

# for row in new_df['0']:
#     alist = row.split(", ")
#     thelist.append(alist)

# %%
# thelist

# %%
#check if text has numbers 
def hasNumbers(inputList):
    for list in inputList:
        for word in list:
            if word.isdigit():
                return True
    return False

hasNumbers(tokenised_words)
# Out:
# True

# %%
# since theres numbers, the numbers need to be converted to words e.g. "2" to "two"

p = inflect.engine()
  
# convert number into words
def convert_number(text):
    # split string into list of words
    temp_str = text.split()
    # initialise empty list
    new_string = []
  
    for word in temp_str:
        # if word is a digit, convert the digit
        # to numbers and append into the new_string list
        if word.isdigit():
            temp = p.number_to_words(word)
            new_string.append(temp)
  
        # append the word as it is
        else:
            new_string.append(word)
  
    # join the words of new_string to form a string
    temp_str = ' '.join(new_string)
    return temp_str

# %%
# example text which contain numbers in it
input_list = ['There are 3 balls in this bag, and 12 in the other one.', '29']
result = [convert_number(each)for each in input_list]
result
# Out:
# ['There are three balls in this bag, and twelve in the other one.',
#  'twenty-nine']

# %%
#NEED TO CHANGE VARIABLE after us to brit eng conversion

tokenised_numerals_converted = [[convert_number(w) for w in each] for each in tokenised_amer]

# %%
#check if text has numbers 
def hasNumbers(inputList):
    for list in inputList:
        for word in list:
            if word.isdigit():
                return True
    return False

hasNumbers(tokenised_numerals_converted)
# Out:
# False

# %% [markdown]
# ## Misspellings

# %%
def correct_typo(tokens):
    spell = SpellChecker()
    return [spell.correction(t) if len(spell.unknown([t]))>0 else t for t in tokens]

# %%
misspelled_test = ['greot', 'coyor', 'and', 'misspeling']
correct_typo(misspelled_test)
# Out:
# ['great', 'color', 'and', 'misspelling']

# %%
tokenised_spellchecked = [correct_typo(each) for each in tokenised_numerals_converted]

# %%
tokenised_spellchecked
# Out:
# [['finally', 'couid', 'nineteen', 'vaccine'],
#  ['assay', 'i', 'couid', 'i', 'vaccine', 'ahi', 'golslightly_smiling_face'],
#  ['first',
#   'batch',
#   '#',
#   'covidvaccine',
#   'ne',
#   'reached',
#   'lgby',
#   'airport',
#   ',',
#   '#',
#   'guwahati',
#   '.',
#   'around',
#   'twenty',
#   'boxes',
#   'vaccines',
#   'received',
#   'today',
#   'at',
#   'guwahati',
#   ',',
#   'out',
#   'which',
#   'seventeen',
#   'are',
#   'assay',
#   'three',
#   'are',
#   'meghalaya',
#   '.'],
#  ['state',
#   'task',
#   'force',
#   'sta',
#   'held',
#   'it',
#   'is',
#   'second',
#   'meeting',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   '.',
#   '#',
#   'nagaland',
#   'read',
#   '-'],
#  ['strengthening',
#   'efforts',
#   'health',
#   'counselors',
#   'effective',
#   'roll',
#   'out',
#   'couid',
#   'vaccine'],
#  ['couid',
#   'vaccine',
#   'arrive',
#   'at',
#   'twenty',
#   'cartons',
#   'vaccines',
#   'arrive',
#   'at'],
#  ['#',
#   'new_video_in_hindi',
#   'The',
#   'government',
#   'should',
#   'rethink',
#   'again',
#   '#',
#   'covidvaccine',
#   ',',
#   'do',
#   'not',
#   'take',
#   'any',
#   'step',
#   'in',
#   'haste',
#   'folded_handsfolded_hands'],
#  ['Corona',
#   'vaccine',
#   '#',
#   'covidvaccine',
#   '#',
#   'covisheeld',
#   'came',
#   'to',
#   'the',
#   'state'],
#  ['this',
#   'is',
#   'what',
#   'entire',
#   'country',
#   'India',
#   'has',
#   'been',
#   'waiting',
#   'since',
#   'march',
#   'two thousand and twenty',
#   '.',
#   'green',
#   'corridors',
#   'being',
#   'created',
#   'by',
#   'police',
#   'multiple',
#   'India',
#   'cities',
#   '.',
#   'visuals',
#   'first',
#   'consignment',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   '#',
#   'covishield',
#   'arrives',
#   'at',
#   'telangana',
#   "'",
#   'i',
#   'immunization',
#   'complex',
#   'koto',
#   '#',
#   'hyderabad',
#   '#',
#   'covidvaccine'],
#  ['lowest',
#   'case',
#   '#',
#   'vaccine',
#   'is',
#   'ready',
#   '#',
#   'india',
#   '.',
#   '#',
#   'indiafightscorona',
#   '#',
#   'covid19',
#   '#',
#   'covidiots',
#   '#',
#   'covidvaccine',
#   '#',
#   'healthcare',
#   '#',
#   'safety',
#   '#',
#   'stanhope',
#   '#',
#   'world',
#   '#',
#   'people',
#   '#',
#   '302pendinginssrcase',
#   '#',
#   'trumpcoupattempt',
#   '#',
#   'trumpbanned',
#   '#',
#   'biden',
#   '#',
#   'university',
#   '#',
#   'masterful',
#   '#',
#   'masterpongal'],
#  ['I',
#   'want',
#   'to',
#   'avoid',
#   'children',
#   'getting',
#   'couid',
#   '.',
#   'install',
#   'antivirus',
#   '.',
#   'I',
#   'do',
#   'not',
#   'need',
#   'an',
#   'ambiguous',
#   'vaccine',
#   '.'],
#  ['if',
#   'bop',
#   'will',
#   'come',
#   'power',
#   ',',
#   'every',
#   'person',
#   'will',
#   'get',
#   'free',
#   'vaccine',
#   'couid',
#   'meanwhile',
#   'bihar',
#   '-'],
#  ['#',
#   '4newstrains',
#   '...',
#   'is',
#   'new',
#   'challenge',
#   '...',
#   'testing',
#   'these',
#   'rampantly',
#   ',',
#   'only',
#   'way',
#   'out',
#   '...',
#   'we',
#   'cannt',
#   'let',
#   'it',
#   'beat',
#   'our',
#   '#',
#   'covidvaccine',
#   'initiatives',
#   '...#',
#   'covid19',
#   'challenging',
#   'science',
#   'even',
#   'more'],
#  ['Something',
#   'happy',
#   'every',
#   'time',
#   'I',
#   'visit',
#   'I',
#   'am',
#   'impressed',
#   'and',
#   'proud',
#   'i',
#   'American_SamoaAmerican_Samoa',
#   'i',
#   'white_heartwhite_heartwhite_heart',
#   '@',
#   'Corona',
#   '-',
#   'couid',
#   '-',
#   'nineteen',
#   'Vaccine',
#   'Center',
#   'riya'],
#  ['beware',
#   'indian',
#   'cargo',
#   'planes',
#   'with',
#   'loads',
#   'couid',
#   'vaccine',
#   'may',
#   'be',
#   'hijacked',
#   '#',
#   'pakistan'],
#  ['live',
#   'update',
#   'out',
#   'six',
#   '#',
#   'covidvaccine',
#   'centers',
#   '#',
#   'telangana',
#   ',',
#   'area',
#   'hospital',
#   '#',
#   'nasally',
#   'has',
#   'been',
#   'selected',
#   'as',
#   'center',
#   '#',
#   'covid19',
#   'vaccination',
#   'program',
#   ',',
#   'i',
#   'inspected',
#   'hospital',
#   'preparations',
#   '.',
#   '#',
#   'covidvaccine2021',
#   '#',
#   'covidvaccinations',
#   '#',
#   'covidvaccinefacts',
#   '#',
#   'hyderabad'],
#  ['yes',
#   ',',
#   'students',
#   'can',
#   'go',
#   'attend',
#   'their',
#   'exams',
#   'couid',
#   'when',
#   'there',
#   'was',
#   'not',
#   'even',
#   'any',
#   'signal',
#   'success',
#   'vaccine',
#   'but',
#   'u',
#   'should',
#   'not',
#   'do',
#   'ur',
#   'work',
#   'also',
#   'do',
#   'not',
#   'forget',
#   'there',
#   'i',
#   'doctors',
#   'nurses',
#   'i',
#   'many',
#   'others',
#   'who',
#   'i',
#   'constantly',
#   'doing',
#   'the',
#   'jobs',
#   'amid',
#   'couid',
#   'risking',
#   'the',
#   'ly',
#   'real',
#   'but',
#   'u',
#   'should',
#   'not',
#   'work',
#   'rid'],
#  ['great',
#   'effort',
#   'eradicate',
#   '#',
#   'covid19',
#   '.',
#   '#',
#   'india',
#   '#',
#   'healthcare',
#   '#',
#   'covidvaccine',
#   '#',
#   'couid',
#   '#',
#   'stateofemergency',
#   '#',
#   'staysail',
#   '#',
#   'swamivivekanandjayanti',
#   '#',
#   'aatmanirbharbharat',
#   '#',
#   'listen',
#   '#',
#   'vivekananda',
#   '#',
#   'priyankagandhi',
#   '#',
#   'homeoffice',
#   '#',
#   'whatsappprivacy',
#   '#',
#   'trumpbegged',
#   '#',
#   'biden',
#   '#',
#   'masterful',
#   '#',
#   'masterpongal',
#   '#',
#   'homeschooling'],
#  ['has',
#   'updated',
#   'info',
#   'now',
#   ':',
#   'so',
#   'four hundred and ninety-three',
#   'has',
#   'delivered',
#   'all',
#   'six',
#   '.',
#   'four',
#   'lakh',
#   'doses',
#   '#',
#   'covidvaccine',
#   'scheduled',
#   'be',
#   'delivered',
#   'today',
#   'bengaluru',
#   '.',
#   'pics',
#   'at',
#   'vaccines',
#   'unloading'],
#  ['#',
#   'vaccinestrategy',
#   'green',
#   'corridor',
#   'made',
#   'truck',
#   'carrying',
#   'couid',
#   'vaccines',
#   ',',
#   'truck',
#   'currently',
#   'enroute',
#   'rajiv',
#   'gandhi',
#   'hospital',
#   '.'],
#  ['welcome',
#   '#',
#   'bengaluru',
#   ',',
#   '#',
#   'couid',
#   '#',
#   'vaccine',
#   'have',
#   'great',
#   'time',
#   '.',
#   '#',
#   'vaccinations'],
#  ['wait',
#   'is',
#   'finally',
#   'over',
#   '.',
#   'first',
#   'consignment',
#   '#',
#   'covidvaccine',
#   'vials',
#   'have',
#   'arrived',
#   'at',
#   'storage',
#   'center',
#   'bengaluru',
#   '.'],
#  ['#',
#   'covidvaccine',
#   'bengaluru',
#   ':',
#   'spicejet',
#   'day',
#   'sent',
#   'it',
#   'is',
#   'est',
#   'batch',
#   'vac',
#   'doses',
#   'i',
#   "'",
#   'lure',
#   'from',
#   'pune',
#   '.',
#   'so',
#   'four hundred and ninety-three',
#   'read',
#   'kia',
#   '@',
#   'twelve',
#   '.',
#   'fifteen',
#   'am',
#   ',',
#   'said',
#   'spokesperson',
#   'ty',
#   'not',
#   'yet',
#   'clear',
#   '.',
#   'deliv',
#   'six',
#   ',',
#   'forty-eight',
#   ',',
#   'zero',
#   'doses',
#   'i',
#   "'",
#   'our',
#   'tue',
#   '&',
#   'amp',
#   ';',
#   'four',
#   'in',
#   'doses',
#   'four',
#   'india',
#   '.',
#   'rep',
#   'pic'],
#  ['Congratulations',
#   'Delhi',
#   'The',
#   'first',
#   'consignment',
#   'of',
#   'Corona',
#   'Vaccine',
#   'reached',
#   'Delhi',
#   '.',
#   '#',
#   'covidvaccine',
#   '#',
#   'delhi'],
#  ['scoop',
#   'est',
#   'look',
#   'it',
#   'suggests',
#   'it',
#   'i',
#   'i',
#   'multi',
#   '-',
#   'dose',
#   'vial',
#   '.',
#   'expiry',
#   'april',
#   'two thousand and twenty-one',
#   'indicates',
#   'limited',
#   'shelf',
#   'life',
#   '.',
#   'two',
#   'doses',
#   'per',
#   'person',
#   'will',
#   'consume',
#   'most',
#   'them',
#   '.',
#   'storage',
#   'course',
#   'at',
#   'two',
#   '-',
#   'eight',
#   'i',
#   'i',
#   '.',
#   '#',
#   'covidvaccine',
#   '#',
#   'indiafightscorona',
#   '#',
#   'vaccineswork'],
#  ['preparatory',
#   'meeting',
#   'regarding',
#   'couid',
#   'vaccine',
#   'sixteen',
#   'Jan',
#   'pro',
#   'ameerpet',
#   'chandrakant',
#   ',',
#   'do',
#   'revathi',
#   ',',
#   'do',
#   'sridhar',
#   'nodal',
#   'office',
#   '#',
#   'bop',
#   '#',
#   'bjpforindia'],
#  ['nepal',
#   'desert_island',
#   'i',
#   'desert_island',
#   'i',
#   'prefers',
#   'indian',
#   'vaccines',
#   'over',
#   'chinese',
#   'as',
#   'am',
#   'gyawali',
#   'visits',
#   'india',
#   'procurement',
#   'half',
#   'million',
#   'doses',
#   'couid',
#   '-',
#   'nineteen',
#   'thermometer',
#   'i',
#   'thermometer',
#   'i',
#   'vaccine',
#   'india',
#   'tops',
#   'agenda',
#   'nepalese',
#   'foreign',
#   'minister',
#   'pradeep',
#   'gyawali',
#   'who',
#   'arrives',
#   'new',
#   'delhi',
#   'january',
#   'fourteen',
#   '.',
#   '#',
#   'newyear2021',
#   '#',
#   'censorship',
#   'flying_saucerflying_saucer'],
#  ['#',
#   'seruminstituteofindia',
#   '#',
#   'covidvaccine',
#   '#',
#   'aatmanirbharbharat'],
#  ['#',
#   'ahmedabad',
#   ':',
#   'first',
#   'consignment',
#   'coronavirus',
#   'vaccine',
#   'arrived',
#   'at',
#   'ahmedabad',
#   "'",
#   'i',
#   'sardar',
#   'vallabhbhai',
#   'patel',
#   'international',
#   'airport',
#   'deputy',
#   'am',
#   'nitin',
#   'patel',
#   'was',
#   'present',
#   'at',
#   'airport',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'covidvaccine',
#   '#',
#   'five hundred and six',
#   '#',
#   'one thousand, two hundred and one',
#   '#',
#   'ourvapii'],
#  ['am',
#   'waiting',
#   'take',
#   'couid',
#   'vaccine',
#   'head',
#   'out',
#   'world',
#   'that',
#   'we',
#   'are',
#   'so',
#   'used',
#   'i',
#   'shows',
#   ',',
#   'recordings',
#   ',',
#   'shoots',
#   'et',
#   'al',
#   'i',
#   'some',
#   'people',
#   'ask',
#   'if',
#   'vaccine',
#   'is',
#   'safe',
#   'or',
#   'without',
#   'side',
#   'effects',
#   'i',
#   'my',
#   'answer',
#   'is',
#   'any',
#   'side',
#   'effect',
#   'is',
#   'benign',
#   'compared',
#   'dreaded',
#   'couid',
#   ',',
#   'especially',
#   'my',
#   'age'],
#  ['couid', 'vaccine', 'mi', 'mah', 'ribeye', '.'],
#  ['"',
#   'Survey',
#   'bhavani',
#   'sukhi',
#   ':',
#   'Survey',
#   'santa',
#   'nirmala',
#   '.',
#   'May',
#   'everyone',
#   'be',
#   'free',
#   'disease',
#   '"',
#   'this',
#   'is',
#   'stamp',
#   'marked',
#   'every',
#   'box',
#   '#',
#   'covidvaccine',
#   'transported',
#   'various',
#   'parts',
#   'country',
#   '....'],
#  ['#',
#   'covidvaccine',
#   'If',
#   'someone',
#   'is',
#   'taking',
#   'medicine',
#   'for',
#   'diseases',
#   'like',
#   'cancer',
#   ',',
#   'diabetes',
#   ',',
#   'high',
#   'blood',
#   'pressure',
#   'etc',
#   ',',
#   'can',
#   'he',
#   'take',
#   'corona',
#   'vaccine',
#   '#',
#   'indiafightscorona',
#   '#',
#   'coronavaccine'],
#  ['boom',
#   'rolling_on_the_floor_laughingrolling_on_the_floor_laughingrolling_on_the_floor_laughing',
#   '.',
#   'that',
#   'is',
#   '#',
#   'rocketship',
#   'rocket',
#   'son',
#   'face_with_tears_of_joyface_with_tears_of_joyperson_facepalminglight_skin_tone',
#   'i',
#   'male_sign',
#   '.',
#   '#',
#   'retweet',
#   '#',
#   'twitch',
#   '#',
#   'twitter',
#   '#',
#   'india',
#   '#',
#   'mumbai',
#   '#',
#   'memes',
#   '#',
#   'funnyvideo',
#   '#',
#   'onlybreath',
#   '#',
#   'covidvaccine',
#   '#',
#   'donaldtrump',
#   '#',
#   'goodmorning',
#   '#',
#   'goodmorningtwitterworld',
#   '#',
#   'boom',
#   '#',
#   'maharashtrian',
#   '#',
#   'instagram',
#   '#',
#   'quoteoftheday',
#   '#',
#   'positivevibes'],
#  ['boom',
#   'rolling_on_the_floor_laughingrolling_on_the_floor_laughingrolling_on_the_floor_laughing',
#   '.',
#   'that',
#   'is',
#   '#',
#   'rocketship',
#   'rocket',
#   'son',
#   'face_with_tears_of_joyface_with_tears_of_joyperson_facepalminglight_skin_tone',
#   'i',
#   'male_sign',
#   '.',
#   '#',
#   'retweet',
#   '#',
#   'twitch',
#   '#',
#   'twitter',
#   '#',
#   'india',
#   '#',
#   'mumbai',
#   '#',
#   'memes',
#   '#',
#   'funnyvideo',
#   '#',
#   'onlybreath',
#   '#',
#   'covidvaccine',
#   '#',
#   'donaldtrump',
#   '#',
#   'goodmorning',
#   '#',
#   'goodmorningtwitterworld',
#   '#',
#   'boom',
#   '#',
#   'maharashtrian',
#   '#',
#   'instagram'],
#  ['blo',
#   'at',
#   'vacant',
#   'kung',
#   'sector',
#   'i',
#   'pocket',
#   '-',
#   'one',
#   'is',
#   'supposed',
#   'reach',
#   'by',
#   'twelve',
#   '.',
#   'zero',
#   'noon',
#   'distribute',
#   'forms',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'till',
#   'now',
#   'there',
#   'is',
#   'no',
#   'sign',
#   '.',
#   'senior',
#   'citizens',
#   'are',
#   'waiting',
#   'but',
#   'no',
#   'sign',
#   'her',
#   'coming',
#   '.',
#   'is',
#   'this',
#   'way'],
#  ['When',
#   'the',
#   'car',
#   'carrying',
#   'the',
#   'loved',
#   'vaccine',
#   'from',
#   'the',
#   'Serum',
#   'Institute',
#   'in',
#   'Pune',
#   ',',
#   'was',
#   'worshiped',
#   '.',
#   'Why',
#   'do',
#   'you',
#   'know',
#   'that',
#   'before',
#   'taking',
#   'the',
#   'vaccine',
#   ',',
#   'you',
#   'should',
#   'also',
#   'worship',
#   '...',
#   'why',
#   'do',
#   'you',
#   'know',
#   '#',
#   'covidvaccine'],
#  ['good',
#   'be',
#   'story',
#   'tracking',
#   'couid',
#   'vaccine',
#   'i',
#   'i',
#   'transportation',
#   'bengaluru'],
#  ['first',
#   'batch',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'at',
#   'ii',
#   'airport',
#   '.',
#   '#',
#   'news'],
#  ['so',
#   'when',
#   'is',
#   'our',
#   'hardworking',
#   'am',
#   'modi',
#   'taking',
#   'couid',
#   'vaccine',
#   'live',
#   'to',
#   'then',
#   'he',
#   'cannot',
#   'miss',
#   'that',
#   'glorious',
#   'or',
#   'moment',
#   ',',
#   'can',
#   'he',
#   'if',
#   'he',
#   'is',
#   'not',
#   'seen',
#   'taking',
#   'one',
#   'live',
#   'feed',
#   ',',
#   'what',
#   'does',
#   'it',
#   'tell',
#   'about',
#   'vaccines',
#   '#',
#   'vaccine',
#   '#',
#   'vaccinestrategy',
#   '#',
#   'seruminstituteofindia'],
#  ['#',
#   'delhi',
#   '|',
#   'first',
#   'consignment',
#   '#',
#   'covishield',
#   'couid',
#   '#',
#   'vaccine',
#   'arrives',
#   'pune',
#   "'",
#   'i',
#   'serum',
#   'institute',
#   'india',
#   'delhi',
#   '.',
#   'pics',
#   'delhi',
#   'airport',
#   "'",
#   'i',
#   'cargo',
#   'terminal',
#   '.'],
#  ['proud',
#   'moment',
#   'pune',
#   '.',
#   'trucks',
#   'carrying',
#   'couid',
#   'vaccines',
#   'their',
#   'way',
#   'airport',
#   'be',
#   'shipped',
#   'all',
#   'over',
#   'country',
#   '.',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'indiafightscorona',
#   '#',
#   'covishield',
#   '#',
#   'seruminstituteofindia',
#   '#',
#   'aatmanirbharbharat',
#   '#',
#   'pune',
#   '#',
#   'corona'],
#  ['why',
#   'is',
#   'spicejet',
#   'still',
#   'flying',
#   'under',
#   'jet',
#   'airways',
#   'colors',
#   'carrying',
#   'couid',
#   'vaccine',
#   'i',
#   'wolf',
#   'sheep',
#   'i',
#   'i',
#   'clothing',
#   'or',
#   'vice',
#   'versa'],
#  ['we',
#   'need',
#   'debunk',
#   'myths',
#   'about',
#   'couid',
#   'vaccine',
#   '.',
#   'great',
#   'interview',
#   'by',
#   'do',
#   'no',
#   'aroma',
#   '.'],
#  ['first',
#   'consignment',
#   '#',
#   'covid19',
#   '#',
#   'vaccine',
#   "'",
#   'covishield',
#   "'",
#   'arrives',
#   'at',
#   'delhi',
#   'airport',
#   'pune',
#   '.',
#   'first',
#   'phase',
#   '#',
#   'vaccination',
#   'india',
#   'starts',
#   'january',
#   'sixteen',
#   '.',
#   '#',
#   'covidvaccine'],
#  ['just', 'in', ':', 'lands', 'with', '#', 'covidvaccine'],
#  ['#',
#   'covidvaccine',
#   'started',
#   'it',
#   'is',
#   'journey',
#   '#',
#   'seruminstituteofindia',
#   '#',
#   'pune',
#   'early',
#   'this',
#   'morning',
#   'different',
#   'locations',
#   '#',
#   'india',
#   '#',
#   'health',
#   '#',
#   'frontlineworkers'],
#  ['#',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'भ_श',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'thumbs_upsyringeclapping_handsclapping_handsspicejet',
#   'has',
#   'carried',
#   'india',
#   'i',
#   'i',
#   'first',
#   'consignment',
#   '#',
#   'couid',
#   'vaccine',
#   'today',
#   '.',
#   '#',
#   'first',
#   'consignment',
#   'i',
#   'covishield',
#   "'",
#   'consisting',
#   'thirty-four',
#   'boxes',
#   'weighing',
#   'one thousand and eighty-eight',
#   'keg',
#   'was',
#   'carried',
#   '#',
#   'pune',
#   '#',
#   'delhi',
#   '#',
#   'vaccine',
#   '#',
#   'covid19'],
#  ['covid19',
#   '|',
#   'carried',
#   'india',
#   'i',
#   'i',
#   'first',
#   'consignment',
#   'couid',
#   'vaccine',
#   'today',
#   '.',
#   'consignment',
#   "'",
#   'covishield',
#   "'",
#   'constitutes',
#   'thirty-four',
#   'boxes',
#   'weights',
#   'one thousand and eighty-eight',
#   'keg',
#   'is',
#   'being',
#   'carried',
#   '#',
#   'pune',
#   '#',
#   'delhi',
#   ':',
#   'ajay',
#   'singh',
#   ',',
#   'chairman',
#   '&',
#   'amp',
#   ';',
#   'i',
#   'i',
#   ',',
#   'spicejet',
#   '#',
#   'covishield',
#   '#',
#   'vaccine',
#   '#',
#   'indian',
#   '#',
#   'thedaily'],
#  ['wow', 'wel', 'come', 'had', 'couid', 'vaccine'],
#  ['what',
#   'positive',
#   'news',
#   'start',
#   'day',
#   'est',
#   'consignment',
#   '#',
#   'covishield',
#   'vaccines',
#   'left',
#   '#',
#   'seruminstituteofindia',
#   'nationwide',
#   'vaccination',
#   'drive',
#   '#',
#   'covidvaccine',
#   '#',
#   'tuesdayvibe'],
#  ['how',
#   'can',
#   'saying',
#   '#',
#   'couid',
#   'vaccines',
#   'made',
#   'india',
#   'are',
#   'not',
#   'worth',
#   'just',
#   'before',
#   'vaccines',
#   'availablepersevering_facepouting_face',
#   'highly',
#   'irresponsible',
#   'act',
#   'i',
#   'seeding',
#   'fear',
#   'viewers',
#   'mindconfounded_face',
#   'plus',
#   'look',
#   'into',
#   'it'],
#  ['couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'starts',
#   'it',
#   'is',
#   'journey',
#   'pune'],
#  ['am',
#   'admit',
#   'party',
#   'jammy',
#   'ok',
#   'demands',
#   'free',
#   'cost',
#   'vaccine',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   'all',
#   'citizens',
#   '.'],
#  ['this',
#   'is',
#   'first',
#   'lot',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   ',',
#   'all',
#   'set',
#   'arrive',
#   'pune',
#   'flight',
#   '.',
#   'later',
#   'day',
#   ',',
#   'air',
#   'india',
#   'flight',
#   'is',
#   'expected',
#   'fly',
#   'another',
#   'consignment',
#   'vaccines',
#   'delhi',
#   ',',
#   'pune',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'vaccine'],
#  ['spicejet',
#   'has',
#   'carried',
#   'india',
#   'i',
#   'i',
#   'first',
#   'consignment',
#   'couid',
#   'vaccine',
#   'today',
#   '.',
#   'first',
#   'consignment',
#   "'",
#   'covishield',
#   "'",
#   'consisting',
#   'thirty-four',
#   'boxes',
#   'weighing',
#   'one thousand and eighty-eight',
#   'keg',
#   'was',
#   'carried',
#   '#',
#   'pune',
#   '#',
#   'delhi'],
#  ['#',
#   'breaking',
#   ':',
#   'first',
#   'lot',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   'that',
#   'will',
#   'come',
#   'delhi',
#   ',',
#   'being',
#   'loaded',
#   'flight',
#   'tuesday',
#   'morning',
#   'at',
#   'pune',
#   'airport',
#   '.'],
#  ['i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'serum',
#   'institute',
#   'india',
#   "'",
#   'i',
#   'covid19',
#   'vaccine',
#   "'",
#   'covishield',
#   "'",
#   'will',
#   'be',
#   'shipped',
#   'different',
#   'locations',
#   'country',
#   'pune',
#   'airport',
#   ',',
#   'ahead',
#   'january',
#   'sixteen',
#   'vaccine',
#   'rollout',
#   '.',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'covidvaccine'],
#  ['india',
#   'wants',
#   'serum',
#   'institute',
#   'lower',
#   'price',
#   'astrazeneca',
#   "'",
#   'i',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'download',
#   'economic',
#   'times',
#   'app',
#   'stay',
#   'updated',
#   'with',
#   'business',
#   'news',
#   '-'],
#  ['will',
#   'pfizer',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'come',
#   'india',
#   'pfizer',
#   'had',
#   'applied',
#   'era',
#   'india',
#   'december',
#   ',',
#   'two thousand and twenty',
#   ',',
#   'but',
#   'they',
#   'have',
#   'not',
#   'attended',
#   'any',
#   'three',
#   'sec',
#   'meetings',
#   'held',
#   'since',
#   'then',
#   '.'],
#  ['last',
#   '-',
#   'mile',
#   'couid',
#   'vaccine',
#   'delivery',
#   'far',
#   'perfect',
#   'sarah',
#   ',',
#   'faraway',
#   'pfizer',
#   'modern',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   'are',
#   'not',
#   'suitable',
#   'sarah',
#   'faraway',
#   ',',
#   'says',
#   'federation',
#   'malaysian',
#   'freight',
#   'forwarded',
#   '.'],
#  ['health',
#   'minister',
#   'assures',
#   'transparency',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'purchase'],
#  ['thermometersyringe',
#   'aussies',
#   'will',
#   'be',
#   'vaccinated',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   'from',
#   'February',
#   ',',
#   'is',
#   'it',
#   'true',
#   'round_pushpinAustralia',
#   'according',
#   'to',
#   'new',
#   'information',
#   'from',
#   'health',
#   'experts',
#   'and',
#   'regulators',
#   ',',
#   'aussies',
#   'will',
#   'be',
#   'vaccinated',
#   'against',
#   'coronavirus',
#   'in',
#   'February',
#   '.',
#   'globe_with_meridians'],
#  ['hopefully',
#   'door',
#   'does',
#   'same',
#   'as',
#   'well',
#   '.',
#   'that',
#   'might',
#   'help',
#   'open',
#   'up',
#   'causeway',
#   'again',
#   'report',
#   ':',
#   'selangor',
#   'buy',
#   'up',
#   'five',
#   'million',
#   'doses',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   'state',
#   'residents',
#   '|'],
#  ['so',
#   'i',
#   'i',
#   've',
#   'had',
#   'first',
#   'dose',
#   'sinopharm',
#   'couid',
#   'vaccine',
#   'i',
#   'i',
#   've',
#   'had',
#   'no',
#   'symptoms',
#   'at',
#   'all',
#   ',',
#   'nothing',
#   'after',
#   'thirty',
#   'hours',
#   'counting',
#   'now',
#   '.',
#   'how',
#   'strange',
#   'this',
#   'whole',
#   'pandemic',
#   'is'],
#  ['am',
#   'shri',
#   'mahendra',
#   'modi',
#   "'",
#   'i',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cos',
#   'roll',
#   '-',
#   'out',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   '.',
#   '#',
#   'indiafightscorona'],
#  ['tamil',
#   'nada',
#   'govt',
#   'doctors',
#   'are',
#   'reluctant',
#   'accept',
#   'couid',
#   'vaccine',
#   'shot',
#   '.',
#   'nurses',
#   'too',
#   'may',
#   'follow',
#   '.',
#   'read'],
#  ['new',
#   'sources',
#   'found',
#   'that',
#   'vitamin',
#   'i',
#   'is',
#   'good',
#   'stopping',
#   'couid',
#   'nineteen',
#   'disease',
#   '.',
#   'sunlight',
#   'is',
#   'good',
#   'source',
#   'gaining',
#   'vitamin',
#   'i',
#   '.',
#   'drink',
#   'cow',
#   "'",
#   'i',
#   'milk',
#   'orange',
#   'juice',
#   '.',
#   'you',
#   'can',
#   'take',
#   'vitamin',
#   'i',
#   'supplement',
#   'tablets',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'coronavirusstrain',
#   '#',
#   'vitamin',
#   '#',
#   'vaccine'],
#  ['govt',
#   'india',
#   'will',
#   'pay',
#   'get',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   '.',
#   'govt',
#   'india',
#   'will',
#   'give',
#   'this',
#   'vaccine',
#   'free',
#   '.',
#   'govt',
#   'india',
#   'will',
#   'earn',
#   'get',
#   'returns',
#   'this',
#   '.',
#   'it',
#   'requires',
#   '"',
#   'extra',
#   '"',
#   'ordinary',
#   'use',
#   'brain',
#   'extraordinary',
#   'times',
#   'collect',
#   'get',
#   'couid',
#   'vaccine',
#   'that',
#   'goi',
#   'will',
#   'purchase',
#   '&',
#   'amp',
#   ';',
#   'giveaway',
#   'free'],
#  ['couid', 'vaccine', 'se', 'yada', 'we', 'need', 'develop', 'spine'],
#  ['#',
#   'vaccine',
#   'first',
#   'batch',
#   '/',
#   'consignment',
#   '#',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'likely',
#   'reach',
#   'jammy',
#   'kashmir',
#   'tomorrow',
#   'or',
#   'wednesday',
#   '.',
#   'health',
#   'workers',
#   'will',
#   'be',
#   'covered',
#   'first',
#   '.'],
#  ['yes',
#   'index_pointing_upcheck_mark_button',
#   'also',
#   'am',
#   'maharashtrian',
#   'must',
#   'be',
#   'requested',
#   'declare',
#   'that',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'will',
#   'be',
#   'free',
#   'all',
#   '.',
#   'tulipfolded_handsrosetriangular_flagtriangular_flagIndiaIndia'],
#  ['upside',
#   '-',
#   'down_face',
#   '#',
#   'russia',
#   'try',
#   'out',
#   "'",
#   'sputnik',
#   '-',
#   'light',
#   "'",
#   'couid',
#   'vaccine',
#   'make',
#   'it',
#   'go',
#   'further'],
#  ['no',
#   'injection',
#   'are',
#   'available',
#   'due',
#   'couid',
#   '-',
#   'nineteen',
#   ',',
#   'only',
#   'vaccines',
#   'are',
#   'stock',
#   ',',
#   'which',
#   'are',
#   'real',
#   '/',
#   'water',
#   "'",
#   'name',
#   "'",
#   'only',
#   'knows',
#   '.',
#   'by',
#   'way',
#   'recent',
#   'excitement',
#   'indian',
#   'economy',
#   'are',
#   'case',
#   'study',
#   'eminent',
#   'economists',
#   'as',
#   'promised',
#   'by',
#   'him',
#   '.'],
#  ['vaccine',
#   'rolled',
#   'out',
#   'not',
#   'lobbies',
#   'and',
#   'corrupt',
#   'politician',
#   ',',
#   'let',
#   'their',
#   'turn',
#   'come',
#   'decide',
#   'take',
#   'or',
#   'die',
#   'infected',
#   'with',
#   'couid'],
#  ['times',
#   'couid',
#   ',',
#   'when',
#   'our',
#   'indian',
#   'scientific',
#   'community',
#   'is',
#   'working',
#   'selflessly',
#   'covishield',
#   'coaxing',
#   'vaccines',
#   ',',
#   'there',
#   'are',
#   'pieces',
#   'information',
#   'that',
#   'are',
#   'defaming',
#   'their',
#   'great',
#   'work',
#   "'",
#   'i',
#   'integrity',
#   '.',
#   'we',
#   ',',
#   'as',
#   'organization',
#   'request',
#   'everyone',
#   'not',
#   'fall',
#   'pit',
#   'politicization'],
#  ['was',
#   'so',
#   'focused',
#   'steering',
#   'discussion',
#   'against',
#   'covidvaccine',
#   'that',
#   'it',
#   'took',
#   'babu',
#   'among',
#   'politicos',
#   'i',
#   'to',
#   'health',
#   'sexy',
#   'get',
#   'anchor',
#   'drop',
#   'his',
#   'campaign',
#   'against',
#   'indigenous',
#   'vaccine',
#   '.',
#   'anchor',
#   'even',
#   'cross',
#   'checked',
#   'with',
#   'tac',
#   'minister',
#   'if',
#   'modi',
#   'ever',
#   'let',
#   'us',
#   'state',
#   'leaders',
#   'speak',
#   'meeting',
#   '.'],
#  ['Finally',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'God',
#   'is',
#   'dear',
#   'to',
#   'our',
#   'country',
#   'and',
#   'is',
#   'not',
#   'dear',
#   'to',
#   'it',
#   '#',
#   'Corona_vaccine',
#   '#',
#   'Kingdom_Saudi_Arabia'],
#  ['agar',
#   'corona',
#   'ke',
#   'sat',
#   'ye',
#   'food',
#   'waste',
#   'bhi',
#   'whatam',
#   'ho',
#   'jake',
#   'ganga',
#   'nah',
#   'lena',
#   'he',
#   'humane',
#   '#',
#   'khaanashah',
#   '#',
#   'indore',
#   '#',
#   'food',
#   '#',
#   'foodwaste',
#   '#',
#   'wastemanagement',
#   '#',
#   'zerocovid',
#   '#',
#   'zerowaste',
#   '#',
#   'covid19',
#   '#',
#   'trending',
#   '#',
#   'coronavirusstrain',
#   '#',
#   'coronavirus',
#   '#',
#   'vaccine',
#   '#',
#   'couid',
#   '#',
#   'sustainability',
#   '#',
#   'foodsecurity',
#   '#',
#   'indiathoughts'],
#  ['am',
#   'modi',
#   "'",
#   'i',
#   'closing',
#   'remarks',
#   'at',
#   'interaction',
#   'with',
#   'chief',
#   'ministers',
#   'all',
#   'states',
#   'couid',
#   'vaccine',
#   'rollout'],
#  ['*',
#   'Vaccines',
#   'are',
#   'still',
#   'in',
#   'trial',
#   'phase',
#   ',',
#   'then',
#   'how',
#   'crores',
#   'of',
#   'doses',
#   'we',
#   'are',
#   'prepared',
#   'for',
#   'vaccination',
#   '*',
#   'thinking_face',
#   '#',
#   'covidvaccine'],
#  ['our',
#   'vaccine',
#   'may',
#   'have',
#   'taken',
#   'time',
#   ',',
#   'but',
#   'it',
#   'is',
#   'very',
#   'likely',
#   'be',
#   'most',
#   'effective',
#   'masses',
#   '.',
#   'keep',
#   'rumors',
#   'aside',
#   ',',
#   'see',
#   'well',
#   'managed',
#   '#',
#   'vaccine',
#   'mahakumbh',
#   'now',
#   '.',
#   'we',
#   'will',
#   'overcome',
#   '#',
#   'couid'],
#  ['we',
#   'i',
#   've',
#   'made',
#   '#',
#   'covidvaccine',
#   'less',
#   'than',
#   'year',
#   ',',
#   'but',
#   'we',
#   'i',
#   've',
#   'not',
#   'been',
#   'able',
#   'make',
#   'fucking',
#   'mask',
#   'that',
#   'doesn',
#   'i',
#   'i',
#   'slip',
#   'down',
#   'your',
#   'nose',
#   'person_facepalmingmedium_skin_tone',
#   'i',
#   'male_sign',
#   'i',
#   '#',
#   'covid19'],
#  ['raj',
#   'ji',
#   ',',
#   'young',
#   'dynasty',
#   'raga',
#   'has',
#   'come',
#   'back',
#   'after',
#   'his',
#   'long',
#   'new',
#   'yr',
#   'blast',
#   'mysterious',
#   'forge',
#   'destination',
#   '.',
#   'ply',
#   'ask',
#   'him',
#   'take',
#   'couid',
#   'vaccines',
#   'bar',
#   'hia',
#   'next',
#   'trip',
#   '.'],
#  ['over',
#   'million',
#   'people',
#   'beijing',
#   'have',
#   'received',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   '.'],
#  ['use',
#   'has',
#   'administered',
#   'one',
#   ',',
#   'one hundred and sixty-seven',
#   ',',
#   'two hundred and fifty-one',
#   'doses',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   ',',
#   'that',
#   'i',
#   'i',
#   'average',
#   'eleven',
#   '.',
#   'eight',
#   'doses',
#   'per',
#   'one hundred',
#   'people',
#   '.',
#   '#',
#   'use',
#   'syringe'],
#  ['#',
#   'cooperativefedralism',
#   'at',
#   'work',
#   '.',
#   'am',
#   'modi',
#   "'",
#   'i',
#   'closing',
#   'remarks',
#   'at',
#   'interaction',
#   'with',
#   'chief',
#   'ministers',
#   'all',
#   'states',
#   'couid',
#   'vaccine',
#   'rollout',
#   'proud',
#   'moment',
#   'india',
#   '.',
#   'health',
#   'safety',
#   'indian',
#   'people',
#   'at',
#   'stake'],
#  ['live',
#   ':',
#   'am',
#   'shri',
#   'is',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cos',
#   'roll',
#   '-',
#   'out',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine'],
#  ['by',
#   'way',
#   'how',
#   'is',
#   'your',
#   'region',
#   'doing',
#   'art',
#   'couid',
#   'numbers',
#   'we',
#   ',',
#   'our',
#   'family',
#   ',',
#   'too',
#   'contracted',
#   'it',
#   'are',
#   'out',
#   'quarantine',
#   'i',
#   'vaccines',
#   'should',
#   'be',
#   'out',
#   'there',
#   'right'],
#  ['it',
#   'is',
#   'ironic',
#   'that',
#   'same',
#   'person',
#   'who',
#   'said',
#   'we',
#   'do',
#   'not',
#   'need',
#   'vaccinessyringe',
#   'right',
#   'now',
#   'got',
#   'infected',
#   'with',
#   '#',
#   'covid19',
#   '.',
#   'maybe',
#   'at',
#   'least',
#   'now',
#   'goal',
#   'understands',
#   'that',
#   'we',
#   'have',
#   'bring',
#   'down',
#   '#',
#   'covidvaccine',
#   '.',
#   '#',
#   'la',
#   '#',
#   'srilanka',
#   '#',
#   'covid19sl',
#   '#',
#   'covid19lk'],
#  ['now',
#   'it',
#   'is',
#   'impossible',
#   'ec',
#   'win',
#   'even',
#   'if',
#   'he',
#   'goes',
#   'another',
#   'appeal',
#   'divisional',
#   'bench',
#   'high',
#   'court',
#   'advice',
#   'nandu',
#   '&',
#   'amp',
#   ';',
#   'co',
#   '.',
#   'it',
#   'would',
#   'be',
#   'foolish',
#   'thing',
#   ',',
#   'if',
#   'he',
#   'takes',
#   'any',
#   'further',
#   'wrong',
#   'step',
#   '.',
#   'now',
#   'he',
#   'should',
#   'realize',
#   'importance',
#   'couid',
#   '#',
#   'covid19',
#   '#',
#   'covidvaccine'],
#  ['big',
#   'breaking',
#   ':',
#   'reports',
#   'that',
#   'cost',
#   'free',
#   'vaccine',
#   'ocr',
#   'frontline',
#   'workers',
#   'will',
#   'be',
#   'borne',
#   'by',
#   'am',
#   '-',
#   'cares',
#   '#',
#   'covidvaccine',
#   'file',
#   'pic'],
#  ['The',
#   'main',
#   'reason',
#   'for',
#   'the',
#   'end',
#   'of',
#   '#',
#   'corona',
#   '#',
#   'covid19',
#   'has',
#   'spread',
#   '#',
#   'covidvaccine',
#   'in',
#   'the',
#   'air'],
#  ['am',
#   'shri',
#   'is',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cos',
#   'roll',
#   '-',
#   'out',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   '.',
#   '#',
#   'indiafightscorona'],
#  ['follow',
#   'us',
#   '-',
#   'serum',
#   "'",
#   'i',
#   "'",
#   'covishield',
#   "'",
#   'vaccine',
#   'would',
#   'be',
#   'available',
#   'at',
#   'price',
#   'i',
#   'two hundred',
#   'per',
#   'vial',
#   ',',
#   'said',
#   'officials',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'coronavirusstrain',
#   '#',
#   'covid19',
#   '#',
#   'vaccine',
#   '#',
#   'covid_19',
#   '#',
#   'couid',
#   '#',
#   'covid2020',
#   '#',
#   'covishield',
#   '#',
#   'covidvacccine',
#   '#',
#   'covidtesting',
#   '#',
#   'covishieldlatestnews'],
#  ['am',
#   'modi',
#   "'",
#   'i',
#   'closing',
#   'remarks',
#   'at',
#   'meeting',
#   'with',
#   'cos',
#   'roll',
#   '-',
#   'out',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine'],
#  ['india',
#   'is',
#   'working',
#   'four',
#   'other',
#   'couid',
#   'vaccines',
#   'says',
#   'am',
#   'modi'],
#  ['#', 'covidvaccine', '#', 'nomo_lacke_crank'],
#  ['first',
#   'purchase',
#   'order',
#   '#',
#   'covidvaccine',
#   'was',
#   'registered',
#   'with',
#   'by',
#   'central',
#   'govt',
#   'i',
#   'pune',
#   '#',
#   'coronavirusvaccine',
#   '#',
#   'coronavirusupdates'],
#  ['center',
#   'says',
#   'that',
#   'there',
#   'will',
#   'be',
#   'single',
#   'purchase',
#   'couid',
#   'vaccine',
#   'do',
#   'we',
#   'see',
#   'another',
#   'cess',
#   'adding',
#   'our',
#   'tax',
#   'now'],
#  ['Corona',
#   'vaccine',
#   ':',
#   'Government',
#   'of',
#   'India',
#   'signs',
#   'eleven',
#   'million',
#   'dose',
#   'agreement',
#   'with',
#   'Serum',
#   'Institute',
#   'Dispatch',
#   'process',
#   'will',
#   'start',
#   'from',
#   'this',
#   'evening',
#   '#',
#   'coronavaccine',
#   '#',
#   'vaccine',
#   '#',
#   'corona',
#   '#',
#   'coronavirus',
#   '#',
#   'couid',
#   '#',
#   'aapnusanjeli',
#   '#',
#   'dad'],
#  ['couid',
#   'vaccines',
#   'likely',
#   'reach',
#   'gujaratis',
#   'today',
#   '.',
#   '#',
#   'coronavirusupdates'],
#  ['indian',
#   'am',
#   'modi',
#   "'",
#   'i',
#   'meet',
#   'with',
#   'cos',
#   'couid',
#   'vaccine',
#   'begins'],
#  ['because',
#   'as',
#   'i',
#   'know',
#   'pfizer',
#   'vaccine',
#   'has',
#   'been',
#   'clinical',
#   'trial',
#   'phase',
#   'three',
#   'usa'],
#  ['nice',
#   'see',
#   'mahendra',
#   'supra',
#   'is',
#   'taking',
#   'lead',
#   'role',
#   'couid',
#   'vaccine',
#   'distribution',
#   'far',
#   'off',
#   'places',
#   'clapping_handsclapping_handsclapping_hands'],
#  ['i',
#   'take',
#   'one',
#   'hour',
#   'looking',
#   'at',
#   'macdonalds',
#   'menu',
#   'even',
#   'tho',
#   'i',
#   'always',
#   'order',
#   'same',
#   'thing',
#   '.',
#   'i',
#   'had',
#   'decide',
#   'if',
#   'i',
#   'want',
#   'get',
#   'couid',
#   'vaccine',
#   'day',
#   '.',
#   'now',
#   'I',
#   'am',
#   'scheduled',
#   'one',
#   ',',
#   'but',
#   'I',
#   'am',
#   'still',
#   'unsure',
#   '.',
#   'confounded_face'],
#  ['banana',
#   'with',
#   'feb',
#   'two thousand and twenty-one',
#   'two_hearts',
#   '#',
#   'valentinesday',
#   'mummy',
#   'couid',
#   'nineteen',
#   'ki',
#   'vaccine',
#   'lagaan',
#   'jana',
#   'i',
#   'face_with_tears_of_joyface_with_tears_of_joyface_with_tears_of_joy'],
#  ['with',
#   'jan',
#   'would',
#   'have',
#   'been',
#   'better',
#   'date',
#   'start',
#   'couid',
#   'vaccine',
#   'india',
#   '.',
#   'something',
#   'would',
#   'have',
#   'worked',
#   'that',
#   'was',
#   'done',
#   'with',
#   'jan',
#   '.',
#   '#',
#   'covid19india',
#   '#',
#   'covid19vaccine',
#   '#',
#   'india',
#   '#',
#   'republican'],
#  ['date',
#   'arrival',
#   'couid',
#   'vaccine',
#   'quantity',
#   'vaccine',
#   'be',
#   'allotted',
#   '#',
#   'dish',
#   'is',
#   'yet',
#   'be',
#   'intimated',
#   'by',
#   'center'],
#  ['the',
#   'heat',
#   'parliamentary',
#   'dissolution',
#   'couid',
#   'has',
#   'become',
#   'non',
#   'issue',
#   '.',
#   'i',
#   'rest',
#   'govt',
#   'machinery',
#   'and',
#   'health',
#   'ministry',
#   'not',
#   'forget',
#   'couid',
#   'menace',
#   'and',
#   'urgently',
#   'make',
#   'available',
#   'vaccines',
#   'from',
#   'next',
#   'fortnight'],
#  ['it',
#   ':',
#   'importing',
#   'vaccines',
#   'made',
#   'us',
#   'or',
#   'uk',
#   'is',
#   'prohibited',
#   '.',
#   'they',
#   'are',
#   'completely',
#   'untrustworthy',
#   '.',
#   'it',
#   'is',
#   'not',
#   'unlikely',
#   'they',
#   'would',
#   'want',
#   'contaminate',
#   'other',
#   'nations',
#   'i',
#   'covidvaccine'],
#  ['pope',
#   'francis',
#   'calls',
#   'opposition',
#   'couid',
#   'vaccine',
#   'i',
#   'suicidal',
#   'denial',
#   'i',
#   'says',
#   'he',
#   'i',
#   'all',
#   'get',
#   'jab'],
#  ['nepal',
#   'am',
#   "'",
#   'i',
#   'india',
#   'visit',
#   ':',
#   'key',
#   'focus',
#   'couid',
#   'vaccine',
#   'procurement',
#   '.'],
#  ['couid',
#   '-',
#   'nineteen',
#   ':',
#   'brazil',
#   'president',
#   'bolsonaro',
#   'urges',
#   'am',
#   'mahendra',
#   'modi',
#   'two',
#   'million',
#   'covishield',
#   'vaccine',
#   'doses',
#   'urgently'],
#  ['west',
#   'bengal',
#   'am',
#   'matata',
#   'banerjee',
#   'promises',
#   'free',
#   'couid',
#   'vaccine',
#   ',',
#   'opposition',
#   'calls',
#   'it',
#   'poll',
#   'sop'],
#  ['grateful',
#   '#',
#   'mamatabanerjee',
#   'who',
#   'promised',
#   'provide',
#   'free',
#   'couid',
#   'vaccine',
#   'everyone',
#   'bengal',
#   'by',
#   'selling',
#   'her',
#   'paintings',
#   'poetry',
#   '.',
#   'rolling_on_the_floor_laughingrolling_on_the_floor_laughing'],
#  ['at',
#   'present',
#   'there',
#   'is',
#   'no',
#   'application',
#   'available',
#   'registration',
#   'getting',
#   'vaccine',
#   'couid',
#   'nineteen',
#   ',',
#   'available',
#   'app',
#   'play',
#   'store',
#   'are',
#   'all',
#   'fake',
#   ',',
#   'do',
#   'not',
#   'reveal',
#   'ur',
#   'info',
#   'them',
#   ',',
#   'when',
#   'app',
#   'is',
#   'ready',
#   'govt',
#   'will',
#   'advertise',
#   'it'],
#  ['delhi',
#   'i',
#   'i',
#   'blu',
#   'print',
#   'introduce',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'immunize',
#   'people',
#   '...'],
#  ['india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   ':',
#   'am',
#   'modi',
#   'via',
#   'name',
#   'app'],
#  ['last',
#   'night',
#   "'",
#   'i',
#   'weird',
#   'dream',
#   ':',
#   'about',
#   'getting',
#   'vaccine',
#   'couid',
#   'that',
#   'i',
#   'bought',
#   'street',
#   'food',
#   'vendor',
#   ',',
#   'had',
#   'administer',
#   'it',
#   'myself',
#   'right',
#   'there',
#   '.'],
#  ['another', 'india', '#', 'covidvaccine', 'success', 'story'],
#  ['promoting', 'confidence', 'couid', '-', 'nineteen', 'vaccines'],
#  ['since',
#   'modi',
#   'govt',
#   'has',
#   'approved',
#   'bharat',
#   'biotech',
#   'vaccine',
#   'without',
#   'results',
#   'ord',
#   'phase',
#   'trial',
#   ',',
#   'modi',
#   'should',
#   'be',
#   'first',
#   'get',
#   'vaccinated',
#   'instill',
#   'confidence',
#   'nation',
#   '#',
#   'bharatbiotech',
#   '#',
#   'indiafightscorona',
#   '#',
#   'covidvaccine',
#   '#',
#   'idiotpmmodi'],
#  ['there',
#   'should',
#   'be',
#   'no',
#   'politics',
#   'couid',
#   'nineteen',
#   'vaccine',
#   '.',
#   'it',
#   'should',
#   'provide',
#   'at',
#   'affordable',
#   'cost',
#   '.'],
#  ['i',
#   'doubt',
#   ',',
#   'couid',
#   'warriors',
#   'are',
#   'being',
#   'targeted',
#   'as',
#   'guinea',
#   'pig',
#   '/',
#   'rats',
#   'by',
#   'corona',
#   'vaccine',
#   'companies',
#   '.',
#   'stop',
#   'humiliating',
#   'humanity',
#   '.',
#   '#',
#   'coronavirusvaccine'],
#  ['they',
#   'spent',
#   'twelve',
#   'years',
#   'solving',
#   'puzzle',
#   '.',
#   'it',
#   'yielded',
#   'first',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   '.',
#   'via'],
#  ['matata',
#   'ji',
#   'announced',
#   'free',
#   'vaccine',
#   'west',
#   'bengal',
#   'heart_suit',
#   'but',
#   'during',
#   'lock',
#   'down',
#   'see',
#   'was',
#   'blaming',
#   'that',
#   'covid19',
#   '/',
#   'lock',
#   'down',
#   'is',
#   'strategy',
#   'make',
#   'fool',
#   'india',
#   'people',
#   ',',
#   'friends',
#   'just',
#   'think',
#   ',',
#   'free',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'is',
#   'just',
#   'lollipop',
#   '.',
#   '#',
#   'name',
#   '#',
#   'narendramodi',
#   '#',
#   'amitshah',
#   '#',
#   'mamatabanerjee',
#   '#',
#   'datak'],
#  ['india',
#   'under',
#   'takes',
#   'lead',
#   'introducing',
#   'vaccines',
#   'counter',
#   'couid',
#   '-',
#   'nineteen',
#   'virus',
#   '.',
#   'even',
#   'prior',
#   'vaccine',
#   'india',
#   'has',
#   'gotten',
#   'number',
#   'cases',
#   'dramatically',
#   'reduce',
#   'as',
#   'these',
#   'rapidly',
#   'increase',
#   'europe',
#   'america',
#   '.',
#   '#',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'i',
#   'एम_म',
#   'i',
#   'i',
#   'i',
#   '_अभ',
#   'i',
#   'i',
#   'i',
#   'i'],
#  ['great',
#   'news',
#   'people',
#   'bengal',
#   '.',
#   'matata',
#   'has',
#   'promised',
#   'free',
#   'couid',
#   'vaccine',
#   'everyone',
#   'bengal',
#   '.',
#   'she',
#   'plans',
#   'sell',
#   'all',
#   'her',
#   'properties',
#   'harish',
#   'chattered',
#   'road',
#   'get',
#   'money',
#   '.'],
#  ['enjoyed',
#   'this',
#   'quick',
#   'video',
#   'debunking',
#   'conspiracies',
#   'surrounding',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'interviewers',
#   ':',
#   'try',
#   'guys',
#   'seven',
#   '.',
#   'am',
#   'subs',
#   'youtube',
#   'interviewee',
#   ':',
#   'do',
#   'anthony',
#   'faci',
#   '.',
#   'never',
#   'seen',
#   'him',
#   'have',
#   'more',
#   'fun',
#   'interview'],
#  ['Alhamdulillah',
#   'today',
#   'I',
#   'took',
#   'corona',
#   'vaccine',
#   'thanks',
#   'dubai',
#   'use',
#   'health',
#   'authorities',
#   'use',
#   'have',
#   'vaccinated',
#   'over',
#   'million',
#   'residents',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   '.',
#   'ten',
#   '.',
#   'one',
#   '.',
#   'two thousand and twenty-one'],
#  ['has',
#   'india',
#   'India',
#   'made',
#   'vaccine',
#   'syringe',
#   'passed',
#   'all',
#   'tests',
#   'secure',
#   'people',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   'or',
#   'is',
#   'it',
#   'another',
#   'political',
#   'gimmick',
#   'lure',
#   'voters',
#   'or',
#   'fool',
#   'people',
#   'remember',
#   'this',
#   'issue',
#   'is',
#   'very',
#   'serious',
#   'government',
#   'must',
#   'ensure',
#   'safety',
#   'security',
#   'india',
#   'India',
#   'citizens',
#   'no',
#   'trials'],
#  ['couid', 'vaccine', 'facts', 'is', 'fiction'],
#  ['got',
#   'himself',
#   'vaccinated',
#   'prove',
#   'his',
#   'couid',
#   'vaccine',
#   'is',
#   'absolutely',
#   'safe',
#   '.',
#   'must',
#   'do',
#   'same',
#   '.',
#   'if',
#   'he',
#   'shies',
#   'away',
#   'his',
#   'personal',
#   'participation',
#   ',',
#   'nation',
#   'must',
#   'question',
#   'his',
#   'leadership',
#   '.'],
#  ['Have',
#   'heard',
#   'that',
#   '#',
#   'covidvaccine',
#   'is',
#   'coming',
#   'on',
#   'with',
#   'January',
#   ',',
#   'who',
#   'is',
#   'getting',
#   'it',
#   'installed',
#   '?'],
#  ['#',
#   'chinese',
#   'doctor',
#   'claims',
#   'that',
#   'sinopharm',
#   'vaccine',
#   'is',
#   'more',
#   'lethal',
#   'than',
#   'couid',
#   'itself',
#   'with',
#   'seventy-three',
#   'side',
#   'effects',
#   'posted',
#   'sarcastically',
#   'or',
#   'truth',
#   'chinese',
#   'never',
#   'fails',
#   'amaze',
#   'surprise',
#   'us',
#   'flushed_faceface_with_tears_of_joy'],
#  ['it',
#   'is',
#   'astonishing',
#   'see',
#   'west',
#   'bengal',
#   'nearly',
#   'ten',
#   'crore',
#   'population',
#   'will',
#   'get',
#   'health',
#   'cover',
#   'free',
#   'cost',
#   'now',
#   'couid',
#   'vaccine',
#   ',',
#   'all',
#   'being',
#   'offered',
#   'with',
#   'elections',
#   'round',
#   'corner',
#   'but',
#   'my',
#   'concern',
#   'is',
#   'how',
#   'will',
#   'government',
#   'foot',
#   'bill',
#   'with',
#   'already',
#   'four',
#   '.',
#   'five',
#   'lakh',
#   'crore',
#   'loan',
#   'our',
#   'head'],
#  ['#',
#   'covid19',
#   '#',
#   'covidvaccine',
#   '#',
#   'vaccinestrategy',
#   '#',
#   'vaccinesideeffects'],
#  ['what',
#   'extraordinary',
#   'start',
#   'two thousand and twenty-one',
#   'wishing',
#   'all',
#   'our',
#   'friends',
#   'followers',
#   'happy',
#   'safe',
#   'new',
#   'year',
#   '.',
#   '#',
#   'theperioclinic',
#   '#',
#   'gums',
#   '#',
#   'implants',
#   '#',
#   'dental',
#   '#',
#   'periodontology',
#   '#',
#   'periodontist',
#   '#',
#   'dentist',
#   '#',
#   'dubaidentist',
#   '#',
#   'dick',
#   '#',
#   'dubai',
#   '#',
#   'dubai',
#   '#',
#   'dubailife',
#   '#',
#   'dab',
#   '#',
#   'covid19',
#   '#',
#   'coronavirus',
#   '#',
#   'covidvaccine',
#   '#',
#   'vaccine'],
#  ['humanity',
#   'inventing',
#   'vaccine',
#   'deal',
#   'with',
#   'couid',
#   'nineteen',
#   '.',
#   'couid',
#   'nineteen',
#   ':'],
#  ['there',
#   'was',
#   'no',
#   'hurry',
#   'do',
#   'this',
#   'trial',
#   'at',
#   'such',
#   'breakneck',
#   'pace',
#   '.',
#   'usually',
#   'vaccine',
#   'trials',
#   'take',
#   'year',
#   'recruit',
#   '.',
#   'who',
#   'will',
#   'blame',
#   'cheerleaders',
#   'now',
#   '.',
#   'couid',
#   'vaccine',
#   'is',
#   'not',
#   'magic',
#   'wand',
#   'which',
#   'can',
#   'hum',
#   'up',
#   'our',
#   'economy',
#   'few',
#   'months',
#   '.'],
#  ['free',
#   '#',
#   'covidvaccine',
#   'everyone',
#   'bengal',
#   'announces',
#   'am',
#   'matata',
#   'banerjee',
#   '....',
#   'wonder',
#   'what',
#   'those',
#   'who',
#   'criticized',
#   'parties',
#   'during',
#   'bihar',
#   'polls',
#   'now',
#   'have',
#   'say',
#   '...',
#   '#',
#   'vaccinepolitics'],
#  ['before',
#   'couid',
#   'vaccine',
#   'roll',
#   'out',
#   'with',
#   'jan',
#   ',',
#   'union',
#   'health',
#   'ministry',
#   'holds',
#   'important',
#   'meeting',
#   'with',
#   'all',
#   'state',
#   '/',
#   'us',
#   'administrators',
#   'review',
#   'examine',
#   'co',
#   '-',
#   'win',
#   'coin',
#   'is',
#   'digital',
#   'platform',
#   'monitor',
#   '&',
#   'amp',
#   ';',
#   'share',
#   'couid',
#   'vaccine',
#   '.',
#   'my',
#   'report',
#   '#',
#   'indiafightscorona',
#   '#',
#   'vaccine',
#   '#',
#   'coin'],
#  ['The',
#   'word',
#   '#',
#   'India',
#   'India',
#   'written',
#   'on',
#   'this',
#   'bottle',
#   'of',
#   'Corona',
#   'vaccine',
#   'is',
#   'enough',
#   'for',
#   'me',
#   'to',
#   'be',
#   'proud',
#   '.',
#   'I',
#   'have',
#   'faith',
#   'in',
#   'my',
#   'country',
#   "'",
#   'i',
#   'scientists',
#   'on',
#   'my',
#   'country',
#   "'",
#   'i',
#   'capabilities',
#   '#',
#   'Jai_Hind',
#   '#',
#   'Vande',
#   'matata',
#   '#',
#   'bharatbiotech',
#   '#',
#   'covidvaccine',
#   'syringeambulance',
#   '#',
#   'india',
#   '#',
#   'sundaymotivation'],
#  ['i',
#   'was',
#   'among',
#   'more',
#   'than',
#   'seventy',
#   ',',
#   'zero',
#   'use',
#   'citizens',
#   'residents',
#   'receive',
#   'their',
#   'first',
#   'dose',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'yesterday',
#   ',',
#   'with',
#   'well',
#   'over',
#   'ten',
#   '%',
#   'population',
#   'already',
#   'vaccinated',
#   '.',
#   'it',
#   'i',
#   'i',
#   'well',
#   '-',
#   'run',
#   'roll',
#   '-',
#   'out',
#   'my',
#   'perspective',
#   'well',
#   'it',
#   'is',
#   'way',
#   'achieving',
#   'fifty',
#   '%',
#   'vaccinated',
#   'qi',
#   '.'],
#  ['done',
#   'with',
#   'first',
#   'dose',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'check_mark_button'],
#  ['Is', 'the', 'couid', 'vaccine', 'safe', '?'],
#  ['so',
#   'nigerian',
#   'govt',
#   'can',
#   'meet',
#   'world',
#   'health',
#   'organization',
#   'meet',
#   'there',
#   'needs',
#   'get',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'i',
#   'don',
#   'i',
#   'i',
#   'blame',
#   'you',
#   'nigerian',
#   'govt',
#   '.',
#   'world',
#   'did',
#   'not',
#   'recognized',
#   'you',
#   'nigerian',
#   'govt',
#   'i',
#   'you',
#   'all',
#   'are',
#   'disgrace',
#   'africa',
#   'i',
#   'thieves',
#   'that',
#   'is',
#   'what',
#   'you',
#   'all',
#   'are',
#   '.',
#   'won',
#   'hoshi',
#   'job'],
#  ['Good',
#   'evening',
#   'everyone',
#   'from',
#   'Al',
#   'batten',
#   'Council',
#   'in',
#   'Abu',
#   'Dhabi',
#   'United_Arab_Emirates',
#   'al',
#   'batten',
#   'males',
#   ',',
#   'taking',
#   'first',
#   'shot',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'syringe'],
#  ['i',
#   'i',
#   'all',
#   'be',
#   'taking',
#   'test',
#   'as',
#   'i',
#   'i',
#   've',
#   'done',
#   'every',
#   'time',
#   'still',
#   'isolating',
#   'two',
#   'weeks',
#   'when',
#   'i',
#   'get',
#   'back',
#   'uk',
#   'end',
#   'month',
#   'dubai',
#   '.',
#   'i',
#   'i',
#   've',
#   'even',
#   'had',
#   'my',
#   'couid',
#   'vaccine',
#   '.',
#   'i',
#   'i',
#   'i',
#   'at',
#   'greater',
#   'risk',
#   'catching',
#   'it',
#   'uk',
#   'then',
#   'you',
#   'are',
#   'me',
#   'bringing',
#   'it',
#   'in',
#   '.'],
#  ['myanmar',
#   '(',
#   'Burma',
#   ')',
#   'myanmar',
#   'has',
#   'ordered',
#   'thirty',
#   'million',
#   'doses',
#   '#',
#   'covidvaccine',
#   'india',
#   'India'],
#  ['nigerian',
#   'govt',
#   'is',
#   'failure',
#   '...',
#   'we',
#   'have',
#   'vaccine',
#   'couid',
#   'nineteen',
#   'united',
#   'arab',
#   'emirate',
#   ',',
#   'mostly',
#   'everybody',
#   'has',
#   'been',
#   'vaccinated',
#   '...',
#   'you',
#   'people',
#   'govt',
#   'only',
#   'know',
#   'how',
#   'lie',
#   'citizens',
#   ',',
#   'embezzling',
#   'our',
#   'money',
#   'thousands',
#   'nigerian',
#   'are',
#   'dying',
#   'day',
#   'by',
#   'day',
#   "b'cos",
#   'you',
#   'bad',
#   'leaders'],
#  ['new',
#   'couid',
#   'strain',
#   'south',
#   'african',
#   'one',
#   'potentially',
#   'resisting',
#   'vaccine',
#   'whewwww',
#   'chileeee',
#   'anxiety'],
#  ['Trust',
#   'me',
#   'matata',
#   'Sarkar',
#   'is',
#   'by',
#   'your',
#   'side',
#   'green_heartgreen_heartgreen_heart',
#   'smiling_face_with_smiling_eyes',
#   '#',
#   'mamatabanerjee',
#   '#',
#   'covid_vaccine'],
#  ['india',
#   'i',
#   'i',
#   'couid',
#   'recovery',
#   'rate',
#   'ninety-six',
#   '.',
#   'thirty-six',
#   '%',
#   'is',
#   'amongst',
#   'highest',
#   'world',
#   '.',
#   'we',
#   'did',
#   'ok',
#   'despite',
#   'our',
#   'huge',
#   'population',
#   'other',
#   'challenges',
#   '...',
#   'makes',
#   'one',
#   'hopeful',
#   'about',
#   'it',
#   'is',
#   'vaccine',
#   'coverage',
#   'too',
#   'this',
#   'year'],
#  ['jail',
#   'modi',
#   'i',
#   'india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   ':',
#   'am',
#   'modi',
#   'via',
#   'name',
#   'app'],
#  ['In',
#   'Delhi',
#   ',',
#   'eighty-nine',
#   'hospitals',
#   'have',
#   'been',
#   'identified',
#   'for',
#   'Phase',
#   'I',
#   'vaccination',
#   ',',
#   'red_triangle_pointed_up',
#   ',',
#   'of',
#   'which',
#   'thirty-six',
#   'are',
#   'government',
#   'and',
#   'fifty-three',
#   'private',
#   'hospitals',
#   '.',
#   'red_triangle_pointed_up',
#   'In',
#   'the',
#   'first',
#   'phase',
#   ',',
#   'the',
#   'vaccine',
#   'will',
#   'be',
#   'given',
#   'to',
#   'healthcare',
#   'workers',
#   '.',
#   'red_triangle_pointed_up12',
#   '-',
#   'thirteen',
#   'By',
#   'January',
#   'the',
#   'vaccine',
#   'will',
#   'come',
#   ',',
#   'we',
#   'have',
#   'enough',
#   'storage',
#   '.',
#   '#',
#   'covidvaccine'],
#  ['myanmar',
#   'has',
#   'ordered',
#   'thirty',
#   'million',
#   'couid',
#   'vaccine',
#   'india',
#   ',',
#   'country',
#   "'",
#   'i',
#   'president',
#   'office',
#   'has',
#   'announced'],
#  ['india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   ':',
#   'am',
#   'modi',
#   'ji',
#   'via',
#   'name',
#   'app'],
#  ['was',
#   'not',
#   'there',
#   'clear',
#   'indication',
#   'that',
#   'vaccine',
#   'was',
#   'not',
#   'complete',
#   'protection',
#   ',',
#   'but',
#   'just',
#   'ensured',
#   'lighter',
#   'case',
#   'couid'],
#  ['In',
#   'Delhi',
#   ',',
#   'eighty-nine',
#   'hospitals',
#   'have',
#   'been',
#   'identified',
#   'for',
#   'the',
#   'first',
#   'phase',
#   'of',
#   'vaccination',
#   ',',
#   'red_triangle_pointed_up',
#   ',',
#   'of',
#   'which',
#   'thirty-six',
#   'are',
#   'government',
#   'and',
#   'fifty-three',
#   'private',
#   'hospitals',
#   '.',
#   'red_triangle_pointed_up',
#   'In',
#   'the',
#   'first',
#   'phase',
#   ',',
#   'the',
#   'vaccine',
#   'will',
#   'be',
#   'given',
#   'to',
#   'healthcare',
#   'workers',
#   '.',
#   'red_triangle_pointed_up12',
#   '-',
#   'thirteen',
#   'By',
#   'January',
#   'the',
#   'vaccine',
#   'will',
#   'come',
#   ',',
#   'we',
#   'have',
#   'enough',
#   'storage',
#   '.',
#   '#',
#   'covidvaccine'],
#  ['do',
#   'sheer',
#   'sainalabdeen',
#   ',',
#   'specialist',
#   'respiratory',
#   'medicine',
#   ':',
#   'i',
#   'during',
#   'trials',
#   'currently',
#   'available',
#   'vaccines',
#   ',',
#   'tracking',
#   'has',
#   'been',
#   'done',
#   'pertaining',
#   'how',
#   'many',
#   'vaccinated',
#   'people',
#   'contract',
#   'couid',
#   '-',
#   'nineteen',
#   'despite',
#   'inoculation',
#   'i'],
#  ['letter',
#   'frontline',
#   'workers',
#   ',',
#   'west',
#   'bengal',
#   'chief',
#   'minister',
#   'matata',
#   'banerjee',
#   'says',
#   'that',
#   'her',
#   'govt',
#   'will',
#   'ensure',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'reaches',
#   'free',
#   'cost',
#   'everyone',
#   'state',
#   '.',
#   'i',
#   'i',
#   'i',
#   'i',
#   'happy',
#   'share',
#   'that',
#   'our',
#   'govt',
#   'will',
#   'ensure',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'reaches',
#   'everyone',
#   'state',
#   'free',
#   'cost',
#   'i'],
#  ['just', 'took', 'first', 'dose', 'couid', '-', 'nineteen', 'vaccine', 'i'],
#  ['india',
#   'ready',
#   'save',
#   'humanity',
#   'with',
#   'two',
#   "'",
#   'made',
#   'india',
#   "'",
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   ':',
#   'am',
#   'via',
#   'name',
#   'app'],
#  ['couid',
#   'number',
#   ':',
#   'nineteen',
#   'date',
#   ':',
# ...
#   'minutes',
#   'after',
#   'uk',
#   'regulator',
#   'approved',
#   'vaccine',
#   '.',
#   'i',
#   'only',
#   'sit',
#   'i',
#   'i',
#   'application',
#   'agenda',
#   'i',
#   'sources'],
#  ['britain',
#   'approves',
#   'astrazeneca',
#   '-',
#   'oxford',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine'],
#  ['"',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'couid',
#   '-',
#   'nineteen',
#   '#',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '"'],
#  ['"',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '"'],
#  ['kab',
#   'milena',
#   'yeh',
#   'vaccine',
#   'yaman',
#   '"',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '"'],
#  ['good',
#   'news',
#   ',',
#   'now',
#   'our',
#   'government',
#   'can',
#   'accelerate',
#   'roll',
#   'out',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'approved',
#   'by',
#   'uk',
#   'government',
#   '#',
#   'covidindia',
#   '#',
#   'covid19',
#   '#',
#   'coviduk'],
#  ['check',
#   'this',
#   'out',
#   'times',
#   'india',
#   'live',
#   ':',
#   'astrazeneca',
#   '-',
#   'oxford',
#   'couid',
#   'vaccine',
#   'approved',
#   'use',
#   'uk',
#   'download',
#   'toi',
#   'app',
#   'now',
#   ':',
#   'lab',
#   'approve',
#   'karo',
#   '...',
#   'daro',
#   'meat',
#   '...',
#   'haji',
#   'karo',
#   'approve',
#   'i'],
#  ['couid',
#   '-',
#   'nineteen',
#   ':',
#   '#',
#   'oxford',
#   '-',
#   'astrazeneca',
#   'coronavirus',
#   'vaccine',
#   'approved',
#   'use',
#   '#',
#   'uk',
#   '.',
#   'serum',
#   'institute',
#   'india',
#   'has',
#   'already',
#   'produced',
#   'forty',
#   '-',
#   'fifty',
#   'million',
#   'doses',
#   'this',
#   'vaccine',
#   'may',
#   'be',
#   '#',
#   'india',
#   'can',
#   'also',
#   'approve',
#   'it',
#   'soon',
#   '.'],
#  ['uk',
#   'regulator',
#   'approves',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine'],
#  ['it', 'i', 'i', 'test', '/', 'trial', 'couid', 'nineteen', 'vaccine', '.'],
#  ['#',
#   'breaking',
#   'uk',
#   'approves',
#   'oxford',
#   '-',
#   'astra',
#   'seneca',
#   'vaccine',
#   '#',
#   'covidvaccine',
#   '#',
#   'oxfordvaccine'],
#  ['astrazeneca',
#   'i',
#   'i',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'has',
#   'been',
#   'approved',
#   'emergency',
#   'supply',
#   'uk'],
#  ['who',
#   'say',
#   'two thousand and twenty',
#   'was',
#   'tuff',
#   'i',
#   'mean',
#   'many',
#   'people',
#   'lost',
#   'there',
#   'loved',
#   'ones',
#   'most',
#   ',',
#   'doctors',
#   'they',
#   'served',
#   'much',
#   'far',
#   'than',
#   'any',
#   'ordinary',
#   'person',
#   'i',
#   'mean',
#   'they',
#   'had',
#   'more',
#   'pain',
#   'than',
#   'us',
#   'may',
#   'this',
#   'year',
#   'be',
#   'year',
#   'cureslightly_smiling_face',
#   '#',
#   'happynewyear',
#   '#',
#   'happynewyear2021',
#   '#',
#   'coronavirus',
#   '#',
#   'covidvaccine',
#   '#',
#   'newyear2021'],
#  ['huge', 'moment', '#', 'couid', '#', 'vaccine'],
#  ['big',
#   'boost',
#   '.',
#   'uk',
#   'clears',
#   'oxford',
#   'astrazeneca',
#   'couid',
#   'vaccine',
#   '.',
#   'regulatory',
#   'approval',
#   'india',
#   'can',
#   'be',
#   'next',
#   'step',
#   '.',
#   '#',
#   'coronavirus',
#   '#',
#   'coronavirusupdates',
#   '#',
#   'coronavirusstrain'],
#  ['oxford',
#   '-',
#   'astra',
#   'seneca',
#   'get',
#   'uk',
#   'regulator',
#   'i',
#   'i',
#   'approval',
#   '#',
#   'covidvaccine'],
#  ['good',
#   'news',
#   'bac',
#   'news',
#   '-',
#   'couid',
#   '-',
#   'nineteen',
#   ':',
#   'oxford',
#   '-',
#   'astrazeneca',
#   'coronavirus',
#   'vaccine',
#   'approved',
#   'use',
#   'uk'],
#  ['great',
#   'news',
#   'hope',
#   'this',
#   'can',
#   'be',
#   'rolled',
#   'out',
#   'developing',
#   'countries',
#   'asap',
#   '|',
#   'couid',
#   '-',
#   'nineteen',
#   ':',
#   'oxford',
#   '/',
#   'astrazeneca',
#   'vaccine',
#   'approved',
#   'use',
#   'uk'],
#  ['as',
#   'couid',
#   'vaccine',
#   'has',
#   'started',
#   'rolling',
#   'out',
#   'cross',
#   'countries',
#   ',',
#   '#',
#   'tilwiththeprint',
#   'revathi',
#   'krishna',
#   'explains',
#   'what',
#   "'",
#   'vaccine',
#   'passport',
#   "'",
#   'is',
#   ',',
#   'why',
#   'one',
#   'might',
#   'need',
#   'it',
#   'travel',
#   '.'],
#  ['volunteered',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'trial',
#   'today',
#   '.',
#   'inshallah',
#   'if',
#   'all',
#   'goes',
#   'well',
#   'trial',
#   'results',
#   'are',
#   'positive',
#   'we',
#   'can',
#   'make',
#   'pakistan',
#   'safe',
#   '.',
#   'palms_up_togethermedium',
#   '-',
#   'light_skin_tonepalms_up_togethermedium',
#   '-',
#   'light_skin_tonepalms_up_togethermedium',
#   '-',
#   'light_skin_tone'],
#  ['let',
#   'me',
#   'remind',
#   'you',
#   'all',
#   '.',
#   'if',
#   'you',
#   'i',
#   're',
#   'planning',
#   'get',
#   'couid',
#   'vaccine',
#   ',',
#   'syringe',
#   'make',
#   'sure',
#   'you',
#   'have',
#   'enough',
#   'sleep',
#   ',',
#   'rest',
#   '&',
#   'amp',
#   ';',
#   'no',
#   'history',
#   'allergy',
#   '.'],
#  ['I', 'am', 'tired', 'of', 'waiting', '#', 'covidvaccine'],
#  ['#',
#   'india',
#   'is',
#   '#',
#   'covid19',
#   'status',
#   '.',
#   '#',
#   'breaking',
#   '#',
#   'healthy',
#   '#',
#   'covidiot',
#   '#',
#   'covidindia',
#   '#',
#   'mastercheftuerkiye',
#   '#',
#   'markup',
#   '#',
#   'socialdistancing',
#   '#',
#   'covidvaccine',
#   '#',
#   'lockdown',
#   '#',
#   'coronaupdatesinindia',
#   '#',
#   'america',
#   '#',
#   'dhoti',
#   '#',
#   'day',
#   '#',
#   'trending',
#   '#',
#   'coronanewstrain'],
#  ['china',
#   ',',
#   'india',
#   'both',
#   'front',
#   'pages',
#   'nepal',
#   'daily',
#   '.',
#   'india',
#   'couid',
#   'vaccine',
#   'procurement',
#   ',',
#   'china',
#   'it',
#   'is',
#   'vice',
#   'minister',
#   "'",
#   'i',
#   '"',
#   'whirlwind',
#   'tour',
#   '"',
#   'over',
#   'political',
#   'crisis',
#   '.'],
#  ['iran',
#   "'",
#   'i',
#   'purpose',
#   'doing',
#   'it',
#   'is',
#   'own',
#   '#',
#   'couid',
#   'vaccine',
#   'is',
#   'solely',
#   'set',
#   'humanity',
#   'serving',
#   'precedent',
#   'worth',
#   'mentioning',
#   'that',
#   'we',
#   'are',
#   'not',
#   'trifling',
#   'with',
#   'people',
#   'lives',
#   '.',
#   'any',
#   'new',
#   '#',
#   'sanctions',
#   'flourish',
#   'new',
#   'field',
#   'science',
#   '#',
#   'iran',
#   '.'],
#  ['you',
#   'can',
#   'i',
#   'i',
#   'let',
#   'your',
#   'guard',
#   'down',
#   'again',
#   'couid',
#   'at',
#   'all',
#   ',',
#   'it',
#   'i',
#   'i',
#   'pretty',
#   'evident',
#   'that',
#   'before',
#   'everybody',
#   'gets',
#   'vaccine',
#   'life',
#   'cannot',
#   'should',
#   'not',
#   'get',
#   'normalcy',
#   'unless',
#   'there',
#   'i',
#   'i',
#   'strain',
#   'that',
#   'all',
#   'tha',
#   'vaccines',
#   'are',
#   'unsuccessful',
#   'against',
#   'it',
#   '#',
#   'stanhope',
#   '#',
#   'staysail',
#   '#',
#   'covid19uk'],
#  ['two',
#   '.',
#   'one',
#   'million',
#   'couid',
#   'vaccine',
#   'doses',
#   'given',
#   'u',
#   '.',
#   'i',
#   '.',
#   'sent',
#   'using',
#   'escape',
#   'app',
#   'androidtrade_mark'],
#  ['#', 'kamalaharris', '#', 'us', '#', 'forbiden', '#', 'covidvaccine'],
#  ['#',
#   'dubai',
#   'receives',
#   'first',
#   'batch',
#   'pfizer',
#   '-',
#   'biotech',
#   "'",
#   'i',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccines',
#   'via'],
#  ['with',
#   'arrival',
#   'i',
#   'new',
#   'uk',
#   'strain',
#   'couid',
#   'india',
#   ',',
#   'we',
#   'prepared',
#   'for',
#   'this',
#   'seventy',
#   '%',
#   'more',
#   'contagious',
#   'variant',
#   'couid',
#   'we',
#   'i',
#   're',
#   'told',
#   'existing',
#   'vaccines',
#   'we',
#   'work',
#   'this',
#   'new',
#   'variant',
#   ',',
#   'but',
#   'what',
#   'i',
#   'i',
#   '=',
#   'lly',
#   'clear',
#   'i',
#   'i',
#   'that',
#   'battle',
#   'is',
#   'far',
#   'from',
#   'over',
#   '.',
#   'we',
#   'must',
#   'hence',
#   ',',
#   'strictly',
#   'follow',
#   'prevention',
#   'protocols',
#   '.'],
#  ['union',
#   'minister',
#   'radar',
#   'athawale',
#   ',',
#   'whose',
#   '"',
#   'go',
#   'corona',
#   ',',
#   'go',
#   '"',
#   'chant',
#   'became',
#   'national',
#   'sensation',
#   ',',
#   'sunday',
#   'came',
#   'out',
#   'with',
#   'new',
#   'slogan',
#   ',',
#   'i',
#   'no',
#   'corona',
#   "i'm",
#   'saying',
#   'it',
#   'was',
#   'response',
#   'new',
#   'strain',
#   'novel',
#   'coronavirus',
#   '.',
#   '#',
#   'coronavirus',
#   '#',
#   'covid19',
#   '#',
#   'covidvaccine',
#   '#',
#   'vaccine',
#   '#',
#   'vaccination',
#   '#',
#   'bop'],
#  ['Now',
#   'another',
#   'new',
#   'tension',
#   'has',
#   'started',
#   'for',
#   'all',
#   'those',
#   'who',
#   'came',
#   'to',
#   '#',
#   'corona',
#   '.',
#   'It',
#   'has',
#   'come',
#   'to',
#   'be',
#   'known',
#   'as',
#   'the',
#   '#',
#   'chinese',
#   'virus',
#   'or',
#   'the',
#   '#',
#   'english',
#   'virus',
#   '.',
#   '#',
#   'covid19',
#   '#',
#   'couid',
#   '#',
#   'covidvaccine'],
#  ['first',
#   'couid',
#   'vaccine',
#   'does',
#   'blue_heart',
#   'Saudi',
#   'Arabia',
#   'From',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'crisis',
#   ',',
#   'it',
#   'was',
#   'and',
#   'still',
#   'is',
#   'the',
#   'best',
#   '.'],
#  ['we',
#   'i',
#   're',
#   'not',
#   'going',
#   'get',
#   'rid',
#   'couid',
#   ',',
#   'no',
#   'clinician',
#   'i',
#   'i',
#   'i',
#   'aware',
#   'even',
#   'suggests',
#   'possibility',
#   'this',
#   '.',
#   'all',
#   'we',
#   'i',
#   're',
#   'trying',
#   'do',
#   'is',
#   'control',
#   'it',
#   'by',
#   'limiting',
#   'it',
#   'is',
#   'spread',
#   ',',
#   'one',
#   'most',
#   'effective',
#   'way',
#   'achieving',
#   'this',
#   'is',
#   'through',
#   'vaccines',
#   '.',
#   'this',
#   'isn',
#   'i',
#   'i',
#   'going',
#   'disappear',
#   'anytime',
#   'soon',
#   '.'],
#  ['lots',
#   'negativity',
#   'surrounding',
#   'arcturus',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'data',
#   '.',
#   'low',
#   'neutralizing',
#   'titers',
#   'may',
#   'look',
#   'disappointing',
#   'but',
#   'response',
#   'cdo',
#   'cdo',
#   'i',
#   'cells',
#   'are',
#   'very',
#   'good',
#   'could',
#   'prevent',
#   'couid',
#   '-',
#   'nineteen',
#   'infection',
#   '.',
#   'immunity',
#   'is',
#   'more',
#   'than',
#   'just',
#   'antibodies',
#   '.'],
#  ['We',
#   'trust',
#   'in',
#   'God',
#   'blue_heart',
#   '@',
#   'Corona',
#   '-',
#   'couid',
#   '-',
#   'nineteen',
#   'Vaccine',
#   'Center',
#   'riya'],
#  ['all',
#   'vaccinated',
#   'people',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   'will',
#   'still',
#   'need',
#   'fourteen',
#   'day',
#   'quarantine',
#   'until',
#   'more',
#   'study',
#   'is',
#   'done',
#   'vaccines',
#   'effects',
#   'stopping',
#   'infection',
#   'spread',
#   'says',
#   'thai',
#   'ministry',
#   'public',
#   'health',
#   '.'],
#  ['got',
#   'health',
#   'card',
#   'number',
#   'now',
#   '"',
#   'book',
#   'couid',
#   'nineteen',
#   'vaccine',
#   '"',
#   'button',
#   'app',
#   'does',
#   'not',
#   'work',
#   'person_facepalmingperson_facepalming',
#   'hope',
#   'there',
#   'has',
#   'update'],
#  ['correct',
#   '.',
#   'covidiots',
#   'bark',
#   'without',
#   'knowledge',
#   'vaccine',
#   '"',
#   'might',
#   '"',
#   'help',
#   'with',
#   'couid',
#   'nineteen',
#   '.',
#   'here',
#   'matter',
#   'is',
#   'new',
#   'couid',
#   '.',
#   'blanket',
#   'ban',
#   'all',
#   'international',
#   'flights',
#   '.'],
#  ['india',
#   'do',
#   'not',
#   'need',
#   'dose',
#   'couid',
#   'nineteen',
#   'vaccine',
#   '.',
#   'man',
#   'ki',
#   'bat',
#   'is',
#   'enough',
#   '.'],
#  ['#',
#   'indiabeginsdryrun',
#   'india',
#   'which',
#   'is',
#   'doing',
#   'well',
#   'couid',
#   'nineteen',
#   'war',
#   'is',
#   'now',
#   'ready',
#   'roll',
#   'out',
#   'it',
#   'is',
#   'vaccine',
#   'program',
#   'as',
#   'per',
#   'plan',
#   '.'],
#  ['flash',
#   ':',
#   'vaccines',
#   'will',
#   'work',
#   'against',
#   'new',
#   'variant',
#   'couid',
#   'virus',
#   'says',
#   'india',
#   "'",
#   'i',
#   'principal',
#   'scientific',
#   'advisor'],
#  ['yes',
#   'i',
#   'got',
#   '#',
#   'jab',
#   'done',
#   '#',
#   'freevaccine',
#   '#',
#   'pfizer',
#   '#',
#   'covidvaccine',
#   '#',
#   'dubai',
#   '@',
#   'add',
#   'al',
#   'hammer',
#   'health',
#   'center'],
#  ['wear',
#   'mask',
#   'even',
#   'after',
#   'getting',
#   'couid',
#   '-',
#   'nineteen',
#   'or',
#   'vaccine',
#   'one',
#   '.',
#   'vaccine',
#   'may',
#   'not',
#   'give',
#   'you',
#   'full',
#   'protection',
#   'vaccinated',
#   'two',
#   '.',
#   'you',
#   'could',
#   'still',
#   'spread',
#   'couid',
#   '-',
#   'nineteen',
#   ',',
#   'even',
#   'after',
#   'getting',
#   'vaccinated',
#   'three',
#   '.',
#   'vaccinated',
#   'people',
#   'might',
#   'think',
#   'it',
#   'is',
#   'okay',
#   'stop',
#   'wearing',
#   'mask',
#   '#',
#   'covid19'],
#  ['breaking',
#   ':',
#   'india',
#   'says',
#   'it',
#   'has',
#   'successfully',
#   'conducted',
#   'dry',
#   'run',
#   'couid',
#   'vaccine',
#   'four',
#   'states',
#   'i',
#   'four',
#   'states',
#   'assay',
#   ',',
#   'anders',
#   'grades',
#   ',',
#   'punjab',
#   '&',
#   'amp',
#   ';',
#   'gujaratis',
#   'with',
#   'with',
#   'december',
#   '.'],
#  ['Information',
#   'is',
#   'constantly',
#   'evolving',
#   'and',
#   'changing',
#   'i',
#   '#',
#   'vaccination',
#   '#',
#   'arthritis',
#   '#',
#   'corona',
#   '#',
#   'pfizer',
#   '#',
#   'kuwait',
#   '#',
#   'corona',
#   '#',
#   'vaccine',
#   '#',
#   'covid_19',
#   '#',
#   'hematology',
#   '#',
#   'rheumatologist'],
#  ['#',
#   'information',
#   'fraudsters',
#   'are',
#   'calling',
#   'asking',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'registration',
#   '.',
#   'they',
#   'ask',
#   'radar',
#   ',',
#   'email',
#   'id',
#   'etc',
#   '.',
#   'subsequently',
#   'authenticate',
#   'radar',
#   ',',
#   'they',
#   'ask',
#   'top',
#   '.',
#   'moment',
#   'top',
#   'is',
#   'given',
#   ',',
#   'money',
#   'is',
#   'siphoned',
#   'off',
#   'radar',
#   'linked',
#   'bank',
#   'account',
#   '.'],
#  ['do',
#   'not',
#   'share',
#   'aadhaar',
#   'card',
#   ',',
#   'banks',
#   ',',
#   'debit',
#   '/',
#   'credit',
#   'card',
#   ',',
#   'top',
#   ',',
#   'address',
#   ',',
#   'pan',
#   'card',
#   'details',
#   'phone',
#   '/',
#   'email',
#   '/',
#   'whatsapp',
#   'do',
#   'not',
#   'pay',
#   'money',
#   'anyone',
#   'registration',
#   'couid',
#   'vaccine',
#   '.',
#   'your',
#   'local',
#   'government',
#   'will',
#   'inform',
#   'you',
#   'procedure',
#   '-',
#   'silver',
#   'innings'],
#  ['new',
#   'couid',
#   '-',
#   'nineteen',
#   'strain',
#   'reaches',
#   'india',
#   ':',
#   'does',
#   'it',
#   'spread',
#   'easily',
#   'vaccines',
#   'will',
#   'not',
#   'work',
#   'here',
#   'are',
#   'all',
#   'your',
#   'questions',
#   'answered'],
#  ['new',
#   'couid',
#   '-',
#   'nineteen',
#   'strain',
#   'reaches',
#   'india',
#   ':',
#   'does',
#   'it',
#   'spread',
#   'easily',
#   'vaccines',
#   'won',
#   'i',
#   'i',
#   'work',
#   'here',
#   'are',
#   'all',
#   'your',
#   'questions',
#   'answered'],
#  ['big',
#   'task',
#   'ahead',
#   'india',
#   '.',
#   'couid',
#   '-',
#   'nineteen',
#   'hasn',
#   'i',
#   'i',
#   'ended',
#   'yet',
#   '.',
#   'it',
#   'is',
#   'getting',
#   'stronger',
#   'we',
#   'need',
#   'combat',
#   'it',
#   '.',
#   'wear',
#   'your',
#   'mask',
#   '.',
#   'face_with_medical_mask',
#   'wash',
#   'your',
#   'hands',
#   '.',
#   'all',
#   'hopes',
#   'couid',
#   'vaccine',
#   '.',
#   'crossed_fingerslight_skin_tone'],
#  ['couid',
#   'vaccine',
#   'has',
#   'been',
#   'used',
#   'by',
#   'more',
#   'than',
#   'twenty-three',
#   'million',
#   'people',
#   'worldwide',
#   '.',
#   'when',
#   'will',
#   'india',
#   'use',
#   'can',
#   'person',
#   'who',
#   'told',
#   'me',
#   'hit',
#   'plates',
#   ',',
#   'flower',
#   'light',
#   'fire',
#   'say',
#   'something'],
#  ['important',
#   'mug',
#   'backhand_index_pointing_downfolded_handsbackhand_index_pointing_down',
#   'fraudsters',
#   'are',
#   'calling',
#   'asking',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'registration',
#   '.',
#   'they',
#   'ask',
#   'radar',
#   ',',
#   'email',
#   'id',
#   'etc',
#   '.',
#   'subsequently',
#   ',',
#   'authenticate',
#   'radar',
#   ',',
#   'they',
#   'ask',
#   'top',
#   '.',
#   'moment',
#   'top',
#   'is',
#   'given',
#   ',',
#   'money',
#   'is',
#   'siphoned',
#   'off',
#   'radar',
#   'linked',
#   'bank',
#   'account',
#   '.'],
#  ['whatsapp',
#   'backhand_index_pointing_rightlight_skin_tone',
#   'beware',
#   'new',
#   'way',
#   'cyber',
#   'crime',
#   '.',
#   'fraudsters',
#   'are',
#   'calling',
#   'asking',
#   'couid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'registration',
#   '.',
#   'they',
#   'ask',
#   'radar',
#   ',',
#   'email',
#   'id',
#   'etc',
#   '.',
#   'then',
#   'authenticate',
#   'radar',
#   ',',
#   'they',
#   'ask',
#   'top',
#   '.',
#   'once',
#   'top',
#   'is',
#   'given',
#   ',',
#   'money',
#   'is',
#   'siphoned',
#   'off',
#   'radar',
#   'linked',
#   'bank',
#   'account',
#   '.'],
#  ['we',
#   'had',
#   'ask',
#   'people',
#   'confirmed',
#   'with',
#   'couid',
#   'india',
#   'yesterday',
#   '.',
#   'with',
#   'sixty',
#   '%',
#   'coverage',
#   'population',
#   'with',
#   'ninety-five',
#   '%',
#   'effective',
#   'vaccine',
#   'this',
#   'number',
#   'would',
#   'have',
#   'been',
#   'seven hundred and fifty',
#   '.',
#   'deaths',
#   'we',
#   'are',
#   'four hundred',
#   'they',
#   'will',
#   'now',
#   'be',
#   'down',
#   'less',
#   'than',
#   'ten',
#   '.'],
#  ...]

# %%
convert_to_str = []

for each in tokenised_spellchecked:
    converted_str = ""
    for i in range(0,len(each)):
        if i == (len(each) - 1):
            converted_str += each[i]
        else:
            converted_str += each[i] + ", "
    convert_to_str.append(converted_str)
    
converted_df = pd.DataFrame(convert_to_str)

converted_df.to_csv('corrected-38k-41k.csv')
