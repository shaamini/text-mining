# %%
import pandas as pd

# %%
first = pd.read_csv("1-corrected-19000-22000.csv")
first.drop(columns = "Unnamed: 0", inplace = True)

# %%
first
# Out:
#                                                       0
# 0     well, this, is, no, surprise, ,, i, spoke, abo...
# 1                    fans, about, #, couid, #, vaccines
# 2     four, dose, vaccine, against, couid, thanks, d...
# 3     india, ', i, fight, against, couid, -, ninetee...
# 4     #, justjoking, #, couid, #, precautiondose, is...
# ...                                                 ...
# 2995  pfizer, data, suggests, third, dose, couid, -,...
# 2996  smiling_face_with_heart, -, eyes, took, a, sin...
# 2997  there, is, no, plan, introduce, #, vaccine, pa...
# 2998  #, nocaptionneeded, ..., red_circle, blue_circ...
# 2999  I, am, at, hah, couid, -, nineteen, vaccine, c...
#
# [3000 rows x 1 columns]

# %%
second = pd.read_csv("2-corrected-22000-25000.csv")
second.drop(columns = "Unnamed: 0", inplace = True)
second
# Out:
#                                                       0
# 0     vaccinated, rainbow, #, vaccinated, #, covidva...
# 1     very, unfortunate, situation, ., following, st...
# 2     statement, by, stating, all, australians, can,...
# 3     true, dat, ., but, also, chances, that, many, ...
# 4     before, :, couid, -, nineteen, vaccines, got, ...
# ...                                                 ...
# 2995  now, reportedly, more, than, five hundred, dos...
# 2996  i, hope, am, gives, update, #, vaccine, procur...
# 2997  I, have, taken, first, dose, couid, -, ninetee...
# 2998  doctors, duty, &, amp, ;, #, couid, patients, ...
# 2999  infectious, diseases, expert, david, lye, call...
#
# [3000 rows x 1 columns]

# %%
third = pd.read_csv("3-corrected-25000-28000.csv")
third.drop(columns = "Unnamed: 0", inplace = True)
third
# Out:
#                                                       0
# 0     took, my, est, dose, couid, nineteen, vaccine,...
# 1     You, can, get, the, vaccine, by, booking, a, s...
# 2     I, am, keep, trying, get, appointment, couid, ...
# 3     he, old, i, get, couid, vaccine, if, my, age, ...
# 4     good, initiative, people, who, are, not, takin...
# ...                                                 ...
# 2995  same, tweets, against, false, propaganda, agai...
# 2996  waiving, patents, couid, vaccines, will, not, ...
# 2997  ", many, scientists, now, believe, couid, -, n...
# 2998  mix, match, couid, vaccine, study, finds, incr...
# 2999  I, am, soo, into, couid, news, these, days, th...
#
# [3000 rows x 1 columns]

# %%
fourth = pd.read_csv("4-corrected-28000-31000.csv")
fourth.drop(columns = "Unnamed: 0", inplace = True)
fourth
# Out:
#                                                       0
# 0     cac, says, twenty-eight, blood, clot, cases, ,...
# 1     biden, urges, parents, get, kids, vaccinated, ...
# 2     u, ., i, ., cac, panel, backs, couid, -, ninet...
# 3     cac, panel, endorses, pfizer, ', i, couid, vac...
# 4     we, should, train, amazon, delivery, guys, giv...
# ...                                                 ...
# 2995  no, couid, so, far, ., taken, first, dose, vac...
# 2996  petition, :, say, ', no, ', couid, ', vaccine,...
# 2997  #, covid19india, #, covidvaccine, #, berojgar_...
# 2998  no, ..., for, fact, ...., it, is, rags, own, t...
# 2999  india, will, remember, how, allowed, rumba, me...
#
# [3000 rows x 1 columns]

# %%
fifth = pd.read_csv("5-corrected-31000-34000.csv")
fifth.drop(columns = "Unnamed: 0", inplace = True)
fifth
# Out:
#                                                       0
# 0     here, you, go, please, stop, spreading, false,...
# 1     not, vaccine, ,, this, is, medicine, couid, .,...
# 2     sir, i, am, willing, donate, blood, before, ta...
# 3     newswatch, :, cac, committee, meet, i, &, amp,...
# 4     doctor, cac, advisory, panel, expects, i, &, a...
# ...                                                 ...
# 2995  who, was, earlier, snapped, arriving, at, lila...
# 2996  Use, #, covidvaccine, #, corona, wilted_flower...
# 2997  given, harsh, socio, -, political, ecosystem, ...
# 2998  blocked, &, amp, ;, bruised, chickies, ., effi...
# 2999  eu, will, tighten, restrictions, couid, vaccin...
#
# [3000 rows x 1 columns]

# %%
sixth = pd.read_csv("6-corrected-34000-38000.csv")
sixth.drop(columns = "Unnamed: 0", inplace = True)
sixth
# Out:
#                                                       0
# 0     selangor, journal, |, astrazeneca, couid, -, n...
# 1     couid, -, nineteen, vaccine, form, pill, is, s...
# 2     good, vaccinate, ., better, vaccine, all, fron...
# 3     sir, please, grant, permission, couid, vaccine...
# 4     health, authorities, have, been, urged, increa...
# ...                                                 ...
# 3995  i, am, afraid, that, infection, will, not, spr...
# 3996  wait, is, now, over, :, delhi, ,, gujaratis, ,...
# 3997  i, think, ,, modi, ji, i, pass, disbar, twenty...
# 3998  first, #, consignment, #, couid, -, nineteen, ...
# 3999  very, good, news, assay, finally, couid, vacci...
#
# [4000 rows x 1 columns]

# %%
frames = [first, second, third, fourth, fifth, sixth]
result = pd.concat(frames)
result
# Out:
#                                                       0
# 0     well, this, is, no, surprise, ,, i, spoke, abo...
# 1                    fans, about, #, couid, #, vaccines
# 2     four, dose, vaccine, against, couid, thanks, d...
# 3     india, ', i, fight, against, couid, -, ninetee...
# 4     #, justjoking, #, couid, #, precautiondose, is...
# ...                                                 ...
# 3995  i, am, afraid, that, infection, will, not, spr...
# 3996  wait, is, now, over, :, delhi, ,, gujaratis, ,...
# 3997  i, think, ,, modi, ji, i, pass, disbar, twenty...
# 3998  first, #, consignment, #, couid, -, nineteen, ...
# 3999  very, good, news, assay, finally, couid, vacci...
#
# [19000 rows x 1 columns]

# %%
result.to_csv('india-corrected-19000-38000.csv', index=False)

# %%
import os
import pandas as pd

masterdf = pd.DataFrame()

for file in os.listdir(os.getcwd()):
    if file.endswith('.csv'):
        masterdf = masterdf.append(pd.read_csv(file))

masterdf.to_csv('india-corrected-19000-38000.csv', index=False)

# %%
df = pd.read_csv("india-corrected-19000-38000.csv")
df.head()
# Out:
#    Unnamed: 0                                                  0
# 0           0  cac, says, twenty-eight, blood, clot, cases, ,...
# 1           1  biden, urges, parents, get, kids, vaccinated, ...
# 2           2  u, ., i, ., cac, panel, backs, couid, -, ninet...
# 3           3  cac, panel, endorses, pfizer, ', i, couid, vac...
# 4           4  we, should, train, amazon, delivery, guys, giv...

# %%
df
# Out:
#        Unnamed: 0                                                  0
# 0               0  cac, says, twenty-eight, blood, clot, cases, ,...
# 1               1  biden, urges, parents, get, kids, vaccinated, ...
# 2               2  u, ., i, ., cac, panel, backs, couid, -, ninet...
# 3               3  cac, panel, endorses, pfizer, ', i, couid, vac...
# 4               4  we, should, train, amazon, delivery, guys, giv...
# ...           ...                                                ...
# 18995        2995  now, reportedly, more, than, five hundred, dos...
# 18996        2996  i, hope, am, gives, update, #, vaccine, procur...
# 18997        2997  I, have, taken, first, dose, couid, -, ninetee...
# 18998        2998  doctors, duty, &, amp, ;, #, couid, patients, ...
# 18999        2999  infectious, diseases, expert, david, lye, call...
#
# [19000 rows x 2 columns]

# %%
df.describe()
# Out:
#            review_id
# count  224819.000000
# mean    40249.121827
# std     23157.562754
# min         0.000000
# 25%     20225.500000
# 50%     40359.000000
# 75%     59894.500000
# max     81040.000000

# %%
df['subcategory'].value_counts()
# Out:
# meat                         71818
# chocolate                    33753
# cheese                       28892
# mylk                         21899
# ice cream                    20565
# yogurt                       15879
# moisturizers                 10278
# cleansers, scrubs & masks     9446
# seafood                       5129
# eggs                          3747
# face                          3413
# Name: subcategory, dtype: int64

# %%
sample_df = df.sample(n = 75000, random_state = 99)

# %%
sample_df
# Out:
#         review_id     brand_category                          category  \
# 196075      72217               food  alternative eggs, meat & seafood
# 20850       15382               food                            frozen
# 211824      78104               food  alternative eggs, meat & seafood
# 173395      63562               food                dairy alternatives
# 65844       29844               food                            snacks
# ...           ...                ...                               ...
# 165600      60788               food  alternative eggs, meat & seafood
# 107650      42579  health and beauty                   body & skincare
# 222896      80294               food                dairy alternatives
# 5556        10006               food                            snacks
# 120710      47215               food                dairy alternatives
#
#          subcategory                                               text  \
# ...

# %%
sample_df['subcategory'].value_counts()
# Out:
# meat                         23938
# chocolate                    11175
# cheese                        9631
# mylk                          7316
# ice cream                     6932
# yogurt                        5262
# moisturizers                  3443
# cleansers, scrubs & masks     3111
# seafood                       1760
# eggs                          1270
# face                          1162
# Name: subcategory, dtype: int64

# %%
sample_df.to_csv('sentences_sample_data.csv', index = False)
