# %%
import pandas as pd

# %%
df = pd.read_csv("india_hashtags.csv")

# %%
df.drop(columns="Unnamed: 0", inplace = True)

# %%
df
# Out:
#                            0
# 0             #stopthespread
# 1                       #rct
# 2                   #covidnc
# 3          #bengalurublogger
# 4                #actorvivek
# ...                      ...
# 11431               #mustafa
# 11432                #baroda
# 11433         #happyholi2021
# 11434   #covidganeshfestival
# 11435  #boosterdosealladults
#
# [11436 rows x 1 columns]

# %%
df2 = pd.read_csv("usa_hashtags.csv")

# %%
df2.drop(columns="Unnamed: 0", inplace = True)

# %%
df2
# Out:
#                                   0
# 0      #oposicionmiserableymezquina
# 1                    #moralmonsters
# 2                         #headline
# 3                             #year
# 4                       #pittsburgh
# ...                             ...
# 27835                 #pandemiclife
# 27836                  #neverforget
# 27837                 #newyorktough
# 27838                    #2021goals
# 27839                  #staydistant
#
# [27840 rows x 1 columns]

# %%
frames = [df, df2]

result = pd.concat(frames)

# %%
result
# Out:
#                        0
# 0         #stopthespread
# 1                   #rct
# 2               #covidnc
# 3      #bengalurublogger
# 4            #actorvivek
# ...                  ...
# 27835      #pandemiclife
# 27836       #neverforget
# 27837      #newyorktough
# 27838         #2021goals
# 27839       #staydistant
#
# [39276 rows x 1 columns]

# %%
result.drop_duplicates(subset=['0'],keep=False,inplace=True)

# %%
result
# Out:
#                               0
# 1                          #rct
# 2                      #covidnc
# 3             #bengalurublogger
# 4                   #actorvivek
# 5                   #patralekha
# ...                         ...
# 27834  #imaginarytrackingdevice
# 27836              #neverforget
# 27837             #newyorktough
# 27838                #2021goals
# 27839              #staydistant
#
# [34972 rows x 1 columns]

# %%
result.to_csv('hashtags.csv')

# %%
df_list = []

for row in df['Text']:
    df_list.append(row)

# %%
df_list
# Out:
# ['soniya mummy hoti toh covid me magic stick ghuma ke death kam kar deti... aur rahul baba apne hanto se taiyar karke sabko vaccination deta',
#  '#pickids : about 20,000 children perlis eligible covid-19 vaccination',
#  'previous covid-19 infection – but not vaccination – improves performance antibodies -',
#  'india’s covid-19 vaccination coverage crosses 171.73 cr mark',
#  'i got call office principal commissioner cgst lucknow,it ascertained status covid vaccination doses by me,all doses booster is taken by me,thanks regards pr commissioner cgst lucknow,',
#  'i have booked flight 13 feb, 2022 toronto new delhi departure time 1155 est please do let me know that as per new guidelines that have come today, is covid-19 test still necessary or i can upload my vaccination certificate only travel',
#  'covid-19 vaccination drive: around 172 crore covid vaccine doses administered india, says govt',
# ...

# %%
len(df_list)
# Out:
# 105992

# %%
cleaned_list = list( dict.fromkeys(df_list) )
print(len(cleaned_list))
# Out:
# 95190

# %%
new_df = pd.DataFrame({'Text':cleaned_list})
new_df.to_csv("../data/USA/usa_antivax.csv", index = False)

# %%
df2 = pd.read_csv("../data/usa_combined.csv")

# %%
df_list2 = []

for row in df2['Text']:
    df_list2.append(row)

# %%
len(df_list2)
# Out:
# 423595

# %%
cleaned_list2 = list( dict.fromkeys(df_list2) )
print(len(cleaned_list2))
# Out:
# 404337

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df
# Out:
#      brand style  rating
# 0  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0
