# %%
# !pip install emot
# !pip install symspellpy
# !pip install setuptools wheel
# !pip install spacy
# !pip install pyspellchecker
# !pip install spellchecker
# !pip install inflect
# !pip install langdetect
# !pip install google_trans_new
# !pip install deep-translator
# !pip install ekphrasis
# !pip install cdifflib
# !pip install gensim
# !pip install wordninja

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
import re, string, json

from symspellpy.symspellpy import SymSpell, Verbosity
import pkg_resources
import spacy
from tqdm.notebook import tqdm
from spellchecker import SpellChecker
import inflect

import difflib
import gensim

import pandas as pd

# %%
df = pd.read_csv("../data/usa_combined.csv")
df
# Out:
#                                                      Text
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       juste se rappeler m. leblanc la pression que l...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 423590           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 423591  got my first pfizer shot today. feeling well g...
# 423592  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 423593  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 423594  we all have do our part end this pandemic— get...
#
# [423595 rows x 1 columns]

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df
# Out:
#                                                      Text
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       juste se rappeler m. leblanc la pression que l...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 423588  if you are eligible, please pre- register covi...
# 423590           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 423592  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 423593  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 423594  we all have do our part end this pandemic— get...
#
# [404337 rows x 1 columns]

# %% [markdown]
# ## Used hashtags

# %%
text = df['Text']
hashtag_list = []
for tweet in text:
#     print(tweet)
    hashtags = re.findall("#[A-Za-z0-9_]+", tweet)
    if len(hashtags) > 0:
        for tag in hashtags:
            hashtag_list.append(tag)

# %%
hashtag_list
# Out:
# ['#covidvaccineconfidence',
#  '#vanguardvaccinationproject',
#  '#populationcontrol',
#  '#omicron',
#  '#vaccination',
#  '#mentalhealth',
#  '#psychtwitter',
#  '#cdnpoli',
#  '#onpoli',
#  '#covid19',
#  '#l',
#  '#polqc',
#  '#getvaccinated',
#  '#vaccineswork',
#  '#canada',
#  '#superbowlmusicfest',
#  '#socal',
#  '#superbowlexperience',
#  '#sblvi',
#  '#hiringphenomenaltalent',
#  '#security',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#legaultmustresign',
#  '#legault',
#  '#covid19',
#  '#localnews',
#  '#newsbreak',
#  '#covid',
#  '#defundcbc',
#  '#defundbbc',
#  '#nyc',
#  '#godblessamerica',
#  '#nonads',
#  '#votehelenkicknadlerny10',
#  '#dyk',
#  '#fightflu',
#  '#heartmonth',
#  '#nowplaying',
#  '#nowspinning',
#  '#np',
#  '#nowstreaming',
#  '#subgenius',
#  '#joerogan',
#  '#antivaxxers',
#  '#covidab',
#  '#covid19',
#  '#repnotrip',
#  '#ableg',
#  '#ciuss_mcq',
#  '#covid19',
#  '#ambulance',
#  '#inacceptable',
#  '#k',
#  '#jdq',
#  '#covid19',
#  '#mybodymychoice',
#  '#rosiebartonappreciationday',
#  '#ohio',
#  '#abpoli',
#  '#covid19ab',
#  '#thankyoukyrie',
#  '#indonesia',
#  '#covid19',
#  '#sblvi',
#  '#world',
#  '#kingstonmines',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#bcpoli',
#  '#covid19',
#  '#brightonco',
#  '#covid19',
#  '#cdnpoli',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#abpoli',
#  '#ableg',
#  '#abhealth',
#  '#maskshelp',
#  '#clownvoy',
#  '#covid19',
#  '#vaccine',
#  '#vaccinated',
#  '#vaccination',
#  '#covid',
#  '#edafeokporo',
#  '#blackhistorymonth',
#  '#rosiebartonappreciationday',
#  '#covid19',
#  '#polqc',
#  '#earthlings',
#  '#thankful',
#  '#fullyvaxxed',
#  '#msriverproject',
#  '#swag',
#  '#antivaxers',
#  '#joerogan',
#  '#subgenius',
#  '#covid19vaccine',
#  '#vhcon',
#  '#teamtoronto',
#  '#cityofto',
#  '#covid19',
#  '#vaccination',
#  '#publichealth',
#  '#weyburn',
#  '#polcan',
#  '#biometrics',
#  '#healthcare',
#  '#data',
#  '#vaccination',
#  '#privacy',
#  '#privacy',
#  '#vaccination',
#  '#vaccinemandates',
#  '#vaccinated',
#  '#data',
#  '#coronavirus',
#  '#vaccine',
#  '#vaccination',
#  '#pandemic',
#  '#buckscounty',
#  '#buckscountynews',
#  '#pennsylvania',
#  '#doh',
#  '#covid19news',
#  '#covidupdate',
#  '#nyctestandtrace',
#  '#covid19',
#  '#covid19',
#  '#covidvaccineboosters',
#  '#covidtesting',
#  '#sjcountyclinics',
#  '#visionaryhomebuilders_ca',
#  '#lesswrong',
#  '#covid19',
#  '#queensu',
#  '#camden',
#  '#covid19',
#  '#covid19vaccine',
#  '#vhcon',
#  '#covid19vaccine',
#  '#vhcon',
#  '#maskmandate',
#  '#nyc',
#  '#covid19',
#  '#asksavanity',
#  '#uftny',
#  '#2',
#  '#cdc',
#  '#vaccination',
#  '#endthemandates',
#  '#picphysicians',
#  '#informedconsent',
#  '#1stdonoharm',
#  '#vaccines',
#  '#vaccination',
#  '#physicians4informedconsent',
#  '#science',
#  '#statistics',
#  '#texas',
#  '#mediafreeamerica',
#  '#vaxupcuny',
#  '#vaccination',
#  '#covid',
#  '#jasonkenney',
#  '#covid19',
#  '#newyork',
#  '#vaccination',
#  '#mask',
#  '#illinois',
#  '#maskmandate',
#  '#covid19',
#  '#covidrestrictions',
#  '#daytonabeachpoker',
#  '#washtimesoped',
#  '#tga',
#  '#pfizer',
#  '#cpacpoli',
#  '#commonsense',
#  '#vaxupphilly',
#  '#cdnmedia',
#  '#cdnpoli',
#  '#justiceforcolten',
#  '#coronavirus',
#  '#skpoli',
#  '#cdnpoli',
#  '#deeperissues',
#  '#endmandatesnow',
#  '#vaccination',
#  '#covidvaccine',
#  '#covid19',
#  '#houston',
#  '#covid19',
#  '#hounews',
#  '#covid19',
#  '#vaccination',
#  '#downtownwindsor',
#  '#windsorontario',
#  '#yqg',
#  '#urgencyofequity',
#  '#covid19',
#  '#veterans',
#  '#seattlemedium',
#  '#castro',
#  '#cheguevara',
#  '#rino',
#  '#rinosalazar',
#  '#healthyelon',
#  '#myocarditis',
#  '#truckerconvoy',
#  '#vaxup',
#  '#maskup',
#  '#firetheucp',
#  '#gostanford',
#  '#covid',
#  '#vaccination',
#  '#delta',
#  '#essexfellsnj',
#  '#truckersconvoy',
#  '#freedomconvoycanada2022',
#  '#endthemandatesnow',
#  '#truckersforfreedom2020',
#  '#trudeaumustresign',
#  '#trudeaunationaldisgrace',
#  '#endmandates',
#  '#wpunj',
#  '#covid19',
#  '#cdnpoli',
#  '#covid19',
#  '#covid19',
#  '#medicine',
#  '#markmywords',
#  '#cdnpoli',
#  '#onpoli',
#  '#nfl',
#  '#walgreens',
#  '#vaccination',
#  '#superbowl',
#  '#nflalumnihealth',
#  '#trudeauhasgottogo',
#  '#trudeaumustresign',
#  '#gojohnnies',
#  '#covid19',
#  '#utpol',
#  '#utah',
#  '#covid19',
#  '#atthecoreofcare',
#  '#covid19',
#  '#covid19',
#  '#freedumbconvoy',
#  '#covid19',
#  '#ststephen',
#  '#chile',
#  '#covid',
#  '#aldianews',
#  '#getvaxxed',
#  '#utsa',
#  '#doyourpart',
#  '#denmark',
#  '#arts',
#  '#artsnews',
#  '#8217',
#  '#cdnpoli',
#  '#covid19',
#  '#toronto',
#  '#masks',
#  '#socialdistancing',
#  '#vaccination',
#  '#vaccinated',
#  '#vaccine',
#  '#vaccination',
#  '#coronavirus',
#  '#vaccinezvous',
#  '#vaccin',
#  '#vaccin',
#  '#vaccinationobligatoire',
#  '#vaccination',
#  '#vaccinatieschade',
#  '#vaccinezvousbordel',
#  '#covid19',
#  '#covid_19',
#  '#covid',
#  '#cdnpolitics',
#  '#cdnpoli',
#  '#fyi',
#  '#news',
#  '#feedly',
#  '#lockhimup',
#  '#ldnont',
#  '#lockhimup',
#  '#ableg',
#  '#abpoli',
#  '#alberta',
#  '#vaers',
#  '#flylgb',
#  '#news',
#  '#election2020',
#  '#airsuvidha',
#  '#califonia',
#  '#onevaxtwolives',
#  '#covid19',
#  '#pushforthevaccine',
#  '#getvaccinated',
#  '#netsareunfair',
#  '#cdnpoli',
#  '#ny21',
#  '#jazz',
#  '#calgary',
#  '#masks',
#  '#vaccination',
#  '#stemeducation',
#  '#covid19',
#  '#occovid19',
#  '#othena',
#  '#thisisourshot',
#  '#ableg',
#  '#abpoli',
#  '#abpse',
#  '#masks',
#  '#mandates',
#  '#tennessee',
#  '#tnleg',
#  '#gopcoup',
#  '#masks',
#  '#vaccination',
#  '#covid19',
#  '#adulting',
#  '#responsibilities',
#  '#studentloans',
#  '#canada',
#  '#qu',
#  '#covid',
#  '#volunteers',
#  '#cannedgoods',
#  '#vaccine',
#  '#trucker',
#  '#ottawa',
#  '#hcm',
#  '#solution',
#  '#covid19',
#  '#automation',
#  '#coronavirus',
#  '#vaccination',
#  '#wakeup',
#  '#covid19',
#  '#teamniagara',
#  '#saveourkids',
#  '#vaccination',
#  '#parents',
#  '#covid19',
#  '#kids',
#  '#novaccinemandate',
#  '#covidsummit',
#  '#ridehigh',
#  '#ridetogether',
#  '#bettzedekgala2022',
#  '#bettzedek',
#  '#vaccination',
#  '#crackpipe',
#  '#healthinsurance',
#  '#covid',
#  '#americans',
#  '#covidvaccine',
#  '#covid19',
#  '#medhat',
#  '#covid19ab',
#  '#conception',
#  '#standwiththecoaches',
#  '#covid19',
#  '#tonga',
#  '#covid19',
#  '#outbreak',
#  '#vaccination',
#  '#98',
#  '#ri',
#  '#rhodeisland',
#  '#ripoli',
#  '#rhodyreport',
#  '#truckers',
#  '#trudeau',
#  '#ems',
#  '#covid19',
#  '#mno',
#  '#unvaccinated',
#  '#freedom',
#  '#endthemandates',
#  '#covid19',
#  '#3',
#  '#covid19',
#  '#ausummit',
#  '#covid19',
#  '#vaccination',
#  '#timbitterrorists',
#  '#ottawa',
#  '#ottawaoccupied',
#  '#convoidelahonte',
#  '#mbpoli',
#  '#covid19mb',
#  '#amarillo',
#  '#coronavirus',
#  '#protest',
#  '#world',
#  '#inquiringminds',
#  '#covid19',
#  '#nchealth',
#  '#ncpol',
#  '#covid19',
#  '#maskmandates',
#  '#hospitalizations',
#  '#deaths',
#  '#infections',
#  '#children',
#  '#vaccination',
#  '#parents',
#  '#teachers',
#  '#mandates',
#  '#responsibility',
#  '#vaccinate',
#  '#newbedford',
#  '#trustthefacts',
#  '#getthevax',
#  '#csu',
#  '#covid19',
#  '#sciencecommunication',
#  '#covid',
#  '#covidvaccine',
#  '#abpse',
#  '#ableg',
#  '#covid19',
#  '#covid19sk',
#  '#tuproposesquoiduhaime',
#  '#sarscov2',
#  '#tcellimmuneresponses',
#  '#omicron',
#  '#boostervaccines',
#  '#informyourchoice',
#  '#medtrademonday',
#  '#covid19',
#  '#vaccination',
#  '#dme',
#  '#hme',
#  '#freetraining',
#  '#covid',
#  '#yqr',
#  '#sk',
#  '#internetpluss',
#  '#vaccinated',
#  '#covid19',
#  '#vaccination',
#  '#restrictions',
#  '#pand',
#  '#togo',
#  '#news',
#  '#abhealth',
#  '#covid19ab',
#  '#cdnpoli',
#  '#covid19',
#  '#canada',
#  '#covid19',
#  '#covid19sk',
#  '#saskatchewan',
#  '#covid19',
#  '#truckersforfreedom2022',
#  '#honkhonk',
#  '#freedomconvoy',
#  '#sask',
#  '#covid19',
#  '#pregnancy',
#  '#srsu',
#  '#yegcc',
#  '#covid19qc',
#  '#novaxdjocovid',
#  '#hwdd22',
#  '#covid19france',
#  '#vaccination',
#  '#dhswi',
#  '#yql',
#  '#yqlcc',
#  '#tonga',
#  '#first',
#  '#covid',
#  '#98',
#  '#arstechnica',
#  '#covid',
#  '#vaxcard',
#  '#test',
#  '#mandate',
#  '#restaurants',
#  '#omicronvarient',
#  '#umboosted',
#  '#umboosted',
#  '#umflint',
#  '#sgumflint',
#  '#goblue',
#  '#vaccination',
#  '#vaccinationclinic',
#  '#booster',
#  '#boosterclinic',
#  '#covid',
#  '#southafrica',
#  '#superbowl',
#  '#nflasocal',
#  '#nflalumnihealth',
#  '#community',
#  '#vaccination',
#  '#nfl',
#  '#inglewood',
#  '#ldnont',
#  '#sasked',
#  '#covid19',
#  '#maskup',
#  '#vaxupnova',
#  '#classwarfare',
#  '#aacon2022',
#  '#truckersconvoy',
#  '#blackdehem22',
#  '#staystrongdc',
#  '#endallmandates',
#  '#trudeaumustresign',
#  '#canpoli',
#  '#honkhonk',
#  '#democrats',
#  '#uspolitics',
#  '#naturalimmunity',
#  '#cdnpoli',
#  '#booster',
#  '#zerflin',
#  '#covid19',
#  '#india',
#  '#covid',
#  '#vaccination',
#  '#covid19',
#  '#kippmemphis',
#  '#staysafe',
#  '#getvaxxed',
#  '#covidvaccine',
#  '#covid19',
#  '#covidvaccine',
#  '#covid',
#  '#vaccineswork',
#  '#getvaccinated',
#  '#caq',
#  '#polqc',
#  '#assnat',
#  '#govlove',
#  '#breaking',
#  '#covid19',
#  '#blues',
#  '#chicagoblues',
#  '#liveblues',
#  '#livemusic',
#  '#shopsmall',
#  '#choosechicago',
#  '#latenightkitchen',
#  '#covid19',
#  '#vaccineswork',
#  '#hypocrisy',
#  '#abortionishealthcare',
#  '#hollywood',
#  '#hypocrisy',
#  '#hypocrites',
#  '#covidontario',
#  '#vaccination',
#  '#covid19',
#  '#vaccinepassort',
#  '#coronavirus',
#  '#onpoli',
#  '#snrtg',
#  '#covid19',
#  '#pivot',
#  '#covid19',
#  '#nurses',
#  '#covid19',
#  '#vaccination',
#  '#notlogical',
#  '#tcell',
#  '#sarscov2',
#  '#icymi',
#  '#accessible',
#  '#blackhistorymonth',
#  '#bhm',
#  '#primarycare',
#  '#covid19',
#  '#vaccination',
#  '#vaccines',
#  '#vaccination',
#  '#throwbackthursday',
#  '#nflalumnihealth',
#  '#cervicalcancer',
#  '#cancer',
#  '#screening',
#  '#vaccination',
#  '#freedomconvoycanada2022',
#  '#truckersconvoy',
#  '#vaccination',
#  '#ottawa',
#  '#getvaccinatedandboosted',
#  '#physicians4informedconsent',
#  '#1stdonoharm',
#  '#vaccines',
#  '#vaccination',
#  '#informedconsent',
#  '#science',
#  '#statistics',
#  '#covid19',
#  '#vaccination',
#  '#covid19',
#  '#vaccinatepasadena',
#  '#vacunacion',
#  '#vaccination',
#  '#coronavirus',
#  '#covid19',
#  '#stgeorge',
#  '#covid19',
#  '#vaccination',
#  '#strongertogether',
#  '#strong',
#  '#hope',
#  '#canada',
#  '#ottawa',
#  '#ottawaoccupied',
#  '#ottawaconvoy',
#  '#covid19',
#  '#omicron',
#  '#vaccination',
#  '#covid19',
#  '#netde',
#  '#coronavirus',
#  '#quarantine',
#  '#india',
#  '#canada',
#  '#pcrtest',
#  '#vaccination',
#  '#airsuvidha',
#  '#vaccination',
#  '#free',
#  '#webinar',
#  '#njbusiness',
#  '#businesstips',
#  '#rally',
#  '#antivaxxers',
#  '#protesters',
#  '#windsorblockade',
#  '#medicareforall',
#  '#vaccinatingsomerset',
#  '#everyvaccinematters',
#  '#beyondtheguidelines',
#  '#ruralhealth',
#  '#didyouknow',
#  '#residentdoctorappreciation2022',
#  '#macresidentsrock',
#  '#scotus',
#  '#capi',
#  '#covid19',
#  '#scgcon',
#  '#covid19',
#  '#vaccination',
#  '#canada',
#  '#canadian',
#  '#vaccination',
#  '#unvaccinated',
#  '#vaccineswork',
#  '#placebo',
#  '#cdc',
#  '#allopathetic',
#  '#drugs',
#  '#doesyourdoctordriveateslaorchangedigitalscriptstosavetrees',
#  '#hospital',
#  '#vaccines',
#  '#vaccination',
#  '#vaccine',
#  '#nurse',
#  '#hamont',
#  '#joescrackheads',
#  '#vaccination',
#  '#crackpipe',
#  '#covid_19',
#  '#maroc',
#  '#vaccination',
#  '#maskssavelives',
#  '#vaccineswork',
#  '#getvaccinated',
#  '#getvaccinatednow',
#  '#getvaccinatedandboosted',
#  '#getvaxxed',
#  '#wearamask',
#  '#maskup',
#  '#covid19',
#  '#bamako',
#  '#vaccination',
#  '#covid19',
#  '#darwin',
#  '#vaccineswork',
#  '#vaccine',
#  '#science',
#  '#god',
#  '#allopathetic',
#  '#hospital',
#  '#drugs',
#  '#money',
#  '#health',
#  '#cdc',
#  '#covid19',
#  '#vaccination',
#  '#drugs',
#  '#medicine',
#  '#doctor',
#  '#omicron',
#  '#vaccine',
#  '#california',
#  '#nomaskmandates',
#  '#cdc',
#  '#vaccination',
#  '#covid19',
#  '#vaccines',
#  '#vaccineswork',
#  '#hospitals',
#  '#drugs',
#  '#money',
#  '#news',
#  '#vaccination',
#  '#vaccines',
#  '#canada',
#  '#endmandates',
#  '#mandatefreedom',
#  '#cdnpoli',
#  '#bcpoli',
#  '#nffc',
#  '#coyr',
#  '#forestallovertheworld',
#  '#blackfuturemonth',
#  '#blm',
#  '#covid19',
#  '#cove',
#  '#covid19',
#  '#vaccination',
#  '#hmelsahly',
#  '#fightflu',
#  '#heartmonth',
#  '#harmreduction',
#  '#cdc',
#  '#vaccineswork',
#  '#doctor',
#  '#nurses',
#  '#hospitals',
#  '#frontlineworkers',
#  '#covid',
#  '#vaccines',
#  '#vaccination',
#  '#vaccine',
#  '#rensa22',
#  '#1',
#  '#2',
#  '#3',
#  '#vaccination',
#  '#cdc',
#  '#virus',
#  '#vaccination',
#  '#vaccineswork',
#  '#vaccines',
#  '#covid19',
#  '#covid',
#  '#drugs',
#  '#interoperability',
#  '#healthcareit',
#  '#digitalhealth',
#  '#myocarditis',
#  '#pathologist',
#  '#hart',
#  '#covid19',
#  '#covidvaccine',
#  '#propaganda',
#  '#cdc',
#  '#covidiots',
#  '#covid19',
#  '#covid',
#  '#vaccination',
#  '#vaccine',
#  '#vaccines',
#  '#vaccinessavelives',
#  '#antivaxxer',
#  '#2',
#  '#1',
#  '#vaccination',
#  '#covidvaccines',
#  '#pregnancy',
#  '#vaccinedata',
#  '#vaccinesafety',
#  '#medicine',
#  '#cdnpoli',
#  '#icd10',
#  '#leominster',
#  '#trustthefacts',
#  '#getthevax',
#  '#covid19canada',
#  '#cdnhealth',
#  '#covid19',
#  '#covid19',
#  '#skpoli',
#  '#canada',
#  '#endthemandatesnow',
#  '#covid19',
#  '#vaccines',
#  '#primarycare',
#  '#publichealth',
#  '#medtwitter',
#  '#sanfrancisco',
#  '#mask',
#  '#vaccination',
#  '#omicron',
#  '#covid19',
#  '#globalhealth',
#  '#covid19ma',
#  '#theearlyedition',
#  '#thursdaymotivation',
#  '#hrsa',
#  '#covax',
#  '#covax',
#  '#breakcovid',
#  '#ibaabackinthesaddle',
#  '#wearelha',
#  '#andalequeesperas',
#  '#covidtesting',
#  '#covidvaccine',
#  '#covid19',
#  '#doitforthem',
#  '#uvso',
#  '#ambassadorbridge',
#  '#truckersforfreedom2020',
#  '#covaxin',
#  '#maskmandates',
#  '#bcpoli',
#  '#endthemandates',
#  '#bigpharma',
#  '#naturalhealth',
#  '#health',
#  '#homeopathy',
#  '#homeopathicmedicin',
#  '#naturalmedicine',
#  '#vaccines',
#  '#freecrackpipes',
#  '#bidenisalaughingstock',
#  '#trump2024tosaveamerica',
#  '#wearesouthern',
#  '#teamsu',
#  '#alabama',
#  '#covid19',
#  '#vaccination',
#  '#omicronvariant',
#  '#covidnyc',
#  '#coronavirusnyc',
#  '#covid',
#  '#coronavirus',
#  '#wecandothis',
#  '#minkwoncenter',
#  '#vaxoutreach',
#  '#icymi',
#  '#publichealthagencyofcanada',
#  '#vaccineforall',
#  '#worldofreasons',
#  '#themcc',
#  '#phac',
#  '#canada',
#  '#justgotmyshot',
#  '#polqc',
#  '#nosd',
#  '#covid19',
#  '#superbowl',
#  '#covid19',
#  '#covid19',
#  '#vaccine',
#  '#vaccination',
#  '#healthcare',
#  '#healthcarestaff',
#  '#cms',
#  '#omnibus',
#  '#skpoli',
#  '#hhr',
#  '#ltc',
#  '#ontario',
#  '#onlab',
#  '#mandatoryvaccination',
#  '#covid19',
#  '#followthemoney',
#  '#covid19',
#  '#corrupt',
#  '#coronavirus',
#  '#nyctestandtrace',
#  '#covid19',
#  '#wearecruise',
#  '#fightcorona',
#  '#covidsafety',
#  '#vaccination',
#  '#covid19',
#  '#niagara',
#  '#vaccination',
#  '#covid19',
#  '#covid19',
#  '#alhambrahighschool',
#  '#ahs',
#  '#biden',
#  '#federal',
#  '#covid',
#  '#vaccination',
#  '#covid19ab',
#  '#rep',
#  '#vaccination',
#  '#calgarychamber',
#  '#vaccines',
#  '#publichealth',
#  '#covid19',
#  '#vaccination',
#  '#flutruxklan',
#  '#covid19',
#  '#azerbaijan',
#  '#covid',
#  '#swagideas',
#  '#vaccinecardholder',
#  '#swagidea',
#  '#vaccinehesitancy',
#  '#canvaxres',
#  '#science',
#  '#pfecolleague',
#  '#covid19vaccine',
#  '#covid19ncancer',
#  '#ccc19',
#  '#mandela',
#  '#blackhistorymonth',
#  '#bhm',
#  '#health',
#  '#covid',
#  '#highriskcovid19',
#  '#vaccination',
#  '#nvac',
#  '#covid19',
#  '#letsdoitforlancashire',
#  '#covid19',
#  '#sarscov2',
#  '#nhhealthy',
#  '#innhfornh',
#  '#polqc',
#  '#covid19',
#  '#covid19',
#  '#polqc',
#  '#freedomconvoy2022',
#  '#vaccination',
#  '#privilege',
#  '#mandated',
#  '#covid19',
#  '#adjuvants',
#  '#naturalinfection',
#  '#precisionvaccines',
#  '#vitapamps',
#  '#immunity',
#  '#vaccination',
#  '#prevention',
#  '#nextgenvaccines',
#  '#keytonyc',
#  '#warriorsnation',
#  '#canadians',
#  '#stop',
#  '#rightnow',
#  '#stophealthpass',
#  '#stopcovipass',
#  '#restaurants',
#  '#bars',
#  '#theatres',
#  '#retailers',
#  '#cruise',
#  '#cruisenews',
#  '#covid19',
#  '#covidvaccines',
#  '#stfu',
#  '#lucmontagnier',
#  '#ramarc',
#  '#w42st',
#  '#covid19',
#  '#saintjohn',
#  '#novascotia',
#  '#endthemandates',
#  '#covid19',
#  '#saintjohn',
#  '#vaccines',
#  '#covid19',
#  '#cedavismd',
#  '#covid19',
#  '#vaccination',
#  '#covid',
#  ...]

# %% [markdown]
# ## Emoji Processing

# %%
import pickle
from emot.emo_unicode import UNICODE_EMOJI, EMOTICONS_EMO

# %%
# # 'Emoji_Dict.p'- download link https://drive.google.com/open?id=1G1vIkkbqPBYPKHcQ8qy0G2zkoab2Qv4v
with open('./Emoji_Dict.p', 'rb') as fp:
    Emoji_Dict = pickle.load(fp)
Emoji_Dict = {v: k for k, v in Emoji_Dict.items()}

# # Function for converting emojis into word
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
    return text

# %%
# TEST: line of text before emoji processing
df["Text"][107]
# Out:
# 'amoa resort has activated its covid-19 protocols will welcome guests as it strictly observes social distancing, face masks wearing enforce vaccination cards-only entry.'

# %%
# TEST: convert_emoji function
convert_emojis(df['Text'][107])
# Out:
# 'amoa resort has activated its covid-19 protocols will welcome guests as it strictly observes social distancing, face masks wearing enforce vaccination cards-only entry.'

# %%
# emoji processing on df["text"] column

df["Text"] = df["Text"].astype(str)
df["new_text"] = df["Text"].apply(convert_emojis)

# %%
df["new_text"][107]

# %% [markdown]
# ## Emoticon Processing

# %%
# 'Emoticon_Dict.p'- download link https://drive.google.com/open?id=1HDpafp97gCl9xZTQWMgP2kKK_NuhENlE
with open('./Emoticon_Dict.p', 'rb') as fp:
    Emoticon_Dict = pickle.load(fp)
    
# Function for converting emoticons into word
def convert_emoticons(text):
    for emot in EMOTICONS_EMO:
        text = text.replace(emot, "_".join(EMOTICONS_EMO[emot].replace(",","").replace(":","").split()))
    return text

# %%
# TEST: convert_emoticons function
sentence_listtext = "Hello :-) :-)"
convert_emoticons(sentence_listtext)
# Out:
# 'Hello Happy_face_smiley Happy_face_smiley'

# %%
df["new_text"] = df["new_text"].apply(convert_emoticons)

# %%
df.head()
# Out:
#                                                 Text  \
# 0  want find way end racism try force people inje...
# 1  this child almost died tetanus, spent months h...
# 2  juste se rappeler m. leblanc la pression que l...
# 3  you would expect cases rise significantly, cou...
# 4  depends whether vaccination status is embedded...
#
#                                             new_text
# 0  want find way end racism try force people inje...
# 1  this child almost died tetanus, spent months h...
# 2  juste se rappeler m. leblanc la pression que l...
# 3  you would expect cases rise significantly, cou...
# 4  depends whether vaccination status is embedded...

# %%
# to deal with utf-8 that pycld can't handle
import regex

RE_BAD_CHARS = regex.compile(r"\p{Cc}|\p{Cs}")

def remove_bad_chars(text):
    return RE_BAD_CHARS.sub("", text)

remove_bad_chars("A\x96 bad char")  # Cc category
# 'A bad char'
# Out:
# 'A bad char'

# %%
df['new_text'] = df['new_text'].apply(remove_bad_chars)

# %% [markdown]
# ## Detecting Languages

# %%
import pycld2 as cld2

tweets = df['new_text']
language = []

for each in tweets:
    text_content = each
    _, _, _, detected_language = cld2.detect(text_content, returnVectors=True)
    language.append(detected_language)

# %%
langs = []

for each in language:
    lang_detected = ""
    for i in range(0,len(each)):
        lang_extracted = each[i][2]
        if i != (len(each) - 1):
            lang_detected += lang_extracted + ", "
        else:
            lang_detected += lang_extracted
    langs.append(lang_detected)

# %%
langs
# Out:
# ['ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'FRENCH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown, FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH, Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH, GREEK, ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH, Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH, Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH, FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown, ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH, Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'FRENCH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'Unknown',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  'ENGLISH',
#  ...]

# %%
df['languages'] = langs
df
# Out:
#                                                      Text  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       juste se rappeler m. leblanc la pression que l...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 423588  if you are eligible, please pre- register covi...
# 423590           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 423592  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 423593  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 423594  we all have do our part end this pandemic— get...
#
#                                                  new_text languages
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 423588  if you are eligible, please pre- register covi...   ENGLISH
# 423590  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 423592  #fauciouchie #2 #vaccinated #vaccinesaveslives...   Unknown
# 423593  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 423594  we all have do our part end this pandemic— get...   ENGLISH
#
# [404337 rows x 3 columns]

# %%
df[df['languages'] != 'ENGLISH'].head()
#check how many rows
# Out:
#                                                  Text  \
# 2   juste se rappeler m. leblanc la pression que l...
# 13                                        vaccination
# 15  1-je comprends exactement ce qui doit être com...
# 35  environ 500 médecins spécialistes participaien...
# 38  c'est bien dommage que ce soit un droit, leur ...
#
#                                              new_text languages
# 2   juste se rappeler m. leblanc la pression que l...    FRENCH
# 13                                        vaccination   Unknown
# 15  1-je comprends exactement ce qui doit être com...    FRENCH
# 35  environ 500 médecins spécialistes participaien...    FRENCH
# 38  c'est bien dommage que ce soit un droit, leur ...    FRENCH

# %%
df[df['languages'] != 'ENGLISH']['new_text']
# Out:
# 2         juste se rappeler m. leblanc la pression que l...
# 13                                              vaccination
# 15        1-je comprends exactement ce qui doit être com...
# 35        environ 500 médecins spécialistes participaien...
# 38        c'est bien dommage que ce soit un droit, leur ...
#                                 ...
# 423579                             ayep. #vaccinesaveslives
# 423582    continue wear your mask preferably double , ge...
# 423585        #vaccinated #vaccinesaveslives syringemicrobe
# 423586    #vaccine #maskup #vaccinesaveslives #vaccinesi...
# 423592    #fauciouchie #2 #vaccinated #vaccinesaveslives...
# Name: new_text, Length: 56002, dtype: object

# %%
df[df['languages'] != 'ENGLISH']['new_text'][105977]
# Out:
# 'it’s time you do your part this fight against covid we reward you your actions we are sure we together be victorious this fight with collective effort everyone raising_handsmedium_skin_tone #vaccinesaveslives #weareinthistogether #plasmadonation #spreadpositivity'

# %%
df.to_csv('usa_after_language_detection.csv')

# %% [markdown]
# ## Language Translation

# %%
# df = pd.read_csv('../data/usa_after_language_detection.csv')

# %%
from deep_translator import GoogleTranslator

non_english = df[df['languages'] != 'ENGLISH']['new_text']

translated = []

for each in non_english:
    translate = GoogleTranslator(source='auto', target='en').translate(each)
    translated.append(translate)

# %%
translated

# %%
#creating new_text column
df['new_text'] = df['Text']

# %%
non_english = df[df['languages'] != 'ENGLISH']

# %%
non_english.head()
#33981 rows

# %%
indexes_list = non_english.index

# %%
indexes_list

# %%
len(indexes_list)

# %%
# range_firstNum = start_range + start_batch

# new_indexes_list = []

# for num in indexes_list:
#     new = num - range_firstNum
#     new_indexes_list.append(new)

# %%
for i in range(0,len(indexes_list)):
    index = indexes_list[i]
    df.iloc[index]['new_text'] = translated[i]

# %%
#check that the new_text col to see to check that the initial non-english rows have been translated
df[df['languages'] != 'ENGLISH']

# %% [markdown]
# ## Language Detection Part 2

# %%
# import pycld2 as cld2

# reviews = df['new_text_after_translation']
# language2 = []

# for each in reviews:
#     text_content = each
#     _, _, _, detected_language = cld2.detect(text_content, returnVectors=True)
#     language2.append(detected_language)

# %%
# langs2 = []

# for each in language2:
#     lang_detected = ""
#     for i in range(0,len(each)):
#         lang_extracted = each[i][2]
#         if i != (len(each) - 1):
#             lang_detected += lang_extracted + ", "
#         else:
#             lang_detected += lang_extracted
#     langs2.append(lang_detected)

# %%
# langs2

# %%
# df['new_languages'] = langs2

# %%
# df.to_csv("usa-after-langdetectandtrans.csv")

# %%
# non_english2 = df[df['new_languages'] != 'ENGLISH']
# non_english2

# %%
#see how many still detected as non-english, brieflcheck is it rly non english
# non_english2.info()

# %%
# non_english2.to_csv('non_english2.csv')

# %% [markdown]
# ## Read df after translation (USA)

# %%
df = pd.read_csv('./df_after_translation_usa.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                               Text  \
# 0           0  want find way end racism try force people inje...
# 1           1  this child almost died tetanus, spent months h...
# 2           2  juste se rappeler m. leblanc la pression que l...
# 3           3  you would expect cases rise significantly, cou...
# 4           4  depends whether vaccination status is embedded...
#
#                                             new_text languages  \
# 0  want find way end racism try force people inje...   ENGLISH
# 1  this child almost died tetanus, spent months h...   ENGLISH
# 2  juste se rappeler m. leblanc la pression que l...    FRENCH
# 3  you would expect cases rise significantly, cou...   ENGLISH
# 4  depends whether vaccination status is embedded...   ENGLISH
#
#                           new_text_after_translation
# 0  want find way end racism try force people inje...
# 1  this child almost died tetanus, spent months h...
# 2  just remember mr. leblanc the pressure that th...
# 3  you would expect cases rise significantly, cou...
# 4  depends whether vaccination status is embedded...

# %%
df
# Out:
#         Unnamed: 0                                               Text  \
# 0                0  want find way end racism try force people inje...
# 1                1  this child almost died tetanus, spent months h...
# 2                2  juste se rappeler m. leblanc la pression que l...
# 3                3  you would expect cases rise significantly, cou...
# 4                4  depends whether vaccination status is embedded...
# ...            ...                                                ...
# 404260      404260  if you are eligible, please pre- register covi...
# 404261      404261           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 404262      404262  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 404263      404263  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 404264      404264  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 404260  if you are eligible, please pre- register covi...   ENGLISH
# 404261  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 404262  #fauciouchie #2 #vaccinated #vaccinesaveslives...   ENGLISH
# 404263  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 404264  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404260  if you are eligible, please pre- register covi...
# 404261  do it others.... flexed_bicepsparty_poppersyri...
# 404262  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 404263  yay raising_handslight_skin_tone congrats dr. ...
# 404264  we all have do our part end this pandemic— get...
#
# [404265 rows x 5 columns]

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                                      Text  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       juste se rappeler m. leblanc la pression que l...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404260  if you are eligible, please pre- register covi...
# 404261           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 404262  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 404263  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 404264  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 404260  if you are eligible, please pre- register covi...   ENGLISH
# 404261  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 404262  #fauciouchie #2 #vaccinated #vaccinesaveslives...   ENGLISH
# 404263  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 404264  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404260  if you are eligible, please pre- register covi...
# 404261  do it others.... flexed_bicepsparty_poppersyri...
# 404262  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 404263  yay raising_handslight_skin_tone congrats dr. ...
# 404264  we all have do our part end this pandemic— get...
#
# [404265 rows x 4 columns]

# %% [markdown]
# ## Text File & Corpus Creation

# %%
# create txt file for each text review

# def CreateCorpusFromDataFrame(corpusfolder, df):
#     for index, r in df.iterrows():
#     # print (r['text'])
#     # print (str(index) + '.txt')
#         text = r['new_text_after_translation']
#         fname = str(index)+'.txt'
#         corpusfile = open(corpusfolder+'/'+fname, "w", encoding="utf-8")
#         corpusfile.write(str(text))
#         corpusfile.close()

# CreateCorpusFromDataFrame('../text-corpus-usa-v2', df)

# reference: https://stackoverflow.com/questions/49088978/how-to-create-corpus-from-pandas-data-frame-to-operate-with-nltk/49104725

# %%
file_directory = '../text-corpus-usa-v2'
filename_pattern = '.+\.txt'

my_corpus = PlaintextCorpusReader(file_directory, filename_pattern)

#Print some words in specific file
test = my_corpus.words('0.txt')
print(test)
print(len(test))
# Out:
# ['want', 'find', 'way', 'end', 'racism', 'try', ...]
# 52

# %%
#Total number of text files i.e. total number of tweets
print(len(my_corpus.fileids()))
# Out:
# 404265

# %%
fdist = nltk.FreqDist(test)
print(fdist.most_common(10))
# Out:
# [('people', 4), ('.', 4), ('i', 3), ('force', 2), ('against', 2), ('vaxx', 2), ('want', 1), ('find', 1), ('way', 1), ('end', 1)]

# %%
# word distribution across all files
fdist_all_files = nltk.FreqDist(my_corpus.words())
print(fdist_all_files.most_common(10))

# %%
#total number of words
total_words = my_corpus.words()
print(total_words)
print(len(total_words))

# %% [markdown]
# ## Tokenization

# %%
#Creating a sorted list of texts since my_corpus.fileids() does not read texts consecutively
#EDIT RANGE
sorted_list = [f'{i}.txt' for i in range(322000, 404265)]

# %%
tokenised_words = [my_corpus.words(each) for each in sorted_list]
tokenised_words

# %%
print(len(tokenised_words))
# Out:
# 2000

# %% [markdown]
# ## Converting British to American English

# %%
#https://stackoverflow.com/questions/42329766/python-nlp-british-english-vs-american-english

import requests

def americanize(word):
    url ="https://raw.githubusercontent.com/hyperreality/American-British-English-Translator/master/data/british_spellings.json"
    british_to_american_dict = requests.get(url).json()

    for british_spelling, american_spelling in british_to_american_dict.items():
        word = word.replace(british_spelling, american_spelling)
  
    return word

# %%
test_americanize = [['flavour', 'colour'], ['apologise', 'travelled']]
test_americanize = [[americanize(w) for w in each] for each in test_americanize]
test_americanize
# Out:
# [['flavor', 'color'], ['apologize', 'traveled']]

# %%
tokenised = [[americanize(w) for w in each] for each in tokenised_words[80000:]]
tokenised
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# Exception in thread Exception in threading.excepthook:Exception ignored in thread started byException ignored in sys.unraisablehook

# %%
# save americanized tokens
convert_to_str = []

for each in tokenised:
    converted_str = ""
    for i in range(0,len(each)):
        if i == (len(each) - 1):
            converted_str += each[i]
        else:
            converted_str += each[i] + ", "
    convert_to_str.append(converted_str)
    
converted_df = pd.DataFrame(convert_to_str)

converted_df.to_csv('usa_americanized_tokens-rach-80000-end.csv')

# %% [markdown]
# ## Conversion to numerals

# %%
#check if text has numbers 
def hasNumbers(inputList):
    for list in inputList:
        for word in list:
            if word.isdigit():
                return True
    return False

hasNumbers(tokenised)
# Out:
# True

# %%
# since theres numbers, the numbers need to be converted to words e.g. "2" to "two"

p = inflect.engine()
  
# convert number into words
def convert_number(text):
    # split string into list of words
    temp_str = text.split()
    # initialise empty list
    new_string = []
  
    for word in temp_str:
        # if word is a digit, convert the digit
        # to numbers and append into the new_string list
        if word.isdigit():
            temp = p.number_to_words(word)
            new_string.append(temp)
  
        # append the word as it is
        else:
            new_string.append(word)
  
    # join the words of new_string to form a string
    temp_str = ' '.join(new_string)
    return temp_str

# %%
# example text which contain numbers in it
input_list = ['There are 3 balls in this bag, and 12 in the other one.', '29']
result = [convert_number(each)for each in input_list]
result
# Out:
# ['There are three balls in this bag, and twelve in the other one.',
#  'twenty-nine']

# %%
#NEED TO CHANGE VARIABLE after us to brit eng conversion

tokenised_numerals_converted = [[convert_number(w) for w in each] for each in tokenised]

# %%
#check if text has numbers 
def hasNumbers(inputList):
    for list in inputList:
        for word in list:
            if word.isdigit():
                return True
    return False

hasNumbers(tokenised_numerals_converted)
# Out:
# False

# %% [markdown]
# ## Misspellings

# %%
def correct_typo(tokens):
    spell = SpellChecker()
    return [spell.correction(t) if len(spell.unknown([t]))>0 else t for t in tokens]

# %%
misspelled_test = ['greot', 'coyor', 'and', 'misspeling']
correct_typo(misspelled_test)

# %%
tokenised_spellchecked = [correct_typo(each) for each in tokenised_numerals_converted]

# %%
tokenised_spellchecked
# Out:
# [['even',
#   'after',
#   'being',
#   'fully',
#   'vaccinated',
#   'boosted',
#   'with',
#   'two',
#   'masks',
#   'everywhere',
#   'i',
#   'go',
#   'i',
#   'still',
#   'feel',
#   'uncomfortable',
#   'when',
#   'i',
#   'hear',
#   'someone',
#   'cough',
#   '.',
#   'coughing',
#   'is',
#   'sure',
#   'way',
#   'get',
#   'move',
#   '.'],
#  ['our',
#   'nurses',
#   'are',
#   'exhausted',
#   '.',
#   'if',
#   'you',
#   'i',
#   're',
#   'not',
#   'vaccinated',
#   ',',
#   'why',
#   'would',
#   'you',
#   'trust',
#   'medicine',
#   'at',
#   'that',
#   'point',
#   'not',
#   'judging',
#   '.',
#   'just',
#   'asking',
#   '.'],
#  ['they', 'will', 'not', 'get', 'vaccinated', '.'],
#  ['omicron',
#   'is',
#   'very',
#   'contagious',
#   '&',
#   'amp',
#   ';',
#   'can',
#   'still',
#   'be',
#   'deadly',
#   '.',
#   'data',
#   'shows',
#   'that',
#   'if',
#   'you',
#   "'",
#   've',
#   'been',
#   'vaccinated',
#   ',',
#   'serious',
#   'illness',
#   'or',
#   'death',
#   'is',
#   'much',
#   'less',
#   'likely',
#   '.',
#   'i',
#   'continue',
#   'encourage',
#   'everyone',
#   'whose',
#   'conscience',
#   '&',
#   'amp',
#   ';',
#   'personal',
#   'health',
#   'allows',
#   'get',
#   'couid',
#   'vaccine',
#   '.',
#   '#',
#   'yourvoice',
#   '#',
#   'personalresponsibility'],
#  ['i',
#   'just',
#   'saw',
#   'commercial',
#   'was',
#   'spokesperson',
#   '.',
#   'not',
#   'nothing',
#   ',',
#   'but',
#   'should',
#   'insurance',
#   'company',
#   'have',
#   'spokesperson',
#   'who',
#   'wont',
#   'get',
#   'vaccinated',
#   'i',
#   "'",
#   'i',
#   'supposed',
#   'trust',
#   'that',
#   'guy'],
#  ['those',
#   'bitching',
#   'about',
#   'tweet',
#   ',',
#   'government',
#   'tells',
#   'them',
#   'stay',
#   'home',
#   'off',
#   'roads',
#   'their',
#   'safety',
#   '&',
#   'amp',
#   ';',
#   'they',
#   'do',
#   '.',
#   'but',
#   'tell',
#   'them',
#   'get',
#   'vaccinated',
#   'or',
#   'wear',
#   'mask',
#   'they',
#   'flip',
#   'out',
#   '.',
#   'reminds',
#   'me',
#   'bunch',
#   'sheep',
#   'i'],
#  ['you',
#   'need',
#   'be',
#   'vaccinated',
#   'enter',
#   'country',
#   '.',
#   'if',
#   'you',
#   'require',
#   'negative',
#   'test',
#   'top',
#   'it',
#   'then',
#   'why',
#   'require',
#   'vaccination',
#   'first',
#   'place',
#   'am',
#   'i',
#   'missing',
#   'something',
#   'here',
#   'you',
#   'should',
#   'get',
#   'vaccinated',
#   'anyway',
#   ',',
#   'but',
#   'this',
#   'kind',
#   'shit',
#   'just',
#   'buries',
#   'safety',
#   'argument',
#   '.'],
#  ['provinces',
#   'don',
#   "'",
#   'i',
#   'have',
#   'resources',
#   'test',
#   'properly',
#   'but',
#   'we',
#   "'",
#   're',
#   'still',
#   'wasting',
#   'tests',
#   'fully',
#   'vaccinated',
#   'travelers',
#   'this',
#   'makes',
#   'literally',
#   'zero',
#   'sense',
#   'at',
#   'this',
#   'point',
#   'we',
#   "'",
#   're',
#   'handing',
#   'anti',
#   '-',
#   'baxters',
#   'their',
#   'arguments',
#   'fucking',
#   'plate',
#   '.',
#   'fucking',
#   'madness',
#   '.'],
#  ['i',
#   'life',
#   "'",
#   'i',
#   'most',
#   'persistent',
#   'urgent',
#   'question',
#   'is',
#   ',',
#   "'",
#   'what',
#   'are',
#   'you',
#   'doing',
#   'others',
#   'i',
#   '-',
#   'martin',
#   'luther',
#   'king',
#   'or',
#   '.',
#   'more',
#   'relevant',
#   'than',
#   'ever',
#   '.',
#   'more',
#   'resonating',
#   'than',
#   'ever',
#   '.',
#   'more',
#   'ways',
#   'than',
#   'ever',
#   '.',
#   'keep',
#   'safe',
#   'by',
#   'staying',
#   'safe',
#   'being',
#   'vaccinated',
#   '-',
#   'you',
#   ',',
#   'yours',
#   'others',
#   '.',
#   '#',
#   'midday'],
#  ['lol',
#   'plan',
#   'was',
#   'pal',
#   'get',
#   'vaccinated',
#   ',',
#   'but',
#   'person_shrugging',
#   'i',
#   'female_sign',
#   'i',
#   'if',
#   'they',
#   'die',
#   'they',
#   'die',
#   'i',
#   'guess',
#   'at',
#   'this',
#   'point',
#   '.'],
#  ['absolutely',
#   '.',
#   'kill',
#   'your',
#   'own',
#   'by',
#   'refusing',
#   'get',
#   'vaccinated',
#   ',',
#   'not',
#   'us',
#   '.'],
#  ['i',
#   "'",
#   'i',
#   'thinking',
#   'if',
#   'he',
#   'starts',
#   'losing',
#   '$$$,',
#   'he',
#   "'",
#   'all',
#   'get',
#   'vaccinated',
#   '.'],
#  ['"',
#   'novak',
#   'djokovic',
#   'will',
#   'be',
#   'granted',
#   'special',
#   'entry',
#   'participate',
#   'australian',
#   'open',
#   'after',
#   'two thousand and twenty-three',
#   '"',
#   'it',
#   'will',
#   'be',
#   'allowed',
#   'two thousand and twenty-three',
#   'if',
#   'he',
#   'gets',
#   'vaccinated',
#   '.',
#   'as',
#   'it',
#   'stands',
#   'now',
#   ',',
#   'he',
#   'won',
#   "'",
#   'i',
#   'be',
#   'allowed',
#   'into',
#   'australia',
#   'three',
#   'years',
#   '.'],
#  ['vaccine',
#   'does',
#   'keep',
#   'some',
#   'people',
#   'getting',
#   'sick',
#   '.',
#   'those',
#   'vaccinated',
#   ',',
#   'that',
#   'do',
#   'get',
#   'sick',
#   ',',
#   'have',
#   'less',
#   'virus',
#   'nasal',
#   'cavities',
#   'they',
#   'cough',
#   'less',
#   ',',
#   'thus',
#   'they',
#   'infect',
#   'fewer',
#   'people',
#   '.',
#   'if',
#   'you',
#   'don',
#   "'",
#   'i',
#   'take',
#   'vaccine',
#   'how',
#   'do',
#   'you',
#   'slow',
#   'spread',
#   'disease'],
#  ['vaccinated', 'or', 'not', ',', 'you', 'miss', 'betty', 'white', '.'],
#  ['today',
#   "'",
#   'i',
#   'thread',
#   'worth',
#   'reading',
#   'is',
#   'anyone',
#   'who',
#   'isn',
#   "'",
#   'i',
#   'vaccinated'],
#  ['it',
#   'is',
#   'not',
#   'clear',
#   'at',
#   'all',
#   'except',
#   'those',
#   'who',
#   'chose',
#   'not',
#   'get',
#   'vaccinated',
#   '.',
#   'so',
#   '-',
#   'called',
#   '"',
#   'natural',
#   'immunity',
#   '"',
#   'becoming',
#   'their',
#   'default',
#   'option',
#   'unless',
#   'course',
#   'they',
#   'first',
#   'succumb',
#   '.'],
#  ['so',
#   '...',
#   'if',
#   'you',
#   'get',
#   'couid',
#   'while',
#   'vaccinated',
#   ',',
#   'this',
#   'course',
#   'action',
#   'will',
#   'reduce',
#   'severity'],
#  ['airlines',
#   'seek',
#   'end',
#   'mandatory',
#   'couid',
#   '-',
#   'nineteen',
#   'testing',
#   'vaccinated',
#   'passengers',
#   'arrival'],
#  ['i',
#   'do',
#   'think',
#   'mandating',
#   'truckers',
#   'be',
#   'vaccinated',
#   'is',
#   'stupid',
#   '.',
#   'they',
#   'associate',
#   'with',
#   'less',
#   'people',
#   'than',
#   'average',
#   'joe',
#   '.'],
#  ['yes',
#   ',',
#   'it',
#   'can',
#   'you',
#   'shouldn',
#   'i',
#   'i',
#   'get',
#   'vaccinated',
#   'or',
#   'boosted',
#   'three',
#   'months',
#   'after',
#   'testing',
#   'positive',
#   'that',
#   'reason',
#   '.'],
#  ['three',
#   'public',
#   'elementaries',
#   ',',
#   'three',
#   'parochial',
#   'elementaries',
#   'so',
#   'far',
#   'wichita',
#   'closed',
#   'tomorrow',
#   'due',
#   'lack',
#   'available',
#   'healthy',
#   'staff',
#   '.',
#   'get',
#   'your',
#   'eligible',
#   'kids',
#   'vaccinated',
#   'boosted',
#   ',',
#   'get',
#   'your',
#   'booster',
#   '.'],
#  ['really',
#   'because',
#   'i',
#   'am',
#   'fully',
#   'vaccinated',
#   'boosted',
#   'don',
#   "'",
#   'i',
#   'go',
#   'public',
#   'without',
#   'mask',
#   '.',
#   'it',
#   "'",
#   'i',
#   'people',
#   'like',
#   'me',
#   'who',
#   'aren',
#   "'",
#   'i',
#   'fucking',
#   'dying',
#   'currently',
#   '.',
#   'fail',
#   '.',
#   'try',
#   'again',
#   '.'],
#  ['so',
#   'long',
#   'as',
#   'anti',
#   '-',
#   'science',
#   'idiots',
#   'continue',
#   'not',
#   'get',
#   'vaccinated',
#   'or',
#   'wear',
#   'mask',
#   'public',
#   ',',
#   'then',
#   'there',
#   'will',
#   'continue',
#   'be',
#   'variants',
#   'evolutions',
#   'couid',
#   '.',
#   'because',
#   'it',
#   "'",
#   'i',
#   'virus',
#   'that',
#   "'",
#   'i',
#   'how',
#   'organisms',
#   'work',
#   '.',
#   'duh',
#   '.',
#   'face_with_rolling_eyesface_with_rolling_eyes'],
#  ['if',
#   'you',
#   'i',
#   're',
#   'not',
#   'vaccinated',
#   'yet',
#   ',',
#   'i',
#   'simply',
#   'have',
#   'no',
#   'respect',
#   'you',
#   '.',
#   'do',
#   'better',
#   '.'],
#  ['get',
#   'vaccinated',
#   'boosted',
#   'if',
#   'you',
#   'haven',
#   "'",
#   'i',
#   'already',
#   '.'],
#  ['because',
#   'you',
#   'give',
#   'shit',
#   'about',
#   'someone',
#   'other',
#   'than',
#   'yourself',
#   'that',
#   'you',
#   'haven',
#   "'",
#   'i',
#   'gotten',
#   'vaccinated',
#   'tells',
#   'world',
#   'everything',
#   '.'],
#  ['media',
#   'should',
#   'be',
#   'more',
#   'truthful',
#   '-',
#   'present',
#   'facts',
#   'how',
#   'many',
#   'people',
#   'have',
#   'been',
#   'vaccinated',
#   ',',
#   'how',
#   'gop',
#   'is',
#   'thwarting',
#   'him',
#   'at',
#   'every',
#   'turn',
#   ',',
#   'how',
#   'economy',
#   'is',
#   'recovering',
#   ',',
#   'etc',
#   '.',
#   'you',
#   'guys',
#   'treated',
#   'trump',
#   'so',
#   'much',
#   'better',
#   'than',
#   'you',
#   'treating',
#   'biden',
#   ',',
#   'maybe',
#   'you',
#   'i',
#   're',
#   'it',
#   'with',
#   'trump'],
#  ['appears',
#   'that',
#   'gaeta',
#   'failed',
#   'get',
#   'vaccinated',
#   'against',
#   'venom',
#   'virus'],
#  ['well',
#   'fully',
#   'vaccinated',
#   ',',
#   'landing',
#   'icu',
#   'couid',
#   'is',
#   'less',
#   'than',
#   '~',
#   'one',
#   ':',
#   'two thousand, five hundred',
#   '.',
#   'its',
#   'also',
#   'threat',
#   'that',
#   'we',
#   'can',
#   'contol',
#   'via',
#   'masks',
#   'social',
#   'distancing',
#   '.',
#   'while',
#   'chance',
#   'random',
#   'attack',
#   'is',
#   'smaller',
#   ',',
#   'its',
#   'something',
#   'we',
#   'cannot',
#   'control',
#   '.',
#   'no',
#   'mystery',
#   'what',
#   'causes',
#   'more',
#   'anxiety',
#   '.'],
#  ['i',
#   'don',
#   'i',
#   'i',
#   'always',
#   'agree',
#   'all',
#   'prof',
#   'hotels',
#   'takes',
#   ',',
#   'but',
#   'please',
#   'get',
#   'vaccinated',
#   'boosted',
#   'don',
#   'i',
#   'i',
#   'through',
#   'your',
#   'life',
#   'away',
#   'needlessly',
#   'assume',
#   'that',
#   'you',
#   'i',
#   'all',
#   'be',
#   'okay',
#   'getting',
#   'couid',
#   'immune',
#   'naive',
#   'give',
#   'your',
#   'body',
#   'fighting',
#   'start'],
#  ['record',
#   ',',
#   'i',
#   'do',
#   'not',
#   'have',
#   'couid',
#   ',',
#   'but',
#   'lot',
#   'people',
#   'close',
#   'me',
#   'have',
#   '.',
#   'i',
#   "'",
#   'i',
#   'fully',
#   'vaccinated',
#   ',',
#   'boosted',
#   ',',
#   'i',
#   'always',
#   'wear',
#   'my',
#   'mask',
#   'when',
#   '/',
#   'if',
#   'i',
#   'leave',
#   'my',
#   'home',
#   '.'],
#  ['i',
#   'i',
#   'i',
#   'so',
#   'sorry',
#   'your',
#   'loss',
#   '.',
#   'losing',
#   'mother',
#   'is',
#   'very',
#   'hard',
#   '.',
#   'why',
#   'would',
#   'she',
#   'not',
#   'have',
#   'vaccine',
#   'she',
#   'must',
#   'have',
#   'been',
#   'vaccinated',
#   'as',
#   'child',
#   'against',
#   'many',
#   'illnesses',
#   '.',
#   'what',
#   'influenced',
#   'her'],
#  ['oh',
#   'hai',
#   '.',
#   'this',
#   'ex',
#   'vaccinated',
#   'football',
#   'fan',
#   'decided',
#   'go',
#   'vegas',
#   'see',
#   'her',
#   'play',
#   '#',
#   'riseupredsea'],
#  ['vaccinated',
#   'steeple',
#   'ewe',
#   'weare',
#   'some',
#   'dumbest',
#   'smart',
#   'pal',
#   'i',
#   'know',
#   '.',
#   'i',
#   'i',
#   'all',
#   'never',
#   'understand',
#   'them',
#   '.',
#   'sky',
#   'is',
#   'falling',
#   'every',
#   'day',
#   '&',
#   'amp',
#   ';',
#   'it',
#   'i',
#   'i',
#   'exhausting'],
#  ['wear',
#   'mask',
#   ',',
#   'social',
#   'distance',
#   'isolate',
#   'till',
#   'it',
#   'passes',
#   '.',
#   'you',
#   'have',
#   'choices',
#   'other',
#   'than',
#   'get',
#   'vaccinated',
#   '.',
#   'talk',
#   'your',
#   'doctor',
#   '.'],
#  ['your',
#   'goodwill',
#   'appears',
#   'have',
#   'backfired',
#   ',',
#   'reilly',
#   ',',
#   'but',
#   'that',
#   "'",
#   'i',
#   'because',
#   'some',
#   'will',
#   'always',
#   'see',
#   'novak',
#   'as',
#   'bad',
#   'guy',
#   'who',
#   'doesn',
#   "'",
#   'i',
#   'belong',
#   'two',
#   'princes',
#   "'",
#   'company',
#   '.',
#   'hell',
#   'yes',
#   'he',
#   'should',
#   'be',
#   'vaccinated',
#   '.',
#   'but',
#   'hate',
#   'he',
#   "'",
#   'i',
#   'getting',
#   'is',
#   'sick',
#   '.'],
#  ['if',
#   'elementary',
#   'high',
#   'school',
#   'kids',
#   'can',
#   'return',
#   'school',
#   '-',
#   'triple',
#   'vaccinated',
#   'college',
#   'kids',
#   'wearing',
#   'masks',
#   'can',
#   'certainly',
#   'return',
#   'important',
#   'class',
#   'education',
#   'at',
#   'college',
#   'earlier',
#   'than',
#   'march'],
#  ['fucking',
#   'idiots',
#   '.',
#   'won',
#   "'",
#   'i',
#   'get',
#   'vaccinated',
#   'won',
#   "'",
#   'i',
#   'wear',
#   'masks',
#   '.',
#   'i',
#   "'",
#   'i',
#   'disappointed_facesorry',
#   '.'],
#  ['let',
#   "'",
#   'i',
#   'not',
#   'forget',
#   'that',
#   'kyrie',
#   'has',
#   'great',
#   'immunity',
#   'now',
#   'having',
#   'virus',
#   '.',
#   'he',
#   'is',
#   'not',
#   'unsafe',
#   'be',
#   'around',
#   'doctors',
#   'all',
#   'over',
#   'world',
#   'advise',
#   'waiting',
#   'at',
#   'least',
#   'three',
#   'months',
#   'get',
#   'vaccinated',
#   'post',
#   'infection',
#   ',',
#   'even',
#   'if',
#   'he',
#   'wanted'],
#  ['why',
#   'would',
#   'they',
#   'treat',
#   'tennis',
#   'player',
#   'better',
#   'than',
#   'they',
#   'treat',
#   'me',
#   'i',
#   "'",
#   'i',
#   'fully',
#   'vaccinated',
#   '.',
#   'i',
#   "'",
#   'i',
#   'positive',
#   'they',
#   'would',
#   'treat',
#   'me',
#   'better',
#   'than',
#   'him',
#   '.',
#   'as',
#   'they',
#   'whomever',
#   'they',
#   'are',
#   'should',
#   '.'],
#  ['i',
#   'wasn',
#   'i',
#   'i',
#   'here',
#   'debate',
#   '.',
#   'i',
#   'i',
#   'i',
#   'not',
#   'naive',
#   'enough',
#   'think',
#   'i',
#   'i',
#   'all',
#   'change',
#   'anyones',
#   'mind',
#   'at',
#   'this',
#   'point',
#   'if',
#   'they',
#   'still',
#   'haven',
#   'i',
#   'i',
#   'gotten',
#   'vaccinated',
#   '.',
#   'two',
#   '/',
#   'two'],
#  ['why',
#   'would',
#   'it',
#   '...',
#   'he',
#   'doesn',
#   "'",
#   'i',
#   'care',
#   'about',
#   'his',
#   'own',
#   'team',
#   'mates',
#   'i',
#   'but',
#   'he',
#   "'",
#   'i',
#   'voice',
#   'voiceless',
#   '...',
#   'just',
#   'trade',
#   'him',
#   'already',
#   'kyrie',
#   'irving',
#   'says',
#   'that',
#   'losing',
#   'kevin',
#   'durant',
#   'injury',
#   'doesn',
#   "'",
#   'i',
#   'change',
#   'his',
#   'stance',
#   'getting',
#   'vaccinated'],
#  ['not', 'playing', 'ny', 'not', 'vaccinated'],
#  ['he',
#   'does',
#   'realize',
#   'if',
#   'nets',
#   'don',
#   "'",
#   'i',
#   'make',
#   'it',
#   'playoffs',
#   'exit',
#   'out',
#   'them',
#   '.',
#   'will',
#   'be',
#   'because',
#   'his',
#   'indecision',
#   'get',
#   'vaccinated',
#   '.',
#   'face_with_raised_eyebrow'],
#  ['do',
#   'you',
#   'really',
#   'think',
#   'that',
#   'could',
#   'really',
#   'end',
#   'pandemic',
#   'especially',
#   'when',
#   'half',
#   'population',
#   'refuses',
#   'wear',
#   'masks',
#   'or',
#   'get',
#   'fully',
#   'vaccinated',
#   'not',
#   'mention',
#   'supreme',
#   'court',
#   'interfering',
#   'where',
#   'medical',
#   'experts',
#   'should',
#   'be',
#   'calling',
#   '"',
#   'shots',
#   '"'],
#  ['read',
#   '.',
#   'today',
#   'she',
#   'posted',
#   'information',
#   'vaccinated',
#   'patients',
#   'who',
#   'got',
#   'couid',
#   '.',
#   'this',
#   'study',
#   'looks',
#   'like',
#   'good',
#   'news',
#   'should',
#   'make',
#   'you',
#   'feel',
#   'some',
#   'relief',
#   'hope',
#   '.',
#   'red_heart'],
#  ['legislators', 'have', 'be', 'vaccinated'],
#  ['thankfully',
#   'you',
#   'were',
#   'vaccinated',
#   'that',
#   'i',
#   'i',
#   'probably',
#   'why',
#   'you',
#   'i',
#   're',
#   'able',
#   'still',
#   'tweet',
#   '.',
#   'headstone'],
#  ['no',
#   '.',
#   'you',
#   'i',
#   're',
#   'not',
#   'same',
#   'boat',
#   '.',
#   'if',
#   'you',
#   'i',
#   're',
#   'fully',
#   'vaccinated',
#   'sans',
#   'underlining',
#   'conditions',
#   'you',
#   'get',
#   'couid',
#   'you',
#   'won',
#   'i',
#   'i',
#   'end',
#   'up',
#   'hospital',
#   'or',
#   'worse',
#   '.'],
#  ['you',
#   'are',
#   'imposing',
#   'your',
#   'belief',
#   'system',
#   'others',
#   '.',
#   'if',
#   'seventy-four',
#   '%',
#   'population',
#   'is',
#   'vaccinated',
#   'then',
#   'you',
#   'are',
#   'clearly',
#   'minority',
#   'so',
#   'step',
#   'up',
#   'plate',
#   'be',
#   'responsible',
#   '.'],
#  ['we',
#   'cant',
#   'control',
#   'peoples',
#   'health',
#   '.',
#   'we',
#   'can',
#   'do',
#   'everything',
#   'possible',
#   'keep',
#   'beds',
#   'open',
#   'whoever',
#   'needs',
#   'one',
#   'though',
#   '.',
#   'vaccinated',
#   'people',
#   'do',
#   'not',
#   'end',
#   'up',
#   'hospitalized',
#   'at',
#   'high',
#   'rate',
#   'untaxed',
#   '.',
#   'there',
#   'is',
#   'oodles',
#   'data',
#   'that',
#   '.',
#   'vaccinate',
#   'help',
#   'medical',
#   'workers',
#   '.'],
#  ['i',
#   "'",
#   'i',
#   'vaccinated',
#   '&',
#   'amp',
#   ';',
#   'think',
#   'it',
#   "'",
#   'i',
#   'total',
#   'bullshit',
#   '.',
#   'but',
#   'hey',
#   ',',
#   'that',
#   "'",
#   'i',
#   'just',
#   'meperson_shrugging',
#   'i',
#   'male_sign',
#   'i'],
#  ['thanks',
#   'my',
#   'daughter',
#   ',',
#   'i',
#   'got',
#   'original',
#   'strain',
#   'now',
#   'omicron',
#   'strain',
#   '.',
#   'i',
#   'have',
#   'is',
#   ',',
#   'it',
#   'took',
#   'me',
#   'full',
#   'four',
#   'weeks',
#   'get',
#   'over',
#   'omicron',
#   ',',
#   'despite',
#   'being',
#   'vaccinated',
#   '.',
#   'thank',
#   'goodness',
#   'i',
#   "'",
#   'i',
#   'already',
#   'disability',
#   'or',
#   'i',
#   'would',
#   'be',
#   'completely',
#   'destitute',
#   'right',
#   'now',
#   '.'],
#  ['if', 'you', 'i', 're', 'vaccinated', ',', 'you', 'i', 'all', 'be', 'fine'],
#  ['i',
#   'novak',
#   '#',
#   'djokovic',
#   'returned',
#   'home',
#   'monday',
#   'after',
#   'being',
#   'thwarted',
#   'defending',
#   'his',
#   'australian',
#   'open',
#   'title',
#   'only',
#   'face',
#   'new',
#   'predicament',
#   ':',
#   'he',
#   'could',
#   'be',
#   'barred',
#   'french',
#   'open',
#   'this',
#   'year',
#   ',',
#   'too',
#   ',',
#   'if',
#   'he',
#   'i',
#   'i',
#   'still',
#   'not',
#   'vaccinated',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   'i'],
#  ['mandate',
#   'them',
#   'get',
#   'vaccinated',
#   '.',
#   'that',
#   "'",
#   'i',
#   'what',
#   '.',
#   'why',
#   'have',
#   'they',
#   'been',
#   'except',
#   'all',
#   'this',
#   'time'],
#  ['thank',
#   'you',
#   '.',
#   'they',
#   "'",
#   're',
#   'both',
#   'doing',
#   'relatively',
#   'well',
#   'under',
#   'circumstances',
#   '.',
#   'i',
#   'convinced',
#   'them',
#   'get',
#   'vaccinated',
#   '.',
#   'sadly',
#   'i',
#   'had',
#   'threaten',
#   'stay',
#   'away',
#   'them',
#   'if',
#   'they',
#   'did',
#   'not',
#   'vaccinate',
#   '.',
#   'my',
#   'surprise',
#   ',',
#   'they',
#   "'",
#   're',
#   'planning',
#   'get',
#   'boosters',
#   '.'],
#  ['i',
#   'think',
#   'not',
#   'being',
#   'vaccinated',
#   'deal',
#   'breaker',
#   'me',
#   'i',
#   'because',
#   'we',
#   'yrs',
#   'into',
#   'this',
#   'shit',
#   'you',
#   'still',
#   'playing',
#   'these',
#   'dumb',
#   'ass',
#   'games',
#   'expressionless_face'],
#  ['very',
#   'troubling',
#   '.',
#   'some',
#   'research',
#   'i',
#   'saw',
#   'today',
#   'indicates',
#   'that',
#   'vaccinated',
#   'with',
#   'couid',
#   'its',
#   'have',
#   'very',
#   'low',
#   'risk',
#   'long',
#   'couid',
#   '.',
#   'one',
#   'study',
#   ',',
#   'but',
#   'very',
#   'encouraging',
#   '.',
#   'see',
#   'posts',
#   'today',
#   'this',
#   'subject',
#   '.'],
#  ['can',
#   'still',
#   'become',
#   'infected',
#   'spread',
#   'it',
#   'others',
#   'if',
#   'you',
#   'are',
#   'vaccinated',
#   '.'],
#  ['they',
#   'basically',
#   'said',
#   'that',
#   'was',
#   'nick',
#   'espn',
#   'asking',
#   'question',
#   'he',
#   'already',
#   'knew',
#   'answer',
#   'while',
#   'laughing',
#   '.',
#   'he',
#   'knows',
#   'kyrie',
#   'isn',
#   "'",
#   'i',
#   'getting',
#   'vaccinated',
#   'but',
#   'wanted',
#   'provoke',
#   'him',
#   'into',
#   'argument',
#   'about',
#   'it',
#   'kai',
#   'was',
#   'like',
#   'expressionless_face'],
#  ['look',
#   'what',
#   'happened',
#   'when',
#   'i',
#   'got',
#   'vaccinated',
#   'rolling_on_the_floor_laughing'],
#  ['atlantic',
#   ':',
#   'silent',
#   ',',
#   'vaccinated',
#   ',',
#   'impatient',
#   'majority',
#   '.',
#   'via'],
#  ['yes',
#   ',',
#   'i',
#   'was',
#   'vaccinated',
#   'three',
#   'times',
#   ',',
#   'but',
#   'omicron',
#   'is',
#   'very',
#   'virulent',
#   'doesn',
#   "'",
#   'i',
#   'care',
#   'expressionless_face'],
#  ['telling',
#   'kyrie',
#   '"',
#   'oh',
#   'you',
#   "'",
#   're',
#   'famous',
#   'kid',
#   'is',
#   'hurt',
#   '...',
#   'that',
#   "'",
#   'i',
#   'why',
#   'you',
#   'should',
#   'get',
#   'vaccinated',
#   '"',
#   'did',
#   'opposite',
#   'what',
#   'that',
#   'guy',
#   'thought',
#   'it',
#   'would',
#   'do',
#   'face_with_rolling_eyes'],
#  ['although',
#   'i',
#   'have',
#   'been',
#   'vaccinated',
#   ',',
#   'day',
#   'i',
#   'share',
#   'this',
#   'with',
#   'total',
#   'stranger',
#   ',',
#   'is',
#   'very',
#   'second',
#   'i',
#   'walk',
#   'away',
#   '.',
#   'there',
#   'are',
#   'enough',
#   'places',
#   'eat',
#   'ny',
#   'that',
#   'won',
#   'i',
#   'i',
#   'interfere',
#   'with',
#   'hippy',
#   'regulations',
#   '.',
#   'oh',
#   '......',
#   'did',
#   'i',
#   'say',
#   'i',
#   'regulations',
#   'i',
#   'thanks',
#   'gilbert',
#   ',',
#   'as',
#   'i',
#   'totally',
#   'agree',
#   'with',
#   'you',
#   'folded_handsbaseball',
#   'i',
#   'elephant'],
#  ['it',
#   "'",
#   'i',
#   'pretty',
#   'much',
#   'nothing',
#   'but',
#   'make',
#   'work',
#   'project',
#   'schools',
#   'districts',
#   '.',
#   'probably',
#   'all',
#   'so',
#   'dah',
#   'can',
#   'turn',
#   'around',
#   'at',
#   'end',
#   'count',
#   'say',
#   ',',
#   '"',
#   'whatever',
#   'it',
#   'is',
#   'percentage',
#   'staff',
#   'are',
#   'vaccinated',
#   ',',
#   'so',
#   'y',
#   "'",
#   'all',
#   'have',
#   'nothing',
#   'worry',
#   'about',
#   'at',
#   'all',
#   'i'],
#  ['voting',
#   'rights',
#   'bill',
#   'has',
#   'nothing',
#   'do',
#   'with',
#   'people',
#   'actually',
#   'voting',
#   'all',
#   'they',
#   'want',
#   'do',
#   'is',
#   'federalize',
#   'elections',
#   'so',
#   'people',
#   'don',
#   "'",
#   'i',
#   'have',
#   'prove',
#   'who',
#   'they',
#   'are',
#   'vote',
#   '.',
#   'but',
#   'you',
#   'have',
#   'prove',
#   'your',
#   'vaccinated',
#   'get',
#   'hamburger'],
#  ['wait',
#   ',',
#   'what',
#   'thirteen',
#   'pages',
#   '.',
#   'all',
#   'say',
#   'that',
#   'now',
#   'boards',
#   'must',
#   'simply',
#   'i',
#   'ask',
#   'each',
#   'employee',
#   'if',
#   'they',
#   'are',
#   'vaccinated',
#   'or',
#   'not',
#   '**.',
#   'what',
#   'am',
#   'i',
#   'missing',
#   'here',
#   'how',
#   'does',
#   'this',
#   'do',
#   'anything',
#   'make',
#   'anyone',
#   'safer',
#   'what',
#   'is',
#   'point',
#   'this',
#   '#',
#   'bed',
#   '#',
#   'coli',
#   '#',
#   'covid19bc',
#   '#',
#   'makeitmakesense',
#   '#',
#   'covid19',
#   '#',
#   'wagthedog'],
#  ['i',
#   'would',
#   'rather',
#   'see',
#   'entire',
#   'african',
#   'continent',
#   'vaccinated',
#   '....',
#   'but',
#   'sure',
#   '.'],
#  ['if',
#   'only',
#   'he',
#   'were',
#   'vaccinated',
#   'had',
#   'mask',
#   'on',
#   '.',
#   'same',
#   'thing',
#   'happened',
#   'jak',
#   'rak',
#   '.',
#   'tiny',
#   'little',
#   'gun',
#   'shot',
#   'wound',
#   'doesn',
#   'i',
#   'i',
#   'kill',
#   'you',
#   '.',
#   'it',
#   'i',
#   'i',
#   'all',
#   'that',
#   'couid',
#   'that',
#   'comes',
#   'rushing',
#   'after',
#   'you',
#   'i',
#   've',
#   'been',
#   'shot',
#   'that',
#   'kills',
#   'you',
#   '.'],
#  ['lot',
#   'people',
#   'had',
#   'ton',
#   'loud',
#   'opinions',
#   'when',
#   'i',
#   'said',
#   "'",
#   'get',
#   'vaccinated',
#   'i',
#   'but',
#   'are',
#   'extremely',
#   'quiet',
#   'when',
#   'i',
#   'said',
#   'couid',
#   'is',
#   'eventually',
#   'gonna',
#   'kill',
#   'me',
#   '.'],
#  ['not',
#   'listening',
#   'your',
#   'bullshit',
#   'dude',
#   '.',
#   'i',
#   'have',
#   'couid',
#   'wasn',
#   'i',
#   'i',
#   'vaccinated',
#   'never',
#   'was',
#   'hospital',
#   '.',
#   'i',
#   'still',
#   'won',
#   'i',
#   'i',
#   'get',
#   'vaccinated',
#   '.',
#   'cry',
#   'more',
#   '.'],
#  ['let', 'me', 'into', 'country', '.', 'i', "'", 'i', 'vaccinated', '.'],
#  ['that',
#   "'",
#   'i',
#   'correct',
#   '.',
#   'thank',
#   'you',
#   'pointing',
#   'out',
#   'quebec',
#   "'",
#   'i',
#   'mistake',
#   '.',
#   'what',
#   'about',
#   'what',
#   'france',
#   'is',
#   'doing',
#   ',',
#   'only',
#   'allowing',
#   'vaccinated',
#   'people',
#   'buy',
#   'alcohol',
#   'cannabis'],
#  ['fully', 'vaccinated', 'raised_hand'],
#  ['but',
#   'symptoms',
#   'are',
#   'not',
#   'as',
#   'bad',
#   '.',
#   'we',
#   'have',
#   'friend',
#   'who',
#   'got',
#   'sick',
#   '.',
#   'has',
#   'had',
#   'three',
#   'shots',
#   '.',
#   'just',
#   'isolated',
#   'himself',
#   'five',
#   'days',
#   'then',
#   'tested',
#   'negative',
#   '.',
#   'he',
#   "'",
#   'i',
#   'seventy-five',
#   '.',
#   'other',
#   'hand',
#   'my',
#   'granddaughter',
#   'got',
#   'sick',
#   'died',
#   'last',
#   'thursday',
#   '.',
#   'was',
#   'not',
#   'vaccinated',
#   '.',
#   'was',
#   'only',
#   'twenty-eight',
#   '.',
#   'come',
#   'on',
#   ',',
#   'man',
#   'crying_face'],
#  ['right',
#   'be',
#   'can',
#   'you',
#   'imagine',
#   'what',
#   'getting',
#   'couid',
#   'without',
#   'vaccine',
#   'would',
#   'be',
#   'like',
#   'lol',
#   'pass',
#   ',',
#   'i',
#   'i',
#   'all',
#   'get',
#   'vaccinated',
#   'deal',
#   'with',
#   'this',
#   'day',
#   'or',
#   'two',
#   '.'],
#  ['"',
#   'conservative',
#   'leader',
#   'erin',
#   'o',
#   'i',
#   'tools',
#   'said',
#   'he',
#   'believes',
#   'all',
#   'those',
#   'uniform',
#   'should',
#   'be',
#   'vaccinated',
#   'against',
#   'couid',
#   '-',
#   'nineteen',
#   ',',
#   'after',
#   'federal',
#   'court',
#   'rejected',
#   'request',
#   'by',
#   'some',
#   'military',
#   'members',
#   'exemption',
#   'vaccine',
#   'mandate',
#   'order',
#   'i',
#   'which',
#   'is',
#   'it'],
#  ['"',
#   'one',
#   'five',
#   'hospital',
#   'patients',
#   'being',
#   'treated',
#   'couid',
#   '-',
#   'nineteen',
#   'alabama',
#   'is',
#   'fully',
#   'vaccinated',
#   'i'],
#  ['it',
#   "'",
#   'i',
#   'nobody',
#   "'",
#   'i',
#   'business',
#   'if',
#   'you',
#   'are',
#   'vaccinated',
#   '.'],
#  ['i',
#   "'",
#   'i',
#   'white',
#   'i',
#   "'",
#   've',
#   'had',
#   'my',
#   'vaccine',
#   'my',
#   'booster',
#   '.',
#   'as',
#   'we',
#   'all',
#   'know',
#   'very',
#   'few',
#   'trump',
#   'supporters',
#   'are',
#   'vaccinated',
#   'because',
#   'they',
#   'are',
#   'silly',
#   'head',
#   '.',
#   'trump',
#   'i',
#   'i',
#   'new',
#   'lies',
#   'mean',
#   'diddly',
#   'squat',
#   '.',
#   'only',
#   'people',
#   'that',
#   'believe',
#   'anything',
#   'he',
#   'says',
#   'are',
#   'just',
#   'idiots',
#   '.'],
#  ['this',
#   'entire',
#   'thread',
#   'is',
#   'joke',
#   '.',
#   'literally',
#   'no',
#   'mention',
#   'actually',
#   'useful',
#   'things',
#   'like',
#   'mandating',
#   'paid',
#   'sick',
#   'days',
#   'workers',
#   'or',
#   'outreach',
#   'programs',
#   'under',
#   '-',
#   'vaccinated',
#   'groups',
#   '.',
#   '#',
#   'covidzero',
#   'gets',
#   'derided',
#   'because',
#   'it',
#   "'",
#   'i',
#   'bunch',
#   'privileged',
#   'toss',
#   'people',
#   'with',
#   'no',
#   'idea',
#   'how',
#   'society',
#   'works',
#   '.'],
#  ['course',
#   '....',
#   'they',
#   'aren',
#   "'",
#   'i',
#   'worried',
#   'about',
#   'bunch',
#   'scientists',
#   'space',
#   ',',
#   'they',
#   'might',
#   'think',
#   'again',
#   '.',
#   'bet',
#   'they',
#   'are',
#   'all',
#   'vaccinated',
#   'believe',
#   'science',
#   '.'],
#  ['this',
#   'nigga',
#   'kyrie',
#   'not',
#   'vaccinated',
#   'get',
#   'him',
#   'outta',
#   'here'],
#  ['i',
#   'i',
#   'i',
#   'bout',
#   'i',
#   'out',
#   'jobbed',
#   'y',
#   'i',
#   'all',
#   'customers',
#   'gotta',
#   'i',
#   'vaccinated',
#   'or',
#   'have',
#   'one',
#   'dose',
#   'at',
#   'least',
#   'get',
#   'served',
#   'loudly_crying_faceloudly_crying_faceloudly_crying_face'],
#  ['...',
#   'you',
#   "'",
#   'i',
#   'think',
#   'vaccines',
#   'would',
#   'be',
#   'designed',
#   'first',
#   'fot',
#   'infants',
#   'kids',
#   '...',
#   'young',
#   'adults',
#   'i',
#   'those',
#   'age',
#   'groups',
#   'first',
#   'zany_face',
#   'getting',
#   'them',
#   'vaccinated',
#   'first',
#   '...',
#   'instead',
#   'having',
#   'them',
#   'edit',
#   'entire',
#   'year',
#   '...',
#   'thumbs_up',
#   'assuming',
#   'we',
#   'believe'],
#  ['please',
#   'read',
#   'it',
#   'please',
#   'please',
#   'get',
#   'vaccinated',
#   'boosted',
#   '.',
#   '#',
#   'covid19'],
#  ['still',
#   'feeling',
#   'ok',
#   '.',
#   'haven',
#   'i',
#   'i',
#   'taken',
#   'test',
#   'yet',
#   '.',
#   'i',
#   'i',
#   'i',
#   'waiting',
#   'guest',
#   'nurse',
#   'bring',
#   'me',
#   'one',
#   '.',
#   'my',
#   'boss',
#   'is',
#   'doing',
#   'really',
#   'well',
#   '.',
#   'really',
#   'mild',
#   'symptoms',
#   '.',
#   'i',
#   'i',
#   'i',
#   'so',
#   'glad',
#   'she',
#   'i',
#   'i',
#   'vaccinated',
#   'boosted'],
#  ['i',
#   'i',
#   'i',
#   'so',
#   'sorry',
#   'hear',
#   'this',
#   'bill',
#   '.',
#   'combination',
#   'couid',
#   'its',
#   'variance',
#   'along',
#   'with',
#   'seasonal',
#   'flu',
#   'is',
#   'really',
#   'doing',
#   'number',
#   'children',
#   '.',
#   'i',
#   'know',
#   'your',
#   'kids',
#   'are',
#   'vaccinated',
#   ',',
#   'but',
#   'there',
#   'i',
#   'i',
#   'only',
#   'so',
#   'much',
#   'we',
#   'can',
#   'do',
#   '.',
#   'everyone',
#   ',',
#   'please',
#   'stay',
#   'masked',
#   'get',
#   'vaccinated',
#   '.',
#   'do',
#   'right',
#   'thing',
#   '.'],
#  ['just',
#   'wanted',
#   'say',
#   'that',
#   'i',
#   'know',
#   'people',
#   'who',
#   'have',
#   'gotten',
#   'couid',
#   'but',
#   'are',
#   'valued',
#   'boosted',
#   'have',
#   'all',
#   'had',
#   'cases',
#   'finished',
#   'worse',
#   'than',
#   'bad',
#   'cold',
#   '.',
#   'people',
#   'i',
#   'know',
#   'without',
#   'booster',
#   'have',
#   'suffered',
#   'people',
#   'who',
#   'ain',
#   "'",
#   'i',
#   'vaccinated',
#   'i',
#   'i',
#   'don',
#   'i',
#   'i',
#   'condone'],
#  ['accept',
#   'almost',
#   '900k',
#   'deaths',
#   ',',
#   'with',
#   'less',
#   'than',
#   '.',
#   'five',
#   '%',
#   'being',
#   'vaccinated',
#   'people'],
#  ['i',
#   'feel',
#   'like',
#   'we',
#   'could',
#   'divide',
#   'care',
#   'between',
#   'vaccinated',
#   'those',
#   'who',
#   'aren',
#   "'",
#   'i',
#   '.',
#   'separate',
#   'offices',
#   '/',
#   'areas',
#   ',',
#   'etc',
#   '.',
#   'we',
#   "'",
#   're',
#   'already',
#   'trying',
#   'care',
#   'everyone',
#   '.',
#   'if',
#   'their',
#   'facilities',
#   'are',
#   'backed',
#   'up',
#   ',',
#   'they',
#   "'",
#   'all',
#   'have',
#   'face',
#   'delays',
#   'like',
#   'many',
#   'non',
#   '-',
#   'couid',
#   'patients',
#   'do',
#   'but',
#   'over',
#   'ours',
#   ',',
#   'we',
#   "'",
#   'all',
#   'feel',
#   'safer',
#   '.'],
#  ['damn', '.', 'wear', 'fucking', 'mask', '.', 'get', 'vaccinated', '.'],
#  ['donna',
#   ',',
#   'i',
#   'hope',
#   'your',
#   'parents',
#   'were',
#   'just',
#   'as',
#   'smart',
#   'as',
#   'you',
#   ',',
#   'absolutely',
#   'refused',
#   'get',
#   'you',
#   'vaccinated',
#   'any',
#   'diseases',
#   ',',
#   'like',
#   'measles',
#   ',',
#   'polio',
#   ',',
#   'etc',
#   '.',
#   'if',
#   'god',
#   'forbid',
#   ',',
#   'you',
#   'were',
#   'vaccinated',
#   ',',
#   'you',
#   'must',
#   'be',
#   'so',
#   'glad',
#   'that',
#   'you',
#   "'",
#   're',
#   'so',
#   'much',
#   'smarter',
#   'than',
#   'your',
#   'parents',
#   'were',
#   '.'],
#  ['getting',
#   'vaccinated',
#   'makes',
#   'you',
#   'smart',
#   'may',
#   'save',
#   'your',
#   'life',
#   '.',
#   'getting',
#   'vaccinated',
#   'is',
#   'patriotic',
#   'thing',
#   'do',
#   'protect',
#   'your',
#   'loved',
#   'ones',
#   'stop',
#   'virus',
#   'mutating',
#   '.',
#   '#'],
#  ['you',
#   'know',
#   'you',
#   'wife',
#   'could',
#   'just',
#   'get',
#   'vaccinated',
#   '.',
#   'has',
#   'be',
#   'less',
#   'hassle',
#   'than',
#   'getting',
#   'fake',
#   'card',
#   '.'],
#  ['i',
#   'returned',
#   'teaching',
#   'after',
#   'winter',
#   'break',
#   'got',
#   'couid',
#   'four',
#   'days',
#   'later',
#   'despite',
#   'being',
#   'triple',
#   'vaccinated',
#   'wearing',
#   'know',
#   '.',
#   'now',
#   'i',
#   'wish',
#   'my',
#   'district',
#   'had',
#   'hit',
#   'pause',
#   'button',
#   '.'],
#  ['i',
#   'was',
#   'busy',
#   'yesterday',
#   'it',
#   'was',
#   'larry',
#   "'",
#   'i',
#   'with',
#   'birthday',
#   '.',
#   'i',
#   'organized',
#   'dinner',
#   'party',
#   'twelve',
#   'private',
#   'room',
#   '.',
#   'everyone',
#   'needed',
#   'be',
#   'vaccinated',
#   '.'],
#  ['some',
#   'are',
#   'not',
#   'getting',
#   'vaccinated',
#   'show',
#   'support',
#   'against',
#   'being',
#   'forced',
#   'getting',
#   'it',
#   '.',
#   'nobody',
#   'usa',
#   'has',
#   'been',
#   'vaccinated',
#   'by',
#   'force',
#   '.',
#   'your',
#   'employer',
#   'making',
#   'rule',
#   'that',
#   'employees',
#   'get',
#   'shot',
#   'is',
#   'perfectly',
#   'legal',
#   'but',
#   'you',
#   "'",
#   're',
#   'still',
#   'left',
#   'with',
#   'choice',
#   'as',
#   'getting',
#   'vaccinated',
#   'or',
#   'not'],
#  ['there',
#   'are',
#   'plenty',
#   'intelligent',
#   'plumbers',
#   'that',
#   'are',
#   'vaccinated',
#   '.',
#   'please',
#   'do',
#   'not',
#   'make',
#   'assumption',
#   'that',
#   'just',
#   'because',
#   'someone',
#   'is',
#   'trade',
#   'they',
#   'are',
#   'idiot',
#   'that',
#   'does',
#   'not',
#   'believe',
#   'vaccinations',
#   'science',
#   '.'],
#  ['i',
#   'monday',
#   'night',
#   'hubba',
#   'at',
#   'dna',
#   'lounge',
#   'tonight',
#   ':',
#   'mon',
#   'jan',
#   'seventeen',
#   ',',
#   'up',
#   'vaccinated',
#   'only',
#   '.',
#   'mask',
#   'up',
#   '.',
#   '#',
#   'dnalounge',
#   '#',
#   'mondaynighthubba',
#   '#',
#   'hubbahubbarevue',
#   '#',
#   'burlesque',
#   '#',
#   'vaccinatedonly',
#   '#',
#   'markup',
#   '#',
#   'sanfrancisco'],
#  ['i',
#   'death',
#   'guild',
#   'at',
#   'dna',
#   'lounge',
#   'tonight',
#   ':',
#   'mon',
#   'jan',
#   'seventeen',
#   ',',
#   '9Happy_face_smiley0pm',
#   'vaccinated',
#   'only',
#   '.',
#   'mask',
#   'up',
#   '.',
#   '#',
#   'dnalounge',
#   '#',
#   'deathguild',
#   '#',
#   'gothic',
#   '#',
#   'industrial',
#   '#',
#   'synthpop',
#   '#',
#   'vaccinatedonly',
#   '#',
#   'markup',
#   '#',
#   'sanfrancisco'],
#  ['wild',
#   'fan',
#   'outside',
#   'ball',
#   'arena',
#   'yelling',
#   'complaining',
#   'because',
#   'i',
#   'the',
#   'game',
#   'starts',
#   'ten',
#   'minutes',
#   'i',
#   'he',
#   'i',
#   'didn',
#   'i',
#   'i',
#   'know',
#   'you',
#   'had',
#   'be',
#   'vaccinated',
#   'or',
#   'have',
#   'negative',
#   'test',
#   'i',
#   'classic'],
#  ['if',
#   'countries',
#   'and',
#   '/',
#   'or',
#   'tournaments',
#   'require',
#   'vaccination',
#   ',',
#   'potential',
#   'participants',
#   'don',
#   'i',
#   'i',
#   'want',
#   'get',
#   'vaccinated',
#   ',',
#   'then',
#   'they',
#   'aren',
#   'i',
#   'i',
#   'allowed',
#   'play',
#   '.',
#   'rest',
#   'is',
#   'just',
#   'noise',
#   '.'],
#  ['.',
#   'get',
#   'vaccinated',
#   'eyessyringebackhand_index_pointing_downmedium',
#   '-',
#   'dark_skin_tone'],
#  ['if',
#   'you',
#   'get',
#   'your',
#   'child',
#   'vaccinated',
#   'protect',
#   'lives',
#   'others',
#   '.'],
#  ['man',
#   'i',
#   'am',
#   'so',
#   'sorry',
#   'you',
#   'were',
#   'attacked',
#   'maxx',
#   'chill',
#   'messaging',
#   '.',
#   'sending',
#   'so',
#   'much',
#   'love',
#   'i',
#   'i',
#   'i',
#   'so',
#   'sorry',
#   'people',
#   'have',
#   'taken',
#   'your',
#   'pro',
#   'vaccine',
#   'stance',
#   'as',
#   'not',
#   'caring',
#   'about',
#   'suffering',
#   'as',
#   'death',
#   'i',
#   'nothing',
#   'wrong',
#   'with',
#   'believing',
#   'vaccines',
#   'you',
#   'convinced',
#   'me',
#   'get',
#   'vaccinated',
#   'purple_heart'],
#  ['i',
#   'asked',
#   'i',
#   'don',
#   "'",
#   'i',
#   'like',
#   'vaccinated',
#   'people',
#   'my',
#   'house',
#   'heart',
#   'kidney',
#   'transplant',
#   'my',
#   'wife',
#   'has',
#   'this',
#   'we',
#   'have',
#   'absolutely',
#   'no',
#   'immune',
#   'systems',
#   'but',
#   'trump',
#   'supporters',
#   'don',
#   "'",
#   'i',
#   'give',
#   'crap',
#   'about',
#   'that',
#   'they',
#   'jeopardize',
#   'their',
#   'kids',
#   'then',
#   'i',
#   'don',
#   "'",
#   'i',
#   'want',
#   'them',
#   'my',
#   'house'],
#  ['our',
#   'own',
#   'amateur',
#   'contact',
#   'tracing',
#   'has',
#   'led',
#   'realization',
#   'my',
#   'roommate',
#   'i',
#   'i',
#   'one',
#   'case',
#   'has',
#   'possibly',
#   'led',
#   'thirteen',
#   'people',
#   'being',
#   'sick',
#   'so',
#   'far',
#   '.',
#   'five',
#   'days',
#   '.',
#   'all',
#   'but',
#   'one',
#   '#',
#   'vaccinated',
#   '#',
#   'boosted',
#   '.',
#   '#',
#   'omicron',
#   'is',
#   'no',
#   'joke',
#   ',',
#   'y',
#   'i',
#   'all',
#   '.',
#   'stay',
#   'safe',
#   '.',
#   '#',
#   'covid19'],
#  ['other',
#   'people',
#   'vaccinated',
#   'does',
#   'protect',
#   'others',
#   '.',
#   'wear',
#   'mask',
#   ',',
#   'i',
#   '-',
#   'ninety-five',
#   'mask',
#   'if',
#   'possible',
#   '.'],
#  ['mandatory', 'children', 'be', 'vaccinated', 'covid19', '.'],
#  ['does',
#   'that',
#   'chart',
#   'say',
#   'uninfected',
#   'people',
#   'are',
#   'reporting',
#   'symptoms',
#   'higher',
#   'than',
#   'people',
#   'infected',
#   'vaccinated',
#   'how',
#   'does',
#   'that',
#   'make',
#   'sense'],
#  ['did',
#   'i',
#   'wear',
#   'my',
#   'green',
#   'wristband',
#   'at',
#   'ballard',
#   'health',
#   'club',
#   'show',
#   'i',
#   "'",
#   'i',
#   'vaccinated',
#   'no',
#   '.',
#   'although',
#   'people',
#   'at',
#   'front',
#   '-',
#   'desk',
#   'know',
#   'me',
#   'it',
#   'doesn',
#   "'",
#   'i',
#   'seem',
#   'like',
#   'people',
#   'wear',
#   'them',
#   'any',
#   'longer',
#   ',',
#   'i',
#   'should',
#   "'",
#   've',
#   '.'],
#  ['i',
#   'follow',
#   'science',
#   '.',
#   'it',
#   'tells',
#   'me',
#   'vaccine',
#   'is',
#   'safe',
#   '.',
#   'i',
#   'am',
#   'vaccinated',
#   'so',
#   'i',
#   'can',
#   'live',
#   '.'],
#  ['this',
#   'is',
#   'wonderful',
#   'news',
#   'vaccinated',
#   'folks',
#   ';',
#   'especially',
#   'with',
#   'more',
#   'contagious',
#   'variants',
#   'like',
#   'omicron',
#   '.'],
#  ['this',
#   'is',
#   'how',
#   'my',
#   'fully',
#   '-',
#   'vaccinated',
#   'immuno',
#   '-',
#   'compromised',
#   'mother',
#   'died',
#   'just',
#   'months',
#   'ago',
#   '.',
#   'if',
#   'you',
#   "'",
#   're',
#   'willing',
#   'get',
#   'treatment',
#   'couid',
#   'at',
#   'hospital',
#   ',',
#   'please',
#   'just',
#   'go',
#   'get',
#   'valued',
#   'skip',
#   'exposing',
#   'people',
#   'who',
#   'could',
#   'die',
#   'be',
#   'whatever',
#   'dumb',
#   'reason',
#   'you',
#   "'",
#   've',
#   'landed',
#   'not',
#   'get',
#   'valued',
#   '.'],
#  ['we',
#   'elect',
#   'get',
#   'standing',
#   'per',
#   '#',
#   'couid',
#   'test',
#   'at',
#   'school',
#   'each',
#   'tuesday',
#   'our',
#   'kids',
#   '.',
#   'this',
#   'week',
#   ',',
#   'test',
#   'result',
#   'had',
#   'big',
#   'delays',
#   '&',
#   'amp',
#   ';',
#   'we',
#   'got',
#   'it',
#   'today',
#   'six',
#   'days',
#   'later',
#   '.',
#   'he',
#   'is',
#   '/',
#   'was',
#   'positive',
#   '.',
#   'tired_face',
#   'thankful',
#   'he',
#   'is',
#   'vaccinated',
#   '&',
#   'amp',
#   ';',
#   'is',
#   'one',
#   'ten',
#   '%',
#   'kids',
#   'who',
#   'wears',
#   'mask',
#   '.',
#   'uf',
#   '#',
#   'omicron',
#   'is',
#   'everywhere',
#   '.'],
#  ['i',
#   'heard',
#   'that',
#   'even',
#   'vaccinated',
#   'people',
#   'who',
#   'get',
#   'couid',
#   'can',
#   'lose',
#   'their',
#   'taste',
#   'smell',
#   '.',
#   'i',
#   'can',
#   'still',
#   'smell',
#   'taste',
#   '...',
#   'unfortunately',
#   '.',
#   'i',
#   'was',
#   'kinda',
#   'hoping',
#   'get',
#   'that',
#   'feature',
#   'so',
#   'i',
#   'could',
#   'maybe',
#   'have',
#   'easier',
#   'time',
#   'not',
#   'eating',
#   'everything',
#   'around',
#   'me',
#   'all',
#   'time',
#   '.'],
#  ['i',
#   'had',
#   'same',
#   'symptoms',
#   'as',
#   'you',
#   'no',
#   'i',
#   'i',
#   'i',
#   'not',
#   'vaccinated',
#   '.',
#   'smiling_face_with_smiling_eyes',
#   '.',
#   'i',
#   'i',
#   've',
#   'been',
#   'out',
#   'work',
#   'about',
#   'two',
#   'weeks',
#   'but',
#   'have',
#   'felt',
#   'ready',
#   'go',
#   'back',
#   'work',
#   'about',
#   'week',
#   'ago',
#   'smiling_face_with_smiling_eyes',
#   '.',
#   'liberal',
#   'bosses',
#   'are',
#   'too',
#   'paranoid',
#   'let',
#   'me',
#   'go',
#   'back',
#   '.',
#   'tests',
#   'are',
#   'taking',
#   'too',
#   'damned',
#   'long',
#   'come',
#   'back',
#   'face_with_monocle',
#   '.',
#   'folded_handslatin_cross',
#   'i',
#   'United_States'],
#  ['i',
#   'hate',
#   'admit',
#   'it',
#   'at',
#   'this',
#   'time',
#   'timer_clock',
#   ',',
#   'i',
#   'would',
#   'say',
#   'yes',
#   '.',
#   'it',
#   'shows',
#   'me',
#   'that',
#   'they',
#   'are',
#   'racist',
#   ',',
#   'certainly',
#   'not',
#   'vaccinated',
#   '.'],
#  ['one',
#   '/',
#   'seventeen',
#   '/',
#   'two thousand and twenty-two',
#   ',',
#   'note',
#   'majority',
#   'er',
#   "'",
#   'i',
#   'arizona',
#   'have',
#   'reached',
#   'capacity',
#   ',',
#   'read',
#   'below',
#   'most',
#   'are',
#   'not',
#   'vaccinated',
#   'couid',
#   '-',
#   'nineteen',
#   '.',
#   'this',
#   'comes',
#   'arizona',
#   'department',
#   'health',
#   '.'],
#  ['why',
#   'are',
#   'post',
#   'secondary',
#   'classes',
#   'on',
#   '-',
#   'line',
#   'until',
#   'end',
#   'february',
#   'school',
#   'age',
#   'children',
#   'are',
#   'back',
#   'school',
#   '.',
#   'post',
#   'secondary',
#   'should',
#   'be',
#   'person',
#   'all',
#   'fully',
#   'vaccinated',
#   'students',
#   '.',
#   'if',
#   'classes',
#   'are',
#   'line',
#   'tuition',
#   'subsidies',
#   'should',
#   'be',
#   'provided',
#   'students',
#   '.'],
#  ['well',
#   'thanks',
#   'listening',
#   ',',
#   'that',
#   "'",
#   'i',
#   'huge',
#   'compliment',
#   'me',
#   'but',
#   'cac',
#   'currently',
#   'qualifies',
#   'one',
#   'dose',
#   'mrna',
#   'as',
#   'partially',
#   'vaccinated',
#   'one',
#   'i',
#   '&',
#   'amp',
#   ';',
#   'i',
#   ',',
#   'two',
#   'as',
#   'fully',
#   'vaccinated',
#   ',',
#   'three',
#   'as',
#   'fully',
#   'vaccinated',
#   'boosted',
#   '.',
#   'that',
#   'may',
#   'change',
#   'but',
#   'my',
#   'knowledge',
#   'it',
#   'has',
#   'not',
#   'currently',
#   '.'],
#  ['when',
#   'you',
#   'follow',
#   'rules',
#   'but',
#   'get',
#   'deported',
#   'by',
#   'court',
#   'public',
#   'opinion',
#   '.',
#   'yes',
#   ',',
#   'he',
#   'should',
#   "'",
#   've',
#   'been',
#   'vaccinated',
#   'but',
#   'australia',
#   'didn',
#   "'",
#   'i',
#   'require',
#   'it',
#   'with',
#   'proper',
#   'exemptions',
#   'i',
#   'especially',
#   'if',
#   'your',
#   'famous',
#   'foreign',
#   'national',
#   '.'],
#  ['i',
#   'think',
#   'they',
#   'will',
#   'expect',
#   'me',
#   'tell',
#   'truth',
#   'immigration',
#   'documents',
#   'be',
#   'vaccinated',
#   '.'],
#  ['expect',
#   'my',
#   'tell',
#   'truth',
#   'immigration',
#   'documents',
#   'get',
#   'vaccinated'],
#  ['wear',
#   'mask',
#   ',',
#   'they',
#   'said',
#   '...',
#   'get',
#   'vaccinated',
#   ',',
#   'they',
#   'said',
#   '.',
#   'get',
#   'another',
#   'shot',
#   ',',
#   'another',
#   '...',
#   'get',
#   'sick',
#   'anyway',
#   '...'],
#  ['i',
#   'refuse',
#   'associate',
#   'with',
#   'people',
#   'that',
#   'refuse',
#   'get',
#   'vaccinated'],
#  ['no',
#   ',',
#   'anymore',
#   'than',
#   'i',
#   'feel',
#   'sorry',
#   'soap',
#   'opera',
#   'starts',
#   'that',
#   'got',
#   'fire',
#   'because',
#   'they',
#   'wouldn',
#   "'",
#   'i',
#   'get',
#   'vaccinated',
#   '.'],
#  ['no',
#   'they',
#   'are',
#   'not',
#   '.',
#   '"',
#   'fully',
#   'vaccinated',
#   '"',
#   '"',
#   'boosted',
#   '"',
#   'are',
#   'two',
#   'different',
#   'terms',
#   '.',
#   'no',
#   'one',
#   'is',
#   'saying',
#   'people',
#   'who',
#   'got',
#   'two',
#   'shots',
#   'are',
#   'not',
#   'vaccinated',
#   '.'],
#  ['who',
#   'cares',
#   'if',
#   'it',
#   'means',
#   'we',
#   'can',
#   'i',
#   'i',
#   'go',
#   'back',
#   'normal',
#   '.',
#   'with',
#   'eighty-eight',
#   '%',
#   'people',
#   'being',
#   'fully',
#   'vaccinated',
#   ',',
#   'if',
#   'we',
#   'can',
#   'i',
#   'i',
#   'open',
#   'safely',
#   'we',
#   'never',
#   'will',
#   ',',
#   'van',
#   'rates',
#   'will',
#   'never',
#   'be',
#   'that',
#   'high',
#   'again',
#   '.',
#   'stop',
#   'scaring',
#   'people',
#   'promote',
#   'healthy',
#   'living',
#   '.',
#   'you',
#   'i',
#   're',
#   'health',
#   'minister',
#   'not',
#   'couid',
#   'reporter'],
#  ['i',
#   "'",
#   'i',
#   'fully',
#   'vaccinated',
#   'if',
#   'there',
#   'is',
#   'fourth',
#   'i',
#   "'",
#   'all',
#   'get',
#   'that',
#   'too',
#   'i',
#   'also',
#   'wear',
#   'mask',
#   'social',
#   'distance',
#   'use',
#   'hand',
#   'sanitizer',
#   'as',
#   'well',
#   'as',
#   'had',
#   'one',
#   'negative',
#   'couid',
#   'test',
#   'i',
#   'with',
#   'you',
#   'i',
#   'wish',
#   'more',
#   'people',
#   'were',
#   'but',
#   'you',
#   'can',
#   "'",
#   'i',
#   'force',
#   'that',
#   'decision',
#   'people',
#   'because',
#   'they',
#   'will',
#   'resist',
#   'even',
#   'stronger'],
#  ['somehow',
#   ',',
#   'my',
#   'youngest',
#   ',',
#   'one',
#   'who',
#   'still',
#   'cannot',
#   'be',
#   'vaccinated',
#   'because',
#   'he',
#   'is',
#   'too',
#   'young',
#   ',',
#   'is',
#   'only',
#   'one',
#   'our',
#   'house',
#   'testing',
#   'negative',
#   '.',
#   'he',
#   'was',
#   'negative',
#   'with',
#   'me',
#   'last',
#   'tuesday',
#   '.',
#   'i',
#   'was',
#   'positive',
#   'friday',
#   '.',
#   'my',
#   'oldest',
#   'is',
#   'positive',
#   'today',
#   '.',
#   'youngest',
#   'just',
#   'got',
#   'his',
#   'negative',
#   'result',
#   'back',
#   '.'],
#  ['who',
#   'cares',
#   '.',
#   'at',
#   'this',
#   'point',
#   'only',
#   'value',
#   'shot',
#   'is',
#   'self',
#   'protection',
#   '.',
#   'we',
#   'don',
#   "'",
#   'i',
#   'even',
#   'know',
#   'if',
#   'that',
#   'will',
#   'hold',
#   'up',
#   '.',
#   'obviously',
#   'this',
#   'is',
#   'devastating',
#   'those',
#   'who',
#   'sold',
#   'story',
#   'virtue',
#   'when',
#   'they',
#   'got',
#   'vaccinated',
#   '.'],
#  ['sec',
#   '.',
#   'defense',
#   'tested',
#   'positive',
#   'week',
#   'or',
#   'so',
#   'ago',
#   '.',
#   'i',
#   'would',
#   'think',
#   ',',
#   'even',
#   'with',
#   'precautions',
#   ',',
#   'many',
#   'pentagon',
#   'will',
#   'be',
#   'positive',
#   '.',
#   'hopefully',
#   'being',
#   'vaccinated',
#   'they',
#   'have',
#   'mild',
#   'no',
#   'symptoms',
#   '.'],
#  ['if',
#   'your',
#   'vaccinated',
#   'you',
#   'i',
#   'all',
#   'be',
#   'fine',
#   '.',
#   'kids',
#   'need',
#   'be',
#   'class',
#   '.',
#   'if',
#   'someone',
#   'is',
#   'fearful',
#   'they',
#   'can',
#   'go',
#   'powerschool',
#   '.'],
#  ['did',
#   'folks',
#   'doing',
#   '"',
#   'death',
#   'nile',
#   '"',
#   'not',
#   'require',
#   'that',
#   'gal',
#   'get',
#   'vaccinated'],
#  ['low',
#   'key',
#   'way',
#   'tell',
#   'someone',
#   'you',
#   'are',
#   'vaccinateTongue_sticking_out_cheeky_playful_or_blowing_a_raspberry',
#   'i',
#   'just',
#   'got',
#   'back',
#   'some',
#   'european',
#   'country',
#   'last',
#   'week'],
#  ['vaccination',
#   'info',
#   ':',
#   'percentage',
#   'overall',
#   'population',
#   'fully',
#   'vaccinateTongue_sticking_out_cheeky_playful_or_blowing_a_raspberry',
#   'seventy-one',
#   '.',
#   'six',
#   '*',
#   'percentage',
#   'adults',
#   'eighteen',
#   '+',
#   'with',
#   'at',
#   'least',
#   'one',
#   'dose',
#   ':',
#   'ninety-three',
#   '.',
#   'three',
#   'percentage',
#   'overall',
#   'population',
#   'with',
#   'at',
#   'least',
#   'one',
#   'jab',
#   ':',
#   'eighty-two',
#   '.',
#   'one',
#   '*',
#   'maryland',
#   'ranks',
#   'ith',
#   'nation',
#   'highest',
#   'fully',
#   'vaccinated',
#   'percentage'],
#  ['people',
#   'who',
#   'don',
#   'i',
#   'i',
#   'like',
#   'killing',
#   'other',
#   'people',
#   'get',
#   'vaccinated'],
#  ['get', 'vaccinated', 'we', 'want', 'you', 'play'],
#  ['how', 'are', 'vaccinated', 'harming', 'un', 'valued'],
#  ['you',
#   'haven',
#   "'",
#   'i',
#   'explained',
#   'how',
#   'bearskin',
#   'lake',
#   'has',
#   'had',
#   'massive',
#   'outbreak',
#   'over',
#   'half',
#   'population',
#   'despite',
#   'being',
#   'overwhelming',
#   'vaccinated',
#   'some',
#   'highest',
#   'numbers',
#   'country',
#   'is',
#   'indigenous',
#   'community',
#   'lying',
#   'or',
#   'is',
#   'it',
#   'government',
#   '/',
#   'big',
#   'pharma',
#   'awaiting',
#   'your',
#   'reply',
#   'face_blowing_a_kiss'],
#  ['vaccinated',
#   'or',
#   'not',
#   'why',
#   'are',
#   'you',
#   'bringing',
#   'fifteen',
#   'people',
#   'ny',
#   'eat',
#   'olive',
#   'garden'],
#  ['is',
#   'it',
#   'complicated',
#   'your',
#   'tiny',
#   'mind',
#   'understand',
#   'medical',
#   'staff',
#   'were',
#   'fired',
#   'not',
#   'getting',
#   'vaccinated',
#   '.',
#   'cac',
#   'cut',
#   'quarantine',
#   'limit',
#   'back',
#   'medical',
#   'staff',
#   'that',
#   'are',
#   'vaccinated',
#   '.',
#   'they',
#   'can',
#   'come',
#   'back',
#   'work',
#   'after',
#   'five',
#   'days',
#   'even',
#   'if',
#   'they',
#   'still',
#   'have',
#   'mild',
#   'symptoms',
#   '.'],
#  ['have', 'you', 'been', 'vaccinated', 'have', 'you', 'been', 'boosted'],
#  ['if',
#   'you',
#   'have',
#   'pay',
#   'someone',
#   'get',
#   'vaccinated',
#   'something',
#   'is',
#   'very',
#   'wrong'],
#  ['also', ',', 'lot', 'globe', 'is', 'not', 'vaccinated', '.'],
#  ['get',
#   'vaccinated',
#   '.',
#   'ease',
#   'burden',
#   '.',
#   'do',
#   'your',
#   'part',
#   '.',
#   'face_with_medical_mask'],
#  ['curious',
#   'nick',
#   'as',
#   'you',
#   'posted',
#   'this',
#   'did',
#   'it',
#   'ever',
#   'occur',
#   'ask',
#   'obvious',
#   'follow',
#   'up',
#   '..."',
#   'governor',
#   'your',
#   'own',
#   'children',
#   'attend',
#   'private',
#   'school',
#   'maryland',
#   'that',
#   'requires',
#   'masks',
#   'vaccinations',
#   'students',
#   'staff',
#   '...',
#   'is',
#   'your',
#   'family',
#   'vaccinated',
#   'how',
#   'does',
#   'square',
#   'with',
#   'your',
#   'executive',
#   'order'],
#  ['you',
#   'say',
#   'you',
#   'are',
#   'catholic',
#   ',',
#   'conservative',
#   'pro',
#   '-',
#   'life',
#   'but',
#   'you',
#   'are',
#   'wrong',
#   '.',
#   'only',
#   'about',
#   'sixty-five',
#   '%',
#   'are',
#   'vaccinated',
#   '.'],
#  ['tell',
#   'me',
#   'if',
#   'this',
#   'is',
#   'dis',
#   '-',
#   'info',
#   'based',
#   'facts',
#   '...',
#   'there',
#   'is',
#   'virtually',
#   'no',
#   'reason',
#   'vaccinate',
#   'healthy',
#   'americans',
#   'under',
#   'sixty-five',
#   'years',
#   'old',
#   'with',
#   'no',
#   'pre',
#   '-',
#   'existing',
#   'conditions',
#   ',',
#   'because',
#   'even',
#   'vaccinated',
#   'can',
#   'both',
#   'get',
#   'spread',
#   'corona',
#   'virus',
#   '.',
#   'vaccinate',
#   'high',
#   'risk',
#   'unhealthy'],
#  ['you', 'forgot', 'circle', 'i', 'vaccinated', 'i', 'offhand'],
#  ['maybe', 'consider', 'getting', 'vaccinated'],
#  ['man',
#   'has',
#   'had',
#   'couid',
#   '.',
#   'what',
#   'hell',
#   'is',
#   'wrong',
#   'with',
#   'you',
#   'people',
#   '.',
#   'no',
#   'matter',
#   'if',
#   'we',
#   "'",
#   're',
#   'vaccinated',
#   'or',
#   'have',
#   'had',
#   'couid',
#   ',',
#   'sooner',
#   'or',
#   'later',
#   'we',
#   "'",
#   'all',
#   'get',
#   'some',
#   'variation',
#   'virus',
#   '.',
#   'sooner',
#   'or',
#   'later',
#   'we',
#   'will',
#   'die',
#   'something',
#   '.'],
#  ['your',
#   'man',
#   'was',
#   'wrong',
#   '.',
#   'he',
#   'wasn',
#   "'",
#   'i',
#   'vaccinated',
#   '.',
#   'he',
#   'lied',
#   'about',
#   'it',
#   '.',
#   'he',
#   'tried',
#   'intimidate',
#   'tennis',
#   'people',
#   'government',
#   'because',
#   'his',
#   'celebrity',
#   '.',
#   'they',
#   'called',
#   'him',
#   'it',
#   'threw',
#   'him',
#   'out',
#   '.',
#   'why',
#   'would',
#   'you',
#   'president',
#   'serbia',
#   'even',
#   'want',
#   'get',
#   'involved'],
#  ['everyone',
#   'should',
#   'get',
#   'vaccinated',
#   'period',
#   'they',
#   'do',
#   'not',
#   'have',
#   'right',
#   'possibly',
#   'infect',
#   'others',
#   'during',
#   'nationally',
#   'known',
#   'health',
#   'emergency',
#   '#',
#   'showmeyourpapers',
#   '&',
#   'amp',
#   ';',
#   'hospitals',
#   'will',
#   'soon',
#   'have',
#   'prioritize',
#   'people',
#   'by',
#   'treating',
#   'vaccinated',
#   'first',
#   '#',
#   'getjabbed',
#   'stop',
#   'nonsense',
#   'lipsticksheritha'],
#  ['under',
#   'the',
#   'age',
#   'eighteen',
#   'your',
#   'chances',
#   'dying',
#   'couid',
#   'is',
#   'about',
#   'one',
#   'million',
#   '.',
#   'about',
#   'same',
#   'odds',
#   'getting',
#   'struck',
#   'by',
#   'lighting',
#   '.',
#   'countries',
#   'with',
#   'highest',
#   'vaccination',
#   'rates',
#   'have',
#   'most',
#   'cases',
#   '.',
#   'shouldn',
#   "'",
#   'i',
#   'it',
#   'be',
#   'most',
# ...
#   '.',
#   'i',
#   'wonder',
#   'if',
#   'grant',
#   'funding',
#   'is',
#   'available'],
#  ['tried',
#   'warn',
#   'folks',
#   'december',
#   '.',
#   'people',
#   'still',
#   'not',
#   'vaccinated',
#   'still',
#   'refusing',
#   'wear',
#   'i',
#   'ninety-five',
#   'mask',
#   '.'],
#  ['president',
#   'biden',
#   'since',
#   'you',
#   'you',
#   'won',
#   'two thousand and twenty',
#   'election',
#   '.',
#   'you',
#   'care',
#   'so',
#   'much',
#   'people',
#   'get',
#   'vaccinated',
#   'get',
#   'their',
#   'booster',
#   'children',
#   'too',
#   '.',
#   'you',
#   'are',
#   'blessed',
#   '.'],
#  ['anyway',
#   '.',
#   'i',
#   'say',
#   'all',
#   'that',
#   'tell',
#   'y',
#   'i',
#   'all',
#   'quite',
#   'simply',
#   'i',
#   'wear',
#   'your',
#   'masks',
#   '.',
#   'be',
#   'respectful',
#   'people',
#   'i',
#   'i',
#   'personal',
#   'space',
#   '.',
#   'wash',
#   'your',
#   'hands',
#   '.',
#   'get',
#   'vaccinated',
#   'boosted',
#   '.',
#   'if',
#   'you',
#   'i',
#   're',
#   'having',
#   'symptoms',
#   'please',
#   'remember',
#   'yourself',
#   'first',
#   ';',
#   'you',
#   'never',
#   'know',
#   'who',
#   'or',
#   'what',
#   'you',
#   'have',
#   'around',
#   'that',
#   'you',
#   'can',
#   'hurt',
#   '.'],
#  ['but',
#   'remember',
#   'that',
#   'all',
#   'other',
#   'tennis',
#   'players',
#   'are',
#   'vaccinated',
#   'as',
#   'required',
#   'by',
#   'australian',
#   'government',
#   '.',
#   'they',
#   'all',
#   'knew',
#   'couid',
#   'vaccination',
#   'rules',
#   'before',
#   'they',
#   'ever',
#   'left',
#   'home',
#   '.',
#   'rules',
#   'are',
#   'rules',
#   '.'],
#  ['all',
#   'you',
#   'anti',
#   '-',
#   'vaccinated',
#   'people',
#   '....',
#   'pay',
#   'attention'],
#  ['antiwar',
#   'movement',
#   'is',
#   'dying',
#   'their',
#   'army',
#   'will',
#   'be',
#   'defeated',
#   'vaccinated',
#   'folks',
#   'will',
#   'celebrate',
#   'worldwide',
#   'health',
#   'restrictions',
#   'will',
#   'be',
#   'lifted',
#   'masks',
#   'will',
#   'leave',
#   'mouth',
#   'nose',
#   ',',
#   'go',
#   'back',
#   'eyes'],
#  ['i',
#   'feel',
#   'same',
#   'way',
#   'but',
#   'i',
#   'not',
#   'sorry',
#   'at',
#   'all',
#   '.',
#   'if',
#   'person',
#   'is',
#   'truly',
#   'unable',
#   'get',
#   'vaccinated',
#   'due',
#   'medical',
#   'condition',
#   'or',
#   'if',
#   'it',
#   "'",
#   'i',
#   'child',
#   'whose',
#   'parents',
#   'won',
#   "'",
#   'i',
#   'allow',
#   'vaccination',
#   'they',
#   'should',
#   'be',
#   'allowed',
#   'in',
#   '.',
#   'deniers',
#   ',',
#   'maga',
#   "'",
#   'i',
#   'need',
#   'go',
#   'home',
#   '.'],
#  ['now',
#   'because',
#   'her',
#   'is',
#   ',',
#   'my',
#   'siblings',
#   'grandmother',
#   'all',
#   'live',
#   'together',
#   'care',
#   'her',
#   '.',
#   'we',
#   'are',
#   'all',
#   'vaccinated',
#   ',',
#   'boosted',
#   ',',
#   'alluded',
#   '.',
#   'did',
#   'it',
#   'as',
#   'soon',
#   'as',
#   'it',
#   'was',
#   'available',
#   '.',
#   'she',
#   'however',
#   ',',
#   'cannot',
#   'be',
#   ',',
#   'because',
#   'again',
#   ',',
#   'fevers',
#   'her',
#   'case',
#   ',',
#   'cause',
#   'seizures',
#   '.',
#   'more',
#   'that',
#   'moment',
#   '.'],
#  ['site',
#   'at',
#   'mega',
#   '-',
#   'cat',
#   'colony',
#   'other',
#   'day',
#   '-',
#   'over',
#   'thirty-five',
#   'cats',
#   'we',
#   'i',
#   'all',
#   'be',
#   'back',
#   'soon',
#   'get',
#   'all',
#   'these',
#   'kitties',
#   'trapped',
#   ',',
#   'neutered',
#   ',',
#   'vaccinated',
#   '.',
#   'it',
#   'i',
#   'i',
#   'lot',
#   'work',
#   '-',
#   'want',
#   'help',
#   'we',
#   'can',
#   'always',
#   'use',
#   'volunteers',
#   ':',
#   'also',
#   ',',
#   'watch',
#   'end',
#   'cute',
#   'goat',
#   'content',
#   '.'],
#  ['you',
#   'have',
#   'get',
#   'vaccinated',
#   'so',
#   'no',
#   'one',
#   'else',
#   'does',
#   '.',
#   'i',
#   'got',
#   'my',
#   'third',
#   'dose',
#   'yesterday',
#   '.',
#   'Canada'],
#  ['problem',
#   'wouldnt',
#   'be',
#   'funding',
#   '.',
#   'problem',
#   'would',
#   'be',
#   'licensing',
#   ',',
#   'etc',
#   '.',
#   'way',
#   'our',
#   'government',
#   'is',
#   'going',
#   'they',
#   'would',
#   'revoke',
#   'licenses',
#   'doctors',
#   'medical',
#   'professionals',
#   'who',
#   'dont',
#   'get',
#   'vaccinated',
#   '.',
#   'no',
#   'licenses',
#   '=',
#   'no',
#   'insurance',
#   'claim',
#   'payouts',
#   '=',
#   'no',
#   'money',
#   '=',
#   'youre',
#   'dead',
#   'water',
#   '.'],
#  ['there',
#   "'",
#   'i',
#   'problem',
#   '.',
#   'there',
#   'should',
#   'be',
#   'no',
#   'exemptions',
#   '.',
#   'you',
#   "'",
#   're',
#   'vaccinated',
#   'you',
#   'play',
#   ',',
#   'you',
#   "'",
#   're',
#   'not',
#   'vaccinated',
#   'you',
#   'don',
#   "'",
#   'i',
#   'play',
#   '.',
#   'tennis',
#   'is',
#   'not',
#   'essential',
#   'activity',
#   ',',
#   'saving',
#   'lives',
#   'is',
#   '.'],
#  ['my',
#   'grandma',
#   'is',
#   'triple',
#   'vaccinated',
#   'still',
#   'went',
#   'out',
#   'loves',
#   'buy',
#   'news',
#   'disappointed_face',
#   'i',
#   'hate',
#   'how',
#   'much',
#   'media',
#   'has',
#   'scared',
#   'people'],
#  ['last',
#   'forty-eight',
#   'hours',
#   ':',
#   'russian',
#   'delegation',
#   'walked',
#   'out',
#   'un',
#   ':',
#   'china',
#   'gave',
#   'taiwan',
#   'ultimatum',
#   'surrender',
#   'immediately',
#   'or',
#   'face',
#   'invasion',
#   ',',
#   'prince',
#   'andrew',
#   'is',
#   'now',
#   'arrested',
#   'his',
#   'nasty',
#   'little',
#   'escapades',
#   'epstein',
#   'island',
#   ',',
#   'biden',
#   'vaccinated',
#   'mandate',
#   'private',
#   'companies',
#   'is',
#   'destroyed',
#   'by',
#   'scouts'],
#  ['-',
#   'couid',
#   'vaccination',
#   'provides',
#   'almost',
#   'complete',
#   'protection',
#   'against',
#   'serious',
#   'morbidity',
#   '/',
#   'mortality',
#   '-',
#   'the',
#   'five',
#   '%',
#   'vaccinated',
#   'folks',
#   'who',
#   'get',
#   'couid',
#   'will',
#   'not',
#   'transmit',
#   'it',
#   'others',
#   '-',
#   'side',
#   'effects',
#   'vaccine',
#   'are',
#   'far',
#   'less',
#   'than',
#   'flu'],
#  ['he',
#   "'",
#   'i',
#   'vaccinated',
#   'though',
#   '.',
#   'not',
#   'sure',
#   'if',
#   'boosted',
#   '.',
#   'so',
#   'either',
#   'then',
#   'vaccine',
#   'is',
#   'garbage',
#   'couid',
#   'can',
#   'still',
#   'hit',
#   'you',
#   'with',
#   'most',
#   'severe',
#   'effects',
#   'or',
#   'vaccine',
#   'caused',
#   'it',
#   '.',
#   'either',
#   'way',
#   'it',
#   "'",
#   'i',
#   'now',
#   'losing',
#   'situation',
#   'they',
#   'have',
#   'fix',
#   'it'],
#  ['i',
#   'been',
#   'told',
#   'my',
#   'cousin',
#   'get',
#   'vaccinated',
#   ',',
#   'now',
#   'omicron',
#   'is',
#   'doing',
#   'her',
#   'dirty',
#   'person_shruggingmedium_skin_tone',
#   'i',
#   'female_sign',
#   'i'],
#  ['same',
#   'republican',
#   'senators',
#   'that',
#   'were',
#   'room',
#   'with',
#   'powerpoint',
#   'how',
#   'overthrow',
#   'government',
#   'said',
#   'nothing',
#   'are',
#   'same',
#   'republican',
#   'senators',
#   'who',
#   'went',
#   'got',
#   'vaccinated',
#   'while',
#   'their',
#   'disinformation',
#   'machine',
#   'told',
#   'their',
#   'base',
#   'not',
#   'to',
#   '...',
#   'republican',
#   'senators',
#   'are',
#   'scum'],
#  ['you',
#   'should',
#   'get',
#   'vaccinated',
#   ',',
#   'homie',
#   '.',
#   'stay',
#   'safe',
#   ',',
#   'hope',
#   'your',
#   'mom',
#   'is',
#   'doing',
#   'well',
#   '.'],
#  ['goal',
#   'is',
#   'get',
#   'people',
#   'vaccinated',
#   'seemingly',
#   'infinite',
#   'number',
#   'times',
#   '.',
#   'treatment',
#   'options',
#   'outside',
#   'this',
#   'narrow',
#   'source',
#   'prevention',
#   'are',
#   'chastised',
#   'ridiculed',
#   '.',
#   'asking',
#   'questions',
#   'about',
#   'narrative',
#   'make',
#   'you',
#   'crackpot',
#   '.',
#   'situation',
#   'warrants',
#   'certain',
#   'level',
#   'skepticism'],
#  ['get',
#   'vaccinated',
#   '.',
#   'get',
#   'boosted',
#   '.',
#   'wear',
#   'mask',
#   'indoors',
#   '.',
#   'love',
#   '-',
#   'you_gestureface_with_medical_masksyringemicrobe'],
#  ['well',
#   ',',
#   'if',
#   'ever',
#   'there',
#   'was',
#   'way',
#   'get',
#   'these',
#   'idiots',
#   'vaccinated',
#   ',',
#   'threaten',
#   'their',
#   'i',
#   'manhood',
#   'face_with_tears_of_joy',
#   'i',
#   'with',
#   '#',
#   'shrinkage',
#   '~',
#   '#',
#   'coviddick',
#   '#',
#   'covidiots',
#   '#',
#   'covid19'],
#  ['im',
#   'vaccinated',
#   'boosted',
#   'still',
#   'couldn',
#   'i',
#   'i',
#   'get',
#   'fucking',
#   'couid',
#   'test',
#   'days',
#   'after',
#   'i',
#   'got',
#   'exposed',
#   '.',
#   'i',
#   'had',
#   'no',
#   'sick',
#   'leave',
#   'work',
#   'either',
#   '.',
#   'work',
#   'that'],
#  ['well',
#   'i',
#   'caught',
#   'couid',
#   ',',
#   'good',
#   'thing',
#   'i',
#   "'",
#   'i',
#   'vaccinated',
#   'so',
#   'symptoms',
#   'aren',
#   "'",
#   'i',
#   'too',
#   'bad',
#   'right',
#   'now',
#   '.',
#   'thanks',
#   'any',
#   'all',
#   'well',
#   'wishes',
#   'prayers',
#   '.'],
#  ['if',
#   'you',
#   'want',
#   'kids',
#   'back',
#   'school',
#   '...',
#   'get',
#   'our',
#   'kids',
#   'vaccinated'],
#  ['i',
#   "'",
#   'i',
#   'not',
#   'getting',
#   'vaccinationsyringe',
#   'due',
#   'medical',
#   'problemssweat_dropletshundred_pointsface_with_raised_eyebrowfootprintsalembic',
#   'i',
#   'test_tubepetri_dishdnamicroscopesyringe',
#   'still',
#   'not',
#   'determined',
#   'get',
#   'vaccinatedsyringemicroscopednapetri_dishtest_tubealembic',
#   'i',
#   'face_with_raised_eyebrowneutral_faceexpressionless_face'],
#  ['people',
#   'need',
#   'stop',
#   'acting',
#   'like',
#   'children',
#   'get',
#   'vaccinated',
#   '.'],
#  ['nice',
#   'thy',
#   'was',
#   'me',
#   'wednesday',
#   '.',
#   'did',
#   'you',
#   'have',
#   'symptoms',
#   'turns',
#   'out',
#   'going',
#   'arena',
#   'country',
#   'concert',
#   'packed',
#   'with',
#   'unmasked',
#   'vaccinated',
#   'people',
#   'wasn',
#   'i',
#   'i',
#   'brightest',
#   'idea',
#   ','],
#  ['you',
#   'know',
#   '...',
#   'its',
#   'infuriating',
#   'during',
#   'first',
#   'year',
#   'couid',
#   ',',
#   'hospital',
#   'my',
#   'wife',
#   'works',
#   'received',
#   'billions',
#   'federal',
#   'bailouts',
#   'but',
#   'meanwhile',
#   'my',
#   'wife',
#   'kept',
#   'getting',
#   'canceled',
#   'shifts',
#   '.',
#   'they',
#   'got',
#   'rich',
#   'we',
#   'suffered',
#   '.',
#   'now',
#   ',',
#   'unless',
#   'she',
#   'gets',
#   'vaccinated',
#   'she',
#   'will',
#   'be',
#   'fired',
#   '.',
#   'total',
#   'is'],
#  ['i',
#   'don',
#   "'",
#   'i',
#   'see',
#   'him',
#   'serving',
#   'texas',
#   'house',
#   'or',
#   'senate',
#   '.',
#   'are',
#   'vaccinated',
#   'people',
#   'not',
#   'also',
#   'dying',
#   'maybe',
#   'you',
#   'should',
#   'stick',
#   'lying',
#   'about',
#   'people',
#   'you',
#   'know',
#   '.',
#   'not',
#   'my',
#   'friends',
#   '.'],
#  ['you', 'gotta', 'be', 'vaccinated', 'go', 'see', 'harlem', 'globetrotters'],
#  ['one',
#   '.',
#   'take',
#   'care',
#   'two',
#   '.',
#   'thank',
#   'you',
#   'being',
#   'fully',
#   'vaccinated'],
#  ['let',
#   'i',
#   'i',
#   '#',
#   'getvaccinated',
#   'because',
#   'we',
#   'i',
#   're',
#   'all',
#   'this',
#   'together',
#   '#',
#   'allmeansall',
#   'with',
#   'rise',
#   '#',
#   'covid19',
#   'cases',
#   '&',
#   'amp',
#   ';',
#   'omicron',
#   ',',
#   'we',
#   'must',
#   'take',
#   'all',
#   'necessary',
#   'precautions',
#   'combat',
#   '#',
#   'covid19',
#   'by',
#   'getting',
#   'vaccinated',
#   ',',
#   'wearing',
#   'mask',
#   '&',
#   'amp',
#   ';',
#   'following',
#   'all',
#   'safety',
#   'protocols',
#   '.',
#   'blue_heartglowing_stargreen_heart',
#   '#',
#   'protectthegusdfamily'],
#  ['my',
#   'wife',
#   'i',
#   'will',
#   'be',
#   'spending',
#   'weekend',
#   'at',
#   'animal',
#   'shelter',
#   'vaccinating',
#   'unwanted',
#   'animals',
#   'before',
#   'they',
#   'get',
#   'put',
#   'down',
#   '.',
#   '#',
#   'stopthespread',
#   '#',
#   'vaccinated',
#   '#',
#   'markup'],
#  ['i',
#   'couldn',
#   "'",
#   'i',
#   'imagine',
#   'how',
#   'poorly',
#   'i',
#   'would',
#   'have',
#   'been',
#   'if',
#   'i',
#   'hadn',
#   "'",
#   'i',
#   'been',
#   'vaccinated',
#   '.'],
#  ['how',
#   'many',
#   'members',
#   'scouts',
#   'are',
#   'vaccinated',
#   'what',
#   'about',
#   'their',
#   'staffs'],
#  ['lol', 'nope', 'he', "'", 'i', 'vaccinated'],
#  ['oh',
#   ',',
#   'my',
#   'bad',
#   '.',
#   'i',
#   'thought',
#   'he',
#   'meant',
#   'it',
#   'wasn',
#   "'",
#   'i',
#   'effective',
#   'against',
#   'virus',
#   'that',
#   "'",
#   'i',
#   'going',
#   'around',
#   'right',
#   'now',
#   '&',
#   'amp',
#   ';',
#   'that',
#   'everyone',
#   "'",
#   'i',
#   'demanding',
#   'we',
#   'get',
#   'vaccinated',
#   'against',
#   '.'],
#  ['i', 'got', 'vaccinated', 'when', 'i', 'was', 'toddler', 'bro', 'chill'],
#  ['whatever',
#   'gets',
#   'it',
#   'done',
#   '.',
#   'i',
#   'understand',
#   'being',
#   'against',
#   'van',
#   'tax',
#   '.',
#   'i',
#   'just',
#   'want',
#   'more',
#   'people',
#   'vaccinated',
#   '.',
#   'that',
#   'man',
#   'we',
#   "'",
#   're',
#   'seeing',
#   'all',
#   'over',
#   'twitter',
#   'this',
#   'morning',
#   'isn',
#   "'",
#   'i',
#   'bad',
#   'person',
#   '.',
#   'he',
#   "'",
#   'i',
#   'victim',
#   'pandemic',
#   '.',
#   'he',
#   'was',
#   'afraid',
#   'followed',
#   'misinformation',
#   'because',
#   'it',
#   'likely',
#   'comforted',
#   'him',
#   '.'],
#  ['omicron',
#   'meet',
#   'portugal',
#   ',',
#   'one',
#   'world',
#   'i',
#   'i',
#   'most',
#   'vaccinated',
#   'nations',
#   '.',
#   'portugal',
#   'has',
#   'vaccinated',
#   '~',
#   'ninety',
#   '%',
#   'its',
#   'total',
#   'population',
#   '.',
#   'Portugal',
#   'don',
#   'i',
#   'i',
#   'tell',
#   'me',
#   'vaccines',
#   'don',
#   'i',
#   'i',
#   'work',
#   '.'],
#  ['yes',
#   'your',
#   'and',
#   'point',
#   '.',
#   'nba',
#   'fact',
#   ',',
#   'treats',
#   'recently',
#   'infected',
#   'players',
#   'as',
#   '"',
#   'vaccinated',
#   'i',
#   'meaning',
#   'they',
#   'follow',
#   'vaccinated',
#   'players',
#   'protocol',
#   'even',
#   'if',
#   'they',
#   'aren',
#   "'",
#   'i',
#   'vaccinated',
#   '.',
#   'it',
#   'makes',
#   'complete',
#   'sense',
#   '.',
#   'i',
#   'think',
#   'ny',
#   'will',
#   'simply',
#   'allow',
#   'performers',
#   'be',
#   'unpaid',
#   'like',
#   'other',
#   'cities',
#   'already'],
#  ['are',
#   'you',
#   'saying',
#   'people',
#   'who',
#   'are',
#   'not',
#   'getting',
#   'vaccinated',
#   'are',
#   'ones',
#   'making',
#   'it',
#   'political',
#   'just',
#   'trying',
#   'clarify',
#   '.'],
#  ['joe',
#   'organ',
#   'has',
#   'no',
#   'idea',
#   'what',
#   'he',
#   "'",
#   'i',
#   'talking',
#   'about',
#   '.',
#   'don',
#   "'",
#   'i',
#   'listen',
#   'him',
#   '.',
#   'get',
#   'vaccinated',
#   '.'],
#  ['i',
#   'call',
#   'triple',
#   'valued',
#   ',',
#   'fully',
#   'vaccinated',
#   '.',
#   'i',
#   'could',
#   'use',
#   'boost'],
#  ['one',
#   '/',
#   'three',
#   'population',
#   'died',
#   ',',
#   'as',
#   'their',
#   'were',
#   'no',
#   'vaccinated',
#   'folks',
#   '.',
#   'this',
#   'is',
#   'probably',
#   'best',
#   'historical',
#   'reason',
#   'get',
#   'vaccinated',
#   'today',
#   '.'],
#  ['yesterday',
#   'i',
#   'posted',
#   'message',
#   'link',
#   'gofundme',
#   'page',
#   'my',
#   'friend',
#   'michael',
#   'i',
#   'root',
#   'fort',
#   'wayne',
#   ',',
#   'indiana',
#   '.',
#   'mike',
#   'was',
#   'hospital',
#   'with',
#   'couid',
#   '-',
#   'nineteen',
#   'related',
#   'pneumonia',
#   'other',
#   'complications',
#   '.',
#   'unfortunately',
#   'we',
#   'lost',
#   'mike',
#   'yesterday',
#   '@',
#   'one thousand, five hundred and forty-four',
#   'est',
#   '.',
#   'mike',
#   'wasn',
#   "'",
#   'i',
#   'vaccinated'],
#  ['he',
#   'isn',
#   "'",
#   'i',
#   'entitled',
#   'his',
#   'own',
#   'opinion',
#   'was',
#   '/',
#   'is',
#   'his',
#   'wife',
#   'vaccinated'],
#  ['more',
#   'americans',
#   'got',
#   'vaccinated',
#   'because',
#   'osha',
#   'forced',
#   'them'],
#  ['lot',
#   'you',
#   'are',
#   'also',
#   'missing',
#   'science',
#   'that',
#   'spread',
#   'can',
#   'still',
#   'happen',
#   'if',
#   'you',
#   'get',
#   'it',
#   'while',
#   'vaccinated',
#   ',',
#   'which',
#   'you',
#   'can',
#   'get',
#   '.',
#   'another',
#   'scientific',
#   'point',
#   'many',
#   'you',
#   'are',
#   'missing',
#   'is',
#   'natural',
#   'immunity',
#   '.',
#   'mandating',
#   'jab',
#   'isn',
#   "'",
#   'i',
#   'going',
#   'prevent',
#   'things',
#   'like',
#   'you',
#   'think',
#   '.',
#   'like',
#   'what',
#   'govt',
#   'claimed'],
#  ['everyone',
#   'who',
#   'is',
#   'medically',
#   'able',
#   'has',
#   'positive',
#   'social',
#   'responsibility',
#   'get',
#   'vaccinated',
#   '.'],
#  ['agree',
#   'that',
#   'exemptions',
#   'should',
#   'not',
#   'exist',
#   'context',
#   'tennis',
#   'tournament',
#   'that',
#   'is',
#   'not',
#   'essential',
#   'activity',
#   '.',
#   'that',
#   'said',
#   '-',
#   'ninety-seven',
#   '%',
#   'players',
#   'at',
#   'open',
#   'are',
#   'vaccinated',
#   'having',
#   'zero',
#   'problems',
#   '.',
#   'he',
#   'made',
#   'choice',
#   'now',
#   'he',
#   'is',
#   'facing',
#   'consequences',
#   '.'],
#  ['pro',
#   'mandate',
#   'folks',
#   ':',
#   'what',
#   'someone',
#   'does',
#   'with',
#   'their',
#   'body',
#   'is',
#   'ultimately',
#   'their',
#   'choice',
#   '.',
#   'that',
#   'is',
#   'moral',
#   'stance',
#   'issue',
#   '.',
#   'before',
#   'we',
#   'go',
#   'further',
#   ',',
#   'full',
#   'disclosure',
#   ',',
#   'i',
#   'am',
#   'vaccinated',
#   'because',
#   'some',
#   'medical',
#   'issues',
#   'i',
#   'have',
#   'that',
#   'put',
#   'me',
#   'at',
#   'higher',
#   'risk',
#   '.'],
#  ...]

# %%
convert_to_str = []

for each in tokenised_spellchecked:
    converted_str = ""
    for i in range(0,len(each)):
        if i == (len(each) - 1):
            converted_str += each[i]
        else:
            converted_str += each[i] + ", "
    convert_to_str.append(converted_str)
    
converted_df = pd.DataFrame(convert_to_str)

converted_df.to_csv('corrected-usa-rach-80000-end.csv')

# %%
converted_df
# Out:
#                                                       0
# 0     want, find, way, end, racism, try, force, peop...
# 1     this, child, almost, died, tetanus, ,, spent, ...
# 2     just, remember, my, ., leblanc, the, pressure,...
# 3     you, would, expect, cases, rise, significantly...
# 4     depends, whether, vaccination, status, is, emb...
# ...                                                 ...
# 1995  this, logic, is, valid, today, but, not, one, ...
# 1996  we, need, mandate, couid, vaccination, i, -, t...
# 1997  do, you, mean, vaccination, because, you, can,...
# 1998  be, fair, i, have, also, visited, more, restau...
# 1999  ", vaccination, is, natural, immunity, too, i,...
#
# [2000 rows x 1 columns]

# %% [markdown]
# ## Compiled CSV

# %%
df2 = pd.read_csv("compiled-after-correction.csv")

# %%
new_tokenised_spellchecked = []

for row in df2['0']:
    alist = row.split(", ")
    new_tokenised_spellchecked.append(alist)

# %%
new_tokenised_spellchecked

# %% [markdown]
# ## Convert to lowercase

# %%
#NEED TO CHANGE VARIABLE AFTER SPELLCHECK

tokenised_lower = [[w.lower() for w in each] for each in tokenised_numerals_converted]
tokenised_lower
# Out:
# [['want',
#   'find',
#   'way',
#   'end',
#   'racism',
#   'try',
#   'force',
#   'people',
#   'inject',
#   'themselves',
#   '.',
#   'that',
#   '’',
#   's',
#   'what',
#   'i',
#   'see',
#   'bunch',
#   'people',
#   'all',
#   'races',
#   'standing',
#   'up',
#   'against',
#   'forced',
#   'vaccination',
#   '.',
#   'not',
#   'against',
#   'vaxx',
#   '.',
#   'some',
#   'people',
#   'need',
#   'these',
#   'vaxx',
#   '&',
#   'amp',
#   ';',
#   'i',
#   'support',
#   'those',
#   'people',
#   'getting',
#   'their',
#   'shot',
#   '.',
#   'i',
#   'draw',
#   'line',
#   'at',
#   'force'],
#  ['this',
#   'child',
#   'almost',
#   'died',
#   'tetanus',
#   ',',
#   'spent',
#   'months',
#   'hospital',
#   'at',
#   'cost',
#   'around',
#   '$',
#   '1m',
#   ',',
#   'his',
#   'parents',
#   'still',
#   'refused',
#   'vaccination',
#   'after',
#   '.',
#   'this',
#   'was',
#   'pre',
#   '-',
#   'pandemic',
#   '.'],
#  ['just',
#   'remember',
#   'mr',
#   '.',
#   'leblanc',
#   'the',
#   'pressure',
#   'that',
#   'the',
#   'provincial',
#   'pm',
#   'and',
#   'the',
#   'business',
#   'world',
#   'asked',
#   'for',
#   'it',
#   'to',
#   'be',
#   'able',
#   'to',
#   're',
#   '-',
#   'open',
#   'the',
#   'borders',
#   'winking_face',
#   'air',
#   'traffic',
#   '.',
#   '+',
#   'will',
#   'the',
#   'provincial',
#   'govt',
#   ',',
#   'qc',
#   'included',
#   ',',
#   'block',
#   'tourists',
#   'who',
#   'will',
#   'not',
#   'have',
#   'a',
#   'pass',
#   '-',
#   'vaccination',
#   'at',
#   'the',
#   'hotel',
#   'at',
#   'the',
#   'restaurant'],
#  ['you',
#   'would',
#   'expect',
#   'cases',
#   'rise',
#   'significantly',
#   ',',
#   'course',
#   ',',
#   'vaccination',
#   'rates',
#   'come',
#   'into',
#   'play',
#   'as',
#   'does',
#   'space',
#   '.',
#   'we',
#   'as',
#   'adults',
#   'are',
#   'not',
#   'usually',
#   'confined',
#   'single',
#   'space',
#   'with',
#   'as',
#   'many',
#   'people',
#   'as',
#   'school',
#   'age',
#   'students',
#   '.',
#   'data',
#   'states',
#   'that',
#   'have',
#   'lifted',
#   'vs',
#   'those',
#   'that',
#   'have',
#   'not',
#   'bears',
#   'this',
#   'out',
#   '.'],
#  ['depends',
#   'whether',
#   'vaccination',
#   'status',
#   'is',
#   'embedded',
#   'qr',
#   'code',
#   'itself',
#   ',',
#   'or',
#   'if',
#   'code',
#   'is',
#   'just',
#   'link',
#   'that',
#   'connects',
#   'back',
#   'end',
#   '.',
#   'i',
#   'read',
#   'about',
#   'it',
#   'when',
#   'it',
#   'was',
#   'released',
#   'but',
#   'can',
#   "'",
#   't',
#   'remember',
#   '.',
#   'will',
#   'see',
#   'it',
#   'i',
#   'can',
#   'find',
#   'it',
#   'again',
#   '.'],
#  ['it',
#   'could',
#   'have',
#   'ripped',
#   '…',
#   'harder',
#   'or',
#   'do',
#   'you',
#   'think',
#   'masking',
#   ',',
#   'isolation',
#   ',',
#   'etc',
#   'ultimately',
#   'had',
#   'no',
#   'impact',
#   'honest',
#   'question',
#   ',',
#   'i',
#   'look',
#   'at',
#   'those',
#   'spikes',
#   'think',
#   'maybe',
#   'they',
#   'would',
#   'have',
#   'looked',
#   'same',
#   'no',
#   'matter',
#   'what',
#   ',',
#   'with',
#   'vaccination',
#   'only',
#   'thing',
#   'that',
#   'definitively',
#   '‘',
#   'worked',
#   '’'],
#  ['they',
#   'do',
#   'this',
#   'at',
#   'vaccination',
#   'centers',
#   'as',
#   'well',
#   '.',
#   'they',
#   'refused',
#   'let',
#   'me',
#   '&',
#   'amp',
#   ';',
#   'my',
#   'elderly',
#   'parent',
#   'wear',
#   'it',
#   'over',
#   'our',
#   'n95',
#   'masks',
#   '.',
#   'lady',
#   'was',
#   'very',
#   'rude',
#   '&',
#   'amp',
#   ';',
#   'said',
#   'i',
#   'could',
#   'i',
#   'have',
#   'covid',
#   '-',
#   'nineteen',
#   '&',
#   'amp',
#   ';',
#   'it',
#   'could',
#   'be',
#   'mask',
#   '.',
#   'i',
#   'refused',
#   '&',
#   'amp',
#   ';',
#   'did',
#   'not',
#   'take',
#   'no',
#   'answer',
#   '.',
#   'she',
#   'said',
#   'ok',
#   'begrudgingly',
#   '.',
#   'it',
#   'was',
#   'absurd',
#   '.'],
#  ['part',
#   'vanguard',
#   'vaccination',
#   'awareness',
#   'project',
#   '-',
#   'series',
#   'free',
#   'tools',
#   'help',
#   'c',
#   '-',
#   'suite',
#   'leaders',
#   'combat',
#   'vaccine',
#   'hesitancy',
#   'resistance',
#   '-',
#   'podcasts',
#   ',',
#   'videos',
#   'articles',
#   '-',
#   'available',
#   'at',
#   '#',
#   'covidvaccineconfidence',
#   '#',
#   'vanguardvaccinationproject'],
#  ['correct',
#   '.',
#   'it',
#   '’',
#   's',
#   'not',
#   'about',
#   'vaccines',
#   '.',
#   'nor',
#   'is',
#   'their',
#   'stated',
#   'goal',
#   'about',
#   'vaccination',
#   '.',
#   'breaking',
#   ':',
#   'cnn',
#   'blogger',
#   'reports',
#   'factual',
#   'news',
#   'accident',
#   '.',
#   'this',
#   'is',
#   'not',
#   'about',
#   'vaccines',
#   '.',
#   'at',
#   'least',
#   'we',
#   'know',
#   'she',
#   'can',
#   'read',
#   ';',
#   'positive',
#   'steps',
#   'towards',
#   'competence'],
#  ['does',
#   'it',
#   'hurt',
#   'your',
#   'head',
#   'actually',
#   'use',
#   'your',
#   'brain',
#   'you',
#   'seem',
#   'be',
#   'incredibly',
#   'brainwashed',
#   '.',
#   'places',
#   'with',
#   'highest',
#   'vaccination',
#   'rates',
#   'world',
#   'have',
#   'some',
#   'highest',
#   'case',
#   'counts',
#   '.',
#   'everyone',
#   'that',
#   'disagrees',
#   'with',
#   'your',
#   'compliance',
#   'totaltiarin',
#   'dictatorships',
#   'must',
#   'be',
#   'called',
#   'names'],
#  ['world',
#   '-',
#   'wide',
#   'mass',
#   'vaccination',
#   'leading',
#   'world',
#   '-',
#   'wide',
#   'digital',
#   'passport',
#   'is',
#   'their',
#   'goal',
#   '.',
#   '#',
#   'populationcontrol'],
#  ['as',
#   'vaccinations',
#   '...',
#   'you',
#   "'",
#   'll',
#   'still',
#   'need',
#   'proof',
#   'vaccination',
#   'restaurants',
#   ',',
#   'movie',
#   'theaters',
#   ',',
#   'museums',
#   ',',
#   'large',
#   'arenas',
#   ',',
#   'gyms',
#   'fitness',
#   'centers',
#   '.',
#   'btw',
#   'nyc',
#   'vaccination',
#   'rate',
#   'is',
#   'now',
#   'at',
#   'seventy-five',
#   '%.',
#   'more',
#   'at',
#   '11pm',
#   'three',
#   '/',
#   'three'],
#  ['following',
#   'tweet',
#   'didn',
#   "'",
#   't',
#   'even',
#   'age',
#   'twelve',
#   'hours',
#   'before',
#   'prince',
#   'charles',
#   'announced',
#   'his',
#   'reinfection',
#   ',',
#   'even',
#   'after',
#   'vaccination',
#   '&',
#   'amp',
#   ';',
#   'booster',
#   '.',
#   'so',
#   ',',
#   'yes',
#   ',',
#   'clearly',
#   'previous',
#   'infection',
#   'protects',
#   'you',
#   'at',
#   'this',
#   'point',
#   '.',
#   'does',
#   'boris',
#   'johnson',
#   'exude',
#   'some',
#   'sort',
#   'hypnotoad',
#   '-',
#   'like',
#   'pheromone',
#   'or',
#   'something'],
#  ['vaccination'],
#  ['private',
#   'businesses',
#   'can',
#   'enforce',
#   'vaccination',
#   'mandates',
#   'if',
#   'they',
#   'choose',
#   'do',
#   'so',
#   '.'],
#  ['one',
#   '-',
#   'i',
#   'understand',
#   'exactly',
#   'what',
#   'needs',
#   'to',
#   'be',
#   'understood',
#   '.',
#   'lame',
#   'link',
#   'two',
#   '-',
#   'even',
#   'if',
#   'it',
#   'remains',
#   'lame',
#   ',',
#   'when',
#   'vaccination',
#   'is',
#   'compulsory',
#   ',',
#   'you',
#   'will',
#   'come',
#   'back',
#   'to',
#   'bawl',
#   '.',
#   'bye',
#   'there'],
#  ['story',
#   'with',
#   'martha',
#   'mccallum',
#   ',',
#   'am',
#   'llc',
#   'senior',
#   'medical',
#   'advisor',
#   'dr',
#   '.',
#   'robert',
#   'redfield',
#   'comments',
#   'confusing',
#   'messaging',
#   ',',
#   'spread',
#   '#',
#   'omicron',
#   'importance',
#   'maintaining',
#   'your',
#   '#',
#   'vaccination',
#   'status',
#   '.',
#   'watch',
#   'full',
#   'interview',
#   'below',
#   'backhand_index_pointing_down'],
#  ['world',
#   "'",
#   's',
#   'top',
#   'virologist',
#   ',',
#   'luc',
#   'montagnier',
#   ',',
#   'winner',
#   'nobel',
#   'prize',
#   'his',
#   'diskovery',
#   'hiv',
#   ',',
#   'died',
#   'today',
#   '.',
#   'he',
#   'warned',
#   'us',
#   'beginning',
#   'that',
#   'covid',
#   '-',
#   'nineteen',
#   'was',
#   'lab',
#   '-',
#   'made',
#   ',',
#   'that',
#   'mass',
#   'vaccination',
#   'with',
#   'leaky',
#   'vaccines',
#   'would',
#   'generate',
#   'endless',
#   'new',
#   'variants',
#   '.',
#   'right',
#   'both',
#   'counts',
#   '.',
#   'rip',
#   '.'],
#  ['obvious',
#   ',',
#   'common',
#   'sense',
#   'solution',
#   'was',
#   'always',
#   'take',
#   'free',
#   'safe',
#   'vaccination',
#   'against',
#   'deadly',
#   'virus',
#   'then',
#   'carry',
#   'about',
#   'your',
#   'business',
#   'like',
#   'non',
#   '-',
#   'lunatic'],
#  ['sure',
#   'tootin',
#   "'",
#   'i',
#   'do',
#   '.',
#   'remember',
#   ',',
#   'i',
#   'grew',
#   'up',
#   'jackson',
#   ',',
#   'mi',
#   ',',
#   'at',
#   'least',
#   'place',
#   'long',
#   'associated',
#   'with',
#   'republican',
#   'party',
#   '.',
#   'i',
#   'am',
#   'familiar',
#   'with',
#   'conservative',
#   'mien',
#   '/',
#   'mindset',
#   ',',
#   '&',
#   'amp',
#   ';',
#   'i',
#   'can',
#   'speak',
#   'that',
#   ',',
#   'i',
#   'think',
#   ',',
#   'plain',
#   'language',
#   '.',
#   'i',
#   'think',
#   'covid',
#   'should',
#   'be',
#   'mandatory',
#   'vaccination',
#   '.'],
#  ['which',
#   'variants',
#   'were',
#   'involved',
#   'what',
#   'was',
#   '%',
#   'vaccination',
#   '/',
#   'masking',
#   '/',
#   'ventilation',
#   'around',
#   'kids',
#   'at',
#   'time',
#   'it',
#   "'",
#   's',
#   'meaningless',
#   'say',
#   '"',
#   'kids',
#   'aren',
#   "'",
#   't',
#   'danger',
#   '",',
#   'unless',
#   'you',
#   'mean',
#   'say',
#   '"',
#   'kids',
#   'have',
#   'not',
#   'nor',
#   'will',
#   'not',
#   'ever',
#   'be',
#   'danger',
#   ',',
#   'no',
#   'matter',
#   'what',
#   '".'],
#  ['it',
#   'has',
#   'last',
#   'i',
#   'looked',
#   'we',
#   'hadn',
#   "'",
#   't',
#   'actually',
#   'hit',
#   'county',
#   'vaccination',
#   'threshold',
#   'because',
#   'difference',
#   'between',
#   'mdh',
#   'cdc',
#   'data',
#   '.',
#   'i',
#   'bet',
#   'most',
#   'secondary',
#   'schools',
#   'have',
#   ',',
#   'though',
#   '.'],
#  ['oh',
#   'i',
#   'see',
#   '.',
#   'so',
#   'what',
#   'your',
#   'saying',
#   'is',
#   'that',
#   'alberta',
#   'businesses',
#   'that',
#   'are',
#   'required',
#   'ask',
#   'proof',
#   'vaccination',
#   'can',
#   '’',
#   't',
#   'rely',
#   'alberta',
#   'government',
#   'they',
#   'have',
#   'rely',
#   'other',
#   'provinces'],
#  ['this',
#   'vision',
#   'public',
#   'health',
#   'decisions',
#   'tied',
#   'local',
#   'conditions',
#   'spread',
#   ',',
#   'vaccination',
#   '&',
#   'amp',
#   ';',
#   'vulnerability',
#   'also',
#   'sounds',
#   'reasonable',
#   'me',
#   '.',
#   'however',
#   ',',
#   'two',
#   'years',
#   'into',
#   'this',
#   ',',
#   'acting',
#   'as',
#   'if',
#   'that',
#   "'",
#   's',
#   'what',
#   'is',
#   'happening',
#   'is',
#   'naive',
#   'at',
#   'best',
#   '.',
#   'partisan',
#   'politics',
#   ',',
#   'even',
#   'at',
#   'local',
#   'level',
#   'often',
#   'is',
#   'big',
#   'factor',
#   '.'],
#  ['oh',
#   'you',
#   'mean',
#   'someone',
#   'told',
#   'you',
#   'they',
#   '’',
#   'd',
#   'kill',
#   'you',
#   'if',
#   'you',
#   'didn',
#   '’',
#   't',
#   'get',
#   'vaccinated',
#   'don',
#   '’',
#   't',
#   'understand',
#   '.',
#   'i',
#   'thought',
#   'you',
#   'said',
#   'no',
#   'vaccination',
#   '.',
#   'how',
#   'did',
#   'you',
#   'lose',
#   'your',
#   'bodily',
#   'autonomy',
#   'then'],
#  ['their',
#   'concerns',
#   'are',
#   'real',
#   ',',
#   'even',
#   'if',
#   'unfounded',
#   '.',
#   'addressing',
#   'them',
#   'with',
#   'empathy',
#   'genuine',
#   'good',
#   'will',
#   'is',
#   'how',
#   'you',
#   'persuade',
#   'them',
#   '.',
#   'canada',
#   'has',
#   'similar',
#   'levels',
#   'adult',
#   'vaccination',
#   'usa',
#   '.'],
#  ['it',
#   'seems',
#   'like',
#   'steel',
#   'man',
#   'here',
#   'is',
#   'about',
#   'many',
#   'mandates',
#   'masks',
#   ',',
#   'vaccination',
#   ',',
#   'testing',
#   ',',
#   'etc',
#   'that',
#   'are',
#   'very',
#   'much',
#   'still',
#   'place',
#   'are',
#   'relatively',
#   'low',
#   'cost',
#   'but',
#   'not',
#   'zero',
#   'cost'],
#  ['i', "'", 'd', 'kill', 'be', 'sally', 'field', 'here'],
#  ['jesus',
#   'christ',
#   '.',
#   'it',
#   "'",
#   's',
#   'vaccination',
#   ',',
#   'not',
#   'being',
#   'forced',
#   'carry',
#   'pregnancy',
#   'term',
#   '.'],
#  ['amazon',
#   'allow',
#   'work',
#   'without',
#   'face',
#   'masks',
#   ',',
#   'require',
#   'vaccination',
#   'paid',
#   'covid',
#   'leave'],
#  ['five',
#   '/',
#   'if',
#   'governments',
#   'primary',
#   'concern',
#   'amd',
#   'justification',
#   'compulsory',
#   'covid',
#   'vaccination',
#   'is',
#   'prevent',
#   'hospitals',
#   ',',
#   'icu',
#   ',',
#   'emergency',
#   'depts',
#   'being',
#   'inundated',
#   'thus',
#   'running',
#   'out',
#   'medical',
#   'resources',
#   ',',
#   'bed',
#   'space',
#   ',',
#   'equipment',
#   'or',
#   'staff',
#   ',',
#   'perhaps',
#   ',',
#   'govt',
#   'should',
#   'require',
#   'all',
#   'hospitals'],
#  ['two',
#   '/',
#   'when',
#   'covid',
#   'vaccines',
#   'have',
#   'proven',
#   'not',
#   'prevent',
#   'spread',
#   'covid',
#   ',',
#   'even',
#   'before',
#   'but',
#   'esp',
#   'with',
#   'omicron',
#   'where',
#   'so',
#   'called',
#   'breakthrough',
#   'cases',
#   'became',
#   'just',
#   'positive',
#   'covid',
#   'cases',
#   'bc',
#   'omicron',
#   'didn',
#   "'",
#   't',
#   'care',
#   'abt',
#   'vaccine',
#   'status',
#   '.',
#   'real',
#   'driving',
#   'force',
#   'vaccination',
#   'has',
#   'become',
#   'minimizing'],
#  ['pile_of_pootrudeau',
#   'pile_of_poowants',
#   'one hundred',
#   '%',
#   'vaccination',
#   'syringe',
#   '**',
#   'new',
#   'video',
#   '***',
#   'via'],
#  ['i',
#   'think',
#   'they',
#   'are',
#   'now',
#   'at',
#   'eighty',
#   '%',
#   'most',
#   'games',
#   'are',
#   'never',
#   'that',
#   'full',
#   'anyway',
#   '.',
#   'you',
#   'are',
#   'meant',
#   'download',
#   'app',
#   'get',
#   '“',
#   'green',
#   '”',
#   'light',
#   'which',
#   'is',
#   'based',
#   'vaccination',
#   'status',
#   '.',
#   'that',
#   'is',
#   'allow',
#   'you',
#   'enter',
#   'stadium',
#   '.',
#   'i',
#   'am',
#   'not',
#   'ground',
#   'there',
#   'so',
#   'unsure',
#   'if',
#   'they',
#   'enforce',
#   'that',
#   'much',
#   '.'],
#  ['i',
#   'see',
#   '…',
#   'so',
#   'how',
#   'do',
#   'alberta',
#   'businesses',
#   'that',
#   'are',
#   'legally',
#   'still',
#   'requires',
#   'obtain',
#   'proof',
#   'vaccination',
#   'do',
#   'so',
#   'yes',
#   'there',
#   'are',
#   'those',
#   'still',
#   'legally',
#   'required',
#   '…'],
#  ['about',
#   'five hundred',
#   'medical',
#   'specialists',
#   'were',
#   'involved',
#   'in',
#   'the',
#   'vaccination',
#   'effort',
#   '.'],
#  ['reaction',
#   'vaccine',
#   ':',
#   'according',
#   'cdc',
#   ',',
#   'anaphylaxis',
#   'after',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'is',
#   'extremely',
#   'rare',
#   'has',
#   'occurred',
#   'about',
#   'five',
#   'people',
#   'per',
#   'one',
#   'million',
#   'vaccinated',
#   'united',
#   'states',
#   ',',
#   'or',
#   '.',
#   'five',
#   '%',
#   'vaccinations',
#   '.'],
#  ['chickahominy',
#   'health',
#   'district',
#   'is',
#   'holding',
#   'vaccination',
#   'clinic',
#   'february',
#   'twenty-four',
#   'three',
#   '-',
#   'six',
#   'pm',
#   'at',
#   'j',
#   '.',
#   'sargent',
#   'reynolds',
#   'community',
#   'college',
#   '.',
#   'please',
#   'use',
#   'this',
#   'link',
#   'register',
#   'but',
#   'walk',
#   '-',
#   'ins',
#   'will',
#   'be',
#   'accepted',
#   '.'],
#  ['it',
#   "'",
#   's',
#   'too',
#   'bad',
#   'that',
#   'it',
#   "'",
#   's',
#   'a',
#   'right',
#   ',',
#   'their',
#   'body',
#   'belongs',
#   'to',
#   'them',
#   'but',
#   'not',
#   'what',
#   'it',
#   'wears',
#   'you',
#   'better',
#   'fight',
#   'to',
#   'fight',
#   'the',
#   'compulsory',
#   'vaccination',
#   'required',
#   'by',
#   'businesses',
#   ',',
#   'employers',
#   'and',
#   'this',
#   'government'],
#  ['do',
#   'you',
#   'have',
#   'nothing',
#   'more',
#   'report',
#   'about',
#   'other',
#   'than',
#   'documents',
#   'trump',
#   'took',
#   'gave',
#   'back',
#   'or',
#   'bullshit',
#   'that',
#   'happened',
#   'january',
#   'six',
#   'how',
#   'about',
#   'let',
#   '’',
#   's',
#   'close',
#   'our',
#   'borders',
#   'let',
#   '’',
#   's',
#   'end',
#   'mask',
#   'vaccination',
#   'mandates',
#   'seriously',
#   'people',
#   'person_facepalminglight_skin_tone',
#   '\u200d',
#   'female_sign',
#   '️'],
#  ['conclusion',
#   'you',
#   'most',
#   'definitely',
#   'cannot',
#   'draw',
#   'that',
#   'is',
#   'that',
#   'mask',
#   'mandates',
#   'don',
#   '’',
#   't',
#   'work',
#   ',',
#   'since',
#   'death',
#   'rates',
#   'are',
#   '*',
#   'much',
#   '*',
#   'lower',
#   'those',
#   'states',
#   '.',
#   'again',
#   ',',
#   'this',
#   'is',
#   'probably',
#   'primarily',
#   'due',
#   'higher',
#   'vaccination',
#   'rates',
#   '.'],
#  ['i',
#   'never',
#   'suggested',
#   'vaccination',
#   'was',
#   'issue',
#   ',',
#   'one',
#   'way',
#   'or',
#   'other',
#   '.'],
#  ['why',
#   'hasn',
#   '’',
#   't',
#   'trump',
#   'been',
#   'arrested',
#   'yet',
#   'we',
#   'look',
#   'like',
#   'laughingstocks',
#   'rest',
#   'world',
#   ',',
#   'still',
#   '.',
#   'also',
#   ',',
#   'i',
#   'am',
#   'terrified',
#   'truckers',
#   '.',
#   'they',
#   'are',
#   'not',
#   'just',
#   'coming',
#   'because',
#   'vaccination',
#   'mandates',
#   ',',
#   'they',
#   'are',
#   'coming',
#   'because',
#   'big',
#   'lie',
#   'perceived',
#   'reinstatement',
#   'tfg',
#   '.'],
#  ['he',
#   'was',
#   'covid',
#   'positive',
#   'when',
#   'he',
#   'died',
#   '.',
#   'i',
#   "'",
#   'm',
#   'amazed',
#   'that',
#   'they',
#   'haven',
#   "'",
#   't',
#   'spun',
#   'this',
#   'into',
#   'covid',
#   'death',
#   'push',
#   'their',
#   'vaccination',
#   'agenda'],
#  ['if',
#   'it',
#   "'",
#   's',
#   'not',
#   'crossed',
#   'with',
#   'the',
#   'data',
#   'on',
#   'vaccination',
#   '...'],
#  ['so',
#   'my',
#   'school',
#   'is',
#   'not',
#   'gonna',
#   'ask',
#   'vaccination',
#   'proof',
#   'because',
#   'they',
#   '“',
#   'respect',
#   'individuality',
#   'health',
#   'decisions',
#   'everyone',
#   '”',
#   'but',
#   'i',
#   'have',
#   'no',
#   'choice',
#   'stay',
#   'virtually',
#   'lol',
#   'hate',
#   'it',
#   'here'],
#  ['as',
#   'i',
#   'linked',
#   'above',
#   ',',
#   'republican',
#   '-',
#   'controlled',
#   'states',
#   ',',
#   'which',
#   'tend',
#   'be',
#   'states',
#   'without',
#   'mask',
#   'mandates',
#   ',',
#   'are',
#   'doing',
#   'far',
#   'worse',
#   'than',
#   'democratic',
#   '-',
#   'controlled',
#   'states',
#   '.',
#   'course',
#   ',',
#   'they',
#   'also',
#   'are',
#   'states',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   ',',
#   'so',
#   'it',
#   '’',
#   's',
#   'hard',
#   'draw',
#   'strong',
#   'conclusion',
#   'that',
#   '.'],
#  ['why',
#   'has',
#   'our',
#   'close',
#   'neighbor',
#   'png',
#   'got',
#   'one',
#   'lowest',
#   'covid',
#   'vaccination',
#   'rates',
#   'world'],
#  ['our',
#   'vaccination',
#   'campaign',
#   'has',
#   'gone',
#   'from',
#   'exemplary',
#   'to',
#   'a',
#   'miserable',
#   'failure',
#   '.'],
#  ['advocacy',
#   'update',
#   '|',
#   'physician',
#   'groups',
#   'urge',
#   'supreme',
#   'court',
#   'uphold',
#   'vaccination',
#   'requirement',
#   ';',
#   'highlights',
#   'parity',
#   'enforcement',
#   'regulatory',
#   'agenda',
#   ';',
#   'more',
#   '.',
#   '#',
#   'mentalhealth',
#   '#',
#   'psychtwitter'],
#  ['me',
#   'putting',
#   'together',
#   'my',
#   'spreadsheet',
#   'what',
#   'oscar',
#   'nominees',
#   'celebrities',
#   'attended',
#   'vaccination',
#   'required',
#   'events',
#   'and',
#   '/',
#   'or',
#   'publicly',
#   'spoken',
#   'out',
#   'about',
#   'vaccine'],
#  ['that',
#   'was',
#   'indian',
#   'health',
#   'department',
#   '.',
#   'sorry',
#   'you',
#   'don',
#   '’',
#   't',
#   'trust',
#   'people',
#   'that',
#   'look',
#   'like',
#   'you',
#   '.',
#   'why',
#   'do',
#   'you',
#   'think',
#   'israel',
#   ',',
#   'with',
#   'ninety',
#   '%+',
#   'vaccination',
#   'rate',
#   ',',
#   'has',
#   'such',
#   'hard',
#   'time',
#   'with',
#   'covid',
#   'right',
#   'now'],
#  ['amerks',
#   'will',
#   'no',
#   'longer',
#   'require',
#   'proof',
#   'vaccination',
#   'entry',
#   'amerks',
#   'games',
#   'or',
#   'any',
#   'events',
#   'at',
#   'blue',
#   'cross',
#   'arena',
#   'beginning',
#   'thursday',
#   ',',
#   'february',
#   '10th',
#   '.'],
#  ['my',
#   'employer',
#   'has',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   '.',
#   'even',
#   'if',
#   'provincial',
#   'federal',
#   'governments',
#   'remove',
#   'mandates',
#   ',',
#   'my',
#   'employer',
#   'will',
#   'still',
#   'have',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   '.',
#   'what',
#   'then',
#   '#',
#   'cdnpoli',
#   '#',
#   'onpoli'],
#  ['demystify',
#   'vaccination',
#   'against',
#   '#',
#   'covid19',
#   'provided',
#   'you',
#   'master',
#   'your',
#   'subject',
#   '.',
#   'clapping_handsmedium_skin_tone',
#   '#',
#   'let',
#   'go'],
#  ['we', 'need', 'have', 'uniformed', 'rule', 'about', 'mask', 'vaccination'],
#  ['so',
#   '....',
#   'conservative',
#   'anti',
#   '-',
#   'abortion',
#   'anti',
#   '-',
#   'vaccination',
#   'people',
#   '....',
#   'thoughts',
#   'prayers',
#   ',',
#   'can',
#   "'",
#   't',
#   'forget',
#   'prayers',
#   '...'],
#  ['classic',
#   'simpson',
#   "'",
#   's',
#   'paradox',
#   '.',
#   'most',
#   'deaths',
#   'are',
#   'among',
#   'elderly',
#   'people',
#   ',',
#   'nearly',
#   'all',
#   'whom',
#   'are',
#   'vaccinated',
#   '.',
#   'with',
#   'lower',
#   'vaccination',
#   'rate',
#   ',',
#   'total',
#   'number',
#   'fatalities',
#   'would',
#   'be',
#   'much',
#   'higher',
#   '.'],
#  ['sounds',
#   'like',
#   'you',
#   '’',
#   're',
#   'planning',
#   'masking',
#   'kids',
#   'indefinitely',
#   'bps',
#   '.',
#   'what',
#   'hospitalization',
#   'rates',
#   ',',
#   'vaccination',
#   'rates',
#   'etc',
#   'are',
#   'you',
#   'deeming',
#   'necessary',
#   'finally',
#   'let',
#   'these',
#   'kids',
#   'finally',
#   'get',
#   'back',
#   'normalcy',
#   'we',
#   'need',
#   'numbers',
#   '.'],
#  ['cases',
#   'have',
#   'gone',
#   'up',
#   'state',
#   'it',
#   'has',
#   'highest',
#   'vaccination',
#   'rate',
#   'as',
#   'january',
#   '.',
#   'you',
#   'ate',
#   'bullshit',
#   'obvious',
#   'fake',
#   'news',
#   'site',
#   'with',
#   'spoon',
#   '.',
#   'this',
#   'is',
#   'why',
#   'i',
#   'am',
#   'insulting',
#   'your',
#   'intelligence',
#   '.'],
#  ['there',
#   "'",
#   's',
#   'lot',
#   'people',
#   'speaking',
#   'out',
#   'like',
#   'pro',
#   '-',
#   'choice',
#   'abortions',
#   'is',
#   'same',
#   'as',
#   'pro',
#   '-',
#   'choice',
#   'relating',
#   'vaccines',
#   '.',
#   'i',
#   'disagree',
#   '.',
#   'abortion',
#   'removes',
#   'choice',
#   'human',
#   'by',
#   'ending',
#   'human',
#   'life',
#   '.',
#   'forced',
#   '/',
#   'coerced',
#   'vaccination',
#   'removes',
#   'choice',
#   'by',
#   'forcing',
#   'human',
#   'risk',
#   'permanent',
#   'damage'],
#  ['not',
#   'delusional',
#   'at',
#   'all',
#   ',',
#   'it',
#   'is',
#   'over',
#   '.',
#   'endemic',
#   '.',
#   'we',
#   'are',
#   'going',
#   'live',
#   'with',
#   'this',
#   '.',
#   'not',
#   'up',
#   'us',
#   '.',
#   'vaccination',
#   ',',
#   'lockdowns',
#   ',',
#   'masks',
#   '-',
#   'covid',
#   'is',
#   'still',
#   'here',
#   '.',
#   'live',
#   'fear',
#   'or',
#   'get',
#   'with',
#   'it',
#   'taking',
#   'precaution',
#   'as',
#   'necessary',
#   'based',
#   'age',
#   'other',
#   'health',
#   'conditions',
#   '.'],
#  ['tell',
#   'that',
#   'unvaccinated',
#   'people',
#   'who',
#   "'",
#   've',
#   'died',
#   'covid',
#   '.',
#   'unfortunately',
#   ',',
#   'that',
#   "'",
#   's',
#   'not',
#   'true',
#   '.',
#   'vaccination',
#   'does',
#   'indeed',
#   'prevent',
#   'some',
#   'most',
#   'dire',
#   'results',
#   'covid',
#   'infection',
#   '.',
#   'that',
#   "'",
#   's',
#   'pretty',
#   'well',
#   'established',
#   '.'],
#  ['tool',
#   '......',
#   'surgeon',
#   'general',
#   'refuses',
#   'disklose',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'status'],
#  ['quebec',
#   'is',
#   'asking',
#   'all',
#   'vaccinating',
#   'physicians',
#   'to',
#   'return',
#   'to',
#   'their',
#   'regular',
#   'activities',
#   'due',
#   'to',
#   'the',
#   'sharp',
#   'drop',
#   'in',
#   'attendance',
#   'at',
#   'vaccination',
#   'clinics',
#   '.',
#   'radio',
#   '-',
#   'canada',
#   'reported',
#   'this',
#   'morning',
#   'that',
#   'vaccinators',
#   'are',
#   'twiddling',
#   'their',
#   'thumbs',
#   '#',
#   'polqc'],
#  ['thank',
#   'you',
#   'keeping',
#   'mask',
#   'mandate',
#   'schools',
#   '.',
#   'folded_handswe',
#   'need',
#   'get',
#   'our',
#   'vaccination',
#   'rates',
#   'up',
#   'do',
#   'more',
#   'education',
#   'outreach',
#   'get',
#   'our',
#   'students',
#   'siblings',
#   'under',
#   'five',
#   'vaccinated',
#   'before',
#   'lifting',
#   'mask',
#   'mandates',
#   '.'],
#  ['according',
#   'to',
#   ',',
#   'vaccination',
#   'and',
#   'abortion',
#   'are',
#   'the',
#   'same',
#   'thing',
#   '.',
#   'welcome',
#   'to',
#   'two thousand and twenty-two'],
#  ['care',
#   'explain',
#   'how',
#   "'",
#   'mental',
#   'health',
#   "'",
#   'has',
#   'anything',
#   'do',
#   'with',
#   'vaccine',
#   'i',
#   "'",
#   'm',
#   'not',
#   'talking',
#   'about',
#   'how',
#   'person',
#   'may',
#   'feel',
#   'about',
#   'it',
#   'one',
#   'way',
#   'or',
#   'other',
#   ',',
#   'i',
#   "'",
#   'm',
#   'talking',
#   'about',
#   'genuine',
#   'mental',
#   'health',
#   'issue',
#   'due',
#   'vaccination',
#   '.',
#   'it',
#   'does',
#   'not',
#   'exist',
#   '.'],
#  ['find',
#   'fixed',
#   'vaccination',
#   'site',
#   'your',
#   'area',
#   '#',
#   'getvaccinated',
#   'today',
#   '.',
#   'visit',
#   'or',
#   'call',
#   'eight hundred and eighty-eight',
#   'one',
#   '-',
#   'love',
#   'six hundred and sixty-three',
#   'five thousand, six hundred and eighty-three',
#   '.'],
#  ['three',
#   '/',
#   'eric',
#   'adams',
#   'has',
#   'also',
#   'repeatedly',
#   'renewed',
#   '“',
#   'key',
#   'nyc',
#   '”',
#   'executive',
#   'order',
#   ',',
#   'which',
#   'requires',
#   'anyone',
#   'over',
#   'age',
#   'five',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'participate',
#   'indoor',
#   'activities',
#   '.',
#   'anyone',
#   'eighteen',
#   'older',
#   ',',
#   'proof',
#   'id',
#   'along',
#   'with',
#   'proof',
#   'vaccination',
#   'is',
#   'required',
#   '.'],
#  ['it',
#   'makes',
#   'me',
#   'sad',
#   ',',
#   'but',
#   'also',
#   'angry',
#   'at',
#   'all',
#   'those',
#   'who',
#   'have',
#   'diskouraged',
#   'vaccination',
#   '.'],
#  ['about',
#   'time',
#   '.',
#   'well',
#   'done',
#   'everyone',
#   'who',
#   'faught',
#   'this',
#   '.',
#   'i',
#   "'",
#   'm',
#   'proud',
#   'us',
#   'all',
#   'revoking',
#   'vaccination',
#   'as',
#   'condition',
#   'deployment',
#   'across',
#   'all',
#   'health',
#   'social',
#   'care'],
#  ['oscars',
#   ':',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'will',
#   'not',
#   'be',
#   'required',
#   'in',
#   '-',
#   'person',
#   'attendees',
#   'exclusive',
#   'via'],
#  ['two',
#   '/',
#   'proof',
#   'vaccination',
#   'is',
#   'still',
#   'required',
#   'indoor',
#   'dining',
#   ',',
#   'events',
#   'at',
#   'arenas',
#   ',',
#   'gyms',
#   ',',
#   'theaters',
#   ',',
#   'museums',
#   'any',
#   'other',
#   'indoor',
#   'entertainment',
#   'new',
#   'york',
#   'city',
#   ',',
#   'as',
#   'part',
#   'initiative',
#   'started',
#   'by',
#   'former',
#   'mayor',
#   '.'],
#  ['what',
#   'makes',
#   'americans',
#   'think',
#   'they',
#   'have',
#   'right',
#   'challenge',
#   'sovereign',
#   'nation',
#   '’',
#   's',
#   'rules',
#   'regarding',
#   'vaccination',
#   'testing',
#   'this',
#   'is',
#   'problem',
#   'our',
#   'creation',
#   'putting',
#   'self',
#   'above',
#   'needs',
#   'country',
#   '#',
#   'vaccineswork',
#   '#',
#   'canada'],
#  ['following',
#   'end',
#   'nevada',
#   "'",
#   's',
#   'mask',
#   'mandate',
#   'this',
#   'morning',
#   ',',
#   'has',
#   'followed',
#   'suit',
#   '.',
#   '"',
#   'nshe',
#   'employees',
#   ',',
#   'students',
#   'members',
#   'public',
#   'are',
#   'no',
#   'longer',
#   'required',
#   'wear',
#   'face',
#   'coverings',
#   'while',
#   'inside',
#   'nshe',
#   'buildings',
#   'irrespective',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'immediately',
#   '"'],
#  ['“',
#   'what',
#   'is',
#   'at',
#   'stake',
#   'applicants',
#   'here',
#   'is',
#   'not',
#   'forcible',
#   'vaccination',
#   'but',
#   'rather',
#   'consequences',
#   'one',
#   "'",
#   's',
#   'choice',
#   'remain',
#   'unvaccinated',
#   '."'],
#  ['trading',
#   'all',
#   'players',
#   'that',
#   'are',
#   'injured',
#   'just',
#   'claim',
#   'no',
#   'injuries',
#   'report',
#   '.',
#   'is',
#   'like',
#   'firing',
#   'all',
#   'non',
#   'vaccinated',
#   'claiming',
#   'you',
#   'have',
#   'one hundred',
#   '%',
#   'vaccination',
#   'rate',
#   'face_with_tears_of_joy'],
#  ['you',
#   'really',
#   'don',
#   "'",
#   't',
#   'get',
#   'it',
#   'do',
#   'you',
#   'person_facepalming',
#   '\u200d',
#   'female_sign',
#   '️',
#   'vaccination',
#   'lessons',
#   'syptoms',
#   'both',
#   'immediate',
#   'long',
#   'term',
#   '.',
#   'you',
#   'can',
#   'still',
#   'get',
#   'it',
#   ',',
#   'but',
#   'unlikely',
#   'it',
#   'will',
#   'be',
#   'serious',
#   'cause',
#   'long',
#   'term',
#   'damage',
#   '.',
#   'ffs',
#   'keep',
#   'up'],
#  ['any',
#   'member',
#   'public',
#   'or',
#   'health',
#   'professional',
#   'can',
#   'submit',
#   'suspected',
#   'side',
#   'effects',
#   'through',
#   'yellow',
#   'card',
#   'scheme',
#   '.',
#   'nature',
#   'yellow',
#   'card',
#   'reporting',
#   'means',
#   'that',
#   'reported',
#   'events',
#   'are',
#   'not',
#   'always',
#   'proven',
#   'side',
#   'effects',
#   '.',
#   'some',
#   'events',
#   'may',
#   'have',
#   'happened',
#   'anyway',
#   ',',
#   'regardless',
#   'vaccination',
#   '.'],
#  ['so',
#   'strange',
#   'that',
#   'people',
#   'who',
#   'are',
#   'claiming',
#   'that',
#   'they',
#   'want',
#   'us',
#   'all',
#   'stop',
#   'living',
#   'fear',
#   'are',
#   'causing',
#   'lot',
#   'more',
#   'fear',
#   'than',
#   'mask',
#   'or',
#   'vaccination',
#   '.',
#   'ever',
#   'caused',
#   'eighty-five',
#   '%',
#   'us',
#   '.',
#   'we',
#   'are',
#   'being',
#   'held',
#   'hostage',
#   '.'],
#  ['kicking',
#   'off',
#   'night',
#   'one',
#   '#',
#   'superbowlmusicfest',
#   'with',
#   '/',
#   'w',
#   '/',
#   'special',
#   'guests',
#   'doors',
#   ':',
#   '7pm',
#   '.',
#   'limited',
#   'number',
#   'tickets',
#   'remain',
#   'at',
#   'guests',
#   'two',
#   '&',
#   'amp',
#   ';',
#   'older',
#   'must',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'or',
#   'neg',
#   'test',
#   '&',
#   'amp',
#   ';',
#   'id',
#   '.',
#   'info',
#   ':'],
#  ['with',
#   'vaccination',
#   'rates',
#   'quite',
#   'low',
#   '&',
#   'lt',
#   ';',
#   'twelve',
#   'age',
#   'range',
#   ',',
#   'more',
#   'thought',
#   'needed',
#   'as',
#   'benefits',
#   'risks',
#   'unmasked',
#   ',',
#   'indoor',
#   'instruction',
#   '.',
#   'glad',
#   'that',
#   'allows',
#   'unmasked',
#   'outdoor',
#   'activities',
#   'that',
#   'our',
#   'fab',
#   '#',
#   'socal',
#   'weather',
#   'makes',
#   'it',
#   'easy',
#   'get',
#   'fresh',
#   'air',
#   '.'],
#  ['i',
#   'truly',
#   'feel',
#   'that',
#   'he',
#   "'",
#   's',
#   'mentally',
#   'unstable',
#   'over',
#   'his',
#   'head',
#   '.',
#   'this',
#   'is',
#   'very',
#   'concerning',
#   '.',
#   'same',
#   'answer',
#   'time',
#   'after',
#   'time',
#   '.',
#   'ninety',
#   '%',
#   'vaccination',
#   'face_with_symbols_on_mouthface_with_symbols_on_mouthface_with_symbols_on_mouth'],
#  ['i',
#   'tend',
#   'let',
#   'it',
#   'slide',
#   'until',
#   'i',
#   'injure',
#   'myself',
#   'i',
#   "'",
#   'm',
#   'klutz',
#   'or',
#   'doc',
#   'notices',
#   'it',
#   "'",
#   's',
#   'been',
#   'awhile',
#   '.',
#   'since',
#   'they',
#   'quit',
#   'using',
#   'horse',
#   'serum',
#   ',',
#   'i',
#   "'",
#   'm',
#   'good',
#   'about',
#   'that',
#   'vaccination',
#   '.'],
#  ['since',
#   'mid',
#   '-',
#   'september',
#   ',',
#   'has',
#   'required',
#   'everyone',
#   'two',
#   'years',
#   'age',
#   'older',
#   'wear',
#   'mask',
#   'indoors',
#   'regardless',
#   'their',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'status',
#   '.',
#   'beginning',
#   'feb',
#   '.',
#   'twenty-two',
#   '—',
#   'day',
#   'after',
#   'presidents',
#   'day',
#   '—',
#   'that',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'case',
#   '.'],
#  ['it',
#   'is',
#   'justified',
#   'be',
#   'frustrated',
#   'with',
#   'people',
#   'who',
#   'won',
#   "'",
#   't',
#   'get',
#   'vaccine',
#   ',',
#   'there',
#   'are',
#   'jobs',
#   'where',
#   'it',
#   'is',
#   'fair',
#   'require',
#   'vaccination',
#   'remain',
#   'employed',
#   '.',
#   'but',
#   'are',
#   'we',
#   'really',
#   'going',
#   'try',
#   'starve',
#   'them',
#   'out'],
#  ['biden',
#   'administration',
#   'adopted',
#   'our',
#   'recommendation',
#   'make',
#   'health',
#   'care',
#   'worker',
#   'vaccination',
#   'condition',
#   'medicare',
#   'medicaid',
#   'funds',
#   '.',
#   'scotus',
#   'upheld',
#   'this',
#   'rule',
#   ',',
#   'which',
#   'is',
#   'so',
#   'important',
#   'patient',
#   'safety'],
#  ['required',
#   'preregistration',
#   'now',
#   'is',
#   'open',
#   'meadville',
#   'medical',
#   'center',
#   '’',
#   's',
#   'next',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'set',
#   'feb',
#   '.',
#   'eighteen',
#   'ten',
#   'a',
#   '.',
#   'm',
#   '.',
#   'one',
#   'p',
#   '.',
#   'm',
#   '.',
#   'at',
#   'nine hundred and eighty-four',
#   'water',
#   'st',
#   '.',
#   'clinic',
#   'is',
#   'pfizer',
#   'vaccine',
#   'only',
#   '.'],
#  ['yes',
#   '.',
#   'prevention',
#   'long',
#   'term',
#   'involves',
#   'vaccination',
#   'masks',
#   '.',
#   'reduce',
#   'speaks',
#   'either',
#   'vaccination',
#   'or',
#   'masks',
#   '.',
#   'let',
#   '’',
#   's',
#   'get',
#   'real',
#   '.',
#   'we',
#   '’',
#   're',
#   'not',
#   'going',
#   'beat',
#   'this',
#   '.',
#   'covid',
#   'is',
#   'new',
#   'one thousand, nine hundred and eighteen',
#   'flu',
#   '.',
#   'we',
#   '’',
#   're',
#   'two',
#   'flu',
#   'shots',
#   'year',
#   'going',
#   'forward',
#   '.',
#   'difference',
#   'is',
#   'this',
#   'virus',
#   'has',
#   'higher',
#   'kill',
#   'rate'],
#  ['that',
#   'seems',
#   'way',
#   'more',
#   'reasonable',
#   ',',
#   'will',
#   'yield',
#   'far',
#   'more',
#   'positive',
#   'results',
#   ',',
#   'than',
#   'just',
#   'rescinding',
#   'vaccination',
#   'mandates',
#   'letting',
#   'people',
#   'make',
#   'their',
#   'own',
#   'decisions',
#   '.'],
#  ['come',
#   'one',
#   'come',
#   'allstar',
#   '️',
#   'one thousand, one hundred and fifty-three',
#   'valencia',
#   'st',
#   '.',
#   'los',
#   'angeles',
#   'ninety thousand and fifteen',
#   'free',
#   'produce',
#   ',',
#   'testing',
#   'vaccination',
#   'all'],
#  ['this',
#   'is',
#   'absurd',
#   '.',
#   'please',
#   'take',
#   'look',
#   'mirror',
#   ',',
#   'man',
#   '.',
#   'your',
#   'fellow',
#   'conservatives',
#   'have',
#   'been',
#   'expressly',
#   'supporting',
#   'blockade',
#   '.',
#   'pm',
#   'is',
#   'not',
#   'main',
#   'culprit',
#   'inflamed',
#   'rhetoric',
#   'by',
#   'calling',
#   'vaccination',
#   'respect',
#   'public',
#   'health',
#   'orders',
#   '.'],
#  ['all',
#   'fans',
#   'who',
#   'receive',
#   'their',
#   '1st',
#   ',',
#   '2nd',
#   'or',
#   'booster',
#   'dose',
#   'covid',
#   'vaccine',
#   'at',
#   'super',
#   'bowl',
#   'experience',
#   'can',
#   'receive',
#   'free',
#   'tickets',
#   'enter',
#   'experience',
#   'that',
#   'day',
#   'or',
#   'future',
#   'date',
#   '.',
#   'be',
#   'sure',
#   'visit',
#   'our',
#   'vaccination',
#   'site',
#   'south',
#   'hall',
#   '.',
#   'see',
#   'you',
#   'there',
#   '#',
#   'superbowlexperience',
#   '#',
#   'sblvi'],
#  ['i',
#   'got',
#   'that',
#   '.',
#   'unease',
#   'my',
#   'part',
#   'can',
#   'pass',
#   '.',
#   'adults',
#   'make',
#   'their',
#   'own',
#   'choices',
#   'suffer',
#   'their',
#   'own',
#   'consequences',
#   '.',
#   'how',
#   'are',
#   'we',
#   'deal',
#   'with',
#   'as',
#   'yet',
#   'low',
#   'vaccination',
#   'rates',
#   'five',
#   '-',
#   'eleven',
#   'at',
#   'least',
#   'twelve',
#   '-',
#   'seventeen',
#   'is',
#   'over',
#   'fifty',
#   '%'],
#  ['my',
#   'physical',
#   'vaccination',
#   'card',
#   'is',
#   '…',
#   'gross',
#   'but',
#   'now',
#   'it',
#   'is',
#   'digital',
#   'thanks'],
#  ['allied',
#   'universal',
#   'is',
#   'looking',
#   'hire',
#   'phenomenal',
#   'security',
#   'site',
#   'supervisor',
#   '-',
#   'unarmed',
#   'vaccination',
#   'required',
#   'las',
#   'vegas',
#   ',',
#   'nv',
#   '.',
#   'join',
#   'our',
#   'diverse',
#   'team',
#   '#',
#   'hiringphenomenaltalent',
#   '#',
#   'security'],
#  ['especially',
#   'if',
#   'vehicle',
#   'is',
#   'towed',
#   'u',
#   '.',
#   's',
#   '.',
#   'they',
#   'are',
#   'not',
#   'allowed',
#   'cross',
#   'border',
#   'get',
#   'it',
#   'because',
#   '…',
#   'wait',
#   'it',
#   '…',
#   'u',
#   '.',
#   's',
#   '.',
#   'requires',
#   'proof',
#   'vaccination',
#   'cross',
#   'into',
#   'u',
#   '.',
#   's',
#   '…'],
#  ['links',
#   'papers',
#   'within',
#   'article',
#   'new',
#   'paper',
#   'emphasizes',
#   'dangers',
#   '&',
#   'amp',
#   ';',
#   'harms',
#   'mandatory',
#   'covid',
#   'vaccination',
#   'policy'],
#  ['same', 'for', 'forced', 'vaccination'],
#  ['this',
#   'is',
#   'myocarditis',
#   'foundation',
#   'website',
#   ':',
#   'known',
#   'potential',
#   'benefits',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'outweigh',
#   'known',
#   'potential',
#   'risks',
#   ',',
#   'including',
#   'possible',
#   'risks',
#   'myocarditis',
#   'or',
#   'pericarditis',
#   '.',
#   '…'],
#  ['politicians',
#   'across',
#   'country',
#   'continue',
#   'infringe',
#   'personal',
#   'liberties',
#   'under',
#   'guise',
#   'public',
#   'safety',
#   '.',
#   'today',
#   ',',
#   'we',
#   'filed',
#   'lawsuit',
#   'against',
#   'city',
#   'chicago',
#   'cook',
#   'county',
#   'end',
#   'illegal',
#   'diskriminatory',
#   '“',
#   'proof',
#   'vaccination',
#   'requirements',
#   '.”'],
#  ['governors',
#   'control',
#   'lockdowns',
#   'they',
#   'started',
#   'long',
#   'before',
#   'biden',
#   'biden',
#   'opened',
#   'things',
#   'up',
#   'with',
#   'his',
#   'vaccination',
#   'program',
#   'not',
#   'sure',
#   'you',
#   'are',
#   'tracking',
#   'right',
#   '.',
#   'trump',
#   'spent',
#   'far',
#   'more',
#   'than',
#   'biden',
#   'it',
#   '’',
#   's',
#   'was',
#   'his',
#   'fed',
#   'that',
#   'failed',
#   'increase',
#   'rates',
#   'during',
#   'his',
#   'presidency'],
#  ['you', 'are', 'talking', 'about', 'the', 'covid', 'vaccination', '...'],
#  ['any',
#   'regulation',
#   'size',
#   'rim',
#   '.',
#   'three',
#   'point',
#   'line',
#   '.',
#   'vaccination',
#   'mandate',
#   '.'],
#  ['as',
#   'monday',
#   ',',
#   'proof',
#   'vaccination',
#   'or',
#   'negative',
#   'covid',
#   '-',
#   'nineteen',
#   'test',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'required',
#   'staff',
#   'visitors',
#   'at',
#   'saskatoon',
#   'public',
#   'schools',
#   'sps',
#   '.'],
#  ['amoa',
#   'resort',
#   'has',
#   'activated',
#   'its',
#   'covid',
#   '-',
#   'nineteen',
#   'protocols',
#   'will',
#   'welcome',
#   'guests',
#   'as',
#   'it',
#   'strictly',
#   'observes',
#   'social',
#   'distancing',
#   ',',
#   'face',
#   'masks',
#   'wearing',
#   'enforce',
#   'vaccination',
#   'cards',
#   '-',
#   'only',
#   'entry',
#   '.'],
#  ['centenary',
#   'hospital',
#   'scarborough',
#   'three hundred and sixty-seven',
#   '3rd',
#   'dose',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'is',
#   'two thousand and twenty-two',
#   '-',
#   'two',
#   '-',
#   'ten',
#   'book',
#   'at',
#   'see',
#   'detailed',
#   'availability',
#   '#',
#   'covid19vaccine',
#   '#',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'three hundred and seventy',
#   '2nd',
#   'dose',
#   'pfizer',
#   'or',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'is',
#   'two thousand and twenty-two',
#   '-',
#   'two',
#   '-',
#   'ten',
#   'book',
#   'at',
#   'see',
#   'detailed',
#   'availability',
#   '#',
#   'covid19vaccine',
#   '#',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'three hundred and seventy',
#   '1st',
#   'dose',
#   'pfizer',
#   'or',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'is',
#   'two thousand and twenty-two',
#   '-',
#   'two',
#   '-',
#   'ten',
#   'book',
#   'at',
#   'see',
#   'detailed',
#   'availability',
#   '#',
#   'covid19vaccine',
#   '#',
#   'vhcon'],
#  ['"',
#   'as',
#   'health',
#   'emergency',
#   'law',
#   'force',
#   'now',
#   'that',
#   'gives',
#   'quebec',
#   'sweeping',
#   'powers',
#   ',',
#   'legault',
#   'said',
#   'it',
#   'will',
#   'be',
#   'dropped',
#   'after',
#   'national',
#   'assembly',
#   'adopts',
#   'new',
#   'legislation',
#   'specifying',
#   'which',
#   'measures',
#   'are',
#   'be',
#   'maintained',
#   'such',
#   'as',
#   'vaccination',
#   'passport',
#   '."',
#   '#',
#   'legaultmustresign',
#   '#',
#   'legault'],
#  ['ability',
#   'be',
#   'always',
#   'free',
#   'restrictions',
#   'after',
#   'vaccination',
#   '.',
#   'that',
#   'was',
#   'supposed',
#   'be',
#   'point',
#   'mandates',
#   ',',
#   'that',
#   'trust',
#   'was',
#   'broken',
#   'when',
#   'we',
#   'closed',
#   'businesses',
#   'again',
#   'jan',
#   '.',
#   'you',
#   'may',
#   'be',
#   'able',
#   'go',
#   'restaurants',
#   'now',
#   ',',
#   'but',
#   'there',
#   'is',
#   'no',
#   'guarantee',
#   'you',
#   'will',
#   'do',
#   'so',
#   'april',
#   '.'],
#  ['genuinely',
#   'curious',
#   ',',
#   'can',
#   'you',
#   'find',
#   'me',
#   'clip',
#   'or',
#   'quote',
#   'trump',
#   'telling',
#   'his',
#   'base',
#   'or',
#   'anyone',
#   'at',
#   'all',
#   'anything',
#   'remotely',
#   'anti',
#   'vaccine',
#   'everything',
#   'he',
#   '’',
#   's',
#   'said',
#   'what',
#   'i',
#   '’',
#   've',
#   'seen',
#   'has',
#   'been',
#   'extremely',
#   'pro',
#   'vaccination',
#   'but',
#   'maybe',
#   'you',
#   'have',
#   'other',
#   'sources',
#   'you',
#   'could',
#   'cite',
#   '.'],
#  ['swastikas',
#   'displayed',
#   'at',
#   'canadian',
#   '‘',
#   'freedom',
#   'convoy',
#   '’',
#   'protests',
#   'against',
#   'vaccination',
#   'mandates'],
#  ['that',
#   "'",
#   's',
#   'treatment',
#   '...',
#   'not',
#   'vaccine',
#   '.',
#   'it',
#   "'",
#   's',
#   'obviously',
#   'not',
#   '"',
#   'natural',
#   'immunity',
#   '"',
#   'by',
#   'any',
#   'definition',
#   '.',
#   'you',
#   'do',
#   'know',
#   'what',
#   'your',
#   'original',
#   'response',
#   'said',
#   ',',
#   'right',
#   'you',
#   'do',
#   'know',
#   'vaccination',
#   'occurs',
#   'prior',
#   'illness',
#   'not',
#   'during',
#   'illness',
#   ',',
#   'right'],
#  ['covid',
#   'vaccination',
#   'does',
#   'not',
#   'prevent',
#   'spread',
#   '.',
#   'stop',
#   'with',
#   'disinformation',
#   '.'],
#  ['absolutely',
#   'since',
#   'i',
#   'live',
#   'ohio',
#   'county',
#   'with',
#   'one',
#   'lowest',
#   'vaccination',
#   'rates'],
#  ['hrig',
#   'is',
#   'very',
#   'thick',
#   'yogurt',
#   '-',
#   'like',
#   'substance',
#   'so',
#   'you',
#   'will',
#   'feel',
#   'that',
#   'vaccination',
#   'can',
#   'clearly',
#   'tell',
#   'it',
#   'apart',
#   'normal',
#   'rabies',
#   'jab',
#   '..',
#   'when',
#   'i',
#   'got',
#   'bitten',
#   'they',
#   'forgot',
#   'administer',
#   'that',
#   '-',
#   'but',
#   'it',
#   "'",
#   's',
#   'must',
#   'really',
#   'rabies',
#   'vaccine',
#   'be',
#   'effective',
#   'post',
#   '-',
#   'trauma',
#   '.'],
#  ['meanwhile',
#   ',',
#   'at',
#   'has',
#   'more',
#   'death',
#   'threats',
#   'against',
#   'superintendent',
#   '“',
#   'upheaval',
#   '”',
#   'littleton',
#   'public',
#   'schools',
#   'over',
#   '#',
#   'covid19',
#   'vaccination',
#   '.',
#   '#',
#   'localnews'],
#  ['when',
#   'proof',
#   'vaccination',
#   'gets',
#   'lifted',
#   ',',
#   'our',
#   'elderly',
#   'will',
#   'then',
#   'be',
#   'forced',
#   'isolate',
#   'protect',
#   'themselves',
#   '.'],
#  ['appeals',
#   'court',
#   'will',
#   'not',
#   'block',
#   'order',
#   'barring',
#   'biden',
#   'federal',
#   'staff',
#   'vaccination',
#   'mandate',
#   '#',
#   'newsbreak'],
#  ['agreed',
#   '.',
#   'i',
#   'suspect',
#   'european',
#   'countries',
#   'have',
#   'higher',
#   'uptake',
#   ',',
#   'part',
#   ',',
#   'because',
#   'they',
#   'honored',
#   'recovery',
#   'previously',
#   'infected',
#   'individuals',
#   'adjusted',
#   'their',
#   'vaccination',
#   'recommendations',
#   'as',
#   'result',
#   '.'],
#  ['so',
#   'are',
#   'you',
#   'against',
#   'mandatory',
#   'mumps',
#   ',',
#   'measles',
#   'rubella',
#   'vaccination',
#   'or',
#   'is',
#   'it',
#   'just',
#   'fake',
#   'outrage',
#   'at',
#   'this',
#   'particular',
#   'vaccine'],
#  ['divorce',
#   'rates',
#   'rise',
#   'as',
#   'vaccination',
#   'adds',
#   'stress',
#   'co',
#   '-',
#   'parenting',
#   '-'],
#  ['vaccination', 'away', 'being', 'special'],
#  ['ugh',
#   ',',
#   'that',
#   'sucks',
#   '.',
#   'schools',
#   'marin',
#   'had',
#   'mass',
#   'vaccination',
#   'days',
#   'with',
#   'support',
#   'dogs',
#   'pretty',
#   'much',
#   'every',
#   'school',
#   'district',
#   '.',
#   'out',
#   'twenty',
#   'minutes',
#   '.'],
#  ['keep',
#   'eye',
#   'out',
#   'some',
#   'vaccination',
#   'clinics',
#   'that',
#   'are',
#   'opening',
#   'at',
#   'sign',
#   'up',
#   'at',
#   'gcms'],
#  ['be',
#   'fair',
#   'some',
#   'parents',
#   ',',
#   'we',
#   'haven',
#   "'",
#   't',
#   'set',
#   'up',
#   'much',
#   'mass',
#   'vaccination',
#   'infrastructure',
#   'we',
#   'did',
#   'grownups',
#   '.',
#   'when',
#   'i',
#   'got',
#   'vaxxed',
#   'it',
#   'was',
#   'easy',
#   'as',
#   'hell',
#   ',',
#   'barely',
#   'twenty',
#   'minutes',
#   'including',
#   'fifteen',
#   'min',
#   'observation',
#   '.',
#   'my',
#   'kids',
#   "'",
#   'second',
#   'dose',
#   ',',
#   'two',
#   'hours',
#   'waiting',
#   'damp',
#   'cold',
#   '.'],
#  ['i',
#   'would',
#   'pay',
#   '$',
#   'two hundred',
#   'list',
#   'all',
#   'nominees',
#   'who',
#   'would',
#   '’',
#   've',
#   'been',
#   'blacklisted',
#   'oscars',
#   'if',
#   'academy',
#   'hadn',
#   '’',
#   't',
#   'blinked',
#   'vaccination',
#   'requirements',
#   '.',
#   'imagine',
#   'meltdown',
#   'twitter',
#   'would',
#   '’',
#   've',
#   'had',
#   'as',
#   'wags',
#   're',
#   '-',
#   'weighted',
#   'how',
#   'much',
#   'they',
#   'liked',
#   'movie',
#   'based',
#   'who',
#   'had',
#   'their',
#   'shots',
#   '.',
#   'my',
#   'god',
#   '.'],
#  ['im',
#   'saying',
#   'by',
#   'stopping',
#   'at',
#   'vaccination',
#   'ending',
#   'your',
#   'inquiry',
#   'there',
#   'it',
#   'is',
#   'arbitrary',
#   '.',
#   'european',
#   'union',
#   'allows',
#   'titers',
#   'negative',
#   'tests',
#   'their',
#   'pass',
#   'system',
#   '.'],
#  ['councilman',
#   'are',
#   'you',
#   'vaccinated',
#   'you',
#   'said',
#   'you',
#   'are',
#   'peoples',
#   '’',
#   'champ',
#   'but',
#   'why',
#   'are',
#   'dc',
#   'vaccination',
#   'rates',
#   'continuing',
#   'lag',
#   'your',
#   'district',
#   'you',
#   'can',
#   'be',
#   'leader',
#   'help',
#   'return',
#   'normal',
#   '-',
#   'especially',
#   'given',
#   'tweet',
#   'you',
#   'deleted',
#   'about',
#   'restaurants',
#   '.'],
#  ['having',
#   'government',
#   'offer',
#   'me',
#   'free',
#   'vaccine',
#   'that',
#   'helps',
#   'boost',
#   'my',
#   'immune',
#   'system',
#   ',',
#   'having',
#   'some',
#   'places',
#   'mostly',
#   'private',
#   'businesses',
#   ',',
#   'not',
#   'government',
#   'mandates',
#   'need',
#   'me',
#   'show',
#   'proof',
#   'vaccination',
#   'or',
#   'negative',
#   'test',
#   ',',
#   'doesn',
#   "'",
#   't',
#   'feel',
#   'like',
#   'oppression',
#   'me',
#   '.'],
#  ['saying',
#   'memory',
#   'cells',
#   'don',
#   '’',
#   't',
#   'remember',
#   'things',
#   'terms',
#   'things',
#   'like',
#   'spike',
#   'proteins',
#   '.',
#   'it',
#   'depends',
#   'disease',
#   'or',
#   'vaccination',
#   '.',
#   'example',
#   ',',
#   'hepatitis',
#   'b',
#   'vaccine',
#   'is',
#   'mainly',
#   'based',
#   'its',
#   'surface',
#   'protein'],
#  ['who',
#   'cares',
#   'what',
#   'these',
#   'people',
#   'say',
#   'i',
#   'personally',
#   'don',
#   "'",
#   't',
#   '.',
#   'fact',
#   ',',
#   'i',
#   'couldn',
#   "'",
#   't',
#   'possibly',
#   'care',
#   'less',
#   '.',
#   'why',
#   'should',
#   'anyone',
#   'care',
#   'they',
#   "'",
#   've',
#   'shown',
#   'us',
#   'all',
#   'exactly',
#   'who',
#   'they',
#   'are',
#   '&',
#   'amp',
#   ';',
#   'what',
#   'they',
#   'think',
#   'ppl',
#   'who',
#   'simply',
#   'don',
#   "'",
#   't',
#   'agree',
#   'w',
#   'them',
#   'forced',
#   '"',
#   'vaccination',
#   '".',
#   'i',
#   'don',
#   "'",
#   't',
#   'care',
#   '.'],
#  ['i',
#   'wish',
#   'everyone',
#   'was',
#   'vaccinated',
#   'but',
#   '...',
#   'mandatory',
#   'vaccination',
#   'for',
#   'truckersarticulated_lorry',
#   'is',
#   'a',
#   'measure',
#   'based',
#   'on',
#   'science',
#   'or',
#   'politicsthinking_face'],
#  ['i',
#   'hope',
#   'ontario',
#   'drops',
#   'this',
#   'proof',
#   'vaccination',
#   'soon',
#   '.',
#   'cause',
#   'it',
#   'bring',
#   'way',
#   'too',
#   'much',
#   'unnecessary',
#   'conflicts',
#   'workers',
#   ',',
#   'especially',
#   'when',
#   'they',
#   'wanna',
#   'change',
#   'up',
#   'type',
#   'vacation',
#   'proof',
#   'dime',
#   '…'],
#  ['tyrannical',
#   'biden',
#   'administration',
#   'wants',
#   'mandatory',
#   'vaccination',
#   'protestors',
#   'canada',
#   'crushed',
#   'beneath',
#   'grinding',
#   'wheels',
#   'federal',
#   'authority',
#   '.'],
#  ['six',
#   'since',
#   'then',
#   ',',
#   '#',
#   'covid',
#   'hospitalizations',
#   'denmark',
#   'have',
#   'also',
#   'been',
#   'ticking',
#   'upwards',
#   'despite',
#   'highest',
#   'booster',
#   'vaccination',
#   'rate',
#   'by',
#   'far',
#   'europe',
#   '.',
#   'please',
#   'take',
#   'look',
#   'at',
#   'hospitalizations',
#   'chart',
#   'below',
#   'by',
#   'our',
#   'world',
#   'data',
#   '.'],
#  ['i',
#   "'",
#   'd',
#   'love',
#   'see',
#   'mental',
#   'gymnastics',
#   'you',
#   'have',
#   'perform',
#   'argue',
#   'protesting',
#   'vaccination',
#   'is',
#   'akin',
#   'protesting',
#   'police',
#   'brutality',
#   'against',
#   'minorities'],
#  ['i',
#   'see',
#   'you',
#   'put',
#   '#',
#   'defundcbc',
#   '#',
#   'defundbbc',
#   'unfortunately',
#   'very',
#   'ppl',
#   'behind',
#   'this',
#   'vaccination',
#   'extravaganza',
#   'are',
#   'same',
#   'ppl',
#   'funding',
#   'these',
#   'news',
#   'networks',
#   '.',
#   'just',
#   'sayin',
#   '.',
#   'i',
#   "'",
#   'm',
#   'totally',
#   'with',
#   'you',
#   'though',
#   'but',
#   'funds',
#   'are',
#   'coming',
#   'baddies',
#   '.'],
#  ['broadway',
#   "'",
#   's',
#   'mask',
#   'vaccination',
#   'requirement',
#   'remains',
#   'through',
#   'april',
#   'thirty'],
#  ['"',
#   'super',
#   'immunity',
#   '"',
#   'is',
#   'fake',
#   '.',
#   'you',
#   'can',
#   'get',
#   'covid',
#   'three hundred',
#   'times',
#   'row',
#   '.',
#   'fact',
#   ',',
#   'my',
#   'therapist',
#   'had',
#   'covid',
#   'two',
#   '-',
#   'three',
#   'times',
#   'row',
#   '.',
#   'vaccination',
#   'has',
#   'less',
#   '"',
#   'health',
#   'risks',
#   '"',
#   'than',
#   'getting',
#   'covid',
#   '.',
#   'you',
#   'are',
#   'going',
#   'kill',
#   'people',
#   'due',
#   'attacking',
#   'proven',
#   'technology',
#   '.'],
#  ['jeffrey',
#   'morris',
#   '"',
#   'they',
#   'also',
#   'have',
#   'population',
#   'number',
#   'each',
#   'vaccinated',
#   'status',
#   'each',
#   'age',
#   'group',
#   'each',
#   'week',
#   'that',
#   'can',
#   'be',
#   'used',
#   'compute',
#   'standardized',
#   'death',
#   'rates',
#   'as',
#   'well',
#   'as',
#   'track',
#   'proportion',
#   'that',
#   'age',
#   'group',
#   'each',
#   'vaccination',
#   'status',
#   'over',
#   'time',
#   '"=',
#   'age',
#   '-',
#   'standardizationcheck_mark',
#   '️'],
#  ['school',
#   'age',
#   'vaccination',
#   'is',
#   '.',
#   '.',
#   '.',
#   'not',
#   'going',
#   'very',
#   'well',
#   '.',
#   'one',
#   'my',
#   'kids',
#   "'",
#   'schools',
#   'is',
#   'right',
#   'around',
#   'fifty-five',
#   '%.',
#   'wtf',
#   'is',
#   'wrong',
#   'with',
#   'parents',
#   '...'],
#  ['yup',
#   '.',
#   'i',
#   'still',
#   'mask',
#   'up',
#   'social',
#   'distance',
#   'i',
#   'am',
#   'through',
#   'vaccination',
#   'booster',
#   '.',
#   'so',
#   ',',
#   'yeah',
#   '.',
#   'be',
#   'smart',
#   '.'],
#  ['besides',
#   'fact',
#   'that',
#   'even',
#   'if',
#   'there',
#   'was',
#   'no',
#   'mandate',
#   'canada',
#   ',',
#   'that',
#   'just',
#   'means',
#   'only',
#   'those',
#   'entering',
#   'other',
#   'countries',
#   'don',
# ...
#   'new',
#   'cases',
#   '.',
#   'north',
#   'central',
#   'zone',
#   'has',
#   'highest',
#   'new',
#   'cases',
#   '.',
#   'thirty',
#   'outbreaks',
#   'confirmed',
#   'high',
#   '-',
#   'risk',
#   'settings',
#   '.',
#   'seventy-nine',
#   '.',
#   'six',
#   '%',
#   'those',
#   'over',
#   'five',
#   'have',
#   'received',
#   'two',
#   'doses',
#   'vaccine',
#   '.',
#   'regina',
#   'is',
#   'area',
#   'with',
#   'highest',
#   'rate',
#   'vaccination',
#   ',',
#   'all',
#   'other',
#   'areas',
#   'are',
#   'below',
#   'eighty',
#   '%.'],
#  ['film',
#   'academy',
#   'reportedly',
#   'won',
#   '’',
#   't',
#   'require',
#   'proof',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'at',
#   'oscars'],
#  ['by',
#   'time',
#   'nba',
#   'playoffs',
#   'start',
#   'there',
#   'won',
#   '’',
#   't',
#   'be',
#   'any',
#   'vaccination',
#   'requirements'],
#  ['"',
#   'but',
#   'he',
#   'said',
#   'it',
#   'was',
#   'right',
#   'moment',
#   'benefit',
#   'omicron',
#   '’',
#   's',
#   'seeming',
#   'mildness',
#   'country',
#   '’',
#   's',
#   'high',
#   'vaccination',
#   'rate',
#   '—',
#   'eighty-one',
#   'percent',
#   'entire',
#   'population',
#   'has',
#   'been',
#   'fully',
#   'vaccinated',
#   ',',
#   'sixty-two',
#   'percent',
#   'have',
#   'received',
#   'additional',
#   'shot',
#   '."',
#   '#',
#   'denmark'],
#  ['idk',
#   'what',
#   'you',
#   'mean',
#   '.',
#   'it',
#   'isn',
#   '’',
#   't',
#   'my',
#   'problem',
#   'if',
#   'they',
#   'choose',
#   'not',
#   'vax',
#   'their',
#   'children',
#   ',',
#   'then',
#   'need',
#   'babysitter',
#   '.',
#   'maybe',
#   'if',
#   'their',
#   'kids',
#   'can',
#   '’',
#   't',
#   'go',
#   'out',
#   'public',
#   'unvaccinated',
#   'it',
#   'woulf',
#   'spur',
#   'parents',
#   'choose',
#   'vaccination',
#   ',',
#   'which',
#   'is',
#   'optimal',
#   ',',
#   'imo',
#   '.'],
#  ['since',
#   'we',
#   'are',
#   'here',
#   ':',
#   'has',
#   'reportedly',
#   'stopped',
#   'facilitating',
#   'payments',
#   'vaccination',
#   'control',
#   'group',
#   '.'],
#  ['.',
#   'what',
#   'happened',
#   'following',
#   'cdc',
#   'guidelines',
#   'what',
#   'did',
#   'you',
#   'cave',
#   'what',
#   '’',
#   's',
#   'gonna',
#   'happen',
#   'when',
#   'rates',
#   'climb',
#   'again',
#   'cali',
#   'has',
#   'good',
#   'vaccination',
#   'rate',
#   '…',
#   'nv',
#   'does',
#   'not',
#   '.',
#   'you',
#   'failed',
#   'this',
#   'state'],
#  ['pm',
#   'couldn',
#   '’',
#   't',
#   'even',
#   'answer',
#   'opposition',
#   'leader',
#   'question',
#   'during',
#   'debate',
#   'questioning',
#   'about',
#   'how',
#   'much',
#   'vaccination',
#   'rate',
#   'is',
#   'enough',
#   'before',
#   'these',
#   'mandates',
#   'are',
#   'lifted',
#   '.',
#   'this',
#   'man',
#   'is',
#   'not',
#   'clearly',
#   'fit',
#   'lead',
#   'this',
#   'great',
#   'country',
#   'he',
#   '’',
#   's',
#   'so',
#   'incompetent',
#   '.'],
#  ['new',
#   'york',
#   'state',
#   'is',
#   'dropping',
#   'mask',
#   'requirements',
#   ',',
#   'but',
#   'broadway',
#   'is',
#   'not',
#   ':',
#   '#',
#   'arts',
#   '#',
#   'artsnews',
#   '"',
#   'broadway',
#   "'",
#   's',
#   'mask',
#   'vaccination',
#   'policy',
#   'will',
#   'remain',
#   'place',
#   'through',
#   'at',
#   'least',
#   'april',
#   'thirty',
#   ',',
#   'most',
#   'recent',
#   'extension',
#   'date',
#   'policy',
#   'announced',
#   'last',
#   'month',
#   '.',
#   'broadway',
#   '...'],
#  ['proof',
#   'world',
#   'is',
#   'being',
#   'taken',
#   'over',
#   '.',
#   'whistles',
#   'are',
#   'being',
#   'blamed',
#   'heart',
#   'attacks',
#   'myocarditis',
#   'occurring',
#   'chests',
#   'athletes',
#   'field',
#   '..',
#   'also',
#   'ottawa',
#   'citizens',
#   'are',
#   'concerned',
#   'about',
#   'exhaust',
#   'trucks',
#   'not',
#   'five',
#   'year',
#   'old',
#   'who',
#   'died',
#   'ten',
#   'minutes',
#   'after',
#   'vaccination'],
#  ['dr',
#   '.',
#   'brian',
#   'temple',
#   'diskusses',
#   'efforts',
#   'debunk',
#   'vaccination',
#   'mistruths',
#   ',',
#   'offers',
#   'advice',
#   'people',
#   'wanting',
#   'go',
#   'into',
#   'health',
#   'care',
#   'shares',
#   'his',
#   'thoughts',
#   'black',
#   'history',
#   '.'],
#  ['check',
#   'out',
#   'england',
#   '’',
#   's',
#   'non',
#   '-',
#   'covid',
#   'death',
#   'spikes',
#   'after',
#   'vaccination',
#   '.'],
#  ['no',
#   'more',
#   'than',
#   'evidence',
#   'that',
#   'masks',
#   'did',
#   'little',
#   'good',
#   '.',
#   'why',
#   'start',
#   'with',
#   'vaccination',
#   'stats',
#   ',',
#   'then',
#   'ask',
#   'about',
#   'masks',
#   ',…',
#   'cable',
#   'tv',
#   'gig',
#   'upcoming'],
#  ['i',
#   "'",
#   'm',
#   'sorry',
#   ',',
#   'i',
#   'know',
#   'how',
#   'important',
#   'it',
#   'is',
#   'convince',
#   'people',
#   'get',
#   'covid',
#   'instead',
#   'getting',
#   'vaccination',
#   ',',
#   'i',
#   "'",
#   'm',
#   'not',
#   'kink',
#   'shaming',
#   ',',
#   'but',
#   'you',
#   'got',
#   'tricked',
#   ',',
#   'people',
#   'who',
#   'don',
#   "'",
#   't',
#   'read',
#   'that',
#   'article',
#   'share',
#   'it',
#   'all',
#   'time',
#   'because',
#   'it',
#   'sounds',
#   'like',
#   'what',
#   'they',
#   'want',
#   'believe'],
#  ['i',
#   'agree',
#   '.',
#   'i',
#   'tried',
#   'steer',
#   'conversation',
#   'towards',
#   'bc',
#   "'",
#   's',
#   'ridiculous',
#   'blocking',
#   'people',
#   'getting',
#   'tested',
#   '.',
#   'vaccine',
#   'mandates',
#   'are',
#   'distraction',
#   '&',
#   'amp',
#   ';',
#   'will',
#   'be',
#   'dropped',
#   'soon',
#   'anyway',
#   '.',
#   'ph',
#   'leadership',
#   'viewed',
#   'them',
#   'as',
#   'just',
#   'tool',
#   'encourage',
#   'vaccination',
#   '.',
#   'that',
#   'work',
#   'is',
#   'done',
#   '.'],
#  ['zany_facezany_facezany_facezany_facezany_facezany_facezany_facezany_facezany_face',
#   '“',
#   'and',
#   'oscar',
#   'hypocrisy',
#   'goes',
#   'to',
#   '…&',
#   'amp',
#   ';#',
#   'eight thousand, two hundred and seventeen',
#   ';:',
#   'twitter',
#   'reacts',
#   'academy',
#   'awards',
#   'not',
#   'requiring',
#   'proof',
#   'vaccination'],
#  ['his',
#   'lifetime',
#   ',',
#   'it',
#   'went',
#   'death',
#   'sentence',
#   'very',
#   'manageable',
#   'condition',
#   ',',
#   'now',
#   'might',
#   'even',
#   'have',
#   'vaccination',
#   'against',
#   'it',
#   'soon',
#   '.',
#   'that',
#   "'",
#   's',
#   'amazing',
#   'testament',
#   'science'],
#  ['luc',
#   'montagnier',
#   '’',
#   's',
#   'beliefs',
#   'about',
#   'vaccination',
#   'milan',
#   'one',
#   '/',
#   'fifteen',
#   '/',
#   'twenty-two',
#   'at',
#   'ten',
#   ':',
#   'twenty-three',
#   ',',
#   'dr',
#   '.',
#   'said',
#   'shared',
#   'that',
#   'it',
#   'will',
#   'be',
#   'up',
#   'unvaccinated',
#   'defend',
#   'humanity',
#   '.',
#   'according',
#   'reliable',
#   'sources',
#   ',',
#   'italian',
#   'translator',
#   'translates',
#   'unvaccinated',
#   'are',
#   'guardians',
#   'humanity',
#   'rip',
#   'seeker',
#   'truth'],
#  ['eight',
#   '/',
#   'u',
#   'so',
#   'makary',
#   'is',
#   'being',
#   'misleading',
#   'when',
#   'he',
#   'uses',
#   'his',
#   'paper',
#   'diskuss',
#   '"',
#   'natural',
#   'immunity',
#   '"',
#   'vs',
#   '.',
#   'vaccination',
#   ',',
#   'since',
#   'he',
#   'isn',
#   "'",
#   't',
#   'assessing',
#   'neutralization',
#   '.',
#   'note',
#   'difference',
#   'between',
#   'what',
#   'his',
#   'paper',
#   'vs',
#   '.',
#   'his',
#   'twitter',
#   'claim',
#   'about',
#   'his',
#   'paper',
#   ':'],
#  ['evidence',
#   'increased',
#   'infection',
#   'risk',
#   'following',
#   'third',
#   'dose',
#   ',',
#   'exacerbated',
#   'by',
#   'vaccination',
#   'drive',
#   'during',
#   'omicron',
#   'wave',
#   ',',
#   'ukhsa',
#   'data',
#   'show',
#   'via'],
#  ['so',
#   'make',
#   'right',
#   'fly',
#   'governed',
#   'by',
#   'airlines',
#   '.',
#   'if',
#   'they',
#   'want',
#   'institute',
#   'mandates',
#   'they',
#   'can',
#   '.',
#   'this',
#   'is',
#   'no',
#   'longer',
#   'about',
#   'public',
#   'health',
#   'given',
#   'we',
#   '’',
#   're',
#   'at',
#   'ninety',
#   '%',
#   'vaccination',
#   ',',
#   'this',
#   'is',
#   'about',
#   'individual',
#   'health',
#   '.'],
#  ['b',
#   '.',
#   'c',
#   '.',
#   'expanding',
#   'vaccination',
#   'requirements',
#   'health',
#   '-',
#   'care',
#   'professionals'],
#  ['we',
#   'will',
#   'be',
#   'mcl',
#   'room',
#   'seven hundred and ten',
#   '.',
#   'please',
#   'make',
#   'sure',
#   'rsvp',
#   'by',
#   '3happy_face_smiley0',
#   '.',
#   'vaccination',
#   'cards',
#   ',',
#   'masks',
#   'are',
#   'required',
#   'link',
#   'below',
#   '-'],
#  ['ah',
#   ',',
#   'well',
#   ',',
#   'with',
#   'each',
#   'answer',
#   ',',
#   'he',
#   'managed',
#   'to',
#   'place',
#   'the',
#   'word',
#   'vaccination',
#   'and',
#   'its',
#   'diminutives',
#   'of',
#   'course',
#   '.',
#   'he',
#   'is',
#   'too',
#   'strong',
#   'our',
#   'national',
#   'juju'],
#  ['really',
#   'not',
#   'happy',
#   'about',
#   'this',
#   '.',
#   'i',
#   'may',
#   'be',
#   'minority',
#   'with',
#   'these',
#   'feelings',
#   ',',
#   'but',
#   'kids',
#   'five',
#   '&',
#   'amp',
#   ';',
#   'under',
#   'still',
#   'can',
#   '’',
#   't',
#   'get',
#   'vaxxed',
#   ',',
#   'many',
#   'people',
#   'remain',
#   'unvaxxed',
#   ',',
#   'this',
#   'says',
#   'fuck',
#   'you',
#   'anyone',
#   'who',
#   'is',
#   'immunocompromised',
#   '.',
#   'full',
#   'vaccination',
#   'clark',
#   'county',
#   ',',
#   'nv',
#   'is',
#   'still',
#   'below',
#   'fifty-six',
#   '%.',
#   'ugh',
#   '.'],
#  ['fyi',
#   ':',
#   'canadian',
#   'truckers',
#   ',',
#   'with',
#   'ninety',
#   '%',
#   'vaccination',
#   'rate',
#   ',',
#   'are',
#   'more',
#   'vaccinated',
#   'than',
#   'any',
#   'single',
#   'demographic',
#   'group',
#   'america',
#   'that',
#   'i',
#   "'",
#   've',
#   'come',
#   'across',
#   ',',
#   'except',
#   'doctors',
#   '.'],
#  ['seriously',
#   '...',
#   'it',
#   "'",
#   's',
#   'well',
#   'documented',
#   'that',
#   'risk',
#   'transmitting',
#   'covid',
#   'is',
#   'same',
#   'regardless',
#   'vaccination',
#   'status'],
#  ['minneapolis',
#   ',',
#   'st',
#   '.',
#   'paul',
#   'immediately',
#   'lift',
#   'mandate',
#   'requiring',
#   'proof',
#   'vaccination',
#   ',',
#   'negative',
#   'test'],
#  ['ask',
#   'her',
#   'if',
#   'proof',
#   'vaccination',
#   'could',
#   'be',
#   'used',
#   'by',
#   'republicans',
#   'voter',
#   'id',
#   '.'],
#  ['yes', 'like', 'vaccination', '.'],
#  ['people',
#   'who',
#   'defend',
#   'joe',
#   'rogan',
#   'like',
#   'say',
#   'that',
#   'he',
#   'has',
#   '‘',
#   'tough',
#   'conversations',
#   '’',
#   'with',
#   '‘',
#   'wide',
#   'range',
#   'voices',
#   '.’',
#   'but',
#   'then',
#   ',',
#   'why',
#   'does',
#   'he',
#   'never',
#   'seem',
#   'host',
#   ',',
#   'say',
#   ',',
#   'critical',
#   'race',
#   'theorists',
#   'trans',
#   'rights',
#   'activists',
#   'real',
#   'doctors',
#   'defend',
#   'vaccination',
#   'anyone',
#   'who',
#   'might',
#   'actually',
#   'challenge',
#   'him'],
#  ['if',
#   'vaccination',
#   'alone',
#   'is',
#   'solution',
#   ',',
#   'then',
#   'we',
#   'need',
#   'next',
#   'gen',
#   'vaccines',
#   'that',
#   'protect',
#   'broadly',
#   'across',
#   'variants',
#   ',',
#   'create',
#   'sterilyzing',
#   'immune',
#   'response',
#   'body',
#   '.',
#   'that',
#   'will',
#   'take',
#   'time',
#   '.',
#   'interim',
#   ',',
#   'premiers',
#   'can',
#   "'",
#   't',
#   'ignore',
#   'ph',
#   'protections',
#   ',',
#   'so',
#   'we',
#   'can',
#   '"',
#   'live',
#   'with',
#   'it',
#   '".'],
#  ['many',
#   'businesses',
#   'introduced',
#   'proof',
#   'vaccination',
#   'mandatory',
#   'masking',
#   'measures',
#   'before',
#   'government',
#   'did',
#   '.',
#   'now',
#   ',',
#   'with',
#   'public',
#   'health',
#   'orders',
#   'set',
#   'end',
#   ',',
#   'could',
#   'businesses',
#   'keep',
#   'those',
#   'requirements',
#   'their',
#   'patrons',
#   'got',
#   'one',
#   'regina',
#   'lawyer',
#   "'",
#   's',
#   'legal',
#   'opinion',
#   '.',
#   'listen',
#   ':'],
#  ['at',
#   'idw',
#   'dinner',
#   'believe',
#   'me',
#   ',',
#   'man',
#   ',',
#   'this',
#   'is',
#   'something',
#   'i',
#   '’',
#   've',
#   'spend',
#   'lot',
#   'time',
#   'thinking',
#   'about',
#   ':',
#   'vaccine',
#   'passports',
#   'are',
#   'essentially',
#   'social',
#   'gulag',
#   '-',
#   'then',
#   'you',
#   'have',
#   'ask',
#   ',',
#   'well',
#   'what',
#   '’',
#   's',
#   'so',
#   'bad',
#   'about',
#   'that',
#   'yo',
#   '-',
#   'oh',
#   'hold',
#   'on',
#   ',',
#   'get',
#   'your',
#   'proof',
#   'vaccination',
#   'id',
#   'ready',
#   'hostess'],
#  ['canr',
#   '—',
#   'lgbtq',
#   'adults',
#   'have',
#   'higher',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'rates',
#   'than',
#   'heterosexual',
#   'adults',
#   ':',
#   'pandemic',
#   'has',
#   'has',
#   'unique',
#   'impact',
#   'lgbtq',
#   'community',
#   '.',
#   'cdc',
#   'says',
#   'lgbt',
#   '"',
#   'persons',
#   'are',
#   'at',
#   'increased',
#   'risk',
#   'severe',
#   'covid',
#   '-',
#   'nineteen',
#   'illness',
#   '...',
#   'view',
#   'article',
#   '...'],
#  ['i',
#   'haven',
#   "'",
#   't',
#   'even',
#   'gotten',
#   'original',
#   'vaccination',
#   'yet',
#   'not',
#   'because',
#   'i',
#   'don',
#   "'",
#   't',
#   'want',
#   'but',
#   'because',
#   'i',
#   "'",
#   'm',
#   'not',
#   'allowed',
#   'make',
#   'my',
#   'own',
#   'medical',
#   'decisions'],
#  ['.',
#   'says',
#   'countries',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'than',
#   'canada',
#   'have',
#   'reopened',
#   '.',
#   'she',
#   'asks',
#   'pm',
#   'trudeau',
#   'if',
#   'he',
#   "'",
#   'll',
#   'only',
#   'end',
#   'mandates',
#   'reopen',
#   'country',
#   'if',
#   'one hundred',
#   '%',
#   'canadians',
#   'are',
#   'vaccinated',
#   '.',
#   'trudeau',
#   'responds',
#   'says',
#   'vaccines',
#   'will',
#   'help',
#   'lift',
#   'restrictions',
#   '.',
#   '#',
#   'cdnpoli'],
#  ['mask',
#   'vaccination',
#   'requirements',
#   'are',
#   'tyranny',
#   'people',
#   'love',
#   'throwing',
#   'that',
#   'word',
#   'around',
#   '...',
#   'and',
#   'name',
#   'calling',
#   'ad',
#   'hominem',
#   'attacks',
#   'are',
#   'not',
#   'going',
#   'make',
#   'your',
#   'argument',
#   'any',
#   'better',
#   '.',
#   'toodles',
#   '.',
#   'waving_handdark_skin_tone'],
#  ['are', 'you', 'anti', 'vaccination', 'or', 'anti', 'covid', 'vaccination'],
#  ['do',
#   'you',
#   'still',
#   'need',
#   'get',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccine',
#   'louisianians',
#   'who',
#   'get',
#   'their',
#   'first',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccination',
#   'shot',
#   'are',
#   'eligible',
#   'receive',
#   '$',
#   'one hundred',
#   ',',
#   'including',
#   'children',
#   'ages',
#   'five',
#   '–',
#   'seventeen',
#   '.',
#   '#',
#   'covid19'],
#  ["'",
#   'make',
#   'vaccination',
#   'process',
#   'easy',
#   'close',
#   'home',
#   'people',
#   "':",
#   'campaign',
#   'focusing',
#   'getting',
#   'covid',
#   '-',
#   'nineteen',
#   'vaccines',
#   'east',
#   '-',
#   'end',
#   '#',
#   'toronto',
#   'residents',
#   'starts',
#   'this',
#   'saturday'],
#  ['choosing',
#   'good',
#   'policy',
#   'choices',
#   'isn',
#   '’',
#   't',
#   'making',
#   'wedge',
#   '.',
#   'if',
#   'anything',
#   ',',
#   'it',
#   'was',
#   'conservatives',
#   'that',
#   'politicized',
#   'issue',
#   'by',
#   'knee',
#   'jerk',
#   'criticizing',
#   'every',
#   'choice',
#   'at',
#   'every',
#   'step',
#   '.',
#   'so',
#   'naturally',
#   ',',
#   'if',
#   'trudeau',
#   'chose',
#   'vaccination',
#   ',',
#   'conservatives',
#   'chose',
#   'opposite',
#   '.'],
#  ['when',
#   'there',
#   'was',
#   'no',
#   'vaccine',
#   'djt',
#   '’',
#   's',
#   'incompetence',
#   'allowed',
#   'isolated',
#   'covid',
#   'infections',
#   'spread',
#   'epidemic',
#   'proportions',
#   ',',
#   'requiring',
#   'trump',
#   'shutdown',
#   ',',
#   'tht',
#   'led',
#   'trump',
#   'recession',
#   '.',
#   'biden',
#   'american',
#   'rescue',
#   'plan',
#   'ended',
#   'trump',
#   'epidemic',
#   '&',
#   'amp',
#   ';',
#   'recession',
#   'by',
#   'organizing',
#   'vaccination',
#   'programs',
#   '.'],
#  ['yes',
#   ',',
#   'photo',
#   'your',
#   'vaccination',
#   'card',
#   'will',
#   'be',
#   'sufficient',
#   'entry',
#   '.',
#   'thanks'],
#  ['watched',
#   'hbo',
#   'vice',
#   'story',
#   'trying',
#   'make',
#   'me',
#   'feel',
#   'guilty',
#   'making',
#   'fun',
#   'people',
#   'that',
#   'denied',
#   'covid',
#   'and',
#   '/',
#   'or',
#   'refused',
#   'vaccination',
#   'later',
#   'died',
#   '.',
#   'me',
#   ':'],
#  ['been',
#   'watching',
#   'coverage',
#   'this',
#   'insanity',
#   'anti',
#   'vaccination',
#   'trucker',
#   'protests',
#   '.',
#   'their',
#   'is',
#   'threat',
#   'trucker',
#   'protest',
#   'at',
#   'super',
#   'bowl',
#   '.',
#   'this',
#   'would',
#   'annoy',
#   'one',
#   '%',
#   'privilege',
#   'class',
#   '&',
#   'amp',
#   ';',
#   'other',
#   'wealthy',
#   'people',
#   '.',
#   'that',
#   'only',
#   'people',
#   'who',
#   'could',
#   'afford',
#   'tickets',
#   '.',
#   'range',
#   'tickets',
#   'prices',
#   'one',
#   'm',
#   '-',
#   '10m'],
#  ['like',
#   '#',
#   'masks',
#   ',',
#   '#',
#   'socialdistancing',
#   ',',
#   '#',
#   'vaccination',
#   '.',
#   'because',
#   'so',
#   'many',
#   'still',
#   'refuse',
#   'get',
#   '#',
#   'vaccinated',
#   ',',
#   'while',
#   'people',
#   'much',
#   'world',
#   'don',
#   "'",
#   't',
#   'even',
#   'yet',
#   'have',
#   'access',
#   '#',
#   'vaccine',
#   ',',
#   'we',
#   'will',
#   'see',
#   'more',
#   'variations',
#   'resulting',
#   'infections',
#   'deaths',
#   '.',
#   'who',
#   'wouldn',
#   "'",
#   't',
#   'assume',
#   'that',
#   'wise',
#   'alien',
#   'four',
#   '/'],
#  ...]

# %% [markdown]
# ## Remove punctuation

# %%
# remove punctuations from tokenised_lower
tokenised_words_only = [[w for w in each if re.search('^[a-z]+$',w)] for each in tokenised_lower]
tokenised_words_only
# Out:
# [['want',
#   'find',
#   'way',
#   'end',
#   'racism',
#   'try',
#   'force',
#   'people',
#   'inject',
#   'themselves',
#   'that',
#   's',
#   'what',
#   'i',
#   'see',
#   'bunch',
#   'people',
#   'all',
#   'races',
#   'standing',
#   'up',
#   'against',
#   'forced',
#   'vaccination',
#   'not',
#   'against',
#   'vaxx',
#   'some',
#   'people',
#   'need',
#   'these',
#   'vaxx',
#   'amp',
#   'i',
#   'support',
#   'those',
#   'people',
#   'getting',
#   'their',
#   'shot',
#   'i',
#   'draw',
#   'line',
#   'at',
#   'force'],
#  ['this',
#   'child',
#   'almost',
#   'died',
#   'tetanus',
#   'spent',
#   'months',
#   'hospital',
#   'at',
#   'cost',
#   'around',
#   'his',
#   'parents',
#   'still',
#   'refused',
#   'vaccination',
#   'after',
#   'this',
#   'was',
#   'pre',
#   'pandemic'],
#  ['just',
#   'remember',
#   'mr',
#   'leblanc',
#   'the',
#   'pressure',
#   'that',
#   'the',
#   'provincial',
#   'pm',
#   'and',
#   'the',
#   'business',
#   'world',
#   'asked',
#   'for',
#   'it',
#   'to',
#   'be',
#   'able',
#   'to',
#   're',
#   'open',
#   'the',
#   'borders',
#   'air',
#   'traffic',
#   'will',
#   'the',
#   'provincial',
#   'govt',
#   'qc',
#   'included',
#   'block',
#   'tourists',
#   'who',
#   'will',
#   'not',
#   'have',
#   'a',
#   'pass',
#   'vaccination',
#   'at',
#   'the',
#   'hotel',
#   'at',
#   'the',
#   'restaurant'],
#  ['you',
#   'would',
#   'expect',
#   'cases',
#   'rise',
#   'significantly',
#   'course',
#   'vaccination',
#   'rates',
#   'come',
#   'into',
#   'play',
#   'as',
#   'does',
#   'space',
#   'we',
#   'as',
#   'adults',
#   'are',
#   'not',
#   'usually',
#   'confined',
#   'single',
#   'space',
#   'with',
#   'as',
#   'many',
#   'people',
#   'as',
#   'school',
#   'age',
#   'students',
#   'data',
#   'states',
#   'that',
#   'have',
#   'lifted',
#   'vs',
#   'those',
#   'that',
#   'have',
#   'not',
#   'bears',
#   'this',
#   'out'],
#  ['depends',
#   'whether',
#   'vaccination',
#   'status',
#   'is',
#   'embedded',
#   'qr',
#   'code',
#   'itself',
#   'or',
#   'if',
#   'code',
#   'is',
#   'just',
#   'link',
#   'that',
#   'connects',
#   'back',
#   'end',
#   'i',
#   'read',
#   'about',
#   'it',
#   'when',
#   'it',
#   'was',
#   'released',
#   'but',
#   'can',
#   't',
#   'remember',
#   'will',
#   'see',
#   'it',
#   'i',
#   'can',
#   'find',
#   'it',
#   'again'],
#  ['it',
#   'could',
#   'have',
#   'ripped',
#   'harder',
#   'or',
#   'do',
#   'you',
#   'think',
#   'masking',
#   'isolation',
#   'etc',
#   'ultimately',
#   'had',
#   'no',
#   'impact',
#   'honest',
#   'question',
#   'i',
#   'look',
#   'at',
#   'those',
#   'spikes',
#   'think',
#   'maybe',
#   'they',
#   'would',
#   'have',
#   'looked',
#   'same',
#   'no',
#   'matter',
#   'what',
#   'with',
#   'vaccination',
#   'only',
#   'thing',
#   'that',
#   'definitively',
#   'worked'],
#  ['they',
#   'do',
#   'this',
#   'at',
#   'vaccination',
#   'centers',
#   'as',
#   'well',
#   'they',
#   'refused',
#   'let',
#   'me',
#   'amp',
#   'my',
#   'elderly',
#   'parent',
#   'wear',
#   'it',
#   'over',
#   'our',
#   'masks',
#   'lady',
#   'was',
#   'very',
#   'rude',
#   'amp',
#   'said',
#   'i',
#   'could',
#   'i',
#   'have',
#   'covid',
#   'nineteen',
#   'amp',
#   'it',
#   'could',
#   'be',
#   'mask',
#   'i',
#   'refused',
#   'amp',
#   'did',
#   'not',
#   'take',
#   'no',
#   'answer',
#   'she',
#   'said',
#   'ok',
#   'begrudgingly',
#   'it',
#   'was',
#   'absurd'],
#  ['part',
#   'vanguard',
#   'vaccination',
#   'awareness',
#   'project',
#   'series',
#   'free',
#   'tools',
#   'help',
#   'c',
#   'suite',
#   'leaders',
#   'combat',
#   'vaccine',
#   'hesitancy',
#   'resistance',
#   'podcasts',
#   'videos',
#   'articles',
#   'available',
#   'at',
#   'covidvaccineconfidence',
#   'vanguardvaccinationproject'],
#  ['correct',
#   'it',
#   's',
#   'not',
#   'about',
#   'vaccines',
#   'nor',
#   'is',
#   'their',
#   'stated',
#   'goal',
#   'about',
#   'vaccination',
#   'breaking',
#   'cnn',
#   'blogger',
#   'reports',
#   'factual',
#   'news',
#   'accident',
#   'this',
#   'is',
#   'not',
#   'about',
#   'vaccines',
#   'at',
#   'least',
#   'we',
#   'know',
#   'she',
#   'can',
#   'read',
#   'positive',
#   'steps',
#   'towards',
#   'competence'],
#  ['does',
#   'it',
#   'hurt',
#   'your',
#   'head',
#   'actually',
#   'use',
#   'your',
#   'brain',
#   'you',
#   'seem',
#   'be',
#   'incredibly',
#   'brainwashed',
#   'places',
#   'with',
#   'highest',
#   'vaccination',
#   'rates',
#   'world',
#   'have',
#   'some',
#   'highest',
#   'case',
#   'counts',
#   'everyone',
#   'that',
#   'disagrees',
#   'with',
#   'your',
#   'compliance',
#   'totaltiarin',
#   'dictatorships',
#   'must',
#   'be',
#   'called',
#   'names'],
#  ['world',
#   'wide',
#   'mass',
#   'vaccination',
#   'leading',
#   'world',
#   'wide',
#   'digital',
#   'passport',
#   'is',
#   'their',
#   'goal',
#   'populationcontrol'],
#  ['as',
#   'vaccinations',
#   'you',
#   'll',
#   'still',
#   'need',
#   'proof',
#   'vaccination',
#   'restaurants',
#   'movie',
#   'theaters',
#   'museums',
#   'large',
#   'arenas',
#   'gyms',
#   'fitness',
#   'centers',
#   'btw',
#   'nyc',
#   'vaccination',
#   'rate',
#   'is',
#   'now',
#   'at',
#   'more',
#   'at',
#   'three',
#   'three'],
#  ['following',
#   'tweet',
#   'didn',
#   't',
#   'even',
#   'age',
#   'twelve',
#   'hours',
#   'before',
#   'prince',
#   'charles',
#   'announced',
#   'his',
#   'reinfection',
#   'even',
#   'after',
#   'vaccination',
#   'amp',
#   'booster',
#   'so',
#   'yes',
#   'clearly',
#   'previous',
#   'infection',
#   'protects',
#   'you',
#   'at',
#   'this',
#   'point',
#   'does',
#   'boris',
#   'johnson',
#   'exude',
#   'some',
#   'sort',
#   'hypnotoad',
#   'like',
#   'pheromone',
#   'or',
#   'something'],
#  ['vaccination'],
#  ['private',
#   'businesses',
#   'can',
#   'enforce',
#   'vaccination',
#   'mandates',
#   'if',
#   'they',
#   'choose',
#   'do',
#   'so'],
#  ['one',
#   'i',
#   'understand',
#   'exactly',
#   'what',
#   'needs',
#   'to',
#   'be',
#   'understood',
#   'lame',
#   'link',
#   'two',
#   'even',
#   'if',
#   'it',
#   'remains',
#   'lame',
#   'when',
#   'vaccination',
#   'is',
#   'compulsory',
#   'you',
#   'will',
#   'come',
#   'back',
#   'to',
#   'bawl',
#   'bye',
#   'there'],
#  ['story',
#   'with',
#   'martha',
#   'mccallum',
#   'am',
#   'llc',
#   'senior',
#   'medical',
#   'advisor',
#   'dr',
#   'robert',
#   'redfield',
#   'comments',
#   'confusing',
#   'messaging',
#   'spread',
#   'omicron',
#   'importance',
#   'maintaining',
#   'your',
#   'vaccination',
#   'status',
#   'watch',
#   'full',
#   'interview',
#   'below'],
#  ['world',
#   's',
#   'top',
#   'virologist',
#   'luc',
#   'montagnier',
#   'winner',
#   'nobel',
#   'prize',
#   'his',
#   'diskovery',
#   'hiv',
#   'died',
#   'today',
#   'he',
#   'warned',
#   'us',
#   'beginning',
#   'that',
#   'covid',
#   'nineteen',
#   'was',
#   'lab',
#   'made',
#   'that',
#   'mass',
#   'vaccination',
#   'with',
#   'leaky',
#   'vaccines',
#   'would',
#   'generate',
#   'endless',
#   'new',
#   'variants',
#   'right',
#   'both',
#   'counts',
#   'rip'],
#  ['obvious',
#   'common',
#   'sense',
#   'solution',
#   'was',
#   'always',
#   'take',
#   'free',
#   'safe',
#   'vaccination',
#   'against',
#   'deadly',
#   'virus',
#   'then',
#   'carry',
#   'about',
#   'your',
#   'business',
#   'like',
#   'non',
#   'lunatic'],
#  ['sure',
#   'tootin',
#   'i',
#   'do',
#   'remember',
#   'i',
#   'grew',
#   'up',
#   'jackson',
#   'mi',
#   'at',
#   'least',
#   'place',
#   'long',
#   'associated',
#   'with',
#   'republican',
#   'party',
#   'i',
#   'am',
#   'familiar',
#   'with',
#   'conservative',
#   'mien',
#   'mindset',
#   'amp',
#   'i',
#   'can',
#   'speak',
#   'that',
#   'i',
#   'think',
#   'plain',
#   'language',
#   'i',
#   'think',
#   'covid',
#   'should',
#   'be',
#   'mandatory',
#   'vaccination'],
#  ['which',
#   'variants',
#   'were',
#   'involved',
#   'what',
#   'was',
#   'vaccination',
#   'masking',
#   'ventilation',
#   'around',
#   'kids',
#   'at',
#   'time',
#   'it',
#   's',
#   'meaningless',
#   'say',
#   'kids',
#   'aren',
#   't',
#   'danger',
#   'unless',
#   'you',
#   'mean',
#   'say',
#   'kids',
#   'have',
#   'not',
#   'nor',
#   'will',
#   'not',
#   'ever',
#   'be',
#   'danger',
#   'no',
#   'matter',
#   'what'],
#  ['it',
#   'has',
#   'last',
#   'i',
#   'looked',
#   'we',
#   'hadn',
#   't',
#   'actually',
#   'hit',
#   'county',
#   'vaccination',
#   'threshold',
#   'because',
#   'difference',
#   'between',
#   'mdh',
#   'cdc',
#   'data',
#   'i',
#   'bet',
#   'most',
#   'secondary',
#   'schools',
#   'have',
#   'though'],
#  ['oh',
#   'i',
#   'see',
#   'so',
#   'what',
#   'your',
#   'saying',
#   'is',
#   'that',
#   'alberta',
#   'businesses',
#   'that',
#   'are',
#   'required',
#   'ask',
#   'proof',
#   'vaccination',
#   'can',
#   't',
#   'rely',
#   'alberta',
#   'government',
#   'they',
#   'have',
#   'rely',
#   'other',
#   'provinces'],
#  ['this',
#   'vision',
#   'public',
#   'health',
#   'decisions',
#   'tied',
#   'local',
#   'conditions',
#   'spread',
#   'vaccination',
#   'amp',
#   'vulnerability',
#   'also',
#   'sounds',
#   'reasonable',
#   'me',
#   'however',
#   'two',
#   'years',
#   'into',
#   'this',
#   'acting',
#   'as',
#   'if',
#   'that',
#   's',
#   'what',
#   'is',
#   'happening',
#   'is',
#   'naive',
#   'at',
#   'best',
#   'partisan',
#   'politics',
#   'even',
#   'at',
#   'local',
#   'level',
#   'often',
#   'is',
#   'big',
#   'factor'],
#  ['oh',
#   'you',
#   'mean',
#   'someone',
#   'told',
#   'you',
#   'they',
#   'd',
#   'kill',
#   'you',
#   'if',
#   'you',
#   'didn',
#   't',
#   'get',
#   'vaccinated',
#   'don',
#   't',
#   'understand',
#   'i',
#   'thought',
#   'you',
#   'said',
#   'no',
#   'vaccination',
#   'how',
#   'did',
#   'you',
#   'lose',
#   'your',
#   'bodily',
#   'autonomy',
#   'then'],
#  ['their',
#   'concerns',
#   'are',
#   'real',
#   'even',
#   'if',
#   'unfounded',
#   'addressing',
#   'them',
#   'with',
#   'empathy',
#   'genuine',
#   'good',
#   'will',
#   'is',
#   'how',
#   'you',
#   'persuade',
#   'them',
#   'canada',
#   'has',
#   'similar',
#   'levels',
#   'adult',
#   'vaccination',
#   'usa'],
#  ['it',
#   'seems',
#   'like',
#   'steel',
#   'man',
#   'here',
#   'is',
#   'about',
#   'many',
#   'mandates',
#   'masks',
#   'vaccination',
#   'testing',
#   'etc',
#   'that',
#   'are',
#   'very',
#   'much',
#   'still',
#   'place',
#   'are',
#   'relatively',
#   'low',
#   'cost',
#   'but',
#   'not',
#   'zero',
#   'cost'],
#  ['i', 'd', 'kill', 'be', 'sally', 'field', 'here'],
#  ['jesus',
#   'christ',
#   'it',
#   's',
#   'vaccination',
#   'not',
#   'being',
#   'forced',
#   'carry',
#   'pregnancy',
#   'term'],
#  ['amazon',
#   'allow',
#   'work',
#   'without',
#   'face',
#   'masks',
#   'require',
#   'vaccination',
#   'paid',
#   'covid',
#   'leave'],
#  ['five',
#   'if',
#   'governments',
#   'primary',
#   'concern',
#   'amd',
#   'justification',
#   'compulsory',
#   'covid',
#   'vaccination',
#   'is',
#   'prevent',
#   'hospitals',
#   'icu',
#   'emergency',
#   'depts',
#   'being',
#   'inundated',
#   'thus',
#   'running',
#   'out',
#   'medical',
#   'resources',
#   'bed',
#   'space',
#   'equipment',
#   'or',
#   'staff',
#   'perhaps',
#   'govt',
#   'should',
#   'require',
#   'all',
#   'hospitals'],
#  ['two',
#   'when',
#   'covid',
#   'vaccines',
#   'have',
#   'proven',
#   'not',
#   'prevent',
#   'spread',
#   'covid',
#   'even',
#   'before',
#   'but',
#   'esp',
#   'with',
#   'omicron',
#   'where',
#   'so',
#   'called',
#   'breakthrough',
#   'cases',
#   'became',
#   'just',
#   'positive',
#   'covid',
#   'cases',
#   'bc',
#   'omicron',
#   'didn',
#   't',
#   'care',
#   'abt',
#   'vaccine',
#   'status',
#   'real',
#   'driving',
#   'force',
#   'vaccination',
#   'has',
#   'become',
#   'minimizing'],
#  ['vaccination', 'syringe', 'new', 'video', 'via'],
#  ['i',
#   'think',
#   'they',
#   'are',
#   'now',
#   'at',
#   'eighty',
#   'most',
#   'games',
#   'are',
#   'never',
#   'that',
#   'full',
#   'anyway',
#   'you',
#   'are',
#   'meant',
#   'download',
#   'app',
#   'get',
#   'green',
#   'light',
#   'which',
#   'is',
#   'based',
#   'vaccination',
#   'status',
#   'that',
#   'is',
#   'allow',
#   'you',
#   'enter',
#   'stadium',
#   'i',
#   'am',
#   'not',
#   'ground',
#   'there',
#   'so',
#   'unsure',
#   'if',
#   'they',
#   'enforce',
#   'that',
#   'much'],
#  ['i',
#   'see',
#   'so',
#   'how',
#   'do',
#   'alberta',
#   'businesses',
#   'that',
#   'are',
#   'legally',
#   'still',
#   'requires',
#   'obtain',
#   'proof',
#   'vaccination',
#   'do',
#   'so',
#   'yes',
#   'there',
#   'are',
#   'those',
#   'still',
#   'legally',
#   'required'],
#  ['about',
#   'medical',
#   'specialists',
#   'were',
#   'involved',
#   'in',
#   'the',
#   'vaccination',
#   'effort'],
#  ['reaction',
#   'vaccine',
#   'according',
#   'cdc',
#   'anaphylaxis',
#   'after',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'is',
#   'extremely',
#   'rare',
#   'has',
#   'occurred',
#   'about',
#   'five',
#   'people',
#   'per',
#   'one',
#   'million',
#   'vaccinated',
#   'united',
#   'states',
#   'or',
#   'five',
#   'vaccinations'],
#  ['chickahominy',
#   'health',
#   'district',
#   'is',
#   'holding',
#   'vaccination',
#   'clinic',
#   'february',
#   'three',
#   'six',
#   'pm',
#   'at',
#   'j',
#   'sargent',
#   'reynolds',
#   'community',
#   'college',
#   'please',
#   'use',
#   'this',
#   'link',
#   'register',
#   'but',
#   'walk',
#   'ins',
#   'will',
#   'be',
#   'accepted'],
#  ['it',
#   's',
#   'too',
#   'bad',
#   'that',
#   'it',
#   's',
#   'a',
#   'right',
#   'their',
#   'body',
#   'belongs',
#   'to',
#   'them',
#   'but',
#   'not',
#   'what',
#   'it',
#   'wears',
#   'you',
#   'better',
#   'fight',
#   'to',
#   'fight',
#   'the',
#   'compulsory',
#   'vaccination',
#   'required',
#   'by',
#   'businesses',
#   'employers',
#   'and',
#   'this',
#   'government'],
#  ['do',
#   'you',
#   'have',
#   'nothing',
#   'more',
#   'report',
#   'about',
#   'other',
#   'than',
#   'documents',
#   'trump',
#   'took',
#   'gave',
#   'back',
#   'or',
#   'bullshit',
#   'that',
#   'happened',
#   'january',
#   'six',
#   'how',
#   'about',
#   'let',
#   's',
#   'close',
#   'our',
#   'borders',
#   'let',
#   's',
#   'end',
#   'mask',
#   'vaccination',
#   'mandates',
#   'seriously',
#   'people'],
#  ['conclusion',
#   'you',
#   'most',
#   'definitely',
#   'cannot',
#   'draw',
#   'that',
#   'is',
#   'that',
#   'mask',
#   'mandates',
#   'don',
#   't',
#   'work',
#   'since',
#   'death',
#   'rates',
#   'are',
#   'much',
#   'lower',
#   'those',
#   'states',
#   'again',
#   'this',
#   'is',
#   'probably',
#   'primarily',
#   'due',
#   'higher',
#   'vaccination',
#   'rates'],
#  ['i',
#   'never',
#   'suggested',
#   'vaccination',
#   'was',
#   'issue',
#   'one',
#   'way',
#   'or',
#   'other'],
#  ['why',
#   'hasn',
#   't',
#   'trump',
#   'been',
#   'arrested',
#   'yet',
#   'we',
#   'look',
#   'like',
#   'laughingstocks',
#   'rest',
#   'world',
#   'still',
#   'also',
#   'i',
#   'am',
#   'terrified',
#   'truckers',
#   'they',
#   'are',
#   'not',
#   'just',
#   'coming',
#   'because',
#   'vaccination',
#   'mandates',
#   'they',
#   'are',
#   'coming',
#   'because',
#   'big',
#   'lie',
#   'perceived',
#   'reinstatement',
#   'tfg'],
#  ['he',
#   'was',
#   'covid',
#   'positive',
#   'when',
#   'he',
#   'died',
#   'i',
#   'm',
#   'amazed',
#   'that',
#   'they',
#   'haven',
#   't',
#   'spun',
#   'this',
#   'into',
#   'covid',
#   'death',
#   'push',
#   'their',
#   'vaccination',
#   'agenda'],
#  ['if',
#   'it',
#   's',
#   'not',
#   'crossed',
#   'with',
#   'the',
#   'data',
#   'on',
#   'vaccination'],
#  ['so',
#   'my',
#   'school',
#   'is',
#   'not',
#   'gonna',
#   'ask',
#   'vaccination',
#   'proof',
#   'because',
#   'they',
#   'respect',
#   'individuality',
#   'health',
#   'decisions',
#   'everyone',
#   'but',
#   'i',
#   'have',
#   'no',
#   'choice',
#   'stay',
#   'virtually',
#   'lol',
#   'hate',
#   'it',
#   'here'],
#  ['as',
#   'i',
#   'linked',
#   'above',
#   'republican',
#   'controlled',
#   'states',
#   'which',
#   'tend',
#   'be',
#   'states',
#   'without',
#   'mask',
#   'mandates',
#   'are',
#   'doing',
#   'far',
#   'worse',
#   'than',
#   'democratic',
#   'controlled',
#   'states',
#   'course',
#   'they',
#   'also',
#   'are',
#   'states',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'so',
#   'it',
#   's',
#   'hard',
#   'draw',
#   'strong',
#   'conclusion',
#   'that'],
#  ['why',
#   'has',
#   'our',
#   'close',
#   'neighbor',
#   'png',
#   'got',
#   'one',
#   'lowest',
#   'covid',
#   'vaccination',
#   'rates',
#   'world'],
#  ['our',
#   'vaccination',
#   'campaign',
#   'has',
#   'gone',
#   'from',
#   'exemplary',
#   'to',
#   'a',
#   'miserable',
#   'failure'],
#  ['advocacy',
#   'update',
#   'physician',
#   'groups',
#   'urge',
#   'supreme',
#   'court',
#   'uphold',
#   'vaccination',
#   'requirement',
#   'highlights',
#   'parity',
#   'enforcement',
#   'regulatory',
#   'agenda',
#   'more',
#   'mentalhealth',
#   'psychtwitter'],
#  ['me',
#   'putting',
#   'together',
#   'my',
#   'spreadsheet',
#   'what',
#   'oscar',
#   'nominees',
#   'celebrities',
#   'attended',
#   'vaccination',
#   'required',
#   'events',
#   'and',
#   'or',
#   'publicly',
#   'spoken',
#   'out',
#   'about',
#   'vaccine'],
#  ['that',
#   'was',
#   'indian',
#   'health',
#   'department',
#   'sorry',
#   'you',
#   'don',
#   't',
#   'trust',
#   'people',
#   'that',
#   'look',
#   'like',
#   'you',
#   'why',
#   'do',
#   'you',
#   'think',
#   'israel',
#   'with',
#   'ninety',
#   'vaccination',
#   'rate',
#   'has',
#   'such',
#   'hard',
#   'time',
#   'with',
#   'covid',
#   'right',
#   'now'],
#  ['amerks',
#   'will',
#   'no',
#   'longer',
#   'require',
#   'proof',
#   'vaccination',
#   'entry',
#   'amerks',
#   'games',
#   'or',
#   'any',
#   'events',
#   'at',
#   'blue',
#   'cross',
#   'arena',
#   'beginning',
#   'thursday',
#   'february'],
#  ['my',
#   'employer',
#   'has',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   'even',
#   'if',
#   'provincial',
#   'federal',
#   'governments',
#   'remove',
#   'mandates',
#   'my',
#   'employer',
#   'will',
#   'still',
#   'have',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   'what',
#   'then',
#   'cdnpoli',
#   'onpoli'],
#  ['demystify',
#   'vaccination',
#   'against',
#   'provided',
#   'you',
#   'master',
#   'your',
#   'subject',
#   'let',
#   'go'],
#  ['we', 'need', 'have', 'uniformed', 'rule', 'about', 'mask', 'vaccination'],
#  ['so',
#   'conservative',
#   'anti',
#   'abortion',
#   'anti',
#   'vaccination',
#   'people',
#   'thoughts',
#   'prayers',
#   'can',
#   't',
#   'forget',
#   'prayers'],
#  ['classic',
#   'simpson',
#   's',
#   'paradox',
#   'most',
#   'deaths',
#   'are',
#   'among',
#   'elderly',
#   'people',
#   'nearly',
#   'all',
#   'whom',
#   'are',
#   'vaccinated',
#   'with',
#   'lower',
#   'vaccination',
#   'rate',
#   'total',
#   'number',
#   'fatalities',
#   'would',
#   'be',
#   'much',
#   'higher'],
#  ['sounds',
#   'like',
#   'you',
#   're',
#   'planning',
#   'masking',
#   'kids',
#   'indefinitely',
#   'bps',
#   'what',
#   'hospitalization',
#   'rates',
#   'vaccination',
#   'rates',
#   'etc',
#   'are',
#   'you',
#   'deeming',
#   'necessary',
#   'finally',
#   'let',
#   'these',
#   'kids',
#   'finally',
#   'get',
#   'back',
#   'normalcy',
#   'we',
#   'need',
#   'numbers'],
#  ['cases',
#   'have',
#   'gone',
#   'up',
#   'state',
#   'it',
#   'has',
#   'highest',
#   'vaccination',
#   'rate',
#   'as',
#   'january',
#   'you',
#   'ate',
#   'bullshit',
#   'obvious',
#   'fake',
#   'news',
#   'site',
#   'with',
#   'spoon',
#   'this',
#   'is',
#   'why',
#   'i',
#   'am',
#   'insulting',
#   'your',
#   'intelligence'],
#  ['there',
#   's',
#   'lot',
#   'people',
#   'speaking',
#   'out',
#   'like',
#   'pro',
#   'choice',
#   'abortions',
#   'is',
#   'same',
#   'as',
#   'pro',
#   'choice',
#   'relating',
#   'vaccines',
#   'i',
#   'disagree',
#   'abortion',
#   'removes',
#   'choice',
#   'human',
#   'by',
#   'ending',
#   'human',
#   'life',
#   'forced',
#   'coerced',
#   'vaccination',
#   'removes',
#   'choice',
#   'by',
#   'forcing',
#   'human',
#   'risk',
#   'permanent',
#   'damage'],
#  ['not',
#   'delusional',
#   'at',
#   'all',
#   'it',
#   'is',
#   'over',
#   'endemic',
#   'we',
#   'are',
#   'going',
#   'live',
#   'with',
#   'this',
#   'not',
#   'up',
#   'us',
#   'vaccination',
#   'lockdowns',
#   'masks',
#   'covid',
#   'is',
#   'still',
#   'here',
#   'live',
#   'fear',
#   'or',
#   'get',
#   'with',
#   'it',
#   'taking',
#   'precaution',
#   'as',
#   'necessary',
#   'based',
#   'age',
#   'other',
#   'health',
#   'conditions'],
#  ['tell',
#   'that',
#   'unvaccinated',
#   'people',
#   'who',
#   've',
#   'died',
#   'covid',
#   'unfortunately',
#   'that',
#   's',
#   'not',
#   'true',
#   'vaccination',
#   'does',
#   'indeed',
#   'prevent',
#   'some',
#   'most',
#   'dire',
#   'results',
#   'covid',
#   'infection',
#   'that',
#   's',
#   'pretty',
#   'well',
#   'established'],
#  ['tool',
#   'surgeon',
#   'general',
#   'refuses',
#   'disklose',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status'],
#  ['quebec',
#   'is',
#   'asking',
#   'all',
#   'vaccinating',
#   'physicians',
#   'to',
#   'return',
#   'to',
#   'their',
#   'regular',
#   'activities',
#   'due',
#   'to',
#   'the',
#   'sharp',
#   'drop',
#   'in',
#   'attendance',
#   'at',
#   'vaccination',
#   'clinics',
#   'radio',
#   'canada',
#   'reported',
#   'this',
#   'morning',
#   'that',
#   'vaccinators',
#   'are',
#   'twiddling',
#   'their',
#   'thumbs',
#   'polqc'],
#  ['thank',
#   'you',
#   'keeping',
#   'mask',
#   'mandate',
#   'schools',
#   'need',
#   'get',
#   'our',
#   'vaccination',
#   'rates',
#   'up',
#   'do',
#   'more',
#   'education',
#   'outreach',
#   'get',
#   'our',
#   'students',
#   'siblings',
#   'under',
#   'five',
#   'vaccinated',
#   'before',
#   'lifting',
#   'mask',
#   'mandates'],
#  ['according',
#   'to',
#   'vaccination',
#   'and',
#   'abortion',
#   'are',
#   'the',
#   'same',
#   'thing',
#   'welcome',
#   'to'],
#  ['care',
#   'explain',
#   'how',
#   'mental',
#   'health',
#   'has',
#   'anything',
#   'do',
#   'with',
#   'vaccine',
#   'i',
#   'm',
#   'not',
#   'talking',
#   'about',
#   'how',
#   'person',
#   'may',
#   'feel',
#   'about',
#   'it',
#   'one',
#   'way',
#   'or',
#   'other',
#   'i',
#   'm',
#   'talking',
#   'about',
#   'genuine',
#   'mental',
#   'health',
#   'issue',
#   'due',
#   'vaccination',
#   'it',
#   'does',
#   'not',
#   'exist'],
#  ['find',
#   'fixed',
#   'vaccination',
#   'site',
#   'your',
#   'area',
#   'getvaccinated',
#   'today',
#   'visit',
#   'or',
#   'call',
#   'one',
#   'love'],
#  ['three',
#   'eric',
#   'adams',
#   'has',
#   'also',
#   'repeatedly',
#   'renewed',
#   'key',
#   'nyc',
#   'executive',
#   'order',
#   'which',
#   'requires',
#   'anyone',
#   'over',
#   'age',
#   'five',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'participate',
#   'indoor',
#   'activities',
#   'anyone',
#   'eighteen',
#   'older',
#   'proof',
#   'id',
#   'along',
#   'with',
#   'proof',
#   'vaccination',
#   'is',
#   'required'],
#  ['it',
#   'makes',
#   'me',
#   'sad',
#   'but',
#   'also',
#   'angry',
#   'at',
#   'all',
#   'those',
#   'who',
#   'have',
#   'diskouraged',
#   'vaccination'],
#  ['about',
#   'time',
#   'well',
#   'done',
#   'everyone',
#   'who',
#   'faught',
#   'this',
#   'i',
#   'm',
#   'proud',
#   'us',
#   'all',
#   'revoking',
#   'vaccination',
#   'as',
#   'condition',
#   'deployment',
#   'across',
#   'all',
#   'health',
#   'social',
#   'care'],
#  ['oscars',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'will',
#   'not',
#   'be',
#   'required',
#   'in',
#   'person',
#   'attendees',
#   'exclusive',
#   'via'],
#  ['two',
#   'proof',
#   'vaccination',
#   'is',
#   'still',
#   'required',
#   'indoor',
#   'dining',
#   'events',
#   'at',
#   'arenas',
#   'gyms',
#   'theaters',
#   'museums',
#   'any',
#   'other',
#   'indoor',
#   'entertainment',
#   'new',
#   'york',
#   'city',
#   'as',
#   'part',
#   'initiative',
#   'started',
#   'by',
#   'former',
#   'mayor'],
#  ['what',
#   'makes',
#   'americans',
#   'think',
#   'they',
#   'have',
#   'right',
#   'challenge',
#   'sovereign',
#   'nation',
#   's',
#   'rules',
#   'regarding',
#   'vaccination',
#   'testing',
#   'this',
#   'is',
#   'problem',
#   'our',
#   'creation',
#   'putting',
#   'self',
#   'above',
#   'needs',
#   'country',
#   'vaccineswork',
#   'canada'],
#  ['following',
#   'end',
#   'nevada',
#   's',
#   'mask',
#   'mandate',
#   'this',
#   'morning',
#   'has',
#   'followed',
#   'suit',
#   'nshe',
#   'employees',
#   'students',
#   'members',
#   'public',
#   'are',
#   'no',
#   'longer',
#   'required',
#   'wear',
#   'face',
#   'coverings',
#   'while',
#   'inside',
#   'nshe',
#   'buildings',
#   'irrespective',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'immediately'],
#  ['what',
#   'is',
#   'at',
#   'stake',
#   'applicants',
#   'here',
#   'is',
#   'not',
#   'forcible',
#   'vaccination',
#   'but',
#   'rather',
#   'consequences',
#   'one',
#   's',
#   'choice',
#   'remain',
#   'unvaccinated'],
#  ['trading',
#   'all',
#   'players',
#   'that',
#   'are',
#   'injured',
#   'just',
#   'claim',
#   'no',
#   'injuries',
#   'report',
#   'is',
#   'like',
#   'firing',
#   'all',
#   'non',
#   'vaccinated',
#   'claiming',
#   'you',
#   'have',
#   'vaccination',
#   'rate'],
#  ['you',
#   'really',
#   'don',
#   't',
#   'get',
#   'it',
#   'do',
#   'you',
#   'vaccination',
#   'lessons',
#   'syptoms',
#   'both',
#   'immediate',
#   'long',
#   'term',
#   'you',
#   'can',
#   'still',
#   'get',
#   'it',
#   'but',
#   'unlikely',
#   'it',
#   'will',
#   'be',
#   'serious',
#   'cause',
#   'long',
#   'term',
#   'damage',
#   'ffs',
#   'keep',
#   'up'],
#  ['any',
#   'member',
#   'public',
#   'or',
#   'health',
#   'professional',
#   'can',
#   'submit',
#   'suspected',
#   'side',
#   'effects',
#   'through',
#   'yellow',
#   'card',
#   'scheme',
#   'nature',
#   'yellow',
#   'card',
#   'reporting',
#   'means',
#   'that',
#   'reported',
#   'events',
#   'are',
#   'not',
#   'always',
#   'proven',
#   'side',
#   'effects',
#   'some',
#   'events',
#   'may',
#   'have',
#   'happened',
#   'anyway',
#   'regardless',
#   'vaccination'],
#  ['so',
#   'strange',
#   'that',
#   'people',
#   'who',
#   'are',
#   'claiming',
#   'that',
#   'they',
#   'want',
#   'us',
#   'all',
#   'stop',
#   'living',
#   'fear',
#   'are',
#   'causing',
#   'lot',
#   'more',
#   'fear',
#   'than',
#   'mask',
#   'or',
#   'vaccination',
#   'ever',
#   'caused',
#   'us',
#   'we',
#   'are',
#   'being',
#   'held',
#   'hostage'],
#  ['kicking',
#   'off',
#   'night',
#   'one',
#   'superbowlmusicfest',
#   'with',
#   'w',
#   'special',
#   'guests',
#   'doors',
#   'limited',
#   'number',
#   'tickets',
#   'remain',
#   'at',
#   'guests',
#   'two',
#   'amp',
#   'older',
#   'must',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'or',
#   'neg',
#   'test',
#   'amp',
#   'id',
#   'info'],
#  ['with',
#   'vaccination',
#   'rates',
#   'quite',
#   'low',
#   'lt',
#   'twelve',
#   'age',
#   'range',
#   'more',
#   'thought',
#   'needed',
#   'as',
#   'benefits',
#   'risks',
#   'unmasked',
#   'indoor',
#   'instruction',
#   'glad',
#   'that',
#   'allows',
#   'unmasked',
#   'outdoor',
#   'activities',
#   'that',
#   'our',
#   'fab',
#   'socal',
#   'weather',
#   'makes',
#   'it',
#   'easy',
#   'get',
#   'fresh',
#   'air'],
#  ['i',
#   'truly',
#   'feel',
#   'that',
#   'he',
#   's',
#   'mentally',
#   'unstable',
#   'over',
#   'his',
#   'head',
#   'this',
#   'is',
#   'very',
#   'concerning',
#   'same',
#   'answer',
#   'time',
#   'after',
#   'time',
#   'ninety',
#   'vaccination'],
#  ['i',
#   'tend',
#   'let',
#   'it',
#   'slide',
#   'until',
#   'i',
#   'injure',
#   'myself',
#   'i',
#   'm',
#   'klutz',
#   'or',
#   'doc',
#   'notices',
#   'it',
#   's',
#   'been',
#   'awhile',
#   'since',
#   'they',
#   'quit',
#   'using',
#   'horse',
#   'serum',
#   'i',
#   'm',
#   'good',
#   'about',
#   'that',
#   'vaccination'],
#  ['since',
#   'mid',
#   'september',
#   'has',
#   'required',
#   'everyone',
#   'two',
#   'years',
#   'age',
#   'older',
#   'wear',
#   'mask',
#   'indoors',
#   'regardless',
#   'their',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'beginning',
#   'feb',
#   'day',
#   'after',
#   'presidents',
#   'day',
#   'that',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'case'],
#  ['it',
#   'is',
#   'justified',
#   'be',
#   'frustrated',
#   'with',
#   'people',
#   'who',
#   'won',
#   't',
#   'get',
#   'vaccine',
#   'there',
#   'are',
#   'jobs',
#   'where',
#   'it',
#   'is',
#   'fair',
#   'require',
#   'vaccination',
#   'remain',
#   'employed',
#   'but',
#   'are',
#   'we',
#   'really',
#   'going',
#   'try',
#   'starve',
#   'them',
#   'out'],
#  ['biden',
#   'administration',
#   'adopted',
#   'our',
#   'recommendation',
#   'make',
#   'health',
#   'care',
#   'worker',
#   'vaccination',
#   'condition',
#   'medicare',
#   'medicaid',
#   'funds',
#   'scotus',
#   'upheld',
#   'this',
#   'rule',
#   'which',
#   'is',
#   'so',
#   'important',
#   'patient',
#   'safety'],
#  ['required',
#   'preregistration',
#   'now',
#   'is',
#   'open',
#   'meadville',
#   'medical',
#   'center',
#   's',
#   'next',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'set',
#   'feb',
#   'eighteen',
#   'ten',
#   'a',
#   'm',
#   'one',
#   'p',
#   'm',
#   'at',
#   'water',
#   'st',
#   'clinic',
#   'is',
#   'pfizer',
#   'vaccine',
#   'only'],
#  ['yes',
#   'prevention',
#   'long',
#   'term',
#   'involves',
#   'vaccination',
#   'masks',
#   'reduce',
#   'speaks',
#   'either',
#   'vaccination',
#   'or',
#   'masks',
#   'let',
#   's',
#   'get',
#   'real',
#   'we',
#   're',
#   'not',
#   'going',
#   'beat',
#   'this',
#   'covid',
#   'is',
#   'new',
#   'flu',
#   'we',
#   're',
#   'two',
#   'flu',
#   'shots',
#   'year',
#   'going',
#   'forward',
#   'difference',
#   'is',
#   'this',
#   'virus',
#   'has',
#   'higher',
#   'kill',
#   'rate'],
#  ['that',
#   'seems',
#   'way',
#   'more',
#   'reasonable',
#   'will',
#   'yield',
#   'far',
#   'more',
#   'positive',
#   'results',
#   'than',
#   'just',
#   'rescinding',
#   'vaccination',
#   'mandates',
#   'letting',
#   'people',
#   'make',
#   'their',
#   'own',
#   'decisions'],
#  ['come',
#   'one',
#   'come',
#   'allstar',
#   'valencia',
#   'st',
#   'los',
#   'angeles',
#   'free',
#   'produce',
#   'testing',
#   'vaccination',
#   'all'],
#  ['this',
#   'is',
#   'absurd',
#   'please',
#   'take',
#   'look',
#   'mirror',
#   'man',
#   'your',
#   'fellow',
#   'conservatives',
#   'have',
#   'been',
#   'expressly',
#   'supporting',
#   'blockade',
#   'pm',
#   'is',
#   'not',
#   'main',
#   'culprit',
#   'inflamed',
#   'rhetoric',
#   'by',
#   'calling',
#   'vaccination',
#   'respect',
#   'public',
#   'health',
#   'orders'],
#  ['all',
#   'fans',
#   'who',
#   'receive',
#   'their',
#   'or',
#   'booster',
#   'dose',
#   'covid',
#   'vaccine',
#   'at',
#   'super',
#   'bowl',
#   'experience',
#   'can',
#   'receive',
#   'free',
#   'tickets',
#   'enter',
#   'experience',
#   'that',
#   'day',
#   'or',
#   'future',
#   'date',
#   'be',
#   'sure',
#   'visit',
#   'our',
#   'vaccination',
#   'site',
#   'south',
#   'hall',
#   'see',
#   'you',
#   'there',
#   'superbowlexperience',
#   'sblvi'],
#  ['i',
#   'got',
#   'that',
#   'unease',
#   'my',
#   'part',
#   'can',
#   'pass',
#   'adults',
#   'make',
#   'their',
#   'own',
#   'choices',
#   'suffer',
#   'their',
#   'own',
#   'consequences',
#   'how',
#   'are',
#   'we',
#   'deal',
#   'with',
#   'as',
#   'yet',
#   'low',
#   'vaccination',
#   'rates',
#   'five',
#   'eleven',
#   'at',
#   'least',
#   'twelve',
#   'seventeen',
#   'is',
#   'over',
#   'fifty'],
#  ['my',
#   'physical',
#   'vaccination',
#   'card',
#   'is',
#   'gross',
#   'but',
#   'now',
#   'it',
#   'is',
#   'digital',
#   'thanks'],
#  ['allied',
#   'universal',
#   'is',
#   'looking',
#   'hire',
#   'phenomenal',
#   'security',
#   'site',
#   'supervisor',
#   'unarmed',
#   'vaccination',
#   'required',
#   'las',
#   'vegas',
#   'nv',
#   'join',
#   'our',
#   'diverse',
#   'team',
#   'hiringphenomenaltalent',
#   'security'],
#  ['especially',
#   'if',
#   'vehicle',
#   'is',
#   'towed',
#   'u',
#   's',
#   'they',
#   'are',
#   'not',
#   'allowed',
#   'cross',
#   'border',
#   'get',
#   'it',
#   'because',
#   'wait',
#   'it',
#   'u',
#   's',
#   'requires',
#   'proof',
#   'vaccination',
#   'cross',
#   'into',
#   'u',
#   's'],
#  ['links',
#   'papers',
#   'within',
#   'article',
#   'new',
#   'paper',
#   'emphasizes',
#   'dangers',
#   'amp',
#   'harms',
#   'mandatory',
#   'covid',
#   'vaccination',
#   'policy'],
#  ['same', 'for', 'forced', 'vaccination'],
#  ['this',
#   'is',
#   'myocarditis',
#   'foundation',
#   'website',
#   'known',
#   'potential',
#   'benefits',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'outweigh',
#   'known',
#   'potential',
#   'risks',
#   'including',
#   'possible',
#   'risks',
#   'myocarditis',
#   'or',
#   'pericarditis'],
#  ['politicians',
#   'across',
#   'country',
#   'continue',
#   'infringe',
#   'personal',
#   'liberties',
#   'under',
#   'guise',
#   'public',
#   'safety',
#   'today',
#   'we',
#   'filed',
#   'lawsuit',
#   'against',
#   'city',
#   'chicago',
#   'cook',
#   'county',
#   'end',
#   'illegal',
#   'diskriminatory',
#   'proof',
#   'vaccination',
#   'requirements'],
#  ['governors',
#   'control',
#   'lockdowns',
#   'they',
#   'started',
#   'long',
#   'before',
#   'biden',
#   'biden',
#   'opened',
#   'things',
#   'up',
#   'with',
#   'his',
#   'vaccination',
#   'program',
#   'not',
#   'sure',
#   'you',
#   'are',
#   'tracking',
#   'right',
#   'trump',
#   'spent',
#   'far',
#   'more',
#   'than',
#   'biden',
#   'it',
#   's',
#   'was',
#   'his',
#   'fed',
#   'that',
#   'failed',
#   'increase',
#   'rates',
#   'during',
#   'his',
#   'presidency'],
#  ['you', 'are', 'talking', 'about', 'the', 'covid', 'vaccination'],
#  ['any',
#   'regulation',
#   'size',
#   'rim',
#   'three',
#   'point',
#   'line',
#   'vaccination',
#   'mandate'],
#  ['as',
#   'monday',
#   'proof',
#   'vaccination',
#   'or',
#   'negative',
#   'covid',
#   'nineteen',
#   'test',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'required',
#   'staff',
#   'visitors',
#   'at',
#   'saskatoon',
#   'public',
#   'schools',
#   'sps'],
#  ['amoa',
#   'resort',
#   'has',
#   'activated',
#   'its',
#   'covid',
#   'nineteen',
#   'protocols',
#   'will',
#   'welcome',
#   'guests',
#   'as',
#   'it',
#   'strictly',
#   'observes',
#   'social',
#   'distancing',
#   'face',
#   'masks',
#   'wearing',
#   'enforce',
#   'vaccination',
#   'cards',
#   'only',
#   'entry'],
#  ['centenary',
#   'hospital',
#   'scarborough',
#   'dose',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'is',
#   'two',
#   'ten',
#   'book',
#   'at',
#   'see',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'or',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'is',
#   'two',
#   'ten',
#   'book',
#   'at',
#   'see',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'or',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'is',
#   'two',
#   'ten',
#   'book',
#   'at',
#   'see',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['as',
#   'health',
#   'emergency',
#   'law',
#   'force',
#   'now',
#   'that',
#   'gives',
#   'quebec',
#   'sweeping',
#   'powers',
#   'legault',
#   'said',
#   'it',
#   'will',
#   'be',
#   'dropped',
#   'after',
#   'national',
#   'assembly',
#   'adopts',
#   'new',
#   'legislation',
#   'specifying',
#   'which',
#   'measures',
#   'are',
#   'be',
#   'maintained',
#   'such',
#   'as',
#   'vaccination',
#   'passport',
#   'legaultmustresign',
#   'legault'],
#  ['ability',
#   'be',
#   'always',
#   'free',
#   'restrictions',
#   'after',
#   'vaccination',
#   'that',
#   'was',
#   'supposed',
#   'be',
#   'point',
#   'mandates',
#   'that',
#   'trust',
#   'was',
#   'broken',
#   'when',
#   'we',
#   'closed',
#   'businesses',
#   'again',
#   'jan',
#   'you',
#   'may',
#   'be',
#   'able',
#   'go',
#   'restaurants',
#   'now',
#   'but',
#   'there',
#   'is',
#   'no',
#   'guarantee',
#   'you',
#   'will',
#   'do',
#   'so',
#   'april'],
#  ['genuinely',
#   'curious',
#   'can',
#   'you',
#   'find',
#   'me',
#   'clip',
#   'or',
#   'quote',
#   'trump',
#   'telling',
#   'his',
#   'base',
#   'or',
#   'anyone',
#   'at',
#   'all',
#   'anything',
#   'remotely',
#   'anti',
#   'vaccine',
#   'everything',
#   'he',
#   's',
#   'said',
#   'what',
#   'i',
#   've',
#   'seen',
#   'has',
#   'been',
#   'extremely',
#   'pro',
#   'vaccination',
#   'but',
#   'maybe',
#   'you',
#   'have',
#   'other',
#   'sources',
#   'you',
#   'could',
#   'cite'],
#  ['swastikas',
#   'displayed',
#   'at',
#   'canadian',
#   'freedom',
#   'convoy',
#   'protests',
#   'against',
#   'vaccination',
#   'mandates'],
#  ['that',
#   's',
#   'treatment',
#   'not',
#   'vaccine',
#   'it',
#   's',
#   'obviously',
#   'not',
#   'natural',
#   'immunity',
#   'by',
#   'any',
#   'definition',
#   'you',
#   'do',
#   'know',
#   'what',
#   'your',
#   'original',
#   'response',
#   'said',
#   'right',
#   'you',
#   'do',
#   'know',
#   'vaccination',
#   'occurs',
#   'prior',
#   'illness',
#   'not',
#   'during',
#   'illness',
#   'right'],
#  ['covid',
#   'vaccination',
#   'does',
#   'not',
#   'prevent',
#   'spread',
#   'stop',
#   'with',
#   'disinformation'],
#  ['absolutely',
#   'since',
#   'i',
#   'live',
#   'ohio',
#   'county',
#   'with',
#   'one',
#   'lowest',
#   'vaccination',
#   'rates'],
#  ['hrig',
#   'is',
#   'very',
#   'thick',
#   'yogurt',
#   'like',
#   'substance',
#   'so',
#   'you',
#   'will',
#   'feel',
#   'that',
#   'vaccination',
#   'can',
#   'clearly',
#   'tell',
#   'it',
#   'apart',
#   'normal',
#   'rabies',
#   'jab',
#   'when',
#   'i',
#   'got',
#   'bitten',
#   'they',
#   'forgot',
#   'administer',
#   'that',
#   'but',
#   'it',
#   's',
#   'must',
#   'really',
#   'rabies',
#   'vaccine',
#   'be',
#   'effective',
#   'post',
#   'trauma'],
#  ['meanwhile',
#   'at',
#   'has',
#   'more',
#   'death',
#   'threats',
#   'against',
#   'superintendent',
#   'upheaval',
#   'littleton',
#   'public',
#   'schools',
#   'over',
#   'vaccination',
#   'localnews'],
#  ['when',
#   'proof',
#   'vaccination',
#   'gets',
#   'lifted',
#   'our',
#   'elderly',
#   'will',
#   'then',
#   'be',
#   'forced',
#   'isolate',
#   'protect',
#   'themselves'],
#  ['appeals',
#   'court',
#   'will',
#   'not',
#   'block',
#   'order',
#   'barring',
#   'biden',
#   'federal',
#   'staff',
#   'vaccination',
#   'mandate',
#   'newsbreak'],
#  ['agreed',
#   'i',
#   'suspect',
#   'european',
#   'countries',
#   'have',
#   'higher',
#   'uptake',
#   'part',
#   'because',
#   'they',
#   'honored',
#   'recovery',
#   'previously',
#   'infected',
#   'individuals',
#   'adjusted',
#   'their',
#   'vaccination',
#   'recommendations',
#   'as',
#   'result'],
#  ['so',
#   'are',
#   'you',
#   'against',
#   'mandatory',
#   'mumps',
#   'measles',
#   'rubella',
#   'vaccination',
#   'or',
#   'is',
#   'it',
#   'just',
#   'fake',
#   'outrage',
#   'at',
#   'this',
#   'particular',
#   'vaccine'],
#  ['divorce',
#   'rates',
#   'rise',
#   'as',
#   'vaccination',
#   'adds',
#   'stress',
#   'co',
#   'parenting'],
#  ['vaccination', 'away', 'being', 'special'],
#  ['ugh',
#   'that',
#   'sucks',
#   'schools',
#   'marin',
#   'had',
#   'mass',
#   'vaccination',
#   'days',
#   'with',
#   'support',
#   'dogs',
#   'pretty',
#   'much',
#   'every',
#   'school',
#   'district',
#   'out',
#   'twenty',
#   'minutes'],
#  ['keep',
#   'eye',
#   'out',
#   'some',
#   'vaccination',
#   'clinics',
#   'that',
#   'are',
#   'opening',
#   'at',
#   'sign',
#   'up',
#   'at',
#   'gcms'],
#  ['be',
#   'fair',
#   'some',
#   'parents',
#   'we',
#   'haven',
#   't',
#   'set',
#   'up',
#   'much',
#   'mass',
#   'vaccination',
#   'infrastructure',
#   'we',
#   'did',
#   'grownups',
#   'when',
#   'i',
#   'got',
#   'vaxxed',
#   'it',
#   'was',
#   'easy',
#   'as',
#   'hell',
#   'barely',
#   'twenty',
#   'minutes',
#   'including',
#   'fifteen',
#   'min',
#   'observation',
#   'my',
#   'kids',
#   'second',
#   'dose',
#   'two',
#   'hours',
#   'waiting',
#   'damp',
#   'cold'],
#  ['i',
#   'would',
#   'pay',
#   'list',
#   'all',
#   'nominees',
#   'who',
#   'would',
#   've',
#   'been',
#   'blacklisted',
#   'oscars',
#   'if',
#   'academy',
#   'hadn',
#   't',
#   'blinked',
#   'vaccination',
#   'requirements',
#   'imagine',
#   'meltdown',
#   'twitter',
#   'would',
#   've',
#   'had',
#   'as',
#   'wags',
#   're',
#   'weighted',
#   'how',
#   'much',
#   'they',
#   'liked',
#   'movie',
#   'based',
#   'who',
#   'had',
#   'their',
#   'shots',
#   'my',
#   'god'],
#  ['im',
#   'saying',
#   'by',
#   'stopping',
#   'at',
#   'vaccination',
#   'ending',
#   'your',
#   'inquiry',
#   'there',
#   'it',
#   'is',
#   'arbitrary',
#   'european',
#   'union',
#   'allows',
#   'titers',
#   'negative',
#   'tests',
#   'their',
#   'pass',
#   'system'],
#  ['councilman',
#   'are',
#   'you',
#   'vaccinated',
#   'you',
#   'said',
#   'you',
#   'are',
#   'peoples',
#   'champ',
#   'but',
#   'why',
#   'are',
#   'dc',
#   'vaccination',
#   'rates',
#   'continuing',
#   'lag',
#   'your',
#   'district',
#   'you',
#   'can',
#   'be',
#   'leader',
#   'help',
#   'return',
#   'normal',
#   'especially',
#   'given',
#   'tweet',
#   'you',
#   'deleted',
#   'about',
#   'restaurants'],
#  ['having',
#   'government',
#   'offer',
#   'me',
#   'free',
#   'vaccine',
#   'that',
#   'helps',
#   'boost',
#   'my',
#   'immune',
#   'system',
#   'having',
#   'some',
#   'places',
#   'mostly',
#   'private',
#   'businesses',
#   'not',
#   'government',
#   'mandates',
#   'need',
#   'me',
#   'show',
#   'proof',
#   'vaccination',
#   'or',
#   'negative',
#   'test',
#   'doesn',
#   't',
#   'feel',
#   'like',
#   'oppression',
#   'me'],
#  ['saying',
#   'memory',
#   'cells',
#   'don',
#   't',
#   'remember',
#   'things',
#   'terms',
#   'things',
#   'like',
#   'spike',
#   'proteins',
#   'it',
#   'depends',
#   'disease',
#   'or',
#   'vaccination',
#   'example',
#   'hepatitis',
#   'b',
#   'vaccine',
#   'is',
#   'mainly',
#   'based',
#   'its',
#   'surface',
#   'protein'],
#  ['who',
#   'cares',
#   'what',
#   'these',
#   'people',
#   'say',
#   'i',
#   'personally',
#   'don',
#   't',
#   'fact',
#   'i',
#   'couldn',
#   't',
#   'possibly',
#   'care',
#   'less',
#   'why',
#   'should',
#   'anyone',
#   'care',
#   'they',
#   've',
#   'shown',
#   'us',
#   'all',
#   'exactly',
#   'who',
#   'they',
#   'are',
#   'amp',
#   'what',
#   'they',
#   'think',
#   'ppl',
#   'who',
#   'simply',
#   'don',
#   't',
#   'agree',
#   'w',
#   'them',
#   'forced',
#   'vaccination',
#   'i',
#   'don',
#   't',
#   'care'],
#  ['i',
#   'wish',
#   'everyone',
#   'was',
#   'vaccinated',
#   'but',
#   'mandatory',
#   'vaccination',
#   'for',
#   'is',
#   'a',
#   'measure',
#   'based',
#   'on',
#   'science',
#   'or'],
#  ['i',
#   'hope',
#   'ontario',
#   'drops',
#   'this',
#   'proof',
#   'vaccination',
#   'soon',
#   'cause',
#   'it',
#   'bring',
#   'way',
#   'too',
#   'much',
#   'unnecessary',
#   'conflicts',
#   'workers',
#   'especially',
#   'when',
#   'they',
#   'wanna',
#   'change',
#   'up',
#   'type',
#   'vacation',
#   'proof',
#   'dime'],
#  ['tyrannical',
#   'biden',
#   'administration',
#   'wants',
#   'mandatory',
#   'vaccination',
#   'protestors',
#   'canada',
#   'crushed',
#   'beneath',
#   'grinding',
#   'wheels',
#   'federal',
#   'authority'],
#  ['six',
#   'since',
#   'then',
#   'covid',
#   'hospitalizations',
#   'denmark',
#   'have',
#   'also',
#   'been',
#   'ticking',
#   'upwards',
#   'despite',
#   'highest',
#   'booster',
#   'vaccination',
#   'rate',
#   'by',
#   'far',
#   'europe',
#   'please',
#   'take',
#   'look',
#   'at',
#   'hospitalizations',
#   'chart',
#   'below',
#   'by',
#   'our',
#   'world',
#   'data'],
#  ['i',
#   'd',
#   'love',
#   'see',
#   'mental',
#   'gymnastics',
#   'you',
#   'have',
#   'perform',
#   'argue',
#   'protesting',
#   'vaccination',
#   'is',
#   'akin',
#   'protesting',
#   'police',
#   'brutality',
#   'against',
#   'minorities'],
#  ['i',
#   'see',
#   'you',
#   'put',
#   'defundcbc',
#   'defundbbc',
#   'unfortunately',
#   'very',
#   'ppl',
#   'behind',
#   'this',
#   'vaccination',
#   'extravaganza',
#   'are',
#   'same',
#   'ppl',
#   'funding',
#   'these',
#   'news',
#   'networks',
#   'just',
#   'sayin',
#   'i',
#   'm',
#   'totally',
#   'with',
#   'you',
#   'though',
#   'but',
#   'funds',
#   'are',
#   'coming',
#   'baddies'],
#  ['broadway',
#   's',
#   'mask',
#   'vaccination',
#   'requirement',
#   'remains',
#   'through',
#   'april',
#   'thirty'],
#  ['super',
#   'immunity',
#   'is',
#   'fake',
#   'you',
#   'can',
#   'get',
#   'covid',
#   'times',
#   'row',
#   'fact',
#   'my',
#   'therapist',
#   'had',
#   'covid',
#   'two',
#   'three',
#   'times',
#   'row',
#   'vaccination',
#   'has',
#   'less',
#   'health',
#   'risks',
#   'than',
#   'getting',
#   'covid',
#   'you',
#   'are',
#   'going',
#   'kill',
#   'people',
#   'due',
#   'attacking',
#   'proven',
#   'technology'],
#  ['jeffrey',
#   'morris',
#   'they',
#   'also',
#   'have',
#   'population',
#   'number',
#   'each',
#   'vaccinated',
#   'status',
#   'each',
#   'age',
#   'group',
#   'each',
#   'week',
#   'that',
#   'can',
#   'be',
#   'used',
#   'compute',
#   'standardized',
#   'death',
#   'rates',
#   'as',
#   'well',
#   'as',
#   'track',
#   'proportion',
#   'that',
#   'age',
#   'group',
#   'each',
#   'vaccination',
#   'status',
#   'over',
#   'time',
#   'age'],
#  ['school',
#   'age',
#   'vaccination',
#   'is',
#   'not',
#   'going',
#   'very',
#   'well',
#   'one',
#   'my',
#   'kids',
#   'schools',
#   'is',
#   'right',
#   'around',
#   'wtf',
#   'is',
#   'wrong',
#   'with',
#   'parents'],
#  ['yup',
#   'i',
#   'still',
#   'mask',
#   'up',
#   'social',
#   'distance',
#   'i',
#   'am',
#   'through',
#   'vaccination',
#   'booster',
#   'so',
#   'yeah',
#   'be',
#   'smart'],
#  ['besides',
#   'fact',
#   'that',
#   'even',
#   'if',
#   'there',
#   'was',
#   'no',
#   'mandate',
#   'canada',
#   'that',
#   'just',
#   'means',
#   'only',
#   'those',
#   'entering',
#   'other',
#   'countries',
#   'don',
#   't',
#   'needed',
#   'follow',
#   'show',
#   'proof',
#   'vaccination',
#   'negative',
#   'test',
#   'or',
#   'quarantine',
#   'what',
#   'is',
#   'point',
#   'when',
#   'you',
#   'can',
#   't',
#   'leave',
#   'country',
#   'without',
#   'that',
#   'proof'],
#  ['here',
#   'is',
#   'ice',
#   'hockey',
#   'harlem',
#   'supporting',
#   'end',
#   'nyc',
#   's',
#   'key',
#   'nyc',
#   'vaccination',
#   'program',
#   'when',
#   'i',
#   'am',
#   'elected',
#   'house',
#   'i',
#   'will',
#   'make',
#   'sure',
#   'you',
#   'become',
#   'famous',
#   'capitol',
#   'hill',
#   'because',
#   'your',
#   'voice',
#   'matter',
#   'godblessamerica',
#   'nonads'],
#  ['twelve',
#   'bay',
#   'area',
#   'counties',
#   'santa',
#   'clara',
#   'has',
#   'highest',
#   'vaccination',
#   'rate',
#   'their',
#   'case',
#   'rate',
#   'ranks',
#   'who',
#   'holds',
#   'santa',
#   'clara',
#   'leadership',
#   'accountable'],
#  ['mandates',
#   'help',
#   'increase',
#   'vaccination',
#   'rates',
#   'they',
#   'prevent',
#   'future',
#   'restrictions',
#   'i',
#   'appreciate',
#   'your',
#   'overall',
#   'tone',
#   'this',
#   'thread',
#   'but',
#   'i',
#   'disagree',
#   'here',
#   'mandates',
#   'should',
#   'not',
#   'be',
#   'done',
#   'attempt',
#   'coerce',
#   'while',
#   'producing',
#   'collateral',
#   'damage',
#   'elsewhere',
#   'accept',
#   'some',
#   'non',
#   'compliance'],
#  ['as',
#   'that',
#   'last',
#   'answer',
#   'apparently',
#   'not',
#   'haven',
#   't',
#   'you',
#   'been',
#   'keeping',
#   'up',
#   'mrna',
#   'vaccination',
#   'stimulates',
#   'robust',
#   'gcs',
#   'containing',
#   'vaccine',
#   'mrna',
#   'spike',
#   'antigen',
#   'up',
#   'eight',
#   'weeks',
#   'postvaccination',
#   'some',
#   'cases'],
#  ['meanwhile',
#   'government',
#   'is',
#   'using',
#   'kids',
#   'as',
#   'shields',
#   'with',
#   'unneccessary',
#   'vaccination',
#   'face',
#   'masks',
#   'schools'],
#  ['since',
#   'there',
#   'is',
#   'ninety',
#   'vaccination',
#   'rate',
#   'super',
#   'majority',
#   'people',
#   'are',
#   'supporting',
#   'federal',
#   'government',
#   'pandemic',
#   'plan',
#   'some',
#   'dummies',
#   'refer',
#   'conspiracy',
#   'theories',
#   'don',
#   't',
#   'get',
#   'vaccinated'],
#  ['paper',
#   'states',
#   'free',
#   'floating',
#   'spike',
#   'proteins',
#   'circulate',
#   'at',
#   'high',
#   'levels',
#   'blood',
#   'after',
#   'vaccination',
#   'vaccinated',
#   'people',
#   'infected',
#   'with',
#   'variants',
#   'covid',
#   'produce',
#   'antibodies',
#   'biased',
#   'toward',
#   'original',
#   'now',
#   'extinct',
#   'variant',
#   'rather',
#   'than',
#   'one',
#   'that',
#   'has',
#   'actually',
#   'infected',
#   'them'],
#  ['it',
#   'sounds',
#   'like',
#   'you',
#   'might',
#   'be',
#   'asking',
#   'immigration',
#   'related',
#   'question',
#   'which',
#   'we',
#   'aren',
#   't',
#   'qualified',
#   'answer',
#   'sorry',
#   'about',
#   'that',
#   'but',
#   'if',
#   'you',
#   're',
#   'asking',
#   'if',
#   'you',
#   'meet',
#   'our',
#   'health',
#   'safety',
#   'requirements',
#   'as',
#   'long',
#   'as',
#   'you',
#   'wear',
#   'mask',
#   'can',
#   'provide',
#   'vaccination',
#   'record',
#   'gov',
#   'id',
#   'yes',
#   'you',
#   'do'],
#  ['what',
#   'did',
#   'he',
#   'say',
#   'that',
#   'was',
#   'incorrect',
#   'terrorists',
#   'are',
#   'causing',
#   'more',
#   'issues',
#   'closures',
#   'supply',
#   'chain',
#   'issues',
#   'than',
#   'any',
#   'restrictions',
#   'did',
#   'vaccination',
#   'is',
#   'only',
#   'way',
#   'put',
#   'this',
#   'period'],
#  ['not',
#   'once',
#   'my',
#   'extended',
#   'pre',
#   'vaccine',
#   'isolation',
#   'did',
#   'i',
#   'think',
#   'you',
#   'know',
#   'what',
#   'i',
#   'need',
#   'fentanyl',
#   'death',
#   'oneself',
#   'or',
#   'loved',
#   'ones',
#   'causes',
#   'far',
#   'more',
#   'psychological',
#   'stress',
#   'than',
#   'having',
#   'wear',
#   'damn',
#   'mask',
#   'or',
#   'show',
#   'proof',
#   'vaccination',
#   'you',
#   'big',
#   'babies'],
#  ['why',
#   'would',
#   'triple',
#   'vaccinated',
#   'person',
#   'living',
#   'county',
#   'with',
#   'vaccination',
#   'rate',
#   'where',
#   'mask'],
#  ['dyk',
#   'about',
#   'half',
#   'adults',
#   'hospitalized',
#   'with',
#   'flu',
#   'have',
#   'heart',
#   'disease',
#   'flu',
#   'vaccination',
#   'is',
#   'especially',
#   'important',
#   'people',
#   'with',
#   'heart',
#   'disease',
#   'because',
#   'they',
#   'are',
#   'at',
#   'higher',
#   'risk',
#   'serious',
#   'flu',
#   'complications',
#   'protect',
#   'yourself',
#   'fightflu',
#   'this',
#   'heartmonth'],
#  ['we',
#   'are',
#   'nowplaying',
#   'pre',
#   'show',
#   'the',
#   'vaccination',
#   'misinformation',
#   'show',
#   'zero',
#   'new',
#   'nowspinning',
#   'np',
#   'nowstreaming',
#   'at',
#   'lt',
#   'lt',
#   'two',
#   'hear',
#   'subgenius',
#   'radio',
#   'end',
#   'times',
#   'joerogan',
#   'antivaxxers',
#   'full',
#   'details'],
#  ['it',
#   'can',
#   'be',
#   'enforced',
#   'like',
#   'parking',
#   'tickets',
#   'spot',
#   'checks',
#   'by',
#   'bylaw',
#   'officers',
#   'protecting',
#   'businesses',
#   'that',
#   'check',
#   'vaccination',
#   'includes',
#   'shots',
#   'etc'],
#  ['not',
#   'biden',
#   'giving',
#   'out',
#   'crack',
#   'pipes',
#   'as',
#   'long',
#   'as',
#   'you',
#   'show',
#   'proof',
#   'vaccination',
#   'lmfaoooo',
#   'i',
#   'saw',
#   'this',
#   'yesterday',
#   'thought',
#   'it',
#   'was',
#   'fake',
#   'we',
#   'are',
#   'literal',
#   'hell'],
#  ['i',
#   'hope',
#   'she',
#   'is',
#   'recieving',
#   'treatment',
#   'she',
#   'has',
#   'problems',
#   'with',
#   'her',
#   'immunity',
#   'system',
#   'like',
#   'people',
#   'who',
#   'have',
#   'had',
#   'too',
#   'many',
#   'vaccination',
#   'some',
#   'cases',
#   'natural',
#   'immunity',
#   'we',
#   'have',
#   'is',
#   'weakened',
#   'check',
#   'reports',
#   'israel'],
#  ['reminder',
#   'we',
#   'are',
#   'offering',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'students',
#   'staff',
#   'families',
#   'amp',
#   'community',
#   'tomorrow',
#   'covid',
#   'nineteen',
#   'testing',
#   'clinic',
#   'students',
#   'amp',
#   'staff',
#   'is',
#   'scheduled',
#   'saturday',
#   'feb',
#   'twelve',
#   'details',
#   'both',
#   'events',
#   'are',
#   'district',
#   'website',
#   'here'],
#  ['this',
#   'is',
#   'stunning',
#   'yet',
#   'we',
#   'want',
#   'treat',
#   'it',
#   'as',
#   'just',
#   'another',
#   'flu',
#   'i',
#   'don',
#   't',
#   'know',
#   'if',
#   'it',
#   'is',
#   'but',
#   'zero',
#   'plus',
#   'americans',
#   'died',
#   'it',
#   'last',
# ...
#   'check',
#   'out',
#   'information',
#   'resources',
#   'vaccination',
#   'we',
#   'all',
#   'need',
#   'do',
#   'our',
#   'part',
#   'keeping',
#   'our',
#   'neighbors',
#   'safe',
#   'so',
#   'learn',
#   'more',
#   'today',
#   'getvaxxed'],
#  ['streets', 'vaccination'],
#  ['covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'is',
#   'open',
#   'couple',
#   'more',
#   'hours',
#   'runners',
#   'swing',
#   'by',
#   'denman',
#   'ballroom',
#   'student',
#   'union',
#   'get',
#   'vaxxed',
#   'syringe',
#   'utsa',
#   'doyourpart'],
#  ['children',
#   'are',
#   'at',
#   'higher',
#   'risk',
#   'covid',
#   'nineteen',
#   'today',
#   'than',
#   'they',
#   'were',
#   'early',
#   'pandemic',
#   'but',
#   'vaccination',
#   'can',
#   'help',
#   'protect',
#   'them',
#   'every',
#   'person',
#   'five',
#   'older',
#   'is',
#   'eligible',
#   'receive',
#   'covid',
#   'nineteen',
#   'vaccine',
#   'syringe',
#   'book',
#   'appointment',
#   'at',
#   'or'],
#  ['service',
#   'nsw',
#   'talks',
#   'bring',
#   'medicare',
#   'card',
#   'app',
#   'following',
#   'success',
#   'with',
#   'vaccination',
#   'certificates'],
#  ['even',
#   'though',
#   'surgical',
#   'masks',
#   'are',
#   'only',
#   'thirteen',
#   'effective',
#   'that',
#   's',
#   'still',
#   'something',
#   'kn',
#   'should',
#   'be',
#   'provided',
#   'so',
#   'idk',
#   'what',
#   'your',
#   'point',
#   'is',
#   'until',
#   'we',
#   're',
#   'at',
#   'like',
#   'ninety',
#   'vaccination',
#   'virus',
#   'will',
#   'still',
#   'mutate',
#   'any',
#   'reduction',
#   'transmission'],
#  ['biggest',
#   'night',
#   'comedy',
#   'is',
#   'finally',
#   'here',
#   'seven',
#   'p',
#   'm',
#   'doors',
#   'open',
#   'eight',
#   'p',
#   'm',
#   'show',
#   'begins',
#   'all',
#   'guests',
#   'two',
#   'amp',
#   'older',
#   'must',
#   'provide',
#   'proof',
#   'full',
#   'vaccination',
#   'or',
#   'negative',
#   'test',
#   'amp',
#   'id',
#   'visit',
#   'more',
#   'all',
#   'times',
#   'amp',
#   'lineup',
#   'subject',
#   'change'],
#  ['except',
#   'many',
#   'businesses',
#   'including',
#   'retail',
#   'bars',
#   'amp',
#   'restaurants',
#   'will',
#   'still',
#   'require',
#   'masks',
#   'proof',
#   'vaccination',
#   'it',
#   's',
#   'their',
#   'freedom',
#   'do',
#   'so'],
#  ['highlights',
#   'five',
#   'new',
#   'cases',
#   'north',
#   'central',
#   'zone',
#   'has',
#   'highest',
#   'new',
#   'cases',
#   'thirty',
#   'outbreaks',
#   'confirmed',
#   'high',
#   'risk',
#   'settings',
#   'six',
#   'those',
#   'over',
#   'five',
#   'have',
#   'received',
#   'two',
#   'doses',
#   'vaccine',
#   'regina',
#   'is',
#   'area',
#   'with',
#   'highest',
#   'rate',
#   'vaccination',
#   'all',
#   'other',
#   'areas',
#   'are',
#   'below',
#   'eighty'],
#  ['film',
#   'academy',
#   'reportedly',
#   'won',
#   't',
#   'require',
#   'proof',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'at',
#   'oscars'],
#  ['by',
#   'time',
#   'nba',
#   'playoffs',
#   'start',
#   'there',
#   'won',
#   't',
#   'be',
#   'any',
#   'vaccination',
#   'requirements'],
#  ['but',
#   'he',
#   'said',
#   'it',
#   'was',
#   'right',
#   'moment',
#   'benefit',
#   'omicron',
#   's',
#   'seeming',
#   'mildness',
#   'country',
#   's',
#   'high',
#   'vaccination',
#   'rate',
#   'percent',
#   'entire',
#   'population',
#   'has',
#   'been',
#   'fully',
#   'vaccinated',
#   'percent',
#   'have',
#   'received',
#   'additional',
#   'shot',
#   'denmark'],
#  ['idk',
#   'what',
#   'you',
#   'mean',
#   'it',
#   'isn',
#   't',
#   'my',
#   'problem',
#   'if',
#   'they',
#   'choose',
#   'not',
#   'vax',
#   'their',
#   'children',
#   'then',
#   'need',
#   'babysitter',
#   'maybe',
#   'if',
#   'their',
#   'kids',
#   'can',
#   't',
#   'go',
#   'out',
#   'public',
#   'unvaccinated',
#   'it',
#   'woulf',
#   'spur',
#   'parents',
#   'choose',
#   'vaccination',
#   'which',
#   'is',
#   'optimal',
#   'imo'],
#  ['since',
#   'we',
#   'are',
#   'here',
#   'has',
#   'reportedly',
#   'stopped',
#   'facilitating',
#   'payments',
#   'vaccination',
#   'control',
#   'group'],
#  ['what',
#   'happened',
#   'following',
#   'cdc',
#   'guidelines',
#   'what',
#   'did',
#   'you',
#   'cave',
#   'what',
#   's',
#   'gonna',
#   'happen',
#   'when',
#   'rates',
#   'climb',
#   'again',
#   'cali',
#   'has',
#   'good',
#   'vaccination',
#   'rate',
#   'nv',
#   'does',
#   'not',
#   'you',
#   'failed',
#   'this',
#   'state'],
#  ['pm',
#   'couldn',
#   't',
#   'even',
#   'answer',
#   'opposition',
#   'leader',
#   'question',
#   'during',
#   'debate',
#   'questioning',
#   'about',
#   'how',
#   'much',
#   'vaccination',
#   'rate',
#   'is',
#   'enough',
#   'before',
#   'these',
#   'mandates',
#   'are',
#   'lifted',
#   'this',
#   'man',
#   'is',
#   'not',
#   'clearly',
#   'fit',
#   'lead',
#   'this',
#   'great',
#   'country',
#   'he',
#   's',
#   'so',
#   'incompetent'],
#  ['new',
#   'york',
#   'state',
#   'is',
#   'dropping',
#   'mask',
#   'requirements',
#   'but',
#   'broadway',
#   'is',
#   'not',
#   'arts',
#   'artsnews',
#   'broadway',
#   's',
#   'mask',
#   'vaccination',
#   'policy',
#   'will',
#   'remain',
#   'place',
#   'through',
#   'at',
#   'least',
#   'april',
#   'thirty',
#   'most',
#   'recent',
#   'extension',
#   'date',
#   'policy',
#   'announced',
#   'last',
#   'month',
#   'broadway'],
#  ['proof',
#   'world',
#   'is',
#   'being',
#   'taken',
#   'over',
#   'whistles',
#   'are',
#   'being',
#   'blamed',
#   'heart',
#   'attacks',
#   'myocarditis',
#   'occurring',
#   'chests',
#   'athletes',
#   'field',
#   'also',
#   'ottawa',
#   'citizens',
#   'are',
#   'concerned',
#   'about',
#   'exhaust',
#   'trucks',
#   'not',
#   'five',
#   'year',
#   'old',
#   'who',
#   'died',
#   'ten',
#   'minutes',
#   'after',
#   'vaccination'],
#  ['dr',
#   'brian',
#   'temple',
#   'diskusses',
#   'efforts',
#   'debunk',
#   'vaccination',
#   'mistruths',
#   'offers',
#   'advice',
#   'people',
#   'wanting',
#   'go',
#   'into',
#   'health',
#   'care',
#   'shares',
#   'his',
#   'thoughts',
#   'black',
#   'history'],
#  ['check',
#   'out',
#   'england',
#   's',
#   'non',
#   'covid',
#   'death',
#   'spikes',
#   'after',
#   'vaccination'],
#  ['no',
#   'more',
#   'than',
#   'evidence',
#   'that',
#   'masks',
#   'did',
#   'little',
#   'good',
#   'why',
#   'start',
#   'with',
#   'vaccination',
#   'stats',
#   'then',
#   'ask',
#   'about',
#   'masks',
#   'cable',
#   'tv',
#   'gig',
#   'upcoming'],
#  ['i',
#   'm',
#   'sorry',
#   'i',
#   'know',
#   'how',
#   'important',
#   'it',
#   'is',
#   'convince',
#   'people',
#   'get',
#   'covid',
#   'instead',
#   'getting',
#   'vaccination',
#   'i',
#   'm',
#   'not',
#   'kink',
#   'shaming',
#   'but',
#   'you',
#   'got',
#   'tricked',
#   'people',
#   'who',
#   'don',
#   't',
#   'read',
#   'that',
#   'article',
#   'share',
#   'it',
#   'all',
#   'time',
#   'because',
#   'it',
#   'sounds',
#   'like',
#   'what',
#   'they',
#   'want',
#   'believe'],
#  ['i',
#   'agree',
#   'i',
#   'tried',
#   'steer',
#   'conversation',
#   'towards',
#   'bc',
#   's',
#   'ridiculous',
#   'blocking',
#   'people',
#   'getting',
#   'tested',
#   'vaccine',
#   'mandates',
#   'are',
#   'distraction',
#   'amp',
#   'will',
#   'be',
#   'dropped',
#   'soon',
#   'anyway',
#   'ph',
#   'leadership',
#   'viewed',
#   'them',
#   'as',
#   'just',
#   'tool',
#   'encourage',
#   'vaccination',
#   'that',
#   'work',
#   'is',
#   'done'],
#  ['and',
#   'oscar',
#   'hypocrisy',
#   'goes',
#   'to',
#   'amp',
#   'twitter',
#   'reacts',
#   'academy',
#   'awards',
#   'not',
#   'requiring',
#   'proof',
#   'vaccination'],
#  ['his',
#   'lifetime',
#   'it',
#   'went',
#   'death',
#   'sentence',
#   'very',
#   'manageable',
#   'condition',
#   'now',
#   'might',
#   'even',
#   'have',
#   'vaccination',
#   'against',
#   'it',
#   'soon',
#   'that',
#   's',
#   'amazing',
#   'testament',
#   'science'],
#  ['luc',
#   'montagnier',
#   's',
#   'beliefs',
#   'about',
#   'vaccination',
#   'milan',
#   'one',
#   'fifteen',
#   'at',
#   'ten',
#   'dr',
#   'said',
#   'shared',
#   'that',
#   'it',
#   'will',
#   'be',
#   'up',
#   'unvaccinated',
#   'defend',
#   'humanity',
#   'according',
#   'reliable',
#   'sources',
#   'italian',
#   'translator',
#   'translates',
#   'unvaccinated',
#   'are',
#   'guardians',
#   'humanity',
#   'rip',
#   'seeker',
#   'truth'],
#  ['eight',
#   'u',
#   'so',
#   'makary',
#   'is',
#   'being',
#   'misleading',
#   'when',
#   'he',
#   'uses',
#   'his',
#   'paper',
#   'diskuss',
#   'natural',
#   'immunity',
#   'vs',
#   'vaccination',
#   'since',
#   'he',
#   'isn',
#   't',
#   'assessing',
#   'neutralization',
#   'note',
#   'difference',
#   'between',
#   'what',
#   'his',
#   'paper',
#   'vs',
#   'his',
#   'twitter',
#   'claim',
#   'about',
#   'his',
#   'paper'],
#  ['evidence',
#   'increased',
#   'infection',
#   'risk',
#   'following',
#   'third',
#   'dose',
#   'exacerbated',
#   'by',
#   'vaccination',
#   'drive',
#   'during',
#   'omicron',
#   'wave',
#   'ukhsa',
#   'data',
#   'show',
#   'via'],
#  ['so',
#   'make',
#   'right',
#   'fly',
#   'governed',
#   'by',
#   'airlines',
#   'if',
#   'they',
#   'want',
#   'institute',
#   'mandates',
#   'they',
#   'can',
#   'this',
#   'is',
#   'no',
#   'longer',
#   'about',
#   'public',
#   'health',
#   'given',
#   'we',
#   're',
#   'at',
#   'ninety',
#   'vaccination',
#   'this',
#   'is',
#   'about',
#   'individual',
#   'health'],
#  ['b',
#   'c',
#   'expanding',
#   'vaccination',
#   'requirements',
#   'health',
#   'care',
#   'professionals'],
#  ['we',
#   'will',
#   'be',
#   'mcl',
#   'room',
#   'please',
#   'make',
#   'sure',
#   'rsvp',
#   'by',
#   'vaccination',
#   'cards',
#   'masks',
#   'are',
#   'required',
#   'link',
#   'below'],
#  ['ah',
#   'well',
#   'with',
#   'each',
#   'answer',
#   'he',
#   'managed',
#   'to',
#   'place',
#   'the',
#   'word',
#   'vaccination',
#   'and',
#   'its',
#   'diminutives',
#   'of',
#   'course',
#   'he',
#   'is',
#   'too',
#   'strong',
#   'our',
#   'national',
#   'juju'],
#  ['really',
#   'not',
#   'happy',
#   'about',
#   'this',
#   'i',
#   'may',
#   'be',
#   'minority',
#   'with',
#   'these',
#   'feelings',
#   'but',
#   'kids',
#   'five',
#   'amp',
#   'under',
#   'still',
#   'can',
#   't',
#   'get',
#   'vaxxed',
#   'many',
#   'people',
#   'remain',
#   'unvaxxed',
#   'this',
#   'says',
#   'fuck',
#   'you',
#   'anyone',
#   'who',
#   'is',
#   'immunocompromised',
#   'full',
#   'vaccination',
#   'clark',
#   'county',
#   'nv',
#   'is',
#   'still',
#   'below',
#   'ugh'],
#  ['fyi',
#   'canadian',
#   'truckers',
#   'with',
#   'ninety',
#   'vaccination',
#   'rate',
#   'are',
#   'more',
#   'vaccinated',
#   'than',
#   'any',
#   'single',
#   'demographic',
#   'group',
#   'america',
#   'that',
#   'i',
#   've',
#   'come',
#   'across',
#   'except',
#   'doctors'],
#  ['seriously',
#   'it',
#   's',
#   'well',
#   'documented',
#   'that',
#   'risk',
#   'transmitting',
#   'covid',
#   'is',
#   'same',
#   'regardless',
#   'vaccination',
#   'status'],
#  ['minneapolis',
#   'st',
#   'paul',
#   'immediately',
#   'lift',
#   'mandate',
#   'requiring',
#   'proof',
#   'vaccination',
#   'negative',
#   'test'],
#  ['ask',
#   'her',
#   'if',
#   'proof',
#   'vaccination',
#   'could',
#   'be',
#   'used',
#   'by',
#   'republicans',
#   'voter',
#   'id'],
#  ['yes', 'like', 'vaccination'],
#  ['people',
#   'who',
#   'defend',
#   'joe',
#   'rogan',
#   'like',
#   'say',
#   'that',
#   'he',
#   'has',
#   'tough',
#   'conversations',
#   'with',
#   'wide',
#   'range',
#   'voices',
#   'but',
#   'then',
#   'why',
#   'does',
#   'he',
#   'never',
#   'seem',
#   'host',
#   'say',
#   'critical',
#   'race',
#   'theorists',
#   'trans',
#   'rights',
#   'activists',
#   'real',
#   'doctors',
#   'defend',
#   'vaccination',
#   'anyone',
#   'who',
#   'might',
#   'actually',
#   'challenge',
#   'him'],
#  ['if',
#   'vaccination',
#   'alone',
#   'is',
#   'solution',
#   'then',
#   'we',
#   'need',
#   'next',
#   'gen',
#   'vaccines',
#   'that',
#   'protect',
#   'broadly',
#   'across',
#   'variants',
#   'create',
#   'sterilyzing',
#   'immune',
#   'response',
#   'body',
#   'that',
#   'will',
#   'take',
#   'time',
#   'interim',
#   'premiers',
#   'can',
#   't',
#   'ignore',
#   'ph',
#   'protections',
#   'so',
#   'we',
#   'can',
#   'live',
#   'with',
#   'it'],
#  ['many',
#   'businesses',
#   'introduced',
#   'proof',
#   'vaccination',
#   'mandatory',
#   'masking',
#   'measures',
#   'before',
#   'government',
#   'did',
#   'now',
#   'with',
#   'public',
#   'health',
#   'orders',
#   'set',
#   'end',
#   'could',
#   'businesses',
#   'keep',
#   'those',
#   'requirements',
#   'their',
#   'patrons',
#   'got',
#   'one',
#   'regina',
#   'lawyer',
#   's',
#   'legal',
#   'opinion',
#   'listen'],
#  ['at',
#   'idw',
#   'dinner',
#   'believe',
#   'me',
#   'man',
#   'this',
#   'is',
#   'something',
#   'i',
#   've',
#   'spend',
#   'lot',
#   'time',
#   'thinking',
#   'about',
#   'vaccine',
#   'passports',
#   'are',
#   'essentially',
#   'social',
#   'gulag',
#   'then',
#   'you',
#   'have',
#   'ask',
#   'well',
#   'what',
#   's',
#   'so',
#   'bad',
#   'about',
#   'that',
#   'yo',
#   'oh',
#   'hold',
#   'on',
#   'get',
#   'your',
#   'proof',
#   'vaccination',
#   'id',
#   'ready',
#   'hostess'],
#  ['canr',
#   'lgbtq',
#   'adults',
#   'have',
#   'higher',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'rates',
#   'than',
#   'heterosexual',
#   'adults',
#   'pandemic',
#   'has',
#   'has',
#   'unique',
#   'impact',
#   'lgbtq',
#   'community',
#   'cdc',
#   'says',
#   'lgbt',
#   'persons',
#   'are',
#   'at',
#   'increased',
#   'risk',
#   'severe',
#   'covid',
#   'nineteen',
#   'illness',
#   'view',
#   'article'],
#  ['i',
#   'haven',
#   't',
#   'even',
#   'gotten',
#   'original',
#   'vaccination',
#   'yet',
#   'not',
#   'because',
#   'i',
#   'don',
#   't',
#   'want',
#   'but',
#   'because',
#   'i',
#   'm',
#   'not',
#   'allowed',
#   'make',
#   'my',
#   'own',
#   'medical',
#   'decisions'],
#  ['says',
#   'countries',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'than',
#   'canada',
#   'have',
#   'reopened',
#   'she',
#   'asks',
#   'pm',
#   'trudeau',
#   'if',
#   'he',
#   'll',
#   'only',
#   'end',
#   'mandates',
#   'reopen',
#   'country',
#   'if',
#   'canadians',
#   'are',
#   'vaccinated',
#   'trudeau',
#   'responds',
#   'says',
#   'vaccines',
#   'will',
#   'help',
#   'lift',
#   'restrictions',
#   'cdnpoli'],
#  ['mask',
#   'vaccination',
#   'requirements',
#   'are',
#   'tyranny',
#   'people',
#   'love',
#   'throwing',
#   'that',
#   'word',
#   'around',
#   'and',
#   'name',
#   'calling',
#   'ad',
#   'hominem',
#   'attacks',
#   'are',
#   'not',
#   'going',
#   'make',
#   'your',
#   'argument',
#   'any',
#   'better',
#   'toodles'],
#  ['are', 'you', 'anti', 'vaccination', 'or', 'anti', 'covid', 'vaccination'],
#  ['do',
#   'you',
#   'still',
#   'need',
#   'get',
#   'covid',
#   'nineteen',
#   'vaccine',
#   'louisianians',
#   'who',
#   'get',
#   'their',
#   'first',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'shot',
#   'are',
#   'eligible',
#   'receive',
#   'including',
#   'children',
#   'ages',
#   'five',
#   'seventeen'],
#  ['make',
#   'vaccination',
#   'process',
#   'easy',
#   'close',
#   'home',
#   'people',
#   'campaign',
#   'focusing',
#   'getting',
#   'covid',
#   'nineteen',
#   'vaccines',
#   'east',
#   'end',
#   'toronto',
#   'residents',
#   'starts',
#   'this',
#   'saturday'],
#  ['choosing',
#   'good',
#   'policy',
#   'choices',
#   'isn',
#   't',
#   'making',
#   'wedge',
#   'if',
#   'anything',
#   'it',
#   'was',
#   'conservatives',
#   'that',
#   'politicized',
#   'issue',
#   'by',
#   'knee',
#   'jerk',
#   'criticizing',
#   'every',
#   'choice',
#   'at',
#   'every',
#   'step',
#   'so',
#   'naturally',
#   'if',
#   'trudeau',
#   'chose',
#   'vaccination',
#   'conservatives',
#   'chose',
#   'opposite'],
#  ['when',
#   'there',
#   'was',
#   'no',
#   'vaccine',
#   'djt',
#   's',
#   'incompetence',
#   'allowed',
#   'isolated',
#   'covid',
#   'infections',
#   'spread',
#   'epidemic',
#   'proportions',
#   'requiring',
#   'trump',
#   'shutdown',
#   'tht',
#   'led',
#   'trump',
#   'recession',
#   'biden',
#   'american',
#   'rescue',
#   'plan',
#   'ended',
#   'trump',
#   'epidemic',
#   'amp',
#   'recession',
#   'by',
#   'organizing',
#   'vaccination',
#   'programs'],
#  ['yes',
#   'photo',
#   'your',
#   'vaccination',
#   'card',
#   'will',
#   'be',
#   'sufficient',
#   'entry',
#   'thanks'],
#  ['watched',
#   'hbo',
#   'vice',
#   'story',
#   'trying',
#   'make',
#   'me',
#   'feel',
#   'guilty',
#   'making',
#   'fun',
#   'people',
#   'that',
#   'denied',
#   'covid',
#   'and',
#   'or',
#   'refused',
#   'vaccination',
#   'later',
#   'died',
#   'me'],
#  ['been',
#   'watching',
#   'coverage',
#   'this',
#   'insanity',
#   'anti',
#   'vaccination',
#   'trucker',
#   'protests',
#   'their',
#   'is',
#   'threat',
#   'trucker',
#   'protest',
#   'at',
#   'super',
#   'bowl',
#   'this',
#   'would',
#   'annoy',
#   'one',
#   'privilege',
#   'class',
#   'amp',
#   'other',
#   'wealthy',
#   'people',
#   'that',
#   'only',
#   'people',
#   'who',
#   'could',
#   'afford',
#   'tickets',
#   'range',
#   'tickets',
#   'prices',
#   'one',
#   'm'],
#  ['like',
#   'masks',
#   'socialdistancing',
#   'vaccination',
#   'because',
#   'so',
#   'many',
#   'still',
#   'refuse',
#   'get',
#   'vaccinated',
#   'while',
#   'people',
#   'much',
#   'world',
#   'don',
#   't',
#   'even',
#   'yet',
#   'have',
#   'access',
#   'vaccine',
#   'we',
#   'will',
#   'see',
#   'more',
#   'variations',
#   'resulting',
#   'infections',
#   'deaths',
#   'who',
#   'wouldn',
#   't',
#   'assume',
#   'that',
#   'wise',
#   'alien',
#   'four'],
#  ...]

# %% [markdown]
# ## Remove words len <= 3

# %%
new_list = []

for alist in tokenised_words_only:
    mini_list = []
    for word in alist:
        if len(word) > 3:
            mini_list.append(word)
    new_list.append(mini_list)

# %%
#test
new_list
# Out:
# [['want',
#   'find',
#   'racism',
#   'force',
#   'people',
#   'inject',
#   'themselves',
#   'that',
#   'what',
#   'bunch',
#   'people',
#   'races',
#   'standing',
#   'against',
#   'forced',
#   'vaccination',
#   'against',
#   'vaxx',
#   'some',
#   'people',
#   'need',
#   'these',
#   'vaxx',
#   'support',
#   'those',
#   'people',
#   'getting',
#   'their',
#   'shot',
#   'draw',
#   'line',
#   'force'],
#  ['this',
#   'child',
#   'almost',
#   'died',
#   'tetanus',
#   'spent',
#   'months',
#   'hospital',
#   'cost',
#   'around',
#   'parents',
#   'still',
#   'refused',
#   'vaccination',
#   'after',
#   'this',
#   'pandemic'],
#  ['just',
#   'remember',
#   'leblanc',
#   'pressure',
#   'that',
#   'provincial',
#   'business',
#   'world',
#   'asked',
#   'able',
#   'open',
#   'borders',
#   'traffic',
#   'will',
#   'provincial',
#   'govt',
#   'included',
#   'block',
#   'tourists',
#   'will',
#   'have',
#   'pass',
#   'vaccination',
#   'hotel',
#   'restaurant'],
#  ['would',
#   'expect',
#   'cases',
#   'rise',
#   'significantly',
#   'course',
#   'vaccination',
#   'rates',
#   'come',
#   'into',
#   'play',
#   'does',
#   'space',
#   'adults',
#   'usually',
#   'confined',
#   'single',
#   'space',
#   'with',
#   'many',
#   'people',
#   'school',
#   'students',
#   'data',
#   'states',
#   'that',
#   'have',
#   'lifted',
#   'those',
#   'that',
#   'have',
#   'bears',
#   'this'],
#  ['depends',
#   'whether',
#   'vaccination',
#   'status',
#   'embedded',
#   'code',
#   'itself',
#   'code',
#   'just',
#   'link',
#   'that',
#   'connects',
#   'back',
#   'read',
#   'about',
#   'when',
#   'released',
#   'remember',
#   'will',
#   'find',
#   'again'],
#  ['could',
#   'have',
#   'ripped',
#   'harder',
#   'think',
#   'masking',
#   'isolation',
#   'ultimately',
#   'impact',
#   'honest',
#   'question',
#   'look',
#   'those',
#   'spikes',
#   'think',
#   'maybe',
#   'they',
#   'would',
#   'have',
#   'looked',
#   'same',
#   'matter',
#   'what',
#   'with',
#   'vaccination',
#   'only',
#   'thing',
#   'that',
#   'definitively',
#   'worked'],
#  ['they',
#   'this',
#   'vaccination',
#   'centers',
#   'well',
#   'they',
#   'refused',
#   'elderly',
#   'parent',
#   'wear',
#   'over',
#   'masks',
#   'lady',
#   'very',
#   'rude',
#   'said',
#   'could',
#   'have',
#   'covid',
#   'nineteen',
#   'could',
#   'mask',
#   'refused',
#   'take',
#   'answer',
#   'said',
#   'begrudgingly',
#   'absurd'],
#  ['part',
#   'vanguard',
#   'vaccination',
#   'awareness',
#   'project',
#   'series',
#   'free',
#   'tools',
#   'help',
#   'suite',
#   'leaders',
#   'combat',
#   'vaccine',
#   'hesitancy',
#   'resistance',
#   'podcasts',
#   'videos',
#   'articles',
#   'available',
#   'covidvaccineconfidence',
#   'vanguardvaccinationproject'],
#  ['correct',
#   'about',
#   'vaccines',
#   'their',
#   'stated',
#   'goal',
#   'about',
#   'vaccination',
#   'breaking',
#   'blogger',
#   'reports',
#   'factual',
#   'news',
#   'accident',
#   'this',
#   'about',
#   'vaccines',
#   'least',
#   'know',
#   'read',
#   'positive',
#   'steps',
#   'towards',
#   'competence'],
#  ['does',
#   'hurt',
#   'your',
#   'head',
#   'actually',
#   'your',
#   'brain',
#   'seem',
#   'incredibly',
#   'brainwashed',
#   'places',
#   'with',
#   'highest',
#   'vaccination',
#   'rates',
#   'world',
#   'have',
#   'some',
#   'highest',
#   'case',
#   'counts',
#   'everyone',
#   'that',
#   'disagrees',
#   'with',
#   'your',
#   'compliance',
#   'totaltiarin',
#   'dictatorships',
#   'must',
#   'called',
#   'names'],
#  ['world',
#   'wide',
#   'mass',
#   'vaccination',
#   'leading',
#   'world',
#   'wide',
#   'digital',
#   'passport',
#   'their',
#   'goal',
#   'populationcontrol'],
#  ['vaccinations',
#   'still',
#   'need',
#   'proof',
#   'vaccination',
#   'restaurants',
#   'movie',
#   'theaters',
#   'museums',
#   'large',
#   'arenas',
#   'gyms',
#   'fitness',
#   'centers',
#   'vaccination',
#   'rate',
#   'more',
#   'three',
#   'three'],
#  ['following',
#   'tweet',
#   'didn',
#   'even',
#   'twelve',
#   'hours',
#   'before',
#   'prince',
#   'charles',
#   'announced',
#   'reinfection',
#   'even',
#   'after',
#   'vaccination',
#   'booster',
#   'clearly',
#   'previous',
#   'infection',
#   'protects',
#   'this',
#   'point',
#   'does',
#   'boris',
#   'johnson',
#   'exude',
#   'some',
#   'sort',
#   'hypnotoad',
#   'like',
#   'pheromone',
#   'something'],
#  ['vaccination'],
#  ['private',
#   'businesses',
#   'enforce',
#   'vaccination',
#   'mandates',
#   'they',
#   'choose'],
#  ['understand',
#   'exactly',
#   'what',
#   'needs',
#   'understood',
#   'lame',
#   'link',
#   'even',
#   'remains',
#   'lame',
#   'when',
#   'vaccination',
#   'compulsory',
#   'will',
#   'come',
#   'back',
#   'bawl',
#   'there'],
#  ['story',
#   'with',
#   'martha',
#   'mccallum',
#   'senior',
#   'medical',
#   'advisor',
#   'robert',
#   'redfield',
#   'comments',
#   'confusing',
#   'messaging',
#   'spread',
#   'omicron',
#   'importance',
#   'maintaining',
#   'your',
#   'vaccination',
#   'status',
#   'watch',
#   'full',
#   'interview',
#   'below'],
#  ['world',
#   'virologist',
#   'montagnier',
#   'winner',
#   'nobel',
#   'prize',
#   'diskovery',
#   'died',
#   'today',
#   'warned',
#   'beginning',
#   'that',
#   'covid',
#   'nineteen',
#   'made',
#   'that',
#   'mass',
#   'vaccination',
#   'with',
#   'leaky',
#   'vaccines',
#   'would',
#   'generate',
#   'endless',
#   'variants',
#   'right',
#   'both',
#   'counts'],
#  ['obvious',
#   'common',
#   'sense',
#   'solution',
#   'always',
#   'take',
#   'free',
#   'safe',
#   'vaccination',
#   'against',
#   'deadly',
#   'virus',
#   'then',
#   'carry',
#   'about',
#   'your',
#   'business',
#   'like',
#   'lunatic'],
#  ['sure',
#   'tootin',
#   'remember',
#   'grew',
#   'jackson',
#   'least',
#   'place',
#   'long',
#   'associated',
#   'with',
#   'republican',
#   'party',
#   'familiar',
#   'with',
#   'conservative',
#   'mien',
#   'mindset',
#   'speak',
#   'that',
#   'think',
#   'plain',
#   'language',
#   'think',
#   'covid',
#   'should',
#   'mandatory',
#   'vaccination'],
#  ['which',
#   'variants',
#   'were',
#   'involved',
#   'what',
#   'vaccination',
#   'masking',
#   'ventilation',
#   'around',
#   'kids',
#   'time',
#   'meaningless',
#   'kids',
#   'aren',
#   'danger',
#   'unless',
#   'mean',
#   'kids',
#   'have',
#   'will',
#   'ever',
#   'danger',
#   'matter',
#   'what'],
#  ['last',
#   'looked',
#   'hadn',
#   'actually',
#   'county',
#   'vaccination',
#   'threshold',
#   'because',
#   'difference',
#   'between',
#   'data',
#   'most',
#   'secondary',
#   'schools',
#   'have',
#   'though'],
#  ['what',
#   'your',
#   'saying',
#   'that',
#   'alberta',
#   'businesses',
#   'that',
#   'required',
#   'proof',
#   'vaccination',
#   'rely',
#   'alberta',
#   'government',
#   'they',
#   'have',
#   'rely',
#   'other',
#   'provinces'],
#  ['this',
#   'vision',
#   'public',
#   'health',
#   'decisions',
#   'tied',
#   'local',
#   'conditions',
#   'spread',
#   'vaccination',
#   'vulnerability',
#   'also',
#   'sounds',
#   'reasonable',
#   'however',
#   'years',
#   'into',
#   'this',
#   'acting',
#   'that',
#   'what',
#   'happening',
#   'naive',
#   'best',
#   'partisan',
#   'politics',
#   'even',
#   'local',
#   'level',
#   'often',
#   'factor'],
#  ['mean',
#   'someone',
#   'told',
#   'they',
#   'kill',
#   'didn',
#   'vaccinated',
#   'understand',
#   'thought',
#   'said',
#   'vaccination',
#   'lose',
#   'your',
#   'bodily',
#   'autonomy',
#   'then'],
#  ['their',
#   'concerns',
#   'real',
#   'even',
#   'unfounded',
#   'addressing',
#   'them',
#   'with',
#   'empathy',
#   'genuine',
#   'good',
#   'will',
#   'persuade',
#   'them',
#   'canada',
#   'similar',
#   'levels',
#   'adult',
#   'vaccination'],
#  ['seems',
#   'like',
#   'steel',
#   'here',
#   'about',
#   'many',
#   'mandates',
#   'masks',
#   'vaccination',
#   'testing',
#   'that',
#   'very',
#   'much',
#   'still',
#   'place',
#   'relatively',
#   'cost',
#   'zero',
#   'cost'],
#  ['kill', 'sally', 'field', 'here'],
#  ['jesus',
#   'christ',
#   'vaccination',
#   'being',
#   'forced',
#   'carry',
#   'pregnancy',
#   'term'],
#  ['amazon',
#   'allow',
#   'work',
#   'without',
#   'face',
#   'masks',
#   'require',
#   'vaccination',
#   'paid',
#   'covid',
#   'leave'],
#  ['five',
#   'governments',
#   'primary',
#   'concern',
#   'justification',
#   'compulsory',
#   'covid',
#   'vaccination',
#   'prevent',
#   'hospitals',
#   'emergency',
#   'depts',
#   'being',
#   'inundated',
#   'thus',
#   'running',
#   'medical',
#   'resources',
#   'space',
#   'equipment',
#   'staff',
#   'perhaps',
#   'govt',
#   'should',
#   'require',
#   'hospitals'],
#  ['when',
#   'covid',
#   'vaccines',
#   'have',
#   'proven',
#   'prevent',
#   'spread',
#   'covid',
#   'even',
#   'before',
#   'with',
#   'omicron',
#   'where',
#   'called',
#   'breakthrough',
#   'cases',
#   'became',
#   'just',
#   'positive',
#   'covid',
#   'cases',
#   'omicron',
#   'didn',
#   'care',
#   'vaccine',
#   'status',
#   'real',
#   'driving',
#   'force',
#   'vaccination',
#   'become',
#   'minimizing'],
#  ['vaccination', 'syringe', 'video'],
#  ['think',
#   'they',
#   'eighty',
#   'most',
#   'games',
#   'never',
#   'that',
#   'full',
#   'anyway',
#   'meant',
#   'download',
#   'green',
#   'light',
#   'which',
#   'based',
#   'vaccination',
#   'status',
#   'that',
#   'allow',
#   'enter',
#   'stadium',
#   'ground',
#   'there',
#   'unsure',
#   'they',
#   'enforce',
#   'that',
#   'much'],
#  ['alberta',
#   'businesses',
#   'that',
#   'legally',
#   'still',
#   'requires',
#   'obtain',
#   'proof',
#   'vaccination',
#   'there',
#   'those',
#   'still',
#   'legally',
#   'required'],
#  ['about',
#   'medical',
#   'specialists',
#   'were',
#   'involved',
#   'vaccination',
#   'effort'],
#  ['reaction',
#   'vaccine',
#   'according',
#   'anaphylaxis',
#   'after',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'extremely',
#   'rare',
#   'occurred',
#   'about',
#   'five',
#   'people',
#   'million',
#   'vaccinated',
#   'united',
#   'states',
#   'five',
#   'vaccinations'],
#  ['chickahominy',
#   'health',
#   'district',
#   'holding',
#   'vaccination',
#   'clinic',
#   'february',
#   'three',
#   'sargent',
#   'reynolds',
#   'community',
#   'college',
#   'please',
#   'this',
#   'link',
#   'register',
#   'walk',
#   'will',
#   'accepted'],
#  ['that',
#   'right',
#   'their',
#   'body',
#   'belongs',
#   'them',
#   'what',
#   'wears',
#   'better',
#   'fight',
#   'fight',
#   'compulsory',
#   'vaccination',
#   'required',
#   'businesses',
#   'employers',
#   'this',
#   'government'],
#  ['have',
#   'nothing',
#   'more',
#   'report',
#   'about',
#   'other',
#   'than',
#   'documents',
#   'trump',
#   'took',
#   'gave',
#   'back',
#   'bullshit',
#   'that',
#   'happened',
#   'january',
#   'about',
#   'close',
#   'borders',
#   'mask',
#   'vaccination',
#   'mandates',
#   'seriously',
#   'people'],
#  ['conclusion',
#   'most',
#   'definitely',
#   'cannot',
#   'draw',
#   'that',
#   'that',
#   'mask',
#   'mandates',
#   'work',
#   'since',
#   'death',
#   'rates',
#   'much',
#   'lower',
#   'those',
#   'states',
#   'again',
#   'this',
#   'probably',
#   'primarily',
#   'higher',
#   'vaccination',
#   'rates'],
#  ['never', 'suggested', 'vaccination', 'issue', 'other'],
#  ['hasn',
#   'trump',
#   'been',
#   'arrested',
#   'look',
#   'like',
#   'laughingstocks',
#   'rest',
#   'world',
#   'still',
#   'also',
#   'terrified',
#   'truckers',
#   'they',
#   'just',
#   'coming',
#   'because',
#   'vaccination',
#   'mandates',
#   'they',
#   'coming',
#   'because',
#   'perceived',
#   'reinstatement'],
#  ['covid',
#   'positive',
#   'when',
#   'died',
#   'amazed',
#   'that',
#   'they',
#   'haven',
#   'spun',
#   'this',
#   'into',
#   'covid',
#   'death',
#   'push',
#   'their',
#   'vaccination',
#   'agenda'],
#  ['crossed', 'with', 'data', 'vaccination'],
#  ['school',
#   'gonna',
#   'vaccination',
#   'proof',
#   'because',
#   'they',
#   'respect',
#   'individuality',
#   'health',
#   'decisions',
#   'everyone',
#   'have',
#   'choice',
#   'stay',
#   'virtually',
#   'hate',
#   'here'],
#  ['linked',
#   'above',
#   'republican',
#   'controlled',
#   'states',
#   'which',
#   'tend',
#   'states',
#   'without',
#   'mask',
#   'mandates',
#   'doing',
#   'worse',
#   'than',
#   'democratic',
#   'controlled',
#   'states',
#   'course',
#   'they',
#   'also',
#   'states',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'hard',
#   'draw',
#   'strong',
#   'conclusion',
#   'that'],
#  ['close', 'neighbor', 'lowest', 'covid', 'vaccination', 'rates', 'world'],
#  ['vaccination',
#   'campaign',
#   'gone',
#   'from',
#   'exemplary',
#   'miserable',
#   'failure'],
#  ['advocacy',
#   'update',
#   'physician',
#   'groups',
#   'urge',
#   'supreme',
#   'court',
#   'uphold',
#   'vaccination',
#   'requirement',
#   'highlights',
#   'parity',
#   'enforcement',
#   'regulatory',
#   'agenda',
#   'more',
#   'mentalhealth',
#   'psychtwitter'],
#  ['putting',
#   'together',
#   'spreadsheet',
#   'what',
#   'oscar',
#   'nominees',
#   'celebrities',
#   'attended',
#   'vaccination',
#   'required',
#   'events',
#   'publicly',
#   'spoken',
#   'about',
#   'vaccine'],
#  ['that',
#   'indian',
#   'health',
#   'department',
#   'sorry',
#   'trust',
#   'people',
#   'that',
#   'look',
#   'like',
#   'think',
#   'israel',
#   'with',
#   'ninety',
#   'vaccination',
#   'rate',
#   'such',
#   'hard',
#   'time',
#   'with',
#   'covid',
#   'right'],
#  ['amerks',
#   'will',
#   'longer',
#   'require',
#   'proof',
#   'vaccination',
#   'entry',
#   'amerks',
#   'games',
#   'events',
#   'blue',
#   'cross',
#   'arena',
#   'beginning',
#   'thursday',
#   'february'],
#  ['employer',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   'even',
#   'provincial',
#   'federal',
#   'governments',
#   'remove',
#   'mandates',
#   'employer',
#   'will',
#   'still',
#   'have',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   'what',
#   'then',
#   'cdnpoli',
#   'onpoli'],
#  ['demystify',
#   'vaccination',
#   'against',
#   'provided',
#   'master',
#   'your',
#   'subject'],
#  ['need', 'have', 'uniformed', 'rule', 'about', 'mask', 'vaccination'],
#  ['conservative',
#   'anti',
#   'abortion',
#   'anti',
#   'vaccination',
#   'people',
#   'thoughts',
#   'prayers',
#   'forget',
#   'prayers'],
#  ['classic',
#   'simpson',
#   'paradox',
#   'most',
#   'deaths',
#   'among',
#   'elderly',
#   'people',
#   'nearly',
#   'whom',
#   'vaccinated',
#   'with',
#   'lower',
#   'vaccination',
#   'rate',
#   'total',
#   'number',
#   'fatalities',
#   'would',
#   'much',
#   'higher'],
#  ['sounds',
#   'like',
#   'planning',
#   'masking',
#   'kids',
#   'indefinitely',
#   'what',
#   'hospitalization',
#   'rates',
#   'vaccination',
#   'rates',
#   'deeming',
#   'necessary',
#   'finally',
#   'these',
#   'kids',
#   'finally',
#   'back',
#   'normalcy',
#   'need',
#   'numbers'],
#  ['cases',
#   'have',
#   'gone',
#   'state',
#   'highest',
#   'vaccination',
#   'rate',
#   'january',
#   'bullshit',
#   'obvious',
#   'fake',
#   'news',
#   'site',
#   'with',
#   'spoon',
#   'this',
#   'insulting',
#   'your',
#   'intelligence'],
#  ['there',
#   'people',
#   'speaking',
#   'like',
#   'choice',
#   'abortions',
#   'same',
#   'choice',
#   'relating',
#   'vaccines',
#   'disagree',
#   'abortion',
#   'removes',
#   'choice',
#   'human',
#   'ending',
#   'human',
#   'life',
#   'forced',
#   'coerced',
#   'vaccination',
#   'removes',
#   'choice',
#   'forcing',
#   'human',
#   'risk',
#   'permanent',
#   'damage'],
#  ['delusional',
#   'over',
#   'endemic',
#   'going',
#   'live',
#   'with',
#   'this',
#   'vaccination',
#   'lockdowns',
#   'masks',
#   'covid',
#   'still',
#   'here',
#   'live',
#   'fear',
#   'with',
#   'taking',
#   'precaution',
#   'necessary',
#   'based',
#   'other',
#   'health',
#   'conditions'],
#  ['tell',
#   'that',
#   'unvaccinated',
#   'people',
#   'died',
#   'covid',
#   'unfortunately',
#   'that',
#   'true',
#   'vaccination',
#   'does',
#   'indeed',
#   'prevent',
#   'some',
#   'most',
#   'dire',
#   'results',
#   'covid',
#   'infection',
#   'that',
#   'pretty',
#   'well',
#   'established'],
#  ['tool',
#   'surgeon',
#   'general',
#   'refuses',
#   'disklose',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status'],
#  ['quebec',
#   'asking',
#   'vaccinating',
#   'physicians',
#   'return',
#   'their',
#   'regular',
#   'activities',
#   'sharp',
#   'drop',
#   'attendance',
#   'vaccination',
#   'clinics',
#   'radio',
#   'canada',
#   'reported',
#   'this',
#   'morning',
#   'that',
#   'vaccinators',
#   'twiddling',
#   'their',
#   'thumbs',
#   'polqc'],
#  ['thank',
#   'keeping',
#   'mask',
#   'mandate',
#   'schools',
#   'need',
#   'vaccination',
#   'rates',
#   'more',
#   'education',
#   'outreach',
#   'students',
#   'siblings',
#   'under',
#   'five',
#   'vaccinated',
#   'before',
#   'lifting',
#   'mask',
#   'mandates'],
#  ['according', 'vaccination', 'abortion', 'same', 'thing', 'welcome'],
#  ['care',
#   'explain',
#   'mental',
#   'health',
#   'anything',
#   'with',
#   'vaccine',
#   'talking',
#   'about',
#   'person',
#   'feel',
#   'about',
#   'other',
#   'talking',
#   'about',
#   'genuine',
#   'mental',
#   'health',
#   'issue',
#   'vaccination',
#   'does',
#   'exist'],
#  ['find',
#   'fixed',
#   'vaccination',
#   'site',
#   'your',
#   'area',
#   'getvaccinated',
#   'today',
#   'visit',
#   'call',
#   'love'],
#  ['three',
#   'eric',
#   'adams',
#   'also',
#   'repeatedly',
#   'renewed',
#   'executive',
#   'order',
#   'which',
#   'requires',
#   'anyone',
#   'over',
#   'five',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'participate',
#   'indoor',
#   'activities',
#   'anyone',
#   'eighteen',
#   'older',
#   'proof',
#   'along',
#   'with',
#   'proof',
#   'vaccination',
#   'required'],
#  ['makes', 'also', 'angry', 'those', 'have', 'diskouraged', 'vaccination'],
#  ['about',
#   'time',
#   'well',
#   'done',
#   'everyone',
#   'faught',
#   'this',
#   'proud',
#   'revoking',
#   'vaccination',
#   'condition',
#   'deployment',
#   'across',
#   'health',
#   'social',
#   'care'],
#  ['oscars',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'will',
#   'required',
#   'person',
#   'attendees',
#   'exclusive'],
#  ['proof',
#   'vaccination',
#   'still',
#   'required',
#   'indoor',
#   'dining',
#   'events',
#   'arenas',
#   'gyms',
#   'theaters',
#   'museums',
#   'other',
#   'indoor',
#   'entertainment',
#   'york',
#   'city',
#   'part',
#   'initiative',
#   'started',
#   'former',
#   'mayor'],
#  ['what',
#   'makes',
#   'americans',
#   'think',
#   'they',
#   'have',
#   'right',
#   'challenge',
#   'sovereign',
#   'nation',
#   'rules',
#   'regarding',
#   'vaccination',
#   'testing',
#   'this',
#   'problem',
#   'creation',
#   'putting',
#   'self',
#   'above',
#   'needs',
#   'country',
#   'vaccineswork',
#   'canada'],
#  ['following',
#   'nevada',
#   'mask',
#   'mandate',
#   'this',
#   'morning',
#   'followed',
#   'suit',
#   'nshe',
#   'employees',
#   'students',
#   'members',
#   'public',
#   'longer',
#   'required',
#   'wear',
#   'face',
#   'coverings',
#   'while',
#   'inside',
#   'nshe',
#   'buildings',
#   'irrespective',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'immediately'],
#  ['what',
#   'stake',
#   'applicants',
#   'here',
#   'forcible',
#   'vaccination',
#   'rather',
#   'consequences',
#   'choice',
#   'remain',
#   'unvaccinated'],
#  ['trading',
#   'players',
#   'that',
#   'injured',
#   'just',
#   'claim',
#   'injuries',
#   'report',
#   'like',
#   'firing',
#   'vaccinated',
#   'claiming',
#   'have',
#   'vaccination',
#   'rate'],
#  ['really',
#   'vaccination',
#   'lessons',
#   'syptoms',
#   'both',
#   'immediate',
#   'long',
#   'term',
#   'still',
#   'unlikely',
#   'will',
#   'serious',
#   'cause',
#   'long',
#   'term',
#   'damage',
#   'keep'],
#  ['member',
#   'public',
#   'health',
#   'professional',
#   'submit',
#   'suspected',
#   'side',
#   'effects',
#   'through',
#   'yellow',
#   'card',
#   'scheme',
#   'nature',
#   'yellow',
#   'card',
#   'reporting',
#   'means',
#   'that',
#   'reported',
#   'events',
#   'always',
#   'proven',
#   'side',
#   'effects',
#   'some',
#   'events',
#   'have',
#   'happened',
#   'anyway',
#   'regardless',
#   'vaccination'],
#  ['strange',
#   'that',
#   'people',
#   'claiming',
#   'that',
#   'they',
#   'want',
#   'stop',
#   'living',
#   'fear',
#   'causing',
#   'more',
#   'fear',
#   'than',
#   'mask',
#   'vaccination',
#   'ever',
#   'caused',
#   'being',
#   'held',
#   'hostage'],
#  ['kicking',
#   'night',
#   'superbowlmusicfest',
#   'with',
#   'special',
#   'guests',
#   'doors',
#   'limited',
#   'number',
#   'tickets',
#   'remain',
#   'guests',
#   'older',
#   'must',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'test',
#   'info'],
#  ['with',
#   'vaccination',
#   'rates',
#   'quite',
#   'twelve',
#   'range',
#   'more',
#   'thought',
#   'needed',
#   'benefits',
#   'risks',
#   'unmasked',
#   'indoor',
#   'instruction',
#   'glad',
#   'that',
#   'allows',
#   'unmasked',
#   'outdoor',
#   'activities',
#   'that',
#   'socal',
#   'weather',
#   'makes',
#   'easy',
#   'fresh'],
#  ['truly',
#   'feel',
#   'that',
#   'mentally',
#   'unstable',
#   'over',
#   'head',
#   'this',
#   'very',
#   'concerning',
#   'same',
#   'answer',
#   'time',
#   'after',
#   'time',
#   'ninety',
#   'vaccination'],
#  ['tend',
#   'slide',
#   'until',
#   'injure',
#   'myself',
#   'klutz',
#   'notices',
#   'been',
#   'awhile',
#   'since',
#   'they',
#   'quit',
#   'using',
#   'horse',
#   'serum',
#   'good',
#   'about',
#   'that',
#   'vaccination'],
#  ['since',
#   'september',
#   'required',
#   'everyone',
#   'years',
#   'older',
#   'wear',
#   'mask',
#   'indoors',
#   'regardless',
#   'their',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'beginning',
#   'after',
#   'presidents',
#   'that',
#   'will',
#   'longer',
#   'case'],
#  ['justified',
#   'frustrated',
#   'with',
#   'people',
#   'vaccine',
#   'there',
#   'jobs',
#   'where',
#   'fair',
#   'require',
#   'vaccination',
#   'remain',
#   'employed',
#   'really',
#   'going',
#   'starve',
#   'them'],
#  ['biden',
#   'administration',
#   'adopted',
#   'recommendation',
#   'make',
#   'health',
#   'care',
#   'worker',
#   'vaccination',
#   'condition',
#   'medicare',
#   'medicaid',
#   'funds',
#   'scotus',
#   'upheld',
#   'this',
#   'rule',
#   'which',
#   'important',
#   'patient',
#   'safety'],
#  ['required',
#   'preregistration',
#   'open',
#   'meadville',
#   'medical',
#   'center',
#   'next',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'eighteen',
#   'water',
#   'clinic',
#   'pfizer',
#   'vaccine',
#   'only'],
#  ['prevention',
#   'long',
#   'term',
#   'involves',
#   'vaccination',
#   'masks',
#   'reduce',
#   'speaks',
#   'either',
#   'vaccination',
#   'masks',
#   'real',
#   'going',
#   'beat',
#   'this',
#   'covid',
#   'shots',
#   'year',
#   'going',
#   'forward',
#   'difference',
#   'this',
#   'virus',
#   'higher',
#   'kill',
#   'rate'],
#  ['that',
#   'seems',
#   'more',
#   'reasonable',
#   'will',
#   'yield',
#   'more',
#   'positive',
#   'results',
#   'than',
#   'just',
#   'rescinding',
#   'vaccination',
#   'mandates',
#   'letting',
#   'people',
#   'make',
#   'their',
#   'decisions'],
#  ['come',
#   'come',
#   'allstar',
#   'valencia',
#   'angeles',
#   'free',
#   'produce',
#   'testing',
#   'vaccination'],
#  ['this',
#   'absurd',
#   'please',
#   'take',
#   'look',
#   'mirror',
#   'your',
#   'fellow',
#   'conservatives',
#   'have',
#   'been',
#   'expressly',
#   'supporting',
#   'blockade',
#   'main',
#   'culprit',
#   'inflamed',
#   'rhetoric',
#   'calling',
#   'vaccination',
#   'respect',
#   'public',
#   'health',
#   'orders'],
#  ['fans',
#   'receive',
#   'their',
#   'booster',
#   'dose',
#   'covid',
#   'vaccine',
#   'super',
#   'bowl',
#   'experience',
#   'receive',
#   'free',
#   'tickets',
#   'enter',
#   'experience',
#   'that',
#   'future',
#   'date',
#   'sure',
#   'visit',
#   'vaccination',
#   'site',
#   'south',
#   'hall',
#   'there',
#   'superbowlexperience',
#   'sblvi'],
#  ['that',
#   'unease',
#   'part',
#   'pass',
#   'adults',
#   'make',
#   'their',
#   'choices',
#   'suffer',
#   'their',
#   'consequences',
#   'deal',
#   'with',
#   'vaccination',
#   'rates',
#   'five',
#   'eleven',
#   'least',
#   'twelve',
#   'seventeen',
#   'over',
#   'fifty'],
#  ['physical', 'vaccination', 'card', 'gross', 'digital', 'thanks'],
#  ['allied',
#   'universal',
#   'looking',
#   'hire',
#   'phenomenal',
#   'security',
#   'site',
#   'supervisor',
#   'unarmed',
#   'vaccination',
#   'required',
#   'vegas',
#   'join',
#   'diverse',
#   'team',
#   'hiringphenomenaltalent',
#   'security'],
#  ['especially',
#   'vehicle',
#   'towed',
#   'they',
#   'allowed',
#   'cross',
#   'border',
#   'because',
#   'wait',
#   'requires',
#   'proof',
#   'vaccination',
#   'cross',
#   'into'],
#  ['links',
#   'papers',
#   'within',
#   'article',
#   'paper',
#   'emphasizes',
#   'dangers',
#   'harms',
#   'mandatory',
#   'covid',
#   'vaccination',
#   'policy'],
#  ['same', 'forced', 'vaccination'],
#  ['this',
#   'myocarditis',
#   'foundation',
#   'website',
#   'known',
#   'potential',
#   'benefits',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'outweigh',
#   'known',
#   'potential',
#   'risks',
#   'including',
#   'possible',
#   'risks',
#   'myocarditis',
#   'pericarditis'],
#  ['politicians',
#   'across',
#   'country',
#   'continue',
#   'infringe',
#   'personal',
#   'liberties',
#   'under',
#   'guise',
#   'public',
#   'safety',
#   'today',
#   'filed',
#   'lawsuit',
#   'against',
#   'city',
#   'chicago',
#   'cook',
#   'county',
#   'illegal',
#   'diskriminatory',
#   'proof',
#   'vaccination',
#   'requirements'],
#  ['governors',
#   'control',
#   'lockdowns',
#   'they',
#   'started',
#   'long',
#   'before',
#   'biden',
#   'biden',
#   'opened',
#   'things',
#   'with',
#   'vaccination',
#   'program',
#   'sure',
#   'tracking',
#   'right',
#   'trump',
#   'spent',
#   'more',
#   'than',
#   'biden',
#   'that',
#   'failed',
#   'increase',
#   'rates',
#   'during',
#   'presidency'],
#  ['talking', 'about', 'covid', 'vaccination'],
#  ['regulation', 'size', 'three', 'point', 'line', 'vaccination', 'mandate'],
#  ['monday',
#   'proof',
#   'vaccination',
#   'negative',
#   'covid',
#   'nineteen',
#   'test',
#   'will',
#   'longer',
#   'required',
#   'staff',
#   'visitors',
#   'saskatoon',
#   'public',
#   'schools'],
#  ['amoa',
#   'resort',
#   'activated',
#   'covid',
#   'nineteen',
#   'protocols',
#   'will',
#   'welcome',
#   'guests',
#   'strictly',
#   'observes',
#   'social',
#   'distancing',
#   'face',
#   'masks',
#   'wearing',
#   'enforce',
#   'vaccination',
#   'cards',
#   'only',
#   'entry'],
#  ['centenary',
#   'hospital',
#   'scarborough',
#   'dose',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['health',
#   'emergency',
#   'force',
#   'that',
#   'gives',
#   'quebec',
#   'sweeping',
#   'powers',
#   'legault',
#   'said',
#   'will',
#   'dropped',
#   'after',
#   'national',
#   'assembly',
#   'adopts',
#   'legislation',
#   'specifying',
#   'which',
#   'measures',
#   'maintained',
#   'such',
#   'vaccination',
#   'passport',
#   'legaultmustresign',
#   'legault'],
#  ['ability',
#   'always',
#   'free',
#   'restrictions',
#   'after',
#   'vaccination',
#   'that',
#   'supposed',
#   'point',
#   'mandates',
#   'that',
#   'trust',
#   'broken',
#   'when',
#   'closed',
#   'businesses',
#   'again',
#   'able',
#   'restaurants',
#   'there',
#   'guarantee',
#   'will',
#   'april'],
#  ['genuinely',
#   'curious',
#   'find',
#   'clip',
#   'quote',
#   'trump',
#   'telling',
#   'base',
#   'anyone',
#   'anything',
#   'remotely',
#   'anti',
#   'vaccine',
#   'everything',
#   'said',
#   'what',
#   'seen',
#   'been',
#   'extremely',
#   'vaccination',
#   'maybe',
#   'have',
#   'other',
#   'sources',
#   'could',
#   'cite'],
#  ['swastikas',
#   'displayed',
#   'canadian',
#   'freedom',
#   'convoy',
#   'protests',
#   'against',
#   'vaccination',
#   'mandates'],
#  ['that',
#   'treatment',
#   'vaccine',
#   'obviously',
#   'natural',
#   'immunity',
#   'definition',
#   'know',
#   'what',
#   'your',
#   'original',
#   'response',
#   'said',
#   'right',
#   'know',
#   'vaccination',
#   'occurs',
#   'prior',
#   'illness',
#   'during',
#   'illness',
#   'right'],
#  ['covid',
#   'vaccination',
#   'does',
#   'prevent',
#   'spread',
#   'stop',
#   'with',
#   'disinformation'],
#  ['absolutely',
#   'since',
#   'live',
#   'ohio',
#   'county',
#   'with',
#   'lowest',
#   'vaccination',
#   'rates'],
#  ['hrig',
#   'very',
#   'thick',
#   'yogurt',
#   'like',
#   'substance',
#   'will',
#   'feel',
#   'that',
#   'vaccination',
#   'clearly',
#   'tell',
#   'apart',
#   'normal',
#   'rabies',
#   'when',
#   'bitten',
#   'they',
#   'forgot',
#   'administer',
#   'that',
#   'must',
#   'really',
#   'rabies',
#   'vaccine',
#   'effective',
#   'post',
#   'trauma'],
#  ['meanwhile',
#   'more',
#   'death',
#   'threats',
#   'against',
#   'superintendent',
#   'upheaval',
#   'littleton',
#   'public',
#   'schools',
#   'over',
#   'vaccination',
#   'localnews'],
#  ['when',
#   'proof',
#   'vaccination',
#   'gets',
#   'lifted',
#   'elderly',
#   'will',
#   'then',
#   'forced',
#   'isolate',
#   'protect',
#   'themselves'],
#  ['appeals',
#   'court',
#   'will',
#   'block',
#   'order',
#   'barring',
#   'biden',
#   'federal',
#   'staff',
#   'vaccination',
#   'mandate',
#   'newsbreak'],
#  ['agreed',
#   'suspect',
#   'european',
#   'countries',
#   'have',
#   'higher',
#   'uptake',
#   'part',
#   'because',
#   'they',
#   'honored',
#   'recovery',
#   'previously',
#   'infected',
#   'individuals',
#   'adjusted',
#   'their',
#   'vaccination',
#   'recommendations',
#   'result'],
#  ['against',
#   'mandatory',
#   'mumps',
#   'measles',
#   'rubella',
#   'vaccination',
#   'just',
#   'fake',
#   'outrage',
#   'this',
#   'particular',
#   'vaccine'],
#  ['divorce', 'rates', 'rise', 'vaccination', 'adds', 'stress', 'parenting'],
#  ['vaccination', 'away', 'being', 'special'],
#  ['that',
#   'sucks',
#   'schools',
#   'marin',
#   'mass',
#   'vaccination',
#   'days',
#   'with',
#   'support',
#   'dogs',
#   'pretty',
#   'much',
#   'every',
#   'school',
#   'district',
#   'twenty',
#   'minutes'],
#  ['keep', 'some', 'vaccination', 'clinics', 'that', 'opening', 'sign', 'gcms'],
#  ['fair',
#   'some',
#   'parents',
#   'haven',
#   'much',
#   'mass',
#   'vaccination',
#   'infrastructure',
#   'grownups',
#   'when',
#   'vaxxed',
#   'easy',
#   'hell',
#   'barely',
#   'twenty',
#   'minutes',
#   'including',
#   'fifteen',
#   'observation',
#   'kids',
#   'second',
#   'dose',
#   'hours',
#   'waiting',
#   'damp',
#   'cold'],
#  ['would',
#   'list',
#   'nominees',
#   'would',
#   'been',
#   'blacklisted',
#   'oscars',
#   'academy',
#   'hadn',
#   'blinked',
#   'vaccination',
#   'requirements',
#   'imagine',
#   'meltdown',
#   'twitter',
#   'would',
#   'wags',
#   'weighted',
#   'much',
#   'they',
#   'liked',
#   'movie',
#   'based',
#   'their',
#   'shots'],
#  ['saying',
#   'stopping',
#   'vaccination',
#   'ending',
#   'your',
#   'inquiry',
#   'there',
#   'arbitrary',
#   'european',
#   'union',
#   'allows',
#   'titers',
#   'negative',
#   'tests',
#   'their',
#   'pass',
#   'system'],
#  ['councilman',
#   'vaccinated',
#   'said',
#   'peoples',
#   'champ',
#   'vaccination',
#   'rates',
#   'continuing',
#   'your',
#   'district',
#   'leader',
#   'help',
#   'return',
#   'normal',
#   'especially',
#   'given',
#   'tweet',
#   'deleted',
#   'about',
#   'restaurants'],
#  ['having',
#   'government',
#   'offer',
#   'free',
#   'vaccine',
#   'that',
#   'helps',
#   'boost',
#   'immune',
#   'system',
#   'having',
#   'some',
#   'places',
#   'mostly',
#   'private',
#   'businesses',
#   'government',
#   'mandates',
#   'need',
#   'show',
#   'proof',
#   'vaccination',
#   'negative',
#   'test',
#   'doesn',
#   'feel',
#   'like',
#   'oppression'],
#  ['saying',
#   'memory',
#   'cells',
#   'remember',
#   'things',
#   'terms',
#   'things',
#   'like',
#   'spike',
#   'proteins',
#   'depends',
#   'disease',
#   'vaccination',
#   'example',
#   'hepatitis',
#   'vaccine',
#   'mainly',
#   'based',
#   'surface',
#   'protein'],
#  ['cares',
#   'what',
#   'these',
#   'people',
#   'personally',
#   'fact',
#   'couldn',
#   'possibly',
#   'care',
#   'less',
#   'should',
#   'anyone',
#   'care',
#   'they',
#   'shown',
#   'exactly',
#   'they',
#   'what',
#   'they',
#   'think',
#   'simply',
#   'agree',
#   'them',
#   'forced',
#   'vaccination',
#   'care'],
#  ['wish',
#   'everyone',
#   'vaccinated',
#   'mandatory',
#   'vaccination',
#   'measure',
#   'based',
#   'science'],
#  ['hope',
#   'ontario',
#   'drops',
#   'this',
#   'proof',
#   'vaccination',
#   'soon',
#   'cause',
#   'bring',
#   'much',
#   'unnecessary',
#   'conflicts',
#   'workers',
#   'especially',
#   'when',
#   'they',
#   'wanna',
#   'change',
#   'type',
#   'vacation',
#   'proof',
#   'dime'],
#  ['tyrannical',
#   'biden',
#   'administration',
#   'wants',
#   'mandatory',
#   'vaccination',
#   'protestors',
#   'canada',
#   'crushed',
#   'beneath',
#   'grinding',
#   'wheels',
#   'federal',
#   'authority'],
#  ['since',
#   'then',
#   'covid',
#   'hospitalizations',
#   'denmark',
#   'have',
#   'also',
#   'been',
#   'ticking',
#   'upwards',
#   'despite',
#   'highest',
#   'booster',
#   'vaccination',
#   'rate',
#   'europe',
#   'please',
#   'take',
#   'look',
#   'hospitalizations',
#   'chart',
#   'below',
#   'world',
#   'data'],
#  ['love',
#   'mental',
#   'gymnastics',
#   'have',
#   'perform',
#   'argue',
#   'protesting',
#   'vaccination',
#   'akin',
#   'protesting',
#   'police',
#   'brutality',
#   'against',
#   'minorities'],
#  ['defundcbc',
#   'defundbbc',
#   'unfortunately',
#   'very',
#   'behind',
#   'this',
#   'vaccination',
#   'extravaganza',
#   'same',
#   'funding',
#   'these',
#   'news',
#   'networks',
#   'just',
#   'sayin',
#   'totally',
#   'with',
#   'though',
#   'funds',
#   'coming',
#   'baddies'],
#  ['broadway',
#   'mask',
#   'vaccination',
#   'requirement',
#   'remains',
#   'through',
#   'april',
#   'thirty'],
#  ['super',
#   'immunity',
#   'fake',
#   'covid',
#   'times',
#   'fact',
#   'therapist',
#   'covid',
#   'three',
#   'times',
#   'vaccination',
#   'less',
#   'health',
#   'risks',
#   'than',
#   'getting',
#   'covid',
#   'going',
#   'kill',
#   'people',
#   'attacking',
#   'proven',
#   'technology'],
#  ['jeffrey',
#   'morris',
#   'they',
#   'also',
#   'have',
#   'population',
#   'number',
#   'each',
#   'vaccinated',
#   'status',
#   'each',
#   'group',
#   'each',
#   'week',
#   'that',
#   'used',
#   'compute',
#   'standardized',
#   'death',
#   'rates',
#   'well',
#   'track',
#   'proportion',
#   'that',
#   'group',
#   'each',
#   'vaccination',
#   'status',
#   'over',
#   'time'],
#  ['school',
#   'vaccination',
#   'going',
#   'very',
#   'well',
#   'kids',
#   'schools',
#   'right',
#   'around',
#   'wrong',
#   'with',
#   'parents'],
#  ['still',
#   'mask',
#   'social',
#   'distance',
#   'through',
#   'vaccination',
#   'booster',
#   'yeah',
#   'smart'],
#  ['besides',
#   'fact',
#   'that',
#   'even',
#   'there',
#   'mandate',
#   'canada',
#   'that',
#   'just',
#   'means',
#   'only',
#   'those',
#   'entering',
#   'other',
#   'countries',
#   'needed',
#   'follow',
#   'show',
#   'proof',
#   'vaccination',
#   'negative',
#   'test',
#   'quarantine',
#   'what',
#   'point',
#   'when',
#   'leave',
#   'country',
#   'without',
#   'that',
#   'proof'],
#  ['here',
#   'hockey',
#   'harlem',
#   'supporting',
#   'vaccination',
#   'program',
#   'when',
#   'elected',
#   'house',
#   'will',
#   'make',
#   'sure',
#   'become',
#   'famous',
#   'capitol',
#   'hill',
#   'because',
#   'your',
#   'voice',
#   'matter',
#   'godblessamerica',
#   'nonads'],
#  ['twelve',
#   'area',
#   'counties',
#   'santa',
#   'clara',
#   'highest',
#   'vaccination',
#   'rate',
#   'their',
#   'case',
#   'rate',
#   'ranks',
#   'holds',
#   'santa',
#   'clara',
#   'leadership',
#   'accountable'],
#  ['mandates',
#   'help',
#   'increase',
#   'vaccination',
#   'rates',
#   'they',
#   'prevent',
#   'future',
#   'restrictions',
#   'appreciate',
#   'your',
#   'overall',
#   'tone',
#   'this',
#   'thread',
#   'disagree',
#   'here',
#   'mandates',
#   'should',
#   'done',
#   'attempt',
#   'coerce',
#   'while',
#   'producing',
#   'collateral',
#   'damage',
#   'elsewhere',
#   'accept',
#   'some',
#   'compliance'],
#  ['that',
#   'last',
#   'answer',
#   'apparently',
#   'haven',
#   'been',
#   'keeping',
#   'mrna',
#   'vaccination',
#   'stimulates',
#   'robust',
#   'containing',
#   'vaccine',
#   'mrna',
#   'spike',
#   'antigen',
#   'eight',
#   'weeks',
#   'postvaccination',
#   'some',
#   'cases'],
#  ['meanwhile',
#   'government',
#   'using',
#   'kids',
#   'shields',
#   'with',
#   'unneccessary',
#   'vaccination',
#   'face',
#   'masks',
#   'schools'],
#  ['since',
#   'there',
#   'ninety',
#   'vaccination',
#   'rate',
#   'super',
#   'majority',
#   'people',
#   'supporting',
#   'federal',
#   'government',
#   'pandemic',
#   'plan',
#   'some',
#   'dummies',
#   'refer',
#   'conspiracy',
#   'theories',
#   'vaccinated'],
#  ['paper',
#   'states',
#   'free',
#   'floating',
#   'spike',
#   'proteins',
#   'circulate',
#   'high',
#   'levels',
#   'blood',
#   'after',
#   'vaccination',
#   'vaccinated',
#   'people',
#   'infected',
#   'with',
#   'variants',
#   'covid',
#   'produce',
#   'antibodies',
#   'biased',
#   'toward',
#   'original',
#   'extinct',
#   'variant',
#   'rather',
#   'than',
#   'that',
#   'actually',
#   'infected',
#   'them'],
#  ['sounds',
#   'like',
#   'might',
#   'asking',
#   'immigration',
#   'related',
#   'question',
#   'which',
#   'aren',
#   'qualified',
#   'answer',
#   'sorry',
#   'about',
#   'that',
#   'asking',
#   'meet',
#   'health',
#   'safety',
#   'requirements',
#   'long',
#   'wear',
#   'mask',
#   'provide',
#   'vaccination',
#   'record'],
#  ['what',
#   'that',
#   'incorrect',
#   'terrorists',
#   'causing',
#   'more',
#   'issues',
#   'closures',
#   'supply',
#   'chain',
#   'issues',
#   'than',
#   'restrictions',
#   'vaccination',
#   'only',
#   'this',
#   'period'],
#  ['once',
#   'extended',
#   'vaccine',
#   'isolation',
#   'think',
#   'know',
#   'what',
#   'need',
#   'fentanyl',
#   'death',
#   'oneself',
#   'loved',
#   'ones',
#   'causes',
#   'more',
#   'psychological',
#   'stress',
#   'than',
#   'having',
#   'wear',
#   'damn',
#   'mask',
#   'show',
#   'proof',
#   'vaccination',
#   'babies'],
#  ['would',
#   'triple',
#   'vaccinated',
#   'person',
#   'living',
#   'county',
#   'with',
#   'vaccination',
#   'rate',
#   'where',
#   'mask'],
#  ['about',
#   'half',
#   'adults',
#   'hospitalized',
#   'with',
#   'have',
#   'heart',
#   'disease',
#   'vaccination',
#   'especially',
#   'important',
#   'people',
#   'with',
#   'heart',
#   'disease',
#   'because',
#   'they',
#   'higher',
#   'risk',
#   'serious',
#   'complications',
#   'protect',
#   'yourself',
#   'fightflu',
#   'this',
#   'heartmonth'],
#  ['nowplaying',
#   'show',
#   'vaccination',
#   'misinformation',
#   'show',
#   'zero',
#   'nowspinning',
#   'nowstreaming',
#   'hear',
#   'subgenius',
#   'radio',
#   'times',
#   'joerogan',
#   'antivaxxers',
#   'full',
#   'details'],
#  ['enforced',
#   'like',
#   'parking',
#   'tickets',
#   'spot',
#   'checks',
#   'bylaw',
#   'officers',
#   'protecting',
#   'businesses',
#   'that',
#   'check',
#   'vaccination',
#   'includes',
#   'shots'],
#  ['biden',
#   'giving',
#   'crack',
#   'pipes',
#   'long',
#   'show',
#   'proof',
#   'vaccination',
#   'lmfaoooo',
#   'this',
#   'yesterday',
#   'thought',
#   'fake',
#   'literal',
#   'hell'],
#  ['hope',
#   'recieving',
#   'treatment',
#   'problems',
#   'with',
#   'immunity',
#   'system',
#   'like',
#   'people',
#   'have',
#   'many',
#   'vaccination',
#   'some',
#   'cases',
#   'natural',
#   'immunity',
#   'have',
#   'weakened',
#   'check',
#   'reports',
#   'israel'],
#  ['reminder',
#   'offering',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'students',
#   'staff',
#   'families',
#   'community',
#   'tomorrow',
#   'covid',
#   'nineteen',
#   'testing',
#   'clinic',
#   'students',
#   'staff',
#   'scheduled',
#   'saturday',
#   'twelve',
#   'details',
#   'both',
#   'events',
#   'district',
#   'website',
#   'here'],
#  ['this',
#   'stunning',
#   'want',
#   'treat',
#   'just',
#   'another',
#   'know',
#   'zero',
#   'plus',
#   'americans',
#   'died',
#   'last',
#   'month',
#   'that',
#   'more',
#   'than',
#   'last',
#   'three',
#   'years',
#   'have',
#   'died',
#   'complications',
#   'want',
#   'find',
#   'rather',
#   'have',
#   'done',
#   'vaccination'],
#  ['watch', 'does', 'trudeau', 'want', 'vaccination', 'rate', 'youtube'],
#  ['that',
#   'eighty',
#   'ninety',
#   'vaccinated',
#   'respectively',
#   'does',
#   'mean',
#   'they',
#   'mandate',
#   'vaccination',
#   'masks',
#   'some',
#   'myself',
#   'included',
#   'understand',
#   'that',
#   'vaccines',
#   'highly',
#   'beneficial',
#   'almost',
#   'that',
#   'doesn',
#   'give',
#   'right',
#   'deprive',
#   'anyone',
#   'their',
#   'rights'],
#  ['things',
#   'heard',
#   'today',
#   'person',
#   'leave',
#   'because',
#   'they',
#   'questions',
#   'about',
#   'need',
#   'booster',
#   'side',
#   'effects',
#   'first',
#   'doses',
#   'covid',
#   'recovered',
#   'person',
#   'losing',
#   'client',
#   'contracts',
#   'because',
#   'they',
#   'wish',
#   'wait',
#   'consider',
#   'vaccination',
#   'because',
#   'some',
#   'health',
#   'concerns'],
#  ['have',
#   'human',
#   'rights',
#   'commission',
#   'maybe',
#   'time',
#   'have',
#   'health',
#   'rights',
#   'commission',
#   'diskrimination',
#   'wrong',
#   'whether',
#   'based',
#   'color',
#   'religion',
#   'universal',
#   'health',
#   'system',
#   'doesn',
#   'diskriminate',
#   'against',
#   'anyone',
#   'should',
#   'with',
#   'vaccination',
#   'injection'],
#  ['support',
#   'right',
#   'turn',
#   'down',
#   'vaccination',
#   'what',
#   'saying',
#   'doesn',
#   'make',
#   'sense',
#   'like',
#   'saying',
#   'wasn',
#   'choice',
#   'evicted',
#   'just',
#   'didn',
#   'want',
#   'rent'],
#  ['talk',
#   'about',
#   'khalistani',
#   'issues',
#   'there',
#   'were',
#   'open',
#   'threats',
#   'during',
#   'tiranga',
#   'yatra',
#   'babbar',
#   'khalsa',
#   'police',
#   'australian',
#   'states',
#   'have',
#   'mostly',
#   'been',
#   'such',
#   'groups',
#   'democracy',
#   'australia',
#   'enforced',
#   'vaccination',
#   'kids',
#   'even',
#   'leave',
#   'country'],
#  ['covidab',
#   'impacts',
#   'have',
#   'evolved',
#   'must',
#   'metrics',
#   'used',
#   'guide',
#   'policy',
#   'rates',
#   'down',
#   'hospitalizations',
#   'remain',
#   'community',
#   'spread',
#   'remains',
#   'absenteeism',
#   'remains',
#   'this',
#   'nowhere',
#   'near',
#   'over',
#   'repnotrip',
#   'ableg'],
#  ['weirdos',
#   'going',
#   'around',
#   'francisco',
#   'bars',
#   'restaurants',
#   'filling',
#   'these',
#   'notice',
#   'civil',
#   'rights',
#   'violations',
#   'asking',
#   'proof',
#   'vaccination'],
#  ['with',
#   'exception',
#   'vaccination',
#   'worst',
#   'since',
#   'beginning',
#   'death',
#   'patient',
#   'ambulance',
#   'icing',
#   'incompetence',
#   'quickly',
#   'investigation',
#   'household',
#   'imposed',
#   'management',
#   'unacceptable'],
#  ['only',
#   'some',
#   'members',
#   'band',
#   'were',
#   'still',
#   'alive',
#   'tell',
#   'what',
#   'they',
#   'think',
#   'vaccination',
#   'wait',
#   'minute'],
#  ['winter',
#   'break',
#   'teen',
#   'arts',
#   'project',
#   'eight',
#   'four',
#   'county',
#   'players',
#   'barborsville',
#   'fifteen',
#   'masks',
#   'required',
#   'regardless',
#   'vaccination',
#   'status'],
#  ['million',
#   'quebecers',
#   'have',
#   'caught',
#   'covid',
#   'since',
#   'december',
#   'four',
#   'million',
#   'since',
#   'march',
#   'there',
#   'only',
#   'three',
#   'million',
#   'vaccination',
#   'solution',
#   'reduce',
#   'contagion'],
#  ['since',
#   'this',
#   'latest',
#   'flip',
#   'flop',
#   'rather',
#   'sudden',
#   'have',
#   'question',
#   'airlines',
#   'still',
#   'requesting',
#   'proof',
#   'vaccination',
#   'some',
#   'international',
#   'destinations',
#   'still',
#   'requiring',
#   'proof',
#   'vaccination'],
#  ['mitigation', 'mean', 'vaccination'],
#  ['then',
#   'question',
#   'they',
#   'enter',
#   'first',
#   'place',
#   'given',
#   'requires',
#   'proof',
#   'vaccination',
#   'entry'],
#  ['made',
#   'intentions',
#   'known',
#   'tues',
#   'announced',
#   'dramatic',
#   'drops',
#   'covid',
#   'cases',
#   'county',
#   'vaccination',
#   'rate',
#   'stop',
#   'state',
#   'interference',
#   'county',
#   'education',
#   'four',
#   'died',
#   'yesterday',
#   'twelve'],
#  ['vaccination',
#   'campaign',
#   'quebec',
#   'asks',
#   'doctors',
#   'return',
#   'their',
#   'regular',
#   'activities'],
#  ['feel',
#   'like',
#   'people',
#   'pissed',
#   'about',
#   'employer',
#   'vaccination',
#   'mandates',
#   'which',
#   'thought',
#   'politically',
#   'dangerous'],
#  ['with',
#   'vaccines',
#   'stop',
#   'them',
#   'meseals',
#   'vaccination',
#   'rate',
#   'canada'],
#  ['know',
#   'that',
#   'only',
#   'boys',
#   'shower',
#   'eighty',
#   'vaccination',
#   'rates',
#   'with',
#   'science'],
#  ['there',
#   'nothing',
#   'here',
#   'comrade',
#   'singh',
#   'told',
#   'directly',
#   'presser',
#   'today',
#   'that',
#   'there',
#   'political',
#   'alignment',
#   'vaccination',
#   'issue',
#   'explain',
#   'that',
#   'everyday',
#   'covid',
#   'cabal',
#   'real',
#   'mybodymychoice',
#   'falls',
#   'deaf',
#   'ears'],
#  ['live',
#   'mercer',
#   'county',
#   'ohio',
#   'vaccination',
#   'rate',
#   'here',
#   'even',
#   'forty',
#   'percent',
#   'continue',
#   'avoiding',
#   'indoor',
#   'spaces',
#   'masking',
#   'when',
#   'running',
#   'errands',
#   'took',
#   'early',
#   'early',
#   'retirement',
#   'hubby',
#   'been',
#   'retired',
#   'several',
#   'years',
#   'refuse',
#   'play',
#   'long',
#   'want'],
#  ['gotta',
#   'love',
#   'fact',
#   'that',
#   'taking',
#   'away',
#   'business',
#   'option',
#   'continue',
#   'check',
#   'vaccination',
#   'status',
#   'they',
#   'want',
#   'thought',
#   'this',
#   'about',
#   'choice',
#   'choice',
#   'vaccinated',
#   'choice',
#   'allow',
#   'your',
#   'business',
#   'abpoli'],
#  ['look',
#   'bright',
#   'side',
#   'with',
#   'fiorellas',
#   'fans',
#   'feel',
#   'about',
#   'vaccination',
#   'able',
#   'ratio',
#   'much',
#   'longer'],
#  ['only',
#   'rates',
#   'masking',
#   'your',
#   'definition',
#   'fully',
#   'includes',
#   'having',
#   'your',
#   'booster',
#   'know',
#   'immunity',
#   'wanes',
#   'only',
#   'infection',
#   'also',
#   'wanes',
#   'severe',
#   'disease',
#   'hospitalization',
#   'death',
#   'masking',
#   'policy',
#   'dose',
#   'vaccination'],
#  ['this',
#   'very',
#   'memory',
#   'holed',
#   'analysis',
#   'every',
#   'state',
#   'elderly',
#   'were',
#   'prioritized',
#   'vaccination',
#   'people',
#   'under',
#   'couldn',
#   'access',
#   'vaccine',
#   'months'],
#  ['nothing',
#   'like',
#   'election',
#   'provide',
#   'accurate',
#   'definition',
#   'fully',
#   'vaxd',
#   'unless',
#   'tourist',
#   'mandate',
#   'vaccination',
#   'aged',
#   'care',
#   'about',
#   'time'],
#  ['thankyoukyrie',
#   'standing',
#   'firm',
#   'your',
#   'vaccination',
#   'beliefs',
#   'driving',
#   'james',
#   'sixers',
#   'three'],
#  ['craig',
#   'approved',
#   'recognized',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'while',
#   'overseas',
#   'have',
#   'recorded',
#   'australian',
#   'immunization',
#   'register',
#   'when',
#   'australia',
#   'find',
#   'more',
#   'information',
#   'about',
#   'this',
#   'website'],
#  ['everything',
#   'public',
#   'health',
#   'everybody',
#   'masking',
#   'better',
#   'ventilation',
#   'vaccination',
#   'reduces',
#   'amount',
#   'virus',
#   'chances',
#   'being',
#   'infected',
#   'sorry',
#   'amanda',
#   'hope',
#   'your'],
#  ['tucson',
#   'electric',
#   'power',
#   'other',
#   'state',
#   'regulated',
#   'utilities',
#   'they',
#   'have',
#   'plans',
#   'mandate',
#   'vaccination',
#   'testing',
#   'beyond',
#   'current',
#   'workplace',
#   'safety',
#   'protocols'],
#  ['montagnier',
#   'clear',
#   'that',
#   'variants',
#   'created',
#   'antibody',
#   'mediated',
#   'selection',
#   'vaccination',
#   'this',
#   'yesterday',
#   'montagnier'],
#  ['will',
#   'chat',
#   'with',
#   'about',
#   'memoir',
#   'sunday',
#   'february',
#   'almost',
#   'romance',
#   'details',
#   'friends',
#   'turned',
#   'year',
#   'almost',
#   'romance',
#   'into',
#   'real',
#   'tickets',
#   'book',
#   'must',
#   'have',
#   'proof',
#   'vaccination',
#   'mask'],
#  ['possible',
#   'businesses',
#   'have',
#   'proof',
#   'vaccination',
#   'without',
#   'code',
#   'copping',
#   'says',
#   'those',
#   'already',
#   'have',
#   'still',
#   'businesses',
#   'still',
#   'printed',
#   'proof',
#   'vaccination',
#   'well'],
#  ['just',
#   'thought',
#   'people',
#   'there',
#   'with',
#   'herpes',
#   'infections',
#   'many',
#   'them',
#   'have',
#   'recurrences',
#   'after',
#   'vaccination',
#   'didn',
#   'make',
#   'possible',
#   'connection',
#   'estimated',
#   'that',
#   'there',
#   'were',
#   'zero',
#   'genital',
#   'herpes',
#   'infections',
#   'united',
#   'states',
#   'single',
#   'year'],
#  ['they',
#   'safer',
#   'than',
#   'aspirin',
#   'tylenol',
#   'travel',
#   'cross',
#   'state',
#   'borders',
#   'without',
#   'showing',
#   'vaccination',
#   'card',
#   'business',
#   'doesn',
#   'want',
#   'serve',
#   'hire',
#   'that',
#   'their',
#   'right',
#   'this',
#   'comparison',
#   'makes',
#   'sense'],
#  ['this',
#   'girl',
#   'selling',
#   'cards',
#   'facebook',
#   'week',
#   'later',
#   'just',
#   'realized',
#   'that',
#   'means',
#   'vaccination',
#   'cards',
#   'valentine',
#   'cards'],
#  ['myocarditis',
#   'rare',
#   'side',
#   'effect',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'made',
#   'headlines',
#   'pediatric',
#   'cardiologist',
#   'explains',
#   'coronavirus',
#   'infection',
#   'poses',
#   'much',
#   'much',
#   'greater',
#   'danger'],
#  ['myocarditis',
#   'rare',
#   'side',
#   'effect',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'made',
#   'headlines',
#   'pediatric',
#   'cardiologist',
#   'hospital',
#   'explains',
#   'coronavirus',
#   'infection',
#   'poses',
#   'much',
#   'much',
#   'greater',
#   'danger'],
#  ['heart',
#   'transplant',
#   'denied',
#   'vaccination',
#   'status',
#   'arthur',
#   'caplan',
#   'bioethics',
#   'drew'],
#  ['supported',
#   'indonesia',
#   'with',
#   'billion',
#   'emergency',
#   'financing',
#   'achieve',
#   'vaccination',
#   'targets',
#   'enhanced',
#   'response',
#   'capacity',
#   'seen',
#   'testing',
#   'labs',
#   'opened',
#   'thousands',
#   'isolation',
#   'critical',
#   'care',
#   'beds',
#   'being',
#   'added'],
#  ['free',
#   'tickets',
#   'super',
#   'bowl',
#   'experience',
#   'your',
#   'booster',
#   'dose',
#   'vaccination',
#   'clinic',
#   'south',
#   'hall',
#   'clinic',
#   'opens',
#   'doors',
#   'experience',
#   'opens',
#   'sblvi'],
#  ['fact',
#   'checkers',
#   'says',
#   'changed',
#   'definition',
#   'vaccination',
#   'increase',
#   'transparency',
#   'this',
#   'probably',
#   'first',
#   'time',
#   'history',
#   'that',
#   'definition',
#   'been',
#   'changed',
#   'this',
#   'reason',
#   'gave',
#   'right',
#   'change',
#   'meaning',
#   'words'],
#  ['world',
#   'photo',
#   'proof',
#   'full',
#   'vaccination',
#   'required',
#   'kingstonmines',
#   'details'],
#  ['taibu',
#   'community',
#   'health',
#   'center',
#   'scarborough',
#   'pediatric',
#   'dose',
#   'pfizer',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['taibu',
#   'community',
#   'health',
#   'center',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
# ...
#   'community',
#   'clinics',
#   'learn',
#   'more'],
#  ['tier',
#   'cruise',
#   'ships',
#   'vaccination',
#   'standard',
#   'excellence',
#   'requires',
#   'that',
#   'least',
#   'passengers',
#   'crew',
#   'date',
#   'with',
#   'covid',
#   'nineteen',
#   'vaccinations',
#   'including',
#   'booster',
#   'shots',
#   'depending',
#   'eligibility'],
#  ['anti',
#   'nurses',
#   'amityville',
#   'have',
#   'been',
#   'accused',
#   'forging',
#   'thousands',
#   'vaccination',
#   'cards',
#   'exchange',
#   'that',
#   'scary'],
#  ['covid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'connecticut',
#   'syringeat',
#   'least',
#   'dose',
#   'syringefully',
#   'syringeadditional',
#   'dose'],
#  ['about',
#   'virus',
#   'repeated',
#   'vaccination',
#   'that',
#   'induces',
#   'vaccinated',
#   'people'],
#  ['perhaps',
#   'pander',
#   'freedumbconvoy',
#   'base',
#   'unclear',
#   'whether',
#   'proof',
#   'vaccination',
#   'mandatory',
#   'masking',
#   'policies',
#   'would',
#   'dropped',
#   'well',
#   'province',
#   'provide',
#   'timeframe',
#   'when',
#   'those',
#   'measures',
#   'would',
#   'come'],
#  ['again',
#   'making',
#   'claim',
#   'that',
#   'there',
#   'have',
#   'been',
#   'events',
#   'four',
#   'months',
#   'more',
#   'after',
#   'vaccination',
#   'given',
#   'need',
#   'provide',
#   'evidence',
#   'that',
#   'such',
#   'example',
#   'exists',
#   'back',
#   'history',
#   'want',
#   'polio',
#   'tdap',
#   'vaccine',
#   'wait'],
#  ['well',
#   'found',
#   'lifting',
#   'vaccination',
#   'mandates',
#   'able',
#   'play',
#   'that',
#   'happens'],
#  ['please',
#   'continue',
#   'take',
#   'covid',
#   'nineteen',
#   'precautions',
#   'wearing',
#   'face',
#   'mask',
#   'maintaining',
#   'distance',
#   'others',
#   'getting',
#   'vaccinated',
#   'schedule',
#   'appointment',
#   'your',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'booster',
#   'call'],
#  ['hosting',
#   'free',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'eight',
#   'eleven',
#   'aebersold',
#   'student',
#   'recreation',
#   'center',
#   'register',
#   'here',
#   'specific',
#   'time',
#   'walk'],
#  ['have',
#   'lots',
#   'spots',
#   'available',
#   'vaccination',
#   'clinic',
#   'tomorrow',
#   'eleven',
#   'garcelon',
#   'civic',
#   'center',
#   'ststephen',
#   'book',
#   'between',
#   'eleven',
#   'seven',
#   'come',
#   'walk',
#   'between'],
#  ['monday',
#   'seven',
#   'chile',
#   'started',
#   'another',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'push',
#   'with',
#   'second',
#   'booster',
#   'dose',
#   'people',
#   'over',
#   'years',
#   'country',
#   'currently',
#   'going',
#   'through',
#   'wave',
#   'infections',
#   'with',
#   'daily',
#   'record',
#   'figures',
#   'over',
#   'thirty',
#   'zero',
#   'aldianews'],
#  ['justin',
#   'reply',
#   'every',
#   'question',
#   'last',
#   'weeks',
#   'canadians',
#   'have',
#   'stepped',
#   'following',
#   'science',
#   'three',
#   'vaccination',
#   'only',
#   'pandemic',
#   'four',
#   'have',
#   'canadians',
#   'back'],
#  ['weird',
#   'hippies',
#   'screamed',
#   'held',
#   'signs',
#   'stating',
#   'down',
#   'with',
#   'establishment',
#   'ones',
#   'their',
#   'seventy',
#   'begging',
#   'government',
#   'keep',
#   'masking',
#   'rules',
#   'vaccination',
#   'passports',
#   'lockdowns'],
#  ['justin',
#   'reply',
#   'canadians',
#   'have',
#   'stepped',
#   'following',
#   'science',
#   'three',
#   'vaccination',
#   'only',
#   'pandemic',
#   'four',
#   'have',
#   'canadians',
#   'back'],
#  ['know',
#   'enough',
#   'about',
#   'your',
#   'covid',
#   'vaccine',
#   'options',
#   'check',
#   'information',
#   'resources',
#   'vaccination',
#   'need',
#   'part',
#   'keeping',
#   'neighbors',
#   'safe',
#   'learn',
#   'more',
#   'today',
#   'getvaxxed'],
#  ['streets', 'vaccination'],
#  ['covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'open',
#   'couple',
#   'more',
#   'hours',
#   'runners',
#   'swing',
#   'denman',
#   'ballroom',
#   'student',
#   'union',
#   'vaxxed',
#   'syringe',
#   'utsa',
#   'doyourpart'],
#  ['children',
#   'higher',
#   'risk',
#   'covid',
#   'nineteen',
#   'today',
#   'than',
#   'they',
#   'were',
#   'early',
#   'pandemic',
#   'vaccination',
#   'help',
#   'protect',
#   'them',
#   'every',
#   'person',
#   'five',
#   'older',
#   'eligible',
#   'receive',
#   'covid',
#   'nineteen',
#   'vaccine',
#   'syringe',
#   'book',
#   'appointment'],
#  ['service',
#   'talks',
#   'bring',
#   'medicare',
#   'card',
#   'following',
#   'success',
#   'with',
#   'vaccination',
#   'certificates'],
#  ['even',
#   'though',
#   'surgical',
#   'masks',
#   'only',
#   'thirteen',
#   'effective',
#   'that',
#   'still',
#   'something',
#   'should',
#   'provided',
#   'what',
#   'your',
#   'point',
#   'until',
#   'like',
#   'ninety',
#   'vaccination',
#   'virus',
#   'will',
#   'still',
#   'mutate',
#   'reduction',
#   'transmission'],
#  ['biggest',
#   'night',
#   'comedy',
#   'finally',
#   'here',
#   'seven',
#   'doors',
#   'open',
#   'eight',
#   'show',
#   'begins',
#   'guests',
#   'older',
#   'must',
#   'provide',
#   'proof',
#   'full',
#   'vaccination',
#   'negative',
#   'test',
#   'visit',
#   'more',
#   'times',
#   'lineup',
#   'subject',
#   'change'],
#  ['except',
#   'many',
#   'businesses',
#   'including',
#   'retail',
#   'bars',
#   'restaurants',
#   'will',
#   'still',
#   'require',
#   'masks',
#   'proof',
#   'vaccination',
#   'their',
#   'freedom'],
#  ['highlights',
#   'five',
#   'cases',
#   'north',
#   'central',
#   'zone',
#   'highest',
#   'cases',
#   'thirty',
#   'outbreaks',
#   'confirmed',
#   'high',
#   'risk',
#   'settings',
#   'those',
#   'over',
#   'five',
#   'have',
#   'received',
#   'doses',
#   'vaccine',
#   'regina',
#   'area',
#   'with',
#   'highest',
#   'rate',
#   'vaccination',
#   'other',
#   'areas',
#   'below',
#   'eighty'],
#  ['film',
#   'academy',
#   'reportedly',
#   'require',
#   'proof',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'oscars'],
#  ['time', 'playoffs', 'start', 'there', 'vaccination', 'requirements'],
#  ['said',
#   'right',
#   'moment',
#   'benefit',
#   'omicron',
#   'seeming',
#   'mildness',
#   'country',
#   'high',
#   'vaccination',
#   'rate',
#   'percent',
#   'entire',
#   'population',
#   'been',
#   'fully',
#   'vaccinated',
#   'percent',
#   'have',
#   'received',
#   'additional',
#   'shot',
#   'denmark'],
#  ['what',
#   'mean',
#   'problem',
#   'they',
#   'choose',
#   'their',
#   'children',
#   'then',
#   'need',
#   'babysitter',
#   'maybe',
#   'their',
#   'kids',
#   'public',
#   'unvaccinated',
#   'woulf',
#   'spur',
#   'parents',
#   'choose',
#   'vaccination',
#   'which',
#   'optimal'],
#  ['since',
#   'here',
#   'reportedly',
#   'stopped',
#   'facilitating',
#   'payments',
#   'vaccination',
#   'control',
#   'group'],
#  ['what',
#   'happened',
#   'following',
#   'guidelines',
#   'what',
#   'cave',
#   'what',
#   'gonna',
#   'happen',
#   'when',
#   'rates',
#   'climb',
#   'again',
#   'cali',
#   'good',
#   'vaccination',
#   'rate',
#   'does',
#   'failed',
#   'this',
#   'state'],
#  ['couldn',
#   'even',
#   'answer',
#   'opposition',
#   'leader',
#   'question',
#   'during',
#   'debate',
#   'questioning',
#   'about',
#   'much',
#   'vaccination',
#   'rate',
#   'enough',
#   'before',
#   'these',
#   'mandates',
#   'lifted',
#   'this',
#   'clearly',
#   'lead',
#   'this',
#   'great',
#   'country',
#   'incompetent'],
#  ['york',
#   'state',
#   'dropping',
#   'mask',
#   'requirements',
#   'broadway',
#   'arts',
#   'artsnews',
#   'broadway',
#   'mask',
#   'vaccination',
#   'policy',
#   'will',
#   'remain',
#   'place',
#   'through',
#   'least',
#   'april',
#   'thirty',
#   'most',
#   'recent',
#   'extension',
#   'date',
#   'policy',
#   'announced',
#   'last',
#   'month',
#   'broadway'],
#  ['proof',
#   'world',
#   'being',
#   'taken',
#   'over',
#   'whistles',
#   'being',
#   'blamed',
#   'heart',
#   'attacks',
#   'myocarditis',
#   'occurring',
#   'chests',
#   'athletes',
#   'field',
#   'also',
#   'ottawa',
#   'citizens',
#   'concerned',
#   'about',
#   'exhaust',
#   'trucks',
#   'five',
#   'year',
#   'died',
#   'minutes',
#   'after',
#   'vaccination'],
#  ['brian',
#   'temple',
#   'diskusses',
#   'efforts',
#   'debunk',
#   'vaccination',
#   'mistruths',
#   'offers',
#   'advice',
#   'people',
#   'wanting',
#   'into',
#   'health',
#   'care',
#   'shares',
#   'thoughts',
#   'black',
#   'history'],
#  ['check', 'england', 'covid', 'death', 'spikes', 'after', 'vaccination'],
#  ['more',
#   'than',
#   'evidence',
#   'that',
#   'masks',
#   'little',
#   'good',
#   'start',
#   'with',
#   'vaccination',
#   'stats',
#   'then',
#   'about',
#   'masks',
#   'cable',
#   'upcoming'],
#  ['sorry',
#   'know',
#   'important',
#   'convince',
#   'people',
#   'covid',
#   'instead',
#   'getting',
#   'vaccination',
#   'kink',
#   'shaming',
#   'tricked',
#   'people',
#   'read',
#   'that',
#   'article',
#   'share',
#   'time',
#   'because',
#   'sounds',
#   'like',
#   'what',
#   'they',
#   'want',
#   'believe'],
#  ['agree',
#   'tried',
#   'steer',
#   'conversation',
#   'towards',
#   'ridiculous',
#   'blocking',
#   'people',
#   'getting',
#   'tested',
#   'vaccine',
#   'mandates',
#   'distraction',
#   'will',
#   'dropped',
#   'soon',
#   'anyway',
#   'leadership',
#   'viewed',
#   'them',
#   'just',
#   'tool',
#   'encourage',
#   'vaccination',
#   'that',
#   'work',
#   'done'],
#  ['oscar',
#   'hypocrisy',
#   'goes',
#   'twitter',
#   'reacts',
#   'academy',
#   'awards',
#   'requiring',
#   'proof',
#   'vaccination'],
#  ['lifetime',
#   'went',
#   'death',
#   'sentence',
#   'very',
#   'manageable',
#   'condition',
#   'might',
#   'even',
#   'have',
#   'vaccination',
#   'against',
#   'soon',
#   'that',
#   'amazing',
#   'testament',
#   'science'],
#  ['montagnier',
#   'beliefs',
#   'about',
#   'vaccination',
#   'milan',
#   'fifteen',
#   'said',
#   'shared',
#   'that',
#   'will',
#   'unvaccinated',
#   'defend',
#   'humanity',
#   'according',
#   'reliable',
#   'sources',
#   'italian',
#   'translator',
#   'translates',
#   'unvaccinated',
#   'guardians',
#   'humanity',
#   'seeker',
#   'truth'],
#  ['eight',
#   'makary',
#   'being',
#   'misleading',
#   'when',
#   'uses',
#   'paper',
#   'diskuss',
#   'natural',
#   'immunity',
#   'vaccination',
#   'since',
#   'assessing',
#   'neutralization',
#   'note',
#   'difference',
#   'between',
#   'what',
#   'paper',
#   'twitter',
#   'claim',
#   'about',
#   'paper'],
#  ['evidence',
#   'increased',
#   'infection',
#   'risk',
#   'following',
#   'third',
#   'dose',
#   'exacerbated',
#   'vaccination',
#   'drive',
#   'during',
#   'omicron',
#   'wave',
#   'ukhsa',
#   'data',
#   'show'],
#  ['make',
#   'right',
#   'governed',
#   'airlines',
#   'they',
#   'want',
#   'institute',
#   'mandates',
#   'they',
#   'this',
#   'longer',
#   'about',
#   'public',
#   'health',
#   'given',
#   'ninety',
#   'vaccination',
#   'this',
#   'about',
#   'individual',
#   'health'],
#  ['expanding',
#   'vaccination',
#   'requirements',
#   'health',
#   'care',
#   'professionals'],
#  ['will',
#   'room',
#   'please',
#   'make',
#   'sure',
#   'rsvp',
#   'vaccination',
#   'cards',
#   'masks',
#   'required',
#   'link',
#   'below'],
#  ['well',
#   'with',
#   'each',
#   'answer',
#   'managed',
#   'place',
#   'word',
#   'vaccination',
#   'diminutives',
#   'course',
#   'strong',
#   'national',
#   'juju'],
#  ['really',
#   'happy',
#   'about',
#   'this',
#   'minority',
#   'with',
#   'these',
#   'feelings',
#   'kids',
#   'five',
#   'under',
#   'still',
#   'vaxxed',
#   'many',
#   'people',
#   'remain',
#   'unvaxxed',
#   'this',
#   'says',
#   'fuck',
#   'anyone',
#   'immunocompromised',
#   'full',
#   'vaccination',
#   'clark',
#   'county',
#   'still',
#   'below'],
#  ['canadian',
#   'truckers',
#   'with',
#   'ninety',
#   'vaccination',
#   'rate',
#   'more',
#   'vaccinated',
#   'than',
#   'single',
#   'demographic',
#   'group',
#   'america',
#   'that',
#   'come',
#   'across',
#   'except',
#   'doctors'],
#  ['seriously',
#   'well',
#   'documented',
#   'that',
#   'risk',
#   'transmitting',
#   'covid',
#   'same',
#   'regardless',
#   'vaccination',
#   'status'],
#  ['minneapolis',
#   'paul',
#   'immediately',
#   'lift',
#   'mandate',
#   'requiring',
#   'proof',
#   'vaccination',
#   'negative',
#   'test'],
#  ['proof', 'vaccination', 'could', 'used', 'republicans', 'voter'],
#  ['like', 'vaccination'],
#  ['people',
#   'defend',
#   'rogan',
#   'like',
#   'that',
#   'tough',
#   'conversations',
#   'with',
#   'wide',
#   'range',
#   'voices',
#   'then',
#   'does',
#   'never',
#   'seem',
#   'host',
#   'critical',
#   'race',
#   'theorists',
#   'trans',
#   'rights',
#   'activists',
#   'real',
#   'doctors',
#   'defend',
#   'vaccination',
#   'anyone',
#   'might',
#   'actually',
#   'challenge'],
#  ['vaccination',
#   'alone',
#   'solution',
#   'then',
#   'need',
#   'next',
#   'vaccines',
#   'that',
#   'protect',
#   'broadly',
#   'across',
#   'variants',
#   'create',
#   'sterilyzing',
#   'immune',
#   'response',
#   'body',
#   'that',
#   'will',
#   'take',
#   'time',
#   'interim',
#   'premiers',
#   'ignore',
#   'protections',
#   'live',
#   'with'],
#  ['many',
#   'businesses',
#   'introduced',
#   'proof',
#   'vaccination',
#   'mandatory',
#   'masking',
#   'measures',
#   'before',
#   'government',
#   'with',
#   'public',
#   'health',
#   'orders',
#   'could',
#   'businesses',
#   'keep',
#   'those',
#   'requirements',
#   'their',
#   'patrons',
#   'regina',
#   'lawyer',
#   'legal',
#   'opinion',
#   'listen'],
#  ['dinner',
#   'believe',
#   'this',
#   'something',
#   'spend',
#   'time',
#   'thinking',
#   'about',
#   'vaccine',
#   'passports',
#   'essentially',
#   'social',
#   'gulag',
#   'then',
#   'have',
#   'well',
#   'what',
#   'about',
#   'that',
#   'hold',
#   'your',
#   'proof',
#   'vaccination',
#   'ready',
#   'hostess'],
#  ['canr',
#   'lgbtq',
#   'adults',
#   'have',
#   'higher',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'rates',
#   'than',
#   'heterosexual',
#   'adults',
#   'pandemic',
#   'unique',
#   'impact',
#   'lgbtq',
#   'community',
#   'says',
#   'lgbt',
#   'persons',
#   'increased',
#   'risk',
#   'severe',
#   'covid',
#   'nineteen',
#   'illness',
#   'view',
#   'article'],
#  ['haven',
#   'even',
#   'gotten',
#   'original',
#   'vaccination',
#   'because',
#   'want',
#   'because',
#   'allowed',
#   'make',
#   'medical',
#   'decisions'],
#  ['says',
#   'countries',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'than',
#   'canada',
#   'have',
#   'reopened',
#   'asks',
#   'trudeau',
#   'only',
#   'mandates',
#   'reopen',
#   'country',
#   'canadians',
#   'vaccinated',
#   'trudeau',
#   'responds',
#   'says',
#   'vaccines',
#   'will',
#   'help',
#   'lift',
#   'restrictions',
#   'cdnpoli'],
#  ['mask',
#   'vaccination',
#   'requirements',
#   'tyranny',
#   'people',
#   'love',
#   'throwing',
#   'that',
#   'word',
#   'around',
#   'name',
#   'calling',
#   'hominem',
#   'attacks',
#   'going',
#   'make',
#   'your',
#   'argument',
#   'better',
#   'toodles'],
#  ['anti', 'vaccination', 'anti', 'covid', 'vaccination'],
#  ['still',
#   'need',
#   'covid',
#   'nineteen',
#   'vaccine',
#   'louisianians',
#   'their',
#   'first',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'shot',
#   'eligible',
#   'receive',
#   'including',
#   'children',
#   'ages',
#   'five',
#   'seventeen'],
#  ['make',
#   'vaccination',
#   'process',
#   'easy',
#   'close',
#   'home',
#   'people',
#   'campaign',
#   'focusing',
#   'getting',
#   'covid',
#   'nineteen',
#   'vaccines',
#   'east',
#   'toronto',
#   'residents',
#   'starts',
#   'this',
#   'saturday'],
#  ['choosing',
#   'good',
#   'policy',
#   'choices',
#   'making',
#   'wedge',
#   'anything',
#   'conservatives',
#   'that',
#   'politicized',
#   'issue',
#   'knee',
#   'jerk',
#   'criticizing',
#   'every',
#   'choice',
#   'every',
#   'step',
#   'naturally',
#   'trudeau',
#   'chose',
#   'vaccination',
#   'conservatives',
#   'chose',
#   'opposite'],
#  ['when',
#   'there',
#   'vaccine',
#   'incompetence',
#   'allowed',
#   'isolated',
#   'covid',
#   'infections',
#   'spread',
#   'epidemic',
#   'proportions',
#   'requiring',
#   'trump',
#   'shutdown',
#   'trump',
#   'recession',
#   'biden',
#   'american',
#   'rescue',
#   'plan',
#   'ended',
#   'trump',
#   'epidemic',
#   'recession',
#   'organizing',
#   'vaccination',
#   'programs'],
#  ['photo',
#   'your',
#   'vaccination',
#   'card',
#   'will',
#   'sufficient',
#   'entry',
#   'thanks'],
#  ['watched',
#   'vice',
#   'story',
#   'trying',
#   'make',
#   'feel',
#   'guilty',
#   'making',
#   'people',
#   'that',
#   'denied',
#   'covid',
#   'refused',
#   'vaccination',
#   'later',
#   'died'],
#  ['been',
#   'watching',
#   'coverage',
#   'this',
#   'insanity',
#   'anti',
#   'vaccination',
#   'trucker',
#   'protests',
#   'their',
#   'threat',
#   'trucker',
#   'protest',
#   'super',
#   'bowl',
#   'this',
#   'would',
#   'annoy',
#   'privilege',
#   'class',
#   'other',
#   'wealthy',
#   'people',
#   'that',
#   'only',
#   'people',
#   'could',
#   'afford',
#   'tickets',
#   'range',
#   'tickets',
#   'prices'],
#  ['like',
#   'masks',
#   'socialdistancing',
#   'vaccination',
#   'because',
#   'many',
#   'still',
#   'refuse',
#   'vaccinated',
#   'while',
#   'people',
#   'much',
#   'world',
#   'even',
#   'have',
#   'access',
#   'vaccine',
#   'will',
#   'more',
#   'variations',
#   'resulting',
#   'infections',
#   'deaths',
#   'wouldn',
#   'assume',
#   'that',
#   'wise',
#   'alien',
#   'four'],
#  ...]

# %%
tokenised_words_only = new_list

# %%
tokenised_words_only
# Out:
# [['want',
#   'find',
#   'racism',
#   'force',
#   'people',
#   'inject',
#   'themselves',
#   'that',
#   'what',
#   'bunch',
#   'people',
#   'races',
#   'standing',
#   'against',
#   'forced',
#   'vaccination',
#   'against',
#   'vaxx',
#   'some',
#   'people',
#   'need',
#   'these',
#   'vaxx',
#   'support',
#   'those',
#   'people',
#   'getting',
#   'their',
#   'shot',
#   'draw',
#   'line',
#   'force'],
#  ['this',
#   'child',
#   'almost',
#   'died',
#   'tetanus',
#   'spent',
#   'months',
#   'hospital',
#   'cost',
#   'around',
#   'parents',
#   'still',
#   'refused',
#   'vaccination',
#   'after',
#   'this',
#   'pandemic'],
#  ['just',
#   'remember',
#   'leblanc',
#   'pressure',
#   'that',
#   'provincial',
#   'business',
#   'world',
#   'asked',
#   'able',
#   'open',
#   'borders',
#   'traffic',
#   'will',
#   'provincial',
#   'govt',
#   'included',
#   'block',
#   'tourists',
#   'will',
#   'have',
#   'pass',
#   'vaccination',
#   'hotel',
#   'restaurant'],
#  ['would',
#   'expect',
#   'cases',
#   'rise',
#   'significantly',
#   'course',
#   'vaccination',
#   'rates',
#   'come',
#   'into',
#   'play',
#   'does',
#   'space',
#   'adults',
#   'usually',
#   'confined',
#   'single',
#   'space',
#   'with',
#   'many',
#   'people',
#   'school',
#   'students',
#   'data',
#   'states',
#   'that',
#   'have',
#   'lifted',
#   'those',
#   'that',
#   'have',
#   'bears',
#   'this'],
#  ['depends',
#   'whether',
#   'vaccination',
#   'status',
#   'embedded',
#   'code',
#   'itself',
#   'code',
#   'just',
#   'link',
#   'that',
#   'connects',
#   'back',
#   'read',
#   'about',
#   'when',
#   'released',
#   'remember',
#   'will',
#   'find',
#   'again'],
#  ['could',
#   'have',
#   'ripped',
#   'harder',
#   'think',
#   'masking',
#   'isolation',
#   'ultimately',
#   'impact',
#   'honest',
#   'question',
#   'look',
#   'those',
#   'spikes',
#   'think',
#   'maybe',
#   'they',
#   'would',
#   'have',
#   'looked',
#   'same',
#   'matter',
#   'what',
#   'with',
#   'vaccination',
#   'only',
#   'thing',
#   'that',
#   'definitively',
#   'worked'],
#  ['they',
#   'this',
#   'vaccination',
#   'centers',
#   'well',
#   'they',
#   'refused',
#   'elderly',
#   'parent',
#   'wear',
#   'over',
#   'masks',
#   'lady',
#   'very',
#   'rude',
#   'said',
#   'could',
#   'have',
#   'covid',
#   'nineteen',
#   'could',
#   'mask',
#   'refused',
#   'take',
#   'answer',
#   'said',
#   'begrudgingly',
#   'absurd'],
#  ['part',
#   'vanguard',
#   'vaccination',
#   'awareness',
#   'project',
#   'series',
#   'free',
#   'tools',
#   'help',
#   'suite',
#   'leaders',
#   'combat',
#   'vaccine',
#   'hesitancy',
#   'resistance',
#   'podcasts',
#   'videos',
#   'articles',
#   'available',
#   'covidvaccineconfidence',
#   'vanguardvaccinationproject'],
#  ['correct',
#   'about',
#   'vaccines',
#   'their',
#   'stated',
#   'goal',
#   'about',
#   'vaccination',
#   'breaking',
#   'blogger',
#   'reports',
#   'factual',
#   'news',
#   'accident',
#   'this',
#   'about',
#   'vaccines',
#   'least',
#   'know',
#   'read',
#   'positive',
#   'steps',
#   'towards',
#   'competence'],
#  ['does',
#   'hurt',
#   'your',
#   'head',
#   'actually',
#   'your',
#   'brain',
#   'seem',
#   'incredibly',
#   'brainwashed',
#   'places',
#   'with',
#   'highest',
#   'vaccination',
#   'rates',
#   'world',
#   'have',
#   'some',
#   'highest',
#   'case',
#   'counts',
#   'everyone',
#   'that',
#   'disagrees',
#   'with',
#   'your',
#   'compliance',
#   'totaltiarin',
#   'dictatorships',
#   'must',
#   'called',
#   'names'],
#  ['world',
#   'wide',
#   'mass',
#   'vaccination',
#   'leading',
#   'world',
#   'wide',
#   'digital',
#   'passport',
#   'their',
#   'goal',
#   'populationcontrol'],
#  ['vaccinations',
#   'still',
#   'need',
#   'proof',
#   'vaccination',
#   'restaurants',
#   'movie',
#   'theaters',
#   'museums',
#   'large',
#   'arenas',
#   'gyms',
#   'fitness',
#   'centers',
#   'vaccination',
#   'rate',
#   'more',
#   'three',
#   'three'],
#  ['following',
#   'tweet',
#   'didn',
#   'even',
#   'twelve',
#   'hours',
#   'before',
#   'prince',
#   'charles',
#   'announced',
#   'reinfection',
#   'even',
#   'after',
#   'vaccination',
#   'booster',
#   'clearly',
#   'previous',
#   'infection',
#   'protects',
#   'this',
#   'point',
#   'does',
#   'boris',
#   'johnson',
#   'exude',
#   'some',
#   'sort',
#   'hypnotoad',
#   'like',
#   'pheromone',
#   'something'],
#  ['vaccination'],
#  ['private',
#   'businesses',
#   'enforce',
#   'vaccination',
#   'mandates',
#   'they',
#   'choose'],
#  ['understand',
#   'exactly',
#   'what',
#   'needs',
#   'understood',
#   'lame',
#   'link',
#   'even',
#   'remains',
#   'lame',
#   'when',
#   'vaccination',
#   'compulsory',
#   'will',
#   'come',
#   'back',
#   'bawl',
#   'there'],
#  ['story',
#   'with',
#   'martha',
#   'mccallum',
#   'senior',
#   'medical',
#   'advisor',
#   'robert',
#   'redfield',
#   'comments',
#   'confusing',
#   'messaging',
#   'spread',
#   'omicron',
#   'importance',
#   'maintaining',
#   'your',
#   'vaccination',
#   'status',
#   'watch',
#   'full',
#   'interview',
#   'below'],
#  ['world',
#   'virologist',
#   'montagnier',
#   'winner',
#   'nobel',
#   'prize',
#   'diskovery',
#   'died',
#   'today',
#   'warned',
#   'beginning',
#   'that',
#   'covid',
#   'nineteen',
#   'made',
#   'that',
#   'mass',
#   'vaccination',
#   'with',
#   'leaky',
#   'vaccines',
#   'would',
#   'generate',
#   'endless',
#   'variants',
#   'right',
#   'both',
#   'counts'],
#  ['obvious',
#   'common',
#   'sense',
#   'solution',
#   'always',
#   'take',
#   'free',
#   'safe',
#   'vaccination',
#   'against',
#   'deadly',
#   'virus',
#   'then',
#   'carry',
#   'about',
#   'your',
#   'business',
#   'like',
#   'lunatic'],
#  ['sure',
#   'tootin',
#   'remember',
#   'grew',
#   'jackson',
#   'least',
#   'place',
#   'long',
#   'associated',
#   'with',
#   'republican',
#   'party',
#   'familiar',
#   'with',
#   'conservative',
#   'mien',
#   'mindset',
#   'speak',
#   'that',
#   'think',
#   'plain',
#   'language',
#   'think',
#   'covid',
#   'should',
#   'mandatory',
#   'vaccination'],
#  ['which',
#   'variants',
#   'were',
#   'involved',
#   'what',
#   'vaccination',
#   'masking',
#   'ventilation',
#   'around',
#   'kids',
#   'time',
#   'meaningless',
#   'kids',
#   'aren',
#   'danger',
#   'unless',
#   'mean',
#   'kids',
#   'have',
#   'will',
#   'ever',
#   'danger',
#   'matter',
#   'what'],
#  ['last',
#   'looked',
#   'hadn',
#   'actually',
#   'county',
#   'vaccination',
#   'threshold',
#   'because',
#   'difference',
#   'between',
#   'data',
#   'most',
#   'secondary',
#   'schools',
#   'have',
#   'though'],
#  ['what',
#   'your',
#   'saying',
#   'that',
#   'alberta',
#   'businesses',
#   'that',
#   'required',
#   'proof',
#   'vaccination',
#   'rely',
#   'alberta',
#   'government',
#   'they',
#   'have',
#   'rely',
#   'other',
#   'provinces'],
#  ['this',
#   'vision',
#   'public',
#   'health',
#   'decisions',
#   'tied',
#   'local',
#   'conditions',
#   'spread',
#   'vaccination',
#   'vulnerability',
#   'also',
#   'sounds',
#   'reasonable',
#   'however',
#   'years',
#   'into',
#   'this',
#   'acting',
#   'that',
#   'what',
#   'happening',
#   'naive',
#   'best',
#   'partisan',
#   'politics',
#   'even',
#   'local',
#   'level',
#   'often',
#   'factor'],
#  ['mean',
#   'someone',
#   'told',
#   'they',
#   'kill',
#   'didn',
#   'vaccinated',
#   'understand',
#   'thought',
#   'said',
#   'vaccination',
#   'lose',
#   'your',
#   'bodily',
#   'autonomy',
#   'then'],
#  ['their',
#   'concerns',
#   'real',
#   'even',
#   'unfounded',
#   'addressing',
#   'them',
#   'with',
#   'empathy',
#   'genuine',
#   'good',
#   'will',
#   'persuade',
#   'them',
#   'canada',
#   'similar',
#   'levels',
#   'adult',
#   'vaccination'],
#  ['seems',
#   'like',
#   'steel',
#   'here',
#   'about',
#   'many',
#   'mandates',
#   'masks',
#   'vaccination',
#   'testing',
#   'that',
#   'very',
#   'much',
#   'still',
#   'place',
#   'relatively',
#   'cost',
#   'zero',
#   'cost'],
#  ['kill', 'sally', 'field', 'here'],
#  ['jesus',
#   'christ',
#   'vaccination',
#   'being',
#   'forced',
#   'carry',
#   'pregnancy',
#   'term'],
#  ['amazon',
#   'allow',
#   'work',
#   'without',
#   'face',
#   'masks',
#   'require',
#   'vaccination',
#   'paid',
#   'covid',
#   'leave'],
#  ['five',
#   'governments',
#   'primary',
#   'concern',
#   'justification',
#   'compulsory',
#   'covid',
#   'vaccination',
#   'prevent',
#   'hospitals',
#   'emergency',
#   'depts',
#   'being',
#   'inundated',
#   'thus',
#   'running',
#   'medical',
#   'resources',
#   'space',
#   'equipment',
#   'staff',
#   'perhaps',
#   'govt',
#   'should',
#   'require',
#   'hospitals'],
#  ['when',
#   'covid',
#   'vaccines',
#   'have',
#   'proven',
#   'prevent',
#   'spread',
#   'covid',
#   'even',
#   'before',
#   'with',
#   'omicron',
#   'where',
#   'called',
#   'breakthrough',
#   'cases',
#   'became',
#   'just',
#   'positive',
#   'covid',
#   'cases',
#   'omicron',
#   'didn',
#   'care',
#   'vaccine',
#   'status',
#   'real',
#   'driving',
#   'force',
#   'vaccination',
#   'become',
#   'minimizing'],
#  ['vaccination', 'syringe', 'video'],
#  ['think',
#   'they',
#   'eighty',
#   'most',
#   'games',
#   'never',
#   'that',
#   'full',
#   'anyway',
#   'meant',
#   'download',
#   'green',
#   'light',
#   'which',
#   'based',
#   'vaccination',
#   'status',
#   'that',
#   'allow',
#   'enter',
#   'stadium',
#   'ground',
#   'there',
#   'unsure',
#   'they',
#   'enforce',
#   'that',
#   'much'],
#  ['alberta',
#   'businesses',
#   'that',
#   'legally',
#   'still',
#   'requires',
#   'obtain',
#   'proof',
#   'vaccination',
#   'there',
#   'those',
#   'still',
#   'legally',
#   'required'],
#  ['about',
#   'medical',
#   'specialists',
#   'were',
#   'involved',
#   'vaccination',
#   'effort'],
#  ['reaction',
#   'vaccine',
#   'according',
#   'anaphylaxis',
#   'after',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'extremely',
#   'rare',
#   'occurred',
#   'about',
#   'five',
#   'people',
#   'million',
#   'vaccinated',
#   'united',
#   'states',
#   'five',
#   'vaccinations'],
#  ['chickahominy',
#   'health',
#   'district',
#   'holding',
#   'vaccination',
#   'clinic',
#   'february',
#   'three',
#   'sargent',
#   'reynolds',
#   'community',
#   'college',
#   'please',
#   'this',
#   'link',
#   'register',
#   'walk',
#   'will',
#   'accepted'],
#  ['that',
#   'right',
#   'their',
#   'body',
#   'belongs',
#   'them',
#   'what',
#   'wears',
#   'better',
#   'fight',
#   'fight',
#   'compulsory',
#   'vaccination',
#   'required',
#   'businesses',
#   'employers',
#   'this',
#   'government'],
#  ['have',
#   'nothing',
#   'more',
#   'report',
#   'about',
#   'other',
#   'than',
#   'documents',
#   'trump',
#   'took',
#   'gave',
#   'back',
#   'bullshit',
#   'that',
#   'happened',
#   'january',
#   'about',
#   'close',
#   'borders',
#   'mask',
#   'vaccination',
#   'mandates',
#   'seriously',
#   'people'],
#  ['conclusion',
#   'most',
#   'definitely',
#   'cannot',
#   'draw',
#   'that',
#   'that',
#   'mask',
#   'mandates',
#   'work',
#   'since',
#   'death',
#   'rates',
#   'much',
#   'lower',
#   'those',
#   'states',
#   'again',
#   'this',
#   'probably',
#   'primarily',
#   'higher',
#   'vaccination',
#   'rates'],
#  ['never', 'suggested', 'vaccination', 'issue', 'other'],
#  ['hasn',
#   'trump',
#   'been',
#   'arrested',
#   'look',
#   'like',
#   'laughingstocks',
#   'rest',
#   'world',
#   'still',
#   'also',
#   'terrified',
#   'truckers',
#   'they',
#   'just',
#   'coming',
#   'because',
#   'vaccination',
#   'mandates',
#   'they',
#   'coming',
#   'because',
#   'perceived',
#   'reinstatement'],
#  ['covid',
#   'positive',
#   'when',
#   'died',
#   'amazed',
#   'that',
#   'they',
#   'haven',
#   'spun',
#   'this',
#   'into',
#   'covid',
#   'death',
#   'push',
#   'their',
#   'vaccination',
#   'agenda'],
#  ['crossed', 'with', 'data', 'vaccination'],
#  ['school',
#   'gonna',
#   'vaccination',
#   'proof',
#   'because',
#   'they',
#   'respect',
#   'individuality',
#   'health',
#   'decisions',
#   'everyone',
#   'have',
#   'choice',
#   'stay',
#   'virtually',
#   'hate',
#   'here'],
#  ['linked',
#   'above',
#   'republican',
#   'controlled',
#   'states',
#   'which',
#   'tend',
#   'states',
#   'without',
#   'mask',
#   'mandates',
#   'doing',
#   'worse',
#   'than',
#   'democratic',
#   'controlled',
#   'states',
#   'course',
#   'they',
#   'also',
#   'states',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'hard',
#   'draw',
#   'strong',
#   'conclusion',
#   'that'],
#  ['close', 'neighbor', 'lowest', 'covid', 'vaccination', 'rates', 'world'],
#  ['vaccination',
#   'campaign',
#   'gone',
#   'from',
#   'exemplary',
#   'miserable',
#   'failure'],
#  ['advocacy',
#   'update',
#   'physician',
#   'groups',
#   'urge',
#   'supreme',
#   'court',
#   'uphold',
#   'vaccination',
#   'requirement',
#   'highlights',
#   'parity',
#   'enforcement',
#   'regulatory',
#   'agenda',
#   'more',
#   'mentalhealth',
#   'psychtwitter'],
#  ['putting',
#   'together',
#   'spreadsheet',
#   'what',
#   'oscar',
#   'nominees',
#   'celebrities',
#   'attended',
#   'vaccination',
#   'required',
#   'events',
#   'publicly',
#   'spoken',
#   'about',
#   'vaccine'],
#  ['that',
#   'indian',
#   'health',
#   'department',
#   'sorry',
#   'trust',
#   'people',
#   'that',
#   'look',
#   'like',
#   'think',
#   'israel',
#   'with',
#   'ninety',
#   'vaccination',
#   'rate',
#   'such',
#   'hard',
#   'time',
#   'with',
#   'covid',
#   'right'],
#  ['amerks',
#   'will',
#   'longer',
#   'require',
#   'proof',
#   'vaccination',
#   'entry',
#   'amerks',
#   'games',
#   'events',
#   'blue',
#   'cross',
#   'arena',
#   'beginning',
#   'thursday',
#   'february'],
#  ['employer',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   'even',
#   'provincial',
#   'federal',
#   'governments',
#   'remove',
#   'mandates',
#   'employer',
#   'will',
#   'still',
#   'have',
#   'mask',
#   'mandatory',
#   'vaccination',
#   'policy',
#   'what',
#   'then',
#   'cdnpoli',
#   'onpoli'],
#  ['demystify',
#   'vaccination',
#   'against',
#   'provided',
#   'master',
#   'your',
#   'subject'],
#  ['need', 'have', 'uniformed', 'rule', 'about', 'mask', 'vaccination'],
#  ['conservative',
#   'anti',
#   'abortion',
#   'anti',
#   'vaccination',
#   'people',
#   'thoughts',
#   'prayers',
#   'forget',
#   'prayers'],
#  ['classic',
#   'simpson',
#   'paradox',
#   'most',
#   'deaths',
#   'among',
#   'elderly',
#   'people',
#   'nearly',
#   'whom',
#   'vaccinated',
#   'with',
#   'lower',
#   'vaccination',
#   'rate',
#   'total',
#   'number',
#   'fatalities',
#   'would',
#   'much',
#   'higher'],
#  ['sounds',
#   'like',
#   'planning',
#   'masking',
#   'kids',
#   'indefinitely',
#   'what',
#   'hospitalization',
#   'rates',
#   'vaccination',
#   'rates',
#   'deeming',
#   'necessary',
#   'finally',
#   'these',
#   'kids',
#   'finally',
#   'back',
#   'normalcy',
#   'need',
#   'numbers'],
#  ['cases',
#   'have',
#   'gone',
#   'state',
#   'highest',
#   'vaccination',
#   'rate',
#   'january',
#   'bullshit',
#   'obvious',
#   'fake',
#   'news',
#   'site',
#   'with',
#   'spoon',
#   'this',
#   'insulting',
#   'your',
#   'intelligence'],
#  ['there',
#   'people',
#   'speaking',
#   'like',
#   'choice',
#   'abortions',
#   'same',
#   'choice',
#   'relating',
#   'vaccines',
#   'disagree',
#   'abortion',
#   'removes',
#   'choice',
#   'human',
#   'ending',
#   'human',
#   'life',
#   'forced',
#   'coerced',
#   'vaccination',
#   'removes',
#   'choice',
#   'forcing',
#   'human',
#   'risk',
#   'permanent',
#   'damage'],
#  ['delusional',
#   'over',
#   'endemic',
#   'going',
#   'live',
#   'with',
#   'this',
#   'vaccination',
#   'lockdowns',
#   'masks',
#   'covid',
#   'still',
#   'here',
#   'live',
#   'fear',
#   'with',
#   'taking',
#   'precaution',
#   'necessary',
#   'based',
#   'other',
#   'health',
#   'conditions'],
#  ['tell',
#   'that',
#   'unvaccinated',
#   'people',
#   'died',
#   'covid',
#   'unfortunately',
#   'that',
#   'true',
#   'vaccination',
#   'does',
#   'indeed',
#   'prevent',
#   'some',
#   'most',
#   'dire',
#   'results',
#   'covid',
#   'infection',
#   'that',
#   'pretty',
#   'well',
#   'established'],
#  ['tool',
#   'surgeon',
#   'general',
#   'refuses',
#   'disklose',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status'],
#  ['quebec',
#   'asking',
#   'vaccinating',
#   'physicians',
#   'return',
#   'their',
#   'regular',
#   'activities',
#   'sharp',
#   'drop',
#   'attendance',
#   'vaccination',
#   'clinics',
#   'radio',
#   'canada',
#   'reported',
#   'this',
#   'morning',
#   'that',
#   'vaccinators',
#   'twiddling',
#   'their',
#   'thumbs',
#   'polqc'],
#  ['thank',
#   'keeping',
#   'mask',
#   'mandate',
#   'schools',
#   'need',
#   'vaccination',
#   'rates',
#   'more',
#   'education',
#   'outreach',
#   'students',
#   'siblings',
#   'under',
#   'five',
#   'vaccinated',
#   'before',
#   'lifting',
#   'mask',
#   'mandates'],
#  ['according', 'vaccination', 'abortion', 'same', 'thing', 'welcome'],
#  ['care',
#   'explain',
#   'mental',
#   'health',
#   'anything',
#   'with',
#   'vaccine',
#   'talking',
#   'about',
#   'person',
#   'feel',
#   'about',
#   'other',
#   'talking',
#   'about',
#   'genuine',
#   'mental',
#   'health',
#   'issue',
#   'vaccination',
#   'does',
#   'exist'],
#  ['find',
#   'fixed',
#   'vaccination',
#   'site',
#   'your',
#   'area',
#   'getvaccinated',
#   'today',
#   'visit',
#   'call',
#   'love'],
#  ['three',
#   'eric',
#   'adams',
#   'also',
#   'repeatedly',
#   'renewed',
#   'executive',
#   'order',
#   'which',
#   'requires',
#   'anyone',
#   'over',
#   'five',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'participate',
#   'indoor',
#   'activities',
#   'anyone',
#   'eighteen',
#   'older',
#   'proof',
#   'along',
#   'with',
#   'proof',
#   'vaccination',
#   'required'],
#  ['makes', 'also', 'angry', 'those', 'have', 'diskouraged', 'vaccination'],
#  ['about',
#   'time',
#   'well',
#   'done',
#   'everyone',
#   'faught',
#   'this',
#   'proud',
#   'revoking',
#   'vaccination',
#   'condition',
#   'deployment',
#   'across',
#   'health',
#   'social',
#   'care'],
#  ['oscars',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'will',
#   'required',
#   'person',
#   'attendees',
#   'exclusive'],
#  ['proof',
#   'vaccination',
#   'still',
#   'required',
#   'indoor',
#   'dining',
#   'events',
#   'arenas',
#   'gyms',
#   'theaters',
#   'museums',
#   'other',
#   'indoor',
#   'entertainment',
#   'york',
#   'city',
#   'part',
#   'initiative',
#   'started',
#   'former',
#   'mayor'],
#  ['what',
#   'makes',
#   'americans',
#   'think',
#   'they',
#   'have',
#   'right',
#   'challenge',
#   'sovereign',
#   'nation',
#   'rules',
#   'regarding',
#   'vaccination',
#   'testing',
#   'this',
#   'problem',
#   'creation',
#   'putting',
#   'self',
#   'above',
#   'needs',
#   'country',
#   'vaccineswork',
#   'canada'],
#  ['following',
#   'nevada',
#   'mask',
#   'mandate',
#   'this',
#   'morning',
#   'followed',
#   'suit',
#   'nshe',
#   'employees',
#   'students',
#   'members',
#   'public',
#   'longer',
#   'required',
#   'wear',
#   'face',
#   'coverings',
#   'while',
#   'inside',
#   'nshe',
#   'buildings',
#   'irrespective',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'immediately'],
#  ['what',
#   'stake',
#   'applicants',
#   'here',
#   'forcible',
#   'vaccination',
#   'rather',
#   'consequences',
#   'choice',
#   'remain',
#   'unvaccinated'],
#  ['trading',
#   'players',
#   'that',
#   'injured',
#   'just',
#   'claim',
#   'injuries',
#   'report',
#   'like',
#   'firing',
#   'vaccinated',
#   'claiming',
#   'have',
#   'vaccination',
#   'rate'],
#  ['really',
#   'vaccination',
#   'lessons',
#   'syptoms',
#   'both',
#   'immediate',
#   'long',
#   'term',
#   'still',
#   'unlikely',
#   'will',
#   'serious',
#   'cause',
#   'long',
#   'term',
#   'damage',
#   'keep'],
#  ['member',
#   'public',
#   'health',
#   'professional',
#   'submit',
#   'suspected',
#   'side',
#   'effects',
#   'through',
#   'yellow',
#   'card',
#   'scheme',
#   'nature',
#   'yellow',
#   'card',
#   'reporting',
#   'means',
#   'that',
#   'reported',
#   'events',
#   'always',
#   'proven',
#   'side',
#   'effects',
#   'some',
#   'events',
#   'have',
#   'happened',
#   'anyway',
#   'regardless',
#   'vaccination'],
#  ['strange',
#   'that',
#   'people',
#   'claiming',
#   'that',
#   'they',
#   'want',
#   'stop',
#   'living',
#   'fear',
#   'causing',
#   'more',
#   'fear',
#   'than',
#   'mask',
#   'vaccination',
#   'ever',
#   'caused',
#   'being',
#   'held',
#   'hostage'],
#  ['kicking',
#   'night',
#   'superbowlmusicfest',
#   'with',
#   'special',
#   'guests',
#   'doors',
#   'limited',
#   'number',
#   'tickets',
#   'remain',
#   'guests',
#   'older',
#   'must',
#   'show',
#   'proof',
#   'full',
#   'vaccination',
#   'test',
#   'info'],
#  ['with',
#   'vaccination',
#   'rates',
#   'quite',
#   'twelve',
#   'range',
#   'more',
#   'thought',
#   'needed',
#   'benefits',
#   'risks',
#   'unmasked',
#   'indoor',
#   'instruction',
#   'glad',
#   'that',
#   'allows',
#   'unmasked',
#   'outdoor',
#   'activities',
#   'that',
#   'socal',
#   'weather',
#   'makes',
#   'easy',
#   'fresh'],
#  ['truly',
#   'feel',
#   'that',
#   'mentally',
#   'unstable',
#   'over',
#   'head',
#   'this',
#   'very',
#   'concerning',
#   'same',
#   'answer',
#   'time',
#   'after',
#   'time',
#   'ninety',
#   'vaccination'],
#  ['tend',
#   'slide',
#   'until',
#   'injure',
#   'myself',
#   'klutz',
#   'notices',
#   'been',
#   'awhile',
#   'since',
#   'they',
#   'quit',
#   'using',
#   'horse',
#   'serum',
#   'good',
#   'about',
#   'that',
#   'vaccination'],
#  ['since',
#   'september',
#   'required',
#   'everyone',
#   'years',
#   'older',
#   'wear',
#   'mask',
#   'indoors',
#   'regardless',
#   'their',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'beginning',
#   'after',
#   'presidents',
#   'that',
#   'will',
#   'longer',
#   'case'],
#  ['justified',
#   'frustrated',
#   'with',
#   'people',
#   'vaccine',
#   'there',
#   'jobs',
#   'where',
#   'fair',
#   'require',
#   'vaccination',
#   'remain',
#   'employed',
#   'really',
#   'going',
#   'starve',
#   'them'],
#  ['biden',
#   'administration',
#   'adopted',
#   'recommendation',
#   'make',
#   'health',
#   'care',
#   'worker',
#   'vaccination',
#   'condition',
#   'medicare',
#   'medicaid',
#   'funds',
#   'scotus',
#   'upheld',
#   'this',
#   'rule',
#   'which',
#   'important',
#   'patient',
#   'safety'],
#  ['required',
#   'preregistration',
#   'open',
#   'meadville',
#   'medical',
#   'center',
#   'next',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'eighteen',
#   'water',
#   'clinic',
#   'pfizer',
#   'vaccine',
#   'only'],
#  ['prevention',
#   'long',
#   'term',
#   'involves',
#   'vaccination',
#   'masks',
#   'reduce',
#   'speaks',
#   'either',
#   'vaccination',
#   'masks',
#   'real',
#   'going',
#   'beat',
#   'this',
#   'covid',
#   'shots',
#   'year',
#   'going',
#   'forward',
#   'difference',
#   'this',
#   'virus',
#   'higher',
#   'kill',
#   'rate'],
#  ['that',
#   'seems',
#   'more',
#   'reasonable',
#   'will',
#   'yield',
#   'more',
#   'positive',
#   'results',
#   'than',
#   'just',
#   'rescinding',
#   'vaccination',
#   'mandates',
#   'letting',
#   'people',
#   'make',
#   'their',
#   'decisions'],
#  ['come',
#   'come',
#   'allstar',
#   'valencia',
#   'angeles',
#   'free',
#   'produce',
#   'testing',
#   'vaccination'],
#  ['this',
#   'absurd',
#   'please',
#   'take',
#   'look',
#   'mirror',
#   'your',
#   'fellow',
#   'conservatives',
#   'have',
#   'been',
#   'expressly',
#   'supporting',
#   'blockade',
#   'main',
#   'culprit',
#   'inflamed',
#   'rhetoric',
#   'calling',
#   'vaccination',
#   'respect',
#   'public',
#   'health',
#   'orders'],
#  ['fans',
#   'receive',
#   'their',
#   'booster',
#   'dose',
#   'covid',
#   'vaccine',
#   'super',
#   'bowl',
#   'experience',
#   'receive',
#   'free',
#   'tickets',
#   'enter',
#   'experience',
#   'that',
#   'future',
#   'date',
#   'sure',
#   'visit',
#   'vaccination',
#   'site',
#   'south',
#   'hall',
#   'there',
#   'superbowlexperience',
#   'sblvi'],
#  ['that',
#   'unease',
#   'part',
#   'pass',
#   'adults',
#   'make',
#   'their',
#   'choices',
#   'suffer',
#   'their',
#   'consequences',
#   'deal',
#   'with',
#   'vaccination',
#   'rates',
#   'five',
#   'eleven',
#   'least',
#   'twelve',
#   'seventeen',
#   'over',
#   'fifty'],
#  ['physical', 'vaccination', 'card', 'gross', 'digital', 'thanks'],
#  ['allied',
#   'universal',
#   'looking',
#   'hire',
#   'phenomenal',
#   'security',
#   'site',
#   'supervisor',
#   'unarmed',
#   'vaccination',
#   'required',
#   'vegas',
#   'join',
#   'diverse',
#   'team',
#   'hiringphenomenaltalent',
#   'security'],
#  ['especially',
#   'vehicle',
#   'towed',
#   'they',
#   'allowed',
#   'cross',
#   'border',
#   'because',
#   'wait',
#   'requires',
#   'proof',
#   'vaccination',
#   'cross',
#   'into'],
#  ['links',
#   'papers',
#   'within',
#   'article',
#   'paper',
#   'emphasizes',
#   'dangers',
#   'harms',
#   'mandatory',
#   'covid',
#   'vaccination',
#   'policy'],
#  ['same', 'forced', 'vaccination'],
#  ['this',
#   'myocarditis',
#   'foundation',
#   'website',
#   'known',
#   'potential',
#   'benefits',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'outweigh',
#   'known',
#   'potential',
#   'risks',
#   'including',
#   'possible',
#   'risks',
#   'myocarditis',
#   'pericarditis'],
#  ['politicians',
#   'across',
#   'country',
#   'continue',
#   'infringe',
#   'personal',
#   'liberties',
#   'under',
#   'guise',
#   'public',
#   'safety',
#   'today',
#   'filed',
#   'lawsuit',
#   'against',
#   'city',
#   'chicago',
#   'cook',
#   'county',
#   'illegal',
#   'diskriminatory',
#   'proof',
#   'vaccination',
#   'requirements'],
#  ['governors',
#   'control',
#   'lockdowns',
#   'they',
#   'started',
#   'long',
#   'before',
#   'biden',
#   'biden',
#   'opened',
#   'things',
#   'with',
#   'vaccination',
#   'program',
#   'sure',
#   'tracking',
#   'right',
#   'trump',
#   'spent',
#   'more',
#   'than',
#   'biden',
#   'that',
#   'failed',
#   'increase',
#   'rates',
#   'during',
#   'presidency'],
#  ['talking', 'about', 'covid', 'vaccination'],
#  ['regulation', 'size', 'three', 'point', 'line', 'vaccination', 'mandate'],
#  ['monday',
#   'proof',
#   'vaccination',
#   'negative',
#   'covid',
#   'nineteen',
#   'test',
#   'will',
#   'longer',
#   'required',
#   'staff',
#   'visitors',
#   'saskatoon',
#   'public',
#   'schools'],
#  ['amoa',
#   'resort',
#   'activated',
#   'covid',
#   'nineteen',
#   'protocols',
#   'will',
#   'welcome',
#   'guests',
#   'strictly',
#   'observes',
#   'social',
#   'distancing',
#   'face',
#   'masks',
#   'wearing',
#   'enforce',
#   'vaccination',
#   'cards',
#   'only',
#   'entry'],
#  ['centenary',
#   'hospital',
#   'scarborough',
#   'dose',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['centenary',
#   'hospital',
#   'margaret',
#   'birch',
#   'wing',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['health',
#   'emergency',
#   'force',
#   'that',
#   'gives',
#   'quebec',
#   'sweeping',
#   'powers',
#   'legault',
#   'said',
#   'will',
#   'dropped',
#   'after',
#   'national',
#   'assembly',
#   'adopts',
#   'legislation',
#   'specifying',
#   'which',
#   'measures',
#   'maintained',
#   'such',
#   'vaccination',
#   'passport',
#   'legaultmustresign',
#   'legault'],
#  ['ability',
#   'always',
#   'free',
#   'restrictions',
#   'after',
#   'vaccination',
#   'that',
#   'supposed',
#   'point',
#   'mandates',
#   'that',
#   'trust',
#   'broken',
#   'when',
#   'closed',
#   'businesses',
#   'again',
#   'able',
#   'restaurants',
#   'there',
#   'guarantee',
#   'will',
#   'april'],
#  ['genuinely',
#   'curious',
#   'find',
#   'clip',
#   'quote',
#   'trump',
#   'telling',
#   'base',
#   'anyone',
#   'anything',
#   'remotely',
#   'anti',
#   'vaccine',
#   'everything',
#   'said',
#   'what',
#   'seen',
#   'been',
#   'extremely',
#   'vaccination',
#   'maybe',
#   'have',
#   'other',
#   'sources',
#   'could',
#   'cite'],
#  ['swastikas',
#   'displayed',
#   'canadian',
#   'freedom',
#   'convoy',
#   'protests',
#   'against',
#   'vaccination',
#   'mandates'],
#  ['that',
#   'treatment',
#   'vaccine',
#   'obviously',
#   'natural',
#   'immunity',
#   'definition',
#   'know',
#   'what',
#   'your',
#   'original',
#   'response',
#   'said',
#   'right',
#   'know',
#   'vaccination',
#   'occurs',
#   'prior',
#   'illness',
#   'during',
#   'illness',
#   'right'],
#  ['covid',
#   'vaccination',
#   'does',
#   'prevent',
#   'spread',
#   'stop',
#   'with',
#   'disinformation'],
#  ['absolutely',
#   'since',
#   'live',
#   'ohio',
#   'county',
#   'with',
#   'lowest',
#   'vaccination',
#   'rates'],
#  ['hrig',
#   'very',
#   'thick',
#   'yogurt',
#   'like',
#   'substance',
#   'will',
#   'feel',
#   'that',
#   'vaccination',
#   'clearly',
#   'tell',
#   'apart',
#   'normal',
#   'rabies',
#   'when',
#   'bitten',
#   'they',
#   'forgot',
#   'administer',
#   'that',
#   'must',
#   'really',
#   'rabies',
#   'vaccine',
#   'effective',
#   'post',
#   'trauma'],
#  ['meanwhile',
#   'more',
#   'death',
#   'threats',
#   'against',
#   'superintendent',
#   'upheaval',
#   'littleton',
#   'public',
#   'schools',
#   'over',
#   'vaccination',
#   'localnews'],
#  ['when',
#   'proof',
#   'vaccination',
#   'gets',
#   'lifted',
#   'elderly',
#   'will',
#   'then',
#   'forced',
#   'isolate',
#   'protect',
#   'themselves'],
#  ['appeals',
#   'court',
#   'will',
#   'block',
#   'order',
#   'barring',
#   'biden',
#   'federal',
#   'staff',
#   'vaccination',
#   'mandate',
#   'newsbreak'],
#  ['agreed',
#   'suspect',
#   'european',
#   'countries',
#   'have',
#   'higher',
#   'uptake',
#   'part',
#   'because',
#   'they',
#   'honored',
#   'recovery',
#   'previously',
#   'infected',
#   'individuals',
#   'adjusted',
#   'their',
#   'vaccination',
#   'recommendations',
#   'result'],
#  ['against',
#   'mandatory',
#   'mumps',
#   'measles',
#   'rubella',
#   'vaccination',
#   'just',
#   'fake',
#   'outrage',
#   'this',
#   'particular',
#   'vaccine'],
#  ['divorce', 'rates', 'rise', 'vaccination', 'adds', 'stress', 'parenting'],
#  ['vaccination', 'away', 'being', 'special'],
#  ['that',
#   'sucks',
#   'schools',
#   'marin',
#   'mass',
#   'vaccination',
#   'days',
#   'with',
#   'support',
#   'dogs',
#   'pretty',
#   'much',
#   'every',
#   'school',
#   'district',
#   'twenty',
#   'minutes'],
#  ['keep', 'some', 'vaccination', 'clinics', 'that', 'opening', 'sign', 'gcms'],
#  ['fair',
#   'some',
#   'parents',
#   'haven',
#   'much',
#   'mass',
#   'vaccination',
#   'infrastructure',
#   'grownups',
#   'when',
#   'vaxxed',
#   'easy',
#   'hell',
#   'barely',
#   'twenty',
#   'minutes',
#   'including',
#   'fifteen',
#   'observation',
#   'kids',
#   'second',
#   'dose',
#   'hours',
#   'waiting',
#   'damp',
#   'cold'],
#  ['would',
#   'list',
#   'nominees',
#   'would',
#   'been',
#   'blacklisted',
#   'oscars',
#   'academy',
#   'hadn',
#   'blinked',
#   'vaccination',
#   'requirements',
#   'imagine',
#   'meltdown',
#   'twitter',
#   'would',
#   'wags',
#   'weighted',
#   'much',
#   'they',
#   'liked',
#   'movie',
#   'based',
#   'their',
#   'shots'],
#  ['saying',
#   'stopping',
#   'vaccination',
#   'ending',
#   'your',
#   'inquiry',
#   'there',
#   'arbitrary',
#   'european',
#   'union',
#   'allows',
#   'titers',
#   'negative',
#   'tests',
#   'their',
#   'pass',
#   'system'],
#  ['councilman',
#   'vaccinated',
#   'said',
#   'peoples',
#   'champ',
#   'vaccination',
#   'rates',
#   'continuing',
#   'your',
#   'district',
#   'leader',
#   'help',
#   'return',
#   'normal',
#   'especially',
#   'given',
#   'tweet',
#   'deleted',
#   'about',
#   'restaurants'],
#  ['having',
#   'government',
#   'offer',
#   'free',
#   'vaccine',
#   'that',
#   'helps',
#   'boost',
#   'immune',
#   'system',
#   'having',
#   'some',
#   'places',
#   'mostly',
#   'private',
#   'businesses',
#   'government',
#   'mandates',
#   'need',
#   'show',
#   'proof',
#   'vaccination',
#   'negative',
#   'test',
#   'doesn',
#   'feel',
#   'like',
#   'oppression'],
#  ['saying',
#   'memory',
#   'cells',
#   'remember',
#   'things',
#   'terms',
#   'things',
#   'like',
#   'spike',
#   'proteins',
#   'depends',
#   'disease',
#   'vaccination',
#   'example',
#   'hepatitis',
#   'vaccine',
#   'mainly',
#   'based',
#   'surface',
#   'protein'],
#  ['cares',
#   'what',
#   'these',
#   'people',
#   'personally',
#   'fact',
#   'couldn',
#   'possibly',
#   'care',
#   'less',
#   'should',
#   'anyone',
#   'care',
#   'they',
#   'shown',
#   'exactly',
#   'they',
#   'what',
#   'they',
#   'think',
#   'simply',
#   'agree',
#   'them',
#   'forced',
#   'vaccination',
#   'care'],
#  ['wish',
#   'everyone',
#   'vaccinated',
#   'mandatory',
#   'vaccination',
#   'measure',
#   'based',
#   'science'],
#  ['hope',
#   'ontario',
#   'drops',
#   'this',
#   'proof',
#   'vaccination',
#   'soon',
#   'cause',
#   'bring',
#   'much',
#   'unnecessary',
#   'conflicts',
#   'workers',
#   'especially',
#   'when',
#   'they',
#   'wanna',
#   'change',
#   'type',
#   'vacation',
#   'proof',
#   'dime'],
#  ['tyrannical',
#   'biden',
#   'administration',
#   'wants',
#   'mandatory',
#   'vaccination',
#   'protestors',
#   'canada',
#   'crushed',
#   'beneath',
#   'grinding',
#   'wheels',
#   'federal',
#   'authority'],
#  ['since',
#   'then',
#   'covid',
#   'hospitalizations',
#   'denmark',
#   'have',
#   'also',
#   'been',
#   'ticking',
#   'upwards',
#   'despite',
#   'highest',
#   'booster',
#   'vaccination',
#   'rate',
#   'europe',
#   'please',
#   'take',
#   'look',
#   'hospitalizations',
#   'chart',
#   'below',
#   'world',
#   'data'],
#  ['love',
#   'mental',
#   'gymnastics',
#   'have',
#   'perform',
#   'argue',
#   'protesting',
#   'vaccination',
#   'akin',
#   'protesting',
#   'police',
#   'brutality',
#   'against',
#   'minorities'],
#  ['defundcbc',
#   'defundbbc',
#   'unfortunately',
#   'very',
#   'behind',
#   'this',
#   'vaccination',
#   'extravaganza',
#   'same',
#   'funding',
#   'these',
#   'news',
#   'networks',
#   'just',
#   'sayin',
#   'totally',
#   'with',
#   'though',
#   'funds',
#   'coming',
#   'baddies'],
#  ['broadway',
#   'mask',
#   'vaccination',
#   'requirement',
#   'remains',
#   'through',
#   'april',
#   'thirty'],
#  ['super',
#   'immunity',
#   'fake',
#   'covid',
#   'times',
#   'fact',
#   'therapist',
#   'covid',
#   'three',
#   'times',
#   'vaccination',
#   'less',
#   'health',
#   'risks',
#   'than',
#   'getting',
#   'covid',
#   'going',
#   'kill',
#   'people',
#   'attacking',
#   'proven',
#   'technology'],
#  ['jeffrey',
#   'morris',
#   'they',
#   'also',
#   'have',
#   'population',
#   'number',
#   'each',
#   'vaccinated',
#   'status',
#   'each',
#   'group',
#   'each',
#   'week',
#   'that',
#   'used',
#   'compute',
#   'standardized',
#   'death',
#   'rates',
#   'well',
#   'track',
#   'proportion',
#   'that',
#   'group',
#   'each',
#   'vaccination',
#   'status',
#   'over',
#   'time'],
#  ['school',
#   'vaccination',
#   'going',
#   'very',
#   'well',
#   'kids',
#   'schools',
#   'right',
#   'around',
#   'wrong',
#   'with',
#   'parents'],
#  ['still',
#   'mask',
#   'social',
#   'distance',
#   'through',
#   'vaccination',
#   'booster',
#   'yeah',
#   'smart'],
#  ['besides',
#   'fact',
#   'that',
#   'even',
#   'there',
#   'mandate',
#   'canada',
#   'that',
#   'just',
#   'means',
#   'only',
#   'those',
#   'entering',
#   'other',
#   'countries',
#   'needed',
#   'follow',
#   'show',
#   'proof',
#   'vaccination',
#   'negative',
#   'test',
#   'quarantine',
#   'what',
#   'point',
#   'when',
#   'leave',
#   'country',
#   'without',
#   'that',
#   'proof'],
#  ['here',
#   'hockey',
#   'harlem',
#   'supporting',
#   'vaccination',
#   'program',
#   'when',
#   'elected',
#   'house',
#   'will',
#   'make',
#   'sure',
#   'become',
#   'famous',
#   'capitol',
#   'hill',
#   'because',
#   'your',
#   'voice',
#   'matter',
#   'godblessamerica',
#   'nonads'],
#  ['twelve',
#   'area',
#   'counties',
#   'santa',
#   'clara',
#   'highest',
#   'vaccination',
#   'rate',
#   'their',
#   'case',
#   'rate',
#   'ranks',
#   'holds',
#   'santa',
#   'clara',
#   'leadership',
#   'accountable'],
#  ['mandates',
#   'help',
#   'increase',
#   'vaccination',
#   'rates',
#   'they',
#   'prevent',
#   'future',
#   'restrictions',
#   'appreciate',
#   'your',
#   'overall',
#   'tone',
#   'this',
#   'thread',
#   'disagree',
#   'here',
#   'mandates',
#   'should',
#   'done',
#   'attempt',
#   'coerce',
#   'while',
#   'producing',
#   'collateral',
#   'damage',
#   'elsewhere',
#   'accept',
#   'some',
#   'compliance'],
#  ['that',
#   'last',
#   'answer',
#   'apparently',
#   'haven',
#   'been',
#   'keeping',
#   'mrna',
#   'vaccination',
#   'stimulates',
#   'robust',
#   'containing',
#   'vaccine',
#   'mrna',
#   'spike',
#   'antigen',
#   'eight',
#   'weeks',
#   'postvaccination',
#   'some',
#   'cases'],
#  ['meanwhile',
#   'government',
#   'using',
#   'kids',
#   'shields',
#   'with',
#   'unneccessary',
#   'vaccination',
#   'face',
#   'masks',
#   'schools'],
#  ['since',
#   'there',
#   'ninety',
#   'vaccination',
#   'rate',
#   'super',
#   'majority',
#   'people',
#   'supporting',
#   'federal',
#   'government',
#   'pandemic',
#   'plan',
#   'some',
#   'dummies',
#   'refer',
#   'conspiracy',
#   'theories',
#   'vaccinated'],
#  ['paper',
#   'states',
#   'free',
#   'floating',
#   'spike',
#   'proteins',
#   'circulate',
#   'high',
#   'levels',
#   'blood',
#   'after',
#   'vaccination',
#   'vaccinated',
#   'people',
#   'infected',
#   'with',
#   'variants',
#   'covid',
#   'produce',
#   'antibodies',
#   'biased',
#   'toward',
#   'original',
#   'extinct',
#   'variant',
#   'rather',
#   'than',
#   'that',
#   'actually',
#   'infected',
#   'them'],
#  ['sounds',
#   'like',
#   'might',
#   'asking',
#   'immigration',
#   'related',
#   'question',
#   'which',
#   'aren',
#   'qualified',
#   'answer',
#   'sorry',
#   'about',
#   'that',
#   'asking',
#   'meet',
#   'health',
#   'safety',
#   'requirements',
#   'long',
#   'wear',
#   'mask',
#   'provide',
#   'vaccination',
#   'record'],
#  ['what',
#   'that',
#   'incorrect',
#   'terrorists',
#   'causing',
#   'more',
#   'issues',
#   'closures',
#   'supply',
#   'chain',
#   'issues',
#   'than',
#   'restrictions',
#   'vaccination',
#   'only',
#   'this',
#   'period'],
#  ['once',
#   'extended',
#   'vaccine',
#   'isolation',
#   'think',
#   'know',
#   'what',
#   'need',
#   'fentanyl',
#   'death',
#   'oneself',
#   'loved',
#   'ones',
#   'causes',
#   'more',
#   'psychological',
#   'stress',
#   'than',
#   'having',
#   'wear',
#   'damn',
#   'mask',
#   'show',
#   'proof',
#   'vaccination',
#   'babies'],
#  ['would',
#   'triple',
#   'vaccinated',
#   'person',
#   'living',
#   'county',
#   'with',
#   'vaccination',
#   'rate',
#   'where',
#   'mask'],
#  ['about',
#   'half',
#   'adults',
#   'hospitalized',
#   'with',
#   'have',
#   'heart',
#   'disease',
#   'vaccination',
#   'especially',
#   'important',
#   'people',
#   'with',
#   'heart',
#   'disease',
#   'because',
#   'they',
#   'higher',
#   'risk',
#   'serious',
#   'complications',
#   'protect',
#   'yourself',
#   'fightflu',
#   'this',
#   'heartmonth'],
#  ['nowplaying',
#   'show',
#   'vaccination',
#   'misinformation',
#   'show',
#   'zero',
#   'nowspinning',
#   'nowstreaming',
#   'hear',
#   'subgenius',
#   'radio',
#   'times',
#   'joerogan',
#   'antivaxxers',
#   'full',
#   'details'],
#  ['enforced',
#   'like',
#   'parking',
#   'tickets',
#   'spot',
#   'checks',
#   'bylaw',
#   'officers',
#   'protecting',
#   'businesses',
#   'that',
#   'check',
#   'vaccination',
#   'includes',
#   'shots'],
#  ['biden',
#   'giving',
#   'crack',
#   'pipes',
#   'long',
#   'show',
#   'proof',
#   'vaccination',
#   'lmfaoooo',
#   'this',
#   'yesterday',
#   'thought',
#   'fake',
#   'literal',
#   'hell'],
#  ['hope',
#   'recieving',
#   'treatment',
#   'problems',
#   'with',
#   'immunity',
#   'system',
#   'like',
#   'people',
#   'have',
#   'many',
#   'vaccination',
#   'some',
#   'cases',
#   'natural',
#   'immunity',
#   'have',
#   'weakened',
#   'check',
#   'reports',
#   'israel'],
#  ['reminder',
#   'offering',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'students',
#   'staff',
#   'families',
#   'community',
#   'tomorrow',
#   'covid',
#   'nineteen',
#   'testing',
#   'clinic',
#   'students',
#   'staff',
#   'scheduled',
#   'saturday',
#   'twelve',
#   'details',
#   'both',
#   'events',
#   'district',
#   'website',
#   'here'],
#  ['this',
#   'stunning',
#   'want',
#   'treat',
#   'just',
#   'another',
#   'know',
#   'zero',
#   'plus',
#   'americans',
#   'died',
#   'last',
#   'month',
#   'that',
#   'more',
#   'than',
#   'last',
#   'three',
#   'years',
#   'have',
#   'died',
#   'complications',
#   'want',
#   'find',
#   'rather',
#   'have',
#   'done',
#   'vaccination'],
#  ['watch', 'does', 'trudeau', 'want', 'vaccination', 'rate', 'youtube'],
#  ['that',
#   'eighty',
#   'ninety',
#   'vaccinated',
#   'respectively',
#   'does',
#   'mean',
#   'they',
#   'mandate',
#   'vaccination',
#   'masks',
#   'some',
#   'myself',
#   'included',
#   'understand',
#   'that',
#   'vaccines',
#   'highly',
#   'beneficial',
#   'almost',
#   'that',
#   'doesn',
#   'give',
#   'right',
#   'deprive',
#   'anyone',
#   'their',
#   'rights'],
#  ['things',
#   'heard',
#   'today',
#   'person',
#   'leave',
#   'because',
#   'they',
#   'questions',
#   'about',
#   'need',
#   'booster',
#   'side',
#   'effects',
#   'first',
#   'doses',
#   'covid',
#   'recovered',
#   'person',
#   'losing',
#   'client',
#   'contracts',
#   'because',
#   'they',
#   'wish',
#   'wait',
#   'consider',
#   'vaccination',
#   'because',
#   'some',
#   'health',
#   'concerns'],
#  ['have',
#   'human',
#   'rights',
#   'commission',
#   'maybe',
#   'time',
#   'have',
#   'health',
#   'rights',
#   'commission',
#   'diskrimination',
#   'wrong',
#   'whether',
#   'based',
#   'color',
#   'religion',
#   'universal',
#   'health',
#   'system',
#   'doesn',
#   'diskriminate',
#   'against',
#   'anyone',
#   'should',
#   'with',
#   'vaccination',
#   'injection'],
#  ['support',
#   'right',
#   'turn',
#   'down',
#   'vaccination',
#   'what',
#   'saying',
#   'doesn',
#   'make',
#   'sense',
#   'like',
#   'saying',
#   'wasn',
#   'choice',
#   'evicted',
#   'just',
#   'didn',
#   'want',
#   'rent'],
#  ['talk',
#   'about',
#   'khalistani',
#   'issues',
#   'there',
#   'were',
#   'open',
#   'threats',
#   'during',
#   'tiranga',
#   'yatra',
#   'babbar',
#   'khalsa',
#   'police',
#   'australian',
#   'states',
#   'have',
#   'mostly',
#   'been',
#   'such',
#   'groups',
#   'democracy',
#   'australia',
#   'enforced',
#   'vaccination',
#   'kids',
#   'even',
#   'leave',
#   'country'],
#  ['covidab',
#   'impacts',
#   'have',
#   'evolved',
#   'must',
#   'metrics',
#   'used',
#   'guide',
#   'policy',
#   'rates',
#   'down',
#   'hospitalizations',
#   'remain',
#   'community',
#   'spread',
#   'remains',
#   'absenteeism',
#   'remains',
#   'this',
#   'nowhere',
#   'near',
#   'over',
#   'repnotrip',
#   'ableg'],
#  ['weirdos',
#   'going',
#   'around',
#   'francisco',
#   'bars',
#   'restaurants',
#   'filling',
#   'these',
#   'notice',
#   'civil',
#   'rights',
#   'violations',
#   'asking',
#   'proof',
#   'vaccination'],
#  ['with',
#   'exception',
#   'vaccination',
#   'worst',
#   'since',
#   'beginning',
#   'death',
#   'patient',
#   'ambulance',
#   'icing',
#   'incompetence',
#   'quickly',
#   'investigation',
#   'household',
#   'imposed',
#   'management',
#   'unacceptable'],
#  ['only',
#   'some',
#   'members',
#   'band',
#   'were',
#   'still',
#   'alive',
#   'tell',
#   'what',
#   'they',
#   'think',
#   'vaccination',
#   'wait',
#   'minute'],
#  ['winter',
#   'break',
#   'teen',
#   'arts',
#   'project',
#   'eight',
#   'four',
#   'county',
#   'players',
#   'barborsville',
#   'fifteen',
#   'masks',
#   'required',
#   'regardless',
#   'vaccination',
#   'status'],
#  ['million',
#   'quebecers',
#   'have',
#   'caught',
#   'covid',
#   'since',
#   'december',
#   'four',
#   'million',
#   'since',
#   'march',
#   'there',
#   'only',
#   'three',
#   'million',
#   'vaccination',
#   'solution',
#   'reduce',
#   'contagion'],
#  ['since',
#   'this',
#   'latest',
#   'flip',
#   'flop',
#   'rather',
#   'sudden',
#   'have',
#   'question',
#   'airlines',
#   'still',
#   'requesting',
#   'proof',
#   'vaccination',
#   'some',
#   'international',
#   'destinations',
#   'still',
#   'requiring',
#   'proof',
#   'vaccination'],
#  ['mitigation', 'mean', 'vaccination'],
#  ['then',
#   'question',
#   'they',
#   'enter',
#   'first',
#   'place',
#   'given',
#   'requires',
#   'proof',
#   'vaccination',
#   'entry'],
#  ['made',
#   'intentions',
#   'known',
#   'tues',
#   'announced',
#   'dramatic',
#   'drops',
#   'covid',
#   'cases',
#   'county',
#   'vaccination',
#   'rate',
#   'stop',
#   'state',
#   'interference',
#   'county',
#   'education',
#   'four',
#   'died',
#   'yesterday',
#   'twelve'],
#  ['vaccination',
#   'campaign',
#   'quebec',
#   'asks',
#   'doctors',
#   'return',
#   'their',
#   'regular',
#   'activities'],
#  ['feel',
#   'like',
#   'people',
#   'pissed',
#   'about',
#   'employer',
#   'vaccination',
#   'mandates',
#   'which',
#   'thought',
#   'politically',
#   'dangerous'],
#  ['with',
#   'vaccines',
#   'stop',
#   'them',
#   'meseals',
#   'vaccination',
#   'rate',
#   'canada'],
#  ['know',
#   'that',
#   'only',
#   'boys',
#   'shower',
#   'eighty',
#   'vaccination',
#   'rates',
#   'with',
#   'science'],
#  ['there',
#   'nothing',
#   'here',
#   'comrade',
#   'singh',
#   'told',
#   'directly',
#   'presser',
#   'today',
#   'that',
#   'there',
#   'political',
#   'alignment',
#   'vaccination',
#   'issue',
#   'explain',
#   'that',
#   'everyday',
#   'covid',
#   'cabal',
#   'real',
#   'mybodymychoice',
#   'falls',
#   'deaf',
#   'ears'],
#  ['live',
#   'mercer',
#   'county',
#   'ohio',
#   'vaccination',
#   'rate',
#   'here',
#   'even',
#   'forty',
#   'percent',
#   'continue',
#   'avoiding',
#   'indoor',
#   'spaces',
#   'masking',
#   'when',
#   'running',
#   'errands',
#   'took',
#   'early',
#   'early',
#   'retirement',
#   'hubby',
#   'been',
#   'retired',
#   'several',
#   'years',
#   'refuse',
#   'play',
#   'long',
#   'want'],
#  ['gotta',
#   'love',
#   'fact',
#   'that',
#   'taking',
#   'away',
#   'business',
#   'option',
#   'continue',
#   'check',
#   'vaccination',
#   'status',
#   'they',
#   'want',
#   'thought',
#   'this',
#   'about',
#   'choice',
#   'choice',
#   'vaccinated',
#   'choice',
#   'allow',
#   'your',
#   'business',
#   'abpoli'],
#  ['look',
#   'bright',
#   'side',
#   'with',
#   'fiorellas',
#   'fans',
#   'feel',
#   'about',
#   'vaccination',
#   'able',
#   'ratio',
#   'much',
#   'longer'],
#  ['only',
#   'rates',
#   'masking',
#   'your',
#   'definition',
#   'fully',
#   'includes',
#   'having',
#   'your',
#   'booster',
#   'know',
#   'immunity',
#   'wanes',
#   'only',
#   'infection',
#   'also',
#   'wanes',
#   'severe',
#   'disease',
#   'hospitalization',
#   'death',
#   'masking',
#   'policy',
#   'dose',
#   'vaccination'],
#  ['this',
#   'very',
#   'memory',
#   'holed',
#   'analysis',
#   'every',
#   'state',
#   'elderly',
#   'were',
#   'prioritized',
#   'vaccination',
#   'people',
#   'under',
#   'couldn',
#   'access',
#   'vaccine',
#   'months'],
#  ['nothing',
#   'like',
#   'election',
#   'provide',
#   'accurate',
#   'definition',
#   'fully',
#   'vaxd',
#   'unless',
#   'tourist',
#   'mandate',
#   'vaccination',
#   'aged',
#   'care',
#   'about',
#   'time'],
#  ['thankyoukyrie',
#   'standing',
#   'firm',
#   'your',
#   'vaccination',
#   'beliefs',
#   'driving',
#   'james',
#   'sixers',
#   'three'],
#  ['craig',
#   'approved',
#   'recognized',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'while',
#   'overseas',
#   'have',
#   'recorded',
#   'australian',
#   'immunization',
#   'register',
#   'when',
#   'australia',
#   'find',
#   'more',
#   'information',
#   'about',
#   'this',
#   'website'],
#  ['everything',
#   'public',
#   'health',
#   'everybody',
#   'masking',
#   'better',
#   'ventilation',
#   'vaccination',
#   'reduces',
#   'amount',
#   'virus',
#   'chances',
#   'being',
#   'infected',
#   'sorry',
#   'amanda',
#   'hope',
#   'your'],
#  ['tucson',
#   'electric',
#   'power',
#   'other',
#   'state',
#   'regulated',
#   'utilities',
#   'they',
#   'have',
#   'plans',
#   'mandate',
#   'vaccination',
#   'testing',
#   'beyond',
#   'current',
#   'workplace',
#   'safety',
#   'protocols'],
#  ['montagnier',
#   'clear',
#   'that',
#   'variants',
#   'created',
#   'antibody',
#   'mediated',
#   'selection',
#   'vaccination',
#   'this',
#   'yesterday',
#   'montagnier'],
#  ['will',
#   'chat',
#   'with',
#   'about',
#   'memoir',
#   'sunday',
#   'february',
#   'almost',
#   'romance',
#   'details',
#   'friends',
#   'turned',
#   'year',
#   'almost',
#   'romance',
#   'into',
#   'real',
#   'tickets',
#   'book',
#   'must',
#   'have',
#   'proof',
#   'vaccination',
#   'mask'],
#  ['possible',
#   'businesses',
#   'have',
#   'proof',
#   'vaccination',
#   'without',
#   'code',
#   'copping',
#   'says',
#   'those',
#   'already',
#   'have',
#   'still',
#   'businesses',
#   'still',
#   'printed',
#   'proof',
#   'vaccination',
#   'well'],
#  ['just',
#   'thought',
#   'people',
#   'there',
#   'with',
#   'herpes',
#   'infections',
#   'many',
#   'them',
#   'have',
#   'recurrences',
#   'after',
#   'vaccination',
#   'didn',
#   'make',
#   'possible',
#   'connection',
#   'estimated',
#   'that',
#   'there',
#   'were',
#   'zero',
#   'genital',
#   'herpes',
#   'infections',
#   'united',
#   'states',
#   'single',
#   'year'],
#  ['they',
#   'safer',
#   'than',
#   'aspirin',
#   'tylenol',
#   'travel',
#   'cross',
#   'state',
#   'borders',
#   'without',
#   'showing',
#   'vaccination',
#   'card',
#   'business',
#   'doesn',
#   'want',
#   'serve',
#   'hire',
#   'that',
#   'their',
#   'right',
#   'this',
#   'comparison',
#   'makes',
#   'sense'],
#  ['this',
#   'girl',
#   'selling',
#   'cards',
#   'facebook',
#   'week',
#   'later',
#   'just',
#   'realized',
#   'that',
#   'means',
#   'vaccination',
#   'cards',
#   'valentine',
#   'cards'],
#  ['myocarditis',
#   'rare',
#   'side',
#   'effect',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'made',
#   'headlines',
#   'pediatric',
#   'cardiologist',
#   'explains',
#   'coronavirus',
#   'infection',
#   'poses',
#   'much',
#   'much',
#   'greater',
#   'danger'],
#  ['myocarditis',
#   'rare',
#   'side',
#   'effect',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'made',
#   'headlines',
#   'pediatric',
#   'cardiologist',
#   'hospital',
#   'explains',
#   'coronavirus',
#   'infection',
#   'poses',
#   'much',
#   'much',
#   'greater',
#   'danger'],
#  ['heart',
#   'transplant',
#   'denied',
#   'vaccination',
#   'status',
#   'arthur',
#   'caplan',
#   'bioethics',
#   'drew'],
#  ['supported',
#   'indonesia',
#   'with',
#   'billion',
#   'emergency',
#   'financing',
#   'achieve',
#   'vaccination',
#   'targets',
#   'enhanced',
#   'response',
#   'capacity',
#   'seen',
#   'testing',
#   'labs',
#   'opened',
#   'thousands',
#   'isolation',
#   'critical',
#   'care',
#   'beds',
#   'being',
#   'added'],
#  ['free',
#   'tickets',
#   'super',
#   'bowl',
#   'experience',
#   'your',
#   'booster',
#   'dose',
#   'vaccination',
#   'clinic',
#   'south',
#   'hall',
#   'clinic',
#   'opens',
#   'doors',
#   'experience',
#   'opens',
#   'sblvi'],
#  ['fact',
#   'checkers',
#   'says',
#   'changed',
#   'definition',
#   'vaccination',
#   'increase',
#   'transparency',
#   'this',
#   'probably',
#   'first',
#   'time',
#   'history',
#   'that',
#   'definition',
#   'been',
#   'changed',
#   'this',
#   'reason',
#   'gave',
#   'right',
#   'change',
#   'meaning',
#   'words'],
#  ['world',
#   'photo',
#   'proof',
#   'full',
#   'vaccination',
#   'required',
#   'kingstonmines',
#   'details'],
#  ['taibu',
#   'community',
#   'health',
#   'center',
#   'scarborough',
#   'pediatric',
#   'dose',
#   'pfizer',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
#   'vhcon'],
#  ['taibu',
#   'community',
#   'health',
#   'center',
#   'scarborough',
#   'dose',
#   'pfizer',
#   'moderna',
#   'spots',
#   'added',
#   'first',
#   'available',
#   'date',
#   'book',
#   'detailed',
#   'availability',
# ...
#   'community',
#   'clinics',
#   'learn',
#   'more'],
#  ['tier',
#   'cruise',
#   'ships',
#   'vaccination',
#   'standard',
#   'excellence',
#   'requires',
#   'that',
#   'least',
#   'passengers',
#   'crew',
#   'date',
#   'with',
#   'covid',
#   'nineteen',
#   'vaccinations',
#   'including',
#   'booster',
#   'shots',
#   'depending',
#   'eligibility'],
#  ['anti',
#   'nurses',
#   'amityville',
#   'have',
#   'been',
#   'accused',
#   'forging',
#   'thousands',
#   'vaccination',
#   'cards',
#   'exchange',
#   'that',
#   'scary'],
#  ['covid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'connecticut',
#   'syringeat',
#   'least',
#   'dose',
#   'syringefully',
#   'syringeadditional',
#   'dose'],
#  ['about',
#   'virus',
#   'repeated',
#   'vaccination',
#   'that',
#   'induces',
#   'vaccinated',
#   'people'],
#  ['perhaps',
#   'pander',
#   'freedumbconvoy',
#   'base',
#   'unclear',
#   'whether',
#   'proof',
#   'vaccination',
#   'mandatory',
#   'masking',
#   'policies',
#   'would',
#   'dropped',
#   'well',
#   'province',
#   'provide',
#   'timeframe',
#   'when',
#   'those',
#   'measures',
#   'would',
#   'come'],
#  ['again',
#   'making',
#   'claim',
#   'that',
#   'there',
#   'have',
#   'been',
#   'events',
#   'four',
#   'months',
#   'more',
#   'after',
#   'vaccination',
#   'given',
#   'need',
#   'provide',
#   'evidence',
#   'that',
#   'such',
#   'example',
#   'exists',
#   'back',
#   'history',
#   'want',
#   'polio',
#   'tdap',
#   'vaccine',
#   'wait'],
#  ['well',
#   'found',
#   'lifting',
#   'vaccination',
#   'mandates',
#   'able',
#   'play',
#   'that',
#   'happens'],
#  ['please',
#   'continue',
#   'take',
#   'covid',
#   'nineteen',
#   'precautions',
#   'wearing',
#   'face',
#   'mask',
#   'maintaining',
#   'distance',
#   'others',
#   'getting',
#   'vaccinated',
#   'schedule',
#   'appointment',
#   'your',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'booster',
#   'call'],
#  ['hosting',
#   'free',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'eight',
#   'eleven',
#   'aebersold',
#   'student',
#   'recreation',
#   'center',
#   'register',
#   'here',
#   'specific',
#   'time',
#   'walk'],
#  ['have',
#   'lots',
#   'spots',
#   'available',
#   'vaccination',
#   'clinic',
#   'tomorrow',
#   'eleven',
#   'garcelon',
#   'civic',
#   'center',
#   'ststephen',
#   'book',
#   'between',
#   'eleven',
#   'seven',
#   'come',
#   'walk',
#   'between'],
#  ['monday',
#   'seven',
#   'chile',
#   'started',
#   'another',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'push',
#   'with',
#   'second',
#   'booster',
#   'dose',
#   'people',
#   'over',
#   'years',
#   'country',
#   'currently',
#   'going',
#   'through',
#   'wave',
#   'infections',
#   'with',
#   'daily',
#   'record',
#   'figures',
#   'over',
#   'thirty',
#   'zero',
#   'aldianews'],
#  ['justin',
#   'reply',
#   'every',
#   'question',
#   'last',
#   'weeks',
#   'canadians',
#   'have',
#   'stepped',
#   'following',
#   'science',
#   'three',
#   'vaccination',
#   'only',
#   'pandemic',
#   'four',
#   'have',
#   'canadians',
#   'back'],
#  ['weird',
#   'hippies',
#   'screamed',
#   'held',
#   'signs',
#   'stating',
#   'down',
#   'with',
#   'establishment',
#   'ones',
#   'their',
#   'seventy',
#   'begging',
#   'government',
#   'keep',
#   'masking',
#   'rules',
#   'vaccination',
#   'passports',
#   'lockdowns'],
#  ['justin',
#   'reply',
#   'canadians',
#   'have',
#   'stepped',
#   'following',
#   'science',
#   'three',
#   'vaccination',
#   'only',
#   'pandemic',
#   'four',
#   'have',
#   'canadians',
#   'back'],
#  ['know',
#   'enough',
#   'about',
#   'your',
#   'covid',
#   'vaccine',
#   'options',
#   'check',
#   'information',
#   'resources',
#   'vaccination',
#   'need',
#   'part',
#   'keeping',
#   'neighbors',
#   'safe',
#   'learn',
#   'more',
#   'today',
#   'getvaxxed'],
#  ['streets', 'vaccination'],
#  ['covid',
#   'nineteen',
#   'vaccination',
#   'clinic',
#   'open',
#   'couple',
#   'more',
#   'hours',
#   'runners',
#   'swing',
#   'denman',
#   'ballroom',
#   'student',
#   'union',
#   'vaxxed',
#   'syringe',
#   'utsa',
#   'doyourpart'],
#  ['children',
#   'higher',
#   'risk',
#   'covid',
#   'nineteen',
#   'today',
#   'than',
#   'they',
#   'were',
#   'early',
#   'pandemic',
#   'vaccination',
#   'help',
#   'protect',
#   'them',
#   'every',
#   'person',
#   'five',
#   'older',
#   'eligible',
#   'receive',
#   'covid',
#   'nineteen',
#   'vaccine',
#   'syringe',
#   'book',
#   'appointment'],
#  ['service',
#   'talks',
#   'bring',
#   'medicare',
#   'card',
#   'following',
#   'success',
#   'with',
#   'vaccination',
#   'certificates'],
#  ['even',
#   'though',
#   'surgical',
#   'masks',
#   'only',
#   'thirteen',
#   'effective',
#   'that',
#   'still',
#   'something',
#   'should',
#   'provided',
#   'what',
#   'your',
#   'point',
#   'until',
#   'like',
#   'ninety',
#   'vaccination',
#   'virus',
#   'will',
#   'still',
#   'mutate',
#   'reduction',
#   'transmission'],
#  ['biggest',
#   'night',
#   'comedy',
#   'finally',
#   'here',
#   'seven',
#   'doors',
#   'open',
#   'eight',
#   'show',
#   'begins',
#   'guests',
#   'older',
#   'must',
#   'provide',
#   'proof',
#   'full',
#   'vaccination',
#   'negative',
#   'test',
#   'visit',
#   'more',
#   'times',
#   'lineup',
#   'subject',
#   'change'],
#  ['except',
#   'many',
#   'businesses',
#   'including',
#   'retail',
#   'bars',
#   'restaurants',
#   'will',
#   'still',
#   'require',
#   'masks',
#   'proof',
#   'vaccination',
#   'their',
#   'freedom'],
#  ['highlights',
#   'five',
#   'cases',
#   'north',
#   'central',
#   'zone',
#   'highest',
#   'cases',
#   'thirty',
#   'outbreaks',
#   'confirmed',
#   'high',
#   'risk',
#   'settings',
#   'those',
#   'over',
#   'five',
#   'have',
#   'received',
#   'doses',
#   'vaccine',
#   'regina',
#   'area',
#   'with',
#   'highest',
#   'rate',
#   'vaccination',
#   'other',
#   'areas',
#   'below',
#   'eighty'],
#  ['film',
#   'academy',
#   'reportedly',
#   'require',
#   'proof',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'oscars'],
#  ['time', 'playoffs', 'start', 'there', 'vaccination', 'requirements'],
#  ['said',
#   'right',
#   'moment',
#   'benefit',
#   'omicron',
#   'seeming',
#   'mildness',
#   'country',
#   'high',
#   'vaccination',
#   'rate',
#   'percent',
#   'entire',
#   'population',
#   'been',
#   'fully',
#   'vaccinated',
#   'percent',
#   'have',
#   'received',
#   'additional',
#   'shot',
#   'denmark'],
#  ['what',
#   'mean',
#   'problem',
#   'they',
#   'choose',
#   'their',
#   'children',
#   'then',
#   'need',
#   'babysitter',
#   'maybe',
#   'their',
#   'kids',
#   'public',
#   'unvaccinated',
#   'woulf',
#   'spur',
#   'parents',
#   'choose',
#   'vaccination',
#   'which',
#   'optimal'],
#  ['since',
#   'here',
#   'reportedly',
#   'stopped',
#   'facilitating',
#   'payments',
#   'vaccination',
#   'control',
#   'group'],
#  ['what',
#   'happened',
#   'following',
#   'guidelines',
#   'what',
#   'cave',
#   'what',
#   'gonna',
#   'happen',
#   'when',
#   'rates',
#   'climb',
#   'again',
#   'cali',
#   'good',
#   'vaccination',
#   'rate',
#   'does',
#   'failed',
#   'this',
#   'state'],
#  ['couldn',
#   'even',
#   'answer',
#   'opposition',
#   'leader',
#   'question',
#   'during',
#   'debate',
#   'questioning',
#   'about',
#   'much',
#   'vaccination',
#   'rate',
#   'enough',
#   'before',
#   'these',
#   'mandates',
#   'lifted',
#   'this',
#   'clearly',
#   'lead',
#   'this',
#   'great',
#   'country',
#   'incompetent'],
#  ['york',
#   'state',
#   'dropping',
#   'mask',
#   'requirements',
#   'broadway',
#   'arts',
#   'artsnews',
#   'broadway',
#   'mask',
#   'vaccination',
#   'policy',
#   'will',
#   'remain',
#   'place',
#   'through',
#   'least',
#   'april',
#   'thirty',
#   'most',
#   'recent',
#   'extension',
#   'date',
#   'policy',
#   'announced',
#   'last',
#   'month',
#   'broadway'],
#  ['proof',
#   'world',
#   'being',
#   'taken',
#   'over',
#   'whistles',
#   'being',
#   'blamed',
#   'heart',
#   'attacks',
#   'myocarditis',
#   'occurring',
#   'chests',
#   'athletes',
#   'field',
#   'also',
#   'ottawa',
#   'citizens',
#   'concerned',
#   'about',
#   'exhaust',
#   'trucks',
#   'five',
#   'year',
#   'died',
#   'minutes',
#   'after',
#   'vaccination'],
#  ['brian',
#   'temple',
#   'diskusses',
#   'efforts',
#   'debunk',
#   'vaccination',
#   'mistruths',
#   'offers',
#   'advice',
#   'people',
#   'wanting',
#   'into',
#   'health',
#   'care',
#   'shares',
#   'thoughts',
#   'black',
#   'history'],
#  ['check', 'england', 'covid', 'death', 'spikes', 'after', 'vaccination'],
#  ['more',
#   'than',
#   'evidence',
#   'that',
#   'masks',
#   'little',
#   'good',
#   'start',
#   'with',
#   'vaccination',
#   'stats',
#   'then',
#   'about',
#   'masks',
#   'cable',
#   'upcoming'],
#  ['sorry',
#   'know',
#   'important',
#   'convince',
#   'people',
#   'covid',
#   'instead',
#   'getting',
#   'vaccination',
#   'kink',
#   'shaming',
#   'tricked',
#   'people',
#   'read',
#   'that',
#   'article',
#   'share',
#   'time',
#   'because',
#   'sounds',
#   'like',
#   'what',
#   'they',
#   'want',
#   'believe'],
#  ['agree',
#   'tried',
#   'steer',
#   'conversation',
#   'towards',
#   'ridiculous',
#   'blocking',
#   'people',
#   'getting',
#   'tested',
#   'vaccine',
#   'mandates',
#   'distraction',
#   'will',
#   'dropped',
#   'soon',
#   'anyway',
#   'leadership',
#   'viewed',
#   'them',
#   'just',
#   'tool',
#   'encourage',
#   'vaccination',
#   'that',
#   'work',
#   'done'],
#  ['oscar',
#   'hypocrisy',
#   'goes',
#   'twitter',
#   'reacts',
#   'academy',
#   'awards',
#   'requiring',
#   'proof',
#   'vaccination'],
#  ['lifetime',
#   'went',
#   'death',
#   'sentence',
#   'very',
#   'manageable',
#   'condition',
#   'might',
#   'even',
#   'have',
#   'vaccination',
#   'against',
#   'soon',
#   'that',
#   'amazing',
#   'testament',
#   'science'],
#  ['montagnier',
#   'beliefs',
#   'about',
#   'vaccination',
#   'milan',
#   'fifteen',
#   'said',
#   'shared',
#   'that',
#   'will',
#   'unvaccinated',
#   'defend',
#   'humanity',
#   'according',
#   'reliable',
#   'sources',
#   'italian',
#   'translator',
#   'translates',
#   'unvaccinated',
#   'guardians',
#   'humanity',
#   'seeker',
#   'truth'],
#  ['eight',
#   'makary',
#   'being',
#   'misleading',
#   'when',
#   'uses',
#   'paper',
#   'diskuss',
#   'natural',
#   'immunity',
#   'vaccination',
#   'since',
#   'assessing',
#   'neutralization',
#   'note',
#   'difference',
#   'between',
#   'what',
#   'paper',
#   'twitter',
#   'claim',
#   'about',
#   'paper'],
#  ['evidence',
#   'increased',
#   'infection',
#   'risk',
#   'following',
#   'third',
#   'dose',
#   'exacerbated',
#   'vaccination',
#   'drive',
#   'during',
#   'omicron',
#   'wave',
#   'ukhsa',
#   'data',
#   'show'],
#  ['make',
#   'right',
#   'governed',
#   'airlines',
#   'they',
#   'want',
#   'institute',
#   'mandates',
#   'they',
#   'this',
#   'longer',
#   'about',
#   'public',
#   'health',
#   'given',
#   'ninety',
#   'vaccination',
#   'this',
#   'about',
#   'individual',
#   'health'],
#  ['expanding',
#   'vaccination',
#   'requirements',
#   'health',
#   'care',
#   'professionals'],
#  ['will',
#   'room',
#   'please',
#   'make',
#   'sure',
#   'rsvp',
#   'vaccination',
#   'cards',
#   'masks',
#   'required',
#   'link',
#   'below'],
#  ['well',
#   'with',
#   'each',
#   'answer',
#   'managed',
#   'place',
#   'word',
#   'vaccination',
#   'diminutives',
#   'course',
#   'strong',
#   'national',
#   'juju'],
#  ['really',
#   'happy',
#   'about',
#   'this',
#   'minority',
#   'with',
#   'these',
#   'feelings',
#   'kids',
#   'five',
#   'under',
#   'still',
#   'vaxxed',
#   'many',
#   'people',
#   'remain',
#   'unvaxxed',
#   'this',
#   'says',
#   'fuck',
#   'anyone',
#   'immunocompromised',
#   'full',
#   'vaccination',
#   'clark',
#   'county',
#   'still',
#   'below'],
#  ['canadian',
#   'truckers',
#   'with',
#   'ninety',
#   'vaccination',
#   'rate',
#   'more',
#   'vaccinated',
#   'than',
#   'single',
#   'demographic',
#   'group',
#   'america',
#   'that',
#   'come',
#   'across',
#   'except',
#   'doctors'],
#  ['seriously',
#   'well',
#   'documented',
#   'that',
#   'risk',
#   'transmitting',
#   'covid',
#   'same',
#   'regardless',
#   'vaccination',
#   'status'],
#  ['minneapolis',
#   'paul',
#   'immediately',
#   'lift',
#   'mandate',
#   'requiring',
#   'proof',
#   'vaccination',
#   'negative',
#   'test'],
#  ['proof', 'vaccination', 'could', 'used', 'republicans', 'voter'],
#  ['like', 'vaccination'],
#  ['people',
#   'defend',
#   'rogan',
#   'like',
#   'that',
#   'tough',
#   'conversations',
#   'with',
#   'wide',
#   'range',
#   'voices',
#   'then',
#   'does',
#   'never',
#   'seem',
#   'host',
#   'critical',
#   'race',
#   'theorists',
#   'trans',
#   'rights',
#   'activists',
#   'real',
#   'doctors',
#   'defend',
#   'vaccination',
#   'anyone',
#   'might',
#   'actually',
#   'challenge'],
#  ['vaccination',
#   'alone',
#   'solution',
#   'then',
#   'need',
#   'next',
#   'vaccines',
#   'that',
#   'protect',
#   'broadly',
#   'across',
#   'variants',
#   'create',
#   'sterilyzing',
#   'immune',
#   'response',
#   'body',
#   'that',
#   'will',
#   'take',
#   'time',
#   'interim',
#   'premiers',
#   'ignore',
#   'protections',
#   'live',
#   'with'],
#  ['many',
#   'businesses',
#   'introduced',
#   'proof',
#   'vaccination',
#   'mandatory',
#   'masking',
#   'measures',
#   'before',
#   'government',
#   'with',
#   'public',
#   'health',
#   'orders',
#   'could',
#   'businesses',
#   'keep',
#   'those',
#   'requirements',
#   'their',
#   'patrons',
#   'regina',
#   'lawyer',
#   'legal',
#   'opinion',
#   'listen'],
#  ['dinner',
#   'believe',
#   'this',
#   'something',
#   'spend',
#   'time',
#   'thinking',
#   'about',
#   'vaccine',
#   'passports',
#   'essentially',
#   'social',
#   'gulag',
#   'then',
#   'have',
#   'well',
#   'what',
#   'about',
#   'that',
#   'hold',
#   'your',
#   'proof',
#   'vaccination',
#   'ready',
#   'hostess'],
#  ['canr',
#   'lgbtq',
#   'adults',
#   'have',
#   'higher',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'rates',
#   'than',
#   'heterosexual',
#   'adults',
#   'pandemic',
#   'unique',
#   'impact',
#   'lgbtq',
#   'community',
#   'says',
#   'lgbt',
#   'persons',
#   'increased',
#   'risk',
#   'severe',
#   'covid',
#   'nineteen',
#   'illness',
#   'view',
#   'article'],
#  ['haven',
#   'even',
#   'gotten',
#   'original',
#   'vaccination',
#   'because',
#   'want',
#   'because',
#   'allowed',
#   'make',
#   'medical',
#   'decisions'],
#  ['says',
#   'countries',
#   'with',
#   'lower',
#   'vaccination',
#   'rates',
#   'than',
#   'canada',
#   'have',
#   'reopened',
#   'asks',
#   'trudeau',
#   'only',
#   'mandates',
#   'reopen',
#   'country',
#   'canadians',
#   'vaccinated',
#   'trudeau',
#   'responds',
#   'says',
#   'vaccines',
#   'will',
#   'help',
#   'lift',
#   'restrictions',
#   'cdnpoli'],
#  ['mask',
#   'vaccination',
#   'requirements',
#   'tyranny',
#   'people',
#   'love',
#   'throwing',
#   'that',
#   'word',
#   'around',
#   'name',
#   'calling',
#   'hominem',
#   'attacks',
#   'going',
#   'make',
#   'your',
#   'argument',
#   'better',
#   'toodles'],
#  ['anti', 'vaccination', 'anti', 'covid', 'vaccination'],
#  ['still',
#   'need',
#   'covid',
#   'nineteen',
#   'vaccine',
#   'louisianians',
#   'their',
#   'first',
#   'covid',
#   'nineteen',
#   'vaccination',
#   'shot',
#   'eligible',
#   'receive',
#   'including',
#   'children',
#   'ages',
#   'five',
#   'seventeen'],
#  ['make',
#   'vaccination',
#   'process',
#   'easy',
#   'close',
#   'home',
#   'people',
#   'campaign',
#   'focusing',
#   'getting',
#   'covid',
#   'nineteen',
#   'vaccines',
#   'east',
#   'toronto',
#   'residents',
#   'starts',
#   'this',
#   'saturday'],
#  ['choosing',
#   'good',
#   'policy',
#   'choices',
#   'making',
#   'wedge',
#   'anything',
#   'conservatives',
#   'that',
#   'politicized',
#   'issue',
#   'knee',
#   'jerk',
#   'criticizing',
#   'every',
#   'choice',
#   'every',
#   'step',
#   'naturally',
#   'trudeau',
#   'chose',
#   'vaccination',
#   'conservatives',
#   'chose',
#   'opposite'],
#  ['when',
#   'there',
#   'vaccine',
#   'incompetence',
#   'allowed',
#   'isolated',
#   'covid',
#   'infections',
#   'spread',
#   'epidemic',
#   'proportions',
#   'requiring',
#   'trump',
#   'shutdown',
#   'trump',
#   'recession',
#   'biden',
#   'american',
#   'rescue',
#   'plan',
#   'ended',
#   'trump',
#   'epidemic',
#   'recession',
#   'organizing',
#   'vaccination',
#   'programs'],
#  ['photo',
#   'your',
#   'vaccination',
#   'card',
#   'will',
#   'sufficient',
#   'entry',
#   'thanks'],
#  ['watched',
#   'vice',
#   'story',
#   'trying',
#   'make',
#   'feel',
#   'guilty',
#   'making',
#   'people',
#   'that',
#   'denied',
#   'covid',
#   'refused',
#   'vaccination',
#   'later',
#   'died'],
#  ['been',
#   'watching',
#   'coverage',
#   'this',
#   'insanity',
#   'anti',
#   'vaccination',
#   'trucker',
#   'protests',
#   'their',
#   'threat',
#   'trucker',
#   'protest',
#   'super',
#   'bowl',
#   'this',
#   'would',
#   'annoy',
#   'privilege',
#   'class',
#   'other',
#   'wealthy',
#   'people',
#   'that',
#   'only',
#   'people',
#   'could',
#   'afford',
#   'tickets',
#   'range',
#   'tickets',
#   'prices'],
#  ['like',
#   'masks',
#   'socialdistancing',
#   'vaccination',
#   'because',
#   'many',
#   'still',
#   'refuse',
#   'vaccinated',
#   'while',
#   'people',
#   'much',
#   'world',
#   'even',
#   'have',
#   'access',
#   'vaccine',
#   'will',
#   'more',
#   'variations',
#   'resulting',
#   'infections',
#   'deaths',
#   'wouldn',
#   'assume',
#   'that',
#   'wise',
#   'alien',
#   'four'],
#  ...]

# %% [markdown]
# ## POS Tagging

# %%
tokens = tokenised_words_only[0]
tokens
# Out:
# ['want',
#  'find',
#  'racism',
#  'force',
#  'people',
#  'inject',
#  'themselves',
#  'that',
#  'what',
#  'bunch',
#  'people',
#  'races',
#  'standing',
#  'against',
#  'forced',
#  'vaccination',
#  'against',
#  'vaxx',
#  'some',
#  'people',
#  'need',
#  'these',
#  'vaxx',
#  'support',
#  'those',
#  'people',
#  'getting',
#  'their',
#  'shot',
#  'draw',
#  'line',
#  'force']

# %%
nltk.pos_tag(tokens)
# Out:
# [('want', 'JJ'),
#  ('find', 'VBP'),
#  ('racism', 'NN'),
#  ('force', 'NN'),
#  ('people', 'NNS'),
#  ('inject', 'VBP'),
#  ('themselves', 'PRP'),
#  ('that', 'IN'),
#  ('what', 'WP'),
#  ('bunch', 'JJ'),
#  ('people', 'NNS'),
#  ('races', 'NNS'),
#  ('standing', 'VBG'),
#  ('against', 'IN'),
#  ('forced', 'VBN'),
#  ('vaccination', 'NN'),
#  ('against', 'IN'),
#  ('vaxx', 'FW'),
#  ('some', 'DT'),
#  ('people', 'NNS'),
#  ('need', 'VBP'),
#  ('these', 'DT'),
#  ('vaxx', 'JJ'),
#  ('support', 'NN'),
#  ('those', 'DT'),
#  ('people', 'NNS'),
#  ('getting', 'VBG'),
#  ('their', 'PRP$'),
#  ('shot', 'JJ'),
#  ('draw', 'JJ'),
#  ('line', 'NN'),
#  ('force', 'NN')]

# %%
pos_tagged = []

for each in tokenised_words_only:
    pos_tags = nltk.pos_tag(each)
    pos_tagged.append(pos_tags)

# %%
pos_tagged
# Out:
# [[('want', 'JJ'),
#   ('find', 'VBP'),
#   ('racism', 'NN'),
#   ('force', 'NN'),
#   ('people', 'NNS'),
#   ('inject', 'VBP'),
#   ('themselves', 'PRP'),
#   ('that', 'IN'),
#   ('what', 'WP'),
#   ('bunch', 'JJ'),
#   ('people', 'NNS'),
#   ('races', 'NNS'),
#   ('standing', 'VBG'),
#   ('against', 'IN'),
#   ('forced', 'VBN'),
#   ('vaccination', 'NN'),
#   ('against', 'IN'),
#   ('vaxx', 'FW'),
#   ('some', 'DT'),
#   ('people', 'NNS'),
#   ('need', 'VBP'),
#   ('these', 'DT'),
#   ('vaxx', 'JJ'),
#   ('support', 'NN'),
#   ('those', 'DT'),
#   ('people', 'NNS'),
#   ('getting', 'VBG'),
#   ('their', 'PRP$'),
#   ('shot', 'JJ'),
#   ('draw', 'JJ'),
#   ('line', 'NN'),
#   ('force', 'NN')],
#  [('this', 'DT'),
#   ('child', 'NN'),
#   ('almost', 'RB'),
#   ('died', 'VBD'),
#   ('tetanus', 'JJ'),
#   ('spent', 'JJ'),
#   ('months', 'NNS'),
#   ('hospital', 'JJ'),
#   ('cost', 'NN'),
#   ('around', 'IN'),
#   ('parents', 'NNS'),
#   ('still', 'RB'),
#   ('refused', 'VBD'),
#   ('vaccination', 'NN'),
#   ('after', 'IN'),
#   ('this', 'DT'),
#   ('pandemic', 'JJ')],
#  [('just', 'RB'),
#   ('remember', 'VB'),
#   ('leblanc', 'JJ'),
#   ('pressure', 'NN'),
#   ('that', 'WDT'),
#   ('provincial', 'JJ'),
#   ('business', 'NN'),
#   ('world', 'NN'),
#   ('asked', 'VBD'),
#   ('able', 'JJ'),
#   ('open', 'JJ'),
#   ('borders', 'NNS'),
#   ('traffic', 'NN'),
#   ('will', 'MD'),
#   ('provincial', 'VB'),
#   ('govt', 'NN'),
#   ('included', 'VBD'),
#   ('block', 'NN'),
#   ('tourists', 'NNS'),
#   ('will', 'MD'),
#   ('have', 'VB'),
#   ('pass', 'VBN'),
#   ('vaccination', 'NN'),
#   ('hotel', 'NN'),
#   ('restaurant', 'NN')],
#  [('would', 'MD'),
#   ('expect', 'VB'),
#   ('cases', 'NNS'),
#   ('rise', 'VBP'),
#   ('significantly', 'RB'),
#   ('course', 'NN'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('come', 'VBP'),
#   ('into', 'IN'),
#   ('play', 'NN'),
#   ('does', 'VBZ'),
#   ('space', 'NN'),
#   ('adults', 'NNS'),
#   ('usually', 'RB'),
#   ('confined', 'VBD'),
#   ('single', 'JJ'),
#   ('space', 'NN'),
#   ('with', 'IN'),
#   ('many', 'JJ'),
#   ('people', 'NNS'),
#   ('school', 'NN'),
#   ('students', 'NNS'),
#   ('data', 'VBP'),
#   ('states', 'NNS'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('lifted', 'VBN'),
#   ('those', 'DT'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('bears', 'VBZ'),
#   ('this', 'DT')],
#  [('depends', 'VBZ'),
#   ('whether', 'IN'),
#   ('vaccination', 'NN'),
#   ('status', 'NN'),
#   ('embedded', 'VBD'),
#   ('code', 'NN'),
#   ('itself', 'PRP'),
#   ('code', 'NN'),
#   ('just', 'RB'),
#   ('link', 'VB'),
#   ('that', 'DT'),
#   ('connects', 'VBZ'),
#   ('back', 'RB'),
#   ('read', 'VBN'),
#   ('about', 'IN'),
#   ('when', 'WRB'),
#   ('released', 'VBN'),
#   ('remember', 'VB'),
#   ('will', 'MD'),
#   ('find', 'VB'),
#   ('again', 'RB')],
#  [('could', 'MD'),
#   ('have', 'VB'),
#   ('ripped', 'VBN'),
#   ('harder', 'JJR'),
#   ('think', 'VBP'),
#   ('masking', 'VBG'),
#   ('isolation', 'NN'),
#   ('ultimately', 'RB'),
#   ('impact', 'JJ'),
#   ('honest', 'JJS'),
#   ('question', 'NN'),
#   ('look', 'VBP'),
#   ('those', 'DT'),
#   ('spikes', 'NNS'),
#   ('think', 'VBP'),
#   ('maybe', 'RB'),
#   ('they', 'PRP'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('looked', 'VBN'),
#   ('same', 'JJ'),
#   ('matter', 'NN'),
#   ('what', 'WP'),
#   ('with', 'IN'),
#   ('vaccination', 'NN'),
#   ('only', 'RB'),
#   ('thing', 'NN'),
#   ('that', 'IN'),
#   ('definitively', 'RB'),
#   ('worked', 'VBD')],
#  [('they', 'PRP'),
#   ('this', 'DT'),
#   ('vaccination', 'NN'),
#   ('centers', 'NNS'),
#   ('well', 'RB'),
#   ('they', 'PRP'),
#   ('refused', 'VBD'),
#   ('elderly', 'JJ'),
#   ('parent', 'NN'),
#   ('wear', 'NN'),
#   ('over', 'IN'),
#   ('masks', 'NNS'),
#   ('lady', 'JJ'),
#   ('very', 'RB'),
#   ('rude', 'VBP'),
#   ('said', 'VBD'),
#   ('could', 'MD'),
#   ('have', 'VB'),
#   ('covid', 'VBN'),
#   ('nineteen', 'NNS'),
#   ('could', 'MD'),
#   ('mask', 'VB'),
#   ('refused', 'VBD'),
#   ('take', 'VB'),
#   ('answer', 'NN'),
#   ('said', 'VBD'),
#   ('begrudgingly', 'RB'),
#   ('absurd', 'JJ')],
#  [('part', 'NN'),
#   ('vanguard', 'NN'),
#   ('vaccination', 'NN'),
#   ('awareness', 'NN'),
#   ('project', 'NN'),
#   ('series', 'NN'),
#   ('free', 'JJ'),
#   ('tools', 'NNS'),
#   ('help', 'VBP'),
#   ('suite', 'VB'),
#   ('leaders', 'NNS'),
#   ('combat', 'VBP'),
#   ('vaccine', 'JJ'),
#   ('hesitancy', 'NN'),
#   ('resistance', 'NN'),
#   ('podcasts', 'NNS'),
#   ('videos', 'VBP'),
#   ('articles', 'NNS'),
#   ('available', 'JJ'),
#   ('covidvaccineconfidence', 'NN'),
#   ('vanguardvaccinationproject', 'NN')],
#  [('correct', 'NN'),
#   ('about', 'IN'),
#   ('vaccines', 'NNS'),
#   ('their', 'PRP$'),
#   ('stated', 'JJ'),
#   ('goal', 'NN'),
#   ('about', 'IN'),
#   ('vaccination', 'NN'),
#   ('breaking', 'NN'),
#   ('blogger', 'NN'),
#   ('reports', 'NNS'),
#   ('factual', 'JJ'),
#   ('news', 'NN'),
#   ('accident', 'NN'),
#   ('this', 'DT'),
#   ('about', 'IN'),
#   ('vaccines', 'NNS'),
#   ('least', 'JJS'),
#   ('know', 'VBP'),
#   ('read', 'JJ'),
#   ('positive', 'JJ'),
#   ('steps', 'NNS'),
#   ('towards', 'NNS'),
#   ('competence', 'NN')],
#  [('does', 'VBZ'),
#   ('hurt', 'VB'),
#   ('your', 'PRP$'),
#   ('head', 'NN'),
#   ('actually', 'RB'),
#   ('your', 'PRP$'),
#   ('brain', 'NN'),
#   ('seem', 'VBP'),
#   ('incredibly', 'RB'),
#   ('brainwashed', 'VBN'),
#   ('places', 'NNS'),
#   ('with', 'IN'),
#   ('highest', 'JJS'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('world', 'NN'),
#   ('have', 'VBP'),
#   ('some', 'DT'),
#   ('highest', 'JJS'),
#   ('case', 'NN'),
#   ('counts', 'VBZ'),
#   ('everyone', 'NN'),
#   ('that', 'WDT'),
#   ('disagrees', 'VBZ'),
#   ('with', 'IN'),
#   ('your', 'PRP$'),
#   ('compliance', 'NN'),
#   ('totaltiarin', 'JJ'),
#   ('dictatorships', 'NNS'),
#   ('must', 'MD'),
#   ('called', 'VBN'),
#   ('names', 'NNS')],
#  [('world', 'NN'),
#   ('wide', 'JJ'),
#   ('mass', 'NN'),
#   ('vaccination', 'NN'),
#   ('leading', 'VBG'),
#   ('world', 'NN'),
#   ('wide', 'JJ'),
#   ('digital', 'JJ'),
#   ('passport', 'NN'),
#   ('their', 'PRP$'),
#   ('goal', 'NN'),
#   ('populationcontrol', 'NN')],
#  [('vaccinations', 'NNS'),
#   ('still', 'RB'),
#   ('need', 'VBP'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('restaurants', 'NNS'),
#   ('movie', 'NN'),
#   ('theaters', 'NNS'),
#   ('museums', 'VBP'),
#   ('large', 'JJ'),
#   ('arenas', 'NNS'),
#   ('gyms', 'VBP'),
#   ('fitness', 'NN'),
#   ('centers', 'NNS'),
#   ('vaccination', 'VBP'),
#   ('rate', 'NN'),
#   ('more', 'RBR'),
#   ('three', 'CD'),
#   ('three', 'CD')],
#  [('following', 'VBG'),
#   ('tweet', 'NN'),
#   ('didn', 'NNS'),
#   ('even', 'RB'),
#   ('twelve', 'VBP'),
#   ('hours', 'NNS'),
#   ('before', 'IN'),
#   ('prince', 'NN'),
#   ('charles', 'NNS'),
#   ('announced', 'VBD'),
#   ('reinfection', 'NN'),
#   ('even', 'RB'),
#   ('after', 'IN'),
#   ('vaccination', 'NN'),
#   ('booster', 'NN'),
#   ('clearly', 'RB'),
#   ('previous', 'JJ'),
#   ('infection', 'NN'),
#   ('protects', 'VBZ'),
#   ('this', 'DT'),
#   ('point', 'NN'),
#   ('does', 'VBZ'),
#   ('boris', 'VB'),
#   ('johnson', 'NN'),
#   ('exude', 'CC'),
#   ('some', 'DT'),
#   ('sort', 'NN'),
#   ('hypnotoad', 'NN'),
#   ('like', 'IN'),
#   ('pheromone', 'NN'),
#   ('something', 'NN')],
#  [('vaccination', 'NN')],
#  [('private', 'JJ'),
#   ('businesses', 'NNS'),
#   ('enforce', 'VBP'),
#   ('vaccination', 'NN'),
#   ('mandates', 'NNS'),
#   ('they', 'PRP'),
#   ('choose', 'VBP')],
#  [('understand', 'RB'),
#   ('exactly', 'RB'),
#   ('what', 'WP'),
#   ('needs', 'VBZ'),
#   ('understood', 'JJ'),
#   ('lame', 'NN'),
#   ('link', 'VBD'),
#   ('even', 'RB'),
#   ('remains', 'VBZ'),
#   ('lame', 'JJ'),
#   ('when', 'WRB'),
#   ('vaccination', 'NN'),
#   ('compulsory', 'NN'),
#   ('will', 'MD'),
#   ('come', 'VB'),
#   ('back', 'RB'),
#   ('bawl', 'NN'),
#   ('there', 'EX')],
#  [('story', 'NN'),
#   ('with', 'IN'),
#   ('martha', 'NN'),
#   ('mccallum', 'NN'),
#   ('senior', 'JJ'),
#   ('medical', 'JJ'),
#   ('advisor', 'NN'),
#   ('robert', 'NN'),
#   ('redfield', 'NN'),
#   ('comments', 'NNS'),
#   ('confusing', 'VBG'),
#   ('messaging', 'VBG'),
#   ('spread', 'NN'),
#   ('omicron', 'FW'),
#   ('importance', 'NN'),
#   ('maintaining', 'VBG'),
#   ('your', 'PRP$'),
#   ('vaccination', 'NN'),
#   ('status', 'NN'),
#   ('watch', 'VBP'),
#   ('full', 'JJ'),
#   ('interview', 'NN'),
#   ('below', 'IN')],
#  [('world', 'NN'),
#   ('virologist', 'NN'),
#   ('montagnier', 'NN'),
#   ('winner', 'NN'),
#   ('nobel', 'JJ'),
#   ('prize', 'NN'),
#   ('diskovery', 'NN'),
#   ('died', 'VBD'),
#   ('today', 'NN'),
#   ('warned', 'VBD'),
#   ('beginning', 'VBG'),
#   ('that', 'IN'),
#   ('covid', 'NN'),
#   ('nineteen', 'NN'),
#   ('made', 'VBD'),
#   ('that', 'IN'),
#   ('mass', 'NN'),
#   ('vaccination', 'NN'),
#   ('with', 'IN'),
#   ('leaky', 'JJ'),
#   ('vaccines', 'NNS'),
#   ('would', 'MD'),
#   ('generate', 'VB'),
#   ('endless', 'JJ'),
#   ('variants', 'NNS'),
#   ('right', 'JJ'),
#   ('both', 'DT'),
#   ('counts', 'NNS')],
#  [('obvious', 'JJ'),
#   ('common', 'JJ'),
#   ('sense', 'NN'),
#   ('solution', 'NN'),
#   ('always', 'RB'),
#   ('take', 'VBP'),
#   ('free', 'JJ'),
#   ('safe', 'JJ'),
#   ('vaccination', 'NN'),
#   ('against', 'IN'),
#   ('deadly', 'RB'),
#   ('virus', 'JJ'),
#   ('then', 'RB'),
#   ('carry', 'VBP'),
#   ('about', 'IN'),
#   ('your', 'PRP$'),
#   ('business', 'NN'),
#   ('like', 'IN'),
#   ('lunatic', 'JJ')],
#  [('sure', 'JJ'),
#   ('tootin', 'NN'),
#   ('remember', 'NN'),
#   ('grew', 'VBD'),
#   ('jackson', 'NN'),
#   ('least', 'JJS'),
#   ('place', 'NN'),
#   ('long', 'RB'),
#   ('associated', 'VBN'),
#   ('with', 'IN'),
#   ('republican', 'JJ'),
#   ('party', 'NN'),
#   ('familiar', 'JJ'),
#   ('with', 'IN'),
#   ('conservative', 'JJ'),
#   ('mien', 'NN'),
#   ('mindset', 'NN'),
#   ('speak', 'VBP'),
#   ('that', 'IN'),
#   ('think', 'VBP'),
#   ('plain', 'JJ'),
#   ('language', 'NN'),
#   ('think', 'VBP'),
#   ('covid', 'NN'),
#   ('should', 'MD'),
#   ('mandatory', 'VB'),
#   ('vaccination', 'NN')],
#  [('which', 'WDT'),
#   ('variants', 'NNS'),
#   ('were', 'VBD'),
#   ('involved', 'VBN'),
#   ('what', 'WP'),
#   ('vaccination', 'NN'),
#   ('masking', 'VBG'),
#   ('ventilation', 'NN'),
#   ('around', 'IN'),
#   ('kids', 'NNS'),
#   ('time', 'NN'),
#   ('meaningless', 'JJ'),
#   ('kids', 'NNS'),
#   ('aren', 'RB'),
#   ('danger', 'JJR'),
#   ('unless', 'IN'),
#   ('mean', 'JJ'),
#   ('kids', 'NNS'),
#   ('have', 'VBP'),
#   ('will', 'MD'),
#   ('ever', 'RB'),
#   ('danger', 'VB'),
#   ('matter', 'NN'),
#   ('what', 'WP')],
#  [('last', 'JJ'),
#   ('looked', 'VBD'),
#   ('hadn', 'JJ'),
#   ('actually', 'RB'),
#   ('county', 'JJ'),
#   ('vaccination', 'NN'),
#   ('threshold', 'NN'),
#   ('because', 'IN'),
#   ('difference', 'NN'),
#   ('between', 'IN'),
#   ('data', 'NNS'),
#   ('most', 'RBS'),
#   ('secondary', 'JJ'),
#   ('schools', 'NNS'),
#   ('have', 'VBP'),
#   ('though', 'IN')],
#  [('what', 'WP'),
#   ('your', 'PRP$'),
#   ('saying', 'VBG'),
#   ('that', 'IN'),
#   ('alberta', 'NN'),
#   ('businesses', 'NNS'),
#   ('that', 'WDT'),
#   ('required', 'VBD'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rely', 'RB'),
#   ('alberta', 'JJ'),
#   ('government', 'NN'),
#   ('they', 'PRP'),
#   ('have', 'VBP'),
#   ('rely', 'RB'),
#   ('other', 'JJ'),
#   ('provinces', 'NNS')],
#  [('this', 'DT'),
#   ('vision', 'NN'),
#   ('public', 'JJ'),
#   ('health', 'NN'),
#   ('decisions', 'NNS'),
#   ('tied', 'VBD'),
#   ('local', 'JJ'),
#   ('conditions', 'NNS'),
#   ('spread', 'VBP'),
#   ('vaccination', 'NN'),
#   ('vulnerability', 'NN'),
#   ('also', 'RB'),
#   ('sounds', 'VBZ'),
#   ('reasonable', 'JJ'),
#   ('however', 'RB'),
#   ('years', 'NNS'),
#   ('into', 'IN'),
#   ('this', 'DT'),
#   ('acting', 'VBG'),
#   ('that', 'IN'),
#   ('what', 'WP'),
#   ('happening', 'VBG'),
#   ('naive', 'JJ'),
#   ('best', 'JJS'),
#   ('partisan', 'JJ'),
#   ('politics', 'NNS'),
#   ('even', 'RB'),
#   ('local', 'JJ'),
#   ('level', 'NN'),
#   ('often', 'RB'),
#   ('factor', 'NN')],
#  [('mean', 'NN'),
#   ('someone', 'NN'),
#   ('told', 'VBD'),
#   ('they', 'PRP'),
#   ('kill', 'VBP'),
#   ('didn', 'RB'),
#   ('vaccinated', 'VBN'),
#   ('understand', 'NN'),
#   ('thought', 'NN'),
#   ('said', 'VBD'),
#   ('vaccination', 'NN'),
#   ('lose', 'VB'),
#   ('your', 'PRP$'),
#   ('bodily', 'RB'),
#   ('autonomy', 'NN'),
#   ('then', 'RB')],
#  [('their', 'PRP$'),
#   ('concerns', 'NNS'),
#   ('real', 'JJ'),
#   ('even', 'RB'),
#   ('unfounded', 'VBD'),
#   ('addressing', 'VBG'),
#   ('them', 'PRP'),
#   ('with', 'IN'),
#   ('empathy', 'JJ'),
#   ('genuine', 'JJ'),
#   ('good', 'NN'),
#   ('will', 'MD'),
#   ('persuade', 'VB'),
#   ('them', 'PRP'),
#   ('canada', 'VB'),
#   ('similar', 'JJ'),
#   ('levels', 'NNS'),
#   ('adult', 'NN'),
#   ('vaccination', 'NN')],
#  [('seems', 'VBZ'),
#   ('like', 'IN'),
#   ('steel', 'NN'),
#   ('here', 'RB'),
#   ('about', 'RB'),
#   ('many', 'JJ'),
#   ('mandates', 'NNS'),
#   ('masks', 'NNS'),
#   ('vaccination', 'NN'),
#   ('testing', 'VBG'),
#   ('that', 'DT'),
#   ('very', 'RB'),
#   ('much', 'JJ'),
#   ('still', 'RB'),
#   ('place', 'VBP'),
#   ('relatively', 'RB'),
#   ('cost', 'NN'),
#   ('zero', 'CD'),
#   ('cost', 'NN')],
#  [('kill', 'VB'), ('sally', 'RB'), ('field', 'NN'), ('here', 'RB')],
#  [('jesus', 'NN'),
#   ('christ', 'NN'),
#   ('vaccination', 'NN'),
#   ('being', 'VBG'),
#   ('forced', 'VBN'),
#   ('carry', 'JJ'),
#   ('pregnancy', 'NN'),
#   ('term', 'NN')],
#  [('amazon', 'RB'),
#   ('allow', 'JJ'),
#   ('work', 'NN'),
#   ('without', 'IN'),
#   ('face', 'NN'),
#   ('masks', 'NNS'),
#   ('require', 'VBP'),
#   ('vaccination', 'NN'),
#   ('paid', 'VBN'),
#   ('covid', 'NN'),
#   ('leave', 'NN')],
#  [('five', 'CD'),
#   ('governments', 'NNS'),
#   ('primary', 'JJ'),
#   ('concern', 'NN'),
#   ('justification', 'NN'),
#   ('compulsory', 'NN'),
#   ('covid', 'NN'),
#   ('vaccination', 'NN'),
#   ('prevent', 'NN'),
#   ('hospitals', 'NNS'),
#   ('emergency', 'NN'),
#   ('depts', 'NNS'),
#   ('being', 'VBG'),
#   ('inundated', 'JJ'),
#   ('thus', 'RB'),
#   ('running', 'VBG'),
#   ('medical', 'JJ'),
#   ('resources', 'NNS'),
#   ('space', 'NN'),
#   ('equipment', 'NN'),
#   ('staff', 'NN'),
#   ('perhaps', 'RB'),
#   ('govt', 'NN'),
#   ('should', 'MD'),
#   ('require', 'VB'),
#   ('hospitals', 'NNS')],
#  [('when', 'WRB'),
#   ('covid', 'NN'),
#   ('vaccines', 'NNS'),
#   ('have', 'VBP'),
#   ('proven', 'VBN'),
#   ('prevent', 'JJ'),
#   ('spread', 'NN'),
#   ('covid', 'VBD'),
#   ('even', 'RB'),
#   ('before', 'IN'),
#   ('with', 'IN'),
#   ('omicron', 'NN'),
#   ('where', 'WRB'),
#   ('called', 'VBN'),
#   ('breakthrough', 'NN'),
#   ('cases', 'NNS'),
#   ('became', 'VBD'),
#   ('just', 'RB'),
#   ('positive', 'JJ'),
#   ('covid', 'NN'),
#   ('cases', 'NNS'),
#   ('omicron', 'VBP'),
#   ('didn', 'JJ'),
#   ('care', 'NN'),
#   ('vaccine', 'NN'),
#   ('status', 'NN'),
#   ('real', 'JJ'),
#   ('driving', 'VBG'),
#   ('force', 'NN'),
#   ('vaccination', 'NN'),
#   ('become', 'NN'),
#   ('minimizing', 'NN')],
#  [('vaccination', 'NN'), ('syringe', 'NN'), ('video', 'NN')],
#  [('think', 'NN'),
#   ('they', 'PRP'),
#   ('eighty', 'VBP'),
#   ('most', 'RBS'),
#   ('games', 'NNS'),
#   ('never', 'RB'),
#   ('that', 'IN'),
#   ('full', 'JJ'),
#   ('anyway', 'RB'),
#   ('meant', 'JJ'),
#   ('download', 'NN'),
#   ('green', 'NN'),
#   ('light', 'NN'),
#   ('which', 'WDT'),
#   ('based', 'VBN'),
#   ('vaccination', 'NN'),
#   ('status', 'NN'),
#   ('that', 'WDT'),
#   ('allow', 'VBP'),
#   ('enter', 'DT'),
#   ('stadium', 'NN'),
#   ('ground', 'NN'),
#   ('there', 'RB'),
#   ('unsure', 'JJ'),
#   ('they', 'PRP'),
#   ('enforce', 'VBP'),
#   ('that', 'IN'),
#   ('much', 'JJ')],
#  [('alberta', 'NN'),
#   ('businesses', 'NNS'),
#   ('that', 'WDT'),
#   ('legally', 'RB'),
#   ('still', 'RB'),
#   ('requires', 'VBZ'),
#   ('obtain', 'VB'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('there', 'EX'),
#   ('those', 'DT'),
#   ('still', 'RB'),
#   ('legally', 'RB'),
#   ('required', 'VBN')],
#  [('about', 'RB'),
#   ('medical', 'JJ'),
#   ('specialists', 'NNS'),
#   ('were', 'VBD'),
#   ('involved', 'VBN'),
#   ('vaccination', 'NN'),
#   ('effort', 'NN')],
#  [('reaction', 'NN'),
#   ('vaccine', 'NN'),
#   ('according', 'VBG'),
#   ('anaphylaxis', 'NN'),
#   ('after', 'IN'),
#   ('covid', 'NN'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('extremely', 'RB'),
#   ('rare', 'JJ'),
#   ('occurred', 'VBD'),
#   ('about', 'IN'),
#   ('five', 'CD'),
#   ('people', 'NNS'),
#   ('million', 'CD'),
#   ('vaccinated', 'VBN'),
#   ('united', 'JJ'),
#   ('states', 'NNS'),
#   ('five', 'CD'),
#   ('vaccinations', 'NNS')],
#  [('chickahominy', 'JJ'),
#   ('health', 'NN'),
#   ('district', 'NN'),
#   ('holding', 'VBG'),
#   ('vaccination', 'NN'),
#   ('clinic', 'NN'),
#   ('february', 'JJ'),
#   ('three', 'CD'),
#   ('sargent', 'NN'),
#   ('reynolds', 'NNS'),
#   ('community', 'NN'),
#   ('college', 'NN'),
#   ('please', 'NN'),
#   ('this', 'DT'),
#   ('link', 'NN'),
#   ('register', 'NN'),
#   ('walk', 'NN'),
#   ('will', 'MD'),
#   ('accepted', 'VB')],
#  [('that', 'DT'),
#   ('right', 'VBD'),
#   ('their', 'PRP$'),
#   ('body', 'NN'),
#   ('belongs', 'VBZ'),
#   ('them', 'PRP'),
#   ('what', 'WP'),
#   ('wears', 'VBZ'),
#   ('better', 'JJR'),
#   ('fight', 'NN'),
#   ('fight', 'NN'),
#   ('compulsory', 'NN'),
#   ('vaccination', 'NN'),
#   ('required', 'VBN'),
#   ('businesses', 'NNS'),
#   ('employers', 'NNS'),
#   ('this', 'DT'),
#   ('government', 'NN')],
#  [('have', 'VB'),
#   ('nothing', 'NN'),
#   ('more', 'JJR'),
#   ('report', 'NN'),
#   ('about', 'IN'),
#   ('other', 'JJ'),
#   ('than', 'IN'),
#   ('documents', 'NNS'),
#   ('trump', 'JJ'),
#   ('took', 'VBD'),
#   ('gave', 'VBD'),
#   ('back', 'RP'),
#   ('bullshit', 'NN'),
#   ('that', 'WDT'),
#   ('happened', 'VBD'),
#   ('january', 'JJ'),
#   ('about', 'IN'),
#   ('close', 'JJ'),
#   ('borders', 'NNS'),
#   ('mask', 'POS'),
#   ('vaccination', 'NN'),
#   ('mandates', 'VBZ'),
#   ('seriously', 'RB'),
#   ('people', 'NNS')],
#  [('conclusion', 'NN'),
#   ('most', 'RBS'),
#   ('definitely', 'RB'),
#   ('cannot', 'JJ'),
#   ('draw', 'VB'),
#   ('that', 'IN'),
#   ('that', 'DT'),
#   ('mask', 'NN'),
#   ('mandates', 'VBZ'),
#   ('work', 'NN'),
#   ('since', 'IN'),
#   ('death', 'NN'),
#   ('rates', 'NNS'),
#   ('much', 'RB'),
#   ('lower', 'JJR'),
#   ('those', 'DT'),
#   ('states', 'NNS'),
#   ('again', 'RB'),
#   ('this', 'DT'),
#   ('probably', 'RB'),
#   ('primarily', 'RB'),
#   ('higher', 'JJR'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS')],
#  [('never', 'RB'),
#   ('suggested', 'VBN'),
#   ('vaccination', 'NN'),
#   ('issue', 'NN'),
#   ('other', 'JJ')],
#  [('hasn', 'NN'),
#   ('trump', 'NN'),
#   ('been', 'VBN'),
#   ('arrested', 'VBN'),
#   ('look', 'RBR'),
#   ('like', 'IN'),
#   ('laughingstocks', 'NNS'),
#   ('rest', 'VBP'),
#   ('world', 'NN'),
#   ('still', 'RB'),
#   ('also', 'RB'),
#   ('terrified', 'VBN'),
#   ('truckers', 'NNS'),
#   ('they', 'PRP'),
#   ('just', 'RB'),
#   ('coming', 'VBG'),
#   ('because', 'IN'),
#   ('vaccination', 'NN'),
#   ('mandates', 'NNS'),
#   ('they', 'PRP'),
#   ('coming', 'VBG'),
#   ('because', 'IN'),
#   ('perceived', 'VBN'),
#   ('reinstatement', 'NN')],
#  [('covid', 'NNS'),
#   ('positive', 'JJ'),
#   ('when', 'WRB'),
#   ('died', 'VBD'),
#   ('amazed', 'VBN'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('haven', 'VBP'),
#   ('spun', 'VB'),
#   ('this', 'DT'),
#   ('into', 'IN'),
#   ('covid', 'JJ'),
#   ('death', 'NN'),
#   ('push', 'VBP'),
#   ('their', 'PRP$'),
#   ('vaccination', 'NN'),
#   ('agenda', 'NN')],
#  [('crossed', 'VBN'), ('with', 'IN'), ('data', 'NNS'), ('vaccination', 'NN')],
#  [('school', 'NN'),
#   ('gonna', 'NN'),
#   ('vaccination', 'NN'),
#   ('proof', 'NN'),
#   ('because', 'IN'),
#   ('they', 'PRP'),
#   ('respect', 'VBP'),
#   ('individuality', 'JJ'),
#   ('health', 'NN'),
#   ('decisions', 'NNS'),
#   ('everyone', 'NN'),
#   ('have', 'VBP'),
#   ('choice', 'NN'),
#   ('stay', 'VBN'),
#   ('virtually', 'RB'),
#   ('hate', 'VBP'),
#   ('here', 'RB')],
#  [('linked', 'VBN'),
#   ('above', 'IN'),
#   ('republican', 'JJ'),
#   ('controlled', 'VBN'),
#   ('states', 'NNS'),
#   ('which', 'WDT'),
#   ('tend', 'VBP'),
#   ('states', 'NNS'),
#   ('without', 'IN'),
#   ('mask', 'NN'),
#   ('mandates', 'NNS'),
#   ('doing', 'VBG'),
#   ('worse', 'JJR'),
#   ('than', 'IN'),
#   ('democratic', 'JJ'),
#   ('controlled', 'VBN'),
#   ('states', 'NNS'),
#   ('course', 'NN'),
#   ('they', 'PRP'),
#   ('also', 'RB'),
#   ('states', 'VBZ'),
#   ('with', 'IN'),
#   ('lower', 'JJR'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('hard', 'JJ'),
#   ('draw', 'NN'),
#   ('strong', 'JJ'),
#   ('conclusion', 'NN'),
#   ('that', 'IN')],
#  [('close', 'RB'),
#   ('neighbor', 'JJ'),
#   ('lowest', 'JJS'),
#   ('covid', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('world', 'NN')],
#  [('vaccination', 'NN'),
#   ('campaign', 'NN'),
#   ('gone', 'VBN'),
#   ('from', 'IN'),
#   ('exemplary', 'JJ'),
#   ('miserable', 'JJ'),
#   ('failure', 'NN')],
#  [('advocacy', 'NN'),
#   ('update', 'JJ'),
#   ('physician', 'NN'),
#   ('groups', 'NNS'),
#   ('urge', 'VBP'),
#   ('supreme', 'JJ'),
#   ('court', 'NN'),
#   ('uphold', 'JJ'),
#   ('vaccination', 'NN'),
#   ('requirement', 'NN'),
#   ('highlights', 'NNS'),
#   ('parity', 'NN'),
#   ('enforcement', 'NN'),
#   ('regulatory', 'JJ'),
#   ('agenda', 'NN'),
#   ('more', 'RBR'),
#   ('mentalhealth', 'NN'),
#   ('psychtwitter', 'NN')],
#  [('putting', 'VBG'),
#   ('together', 'RB'),
#   ('spreadsheet', 'VB'),
#   ('what', 'WP'),
#   ('oscar', 'NN'),
#   ('nominees', 'JJ'),
#   ('celebrities', 'NNS'),
#   ('attended', 'VBD'),
#   ('vaccination', 'NN'),
#   ('required', 'VBN'),
#   ('events', 'NNS'),
#   ('publicly', 'RB'),
#   ('spoken', 'VBN'),
#   ('about', 'RP'),
#   ('vaccine', 'NN')],
#  [('that', 'DT'),
#   ('indian', 'JJ'),
#   ('health', 'NN'),
#   ('department', 'NN'),
#   ('sorry', 'NN'),
#   ('trust', 'NN'),
#   ('people', 'NNS'),
#   ('that', 'WDT'),
#   ('look', 'VBP'),
#   ('like', 'IN'),
#   ('think', 'VBP'),
#   ('israel', 'NNS'),
#   ('with', 'IN'),
#   ('ninety', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rate', 'NN'),
#   ('such', 'JJ'),
#   ('hard', 'JJ'),
#   ('time', 'NN'),
#   ('with', 'IN'),
#   ('covid', 'NNS'),
#   ('right', 'RB')],
#  [('amerks', 'NNS'),
#   ('will', 'MD'),
#   ('longer', 'VB'),
#   ('require', 'VB'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('entry', 'NN'),
#   ('amerks', 'VBZ'),
#   ('games', 'NNS'),
#   ('events', 'NNS'),
#   ('blue', 'JJ'),
#   ('cross', 'JJ'),
#   ('arena', 'NN'),
#   ('beginning', 'VBG'),
#   ('thursday', 'JJ'),
#   ('february', 'JJ')],
#  [('employer', 'NN'),
#   ('mask', 'NN'),
#   ('mandatory', 'JJ'),
#   ('vaccination', 'NN'),
#   ('policy', 'NN'),
#   ('even', 'RB'),
#   ('provincial', 'JJ'),
#   ('federal', 'JJ'),
#   ('governments', 'NNS'),
#   ('remove', 'VB'),
#   ('mandates', 'NNS'),
#   ('employer', 'VBP'),
#   ('will', 'MD'),
#   ('still', 'RB'),
#   ('have', 'VB'),
#   ('mask', 'JJ'),
#   ('mandatory', 'JJ'),
#   ('vaccination', 'NN'),
#   ('policy', 'NN'),
#   ('what', 'WP'),
#   ('then', 'RB'),
#   ('cdnpoli', 'VBZ'),
#   ('onpoli', 'NNS')],
#  [('demystify', 'VB'),
#   ('vaccination', 'NN'),
#   ('against', 'IN'),
#   ('provided', 'VBN'),
#   ('master', 'NN'),
#   ('your', 'PRP$'),
#   ('subject', 'NN')],
#  [('need', 'NN'),
#   ('have', 'VBP'),
#   ('uniformed', 'VBN'),
#   ('rule', 'NN'),
#   ('about', 'IN'),
#   ('mask', 'NN'),
#   ('vaccination', 'NN')],
#  [('conservative', 'JJ'),
#   ('anti', 'JJ'),
#   ('abortion', 'NN'),
#   ('anti', 'JJ'),
#   ('vaccination', 'NN'),
#   ('people', 'NNS'),
#   ('thoughts', 'VBP'),
#   ('prayers', 'NNS'),
#   ('forget', 'VBP'),
#   ('prayers', 'NNS')],
#  [('classic', 'JJ'),
#   ('simpson', 'NN'),
#   ('paradox', 'NN'),
#   ('most', 'RBS'),
#   ('deaths', 'NNS'),
#   ('among', 'IN'),
#   ('elderly', 'JJ'),
#   ('people', 'NNS'),
#   ('nearly', 'RB'),
#   ('whom', 'WP'),
#   ('vaccinated', 'VBD'),
#   ('with', 'IN'),
#   ('lower', 'JJR'),
#   ('vaccination', 'NN'),
#   ('rate', 'NN'),
#   ('total', 'JJ'),
#   ('number', 'NN'),
#   ('fatalities', 'NNS'),
#   ('would', 'MD'),
#   ('much', 'RB'),
#   ('higher', 'JJR')],
#  [('sounds', 'NNS'),
#   ('like', 'IN'),
#   ('planning', 'VBG'),
#   ('masking', 'VBG'),
#   ('kids', 'NNS'),
#   ('indefinitely', 'RB'),
#   ('what', 'WP'),
#   ('hospitalization', 'NN'),
#   ('rates', 'NNS'),
#   ('vaccination', 'VBP'),
#   ('rates', 'NNS'),
#   ('deeming', 'VBG'),
#   ('necessary', 'JJ'),
#   ('finally', 'RB'),
#   ('these', 'DT'),
#   ('kids', 'NNS'),
#   ('finally', 'RB'),
#   ('back', 'RB'),
#   ('normalcy', 'JJ'),
#   ('need', 'NN'),
#   ('numbers', 'NNS')],
#  [('cases', 'NNS'),
#   ('have', 'VBP'),
#   ('gone', 'VBN'),
#   ('state', 'NN'),
#   ('highest', 'JJS'),
#   ('vaccination', 'NN'),
#   ('rate', 'NN'),
#   ('january', 'JJ'),
#   ('bullshit', 'NN'),
#   ('obvious', 'JJ'),
#   ('fake', 'JJ'),
#   ('news', 'NN'),
#   ('site', 'NN'),
#   ('with', 'IN'),
#   ('spoon', 'NN'),
#   ('this', 'DT'),
#   ('insulting', 'VBG'),
#   ('your', 'PRP$'),
#   ('intelligence', 'NN')],
#  [('there', 'RB'),
#   ('people', 'NNS'),
#   ('speaking', 'VBG'),
#   ('like', 'IN'),
#   ('choice', 'NN'),
#   ('abortions', 'NNS'),
#   ('same', 'JJ'),
#   ('choice', 'NN'),
#   ('relating', 'VBG'),
#   ('vaccines', 'NNS'),
#   ('disagree', 'JJ'),
#   ('abortion', 'NN'),
#   ('removes', 'VBZ'),
#   ('choice', 'NN'),
#   ('human', 'JJ'),
#   ('ending', 'VBG'),
#   ('human', 'JJ'),
#   ('life', 'NN'),
#   ('forced', 'VBD'),
#   ('coerced', 'JJ'),
#   ('vaccination', 'NN'),
#   ('removes', 'VBZ'),
#   ('choice', 'NN'),
#   ('forcing', 'VBG'),
#   ('human', 'JJ'),
#   ('risk', 'NN'),
#   ('permanent', 'NN'),
#   ('damage', 'NN')],
#  [('delusional', 'NN'),
#   ('over', 'IN'),
#   ('endemic', 'JJ'),
#   ('going', 'VBG'),
#   ('live', 'JJ'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('vaccination', 'NN'),
#   ('lockdowns', 'VBZ'),
#   ('masks', 'NNS'),
#   ('covid', 'NN'),
#   ('still', 'RB'),
#   ('here', 'RB'),
#   ('live', 'JJ'),
#   ('fear', 'NN'),
#   ('with', 'IN'),
#   ('taking', 'VBG'),
#   ('precaution', 'NN'),
#   ('necessary', 'JJ'),
#   ('based', 'VBN'),
#   ('other', 'JJ'),
#   ('health', 'NN'),
#   ('conditions', 'NNS')],
#  [('tell', 'NN'),
#   ('that', 'WDT'),
#   ('unvaccinated', 'JJ'),
#   ('people', 'NNS'),
#   ('died', 'VBD'),
#   ('covid', 'JJ'),
#   ('unfortunately', 'RB'),
#   ('that', 'IN'),
#   ('true', 'JJ'),
#   ('vaccination', 'NN'),
#   ('does', 'VBZ'),
#   ('indeed', 'RB'),
#   ('prevent', 'VB'),
#   ('some', 'DT'),
#   ('most', 'RBS'),
#   ('dire', 'JJ'),
#   ('results', 'NNS'),
#   ('covid', 'JJ'),
#   ('infection', 'NN'),
#   ('that', 'IN'),
#   ('pretty', 'RB'),
#   ('well', 'RB'),
#   ('established', 'VBN')],
#  [('tool', 'NN'),
#   ('surgeon', 'NN'),
#   ('general', 'JJ'),
#   ('refuses', 'VBZ'),
#   ('disklose', 'JJ'),
#   ('covid', 'NNS'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('status', 'NN')],
#  [('quebec', 'RB'),
#   ('asking', 'VBG'),
#   ('vaccinating', 'VBG'),
#   ('physicians', 'NNS'),
#   ('return', 'VBP'),
#   ('their', 'PRP$'),
#   ('regular', 'JJ'),
#   ('activities', 'NNS'),
#   ('sharp', 'JJ'),
#   ('drop', 'NN'),
#   ('attendance', 'NN'),
#   ('vaccination', 'NN'),
#   ('clinics', 'NNS'),
#   ('radio', 'VBP'),
#   ('canada', 'NN'),
#   ('reported', 'VBD'),
#   ('this', 'DT'),
#   ('morning', 'NN'),
#   ('that', 'IN'),
#   ('vaccinators', 'NNS'),
#   ('twiddling', 'VBG'),
#   ('their', 'PRP$'),
#   ('thumbs', 'NNS'),
#   ('polqc', 'NN')],
#  [('thank', 'NN'),
#   ('keeping', 'VBG'),
#   ('mask', 'JJ'),
#   ('mandate', 'NN'),
#   ('schools', 'NNS'),
#   ('need', 'VBP'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('more', 'JJR'),
#   ('education', 'NN'),
#   ('outreach', 'NN'),
#   ('students', 'NNS'),
#   ('siblings', 'NNS'),
#   ('under', 'IN'),
#   ('five', 'CD'),
#   ('vaccinated', 'JJ'),
#   ('before', 'IN'),
#   ('lifting', 'VBG'),
#   ('mask', 'NN'),
#   ('mandates', 'NNS')],
#  [('according', 'VBG'),
#   ('vaccination', 'NN'),
#   ('abortion', 'NN'),
#   ('same', 'JJ'),
#   ('thing', 'NN'),
#   ('welcome', 'NN')],
#  [('care', 'NN'),
#   ('explain', 'VBP'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('anything', 'NN'),
#   ('with', 'IN'),
#   ('vaccine', 'NN'),
#   ('talking', 'VBG'),
#   ('about', 'IN'),
#   ('person', 'NN'),
#   ('feel', 'VBP'),
#   ('about', 'IN'),
#   ('other', 'JJ'),
#   ('talking', 'VBG'),
#   ('about', 'IN'),
#   ('genuine', 'JJ'),
#   ('mental', 'JJ'),
#   ('health', 'NN'),
#   ('issue', 'NN'),
#   ('vaccination', 'NN'),
#   ('does', 'VBZ'),
#   ('exist', 'VB')],
#  [('find', 'VB'),
#   ('fixed', 'JJ'),
#   ('vaccination', 'NN'),
#   ('site', 'NN'),
#   ('your', 'PRP$'),
#   ('area', 'NN'),
#   ('getvaccinated', 'VBD'),
#   ('today', 'NN'),
#   ('visit', 'NN'),
#   ('call', 'NN'),
#   ('love', 'NN')],
#  [('three', 'CD'),
#   ('eric', 'JJ'),
#   ('adams', 'NNS'),
#   ('also', 'RB'),
#   ('repeatedly', 'RB'),
#   ('renewed', 'VBN'),
#   ('executive', 'NN'),
#   ('order', 'NN'),
#   ('which', 'WDT'),
#   ('requires', 'VBZ'),
#   ('anyone', 'NN'),
#   ('over', 'IN'),
#   ('five', 'CD'),
#   ('show', 'NN'),
#   ('proof', 'NN'),
#   ('full', 'JJ'),
#   ('vaccination', 'NN'),
#   ('participate', 'VB'),
#   ('indoor', 'JJ'),
#   ('activities', 'NNS'),
#   ('anyone', 'NN'),
#   ('eighteen', 'JJ'),
#   ('older', 'JJR'),
#   ('proof', 'NN'),
#   ('along', 'IN'),
#   ('with', 'IN'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('required', 'VBN')],
#  [('makes', 'VBZ'),
#   ('also', 'RB'),
#   ('angry', 'JJ'),
#   ('those', 'DT'),
#   ('have', 'VBP'),
#   ('diskouraged', 'VBN'),
#   ('vaccination', 'NN')],
#  [('about', 'IN'),
#   ('time', 'NN'),
#   ('well', 'RB'),
#   ('done', 'VBN'),
#   ('everyone', 'NN'),
#   ('faught', 'NN'),
#   ('this', 'DT'),
#   ('proud', 'JJ'),
#   ('revoking', 'VBG'),
#   ('vaccination', 'NN'),
#   ('condition', 'NN'),
#   ('deployment', 'NN'),
#   ('across', 'IN'),
#   ('health', 'NN'),
#   ('social', 'JJ'),
#   ('care', 'NN')],
#  [('oscars', 'NNS'),
#   ('covid', 'VBP'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('will', 'MD'),
#   ('required', 'VB'),
#   ('person', 'NN'),
#   ('attendees', 'NNS'),
#   ('exclusive', 'JJ')],
#  [('proof', 'NN'),
#   ('vaccination', 'NN'),
#   ('still', 'RB'),
#   ('required', 'VBN'),
#   ('indoor', 'JJ'),
#   ('dining', 'VBG'),
#   ('events', 'NNS'),
#   ('arenas', 'JJ'),
#   ('gyms', 'NN'),
#   ('theaters', 'NNS'),
#   ('museums', 'VBP'),
#   ('other', 'JJ'),
#   ('indoor', 'JJ'),
#   ('entertainment', 'NN'),
#   ('york', 'NN'),
#   ('city', 'NN'),
#   ('part', 'NN'),
#   ('initiative', 'NN'),
#   ('started', 'VBD'),
#   ('former', 'JJ'),
#   ('mayor', 'NN')],
#  [('what', 'WP'),
#   ('makes', 'VBZ'),
#   ('americans', 'NNS'),
#   ('think', 'VBP'),
#   ('they', 'PRP'),
#   ('have', 'VBP'),
#   ('right', 'JJ'),
#   ('challenge', 'NN'),
#   ('sovereign', 'JJ'),
#   ('nation', 'NN'),
#   ('rules', 'NNS'),
#   ('regarding', 'VBG'),
#   ('vaccination', 'NN'),
#   ('testing', 'VBG'),
#   ('this', 'DT'),
#   ('problem', 'NN'),
#   ('creation', 'NN'),
#   ('putting', 'VBG'),
#   ('self', 'PRP'),
#   ('above', 'IN'),
#   ('needs', 'NNS'),
#   ('country', 'NN'),
#   ('vaccineswork', 'NN'),
#   ('canada', 'NN')],
#  [('following', 'VBG'),
#   ('nevada', 'JJ'),
#   ('mask', 'NN'),
#   ('mandate', 'NN'),
#   ('this', 'DT'),
#   ('morning', 'NN'),
#   ('followed', 'VBD'),
#   ('suit', 'NN'),
#   ('nshe', 'NN'),
#   ('employees', 'NNS'),
#   ('students', 'NNS'),
#   ('members', 'NNS'),
#   ('public', 'JJ'),
#   ('longer', 'RB'),
#   ('required', 'VBN'),
#   ('wear', 'JJ'),
#   ('face', 'NN'),
#   ('coverings', 'NNS'),
#   ('while', 'IN'),
#   ('inside', 'IN'),
#   ('nshe', 'JJ'),
#   ('buildings', 'NNS'),
#   ('irrespective', 'JJ'),
#   ('covid', 'NN'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('status', 'NN'),
#   ('effective', 'JJ'),
#   ('immediately', 'RB')],
#  [('what', 'WP'),
#   ('stake', 'NN'),
#   ('applicants', 'NNS'),
#   ('here', 'RB'),
#   ('forcible', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rather', 'RB'),
#   ('consequences', 'VBZ'),
#   ('choice', 'NN'),
#   ('remain', 'NN'),
#   ('unvaccinated', 'JJ')],
#  [('trading', 'NN'),
#   ('players', 'NNS'),
#   ('that', 'WDT'),
#   ('injured', 'VBD'),
#   ('just', 'RB'),
#   ('claim', 'JJ'),
#   ('injuries', 'NNS'),
#   ('report', 'VBP'),
#   ('like', 'IN'),
#   ('firing', 'VBG'),
#   ('vaccinated', 'VBN'),
#   ('claiming', 'VBG'),
#   ('have', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rate', 'NN')],
#  [('really', 'RB'),
#   ('vaccination', 'JJ'),
#   ('lessons', 'NNS'),
#   ('syptoms', 'VBP'),
#   ('both', 'DT'),
#   ('immediate', 'JJ'),
#   ('long', 'JJ'),
#   ('term', 'NN'),
#   ('still', 'RB'),
#   ('unlikely', 'RB'),
#   ('will', 'MD'),
#   ('serious', 'JJ'),
#   ('cause', 'VB'),
#   ('long', 'JJ'),
#   ('term', 'NN'),
#   ('damage', 'NN'),
#   ('keep', 'VB')],
#  [('member', 'NN'),
#   ('public', 'JJ'),
#   ('health', 'NN'),
#   ('professional', 'JJ'),
#   ('submit', 'NN'),
#   ('suspected', 'VBD'),
#   ('side', 'JJ'),
#   ('effects', 'NNS'),
#   ('through', 'IN'),
#   ('yellow', 'JJ'),
#   ('card', 'NN'),
#   ('scheme', 'NN'),
#   ('nature', 'NN'),
#   ('yellow', 'JJ'),
#   ('card', 'NN'),
#   ('reporting', 'NN'),
#   ('means', 'VBZ'),
#   ('that', 'IN'),
#   ('reported', 'VBD'),
#   ('events', 'NNS'),
#   ('always', 'RB'),
#   ('proven', 'RB'),
#   ('side', 'JJ'),
#   ('effects', 'NNS'),
#   ('some', 'DT'),
#   ('events', 'NNS'),
#   ('have', 'VBP'),
#   ('happened', 'VBN'),
#   ('anyway', 'RB'),
#   ('regardless', 'JJ'),
#   ('vaccination', 'NN')],
#  [('strange', 'JJ'),
#   ('that', 'IN'),
#   ('people', 'NNS'),
#   ('claiming', 'VBG'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('want', 'VBP'),
#   ('stop', 'JJ'),
#   ('living', 'NN'),
#   ('fear', 'NN'),
#   ('causing', 'VBG'),
#   ('more', 'JJR'),
#   ('fear', 'NN'),
#   ('than', 'IN'),
#   ('mask', 'NN'),
#   ('vaccination', 'NN'),
#   ('ever', 'RB'),
#   ('caused', 'VBD'),
#   ('being', 'VBG'),
#   ('held', 'VBN'),
#   ('hostage', 'NN')],
#  [('kicking', 'VBG'),
#   ('night', 'NN'),
#   ('superbowlmusicfest', 'NN'),
#   ('with', 'IN'),
#   ('special', 'JJ'),
#   ('guests', 'NNS'),
#   ('doors', 'NNS'),
#   ('limited', 'VBD'),
#   ('number', 'NN'),
#   ('tickets', 'NNS'),
#   ('remain', 'VBP'),
#   ('guests', 'NNS'),
#   ('older', 'JJR'),
#   ('must', 'MD'),
#   ('show', 'VB'),
#   ('proof', 'JJ'),
#   ('full', 'JJ'),
#   ('vaccination', 'NN'),
#   ('test', 'NN'),
#   ('info', 'NN')],
#  [('with', 'IN'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('quite', 'RB'),
#   ('twelve', 'VBP'),
#   ('range', 'NN'),
#   ('more', 'RBR'),
#   ('thought', 'NN'),
#   ('needed', 'VBN'),
#   ('benefits', 'NNS'),
#   ('risks', 'NNS'),
#   ('unmasked', 'JJ'),
#   ('indoor', 'JJ'),
#   ('instruction', 'NN'),
#   ('glad', 'NN'),
#   ('that', 'WDT'),
#   ('allows', 'VBZ'),
#   ('unmasked', 'JJ'),
#   ('outdoor', 'JJ'),
#   ('activities', 'NNS'),
#   ('that', 'WDT'),
#   ('socal', 'JJ'),
#   ('weather', 'NN'),
#   ('makes', 'VBZ'),
#   ('easy', 'JJ'),
#   ('fresh', 'JJ')],
#  [('truly', 'RB'),
#   ('feel', 'VB'),
#   ('that', 'IN'),
#   ('mentally', 'RB'),
#   ('unstable', 'JJ'),
#   ('over', 'IN'),
#   ('head', 'NN'),
#   ('this', 'DT'),
#   ('very', 'RB'),
#   ('concerning', 'JJ'),
#   ('same', 'JJ'),
#   ('answer', 'NN'),
#   ('time', 'NN'),
#   ('after', 'IN'),
#   ('time', 'NN'),
#   ('ninety', 'NN'),
#   ('vaccination', 'NN')],
#  [('tend', 'JJ'),
#   ('slide', 'NN'),
#   ('until', 'IN'),
#   ('injure', 'NN'),
#   ('myself', 'PRP'),
#   ('klutz', 'VBD'),
#   ('notices', 'NNS'),
#   ('been', 'VBN'),
#   ('awhile', 'JJ'),
#   ('since', 'IN'),
#   ('they', 'PRP'),
#   ('quit', 'VBP'),
#   ('using', 'VBG'),
#   ('horse', 'NN'),
#   ('serum', 'NN'),
#   ('good', 'JJ'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('vaccination', 'NN')],
#  [('since', 'IN'),
#   ('september', 'NN'),
#   ('required', 'VBN'),
#   ('everyone', 'NN'),
#   ('years', 'NNS'),
#   ('older', 'VBP'),
#   ('wear', 'JJ'),
#   ('mask', 'NN'),
#   ('indoors', 'NNS'),
#   ('regardless', 'VBP'),
#   ('their', 'PRP$'),
#   ('covid', 'NN'),
#   ('nineteen', 'IN'),
#   ('vaccination', 'NN'),
#   ('status', 'NN'),
#   ('beginning', 'NN'),
#   ('after', 'IN'),
#   ('presidents', 'NNS'),
#   ('that', 'WDT'),
#   ('will', 'MD'),
#   ('longer', 'VB'),
#   ('case', 'NN')],
#  [('justified', 'JJ'),
#   ('frustrated', 'VBN'),
#   ('with', 'IN'),
#   ('people', 'NNS'),
#   ('vaccine', 'VBP'),
#   ('there', 'RB'),
#   ('jobs', 'NNS'),
#   ('where', 'WRB'),
#   ('fair', 'NN'),
#   ('require', 'VB'),
#   ('vaccination', 'NN'),
#   ('remain', 'VBP'),
#   ('employed', 'JJ'),
#   ('really', 'RB'),
#   ('going', 'VBG'),
#   ('starve', 'VB'),
#   ('them', 'PRP')],
#  [('biden', 'JJ'),
#   ('administration', 'NN'),
#   ('adopted', 'VBD'),
#   ('recommendation', 'JJ'),
#   ('make', 'VBP'),
#   ('health', 'NN'),
#   ('care', 'NN'),
#   ('worker', 'NN'),
#   ('vaccination', 'NN'),
#   ('condition', 'NN'),
#   ('medicare', 'NN'),
#   ('medicaid', 'VBN'),
#   ('funds', 'NNS'),
#   ('scotus', 'JJ'),
#   ('upheld', 'IN'),
#   ('this', 'DT'),
#   ('rule', 'NN'),
#   ('which', 'WDT'),
#   ('important', 'JJ'),
#   ('patient', 'NN'),
#   ('safety', 'NN')],
#  [('required', 'VBN'),
#   ('preregistration', 'NN'),
#   ('open', 'JJ'),
#   ('meadville', 'NNP'),
#   ('medical', 'JJ'),
#   ('center', 'NN'),
#   ('next', 'JJ'),
#   ('covid', 'NN'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('clinic', 'NN'),
#   ('eighteen', 'JJ'),
#   ('water', 'NN'),
#   ('clinic', 'JJ'),
#   ('pfizer', 'NN'),
#   ('vaccine', 'NN'),
#   ('only', 'RB')],
#  [('prevention', 'NN'),
#   ('long', 'JJ'),
#   ('term', 'NN'),
#   ('involves', 'VBZ'),
#   ('vaccination', 'NN'),
#   ('masks', 'NNS'),
#   ('reduce', 'VB'),
#   ('speaks', 'NNS'),
#   ('either', 'DT'),
#   ('vaccination', 'NN'),
#   ('masks', 'NNS'),
#   ('real', 'JJ'),
#   ('going', 'VBG'),
#   ('beat', 'NN'),
#   ('this', 'DT'),
#   ('covid', 'NN'),
#   ('shots', 'VBD'),
#   ('year', 'NN'),
#   ('going', 'VBG'),
#   ('forward', 'RB'),
#   ('difference', 'NN'),
#   ('this', 'DT'),
#   ('virus', 'NN'),
#   ('higher', 'JJR'),
#   ('kill', 'NN'),
#   ('rate', 'NN')],
#  [('that', 'DT'),
#   ('seems', 'VBZ'),
#   ('more', 'RBR'),
#   ('reasonable', 'JJ'),
#   ('will', 'MD'),
#   ('yield', 'VB'),
#   ('more', 'RBR'),
#   ('positive', 'JJ'),
#   ('results', 'NNS'),
#   ('than', 'IN'),
#   ('just', 'RB'),
#   ('rescinding', 'VBG'),
#   ('vaccination', 'NN'),
#   ('mandates', 'NNS'),
#   ('letting', 'VBG'),
#   ('people', 'NNS'),
#   ('make', 'VBP'),
#   ('their', 'PRP$'),
#   ('decisions', 'NNS')],
#  [('come', 'VBN'),
#   ('come', 'JJ'),
#   ('allstar', 'NN'),
#   ('valencia', 'NN'),
#   ('angeles', 'NNS'),
#   ('free', 'JJ'),
#   ('produce', 'VBP'),
#   ('testing', 'VBG'),
#   ('vaccination', 'NN')],
#  [('this', 'DT'),
#   ('absurd', 'JJ'),
#   ('please', 'NN'),
#   ('take', 'VB'),
#   ('look', 'NN'),
#   ('mirror', 'FW'),
#   ('your', 'PRP$'),
#   ('fellow', 'JJ'),
#   ('conservatives', 'NNS'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('expressly', 'RB'),
#   ('supporting', 'VBG'),
#   ('blockade', 'NN'),
#   ('main', 'JJ'),
#   ('culprit', 'NN'),
#   ('inflamed', 'VBD'),
#   ('rhetoric', 'JJ'),
#   ('calling', 'VBG'),
#   ('vaccination', 'NN'),
#   ('respect', 'VBP'),
#   ('public', 'JJ'),
#   ('health', 'NN'),
#   ('orders', 'NNS')],
#  [('fans', 'NNS'),
#   ('receive', 'VBP'),
#   ('their', 'PRP$'),
#   ('booster', 'NN'),
#   ('dose', 'NN'),
#   ('covid', 'JJ'),
#   ('vaccine', 'NN'),
#   ('super', 'JJ'),
#   ('bowl', 'NN'),
#   ('experience', 'NN'),
#   ('receive', 'VBP'),
#   ('free', 'JJ'),
#   ('tickets', 'NNS'),
#   ('enter', 'VBP'),
#   ('experience', 'NN'),
#   ('that', 'IN'),
#   ('future', 'JJ'),
#   ('date', 'NN'),
#   ('sure', 'JJ'),
#   ('visit', 'NN'),
#   ('vaccination', 'NN'),
#   ('site', 'NN'),
#   ('south', 'JJ'),
#   ('hall', 'NN'),
#   ('there', 'EX'),
#   ('superbowlexperience', 'NN'),
#   ('sblvi', 'NN')],
#  [('that', 'DT'),
#   ('unease', 'JJ'),
#   ('part', 'NN'),
#   ('pass', 'NN'),
#   ('adults', 'NNS'),
#   ('make', 'VBP'),
#   ('their', 'PRP$'),
#   ('choices', 'NNS'),
#   ('suffer', 'VBP'),
#   ('their', 'PRP$'),
#   ('consequences', 'NNS'),
#   ('deal', 'NN'),
#   ('with', 'IN'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('five', 'CD'),
#   ('eleven', 'RB'),
#   ('least', 'JJS'),
#   ('twelve', 'JJ'),
#   ('seventeen', 'NN'),
#   ('over', 'IN'),
#   ('fifty', 'NN')],
#  [('physical', 'JJ'),
#   ('vaccination', 'NN'),
#   ('card', 'NN'),
#   ('gross', 'JJ'),
#   ('digital', 'JJ'),
#   ('thanks', 'NNS')],
#  [('allied', 'VBN'),
#   ('universal', 'JJ'),
#   ('looking', 'VBG'),
#   ('hire', 'NN'),
#   ('phenomenal', 'JJ'),
#   ('security', 'NN'),
#   ('site', 'NN'),
#   ('supervisor', 'NN'),
#   ('unarmed', 'JJ'),
#   ('vaccination', 'NN'),
#   ('required', 'VBN'),
#   ('vegas', 'NN'),
#   ('join', 'NN'),
#   ('diverse', 'JJ'),
#   ('team', 'NN'),
#   ('hiringphenomenaltalent', 'NN'),
#   ('security', 'NN')],
#  [('especially', 'RB'),
#   ('vehicle', 'NN'),
#   ('towed', 'VBD'),
#   ('they', 'PRP'),
#   ('allowed', 'VBD'),
#   ('cross', 'NN'),
#   ('border', 'NN'),
#   ('because', 'IN'),
#   ('wait', 'NN'),
#   ('requires', 'VBZ'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('cross', 'NN'),
#   ('into', 'IN')],
#  [('links', 'NNS'),
#   ('papers', 'NNS'),
#   ('within', 'IN'),
#   ('article', 'NN'),
#   ('paper', 'NN'),
#   ('emphasizes', 'VBZ'),
#   ('dangers', 'NNS'),
#   ('harms', 'NNS'),
#   ('mandatory', 'JJ'),
#   ('covid', 'JJ'),
#   ('vaccination', 'NN'),
#   ('policy', 'NN')],
#  [('same', 'JJ'), ('forced', 'VBN'), ('vaccination', 'NN')],
#  [('this', 'DT'),
#   ('myocarditis', 'NN'),
#   ('foundation', 'NN'),
#   ('website', 'WRB'),
#   ('known', 'VBN'),
#   ('potential', 'JJ'),
#   ('benefits', 'NNS'),
#   ('covid', 'VBP'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('outweigh', 'RB'),
#   ('known', 'VBN'),
#   ('potential', 'JJ'),
#   ('risks', 'NNS'),
#   ('including', 'VBG'),
#   ('possible', 'JJ'),
#   ('risks', 'NNS'),
#   ('myocarditis', 'NN'),
#   ('pericarditis', 'NN')],
#  [('politicians', 'NNS'),
#   ('across', 'VBP'),
#   ('country', 'NN'),
#   ('continue', 'VBP'),
#   ('infringe', 'VBP'),
#   ('personal', 'JJ'),
#   ('liberties', 'NNS'),
#   ('under', 'IN'),
#   ('guise', 'JJ'),
#   ('public', 'JJ'),
#   ('safety', 'NN'),
#   ('today', 'NN'),
#   ('filed', 'VBD'),
#   ('lawsuit', 'NN'),
#   ('against', 'IN'),
#   ('city', 'NN'),
#   ('chicago', 'NN'),
#   ('cook', 'VBD'),
#   ('county', 'JJ'),
#   ('illegal', 'JJ'),
#   ('diskriminatory', 'NN'),
#   ('proof', 'NN'),
#   ('vaccination', 'NN'),
#   ('requirements', 'NNS')],
#  [('governors', 'NNS'),
#   ('control', 'VBP'),
#   ('lockdowns', 'VBZ'),
#   ('they', 'PRP'),
#   ('started', 'VBD'),
#   ('long', 'RB'),
#   ('before', 'RB'),
#   ('biden', 'JJ'),
#   ('biden', 'NN'),
#   ('opened', 'VBD'),
#   ('things', 'NNS'),
#   ('with', 'IN'),
#   ('vaccination', 'NN'),
#   ('program', 'NN'),
#   ('sure', 'JJ'),
#   ('tracking', 'VBG'),
#   ('right', 'JJ'),
#   ('trump', 'NN'),
#   ('spent', 'VBD'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('biden', 'NN'),
#   ('that', 'WDT'),
#   ('failed', 'VBD'),
#   ('increase', 'NN'),
#   ('rates', 'NNS'),
#   ('during', 'IN'),
#   ('presidency', 'NN')],
#  [('talking', 'VBG'), ('about', 'IN'), ('covid', 'NN'), ('vaccination', 'NN')],
#  [('regulation', 'NN'),
#   ('size', 'NN'),
#   ('three', 'CD'),
#   ('point', 'NN'),
#   ('line', 'NN'),
#   ('vaccination', 'NN'),
#   ('mandate', 'NN')],
#  [('monday', 'NN'),
#   ('proof', 'NN'),
#   ('vaccination', 'NN'),
#   ('negative', 'JJ'),
#   ('covid', 'NN'),
#   ('nineteen', 'JJ'),
#   ('test', 'NN'),
#   ('will', 'MD'),
#   ('longer', 'RBR'),
#   ('required', 'JJ'),
#   ('staff', 'NN'),
#   ('visitors', 'NNS'),
#   ('saskatoon', 'VBP'),
#   ('public', 'JJ'),
#   ('schools', 'NNS')],
#  [('amoa', 'NN'),
#   ('resort', 'NN'),
#   ('activated', 'VBD'),
#   ('covid', 'NN'),
#   ('nineteen', 'NN'),
#   ('protocols', 'NNS'),
#   ('will', 'MD'),
#   ('welcome', 'VB'),
#   ('guests', 'NNS'),
#   ('strictly', 'RB'),
#   ('observes', 'VBZ'),
#   ('social', 'JJ'),
#   ('distancing', 'VBG'),
#   ('face', 'NN'),
#   ('masks', 'NNS'),
#   ('wearing', 'VBG'),
#   ('enforce', 'NN'),
#   ('vaccination', 'NN'),
#   ('cards', 'NNS'),
#   ('only', 'RB'),
#   ('entry', 'VBP')],
#  [('centenary', 'JJ'),
#   ('hospital', 'NN'),
#   ('scarborough', 'NN'),
#   ('dose', 'NN'),
#   ('moderna', 'FW'),
#   ('spots', 'NNS'),
#   ('added', 'VBD'),
#   ('first', 'RB'),
#   ('available', 'JJ'),
#   ('date', 'NN'),
#   ('book', 'NN'),
#   ('detailed', 'JJ'),
#   ('availability', 'NN'),
#   ('vhcon', 'NN')],
#  [('centenary', 'JJ'),
#   ('hospital', 'NN'),
#   ('margaret', 'VBD'),
#   ('birch', 'NN'),
#   ('wing', 'VBG'),
#   ('scarborough', 'JJ'),
#   ('dose', 'JJ'),
#   ('pfizer', 'NN'),
#   ('moderna', 'JJ'),
#   ('spots', 'NNS'),
#   ('added', 'VBD'),
#   ('first', 'RB'),
#   ('available', 'JJ'),
#   ('date', 'NN'),
#   ('book', 'NN'),
#   ('detailed', 'JJ'),
#   ('availability', 'NN'),
#   ('vhcon', 'NN')],
#  [('centenary', 'JJ'),
#   ('hospital', 'NN'),
#   ('margaret', 'VBD'),
#   ('birch', 'NN'),
#   ('wing', 'VBG'),
#   ('scarborough', 'JJ'),
#   ('dose', 'JJ'),
#   ('pfizer', 'NN'),
#   ('moderna', 'JJ'),
#   ('spots', 'NNS'),
#   ('added', 'VBD'),
#   ('first', 'RB'),
#   ('available', 'JJ'),
#   ('date', 'NN'),
#   ('book', 'NN'),
#   ('detailed', 'JJ'),
#   ('availability', 'NN'),
#   ('vhcon', 'NN')],
#  [('health', 'NN'),
#   ('emergency', 'NN'),
#   ('force', 'NN'),
#   ('that', 'WDT'),
#   ('gives', 'VBZ'),
#   ('quebec', 'RB'),
#   ('sweeping', 'JJ'),
#   ('powers', 'NNS'),
#   ('legault', 'NN'),
#   ('said', 'VBD'),
#   ('will', 'MD'),
#   ('dropped', 'VBN'),
#   ('after', 'IN'),
#   ('national', 'JJ'),
#   ('assembly', 'NN'),
#   ('adopts', 'NNS'),
#   ('legislation', 'NN'),
#   ('specifying', 'VBG'),
#   ('which', 'WDT'),
#   ('measures', 'NNS'),
#   ('maintained', 'VBD'),
#   ('such', 'JJ'),
#   ('vaccination', 'NN'),
#   ('passport', 'NN'),
#   ('legaultmustresign', 'NN'),
#   ('legault', 'NN')],
#  [('ability', 'NN'),
#   ('always', 'RB'),
#   ('free', 'JJ'),
#   ('restrictions', 'NNS'),
#   ('after', 'IN'),
#   ('vaccination', 'NN'),
#   ('that', 'WDT'),
#   ('supposed', 'VBD'),
#   ('point', 'NN'),
#   ('mandates', 'NNS'),
#   ('that', 'IN'),
#   ('trust', 'NN'),
#   ('broken', 'VBN'),
#   ('when', 'WRB'),
#   ('closed', 'JJ'),
#   ('businesses', 'NNS'),
#   ('again', 'RB'),
#   ('able', 'JJ'),
#   ('restaurants', 'NNS'),
#   ('there', 'EX'),
#   ('guarantee', 'NN'),
#   ('will', 'MD'),
#   ('april', 'VB')],
#  [('genuinely', 'RB'),
#   ('curious', 'JJ'),
#   ('find', 'VBP'),
#   ('clip', 'JJ'),
#   ('quote', 'JJ'),
#   ('trump', 'NN'),
#   ('telling', 'VBG'),
#   ('base', 'NN'),
#   ('anyone', 'NN'),
#   ('anything', 'NN'),
#   ('remotely', 'RB'),
#   ('anti', 'JJ'),
#   ('vaccine', 'NN'),
#   ('everything', 'NN'),
#   ('said', 'VBD'),
#   ('what', 'WP'),
#   ('seen', 'VBN'),
#   ('been', 'VBN'),
#   ('extremely', 'RB'),
#   ('vaccination', 'JJ'),
#   ('maybe', 'RB'),
#   ('have', 'VBP'),
#   ('other', 'JJ'),
#   ('sources', 'NNS'),
#   ('could', 'MD'),
#   ('cite', 'VB')],
#  [('swastikas', 'NN'),
#   ('displayed', 'VBD'),
#   ('canadian', 'JJ'),
#   ('freedom', 'NN'),
#   ('convoy', 'NN'),
#   ('protests', 'NNS'),
#   ('against', 'IN'),
#   ('vaccination', 'NN'),
#   ('mandates', 'NNS')],
#  [('that', 'DT'),
#   ('treatment', 'NN'),
#   ('vaccine', 'NN'),
#   ('obviously', 'RB'),
#   ('natural', 'JJ'),
#   ('immunity', 'NN'),
#   ('definition', 'NN'),
#   ('know', 'VBP'),
#   ('what', 'WP'),
#   ('your', 'PRP$'),
#   ('original', 'JJ'),
#   ('response', 'NN'),
#   ('said', 'VBD'),
#   ('right', 'RB'),
#   ('know', 'JJ'),
#   ('vaccination', 'NN'),
#   ('occurs', 'VBZ'),
#   ('prior', 'JJ'),
#   ('illness', 'NN'),
#   ('during', 'IN'),
#   ('illness', 'NN'),
#   ('right', 'NN')],
#  [('covid', 'JJ'),
#   ('vaccination', 'NN'),
#   ('does', 'VBZ'),
#   ('prevent', 'VB'),
#   ('spread', 'VB'),
#   ('stop', 'VB'),
#   ('with', 'IN'),
#   ('disinformation', 'NN')],
#  [('absolutely', 'RB'),
#   ('since', 'IN'),
#   ('live', 'JJ'),
#   ('ohio', 'NNS'),
#   ('county', 'NN'),
#   ('with', 'IN'),
#   ('lowest', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS')],
#  [('hrig', 'JJ'),
#   ('very', 'RB'),
#   ('thick', 'JJ'),
#   ('yogurt', 'NN'),
#   ('like', 'IN'),
#   ('substance', 'NN'),
#   ('will', 'MD'),
#   ('feel', 'VB'),
#   ('that', 'IN'),
#   ('vaccination', 'NN'),
#   ('clearly', 'RB'),
#   ('tell', 'VBP'),
#   ('apart', 'RB'),
#   ('normal', 'JJ'),
#   ('rabies', 'NNS'),
#   ('when', 'WRB'),
#   ('bitten', 'NN'),
#   ('they', 'PRP'),
#   ('forgot', 'VBD'),
#   ('administer', 'NN'),
#   ('that', 'WDT'),
#   ('must', 'MD'),
#   ('really', 'RB'),
#   ('rabies', 'VB'),
#   ('vaccine', 'NN'),
#   ('effective', 'JJ'),
#   ('post', 'NN'),
#   ('trauma', 'NN')],
#  [('meanwhile', 'RB'),
#   ('more', 'RBR'),
#   ('death', 'NN'),
#   ('threats', 'NNS'),
#   ('against', 'IN'),
#   ('superintendent', 'JJ'),
#   ('upheaval', 'JJ'),
#   ('littleton', 'NN'),
#   ('public', 'NN'),
#   ('schools', 'NNS'),
#   ('over', 'IN'),
#   ('vaccination', 'NN'),
#   ('localnews', 'NNS')],
#  [('when', 'WRB'),
#   ('proof', 'NN'),
#   ('vaccination', 'NN'),
#   ('gets', 'VBZ'),
#   ('lifted', 'VBN'),
#   ('elderly', 'RB'),
#   ('will', 'MD'),
#   ('then', 'RB'),
#   ('forced', 'VB'),
#   ('isolate', 'NN'),
#   ('protect', 'NN'),
#   ('themselves', 'PRP')],
#  [('appeals', 'NNS'),
#   ('court', 'NN'),
#   ('will', 'MD'),
#   ('block', 'VB'),
#   ('order', 'NN'),
#   ('barring', 'VBG'),
#   ('biden', 'JJ'),
#   ('federal', 'JJ'),
#   ('staff', 'NN'),
#   ('vaccination', 'NN'),
#   ('mandate', 'NN'),
#   ('newsbreak', 'NN')],
#  [('agreed', 'VBN'),
#   ('suspect', 'JJ'),
#   ('european', 'JJ'),
#   ('countries', 'NNS'),
#   ('have', 'VBP'),
#   ('higher', 'JJR'),
#   ('uptake', 'JJ'),
#   ('part', 'NN'),
#   ('because', 'IN'),
#   ('they', 'PRP'),
#   ('honored', 'VBD'),
#   ('recovery', 'NN'),
#   ('previously', 'RB'),
#   ('infected', 'VBN'),
#   ('individuals', 'NNS'),
#   ('adjusted', 'VBD'),
#   ('their', 'PRP$'),
#   ('vaccination', 'NN'),
#   ('recommendations', 'NNS'),
#   ('result', 'VBP')],
#  [('against', 'IN'),
#   ('mandatory', 'JJ'),
#   ('mumps', 'NNS'),
#   ('measles', 'NNS'),
#   ('rubella', 'VBP'),
#   ('vaccination', 'NN'),
#   ('just', 'RB'),
#   ('fake', 'JJ'),
#   ('outrage', 'NN'),
#   ('this', 'DT'),
#   ('particular', 'JJ'),
#   ('vaccine', 'NN')],
#  [('divorce', 'NN'),
#   ('rates', 'NNS'),
#   ('rise', 'VBP'),
#   ('vaccination', 'NN'),
#   ('adds', 'VBZ'),
#   ('stress', 'NN'),
#   ('parenting', 'NN')],
#  [('vaccination', 'NN'), ('away', 'RB'), ('being', 'VBG'), ('special', 'JJ')],
#  [('that', 'DT'),
#   ('sucks', 'VBZ'),
#   ('schools', 'NNS'),
#   ('marin', 'JJ'),
#   ('mass', 'NN'),
#   ('vaccination', 'NN'),
#   ('days', 'NNS'),
#   ('with', 'IN'),
#   ('support', 'JJ'),
#   ('dogs', 'NNS'),
#   ('pretty', 'RB'),
#   ('much', 'JJ'),
#   ('every', 'DT'),
#   ('school', 'NN'),
#   ('district', 'NN'),
#   ('twenty', 'NN'),
#   ('minutes', 'NNS')],
#  [('keep', 'VB'),
#   ('some', 'DT'),
#   ('vaccination', 'NN'),
#   ('clinics', 'NNS'),
#   ('that', 'IN'),
#   ('opening', 'VBG'),
#   ('sign', 'NN'),
#   ('gcms', 'NN')],
#  [('fair', 'JJ'),
#   ('some', 'DT'),
#   ('parents', 'NNS'),
#   ('haven', 'RB'),
#   ('much', 'JJ'),
#   ('mass', 'NN'),
#   ('vaccination', 'NN'),
#   ('infrastructure', 'NN'),
#   ('grownups', 'NNS'),
#   ('when', 'WRB'),
#   ('vaxxed', 'JJ'),
#   ('easy', 'JJ'),
#   ('hell', 'NN'),
#   ('barely', 'RB'),
#   ('twenty', 'JJ'),
#   ('minutes', 'NNS'),
#   ('including', 'VBG'),
#   ('fifteen', 'JJ'),
#   ('observation', 'NN'),
#   ('kids', 'NNS'),
#   ('second', 'VBD'),
#   ('dose', 'JJ'),
#   ('hours', 'NNS'),
#   ('waiting', 'VBG'),
#   ('damp', 'NN'),
#   ('cold', 'NN')],
#  [('would', 'MD'),
#   ('list', 'VB'),
#   ('nominees', 'NNS'),
#   ('would', 'MD'),
#   ('been', 'VBN'),
#   ('blacklisted', 'VBN'),
#   ('oscars', 'NNS'),
#   ('academy', 'IN'),
#   ('hadn', 'NN'),
# ...
#   ('this', 'DT'),
#   ('state', 'NN')],
#  [('couldn', 'NNS'),
#   ('even', 'RB'),
#   ('answer', 'JJR'),
#   ('opposition', 'NN'),
#   ('leader', 'NN'),
#   ('question', 'NN'),
#   ('during', 'IN'),
#   ('debate', 'NN'),
#   ('questioning', 'VBG'),
#   ('about', 'RB'),
#   ('much', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rate', 'NN'),
#   ('enough', 'JJ'),
#   ('before', 'IN'),
#   ('these', 'DT'),
#   ('mandates', 'NNS'),
#   ('lifted', 'VBD'),
#   ('this', 'DT'),
#   ('clearly', 'RB'),
#   ('lead', 'NN'),
#   ('this', 'DT'),
#   ('great', 'JJ'),
#   ('country', 'NN'),
#   ('incompetent', 'NN')],
#  [('york', 'NN'),
#   ('state', 'NN'),
#   ('dropping', 'VBG'),
#   ('mask', 'NN'),
#   ('requirements', 'NNS'),
#   ('broadway', 'RP'),
#   ('arts', 'NNS'),
#   ('artsnews', 'VBZ'),
#   ('broadway', 'RB'),
#   ('mask', 'JJ'),
#   ('vaccination', 'NN'),
#   ('policy', 'NN'),
#   ('will', 'MD'),
#   ('remain', 'VB'),
#   ('place', 'NN'),
#   ('through', 'IN'),
#   ('least', 'JJS'),
#   ('april', 'JJ'),
#   ('thirty', 'NN'),
#   ('most', 'RBS'),
#   ('recent', 'JJ'),
#   ('extension', 'NN'),
#   ('date', 'NN'),
#   ('policy', 'NN'),
#   ('announced', 'VBD'),
#   ('last', 'JJ'),
#   ('month', 'NN'),
#   ('broadway', 'VBD')],
#  [('proof', 'NN'),
#   ('world', 'NN'),
#   ('being', 'VBG'),
#   ('taken', 'VBN'),
#   ('over', 'RP'),
#   ('whistles', 'NNS'),
#   ('being', 'VBG'),
#   ('blamed', 'VBN'),
#   ('heart', 'NN'),
#   ('attacks', 'NNS'),
#   ('myocarditis', 'VBP'),
#   ('occurring', 'VBG'),
#   ('chests', 'NNS'),
#   ('athletes', 'NNS'),
#   ('field', 'NN'),
#   ('also', 'RB'),
#   ('ottawa', 'JJ'),
#   ('citizens', 'NNS'),
#   ('concerned', 'VBN'),
#   ('about', 'IN'),
#   ('exhaust', 'NN'),
#   ('trucks', 'NNS'),
#   ('five', 'CD'),
#   ('year', 'NN'),
#   ('died', 'VBD'),
#   ('minutes', 'NNS'),
#   ('after', 'IN'),
#   ('vaccination', 'NN')],
#  [('brian', 'JJ'),
#   ('temple', 'NN'),
#   ('diskusses', 'NNS'),
#   ('efforts', 'NNS'),
#   ('debunk', 'VBP'),
#   ('vaccination', 'NN'),
#   ('mistruths', 'NNS'),
#   ('offers', 'VBZ'),
#   ('advice', 'NN'),
#   ('people', 'NNS'),
#   ('wanting', 'VBG'),
#   ('into', 'IN'),
#   ('health', 'NN'),
#   ('care', 'NN'),
#   ('shares', 'NNS'),
#   ('thoughts', 'NNS'),
#   ('black', 'JJ'),
#   ('history', 'NN')],
#  [('check', 'NN'),
#   ('england', 'NN'),
#   ('covid', 'VBZ'),
#   ('death', 'NN'),
#   ('spikes', 'NNS'),
#   ('after', 'IN'),
#   ('vaccination', 'NN')],
#  [('more', 'RBR'),
#   ('than', 'IN'),
#   ('evidence', 'NN'),
#   ('that', 'IN'),
#   ('masks', 'VBZ'),
#   ('little', 'RB'),
#   ('good', 'JJ'),
#   ('start', 'NN'),
#   ('with', 'IN'),
#   ('vaccination', 'NN'),
#   ('stats', 'NNS'),
#   ('then', 'RB'),
#   ('about', 'IN'),
#   ('masks', 'NNS'),
#   ('cable', 'NN'),
#   ('upcoming', 'NN')],
#  [('sorry', 'NN'),
#   ('know', 'VBP'),
#   ('important', 'JJ'),
#   ('convince', 'NN'),
#   ('people', 'NNS'),
#   ('covid', 'VBP'),
#   ('instead', 'RB'),
#   ('getting', 'VBG'),
#   ('vaccination', 'NN'),
#   ('kink', 'VB'),
#   ('shaming', 'VBG'),
#   ('tricked', 'JJ'),
#   ('people', 'NNS'),
#   ('read', 'VBP'),
#   ('that', 'IN'),
#   ('article', 'NN'),
#   ('share', 'NN'),
#   ('time', 'NN'),
#   ('because', 'IN'),
#   ('sounds', 'NNS'),
#   ('like', 'IN'),
#   ('what', 'WP'),
#   ('they', 'PRP'),
#   ('want', 'VBP'),
#   ('believe', 'VBP')],
#  [('agree', 'RB'),
#   ('tried', 'VBN'),
#   ('steer', 'NN'),
#   ('conversation', 'NN'),
#   ('towards', 'NNS'),
#   ('ridiculous', 'JJ'),
#   ('blocking', 'VBG'),
#   ('people', 'NNS'),
#   ('getting', 'VBG'),
#   ('tested', 'JJ'),
#   ('vaccine', 'NN'),
#   ('mandates', 'VBZ'),
#   ('distraction', 'NN'),
#   ('will', 'MD'),
#   ('dropped', 'VB'),
#   ('soon', 'RB'),
#   ('anyway', 'RB'),
#   ('leadership', 'NN'),
#   ('viewed', 'VBD'),
#   ('them', 'PRP'),
#   ('just', 'RB'),
#   ('tool', 'NN'),
#   ('encourage', 'NN'),
#   ('vaccination', 'NN'),
#   ('that', 'WDT'),
#   ('work', 'NN'),
#   ('done', 'VBN')],
#  [('oscar', 'NN'),
#   ('hypocrisy', 'NN'),
#   ('goes', 'VBZ'),
#   ('twitter', 'JJ'),
#   ('reacts', 'NNS'),
#   ('academy', 'VBP'),
#   ('awards', 'NNS'),
#   ('requiring', 'VBG'),
#   ('proof', 'NN'),
#   ('vaccination', 'NN')],
#  [('lifetime', 'JJ'),
#   ('went', 'VBD'),
#   ('death', 'NN'),
#   ('sentence', 'NN'),
#   ('very', 'RB'),
#   ('manageable', 'JJ'),
#   ('condition', 'NN'),
#   ('might', 'MD'),
#   ('even', 'RB'),
#   ('have', 'VB'),
#   ('vaccination', 'NN'),
#   ('against', 'IN'),
#   ('soon', 'RB'),
#   ('that', 'IN'),
#   ('amazing', 'VBG'),
#   ('testament', 'NN'),
#   ('science', 'NN')],
#  [('montagnier', 'JJR'),
#   ('beliefs', 'NNS'),
#   ('about', 'IN'),
#   ('vaccination', 'NN'),
#   ('milan', 'NN'),
#   ('fifteen', 'NN'),
#   ('said', 'VBD'),
#   ('shared', 'VBN'),
#   ('that', 'WDT'),
#   ('will', 'MD'),
#   ('unvaccinated', 'VB'),
#   ('defend', 'NN'),
#   ('humanity', 'NN'),
#   ('according', 'VBG'),
#   ('reliable', 'JJ'),
#   ('sources', 'NNS'),
#   ('italian', 'JJ'),
#   ('translator', 'NN'),
#   ('translates', 'NNS'),
#   ('unvaccinated', 'JJ'),
#   ('guardians', 'NNS'),
#   ('humanity', 'NN'),
#   ('seeker', 'NN'),
#   ('truth', 'NN')],
#  [('eight', 'CD'),
#   ('makary', 'JJ'),
#   ('being', 'VBG'),
#   ('misleading', 'VBG'),
#   ('when', 'WRB'),
#   ('uses', 'NNS'),
#   ('paper', 'NN'),
#   ('diskuss', 'VBZ'),
#   ('natural', 'JJ'),
#   ('immunity', 'NN'),
#   ('vaccination', 'NN'),
#   ('since', 'IN'),
#   ('assessing', 'VBG'),
#   ('neutralization', 'NN'),
#   ('note', 'NN'),
#   ('difference', 'NN'),
#   ('between', 'IN'),
#   ('what', 'WP'),
#   ('paper', 'NN'),
#   ('twitter', 'NN'),
#   ('claim', 'NN'),
#   ('about', 'IN'),
#   ('paper', 'NN')],
#  [('evidence', 'NN'),
#   ('increased', 'VBD'),
#   ('infection', 'NN'),
#   ('risk', 'NN'),
#   ('following', 'VBG'),
#   ('third', 'JJ'),
#   ('dose', 'JJ'),
#   ('exacerbated', 'JJ'),
#   ('vaccination', 'NN'),
#   ('drive', 'NN'),
#   ('during', 'IN'),
#   ('omicron', 'NN'),
#   ('wave', 'VBP'),
#   ('ukhsa', 'JJ'),
#   ('data', 'NNS'),
#   ('show', 'NN')],
#  [('make', 'VB'),
#   ('right', 'JJ'),
#   ('governed', 'VBN'),
#   ('airlines', 'NNS'),
#   ('they', 'PRP'),
#   ('want', 'VBP'),
#   ('institute', 'JJ'),
#   ('mandates', 'NNS'),
#   ('they', 'PRP'),
#   ('this', 'DT'),
#   ('longer', 'RBR'),
#   ('about', 'IN'),
#   ('public', 'JJ'),
#   ('health', 'NN'),
#   ('given', 'VBN'),
#   ('ninety', 'CD'),
#   ('vaccination', 'NN'),
#   ('this', 'DT'),
#   ('about', 'IN'),
#   ('individual', 'JJ'),
#   ('health', 'NN')],
#  [('expanding', 'VBG'),
#   ('vaccination', 'NN'),
#   ('requirements', 'NNS'),
#   ('health', 'NN'),
#   ('care', 'NN'),
#   ('professionals', 'NNS')],
#  [('will', 'MD'),
#   ('room', 'NN'),
#   ('please', 'VB'),
#   ('make', 'JJ'),
#   ('sure', 'JJ'),
#   ('rsvp', 'NN'),
#   ('vaccination', 'NN'),
#   ('cards', 'NNS'),
#   ('masks', 'NNS'),
#   ('required', 'VBN'),
#   ('link', 'VBP'),
#   ('below', 'IN')],
#  [('well', 'RB'),
#   ('with', 'IN'),
#   ('each', 'DT'),
#   ('answer', 'NN'),
#   ('managed', 'VBD'),
#   ('place', 'NN'),
#   ('word', 'NN'),
#   ('vaccination', 'NN'),
#   ('diminutives', 'VBZ'),
#   ('course', 'NN'),
#   ('strong', 'JJ'),
#   ('national', 'JJ'),
#   ('juju', 'NN')],
#  [('really', 'RB'),
#   ('happy', 'JJ'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('minority', 'NN'),
#   ('with', 'IN'),
#   ('these', 'DT'),
#   ('feelings', 'NNS'),
#   ('kids', 'NNS'),
#   ('five', 'CD'),
#   ('under', 'IN'),
#   ('still', 'RB'),
#   ('vaxxed', 'VBN'),
#   ('many', 'JJ'),
#   ('people', 'NNS'),
#   ('remain', 'VBP'),
#   ('unvaxxed', 'JJ'),
#   ('this', 'DT'),
#   ('says', 'VBZ'),
#   ('fuck', 'VBP'),
#   ('anyone', 'NN'),
#   ('immunocompromised', 'VBN'),
#   ('full', 'JJ'),
#   ('vaccination', 'NN'),
#   ('clark', 'NN'),
#   ('county', 'NN'),
#   ('still', 'RB'),
#   ('below', 'IN')],
#  [('canadian', 'JJ'),
#   ('truckers', 'NNS'),
#   ('with', 'IN'),
#   ('ninety', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rate', 'NN'),
#   ('more', 'RBR'),
#   ('vaccinated', 'JJ'),
#   ('than', 'IN'),
#   ('single', 'JJ'),
#   ('demographic', 'JJ'),
#   ('group', 'NN'),
#   ('america', 'VBZ'),
#   ('that', 'IN'),
#   ('come', 'VBP'),
#   ('across', 'IN'),
#   ('except', 'IN'),
#   ('doctors', 'NNS')],
#  [('seriously', 'RB'),
#   ('well', 'RB'),
#   ('documented', 'VBN'),
#   ('that', 'IN'),
#   ('risk', 'NN'),
#   ('transmitting', 'VBG'),
#   ('covid', 'JJ'),
#   ('same', 'JJ'),
#   ('regardless', 'JJ'),
#   ('vaccination', 'NN'),
#   ('status', 'NN')],
#  [('minneapolis', 'NN'),
#   ('paul', 'NN'),
#   ('immediately', 'RB'),
#   ('lift', 'JJ'),
#   ('mandate', 'NN'),
#   ('requiring', 'VBG'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('negative', 'JJ'),
#   ('test', 'NN')],
#  [('proof', 'NN'),
#   ('vaccination', 'NN'),
#   ('could', 'MD'),
#   ('used', 'VBN'),
#   ('republicans', 'NNS'),
#   ('voter', 'RBR')],
#  [('like', 'IN'), ('vaccination', 'NN')],
#  [('people', 'NNS'),
#   ('defend', 'VBP'),
#   ('rogan', 'VBP'),
#   ('like', 'IN'),
#   ('that', 'DT'),
#   ('tough', 'JJ'),
#   ('conversations', 'NNS'),
#   ('with', 'IN'),
#   ('wide', 'JJ'),
#   ('range', 'NN'),
#   ('voices', 'NNS'),
#   ('then', 'RB'),
#   ('does', 'VBZ'),
#   ('never', 'RB'),
#   ('seem', 'VB'),
#   ('host', 'RB'),
#   ('critical', 'JJ'),
#   ('race', 'NN'),
#   ('theorists', 'NNS'),
#   ('trans', 'VBZ'),
#   ('rights', 'NNS'),
#   ('activists', 'NNS'),
#   ('real', 'JJ'),
#   ('doctors', 'NNS'),
#   ('defend', 'VBP'),
#   ('vaccination', 'NN'),
#   ('anyone', 'NN'),
#   ('might', 'MD'),
#   ('actually', 'RB'),
#   ('challenge', 'VB')],
#  [('vaccination', 'NN'),
#   ('alone', 'RB'),
#   ('solution', 'NN'),
#   ('then', 'RB'),
#   ('need', 'VB'),
#   ('next', 'JJ'),
#   ('vaccines', 'NNS'),
#   ('that', 'WDT'),
#   ('protect', 'VBP'),
#   ('broadly', 'RB'),
#   ('across', 'IN'),
#   ('variants', 'NNS'),
#   ('create', 'VBP'),
#   ('sterilyzing', 'VBG'),
#   ('immune', 'JJ'),
#   ('response', 'NN'),
#   ('body', 'NN'),
#   ('that', 'WDT'),
#   ('will', 'MD'),
#   ('take', 'VB'),
#   ('time', 'NN'),
#   ('interim', 'JJ'),
#   ('premiers', 'NNS'),
#   ('ignore', 'VBP'),
#   ('protections', 'NNS'),
#   ('live', 'VBP'),
#   ('with', 'IN')],
#  [('many', 'JJ'),
#   ('businesses', 'NNS'),
#   ('introduced', 'VBD'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('mandatory', 'NN'),
#   ('masking', 'VBG'),
#   ('measures', 'NNS'),
#   ('before', 'IN'),
#   ('government', 'NN'),
#   ('with', 'IN'),
#   ('public', 'JJ'),
#   ('health', 'NN'),
#   ('orders', 'NNS'),
#   ('could', 'MD'),
#   ('businesses', 'NNS'),
#   ('keep', 'VB'),
#   ('those', 'DT'),
#   ('requirements', 'NNS'),
#   ('their', 'PRP$'),
#   ('patrons', 'NNS'),
#   ('regina', 'VBP'),
#   ('lawyer', 'NN'),
#   ('legal', 'JJ'),
#   ('opinion', 'NN'),
#   ('listen', 'NN')],
#  [('dinner', 'NN'),
#   ('believe', 'VBP'),
#   ('this', 'DT'),
#   ('something', 'NN'),
#   ('spend', 'JJ'),
#   ('time', 'NN'),
#   ('thinking', 'VBG'),
#   ('about', 'IN'),
#   ('vaccine', 'NN'),
#   ('passports', 'NNS'),
#   ('essentially', 'RB'),
#   ('social', 'JJ'),
#   ('gulag', 'NN'),
#   ('then', 'RB'),
#   ('have', 'VBP'),
#   ('well', 'RB'),
#   ('what', 'WP'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('hold', 'VB'),
#   ('your', 'PRP$'),
#   ('proof', 'JJ'),
#   ('vaccination', 'NN'),
#   ('ready', 'JJ'),
#   ('hostess', 'NN')],
#  [('canr', 'NN'),
#   ('lgbtq', 'NN'),
#   ('adults', 'NNS'),
#   ('have', 'VBP'),
#   ('higher', 'JJR'),
#   ('covid', 'NN'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('than', 'IN'),
#   ('heterosexual', 'JJ'),
#   ('adults', 'NNS'),
#   ('pandemic', 'JJ'),
#   ('unique', 'JJ'),
#   ('impact', 'NN'),
#   ('lgbtq', 'NNP'),
#   ('community', 'NN'),
#   ('says', 'VBZ'),
#   ('lgbt', 'JJ'),
#   ('persons', 'NNS'),
#   ('increased', 'VBD'),
#   ('risk', 'NN'),
#   ('severe', 'RB'),
#   ('covid', 'JJ'),
#   ('nineteen', 'JJ'),
#   ('illness', 'NN'),
#   ('view', 'NN'),
#   ('article', 'NN')],
#  [('haven', 'RB'),
#   ('even', 'RB'),
#   ('gotten', 'VBP'),
#   ('original', 'JJ'),
#   ('vaccination', 'NN'),
#   ('because', 'IN'),
#   ('want', 'NN'),
#   ('because', 'IN'),
#   ('allowed', 'VBN'),
#   ('make', 'VBP'),
#   ('medical', 'JJ'),
#   ('decisions', 'NNS')],
#  [('says', 'VBZ'),
#   ('countries', 'NNS'),
#   ('with', 'IN'),
#   ('lower', 'JJR'),
#   ('vaccination', 'NN'),
#   ('rates', 'NNS'),
#   ('than', 'IN'),
#   ('canada', 'NNS'),
#   ('have', 'VBP'),
#   ('reopened', 'VBN'),
#   ('asks', 'NNS'),
#   ('trudeau', 'IN'),
#   ('only', 'RB'),
#   ('mandates', 'VBZ'),
#   ('reopen', 'JJ'),
#   ('country', 'NN'),
#   ('canadians', 'NNS'),
#   ('vaccinated', 'VBD'),
#   ('trudeau', 'NN'),
#   ('responds', 'NNS'),
#   ('says', 'VBZ'),
#   ('vaccines', 'NNS'),
#   ('will', 'MD'),
#   ('help', 'VB'),
#   ('lift', 'VB'),
#   ('restrictions', 'NNS'),
#   ('cdnpoli', 'VB')],
#  [('mask', 'NN'),
#   ('vaccination', 'NN'),
#   ('requirements', 'NNS'),
#   ('tyranny', 'JJ'),
#   ('people', 'NNS'),
#   ('love', 'VBP'),
#   ('throwing', 'VBG'),
#   ('that', 'IN'),
#   ('word', 'NN'),
#   ('around', 'IN'),
#   ('name', 'NN'),
#   ('calling', 'VBG'),
#   ('hominem', 'NN'),
#   ('attacks', 'NNS'),
#   ('going', 'VBG'),
#   ('make', 'VB'),
#   ('your', 'PRP$'),
#   ('argument', 'NN'),
#   ('better', 'RBR'),
#   ('toodles', 'NNS')],
#  [('anti', 'JJ'),
#   ('vaccination', 'NN'),
#   ('anti', 'NN'),
#   ('covid', 'NN'),
#   ('vaccination', 'NN')],
#  [('still', 'RB'),
#   ('need', 'VB'),
#   ('covid', 'NNS'),
#   ('nineteen', 'JJ'),
#   ('vaccine', 'NN'),
#   ('louisianians', 'NNS'),
#   ('their', 'PRP$'),
#   ('first', 'JJ'),
#   ('covid', 'NN'),
#   ('nineteen', 'JJ'),
#   ('vaccination', 'NN'),
#   ('shot', 'NN'),
#   ('eligible', 'JJ'),
#   ('receive', 'NN'),
#   ('including', 'VBG'),
#   ('children', 'NNS'),
#   ('ages', 'VBZ'),
#   ('five', 'CD'),
#   ('seventeen', 'NN')],
#  [('make', 'VB'),
#   ('vaccination', 'NN'),
#   ('process', 'NN'),
#   ('easy', 'JJ'),
#   ('close', 'RB'),
#   ('home', 'NN'),
#   ('people', 'NNS'),
#   ('campaign', 'NN'),
#   ('focusing', 'VBG'),
#   ('getting', 'VBG'),
#   ('covid', 'JJ'),
#   ('nineteen', 'JJ'),
#   ('vaccines', 'NNS'),
#   ('east', 'RB'),
#   ('toronto', 'IN'),
#   ('residents', 'NNS'),
#   ('starts', 'VBZ'),
#   ('this', 'DT'),
#   ('saturday', 'NN')],
#  [('choosing', 'VBG'),
#   ('good', 'JJ'),
#   ('policy', 'NN'),
#   ('choices', 'NNS'),
#   ('making', 'VBG'),
#   ('wedge', 'NN'),
#   ('anything', 'NN'),
#   ('conservatives', 'VBZ'),
#   ('that', 'IN'),
#   ('politicized', 'JJ'),
#   ('issue', 'NN'),
#   ('knee', 'NN'),
#   ('jerk', 'NN'),
#   ('criticizing', 'VBG'),
#   ('every', 'DT'),
#   ('choice', 'NN'),
#   ('every', 'DT'),
#   ('step', 'NN'),
#   ('naturally', 'RB'),
#   ('trudeau', 'VBZ'),
#   ('chose', 'JJ'),
#   ('vaccination', 'NN'),
#   ('conservatives', 'NNS'),
#   ('chose', 'VBD'),
#   ('opposite', 'JJ')],
#  [('when', 'WRB'),
#   ('there', 'EX'),
#   ('vaccine', 'VBP'),
#   ('incompetence', 'NN'),
#   ('allowed', 'VBN'),
#   ('isolated', 'JJ'),
#   ('covid', 'NN'),
#   ('infections', 'NNS'),
#   ('spread', 'VBP'),
#   ('epidemic', 'JJ'),
#   ('proportions', 'NNS'),
#   ('requiring', 'VBG'),
#   ('trump', 'NN'),
#   ('shutdown', 'JJ'),
#   ('trump', 'NN'),
#   ('recession', 'NN'),
#   ('biden', 'JJ'),
#   ('american', 'JJ'),
#   ('rescue', 'NN'),
#   ('plan', 'NN'),
#   ('ended', 'VBD'),
#   ('trump', 'JJ'),
#   ('epidemic', 'JJ'),
#   ('recession', 'NN'),
#   ('organizing', 'VBG'),
#   ('vaccination', 'NN'),
#   ('programs', 'NNS')],
#  [('photo', 'VB'),
#   ('your', 'PRP$'),
#   ('vaccination', 'NN'),
#   ('card', 'NN'),
#   ('will', 'MD'),
#   ('sufficient', 'VB'),
#   ('entry', 'NN'),
#   ('thanks', 'NNS')],
#  [('watched', 'JJ'),
#   ('vice', 'NN'),
#   ('story', 'NN'),
#   ('trying', 'VBG'),
#   ('make', 'VB'),
#   ('feel', 'VB'),
#   ('guilty', 'JJ'),
#   ('making', 'VBG'),
#   ('people', 'NNS'),
#   ('that', 'WDT'),
#   ('denied', 'VBD'),
#   ('covid', 'NNS'),
#   ('refused', 'VBN'),
#   ('vaccination', 'NN'),
#   ('later', 'RB'),
#   ('died', 'VBD')],
#  [('been', 'VBN'),
#   ('watching', 'VBG'),
#   ('coverage', 'NN'),
#   ('this', 'DT'),
#   ('insanity', 'NN'),
#   ('anti', 'VBZ'),
#   ('vaccination', 'NN'),
#   ('trucker', 'NN'),
#   ('protests', 'VBZ'),
#   ('their', 'PRP$'),
#   ('threat', 'NN'),
#   ('trucker', 'NN'),
#   ('protest', 'JJS'),
#   ('super', 'NN'),
#   ('bowl', 'NN'),
#   ('this', 'DT'),
#   ('would', 'MD'),
#   ('annoy', 'VB'),
#   ('privilege', 'JJ'),
#   ('class', 'NN'),
#   ('other', 'JJ'),
#   ('wealthy', 'JJ'),
#   ('people', 'NNS'),
#   ('that', 'IN'),
#   ('only', 'RB'),
#   ('people', 'NNS'),
#   ('could', 'MD'),
#   ('afford', 'VB'),
#   ('tickets', 'NNS'),
#   ('range', 'JJ'),
#   ('tickets', 'NNS'),
#   ('prices', 'NNS')],
#  [('like', 'IN'),
#   ('masks', 'NNS'),
#   ('socialdistancing', 'VBG'),
#   ('vaccination', 'NN'),
#   ('because', 'IN'),
#   ('many', 'JJ'),
#   ('still', 'RB'),
#   ('refuse', 'VBP'),
#   ('vaccinated', 'VBN'),
#   ('while', 'IN'),
#   ('people', 'NNS'),
#   ('much', 'JJ'),
#   ('world', 'NN'),
#   ('even', 'RB'),
#   ('have', 'VBP'),
#   ('access', 'NN'),
#   ('vaccine', 'NN'),
#   ('will', 'MD'),
#   ('more', 'RBR'),
#   ('variations', 'NNS'),
#   ('resulting', 'VBG'),
#   ('infections', 'NNS'),
#   ('deaths', 'NNS'),
#   ('wouldn', 'VBP'),
#   ('assume', 'VBP'),
#   ('that', 'IN'),
#   ('wise', 'NN'),
#   ('alien', 'RB'),
#   ('four', 'CD')],
#  ...]

# %%
df['pos_tagged_words'] = pos_tagged
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14324/1355882041.py in <module>
# ----> 1 df['pos_tagged_words'] = pos_tagged
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (2000) does not match length of index (404265)

# %%
df.head()

# %% [markdown]
# ## Stop word removal

# %%
# TEST: remove stop words from test_words_only
from nltk.corpus import stopwords
stop_list = stopwords.words('english')

test_words_only1 = ['not', 'great', 'color', 'and', 'cruelty', 'free', 'i', 'use', 'elf', 'cosmetics', 'every', 'day', 'and', 'i', 'love', 'it']
test_stopremoved = [w for w in test_words_only1 if w not in stop_list or w == 'not']
print(test_stopremoved)

# %%
# remove stop words from tokenised_words_only
from nltk.corpus import stopwords
stop_list = stopwords.words('english')
tokenised_stopremoved = [[w for w in each if w not in stop_list or w == 'not'] for each in tokenised_words_only]
tokenised_stopremoved

# %% [markdown]
# ## Bigram & Trigram Models

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(tokenised_stopremoved, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[tokenised_stopremoved], threshold=100)
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]
def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
# Form Bigrams
tokenised_bigrams = make_bigrams(tokenised_stopremoved)
# Form Trigrams
tokenised_trigrams = make_trigrams(tokenised_stopremoved)

# %%
tokenised_bigrams

# %%
tokenised_trigrams

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# ### Lemmatization with all postags

# %%
# TEST: lemmatisation of test_stopremoved
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
test_lemmatized = [lemmatizer.lemmatize(w)for w in test_stopremoved]
print(test_lemmatized)

# %%
#normal lemmatization of tokenised_stopremoved
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
tokenised_lemmatized_1 = [[lemmatizer.lemmatize(w) for w in each] for each in tokenised_bigrams]
tokenised_lemmatized_1

# %% [markdown]
# ### Lemmatisation with noun, adj, verb and adv

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
import spacy 

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
tokenised_lemmatized_2 = lemmatization(tokenised_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
tokenised_lemmatized_2

# %% [markdown]
# ### Lemmatisation with nouns only

# %%
def lemmatization_noun(texts, allowed_postags=['NOUN']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
import spacy 

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
tokenised_lemmatized_3 = lemmatization_noun(tokenised_bigrams, allowed_postags=['NOUN'])
tokenised_lemmatized_3

# %% [markdown]
# ### Gibberish Remover

# %%
#test
trial_nested=[['happy', 'time', 'ajsdnkfjak'],[],[],['dsnfkajka','yo','wassup']]

# %%
#test
len([])

if len([])== False:
    print('hi')

# %%
#test
from gibberish_detector import detector
# load the gibberish detection model
Detector = detector.create_from_model('../Gibberish-Detector-master/gibberish-detector.model')

##change variable tokenised_lemmatized_x

new_list = []

for alist in trial_nested:
    mini_list = []
    if len(alist):
        for word in alist:
            test = Detector.is_gibberish(word)
            if test == False:
                mini_list.append(word)
    new_list.append(mini_list)

# %%
#test
new_list

# %%
#this is for tokenised_lemmatized_1
from gibberish_detector import detector
# load the gibberish detection model
Detector = detector.create_from_model('../Gibberish-Detector-master/gibberish-detector.model')

##change variable tokenised_lemmatized_x
new_list = []

for alist in tokenised_lemmatized_1:
    mini_list = []
    if len(alist):
        for word in alist:
            test = Detector.is_gibberish(word)
            if test == False:
                mini_list.append(word)
    new_list.append(mini_list)
    
tokenised_lemmatized_1 = new_list

# %%
tokenised_lemmatized_1

# %%
#this is for tokenised_lemmatized_2
from gibberish_detector import detector
# load the gibberish detection model
Detector = detector.create_from_model('../Gibberish-Detector-master/gibberish-detector.model')

##change variable tokenised_lemmatized_x
new_list2 = []

for alist in tokenised_lemmatized_2:
    mini_list = []
    if len(alist):
        for word in alist:
            test = Detector.is_gibberish(word)
            if test == False:
                mini_list.append(word)
    new_list2.append(mini_list)
                
tokenised_lemmatized_2 = new_list2

# %%
tokenised_lemmatized_2

# %%
#this is for tokenised_lemmatized_3
from gibberish_detector import detector
# load the gibberish detection model
Detector = detector.create_from_model('../Gibberish-Detector-master/gibberish-detector.model')

##change variable tokenised_lemmatized_x
new_list3 = []

for alist in tokenised_lemmatized_3:
    mini_list = []
    if len(alist):
        for word in alist:
            test = Detector.is_gibberish(word)
            if test == False:
                mini_list.append(word)
    new_list3.append(mini_list)
                
tokenised_lemmatized_3 = new_list3

# %%
tokenised_lemmatized_3

# %% [markdown]
# ## Creating column with Pre-processed words

# %%
df["words_processed_all"] = tokenised_lemmatized_1
df["words_processed_noun_adj_verb_adv"] = tokenised_lemmatized_2
df["words_processed_noun"] = tokenised_lemmatized_3

# %%
df.head()

# %%
df.to_csv('usa-v2-preprocessed.csv')

# %% [markdown]
# ## TFIDF

# %%
df['words_processed_all']

# %%
def listToString(s): 
    # initialize an empty string
    str1 = "" 
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    # return string  
    return str1

# %%
newlist = []

for each in df['words_processed_all']:
    new = each.strip("][").replace("'","").split(", ")
    newlist.append(new)

# %%
newlist

# %%
joined_list = []

for lis in newlist:
    new = " ".join(lis)
    joined_list.append(new)

# %%
joined_list

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
import pandas as pd
cv = CountVectorizer()
word_count_vector = cv.fit_transform(joined_list)
tf = pd.DataFrame(word_count_vector.toarray(), columns=cv.get_feature_names())
print(tf)

# %%
tfidf_transformer = TfidfTransformer()
X = tfidf_transformer.fit_transform(word_count_vector)
idf = pd.DataFrame({'feature_name':cv.get_feature_names(), 'idf_weights':tfidf_transformer.idf_})
idf.sort_values('idf_weights', ascending=False, inplace=True)

# %%
idf.to_csv('tfidf-descending.csv')

# %%
tf_idf = pd.DataFrame(X.toarray(),columns=cv.get_feature_names())
tf_idf
