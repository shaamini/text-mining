# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/Users/janviaswani/Desktop/text-mining/News Classification'

# %%
# pip install git+https://github.com/siddharth17196/english-hindi-transliteration

# %%
df = pd.read_csv("ENGLISH-1.5kSample-USA.csv")
df
# Out:
#       Unnamed: 0                                               Text  \
# 0              0  want find way end racism try force people inje...
# 1              1  this child almost died tetanus, spent months h...
# 2              2  juste se rappeler m. leblanc la pression que l...
# 3              3  you would expect cases rise significantly, cou...
# 4              4  depends whether vaccination status is embedded...
# ...          ...                                                ...
# 1404        1496  give us two days, we give you headstart hwtc's...
# 1405        1497  serving as biden‚Äôs top science adviser, eric...
# 1406        1498  please read this letter outlining decepticons‚...
# 1407        1499  get your covid-19 vaccination or booster at ib...
# 1408        1500  effective march 1, guests will no longer need ...
#
#                                                new_text languages  \
# 0     want find way end racism try force people inje...   ENGLISH
# ...

# %%
df["text_type"].value_counts()
# Out:
# opinion-based    854
# fact-based       555
# Name: text_type, dtype: int64

# %%
fact = df[df["text_type"]=="fact-based"]
opinion = df[df["text_type"] == "opinion-based"]

# %%
for i in range(len(fact)):
    each = fact.iloc[i]["new_text_after_translation"]
    print(i)
    print(each)
    print(" ")
# Out:
# 0
# this child almost died tetanus, spent months hospital at cost around $1m, his parents still refused vaccination after. this was pre-pandemic.
#
# 1
# as vaccinations... you'll still need proof vaccination restaurants, movie theaters, museums, large arenas, gyms fitness centers. btw nyc vaccination rate is now at 75%. more at 11pm 3/3
#
# 2
# following tweet didn't even age 12 hours before prince charles announced his reinfection, even after vaccination &amp; booster. so, yes, clearly previous infection protects you at this point. does boris johnson exude some sort hypnotoad-like pheromone or something
#
# 3
# vaccination
#
# 4
# private businesses can enforce vaccination mandates if they choose do so.
#
# 5
# story with martha mccallum, am llc senior medical advisor dr. robert redfield comments confusing messaging , spread #omicron importance maintaining your #vaccination status. watch full interview below backhand_index_pointing_down
#
# 6
# ...

# %%
actual_opinion = fact.iloc[[0, 2,6,7,14,15, 21, 26, 28, 37, 43,44,48,49,50,51,53,55,56,57,61,62,66,72,85,86,90,91,96,111,112,115,119,120,124,126,128,133,145,152,153,154,158,162,165.,166,168,175,183,184,185,186,190,192, 195,196,199,200,202,203,204,215,217,220,223,224,225,
                           226,228,229,230,232,233,235,236,239,240,241,243,244,247,249,252,254,255,256,257,258,260,261,266,267,268,271,273,274,277,279,281,283,287,288,289,303,304,305,316,318,329,331,336,339,345,347,353,355,357,358,359,361,369,374,376,378,379,383,394,396,397,
                           400,401,402,404,406,407,408,409,410,412,414,415,417,418,419,421,423,426,428,429,430,431,432,433,434,435,437,438,440,441,442,443,444,446,447,448,449,450,452,459,460,462,464,467,474,475,476,477,481,482,483,484,491,494,495,504,505,506,508,509,510,511,
                           513,514,518,522,525,531,532,540,544,548]]
actual_opinion
# Out:
#       Unnamed: 0                                               Text  \
# 1              1  this child almost died tetanus, spent months h...
# 12            12  following tweet didn't even age 12 hours befor...
# 17            17  world's top virologist, luc montagnier, winner...
# 23            23  this vision public health decisions tied local...
# 53            54  d√©emystifier la vaccination contre l la #covi...
# ...          ...                                                ...
# 1345        1433  "this year‚Äôs oscars ceremony will not requir...
# 1359        1447  new : vaccines are working, but there are stil...
# 1383        1472  dum dum/'s threats are just bully tactics. i w...
# 1392        1483  most people w/prior #sarscov2 infection or vac...
# 1398        1489  ask cdc why quarantine went 10-14 days down 5 ...
#
#                                                new_text languages  \
# 1     this child almost died tetanus, spent months h...   ENGLISH
# ...

# %%
actual_opinion['text_type'] = actual_opinion['text_type'].replace(['fact-based'],'opinion-based')
# Out:
# <ipython-input-13-95a5594df89c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actual_opinion['text_type'] = actual_opinion['text_type'].replace(['fact-based'],'opinion-based')

# %%
actual_opinion
# Out:
#       Unnamed: 0                                               Text  \
# 1              1  this child almost died tetanus, spent months h...
# 12            12  following tweet didn't even age 12 hours befor...
# 17            17  world's top virologist, luc montagnier, winner...
# 23            23  this vision public health decisions tied local...
# 53            54  d√©emystifier la vaccination contre l la #covi...
# ...          ...                                                ...
# 1345        1433  "this year‚Äôs oscars ceremony will not requir...
# 1359        1447  new : vaccines are working, but there are stil...
# 1383        1472  dum dum/'s threats are just bully tactics. i w...
# 1392        1483  most people w/prior #sarscov2 infection or vac...
# 1398        1489  ask cdc why quarantine went 10-14 days down 5 ...
#
#                                                new_text languages  \
# 1     this child almost died tetanus, spent months h...   ENGLISH
# ...

# %%
df[df["Unnamed: 0"] == 12]
# Out:
#     Unnamed: 0                                               Text  \
# 12          12  following tweet didn't even age 12 hours befor...
#
#                                              new_text languages  \
# 12  following tweet didn't even age 12 hours befor...   ENGLISH
#
#                            new_text_after_translation  \
# 12  following tweet didn't even age 12 hours befor...
#
#                                      pos_tagged_words  \
# 12  [('following', 'VBG'), ('tweet', 'NN'), ('didn...
#
#                                   words_processed_all  \
# 12  ['following', 'tweet', 'even', 'age', 'twelve'...
#
#                     words_processed_noun_adj_verb_adv  \
# 12  ['follow', 'even', 'age', 'hour', 'announce', ...
#
#                                  words_processed_noun  subjectivity  \
# 12  ['age', 'hour', 'infection', 'amp', 'booster',...      0.133333
#
#      text_type
# 12  fact-based

# %%
#Replace all rows in df indicated as objective with subjective
df.loc[actual_opinion.index, :] = actual_opinion[:]

# %%
df["text_type"].value_counts()
# Out:
# opinion-based    1055
# fact-based        354
# Name: text_type, dtype: int64

# %%
df[df["Unnamed: 0"] == 12]
# Out:
#     Unnamed: 0                                               Text  \
# 12          12  following tweet didn't even age 12 hours befor...
#
#                                              new_text languages  \
# 12  following tweet didn't even age 12 hours befor...   ENGLISH
#
#                            new_text_after_translation  \
# 12  following tweet didn't even age 12 hours befor...
#
#                                      pos_tagged_words  \
# 12  [('following', 'VBG'), ('tweet', 'NN'), ('didn...
#
#                                   words_processed_all  \
# 12  ['following', 'tweet', 'even', 'age', 'twelve'...
#
#                     words_processed_noun_adj_verb_adv  \
# 12  ['follow', 'even', 'age', 'hour', 'announce', ...
#
#                                  words_processed_noun  subjectivity  \
# 12  ['age', 'hour', 'infection', 'amp', 'booster',...      0.133333
#
#         text_type
# 12  opinion-based

# %%
df.to_csv("labelled_data_objective_subjective_usa.csv")

# %% [markdown]
# ## Some other functions to help deal with different languages & almost similar tweets

# %%
# from difflib import SequenceMatcher
# s_1 = 'Mohan Mehta'
# s_2 = 'Mohan Mehte'
# print(SequenceMatcher(a=s_1,b=s_2).ratio())

# %%
# from elt.translit import translit

# to_hindi = translit('hindi')
# hi = to_hindi.convert(['sirf galtiyan nikalna aata he tumko bhai'])
# hi

# %%
# from deep_translator import GoogleTranslator

# translated = []

# for each in hi:
#     translate = GoogleTranslator(source='auto', target='en').translate(each)
#     translated.append(translate)
    
# translated
