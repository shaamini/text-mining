# %%
import pandas as pd
from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora, models
from gensim.utils import simple_preprocess
import gensim, spacy
from gensim.models.ldamulticore import LdaMulticore
import re
from gensim.models import Phrases
from gensim.models.phrases import Phraser

# %%
df = pd.read_csv('token_lemm.csv')
df
# Out:
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 320117  pretty remarkable achievement. thank you all v...
# 320118  oh that explains similar - seemingly out nowhe...
# 320119  do it others.... flexed_bicepsparty_poppersyri...
# 320120  yay raising_handslight_skin_tone congrats dr. ...
# 320121  we all have do our part end this pandemic— get...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 320117  ['pretty', 'remarkable', 'achievement', 'thank...
# 320118  ['explains', 'similar', 'seemingly', 'nowhere'...
# 320119                    ['others', 'vaccinesaveslives']
# 320120  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 320121  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 320117  ['pretty', 'remarkable', 'achievement', 'thank...
# 320118  ['explain', 'similar', 'seemingly', 'nowhere',...
# 320119                      ['other', 'vaccinesaveslive']
# 320120  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 320121  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 320117  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 320118                  ['message', 'background', 'folk']  subjective
# 320119                                          ['other']  subjective
# 320120              ['congrat', 'feeling', 'safetyfirst']  subjective
# 320121  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment                              tokenised_stopremoved
# 0               2  ['end', 'racism', 'force', 'bunch', 'race', 's...
# 1               0  ['child', 'tetanus', 'hospital', 'cost', 'pare...
# 2               0  ['leblanc', 'pressure', 'business', 'world', '...
# 3               2  ['case', 'rate', 'play', 'space', 'adult', 'sp...
# 4               2  ['status', 'code', 'link', 'connect', 'end', '...
# ...           ...                                                ...
# 320117          2  ['achievement', 'volunteer', 'shotsshotsshot',...
# 320118          0                  ['message', 'background', 'folk']
# 320119          2                                                 []
# 320120          2              ['congrat', 'feeling', 'safetyfirst']
# 320121          2    ['end', 'help', 'physician', 'monitor', 'site']
#
# [320122 rows x 7 columns]

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
tokenised_lemmatized = list(sent_to_words(df['tokenised_stopremoved']))

# %%
tokenised_lemmatized
# Out:
# [['end', 'racism', 'force', 'bunch', 'race', 'support', 'force'],
#  ['child', 'tetanus', 'hospital', 'cost', 'parent', 'pandemic'],
#  ['leblanc',
#   'pressure',
#   'business',
#   'world',
#   'border',
#   'air',
#   'traffic',
#   'block',
#   'tourist',
#   'hotel',
#   'restaurant'],
#  ['case',
#   'rate',
#   'play',
#   'space',
#   'adult',
#   'space',
#   'school',
#   'age',
#   'student',
#   'datum',
#   'state',
#   'bear'],
#  ['status', 'code', 'link', 'connect', 'end', 'read'],
#  ['isolation', 'question', 'look', 'spike', 'matter'],
#  ['center', 'parent', 'mask', 'answer'],
#  ['tool',
#   'suite',
#   'leader',
#   'combat',
#   'hesitancy',
#   'resistance',
#   'video',
#   'article'],
#  ['goal', 'blogger', 'news', 'accident', 'step', 'competence'],
#  ['head', 'brain', 'place', 'rate', 'case_count', 'dictatorship', 'name'],
#  ['world', 'passport', 'goal'],
#  ['restaurant', 'arena', 'fitness', 'center', 'rate'],
#  ['age',
#   'infection',
#   'booster',
#   'infection',
#   'protect',
#   'hypnotoad',
#   'pheromone'],
#  ['understand', 'link', 'compulsory', 'bawl', 'bye'],
#  ['winner', 'lab', 'variant', 'count'],
#  ['common_sense', 'solution', 'virus', 'business'],
#  ['tooting', 'place', 'language'],
#  ['variant', 'ventilation', 'kid', 'kid', 'danger', 'kid', 'danger', 'matter'],
#  ['county', 'threshold', 'datum', 'school'],
#  ['business', 'proof', 'government', 'province'],
#  ['vision',
#   'health',
#   'decision',
#   'condition',
#   'vulnerability',
#   'politic',
#   'level',
#   'factor'],
#  ['understand', 'thought'],
#  ['concern', 'level'],
#  ['steel', 'mandate', 'mask', 'testing', 'cost', 'cost'],
#  [],
#  ['pregnancy', 'term'],
#  ['government',
#   'concern',
#   'prevent',
#   'hospital',
#   'emergency',
#   'depth',
#   'resource',
#   'bed',
#   'space',
#   'equipment',
#   'staff',
#   'hospital'],
#  ['spread', 'case', 'care', 'status', 'force'],
#  ['game', 'green_light', 'status', 'stadium', 'enforce'],
#  ['business', 'proof'],
#  ['specialist', 'effort'],
#  [],
#  ['body', 'fight', 'business', 'employer', 'government'],
#  ['report', 'document', 'trump', 'bullshit', 'border', 'end', 'mandate'],
#  ['conclusion', 'mandate', 'death', 'rate', 'state', 'rate'],
#  ['issue'],
#  ['laughingstock',
#   'rest',
#   'world',
#   'trucker',
#   'mandate',
#   'lie',
#   'reinstatement',
#   'tag'],
#  ['death', 'push', 'agenda'],
#  ['school',
#   'proof',
#   'respect',
#   'individuality',
#   'health',
#   'decision',
#   'choice',
#   'lol',
#   'hate'],
#  ['state',
#   'state',
#   'mask',
#   'mandate',
#   'state',
#   'course',
#   'rate',
#   'conclusion'],
#  ['neighbor', 'pig', 'rate', 'world'],
#  ['celebrity', 'event'],
#  ['trust', 'rate'],
#  ['policy', 'government', 'mandate', 'employer', 'policy'],
#  ['subject'],
#  ['rule', 'mask'],
#  ['abortion', 'thought', 'prayer', 'prayer'],
#  ['paradox', 'death', 'rate', 'fatality'],
#  ['masking', 'kid', 'hospitalization', 'rate', 'rate', 'kid', 'normalcy'],
#  ['case', 'state', 'rate', 'news', 'site', 'spoon', 'intelligence'],
#  ['choice',
#   'abortion',
#   'choice',
#   'abortion',
#   'remove',
#   'life',
#   'remove',
#   'choice',
#   'risk'],
#  ['endemic',
#   'lockdown',
#   'mask',
#   'fear',
#   'precaution',
#   'age',
#   'health',
#   'condition'],
#  ['result', 'infection'],
#  ['status'],
#  ['mandate',
#   'school',
#   'rate',
#   'education',
#   'outreach',
#   'student',
#   'sibling',
#   'mask',
#   'mandate'],
#  ['abortion'],
#  ['explain', 'issue'],
#  ['eric_adam', 'key', 'order', 'age', 'show', 'proof', 'participate', 'proof'],
#  [],
#  ['faught', 'health', 'care'],
#  ['challenge',
#   'nation',
#   'rule',
#   'testing',
#   'problem',
#   'creation',
#   'self',
#   'country'],
#  ['stake', 'applicant', 'choice'],
#  ['trading', 'player', 'claim', 'injury', 'rate'],
#  ['lesson', 'damage', 'ifs'],
#  ['member',
#   'submit',
#   'card',
#   'card',
#   'reporting',
#   'mean',
#   'event',
#   'side_effect',
#   'event'],
#  ['fear', 'fear', 'mask', 'held_hostage'],
#  ['rate',
#   'benefit',
#   'risk',
#   'instruction',
#   'glad',
#   'activity',
#   'weather',
#   'air'],
#  ['head', 'answer'],
#  ['slide', 'injure', 'notice', 'horse', 'serum'],
#  [],
#  ['recommendation', 'health', 'care', 'worker', 'fund', 'scout', 'safety'],
#  ['prevention',
#   'mask',
#   'mask',
#   'flu',
#   'flu',
#   'shot',
#   'difference',
#   'virus',
#   'kill',
#   'rate'],
#  ['yield', 'result', 'mandate', 'decision'],
#  ['altar', 'produce', 'testing'],
#  ['look', 'mirror', 'conservative', 'blockade', 'rhetoric', 'health', 'order'],
#  ['fan',
#   'super_bowl',
#   'experience',
#   'ticket',
#   'experience',
#   'future',
#   'date',
#   'visit',
#   'site'],
#  ['pass', 'adult', 'choice', 'consequence', 'rate'],
#  ['card', 'thank'],
#  ['vehicle'],
#  [],
#  ['website', 'benefit', 'outweigh', 'risk', 'risk'],
#  ['lockdown',
#   'biden',
#   'biden',
#   'program',
#   'trump',
#   'increase',
#   'rate',
#   'presidency'],
#  ['ability',
#   'restriction',
#   'mandate',
#   'trust',
#   'business',
#   'restaurant',
#   'guarantee'],
#  ['find', 'clip', 'base', 'source'],
#  ['treatment', 'definition', 'response', 'illness'],
#  ['prevent', 'spread', 'disinformation'],
#  ['rate'],
#  ['substance', 'rabie', 'forgot', 'administer', 'post'],
#  ['isolate', 'protect'],
#  ['recovery', 'individual', 'recommendation'],
#  ['measle', 'outrage'],
#  ['dog', 'twenty_minute'],
#  ['parent', 'infrastructure', 'grownup', 'hell', 'kid', 'cold'],
#  ['list',
#   'nominee',
#   'requirement',
#   'meltdown',
#   'twitter',
#   'wag',
#   'movie',
#   'shot'],
#  ['inquiry', 'european_union', 'titer', 'test', 'system'],
#  ['rate', 'district', 'leader', 'tweet', 'restaurant'],
#  ['government',
#   'place',
#   'business',
#   'government',
#   'mandate',
#   'show',
#   'proof',
#   'oppression'],
#  ['term', 'surface', 'protein'],
#  ['fact', 'care', 'pal', 'care'],
#  ['measure', 'science'],
#  ['bring', 'conflict', 'worker', 'type', 'vacation', 'proof', 'dime'],
#  ['protestor', 'wheel'],
#  ['hospitalization',
#   'booster',
#   'rate',
#   'look',
#   'hospitalization',
#   'chart',
#   'world'],
#  ['gymnastic', 'police', 'brutality', 'minority'],
#  ['defundcbc', 'defundbbc', 'extravaganza', 'network', 'fund', 'baddie'],
#  ['immunity', 'fact', 'therapist', 'health', 'risk', 'kill', 'technology'],
#  ['school', 'age', 'kid', 'school', 'parent'],
#  [],
#  ['fact', 'country', 'follow', 'show', 'leave', 'country', 'proof'],
#  ['ice', 'hockey', 'end', 'program'],
#  ['mandate',
#   'rate',
#   'restriction',
#   'tone',
#   'thread',
#   'mandate',
#   'attempt',
#   'coerce'],
#  ['answer', 'stimulate', 'gas', 'postvaccination', 'case'],
#  ['government', 'kid', 'face', 'mask', 'school'],
#  ['rate', 'majority', 'government', 'pandemic', 'plan', 'dummy'],
#  ['paper',
#   'state',
#   'spike_protein',
#   'level',
#   'blood',
#   'variant',
#   'produce',
#   'antibody',
#   'variant'],
#  ['immigration',
#   'question',
#   'answer',
#   'health',
#   'safety',
#   'requirement',
#   'record'],
#  ['terrorist', 'issue', 'issue', 'restriction', 'period'],
#  ['isolation',
#   'fentanyl',
#   'death',
#   'loved_one',
#   'stress',
#   'mask',
#   'show',
#   'proof',
#   'baby'],
#  ['county', 'rate', 'mask'],
#  ['half',
#   'adult',
#   'flu',
#   'heart',
#   'disease',
#   'heart',
#   'disease',
#   'risk',
#   'flu',
#   'complication'],
#  ['misinformation',
#   'nowspinning',
#   'hear',
#   'subgenius',
#   'radio',
#   'end',
#   'antivaxxer',
#   'detail'],
#  ['parking', 'ticket', 'check', 'bylaw', 'officer', 'business', 'shot'],
#  ['show', 'proof', 'hell'],
#  ['hope', 'treatment', 'problem', 'immunity', 'system', 'case', 'check'],
#  ['flu', 'flu', 'complication'],
#  ['mask', 'understand', 'right'],
#  ['leave',
#   'question',
#   'booster',
#   'dose',
#   'client',
#   'contract',
#   'health',
#   'concern'],
#  ['discrimination',
#   'color',
#   'sex',
#   'religion',
#   'health',
#   'system',
#   'injection'],
#  ['turn', 'sense', 'choice', 'pay', 'rent'],
#  ['issue',
#   'threat',
#   'police',
#   'state',
#   'group',
#   'democracy',
#   'kid',
#   'country'],
#  ['impact',
#   'metric',
#   'guide',
#   'policy',
#   'icu',
#   'rate',
#   'hospitalization',
#   'community',
#   'spread',
#   'absenteeism',
#   'repnotrip'],
#  ['ac', 'death', 'ambulance', 'incompetence', 'management'],
#  ['member', 'minute'],
#  ['quebecer', 'solution', 'reduce', 'contagion'],
#  ['question', 'airline', 'proof', 'destination', 'proof'],
#  ['mitigation'],
#  ['question', 'place', 'entry'],
#  ['intention', 'tue', 'drop', 'case', 'county', 'rate', 'state'],
#  ['employer', 'mandate'],
#  ['boy', 'rate', 'science'],
#  ['alignment', 'issue', 'cabal', 'mybodymychoice', 'ear'],
#  ['rate',
#   'percent',
#   'indoor_space',
#   'running',
#   'errand',
#   'retirement',
#   'hubby'],
#  ['fact',
#   'business',
#   'option',
#   'status',
#   'choice',
#   'choice',
#   'choice',
#   'business',
#   'poli'],
#  ['side', 'fiorella', 'fan', 'ratio'],
#  ['rate',
#   'definition',
#   'immunity',
#   'infection',
#   'hospitalization',
#   'death',
#   'policy'],
#  ['memory', 'analysis', 'state', 'access'],
#  ['election', 'definition', 'tourist', 'mandate', 'care'],
#  ['firm', 'belief', 'sixer'],
#  ['health', 'ventilation', 'amount', 'virus', 'air', 'chance'],
#  ['utility', 'plan', 'testing', 'safety', 'protocol'],
#  ['variant', 'antibody', 'selection', 'ade'],
#  ['business', 'code', 'app', 'business'],
#  ['recurrence', 'connection', 'herpe', 'infection'],
#  ['state', 'border', 'card', 'business', 'comparison', 'makes_sense'],
#  ['girl', 'selling', 'card', 'card', 'card'],
#  ['history', 'definition', 'reason', 'change', 'meaning'],
#  ['card',
#   'comparison',
#   'water',
#   'context',
#   'creation',
#   'role',
#   'strategy',
#   'impact'],
#  ['clinic', 'health', 'screening', 'vendor', 'music', 'food', 'fun', 'flyer'],
#  ['policy', 'science'],
#  ['propaganda', 'exercise', 'rate', 'world', 'guilt', 'business'],
#  ['mask', 'mandate', 'proof'],
#  ['protect', 'border', 'trucker', 'cross_border', 'rule', 'care'],
#  ['risk',
#   'reduction',
#   'virus',
#   'circulate',
#   'body',
#   'antibody',
#   'virus',
#   'body'],
#  ['topic', 'supporter'],
#  ['event', 'terrace'],
#  ['recovery', 'bow', 'timing', 'pass'],
#  ['pneumonia', 'influenza', 'trap'],
#  ['party',
#   'weekend',
#   'matter',
#   'root',
#   'mask',
#   'defensive',
#   'play',
#   'care',
#   'matter'],
#  ['bill', 'mandate', 'school', 'kid', 'kid', 'school', 'requirement'],
#  ['cell',
#   'subject',
#   'infection',
#   'history',
#   'tool',
#   'monitoring',
#   'protection'],
#  ['opponent', 'distrust', 'product', 'test', 'principle', 'package'],
#  ['wave', 'wave', 'fact', 'occurrence'],
#  ['study', 'reality', 'mandate', 'hospitalization', 'path', 'pandemic'],
#  ['regime',
#   'spokespeople',
#   'mom',
#   'sentiment',
#   'protest',
#   'protest',
#   'mandate',
#   'sentiment',
#   'trucker'],
#  ['difference', 'canadian', 'spectrum', 'restriction', 'life', 'goal'],
#  ['card', 'wash_hand'],
#  ['record', 'idea', 'question', 'importance', 'typhoid'],
#  ['court', 'fund', 'platform'],
#  ['anti_baxter', 'majority', 'staff', 'member', 'business'],
#  ['twitter', 'feed', 'blame', 'proof', 'diagnosis', 'fact'],
#  ['favor', 'tool', 'tension', 'pass'],
#  ['net',
#   'hocus',
#   'drop',
#   'mask',
#   'mandate',
#   'requirement',
#   'business',
#   'customer',
#   'mask'],
#  ['center'],
#  ['transmission',
#   'risk',
#   'approach',
#   'wish',
#   'wear',
#   'mask',
#   'risk',
#   'assessment'],
#  ['measure'],
#  ['mandate', 'trucker'],
#  ['spread', 'die', 'reason', 'categorize', 'status'],
#  ['stage', 'wink', 'actor', 'premier', 'mandate'],
#  ['infection', 'rate', 'country', 'mask'],
#  ['key', 'health', 'activity'],
#  ['business', 'proof', 'reader', 'business', 'status', 'wolf', 'health'],
#  ['reason', 'majority', 'canadian', 'mandate'],
#  ['limitation',
#   'clinician',
#   'report',
#   'adverse_event',
#   'event',
#   'hospitalization',
#   'veer',
#   'reporting',
#   'system',
#   'veer'],
#  ['child', 'organization', 'girl', 'guide', 'check', 'status', 'child'],
#  ['outlier', 'profession', 'benefit', 'population', 'statistic', 'want'],
#  ['elimination', 'proof', 'satisfy', 'avoid', 'fan', 'club'],
#  ['doctor',
#   'doctor',
#   'effect',
#   'etc',
#   'doctor',
#   'kid',
#   'language',
#   'crusader'],
#  ['claim', 'family', 'trip', 'world', 'fact'],
#  ['business',
#   'mask',
#   'customer',
#   'proof',
#   'status',
#   'proof',
#   'mask',
#   'policy'],
#  ['state'],
#  ['train', 'airline', 'proof', 'province', 'app', 'train', 'holiday'],
#  ['study', 'risk', 'effect', 'brother', 'amateur', 'bicycle', 'exhaustion'],
#  ['bribe', 'state', 'rate', 'discussion', 'tweet', 'mention'],
#  ['supply', 'medication', 'state', 'child', 'progress', 'maskshelp'],
#  ['histrionic',
#   'government',
#   'actor',
#   'argument',
#   'excuse',
#   'avoid',
#   'requirement'],
#  ['fault', 'liberty', 'reality'],
#  ['date', 'beer', 'license', 'name', 'home', 'address'],
#  ['hit', 'policy', 'employee', 'attend'],
#  ['child', 'seeing', 'premise', 'want', 'death', 'status', 'policy'],
#  ['brain',
#   'trust',
#   'ground',
#   'support',
#   'convoy',
#   'jurisdiction',
#   'mandate',
#   'cross_border'],
#  ['goal',
#   'stress',
#   'ear',
#   'stay',
#   'omicron',
#   'flu',
#   'precaution',
#   'life',
#   'life'],
#  ['tip'],
#  ['restriction'],
#  ['report', 'oscar', 'test', 'proof'],
#  ['age', 'bracket', 'rate', 'case', 'rate', 'graph'],
#  ['propaganda', 'school'],
#  ['status', 'intelligence'],
#  ['worker', 'visitor'],
#  ['reporter', 'pulp', 'email', 'reason', 'redefinition', 'fact', 'check'],
#  ['application', 'proof', 'version'],
#  ['encouragement',
#   'passport',
#   'plan',
#   'requirement',
#   'stick',
#   'needle',
#   'yrs',
#   'work'],
#  ['stance', 'spin'],
#  ['mandate',
#   'city',
#   'folk',
#   'proof',
#   'indoor_dining',
#   'event',
#   'arena',
#   'gyms_theater',
#   'museum'],
#  ['history', 'context', 'tuskegee'],
#  ['center', 'permit', 'work', 'hospital'],
#  ['season', 'existence', 'change', 'argument', 'matter', 'deny'],
#  ['policy', 'science'],
#  ['proof', 'felony'],
#  ['help',
#   'business',
#   'school',
#   'team',
#   'pandemic',
#   'testing',
#   'reporting',
#   'solution',
#   'status'],
#  ['evidence'],
#  ['eye'],
#  ['rape', 'deserve', 'sun', 'end', 'triage', 'line', 'care'],
#  ['shot'],
#  [],
#  ['evidence', 'case'],
#  ['ambiguity',
#   'mask',
#   'drug',
#   'therapy',
#   'query',
#   'recomendation',
#   'efficacy',
#   'datum'],
#  ['passport',
#   'infection',
#   'rate',
#   'infection',
#   'mirror',
#   'rate',
#   'mandate',
#   'ontario'],
#  ['clock', 'dust', 'check'],
#  ['mask', 'talk', 'remedy'],
#  ['party', 'issue', 'party', 'opinion', 'siding', 'mask', 'hardship'],
#  ['datum',
#   'case_count',
#   'rate',
#   'availability',
#   'testing',
#   'availability',
#   'treatment',
#   'facility',
#   'decision',
#   'team',
#   'health',
#   'expert',
#   'leader'],
#  ['argument', 'child', 'passport', 'mention', 'effort', 'nuance'],
#  ['case', 'hospitalization', 'rate'],
#  ['restriction',
#   'mandate',
#   'employer',
#   'requirement',
#   'community',
#   'hospital',
#   'surgery'],
#  ['card'],
#  ['stop', 'idea', 'lifestyle', 'choice', 'kid', 'impact'],
#  ['credit', 'credit', 'arm'],
#  ['kudo', 'requirement', 'place'],
#  ['couple',
#   'program',
#   'guise',
#   'virus',
#   'jabbed',
#   'woman',
#   'issue',
#   'miscarriage',
#   'piece'],
#  ['course', 'question', 'answer', 'question'],
#  ['status', 'choice', 'virus', 'million', 'life', 'generation'],
#  ['rate', 'ontario', 'end', 'game', 'liberal'],
#  ['reading', 'tweet', 'death', 'rate', 'rate', 'rate'],
#  ['mandate', 'rule', 'business', 'mandate'],
#  ['society', 'death', 'scientist', 'virus'],
#  ['rate',
#   'case',
#   'hospitalization',
#   'risk',
#   'atm',
#   'outbreak',
#   'mask',
#   'badge',
#   'science',
#   'cac'],
#  ['fact',
#   'check',
#   'website',
#   'misinformation',
#   'context',
#   'foil',
#   'email',
#   'panic',
#   'redefine'],
#  ['status', 'detail'],
#  ['booster'],
#  ['shame',
#   'publish',
#   'type',
#   'article',
#   'scientist',
#   'manipulation',
#   'newspaper'],
#  [],
#  ['clinic', 'noon', 'kid', 'school', 'parent', 'clinic'],
#  ['issue',
#   'ego',
#   'accuracy',
#   'datum',
#   'name',
#   'virus',
#   'animal',
#   'reservoir',
#   'source',
#   'claim',
#   'ism'],
#  ['status', 'fascist', 'terrorist', 'group'],
#  ['work', 'world', 'country', 'amount', 'booster'],
#  ['study',
#   'scientist',
#   'student',
#   'staff',
#   'mask',
#   'school',
#   'transmission',
#   'right_winger',
#   'mask'],
#  ['benefit', 'baffle', 'statistic', 'virus', 'fact'],
#  ['regime',
#   'politicization',
#   'highway',
#   'society',
#   'syringerat',
#   'control',
#   'heckler',
#   'truck'],
#  ['harden', 'sense'],
#  ['leadership', 'end', 'winter', 'term', 'proof', 'student', 'semester'],
#  ['loosen',
#   'restriction',
#   'rate',
#   'booster',
#   'booster',
#   'protection',
#   'omicron'],
#  ['truck', 'right_wing', 'convoy'],
#  [],
#  ['mask'],
#  ['hospital', 'head', 'budget', 'vote', 'handling', 'plot', 'rest'],
#  ['restriction', 'personality'],
#  ['chicken', 'death', 'rate', 'party'],
#  ['world', 'change'],
#  ['million', 'immunity', 'health', 'risk'],
#  ['note', 'rate', 'datum', 'rate', 'survey', 'result'],
#  ['plan', 'clinic', 'check', 'mate'],
#  ['traffic', 'health', 'doctor', 'duty', 'manager', 'site'],
#  ['rape', 'fuck', 'wrong'],
#  ['prove'],
#  ['trucker_protest', 'state', 'proof', 'pandemic', 'management'],
#  ['flu', 'theater', 'segregation', 'hate', 'system'],
#  ['treat', 'night', 'mask', 'group', 'joy', 'music', 'earthling'],
#  [],
#  ['passport'],
#  ['purpose'],
#  ['game',
#   'student',
#   'card',
#   'comfort',
#   'color',
#   'shirt',
#   'grant',
#   'msriverproject'],
#  ['rate', 'percent'],
#  ['proof',
#   'policy',
#   'place',
#   'fall',
#   'logic',
#   'dropping',
#   'requirement',
#   'end',
#   'goal'],
#  ['network',
#   'misinformation',
#   'show',
#   'song',
#   'root',
#   'history',
#   'insanity',
#   'antivaxrs',
#   'war',
#   'radio',
#   'detail'],
#  ['restaurant', 'card'],
#  ['look',
#   'world',
#   'restriction',
#   'lockdown',
#   'mandate',
#   'rate',
#   'blood',
#   'stone'],
#  ['illness', 'skin', 'card'],
#  ['equity', 'power', 'health', 'source', 'stat'],
#  ['neighborhood', 'rate', 'sparrow', 'creek', 'ord', 'dose'],
#  ['rate', 'infection', 'aspect', 'share', 'video'],
#  ['case', 'issue'],
#  ['life', 'passport', 'mandate', 'support'],
#  ['flu', 'flu'],
#  ['country', 'goal', 'vaccinate'],
#  ['country',
#   'goal',
#   'percent',
#   'rate',
#   'talk',
#   'safety',
#   'measure',
#   'safety',
#   'measure',
#   'country',
#   'seesaw',
#   'erode',
#   'trust'],
#  ['theater', 'attend', 'class', 'finder', 'help', 'thank'],
#  ['hepburn', 'requirement', 'city', 'hepburn', 'facility', 'website'],
#  ['protection',
#   'infection',
#   'transmission',
#   'booster',
#   'protection',
#   'hospitalization',
#   'death'],
#  ['mask'],
#  [],
#  ['mandate'],
#  ['country',
#   'world',
#   'population',
#   'country',
#   'rate',
#   'maniac',
#   'logic',
#   'science'],
#  ['date', 'mos', 'past', 'infection', 'omicron', 'variant'],
#  ['plan',
#   'apostle',
#   'right',
#   'law',
#   'order',
#   'conservative',
#   'trucker',
#   'economy'],
#  ['team', 'league', 'season', 'playoff', 'team', 'game'],
#  ['situation', 'cost', 'restriction', 'rate'],
#  [],
#  ['crisis', 'push', 'mandate', 'age', 'enhance'],
#  ['mask', 'data', 'city'],
#  ['country',
#   'world',
#   'population',
#   'country',
#   'rate',
#   'maniac',
#   'logic',
#   'science'],
#  ['mistake'],
#  ['statistic', 'none', 'look', 'statistic', 'bias'],
#  ['class', 'residence', 'circ', 'residence'],
#  ['leverage', 'virus'],
#  ['mask', 'stop', 'generalization'],
#  ['program', 'business', 'path', 'business', 'recruitment'],
#  ['mask',
#   'truth',
#   'restriction',
#   'kid',
#   'adult',
#   'school',
#   'data',
#   'science',
#   'politic',
#   'noise'],
#  ['gestation',
#   'company',
#   'policy',
#   'company',
#   'drug',
#   'test',
#   'policy',
#   'refuse',
#   'workplace',
#   'place'],
#  ['border', 'movement'],
#  ['progress', 'status', 'virus'],
#  ['outreach', 'gap', 'work', 'effort', 'strategy', 'death', 'country'],
#  ['pandemic'],
#  ['worry', 'concern', 'risk'],
#  ['program', 'dialog', 'canadian', 'tyrant'],
#  ['hospitalization', 'data', 'death', 'datum', 'omicron', 'coverage', 'case'],
#  ['territory', 'rate'],
#  ['player', 'team', 'hope', 'card', 'player', 'sixer', 'fan'],
#  ['mandate', 'metro', 'area', 'rate'],
#  ['premier', 'rule', 'visitor', 'state'],
#  ['school', 'play', 'music', 'experience', 'todaylaptop'],
#  [],
#  ['pregnancy', 'woman', 'risk', 'authority', 'case'],
#  ['death', 'hygiene', 'health'],
#  ['elite', 'pass'],
#  ['discussion', 'makes_sense', 'trick', 'credit'],
#  ['mandate', 'mandate', 'protest', 'country', 'status'],
#  ['fact', 'rate', 'teenager', 'frame', 'information', 'wrong'],
#  ['clue', 'nation'],
#  ['theater', 'requirement'],
#  ['misinformation', 'rate', 'nation', 'misinformation', 'beginning'],
#  ['congrat',
#   'winner',
#   'prevention',
#   'challenge',
#   'competition',
#   'well',
#   'visit',
#   'rate'],
#  ['corn', 'pop', 'portrayal', 'economy', 'twitter', 'react', 'proof'],
#  ['mandate'],
#  ['birth', 'certificate', 'proof', 'cruise', 'welcome'],
#  ['mask', 'mandate', 'requirement'],
#  ['refusal', 'force'],
#  ['majority', 'attendee', 'employee', 'attendee', 'award', 'ceremony'],
#  ['booster', 'pass'],
#  ['ticket', 'show', 'taping', 'show', 'testing', 'pretend', 'hysteria'],
#  ['concert', 'event', 'venue', 'series', 'proof', 'test', 'info'],
#  ['weekend', 'holiday', 'mask', 'syringe'],
#  ['show', 'proof', 'place'],
#  ['mandate', 'system', 'mortality', 'event'],
#  ['immunization'],
#  ['render', 'immunity', 'system', 'goal', 'post', 'immunization', 'hack'],
#  ['sheriff', 'mandate', 'suicide', 'pact'],
#  ['liberal',
#   'attempt',
#   'divide',
#   'refusal',
#   'follow',
#   'science',
#   'root',
#   'cause'],
#  ['reporter', 'status', 'matter'],
#  ['mentality', 'rate', 'toilet'],
#  ['investigation', 'govern'],
#  ['reassess',
#   'metric',
#   'case',
#   'hospital',
#   'admission',
#   'rate',
#   'asksavanity'],
#  ['rise',
#   'transmisibility',
#   'infection',
#   'booster',
#   'adult',
#   'hospitalization',
#   'child',
#   'example',
#   'con'],
#  ['conservative', 'campaign', 'end', 'disease', 'elite'],
#  ['work', 'chance'],
#  ['status', 'client'],
#  ['illness',
#   'care',
#   'patient',
#   'bag',
#   'base',
#   'rate',
#   'falsification',
#   'patient'],
#  ['shot', 'blood', 'test', 'trace', 'adult'],
#  ['variance', 'study', 'protection'],
#  ['teacher', 'job', 'anxiety', 'life'],
#  ['help', 'track', 'reaction', 'hunting'],
#  ['lie', 'mandate', 'liar'],
#  ['death', 'study', 'prevent'],
#  [],
#  ['pioneer', 'doctor', 'work', 'disease'],
#  ['government',
#   'job',
#   'news',
#   'finance',
#   'export',
#   'face',
#   'jeffrie',
#   'job',
#   'credit'],
#  ['friend', 'friend', 'choice'],
#  ['focus', 'risk', 'group', 'year_old'],
#  ['planning', 'proof', 'card'],
#  ['search', 'group', 'site', 'place', 'kid', 'site', 'hospital'],
#  ['authority',
#   'coronavirus',
#   'case',
#   'record',
#   'spread',
#   'rate',
#   'absence',
#   'restriction',
#   'adult'],
#  ['rate', 'deadline', 'mandate'],
#  ['death', 'incline', 'end', 'date', 'auto', 'immunity', 'post', 'stroke'],
#  ['jurisdiction',
#   'end',
#   'mandate',
#   'level',
#   'case',
#   'metric',
#   'virus',
#   'testing',
#   'rate',
#   'endthemandate'],
#  ['removing',
#   'mandate',
#   'social_distance',
#   'mask',
#   'booster',
#   'freedom',
#   'choice'],
#  ['service', 'stroke', 'heart_attack', 'war', 'biden', 'country', 'world'],
#  ['infection',
#   'protection',
#   'infection',
#   'level',
#   'infection',
#   'measure',
#   'infection'],
#  ['rate', 'infection', 'child'],
#  ['percentage', 'population', 'immunity', 'infection'],
#  ['worker',
#   'business',
#   'brainer',
#   'incentive',
#   'testing',
#   'incentive',
#   'testing'],
#  ['government', 'health', 'measure'],
#  ['restriction',
#   'mandate',
#   'concern',
#   'society',
#   'benefit',
#   'government',
#   'safety'],
#  ['state', 'status', 'bout'],
#  ['school',
#   'place',
#   'quality',
#   'mask',
#   'value',
#   'kind',
#   'mask',
#   'rapid_test',
#   'case'],
#  ['teacher', 'status', 'list', 'medication', 'child'],
#  ['hole', 'border', 'loss', 'vehicle', 'society', 'crowd'],
#  ['team', 'news', 'cycle', 'matter', 'status', 'baseball'],
#  ['antibody', 'immunity', 'population', 'fact', 'survivor', 'tunnel'],
#  ['nose', 'harm', 'liberal', 'body', 'choice', 'guess'],
#  ['appointment', 'child', 'approval'],
#  ['datum',
#   'cac',
#   'omicron',
#   'period',
#   'hospitalization',
#   'condition',
#   'adult',
#   'hospital',
#   'rate',
#   'idaho'],
#  ['infection'],
#  ['track', 'infection', 'rate', 'rate'],
#  ['exemption', 'cmon', 'exemption', 'exemption', 'rate', 'idea'],
#  ['idea', 'trouble', 'wear_mask', 'child', 'school', 'issue', 'kid', 'rate'],
#  ['smallpox', 'thank'],
#  ['choice', 'community', 'talking_point', 'country', 'requirement'],
#  ['seasonal_flu', 'thank', 'measure', 'restriction'],
#  ['normality', 'mask', 'patient', 'staff', 'office', 'grief', 'option'],
#  ['show', 'card', 'place', 'site', 'night', 'place'],
#  ['expertise', 'death'],
#  ['window', 'effectiveness', 'effect'],
#  ['amount', 'tweet', 'trade', 'deadline', 'status', 'whomever'],
#  ['doctor', 'evening', 'pajama', 'death', 'immunity', 'look', 'mirror'],
#  ['protester', 'country', 'rate', 'mandate', 'auto_maker', 'production'],
#  ['interest', 'test', 'order', 'bar'],
#  ['card', 'mask'],
#  ['reason', 'reason', 'condition', 'allergy', 'choice', 'disorder'],
#  ['government', 'worker', 'information'],
#  ['print', 'download', 'copy', 'eye'],
#  ['fact', 'passport', 'name', 'ram', 'leave', 'country'],
#  ['record'],
#  ['elite', 'shout'],
#  ['proof',
#   'border',
#   'trucker',
#   'exemption',
#   'call',
#   'trucker',
#   'terrorist',
#   'trucker'],
#  ['future'],
#  ['awareness', 'brigade'],
#  ['proof', 'place', 'student'],
#  ['fact_checker'],
#  ['state', 'city', 'mandate', 'museum', 'arena'],
#  ['represent', 'government', 'life', 'government', 'control', 'life'],
#  ['life', 'country', 'mandate', 'school', 'student', 'loan'],
#  ['company', 'work', 'policy', 'leader', 'mask', 'policy', 'employee', 'site'],
#  [],
#  ['brain', 'abscess', 'brain', 'cancer', 'category'],
#  ['definition',
#   'immunity',
#   'disease',
#   'contract',
#   'disease',
#   'contract',
#   'disease',
#   'increase',
#   'risk',
#   'myocarditis'],
#  ['ignorance', 'circus', 'status'],
#  ['joke', 'orgy', 'street', 'orgy', 'mass', 'event', 'aneurysm'],
#  ['world', 'government', 'capacity', 'thinking', 'analysis', 'prevent'],
#  ['play', 'emergence', 'omicron', 'guest', 'status', 'detail'],
#  ['think',
#   'amount',
#   'tyrant',
#   'power',
#   'herd_immunity',
#   'target',
#   'virus',
#   'endemic',
#   'move',
#   'life'],
#  ['elixir', 'government'],
#  ['science', 'reality', 'harm', 'science', 'anthology', 'bullshit', 'child'],
#  ['attempt',
#   'tea',
#   'shift',
#   'blame',
#   'child',
#   'child',
#   'age',
#   'help',
#   'formulation',
#   'dosage',
#   'child',
#   'weight'],
#  ['require', 'mask', 'passport', 'test'],
#  ['host', 'rabie', 'clinic', 'pet'],
#  ['record', 'clinic', 'retrieve'],
#  [],
#  ['version',
#   'idea',
#   'section',
#   'page',
#   'health',
#   'project',
#   'proportion',
#   'group',
#   'proportionality',
#   'assumption'],
#  ['rate', 'town', 'mask', 'child', 'science'],
#  ['flag', 'rate', 'vast_majority'],
#  ['government', 'child', 'child', 'body', 'system'],
#  ['assumption', 'reason'],
#  ['test', 'bar', 'restaurant', 'twin_citie', 'vote', 'commonsense'],
#  ['county', 'rate', 'surge', 'case', 'delta'],
#  ['mom', 'report', 'journalist', 'touch', 'lack', 'transparency', 'hesitancy'],
#  ['respect',
#   'fear',
#   'watch',
#   'plan',
#   'weather',
#   'infection',
#   'increase',
#   'future',
#   'bright'],
#  ['nation', 'effort', 'fight', 'virus'],
#  ['act',
#   'collection',
#   'law',
#   'boost',
#   'health',
#   'authority',
#   'update',
#   'condition'],
#  ['approach',
#   'patio',
#   'occasion',
#   'wave',
#   'decision',
#   'restaurant',
#   'doubt',
#   'action',
#   'data',
#   'evidence',
#   'caution'],
#  ['virus', 'life', 'age', 'matter'],
#  ['reduce', 'variant', 'mutation'],
#  ['rate', 'bar'],
#  ['reporter', 'stuff', 'fact', 'soul', 'order'],
#  ['rate'],
#  ['proof', 'policy', 'history', 'jury'],
#  ['note'],
#  ['rate', 'requirement', 'show', 'proof', 'pick', 'place', 'fin'],
#  ['community',
#   'rate',
#   'child',
#   'measure',
#   'vulnerability',
#   'infection',
#   'antibody'],
#  ['country',
#   'health',
#   'care',
#   'system',
#   'system',
#   'rate',
#   'blame',
#   'medicine'],
#  ['risk', 'level', 'kid', 'spread', 'protection', 'stall', 'teachers_union'],
#  ['collapse', 'hospital', 'system', 'death', 'area', 'watch', 'argument'],
#  ['country', 'adult', 'rate', 'restriction', 'enemy', 'punishing'],
#  ['idea', 'lock', 'screen', 'wallpaper', 'card'],
#  ['period',
#   'immunity',
#   'benefit',
#   'immunity',
#   'variant',
#   'defeating',
#   'immunity'],
#  ['customer', 'business', 'employee', 'customer', 'fear', 'legal_action'],
#  ['rate', 'question', 'deeperissue'],
#  [],
#  ['proof', 'requirement', 'twin_citie'],
#  ['trade', 'mandate', 'term'],
#  ['criterion', 'inclusion', 'disease'],
#  ['freedom', 'science', 'disease', 'disability', 'schedule'],
#  ['debate', 'restriction', 'leader', 'country', 'rate', 'restriction'],
#  ['bribery'],
#  ['status', 'indicator', 'party', 'teen', 'fool', 'reason', 'hope'],
#  ['control',
#   'obesity',
#   'cohort',
#   'yrs',
#   'decade',
#   'mask',
#   'anger',
#   'freedom',
#   'cost',
#   'death'],
#  ['mask', 'street', 'regard', 'show', 'status'],
#  ['death', 'threat', 'kid', 'video', 'school', 'clinic'],
#  ['card'],
#  ['spread', 'scientist'],
#  ['alteration', 'population', 'post', 'case'],
#  ['look',
#   'obsolescence',
#   'item',
#   'life',
#   'force',
#   'industry',
#   'pharma',
#   'industry',
#   'money',
#   'government',
#   'society'],
#  ['thread', 'weapon', 'pandemic', 'sense', 'risk'],
#  ['profuse',
#   'state',
#   'checkout',
#   'replicating',
#   'virus',
#   'spike',
#   'cell',
#   'body'],
#  ['status', 'litmus', 'test', 'test'],
#  ['government',
#   'field',
#   'segregation',
#   'punishment',
#   'government',
#   'work',
#   'country',
#   'pawn'],
#  ['load', 'crap', 'mask', 'sense', 'transmission', 'fact'],
#  ['party',
#   'overreach',
#   'problem',
#   'bully',
#   'mode',
#   'morning',
#   'municipality',
#   'school',
#   'university',
#   'increase',
#   'rate',
#   'hospital',
#   'hypocrisy'],
#  ['pillar',
#   'policy',
#   'stay',
#   'place',
#   'argument',
#   'testing',
#   'requirement',
#   'community'],
#  ['burger', 'fry', 'card'],
#  ['reason', 'employment', 'lawyer', 'termination', 'belief', 'status'],
#  ['mandate', 'arena', 'law', 'path', 'work', 'requirement', 'eye'],
#  ['picture', 'death', 'campaign'],
#  ['status', 'idea', 'status', 'idea', 'mutating'],
#  [],
#  ['premium', 'load', 'group', 'life', 'insurance', 'employer', 'area'],
#  ['course', 'live', 'immunity', 'repeat'],
#  ['country',
#   'rubella',
#   'half',
#   'rubella',
#   'transmission',
#   'rubella',
#   'elimination',
#   'protect',
#   'baby',
#   'country',
#   'coverage'],
#  ['legislator',
#   'amendment',
#   'prohibit',
#   'discrimination',
#   'status',
#   'orientation',
#   'gender',
#   'identity'],
#  ['shot'],
#  ['rate',
#   'map',
#   'show',
#   'work',
#   'delivery',
#   'vaccinate',
#   'kid',
#   'adult',
#   'urgencyofequity'],
#  ['hospital', 'nurse', 'knife', 'drawer'],
#  ['end', 'mandate'],
#  ['path', 'want'],
#  ['omicron',
#   'evade',
#   'quality',
#   'mask',
#   'leader',
#   'responsibility',
#   'health',
#   'example'],
#  ['booster', 'rate', 'kid', 'work', 'meantime', 'damage'],
#  ['mask', 'transmission', 'community', 'area', 'event'],
#  ['opinion',
#   'store',
#   'sporting_event',
#   'concert',
#   'capacity',
#   'proof',
#   'mask',
#   'peer',
#   'pressure',
#   'jay'],
#  ['rate', 'state'],
#  ['trick', 'plan', 'shut', 'virus'],
#  ['effect', 'omicron', 'spread', 'size', 'spread', 'omicron'],
#  ['math', 'commission', 'vote', 'level', 'vote', 'illegal', 'rinosalazar'],
#  ['chance',
#   'hospital',
#   'chance',
#   'infection',
#   'place',
#   'variant',
#   'infection',
#   'omicron',
#   'line',
#   'defense'],
#  ['epidemiologist',
#   'health',
#   'expert',
#   'twitter',
#   'user',
#   'expertise',
#   'field'],
#  ['option', 'immune', 'recover', 'stop', 'concept'],
#  ['increase', 'death', 'picture', 'death'],
#  ['age', 'sex', 'comparison', 'risk', 'risk', 'source'],
#  ['child', 'adult', 'booster', 'booster', 'punishment'],
#  ['comparison',
#   'sex',
#   'pre_existing',
#   'condition',
#   'significance',
#   'comorbiditie'],
#  ['mandate',
#   'think',
#   'snowflake',
#   'extortion',
#   'terrorism',
#   'problem',
#   'gas',
#   'pollute',
#   'silly',
#   'value',
#   'markup'],
#  ['requirement', 'mandate', 'infection', 'rate', 'decision', 'amount'],
#  ['rate', 'rate', 'death', 'rate'],
#  ['rate',
#   'infection',
#   'rate',
#   'effect',
#   'limo',
#   'guessing',
#   'death',
#   'cardio',
#   'event'],
#  ['laboratory',
#   'virus',
#   'toilet',
#   'forget',
#   'laboratory',
#   'generation',
#   'virus'],
#  ['rate', 'infection', 'child'],
#  ['mandate', 'question', 'mandate'],
#  ['clinic', 'walk', 'shot', 'well', 'booster', 'community', 'event'],
#  ['wave', 'horizon', 'pier', 'foot', 'half', 'firetheucp'],
#  ['infection',
#   'boost',
#   'immunity',
#   'health',
#   'problem',
#   'damage',
#   'immune_system'],
#  ['virus',
#   'opportunity',
#   'mask',
#   'transmission',
#   'probability',
#   'infection',
#   'mutation',
#   'method',
#   'population',
#   'page'],
#  ['truth'],
#  ['rate', 'position', 'state', 'policy'],
#  ['proof', 'crack_pipe'],
#  [],
#  ['card'],
#  ['level',
#   'place',
#   'booster',
#   'rate',
#   'wave',
#   'infection',
#   'place',
#   'criterion',
#   'wane',
#   'cycle'],
#  ['hurting', 'team', 'championship', 'player'],
#  ['rate'],
#  ['service', 'code', 'code'],
#  ['trust', 'individual', 'heart', 'condition', 'exemption', 'avoid'],
#  ['body'],
#  ['state', 'line', 'criterion', 'state', 'death', 'rate', 'rate'],
#  ['worry', 'pseudo', 'damage', 'life', 'save'],
#  ['status', 'hospitalization', 'couple', 'thinking', 'work'],
#  ['measle', 'jeopardize', 'jeopardizing'],
#  ['mask',
#   'evidence',
#   'hospital',
#   'death',
#   'area',
#   'rate',
#   'mandate',
#   'republican',
#   'charge'],
#  ['capacity', 'tolerance'],
#  ['hospital', 'stage', 'med', 'treatment'],
#  ['plan', 'passport', 'situation', 'masking', 'news'],
#  ['harm_reduction'],
#  ['shitty'],
#  ['occupier', 'trucker', 'path', 'freedom', 'disease', 'protection', 'health'],
#  ['air',
#   'gas',
#   'inflation',
#   'business',
#   'massless',
#   'refuse',
#   'life',
#   'policy'],
#  ['president',
#   'case',
#   'biden',
#   'team',
#   'program',
#   'economy',
#   'sense',
#   'president',
#   'control',
#   'economy'],
#  ['data', 'decade', 'decade', 'campaign', 'place', 'data', 'measle'],
#  ['mandate', 'wave'],
#  ['map', 'push', 'end', 'mandate'],
#  ['mandate',
#   'kudo',
#   'contradiction',
#   'choice',
#   'language',
#   'quebec',
#   'libertarian'],
#  ['kill_bacterium'],
#  [],
#  ['case',
#   'removal',
#   'school',
#   'student',
#   'mask',
#   'school',
#   'student',
#   'mandate'],
#  ['holiday', 'campaign', 'paperwork', 'care', 'lack', 'work'],
#  ['language', 'definition', 'prevent', 'user'],
#  ['adult', 'mandate', 'rate', 'child', 'indicator', 'mandate'],
#  ['wording', 'directive', 'absence', 'pay'],
#  ['mandate', 'card', 'restaurant', 'matter'],
#  ['help', 'variant', 'variant', 'schedule', 'appointment'],
#  ['care', 'track', 'train'],
#  ['rate'],
#  ['mask', 'accessibility', 'risk', 'pandemic'],
#  ['attack', 'power', 'pass', 'shame', 'apartheid', 'damage'],
#  ['card', 'ease', 'country'],
#  ['case',
#   'share',
#   'visitation',
#   'visitor',
#   'inpatient',
#   'admission',
#   'exception',
#   'requirement',
#   'visitor',
#   'proof'],
#  ['restriction',
#   'politic',
#   'utilization',
#   'hospital',
#   'resource',
#   'neoliberalism'],
#  ['risk',
#   'flu',
#   'illness',
#   'flu',
#   'virus',
#   'flu',
#   'shot',
#   'couple',
#   'flu',
#   'protect',
#   'virus',
#   'flu'],
#  ['help', 'condition', 'risk'],
#  [],
#  ['example', 'status', 'list', 'none', 'business', 'list'],
#  ['mask', 'choice'],
#  ['chance',
#   'death',
#   'infection',
#   'death',
#   'infection',
#   'death',
#   'worker',
#   'chill',
#   'risk'],
#  ['drop', 'death', 'mass', 'increase', 'excess_death'],
#  ['anthrax'],
#  ['majority', 'death', 'immunity', 'boost', 'risk', 'profile'],
#  ['life', 'retirement', 'lockdown', 'mandate', 'canadian'],
#  ['mode',
#   'denial',
#   'coercion',
#   'discrimination',
#   'bread',
#   'butter',
#   'platform',
#   'place'],
#  ['fact',
#   'majority',
#   'death',
#   'outbreak',
#   'care',
#   'home',
#   'environment',
#   'virus',
#   'measure',
#   'sense'],
#  ['needle', 'freedom', 'freedom', 'refuse', 'health', 'policy', 'mask'],
#  ['worry', 'case', 'community', 'child', 'keeping', 'case'],
#  ['weight', 'status', 'manufacturer', 'individual'],
#  ['priest', 'protest'],
#  ['address', 'outreach', 'program', 'adult', 'million', 'child'],
#  ['affect', 'job', 'mandate', 'restriction'],
#  ['card', 'crime'],
#  ['founder',
#   'self',
#   'law',
#   'charter',
#   'removal',
#   'travel',
#   'law',
#   'suit',
#   'rest',
#   'border',
#   'line'],
#  ['proof'],
#  ['melanie',
#   'percentage',
#   'estimation',
#   'rate',
#   'ontario',
#   'rate',
#   'increase',
#   'move'],
#  ['question', 'plan', 'force', 'dropping', 'restriction', 'situation'],
#  ['rate', 'disease'],
#  ['night', 'fire', 'guitar', 'door', 'show', 'guest', 'proof', 'change'],
#  ['impact',
#   'workforce',
#   'rate',
#   'challenge',
#   'burnout',
#   'leave',
#   'rate',
#   'loss',
#   'science',
#   'impact'],
#  ['status'],
#  ['night', 'proof', 'film'],
#  ['virus', 'mutation'],
#  ['net', 'decade', 'medicine'],
#  [],
#  ['change', 'definition', 'system', 'legitimize', 'gene', 'activation', 'job'],
#  ['death',
#   'increase',
#   'issue',
#   'health',
#   'issue',
#   'government',
#   'care',
#   'health',
#   'mandate',
#   'virus'],
#  ['hospitalization', 'death', 'country', 'rate'],
#  ['passport', 'mask', 'restriction'],
#  ['politician', 'relation'],
#  [],
#  ['datum', 'protection', 'risk', 'death', 'infection', 'study'],
#  ['move', 'move', 'chemistry'],
#  ['comparison', 'car'],
#  ['status'],
#  ['hero', 'city', 'lawsuit', 'markmyword'],
#  ['history', 'virus', 'virus', 'coincidence'],
#  ['ad',
#   'stock',
#   'westbrook',
#   'contract',
#   'rest',
#   'team',
#   'bait',
#   'bag',
#   'change'],
#  ['face', 'downtown', 'summering', 'setting', 'status'],
#  ['rate',
#   'staff',
#   'adult',
#   'area',
#   'correlation',
#   'mask',
#   'mandate',
#   'rate',
#   'direction',
#   'mandate'],
#  ['tuberculosis', 'blanket', 'child', 'body', 'bag', 'movie'],
#  ['help',
#   'case',
#   'justifie',
#   'privilege',
#   'privilege',
#   'sense',
#   'responsibility',
#   'duty'],
#  ['misinformation',
#   'disinformation',
#   'riot',
#   'rioter',
#   'immigration',
#   'border',
#   'activity',
#   'law',
#   'order',
#   'terrorism',
#   'mail',
#   'ballot',
#   'ballot',
#   'validation'],
#  ['definition', 'definition', 'definition', 'definition', 'fact'],
#  ['mandate',
#   'democracy',
#   'politic',
#   'division',
#   'bean',
#   'pillar',
#   'democracy',
#   'law',
#   'representation',
#   'knowledge'],
#  ['bill', 'operation', 'cost'],
#  ['email'],
#  ['level', 'understanding'],
#  ['hocus', 'requirement', 'indoor', 'business'],
#  ['datum', 'spike', 'infection', 'correlation', 'scientist'],
#  ['sars_cov', 'infection', 'hospitalization', 'death', 'dose', 'dose'],
#  ['case', 'death', 'dozen', 'life'],
#  ['government', 'work', 'stir', 'pot', 'twitter', 'oscar', 'event', 'test'],
#  ['rate',
#   'nightmare',
#   'school',
#   'change',
#   'mandate',
#   'lack',
#   'care',
#   'decision'],
#  ['bulletin', 'pastor', 'letter', 'church', 'trad', 'publication', 'teaching'],
#  ['virus',
#   'population',
#   'variant',
#   'stop',
#   'limit',
#   'mutation',
#   'hospital',
#   'hospital'],
#  ['coronaviruse', 'virus', 'booster', 'shot'],
#  ['reason', 'ordeal'],
#  ['thank', 'recover', 'morning', 'cousin', 'battle', 'dishonesty'],
#  ['put', 'car', 'place', 'face', 'consequence', 'decision'],
#  ['mandate'],
#  ['parent', 'school', 'head', 'child', 'county', 'rate', 'positivity', 'mask'],
#  ['definition',
#   'definition',
#   'defense',
#   'level',
#   'vitamin',
#   'definition',
#   'defense',
#   'infection',
#   'equate'],
#  ['stranger', 'appointment', 'spring'],
#  ['laker', 'asset', 'upgrade', 'roster'],
#  ['thought', 'prayer', 'proof', 'friend'],
#  ['recognition',
#   'contagion',
#   'phase',
#   'pandemic',
#   'matter',
#   'opinion',
#   'respect',
#   'objectivity'],
#  ['rate', 'population', 'group', 'fraction', 'population'],
#  ['situation', 'mind', 'plan', 'recommend', 'government', 'measure'],
#  ['flyer', 'site', 'paper', 'door', 'site', 'site'],
#  [],
#  ['think', 'fact', 'risk', 'oop'],
#  ['house', 'oscar', 'entry', 'mask', 'discussion', 'deadline'],
#  ['cruise', 'state', 'testing', 'boarding', 'test', 'none', 'ability'],
#  ['kid',
#   'family',
#   'argument',
#   'kid',
#   'mild_symptom',
#   'cold',
#   'nonsense',
#   'dialog'],
#  ['status', 'impact', 'booster', 'kid', 'case', 'end', 'case', 'fever'],
#  ['trucker', 'mask', 'money'],
#  ['test', 'health', 'measure', 'heap', 'bump', 'case', 'reporting'],
#  ['clinic'],
#  ['mask', 'participation', 'child'],
#  ['headline', 'article', 'protection', 'fact', 'reality', 'statement'],
#  ['track', 'blocking', 'demand', 'government', 'mandate'],
#  ['infection', 'transmission', 'solution', 'stock'],
#  ['define', 'outbreak', 'survival', 'instinct'],
#  ['rate', 'increase'],
#  ['mandate', 'net', 'franchise'],
#  ['story',
#   'doctor',
#   'child',
#   'abuse',
#   'position',
#   'responsibility',
#   'gain',
#   'license'],
#  ['vac', 'rate', 'country', 'example', 'rate', 'case'],
#  ['primary_serie', 'sign', 'body', 'building', 'protection'],
#  [],
#  ['country', 'mandate', 'war', 'deal', 'work', 'peace'],
#  ['immunity',
#   'pal',
#   'immunity',
#   'wave',
#   'death',
#   'mask',
#   'etc',
#   'fall',
#   'wave'],
#  ['help',
#   'effort',
#   'share',
#   'science',
#   'phone',
#   'community',
#   'rate',
#   'thank',
#   'enthusiasm'],
#  ['mask'],
#  ['government',
#   'force',
#   'population',
#   'infection',
#   'transmission',
#   'party',
#   'leader',
#   'water'],
#  ['report', 'oscar', 'test', 'proof'],
#  ['protest', 'persuasion', 'attention', 'mandate'],
#  ['antivaxxer', 'import', 'article', 'antivaxxer', 'evidence'],
#  ['woman', 'life', 'claim', 'science', 'disgrace', 'prison'],
#  ['infection',
#   'pregnancy',
#   'date',
#   'flu',
#   'talk',
#   'provider',
#   'infection',
#   'pregnancy'],
#  ['thousand', 'card'],
#  ['virus', 'induce'],
#  ['base', 'proof', 'policy', 'province', 'timeframe', 'measure'],
#  ['claim', 'event', 'evidence', 'example', 'history', 'polio'],
#  ['mandate', 'play'],
#  ['question', 'canadian', 'science', 'end', 'canadian'],
#  ['sign', 'establishment', 'government', 'rule', 'passport', 'lockdown'],
#  ['option', 'information', 'resource', 'neighbor'],
#  ['street'],
#  ['clinic', 'couple', 'runner', 'ballroom', 'student', 'union'],
#  ['mask', 'ink', 'virus', 'reduction', 'transmission'],
#  ['night', 'comedy', 'door', 'show', 'guest', 'proof', 'change'],
#  ['business', 'bar', 'restaurant', 'mask', 'freedom'],
#  ['playoff', 'requirement'],
#  ['mildness',
#   'country',
#   'rate',
#   'percent',
#   'population',
#   'percent',
#   'shot',
#   'denmark'],
#  ['problem', 'child', 'kid', 'parent'],
#  ['guideline', 'rate', 'cali', 'rate', 'state'],
#  ['opposition',
#   'leader',
#   'question',
#   'debate',
#   'rate',
#   'mandate',
#   'lead',
#   'country'],
#  ['whistle',
#   'myocarditis',
#   'chest',
#   'athlete',
#   'field',
#   'citizen',
#   'exhaust',
#   'truck',
#   'minute'],
#  ['evidence', 'start', 'stat', 'mask', 'cable', 'gig'],
#  ['convince', 'kink', 'shaming', 'article', 'share', 'want'],
#  ['conversation', 'mandate', 'distraction', 'leadership', 'tool', 'work'],
#  ['lifetime', 'death', 'sentence', 'condition', 'testament', 'science'],
#  ['fly', 'airline', 'institute', 'mandate', 'health', 'health'],
#  ['card', 'mask', 'link'],
#  ['place', 'course', 'juju'],
#  ['minority', 'feeling', 'kid', 'fuck'],
#  ['rate', 'group', 'doctor'],
#  ['risk', 'status'],
#  ['conversation',
#   'voice',
#   'host',
#   'race',
#   'theorist',
#   'right',
#   'activist',
#   'doctor'],
#  ['solution', 'variant', 'body', 'premier', 'protection'],
#  ['gulag', 'hostess'],
#  ['decision'],
#  ['country', 'rate', 'end', 'mandate', 'country', 'canadian', 'restriction'],
#  ['requirement', 'name', 'ad', 'hominem', 'attack', 'argument', 'noodle'],
#  [],
#  ['policy',
#   'choice',
#   'wedge',
#   'conservative',
#   'issue',
#   'knee',
#   'jerk',
#   'choice',
#   'step',
#   'conservative'],
#  ['dot',
#   'incompetence',
#   'infection',
#   'epidemic',
#   'proportion',
#   'trump',
#   'recession',
#   'plan',
#   'recession',
#   'program'],
#  ['story'],
#  ['coverage',
#   'insanity',
#   'anti',
#   'threat',
#   'privilege',
#   'class',
#   'ticket',
#   'ticket',
#   'price'],
#  ['mask', 'world', 'access', 'variation', 'infection', 'death'],
#  ['sixer', 'ass'],
#  ['kid', 'virus', 'risk', 'factor', 'population', 'rate'],
#  ['status', 'net', 'team', 'shoot', 'throw', 'playoff', 'line'],
#  ['regimen', 'start'],
#  ['pandemic', 'band', 'thug', 'journalist'],
#  ['record'],
#  ['mask', 'help', 'wear_mask'],
#  ['doctors_nurse',
#   'scientist',
#   'researcher',
#   'family',
#   'relative',
#   'world',
#   'disease',
#   'death',
#   'smallpox',
#   'limit'],
#  ['difference', 'family', 'life', 'friendship', 'coronavirus'],
#  ['passport',
#   'useless',
#   'reinforcement',
#   'division',
#   'punishment',
#   'trend',
#   'center',
#   'doubt',
#   'scare'],
#  ['shot', 'dam'],
#  ['milk', 'pressure', 'mandate', 'poll'],
#  ['demand', 'status', 'segregation'],
#  ['school', 'staff', 'school', 'staff', 'education', 'approach'],
#  ['protest',
#   'mandate',
#   'actuality',
#   'liberal',
#   'election',
#   'minority',
#   'vote',
#   'district'],
#  ['social_distance', 'virus'],
#  ['study', 'expert', 'locale', 'report', 'difference', 'mask', 'school'],
#  ['creep', 'process', 'cut', 'virus', 'host', 'supply', 'end'],
#  ['comment', 'case', 'risking', 'disease', 'death', 'purpose'],
#  [],
#  ['sex', 'race', 'religion', 'status'],
#  ['approach', 'school', 'school', 'basis', 'rate', 'school', 'mandate'],
#  ['question', 'reason', 'rate'],
#  ['policy', 'place', 'state', 'requirement'],
#  ['rushing', 'measure', 'rate', 'population', 'science', 'result', 'variant'],
#  ['factor', 'mean', 'immunity', 'infection', 'hospital'],
#  [],
#  ['cripe', 'weeks_ago', 'decrease', 'spike', 'rate'],
#  ['customer', 'side', 'morning', 'show', 'proof'],
#  ['vast_majority'],
#  ['issue', 'rate', 'government', 'mask', 'government'],
#  ['state', 'status', 'hospital', 'statistic'],
#  ['attack', 'integrity', 'state', 'business', 'treatment'],
#  ['answer', 'question', 'restriction'],
#  ['warning', 'weekend', 'card', 'card'],
#  ['statement', 'force'],
#  ['definition', 'method'],
#  ['freedom', 'travel', 'force', 'card'],
#  ['decline', 'case', 'spot', 'retire', 'policy', 'threat', 'precaution'],
#  ['center'],
#  ['adult', 'booster', 'protection', 'infection', 'adult', 'stay', 'date'],
#  ['development',
#   'approach',
#   'vilify',
#   'therapeutic',
#   'treatment',
#   'lack',
#   'transmission',
#   'control'],
#  ['jab', 'force', 'imagine', 'trump', 'mandating'],
#  ['inventor', 'medium', 'omitting', 'fact', 'force'],
#  ['research', 'impact', 'risk'],
#  ['impression', 'feel', 'precaution'],
#  ['game', 'daughter', 'weekend'],
#  ['show', 'joke', 'coverage', 'protest', 'joke', 'nonsense', 'shove'],
#  ['talking', 'commercial'],
#  ['generation', 'million', 'survivor', 'life', 'brain', 'reason'],
#  ['administration',
#   'transmission',
#   'follower',
#   'mask',
#   'end',
#   'result',
#   'variant',
#   'death'],
#  ['bull', 'inhibitor', 'reason'],
#  ['support', 'nice_try'],
#  ['efficacy', 'infection', 'infection', 'protection'],
#  ['nation', 'travel_ban', 'entry', 'death', 'blow', 'psychosis', 'break'],
#  ['key', 'anti_baxter', 'hostage', 'country', 'policy', 'language', 'sense'],
#  ['co',
#   'paper',
#   'factor',
#   'variable',
#   'intent',
#   'uptake',
#   'change',
#   'campaign'],
#  ['fi', 'driver'],
#  ['request',
#   'proof',
#   'check',
#   'makes_sense',
#   'business',
#   'fyi',
#   'discrimination'],
#  ['author',
#   'decision',
#   'favor',
#   'disease',
#   'article',
#   'mechanism',
#   'proof',
#   'issue'],
#  ['confer',
#   'rod',
#   'infection',
#   'antigen',
#   'exposure',
#   'response',
#   'variant',
#   'terminal_center'],
#  ['thank',
#   'fight',
#   'demand',
#   'answer',
#   'datum',
#   'administration',
#   'mandate',
#   'truth'],
#  ['protest', 'case', 'family', 'case', 'nonsense'],
#  [],
#  ['doctor', 'want'],
#  ['season', 'status', 'player', 'rule'],
#  ['disease', 'effect', 'refuse'],
#  ['city', 'mandate', 'child', 'school', 'let'],
#  ['freakin', 'parrot', 'tool'],
#  ['infection', 'transmission'],
#  ['produce', 'infection'],
#  ['summer'],
#  ['forum', 'question', 'virus'],
#  ['life',
#   'insurance',
#   'industry',
#   'target',
#   'premium',
#   'load',
#   'employer',
#   'county',
#   'rate',
#   'risk',
#   'factor'],
#  ['morbidity',
#   'read',
#   'link',
#   'type',
#   'diabetes',
#   'evidence',
#   'risk',
#   'benefit'],
#  ['show', 'card'],
#  ['line', 'defense', 'infection', 'onevaxtwolive'],
#  ['rate',
#   'city',
#   'worker',
#   'audience',
#   'collar',
#   'cop',
#   'teacher',
#   'sanitation'],
#  [],
#  ['outbreak', 'bullshit', 'mandate', 'proof'],
#  ['cheerleader', 'mandate', 'terrorist'],
#  ['conclusion',
#   'form',
#   'tool',
#   'coercion',
#   'force',
#   'kind',
#   'disguise',
#   'politician',
#   'impose'],
#  ['future',
#   'bet',
#   'season',
#   'bet',
#   'money',
#   'team',
#   'rate',
#   'roster',
#   'superbowl',
#   'advantage'],
#  ['face', 'infection', 'mask', 'rate'],
#  ['netsareunfair'],
#  ['death', 'rate', 'child'],
#  ['wonder', 'show', 'proof'],
#  ['nurse', 'staff', 'site', 'slot', 'site'],
#  ['definition', 'prevent', 'history', 'herd_immunity'],
#  ['kid',
#   'booster',
#   'clinic',
#   'child',
#   'child',
#   'booster',
#   'school',
#   'nurse',
#   'info'],
#  ['country', 'requirement', 'mandate'],
#  ['evidence', 'risk'],
#  ['rate', 'level'],
#  ['math'],
#  ['practice'],
#  ['chance', 'mandate', 'reason', 'nice_try'],
#  ['etc',
#   'meaning',
#   'wastewater',
#   'treatment',
#   'respect',
#   'infection',
#   'trend'],
#  ['effect', 'reporting', 'case', 'status'],
#  ['condition', 'regret'],
#  ['ifr', 'death', 'rate'],
#  ['reason', 'reason', 'moderation', 'norm', 'debate', 'consideration'],
#  ['distinction', 'deadset', 'mandate', 'show', 'status', 'series', 'booster'],
#  ['job', 'puff'],
#  ['death',
#   'threat',
#   'desire',
#   'temperature',
#   'convoy',
#   'protestor',
#   'right_wing',
#   'extremist',
#   'hostage',
#   'stop'],
#  ['redefine', 'terminology', 'suit', 'description', 'deviation', 'individual'],
#  ['guidance',
#   'prevent',
#   'transmission',
#   'infection',
#   'update',
#   'data',
#   'problem'],
#  ['rate', 'world', 'spread', 'justification', 'mandate'],
#  ['hospitalization', 'icu', 'age', 'course'],
#  ['infection', 'hospitalization', 'death', 'status'],
#  ['ass', 'term', 'tho', 'vacation', 'stop', 'misleading'],
#  ['test', 'efficacy', 'cost', 'payment', 'rate'],
#  ['violation', 'government', 'stoll', 'state', 'emergency'],
#  ['science', 'science', 'unmask', 'kid', 'science', 'tuberculosis'],
#  ['business', 'individual', 'status', 'remedy'],
#  ['rate', 'trust', 'science'],
#  ['mandate', 'clutch', 'sport', 'article', 'write', 'tiny_bit', 'end', 'bout'],
#  ['fear', 'prevent', 'nonsense', 'validate'],
#  ['citizen', 'home', 'citizen', 'serbian', 'cross_border'],
#  ['case', 'grade', 'mask'],
#  ['millennial', 'home'],
#  ['requirement',
#   'occupation',
#   'condition',
#   'restriction',
#   'fact',
#   'condition',
#   'door',
#   'regulation'],
#  ['shot',
#   'reek',
#   'kickback',
#   'pharmaceutical',
#   'liability',
#   'shot',
#   'booster',
#   'poison',
#   'shove'],
#  ['hospital', 'death'],
#  ['infection',
#   'reason',
#   'immunity',
#   'evade',
#   'impact',
#   'transmission',
#   'selection',
#   'pressure'],
#  ['contrast',
#   'state',
#   'leverage',
#   'exhaustion',
#   'childhood',
#   'regime',
#   'education'],
#  ['center'],
#  ['employee',
#   'family',
#   'trucking',
#   'logistic',
#   'company',
#   'question',
#   'wisdom',
#   'mandate',
#   'place',
#   'blockade'],
#  ['thank'],
#  ['concert'],
#  ['woman', 'age', 'status', 'question'],
#  ['fight', 'virus'],
#  ['rate', 'country', 'dude'],
#  ['state', 'mandate', 'segment', 'population', 'kid', 'sake'],
#  ['customer', 'lawyer', 'business'],
#  ['boy', 'visit', 'stud'],
#  ['olympic', 'spectator', 'bubble', 'super_bowl', 'test'],
#  ['thought', 'issue'],
#  ['catch', 'spread', 'damage', 'work'],
#  ['freedom', 'choice', 'discriminate', 'harm', 'livelihood', 'shame'],
#  ['nice_try', 'protection'],
#  ['death', 'death', 'mask', 'ca', 'risk', 'rule', 'variable', 'stemeducation'],
#  ['poison', 'head', 'story', 'folk'],
#  ['freedom',
#   'employer',
#   'health',
#   'insurance',
#   'self',
#   'company',
#   'hospitalization',
#   'bottom_line',
#   'insanity'],
#  ['morning', 'police_officer', 'safety', 'answer', 'hope'],
#  ['article', 'measure', 'level'],
#  ['simmon', 'depth', 'carry'],
#  ['announce', 'tonight', 'culture'],
#  ['outcome', 'rate', 'mask', 'obedience'],
#  ['discrimination', 'definition', 'sexuality', 'gender', 'etc', 'fact'],
#  ['disagree',
#   'threat',
#   'civilization',
#   'state',
#   'country',
#   'erosion',
#   'sense',
#   'community',
#   'risk',
#   'benefit'],
#  ['smallpox', 'scar', 'shoulder', 'age', 'answer', 'dogging'],
#  ['work', 'hesitancy', 'message'],
#  ['launch', 'record', 'web', 'district', 'resident', 'access', 'record'],
#  ['smallpox', 'physician'],
#  ['card', 'team', 'league'],
#  [],
#  ['state', 'rate', 'level', 'death', 'conversation', 'world'],
#  ['student', 'health', 'measure', 'place', 'end', 'semester', 'abuse'],
#  ['report', 'mask', 'mandate', 'state', 'viewer', 'state', 'mask'],
#  ['mayor', 'crack', 'scare'],
#  ['movie',
#   'pandemic',
#   'class',
#   'citizen',
#   'proof',
#   'discrimination',
#   'health',
#   'measure',
#   'plot'],
#  ['promise', 'promise', 'restriction'],
#  ['mandate'],
#  ['outcome', 'country', 'considering', 'rate'],
#  ['province', 'country', 'state', 'place', 'rate'],
#  ['season', 'stance', 'title'],
#  ['clinic', 'volunteer', 'food', 'bag', 'spaghetti', 'appointment'],
#  ['mandate'],
#  ['mask',
#   'mandate',
#   'chaos',
#   'campus',
#   'class',
#   'community',
#   'transmission',
#   'rate'],
#  ['health',
#   'rescind',
#   'order',
#   'city',
#   'mask',
#   'entry',
#   'type',
#   'city',
#   'rescission',
#   'policy',
#   'effect'],
#  ['age',
#   'datum',
#   'immunity',
#   'kid',
#   'infection',
#   'sign',
#   'effect',
#   'virus',
#   'stay'],
#  ['exposure',
#   'reason',
#   'discussion',
#   'immunity',
#   'consideration',
#   'discussion'],
#  ['requirement', 'morning', 'kid'],
#  ['mandate', 'proof', 'restriction', 'reason', 'protest', 'normalcy'],
#  ['chickenpox'],
#  ['infection', 'rate'],
#  ['virus',
#   'fact',
#   'prevent',
#   'virus',
#   'death',
#   'role',
#   'face',
#   'crisis',
#   'faci',
#   'friend',
#   'government',
#   'funding',
#   'face',
#   'mask',
#   'work',
#   'cell'],
#  ['precaution'],
#  ['card'],
#  ['fact', 'matter', 'status', 'infect', 'mutate', 'health', 'livelihood'],
#  ['benefit', 'abandonment', 'measure', 'program', 'none', 'play', 'leave'],
#  ['clinic'],
#  ['country',
#   'child',
#   'grave',
#   'mass',
#   'death',
#   'bone',
#   'health',
#   'precaution',
#   'thinking'],
#  ['option', 'community', 'search', 'visit', 'individual'],
#  ['mandate', 'motivate', 'temp', 'mandate', 'goal'],
#  ['difference', 'viral_load', 'policy', 'rate'],
#  ['mask'],
#  [],
#  ['work', 'dedication', 'milestone'],
#  ['moment', 'action', 'saveourkid', 'intervention', 'parent', 'kid'],
#  ['hip', 'privacy', 'status'],
#  ['net'],
#  ['job', 'choice'],
#  ['guideline', 'kid', 'shooter', 'mill', 'simmon', 'shoot'],
#  ['world', 'food', 'clothing', 'life', 'hospital', 'dentist'],
#  ['reminder',
#   'place',
#   'order',
#   'portion',
#   'spending',
#   'organization',
#   'parenthood'],
#  [],
#  ['schedule', 'covidsummit', 'world'],
#  ['place', 'proof', 'folk', 'information'],
#  ['pal', 'efficacy', 'virus', 'effort', 'space', 'space'],
#  ['population', 'sequela', 'path', 'mitigation'],
#  ['claim', 'population', 'case', 'rate'],
#  ['population', 'population', 'population', 'immunity', 'imperfect'],
#  ['nation', 'effort', 'fight', 'virus'],
#  ['world',
#   'evidence',
#   'slowing',
#   'surge',
#   'infection',
#   'surge',
#   'rate',
#   'protection',
#   'restriction',
#   'rate',
#   'science'],
#  ['attendance'],
#  ['mandate', 'requirement', 'ditch'],
#  ['child'],
#  ['net', 'draft', 'pick', 'trading', 'harden', 'rule'],
#  ['event',
#   'attendee',
#   'proof',
#   'wear',
#   'mask',
#   'state',
#   'protocol',
#   'information',
#   'purchase',
#   'ticket',
#   'visit',
#   'bettzedek'],
#  ['thought', 'mandate', 'mandate', 'mandate', 'folk', 'difference', 'rate'],
#  ['status', 'restaurant', 'prove', 'crack', 'addict', 'crackpipe'],
#  ['infection',
#   'rate',
#   'child',
#   'infection',
#   'rate',
#   'delta',
#   'child',
#   'business',
#   'corporation'],
#  ['health',
#   'care',
#   'system',
#   'rule',
#   'care',
#   'build',
#   'infrastructure',
#   'support',
#   'anthrax',
#   'community',
#   'healthinsurance',
#   'screenplay'],
#  [],
#  ['mandate', 'land', 'crossing', 'job'],
#  ['progressive',
#   'government',
#   'coercion',
#   'product',
#   'credibility',
#   'guess',
#   'progressive'],
#  ['place', 'rule', 'athlete', 'city', 'proof', 'mask', 'spring'],
#  ['education',
#   'practice',
#   'community',
#   'community',
#   'role',
#   'model',
#   'scourge'],
#  ['border', 'migrant'],
#  ['ink',
#   'folk',
#   'half',
#   'kid',
#   'injury',
#   'half',
#   'simmon',
#   'problem',
#   'trade'],
#  ['ground',
#   'report',
#   'question',
#   'connection',
#   'requirement',
#   'sample',
#   'trucker',
#   'focus',
#   'trucker',
#   'protestor'],
#  ['work',
#   'conclusion',
#   'choice',
#   'individual',
#   'impact',
#   'pandemic',
#   'trajectory'],
#  ['mandate'],
#  ['follow_suit', 'ground', 'case'],
#  ['arrival', 'datum'],
#  ['requirement', 'register', 'event', 'venue'],
#  ['thread',
#   'country',
#   'restriction',
#   'rate',
#   'denmark',
#   'hospital',
#   'situation'],
#  ['mask', 'control'],
#  ['mutate',
#   'rate',
#   'ship',
#   'complication',
#   'risk',
#   'datum',
#   'support',
#   'protection',
#   'emphasis'],
#  ['omicron', 'dose', 'datum', 'news', 'fall'],
#  ['infection', 'reuter', 'reason', 'choice', 'alternative', 'medicine'],
#  ['simmon', 'kid', 'contender'],
#  ['none',
#   'beginning',
#   'cooperate',
#   'virus',
#   'virus',
#   'existence',
#   'mandate',
#   'court',
#   'disinformation'],
#  ['couple',
#   'reduce_chance',
#   'conception',
#   'infection',
#   'sars_cov',
#   'reduction',
#   'fertility',
#   'male',
#   'safety',
#   'couple',
#   'conceive'],
#  ['snack', 'staff', 'switch'],
#  [],
#  ['transparent'],
#  ['cab', 'pok'],
#  ['rule', 'change', 'playoff'],
#  ['crack_pipe', 'friend'],
#  ['net', 'team', 'ruin', 'season', 'moment', 'streak'],
#  ['shot', 'primary_serie', 'sign', 'body', 'building', 'protection', 'mo'],
#  ['team', 'status', 'playoff', 'series', 'play', 'score', 'net', 'eye'],
#  ['agreement', 'truck', 'trucker'],
#  ['providence', 'employee', 'policy', 'suspension'],
#  ['establishment', 'superintendent', 'call', 'spine', 'truth'],
#  ['protest', 'air', 'train', 'travel', 'restriction'],
#  ['job',
#   'chain',
#   'employee',
#   'mold',
#   'tomato',
#   'customer',
#   'staff',
#   'food',
#   'floor',
#   'employee',
#   'card'],
#  ['rate', 'case', 'hospitalization', 'death', 'work'],
#  ['study'],
#  ['rate', 'correlation', 'map'],
#  ['term', 'restriction', 'campaign', 'death', 'senior', 'bonker', 'bonker'],
#  ['opinion', 'provider', 'topic', 'mandate', 'survey'],
#  ['simmon', 'fact', 'trade', 'asset', 'mandate', 'chance', 'requirement'],
#  ['employment',
#   'job',
#   'field',
#   'citizen',
#   'employment',
#   'freedom',
#   'endthemandate'],
#  ['assumption', 'distinction', 'risk', 'benefit', 'analyze'],
#  ['difference',
#   'prevention',
#   'harm',
#   'moment',
#   'rate',
#   'mask',
#   'mandate',
#   'course',
#   'outlaw',
#   'driving',
#   'safety',
#   'measure'],
#  ['benefit', 'minimizing', 'risk', 'state', 'threat', 'civilization', 'virus'],
#  ['joke', 'protest', 'dentist'],
#  [],
#  ...]

# %%
dictionary = gensim.corpora.Dictionary(tokenised_lemmatized)
# create BOW dictionary
bow_corpus = [dictionary.doc2bow(doc) for doc in tokenised_lemmatized]

# %%
#Load the save classifier 
import pickle
model_saved = open("usa_gsdmm.model", "rb") #binary read
mgp = pickle.load(model_saved)
model_saved.close()

# %%
import numpy as np

# %%
vocab_length = len(dictionary)

# %%
# print number of documents per topic
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic :', doc_count)

# Topics sorted by the number of document they are allocated to
top_index = doc_count.argsort()[-15:][::-1]
print('Most important clusters (by number of docs inside):', top_index)

# define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

# get top words in topics
top_words(mgp.cluster_word_distribution, top_index, 20)
# Out:
# Number of documents per topic : [48162 50438 47515 38549 29113 24322 20224 24138 37661]
# Most important clusters (by number of docs inside): [1 0 2 3 8 4 5 7 6]
#
# Cluster 1 : [('death', 6847), ('virus', 5986), ('rate', 4337), ('case', 4252), ('infection', 3979), ('risk', 3492), ('shot', 3309), ('booster', 3166), ('datum', 2744), ('hospitalization', 2478), ('variant', 2408), ('population', 2220), ('study', 1931), ('immunity', 1768), ('flu', 1665), ('fact', 1571), ('protection', 1553), ('dose', 1540), ('country', 1489), ('disease', 1410)]
#
# Cluster 0 : [('mask', 12405), ('hospital', 5034), ('mandate', 3646), ('health', 3408), ('care', 3244), ('patient', 2472), ('wear', 2426), ('work', 2378), ('virus', 2229), ('life', 1971), ('choice', 1775), ('risk', 1722), ('case', 1477), ('place', 1343), ('science', 1244), ('rate', 1228), ('folk', 1226), ('death', 1215), ('reason', 1200), ('shot', 1190)]
#
# Cluster 2 : [('mandate', 4755), ('trucker', 3437), ('country', 2309), ('freedom', 2234), ('government', 2214), ('choice', 2166), ('mask', 2066), ('anthrax', 1852), ('job', 1639), ('protest', 1597), ('life', 1258), ('work', 1108), ('canadian', 1084), ('science', 967), ('health', 964), ('death', 949), ('support', 944), ('right', 916), ('state', 879), ('business', 877)]
#
# Cluster 3 : [('government', 2039), ('trust', 1871), ('money', 1779), ('company', 1619), ('science', 1240), ('datum', 1230), ('country', 1165), ('world', 1153), ('trump', 1140), ('dose', 918), ('drug', 888), ('shot', 884), ('stock', 876), ('fact', 867), ('work', 835), ('approval', 832), ('trial', 824), ('health', 794), ('scientist', 720), ('anthrax', 713)]
#
# Cluster 8 : [('shot', 10462), ('booster', 6624), ('arm', 5370), ('dose', 4644), ('side_effect', 2950), ('flu', 2719), ('symptom', 1845), ('fever', 1662), ('reaction', 1543), ('pain', 1315), ('morning', 1258), ('night', 1073), ('tomorrow', 1012), ('headache', 912), ('effect', 879), ('chill', 865), ('fatigue', 861), ('friend', 858), ('work', 841), ('wife', 823)]
#
# Cluster 4 : [('kid', 6312), ('child', 5906), ('mask', 4248), ('school', 4071), ('parent', 2643), ('family', 2320), ('friend', 1781), ('teacher', 1300), ('student', 1278), ('risk', 1191), ('adult', 1096), ('mandate', 977), ('life', 908), ('work', 877), ('shot', 772), ('son', 704), ('mom', 699), ('age', 693), ('daughter', 679), ('home', 661)]
#
# Cluster 5 : [('trust', 1613), ('doctor', 1511), ('science', 1409), ('anthrax', 1081), ('body', 880), ('patient', 782), ('friend', 778), ('cancer', 750), ('life', 746), ('hospital', 730), ('virus', 694), ('heart', 688), ('woman', 593), ('death', 589), ('shot', 533), ('baxter', 532), ('blood', 525), ('medicine', 497), ('reason', 488), ('issue', 472)]
#
# Cluster 7 : [('dose', 5252), ('shot', 2781), ('booster', 2473), ('thank', 1548), ('appointment', 1380), ('syringe', 911), ('clinic', 821), ('site', 767), ('morning', 587), ('health', 584), ('tomorrow', 583), ('pharmacy', 518), ('line', 507), ('card', 467), ('work', 465), ('friend', 446), ('book', 426), ('state', 415), ('family', 399), ('astrazeneca', 395)]
#
# Cluster 6 : [('player', 1809), ('game', 1318), ('team', 1259), ('mask', 812), ('play', 615), ('test', 519), ('fan', 510), ('card', 485), ('show', 429), ('season', 401), ('home', 401), ('event', 375), ('shot', 370), ('proof', 354), ('friend', 350), ('restaurant', 342), ('rule', 322), ('work', 307), ('place', 304), ('booster', 282)]

# %%
# import library from gensim  
from gensim.models import CoherenceModel

# define function to get words in topics
def get_topics_lists(model, top_clusters, n_words):
    '''
    Gets lists of words in topics as a list of lists.
    
    model: gsdmm instance
    top_clusters:  numpy array containing indices of top_clusters
    n_words: top n number of words to include
    
    '''
    # create empty list to contain topics
    topics = []
    
    # iterate over top n clusters
    for cluster in top_clusters:
        #create sorted dictionary of word distributions
        sorted_dict = sorted(model.cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:n_words]
         
        #create empty list to contain words
        topic = []
        
        #iterate over top n words in topic
        for k,v in sorted_dict:
            #append words to topic list
            topic.append(k)
            
        #append topics to topics list    
        topics.append(topic)
    
    return topics

# get topics to feed to coherence model
topics = get_topics_lists(mgp, top_index, 20) 

# evaluate model using Topic Coherence score
cm_gsdmm = CoherenceModel(topics=topics, 
                          dictionary=dictionary, 
                          corpus=bow_corpus, 
                          texts=tokenised_lemmatized, 
                          coherence='c_v')

# get coherence value
coherence_gsdmm = cm_gsdmm.get_coherence()  

print(coherence_gsdmm)
# Out:
# 0.31411489447878865

# %%
topics
# Out:
# [['death',
#   'virus',
#   'rate',
#   'case',
#   'infection',
#   'risk',
#   'shot',
#   'booster',
#   'datum',
#   'hospitalization',
#   'variant',
#   'population',
#   'study',
#   'immunity',
#   'flu',
#   'fact',
#   'protection',
#   'dose',
#   'country',
#   'disease'],
#  ['mask',
#   'hospital',
#   'mandate',
#   'health',
#   'care',
#   'patient',
#   'wear',
#   'work',
#   'virus',
#   'life',
#   'choice',
#   'risk',
#   'case',
#   'place',
#   'science',
#   'rate',
#   'folk',
#   'death',
#   'reason',
#   'shot'],
#  ['mandate',
#   'trucker',
#   'country',
#   'freedom',
#   'government',
#   'choice',
#   'mask',
#   'anthrax',
#   'job',
#   'protest',
#   'life',
#   'work',
#   'canadian',
#   'science',
#   'health',
#   'death',
#   'support',
#   'right',
#   'state',
#   'business'],
#  ['government',
#   'trust',
#   'money',
#   'company',
#   'science',
#   'datum',
#   'country',
#   'world',
#   'trump',
#   'dose',
#   'drug',
#   'shot',
#   'stock',
#   'fact',
#   'work',
#   'approval',
#   'trial',
#   'health',
#   'scientist',
#   'anthrax'],
#  ['shot',
#   'booster',
#   'arm',
#   'dose',
#   'side_effect',
#   'flu',
#   'symptom',
#   'fever',
#   'reaction',
#   'pain',
#   'morning',
#   'night',
#   'tomorrow',
#   'headache',
#   'effect',
#   'chill',
#   'fatigue',
#   'friend',
#   'work',
#   'wife'],
#  ['kid',
#   'child',
#   'mask',
#   'school',
#   'parent',
#   'family',
#   'friend',
#   'teacher',
#   'student',
#   'risk',
#   'adult',
#   'mandate',
#   'life',
#   'work',
#   'shot',
#   'son',
#   'mom',
#   'age',
#   'daughter',
#   'home'],
#  ['trust',
#   'doctor',
#   'science',
#   'anthrax',
#   'body',
#   'patient',
#   'friend',
#   'cancer',
#   'life',
#   'hospital',
#   'virus',
#   'heart',
#   'woman',
#   'death',
#   'shot',
#   'baxter',
#   'blood',
#   'medicine',
#   'reason',
#   'issue'],
#  ['dose',
#   'shot',
#   'booster',
#   'thank',
#   'appointment',
#   'syringe',
#   'clinic',
#   'site',
#   'morning',
#   'health',
#   'tomorrow',
#   'pharmacy',
#   'line',
#   'card',
#   'work',
#   'friend',
#   'book',
#   'state',
#   'family',
#   'astrazeneca'],
#  ['player',
#   'game',
#   'team',
#   'mask',
#   'play',
#   'test',
#   'fan',
#   'card',
#   'show',
#   'season',
#   'home',
#   'event',
#   'shot',
#   'proof',
#   'friend',
#   'restaurant',
#   'rule',
#   'work',
#   'place',
#   'booster']]
