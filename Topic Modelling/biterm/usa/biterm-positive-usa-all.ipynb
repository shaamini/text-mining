# %%
#for windows users:
#pip install bitermplus

#for mac users:
# xcode-select --install
# brew install libomp
# pip3 install bitermplus

# pip install tmplot
# pip install tomotopy

# %%
import bitermplus as btm
import numpy as np
import pandas as pd

import json 
import csv
import nltk
import unicodedata
import re
import sys
from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora, models
from gensim.utils import simple_preprocess
import gensim, spacy
from gensim.models.ldamulticore import LdaMulticore
import re
from gensim.models import Phrases
from gensim.models.phrases import Phraser

# %%
df = pd.read_csv("../pos_neg_usa.csv")
df
# Out:
#         Unnamed: 0   index                                               Text  \
# 0                0       0  want find way end racism try force people inje...
# 1                1       1  this child almost died tetanus, spent months h...
# 2                2       2  juste se rappeler m. leblanc la pression que l...
# 3                3       3  you would expect cases rise significantly, cou...
# 4                4       4  depends whether vaccination status is embedded...
# ...            ...     ...                                                ...
# 315598      404255  404255  pretty remarkable achievement. thank you all v...
# 315599      404258  404258  oh that explains similar - seemingly out nowhe...
# 315600      404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 315601      404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 315602      404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 315598  pretty remarkable achievement. thank you all v...   ENGLISH
# 315599  oh that explains similar - seemingly out nowhe...   ENGLISH
# 315600  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 315601  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 315602  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 315598  pretty remarkable achievement. thank you all v...
# 315599  oh that explains similar - seemingly out nowhe...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 315598  [('pretty', 'RB'), ('remarkable', 'JJ'), ('ach...
# 315599  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
# 315600  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 315601  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 315602  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explains', 'similar', 'seemingly', 'nowhere'...
# 315600                    ['others', 'vaccinesaveslives']
# 315601  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explain', 'similar', 'seemingly', 'nowhere',...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 315598  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 315599  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 315600                      ['other', 'vaccinesaveslive']  subjective
# 315601  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 315602  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 315598          2
# 315599          0
# 315600          2
# 315601          2
# 315602          2
#
# [315603 rows x 12 columns]

# %%
df.drop(columns = ['Unnamed: 0', 'Text', 'index', 'new_text', 'languages', 'pos_tagged_words'], inplace = True)
df
# Out:
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 315598  pretty remarkable achievement. thank you all v...
# 315599  oh that explains similar - seemingly out nowhe...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explains', 'similar', 'seemingly', 'nowhere'...
# 315600                    ['others', 'vaccinesaveslives']
# 315601  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explain', 'similar', 'seemingly', 'nowhere',...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 315598  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 315599  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 315600                      ['other', 'vaccinesaveslive']  subjective
# 315601  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 315602  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 315598          2
# 315599          0
# 315600          2
# 315601          2
# 315602          2
#
# [315603 rows x 6 columns]

# %%
df['words_processed_all'].values[0][0]
# Out:
# '['

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
tokens_words_processed_all = list(sent_to_words(df['words_processed_all']))

# %%
from nltk.corpus import stopwords
stop_list = stopwords.words('english')
high_freq_known_words = ['covid','couid', 'pfizer', 'amp', 'people', 'covidvaccine', 'covishield', 'moderna', 'vaccine', 'astrazeneca', 'vaccinate', 'vaccinated', 'vaccination', 'vaccines']

stop_list.extend(high_freq_known_words)

test_words_only1 = ['not', 'vaccine', 'covid', 'and', 'vegan', 'cruelty', 'free', 'i', 'use', 'elf', 'cosmetics', 'every', 'day', 'and', 'i', 'love', 'it']
test_stopremoved = [w for w in test_words_only1 if w not in stop_list or w == 'not']
print(test_stopremoved)
# Out:
# ['not', 'vegan', 'cruelty', 'free', 'use', 'elf', 'cosmetics', 'every', 'day', 'love']

# %%
stop_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'covid',
#  'couid',
#  'pfizer',
#  'amp',
#  'people',
#  'covidvaccine',
#  'covishield',
#  'moderna',
#  'vaccine',
#  'astrazeneca',
#  'vaccinate',
#  'vaccinated',
#  'vaccination',
#  'vaccines']

# %%
df['words_processed_all'] = tokens_words_processed_all

# %%
# remove stop words from tokenised_words_only

tokenised_stopremoved = [[w for w in each if w not in stop_list or w == 'not'] for each in tokens_words_processed_all]
tokenised_stopremoved
# Out:
# [['want',
#   'find',
#   'way',
#   'end',
#   'racism',
#   'try',
#   'force',
#   'inject',
#   'see',
#   'bunch',
#   'race',
#   'standing',
#   'forced',
#   'not',
#   'need',
#   'support',
#   'getting',
#   'shot',
#   'draw_line',
#   'force'],
#  ['child',
#   'almost',
#   'died',
#   'tetanus',
#   'spent',
#   'month',
#   'hospital',
#   'cost',
#   'around',
#   'parent',
#   'still',
#   'refused',
#   'pre',
#   'pandemic'],
#  ['remember',
#   'leblanc',
#   'pressure',
#   'provincial',
#   'business',
#   'world',
#   'asked',
#   'able',
#   'open',
#   'border',
#   'air',
#   'traffic',
#   'provincial',
#   'govt',
#   'ac',
#   'included',
#   'block',
#   'tourist',
#   'not',
#   'pas',
#   'hotel',
#   'restaurant'],
#  ['would',
#   'expect',
#   'case',
#   'rise',
#   'significantly',
#   'course',
#   'rate',
#   'come',
#   'play',
#   'space',
#   'adult',
#   'not',
#   'usually',
#   'confined',
#   'single',
#   'space',
#   'many',
#   'school',
#   'age',
#   'student',
#   'data',
#   'state',
#   'lifted',
#   'not',
#   'bear'],
#  ['depends',
#   'whether',
#   'status',
#   'embedded',
#   'code',
#   'code',
#   'link',
#   'connects',
#   'back',
#   'end',
#   'read',
#   'released',
#   'remember',
#   'see',
#   'find'],
#  ['could',
#   'ripped',
#   'harder',
#   'think',
#   'masking',
#   'isolation',
#   'etc',
#   'ultimately',
#   'impact',
#   'honest',
#   'question',
#   'look',
#   'spike',
#   'think',
#   'maybe',
#   'would',
#   'looked',
#   'matter',
#   'thing',
#   'definitively',
#   'worked'],
#  ['center',
#   'well',
#   'refused',
#   'let',
#   'elderly',
#   'parent',
#   'wear',
#   'not',
#   'mask',
#   'lady',
#   'rude',
#   'said',
#   'could',
#   'nineteen',
#   'could',
#   'mask',
#   'refused',
#   'not',
#   'take',
#   'answer',
#   'said',
#   'begrudgingly',
#   'absurd'],
#  ['part',
#   'vanguard',
#   'awareness',
#   'project',
#   'series',
#   'free',
#   'tool',
#   'help',
#   'suite',
#   'leader',
#   'combat',
#   'hesitancy',
#   'resistance',
#   'podcasts',
#   'video',
#   'article',
#   'available'],
#  ['correct',
#   'not',
#   'stated',
#   'goal',
#   'breaking',
#   'blogger',
#   'report',
#   'factual',
#   'news',
#   'accident',
#   'not',
#   'least',
#   'know',
#   'read',
#   'positive',
#   'step',
#   'towards',
#   'competence'],
#  ['hurt',
#   'head',
#   'actually',
#   'use',
#   'brain',
#   'seem',
#   'incredibly',
#   'brainwashed',
#   'place',
#   'highest',
#   'rate',
#   'world',
#   'highest',
#   'case_counts',
#   'everyone',
#   'disagrees',
#   'compliance',
#   'totalitarian',
#   'dictatorship',
#   'must',
#   'called',
#   'name'],
#  ['world',
#   'wide',
#   'mass',
#   'leading',
#   'world',
#   'wide',
#   'digital',
#   'passport',
#   'goal'],
#  ['still',
#   'need',
#   'proof',
#   'restaurant',
#   'movie_theater',
#   'museum',
#   'large',
#   'arena',
#   'fitness',
#   'center',
#   'bow',
#   'rate',
#   'three',
#   'three'],
#  ['following',
#   'tweet',
#   'even',
#   'age',
#   'twelve',
#   'hour',
#   'prince',
#   'charles',
#   'announced',
#   'infection',
#   'even',
#   'booster',
#   'yes',
#   'clearly',
#   'previous',
#   'infection',
#   'protects',
#   'point',
#   'boris',
#   'johnson',
#   'exude',
#   'sort',
#   'hypnotoad',
#   'like',
#   'pheromone',
#   'something'],
#  ['one',
#   'understand',
#   'exactly',
#   'need',
#   'understood',
#   'lame',
#   'link',
#   'two',
#   'even',
#   'remains',
#   'lame',
#   'compulsory',
#   'come',
#   'back',
#   'bawl',
#   'bye'],
#  ['world',
#   'top',
#   'virologist',
#   'luc_montagnier',
#   'winner',
#   'nobel_prize',
#   'discovery',
#   'hiv',
#   'died',
#   'today',
#   'warned',
#   'beginning',
#   'nineteen',
#   'lab',
#   'made',
#   'mass',
#   'leaky',
#   'would',
#   'generate',
#   'endless',
#   'new',
#   'variant',
#   'right',
#   'count',
#   'rip'],
#  ['obvious',
#   'common_sense',
#   'solution',
#   'always',
#   'take',
#   'free',
#   'safe',
#   'deadly',
#   'virus',
#   'carry',
#   'business',
#   'like',
#   'non',
#   'lunatic'],
#  ['sure',
#   'tooting',
#   'remember',
#   'grew',
#   'jackson',
#   'mi',
#   'least',
#   'place',
#   'long',
#   'associated',
#   'familiar',
#   'conservative',
#   'mien',
#   'mindset',
#   'speak',
#   'think',
#   'plain',
#   'language',
#   'think',
#   'mandatory'],
#  ['variant',
#   'involved',
#   'masking',
#   'ventilation',
#   'around',
#   'kid',
#   'time',
#   'meaningless',
#   'say',
#   'kid',
#   'danger',
#   'unless',
#   'mean',
#   'say',
#   'kid',
#   'not',
#   'not',
#   'ever',
#   'danger',
#   'matter'],
#  ['last',
#   'looked',
#   'actually',
#   'hit',
#   'county',
#   'threshold',
#   'difference',
#   'mah',
#   'cac',
#   'data',
#   'bet',
#   'secondary',
#   'school',
#   'though'],
#  ['see',
#   'saying',
#   'alberta',
#   'business',
#   'required',
#   'ask',
#   'proof',
#   'rely',
#   'alberta',
#   'government',
#   'rely',
#   'province'],
#  ['vision',
#   'public',
#   'health',
#   'decision',
#   'tied',
#   'local',
#   'condition',
#   'spread',
#   'vulnerability',
#   'also',
#   'sound',
#   'reasonable',
#   'however',
#   'two',
#   'year',
#   'acting',
#   'happening',
#   'naive',
#   'best',
#   'partisan',
#   'politics',
#   'even',
#   'local',
#   'level',
#   'often',
#   'big',
#   'factor'],
#  ['mean',
#   'someone',
#   'told',
#   'kill',
#   'get',
#   'understand',
#   'thought',
#   'said',
#   'lose',
#   'bodily_autonomy'],
#  ['concern',
#   'real',
#   'even',
#   'unfounded',
#   'addressing',
#   'empathy',
#   'genuine',
#   'good',
#   'persuade',
#   'canada',
#   'similar',
#   'level',
#   'adult',
#   'usa'],
#  ['seems',
#   'like',
#   'steel',
#   'man',
#   'many',
#   'mandate',
#   'mask',
#   'testing',
#   'etc',
#   'much',
#   'still',
#   'place',
#   'relatively',
#   'low',
#   'cost',
#   'not',
#   'zero',
#   'cost'],
#  ['kill', 'sally', 'field'],
#  ['jesus_christ', 'not', 'forced', 'carry', 'pregnancy', 'term'],
#  ['five',
#   'government',
#   'primary',
#   'concern',
#   'justification',
#   'compulsory',
#   'prevent',
#   'hospital',
#   'icu',
#   'emergency',
#   'depth',
#   'inundated',
#   'thus',
#   'running',
#   'medical',
#   'resource',
#   'bed',
#   'space',
#   'equipment',
#   'staff',
#   'perhaps',
#   'govt',
#   'require',
#   'hospital'],
#  ['two',
#   'proven',
#   'not',
#   'prevent',
#   'spread',
#   'even',
#   'esp',
#   'omicron',
#   'called',
#   'became',
#   'positive',
#   'case',
#   'omicron',
#   'care',
#   'status',
#   'real',
#   'driving',
#   'force',
#   'become',
#   'minimizing'],
#  ['think',
#   'eighty',
#   'game',
#   'never',
#   'full',
#   'anyway',
#   'meant',
#   'download_app',
#   'get',
#   'green_light',
#   'based',
#   'status',
#   'allow',
#   'enter',
#   'stadium',
#   'not',
#   'ground',
#   'unsure',
#   'enforce',
#   'much'],
#  ['medical', 'specialist', 'involved', 'effort'],
#  ['reaction',
#   'according',
#   'cac',
#   'anaphylaxis',
#   'nineteen',
#   'extremely_rare',
#   'occurred',
#   'five',
#   'per',
#   'one',
#   'million',
#   'united_states',
#   'five'],
#  ['bad',
#   'right',
#   'body',
#   'belongs',
#   'not',
#   'wear',
#   'better',
#   'fight',
#   'fight',
#   'compulsory',
#   'required',
#   'business',
#   'employer',
#   'government'],
#  ['nothing',
#   'report',
#   'document',
#   'trump',
#   'took',
#   'gave',
#   'back',
#   'bullshit',
#   'happened',
#   'january',
#   'let',
#   'close',
#   'border',
#   'let',
#   'end',
#   'mask',
#   'mandate',
#   'seriously'],
#  ['conclusion',
#   'definitely',
#   'cannot',
#   'draw',
#   'mask',
#   'mandate',
#   'work',
#   'since',
#   'death',
#   'rate',
#   'much',
#   'lower',
#   'state',
#   'probably',
#   'primarily',
#   'due',
#   'higher',
#   'rate'],
#  ['never', 'suggested', 'issue', 'one', 'way'],
#  ['trump',
#   'arrested',
#   'yet',
#   'look',
#   'like',
#   'laughingstock',
#   'rest',
#   'world',
#   'still',
#   'also',
#   'terrified',
#   'trucker',
#   'not',
#   'coming',
#   'mandate',
#   'coming',
#   'big',
#   'lie',
#   'perceived',
#   'reinstatement',
#   'tag'],
#  ['positive', 'died', 'amazed', 'spun', 'death', 'push', 'agenda'],
#  ['school',
#   'not',
#   'gonna',
#   'ask',
#   'proof',
#   'respect',
#   'individuality',
#   'health',
#   'decision',
#   'everyone',
#   'choice',
#   'stay',
#   'virtually',
#   'lol',
#   'hate'],
#  ['linked',
#   'republican',
#   'controlled',
#   'state',
#   'tend',
#   'state',
#   'without',
#   'mask',
#   'mandate',
#   'far',
#   'worse',
#   'democratic',
#   'controlled',
#   'state',
#   'course',
#   'also',
#   'state',
#   'lower',
#   'rate',
#   'hard',
#   'draw',
#   'strong',
#   'conclusion'],
#  ['close', 'neighbor', 'pig', 'got', 'one', 'lowest', 'rate', 'world'],
#  ['indian',
#   'health',
#   'department',
#   'sorry',
#   'trust',
#   'look',
#   'like',
#   'think',
#   'israel',
#   'ninety',
#   'rate',
#   'hard',
#   'time',
#   'right'],
#  ['employer',
#   'mask',
#   'mandatory',
#   'policy',
#   'even',
#   'provincial',
#   'federal',
#   'government',
#   'remove',
#   'mandate',
#   'employer',
#   'still',
#   'mask',
#   'mandatory',
#   'policy',
#   'cannoli_poli'],
#  ['demystify', 'provided', 'master', 'subject', 'let', 'go'],
#  ['conservative',
#   'anti',
#   'abortion',
#   'anti',
#   'thought',
#   'prayer',
#   'forget',
#   'prayer'],
#  ['classic',
#   'simpson',
#   'paradox',
#   'death',
#   'among',
#   'elderly',
#   'nearly',
#   'lower',
#   'rate',
#   'total',
#   'number',
#   'fatality',
#   'would',
#   'much',
#   'higher'],
#  ['sound',
#   'like',
#   'planning',
#   'masking',
#   'kid',
#   'indefinitely',
#   'bus',
#   'hospitalization',
#   'rate',
#   'rate',
#   'etc',
#   'deeming',
#   'necessary',
#   'finally',
#   'let',
#   'kid',
#   'finally',
#   'get',
#   'back',
#   'normalcy',
#   'need',
#   'number'],
#  ['case',
#   'gone',
#   'state',
#   'highest',
#   'rate',
#   'january',
#   'ate',
#   'bullshit',
#   'obvious',
#   'fake',
#   'news',
#   'site',
#   'spoon',
#   'insulting',
#   'intelligence'],
#  ['lot',
#   'speaking',
#   'like',
#   'pro',
#   'choice',
#   'abortion',
#   'pro',
#   'choice',
#   'relating',
#   'disagree',
#   'abortion',
#   'remove',
#   'choice',
#   'human',
#   'ending',
#   'human',
#   'life',
#   'forced',
#   'coerced',
#   'remove',
#   'choice',
#   'forcing',
#   'human',
#   'risk'],
#  ['not',
#   'delusional',
#   'endemic',
#   'going',
#   'live',
#   'not',
#   'lockdown',
#   'mask',
#   'still',
#   'live',
#   'fear',
#   'get',
#   'taking',
#   'precaution',
#   'necessary',
#   'based',
#   'age',
#   'health',
#   'condition'],
#  ['tell',
#   'died',
#   'unfortunately',
#   'not',
#   'true',
#   'indeed',
#   'prevent',
#   'dire',
#   'result',
#   'infection',
#   'pretty',
#   'well',
#   'established'],
#  ['tool', 'surgeon_general', 'refuse', 'disclose', 'nineteen', 'status'],
#  ['thank',
#   'keeping',
#   'mask',
#   'mandate',
#   'school',
#   'need',
#   'get',
#   'rate',
#   'education',
#   'outreach',
#   'get',
#   'student',
#   'sibling',
#   'five',
#   'lifting',
#   'mask',
#   'mandate'],
#  ['according', 'abortion', 'thing', 'welcome'],
#  ['care',
#   'explain',
#   'mental_health',
#   'anything',
#   'not',
#   'talking',
#   'person',
#   'may',
#   'feel',
#   'one',
#   'way',
#   'talking',
#   'genuine',
#   'mental_health',
#   'issue',
#   'due',
#   'not',
#   'exist'],
#  ['three',
#   'eric_adams',
#   'also',
#   'repeatedly',
#   'renewed',
#   'key',
#   'executive',
#   'order',
#   'requires',
#   'anyone',
#   'age',
#   'five',
#   'show',
#   'proof',
#   'full',
#   'participate',
#   'anyone',
#   'eighteen',
#   'older',
#   'proof',
#   'id',
#   'along',
#   'proof',
#   'required'],
#  ['make', 'sad', 'also', 'angry', 'discouraged'],
#  ['time',
#   'well',
#   'done',
#   'everyone',
#   'faught',
#   'proud',
#   'revoking',
#   'across',
#   'health',
#   'social',
#   'care'],
#  ['make',
#   'american',
#   'think',
#   'right',
#   'challenge',
#   'sovereign',
#   'nation',
#   'rule',
#   'regarding',
#   'testing',
#   'problem',
#   'creation',
#   'putting',
#   'self',
#   'need',
#   'country',
#   'vaccineswork',
#   'canada'],
#  ['stake',
#   'applicant',
#   'not',
#   'forcible',
#   'rather',
#   'consequence',
#   'one',
#   'choice',
#   'remain'],
#  ['trading',
#   'player',
#   'injured',
#   'claim',
#   'injury',
#   'report',
#   'like',
#   'firing',
#   'non',
#   'claiming',
#   'rate'],
#  ['really',
#   'get',
#   'lesson',
#   'symptom',
#   'immediate',
#   'long_term',
#   'still',
#   'get',
#   'unlikely',
#   'serious',
#   'cause',
#   'long_term',
#   'damage',
#   'ifs',
#   'keep'],
#  ['member',
#   'public',
#   'health',
#   'professional',
#   'submit',
#   'suspected',
#   'side_effect',
#   'yellow',
#   'card',
#   'scheme',
#   'nature',
#   'yellow',
#   'card',
#   'reporting',
#   'mean',
#   'reported',
#   'event',
#   'not',
#   'always',
#   'proven',
#   'side_effect',
#   'event',
#   'may',
#   'happened',
#   'anyway',
#   'regardless'],
#  ['strange',
#   'claiming',
#   'want',
#   'stop',
#   'living',
#   'fear',
#   'causing',
#   'lot',
#   'fear',
#   'mask',
#   'ever',
#   'caused',
#   'held_hostage'],
#  ['rate',
#   'quite',
#   'low',
#   'twelve',
#   'age_range',
#   'thought',
#   'needed',
#   'benefit',
#   'risk',
#   'unmasked',
#   'indoor',
#   'instruction',
#   'glad',
#   'allows',
#   'unmasked',
#   'outdoor',
#   'activity',
#   'fab',
#   'socal',
#   'weather',
#   'make',
#   'easy',
#   'get',
#   'fresh',
#   'air'],
#  ['truly',
#   'feel',
#   'mentally',
#   'unstable',
#   'head',
#   'concerning',
#   'answer',
#   'time',
#   'time',
#   'ninety'],
#  ['tend',
#   'let',
#   'slide',
#   'injure',
#   'doc',
#   'notice',
#   'awhile',
#   'since',
#   'quit',
#   'using',
#   'horse',
#   'serum',
#   'good'],
#  ['justified',
#   'frustrated',
#   'get',
#   'job',
#   'fair',
#   'require',
#   'remain',
#   'employed',
#   'really',
#   'going',
#   'try',
#   'starve'],
#  ['adopted',
#   'recommendation',
#   'make',
#   'health',
#   'care',
#   'worker',
#   'condition',
#   'medicare',
#   'medicaid',
#   'fund',
#   'scout',
#   'upheld',
#   'rule',
#   'important',
#   'patient',
#   'safety'],
#  ['yes',
#   'prevention',
#   'long_term',
#   'involves',
#   'mask',
#   'reduce',
#   'speaks',
#   'either',
#   'mask',
#   'let',
#   'get',
#   'real',
#   'not',
#   'going',
#   'beat',
#   'new',
#   'flu',
#   'two',
#   'flu',
#   'shot',
#   'year',
#   'going',
#   'forward',
#   'difference',
#   'virus',
#   'higher',
#   'kill',
#   'rate'],
#  ['seems',
#   'way',
#   'reasonable',
#   'yield',
#   'far',
#   'positive',
#   'result',
#   'rescinding',
#   'mandate',
#   'letting',
#   'make',
#   'decision'],
#  ['come',
#   'one',
#   'come',
#   'altar',
#   'valencia',
#   'los_angeles',
#   'free',
#   'produce',
#   'testing'],
#  ['absurd',
#   'please',
#   'take',
#   'look',
#   'mirror',
#   'man',
#   'fellow',
#   'conservative',
#   'expressly',
#   'supporting',
#   'blockade',
#   'not',
#   'main',
#   'culprit',
#   'inflamed',
#   'rhetoric',
#   'calling',
#   'respect',
#   'public',
#   'health',
#   'order'],
#  ['fan',
#   'receive',
#   'est',
#   'booster',
#   'dose',
#   'super_bowl',
#   'experience',
#   'receive',
#   'free',
#   'ticket',
#   'enter',
#   'experience',
#   'day',
#   'future',
#   'date',
#   'sure',
#   'visit',
#   'site',
#   'south',
#   'hall',
#   'see',
#   'solve'],
#  ['got',
#   'unease',
#   'part',
#   'pas',
#   'adult',
#   'make',
#   'choice',
#   'suffer',
#   'consequence',
#   'deal',
#   'yet',
#   'low',
#   'rate',
#   'five_eleven',
#   'least',
#   'fifty'],
#  ['physical', 'card', 'gross', 'digital', 'thanks'],
#  ['especially',
#   'vehicle',
#   'towed',
#   'not',
#   'allowed',
#   'cross_border',
#   'get',
#   'wait',
#   'requires',
#   'proof',
#   'cross'],
#  ['myocarditis',
#   'foundation',
#   'website',
#   'known',
#   'potential',
#   'benefit',
#   'nineteen',
#   'outweigh',
#   'known',
#   'potential',
#   'risk',
#   'including',
#   'possible',
#   'risk'],
#  ['governor',
#   'control',
#   'lockdown',
#   'started',
#   'long',
#   'biden',
#   'biden',
#   'opened',
#   'thing',
#   'program',
#   'not',
#   'sure',
#   'tracking',
#   'right',
#   'trump',
#   'spent',
#   'far',
#   'biden',
#   'fed',
#   'failed',
#   'increase',
#   'rate',
#   'presidency'],
#  ['ability',
#   'always',
#   'free',
#   'restriction',
#   'supposed',
#   'point',
#   'mandate',
#   'trust',
#   'broken',
#   'closed',
#   'business',
#   'jan',
#   'may',
#   'able',
#   'go',
#   'restaurant',
#   'guarantee',
#   'april'],
#  ['genuinely',
#   'curious',
#   'find',
#   'clip',
#   'quote',
#   'trump',
#   'telling',
#   'base',
#   'anyone',
#   'anything',
#   'remotely',
#   'anti',
#   'everything',
#   'said',
#   'seen',
#   'extremely',
#   'pro',
#   'maybe',
#   'source',
#   'could',
#   'cite'],
#  ['treatment',
#   'not',
#   'obviously',
#   'not',
#   'definition',
#   'know',
#   'original',
#   'response',
#   'said',
#   'right',
#   'know',
#   'occurs',
#   'prior',
#   'illness',
#   'not',
#   'illness',
#   'right'],
#  ['not', 'prevent', 'spread', 'stop', 'disinformation'],
#  ['absolutely', 'since', 'live', 'ohio', 'county', 'one', 'lowest', 'rate'],
#  ['rig',
#   'thick',
#   'yogurt',
#   'like',
#   'substance',
#   'feel',
#   'clearly',
#   'tell',
#   'apart',
#   'normal',
#   'rabies',
#   'jab',
#   'got',
#   'bitten',
#   'forgot',
#   'administer',
#   'must',
#   'really',
#   'rabies',
#   'effective',
#   'post',
#   'trauma'],
#  ['proof', 'get', 'lifted', 'elderly', 'forced', 'isolate', 'protect'],
#  ['agreed',
#   'suspect',
#   'higher',
#   'uptake',
#   'part',
#   'honored',
#   'recovery',
#   'individual',
#   'adjusted',
#   'recommendation',
#   'result'],
#  ['mandatory', 'mumps', 'measles', 'rubella', 'fake', 'outrage', 'particular'],
#  ['ugh',
#   'suck',
#   'school',
#   'marin',
#   'mass',
#   'day',
#   'support',
#   'dog',
#   'pretty',
#   'much',
#   'every',
#   'school_district',
#   'twenty_minutes'],
#  ['fair',
#   'parent',
#   'set',
#   'much',
#   'mass',
#   'infrastructure',
#   'grownup',
#   'got',
#   'valued',
#   'easy',
#   'hell',
#   'barely',
#   'twenty_minutes',
#   'including',
#   'fifteen',
#   'min',
#   'observation',
#   'kid',
#   'second',
#   'dose',
#   'two',
#   'hour',
#   'waiting',
#   'damp',
#   'cold'],
#  ['would',
#   'pay',
#   'list',
#   'nominee',
#   'would',
#   'blacklisted',
#   'oscar',
#   'academy',
#   'blinked',
#   'requirement',
#   'imagine',
#   'meltdown',
#   'twitter',
#   'would',
#   'wag',
#   'weighted',
#   'much',
#   'liked',
#   'movie',
#   'based',
#   'shot',
#   'god'],
#  ['im',
#   'saying',
#   'stopping',
#   'ending',
#   'inquiry',
#   'arbitrary',
#   'european_union',
#   'allows',
#   'titer',
#   'negative',
#   'test',
#   'pas',
#   'system'],
#  ['councilman',
#   'said',
#   'champ',
#   'rate',
#   'continuing',
#   'lag',
#   'district',
#   'leader',
#   'help',
#   'return_normal',
#   'especially',
#   'given',
#   'tweet',
#   'deleted',
#   'restaurant'],
#  ['government',
#   'offer',
#   'free',
#   'help',
#   'boost',
#   'immune_system',
#   'place',
#   'mostly',
#   'private',
#   'business',
#   'not',
#   'government',
#   'mandate',
#   'need',
#   'show',
#   'proof',
#   'negative_test',
#   'feel',
#   'like',
#   'oppression'],
#  ['saying',
#   'memory_cells',
#   'remember',
#   'thing',
#   'term',
#   'thing',
#   'like',
#   'spike_proteins',
#   'depends',
#   'disease',
#   'example',
#   'hepatitis',
#   'mainly',
#   'based',
#   'surface',
#   'protein'],
#  ['care',
#   'say',
#   'personally',
#   'fact',
#   'possibly',
#   'care',
#   'le',
#   'anyone',
#   'care',
#   'shown',
#   'exactly',
#   'think',
#   'pal',
#   'simply',
#   'agree',
#   'forced',
#   'care'],
#  ['wish', 'everyone', 'mandatory', 'measure', 'based', 'science'],
#  ['hope',
#   'ontario',
#   'drop',
#   'proof',
#   'soon',
#   'cause',
#   'bring',
#   'way',
#   'much',
#   'unnecessary',
#   'conflict',
#   'worker',
#   'especially',
#   'wanna',
#   'change',
#   'type',
#   'vacation',
#   'proof',
#   'dime'],
#  ['tyrannical',
#   'want',
#   'mandatory',
#   'protestors',
#   'canada',
#   'crushed',
#   'beneath',
#   'grinding',
#   'wheel',
#   'federal',
#   'authority'],
#  ['since',
#   'hospitalization',
#   'denmark',
#   'also',
#   'ticking',
#   'upwards',
#   'despite',
#   'highest',
#   'booster',
#   'rate',
#   'far',
#   'europe',
#   'please',
#   'take',
#   'look',
#   'hospitalization',
#   'chart',
#   'world',
#   'data'],
#  ['love',
#   'see',
#   'mental',
#   'gymnastics',
#   'perform',
#   'argue',
#   'protesting',
#   'akin',
#   'protesting',
#   'police',
#   'brutality',
#   'minority'],
#  ['see',
#   'put',
#   'defundcbc',
#   'defundbbc',
#   'unfortunately',
#   'pal',
#   'behind',
#   'extravaganza',
#   'pal',
#   'funding',
#   'news',
#   'network',
#   'sayin',
#   'totally',
#   'though',
#   'fund',
#   'coming',
#   'baddie'],
#  ['super',
#   'immunity',
#   'fake',
#   'get',
#   'time',
#   'row',
#   'fact',
#   'therapist',
#   'two',
#   'three',
#   'time',
#   'row',
#   'le',
#   'health',
#   'risk',
#   'getting',
#   'going',
#   'kill',
#   'due',
#   'attacking',
#   'proven',
#   'technology'],
#  ['school',
#   'age',
#   'not',
#   'going',
#   'well',
#   'one',
#   'kid',
#   'school',
#   'right',
#   'around',
#   'wif',
#   'wrong',
#   'parent'],
#  ['yup', 'still', 'mask', 'social_distance', 'booster', 'yeah', 'smart'],
#  ['besides',
#   'fact',
#   'even',
#   'mandate',
#   'canada',
#   'mean',
#   'entering',
#   'country',
#   'needed',
#   'follow',
#   'show',
#   'proof',
#   'negative_test',
#   'quarantine',
#   'point',
#   'leave',
#   'country',
#   'without',
#   'proof'],
#  ['ice',
#   'hockey',
#   'harlem',
#   'supporting',
#   'end',
#   'key',
#   'program',
#   'elected',
#   'house',
#   'make',
#   'sure',
#   'become',
#   'famous',
#   'capitol',
#   'hill',
#   'voice',
#   'matter',
#   'godblessamerica',
#   'nomad'],
#  ['mandate',
#   'help',
#   'increase',
#   'rate',
#   'prevent',
#   'future',
#   'restriction',
#   'appreciate',
#   'overall',
#   'tone',
#   'thread',
#   'disagree',
#   'mandate',
#   'not',
#   'done',
#   'attempt',
#   'coerce',
#   'producing',
#   'elsewhere',
#   'accept',
#   'non_compliance'],
#  ['last',
#   'answer',
#   'apparently',
#   'not',
#   'keeping',
#   'stimulates',
#   'robust',
#   'gas',
#   'containing',
#   'spike_antigen',
#   'eight',
#   'week',
#   'postvaccination',
#   'case'],
#  ['meanwhile',
#   'government',
#   'using',
#   'kid',
#   'shield',
#   'unneccessary',
#   'face',
#   'mask',
#   'school'],
#  ['since',
#   'ninety',
#   'rate',
#   'super',
#   'majority',
#   'supporting',
#   'federal',
#   'government',
#   'pandemic',
#   'plan',
#   'dummy',
#   'refer',
#   'get'],
#  ['paper',
#   'state',
#   'free',
#   'floating',
#   'spike_proteins',
#   'circulate',
#   'high',
#   'level',
#   'blood',
#   'infected',
#   'variant',
#   'produce',
#   'antibody',
#   'biased',
#   'toward',
#   'original',
#   'extinct',
#   'variant',
#   'rather',
#   'one',
#   'actually',
#   'infected'],
#  ['sound',
#   'like',
#   'might',
#   'asking',
#   'immigration',
#   'related',
#   'question',
#   'qualified',
#   'answer',
#   'sorry',
#   'asking',
#   'meet',
#   'health',
#   'safety',
#   'requirement',
#   'long',
#   'wear_mask',
#   'provide',
#   'record',
#   'gov',
#   'id',
#   'yes'],
#  ['say',
#   'incorrect',
#   'terrorist',
#   'causing',
#   'issue',
#   'closure',
#   'supply_chain',
#   'issue',
#   'restriction',
#   'way',
#   'put',
#   'period'],
#  ['not',
#   'extended',
#   'pre',
#   'isolation',
#   'think',
#   'know',
#   'need',
#   'fentanyl',
#   'death',
#   'oneself',
#   'loved_one',
#   'cause',
#   'far',
#   'psychological',
#   'stress',
#   'wear',
#   'damn',
#   'mask',
#   'show',
#   'proof',
#   'big',
#   'baby'],
#  ['would', 'triple', 'person', 'living', 'county', 'rate', 'mask'],
#  ['dye',
#   'half',
#   'adult',
#   'hospitalized',
#   'flu',
#   'heart',
#   'disease',
#   'flu',
#   'especially',
#   'important',
#   'heart',
#   'disease',
#   'higher',
#   'risk',
#   'serious',
#   'flu',
#   'complication',
#   'protect',
#   'rightful',
#   'heartmonth'],
#  ['downplaying',
#   'pre',
#   'show',
#   'misinformation',
#   'show',
#   'zero',
#   'new',
#   'nowspinning',
#   'nowstreaming',
#   'two',
#   'hear',
#   'subgenius',
#   'radio',
#   'end',
#   'time',
#   'joerogan',
#   'antivaxxers',
#   'full',
#   'detail'],
#  ['enforced',
#   'like',
#   'parking',
#   'ticket',
#   'spot',
#   'check',
#   'bylaw',
#   'officer',
#   'protecting',
#   'business',
#   'check',
#   'includes',
#   'ord',
#   'shot',
#   'etc'],
#  ['not',
#   'biden',
#   'giving',
#   'crack_pipes',
#   'long',
#   'show',
#   'proof',
#   'saw',
#   'yesterday',
#   'thought',
#   'fake',
#   'literal',
#   'hell'],
#  ['hope',
#   'receiving',
#   'treatment',
#   'problem',
#   'immunity',
#   'system',
#   'like',
#   'many',
#   'case',
#   'weakened',
#   'check',
#   'report',
#   'israel'],
#  ['stunning',
#   'yet',
#   'want',
#   'treat',
#   'another',
#   'flu',
#   'know',
#   'zero',
#   'plus',
#   'american',
#   'died',
#   'last',
#   'month',
#   'last',
#   'three',
#   'year',
#   'died',
#   'flu',
#   'complication',
#   'want',
#   'find',
#   'rather',
#   'done'],
#  ['eighty',
#   'ninety',
#   'respectively',
#   'not',
#   'mean',
#   'pro',
#   'mandate',
#   'mask',
#   'etc',
#   'included',
#   'understand',
#   'highly',
#   'beneficial',
#   'almost',
#   'give',
#   'right',
#   'deprive',
#   'anyone',
#   'right'],
#  ['thing',
#   'heard',
#   'today',
#   'person',
#   'put',
#   'leave',
#   'question',
#   'need',
#   'booster',
#   'side_effect',
#   'first',
#   'two',
#   'dos',
#   'recovered',
#   'person',
#   'losing',
#   'client',
#   'contract',
#   'wish',
#   'wait',
#   'consider',
#   'health',
#   'concern'],
#  ['human_right',
#   'commission',
#   'maybe',
#   'time',
#   'health',
#   'right',
#   'commission',
#   'discrimination',
#   'wrong',
#   'whether',
#   'based',
#   'color',
#   'sex',
#   'religion',
#   'etc',
#   'universal',
#   'health',
#   'system',
#   'discriminate',
#   'anyone',
#   'injection'],
#  ['support',
#   'right',
#   'turn',
#   'saying',
#   'make',
#   'sense',
#   'like',
#   'saying',
#   'choice',
#   'get',
#   'evicted',
#   'want',
#   'pay',
#   'rent'],
#  ['talk',
#   'khalistani',
#   'issue',
#   'open',
#   'threat',
#   'tiring',
#   'katra',
#   'jabbar',
#   'kalsa',
#   'etc',
#   'police',
#   'australian',
#   'state',
#   'mostly',
#   'pro',
#   'group',
#   'democracy',
#   'australia',
#   'enforced',
#   'kid',
#   'even',
#   'leave',
#   'country'],
#  ['exception',
#   'one',
#   'worst',
#   'ac',
#   'since',
#   'beginning',
#   'death',
#   'patient',
#   'ambulance',
#   'icing',
#   'incompetence',
#   'quickly',
#   'sir',
#   'investigation',
#   'household',
#   'imposed',
#   'management',
#   'unacceptable'],
#  ['member', 'band', 'still', 'alive', 'tell', 'think', 'wait', 'minute'],
#  ['two',
#   'million',
#   'quebecers',
#   'caught',
#   'since',
#   'december',
#   'four',
#   'million',
#   'since',
#   'march',
#   'one',
#   'three',
#   'million',
#   'non',
#   'van',
#   'solution',
#   'reduce',
#   'contagion'],
#  ['since',
#   'latest',
#   'flip_flop',
#   'rather',
#   'sudden',
#   'question',
#   'two',
#   'airline',
#   'still',
#   'requesting',
#   'proof',
#   'international',
#   'destination',
#   'still',
#   'requiring',
#   'proof'],
#  ['mitigation', 'mean'],
#  ['question',
#   'enter',
#   'first',
#   'place',
#   'given',
#   'requires',
#   'proof',
#   'entry'],
#  ['gov',
#   'made',
#   'intention',
#   'known',
#   'tues',
#   'announced',
#   'dramatic',
#   'drop',
#   'case',
#   'not',
#   'county',
#   'rate',
#   'stop',
#   'state',
#   'interference',
#   'county',
#   'education',
#   'four',
#   'died',
#   'yesterday',
#   'twelve'],
#  ['feel',
#   'like',
#   'pissed',
#   'employer',
#   'mandate',
#   'thought',
#   'politically',
#   'dangerous'],
#  ['know', 'see', 'boy', 'shower', 'eighty', 'rate', 'lot', 'science'],
#  ['nothing',
#   'see',
#   'comrade',
#   'singh',
#   'told',
#   'directly',
#   'presser',
#   'today',
#   'political',
#   'alignment',
#   'issue',
#   'explain',
#   'everyday',
#   'cabal',
#   'real',
#   'mybodymychoice',
#   'fall',
#   'deaf',
#   'ear'],
#  ['live',
#   'mercer',
#   'county',
#   'ohio',
#   'rate',
#   'even',
#   'forty',
#   'percent',
#   'continue',
#   'avoiding',
#   'indoor_spaces',
#   'masking',
#   'running',
#   'errand',
#   'took',
#   'early',
#   'early',
#   'retirement',
#   'hubby',
#   'retired',
#   'several',
#   'year',
#   'refuse',
#   'play',
#   'long',
#   'want'],
#  ['gotta',
#   'love',
#   'fact',
#   'taking',
#   'away',
#   'business',
#   'option',
#   'continue',
#   'check',
#   'status',
#   'want',
#   'thought',
#   'choice',
#   'choice',
#   'not',
#   'get',
#   'choice',
#   'allow',
#   'business',
#   'poli'],
#  ['look',
#   'bright',
#   'side',
#   'fiorellas',
#   'fan',
#   'feel',
#   'able',
#   'ratio',
#   'much',
#   'longer'],
#  ['tie',
#   'van',
#   'rate',
#   'masking',
#   'definition',
#   'fully',
#   'van',
#   'includes',
#   'booster',
#   'know',
#   'immunity',
#   'wane',
#   'not',
#   'infection',
#   'also',
#   'wane',
#   'severe_disease',
#   'hospitalization',
#   'death',
#   'tie',
#   'masking',
#   'policy',
#   'two',
#   'dose'],
#  ['memory',
#   'holed',
#   'analysis',
#   'every',
#   'state',
#   'elderly',
#   'prioritized',
#   'access',
#   'month'],
#  ['nothing',
#   'like',
#   'election',
#   'provide',
#   'accurate',
#   'definition',
#   'fully',
#   'vad',
#   'unless',
#   'tourist',
#   'mandate',
#   'aged',
#   'care',
#   'time'],
#  ['thankyoukyrie',
#   'standing',
#   'firm',
#   'belief',
#   'driving',
#   'james',
#   'sixer',
#   'three'],
#  ['everything',
#   'public',
#   'health',
#   'everybody',
#   'masking',
#   'better',
#   'ventilation',
#   'reduces',
#   'amount',
#   'virus',
#   'air',
#   'chance',
#   'infected',
#   'ugh',
#   'sorry',
#   'amanda',
#   'hope',
#   'dad'],
#  ['tucson',
#   'electric',
#   'power',
#   'state',
#   'regulated',
#   'utility',
#   'say',
#   'plan',
#   'mandate',
#   'testing',
#   'beyond',
#   'current',
#   'workplace',
#   'safety',
#   'protocol'],
#  ['luc_montagnier',
#   'clear',
#   'new',
#   'variant',
#   'created',
#   'antibody',
#   'mediated',
#   'selection',
#   'ade',
#   'due',
#   'put',
#   'yesterday',
#   'rip',
#   'montagnier'],
#  ['thought',
#   'herpes',
#   'infection',
#   'many',
#   'recurrence',
#   'make',
#   'possible',
#   'connection',
#   'cac',
#   'estimated',
#   'zero',
#   'new',
#   'genital',
#   'herpes',
#   'infection',
#   'united_states',
#   'single',
#   'year'],
#  ['safer',
#   'aspirin',
#   'tylenol',
#   'travel',
#   'cross',
#   'state',
#   'border',
#   'without',
#   'showing',
#   'card',
#   'business',
#   'want',
#   'serve',
#   'hire',
#   'right',
#   'comparison',
#   'makes_sense'],
#  ['girl',
#   'selling',
#   'card',
#   'facebook',
#   'week',
#   'later',
#   'realized',
#   'mean',
#   'card',
#   'not',
#   'valentine',
#   'card'],
#  ['fact_checkers',
#   'say',
#   'cac',
#   'probably',
#   'first',
#   'time',
#   'history',
#   'definition',
#   'changed',
#   'reason',
#   'gave',
#   'cac',
#   'right',
#   'change',
#   'meaning',
#   'word'],
#  ['pas',
#   'not',
#   'simple',
#   'card',
#   'present',
#   'traveling',
#   'comparison',
#   'not',
#   'hold',
#   'water',
#   'forget',
#   'context',
#   'creation',
#   'forget',
#   'role',
#   'play',
#   'get',
#   'legal',
#   'punitive',
#   'strategy',
#   'forget',
#   'social',
#   'impact'],
#  ['acc',
#   'hosting',
#   'block',
#   'party',
#   'right',
#   'neighborhood',
#   'clinic',
#   'health',
#   'screening',
#   'resource',
#   'various',
#   'vendor',
#   'music',
#   'free',
#   'food',
#   'fun',
#   'come',
#   'february',
#   'see',
#   'flyer',
#   'info'],
#  ['sure',
#   'never',
#   'get',
#   'never',
#   'transmit',
#   'safer',
#   'tested',
#   'negative',
#   'within',
#   'hour',
#   'funny',
#   'current',
#   'policy',
#   'science'],
#  ['totally',
#   'disagree',
#   'patrick',
#   'propaganda',
#   'exercise',
#   'make',
#   'recalcitrant',
#   'feel',
#   'guilty',
#   'however',
#   'rate',
#   'quebec',
#   'highest',
#   'world',
#   'not',
#   'getting',
#   'guilt',
#   'ridden',
#   'business'],
#  ['realize',
#   'lift',
#   'mask',
#   'mandate',
#   'next',
#   'week',
#   'allowed',
#   'ask',
#   'proof'],
#  ['united_states',
#   'right',
#   'protect',
#   'border',
#   'trucker',
#   'paid',
#   'dearly',
#   'likely',
#   'usa',
#   'saying',
#   'one',
#   'cross_border',
#   'without',
#   'like',
#   'rule',
#   'fuck',
#   'care',
#   'find',
#   'really',
#   'behind'],
#  ['almost',
#   'certainly',
#   'huge',
#   'risk',
#   'reduction',
#   'considering',
#   'much',
#   'cut',
#   'time',
#   'virus',
#   'circulates',
#   'body',
#   'produce',
#   'elongated',
#   'immune_response',
#   'immuno',
#   'naive',
#   'develop',
#   'antibody',
#   'one',
#   'three',
#   'week',
#   'virus',
#   'enters',
#   'body'],
#  ['might',
#   'know',
#   'le',
#   'know',
#   'topic',
#   'believe',
#   'anti',
#   'republican',
#   'supporter'],
#  ['free', 'nineteen', 'event', 'friday', 'mountlake', 'terrace'],
#  ['got',
#   'proof',
#   'recovery',
#   'cool',
#   'today',
#   'bow',
#   'actually',
#   'incredibly',
#   'lucky',
#   'timing',
#   'wise',
#   'since',
#   'pas',
#   'running',
#   'next',
#   'month',
#   'good',
#   'november'],
#  ['nine',
#   'jab',
#   'nov',
#   'jan',
#   'shingle',
#   'two',
#   'pneumonia',
#   'one',
#   'modern',
#   'three',
#   'influenza',
#   'two',
#   'trap',
#   'one',
#   'even',
#   'alive'],
#  ['attending',
#   'super_bowl',
#   'party',
#   'weekend',
#   'matter',
#   'root',
#   'staying_home',
#   'sick',
#   'mask',
#   'key',
#   'defensive',
#   'play',
#   'taking',
#   'care',
#   'matter',
#   'let',
#   'tackle',
#   'together'],
#  ['sure',
#   'gop',
#   'introducing',
#   'bill',
#   'get',
#   'rid',
#   'mandate',
#   'public',
#   'elementary',
#   'school',
#   'free',
#   'poor',
#   'kid',
#   'rich',
#   'send',
#   'kid',
#   'private',
#   'school',
#   'strict',
#   'requirement'],
#  ['anticipate',
#   'cell',
#   'based',
#   'scheme',
#   'classify',
#   'subject',
#   'based',
#   'natural',
#   'infection',
#   'history',
#   'important',
#   'tool',
#   'longitudinal',
#   'monitoring',
#   'establishing',
#   'sars_cov',
#   'two',
#   'correlate',
#   'protection'],
#  ['not',
#   'opponent',
#   'distrust',
#   'current',
#   'new',
#   'product',
#   'not',
#   'stood',
#   'test',
#   'time',
#   'apply',
#   'precautionary',
#   'principle',
#   'putting',
#   'everyone',
#   'package',
#   'listen',
#   'first'],
#  ['try',
#   'remember',
#   'wave',
#   'wave',
#   'went',
#   'center',
#   'fact',
#   'daily',
#   'occurrence',
#   'week',
#   'week',
#   'pal',
#   'loud',
#   'negligible'],
#  ['great',
#   'prime_minister',
#   'not',
#   'ignorant',
#   'study',
#   'reality',
#   'science',
#   'data',
#   'say',
#   'mandate',
#   'path',
#   'minimal',
#   'hospitalization',
#   'path',
#   'quickly',
#   'ending',
#   'pandemic'],
#  ['regime',
#   'spokespeople',
#   'mom',
#   'keep',
#   'referring',
#   'anti',
#   'sentiment',
#   'protest',
#   'totally',
#   'clueless',
#   'trying',
#   'create',
#   'false',
#   'narrative',
#   'protest',
#   'reflect',
#   'anti',
#   'mandate',
#   'sentiment',
#   'must',
#   'know',
#   'since',
#   'ninety',
#   'trucker'],
#  ['difference',
#   'among',
#   'canadian',
#   'minuscule',
#   'across',
#   'political',
#   'spectrum',
#   'come',
#   'restriction',
#   'want',
#   'life',
#   'return_normal',
#   'goal',
#   'knew',
#   'would',
#   'never',
#   'get',
#   'stop',
#   'thinking',
#   'could',
#   'cannoli'],
#  ['ever',
#   'go',
#   'idaho',
#   'get',
#   'hug',
#   'wear_mask',
#   'show',
#   'card',
#   'wash_hands',
#   'cause',
#   'smart'],
#  ['record',
#   'false',
#   'get',
#   'idea',
#   'question',
#   'importance',
#   'like',
#   'typhoid',
#   'not',
#   'one',
#   'know',
#   'even',
#   'among',
#   'called',
#   'anti',
#   'several'],
#  ['ontario',
#   'superior',
#   'court',
#   'freeze',
#   'fund',
#   'raised',
#   'givesendgo',
#   'platform'],
#  ['not',
#   'anti_baxters',
#   'trying',
#   'keep',
#   'safe',
#   'untested',
#   'high',
#   'injury',
#   'majority',
#   'yell',
#   'staff',
#   'member',
#   'walk',
#   'take',
#   'business',
#   'elsewhere',
#   'stop',
#   'assuming',
#   'something',
#   'chosen',
#   'not',
#   'understand'],
#  ['whaf',
#   'anyone',
#   'anywhere',
#   'go',
#   'onto',
#   'twitter',
#   'feed',
#   'blame',
#   'whatever',
#   'want',
#   'proof',
#   'diagnosis',
#   'fact',
#   'exactly',
#   'wrong',
#   'many',
#   'believe',
#   'anything',
#   'long',
#   'fit',
#   'narrative'],
#  ['like',
#   'favor',
#   'especially',
#   'vulnerable',
#   'hope',
#   'discriminatory',
#   'tool',
#   'fuel',
#   'social',
#   'tension',
#   'longer',
#   'worth',
#   'anything',
#   'since',
#   'omicron',
#   'wave',
#   'present',
#   'pas',
#   'disappear',
#   'soon',
#   'possible'],
#  ['army', 'leaf', 'center', 'quebec', 'not', 'busy'],
#  ['time',
#   'drop',
#   'proof',
#   'inoculation',
#   'not',
#   'prevent',
#   'transmission',
#   'adopt',
#   'risk',
#   'based',
#   'approach',
#   'protect',
#   'vulnerable',
#   'wish',
#   'wear',
#   'mask',
#   'continue',
#   'allow',
#   'make',
#   'risk',
#   'assessment'],
#  ['caricature',
#   'misrepresent',
#   'thing',
#   'however',
#   'accustomed',
#   'much',
#   'finesse',
#   'subtlety',
#   'issue',
#   'passport',
#   'nothing',
#   'political',
#   'measure',
#   'well'],
#  ['realize',
#   'enacted',
#   'mandate',
#   'trucker',
#   'even',
#   'canada',
#   'lifted',
#   'mandate',
#   'still',
#   'able',
#   'enter'],
#  ['get',
#   'spread',
#   'nearly',
#   'often',
#   'get',
#   'really',
#   'sick',
#   'die',
#   'valid',
#   'reason',
#   'categorize',
#   'status',
#   'else'],
#  ['see',
#   'man',
#   'go',
#   'national',
#   'stage',
#   'representative',
#   'wink',
#   'bad',
#   'actor',
#   'young',
#   'said',
#   'let',
#   'really',
#   'clear',
#   'premier',
#   'not',
#   'trucker',
#   'mandate',
#   'premier',
#   'ego',
#   'cowardice'],
#  ['maryland',
#   'reported',
#   'lowest',
#   'infection',
#   'rate',
#   'country',
#   'today',
#   'mask',
#   'work'],
#  ['nineteen',
#   'key',
#   'health',
#   'requirement',
#   'indoor',
#   'public',
#   'activity',
#   'key',
#   'via'],
#  ['business',
#   'free',
#   'still',
#   'require',
#   'proof',
#   'taking',
#   'reader',
#   'away',
#   'business',
#   'verify',
#   'status',
#   'really',
#   'want',
#   'throw',
#   'wolf',
#   'poli',
#   'able',
#   'health'],
#  ['lol',
#   'majority',
#   'reason',
#   'stole',
#   'lost',
#   'true',
#   'conservative',
#   'supported',
#   'forced',
#   'strongly',
#   'work',
#   'clear',
#   'majority',
#   'canadian',
#   'mandate',
#   'forced',
#   'take',
#   'insane'],
#  ['saying',
#   'study',
#   'several',
#   'limitation',
#   'first',
#   'although',
#   'clinician',
#   'required',
#   'report',
#   'serious',
#   'adverse_events',
#   'nineteen',
#   'including',
#   'event',
#   'leading',
#   'hospitalization',
#   'veers',
#   'passive',
#   'reporting',
#   'system',
#   'veers',
#   'may',
#   'incomplete'],
#  ['child',
#   'organization',
#   'rely',
#   'like',
#   'girl',
#   'guide',
#   'required',
#   'check',
#   'status',
#   'truly',
#   'not',
#   'care',
#   'child'],
#  ['quack',
#   'outlier',
#   'every',
#   'profession',
#   'not',
#   'understanding',
#   'need',
#   'virologist',
#   'understand',
#   'tremendous',
#   'benefit',
#   'population',
#   'statistic',
#   'individual',
#   'not',
#   'understanding',
#   'want'],
#  ['guess',
#   'even',
#   'premature',
#   'elimination',
#   'proof',
#   'masking',
#   'satisfy',
#   'tamara',
#   'avoid',
#   'take',
#   'get',
#   'fan',
#   'club'],
#  ['doctor',
#   'outraged',
#   'doctor',
#   'honestly',
#   'discussing',
#   'sided',
#   'effect',
#   'etc',
#   'saying',
#   'would',
#   'stop',
#   'vaccinating',
#   'mostly',
#   'doctor',
#   'insisting',
#   'kid',
#   'need',
#   'using',
#   'language',
#   'anti',
#   'crusader'],
#  ['claim',
#   'family',
#   'sect',
#   'holy',
#   'spirit',
#   'near',
#   'juliette',
#   'brought',
#   'back',
#   'trip',
#   'notoriously',
#   'anti',
#   'live',
#   'world',
#   'literally',
#   'backyard',
#   'publicized',
#   'time',
#   'fact'],
#  ['mandate',
#   'business',
#   'either',
#   'require',
#   'mask',
#   'require',
#   'customer',
#   'show',
#   'proof',
#   'status',
#   'nice',
#   'always',
#   'show',
#   'proof',
#   'regardless',
#   'mask',
#   'mask',
#   'policy'],
#  ['article', 'state', 'confirmed', 'due', 'nineteen'],
#  ['point',
#   'train',
#   'airline',
#   'still',
#   'required',
#   'legally',
#   'review',
#   'proof',
#   'know',
#   'via',
#   'used',
#   'province',
#   'app',
#   'took',
#   'train',
#   'holiday'],
#  ['study',
#   'suggest',
#   'might',
#   'halve',
#   'risk',
#   'long',
#   'effect',
#   'brother',
#   'long',
#   'competitive',
#   'amateur',
#   'bicycle',
#   'barely',
#   'ride',
#   'succumbing',
#   'exhaustion'],
#  ['probably',
#   'cheaper',
#   'effective',
#   'bribe',
#   'get',
#   'least',
#   'state',
#   'lowest',
#   'rate',
#   'weirdly',
#   'never',
#   'heard',
#   'suggest',
#   'mandate',
#   'discussion',
#   'maybe',
#   'read',
#   'tweet',
#   'closely',
#   'enough',
#   'mention'],
#  ['please',
#   'wait',
#   'decent',
#   'supply',
#   'therapeutic',
#   'medication',
#   'state',
#   'wait',
#   'youngest',
#   'child',
#   'eligible',
#   'reverse',
#   'progress',
#   'maskshelp'],
#  ['tendentious',
#   'histrionics',
#   'hearing',
#   'along',
#   'australian',
#   'government',
#   'bad',
#   'actor',
#   'armageddon',
#   'argument',
#   'whether',
#   'able',
#   'use',
#   'trumped',
#   'excuse',
#   'avoid',
#   'requirement'],
#  ['hahahaha',
#   'constituent',
#   'access',
#   'free',
#   'holy',
#   'fuck',
#   'fault',
#   'chose',
#   'not',
#   'get',
#   'think',
#   'supporting',
#   'liberty',
#   'solely',
#   'political',
#   'point',
#   'touch',
#   'reality',
#   'thought',
#   'even',
#   'know',
#   'bio'],
#  ['showing',
#   'date',
#   'get',
#   'beer',
#   'creepy',
#   'anyway',
#   'license',
#   'show',
#   'full',
#   'name',
#   'home',
#   'address'],
#  ['massive', 'hit', 'say', 'curious', 'policy', 'employee', 'want', 'attend'],
#  ['throughout',
#   'pandemic',
#   'healthy',
#   'child',
#   'far',
#   'away',
#   'least',
#   'likely',
#   'die',
#   'seeing',
#   'unseated',
#   'premise',
#   'want',
#   'get',
#   'zero',
#   'death',
#   'regardless',
#   'status',
#   'not',
#   'sound',
#   'policy'],
#  ['yeah',
#   'not',
#   'mine',
#   'one',
#   'brain',
#   'trust',
#   'providing',
#   'ground',
#   'support',
#   'convoy',
#   'open',
#   'trudeau',
#   'jurisdiction',
#   'provincial',
#   'mandate',
#   'cross_border',
#   'policy',
#   'canada',
#   'take',
#   'civics',
#   'lesson',
#   'skippy'],
#  ['gov',
#   'mom',
#   'accomplished',
#   'goal',
#   'riddled',
#   'stress',
#   'ear',
#   'expecting',
#   'unrealistic',
#   'stay',
#   'need',
#   'learn',
#   'live',
#   'omicron',
#   'like',
#   'flu',
#   'take',
#   'precaution',
#   'old',
#   'compromised',
#   'life',
#   'fear',
#   'not',
#   'life'],
#  ['thanks', 'ge', 'going', 'soon', 'leaving', 'big', 'tip'],
#  ['yes',
#   'need',
#   'learn',
#   'live',
#   'eventually',
#   'mean',
#   'completely',
#   'dropping',
#   'restriction',
#   'especially',
#   'masking',
#   'aware',
#   'important',
#   'taken',
#   'every',
#   'know',
#   'man',
#   'applies',
#   'age_group',
#   'still',
#   'alive'],
#  ['report', 'oscar', 'require', 'negative', 'test', 'not', 'proof'],
#  ['age',
#   'bracket',
#   'rate',
#   'case',
#   'rate',
#   'graph',
#   'continues',
#   'fascinating'],
#  ['deliberately',
#   'used',
#   'propaganda',
#   'make',
#   'uneducated',
#   'believe',
#   'harmful',
#   'promoting',
#   'school',
#   'german',
#   'elite',
#   'eventually',
#   'actively',
#   'withheld',
#   'deemed',
#   'undesirable',
#   'asked'],
#  ['status', 'not', 'determine', 'intelligence'],
#  ['hi',
#   'hope',
#   'well',
#   'wondering',
#   'current',
#   'nineteen',
#   'rule',
#   'temporary',
#   'day',
#   'worker',
#   'visitor',
#   'respective',
#   'one',
#   'two'],
#  ['reporter',
#   'sophia',
#   'pulp',
#   'work',
#   'hard',
#   'email',
#   'discussing',
#   'reason',
#   'cac',
#   'redefinition',
#   'publicly',
#   'available',
#   'either',
#   'know',
#   'omitted',
#   'fact',
#   'check'],
#  ['varicose',
#   'application',
#   'used',
#   'quebec',
#   'show',
#   'proof',
#   'suddenly',
#   'longer',
#   'compatible',
#   'version',
#   'android',
#   'eight',
#   'one',
#   'super',
#   'practical',
#   'say'],
#  ['remove',
#   'encouragement',
#   'passport',
#   'would',
#   'le',
#   'intelligent',
#   'incentivized',
#   'better',
#   'plan',
#   'removing',
#   'rep',
#   'make',
#   'three',
#   'dose',
#   'requirement',
#   'stick',
#   'thing',
#   'moved',
#   'needle',
#   'two',
#   'yr',
#   'begging',
#   'work'],
#  ['net',
#   'fan',
#   'obviously',
#   'wish',
#   'kyrie',
#   'different',
#   'stance',
#   'topic',
#   'far',
#   'performing',
#   'completely',
#   'harmless',
#   'native',
#   'american',
#   'ritual',
#   'not',
#   'sure',
#   'anyone',
#   'put',
#   'negative',
#   'spin'],
#  ['yes',
#   'mandate',
#   'stand',
#   'corrected',
#   'however',
#   'city',
#   'van',
#   'mandate',
#   'still',
#   'stringent',
#   'usual',
#   'city',
#   'folk',
#   'still',
#   'burden',
#   'proof',
#   'required',
#   'indoor_dining',
#   'event',
#   'arena',
#   'gyms_theaters',
#   'museum',
#   'etc'],
#  ['bringing',
#   'history',
#   'crucial',
#   'explaining',
#   'black',
#   'concerned',
#   'context',
#   'tuskegee'],
#  ['center',
#   'nurse',
#   'retired',
#   'special',
#   'permit',
#   'unfit',
#   'work',
#   'hospital',
#   'not',
#   'let',
#   'see'],
#  ['described',
#   'flu',
#   'season',
#   'existence',
#   'voluntary',
#   'change',
#   'entire',
#   'argument',
#   'matter',
#   'much',
#   'deny',
#   'still',
#   'argument'],
#  ['please',
#   'update',
#   'policy',
#   'science',
#   'changed',
#   'recognizes',
#   'everyone',
#   'talking',
#   'long',
#   'time'],
#  ['proof', 'proof', 'felony'],
#  ['excited',
#   'expand',
#   'not',
#   'data',
#   'partnership',
#   'spartan',
#   'medical',
#   'help',
#   'business',
#   'school',
#   'keep',
#   'team',
#   'safe',
#   'nineteen',
#   'pandemic',
#   'expanded',
#   'testing',
#   'reporting',
#   'solution',
#   'include',
#   'tracking',
#   'status'],
#  ['way', 'miss', 'point', 'evidence', 'show', 'mass', 'never', 'eradicate'],
#  ['cac', 'eye'],
#  ['swear',
#   'fuck',
#   'anyone',
#   'compare',
#   'rape',
#   'deserves',
#   'launched',
#   'fucking',
#   'sun',
#   'also',
#   'deserve',
#   'go',
#   'end',
#   'triage',
#   'line',
#   'need',
#   'care'],
#  ['drop', 'conspiracy', 'violating', 'person', 'shot'],
#  ['looming_scandal',
#   'many',
#   'ifl_players',
#   'playing',
#   'fake',
#   'cards_mina',
#   'time',
#   'say',
#   'ifl_model',
#   'antonio_brown',
#   'fake',
#   'card_evander',
#   'kane_suspension',
#   'nil_found',
#   'guilty'],
#  ['respect',
#   'medical',
#   'evidence',
#   'show',
#   'mandatory',
#   'case',
#   'unjustifiable'],
#  ['much',
#   'ambiguity',
#   'mask',
#   'not',
#   'worth',
#   'dying',
#   'hill',
#   'need',
#   'focus',
#   'drug',
#   'therapy',
#   'query',
#   'recomendation',
#   'getting',
#   'three',
#   'year',
#   'approved',
#   'wait',
#   'efficacy',
#   'data',
#   'modern',
#   'higher',
#   'dose',
#   'answer',
#   'fda',
#   'requested',
#   'twentyfour'],
#  ['need',
#   'get',
#   'rid',
#   'passport',
#   'infection',
#   'rate',
#   'eighty',
#   'ninety',
#   'infection',
#   'mirror',
#   'rate',
#   'eighty',
#   'ninety',
#   'public',
#   'pass',
#   'mandate',
#   'discriminatory',
#   'let',
#   'open',
#   'ontario',
#   'everyone'],
#  ['end',
#   'feb',
#   'clock',
#   'get',
#   'dust',
#   'early',
#   'march',
#   'check',
#   'google',
#   'sunday',
#   'march',
#   'thirteen',
#   'end',
#   'march'],
#  ['useless', 'mask', 'experimental', 'talk', 'remedy'],
#  ['hardly',
#   'wedge',
#   'conservative',
#   'party',
#   'made',
#   'divisive',
#   'issue',
#   'outside',
#   'conservative',
#   'party',
#   'opinion',
#   'fairly',
#   'harmonious',
#   'siding',
#   'mask',
#   'neither',
#   'hardship'],
#  ['grateful',
#   'gov',
#   'look',
#   'multiple',
#   'data',
#   'point',
#   'case_counts',
#   'hospitalization',
#   'rate',
#   'availability',
#   'testing',
#   'availability',
#   'treatment',
#   'investment',
#   'healthcare',
#   'facility',
#   'make',
#   'decision',
#   'team',
#   'public',
#   'health',
#   'expert',
#   'leader'],
#  ['allowed',
#   'say',
#   'argument',
#   'child',
#   'passport',
#   'mention',
#   'think',
#   'effort',
#   'made',
#   'short',
#   'begin',
#   'see',
#   'nuance',
#   'plus'],
#  ['look', 'accurate', 'case', 'hospitalization', 'rate', 'plunging'],
#  ['hometown',
#   'still',
#   'red',
#   'zone',
#   'earth',
#   'anyone',
#   'justify',
#   'removing',
#   'restriction',
#   'mask',
#   'mandate',
#   'employer',
#   'requirement',
#   'community',
#   'still',
#   'red',
#   'hospital',
#   'still',
#   'schedule',
#   'medically',
#   'necessary',
#   'surgery'],
#  ['fake', 'card', 'fake', 'ghetto'],
#  ['not',
#   'stop',
#   'spreading',
#   'stop',
#   'getting',
#   'protecting',
#   'idea',
#   'posted',
#   'also',
#   'bad',
#   'lifestyle',
#   'choice',
#   'passed',
#   'kid',
#   'impact'],
#  ['not',
#   'taking',
#   'credit',
#   'taking',
#   'credit',
#   'getting',
#   'arm',
#   'american',
#   'remember'],
#  ['kudos', 'putting', 'requirement', 'place', 'pandemic', 'yet'],
#  ['couple',
#   'shady',
#   'global',
#   'forced',
#   'program',
#   'guise',
#   'benign',
#   'virus',
#   'already',
#   'dropping',
#   'dead',
#   'shortly',
#   'getting',
#   'jabbed',
#   'surely',
#   'come',
#   'long_term',
#   'also',
#   'woman',
#   'experiencing',
#   'menstrual',
#   'issue',
#   'miscarriage',
#   'piece',
#   'fit'],
#  ['course',
#   'directly',
#   'answer',
#   'question',
#   'would',
#   'imagine',
#   'answer',
#   'question',
#   'many',
#   'well',
#   'protected',
#   'complicated',
#   'betting',
#   'not',
#   'anywhere_near',
#   'large',
#   'set'],
#  ['comparing',
#   'something',
#   'like',
#   'status',
#   'choice',
#   'living',
#   'virus',
#   'taken',
#   'million',
#   'life',
#   'basically',
#   'wiped',
#   'entire',
#   'generation',
#   'not',
#   'comparable',
#   'whatsoever',
#   'said',
#   'pride',
#   'yam',
#   'committee',
#   'chair',
#   'michel',
#   'bower'],
#  ['rate', 'high', 'ontario', 'end', 'game', 'liberal'],
#  ['sorry',
#   'reading',
#   'last',
#   'tweet',
#   'time',
#   'see',
#   'understood',
#   'death',
#   'rate',
#   'rate',
#   'not',
#   'much',
#   'lower',
#   'serbia',
#   'rate',
#   'fifty'],
#  ['appears',
#   'la',
#   'heath',
#   'department',
#   'recently',
#   'changed',
#   'mandate',
#   'rule',
#   'business',
#   'require',
#   'mandate',
#   'not'],
#  ['thing',
#   'limited',
#   'personal_choice',
#   'rejecting',
#   'protect',
#   'vulnerable',
#   'society',
#   'bit',
#   'selfish',
#   'really',
#   'not',
#   'get',
#   'working',
#   'minimize',
#   'excessive',
#   'death',
#   'scientist',
#   'learn',
#   'new',
#   'virus'],
#  ['pair',
#   'high',
#   'local',
#   'rate',
#   'low',
#   'daily',
#   'case',
#   'hospitalization',
#   'risk',
#   'even',
#   'vulnerable',
#   'low',
#   'atm',
#   'new',
#   'variant',
#   'emerges',
#   'another',
#   'outbreak',
#   'mask',
#   'otherwise',
#   'tribal',
#   'badge',
#   'not',
#   'backed',
#   'science',
#   'ie',
#   'cac'],
#  ['fact',
#   'check',
#   'calling',
#   'redefinition',
#   'exact',
#   'copy',
#   'cac',
#   'website',
#   'misinformation',
#   'due',
#   'missing',
#   'context',
#   'ap',
#   'include',
#   'foil',
#   'email',
#   'show',
#   'cac',
#   'panic',
#   'need',
#   'redefine'],
#  ['thursday',
#   'ended',
#   'nevada',
#   'mask',
#   'mandate',
#   'effective',
#   'immediately',
#   'regardless',
#   'status',
#   'full',
#   'detail'],
#  ['booster',
#   'important',
#   'not',
#   'protect',
#   'around',
#   'vulnerable',
#   'still',
#   'jeopardy',
#   'nineteen',
#   'via'],
#  ['nonsense',
#   'shame',
#   'publish',
#   'type',
#   'article',
#   'ostracize',
#   'great',
#   'scientist',
#   'denounced',
#   'current',
#   'manipulation',
#   'ashamed',
#   'ultra',
#   'liberal',
#   'belgian',
#   'newspaper',
#   'published'],
#  ['nurse',
#   'claim',
#   'canadian',
#   'justin_trudeau',
#   'nineteen',
#   'faked',
#   'point',
#   'red_flag'],
#  ['harry',
#   'race',
#   'stated',
#   'continue',
#   'friday',
#   'clinic',
#   'start',
#   'new',
#   'time',
#   'noon',
#   'two',
#   'make',
#   'easier',
#   'kid',
#   'come',
#   'school',
#   'parent',
#   'every',
#   'friday',
#   'clinic',
#   'person',
#   'receiving',
#   'first',
#   'exciting',
#   'see',
#   'happen'],
#  ['issue',
#   'concerned',
#   'ego',
#   'rather',
#   'accuracy',
#   'data',
#   'name',
#   'single',
#   'virus',
#   'animal',
#   'reservoir',
#   'ever',
#   'eliminated',
#   'provide',
#   'source',
#   'claim',
#   'beyond',
#   'say',
#   'ism'],
#  ['said',
#   'discriminate',
#   'status',
#   'really',
#   'hate',
#   'fascist',
#   'terrorist',
#   'hate',
#   'group',
#   'posing',
#   'freedom_fighter'],
#  ['work',
#   'considerably',
#   'better',
#   'around',
#   'world',
#   'valued',
#   'not',
#   'developed',
#   'country',
#   'getting',
#   'global',
#   'needed',
#   'otherwise',
#   'endless',
#   'amount',
# ...
#   'intervention',
#   'misleading',
#   'parent',
#   'shot',
#   'safe',
#   'kid'],
#  ['since',
#   'schooled',
#   'hip',
#   'not',
#   'thought',
#   'whole',
#   'point',
#   'thing',
#   'violate',
#   'privacy',
#   'status'],
#  ['thing', 'may', 'keep', 'net', 'winning', 'east'],
#  ['not', 'sure', 'aware', 'look', 'new', 'job', 'require', 'wow', 'choice'],
#  ['mill',
#   'old',
#   'cac',
#   'relaxing',
#   'guideline',
#   'kyrie',
#   'coming',
#   'back',
#   'soon',
#   'healthy',
#   'kid',
#   'near',
#   'future',
#   'seth',
#   'well',
#   'decent',
#   'shooter',
#   'got',
#   'patty',
#   'mill',
#   'simmons',
#   'even',
#   'need',
#   'shoot',
#   'much',
#   'although',
#   'think',
#   'sit'],
#  ['partake',
#   'anything',
#   'today',
#   'modern',
#   'world',
#   'grow',
#   'food',
#   'make',
#   'clothing',
#   'never',
#   'life',
#   'never',
#   'visited',
#   'hospital',
#   'dentist'],
#  ['reminder',
#   'use',
#   'place',
#   'amazon',
#   'order',
#   'portion',
#   'spending',
#   'go',
#   'favorite',
#   'organization',
#   'planned',
#   'parenthood'],
#  ['japan', 'mandate'],
#  ['come',
#   'let',
#   'get',
#   'done',
#   'schedule',
#   'covidsummit',
#   'get',
#   'seventy',
#   'world',
#   'thank'],
#  ['agree', 'place', 'requiring', 'proof', 'folk', 'useful', 'information'],
#  ['cac',
#   'feasibly',
#   'sit',
#   'pal',
#   'patiently',
#   'explain',
#   'wane',
#   'efficacy',
#   'virus',
#   'reproduce',
#   'quickly',
#   'respond',
#   'adaptive',
#   'effort',
#   'mask',
#   'useful',
#   'tight',
#   'confined',
#   'space',
#   'not',
#   'competing',
#   'min',
#   'headline',
#   'space'],
#  ['lol',
#   'nothing',
#   'big_pharma',
#   'would',
#   'want',
#   'population',
#   'slowly',
#   'dying',
#   'sequela',
#   'let',
#   'rip',
#   'refused',
#   'cheaper',
#   'path',
#   'non',
#   'pharma',
#   'mitigation'],
#  ['not',
#   'sure',
#   'many',
#   'infected',
#   'recently',
#   'boiled',
#   'claim',
#   'twentyfive',
#   'population',
#   'number',
#   'new',
#   'case',
#   'remains',
#   'extremely',
#   'high',
#   'likely',
#   'continue',
#   'three',
#   'dose',
#   'rate',
#   'not',
#   'high'],
#  ['omicron',
#   'expand',
#   'quickly',
#   'population',
#   'le',
#   'thirty',
#   'population',
#   'population',
#   'broader',
#   'better',
#   'immunity',
#   'due',
#   'sixty',
#   'highly',
#   'vulnerable',
#   'bolstered',
#   'imperfect',
#   'van',
#   'slow_spread'],
#  ['seven',
#   'million',
#   'american',
#   'left',
#   'behind',
#   'nation',
#   'wobbly',
#   'effort',
#   'get',
#   'back_normal',
#   'weak',
#   'immune_system',
#   'simply',
#   'rev',
#   'fight',
#   'virus',
#   'like',
#   'healthy',
#   'one'],
#  ['real',
#   'world',
#   'evidence',
#   'slowing',
#   'surge',
#   'infection',
#   'surge',
#   'happened',
#   'regardless',
#   'rate',
#   'available',
#   'anyone',
#   'want',
#   'protection',
#   'applying',
#   'restriction',
#   'based',
#   'rate',
#   'science',
#   'based'],
#  ['thee', 'not', 'oscar', 'person', 'attendance', 'not', 'contingent_upon'],
#  ['nothing',
#   'nice',
#   'mandate',
#   'kept',
#   'requirement',
#   'month',
#   'not',
#   'sure',
#   'ditch'],
#  ['net',
#   'get',
#   'replenish',
#   'draft',
#   'pick',
#   'lost',
#   'trading',
#   'harden',
#   'think',
#   'probably',
#   'reverse',
#   'rule',
#   'sooner',
#   'later'],
#  ['event',
#   'attendee',
#   'must',
#   'show',
#   'proof',
#   'wear',
#   'mask',
#   'time',
#   'except',
#   'eating_drinking',
#   'follow',
#   'state',
#   'local',
#   'protocol',
#   'information',
#   'purchase',
#   'ticket',
#   'visit',
#   'bettzedek'],
#  ['also',
#   'changed',
#   'thought',
#   'around',
#   'mandate',
#   'fairly',
#   'recently',
#   'unsure',
#   'whether',
#   'mandate',
#   'effective',
#   'mandate',
#   'work',
#   'get',
#   'folk',
#   'enough',
#   'make',
#   'significant',
#   'difference',
#   'rate',
#   'know'],
#  ['know',
#   'prove',
#   'status',
#   'get',
#   'restaurant',
#   'prove',
#   'crack',
#   'addict',
#   'get',
#   'free',
#   'crackpipe'],
#  ['one',
#   'affect',
#   'infection',
#   'rate',
#   'two',
#   'child',
#   'affect',
#   'infection',
#   'rate',
#   'make',
#   'possible',
#   'survive',
#   'get',
#   'delta',
#   'child',
#   'suffering',
#   'business',
#   'corporation'],
#  ['yes',
#   'must',
#   'actively',
#   'protect',
#   'health',
#   'care',
#   'system',
#   'new',
#   'rule',
#   'eligible',
#   'opt',
#   'ordinary',
#   'not',
#   'allowed',
#   'opt',
#   'hospital',
#   'care',
#   'build',
#   'infrastructure',
#   'support',
#   'anthrax',
#   'community',
#   'healthinsurance',
#   'sound',
#   'like',
#   'screenplay'],
#  ['table', 'probably', 'proof', 'ridiculous'],
#  ['said',
#   'someone',
#   'earlier',
#   'mandate',
#   'vague',
#   'lot',
#   'mandate',
#   'not',
#   'released',
#   'right',
#   'away',
#   'even',
#   'cross_border',
#   'usa',
#   'mandate',
#   'land',
#   'crossing',
#   'agree',
#   'one',
#   'lose',
#   'job'],
#  ['progressive',
#   'spilled',
#   'billie',
#   'gifford',
#   'co',
#   'others',
#   'supporting',
#   'government',
#   'backed',
#   'coercion',
#   'using',
#   'product',
#   'could',
#   'advocated',
#   'without',
#   'losing',
#   'credibility',
#   'guess',
#   'know',
#   'progressive',
#   'really'],
#  ['would',
#   'certainly',
#   'surprise',
#   'one',
#   'three',
#   'place',
#   'rule',
#   'affecting',
#   'pro',
#   'athlete',
#   'also',
#   'talking',
#   'city',
#   'required',
#   'proof',
#   'negative_test',
#   'mask',
#   'wearing',
#   'sit',
#   'twenty',
#   'capacity',
#   'city',
#   'field',
#   'yankee',
#   'stadium',
#   'last',
#   'spring'],
#  ['dental',
#   'research',
#   'education',
#   'practice',
#   'community',
#   'serve',
#   'community',
#   'role',
#   'model',
#   'mitigate',
#   'scourge',
#   'nineteen',
#   'mandating'],
#  ['american', 'forced', 'border', 'wide', 'open', 'infected', 'migrant'],
#  ['ink',
#   'folk',
#   'keep',
#   'saying',
#   'big',
#   'three',
#   'brooklyn',
#   'big',
#   'one',
#   'five',
#   'half',
#   'kid',
#   'injury',
#   'half',
#   'kyrie',
#   'half',
#   'simmons',
#   'really',
#   'know',
#   'problem',
#   'philly',
#   'def',
#   'trade'],
#  ['article',
#   'barely',
#   'qualifies',
#   'ground',
#   'report',
#   'ignores',
#   'question',
#   'whether',
#   'connection',
#   'trucking',
#   'requirement',
#   'skewed',
#   'sample',
#   'trucker',
#   'also',
#   'immigrant',
#   'odd',
#   'focus',
#   'non',
#   'trucker',
#   'protestors'],
#  ['great',
#   'work',
#   'amazing',
#   'love',
#   'conclusion',
#   'individual',
#   'choice',
#   'hesitant',
#   'individual',
#   'substantial',
#   'impact',
#   'pandemic',
#   'trajectory'],
#  ['mandate', 'gone', 'stop', 'brooklyn', 'making', 'noise', 'blame', 'kyrie'],
#  ['common',
#   'collective',
#   'done',
#   'something',
#   'reasonable',
#   'suggest',
#   'others',
#   'follow_suit',
#   'simply',
#   'ground',
#   'promised',
#   'full',
#   'reopening',
#   'upon',
#   'mass',
#   'clearly',
#   'not',
#   'case',
#   'either'],
#  ['one',
#   'could',
#   'said',
#   'seriously',
#   'arrival',
#   'omicron',
#   'particular',
#   'ord',
#   'dose',
#   'data',
#   'proposed',
#   'recently'],
#  ['made',
#   'proof',
#   'requirement',
#   'register',
#   'event',
#   'close',
#   'venue',
#   'anyone',
#   'pre',
#   'registered'],
#  ['thread',
#   'show',
#   'country',
#   'denmark',
#   'canada',
#   'safely',
#   'lift',
#   'restriction',
#   'canada',
#   'higher',
#   'rate',
#   'denmark',
#   'also',
#   'test',
#   'everyone',
#   'admitted',
#   'hospital',
#   'situation',
#   'bad',
#   'think'],
#  ['sorry',
#   'nurse',
#   'iam',
#   'not',
#   'going',
#   'take',
#   'mask',
#   'yet',
#   'think',
#   'still',
#   'really',
#   'contagious',
#   'need',
#   'get',
#   'control',
#   'important'],
#  ['zoonotic',
#   'going',
#   'mutate',
#   'regardless',
#   'rate',
#   'ship',
#   'long',
#   'sailed',
#   'complication',
#   'healthy',
#   'low',
#   'risk',
#   'data',
#   'support',
#   'elderly',
#   'deserve',
#   'focused',
#   'protection',
#   'emphasis',
#   'focused'],
#  ['one',
#   'omicron',
#   'two',
#   'month',
#   'two',
#   'including',
#   'three',
#   'dos',
#   'month',
#   'three',
#   'data',
#   'short',
#   'news',
#   'could',
#   'never',
#   'written',
#   'fall',
#   'would',
#   'answer'],
#  ['get',
#   'prior',
#   'infection',
#   'protective',
#   'delta',
#   'surge',
#   'via',
#   'reuters',
#   'literally',
#   'reason',
#   'antagonize',
#   'someone',
#   'thier',
#   'medical',
#   'choice',
#   'especially',
#   'natural',
#   'herd_immunity',
#   'alternative',
#   'medicine'],
#  ['feeling',
#   'simmons',
#   'possibly',
#   'perfect',
#   'complement',
#   'kid',
#   'irving',
#   'net',
#   'one',
#   'away',
#   'contender'],
#  ['none',
#   'true',
#   'beginning',
#   'republican',
#   'refused',
#   'cooperate',
#   'virus',
#   'downplayed',
#   'virus',
#   'denied',
#   'existence',
#   'fought',
#   'mask',
#   'mandate',
#   'court',
#   'pushed',
#   'quack',
#   'remedy',
#   'disinformation'],
#  ['new',
#   'study',
#   'couple',
#   'nineteen',
#   'reduce_chances',
#   'conception',
#   'infection',
#   'sars_cov',
#   'two',
#   'associated',
#   'short_term',
#   'reduction',
#   'fertility',
#   'male',
#   'reinforcing',
#   'safety',
#   'couple',
#   'trying',
#   'conceive'],
#  ['pic',
#   'party',
#   'get',
#   'snack',
#   'getting',
#   'kevin',
#   'get',
#   'multiple',
#   'staff',
#   'switch'],
#  ['recognize', 'ploy', 'power', 'museum', 'require'],
#  ['well', 'transparent', 'even', 'though', 'called', 'saying', 'past', 'year'],
#  ['pok', 'pushing', 'mandatory', 'cab', 'pok', 'anti_var'],
#  ['rule', 'change', 'playoff'],
#  ['show', 'proof', 'get', 'free', 'crack_pipe', 'asking', 'friend'],
#  ['net',
#   'built',
#   'team',
#   'kyrie_irving',
#   'bro',
#   'let',
#   'ruin',
#   'season',
#   'kid',
#   'commission',
#   'moment',
#   'current',
#   'extended',
#   'losing',
#   'streak',
#   'despite',
#   'kyrie',
#   'return',
#   'wonder',
#   'harden',
#   'wanted'],
#  ['fema',
#   'receive',
#   'booster',
#   'shot',
#   'may',
#   'side_effect',
#   'like',
#   'felt',
#   'nineteen',
#   'primary_series',
#   'side_effect',
#   'normal',
#   'sign',
#   'body',
#   'building',
#   'protection',
#   'nineteen',
#   'mo'],
#  ['got',
#   'better',
#   'team',
#   'nod',
#   'one',
#   'simple',
#   'thing',
#   'kyrie',
#   'status',
#   'playoff',
#   'could',
#   'potentially',
#   'turn',
#   'series',
#   'play',
#   'home_game',
#   'ben',
#   'score',
#   'could',
#   'cripple',
#   'net',
#   'fully',
#   'healthy',
#   'eye'],
#  ['sure',
#   'reciprocal',
#   'agreement',
#   'usa',
#   'would',
#   'happen',
#   'truck',
#   'cross_border',
#   'south',
#   'without',
#   'proof',
#   'american',
#   'trucker',
#   'could',
#   'cross_border'],
#  ['let',
#   'hope',
#   'democrat',
#   'city',
#   'providence',
#   'employee',
#   'not',
#   'compliant',
#   'policy',
#   'march',
#   'subject',
#   'suspension',
#   'ri',
#   'rhodeisland',
#   'tripoli',
#   'rhodyreport'],
#  ['smithsonian',
#   'require',
#   'plenty',
#   'eating',
#   'establishment',
#   'either',
#   'really',
#   'going',
#   'superintendent',
#   'call',
#   'spine',
#   'truth'],
#  ['know',
#   'entire',
#   'protest',
#   'started',
#   'trucker',
#   'trudeau',
#   'border',
#   'mandate',
#   'well',
#   'air',
#   'train',
#   'travel',
#   'restriction',
#   'nationally',
#   'internationally',
#   'right'],
#  ['shit',
#   'sherlock',
#   'high',
#   'rate',
#   'case',
#   'however',
#   'hospitalization',
#   'death',
#   'overwhelmingly',
#   'work'],
#  ['careless', 'take', 'long_term', 'study', 'low', 'dolt', 'bro'],
#  ['anyone',
#   'else',
#   'think',
#   'represents',
#   'rate',
#   'think',
#   'strong',
#   'correlation',
#   'political',
#   'map'],
#  ['term',
#   'handling',
#   'well',
#   'could',
#   'lot',
#   'worse',
#   'keeping',
#   'restriction',
#   'going',
#   'even',
#   'past',
#   'campaign',
#   'death',
#   'even',
#   'worse',
#   'conservative',
#   'senior',
#   'refuse',
#   'get',
#   'bonkers',
#   'fucking',
#   'bonkers'],
#  ['help',
#   'survey',
#   'seek',
#   'obtain',
#   'opinion',
#   'active',
#   'em',
#   'provider',
#   'topic',
#   'mandate',
#   'take',
#   'survey'],
#  ['two',
#   'point',
#   'harden',
#   'simmons',
#   'deal',
#   'one',
#   'simmons',
#   'never',
#   'playing',
#   'fact',
#   'trade',
#   'zero',
#   'asset',
#   'someone',
#   'like',
#   'harden',
#   'massive',
#   'win',
#   'two',
#   'guess',
#   'certain',
#   'mandate',
#   'lifted',
#   'reasonable',
#   'chance',
#   'requirement'],
#  ['blocked',
#   'employment',
#   'requirement',
#   'eight',
#   'job',
#   'far',
#   'field',
#   'shot',
#   'give',
#   'right',
#   'american',
#   'citizen',
#   'employment',
#   'freedom',
#   'endthemandates'],
#  ['not',
#   'assumption',
#   'straw_man',
#   'relatively',
#   'safer',
#   'huge',
#   'important',
#   'distinction',
#   'risk',
#   'benefit',
#   'analyzes',
#   'favor',
#   'virtually',
#   'everyone'],
#  ['difference',
#   'abandoning',
#   'prevention',
#   'mitigating',
#   'harm',
#   'moment',
#   'given',
#   'rate',
#   'removing',
#   'mask',
#   'mandate',
#   'ill',
#   'advised',
#   'course',
#   'outlaw',
#   'driving',
#   'also',
#   'abandon',
#   'safety',
#   'measure',
#   'make',
#   'safer'],
#  ['applies',
#   'dramatically',
#   'exaggerated',
#   'outright',
#   'fabricated',
#   'benefit',
#   'minimizing',
#   'risk',
#   'point',
#   'compulsory',
#   'ordered',
#   'state',
#   'long',
#   'run',
#   'far',
#   'greater',
#   'threat',
#   'civilization',
#   'virus'],
#  ['soon',
#   'dentist',
#   'joke',
#   'start',
#   'flocking',
#   'protest',
#   'mandatory',
#   'dentist'],
#  ['mean',
#   'yeah',
#   'ever',
#   'effective',
#   'say',
#   'strengthen',
#   'immune_system',
#   'false',
#   'advocating',
#   'general'],
#  ['teacher',
#   'parent',
#   'student',
#   'terrorized',
#   'anti',
#   'mask',
#   'anti',
#   'covidiots',
#   'charter_rights',
#   'freedom',
#   'cannot',
#   'make',
#   'terrified',
#   'go',
#   'unhappy',
#   'hope',
#   'every',
#   'single',
#   'one',
#   'get',
#   'arrested'],
#  ['toronto_star',
#   'running',
#   'poll',
#   'far',
#   'passport',
#   'system',
#   'please',
#   'vote'],
#  ['hello',
#   'quick',
#   'question',
#   'international',
#   'visitor',
#   'cac',
#   'nineteen',
#   'record',
#   'approved',
#   'gov',
#   'work',
#   'proof',
#   'entering',
#   'royal',
#   'thanks'],
#  ['committed',
#   'helping',
#   'stay',
#   'safe',
#   'help',
#   'saturday',
#   'hosting',
#   'another',
#   'free',
#   'clinic'],
#  ['arguably',
#   'post',
#   'infection',
#   'immunity',
#   'communicate',
#   'relevant',
#   'idea',
#   'immunity',
#   'made',
#   'possible',
#   'without',
#   'intervention',
#   'technically',
#   'term',
#   'post',
#   'infection',
#   'immunity',
#   'could',
#   'likewise',
#   'applied',
#   'since',
#   'also',
#   'achieved',
#   'infection'],
#  ['voting',
#   'killed',
#   'many',
#   'congressman',
#   'side',
#   'seem',
#   'understand',
#   'analogy',
#   'work',
#   'better',
#   'one',
#   'follows',
#   'actual',
#   'logic',
#   'mandating',
#   'show',
#   'card',
#   'eat',
#   'not',
#   'id',
#   'gun',
#   'touch',
#   'blah_blah'],
#  ['paula',
#   'newton',
#   'reported',
#   'change',
#   'requirement',
#   'cross',
#   'canada',
#   'border',
#   'month',
#   'ago',
#   'got',
#   'detail',
#   'completely',
#   'wrong',
#   'rounded',
#   'canadian',
#   'number',
#   'compared',
#   'like',
#   'meaningful'],
#  ['pattern',
#   'got',
#   'long',
#   'symptom',
#   'looked',
#   'please',
#   'eight',
#   'month',
#   'hell',
#   'post',
#   'one',
#   'desperate',
#   'answer',
#   'thanks'],
#  ['substantially',
#   'free',
#   'virus',
#   'current',
#   'rate',
#   'ninety',
#   'van',
#   'think',
#   'adding',
#   'rest',
#   'anything'],
#  ['particularly',
#   'reached',
#   'announced',
#   'milestone',
#   'expert',
#   'move',
#   'goalpost',
#   'one',
#   'occasion'],
#  ['hit', 'de', 'selling', 'card'],
#  ['want',
#   'total',
#   'control',
#   'get',
#   'jab',
#   'booster',
#   'follow',
#   'favorite',
#   'lockdown',
#   'land',
#   'free',
#   'anymore',
#   'show',
#   'status',
#   'enter'],
#  ['passport',
#   'never',
#   'not',
#   'never',
#   'required',
#   'grocery_store',
#   'pharmacy',
#   'clinic'],
#  ['say',
#   'let',
#   'everyone',
#   'experience',
#   'something',
#   'like',
#   'least',
#   'like',
#   'future',
#   'terrible',
#   'decision'],
#  ['bro',
#   'support',
#   'mandate',
#   'elin',
#   'issue',
#   'trudeau',
#   'rate',
#   'reaching',
#   'ninety',
#   'mandate',
#   'provincial',
#   'mostly',
#   'loud',
#   'bubble',
#   'add',
#   'support',
#   'international',
#   'troll',
#   'corrupt',
#   'president',
#   'state',
#   'gov',
#   'house',
#   'member',
#   'support',
#   'not',
#   'count'],
#  ['going',
#   'problem',
#   'think',
#   'nearest',
#   'major',
#   'bus',
#   'station',
#   'new_york',
#   'state',
#   'required',
#   'rail',
#   'passenger'],
#  ['force',
#   'work',
#   'someone',
#   'mandate',
#   'still',
#   'choice',
#   'not',
#   'good',
#   'comparison'],
#  ['summit',
#   'reiterated',
#   'commitment',
#   'continue',
#   'working',
#   'together',
#   'offering',
#   'support',
#   'ignite',
#   'four',
#   'engine',
#   'recovery',
#   'financial',
#   'system',
#   'recovery',
#   'read'],
#  ['anti',
#   'goofy',
#   'fuck',
#   'socialist',
#   'bloc',
#   'country',
#   'among',
#   'one',
#   'producing',
#   'world',
#   'distributing',
#   'highest',
#   'rate',
#   'not',
#   'reason',
#   'oppose',
#   'ignore',
#   'nazi',
#   'rally',
#   'goofy'],
#  ['kendrick',
#   'perkins',
#   'assumption',
#   'everybody',
#   'want',
#   'brooklyn',
#   'kyrie',
#   'anti',
#   'antic',
#   'mean',
#   'put',
#   'past',
#   'lol'],
#  ...]

# %%
df['words_processed_all'].values[0][0]
# Out:
# 'want'

# %%
df['tokenised_stopremoved'] = tokenised_stopremoved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315603 entries, 0 to 315602
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   new_text_after_translation         315603 non-null  object
#  1   words_processed_all                315603 non-null  object
#  2   words_processed_noun_adj_verb_adv  315603 non-null  object
#  3   words_processed_noun               315603 non-null  object
#  4   text_type                          315603 non-null  object
#  5   sentiment                          315603 non-null  int64
#  6   tokenised_stopremoved              315603 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 16.9+ MB

# %%
df['sentiment'].value_counts()
# Out:
# 2    222780
# 0     92823
# Name: sentiment, dtype: int64

# %%
positive_df = df[df['sentiment'] == 2]

# %%
positive_df
# Out:
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# 5       it could have ripped… harder or do you think m...
# 6       they do this at vaccination centres as well. t...
# ...                                                   ...
# 315597  contrary american belief, vaccine is not perso...
# 315598  pretty remarkable achievement. thank you all v...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                       words_processed_all  \
# 0       [want, find, way, end, racism, try, force, peo...
# 3       [would, expect, case, rise, significantly, cou...
# 4       [depends, whether, vaccination, status, embedd...
# 5       [could, ripped, harder, think, masking, isolat...
# 6       [vaccination, center, well, refused, let, amp,...
# ...                                                   ...
# 315597  [contrary, american, belief, vaccine, not, per...
# 315598  [pretty, remarkable, achievement, thank, volun...
# 315600                                           [others]
# 315601  [yay, congrats, fully, vaccinated, best, feeli...
# 315602  [part, end, pandemic, get, vaccine, try, help,...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# 5       ['could', 'rip', 'hard', 'think', 'mask', 'iso...
# 6       ['vaccination', 'center', 'well', 'refuse', 'l...
# ...                                                   ...
# 315597  ['contrary', 'vaccine', 'personal', 'choice', ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# 5       ['isolation', 'question', 'look', 'spike', 'ma...  subjective
# 6       ['vaccination', 'center', 'parent', 'mask', 'a...  subjective
# ...                                                   ...         ...
# 315597  ['vaccine', 'choice', 'people', 'risk', 'vacci...  subjective
# 315598  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 315600                      ['other', 'vaccinesaveslive']  subjective
# 315601  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 315602  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment                              tokenised_stopremoved
# 0               2  [want, find, way, end, racism, try, force, inj...
# 3               2  [would, expect, case, rise, significantly, cou...
# 4               2  [depends, whether, status, embedded, code, cod...
# 5               2  [could, ripped, harder, think, masking, isolat...
# 6               2  [center, well, refused, let, elderly, parent, ...
# ...           ...                                                ...
# 315597          2  [contrary, american, belief, not, personal, ch...
# 315598          2  [pretty, remarkable, achievement, thank, volun...
# 315600          2                                           [others]
# 315601          2  [yay, congrats, fully, best, feeling, safetyfi...
# 315602          2  [part, end, pandemic, get, try, help, others, ...
#
# [222780 rows x 7 columns]

# %%
texts = positive_df['words_processed_all']

# %%
new_text_all = []

for row in texts:
    # print(type(row))
    new_row = " ".join(row)
    new_text_all.append(new_row)

# %%
new_text_all
# Out:
# ['want find way end racism try force people inject see bunch people race standing forced vaccination not people need amp support people getting shot draw_line force',
#  'would expect case rise significantly course vaccination rate come play space adult not usually confined single space many people school age student data state lifted not bear',
#  'depends whether vaccination status embedded code code link connects back end read released remember see find',
#  'could ripped harder think masking isolation etc ultimately impact honest question look spike think maybe would looked matter vaccination thing definitively worked',
#  'vaccination center well refused let amp elderly parent wear not mask lady rude amp said could couid nineteen amp could mask refused amp not take answer said begrudgingly absurd',
#  'part vanguard vaccination awareness project series free tool help suite leader combat vaccine hesitancy resistance podcasts video article available',
#  'correct not vaccine stated goal vaccination breaking blogger report factual news accident not vaccine least know read positive step towards competence',
#  'vaccination still need proof vaccination restaurant movie_theater museum large arena fitness center bow vaccination rate three three',
#  'following tweet even age twelve hour prince charles announced infection even vaccination amp booster yes clearly previous infection protects point boris johnson exude sort hypnotoad like pheromone something',
#  'one understand exactly need understood lame link two even remains lame vaccination compulsory come back bawl bye',
#  'world top virologist luc_montagnier winner nobel_prize discovery hiv died today warned beginning couid nineteen lab made mass vaccination leaky vaccine would generate endless new variant right count rip',
#  'obvious common_sense solution always take free safe vaccination deadly virus carry business like non lunatic',
#  'sure tooting remember grew jackson mi least place long associated familiar conservative mien mindset amp speak think plain language think couid mandatory vaccination',
#  'variant involved vaccination masking ventilation around kid time meaningless say kid danger unless mean say kid not not ever danger matter',
#  'last looked actually hit county vaccination threshold difference mah cac data bet secondary school though',
#  'vision public health decision tied local condition spread vaccination amp vulnerability also sound reasonable however two year acting happening naive best partisan politics even local level often big factor',
#  'mean someone told kill get vaccinated understand thought said vaccination lose bodily_autonomy',
#  'concern real even unfounded addressing empathy genuine good persuade canada similar level adult vaccination usa',
#  'seems like steel man many mandate mask vaccination testing etc much still place relatively low cost not zero cost',
#  'kill sally field',
#  'five government primary concern justification compulsory couid vaccination prevent hospital icu emergency depth inundated thus running medical resource bed space equipment staff perhaps govt require hospital',
#  'two couid vaccine proven not prevent spread couid even esp omicron called became positive couid case omicron care vaccine status real driving force vaccination become minimizing',
#  'think eighty game never full anyway meant download_app get green_light based vaccination status allow enter stadium not ground unsure enforce much',
#  'medical specialist involved vaccination effort',
#  'nothing report document trump took gave back bullshit happened january let close border let end mask vaccination mandate seriously people',
#  'never suggested vaccination issue one way',
#  'trump arrested yet look like laughingstock rest world still also terrified trucker not coming vaccination mandate coming big lie perceived reinstatement tag',
#  'school not gonna ask vaccination proof respect individuality health decision everyone choice stay virtually lol hate',
#  'indian health department sorry trust people look like think israel ninety vaccination rate hard time couid right',
#  'employer mask mandatory vaccination policy even provincial federal government remove mandate employer still mask mandatory vaccination policy cannoli_poli',
#  'demystify vaccination provided master subject let go',
#  'sound like planning masking kid indefinitely bus hospitalization rate vaccination rate etc deeming necessary finally let kid finally get back normalcy need number',
#  'not delusional endemic going live not vaccination lockdown mask couid still live fear get taking precaution necessary based age health condition',
#  'tool surgeon_general refuse disclose couid nineteen vaccination status',
#  'thank keeping mask mandate school need get vaccination rate education outreach get student sibling five vaccinated lifting mask mandate',
#  'according vaccination abortion thing welcome',
#  'care explain mental_health anything vaccine not talking person may feel one way talking genuine mental_health issue due vaccination not exist',
#  'time well done everyone faught proud revoking vaccination across health social care',
#  'make american think right challenge sovereign nation rule regarding vaccination testing problem creation putting self need country vaccineswork canada',
#  'member public health professional submit suspected side_effect yellow card scheme nature yellow card reporting mean reported event not always proven side_effect event may happened anyway regardless vaccination',
#  'truly feel mentally unstable head concerning answer time time ninety vaccination',
#  'justified frustrated people get vaccine job fair require vaccination remain employed really going try starve',
#  'adopted recommendation make health care worker vaccination condition medicare medicaid fund scout upheld rule important patient safety',
#  'yes prevention long_term involves vaccination mask reduce speaks either vaccination mask let get real not going beat couid new flu two flu shot year going forward difference virus higher kill rate',
#  'seems way reasonable yield far positive result rescinding vaccination mandate letting people make decision',
#  'come one come altar valencia los_angeles free produce testing vaccination',
#  'absurd please take look mirror man fellow conservative expressly supporting blockade not main culprit inflamed rhetoric calling vaccination respect public health order',
#  'fan receive est booster dose couid vaccine super_bowl experience receive free ticket enter experience day future date sure visit vaccination site south hall see solve',
#  'physical vaccination card gross digital thanks',
#  'myocarditis foundation website known potential benefit couid nineteen vaccination outweigh known potential risk including possible risk',
#  'ability always free restriction vaccination supposed point mandate trust broken closed business jan may able go restaurant guarantee april',
#  'couid vaccination not prevent spread stop disinformation',
#  'rig thick yogurt like substance feel vaccination clearly tell apart normal rabies jab got bitten forgot administer must really rabies vaccine effective post trauma',
#  'proof vaccination get lifted elderly forced isolate protect',
#  'agreed suspect higher uptake part honored recovery individual adjusted vaccination recommendation result',
#  'fair parent set much mass vaccination infrastructure grownup got valued easy hell barely twenty_minutes including fifteen min observation kid second dose two hour waiting damp cold',
#  'would pay list nominee would blacklisted oscar academy blinked vaccination requirement imagine meltdown twitter would wag weighted much liked movie based shot god',
#  'government offer free vaccine help boost immune_system place mostly private business not government mandate need show proof vaccination negative_test feel like oppression',
#  'care people say personally fact possibly care le anyone care shown exactly amp think pal simply agree forced vaccination care',
#  'wish everyone vaccinated mandatory vaccination measure based science',
#  'love see mental gymnastics perform argue protesting vaccination akin protesting police brutality minority',
#  'see put defundcbc defundbbc unfortunately pal behind vaccination extravaganza pal funding news network sayin totally though fund coming baddie',
#  'super immunity fake get couid time row fact therapist couid two three time row vaccination le health risk getting couid going kill people due attacking proven technology',
#  'yup still mask social_distance vaccination booster yeah smart',
#  'mandate help increase vaccination rate prevent future restriction appreciate overall tone thread disagree mandate not done attempt coerce producing elsewhere accept non_compliance',
#  'paper state free floating spike_proteins circulate high level blood vaccination vaccinated people infected variant couid produce antibody biased toward original extinct variant rather one actually infected',
#  'sound like might asking immigration related question qualified answer sorry asking meet health safety requirement long wear_mask provide vaccination record gov id yes',
#  'say incorrect terrorist causing issue closure supply_chain issue restriction vaccination way put period',
#  'not extended pre vaccine isolation think know need fentanyl death oneself loved_one cause far psychological stress wear damn mask show proof vaccination big baby',
#  'would triple vaccinated person living county vaccination rate mask',
#  'dye half adult hospitalized flu heart disease flu vaccination especially important people heart disease higher risk serious flu complication protect rightful heartmonth',
#  'enforced like parking ticket spot check bylaw officer protecting business check vaccination includes ord shot etc',
#  'hope receiving treatment problem immunity system like people many vaccination case weakened check report israel',
#  'eighty ninety vaccinated respectively not mean pro mandate vaccination mask etc included understand vaccine highly beneficial almost give right deprive anyone right',
#  'thing heard today person put leave question need booster side_effect first two dos couid recovered person losing client contract wish wait consider vaccination health concern',
#  'human_right commission maybe time health right commission discrimination wrong whether based color sex religion etc universal health system discriminate anyone vaccination injection',
#  'support right turn vaccination saying make sense like saying choice get evicted want pay rent',
#  'member band still alive tell think vaccination wait minute',
#  'two million quebecers caught couid since december four million since march one three million non van vaccination solution reduce contagion',
#  'question enter first place given requires proof vaccination entry',
#  'gov made intention known tues announced dramatic drop couid case not county vaccination rate stop state interference county education four died yesterday twelve',
#  'live mercer county ohio vaccination rate even forty percent continue avoiding indoor_spaces masking running errand took early early retirement hubby retired several year refuse play long want',
#  'gotta love fact taking away business option continue check vaccination status want thought choice choice not get vaccinated choice allow business poli',
#  'look bright side fiorellas fan feel vaccination able ratio much longer',
#  'tie van rate masking definition fully van includes booster know immunity wane not infection also wane severe_disease hospitalization amp death tie masking policy two dose vaccination',
#  'memory holed analysis every state elderly prioritized vaccination people access vaccine month',
#  'nothing like election provide accurate definition fully vad unless tourist mandate vaccination aged care time',
#  'everything public health everybody masking better ventilation vaccination reduces amount virus air chance infected ugh sorry amanda hope dad',
#  'tucson electric power state regulated utility say plan mandate vaccination testing beyond current workplace safety protocol',
#  'luc_montagnier clear new variant created antibody mediated selection ade due vaccination put yesterday rip montagnier',
#  'girl selling card facebook week later realized mean vaccination card not valentine card',
#  'vaccination pas not simple vaccination card present traveling comparison not hold water forget context creation forget role play get legal punitive strategy forget social impact',
#  'acc hosting block party right neighborhood vaccination clinic health screening resource various vendor music free food fun come february see flyer info',
#  'almost certainly huge risk reduction considering much vaccination cut time virus circulates body produce elongated immune_response immuno naive people develop antibody one three week virus enters body',
#  'might know le know topic believe anti vaccination republican supporter',
#  'free couid nineteen vaccination event friday mountlake terrace',
#  'got proof recovery cool today bow actually incredibly lucky timing wise since vaccination pas running next month good november',
#  'nine vaccination jab nov jan shingle two pneumonia one modern three influenza two trap one even alive',
#  'attending super_bowl party weekend matter root vaccination staying_home sick mask key defensive play taking care matter let tackle together',
#  'sure gop introducing bill get rid mandate vaccine public elementary school free poor kid rich send kid private school strict vaccination requirement',
#  'anticipate cell based scheme classify subject based vaccination amp natural infection history important tool longitudinal monitoring vaccination amp establishing sars_cov two correlate protection',
#  'not opponent vaccination distrust current vaccine new product not stood test time apply precautionary principle putting everyone package listen people first',
#  'try remember wave wave people went vaccination center amp fact daily occurrence week week pal loud negligible',
#  'great prime_minister not ignorant study reality science data say vaccination mandate path minimal hospitalization path quickly ending pandemic',
#  'difference among canadian minuscule across political spectrum come restriction want life return_normal goal vaccination amp knew would never get stop thinking could cannoli',
#  'ever go idaho get hug wear_mask show vaccination card wash_hands cause smart people',
#  'vaccinated like favor vaccination especially vulnerable people hope discriminatory tool fuel social tension longer worth anything since omicron wave present pas disappear soon possible',
#  'time drop proof vaccination inoculation not prevent transmission adopt risk based approach protect vulnerable wish wear mask continue allow people make risk assessment',
#  'realize enacted vaccination mandate trucker even canada lifted mandate still able enter',
#  'see man go national stage representative wink bad actor young said let really clear premier not trucker vaccination mandate premier ego cowardice',
#  'couid nineteen vaccine key health vaccination requirement indoor public activity key via',
#  'business free still require proof vaccination taking reader away business verify vaccination status really want throw wolf poli able health',
#  'lol majority reason stole lost true conservative supported forced vaccination strongly work clear majority canadian mandate forced take insane',
#  'saying study several limitation first although clinician required report serious adverse_events couid nineteen vaccination including event leading hospitalization veers passive reporting system veers may incomplete',
#  'child organization rely like girl guide required check vaccination status people truly not care child',
#  'guess even premature elimination proof vaccination amp masking satisfy tamara avoid take get fan club',
#  'claim family sect holy spirit near juliette brought back trip notoriously anti vaccination live world literally backyard publicized time fact',
#  'no mandate business either require mask require customer show proof vaccination status nice always show proof vaccination regardless mask mask policy',
#  'point train airline still required legally review proof vaccination know via used province app took train holiday',
#  'please wait decent supply therapeutic medication state wait youngest child eligible vaccination reverse progress maskshelp',
#  'hahahaha constituent access free vaccination holy fuck fault chose not get think supporting liberty solely political point touch reality thought even know bio',
#  'showing vaccination date get beer creepy anyway license show full name home address',
#  'couid massive hit say curious vaccination policy employee want attend',
#  'throughout pandemic healthy child far away least likely die couid seeing unseated premise want get zero couid death regardless vaccination status not sound policy',
#  'yeah not mine one brain trust providing ground support convoy open trudeau jurisdiction provincial mandate cross_border vaccination policy canada take civics lesson skippy',
#  'gov mom accomplished goal riddled stress ear expecting vaccination unrealistic couid stay need learn live omicron like flu take precaution old compromised life fear not life',
#  'thanks ge going soon leaving big tip',
#  'yes need learn live eventually mean completely dropping restriction especially masking vaccination aware important taken every vaccine know man applies age_group still alive',
#  'report oscar require negative couid test not vaccination proof',
#  'deliberately used propaganda make uneducated believe vaccine harmful promoting vaccination school german elite eventually actively withheld vaccine deemed undesirable asked',
#  'hi hope well wondering current couid nineteen vaccination amp rule temporary day worker visitor respective one two',
#  'reporter sophia pulp work hard email discussing reason cac redefinition vaccination publicly available either know omitted fact check',
#  'varicose application used quebec show proof vaccination suddenly longer compatible version android eight one super practical say',
#  'remove encouragement vaccination passport would le intelligent incentivized better plan removing rep make three dose requirement stick thing moved needle two yr begging work',
#  'net fan obviously wish kyrie different stance vaccination topic far performing completely harmless native american ritual not sure anyone put negative spin',
#  'yes mandate stand corrected however city van mandate still stringent vaccinated usual city folk still burden proof vaccination required indoor_dining event arena gyms_theaters museum etc',
#  'bringing history crucial explaining black people concerned context tuskegee vaccination',
#  'described flu season existence voluntary vaccination change entire argument matter much deny still argument',
#  'please update vaccination policy science changed recognizes everyone talking long time',
#  'excited expand not data partnership spartan medical help business school keep team safe couid nineteen pandemic expanded testing reporting solution include tracking vaccination status',
#  'swear fuck anyone compare vaccination rape deserves launched fucking sun also deserve go end triage line need care',
#  'looming_scandal many ifl_players playing fake vaccination cards_mina time say ifl_model antonio_brown fake vaccine card_evander kane_suspension nil_found guilty',
#  'much ambiguity mask not worth dying hill need focus vaccination drug therapy couid query recomendation getting three year pfizer vaccine approved wait efficacy data modern higher dose vaccine answer fda requested twentyfour',
#  'need get rid vaccine passport infection rate eighty ninety infection vaccinated mirror vaccination rate eighty ninety public vaccinated pass mandate discriminatory let open ontario everyone',
#  'useless mask amp experimental vaccination talk remedy',
#  'hardly wedge conservative party made divisive issue outside conservative party opinion fairly harmonious siding vaccination mask neither hardship',
#  'grateful gov look multiple data point case_counts hospitalization vaccination rate availability testing availability treatment investment healthcare facility make decision team public health expert leader',
#  'hometown still red zone earth anyone justify removing restriction mask mandate employer vaccination requirement community still red hospital still schedule medically necessary surgery',
#  'fake vaccination card fake ghetto',
#  'kudos putting vaccination requirement place pandemic yet',
#  'couple shady global forced vaccination program guise benign virus people already dropping dead shortly getting jabbed surely come long_term also woman experiencing menstrual issue miscarriage piece fit',
#  'course directly answer vaccination question would imagine answer question many people well protected vaccine complicated betting not anywhere_near large set people',
#  'comparing something like vaccination status choice people living virus taken million life basically wiped entire generation not comparable whatsoever said pride yam committee chair michel bower',
#  'thing limited personal_choice rejecting vaccination protect vulnerable society bit selfish really not get vaccine working minimize excessive death scientist learn new virus',
#  'thursday ended nevada mask mandate effective immediately regardless vaccination status full detail',
#  'couid vaccination amp booster important not protect around vulnerable still jeopardy couid nineteen via',
#  'nonsense shame publish type article ostracize great scientist denounced current manipulation vaccination ashamed ultra liberal belgian newspaper published',
#  'nurse claim canadian justin_trudeau couid nineteen vaccination faked point red_flag',
#  'harry race stated continue friday vaccine clinic start new time noon two make easier kid come school parent every friday clinic person receiving first vaccination exciting see happen',
#  'work considerably better people around world valued not developed country getting people global vaccination needed otherwise endless amount booster couid survive',
#  'study scientist germany prove student staff wearing mask school prevent transmission couid bad right_wingers politicize mask wearing vaccination bow would child comfortable intubated',
#  'vaccination personal benefit baffle claim big statistic yet entirely ignore virus worst many demographic young amp healthy largely unaffected fact',
#  'trudeau regime caused politicization amp rift society way highway divide society need total vaccination syringerat sound like total control bring heckler amp big white truck',
#  'pretty whack harden since kyrie part native american belief vaccination thing would make way sense',
#  'fortunately show leadership evidently masking remains required end winter term proof vaccination still required student enrolled current semester',
#  'want loosen restriction need get vaccination rate need people fully vaccinated get booster eligible right gotten boosted yet booster provide much protection omicron',
#  'truck blockaded right_wing convoy thing going',
#  'mock people wear double mask vaccination',
#  'applies people made couid restriction vaccination masking entire personality',
#  'say million infected recovered super immunity need vaccinated vaccination health risk',
#  'not pedantic think important note not vaccination rate data vaccination rate survey result',
#  'awesome institute plan open voluntary free vaccination clinic check mate',
#  'decrease traffic vaccination center directive ministry health asks doctor resume usual duty manager prioritize people site contribute polic',
#  'dwight say pre couid lot people never vaccination prove',
#  'special treat see first night since time couid glad required proof vaccination amp mask phenomenally talented group amp joy hear live music earthling thankful',
#  'eleven yr_old long couid not cleared vaccination fullyvaxxed masking',
#  'hey play game first ten ten student find show physical vaccination card receive new comfort color shirt made possible grant msriverproject swag',
#  'trudeau want vaccination rate via canada percent china china achieve expect canada beat number',
#  'alter vaccine requirement no proof full vaccination policy place since fall see logic dropping vaccine requirement basically end goal still need people',
#  'net self destruction one mental illness two ashy skin three vaccination card',
#  'not disputing vaccine equity power vaccination global public health always curious source stats',
#  'neighborhood vaccination rate pal fifty jan thirteen twentynine olive sparrow thirteen ord dos fifty creek ord dos fairbanks sparrow fourteen ord dos pelham park sparrow fifteen ord dos clinton ord dos',
#  'thank let get life back_normal forced vaccination passport mandate hope get trudumb get support',
#  'country collectively reach goal seventy percent vaccination rate amp talk lifting safety measure talking lifting safety measure prematurely put entire country seesaw frustrates public amp erodes trust publichealth',
#  'huge theater continues require mask proof vaccination attend show class state nice vaccine finder help locate get one near thanks help keeping everybody safe possible',
#  'hepburn effective monday february fourteen city hepburn remove proof couid nineteen vaccination negative_test requirement city hepburn facility read website',
#  'vaccine effective universal vaccination required get amp omicron current vaccine protection infection amp transmission much lower booster protection hospitalization amp death still high',
#  'vaccination work many dos willing take wearing mask keeping anti',
#  'nevada unmasked via whether mandate not vaccination masking best way protect couid',
#  'people date couid nineteen vaccination fully valued boosted five mo past dose infection much likely immune evasive omicron variant',
#  'yes think pack best team league last three season want see become best playoff team tell get vaccination miss game',
#  'canada critical situation nap backed trudeau say critical mean cost living higher ever endless restriction even incredibly high vaccination rate',
#  'consider faci middle hiv crisis also complicit couid vaccination push faci van mandate figured way super spread age via enhance resulting van',
#  'yep city follow province mask mandate proof vaccination province adequate data city not stop interfering',
#  'never asked vaccination enroll go class even live residence circ asked living residence though also mandatory',
#  'well awkward oct nineteen leverage new virus universal vaccination',
#  'not true geraldo mask along not vaccination stop making generalization people',
#  'mask come hard truth lifting couid restriction ideal universal vaccination among kid amp adult school yes data messy still lean science not politics amp noise bully',
#  'denying forced gestation vastly different private company policy company drug test policy refuse fired required vaccination different many workplace already mandatory vaccination place',
#  'mandatory vaccination applies american driver cross canadian border explain not movement trucker',
#  'find state county data coronavirus vaccine vaccination pandemic buckscounty buckscountynews pennsylvania doh',
#  'worry long couid really concern vaccinated vaccination seems significantly reduce risk',
#  'stop forced vaccination program time dialog canadian stop tyrant',
#  'thank getting rid cancerous player team hope rot brooklyn vaccination card stop second best player playing home good kid man always injured sincerely sixer fan',
#  'mention twelve mandate blue metro area vaccination rate high',
#  'decided get archer vaccinated could go back school amp hang friend matthew staff ochre medical center amp play music making vaccination experience positive todaylaptop',
#  'uncommon outcome pregnancy woman couid nineteen face elevated risk authority believe vaccination help prevent case',
#  'couid nineteen vaccination not required elite get free pas',
#  'hear answer question ninety vaccination enough clue civilized nation become tyrannical',
#  'long since seen live theater masking vaccination requirement help easing back',
#  'think corn pop get oscar portrayal acting like america economy oscar hypocrisy go twitter reacts academy_award not requiring proof vaccination',
#  'even remotely vaccination mandate might point never',
#  'make sure id passport birth certificate proof vaccination may required certain cruise ho see like welcome',
#  'people want mask mandate eliminated vaccination requirement dropped find personally inconvenient',
#  'marine corp separated marine couid nineteen vaccination refusal number still force latest',
#  'would booked ticket gutted show live taping houston end month show requires vaccination testing pretend like couid hysteria beginning complicit not much better',
#  'concert event first avenue associated venue continue require either proof full series couid nineteen vaccination proof negative couid nineteen test taken prior hour info',
#  'reopening weekend february twelve thirteen come visit sat sun amp stat holiday one please note mask mandatory syringe proof vaccination required',
#  'thought dropping mask mandate improved vaccination could persuaded find implausible current system incentivize feel bit ill timed highest mortality event like god coming two month prior vaccine',
#  'ignoring rise ba two amp increased transmisibility amp potential infection low five vaccination slow amp low booster adult rising hospitalization child look like another example con never learning',
#  'vaccination work protected uninfected work feel foolish afraid becoming infected chance becoming infected greater submitted',
#  'completely dependent illness care putting patient one bag base rate falsification many patient qualified get vaccination whatsoever',
#  'sister law two pfizer vaccination shot blood test showed trace antibody one seven million adult remain vulnerable couid',
#  'two incredibly inaccurate much much better variance cac published study show provides better protection vaccination',
#  'teacher may often family_member job stressful already support not add anxiety life',
#  'forget enroll little one safe help cac keep track vaccination reaction happy hunting sixteen sixteen',
#  'cac state people back day including pioneer doctor titan vaccine damn idiotic understand vaccination work stupidly thought prevent eradicate disease',
#  'posted day ago finding government report quite planning explaining new job today local news finance export confirmed like smack face hakim jeffries run around give job credit vaccination',
#  'know lost friend friend people support forced vaccination choice',
#  'focusing universal vaccination rather keeping intense focus high risk group overwhelmingly elderly serious ended prioritizing thing like vaccine five year_olds reaching van hesitant seventy year_olds',
#  'planning go year proof vaccination nothing little xeroxed card like yikes',
#  'want proactive search group site got pfizer five_eleven vaccine early place took three oldest kid walk drive_thru vaccination site next hospital nine',
#  'russian authority reported zero new confirmed coronavirus case another record fueled rapid spread omicron variant amid low vaccination rate absence major restriction adult',
#  'death going steadily vaccination sharp incline end present date heard lot people developing auto immunity post vaccine heart_attack post van amp booster two stroke post van booster friend deena henshaw stats canada',
#  'get excited jurisdiction say end mandate moderate level couid case reached cac metric ridiculous amp still based virus testing amp vaccination rate different endthemandates',
#  'one win vaccination removing mandate mean everyone win continue social_distance wear mask get booster freedom_convoy asking freedom choice',
#  'vaccination top prior infection provides better protection prior infection standard level prior infection way measure someone prior infection effective dose not might others not much',
#  'rate five_eleven vaccination dropping since november people not vaccinating infection recovered child especially latest variant five_eleven yos need vaccine based two yo wild_type spike latest variant',
#  'federal government cannot change vaccination requirement crossing_border public health measure provincial not federal',
#  'coercion not choice not demanding restriction vaccination mandate concern society think benefit right not coerced government forced comply illusion safety',
#  'allow air_filtration school even better put place quality mask allowed everywhere stop removing not vaccination value kind mask rapid_tests available accessible per case tracing',
#  'claim destroy antibody need provide immunity effective hence vaccination important certain population fact robust survivor couid good thing everyone tunnel visioned',
#  'bee thread looking_forward month let start talking find pfizer five vaccination appointment mentioned able get older child vaccinated shortly malenky gave approval five_eleven one',
#  'interesting data cac approximately twenty early omicron period hospitalization non couid nineteen condition particularly among young vaccinated adult one hospital vaccination rate much higher idaho',
#  'one suggesting intentional infection certainly not forced vaccination',
#  'one twenty zero legitimate medical exemption per cmon even let five non proven exemption every one proven exemption mean vaccination rate idea happy ninety vaccinated ridiculous',
#  'idea people trouble wear_mask want want child masked school issue kid really not difficult granted new england pretty high vaccination rate',
#  'smallpox eradicated thanks vaccination seems',
#  'really global pandemic personal ignorant choice supersede community repeating debunked talking_point actually help anyone country already certain vaccination requirement enter not new',
#  'seasonal_flu give zero three zero nineteen comparable thanks vaccination measure closure restriction etc three',
#  'stopped arguing mandate nonexistent texas since early normality vaccination mask patient staff want wear_mask office give grief option',
#  'needed show vaccination card place set tricky one site good time square especially night easily one favorite place ever sure',
#  'vaccination data super reliable part really outside expertise anyway assure many senior death vaccinated people however impossible otherwise',
#  'important note vaccination short window effectiveness not come without potential adverse effect',
#  'show vaccination card since wearing mask',
#  'really plenty good reason opt vaccination reason involve thing like rare immunological condition amp serious rare allergy choice kaylee talking result oppositional defiant disorder',
#  'fun fact found today quebec automatically update vaccine passport legally change name ram sure save old proof vaccination able leave country',
#  'like actually checking vaccination record',
#  'curious hollywood elite want shout vaccination get',
#  'brat ready send vaccination awareness brigade go door_door',
#  'keeping masking vaccination proof place student',
#  'indoor mask mandate new_york state expired today new_york city maintain citywide mandate key require proof vaccination enter museum arena',
#  'love much sir thank giving life country humbly request mandate vaccination close school switch remote also love finally forgive student loan',
#  'glad company work left mask policy local leader decided would lift mask wearing policy reach vaccination employee site guess going continue wear_mask',
#  'brain abscess brain cancer put category well within week ord dose vaccination thing found insane',
#  'one actually vaccinated definition produced immunity disease not get vaccinated contract disease not get vaccination boosted contract disease not get vaccinated boosted increase risk myocarditis',
#  'future hiv vaccine could developed sexually transmitted used joke post hiv causing orgy street never imagined orgy mass vaccination event aneurysm',
#  'wondering world living government many people basic capacity logical thinking analysis vaccine work vaccination prevent require others vaccinated vaccine not work vaccination',
#  'keeping safe play due emergence omicron variant couid nineteen strongly recommending guest wear_mask visiting regardless vaccination status detail',
#  'hilarious think amount vaccination make go away tyrant give power willingly insanely naive two year initial herd_immunity target met yet still not slowing virus endemic move life',
#  'indisputable vaccination not sole elixir warding boogie man know couid nineteen yet government would believe washtimesoped',
#  'science deny reality twenty year may well nobel several harm done science far great still invented anthology bullshit vaccination child',
#  'time make illegal require mask proof vaccination digital couid passport negative couid test',
#  'dutch county spa host free rabies vaccination clinic pet',
#  'minnesota health department make hard get vaccination record go local clinic retrieve',
#  'bow read updated version paper dismiss idea section page fourteen however start assumed thirteen sixteen poor health project proportion throughout vaccination group time using proportionality assumption',
#  'making assumption people lean right think unreasonable although personally know one liberal person refusing vaccination facebook reason',
#  'county low vaccination rate endured intense surge couid case delta wave study_finds',
#  'totally mom report got better post vaccination great hear equal number opposite happen yet journalist touch lack transparency drive hesitancy frustrating',
#  'due respect live fear like watch number plan accordingly needed warmer weather week away number people immunity either vaccination prior infection increase everyday future bright',
#  'seven million american left behind nation wobbly effort get back_normal weak immune_system simply rev fight virus vaccination like healthy one',
#  'specific single act couid vaccination act collection law available created maintain boost health canadian industry authority update condition time time',
#  'please get annual vaccination preventing various couid virus live life got polio vaccine young age given vaccination thankful never political matter',
#  'vaccination rate high enough people feel safe bar omicron subsided plus vaccine mandate imagine philly similar',
#  'not sure reporter tweet stuff fact lot canadian mistrust mainstream commedia nothing important vaccination soul searching order cannoli',
#  'trudeau want vaccination rate via walk something read loud',
#  'multiple vaccination childhood note wiener paper',
#  'would easier van booster rate higher not liked requirement show proof vaccination felt safer going pick choose place based whether think clientele likely valued not go two fin',
#  'excellent question dan york show answer community low vaccination rate child twentyfive measure vulnerability infection antibody vulnerable maybe already couid',
#  'specious excuse apart absurdly low risk level untaxed kid omicron spread basically regardless vaccination five thirty protection stall tactic part teachers_unions point word cruel',
#  'country ninety adult vaccination rate vaccine restriction correctly interpreted scapegoating enemy punishing',
#  'actually good idea set lock screen wallpaper pic ur vaccination card',
#  'average one period boost immunity not apply equally everyone people need likely get le benefit vaccination immunity wear fairly quickly even new variant get much better defeating immunity',
#  'know something deeper going pretty much looking vaccination rate dancing around question much making deeperissues endmandatesnow good one',
#  'got shot ten month ago still proof vaccination enough need negative_test',
#  'proof vaccination negative_test requirement twin_cities effective immediately',
#  'much would like many thybulle alright trade not great depends getting injured back amp whatever happens vaccination mandate term irving',
#  'think group definitively established either criterion met inclusion couid nineteen vaccine required vaccination attend public school washington state vaccine not prevent disease',
#  'man pawn freedom endangered truly cared freedom would follow science get vaccinated protect one another disease disability following vaccination schedule including couid',
#  'debate parliament support conservative debate restriction lol trudeau even answer properly conservative leader said many country lower vaccination rate canada ninety already lifted restriction',
#  'bribery usual vaccination covidvaccine',
#  'chos given total control prioritized old amp sickly obesity cohort barely existed sixty yr ago young amp healthy people decade live vaccination came mask deprivation draconian edict amp anger many wanted freedom cost even unnecessary death',
#  'pretty much people wearing mask street subway safe regard show vaccination status want go inside anywhere well',
#  'hope someone eye canon queen romana diddle made death threat involved kid couid vaccine two ago via video ottawa amp hosting school vaccination clinic',
#  'yes wear_mask bring vaccination card know gotten vaccine nothing go dictionary learn anything going',
#  'certainly learn lot twitter thought vaccination reduced spread couid silly believing scientist',
#  'main pillar policy full vaccination stay place argument made testing requirement serve punish people done everything required protect community',
#  'also terminated reason go see employment lawyer termination religious belief not vaccination status',
#  'course thing not achieved vaccination live die trashed immunity repeat vaccination imagine',
#  'country provide rubella containing vaccine rev amp nearly half stopped rubella transmission achieve global rubella elimination amp protect baby remaining country must offer rev amp maintain high vaccination coverage',
#  'clear louisiana legislator want pas constitutional amendment prohibit discrimination based vaccination status perfectly_fine allowing based sexual orientation gender identity',
#  'vaccination rate kid five_eleven range ten map twelve fifteen show better possible work amp time vaccine delivery urgently need vaccinate kid amp adult focus urgencyofequity',
#  'hey candice_bergen know hospital amp nurse past breaking point smart amp couid vaccination est place inc ferrari not sharpest knife drawer',
#  'path want take put pandemic behind quicker certain one mandatory vaccination stuttering drawn affair seattlemedium',
#  'vaccine great omicron evades vaccination better high quality properly fitting mask leader abrogating responsibility public health time people grab lead example',
#  'yes get ninety vaccination booster rate including kid seems work vaccine hesitant not straightforward way achieve meantime causing lot damage everyone',
#  'thank donating sixty zero mask charla help fight couid transmission community distribute vaccination clinic area person event make sure stay healthy',
#  'opinion open everything store sporting_events concert etc full capacity maintain proof vaccination make mask recommended optional let peer pressure handle one forced get vaccinated might not see jay play',
#  'coming one trick pony whose entire couid plan relied exclusively mass vaccination promising shut virus',
#  'let math one voted jan commission two vote remove marjorie greene three voted expand vaccination database fed level four vote make biden illegals legal five like castro cheguevara result yes super rino better known rinosalazar',
#  'vaccination greatly_reduces chance ending hospital dying vaccination also greatly_reduces chance infection first place variant even reduces_chances infection omicron lot first line defense important',
#  'sure epidemiologist virologist public health expert etc random twitter user expertise field know actually vaccination',
#  'mean usual age sex comparison risk healthy young people myocarditis overestimated relative risk vaccination le favorable source myocarditis one two vaccination',
#  'clear rationale healthy child need vaccination healthy young adult need booster infected need booster reasonable based patient choice gratuitous social economic punishment cannot justified',
#  'usual comparison myocarditis couid vaccination simply age sex however compare apples_oranges myocarditis couid strongly associated pre_existing condition vaccination significance comorbidities',
#  'science vaccination laboratory vaccine rna virus comparable sit toilet forget take trouser laboratory make vaccine already outdated not work new generation virus',
#  'rate five_eleven vaccination dropping since november people not vaccinating infection recovered child especially latest variant five_eleven yos need vaccine based two yo wild_type spike latest variant',
#  'vaccination trudeau want canada achieve lift mandate think legit question pretty sure ninety mandate would long gone',
#  'galati announcing two day away grand vaccination clinic walk drive_thru first second round shot pfizer modern well booster syringe please register community event visting',
#  'difficult convey couid infection lead temporary boost immunity like vaccination also cause long_term health problem including damage immune_system word people become couid',
#  'joe_biden must show proof vaccination everything except crossing_border receiving free crack_pipes',
#  'first time eating really asked vaccination card',
#  'said even relevant shut dribble people forced vaccination not gonna go play somewhere tend hurting team win championship harden probably stay kyrie part time player',
#  'vaccination rate',
#  'vaccinated people physical proof vaccination going denied service code need ensure people get code',
#  'trust quote individual pretty surprised learn man serious heart condition unable get medical exemption avoid vaccination sure happened also super easy thing lie',
#  'show many people vaccination not prioritize body kyrie doofus',
#  'worry myriad understood well vaccination yes known vaccine proven not pseudo gene_therapy damage life save always wholeheartedly',
#  'free choose measles able jeopardize health take vaccination prevent jeopardizing',
#  'plan currently drop passport vaccination situation masking said elliott wednesday believe masking going important time come news',
#  'mob rule canada occupier hurting others name freedom ninety can inch ninety trucker vaccinated path freedom vaccination communicable disease protection others health',
#  'polluting air wasting precious gas increasing supply_chain inflation hurting local business go massless cross_border amp refuse take vaccination may save life bad policy sound insane',
#  'specific data decade decade vaccination campaign place harder get data measles though',
#  'lift proof vaccination mandate going implement next wave',
#  'dear canadian call map need push end mandate remove vaccination pass truckersconvoy',
#  'fully onboard vaccine mandate kudos noting contradiction restricting free choice good thing vaccination not others promoting french common language quebec lot part time libertarian',
#  'trudeau many getting sick vaccination not kill_bacterium vaccine kill_bacterium ivermectin cry one',
#  'talk child pediatrician healthcare provider couid nineteen vaccination',
#  'would far easier make case removal school student mask mandate school student vaccination mandate',
#  'hired holiday participate vaccination campaign time finalize paperwork learn longer need care lack work get jab',
#  'centers_disease say changed language definition vaccination prevent social_media user falsely claimed couid nineteen vaccine ineffective',
#  'many like quote ninety adult vaccinated ninety vaccine mandate say look vaccination rate child forty better indicator many people believe may support mandate endmandates',
#  'im not sure got vaccinated last day possible denied medical wording faculty_staff fail comply vaccination directive may placed non disciplinary leave absence without pay',
#  'might lift mandate soon anyway need vaccinated longer show vaccination card restaurant matter time',
#  'not vaccination help prevent new variant arising also help fight survive new variant become infected schedule vaccine appointment',
# ...
#  'fear politician instilled doctor not write exemption one red_flag ethical vaccination campaign prove gas caused astrazeneca shot must suffer one reason protester fight freedom',
#  'city providence sent warning wednesday employee not complied city vaccination policy spokesperson mayor office told',
#  'pretty strict vaccine policy october literally prohibited kid twelve coming vaccinated know vaccinated player spectator definitely show proof vaccination access ground',
#  'school private amp catholic currently state achieve eighty vaccination student amp staff county drop seven case per zero mask go away clear since first day amp appreciated agree government clear',
#  'dude never ever actually mask vaccination please understand',
#  'yeah personally think point vaccination country seems silly vaccinated got want move',
#  'card holder vaccination card need one',
#  'recent data suggest infection car one four first time car would translate ifr infection mid bad flu season range could higher lower level vaccination',
#  'today focus couid nineteen put spotlight inequity society influencing approach couid vaccination northwest toronto click read bum',
#  'person different age state health etc difference symptom intensity disease severity not related vaccination consistent nuanced not white black',
#  'caveat hospitalization data include patient hospital couid not necessarily couid also potential factor given high omicron high vaccination rate county',
#  'wastewater data show omicron peaked higher initial dec_jan crisis peak currently around level aug peak amount rna bit tell whole story especially vaccination preventing hospitalization amp death',
#  'introducing lamina come get valid vaccination paper reduced wallet size laminated trying help keep changing time take photo use health card even code',
#  'understand saying people refuse get vaccinated made choice moral enter anymore interesting study wale correlating adverse childhood vaccination event couid vaccine rejection',
#  'sure think right still think death come high considering benefit le virulence high vaccination right look like benefit one thing happened',
#  'global pandemic wreaked havoc supply_chains housing cost going awhile would help could get vaccination',
#  'expert say change cac vaccination definition normal',
#  'except queen park federal mandate vaccinated come canada already crossed state would prove vaccination status border point moot',
#  'frankly question vaccination rapid_tests etc minister much consideration higher education health ask go reassure community everything not worked since start school year',
#  'like trucker waited europe etc rolled back couid restriction micron decline vaccination rate generally rising knowing pattern na following europe trend would likely mean end nigh way claim victory',
#  'valued resident got vaccination va',
#  'le two week next person show wednesday feb hard kingston seven show local provincial couid nineteen protocol including masking proof vaccination place camera randy nicker',
#  'hospital cannot turn people away regardless vaccination status everyone must wear_mask rly matter couid patient hospital valued',
#  'glad brought not high risk patient heart disease need vaccination booster need nuanced guidance managing primarycare counsel moment nutrition exercise mask needed approp know not',
#  'updated table booster vaccine effect reducing omicron infection seven study show least fifty increased protection compared two shot vaccination omicron breakthrough seem common',
#  'help learn vaccination rate among disability community family caregiver well not getting vaccinated syringe take survey',
#  'right smart thing vaccination year people thought received flu shot vaccine completely immune getting flu vaccine',
#  'working undergrad student question found stuff skirt around edge critical lit vaccination nothing outside journalism center link would love chat something preoccupation',
#  'yep everything hinge get rid forced masking case forced vaccination fall apart',
#  'evidence show vaccine safe effective even retained efficacy despite omicron fifty mutation evidence show mask effective vaccination reduces eliminate transmission believe see mean',
#  'fever myaligia not side_effect effect vaccination yet assuring serious side_effect reported however around ten patient definitely refused vaccination',
#  'need mandate couid vaccination twelve student current rate really low age_group right otherwise mask mandate stay place school reach endemic phase',
#  'mean vaccination get couid vaccinated le severe le infectious still get couid',
#  'prominent highly educated scientist expert somehow become biased vaccination amp safety protocol effort unfathomable equally informative decision maker rational scientist',
#  'bode say young people burden couid infection recently say largely cannot vaccinated right think vaccination youngest kid help make sure kid better protected',
#  'interesting meeting great forum highlight success rwanda vaccination program',
#  'maryland result omicron wave one would expected two ards le severe variant vaccination not one vaccinated state country',
#  'not healthy child child worse child wear_mask herd_immunity vaccination parent want kid protect kid understand',
#  'flipping many right_wingers free universal healthcare guaranteed income climate action billionaire taxation police reform abolition flipping anti vaccination public health skepticism privileging privilege safety etc',
#  'live interview major news channel india said truckersconvoy protest vaccination mandate continues center ottawa live near canadian parliament amp see major street near parliament blocked truck',
#  'airport security asked proof vaccination problem keep phone',
#  'name another place twenty people sit room seven hour day five day week even back office like ten people floor office also vaccination rate school aged kid much lower rest',
#  'still spread even vaccinated although certainly make le likely masking reduces transmission rate annoyance agree vaccination chance death point one two',
#  'yep agree everything said still catch wave good health motivation vaccination right time',
#  'survivor bias seems come together multiple experience survivor bias vaccination survivor bias infection survivor bias multiple infection survivor bias asymptomatic infection',
#  'know certain vaccine may induce inflammation heart want stay informed join pic free vaccine vaccination informedconsent science statistic',
#  'delta measurement impact overall transmission longer case omicron even level vaccination changed time turn page reintroduce measure necessary according new variant',
#  'vaccinated boosted symptom fever_chills slight dry cough two day felt like got second vaccination',
#  'big_deal show vaccination proof phone big burden folk door quick look',
#  'country dropping mitigation step adult vaccination rate approach eighty obviously going see anytime_soon',
#  'analysis study using data adjusted time vaccination saying data vaccinated people removed quite dishonest',
#  'hold lifting vaccination mask mandate mean kyrie play home_game right',
#  'barbaric pandemic response pathologically greedy dictating policy gov amp operate ruling pol party pandemic policy actively opposes mitigation amp vaccination amp order pandemic profit curve flattens',
#  'yeah making hiv thing back another scare fear campaign boogie man nightmare normalizing hiv testing hiv vaccination hiv',
#  'understanding sixty forty split absolutely key strongest evidence released yet vaccination potential path adopted absolute highest like uptake',
#  'peter rowan free mexican airforce featuring los texmaniacs feb folk master peter rowan join grammy winning los texmaniacs groove full vaccination mask required entry ticket',
#  'keep spinning valued preaching importance vaccination liberal government continues mock canadian',
#  'new_york state mask proof vaccination mandate end business cool insuring arena lift mask policy face mask still encouraged vaccinated visitor via',
#  'new_york state mask proof vaccination mandate end business cool insuring arena lift mask policy face mask still encouraged vaccinated visitor',
#  'day far couid hell chill body_aches multiple fever nap rinse repeat thankful care place great family great friend day seven hoping get better vaccination strong hope',
#  'ever get tired afraid like done every vaccination hear expert afraid even got infected antiviral option free couid test pack available',
#  'canada ottawa understand not worker trucker vaccination although facet moment history extremism question need ask today fight back ottawaoccupied ottawaconvoy',
#  'dash handled vaccination visit like champ value pet vaccination way need equally aggressive couid nineteen get vaccinated people',
#  'early morning internal medicine round wonderful group resident thought get vaccinated couid omicron vaccination wear mask',
#  'yes current strain considering initial premise conversation especially original comment efficacy omicron vaccination opposed infection omicron seems relevant',
#  'negligence change vaccine suppose centers_disease told ap agency vaccination add detail amp def removed immunity amp state stimulation body immune_response',
#  'final version new adjuvant van strategy today showing expansion episode recognized vaccination sars flu great work led lab side led take look',
#  'supportive keeping mask mandate school vaccination rate child five_eleven way higher vaccine available age five ith grader sip student enough virtual school last two year last life time',
#  'many denied unsupported claim le effective two week vaccination three month',
#  'public policy perspective suggests mandate really expanded incredibly difficult endanger others vaccinated suggests give employer right demand vaccination put tdo form etc',
#  'huge thank marie eve nurse vaccinated medical staff canadian armed_forces helping book vaccination appointment going good one',
#  'history repeating left rally anti vaccination league canada old city_hall toronto november thirteen right protestors gather queen park blood street west demonstration toronto feb five antivaxxers protester windsorblockade',
#  'sigh thank teaching correlation causation mi patient one talking also vaccination rate stop trying make complex thing simple failing medicareforall',
#  'one support vaccination untrue two evidence read opposite three intentional infection bad idea respect immunity already suffered infection many government recognize',
#  'clinic two additional clinic bridgwater week weekend need book walk friendly team pleased meet',
#  'let say get say coverage three dos including two dos twelve would close getting point would fall one vaccination dynamic not quite close',
#  'make nut vaccination card get yacht party one nut people van card',
#  'large_scale vaccination drive mandate ith wave start around beginning may two week easter irony would put back thick thing calgary cowboy syphilis festival hilarious cancel',
#  'new new annals two expert debate appropriate test interval young patient not yet undergone cervical_cancer screening received hav vaccination',
#  'coercion not consent people get vaccinated work vaccination able work choice please note not people get vaccinated first place',
#  'andyouknow currently enrolled spring student received couid nineteen booster vaccine get free ten gift_card simply bring proof booster vaccination photo_id santa maria campus lac cashier office',
#  'friend lake george library hold monthly book sale saturday month usual event held canada street lake george mask required regardless vaccination status event subject change due couid nineteen',
#  'stopped going removed vaccination mandate scout decision',
#  'loudspeaker capi hosting free well check pop clinic couid vaccine get child free child check couid vaccine time check flyer_details laptopchild check',
#  'occurred hope kirby date tetanus vaccination',
#  'fight spread get vaccinated wear_mask public indoor setting social_distance crowded area free vaccination site',
#  'would think instance vaccination like authorized emergency_use authorization freedom choice freedom exist still america stephen skol tell podcast',
#  'attending scion skip line scan code upload validate vaccination info learn health safety measure',
#  'due low number vaccinated student certain elementary school city could eighty vaccination rate put place mask mandate lifted particular school',
#  'understand rather framing many others using not like promote vaccination not like declined make high quality mask available especially became important omicron',
#  'reason selfish ignorant people freedom canadian people older five unselfish received vaccination protect family friend citizen end even vaccinated',
#  'know best scoring guard league not extend regardless vaccination situation',
#  'vaccineswork better placebo given cac new definition study result change say five month five year allopathetic drug hospital vaccine vaccination vaccine nurse',
#  'path want take put pandemic behind quicker certain one mandatory vaccination stuttering drawn affair memo',
#  'umm quick question joescrackheads show vaccination card get free crackpipe kit',
#  'morocco number contamination case declared last twentynine death deplored interval warning respect adhere national vaccination campaign syringe',
#  'pretty sure periodic overhead announcement free site vaccination new_orleans airport appeal surprising number traveler simply ignore periodic overhead announcement face mask',
#  'one shared article said vaccine severe_illness citing seventy eighty israeli severe couid patient vaccinated ninety vaccination rate freaked blocked noted something must account gap',
#  'one two despite end delaware universal indoor mask mandate feb eleven face mask continue required long_term care facility way keep vulnerable resident staff visitor safe face mask required matter person vaccination status',
#  'vaccination mandate like communicable disease',
#  'parent fence either worried possible long_term effect vaccine kid think not necessary would rather roll dice',
#  'virus done yet wishful thinking work nearly well vaccination maskssavelives vaccineswork getvaccinated wearamask markup',
#  'seems pointless expend social amp political capital weakly enforced relatively low efficacy measure rather continuing promote vaccination ensuring high quality mask anyone want',
#  'bottom_line clear global vaccination save enormous amount life price fraction amount spent couid response amount willing spend save life context five seven',
#  'analysis not account downstream benefit global vaccination including impact economic recovery hospitalization long couid reduced risk new variant emerging four seven',
#  'wearing mask target not lockdown limit indoor event capacity not lockdown requiring vaccination work patient not lockdown somebody please air drop dictionary america not hardcover ow maybe little pocket paperback',
#  'ri announced indoor mask mandate vaccination status check tomorrow end school mask mandate feb match announcement already made mass conn feel like giving',
#  'good news alert mourn people lost hope odds inch huge inequity access vaccination weathered storm resilience amp determination informed africa long history amp experience controlling outbreak',
#  'really hope check proof vaccination giving away crack_pipes',
#  'conservative clearly calling barrier removed saying continue protester fight mandatory vaccination various workplace acting leader party',
#  'zero scientific data math let say every infected person spread two people mean ten vaccinated turn twenty new case forty vaccination worked one ten time still would mean would nine nine turn eighteen case',
#  'would reaction allow vaccination mask something protect let darwin sort anti people know increase risk others perhaps manageable time',
#  'malaria research holds_lessons childhood couid vaccination via',
#  ...]

# %%
positive_df['new_text_all'] = new_text_all
# Out:
# /var/folders/lg/w8d05wzd48q3m5_s46qt2fxc0000gn/T/ipykernel_87065/4226431711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_df['new_text_all'] = new_text_all

# %%
texts = positive_df['new_text_all']

# %%
texts
# Out:
# 0         want find way end racism try force people inje...
# 3         would expect case rise significantly course va...
# 4         depends whether vaccination status embedded co...
# 5         could ripped harder think masking isolation et...
# 6         vaccination center well refused let amp elderl...
#                                 ...
# 315597    contrary american belief vaccine not personal ...
# 315598    pretty remarkable achievement thank volunteer ...
# 315600                                               others
# 315601    yay congrats fully vaccinated best feeling saf...
# 315602    part end pandemic get vaccine try help others ...
# Name: new_text_all, Length: 222780, dtype: object

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

high_freq_known_words = ['covid','couid', 'pfizer', 'amp', 'people', 'covidvaccine', 'covishield', 'moderna', 'vaccine', 'astrazeneca', 'vaccinate', 'vaccinated', 'vaccination', 'vaccines']

stop_words.extend(high_freq_known_words)

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=4, M=20, alpha=50/4, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [14:22<00:00,  1.44s/it]

# %%
stable_topics = [0, 1, 2, 3]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0    topic1   topic2     topic3
# 0       get    modern      get        get
# 1    modern       one     mask  effective
# 2      shot      dose  mandate        one
# 3   booster       get     anti        two
# 4       day       two     like      still
# 5      dose     today       go      virus
# 6       two     first     want    booster
# 7     shoot        go      one        say
# 8       one      year      say       mask
# 9      feel       say     wear       know
# 10   second      make     know       case
# 11    first  nineteen     make      fully

# %% [markdown]
# ## 5 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=5, M=20, alpha=50/5, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [14:48<00:00,  1.48s/it]

# %%
stable_topics = [0, 1, 2, 3, 4]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0   topic1   topic2   topic3     topic4
# 0    modern      get     anti      get  effective
# 1       get   modern      get     mask        get
# 2      dose     shot     like       go        one
# 3       one  booster      one  mandate        two
# 4       two      day  mandate     wear      virus
# 5     first      two      say    still        say
# 6     today     dose     make      one    booster
# 7   booster    shoot       go      kid     modern
# 8      shot     feel    would     want      still
# 9      week      one    think     like    variant
# 10    thank   second     want     need  infection
# 11       go    first     know     know       know

# %% [markdown]
# ## 6 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=6, M=20, alpha=50/6, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [15:48<00:00,  1.58s/it]

# %%
stable_topics = [0, 1, 2, 3, 4, 5]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0   topic1   topic2    topic3     topic4 topic5
# 0       get      get   modern   mandate  effective    get
# 1      mask     shot      get      like        one   anti
# 2      wear   modern     dose   trucker        get   like
# 3     still  booster      one       one        two     go
# 4       kid      day    first    canada      virus    say
# 5        go      two  booster  canadian    booster   make
# 6   mandate     dose    today     would     modern   take
# 7       one    shoot     shot     right  infection   know
# 8    school     feel      two      want      still   want
# 9     fully   second    thank   country    variant  trust
# 10     need      one       go     think        say    one
# 11     work    first     week       get   nineteen   mask

# %% [markdown]
# ## 7 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=7, M=20, alpha=50/7, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [16:43<00:00,  1.67s/it]

# %%
stable_topics = [0, 1, 2, 3, 4, 5, 6]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0     topic1   topic2   topic3   topic4     topic5 topic6
# 0       get        get      get     like     mask     modern    get
# 1    modern  effective   modern      one  mandate        one   anti
# 2   booster        one     shot     anti      get       dose     go
# 3      dose        two      day  trucker     wear        fda   mask
# 4      shot      virus  booster    think    still        say   like
# 5       one      still      two       go      kid        two    say
# 6       two    omicron     feel     know   school  effective   take
# 7     today  infection     dose    would       go   nineteen   make
# 8        go    booster    shoot      get    fully       make   know
# 9     first       case   second     time     want     health   want
# 10     week    variant      one      see      one      would    one
# 11    shoot      death    first      got     need      first  would

# %% [markdown]
# ## 8 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=8, M=20, alpha=50/8, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [18:11<00:00,  1.82s/it]

# %%
stable_topics = [0, 1, 2, 3, 4, 5, 6, 7]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0 topic1  topic2   topic3    topic4   topic5     topic6 topic7
# 0       get    get    like      get   mandate     mask  effective    get
# 1    modern    one  modern   modern      anti  mandate        one   anti
# 2      shot    two      go     dose      like      get        two     go
# 3       day    got     one  booster   trucker     wear      virus   mask
# 4   booster   year    good     shot       one    still        get   like
# 5      feel  fully    game      one     right   school  infection    say
# 6     shoot    kid     see    first    canada       go    variant   take
# 7       two  still  jansen      two     would      kid       case   know
# 8      dose    day    play    today  canadian     need      still   make
# 9    second  three    team     week      want    fully    omicron   want
# 10      arm   mask    time    thank      make   health      death    one
# 11    first   time    make    shoot       say   public     modern  would
