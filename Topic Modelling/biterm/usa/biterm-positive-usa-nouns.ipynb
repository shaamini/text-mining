# %%
#for windows users:
#pip install bitermplus

#for mac users:
# xcode-select --install
# brew install libomp
# pip3 install bitermplus

# pip install tmplot
# pip install tomotopy

# %%
import bitermplus as btm
import numpy as np
import pandas as pd

import json 
import csv
import nltk
import unicodedata
import re
import sys
from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora, models
from gensim.utils import simple_preprocess
import gensim, spacy
from gensim.models.ldamulticore import LdaMulticore
import re
from gensim.models import Phrases
from gensim.models.phrases import Phraser

# %%
df = pd.read_csv("../pos_neg_usa.csv")
df
# Out:
#         Unnamed: 0   index                                               Text  \
# 0                0       0  want find way end racism try force people inje...
# 1                1       1  this child almost died tetanus, spent months h...
# 2                2       2  juste se rappeler m. leblanc la pression que l...
# 3                3       3  you would expect cases rise significantly, cou...
# 4                4       4  depends whether vaccination status is embedded...
# ...            ...     ...                                                ...
# 315598      404255  404255  pretty remarkable achievement. thank you all v...
# 315599      404258  404258  oh that explains similar - seemingly out nowhe...
# 315600      404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 315601      404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 315602      404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 315598  pretty remarkable achievement. thank you all v...   ENGLISH
# 315599  oh that explains similar - seemingly out nowhe...   ENGLISH
# 315600  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 315601  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 315602  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 315598  pretty remarkable achievement. thank you all v...
# 315599  oh that explains similar - seemingly out nowhe...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 315598  [('pretty', 'RB'), ('remarkable', 'JJ'), ('ach...
# 315599  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
# 315600  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 315601  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 315602  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explains', 'similar', 'seemingly', 'nowhere'...
# 315600                    ['others', 'vaccinesaveslives']
# 315601  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explain', 'similar', 'seemingly', 'nowhere',...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 315598  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 315599  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 315600                      ['other', 'vaccinesaveslive']  subjective
# 315601  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 315602  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 315598          2
# 315599          0
# 315600          2
# 315601          2
# 315602          2
#
# [315603 rows x 12 columns]

# %%
df.drop(columns = ['Unnamed: 0', 'Text', 'index', 'new_text', 'languages', 'pos_tagged_words'], inplace = True)
df
# Out:
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 315598  pretty remarkable achievement. thank you all v...
# 315599  oh that explains similar - seemingly out nowhe...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explains', 'similar', 'seemingly', 'nowhere'...
# 315600                    ['others', 'vaccinesaveslives']
# 315601  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explain', 'similar', 'seemingly', 'nowhere',...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 315598  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 315599  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 315600                      ['other', 'vaccinesaveslive']  subjective
# 315601  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 315602  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 315598          2
# 315599          0
# 315600          2
# 315601          2
# 315602          2
#
# [315603 rows x 6 columns]

# %%
df['words_processed_noun'].values[0][0]
# Out:
# '['

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
tokens_words_processed_noun = list(sent_to_words(df['words_processed_noun']))

# %%
from nltk.corpus import stopwords
stop_list = stopwords.words('english')
high_freq_known_words = ['covid','couid', 'pfizer', 'amp', 'people', 'covidvaccine', 'covishield', 'moderna', 'vaccine', 'astrazeneca', 'vaccinate', 'vaccinated', 'vaccination', 'vaccines']

stop_list.extend(high_freq_known_words)

test_words_only1 = ['not', 'vaccine', 'covid', 'and', 'vegan', 'cruelty', 'free', 'i', 'use', 'elf', 'cosmetics', 'every', 'day', 'and', 'i', 'love', 'it']
test_stopremoved = [w for w in test_words_only1 if w not in stop_list or w == 'not']
print(test_stopremoved)
# Out:
# ['not', 'vegan', 'cruelty', 'free', 'use', 'elf', 'cosmetics', 'every', 'day', 'love']

# %%
stop_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'covid',
#  'couid',
#  'pfizer',
#  'amp',
#  'people',
#  'covidvaccine',
#  'covishield',
#  'moderna',
#  'vaccine',
#  'astrazeneca',
#  'vaccinate',
#  'vaccinated',
#  'vaccination',
#  'vaccines']

# %%
df['words_processed_noun'] = tokens_words_processed_noun

# %%
# remove stop words from tokenised_words_only

tokenised_stopremoved = [[w for w in each if w not in stop_list or w == 'not'] for each in tokens_words_processed_noun]
tokenised_stopremoved
# Out:
# [['way', 'end', 'racism', 'force', 'bunch', 'race', 'support', 'force'],
#  ['child', 'tetanus', 'month', 'hospital', 'cost', 'parent', 'pandemic'],
#  ['leblanc',
#   'pressure',
#   'business',
#   'world',
#   'border',
#   'air',
#   'traffic',
#   'block',
#   'tourist',
#   'hotel',
#   'restaurant'],
#  ['case',
#   'rate',
#   'play',
#   'space',
#   'adult',
#   'space',
#   'school',
#   'age',
#   'student',
#   'datum',
#   'state',
#   'bear'],
#  ['status', 'code', 'link', 'connect', 'end', 'read'],
#  ['isolation', 'question', 'look', 'spike', 'matter', 'thing'],
#  ['center', 'parent', 'mask', 'answer'],
#  ['tool',
#   'suite',
#   'leader',
#   'combat',
#   'hesitancy',
#   'resistance',
#   'video',
#   'article'],
#  ['goal', 'blogger', 'news', 'accident', 'step', 'competence'],
#  ['head', 'brain', 'place', 'rate', 'case_count', 'dictatorship', 'name'],
#  ['world', 'passport', 'goal'],
#  ['restaurant', 'arena', 'fitness', 'center', 'rate'],
#  ['age',
#   'hour',
#   'infection',
#   'booster',
#   'infection',
#   'protect',
#   'hypnotoad',
#   'pheromone'],
#  ['understand', 'link', 'compulsory', 'bawl', 'bye'],
#  ['winner', 'today', 'lab', 'variant', 'count'],
#  ['common_sense', 'solution', 'virus', 'business'],
#  ['tooting', 'place', 'language'],
#  ['variant',
#   'ventilation',
#   'kid',
#   'time',
#   'kid',
#   'danger',
#   'kid',
#   'danger',
#   'matter'],
#  ['county', 'threshold', 'datum', 'school'],
#  ['business', 'proof', 'government', 'province'],
#  ['vision',
#   'health',
#   'decision',
#   'condition',
#   'vulnerability',
#   'year',
#   'politic',
#   'level',
#   'factor'],
#  ['understand', 'thought'],
#  ['concern', 'level'],
#  ['steel', 'man', 'mandate', 'mask', 'testing', 'cost', 'cost'],
#  [],
#  ['pregnancy', 'term'],
#  ['government',
#   'concern',
#   'prevent',
#   'hospital',
#   'emergency',
#   'depth',
#   'resource',
#   'bed',
#   'space',
#   'equipment',
#   'staff',
#   'hospital'],
#  ['spread', 'case', 'care', 'status', 'force'],
#  ['game', 'green_light', 'status', 'stadium', 'enforce'],
#  ['specialist', 'effort'],
#  [],
#  ['body', 'fight', 'business', 'employer', 'government'],
#  ['report', 'document', 'trump', 'bullshit', 'border', 'end', 'mandate'],
#  ['conclusion', 'mandate', 'death', 'rate', 'state', 'rate'],
#  ['issue', 'way'],
#  ['laughingstock',
#   'rest',
#   'world',
#   'trucker',
#   'mandate',
#   'lie',
#   'reinstatement',
#   'tag'],
#  ['death', 'push', 'agenda'],
#  ['school',
#   'proof',
#   'respect',
#   'individuality',
#   'health',
#   'decision',
#   'choice',
#   'lol',
#   'hate'],
#  ['state',
#   'state',
#   'mask',
#   'mandate',
#   'state',
#   'course',
#   'rate',
#   'conclusion'],
#  ['neighbor', 'pig', 'rate', 'world'],
#  ['trust', 'rate', 'time'],
#  ['policy', 'government', 'mandate', 'employer', 'policy'],
#  ['subject'],
#  ['abortion', 'thought', 'prayer', 'prayer'],
#  ['paradox', 'death', 'rate', 'number', 'fatality'],
#  ['masking',
#   'kid',
#   'hospitalization',
#   'rate',
#   'rate',
#   'kid',
#   'normalcy',
#   'number'],
#  ['case', 'state', 'rate', 'news', 'site', 'spoon', 'intelligence'],
#  ['lot',
#   'choice',
#   'abortion',
#   'choice',
#   'abortion',
#   'remove',
#   'life',
#   'remove',
#   'choice',
#   'risk'],
#  ['endemic',
#   'lockdown',
#   'mask',
#   'fear',
#   'precaution',
#   'age',
#   'health',
#   'condition'],
#  ['result', 'infection'],
#  ['status'],
#  ['mandate',
#   'school',
#   'rate',
#   'education',
#   'outreach',
#   'student',
#   'sibling',
#   'mask',
#   'mandate'],
#  ['abortion', 'thing'],
#  ['explain', 'person', 'way', 'issue'],
#  ['eric_adam', 'key', 'order', 'age', 'show', 'proof', 'participate', 'proof'],
#  [],
#  ['time', 'faught', 'health', 'care'],
#  ['challenge',
#   'nation',
#   'rule',
#   'testing',
#   'problem',
#   'creation',
#   'self',
#   'country'],
#  ['stake', 'applicant', 'choice'],
#  ['trading', 'player', 'claim', 'injury', 'rate'],
#  ['lesson', 'damage', 'ifs'],
#  ['member',
#   'submit',
#   'card',
#   'card',
#   'reporting',
#   'mean',
#   'event',
#   'side_effect',
#   'event'],
#  ['fear', 'lot', 'fear', 'mask', 'held_hostage'],
#  ['rate',
#   'benefit',
#   'risk',
#   'instruction',
#   'glad',
#   'activity',
#   'weather',
#   'air'],
#  ['head', 'answer', 'time', 'time'],
#  ['slide', 'injure', 'notice', 'horse', 'serum'],
#  [],
#  ['recommendation', 'health', 'care', 'worker', 'fund', 'scout', 'safety'],
#  ['prevention',
#   'mask',
#   'mask',
#   'flu',
#   'flu',
#   'shot',
#   'year',
#   'difference',
#   'virus',
#   'kill',
#   'rate'],
#  ['way', 'yield', 'result', 'mandate', 'decision'],
#  ['altar', 'produce', 'testing'],
#  ['look',
#   'mirror',
#   'man',
#   'conservative',
#   'blockade',
#   'rhetoric',
#   'health',
#   'order'],
#  ['fan',
#   'super_bowl',
#   'experience',
#   'ticket',
#   'experience',
#   'day',
#   'future',
#   'date',
#   'visit',
#   'site'],
#  ['part', 'pass', 'adult', 'choice', 'consequence', 'rate'],
#  ['card', 'thank'],
#  ['vehicle'],
#  ['website', 'benefit', 'outweigh', 'risk', 'risk'],
#  ['lockdown',
#   'biden',
#   'biden',
#   'thing',
#   'program',
#   'trump',
#   'increase',
#   'rate',
#   'presidency'],
#  ['ability',
#   'restriction',
#   'point',
#   'mandate',
#   'trust',
#   'business',
#   'restaurant',
#   'guarantee'],
#  ['find', 'clip', 'base', 'source'],
#  ['treatment', 'definition', 'response', 'illness'],
#  ['prevent', 'spread', 'disinformation'],
#  ['rate'],
#  ['substance', 'rabie', 'forgot', 'administer', 'post'],
#  ['isolate', 'protect'],
#  ['part', 'recovery', 'individual', 'recommendation'],
#  ['measle', 'outrage'],
#  ['day', 'dog', 'twenty_minute'],
#  ['parent', 'infrastructure', 'grownup', 'hell', 'kid', 'hour', 'cold'],
#  ['list',
#   'nominee',
#   'requirement',
#   'meltdown',
#   'twitter',
#   'wag',
#   'movie',
#   'shot'],
#  ['inquiry', 'european_union', 'titer', 'test', 'system'],
#  ['rate', 'district', 'leader', 'tweet', 'restaurant'],
#  ['government',
#   'place',
#   'business',
#   'government',
#   'mandate',
#   'show',
#   'proof',
#   'oppression'],
#  ['thing', 'term', 'thing', 'surface', 'protein'],
#  ['fact', 'care', 'pal', 'care'],
#  ['measure', 'science'],
#  ['bring', 'way', 'conflict', 'worker', 'type', 'vacation', 'proof', 'dime'],
#  ['protestor', 'wheel'],
#  ['hospitalization',
#   'booster',
#   'rate',
#   'look',
#   'hospitalization',
#   'chart',
#   'world'],
#  ['love', 'gymnastic', 'police', 'brutality', 'minority'],
#  ['defundcbc', 'defundbbc', 'extravaganza', 'network', 'fund', 'baddie'],
#  ['immunity',
#   'time',
#   'fact',
#   'therapist',
#   'time',
#   'health',
#   'risk',
#   'kill',
#   'technology'],
#  ['school', 'age', 'kid', 'school', 'parent'],
#  [],
#  ['fact', 'country', 'follow', 'show', 'point', 'leave', 'country', 'proof'],
#  ['ice', 'hockey', 'end', 'program'],
#  ['mandate',
#   'rate',
#   'restriction',
#   'tone',
#   'thread',
#   'mandate',
#   'attempt',
#   'coerce'],
#  ['answer', 'stimulate', 'gas', 'week', 'postvaccination', 'case'],
#  ['government', 'kid', 'face', 'mask', 'school'],
#  ['rate', 'majority', 'government', 'pandemic', 'plan', 'dummy'],
#  ['paper',
#   'state',
#   'spike_protein',
#   'level',
#   'blood',
#   'variant',
#   'produce',
#   'antibody',
#   'variant'],
#  ['immigration',
#   'question',
#   'answer',
#   'health',
#   'safety',
#   'requirement',
#   'record'],
#  ['terrorist', 'issue', 'issue', 'restriction', 'way', 'period'],
#  ['isolation',
#   'fentanyl',
#   'death',
#   'loved_one',
#   'stress',
#   'mask',
#   'show',
#   'proof',
#   'baby'],
#  ['person', 'county', 'rate', 'mask'],
#  ['half',
#   'adult',
#   'flu',
#   'heart',
#   'disease',
#   'heart',
#   'disease',
#   'risk',
#   'flu',
#   'complication'],
#  ['misinformation',
#   'nowspinning',
#   'hear',
#   'subgenius',
#   'radio',
#   'end',
#   'time',
#   'antivaxxer',
#   'detail'],
#  ['parking', 'ticket', 'check', 'bylaw', 'officer', 'business', 'shot'],
#  ['show', 'proof', 'yesterday', 'hell'],
#  ['hope', 'treatment', 'problem', 'immunity', 'system', 'case', 'check'],
#  ['flu', 'month', 'year', 'flu', 'complication'],
#  ['mask', 'understand', 'right'],
#  ['thing',
#   'today',
#   'person',
#   'leave',
#   'question',
#   'booster',
#   'dose',
#   'person',
#   'client',
#   'contract',
#   'health',
#   'concern'],
#  ['discrimination',
#   'color',
#   'sex',
#   'religion',
#   'health',
#   'system',
#   'injection'],
#  ['turn', 'sense', 'choice', 'pay', 'rent'],
#  ['issue',
#   'threat',
#   'police',
#   'state',
#   'group',
#   'democracy',
#   'kid',
#   'country'],
#  ['ac', 'death', 'ambulance', 'incompetence', 'management'],
#  ['member', 'minute'],
#  ['quebecer', 'solution', 'reduce', 'contagion'],
#  ['question', 'airline', 'proof', 'destination', 'proof'],
#  ['mitigation'],
#  ['question', 'place', 'entry'],
#  ['intention', 'tue', 'drop', 'case', 'county', 'rate', 'state', 'yesterday'],
#  ['employer', 'mandate'],
#  ['boy', 'rate', 'science'],
#  ['today', 'alignment', 'issue', 'cabal', 'mybodymychoice', 'ear'],
#  ['rate',
#   'percent',
#   'indoor_space',
#   'running',
#   'errand',
#   'retirement',
#   'hubby',
#   'year'],
#  ['fact',
#   'business',
#   'option',
#   'status',
#   'choice',
#   'choice',
#   'choice',
#   'business',
#   'poli'],
#  ['side', 'fiorella', 'fan', 'ratio'],
#  ['rate',
#   'definition',
#   'immunity',
#   'infection',
#   'hospitalization',
#   'death',
#   'policy'],
#  ['memory', 'analysis', 'state', 'access', 'month'],
#  ['election', 'definition', 'tourist', 'mandate', 'care', 'time'],
#  ['firm', 'belief', 'sixer'],
#  ['health', 'ventilation', 'amount', 'virus', 'air', 'chance'],
#  ['utility', 'plan', 'testing', 'safety', 'protocol'],
#  ['variant', 'antibody', 'selection', 'ade', 'yesterday'],
#  ['recurrence', 'connection', 'herpe', 'infection', 'year'],
#  ['state', 'border', 'card', 'business', 'comparison', 'makes_sense'],
#  ['girl', 'selling', 'card', 'week', 'card', 'card'],
#  ['time', 'history', 'definition', 'reason', 'change', 'meaning', 'word'],
#  ['card',
#   'comparison',
#   'water',
#   'context',
#   'creation',
#   'role',
#   'strategy',
#   'impact'],
#  ['clinic', 'health', 'screening', 'vendor', 'music', 'food', 'fun', 'flyer'],
#  ['hour', 'policy', 'science'],
#  ['propaganda', 'exercise', 'rate', 'world', 'guilt', 'business'],
#  ['mask', 'mandate', 'week', 'proof'],
#  ['protect', 'border', 'trucker', 'cross_border', 'rule', 'care'],
#  ['risk',
#   'reduction',
#   'time',
#   'virus',
#   'circulate',
#   'body',
#   'antibody',
#   'week',
#   'virus',
#   'body'],
#  ['topic', 'supporter'],
#  ['event', 'terrace'],
#  ['recovery', 'today', 'bow', 'timing', 'pass', 'month'],
#  ['pneumonia', 'influenza', 'trap'],
#  ['party',
#   'weekend',
#   'matter',
#   'root',
#   'mask',
#   'defensive',
#   'play',
#   'care',
#   'matter'],
#  ['bill', 'mandate', 'school', 'kid', 'kid', 'school', 'requirement'],
#  ['cell',
#   'subject',
#   'infection',
#   'history',
#   'tool',
#   'monitoring',
#   'protection'],
#  ['opponent', 'distrust', 'product', 'test', 'time', 'principle', 'package'],
#  ['wave', 'wave', 'fact', 'occurrence', 'week', 'week'],
#  ['study', 'reality', 'mandate', 'hospitalization', 'path', 'pandemic'],
#  ['regime',
#   'spokespeople',
#   'mom',
#   'sentiment',
#   'protest',
#   'protest',
#   'mandate',
#   'sentiment',
#   'trucker'],
#  ['difference', 'canadian', 'spectrum', 'restriction', 'life', 'goal'],
#  ['card', 'wash_hand'],
#  ['record', 'idea', 'question', 'importance', 'typhoid'],
#  ['court', 'fund', 'platform'],
#  ['anti_baxter', 'majority', 'staff', 'member', 'business'],
#  ['twitter', 'feed', 'blame', 'proof', 'diagnosis', 'fact'],
#  ['favor', 'tool', 'tension', 'pass'],
#  ['center'],
#  ['time',
#   'transmission',
#   'risk',
#   'approach',
#   'wish',
#   'wear',
#   'mask',
#   'risk',
#   'assessment'],
#  ['thing', 'measure'],
#  ['mandate', 'trucker'],
#  ['spread', 'die', 'reason', 'categorize', 'status'],
#  ['man', 'stage', 'wink', 'actor', 'premier', 'mandate'],
#  ['infection', 'rate', 'country', 'today', 'mask'],
#  ['key', 'health', 'activity'],
#  ['business', 'proof', 'reader', 'business', 'status', 'wolf', 'health'],
#  ['reason', 'majority', 'canadian', 'mandate'],
#  ['limitation',
#   'clinician',
#   'report',
#   'adverse_event',
#   'event',
#   'hospitalization',
#   'veer',
#   'reporting',
#   'system',
#   'veer'],
#  ['child', 'organization', 'girl', 'guide', 'check', 'status', 'child'],
#  ['outlier', 'profession', 'benefit', 'population', 'statistic', 'want'],
#  ['elimination', 'proof', 'satisfy', 'avoid', 'fan', 'club'],
#  ['doctor',
#   'doctor',
#   'effect',
#   'etc',
#   'doctor',
#   'kid',
#   'language',
#   'crusader'],
#  ['claim', 'family', 'trip', 'world', 'time', 'fact'],
#  ['business',
#   'mask',
#   'customer',
#   'proof',
#   'status',
#   'proof',
#   'mask',
#   'policy'],
#  ['state'],
#  ['point', 'train', 'airline', 'proof', 'province', 'app', 'train', 'holiday'],
#  ['study', 'risk', 'effect', 'brother', 'amateur', 'bicycle', 'exhaustion'],
#  ['bribe', 'state', 'rate', 'discussion', 'tweet', 'mention'],
#  ['supply', 'medication', 'state', 'child', 'progress', 'maskshelp'],
#  ['histrionic',
#   'government',
#   'actor',
#   'argument',
#   'use',
#   'excuse',
#   'avoid',
#   'requirement'],
#  ['fault', 'liberty', 'point', 'reality'],
#  ['date', 'beer', 'license', 'name', 'home', 'address'],
#  ['hit', 'policy', 'employee', 'attend'],
#  ['child', 'seeing', 'premise', 'want', 'death', 'status', 'policy'],
#  ['brain',
#   'trust',
#   'ground',
#   'support',
#   'convoy',
#   'jurisdiction',
#   'mandate',
#   'cross_border'],
#  ['goal',
#   'stress',
#   'ear',
#   'stay',
#   'omicron',
#   'flu',
#   'precaution',
#   'life',
#   'life'],
#  ['tip'],
#  ['restriction', 'man'],
#  ['report', 'oscar', 'test', 'proof'],
#  ['age', 'bracket', 'rate', 'case', 'rate', 'graph'],
#  ['propaganda', 'school'],
#  ['status', 'intelligence'],
#  ['day', 'worker', 'visitor'],
#  ['reporter', 'pulp', 'email', 'reason', 'redefinition', 'fact', 'check'],
#  ['application', 'proof', 'version'],
#  ['encouragement',
#   'passport',
#   'plan',
#   'requirement',
#   'stick',
#   'thing',
#   'needle',
#   'yrs',
#   'work'],
#  ['stance', 'spin'],
#  ['mandate',
#   'city',
#   'folk',
#   'proof',
#   'indoor_dining',
#   'event',
#   'arena',
#   'gyms_theater',
#   'museum'],
#  ['history', 'context', 'tuskegee'],
#  ['center', 'permit', 'work', 'hospital'],
#  ['season', 'existence', 'change', 'argument', 'matter', 'deny'],
#  ['policy', 'science', 'time'],
#  ['proof', 'felony'],
#  ['help',
#   'business',
#   'school',
#   'team',
#   'pandemic',
#   'testing',
#   'reporting',
#   'solution',
#   'status'],
#  ['point', 'evidence'],
#  ['eye'],
#  ['rape', 'deserve', 'sun', 'end', 'triage', 'line', 'care'],
#  ['person', 'shot'],
#  [],
#  ['evidence', 'case'],
#  ['ambiguity',
#   'mask',
#   'drug',
#   'therapy',
#   'query',
#   'recomendation',
#   'year',
#   'efficacy',
#   'datum'],
#  ['passport',
#   'infection',
#   'rate',
#   'infection',
#   'mirror',
#   'rate',
#   'mandate',
#   'ontario'],
#  ['clock', 'dust', 'check'],
#  ['mask', 'talk', 'remedy'],
#  ['party', 'issue', 'party', 'opinion', 'siding', 'mask', 'hardship'],
#  ['datum',
#   'point',
#   'case_count',
#   'rate',
#   'availability',
#   'testing',
#   'availability',
#   'treatment',
#   'facility',
#   'decision',
#   'team',
#   'health',
#   'expert',
#   'leader'],
#  ['argument', 'child', 'passport', 'mention', 'effort', 'nuance'],
#  ['case', 'hospitalization', 'rate'],
#  ['restriction',
#   'mandate',
#   'employer',
#   'requirement',
#   'community',
#   'hospital',
#   'surgery'],
#  ['card'],
#  ['stop', 'idea', 'lifestyle', 'choice', 'kid', 'impact'],
#  ['credit', 'credit', 'arm'],
#  ['kudo', 'requirement', 'place'],
#  ['couple',
#   'program',
#   'guise',
#   'virus',
#   'jabbed',
#   'woman',
#   'issue',
#   'miscarriage',
#   'piece'],
#  ['course', 'question', 'answer', 'question'],
#  ['status', 'choice', 'virus', 'million', 'life', 'generation'],
#  ['rate', 'ontario', 'end', 'game', 'liberal'],
#  ['reading', 'tweet', 'time', 'death', 'rate', 'rate', 'rate'],
#  ['mandate', 'rule', 'business', 'mandate'],
#  ['thing', 'society', 'bit', 'death', 'scientist', 'virus'],
#  ['rate',
#   'case',
#   'hospitalization',
#   'risk',
#   'atm',
#   'outbreak',
#   'mask',
#   'badge',
#   'science',
#   'cac'],
#  ['fact',
#   'check',
#   'website',
#   'misinformation',
#   'context',
#   'foil',
#   'email',
#   'panic',
#   'redefine'],
#  ['status', 'detail'],
#  ['booster'],
#  ['shame',
#   'publish',
#   'type',
#   'article',
#   'scientist',
#   'manipulation',
#   'newspaper'],
#  ['point'],
#  ['clinic', 'time', 'noon', 'kid', 'school', 'parent', 'clinic', 'person'],
#  ['issue',
#   'ego',
#   'accuracy',
#   'datum',
#   'name',
#   'virus',
#   'animal',
#   'reservoir',
#   'source',
#   'claim',
#   'ism'],
#  ['status', 'fascist', 'terrorist', 'group'],
#  ['work', 'world', 'country', 'amount', 'booster'],
#  ['study',
#   'scientist',
#   'student',
#   'staff',
#   'mask',
#   'school',
#   'transmission',
#   'right_winger',
#   'mask'],
#  ['benefit', 'baffle', 'statistic', 'virus', 'fact'],
#  ['regime',
#   'politicization',
#   'way',
#   'highway',
#   'society',
#   'syringerat',
#   'control',
#   'heckler',
#   'truck'],
#  ['harden', 'thing', 'way', 'sense'],
#  ['leadership', 'end', 'winter', 'term', 'proof', 'student', 'semester'],
#  ['loosen',
#   'restriction',
#   'rate',
#   'booster',
#   'booster',
#   'protection',
#   'omicron'],
#  ['truck', 'right_wing', 'convoy', 'thing'],
#  [],
#  ['mask'],
#  ['hospital', 'head', 'budget', 'vote', 'handling', 'plot', 'rest'],
#  ['restriction', 'personality'],
#  ['chicken', 'death', 'rate', 'party'],
#  ['world', 'change'],
#  ['million', 'immunity', 'health', 'risk'],
#  ['note', 'rate', 'datum', 'rate', 'survey', 'result'],
#  ['plan', 'clinic', 'check', 'mate'],
#  ['traffic', 'health', 'doctor', 'duty', 'manager', 'site'],
#  ['rape', 'fuck', 'wrong'],
#  ['lot', 'prove'],
#  ['trucker_protest', 'state', 'proof', 'pandemic', 'management'],
#  ['flu', 'theater', 'segregation', 'hate', 'system'],
#  ['treat', 'night', 'time', 'mask', 'group', 'joy', 'music', 'earthling'],
#  [],
#  ['passport'],
#  ['game',
#   'student',
#   'card',
#   'comfort',
#   'color',
#   'shirt',
#   'grant',
#   'msriverproject'],
#  ['rate', 'percent', 'number'],
#  ['proof',
#   'policy',
#   'place',
#   'fall',
#   'logic',
#   'dropping',
#   'requirement',
#   'end',
#   'goal'],
#  ['network',
#   'misinformation',
#   'show',
#   'today',
#   'song',
#   'root',
#   'history',
#   'insanity',
#   'antivaxrs',
#   'war',
#   'radio',
#   'detail'],
#  ['look',
#   'world',
#   'restriction',
#   'lockdown',
#   'mandate',
#   'rate',
#   'blood',
#   'stone'],
#  ['illness', 'skin', 'card'],
#  ['equity', 'power', 'health', 'source', 'stat'],
#  ['neighborhood', 'rate', 'sparrow', 'creek', 'ord', 'dose'],
#  ['number', 'rate', 'infection', 'aspect', 'share', 'video'],
#  ['case', 'issue'],
#  ['life', 'passport', 'mandate', 'support'],
#  ['flu', 'number', 'flu'],
#  ['person', 'country', 'lot', 'goal'],
#  ['country',
#   'goal',
#   'percent',
#   'rate',
#   'talk',
#   'safety',
#   'measure',
#   'safety',
#   'measure',
#   'country',
#   'seesaw',
#   'erode',
#   'trust'],
#  ['theater', 'attend', 'class', 'finder', 'help', 'thank'],
#  ['hepburn', 'requirement', 'city', 'hepburn', 'facility', 'website'],
#  ['protection',
#   'infection',
#   'transmission',
#   'booster',
#   'protection',
#   'hospitalization',
#   'death'],
#  ['mask'],
#  [],
#  ['mandate', 'way'],
#  ['country',
#   'world',
#   'population',
#   'country',
#   'rate',
#   'maniac',
#   'logic',
#   'science'],
#  ['date', 'mos', 'past', 'infection', 'omicron', 'variant'],
#  ['plan',
#   'apostle',
#   'right',
#   'law',
#   'order',
#   'conservative',
#   'trucker',
#   'economy'],
#  ['team', 'league', 'season', 'playoff', 'team', 'game'],
#  ['situation', 'cost', 'restriction', 'rate'],
#  [],
#  ['crisis', 'push', 'mandate', 'age', 'enhance'],
#  ['mask', 'data', 'city'],
#  ['country',
#   'world',
#   'population',
#   'country',
#   'rate',
#   'maniac',
#   'logic',
#   'science'],
#  ['mistake'],
#  ['statistic', 'none', 'look', 'statistic', 'bias'],
#  ['class', 'residence', 'circ', 'residence'],
#  ['leverage', 'virus'],
#  ['mask', 'stop', 'generalization'],
#  ['program', 'business', 'path', 'business', 'recruitment'],
#  ['mask',
#   'truth',
#   'restriction',
#   'kid',
#   'adult',
#   'school',
#   'data',
#   'science',
#   'politic',
#   'noise'],
#  ['gestation',
#   'company',
#   'policy',
#   'company',
#   'drug',
#   'test',
#   'policy',
#   'refuse',
#   'workplace',
#   'place'],
#  ['border', 'movement'],
#  ['progress', 'status', 'shit', 'virus'],
#  ['outreach', 'gap', 'work', 'effort', 'strategy', 'death', 'country'],
#  ['pandemic'],
#  ['worry', 'concern', 'risk'],
#  ['program', 'time', 'dialog', 'canadian', 'tyrant'],
#  ['hospitalization', 'data', 'death', 'datum', 'omicron', 'coverage', 'case'],
#  ['territory', 'rate'],
#  ['player', 'team', 'hope', 'card', 'player', 'man', 'sixer', 'fan'],
#  ['mandate', 'metro', 'area', 'rate'],
#  ['premier', 'rule', 'visitor', 'state'],
#  ['school', 'play', 'music', 'experience', 'todaylaptop'],
#  [],
#  ['pregnancy', 'woman', 'risk', 'authority', 'case'],
#  ['death', 'hygiene', 'health'],
#  ['elite', 'pass'],
#  ['word', 'discussion', 'makes_sense', 'trick', 'credit'],
#  ['mandate', 'mandate', 'protest', 'country', 'status'],
#  ['fact', 'rate', 'teenager', 'frame', 'information', 'wrong'],
#  ['clue', 'nation'],
#  ['theater', 'requirement'],
#  ['thing', 'misinformation', 'rate', 'nation', 'misinformation', 'beginning'],
#  ['congrat',
#   'winner',
#   'prevention',
#   'challenge',
#   'competition',
#   'well',
#   'visit',
#   'rate'],
#  ['corn', 'pop', 'portrayal', 'economy', 'twitter', 'react', 'proof'],
#  ['mandate'],
#  ['birth', 'certificate', 'proof', 'cruise', 'welcome'],
#  ['mask', 'mandate', 'requirement'],
#  ['refusal', 'number', 'force'],
#  ['majority', 'attendee', 'employee', 'attendee', 'award', 'ceremony'],
#  ['booster', 'pass'],
#  ['ticket', 'show', 'taping', 'show', 'testing', 'pretend', 'hysteria'],
#  ['concert', 'event', 'venue', 'series', 'proof', 'test', 'hour', 'info'],
#  ['weekend', 'holiday', 'mask', 'syringe'],
#  ['show', 'proof', 'place'],
#  ['mandate', 'system', 'bit', 'mortality', 'event', 'month'],
#  ['immunization'],
#  ['render', 'immunity', 'system', 'goal', 'post', 'immunization', 'hack'],
#  ['liberal',
#   'attempt',
#   'divide',
#   'refusal',
#   'follow',
#   'science',
#   'root',
#   'cause'],
#  ['reporter', 'status', 'matter'],
#  ['mentality', 'rate', 'toilet'],
#  ['reassess',
#   'week',
#   'metric',
#   'case',
#   'hospital',
#   'admission',
#   'rate',
#   'asksavanity'],
#  ['rise',
#   'transmisibility',
#   'infection',
#   'booster',
#   'adult',
#   'hospitalization',
#   'child',
#   'example',
#   'con'],
#  ['conservative', 'campaign', 'end', 'disease', 'elite'],
#  ['work', 'chance'],
#  ['status', 'client'],
#  ['illness',
#   'care',
#   'patient',
#   'bag',
#   'base',
#   'rate',
#   'falsification',
#   'patient'],
#  ['shot', 'blood', 'test', 'trace', 'adult'],
#  ['variance', 'study', 'protection'],
#  ['teacher', 'job', 'anxiety', 'life'],
#  ['one', 'help', 'track', 'reaction', 'hunting'],
#  ['lie', 'mandate', 'liar'],
#  ['death', 'study', 'prevent'],
#  [],
#  ['day', 'pioneer', 'doctor', 'work', 'disease'],
#  ['day',
#   'government',
#   'job',
#   'today',
#   'news',
#   'finance',
#   'export',
#   'face',
#   'jeffrie',
#   'job',
#   'credit'],
#  ['friend', 'friend', 'choice'],
#  ['focus', 'risk', 'group', 'thing', 'year_old'],
#  ['planning', 'year', 'proof', 'card'],
#  ['search', 'group', 'site', 'place', 'kid', 'site', 'hospital'],
#  ['authority',
#   'coronavirus',
#   'case',
#   'record',
#   'spread',
#   'rate',
#   'absence',
#   'restriction',
#   'adult'],
#  ['rate', 'deadline', 'mandate'],
#  ['death',
#   'incline',
#   'end',
#   'date',
#   'lot',
#   'auto',
#   'immunity',
#   'post',
#   'stroke'],
#  ['jurisdiction',
#   'end',
#   'mandate',
#   'level',
#   'case',
#   'metric',
#   'virus',
#   'testing',
#   'rate',
#   'endthemandate'],
#  ['removing',
#   'mandate',
#   'social_distance',
#   'mask',
#   'booster',
#   'freedom',
#   'choice'],
#  ['service',
#   'one',
#   'stroke',
#   'heart_attack',
#   'war',
#   'biden',
#   'country',
#   'part',
#   'world'],
#  ['infection',
#   'protection',
#   'infection',
#   'level',
#   'infection',
#   'way',
#   'measure',
#   'infection'],
#  ['rate', 'infection', 'child'],
#  ['percentage', 'population', 'immunity', 'infection'],
#  ['government', 'health', 'measure'],
#  ['restriction',
#   'mandate',
#   'concern',
#   'society',
#   'benefit',
#   'government',
#   'safety'],
#  ['state', 'status', 'bout'],
#  ['school',
#   'place',
#   'quality',
#   'mask',
#   'value',
#   'kind',
#   'mask',
#   'rapid_test',
#   'case'],
#  ['teacher', 'status', 'list', 'medication', 'one', 'child'],
#  ['hole', 'border', 'loss', 'vehicle', 'society', 'crowd'],
#  ['team', 'news', 'cycle', 'matter', 'hour', 'status', 'love', 'baseball'],
#  ['antibody', 'immunity', 'population', 'fact', 'survivor', 'thing', 'tunnel'],
#  ['nose', 'harm', 'liberal', 'body', 'choice', 'guess'],
#  ['month', 'appointment', 'child', 'approval'],
#  ['datum',
#   'cac',
#   'omicron',
#   'period',
#   'hospitalization',
#   'condition',
#   'adult',
#   'hospital',
#   'rate',
#   'idaho'],
#  ['infection'],
#  ['track', 'infection', 'rate', 'rate'],
#  ['exemption', 'cmon', 'exemption', 'exemption', 'rate', 'idea'],
#  ['idea', 'trouble', 'wear_mask', 'child', 'school', 'issue', 'kid', 'rate'],
#  ['smallpox', 'thank'],
#  ['choice', 'community', 'talking_point', 'country', 'requirement'],
#  ['seasonal_flu', 'thank', 'measure', 'restriction'],
#  ['normality', 'mask', 'patient', 'staff', 'office', 'grief', 'option'],
#  ['show', 'card', 'place', 'site', 'time', 'night', 'place'],
#  ['part', 'expertise', 'death'],
#  ['window', 'effectiveness', 'effect'],
#  ['amount', 'tweet', 'trade', 'deadline', 'status', 'whomever'],
#  ['doctor', 'evening', 'pajama', 'death', 'immunity', 'look', 'mirror'],
#  ['protester', 'country', 'rate', 'mandate', 'auto_maker', 'production'],
#  ['interest', 'today', 'test', 'order', 'bar'],
#  ['card', 'mask'],
#  ['reason', 'reason', 'thing', 'condition', 'allergy', 'choice', 'disorder'],
#  ['government', 'worker', 'year', 'information'],
#  ['print', 'download', 'copy', 'eye'],
#  ['fact', 'today', 'passport', 'name', 'ram', 'leave', 'country'],
#  ['record'],
#  ['elite', 'shout'],
#  ['proof',
#   'border',
#   'trucker',
#   'exemption',
#   'call',
#   'trucker',
#   'terrorist',
#   'trucker'],
#  ['future'],
#  ['awareness', 'brigade'],
#  ['proof', 'place', 'student'],
#  ['fact_checker'],
#  ['state', 'today', 'city', 'mandate', 'museum', 'arena'],
#  ['represent', 'government', 'life', 'government', 'control', 'life', 'point'],
#  ['love', 'life', 'country', 'mandate', 'school', 'student', 'loan'],
#  ['company', 'work', 'policy', 'leader', 'mask', 'policy', 'employee', 'site'],
#  [],
#  ['brain', 'abscess', 'brain', 'cancer', 'category', 'week', 'thing'],
#  ['definition',
#   'immunity',
#   'disease',
#   'contract',
#   'disease',
#   'contract',
#   'disease',
#   'increase',
#   'risk',
#   'myocarditis'],
#  ['ignorance', 'circus', 'status'],
#  ['joke', 'orgy', 'street', 'orgy', 'mass', 'event', 'aneurysm'],
#  ['world', 'government', 'capacity', 'thinking', 'analysis', 'prevent'],
#  ['play', 'emergence', 'omicron', 'guest', 'status', 'detail'],
#  ['think',
#   'amount',
#   'tyrant',
#   'power',
#   'year',
#   'herd_immunity',
#   'target',
#   'virus',
#   'endemic',
#   'move',
#   'life'],
#  ['elixir', 'man', 'government'],
#  ['science',
#   'reality',
#   'year',
#   'harm',
#   'science',
#   'anthology',
#   'bullshit',
#   'child'],
#  ['attempt',
#   'tea',
#   'shift',
#   'blame',
#   'child',
#   'child',
#   'age',
#   'help',
#   'formulation',
#   'dosage',
#   'child',
#   'weight'],
#  ['time', 'require', 'mask', 'passport', 'test'],
#  ['host', 'rabie', 'clinic', 'pet'],
#  ['record', 'clinic', 'retrieve'],
#  [],
#  ['version',
#   'idea',
#   'section',
#   'page',
#   'health',
#   'project',
#   'proportion',
#   'group',
#   'time',
#   'proportionality',
#   'assumption'],
#  ['rate', 'town', 'mask', 'child', 'science'],
#  ['flag', 'rate', 'vast_majority'],
#  ['assumption', 'person', 'reason'],
#  ['county', 'rate', 'surge', 'case', 'delta'],
#  ['mom',
#   'report',
#   'number',
#   'journalist',
#   'touch',
#   'lack',
#   'transparency',
#   'hesitancy'],
#  ['respect',
#   'fear',
#   'watch',
#   'number',
#   'plan',
#   'weather',
#   'week',
#   'number',
#   'infection',
#   'increase',
#   'future',
#   'bright'],
#  ['nation', 'effort', 'fight', 'virus'],
#  ['act',
#   'collection',
#   'law',
#   'boost',
#   'health',
#   'authority',
#   'update',
#   'condition',
#   'time',
#   'time'],
#  ['approach',
#   'patio',
#   'occasion',
#   'wave',
#   'decision',
#   'restaurant',
#   'doubt',
#   'action',
#   'data',
#   'evidence',
#   'caution'],
#  ['virus', 'life', 'age', 'matter'],
#  ['reduce', 'variant', 'mutation'],
#  ['rate', 'bar'],
#  ['reporter', 'stuff', 'fact', 'soul', 'order'],
#  ['rate'],
#  ['yesterday', 'proof', 'policy', 'time', 'history', 'year', 'day', 'jury'],
#  ['note'],
#  ['rate', 'requirement', 'show', 'proof', 'pick', 'place', 'fin'],
#  ['community',
#   'rate',
#   'child',
#   'measure',
#   'vulnerability',
#   'infection',
#   'antibody'],
#  ['country',
#   'health',
#   'care',
#   'system',
#   'system',
#   'rate',
#   'blame',
#   'medicine'],
#  ['risk',
#   'level',
#   'kid',
#   'spread',
#   'protection',
#   'stall',
#   'part',
#   'teachers_union',
#   'point',
#   'word'],
#  ['collapse', 'hospital', 'system', 'death', 'area', 'watch', 'argument'],
#  ['country', 'adult', 'rate', 'restriction', 'enemy', 'punishing'],
#  ['idea', 'lock', 'screen', 'wallpaper', 'card'],
#  ['period',
#   'immunity',
#   'benefit',
#   'immunity',
#   'variant',
#   'defeating',
#   'immunity'],
#  ['customer', 'business', 'employee', 'customer', 'fear', 'legal_action'],
#  ['rate', 'question', 'deeperissue', 'one'],
#  ['month', 'need'],
#  ['proof', 'requirement', 'twin_citie'],
#  ['trade', 'mandate', 'term'],
#  ['criterion', 'inclusion', 'disease'],
#  ['freedom', 'science', 'one', 'disease', 'disability', 'schedule'],
#  ['debate', 'restriction', 'leader', 'country', 'rate', 'restriction'],
#  ['bribery'],
#  ['status', 'indicator', 'party', 'teen', 'fool', 'reason', 'hope'],
#  ['control',
#   'obesity',
#   'cohort',
#   'yrs',
#   'decade',
#   'mask',
#   'anger',
#   'freedom',
#   'cost',
#   'death'],
#  ['mask', 'street', 'regard', 'show', 'status'],
#  ['death', 'threat', 'kid', 'video', 'school', 'clinic'],
#  ['card'],
#  ['lot', 'spread', 'scientist'],
#  ['alteration', 'population', 'number', 'post', 'case'],
#  ['look',
#   'obsolescence',
#   'item',
#   'life',
#   'force',
#   'industry',
#   'pharma',
#   'industry',
#   'money',
#   'government',
#   'society'],
#  ['thread', 'weapon', 'pandemic', 'sense', 'risk'],
#  ['profuse',
#   'state',
#   'checkout',
#   'replicating',
#   'virus',
#   'spike',
#   'cell',
#   'body'],
#  ['status', 'litmus', 'test', 'test'],
#  ['thing',
#   'government',
#   'field',
#   'segregation',
#   'punishment',
#   'government',
#   'work',
#   'country',
#   'pawn'],
#  ['load', 'crap', 'mask', 'word', 'sense', 'transmission', 'fact'],
#  ['party',
#   'overreach',
#   'problem',
#   'bully',
#   'mode',
#   'morning',
#   'municipality',
#   'school',
#   'university',
#   'increase',
#   'rate',
#   'hospital',
#   'hypocrisy'],
#  ['pillar',
#   'policy',
#   'stay',
#   'place',
#   'argument',
#   'testing',
#   'requirement',
#   'community'],
#  ['burger', 'fry', 'card', 'day'],
#  ['reason', 'employment', 'lawyer', 'termination', 'belief', 'status'],
#  ['mandate', 'arena', 'law', 'path', 'work', 'requirement', 'eye'],
#  ['picture', 'death', 'campaign'],
#  ['status', 'idea', 'status', 'idea', 'mutating'],
#  [],
#  ['premium', 'load', 'group', 'life', 'insurance', 'employer', 'area'],
#  ['course', 'thing', 'live', 'immunity', 'repeat'],
#  ['country',
#   'rubella',
#   'half',
#   'rubella',
#   'transmission',
#   'rubella',
#   'elimination',
#   'protect',
#   'baby',
#   'country',
#   'coverage'],
#  ['legislator',
#   'amendment',
#   'prohibit',
#   'discrimination',
#   'status',
#   'orientation',
#   'gender',
#   'identity'],
#  ['shot'],
#  ['rate',
#   'map',
#   'show',
#   'work',
#   'time',
#   'delivery',
#   'kid',
#   'adult',
#   'urgencyofequity'],
#  ['hospital', 'nurse', 'point', 'knife', 'drawer'],
#  ['end', 'mandate'],
#  ['path', 'want'],
#  ['omicron',
#   'evade',
#   'quality',
#   'mask',
#   'leader',
#   'responsibility',
#   'health',
#   'time',
#   'example'],
#  ['booster', 'rate', 'kid', 'work', 'way', 'meantime', 'lot', 'damage'],
#  ['mask', 'transmission', 'community', 'area', 'person', 'event'],
#  ['opinion',
#   'store',
#   'sporting_event',
#   'concert',
#   'capacity',
#   'proof',
#   'mask',
#   'peer',
#   'pressure',
#   'jay'],
#  ['rate', 'state'],
#  ['trick', 'plan', 'shut', 'virus'],
#  ['effect', 'omicron', 'spread', 'size', 'spread', 'omicron'],
#  ['math', 'commission', 'vote', 'level', 'vote', 'illegal', 'rinosalazar'],
#  ['chance',
#   'hospital',
#   'chance',
#   'infection',
#   'place',
#   'variant',
#   'infection',
#   'omicron',
#   'line',
#   'defense'],
#  ['epidemiologist',
#   'health',
#   'expert',
#   'twitter',
#   'user',
#   'expertise',
#   'field'],
#  ['option', 'immune', 'recover', 'stop', 'concept'],
#  ['increase', 'death', 'picture', 'death'],
#  ['age', 'sex', 'comparison', 'risk', 'risk', 'source'],
#  ['child', 'adult', 'booster', 'need', 'booster', 'punishment'],
#  ['comparison',
#   'sex',
#   'pre_existing',
#   'condition',
#   'significance',
#   'comorbiditie'],
#  ['mandate',
#   'think',
#   'snowflake',
#   'extortion',
#   'terrorism',
#   'problem',
#   'gas',
#   'pollute',
#   'silly',
#   'value',
#   'markup'],
#  ['requirement',
#   'mandate',
#   'infection',
#   'rate',
#   'number',
#   'decision',
#   'amount',
#   'year'],
#  ['rate', 'rate', 'death', 'rate'],
#  ['rate',
#   'infection',
#   'rate',
#   'effect',
#   'limo',
#   'guessing',
#   'death',
#   'day',
#   'cardio',
#   'event'],
#  ['laboratory',
#   'virus',
#   'toilet',
#   'forget',
#   'laboratory',
#   'generation',
#   'virus'],
#  ['rate', 'infection', 'child'],
#  ['mandate', 'question', 'mandate'],
#  ['day', 'clinic', 'walk', 'shot', 'well', 'booster', 'community', 'event'],
#  ['wave', 'horizon', 'pier', 'foot', 'half', 'firetheucp'],
#  ['infection',
#   'boost',
#   'immunity',
#   'health',
#   'problem',
#   'damage',
#   'immune_system',
#   'word'],
#  ['virus',
#   'opportunity',
#   'time',
#   'person',
#   'mask',
#   'transmission',
#   'probability',
#   'infection',
#   'mutation',
#   'method',
#   'population',
#   'page'],
#  ['truth'],
#  ['rate', 'position', 'state', 'policy'],
#  ['proof', 'crack_pipe'],
#  [],
#  ['time', 'card'],
#  ['level',
#   'place',
#   'booster',
#   'rate',
#   'wave',
#   'infection',
#   'place',
#   'criterion',
#   'wane',
#   'cycle'],
#  ['hurting', 'team', 'championship', 'time', 'player'],
#  ['rate'],
#  ['service', 'code', 'code'],
#  ['trust',
#   'individual',
#   'man',
#   'heart',
#   'condition',
#   'exemption',
#   'avoid',
#   'thing'],
#  ['body'],
#  ['state', 'line', 'criterion', 'state', 'death', 'rate', 'rate'],
#  ['worry', 'pseudo', 'damage', 'life', 'save'],
#  ['status', 'hospitalization', 'couple', 'thinking', 'work'],
#  ['measle', 'jeopardize', 'jeopardizing'],
#  ['mask',
#   'evidence',
#   'hospital',
#   'death',
#   'area',
#   'rate',
#   'mandate',
#   'republican',
#   'charge'],
#  ['capacity', 'tolerance'],
#  ['time', 'hospital', 'stage', 'med', 'treatment'],
#  ['plan', 'passport', 'situation', 'masking', 'time', 'news'],
#  ['harm_reduction'],
#  ['month', 'shitty'],
#  ['occupier', 'trucker', 'path', 'freedom', 'disease', 'protection', 'health'],
#  ['air',
#   'gas',
#   'inflation',
#   'business',
#   'massless',
#   'refuse',
#   'life',
#   'policy'],
#  ['president',
#   'case',
#   'biden',
#   'team',
#   'program',
#   'economy',
#   'sense',
#   'president',
#   'control',
#   'economy'],
#  ['data', 'decade', 'decade', 'campaign', 'place', 'data', 'measle'],
#  ['mandate', 'wave'],
#  ['map', 'push', 'end', 'mandate'],
#  ['mandate',
#   'kudo',
#   'contradiction',
#   'choice',
#   'thing',
#   'language',
#   'quebec',
#   'lot',
#   'part',
#   'time',
#   'libertarian'],
#  ['kill_bacterium'],
#  [],
#  ['case',
#   'removal',
#   'school',
#   'student',
#   'mask',
#   'school',
#   'student',
#   'mandate'],
#  ['holiday', 'campaign', 'time', 'paperwork', 'care', 'lack', 'work'],
#  ['language', 'definition', 'prevent', 'user'],
#  ['adult', 'mandate', 'rate', 'child', 'indicator', 'mandate'],
#  ['day', 'wording', 'directive', 'absence', 'pay'],
#  ['mandate', 'card', 'restaurant', 'matter', 'time'],
#  ['help', 'variant', 'variant', 'schedule', 'appointment'],
#  ['care', 'track', 'train'],
#  ['rate', 'part'],
#  ['mask', 'accessibility', 'risk', 'pandemic'],
#  ['attack', 'power', 'pass', 'shame', 'apartheid', 'damage'],
#  ['card', 'ease', 'country'],
#  ['case',
#   'share',
#   'visitation',
#   'visitor',
#   'inpatient',
#   'admission',
#   'exception',
#   'requirement',
#   'visitor',
#   'proof'],
#  ['restriction',
#   'politic',
#   'utilization',
#   'hospital',
#   'resource',
#   'neoliberalism'],
#  ['risk',
#   'flu',
#   'illness',
#   'flu',
#   'virus',
#   'flu',
#   'shot',
#   'couple',
#   'week',
#   'flu',
#   'protect',
#   'virus',
#   'flu'],
#  ['help', 'condition', 'risk'],
#  ['part'],
#  ['example', 'status', 'list', 'none', 'business', 'list'],
#  ['mask', 'choice'],
#  ['year',
#   'chance',
#   'death',
#   'infection',
#   'year',
#   'death',
#   'infection',
#   'person',
#   'death',
#   'person',
#   'worker',
#   'chill',
#   'risk'],
#  ['drop', 'death', 'mass', 'increase', 'excess_death'],
#  ['anthrax', 'point'],
#  ['majority', 'death', 'immunity', 'boost', 'risk', 'profile'],
#  ['life', 'year', 'retirement', 'lockdown', 'mandate', 'canadian'],
#  ['mode',
#   'denial',
#   'coercion',
#   'discrimination',
#   'bread',
#   'butter',
#   'platform',
#   'place'],
#  ['fact',
#   'majority',
#   'death',
#   'outbreak',
#   'care',
#   'home',
#   'environment',
#   'virus',
#   'measure',
#   'sense'],
#  ['needle', 'freedom', 'freedom', 'refuse', 'health', 'policy', 'mask'],
#  ['worry', 'case', 'community', 'child', 'keeping', 'case'],
#  ['weight', 'status', 'manufacturer', 'use', 'individual'],
#  ['priest', 'protest'],
#  ['address', 'outreach', 'program', 'adult', 'million', 'child'],
#  ['affect', 'job', 'mandate', 'restriction'],
#  ['card', 'crime', 'year'],
#  ['founder',
#   'self',
#   'law',
#   'charter',
#   'removal',
#   'travel',
#   'law',
#   'suit',
#   'rest',
#   'border',
#   'line'],
#  ['proof'],
#  ['melanie',
#   'percentage',
#   'bit',
#   'estimation',
#   'rate',
#   'ontario',
#   'rate',
#   'increase',
#   'time',
#   'move'],
#  ['question', 'plan', 'force', 'dropping', 'restriction', 'situation'],
#  ['number', 'rate', 'number', 'disease'],
#  ['night',
#   'fire',
#   'guitar',
#   'door',
#   'show',
#   'guest',
#   'proof',
#   'time',
#   'change'],
#  ['impact',
#   'workforce',
#   'rate',
#   'challenge',
#   'burnout',
#   'leave',
#   'rate',
#   'loss',
#   'science',
#   'impact'],
#  ['status'],
#  ['night', 'proof', 'film'],
#  ['virus', 'mutation'],
#  ['net', 'decade', 'medicine'],
#  ['person'],
#  ['change', 'definition', 'system', 'legitimize', 'gene', 'activation', 'job'],
#  ['death',
#   'increase',
#   'issue',
#   'health',
#   'issue',
#   'government',
#   'care',
#   'health',
#   'mandate',
#   'virus'],
#  ['hospitalization', 'death', 'country', 'rate'],
#  ['passport', 'mask', 'restriction'],
#  ['politician', 'relation'],
#  [],
#  ['datum', 'protection', 'risk', 'death', 'infection', 'study'],
#  ['move', 'move', 'chemistry'],
#  ['comparison', 'car'],
#  ['status'],
#  ['hero', 'city', 'lawsuit', 'markmyword'],
#  ['history', 'virus', 'virus', 'coincidence'],
#  ['ad',
#   'stock',
#   'lot',
#   'westbrook',
#   'contract',
#   'rest',
#   'team',
#   'bait',
#   'bag',
#   'change'],
#  ['face', 'downtown', 'summering', 'setting', 'status'],
#  ['rate',
#   'staff',
#   'adult',
#   'area',
#   'correlation',
#   'mask',
#   'mandate',
#   'rate',
#   'direction',
#   'mandate'],
#  ['tuberculosis', 'blanket', 'child', 'body', 'bag', 'movie'],
#  ['help',
#   'case',
#   'person',
#   'justifie',
#   'privilege',
#   'privilege',
#   'sense',
#   'responsibility',
#   'duty'],
#  ['misinformation',
#   'disinformation',
#   'riot',
#   'rioter',
#   'immigration',
#   'border',
#   'activity',
#   'law',
#   'order',
#   'terrorism',
#   'mail',
#   'ballot',
#   'ballot',
#   'validation'],
#  ['definition', 'definition', 'definition', 'definition', 'fact'],
#  ['mandate',
#   'democracy',
#   'politic',
#   'part',
#   'division',
#   'bean',
#   'pillar',
#   'democracy',
#   'law',
#   'representation',
#   'knowledge'],
#  ['bill', 'operation', 'cost'],
#  ['email'],
#  ['level', 'understanding'],
#  ['hocus', 'requirement', 'indoor', 'business'],
#  ['datum', 'week', 'spike', 'infection', 'correlation', 'scientist'],
#  ['sars_cov',
#   'infection',
#   'hospitalization',
#   'death',
#   'dose',
#   'dose',
#   'person'],
#  ['case', 'death', 'dozen', 'life', 'year'],
#  ['government', 'work', 'stir', 'pot', 'twitter', 'oscar', 'event', 'test'],
#  ['rate',
#   'nightmare',
#   'school',
#   'change',
#   'mandate',
#   'lack',
#   'care',
#   'decision'],
#  ['bulletin',
#   'year',
#   'pastor',
#   'letter',
#   'church',
#   'trad',
#   'publication',
#   'teaching'],
#  ['virus',
#   'population',
#   'variant',
#   'stop',
#   'limit',
#   'mutation',
#   'hospital',
#   'hospital'],
#  ['coronaviruse', 'virus', 'booster', 'shot'],
#  ['reason', 'ordeal'],
#  ['thank', 'recover', 'morning', 'cousin', 'battle', 'dishonesty'],
#  ['put', 'car', 'place', 'face', 'consequence', 'decision'],
#  ['mandate'],
#  ['parent', 'school', 'head', 'child', 'county', 'rate', 'positivity', 'mask'],
#  ['definition',
#   'definition',
#   'defense',
#   'level',
#   'vitamin',
#   'definition',
#   'defense',
#   'infection',
#   'equate'],
#  ['point', 'stranger', 'appointment', 'spring'],
#  ['laker', 'asset', 'upgrade', 'roster'],
#  ['thought', 'prayer', 'proof', 'friend'],
#  ['recognition',
#   'contagion',
#   'phase',
#   'pandemic',
#   'point',
#   'matter',
#   'opinion',
#   'day',
#   'respect',
#   'objectivity'],
#  ['number', 'rate', 'population', 'number', 'group', 'fraction', 'population'],
#  ['situation', 'today', 'mind', 'plan', 'recommend', 'government', 'measure'],
#  ['flyer', 'site', 'today', 'paper', 'door', 'site', 'site', 'way'],
#  [],
#  ['think', 'fact', 'risk', 'oop'],
#  ['house', 'oscar', 'entry', 'mask', 'discussion', 'deadline'],
#  ['cruise',
#   'state',
#   'day',
#   'testing',
#   'boarding',
#   'test',
#   'none',
#   'ability',
#   'time'],
#  ['kid',
#   'family',
#   'argument',
#   'kid',
#   'mild_symptom',
#   'cold',
#   'nonsense',
#   'dialog'],
#  ['status', 'impact', 'booster', 'kid', 'case', 'end', 'case', 'fever', 'day'],
#  ['trucker', 'need', 'mask', 'money'],
#  ['test', 'health', 'measure', 'heap', 'bump', 'case', 'reporting'],
#  ['clinic'],
#  ['mask', 'participation', 'child'],
#  ['headline', 'article', 'protection', 'fact', 'reality', 'statement'],
#  ['track', 'blocking', 'demand', 'government', 'mandate'],
#  ['infection', 'transmission', 'solution', 'stock'],
#  ['define', 'word', 'outbreak', 'survival', 'instinct', 'number'],
#  ['rate', 'increase'],
#  ['mandate', 'net', 'franchise'],
#  ['story',
#   'doctor',
#   'child',
#   'abuse',
#   'position',
#   'responsibility',
#   'gain',
#   'license'],
#  ['vac', 'rate', 'country', 'example', 'rate', 'case'],
#  ['primary_serie', 'sign', 'body', 'building', 'protection'],
#  [],
#  ['country', 'mandate', 'war', 'deal', 'work', 'peace'],
#  ['immunity',
#   'person',
#   'pal',
#   'immunity',
#   'wave',
#   'death',
#   'need',
#   'mask',
#   'etc',
#   'need',
#   'fall',
#   'wave'],
#  ['help',
#   'effort',
#   'share',
#   'science',
#   'phone',
#   'community',
#   'rate',
#   'thank',
#   'enthusiasm'],
#  ['mask'],
#  ['month',
#   'government',
#   'force',
#   'population',
#   'infection',
#   'transmission',
#   'party',
#   'leader',
#   'water'],
#  ['report', 'oscar', 'test', 'proof'],
#  ['protest', 'year', 'persuasion', 'attention', 'mandate', 'year', 'one'],
#  ['antivaxxer', 'import', 'article', 'antivaxxer', 'evidence'],
#  ['year', 'woman', 'life', 'claim', 'science', 'disgrace', 'prison'],
#  ['way',
#   'infection',
#   'pregnancy',
#   'date',
#   'flu',
#   'talk',
#   'provider',
#   'infection',
#   'pregnancy'],
#  ['thousand', 'card'],
#  ['virus', 'induce'],
#  ['base', 'proof', 'policy', 'province', 'timeframe', 'measure'],
#  ['claim', 'event', 'evidence', 'example', 'history', 'polio'],
#  ['mandate', 'play'],
#  ['question', 'week', 'canadian', 'science', 'way', 'end', 'canadian'],
#  ['sign',
#   'establishment',
#   'one',
#   'government',
#   'rule',
#   'passport',
#   'lockdown'],
#  ['option', 'information', 'resource', 'part', 'neighbor', 'today'],
#  ['street'],
#  ['clinic', 'couple', 'hour', 'runner', 'ballroom', 'student', 'union'],
#  ['mask', 'ink', 'point', 'virus', 'reduction', 'transmission'],
#  ['night', 'comedy', 'door', 'show', 'guest', 'proof', 'time', 'change'],
#  ['business', 'bar', 'restaurant', 'mask', 'freedom'],
#  ['playoff', 'requirement'],
#  ['mildness',
#   'country',
#   'rate',
#   'percent',
#   'population',
#   'percent',
#   'shot',
#   'denmark'],
#  ['problem', 'child', 'kid', 'parent'],
#  ['guideline', 'rate', 'cali', 'rate', 'state'],
#  ['opposition',
#   'leader',
#   'question',
#   'debate',
#   'rate',
#   'mandate',
#   'man',
#   'lead',
#   'country'],
#  ['whistle',
#   'myocarditis',
#   'chest',
#   'athlete',
#   'field',
#   'citizen',
#   'exhaust',
#   'truck',
#   'year',
#   'minute'],
#  ['evidence', 'start', 'stat', 'mask', 'cable', 'gig'],
#  ['convince', 'kink', 'shaming', 'article', 'share', 'time', 'want'],
#  ['conversation', 'mandate', 'distraction', 'leadership', 'tool', 'work'],
#  ['lifetime', 'death', 'sentence', 'condition', 'testament', 'science'],
#  ['fly', 'airline', 'institute', 'mandate', 'health', 'health'],
#  ['room', 'card', 'mask', 'link'],
#  ['place', 'word', 'course', 'juju'],
#  ['minority', 'feeling', 'kid', 'fuck'],
#  ['rate', 'group', 'doctor'],
#  ['risk', 'status'],
#  ['conversation',
#   'voice',
#   'host',
#   'race',
#   'theorist',
#   'right',
#   'activist',
#   'doctor'],
#  ['solution', 'variant', 'body', 'time', 'premier', 'protection'],
#  ['man', 'lot', 'time', 'gulag', 'hostess'],
#  ['decision'],
#  ['country', 'rate', 'end', 'mandate', 'country', 'canadian', 'restriction'],
#  ['requirement',
#   'word',
#   'name',
#   'ad',
#   'hominem',
#   'attack',
#   'argument',
#   'noodle'],
#  [],
#  ['policy',
#   'choice',
#   'wedge',
#   'conservative',
#   'issue',
#   'knee',
#   'jerk',
#   'choice',
#   'step',
#   'conservative'],
#  ['dot',
#   'incompetence',
#   'infection',
#   'epidemic',
#   'proportion',
#   'trump',
#   'recession',
#   'plan',
#   'recession',
#   'program'],
#  ['story'],
#  ['coverage',
#   'insanity',
#   'anti',
#   'threat',
#   'privilege',
#   'class',
#   'ticket',
#   'ticket',
#   'price'],
#  ['mask', 'world', 'access', 'variation', 'infection', 'death'],
#  ['sixer', 'ass'],
#  ['kid', 'virus', 'risk', 'factor', 'population', 'rate'],
#  ['status', 'net', 'team', 'shoot', 'throw', 'playoff', 'year', 'line'],
#  ['regimen', 'go', 'year', 'start'],
#  ['pandemic', 'band', 'thug', 'journalist'],
#  ['record'],
#  ['mask', 'help', 'wear_mask'],
#  ['doctors_nurse',
#   'scientist',
#   'researcher',
#   'family',
#   'relative',
#   'world',
#   'disease',
#   'death',
#   'smallpox',
#   'limit'],
#  ['difference', 'family', 'life', 'friendship', 'person', 'coronavirus'],
#  ['passport',
#   'useless',
#   'reinforcement',
#   'division',
#   'punishment',
#   'trend',
#   'center',
#   'doubt',
#   'scare'],
#  ['shot', 'dam'],
#  ['milk', 'pressure', 'number', 'mandate', 'poll'],
#  ['point', 'demand', 'status', 'segregation'],
#  ['school', 'staff', 'school', 'staff', 'education', 'approach'],
#  ['protest',
#   'mandate',
#   'actuality',
#   'liberal',
#   'election',
#   'minority',
#   'vote',
#   'district'],
#  ['social_distance', 'virus'],
#  ['study', 'expert', 'locale', 'report', 'difference', 'mask', 'school'],
#  ['time', 'creep', 'process', 'cut', 'virus', 'host', 'supply', 'end'],
#  ['comment', 'case', 'risking', 'disease', 'death', 'purpose'],
#  [],
#  ['sex', 'race', 'religion', 'status'],
#  ['approach', 'school', 'school', 'basis', 'rate', 'school', 'mandate'],
#  ['question', 'reason', 'rate'],
#  ['policy', 'place', 'state', 'requirement'],
#  ['rushing', 'measure', 'rate', 'population', 'science', 'result', 'variant'],
#  ['factor', 'mean', 'immunity', 'infection', 'time', 'hospital'],
#  [],
#  ['cripe', 'weeks_ago', 'decrease', 'go', 'spike', 'rate'],
#  ['customer', 'side', 'morning', 'show', 'proof'],
#  ['vast_majority'],
#  ['issue', 'rate', 'government', 'mask', 'government'],
#  ['state', 'status', 'hospital', 'statistic'],
#  ['attack', 'integrity', 'state', 'business', 'treatment'],
#  ['today', 'answer', 'question', 'way', 'restriction'],
#  ['warning', 'weekend', 'card', 'card'],
#  ['week', 'statement', 'force', 'word'],
#  ['day', 'definition', 'method'],
#  ['freedom', 'travel', 'force', 'card'],
#  ['decline', 'case', 'spot', 'retire', 'policy', 'threat', 'precaution'],
#  ['center'],
#  ['adult',
#   'booster',
#   'time',
#   'protection',
#   'infection',
#   'adult',
#   'stay',
#   'date'],
#  ['development',
#   'approach',
#   'vilify',
#   'therapeutic',
#   'treatment',
#   'man',
#   'lack',
#   'transmission',
#   'control'],
#  ['jab', 'force', 'imagine', 'trump', 'mandating'],
#  ['inventor', 'medium', 'thing', 'omitting', 'fact', 'force'],
#  ['research', 'impact', 'risk'],
#  ['impression', 'lot', 'feel', 'precaution'],
#  ['game', 'daughter', 'weekend'],
#  ['show', 'joke', 'coverage', 'protest', 'joke', 'nonsense', 'shove'],
#  ['talking', 'commercial'],
#  ['generation', 'million', 'survivor', 'life', 'brain', 'reason'],
#  ['administration',
#   'transmission',
#   'follower',
#   'mask',
#   'end',
#   'result',
#   'variant',
#   'death'],
#  ['bull', 'inhibitor', 'word', 'reason'],
#  ['support', 'nice_try'],
#  ['efficacy', 'person', 'infection', 'infection', 'protection'],
#  ['nation', 'travel_ban', 'entry', 'death', 'blow', 'psychosis', 'break'],
#  ['key', 'anti_baxter', 'hostage', 'country', 'policy', 'language', 'sense'],
#  ['co',
#   'paper',
#   'factor',
#   'variable',
#   'intent',
#   'uptake',
#   'change',
#   'campaign'],
#  ['fi', 'driver'],
#  ['request',
#   'proof',
#   'check',
#   'makes_sense',
#   'business',
#   'fyi',
#   'discrimination'],
#  ['author',
#   'decision',
#   'favor',
#   'disease',
#   'article',
#   'mechanism',
#   'proof',
#   'issue'],
#  ['confer',
#   'rod',
#   'infection',
#   'antigen',
#   'exposure',
#   'response',
#   'variant',
#   'terminal_center'],
#  ['thank',
#   'fight',
#   'demand',
#   'answer',
#   'datum',
#   'administration',
#   'mandate',
#   'truth'],
#  ['protest', 'case', 'family', 'case', 'nonsense'],
#  ['way'],
#  ['doctor', 'want'],
#  ['season', 'status', 'player', 'rule'],
#  ['disease', 'effect', 'refuse'],
#  ['city', 'mandate', 'child', 'school', 'let'],
#  ['freakin', 'parrot', 'tool'],
#  ['infection', 'transmission'],
#  ['produce', 'infection'],
#  ['summer'],
#  ['month', 'forum', 'question', 'virus'],
#  ['life',
#   'insurance',
#   'industry',
#   'target',
#   'premium',
#   'load',
#   'employer',
#   'county',
#   'rate',
#   'risk',
#   'factor'],
#  ['morbidity',
#   'read',
#   'link',
#   'type',
#   'diabetes',
#   'evidence',
#   'today',
#   'risk',
#   'benefit'],
#  ['line', 'defense', 'infection', 'onevaxtwolive'],
#  ['rate',
#   'city',
#   'worker',
#   'audience',
#   'collar',
#   'cop',
#   'teacher',
#   'sanitation'],
#  [],
#  ['outbreak', 'bullshit', 'mandate', 'proof'],
#  ['cheerleader', 'mandate', 'terrorist'],
#  ['conclusion',
#   'form',
#   'tool',
#   'coercion',
#   'force',
#   'kind',
#   'disguise',
#   'politician',
#   'impose'],
#  ['future',
#   'bet',
#   'year',
#   'season',
#   'bet',
#   'money',
#   'team',
#   'rate',
#   'roster',
#   'superbowl',
#   'advantage'],
#  ['face', 'day', 'infection', 'year', 'month', 'time', 'mask', 'rate'],
#  ['netsareunfair'],
#  ['death', 'rate', 'child'],
#  ['thing', 'wonder', 'show', 'proof'],
#  ['definition', 'prevent', 'history', 'herd_immunity'],
#  ['kid',
#   'booster',
#   'clinic',
#   'child',
#   'child',
#   'booster',
#   'school',
#   'nurse',
#   'info'],
#  ['country', 'requirement', 'mandate'],
#  ['evidence', 'risk'],
#  ['rate', 'level'],
#  ['way', 'math', 'way'],
#  ['practice'],
#  ['chance', 'mandate', 'reason', 'nice_try'],
#  ['etc',
#   'meaning',
#   'wastewater',
#   'treatment',
#   'respect',
#   'infection',
#   'trend'],
#  ['effect', 'reporting', 'case', 'status'],
#  ['condition', 'regret'],
#  ['week', 'ifr', 'death', 'rate'],
#  ['reason', 'reason', 'moderation', 'norm', 'debate', 'consideration'],
#  ['distinction', 'deadset', 'mandate', 'show', 'status', 'series', 'booster'],
#  ['job', 'puff'],
#  ['death',
#   'threat',
#   'desire',
#   'temperature',
#   'convoy',
#   'protestor',
#   'right_wing',
#   'extremist',
#   'hostage',
#   'need',
#   'stop'],
#  ['redefine', 'terminology', 'suit', 'description', 'deviation', 'individual'],
#  ['guidance',
#   'prevent',
#   'transmission',
#   'infection',
#   'update',
#   'data',
#   'problem'],
#  ['rate', 'world', 'spread', 'justification', 'mandate'],
#  ['hospitalization', 'icu', 'age', 'course'],
#  ['infection', 'hospitalization', 'death', 'status'],
#  ['ass', 'term', 'part', 'tho', 'vacation', 'stop', 'word', 'misleading'],
#  ['test', 'efficacy', 'cost', 'payment', 'rate'],
#  ['violation', 'government', 'stoll', 'state', 'emergency'],
#  ['science',
#   'yesterday',
#   'science',
#   'unmask',
#   'kid',
#   'science',
#   'tuberculosis'],
#  ['business', 'individual', 'status', 'remedy'],
#  ['rate', 'trust', 'science'],
#  ['mandate', 'clutch', 'sport', 'article', 'write', 'tiny_bit', 'end', 'bout'],
#  ['fear', 'prevent', 'nonsense', 'validate'],
#  ['citizen', 'home', 'citizen', 'serbian', 'cross_border'],
#  ['case', 'grade', 'mask'],
#  ['millennial', 'home'],
#  ['requirement',
#   'occupation',
#   'condition',
#   'restriction',
#   'fact',
#   'condition',
#   'door',
#   'regulation'],
#  ['shot',
#   'reek',
#   'kickback',
#   'pharmaceutical',
#   'liability',
#   'shot',
#   'booster',
#   'poison',
#   'shove'],
#  ['hospital', 'death'],
#  ['infection',
#   'reason',
#   'immunity',
#   'evade',
#   'impact',
#   'transmission',
#   'selection',
#   'pressure'],
#  ['contrast',
#   'state',
#   'leverage',
#   'exhaustion',
#   'childhood',
#   'regime',
#   'education'],
#  ['center'],
#  ['employee',
#   'family',
#   'trucking',
#   'logistic',
#   'company',
#   'question',
#   'wisdom',
#   'mandate',
#   'place',
#   'day',
#   'blockade'],
#  ['thank'],
#  ['concert'],
#  ['woman', 'age', 'status', 'question'],
#  ['fight', 'virus'],
#  ['rate', 'country', 'dude'],
#  ['thing',
#   'state',
#   'mandate',
#   'week',
#   'segment',
#   'population',
#   'kid',
#   'month',
#   'sake'],
#  ['customer', 'lawyer', 'business'],
#  ['boy', 'visit', 'stud'],
#  ['olympic', 'spectator', 'bubble', 'super_bowl', 'test'],
#  ['thought', 'issue'],
#  ['catch', 'spread', 'point', 'damage', 'work'],
#  ['freedom', 'choice', 'discriminate', 'harm', 'livelihood', 'shame'],
#  ['nice_try', 'protection'],
#  ['death', 'death', 'mask', 'ca', 'risk', 'rule', 'variable', 'stemeducation'],
#  ['poison', 'head', 'story', 'month', 'folk'],
#  ['freedom',
#   'employer',
#   'health',
#   'insurance',
#   'self',
#   'company',
#   'hospitalization',
#   'bottom_line',
#   'insanity'],
#  ['morning', 'police_officer', 'safety', 'answer', 'hope'],
#  ['article', 'measure', 'level'],
#  ['simmon', 'depth', 'carry'],
#  ['outcome', 'rate', 'mask', 'obedience'],
#  ['discrimination', 'definition', 'sexuality', 'gender', 'etc', 'fact'],
#  ['disagree',
#   'threat',
#   'civilization',
#   'state',
#   'country',
#   'erosion',
#   'sense',
#   'community',
#   'risk',
#   'benefit'],
#  ['smallpox', 'scar', 'shoulder', 'age', 'answer', 'dogging'],
#  ['work', 'hesitancy', 'message'],
#  ['launch', 'record', 'web', 'district', 'resident', 'access', 'record'],
#  ['smallpox', 'physician'],
#  ['card', 'team', 'league'],
#  [],
#  ['state', 'rate', 'level', 'death', 'conversation', 'world'],
#  ['student', 'health', 'measure', 'place', 'end', 'semester', 'abuse'],
#  ['report', 'mask', 'mandate', 'state', 'viewer', 'state', 'mask'],
#  ['mayor', 'crack', 'scare'],
#  ['movie',
#   'pandemic',
#   'class',
#   'citizen',
#   'proof',
#   'discrimination',
#   'health',
#   'measure',
#   'plot'],
#  ['promise', 'promise', 'restriction'],
#  ['mandate'],
#  ['outcome', 'number', 'country', 'considering', 'rate'],
#  ['province', 'country', 'state', 'place', 'rate'],
#  ['season', 'stance', 'time', 'title'],
#  ['clinic', 'volunteer', 'food', 'bag', 'spaghetti', 'appointment'],
#  ['mandate'],
#  ['mask',
#   'mandate',
#   'chaos',
#   'campus',
#   'person',
#   'class',
#   'community',
#   'transmission',
#   'rate'],
#  ['health',
#   'rescind',
#   'order',
#   'city',
#   'mask',
#   'entry',
#   'type',
#   'city',
#   'rescission',
#   'policy',
#   'effect'],
#  ['age',
#   'datum',
#   'immunity',
#   'kid',
#   'infection',
#   'sign',
#   'effect',
#   'virus',
#   'stay'],
#  ['exposure',
#   'time',
#   'reason',
#   'discussion',
#   'immunity',
#   'consideration',
#   'discussion'],
#  ['today', 'requirement', 'morning', 'kid'],
#  ['mandate', 'proof', 'restriction', 'reason', 'protest', 'thing', 'normalcy'],
#  ['chickenpox', 'lot'],
#  ['infection', 'rate'],
#  ['way',
#   'virus',
#   'fact',
#   'prevent',
#   'virus',
#   'death',
#   'role',
#   'face',
#   'crisis',
#   'faci',
#   'friend',
#   'government',
#   'funding',
#   'face',
#   'mask',
#   'work',
#   'cell'],
#  ['precaution'],
#  ['card'],
#  ['fact', 'matter', 'status', 'infect', 'mutate', 'health', 'livelihood'],
#  ['benefit', 'abandonment', 'measure', 'program', 'none', 'play', 'leave'],
#  ['clinic'],
#  ['country',
#   'child',
#   'grave',
#   'mass',
#   'death',
#   'bone',
#   'health',
#   'precaution',
#   'thinking'],
#  ['option', 'community', 'search', 'visit', 'individual'],
#  ['mandate', 'motivate', 'temp', 'mandate', 'goal'],
#  ['difference', 'viral_load', 'policy', 'rate'],
#  ['mask'],
#  ['part', 'work', 'dedication', 'milestone'],
#  ['moment', 'action', 'saveourkid', 'intervention', 'parent', 'kid'],
#  ['hip', 'point', 'thing', 'privacy', 'status'],
#  ['thing', 'net'],
#  ['job', 'choice'],
#  ['guideline', 'kid', 'shooter', 'mill', 'simmon', 'shoot'],
#  ['today', 'world', 'food', 'clothing', 'life', 'hospital', 'dentist'],
#  ['reminder',
#   'use',
#   'place',
#   'order',
#   'portion',
#   'spending',
#   'organization',
#   'parenthood'],
#  [],
#  ['schedule', 'covidsummit', 'world'],
#  ['place', 'proof', 'folk', 'information'],
#  ['pal', 'efficacy', 'virus', 'effort', 'space', 'space'],
#  ['population', 'sequela', 'path', 'mitigation'],
#  ['claim', 'population', 'number', 'case', 'rate'],
#  ['population', 'population', 'population', 'immunity', 'imperfect'],
#  ['nation', 'effort', 'fight', 'virus'],
#  ['world',
#   'evidence',
#   'slowing',
#   'surge',
#   'infection',
#   'surge',
#   'rate',
#   'protection',
#   'restriction',
#   'rate',
#   'science'],
#  ['person', 'attendance'],
#  ['mandate', 'requirement', 'month', 'ditch'],
#  ['net', 'draft', 'pick', 'trading', 'harden', 'rule'],
#  ['event',
#   'attendee',
#   'proof',
#   'wear',
#   'mask',
#   'time',
#   'state',
#   'protocol',
#   'information',
#   'purchase',
#   'ticket',
#   'visit',
#   'bettzedek'],
#  ['thought', 'mandate', 'mandate', 'mandate', 'folk', 'difference', 'rate'],
#  ['status', 'restaurant', 'prove', 'crack', 'addict', 'crackpipe'],
#  ['infection',
#   'rate',
#   'child',
#   'infection',
#   'rate',
#   'delta',
#   'child',
#   'business',
#   'corporation'],
#  ['health',
#   'care',
#   'system',
#   'rule',
#   'care',
#   'build',
#   'infrastructure',
#   'support',
#   'anthrax',
#   'community',
#   'healthinsurance',
#   'screenplay'],
#  [],
#  ['lot', 'mandate', 'land', 'crossing', 'job'],
#  ['progressive',
#   'government',
#   'coercion',
#   'product',
#   'credibility',
#   'guess',
#   'progressive'],
#  ['place', 'rule', 'athlete', 'city', 'proof', 'mask', 'spring'],
#  ['education',
#   'practice',
#   'community',
#   'community',
#   'role',
#   'model',
#   'scourge'],
#  ['border', 'migrant'],
#  ['ink',
#   'folk',
#   'half',
#   'kid',
#   'injury',
#   'half',
#   'simmon',
#   'problem',
#   'trade'],
#  ['ground',
#   'report',
#   'question',
#   'connection',
#   'requirement',
#   'sample',
#   'trucker',
#   'focus',
#   'trucker',
#   'protestor'],
#  ['work',
#   'love',
#   'conclusion',
#   'choice',
#   'individual',
#   'impact',
#   'pandemic',
#   'trajectory'],
#  ['mandate'],
#  ['follow_suit', 'ground', 'case'],
#  ['arrival', 'datum'],
#  ['requirement', 'register', 'event', 'venue'],
#  ['thread',
#   'country',
#   'restriction',
#   'rate',
#   'denmark',
#   'hospital',
#   'situation'],
#  ['mask', 'control'],
#  ['mutate',
#   'rate',
#   'ship',
#   'complication',
#   'risk',
#   'datum',
#   'support',
#   'protection',
#   'emphasis'],
#  ['omicron', 'month', 'dose', 'month', 'datum', 'news', 'fall'],
#  ['infection', 'reuter', 'reason', 'choice', 'alternative', 'medicine'],
#  ['simmon', 'kid', 'contender'],
#  ['none',
#   'beginning',
#   'cooperate',
#   'virus',
#   'virus',
#   'existence',
#   'mandate',
#   'court',
#   'disinformation'],
#  ['couple',
#   'reduce_chance',
#   'conception',
#   'infection',
#   'sars_cov',
#   'reduction',
#   'fertility',
#   'male',
#   'safety',
#   'couple',
#   'conceive'],
#  ['snack', 'staff', 'switch'],
#  [],
#  ['transparent', 'year'],
#  ['cab', 'pok'],
#  ['rule', 'change', 'playoff'],
#  ['crack_pipe', 'friend'],
#  ['net', 'team', 'ruin', 'season', 'moment', 'streak'],
#  ['shot', 'primary_serie', 'sign', 'body', 'building', 'protection', 'mo'],
#  ['team',
#   'thing',
#   'status',
#   'playoff',
#   'series',
#   'play',
#   'score',
#   'net',
#   'eye'],
#  ['agreement', 'truck', 'trucker'],
#  ['providence', 'employee', 'policy', 'suspension'],
#  ['establishment', 'superintendent', 'call', 'spine', 'truth'],
#  ['protest', 'air', 'train', 'travel', 'restriction'],
#  ['rate', 'case', 'hospitalization', 'death', 'work'],
#  ['study'],
#  ['rate', 'correlation', 'map'],
#  ['term', 'restriction', 'campaign', 'death', 'senior', 'bonker', 'bonker'],
#  ['opinion', 'provider', 'topic', 'mandate', 'survey'],
#  ['point',
#   'simmon',
#   'fact',
#   'trade',
#   'asset',
#   'mandate',
#   'chance',
#   'requirement'],
#  ['employment',
#   'job',
#   'field',
#   'citizen',
#   'employment',
#   'freedom',
#   'endthemandate'],
#  ['assumption', 'distinction', 'risk', 'benefit', 'analyze'],
#  ['difference',
#   'prevention',
#   'harm',
#   'moment',
#   'rate',
#   'mask',
#   'mandate',
#   'course',
#   'outlaw',
#   'driving',
#   'safety',
#   'measure'],
#  ['benefit', 'minimizing', 'risk', 'state', 'threat', 'civilization', 'virus'],
#  ['joke', 'protest', 'dentist'],
#  [],
#  ['teacher', 'parent', 'student', 'charter_right', 'freedom', 'one'],
#  ['poll', 'passport', 'system'],
#  ['question', 'visitor', 'record', 'royal', 'thank'],
#  ['help', 'clinic'],
#  ['infection',
#   'immunity',
#   'idea',
#   'immunity',
#   'intervention',
#   'term',
#   'post',
#   'infection',
#   'immunity',
#   'infection'],
#  ['voting', 'congressman', 'side', 'analogy', 'logic', 'card', 'gun', 'touch'],
#  ['change', 'requirement', 'border', 'month', 'detail', 'number'],
#  ['pattern', 'symptom', 'month', 'answer', 'thank'],
#  ['virus', 'rate', 'rest'],
#  ['milestone', 'expert', 'goalpost', 'occasion'],
#  ['card'],
#  ['control', 'booster', 'land', 'status'],
#  ['passport', 'pharmacy', 'clinic'],
#  ['decision'],
#  ['support',
#   'issue',
#   'rate',
#   'mandate',
#   'bubble',
#   'support',
#   'troll',
#   'president',
#   'state',
#   'member'],
#  ['problem', 'bus', 'station', 'state', 'rail', 'passenger'],
#  ['force', 'work', 'comparison'],
#  ['summit',
#   'commitment',
#   'support',
#   'engine',
#   'recovery',
#   'system',
#   'recovery',
#   'read'],
#  ['country', 'one', 'world', 'rate', 'reason', 'ignore'],
#  ['assumption', 'antic'],
#  ...]

# %%
df['words_processed_noun'].values[0][0]
# Out:
# 'way'

# %%
df['tokenised_stopremoved'] = tokenised_stopremoved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315603 entries, 0 to 315602
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   new_text_after_translation         315603 non-null  object
#  1   words_processed_all                315603 non-null  object
#  2   words_processed_noun_adj_verb_adv  315603 non-null  object
#  3   words_processed_noun               315603 non-null  object
#  4   text_type                          315603 non-null  object
#  5   sentiment                          315603 non-null  int64
#  6   tokenised_stopremoved              315603 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 16.9+ MB

# %%
df['sentiment'].value_counts()
# Out:
# 2    222780
# 0     92823
# Name: sentiment, dtype: int64

# %%
positive_df = df[df['sentiment'] == 2]

# %%
positive_df
# Out:
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# 5       it could have ripped… harder or do you think m...
# 6       they do this at vaccination centres as well. t...
# ...                                                   ...
# 315597  contrary american belief, vaccine is not perso...
# 315598  pretty remarkable achievement. thank you all v...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# 5       ['could', 'ripped', 'harder', 'think', 'maskin...
# 6       ['vaccination', 'center', 'well', 'refused', '...
# ...                                                   ...
# 315597  ['contrary', 'american', 'belief', 'vaccine', ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315600                    ['others', 'vaccinesaveslives']
# 315601  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# 5       ['could', 'rip', 'hard', 'think', 'mask', 'iso...
# 6       ['vaccination', 'center', 'well', 'refuse', 'l...
# ...                                                   ...
# 315597  ['contrary', 'vaccine', 'personal', 'choice', ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       [way, end, racism, force, people, bunch, peopl...  subjective
# 3       [case, vaccination, rate, play, space, adult, ...  subjective
# 4       [vaccination, status, code, link, connect, end...  subjective
# 5       [isolation, question, look, spike, matter, vac...  subjective
# 6       [vaccination, center, parent, mask, amp, amp, ...  subjective
# ...                                                   ...         ...
# 315597     [vaccine, choice, people, risk, vaccine, part]  subjective
# 315598  [achievement, volunteer, shotsshotsshot, fauci...  subjective
# 315600                                            [other]  subjective
# 315601                    [congrat, feeling, safetyfirst]  subjective
# 315602  [part, end, vaccine, help, other, vaccine, tod...  subjective
#
#         sentiment                              tokenised_stopremoved
# 0               2  [way, end, racism, force, bunch, race, support...
# 3               2  [case, rate, play, space, adult, space, school...
# 4               2           [status, code, link, connect, end, read]
# 5               2  [isolation, question, look, spike, matter, thing]
# 6               2                     [center, parent, mask, answer]
# ...           ...                                                ...
# 315597          2                               [choice, risk, part]
# 315598          2  [achievement, volunteer, shotsshotsshot, fauci...
# 315600          2                                                 []
# 315601          2                    [congrat, feeling, safetyfirst]
# 315602          2  [part, end, help, today, physician, monitor, s...
#
# [222780 rows x 7 columns]

# %%
texts = positive_df['words_processed_noun']

# %%
new_text_noun = []

for row in texts:
    # print(type(row))
    new_row = " ".join(row)
    new_text_noun.append(new_row)

# %%
new_text_noun
# Out:
# ['way end racism force people bunch people race vaccination people amp support people force',
#  'case vaccination rate play space adult space people school age student datum state bear',
#  'vaccination status code link connect end read',
#  'isolation question look spike matter vaccination thing',
#  'vaccination center parent mask amp amp answer',
#  'tool suite leader combat vaccine hesitancy resistance video article',
#  'vaccine goal vaccination blogger news accident vaccine step competence',
#  'vaccination vaccination restaurant arena fitness center vaccination rate',
#  'age hour infection amp booster infection protect hypnotoad pheromone',
#  'understand link vaccination compulsory bawl bye',
#  'winner today couid lab vaccination vaccine variant count',
#  'common_sense solution vaccination virus business',
#  'tooting place language couid vaccination',
#  'variant vaccination ventilation kid time kid danger kid danger matter',
#  'county vaccination threshold datum school',
#  'vision health decision condition vaccination amp vulnerability year politic level factor',
#  'understand thought vaccination',
#  'concern level',
#  'steel man mandate mask vaccination testing cost cost',
#  '',
#  'government concern prevent hospital emergency depth resource bed space equipment staff hospital',
#  'couid vaccine spread couid couid case care vaccine status force vaccination',
#  'game green_light vaccination status stadium enforce',
#  'specialist vaccination effort',
#  'report document trump bullshit border end vaccination mandate people',
#  'vaccination issue way',
#  'laughingstock rest world trucker vaccination mandate lie reinstatement tag',
#  'school vaccination proof respect individuality health decision choice lol hate',
#  'trust people vaccination rate time couid',
#  'vaccination policy government mandate employer vaccination policy',
#  'subject',
#  'masking kid hospitalization rate vaccination rate kid normalcy number',
#  'endemic vaccination lockdown mask fear precaution age health condition',
#  'couid vaccination status',
#  'mandate school vaccination rate education outreach student sibling mask mandate',
#  'vaccination abortion thing',
#  'explain vaccine person way issue vaccination',
#  'time faught vaccination health care',
#  'challenge nation rule vaccination testing problem creation self country',
#  'member submit card card reporting mean event side_effect event vaccination',
#  'head answer time time vaccination',
#  'people vaccine vaccination',
#  'recommendation health care worker fund scout safety',
#  'prevention vaccination mask vaccination mask couid flu flu shot year difference virus kill rate',
#  'way yield result vaccination mandate people decision',
#  'altar produce testing vaccination',
#  'look mirror man conservative blockade rhetoric vaccination health order',
#  'fan couid vaccine super_bowl experience ticket experience day future date visit vaccination site',
#  'card thank',
#  'website benefit couid vaccination outweigh risk risk',
#  'ability restriction vaccination point mandate trust business restaurant guarantee',
#  'couid prevent spread disinformation',
#  'substance vaccination rabie forgot administer post',
#  'vaccination isolate protect',
#  'part recovery individual vaccination recommendation',
#  'parent vaccination infrastructure grownup hell kid hour cold',
#  'list nominee vaccination requirement meltdown twitter wag movie shot',
#  'government vaccine place business government mandate show proof vaccination oppression',
#  'people fact care amp pal vaccination care',
#  'vaccination measure science',
#  'love gymnastic vaccination police brutality minority',
#  'defundcbc defundbbc vaccination extravaganza network fund baddie',
#  'immunity couid time fact therapist couid time health risk couid kill people technology',
#  '',
#  'mandate vaccination rate restriction tone thread mandate attempt coerce',
#  'paper state spike_protein level blood vaccination people variant produce antibody variant',
#  'immigration question answer health safety requirement vaccination record',
#  'terrorist issue issue restriction vaccination way period',
#  'vaccine isolation fentanyl death loved_one stress mask show proof vaccination baby',
#  'person county vaccination rate mask',
#  'half adult flu heart disease people heart disease risk flu complication',
#  'parking ticket check bylaw officer business vaccination shot',
#  'hope treatment problem immunity system people vaccination case check',
#  'vaccination mask understand vaccine right',
#  'thing today person leave question booster dose couid person client contract vaccination health concern',
#  'discrimination color sex religion health system vaccination injection',
#  'turn vaccination sense choice pay rent',
#  'member minute',
#  'quebecer couid vaccination solution reduce contagion',
#  'question place vaccination entry',
#  'intention tue drop couid case county vaccination rate state yesterday',
#  'rate percent indoor_space running errand retirement hubby year',
#  'fact business option vaccination status choice choice choice business poli',
#  'side fiorella fan vaccination ratio',
#  'rate definition immunity infection hospitalization amp death policy vaccination',
#  'memory analysis state vaccination people access vaccine month',
#  'election definition tourist mandate care time',
#  'health ventilation vaccination amount virus air chance',
#  'utility plan vaccination testing safety protocol',
#  'variant antibody selection ade vaccination yesterday',
#  'girl selling card week vaccination card card',
#  'vaccination vaccination card comparison water context creation role strategy impact',
#  'clinic health screening vendor music food fun flyer',
#  'risk reduction vaccination time virus circulate body people antibody week virus body',
#  'topic supporter',
#  'couid vaccination event terrace',
#  'recovery today bow timing vaccination pass month',
#  'pneumonia influenza trap',
#  'party weekend matter root mask defensive play care matter',
#  'bill mandate vaccine school kid kid school vaccination requirement',
#  'cell subject vaccination amp infection history tool monitoring vaccination amp protection',
#  'opponent distrust vaccine product test time principle package people',
#  'wave wave people vaccination fact occurrence week week',
#  'study reality vaccination mandate hospitalization path pandemic',
#  'difference canadian spectrum restriction life goal vaccination',
#  'vaccination card wash_hand people',
#  'favor vaccination people tool tension pass',
#  'time transmission risk approach wish wear mask people risk assessment',
#  'vaccination mandate trucker',
#  'man stage wink actor premier vaccination mandate',
#  'couid vaccine key health vaccination activity',
#  'business proof vaccination reader business vaccination status wolf health',
#  'reason vaccination majority canadian mandate',
#  'limitation clinician report adverse_event couid vaccination event hospitalization veer reporting system veer',
#  'child organization girl guide check vaccination status people child',
#  'elimination proof vaccination amp satisfy avoid fan club',
#  'claim family trip vaccination world time fact',
#  'business mask customer proof vaccination status proof vaccination mask policy',
#  'point train airline proof vaccination province app train holiday',
#  'supply medication state child vaccination progress maskshelp',
#  'fault liberty point reality',
#  'vaccination date beer license name home address',
#  'hit vaccination policy employee attend',
#  'child couid seeing premise want couid death vaccination status policy',
#  'brain trust ground support convoy jurisdiction mandate cross_border',
#  'goal stress ear vaccination couid stay omicron flu precaution life life',
#  'tip',
#  'restriction vaccination vaccine man',
#  'report oscar couid test vaccination proof',
#  'propaganda vaccine vaccination school vaccine',
#  'couid vaccination amp day worker visitor',
#  'reporter pulp email reason redefinition fact check',
#  'application proof vaccination version',
#  'encouragement vaccination passport plan requirement stick thing needle yrs work',
#  'stance spin',
#  'mandate city folk proof vaccination indoor_dining event arena gyms_theater museum',
#  'history people context tuskegee vaccination',
#  'season existence vaccination change argument matter deny',
#  'vaccination policy science time',
#  'help business school team couid pandemic testing reporting solution vaccination status',
#  'vaccination rape deserve sun end triage line care',
#  'vaccination vaccine',
#  'ambiguity mask vaccination drug therapy query recomendation year vaccine efficacy datum vaccine',
#  'vaccine passport infection rate infection mirror vaccination rate mandate ontario',
#  'mask vaccination talk remedy',
#  'party issue party opinion siding vaccination mask hardship',
#  'datum point case_count vaccination rate availability testing availability treatment facility decision team health expert leader',
#  'restriction mandate employer vaccination requirement community hospital surgery',
#  'vaccination card',
#  'kudo vaccination requirement place',
#  'couple vaccination program guise virus people jabbed woman issue miscarriage piece',
#  'course vaccination question answer question people vaccine people',
#  'vaccination status choice people virus million life generation',
#  'thing vaccination society bit vaccine death scientist virus',
#  'vaccination status detail',
#  'booster couid',
#  'shame publish type article scientist manipulation vaccination newspaper',
#  'couid vaccination point',
#  'vaccine clinic time noon kid school parent clinic person vaccination',
#  'work people world country people vaccination amount booster couid',
#  'study scientist student staff mask school transmission couid right_winger mask',
#  'benefit baffle statistic virus amp fact',
#  'regime politicization way highway society vaccination syringerat control heckler truck',
#  'harden vaccination thing way sense',
#  'leadership end winter term proof vaccination student semester',
#  'loosen restriction vaccination rate people booster booster protection omicron',
#  'truck right_wing convoy thing',
#  'people mask vaccination',
#  'people couid restriction vaccination personality',
#  'million immunity vaccination health risk',
#  'note vaccination rate datum vaccination rate survey result',
#  'plan vaccination clinic check mate',
#  'traffic vaccination health doctor duty manager people site',
#  'couid lot people prove',
#  'treat night time vaccination amp mask group amp joy music earthling',
#  'couid vaccination',
#  'game student vaccination card comfort color shirt grant msriverproject',
#  'vaccination rate percent number',
#  'proof vaccination policy place fall logic dropping vaccine requirement end goal people',
#  'illness skin vaccination card',
#  'vaccine equity power health source stat',
#  'neighborhood vaccination rate sparrow creek ord dose',
#  'life vaccination passport mandate support',
#  'country goal percent vaccination rate amp talk safety measure safety measure country seesaw amp erode trust',
#  'theater vaccination attend class vaccine finder help thank',
#  'hepburn couid vaccination requirement city hepburn facility website',
#  'vaccine protection infection amp transmission booster protection hospitalization amp death',
#  'vaccination mask',
#  'mandate vaccination way couid',
#  'people date couid vaccination mos past infection omicron variant',
#  'team league season playoff team game',
#  'situation cost restriction vaccination rate',
#  'crisis couid vaccination push mandate age enhance',
#  'mask data city',
#  'vaccination class residence circ residence',
#  'leverage virus',
#  'mask vaccination stop generalization people',
#  'mask truth couid restriction vaccination kid amp adult school data science politic amp noise',
#  'gestation company policy company drug test policy refuse vaccination workplace vaccination place',
#  'vaccination border movement',
#  'pandemic',
#  'worry couid concern vaccination risk',
#  'vaccination program time dialog canadian tyrant',
#  'player team hope card player man sixer fan',
#  'mandate metro area vaccination rate',
#  'school amp play music vaccination experience todaylaptop',
#  'pregnancy woman risk authority vaccination case',
#  'couid vaccination elite pass',
#  'vaccination clue nation',
#  'theater vaccination requirement',
#  'corn pop portrayal economy twitter react proof vaccination',
#  'vaccination mandate',
#  'birth certificate proof vaccination cruise welcome',
#  'people mask mandate vaccination requirement',
#  'couid vaccination refusal number force',
#  'ticket show taping show testing pretend couid hysteria',
#  'concert event venue series couid vaccination proof couid test hour info',
#  'weekend holiday mask syringe',
#  'mandate vaccination system bit mortality event month vaccine',
#  'rise transmisibility amp infection vaccination amp booster adult hospitalization child example con',
#  'work chance',
#  'illness care patient bag base rate falsification patient vaccination',
#  'vaccination shot blood test trace adult couid',
#  'variance study protection vaccination',
#  'teacher job anxiety life',
#  'one help track vaccination reaction hunting',
#  'people day pioneer doctor vaccine vaccination work disease',
#  'day government job today news finance export face jeffrie job credit vaccination',
#  'friend friend people vaccination choice',
#  'vaccination focus risk group thing vaccine year_old',
#  'planning year proof vaccination card',
#  'search group site vaccine place kid vaccination site hospital',
#  'authority coronavirus case record spread vaccination rate absence restriction adult',
#  'death vaccination incline end date lot people auto immunity post vaccine stroke',
#  'jurisdiction end mandate level couid case metric amp virus testing amp vaccination rate endthemandate',
#  'vaccination removing mandate social_distance mask booster freedom choice',
#  'infection protection infection level infection way measure infection other',
#  'rate vaccination people infection child vaccine',
#  'government health measure',
#  'restriction vaccination mandate concern society benefit government safety',
#  'school place quality mask vaccination value kind mask rapid_test case',
#  'antibody immunity vaccination population fact survivor thing tunnel',
#  'month vaccination appointment child approval',
#  'datum cac omicron period hospitalization couid condition adult hospital vaccination rate idaho',
#  'infection vaccination',
#  'exemption cmon exemption exemption vaccination rate idea',
#  'idea people trouble wear_mask child school issue kid vaccination rate',
#  'smallpox thank vaccination',
#  'choice community talking_point country vaccination requirement',
#  'seasonal_flu thank vaccination measure restriction',
#  'normality vaccination mask patient staff office grief option',
#  'show vaccination card place site time night place',
#  'part expertise death people',
#  'window effectiveness effect',
#  'card mask',
#  'reason vaccination reason thing condition allergy choice disorder',
#  'fact today vaccine passport name ram vaccination leave country',
#  'vaccination record',
#  'elite shout vaccination',
#  'vaccination awareness brigade',
#  'vaccination proof place student',
#  'state today city mandate vaccination museum arena',
#  'love life country mandate school student loan',
#  'company work policy leader mask policy vaccination employee site',
#  'brain abscess brain cancer category week vaccination thing',
#  'definition immunity disease contract disease vaccination contract disease increase risk myocarditis',
#  'vaccine joke orgy street orgy mass vaccination event aneurysm',
#  'world government people capacity thinking analysis vaccine vaccination prevent other vaccine vaccination',
#  'play emergence omicron couid guest vaccination status detail',
#  'think amount vaccination tyrant power year herd_immunity target virus endemic move life',
#  'vaccination elixir man couid government',
#  'science reality year harm science anthology bullshit vaccination child',
#  'time require mask couid passport couid test',
#  'host rabie vaccination clinic pet',
#  'vaccination record clinic retrieve',
#  'version idea section page health project proportion vaccination group time proportionality assumption',
#  'assumption people person reason',
#  'county vaccination rate surge couid case delta',
#  'mom report vaccination number journalist touch lack transparency hesitancy',
#  'respect fear watch number plan weather week number people vaccination infection increase future bright',
#  'nation effort fight virus vaccination',
#  'act collection law boost health authority update condition time time',
#  'vaccination couid virus life age vaccination matter',
#  'vaccination rate people bar',
#  'reporter stuff fact vaccination soul order',
#  'vaccination rate',
#  'note',
#  'rate requirement show proof vaccination pick place fin',
#  'community vaccination rate child measure vulnerability infection antibody',
#  'risk level kid spread protection stall part teachers_union point word',
#  'country adult vaccination rate vaccine restriction enemy punishing',
#  'idea lock screen wallpaper vaccination card',
#  'period immunity people benefit vaccination immunity variant defeating immunity',
#  'vaccination rate question deeperissue one',
#  'month vaccination need',
#  'proof vaccination requirement twin_citie',
#  'trade amp vaccination mandate term',
#  'criterion inclusion couid vaccine disease',
#  'freedom science one disease disability vaccination schedule couid',
#  'debate restriction leader country vaccination rate restriction',
#  'bribery vaccination covidvaccine',
#  'control amp obesity cohort yrs amp people decade vaccination mask anger freedom cost death',
#  'people mask street regard show vaccination status',
#  'death threat kid vaccine video school vaccination clinic',
#  'vaccination card vaccine',
#  'lot vaccination spread couid scientist',
#  'pillar policy vaccination stay place argument testing requirement people community',
#  'reason employment lawyer termination belief vaccination status',
#  'course thing vaccination live immunity repeat vaccination',
#  'country rubella vaccine half rubella transmission rubella elimination amp protect baby country amp vaccination coverage',
#  'legislator amendment prohibit discrimination vaccination status orientation gender identity',
#  'vaccination rate map show work amp time vaccine delivery vaccinate kid amp adult urgencyofequity',
#  'hospital amp nurse point vaccination knife drawer',
#  'path want vaccination',
#  'vaccine omicron evade quality mask leader responsibility health time people example',
#  'vaccination booster rate kid work way meantime lot damage',
#  'mask couid transmission community area person event',
#  'opinion store sporting_event concert capacity proof vaccination mask peer pressure jay',
#  'trick couid plan shut virus',
#  'math commission vote level vote illegal rinosalazar',
#  'chance hospital vaccination chance infection place variant infection omicron line defense',
#  'epidemiologist health expert twitter user expertise field vaccination',
#  'age sex comparison risk people risk vaccination source vaccination',
#  'child vaccination adult booster need booster punishment',
#  'comparison sex pre_existing condition vaccination significance comorbiditie',
#  'laboratory virus toilet forget laboratory vaccine generation virus',
#  'rate vaccination people infection child vaccine',
#  'mandate question mandate',
#  'day clinic walk shot pfizer well booster community event',
#  'couid infection boost immunity vaccination health problem damage immune_system word people couid',
#  'proof vaccination crack_pipe',
#  'time vaccination card',
#  'people vaccination hurting team championship time player',
#  'vaccination rate',
#  'people vaccination service code people code',
#  'trust individual man heart condition exemption avoid vaccination thing',
#  'people body',
#  'worry vaccination vaccine pseudo damage life save',
#  'measle jeopardize jeopardizing',
#  'plan passport vaccination situation masking time news',
#  'occupier trucker path freedom vaccination disease protection other health',
#  'air gas inflation business massless amp refuse vaccination life policy',
#  'data decade decade vaccination campaign place data measle',
#  'mandate wave',
#  'map push end mandate vaccination',
#  'vaccine mandate kudo contradiction choice thing other language quebec lot part time libertarian',
#  'vaccination kill_bacterium vaccine',
#  'couid vaccination',
#  'case removal school student mask school student vaccination mandate',
#  'holiday vaccination campaign time paperwork care lack work',
#  'language definition vaccination prevent user couid vaccine',
#  'adult vaccine mandate vaccination rate child indicator people mandate',
#  'day wording directive absence pay',
#  'mandate vaccination card restaurant matter time',
#  'help variant variant schedule vaccine appointment',
#  'vaccination care track train',
#  'rate vaccination part',
#  'mask vaccination accessibility risk pandemic',
#  'vaccination card ease country',
#  'couid case share visitation visitor inpatient admission exception requirement visitor proof vaccination couid',
#  'vaccination restriction politic utilization hospital resource neoliberalism',
#  'risk flu illness people flu virus flu shot couple week flu vaccine protect virus flu',
#  'vaccine vaccine vaccination help condition vaccine risk',
#  'people mask choice vaccination people',
#  'majority death vaccination immunity boost risk profile',
#  'life year retirement lockdown vaccination mandate canadian',
#  'mode denial vaccination coercion amp discrimination bread amp butter platform place',
#  'needle freedom freedom other refuse health policy vaccination mask',
#  'other weight amp status vaccination manufacturer use amp individual',
#  'address vaccination vaccination outreach program adult million child',
#  'vaccination card crime year',
#  'founder self law charter removal travel vaccination law suit rest border line',
#  'proof vaccination couid',
#  'question plan force vaccination dropping restriction situation',
#  'night fire guitar door show guest amp proof vaccination amp time change',
#  'night proof vaccination film',
#  'vaccination virus mutation',
#  'net couid vaccination decade medicine vaccination',
#  'person vaccination couid',
#  'change definition system legitimize gene activation vaccination job',
#  'death vaccination increase issue health issue amp government care health mandate virus',
#  'vaccination passport mask couid restriction',
#  'politician relation vaccination',
#  'vaccination',
#  'datum protection vaccination risk death infection study',
#  'move move chemistry',
#  'vaccination hero city lawsuit markmyword',
#  'ad stock lot westbrook contract rest team bait bag change',
#  'face downtown summering setting vaccination status',
#  'vaccination rate staff adult area correlation mask mandate rate direction mandate',
#  'bill vaccination operation cost vaccine',
#  'level understanding',
#  'hocus requirement indoor business vaccination',
#  'datum week vaccination spike infection correlation scientist',
#  'vaccination sars_cov infection hospitalization death vaccination dose dose person',
#  'case death vaccination dozen life year',
#  'bulletin year pastor letter church couid vaccination trad publication teaching',
#  'virus population variant vaccination stop limit mutation hospital hospital',
#  'vaccination coronaviruse virus vaccine booster shot',
#  'reason vaccination ordeal',
#  'thank people recover people morning cousin battle dishonesty vaccination',
#  'vaccination definition definition defense level vitamin definition defense infection equate',
#  'vaccination recognition contagion phase pandemic point matter opinion day respect objectivity',
#  'situation today couid vaccination amp mind plan recommend government measure',
#  'flyer vaccination site today paper door site site way',
#  'think fact risk vaccination oop',
#  'house oscar vaccination entry mask discussion deadline',
#  'cruise state day testing boarding test vaccination amp none ability time',
#  'kid vaccination couid family argument couid kid mild_symptom cold nonsense dialog',
#  'vaccination status impact booster kid case end case fever day',
#  'test health measure heap vaccination bump case reporting',
#  'mask participation child vaccination',
#  'infection transmission solution stock people',
#  'define word outbreak survival instinct vaccination number',
#  'story doctor vaccination child abuse position responsibility gain license',
#  'couid primary_serie vaccination sign body building protection couid',
#  'vaccination',
#  'country mandate vaccination war deal other work peace',
#  'immunity vaccination person pal immunity wave death need mask etc need fall wave',
#  'help effort share science vaccine phone community vaccination rate thank enthusiasm',
#  'mask vaccination',
#  'report oscar couid test vaccination proof',
#  'protest year persuasion attention vaccination mandate year one',
#  'year woman life claim science disgrace prison',
#  'way infection pregnancy vaccination date flu vaccination talk provider vaccination infection pregnancy',
#  'virus vaccination induce people',
#  'base proof vaccination policy province timeframe measure',
#  'vaccination mandate play',
#  'question week canadian science vaccination way end canadian',
#  'couid vaccine option information resource vaccination part neighbor today',
#  'street vaccination',
#  'couid vaccination clinic couple hour runner ballroom student union',
#  'mask ink point vaccination virus reduction transmission',
#  'night comedy door show guest amp proof vaccination amp time change',
#  'business bar restaurant mask freedom',
#  'problem child kid parent',
#  'opposition leader question debate vaccination rate mandate man lead country',
#  'whistle myocarditis chest athlete field citizen exhaust truck year minute vaccination',
#  'evidence start vaccination stat mask cable gig',
#  'convince people couid vaccination kink shaming people article share time want',
#  'conversation people vaccine mandate distraction amp leadership tool vaccination work',
#  'fly airline institute mandate health vaccination health',
#  'room vaccination card mask link',
#  'place word course juju',
#  'minority feeling kid amp people fuck',
#  'vaccination rate group doctor',
#  'risk couid vaccination status',
#  'people conversation voice host race theorist right activist doctor vaccination',
#  'solution vaccine variant body time premier protection',
#  'man lot time vaccine gulag vaccination hostess',
#  'country vaccination rate end mandate country canadian vaccine restriction',
#  'vaccination requirement people word name ad hominem attack argument noodle',
#  'mask vaccination people world access vaccine variation infection death',
#  'sixer ass',
#  'kid virus risk factor vaccination population rate',
#  'vaccination status net team shoot throw playoff year line',
#  'vaccination regimen go year start',
#  'vaccination pandemic band thug journalist',
#  'doctors_nurse scientist researcher people family relative world disease death smallpox limit people',
#  'difference family life friendship person vaccination coronavirus',
#  'vaccination shot dam',
#  'point demand people vaccination status segregation',
#  'vaccination school staff school staff education vaccination approach',
#  'protest mandate actuality liberal election minority vote district',
#  'study expert vaccination locale report difference mask school',
#  'time creep process cut virus host supply end',
#  'comment vaccine case vaccine risking disease death purpose vaccination',
#  '',
#  'sex race religion vaccination status',
#  'approach school school basis vaccination rate school mandate',
#  'question reason people rate couid',
#  'vaccination policy place state requirement',
#  'rushing measure vaccination rate population science result variant',
#  'factor mean immunity couid infection time hospital vaccination',
#  'vaccination',
#  'customer side morning show proof couid vaccination',
#  'today vaccination answer question vaccination way restriction',
#  'warning weekend vaccination card card',
#  'vaccination week statement force vaccination word',
#  'day vaccination definition method',
#  'freedom travel force vaccination card',
#  'decline couid case spot retire vaccination policy couid threat precaution',
#  'adult couid booster time protection infection adult stay date vaccination',
#  'development vaccine approach couid vilify therapeutic treatment man vaccination lack transmission control',
#  'amp impression lot people feel precaution vaccination',
#  'generation million couid survivor life brain reason vaccination',
#  'administration transmission follower mask vaccination end result vaccination variant death',
#  'vaccination support nice_try',
#  'co paper factor variable vaccine intent uptake change vaccination campaign',
#  'request proof vaccination check makes_sense business fyi discrimination',
#  'author decision favor vaccination disease article mechanism proof issue',
#  'confer rod infection antigen exposure response variant vaccine terminal_center',
#  'thank fight demand answer datum vaccination administration mandate truth',
#  'way',
#  'doctor vaccination want',
#  'season vaccination status player rule',
#  'disease effect refuse',
#  'city vaccination mandate child school let',
#  'infection transmission',
#  'summer vaccination',
#  'month forum question virus vaccination',
#  'life insurance industry target premium load employer county vaccination rate risk factor',
#  'couid line defense couid infection vaccination onevaxtwolive',
#  'rate city worker audience collar cop teacher sanitation vaccine',
#  'vaccination',
#  'future bet year season bet money team vaccination rate roster superbowl advantage',
#  'face couid day infection year month time mask vaccination rate',
#  'vaccination netsareunfair',
#  'thing wonder people show couid vaccination proof',
#  'definition vaccination couid vaccine vaccine prevent couid vaccine history herd_immunity',
#  'kid couid booster clinic child child vaccine booster school nurse info',
#  'country vaccination requirement mandate',
#  'way vaccination math way',
#  'people practice vaccination',
#  'chance vaccination mandate reason nice_try',
#  'vaccination etc meaning wastewater treatment respect infection trend',
#  'people reason reason vaccination moderation norm debate consideration',
#  'distinction deadset mandate show vaccination status series booster',
#  'redefine terminology suit vaccine vaccination description deviation individual',
#  'guidance amp vaccination prevent transmission infection update data problem',
#  'science yesterday science unmask kid science tuberculosis vaccination',
#  'business individual people vaccination status people remedy',
#  'fear prevent other nonsense validate',
#  'citizen home citizen serbian vaccination cross_border',
#  'case grade mask',
#  'millennial home vaccination',
#  'vaccination shot reek kickback pharmaceutical liability shot booster poison shove',
#  'infection reason immunity evade impact transmission selection pressure',
#  'employee family trucking logistic company question wisdom vaccination mandate place day blockade',
#  'woman age vaccination status question',
#  'fight virus vaccination',
#  'customer lawyer business vaccination',
#  'boy vaccination visit stud',
#  'olympic spectator bubble super_bowl vaccination couid test',
#  'thought issue vaccination',
#  'people catch spread couid point vaccination damage work',
#  'freedom choice discriminate people vaccination harm people livelihood shame',
#  'nice_try vaccination protection',
#  'poison people head story month folk',
#  'freedom employer vaccination health insurance self company couid hospitalization bottom_line insanity',
#  'morning police_officer safety answer hope vaccination',
#  'article measure level vaccination',
#  'smallpox vaccination scar shoulder age vaccination answer dogging',
#  'work hesitancy couid vaccine vaccination message',
#  'launch vaccine record web district resident access couid vaccination record',
#  'smallpox vaccination physician',
#  'card team league',
#  'vaccination',
#  'student health measure vaccination place end semester abuse',
#  'report mask mandate state viewer state mask vaccination',
#  'mayor vaccine crack scare',
#  'people vaccine movie pandemic class citizen proof vaccination discrimination health measure plot',
#  'promise promise people people vaccination restriction',
#  'mandate',
#  'season stance time title',
#  'clinic volunteer food bag spaghetti people vaccine vaccination appointment',
#  'health rescind order city mask vaccination entry type city rescission policy effect',
#  'vaccination age datum immunity kid infection sign effect virus stay',
#  'exposure time reason discussion vaccination immunity consideration discussion',
#  'today vaccination requirement morning kid',
#  'couid mandate vaccination proof vaccination couid restriction reason protest thing normalcy people',
#  'vaccination infection rate',
#  'card vaccination',
#  'benefit abandonment measure vaccination program none play leave',
#  'clinic',
#  'country child grave mass death bone health precaution thinking amp',
#  'couid option community search vaccine visit individual couid vaccination',
#  'difference viral_load policy vaccination rate',
#  'mask vaccination',
#  'part work dedication milestone',
#  'moment action saveourkid vaccination intervention parent kid',
#  'hip point thing privacy vaccination status',
#  'thing net',
#  'job vaccination choice',
#  'vaccination guideline kid shooter mill simmon shoot',
#  'reminder use place order portion spending organization parenthood',
#  'schedule covidsummit vaccination world',
#  'people claim population number case vaccination rate',
#  'population population population immunity vaccination imperfect',
#  'nation effort fight virus vaccination',
#  'mandate vaccination requirement month ditch',
#  'event attendee proof vaccination wear mask time state couid protocol information purchase ticket visit bettzedek',
#  'thought vaccine mandate mandate mandate folk difference vaccination rate',
#  'vaccination status restaurant prove crack addict crackpipe',
#  'health care system rule vaccination care build infrastructure support anthrax community healthinsurance screenplay',
#  'lot mandate land crossing job',
#  'place rule athlete city proof vaccination mask spring',
#  'education practice community community role model scourge couid vaccination couid',
#  'vaccination border migrant',
#  'ground report question connection amp vaccination requirement sample trucker focus trucker protestor',
#  'work love conclusion vaccination choice vaccine individual impact pandemic trajectory',
#  'arrival datum',
#  'vaccination requirement register event venue',
#  'thread country restriction vaccination rate denmark amp hospital couid situation',
#  'mask people control vaccination',
#  'mutate vaccination rate ship complication people risk datum support protection emphasis',
#  'omicron month vaccination dose month datum news fall',
#  'couid infection reuter reason choice alternative medicine',
#  'none beginning cooperate virus virus existence mandate court vaccine disinformation',
#  'couple couid vaccination reduce_chance conception infection sars_cov reduction fertility male safety vaccination couple conceive',
#  'snack vaccination staff switch',
#  'rule vaccination change playoff',
#  'vaccination crack_pipe friend',
#  'net team vaccination ruin season moment streak',
#  'shot couid primary_serie vaccination sign body building protection couid mo',
#  'team thing vaccination status playoff series play score net eye',
#  'vaccination establishment superintendent call spine truth',
#  'protest air train travel restriction',
#  'opinion provider topic vaccination mandate survey',
#  'employment vaccination job field citizen employment freedom endthemandate',
#  'assumption distinction risk benefit analyze vaccination',
#  'difference prevention harm moment vaccination rate mask mandate course outlaw driving safety measure',
#  'joke protest vaccination dentist',
#  'vaccination',
#  'teacher parent student vaccination charter_right freedom people one',
#  'poll vaccination passport system',
#  'question visitor couid vaccination record vaccination royal thank',
#  'help vaccination clinic',
#  'infection immunity idea immunity intervention term post infection immunity vaccination infection',
#  'change requirement border month detail vaccination number',
#  'pattern couid symptom vaccination month pfizer answer thank',
#  'virus vaccination rate rest',
#  'milestone vaccination expert goalpost occasion',
#  'vaccination card',
#  'control booster land vaccination status',
#  'vaccination passport pharmacy vaccination clinic',
#  'vaccination decision',
#  'support issue vaccination rate mandate bubble support troll president state member',
#  'problem bus station state vaccination rail passenger',
#  'force work vaccination comparison',
#  'summit commitment support engine recovery system recovery read',
#  'vaccination year people year',
#  'people guidance vaccine requirement virus vaccination requirement child school',
#  'freedom force people vaccination line sand',
#  'time number antibody people performance antibody infection vaccination',
#  'transmission omicron tool importance',
#  'vaccination mandate mask mandate month mask downside upside',
#  'restriction coercion vaccination transmission mask mandate one care coercion bullying',
#  'place policy vaccine place year proof vaccination thing job schooling placement healthcare',
#  'sheep anthrax vest movement power vaccination',
#  'vaccination rate',
#  'discussion family tonight vaccination location',
#  'time day week',
#  'mandate',
#  'trumpet crossing vaccination freedom think economy trump era opinion',
#  'omicron vaccination status infection virus other symptom',
#  'immunity vaccination polio time vaccine protect omicron variant protection',
#  'reason vaccination purpose saving_live',
#  'effort update pharmacy team vaccination guideline location appointment information detail',
#  'consequence vaccine people vaccination',
#  'vaccination people',
#  'masking group punishment health',
#  'child sacrifice vaccination area limit mine contact',
#  'checking',
#  'vaccination booster amp couid time',
#  'people protester passenger vehicle strip club vaccination',
#  'line ticket boy varsity basketball tonight mask',
#  'run autumn stadium noon information',
#  'variant vaccine vaccination dose booster prevent folk shot mutation limo',
#  'year ceremony proof vaccination couid petri_dish',
#  'vaccination status business guidance',
#  'number nation flu vaccination testing policy',
#  'son health vaccination status health practice office people saying doc doctor expertise',
#  'vaccine case couid variant myocarditis amp pericarditis issue infection occurrence vaccination',
#  'hospital year pandemic vaccination overweight',
#  'staff show proof vaccination visitor datum guiding decision',
#  'show vaccination card hat',
#  'time parent school',
#  'vaccine vaccination eligibility equity show access adult child amp child',
#  'time effect kid vaccination prevention position',
#  'mandate industry vaccination traveler rail air lift',
#  'stress treatment infection stress infection thing infection part message',
#  'family priority pandemic vaccination removing mandate group county shot',
#  'people age rate proof vaccination reason people',
#  'thing organ stuff repeat motive vaccination',
#  'people couid population vaccination order curb',
#  'student person vaccination requirement abuse',
#  'arbitrator employer vaccination policy employee return office',
#  'place proof vaccination restaurant lot restaurant establishment',
#  'end suit avoid end observation recommend vaccination',
#  'thank support health kiwis drive vaccination consequence part society job choice',
#  'vaccination proof fun show',
#  'people infection vaccination variant',
#  'day vaccination status science',
#  'existence side_effect vaccination',
#  'disease people freedom impact right decision vaccination mask',
#  'amp vaccination booster',
#  'vaccination number goal risk balance example age health cohort virus threat threat other',
#  'meme opposition vaccination precedent opposition smallpox vaccination wane opponent smallpox',
#  'post story ignore kid parent worth',
#  'vaccination vet',
#  'jurisdiction couid vaccination rest world brunt failure medium',
#  'clerk vaccination test requirement owner place',
#  'misinformation look study group today vaccination rate omicron',
#  'compromise kicker talk day leadership preache injury',
#  'number folk time death vaccination requirement',
#  'mask',
#  'vaccination series dose message patient health',
#  'vaccination proof couid border',
#  'growth people travel couid vaccination rate',
#  'couid primary_serie vaccination sign body building protection couid',
#  'government student person class proof vaccination health protocol place news release',
#  'cruise line passenger mask kid board proof vaccination',
#  'vaccination card vote',
#  'proof vaccination enter store foot grocery pharmacy',
#  'couid worry vaccination crap honkhonk freedomconvoy',
#  'eye immunization service ask population amp icy couid vaccine booster yrs mo dose',
#  'behavior business policy indicator compliance safety measure vaccination booster hygiene amp',
#  'stance vaccination religion team',
#  'vaccination mask test',
#  'vaccination campaign benefit',
#  'part level vaccination couid party',
#  'couid vaccination testimony report contact',
#  'month post vaccination approach couid mitigation spot vaccine wall advocacy ideology',
#  'part vaccination',
#  'point money thousand people vaccination check mandate',
#  'distance list item break running diesel vaccination truck_driver time',
#  'shoe belt airport year vaccination rate response buffet environment variant people day couid',
#  'capsule virology immunology level level vaccination weapon',
#  'citizen fact vaccination mandate people activity people',
#  'case vaccination requirement case case ride restriction prepare case',
#  'couid vaccination child year',
#  'morning',
#  'situation student school vaccination rate year sing dance act process rapid_test exception',
#  'couid vaccination clarification',
#  'mandate today vaccination status couid test',
#  'event check vaccination mask comfy night',
#  'kid vaccination clinic yesterday load vaccine',
#  'movie vaccination day couid test',
#  'vaccination rate interpretation wastewater measure',
#  'vaccination year_old couple generation',
#  'congratulation hesitancy factor portion individual individual uncertainty infection vaccination issue risk reward calculation',
#  'vaccination ventilation testing way news strategy mask mandate people',
#  'projection people care people care vaccination status society',
#  'role advocacy partnership couid vaccination rate initiative people disability',
#  'child vaccination measure cloth mask',
#  'recommendation area policy level masking area vaccination rate rate hospitalization',
#  'child vaccination desi family child date child visit vaccination',
#  'coordination resident company employee audience vaccination policy visit info theater',
#  'question imprinting thought arise lens infection vaccination cell paper way',
#  'body proof vaccination crack_pipe',
#  'emergency measure government compulsory soldier site',
#  'put end vaccine passport vaccine extortion end blockage',
#  'alarm vaccination doctor expert whistleblower',
#  'comment vaccination focus',
#  'vaccination rate bus kid reason highschooler',
#  'park',
#  'lot thing help today vaccination passport bother force people',
#  'vaccine event vaccination page check page event',
#  'vaccination code',
#  'injection bow nurse vaccination lot safety vaccine',
#  'plot data plot',
#  'situation parent couid vaccination',
#  'sound research work time study research mass vaccination',
#  'people vaccination dose',
#  'epidemic people activity consequence vaccination precaution risk',
#  'time revolution',
#  'kid vaccination rate mask',
#  'kid vaccination kid wa couid community family friend syringe sparkle',
#  'county vaccination rate couid case study result',
#  'actor proof vaccination attend event vaccine restaurant child school hypocrisy',
#  'thing vaccination',
#  'country country vaccination rate one',
#  'vaccination anti_viral',
#  'county vaccination rate surge couid case delta work',
#  'cig tally app card',
#  'response protestor job canadian vaccination rate attack majority',
#  'proof vaccination restaurant vaccination rate',
#  'couid nineteen community part vaccination opportunity',
#  'bitch saying vaccination school',
#  'insurance premium employer vaccination area politic end couid seriousness science deserve pocket book shift end couid',
#  'patient question vaccination requirement caregiver transplant recipient',
#  'force support repercussion',
#  'cost compare benefit vaccination support child benefit',
#  'vaccination requirement example ignorance principle',
#  'town nflalumnihealth amp testing event health expert amp football inglewood',
#  'addition point time experiment part vaccination town reason trepidation part root issue',
#  'datum couid couid vaccination movement acceptance couid vaccine',
#  'girl basketball basketball tonight night senior theme school vaccination',
#  'proof vaccination crack_pipe',
#  'repeat vaccination people',
#  'herd_immunity vaccination safety people term group people point mandate',
#  'vaccination rate mandate head people mandate',
#  'story vaccination number restaurant posting folk eat indoor',
#  'employer vaccination right job market segregating',
#  'state vaccination booster durable mitigation',
#  'reason seat pop proof vaccination option attest',
#  'vaccination year_old couple generation',
#  'unit availability vaccination clinic',
#  'government response vaccination fine',
#  'restaurant requirement vaccination number',
#  'player vaccination status compliance health rule pandemic award teammate matter',
#  'exposure level dose thermodynamic vaccination antibody_level cross convalescent',
#  'surprise population fish food year round construction education trade use vaccination policy need',
#  'subject vaccination disease health system table notion disappearance disease',
#  'case death hospitalization addition vaccination rate amp vaxupnova',
#  'sense passport',
#  'immunity infection',
#  'consequence youth vaccination rate school mask mandate work health officer superintendent comment',
#  'vaccination system',
#  'vaccination religion mind people lie time truth charge',
#  'self professional',
#  'world vaccination rate start',
#  'consideration stage employer vaccination status amp request vaccine vaccination status disability inquiry',
#  'track info rule athlete amp spectator charge proof livestream',
#  'indicator infection condition infection diabetes heart damage infection vaccination status age',
#  'health expert vaccination number spread scenario end pandemic',
#  'datum year vaccination religion awakening brutal',
#  'mask vaccination status',
#  'article tip sentence people couid period vaccination illness mean',
#  'wing hockey team star player player travel pay game vaccination healthcare system income',
#  'parent couid vaccination',
#  'vaccination card crime year',
#  'way pandemic vaccination endallmandate honkhonk',
#  'people dive vaccination number people data collection system',
#  'mask vaccination status mandate tomorrow match school mask mandate school board',
#  'naturalimmunity immunity datum advice age',
#  'exception vaccination requirement',
#  'plan passport vaccination situation masking time',
#  'none patient timeframe tweet science article textbook case health community vaccination',
#  'race vaccination rate shot booster',
#  'sliver optimism vaccination school vaccination adult',
#  'booster vaccination',
#  'background dot vaccination clinic priority couid vaccine',
#  'booster vaccine omicron wave health couid vaccination clinic',
#  'line tomorrow proof vaccination test event',
#  'vaccine risk death year people vaccination place mask',
#  'vigilance adverse_event couid vaccination confidence vaccination pandemic',
#  'vaccination kid adult school hospitalization week quality mask school',
#  'state parent play date vaccination',
#  'ensure rate contamination slaughter child vaccination',
#  'couid vaccine verification record vaccination',
#  'hour violation emergency order vaccination check session resolution',
#  'mask child vaccine vaccination rate state hospitalization',
#  'person date couid vaccination protection infection severe_illness hospitalization sequelae death',
#  'organizer trucker trucker trucker vaccination thing list',
#  'vaccine freedom living vaccination',
#  'kind anxiety rock vaccination venue',
#  'vaccination strategy prevent infection complication transmission couid vaccination dose dose',
#  'canadian couid vaccination',
#  'computer vaccination card car worry way railroad',
#  'event calendar twitter vaccination requirement group power',
#  'vaccination scientist society article explore researcher other fight couid',
#  'phase success vaccination spread therapeutic reduce death people people',
#  'tomorrow vaccination clinic campus vaccination walk_up welcome share post vaccination tomorrow staysail',
#  'government advisor vaccination kid politician school health reason choice kid',
#  'employer health intervention convoy end risk case organizer labor',
#  'attend year',
#  'response master mask wear mask mask vaccination risk respond',
#  'concern school age kid sibling age vaccination wish hold precaution',
#  'disparity vaccination rate people color alliance share vaccine info amp resource amp event',
#  'school student thing vaccination school vaccination',
#  'policy push child vaccination focus equity leader health way',
#  'safety safety thing code safety safety people',
#  'explanation guess masking prevalence vaccination prevalence',
#  'math student application function year engineering student project supply',
#  'people couid variant couid people chance',
#  'partner shot time booster month vaccination record date mine min update',
#  'course criticizing picture expert immunity vaccination bias reality',
#  'base decision school vaccination status',
#  'heritage murder ancestor people vaccination journalist statement protester',
#  'reduce variant folk death flu level death flu level vaccination rule',
#  'process decision freedom emergency size employer vaccination',
#  'proof couid vaccination',
#  'child vaccination hypocrite',
#  'friend campaign activism community vaccination clinic year work',
#  'research repeat couid vaccination infliximab',
#  'data level relax mitigation step level vaccination level',
#  'couid other country country vaccination case',
#  'masking vaccination requirement starter supply treatment living couid mean',
#  'amp trucker attempt economy order mask amp vaccination requirement people disobedience',
#  'finding study individual vaccination copy number duration viral risk virus transmission',
#  'vaccination rate risk canadian dose country access vaccine way reduce variant amp',
#  'lockdown policy country roadway show proof',
#  'vaccination status state case',
#  'cell work antune infection study example teamwork lab',
#  'article academy test test day event award critic choice award vaccination',
#  'border nurse work mandate need border protest mandate',
#  'existence danger threat way body vaccination pass people',
#  'vaccination reduce idea virus produce infection individual vision vaccine pal',
#  'course vaccination mandate government people government people order',
#  'country visit proof vaccination immunity',
#  'update vaccination increase holiday vaccine availability',
#  'childhood vaccination event couid vaccine rejection',
#  'child signal heart_attack overlook vaccination',
#  'vaccination mask',
#  'vaccination seroprevalence study infection capture protein',
#  'fear politician doctor exemption vaccination campaign prove gas reason protester freedom',
#  'warning employee city vaccination',
#  'vaccine policy kid player spectator vaccination access ground',
#  'school catholic state vaccination student case mask day amp government',
#  'mask vaccination',
#  'point vaccination country want move',
#  'card',
#  'datum infection car time car ifr infection flu season range level',
#  'today focus couid spotlight society bum',
#  'person age state health symptom intensity disease severity vaccination consistent',
#  'hospitalization datum patient hospital couid factor omicron vaccination rate county',
#  'dec_jan crisis peak level bit story vaccination hospitalization amp death',
#  'vaccination paper wallet size help time photo health card code',
#  'people choice study wale childhood vaccination event vaccine rejection',
#  'death considering benefit virulence vaccination right benefit thing',
#  'pandemic havoc housing cost awhile vaccination',
#  'expert change vaccination definition',
#  'state vaccination status border point',
#  'question vaccination rapid_test minister consideration education health ask reassure community school year',
#  'trucker couid restriction micron vaccination rate pattern trend victory',
#  '',
#  'week person couid protocol proof vaccination place camera randy nicker',
#  'hospital people vaccination status matter couid patient hospital',
#  'risk patient heart disease vaccination guidance primarycare counsel moment nutrition exercise mask',
#  'vaccine effect infection study protection vaccination omicron breakthrough',
#  'vaccination rate disability community family caregiver syringe survey',
#  'vaccination year people flu vaccine flu vaccine',
#  'undergrad student question stuff skirt edge vaccination journalism center link chat preoccupation',
#  'hinge case vaccination',
#  'evidence vaccine efficacy mutation evidence mask vaccination reduce transmission',
#  'side_effect effect vaccination side_effect patient vaccination',
#  'vaccination student rate mandate stay place school phase',
#  'couid couid',
#  'scientist expert vaccination amp safety protocol decision maker scientist',
#  'people burden couid infection vaccination kid kid',
#  'meeting forum program',
#  'wave ard vaccination state country',
#  'child child child wear_mask herd_immunity vaccination parent kid kid',
#  'right_winger healthcare income climate action billionaire police reform abolition flipping health skepticism privileging privilege safety',
#  'interview mandate center parliament street parliament truck',
#  'vaccination problem phone',
#  'place people room hour day day week office people floor office rate school kid',
#  'reduce transmission rate annoyance death point',
#  'wave health motivation vaccination time',
#  'experience infection infection',
#  'vaccine inflammation heart vaccination informedconsent science statistic',
#  'impact transmission case omicron level vaccination time turn page reintroduce measure variant',
#  'symptom cough day vaccination',
#  'vaccination proof phone burden folk look',
#  'country mitigation step adult vaccination rate approach',
#  'study datum time vaccination datum people',
#  'vaccination mask mandate',
#  'response dictating policy party policy mitigation amp vaccination amp order profit curve flatten',
#  'thing scare fear campaign vaccination',
#  'forty split evidence vaccination path',
#  'vaccination mask entry ticket',
#  'importance vaccination government canadian',
#  'state mask mandate business arena lift mask policy face mask visitor',
#  'state mask mandate business arena lift mask policy face mask visitor',
#  'day fever nap repeat care place family friend day hoping vaccination hope',
#  'vaccination expert antiviral option couid test pack',
#  'worker vaccination facet moment history extremism question today ottawaconvoy',
#  'vaccination visit champ value vaccination way couid people',
#  'morning medicine group resident thought couid omicron vaccination mask',
#  'strain premise conversation comment infection omicron',
#  'negligence vaccine vaccination detail amp def immunity amp state stimulation body immune_response',
#  'strategy today expansion episode vaccination work lab side look',
#  'keeping mask mandate school vaccination rate child way vaccine age grader student school year life time',
#  'claim week vaccination month',
#  'policy perspective mandate other employer demand vaccination form',
#  'staff book vaccination appointment one',
#  'history rally protestor antivaxxer protester',
#  'correlation causation patient vaccination rate stop thing medicareforall',
#  'support vaccination evidence infection idea respect immunity infection government',
#  'clinic clinic bridgwater week weekend book team',
#  'let coverage dose dose point vaccination dynamic',
#  'vaccination card yacht party people card',
#  'wave beginning week easter irony thing',
#  'annal expert test interval patient screening vaccination',
#  'coercion consent people work vaccination work choice people place',
#  'spring student couid booster vaccine proof',
#  'friend book sale month event mask vaccination status event change couid',
#  'vaccination mandate decision',
#  'check pop couid vaccine child child check couid vaccine time check laptopchild check',
#  'date vaccination',
#  'spread setting social_distance area vaccination site',
#  'instance vaccination authorization freedom choice freedom',
#  'scion validate vaccination info health safety measure',
#  'number student school city vaccination rate put place mask mandate school',
#  'other vaccination quality mask omicron',
#  'reason people people unselfish vaccination protect family friend citizen',
#  'vaccination situation',
#  'vaccineswork placebo definition study result change month year drug hospital vaccine vaccine nurse',
#  'path want vaccination memo',
#  'joescrackhead vaccination card crackpipe kit',
#  'number contamination case twentynine death warning respect campaign syringe',
#  'announcement site vaccination airport appeal number traveler announcement mask',
#  'article vaccine severe_illness couid patient vaccination rate gap',
#  'mask care facility way resident staff visitor face mask matter person vaccination status',
#  'mandate disease',
#  'parent effect vaccine kid dice',
#  'virus thinking work markup',
#  'amp capital efficacy measure vaccination quality mask',
#  'vaccination amount price fraction amount couid response amount life',
#  'analysis vaccination recovery hospitalization couid risk variant',
#  'mask target lockdown limit event capacity vaccination work patient air dictionary pocket paperback',
#  'mask mandate vaccination status check tomorrow end school mask mandate announcement',
#  'alert mourn people hope inequity access vaccination storm resilience amp determination history amp experience outbreak',
#  '',
#  'conservative barrier protester vaccination workplace leader party',
#  'datum math person people case vaccination time case',
#  'vaccination mask protect people increase risk other time',
#  'couid vaccination',
#  ...]

# %%
positive_df['new_text_noun'] = new_text_noun
# Out:
# /var/folders/lg/w8d05wzd48q3m5_s46qt2fxc0000gn/T/ipykernel_86895/1604708766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_df['new_text_noun'] = new_text_noun

# %%
texts = positive_df['new_text_noun']

# %%
texts
# Out:
# 0         way end racism force people bunch people race ...
# 3         case vaccination rate play space adult space p...
# 4             vaccination status code link connect end read
# 5         isolation question look spike matter vaccinati...
# 6             vaccination center parent mask amp amp answer
#                                 ...
# 315597              vaccine choice people risk vaccine part
# 315598     achievement volunteer shotsshotsshot fauciouchie
# 315600                                                other
# 315601                          congrat feeling safetyfirst
# 315602    part end vaccine help other vaccine today phys...
# Name: new_text_noun, Length: 222780, dtype: object

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

high_freq_known_words = ['covid','couid', 'pfizer', 'amp', 'people', 'covidvaccine', 'covishield', 'moderna', 'vaccine', 'astrazeneca', 'vaccinate', 'vaccinated', 'vaccination', 'vaccines']

stop_words.extend(high_freq_known_words)

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=4, M=20, alpha=50/4, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [02:27<00:00,  4.08it/s]

# %%
stable_topics = [0, 1, 2, 3]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#       topic0     topic1       topic2      topic3
# 0       mask      virus          day        time
# 1        kid       shot         shot     mandate
# 2    mandate    booster         dose       thing
# 3     school       year      booster        year
# 4      child       time        today     trucker
# 5     health      death          arm  government
# 6       time  infection         week     country
# 7       care      datum         time       trust
# 8     family       case         hour         job
# 9     choice       risk  side_effect     anthrax
# 10  hospital       dose          flu         way
# 11      work      study    yesterday       today

# %% [markdown]
# ## 5 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=5, M=20, alpha=50/5, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [01:58<00:00,  5.04it/s]

# %%
stable_topics = [0, 1, 2, 3, 4]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#       topic0     topic1       topic2      topic3       topic4
# 0       mask      virus          day     mandate        today
# 1        kid    booster         shot      choice         dose
# 2     school  infection         dose        mask         time
# 3      child       year      booster       thing         week
# 4    mandate       shot          arm     trucker          day
# 5     health      death        today        time         shot
# 6       time      datum         week      health         year
# 7     family       time         hour  government        thank
# 8       care       case          flu     freedom         team
# 9   hospital       risk  side_effect     country      booster
# 10      year       dose         time         job         game
# 11      work      study    yesterday       trust  appointment

# %% [markdown]
# ## 6 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=6, M=20, alpha=50/6, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [02:04<00:00,  4.83it/s]

# %%
stable_topics = [0, 1, 2, 3, 4, 5]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#          topic0    topic1     topic2       topic3      topic4       topic5
# 0       mandate      mask      virus          day        year         dose
# 1          mask       kid       case         shot       trust        today
# 2        choice    school  infection         dose        time         week
# 3        health     child    booster      booster     science         time
# 4       trucker    family      death          arm       thing          day
# 5       freedom      care       shot        today     anthrax         shot
# 6       country      year       time         week      doctor      booster
# 7          time  hospital      datum         hour       world         team
# 8         thing      time       risk          flu         way  appointment
# 9           job    health       year  side_effect        life        thank
# 10   government    friend       dose         time  government         game
# 11  restriction    parent       mask    yesterday   scientist       player

# %% [markdown]
# ## 7 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=7, M=20, alpha=50/7, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [02:14<00:00,  4.45it/s]

# %%
stable_topics = [0, 1, 2, 3, 4, 5, 6]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#         topic0   topic1   topic2       topic3       topic4     topic5  \
# 0      mandate     time     mask          day         dose      virus
# 1       health     year      kid         shot        today      death
# 2         mask    thing   school          arm         week  infection
# 3       choice  anthrax    child      booster         shot       case
# 4      trucker   friend  mandate         dose      booster       time
# 5         care     game     time         hour          day    booster
# 6      freedom    today     wear        today        thank       year
# 7      country   player   family          flu         time       shot
# 8   government     team     year  side_effect  appointment      datum
# 9        thing    trust   parent         week     hospital       risk
# 10         job   family     work         time        month      study
# 11        time     life      day      symptom       health       mask
#
#         topic6
# 0         dose
# 1         year
# 2      company
# 3         time
# 4          day
# 5        money
# 6         shot
# 7   government
# 8      country
# 9        today
# 10        test
# 11        week

# %% [markdown]
# ## 8 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=8, M=20, alpha=50/8, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [02:31<00:00,  3.95it/s]

# %%
stable_topics = [0, 1, 2, 3, 4, 5, 6, 7]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#       topic0   topic1     topic2      topic3       topic4  topic5  \
# 0       care     mask      virus        year          day    time
# 1     family      kid  infection       trust         shot    game
# 2   hospital   school       case       datum          arm  player
# 3     health    child      death     science      booster    team
# 4     friend  mandate    booster        time         dose   today
# 5    patient     wear       time       trial         hour    year
# 6       life     year       shot     company        today   thing
# 7       mask     time       mask       world          flu     day
# 8       year   parent       risk   scientist  side_effect    play
# 9     choice  student      datum       thing         week    love
# 10      time     work       rate      doctor         time    card
# 11     child      day    variant  government    yesterday     way
#
#          topic6       topic7
# 0       mandate         dose
# 1          mask        today
# 2        health         shot
# 3       trucker         week
# 4        choice      booster
# 5       freedom          day
# 6       country         time
# 7         thing        thank
# 8    government  appointment
# 9           job        month
# 10         time       clinic
# 11  restriction         site
