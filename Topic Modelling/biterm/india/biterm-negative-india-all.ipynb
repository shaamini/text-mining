# %%
#for windows users:
#pip install bitermplus

#for mac users:
#xcode-select --install
#brew install libomp
#pip3 install bitermplus

# pip install tmplot
# pip install tomotopy

# %%
# pip install -U scikit-learn

# %%
import bitermplus as btm
import numpy as np
import pandas as pd

# %%
# Importing data
df = pd.read_csv(
    '../pos_neg_india.csv')

# %%
df
# Out:
#        Unnamed: 0  index                                               Text  \
# 0               0      0  soniya mummy hoti toh covid me magic stick ghu...
# 1              12     12  is covid ki waja se buht saray logon ne apne p...
# 2              18     18  deaths due covid what is vaccination rate what...
# 3              28     28  vaccination against covid- 19 is necessity tod...
# 4              33     33  very surprising that unvaccinated population &...
# ...           ...    ...                                                ...
# 37618       95179  95179  nature seems have already started working savi...
# 37619       95180  95180  dear , we #india 🇮🇳has helped this #world incl...
# 37620       95184  95184  our sincere request state central govt 🙏🙏. ple...
# 37621       95185  95185  thanks your appreciation valuable feedback abo...
# 37622       95186  95186  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                                 new_text         languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 1      is covid ki waja se buht saray logon ne apne p...           Unknown
# 2      deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 3      vaccination against covid- 19 is necessity tod...           ENGLISH
# 4      very surprising that unvaccinated population &...           ENGLISH
# ...                                                  ...               ...
# 37618  nature seems have already started working savi...           ENGLISH
# 37619  dear , we #india Indiahas helped this #world i...           ENGLISH
# 37620  our sincere request state central govt folded_...           ENGLISH
# 37621  thanks your appreciation valuable feedback abo...           ENGLISH
# 37622  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
#
#                                               translated     new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 1      is covid ki waja se buht saray logon ne apne p...           Unknown
# 2      deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 3      vaccination against covid- 19 is necessity tod...           ENGLISH
# 4      very surprising that unvaccinated population &...           ENGLISH
# ...                                                  ...               ...
# 37618  nature seems have already started working savi...           ENGLISH
# 37619  dear , we #india Indiahas helped this #world i...           ENGLISH
# 37620  our sincere request state central govt folded_...           ENGLISH
# 37621  thanks your appreciation valuable feedback abo...           ENGLISH
# 37622  i can’t wait get my 2nd dose #covidvaccine ove...           ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 1      [('is', 'VBZ'), ('couid', 'JJ'), ('ki', 'NN'),...
# 2      [('deaths', 'NNS'), ('due', 'JJ'), ('couid', '...
# 3      [('vaccination', 'NN'), ('against', 'IN'), ('c...
# 4      [('very', 'RB'), ('surprising', 'JJ'), ('that'...
# ...                                                  ...
# 37618  [('nature', 'NN'), ('seems', 'VBZ'), ('have', ...
# 37619  [('dear', 'IN'), ('we', 'PRP'), ('india', 'VBP...
# 37620  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 37621  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
# 37622  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1      ['couid', 'ki', 'raja', 'se', 'spray', 'logon'...
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['vaccination', 'couid', 'nineteen', 'necessit...
# 4      ['surprising', 'vaccinated', 'population', 'yr...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'india', 'indians', 'help', 'world', ...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 1                         ['hair', 'ply', 'vaccination']
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['necessity', 'today', 'scenario', 'hope', 'pr...
# 4      ['surprising', 'vaccinated', 'population', 'yr...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'help', 'world', 'include', 'kindness...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type  \
# 0                                              ['death']  subjective
# 1                         ['hair', 'ply', 'vaccination']  subjective
# 2      ['death', 'couid', 'vaccination', 'rate', 'har...  subjective
# 3          ['necessity', 'today', 'scenario', 'problem']  subjective
# 4      ['population', 'yrs', 'offline', 'class', 'amp...  subjective
# ...                                                  ...         ...
# 37618  ['nature', 'generation', 'vaccinesaveslive', '...  subjective
# 37619    ['world', 'kindnessmatter', 'vaccinesaveslive']  subjective
# 37620  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 37621  ['thank', 'appreciation', 'feedback', 'vaccine...  subjective
# 37622  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
#
#        sentiment
# 0              0
# 1              2
# 2              2
# 3              2
# 4              0
# ...          ...
# 37618          2
# 37619          2
# 37620          2
# 37621          2
# 37622          2
#
# [37623 rows x 13 columns]

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df = df[df['sentiment']==0]

# %%
df.head()
# Out:
#    index                                               Text  \
# 0      0  soniya mummy hoti toh covid me magic stick ghu...
# 4     33  very surprising that unvaccinated population &...
# 7     60  under guidance saint gurmeet ram rahim ji, der...
# 8     68  bro you know where was case covid detected ind...
# 9     81  your muslim teachers intellectuals boycott cov...
#
#                                             new_text languages  \
# 0  soniya mummy hoti toh covid me magic stick ghu...   Unknown
# 4  very surprising that unvaccinated population &...   ENGLISH
# 7  under guidance saint gurmeet ram rahim ji, der...   ENGLISH
# 8  bro you know where was case covid detected ind...   ENGLISH
# 9  your muslim teachers intellectuals boycott cov...   ENGLISH
#
#                                           translated new_languages  \
# 0  soniya mummy hoti toh covid me magic stick ghu...       Unknown
# 4  very surprising that unvaccinated population &...       ENGLISH
# 7  under guidance saint gurmeet ram rahim ji, der...       ENGLISH
# 8  bro you know where was case covid detected ind...       ENGLISH
# 9  your muslim teachers intellectuals boycott cov...       ENGLISH
#
#                                     pos_tagged_words  \
# 0  [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 4  [('very', 'RB'), ('surprising', 'JJ'), ('that'...
# 7  [('under', 'IN'), ('guidance', 'NN'), ('saint'...
# 8  [('bro', 'NN'), ('you', 'PRP'), ('know', 'VBP'...
# 9  [('your', 'PRP$'), ('muslim', 'NN'), ('teacher...
#
#                                  words_processed_all  \
# 0  ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 4  ['surprising', 'vaccinated', 'population', 'yr...
# 7  ['guidance', 'saint', 'greet', 'ram', 'rahim',...
# 8  ['bro', 'know', 'case', 'couid', 'detected', '...
# 9  ['muslim', 'teacher', 'intellectual', 'boycott...
#
#                    words_processed_noun_adj_verb_adv  \
# 0                                          ['death']
# 4  ['surprising', 'vaccinated', 'population', 'yr...
# 7  ['follower', 'take', 'pledge', 'get', 'vaccina...
# 8  ['case', 'detect', 'fail', 'bring', 'case', 'b...
# 9  ['intellectual', 'education', 'top', 'leader',...
#
#                                 words_processed_noun   text_type  sentiment
# 0                                          ['death']  subjective          0
# 4  ['population', 'yrs', 'offline', 'class', 'amp...  subjective          0
# 7  ['follower', 'pledge', 'couid', 'vaccination',...  subjective          0
# 8  ['case', 'case', 'testing', 'people', 'vaccina...  subjective          0
# 9  ['intellectual', 'education', 'leader', 'healt...  subjective          0

# %%
df.reset_index(inplace=True)

# %%
df.drop(['index'], axis=1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#        level_0                                               Text  \
# 0            0  soniya mummy hoti toh covid me magic stick ghu...
# 1            4  very surprising that unvaccinated population &...
# 2            7  under guidance saint gurmeet ram rahim ji, der...
# 3            8  bro you know where was case covid detected ind...
# 4            9  your muslim teachers intellectuals boycott cov...
# ...        ...                                                ...
# 20024    37598  you are right. till today there is no mention ...
# 20025    37601  do we have eat scotch eggs until we are vaccin...
# 20026    37602  it means even if 50% vaccinated lead herd immu...
# 20027    37611  that is good decision. even two doses policy j...
# 20028    37617  indian gene with 66yrs no comorbidities ,he is...
#
#                                                 new_text languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...   Unknown
# 1      very surprising that unvaccinated population &...   ENGLISH
# 2      under guidance saint gurmeet ram rahim ji, der...   ENGLISH
# 3      bro you know where was case covid detected ind...   ENGLISH
# 4      your muslim teachers intellectuals boycott cov...   ENGLISH
# ...                                                  ...       ...
# 20024  you are right. till today there is no mention ...   ENGLISH
# 20025  do we have eat scotch eggs until we are vaccin...   ENGLISH
# 20026  it means even if 50% vaccinated lead herd immu...   ENGLISH
# 20027  that is good decision. even two doses policy j...   ENGLISH
# 20028  indian gene with 66yrs no comorbidities ,he is...   ENGLISH
#
#                                               translated new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...       Unknown
# 1      very surprising that unvaccinated population &...       ENGLISH
# 2      under guidance saint gurmeet ram rahim ji, der...       ENGLISH
# 3      bro you know where was case covid detected ind...       ENGLISH
# 4      your muslim teachers intellectuals boycott cov...       ENGLISH
# ...                                                  ...           ...
# 20024  you are right. till today there is no mention ...       ENGLISH
# 20025  do we have eat scotch eggs until we are vaccin...       ENGLISH
# 20026  it means even if 50% vaccinated lead herd immu...       ENGLISH
# 20027  that is good decision. even two doses policy j...       ENGLISH
# 20028  indian gene with 66yrs no comorbidities ,he is...       ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 1      [('very', 'RB'), ('surprising', 'JJ'), ('that'...
# 2      [('under', 'IN'), ('guidance', 'NN'), ('saint'...
# 3      [('bro', 'NN'), ('you', 'PRP'), ('know', 'VBP'...
# 4      [('your', 'PRP$'), ('muslim', 'NN'), ('teacher...
# ...                                                  ...
# 20024  [('you', 'PRP'), ('are', 'VBP'), ('right', 'JJ...
# 20025  [('do', 'VBP'), ('we', 'PRP'), ('have', 'VB'),...
# 20026  [('it', 'PRP'), ('means', 'VBZ'), ('even', 'RB...
# 20027  [('that', 'DT'), ('is', 'VBZ'), ('good', 'JJ')...
# 20028  [('indian', 'JJ'), ('gene', 'NN'), ('with', 'I...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1      ['surprising', 'vaccinated', 'population', 'yr...
# 2      ['guidance', 'saint', 'greet', 'ram', 'rahim',...
# 3      ['bro', 'know', 'case', 'couid', 'detected', '...
# 4      ['muslim', 'teacher', 'intellectual', 'boycott...
# ...                                                  ...
# 20024  ['right', 'till', 'today', 'mention', 'local',...
# 20025  ['eat', 'scotch', 'vaccinate', 'little', 'conf...
# 20026  ['mean', 'even', 'fifty', 'vaccinated', 'lead'...
# 20027  ['good', 'decision', 'even', 'two', 'dose', 'p...
# 20028  ['indian', 'gene', 'yrs', 'comorbiditie', 'see...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 1      ['surprising', 'vaccinated', 'population', 'yr...
# 2      ['follower', 'take', 'pledge', 'get', 'vaccina...
# 3      ['case', 'detect', 'fail', 'bring', 'case', 'b...
# 4      ['intellectual', 'education', 'top', 'leader',...
# ...                                                  ...
# 20024  ['right', 'today', 'mention', 'local', 'train'...
# 20025  ['eat', 'scotch', 'vaccinate', 'little', 'conf...
# 20026  ['mean', 'even', 'vaccinated', 'lead', 'herd_i...
# 20027  ['good', 'decision', 'even', 'dose', 'policy',...
# 20028  ['gene', 'comorbiditie', 'seem', 'say', 'vacci...
#
#                                     words_processed_noun   text_type  \
# 0                                              ['death']  subjective
# 1      ['population', 'yrs', 'offline', 'class', 'amp...  subjective
# 2      ['follower', 'pledge', 'couid', 'vaccination',...  subjective
# 3      ['case', 'case', 'testing', 'people', 'vaccina...  subjective
# 4      ['intellectual', 'education', 'leader', 'healt...  subjective
# ...                                                  ...         ...
# 20024  ['today', 'train', 'availability', 'general_pu...  subjective
# 20025            ['scotch', 'lot', 'emphasis', 'scotch']  subjective
# 20026                          ['lead', 'herd_immunity']  subjective
# 20027  ['decision', 'dose', 'policy', 'jab', 'vaccine...  subjective
# 20028  ['gene', 'comorbiditie', 'vaccine', 'reason', ...  subjective
#
#        sentiment
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 20024          0
# 20025          0
# 20026          0
# 20027          0
# 20028          0
#
# [20029 rows x 12 columns]

# %%
texts = df['words_processed_all']

# %%
texts
# Out:
# 0        ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1        ['surprising', 'vaccinated', 'population', 'yr...
# 2        ['guidance', 'saint', 'greet', 'ram', 'rahim',...
# 3        ['bro', 'know', 'case', 'couid', 'detected', '...
# 4        ['muslim', 'teacher', 'intellectual', 'boycott...
#                                ...
# 20024    ['right', 'till', 'today', 'mention', 'local',...
# 20025    ['eat', 'scotch', 'vaccinate', 'little', 'conf...
# 20026    ['mean', 'even', 'fifty', 'vaccinated', 'lead'...
# 20027    ['good', 'decision', 'even', 'two', 'dose', 'p...
# 20028    ['indian', 'gene', 'yrs', 'comorbiditie', 'see...
# Name: words_processed_all, Length: 20029, dtype: object

# %%
new_text_noun = []

for row in texts:
    new_row = row.strip("][").replace("'","").split(", ")
    new_row = " ".join(new_row)
    new_text_noun.append(new_row)

# %%
new_text_noun
# Out:
# ['soniya mummy hot toh couid magic stick huma ke death kam kar deli aur rahul baba ape hadto se tayyar kake vaccination data',
#  'surprising vaccinated population yr forcefully exposed attend offline class amp examination present couid situation one care safety cannot offline class amp examination begin couid vaccination well',
#  'guidance saint greet ram rahim dear sacha sauna follower took pledge get vaccinated encourage_others couid nineteen vaccination get inoculated selfless service humanity',
#  'bro know case couid detected india fact kerala failed bring case boasting given testing heard many people kerala still feel vaccination taboo',
#  'muslim teacher intellectual boycott couid vaccination education top leader visiting u health health system flood couid pandemic nation seen delivering social service harmonious act',
#  'lord macaulay education system promotes religious conversion appeasement health service many people still couid positive infection rate high death rate high vaccination rate social welfare promotes people join isi',
#  'not oppression people yesterday taken appointment couid nineteen vaccine wife today vaccination worker present wasted time money',
#  'effectiveness vaccine life changing number vaccination rajasthan gone taken vaccine rajasthanrevealed rajasthan vaccineswork vaccinemandates couid safetyfirst thursdayvibes',
#  'adam rare autoimmune disease causing demyelination brain spinal cord many precipitating factor trigger known rare defi vaccination recently also associated couid infection rarely couid nineteen vaccination',
#  'let_us suppose bro one shot dead spot show biodata information like national id card couid nineteen vaccination card photo one day came know home make video mobile expose',
#  'let rephrase not favour sending kid school without couid vaccination vaccinated severe disease time kid vaccine available vaccination card needed school admission',
#  'almost couid infection minor symptom taking vaccination panic treat like fever rest home additional precaution wearing_mask avoid sharing personal stuff home',
#  'stop stupid blind real fact surplus fund cares_fund despite used vaccination crore allocated couid people money mean time bop grown wealthiest party last eight year earth eight',
#  'take pledge get vaccinated encourage_others couid nineteen vaccination get inoculated dear sacha sauna selfless service humanity saint greet ram rahim',
#  'death blow cannot dealt rna corona virus like couid purpose vaccination not eliminate couid convert pandemic endemic progressive mutation mostly beneficial force virus adapt human causing le harm',
#  'couid really exists already immune u exposure point forced vaccination child covidiot',
#  'still need hospitalization vaccination amp endless booster doze time face harsh truth billion conned amp made pay compromising immune_system couid amp many variant vaccine global scam epic proportion',
#  'cannot see vaccination introduced graph also strangely death today couid week omicron remove one would died anyway still comparable daily cancer death',
#  'professor think couid vaccination worldwide clinical_trial hope got saline injection not real deal belief people died depression couid also competent teacher far biology degree',
#  'case one person couid vaccination certificate shown issued document digilocker contains photo however not case another vaccinated person enable photo another vaccinated person',
#  'good decision abandon routine couid testing admission delivery surgery etc asymptomatic patient result india high vaccination percentage kudos u one man vision execution',
#  'hopping not become like someday couid vaccination',
#  'promote health dot birthday make fake entry vaccination make fake entry people get vaccine anybody couid death responsible u health dot kindly reply happen',
#  'wife child couid nineteen vaccination rolled time one severe complication couid nineteen situation worsening better get protection get infected virus',
#  'obsessed dead_body today talk sikh genocide sponsored riot started appeasement policy amp couid death amp dead_body ganga basically hindu died couid inc doubting vaccination hypocrite',
#  'avoid couid nineteen vaccination way remove couid vote bop as',
#  'despite virus appearing evade vaccine used ongoing commitment global couid vaccination definitely still key',
#  'letter consent sent parent child vaccinated school parent declined amp not want child vaccinated couid hoping make appearance encourage uptake vaccination school',
#  'referring joe organ unfortunate comment couid vaccination not horrible comment clear',
#  'hope not may damaging effect couid immediate risk death drastically reduced vaccination reason step three dose vaccine regimen',
#  'everyone getting vaccinated couid vaccination situation prothomalo covidvaccine',
#  'anything mandated vaccination status upon time believed getting vaccinated shield getting couid since virus evolved not policy kindergarten debate',
#  'nothing wrong picture loved mahendra_modi certificate elected majority indian not problem couid management india vaccination best whole universe success reveal shit',
#  'answer simple lockdown not solution current pandemic many european country lifted restriction focused vaccination individual responsibility follow couid preventive_measures',
#  'common human facing four kind fear one couid amp variant two vaccinated people infected ultimate result vaccination three nose not covered mask virus police attack four fear news disease',
#  'kinda annoying see pal protesting anti mask anti van like argument person got van still got couid like even understand difference vaccination treatment glad following basic protocol',
#  'month period got watching mustafa youtube fuck couid vaccination done already excruciating cycle sanity',
#  'covidvaccination grand exp going wait outcome consented gas exp worry know exp exp aim euthanized culled rehabilitated fate decided experimenter not exp aim',
#  'kyun must ration marino tak poor woman got vaccination ka bandobast kira india handled couid better developed country',
#  'law le justice politician le freedom couid vaccination le natural_immunity',
#  'clear like crystal couid vaccine not work part problem not solution stop mandate vaccination stopvaccinemandates',
#  'poor response public million covidvaccine dos nearing expiry private_hospitals want utilised vaccine amp use governmenthospitals report covidvaccination',
#  'foolish idea almost indian already got infected developed highest possible immunity couid nineteen need vaccination really love india indiana stop vaccination immediate effect',
#  'protesting taking help kanhaiya kumar yogendra yadav broker dallas democracy trying one best vaccination drive wanting couid spread like wild fire bad democracy belittling armed force bad',
#  'man swore kid never join politics lied amp u turn exist delhi road build single hospital eight year utilise central fund build plant criticises man led world biggest couid vaccination drive',
#  'surprised educated learned canadian friend opposing vaccination whole family got couid recovered fast flu like symptom many case point vaccine help big way',
#  'sister couid vaccine know many vaccine not think people introduced india not publicizing pic not know issue not affix vaccination particular government',
#  'gentleman message beloved people canada vaccination not compulsory remember un vaccinated develop phnumonua couid nineteen infection prepare departure kindly wise decision decision change could save life',
#  'not taken single couid leave last two year yet company insist safety others must comply else lose job meanwhile many colleague falling sick even fully vaccinated fall sick couid post vaccination fine',
#  'vaccination good way avoid corona keeping view epidemic couid one humanitarian act added dear sacha sauna organisation wear_masks inspire others wear babaramrahim',
#  'aussie government confirmed novak valid exemption deported anti vaccination sentiment expect rafa boycott rafa could say something kind like nick kyrgios not say anything novak donated rafa fundraising couid crisis',
#  'space twitter healthy debate provaxxers people couid nineteen try understand point view without judgement covidvaccine covidvaccination vaccine pfizer modern coaxing boostershot',
#  'trying show vaccinated people catch couid catch bad one die higher vaccination rate higher rate usa woefully bolstered',
#  'absolutely brings back feeling hopelessness vaccination round need change narrative reporting style really mean couid endemic show u fruit vaccination labour focus cat four amp five',
#  'time like today couid vaccination become vital u well people protection saint ram rahim emphasized importance therefore added two welfare work list e getvaccinated encourage_others',
#  'grateful god saved u second wave couid infected fully vaccinated able come infected third_wave lost friend relative vaccination',
#  'vaccine risk post vaccination allergy low according report doctor suggested individual allergy condition take allergy medication getting couid vaccination doctor recommend taking couid vaccine',
#  'wrong u get disease not taken vaccination ur loss take vaccination u would also taken polio vaccination not not u taken couid vaccination student teach biology',
#  'aided large_scale vaccination possibly milder omicron_variant family doctor armed paracetamol forefront india couid thirdwave read story know coped surge patient',
#  'whatever vaccination coverage without u finally seems couid behind u manipulator withdraw easy money stock lol',
#  'oral people not stepping due couid restriction also theater chennai demanding dual vaccination give good idea country help country economy development',
#  'pandemicofthevaccinated couid vaccination simply not work harm good stop vaccination mandate spare child deadly shot',
#  'think protection offered vaccination hyped political financial reason know wrong',
#  'first devi paul got message getting couid vaccine not family mistake bogus vaccination please look_matter vaccination',
#  'fda used critically flawed risk benefit analysis justify couid vaccine child hazard couid nineteen vaccination exceed advantage million child',
#  'couid vaccine made susceptible viral infection vaccination immune_system strong enough fight viral disease become sick every week strange',
#  'yup still not know impact survivor hopefully not bad vaccination',
#  'heal kaiten global couid vaccination perception pal fill survey covidvaccine perceptionsurvey healhealth healfoundation vaccinehesitancy know going right wrong',
#  'better come work couid ward talk human right aspect vaccination human right person sitting next vaccinated passenger bus carrying virus home giving child',
#  'not question intolerance question photograph needed couid vaccination certificate logic photo printed couid death certificate flawed logic',
#  'warning country high vaccination rate denmark scrap restriction disbanded lost touch amp relevance live couid without major restriction vaccination rate high covidvaccine',
#  'maybe couid well asymptomatic telah check tak ignorance bliss spread around healthy beak faith vaccination not transmit pop',
#  'people say not worry high couid number say worry yes vaccination amp booster cannot take thing easy not large crowd use mask properly sanitise often watch distance govt assurance not good enough',
#  'son former bronchitis patient see effect easy get flu slow healthy mixed sinus issue would not risk not give couid vaccination even usual virus affect badly long couid effect naudzubillah',
#  'couid nineteen contagious disease caused severe acute respiratory syndrome coronavirus two getvaccinated couid nineteen protect family couid nineteen vaccination camp organized various state block guidance',
#  'imagine compare smallpox couid justify vaccination child second not kill child people right vote',
#  'surprising vaccination couid not compulsory person not got single dose must punished de pose risk others got vaccinated fine facility movement checked risk',
#  'not want wear_mask stay away dubai couid rate low lockdown brief early economic social impact minimal highest vaccination rate world',
#  'ferozepur police view increasing number couid case urge get corona vaccination safety safety others ferozepur police help doctor vaccinated police_personnel booster dose punjabfightscorona',
#  'peak couid vaccination line one removed mask sneeze questioned said mask ganda nazi go jaya upside',
#  'strange canadian amp family shifted secret location protester opposed compulsory couid nineteen vaccination thousand stage protest ottawa canada vaccine mandate via',
#  'showing two dose vaccination certificate also forcing traveller take roper making passenger wait hour station please take immediate action else couid spread start spot making public gathering longtime',
#  'lied woman lied paid lied couid vaccination lied many election',
#  'someone say djokovic couid vaccination queue right aspen australianopen nadal rafaelnadal',
#  'si vaccine name u click couid nineteen vaccination normally dior blast sum u got',
#  'pundit looking evidence effectiveness covidvaccination boostershot simple get understand still want deny well live',
#  'sir student got infected fully vaccination sir one friend got couid ord time death bed ply mercy u month two close institution might pandemic control otherwise student die soon',
#  'inner men_women getting vaccinated india india accelerating couid nineteen vaccine drive vaccination rate remain higher among men many woman lack access health information view_article',
#  'acute phase couid first hurdle couid progress long couid lead permanent disability early death risk vaccination significantly le risk infection anyone telling otherwise know fact',
#  'handy io fifteen four able import couid vaccination status use mom via apple wallet',
#  'future couid booster looking like vaccination boosterdose',
#  'people getting affected couid time even vaccination booster dose govt left private company develop vaccine amp kept concentration money not public health unfortunate',
#  'use keeping market office closed present couid situation even school open asap present symptom couid mild may due vaccination almost every one get cured three four day suggestion',
#  'way may clarify use word breaking help others know whether foolish naive foolish overjoyed vaccination testing proven useless naive childishly think couid pandemic saying farewell',
#  'not vaccine supposed preventive nature couid vaccine unable prevent couid specified duration vaccination bow claim le severity also debatable',
#  'vaccination way reduce death rate due couid booster dose reduce',
#  'aryan govt opening schools_colleges not aware rising case district couid also catch vaccinated people vaccination not solution school not open feb student life precious study exam haryanaschools close',
#  'prove vaccinated still death relative got asthma couid recent time vaccinated fully doctor vaccination not danger condition',
#  'know people not antivaxxer true people suffering pain numbness leg arm due blood clot couid vaccination',
#  'fake couid vaccination raiganj utter dinajpur wife got message vaccinated dose today yesterday not took dose taking vaccination name plus look_matter',
#  'around two wednesday marti nineteen waiting queue get second dose couid nineteen vaccine turn came surprise screen vaccination centre showed already taken second dose three four',
#  'couid testing education institute carried omicron hit city ascertain disease spread among student ensure accurate disease mapping data suggests strong correlation vaccination level infection rate various city',
#  'enough zoom want classroom step one vaccination step two reopen campus maintaining couid protocol amp stop infamous digital divide reopeningsafely reopencampus notodigitaldivide',
#  'ab couid nineteen got either vaccination infection blood not mean not infected catch virus nose mouth swab taken nasopharynx possible',
#  'least price pay not believing couid hesitate vaccination not following sop idiot minister',
#  'couid nineteen vaccine not change human dna rather remain mortal',
#  'al everything wide open even gathering people school college closing stadium academy u impose restriction lik vaccination amp couid norm sport depth trying two damage two future talent ply intervene one two',
#  'considering hve done considerably well plus fact high rate vaccination couid big shud also go ahead try living normally',
#  'keep going question use booster doze couid vaccination first place first dose vaccination much hard pain chest heart hated taking vaccine first place belive immunity',
#  'state sarma statement came centre responding plea made clear supreme_court couid nineteen guideline envisage forcible vaccination without obtaining consent concerned individual',
#  'not allowed enter near place new delhi office couid vaccination rule website also impose govt not mandated get connection converted commercial',
#  'not suggesting like ten based detected long couid far vaccination roughly half risk child also likely show delayed long couid presentation actual case rate likely higher appear child age',
#  'current circumstance every country plenty local data draft local guideline couid management vaccination therefore guidance document issued supported local data time missing dominated foreign data',
#  'elite ifs living metro city think shutting everything solution stop couid despite vaccine effective couid pill not first world country nincompoop rather focus vaccination',
#  'amp propaganda not work saving indian couid vaccination work bjpfailsvaccination',
#  'vaccine make anti body couid nineteen body one time vaccination done one force not taking putting many life danger',
#  'fact novak djokovic making mockery australian couid protocol taking ride supporting anti vaccination encouraging people time omicron surging high island',
#  'one thing learn djokovic debacle tournament need clear couid vaccination policy player exemption guaranteed unless serious health risk player health risk defined ifs buts',
#  'people compare polio vaccine couid vaccination idiot polio vaccine side_effect till rare',
#  'couid positivity ratio pakistan jumped one eight percent last two week however good thing fatality ratio num patient critical care staying low mean vaccine working get vaccinated keep following couid vaccination',
#  'middle quarantine status low risk cannot even assessment want submit couid status not allowed cannot even see vaccination date want submit anything jam continues',
#  'vaccination absolutely necessary control couid',
#  'observing predisposition vaccinated getting new couid vaccination seems right vaccine not medicine not give immediate relief',
#  'corona growing even vaccination vaccine fake government corona fake rajthackeray offhand covidvaccination',
#  'time fight couid nineteen every one take vaccine dose people talk vaccine support take vaccination dose saint singh insane added two welfare work list ongoing welfare work fightagainstcovid',
#  'food thought complain restriction due couid resist wearing_mask social_distancing vaccination etc not realising much harsher time forefather faced lived contended life message',
#  'couid vaccination taken even people food allergy caution',
#  'excuse doctor sahab tweet like not acceptable much unfair main person behind suggestion couid nineteen vaccination one chetan bhagat people not forgive mistake demand apology',
#  'treat couid like flu end mass vaccination booster vaccine expert',
#  'not sick couid yet alhamdullilah prevention vaccination work',
#  'give u road amp piped water first not life_saving talk vaccine heavy push back today settlement vaccination citing obvious amp immediate life saver missing vi vi couid vaccine diva',
#  'singapore icu case per_capita vaccination status orange not fully valued tiny red line vaccinated whole caseload trending yay plainly see almost folk icu couid not fully vaccinated',
#  'couid nineteen third_wave arrived omicron_variant according expert vaccination not effective result election possible cost life staff electorate due violation couid guideline situation worst epi responsible',
#  'bro dna u see infrastructure development india dna u see defense advancement dna u see couid vaccination dna u see gap_growth world dna u see new education policy dna u see terror attack last seven yr indian city u cannot go eye treatment',
#  'fifth wave couid nineteen made abrupt decision close mass vaccination centre nine park',
#  'important get vaccinated reduce risk hospitalization death couid wearing high quality not mask ventilation room important prevent infection vaccination last line defence',
#  'romantically treatment infected patient pandemic increasing infected patient root unstoppable outbreak vaccination much better proactive way save_lives rack brain rush get vaccinated couid',
#  'absolutely wrong son school one want vaccination specific community not control screen time sugar intake anything else restrict son exposure crap social_media sugar couid vaccination not stereotype',
#  'heck thera corona student',
#  'government put slam increase price medicine pandemic couid slab vaccination cost medicine cost not whichever lower high time learn lean bend required time not sell humanity',
#  'aspen not sport india aman dahlia withdraw aspen whereas novak djokovic couid nineteen vaccination exemption wah wah',
#  'couid case starting increase amp wear not mask properly maintain_social distancing vaccination want choice definitely one amp two goya get arse amp move ultra',
#  'halt hai couid vaccination ki chante se line lage hai aur shady giant aur lag jaya hid infection hone chance hai hospital name govt district combined hospital sector thirty',
#  'highly disagree vaccination fundamental right irrespective third person matter parent relative vaccine hesitancy myth harmful fight couid',
#  'herd_immunity natural infection vaccination may not workable solution present juncture due dynamic mutation spike_protein couid virusmicrobeit proved omicron mutation may weakened endemic dangerous stopspreading research',
#  'today visited mata man devi temple panchkula shocked see nobody following couid protocol like wearing_masks sanitizer etc not even checking couid vaccination certificate despite clear guideline govt',
#  'part car contribute saving life human publishing information vaccination medicine formula',
#  'overreacting omicron yes infectious spread faster lockdown not answer world restriction couid appreciate behaviour vaccination worked not want lockdown',
#  'sharif yardarm unimaginable handled couid amp vaccination like pit govt done would bombarded torrent editorial op ed amp talk show reminding u well pakistan managed worst global pandemic century despite poor resource amp state capacity',
#  'way couid raging globally passing double vaccination amp infecting folk ease say time come vaccination drive waste time money asking',
#  'rest took couid vaccination',
#  'not get second dose vaccination know message sent completed vaccination wrong government way central state government crossed crore vaccination couid',
#  'proving everyday worst newspaper whose work create panic amongst people stop business name couid nineteen please take action spreading fake news vaccination',
#  'city united_states couid hospitalization death low vaccination understand difference vaccine protects life people around detour getting virus',
#  'teen died day vaccination abit long long period right many factor could transpired day meanwhile official death couid people think first wait autopsy result first also policy wise cannot much change',
#  'deepak check done train check pas couid certificate vaccination detail really hard track habet multiple entry exit point railway_station not make sense',
#  'know situation indianrailways union health minister concentrated vaccination not protocol pathetic experience show govt taking precaution control couid kindly look issue',
#  'lot russian player karate donkey ruble etc informed got couid nineteen not russia know personally also know require vaccination sick recently coincidence',
#  'hotel staying tonight interested seeing vaccination certificate maybe heard vaccinated people spread couid also interested seeing passport maybe certain guest like remain anonymous',
#  'information population poor country not even first dose vaccination couid disturbing',
#  'mandated irrespective state even checking roper people tested_positive true even people coming abroad needed increase awareness masking vaccination not seen govt supporting couid based loot',
#  'strong recommendation protective like vaccination mask ventilation manufacturer vaccine talk effectiveness long dose last even two year couid surprise still expert talk protective amp not treatment',
#  'priest really afraid god understands god terrible wrath know god threat destroy church upon coming back true belief couid sent god punish humankind know people not talk nonsense vaccination',
#  'last time shoulder affair good',
#  'want vaccine dos every three twelve month need elimination way avoid long couid constant vaccination elimination virus pick one doomed eventual long_term disease disability',
#  'cac not consider person vaccinated two week injection therefor everyone withing first two week injected not considered vaccine death pfizer couid vaccination vaccinesideeffect vaccinedeaths',
#  'not sure incorrect ask minimal get vaccinated happening almost everywhere day given fact even called double vaccination people get affected couid player vaccinated know still happen',
#  'recent visit indore heard people family circle still not taken couid vaccine would probably never take not putting risk everyone around well strict regulation get enforcing vaccination',
#  'country making record covidvaccination craftsman hardworking determined para medical staff despite difficulty getting vaccinated full spirit understanding people remote rural_area vaccinating like also work patience',
#  'even country containment struggle get zero couid policy get vaccination rate',
#  'well said indian journos tacit understanding amongst peddle sort narrative suit political convenience couid vaccination clearly demonstrated shame fellow',
#  'good many brand possible deserve licensing must allowed enter public vaccination domain co couid still alive amp kicking not dead yet amp keep kicking back amp form new variant hospital must filled amp loaded vaccine',
#  'seem like couid back world football match postponed player impacted nineteen time get vaccinated please vaccination',
#  'got est vaccine amp ashamed take not believe couid vaccine government rule mandate crippled work vaccinesideeffects vaccine vaccinemandate vaccination vaccinated vaccinate',
#  'not getting involved vaccine argument sum not word best way seen explain feel couid vaccination fully vaccinated bolstered not know',
#  'sir condition maa kamakhya mandar vaccination verification counter today unable understand preventing couid nineteen spreading administration lot corruption counter operator',
#  'plus know buti people faking couid result vaccination certificate could one reason banned u not backing coma ifeyonso timaonjeza short cut',
#  'shocking cannot believe nonsense action bop govt stop factory making syrinx badly needed couid vaccination wake impending ord_wave',
#  'height dutyfulness couid vaccination',
#  'thursday receive many patient routine_immunization add couid vaccination day many people transport issue remote_areas thursday quite accessible way easily cover population planned non chaotic manner',
#  'high time normalise couid vaccination like routine_immunization much convenient people get dose time without chaos day week like ri thursday medtwitter mended',
#  'let_us wearamask even vaccination couid negative report law ensure safety vaccinated people aircraft ewe ewe ewe ewe groomed',
#  'recommendation make anti couid vaccination mandatory country seriously considered otherwise recurrence disease inform cannot controlled opined last resort',
#  'common men need prove first not ghanchakkar couid appropriate_behaviour vaccination cannot not expect blame government silly little thing traveled day believe best mad rush',
#  'indian government caught wrong foot decision booster child vaccination couid delayed variant omicron arrived vengeance',
#  'really going quit job medical officer thing get convince people get vaccinated covidvaccination medtwitter mended',
#  'india take lead providing anti couid vaccination programme developing country belief principle vasudaiva kutumba sanskrit mean entire universal people one family vaccine coaxing proving effective',
#  'hope test prove omnicronvariant contagious mild couid illness effect malaysia vaccination progress far advisable continue wear_masks remain vigilant couid teaching live present yr duty humble gratitude',
#  'resisting vaccination couid please not avoid get vaccinated today',
#  'courtesy boogey couid first couid vaccine vaccination drive booster jab amp dropped not enough vaccine export committed manufacturer cycle restarted new strain orion',
#  'another couid conspiracy learned muslim india afraid get vaccinated mahendra_modi put face vaccine certificate said smith muslim child hindu vaccination plot make muslim infertile',
#  'first hand hear case vaccinated young adult die shortly vaccination people involved prefer think term causation correlation not causation not argue van hence protected couid got couid recently fine',
#  'india better covidvaccination percentage paper understand people died got second dose skull amp many others getting certificate without second dose received three small sample seventy eighty',
#  'sing sikh hote chute indian much gaan penne wale sale tere pe hindi hang se hi likei gai kia kara penchant jodie gandhi feline ki beat ki tha missile man muslim couid vaccination wo muslim kia tere anchor ni kia karen wale',
#  'covidvaccination modern sir wife vaccinated modern vaccine two shot visit usa earlier year unable obtain universal travel pas modern not appear valid vaccine option kindly help',
#  'not coming vaccination pose bigger danger u vaccine hesitancy raised concern health management beware people couid threatening',
#  'hope government telangana watching development couid front closely view omicron_variant outbreak world request everyone take instruction healthcare authority seriously like vaccination mask hygiene',
#  'thin line alarm frightening believe science explain not literature alarm already good couid appropriate_behaviour vaccination irrespective strain mere frightening name not know detail strain',
#  'stupidity metaverse multiverse except current universe stupidity coronaviruspandemic multiverse cac vaccination vaccinemandate mandatoryvaccination populationcontrollaw healthy',
#  'reviewed couid nineteen vaccination related situation light new variant remain vigilant focus containment ensuring increased second dose coverage would urge people continue following social_distancing wear_masks',
#  'new variant serious threat high time goi get serious providing vaccine security countryman bad vaccination figure cannot hidden long behind one man photo omicron covidvariant couid',
#  'getting mild infection couid nineteen vaccination give best protection future variant expert current vaccine teach body recognise spike protein surface virus could change virus mutates',
#  'sending child school necessary three point one negligible rare proportion yr serious couid complication two obesity mobile use amp lack social interaction dangerous three adult getting vaccination schoolsreopen',
#  'jo log oppose rhe vaccine ka australia australia america netherlands netherlands wo number idiot vaccine vaccination',
#  'taking covidvaccination right choose right choose also come responsibility esp social responsibility humanrights',
#  'gas price started rise colonial pipeline hacked shut le forget everything else think need look couid distribution good delaying supply demand still raising price vaccination could solve issue',
#  'teacher challenge couid vaccine mandate school delhi high court issue notice teacher delhi based government school argued personal choice matter since vaccination voluntary school cannot force take shot',
#  'teacher challenge couid vaccine mandate school delhi high court issue notice teacher delhi based government school argued personal choice matter since vaccination voluntary school cannot force take shot',
#  'couid vaccine included normal childhood vaccination schedule possible achieve vaccination triple dosing yearly booster might even able away mask',
#  'someone play cricket china reply well took half world one bat funny quote covidisairborne covidvaccination whan lockdown',
#  'risk low existing uncontroversial vaccine part normal vaccination schedule push lower risk even people got knickers twist couid vaccine look reason say',
#  'despite negative propaganda fake liberal amp fear hate mongering leader indian modi able inspire indian many area couid vaccination amp india successful couid defence living example many observer say',
#  'faci booster keeping people healthy not alive joe_biden chief medical adviser future couid nineteen vaccination prevent next pandemic',
#  'farce cover south east asia india achieved billion couid vaccination not wrote word let answer not sell must payroll many others apart',
#  'world couid vaccination status get booster others nothing vaccineequity',
#  'really matter either current level vaccination declining immunity aside coupled infected slow spread virus coming week couid going endemic foreseeable future live cave forever',
#  'enough enough long time china cannot allow international student career matter anyhow go back university couid nineteen vaccination sinopharm complete',
#  'india country couid vaccine invented research work need fund india opposition started spreading rumour couid vaccine contains cow pig fat prevent vaccination drive not happen country',
#  'sanjay ha money used fund shortfall revenue caused evasion rahul pa kari de aith pasar jayalalithas rogue cong men amp business men prop ai su bank etc feed eighty people free couid fund free vaccination people',
#  'note nightlife bar remain mandated closed however due couid nineteen despite eighty percent vaccination rate locally strictly enforced pattaya street still quiet',
#  'far okay left arm feel heavy covidvaccination',
#  'modi govt gone systematically step step bank account haar seeding subsidy demonetisation get see part pay digital payment sign even small tea stall couid vaccination went smooth due digital platform',
#  'govt claim collected used pay free vaccination roll plus whatever distribution wealth pertaining couid one need retrospect plus bond oil company need pay govt owes oil company lot money money',
#  'respected rule imposed mumbai public show printed couid vaccination certificate verified official every railway_station harrassing treatment given mumbai public',
#  'also allowing virus destroy u not way forward politically driven lie not supported science couid high transmission rate possible endemic low level outbreak always ravage even high vaccination rate',
#  'sixteen death many vaccinated mindset may need change vaccination part couid package',
#  'dear sir dist health dep integrity issue amp not know not good uneducated people suffer couid nineteen dep job totally proud vaccination proof',
#  'better look tar absolute number case also would not vaccinated believe vaccine break thru case getting hospital minimal data u still need continue vaccination follow couid protocol',
#  'couid case increasing daily situation many place strict lockdown also whole family_members got infected couid full vaccination including againstcollegereopening studentslivesmatter onlineclassonlineexam',
#  'late men seem love show front men march would pee wall use men wall couid changed brain even vaccination not helping u stupid analogy',
#  'commentary parent sibling refuse couid nineteen vaccination',
#  'life matter respect value humanity forcing innocent trolling punishment equal injustice let sport sport not propaganda really want service vaccination couid',
#  'overacted bus neither ask single double vaccination certificate universal pas make wonder couid oil travel train',
#  'nigh plus join speaker argentina namibian netherlands chair germany discus couid vaccination challenge opportunity talking unmet commitment couid vaccine',
#  'add pal not know many case right people care think immune couid two dose vaccination',
#  'couid moment west_bengal school open november decision may not right faith beloved didi amp chief_minister west_bengal child vaccination got illness time suspicious viral fever plus think',
#  'crore couid nineteen vaccination praise modi effort becoz due modi dog house poor prostitute lute khan market delhi destined way ever god mother not return',
#  'sorry unforgettable regime forgot many people died gasping breath want hospital bed denied timely amp proper funeral boast success vaccination amp couid control never forgotten',
#  'time larger state learn smaller one increasing couid vaccination number',
#  'antibody produced agaist couid infection infection antibody test severity couid infection related effect level natural_immunity exposure vaccination protective time natural_immunity present le effective',
#  'sir plus work inflation immediately plus stop polarisation people india ur govt reduce fuel surely inflation pandemic couid burden govt crore vaccination achievement best luck',
#  'people society still not want vaccination strict instruction needed class people prove risky control couid nineteen',
#  'truth chinese vaccination china use force coercion drive couid nineteen vaccination rate not answer',
#  'perfectly right opportune time make vaccination available clinic nursing home casualty blood bank mobile clinic amp public place currently relative hesitancy making effort reach vaccination centre',
#  'certainly show solidarity leader man quite capable lead country quarter national international level couid vaccination etc even america could not achieve within nine month crore vaccinated',
#  'like world baseball series three country play baseball japan not play u one winner runner two country population one billion thus couid vaccination one winner another runner however rejoice',
#  'probably thailand thought job ha not worth indian coming spreading couid probably trust indian vaccination certificate either',
#  'modi govt taken intensive vaccination programme many lakh indian would saved couid death',
#  'sir doubt couid nineteen vaccination exercise progressing appreciable regard neither common peoplenorthe goi amp concerned state government pay importance baseless mentioning poor performance opposition party',
#  'modi people dying due_lack mass funeral due couid body flown ganga river vaccination gained momentum intervened busy staging event modihaitomumkinhai',
#  'battling cancer contracting couid combination low immunity comorbities lost battle life vaccination playing vital role protecting mass',
#  'secretary state colin powell couid remember couid could kill not covidiot refusing vaccination yes vaccination protects couid',
#  'post vaccination couid death rate drastically come go crematorium see statistic',
#  'got first jab sputnik today hey please go get vaccinated religious national moral duty get done asap order contain_spread covidvaccination',
#  'may govt fund unplanned expenditure couid free vaccination free ration eighty people almost year idea',
#  'hello mam tsar singh nodal incharge man medical_college son hospital couid nineteen vaccination centre prayagraj mob ply talk resolving complaint',
#  'main issue choose not vaccinate not risk child health willingness risk health community consideration important get couid one vaccination vaccinemandate',
#  'singapore new couid case aerial spraying neem oil recommended control corona virus spreading via air neem antiviral property lockdown amp vaccination prevent corona virus spreading man man control virus floating air',
#  'not first one literally one talking vaccinated travel couid vaccination personal prophylactic stop transmission virus herd_immunity mute effect couid',
#  'fact check economy bouncing back couid vaccination close reaching crore mark not expose bias openly ajeep not blatantly partisan least figlia credibility',
#  'not said anything wrong not vaccination also many welfare program running couid time money state government take initiative reduce not contribution central program',
#  'let_us ensure every one india take couid vaccination whether govt private hospital report allegation as fit seva sharath indulging money making business vaccination',
#  'see ninety adult vaccination might reach later couid couid side_effect dead_body still alive food thought goodbye',
#  'unnecessary concern estimate planning skill goi u learning couid vaccination let outcome surprise fool paradise long marketing hide reality waste energy something productive',
#  'also natural_immunity couid infection le long lasting variable vaccination repeated infection cell depletion reminiscent hiv absolutely not want infected multiple time repeat infection compound long_term damage',
#  'indeed difficult understand mean vaccination elderly not reduce serious consequence couid nineteen mean age independent factor mortality even vaccinated people please respond',
#  'question vaccination get vaccinated couid nineteen yes not know product biotechnology would dare spread fictitious story similar one farm technology use vetopower farmer alone',
#  'korean wonder aloud say eighty vaccination rate case ever come answer plan along hello govt said going live couid endemic dontbesoblurcan',
#  'take home couid drug molnupiravir may way vaccination still first line defence via',
#  'including anti van would never reach population number one number two high exponential coverage vaccination resulted excrement total sum couid case daily one could deny efficacy would deny give fact not mumble',
#  'seen kid come bad state due miss post couid admitted pick needing inotrope ventilated ever think myocarditis post vaccination till_date not seen case',
#  'get universal pas double vaccination couid certificate mumbai point not trust certificate issued usual site not working properly',
#  'sir boarding shall subject production couid negative report vaccination certificate pal',
#  'factor seem readily explained e excess risk immunocompromised patient elucidating risk infection despite full vaccination couid nineteen naive individual imperative',
#  'una higher proportion long couid meanwhile internet anti govt people still downplaying vaccinated people downplaying govt correct decision vaccinate instead keep laughing joking version vaccination bad',
#  'respected minister sir social protocol vaccination amp step commend get bringing couid nineteen low level opening dining hotel cinema hall gradually welcome step u could pal away mask put car people challenged unfairly feel',
#  'stop couid nineteen vaccination update would genshinimpact',
#  'policy abu_dhabi run pretty much across whole population three use population tested daily mainly ad vaccination rate highest world sadly not release data anyway national level end couid',
#  'deeply perturbed decision goi stop supplying zero five syrinx amp synergizes state couid vaccination derails entire vaccination programme not fair towards state appeal take back decision',
#  'study regarding whether clot prior couid infection lead cardiac failure also effect vaccination also studied hearing lot news like',
#  'hearing lot young people getting cardiac trouble not know whether due clot prior couid infection due clot result vaccination',
#  'ugh appreciated couid vaccination campus mother amp child care refusing give vaccine child lady nurse giving vague reason took vaccine private je government hospital',
#  'guru america useless country much better respect couid handling look vaccination rate look supply status hospital',
#  'vaccination hid gem itisvaccination yogiadityanath renews modi couid management',
#  'special couid vaccination drive conducted woman today across mumbai situation ground seems totally different',
#  'hope education minister stay true word force student return school education minister thienthong said parent worried student study home also made clear couid nineteen vaccination voluntary student',
#  'yes need yellow couid vaccination passport order go restaurant europe example thai version not valid',
#  'yes know many friend colleague contracted couid vaccination non neither got hospitalised died common cold like symptom vaccine give least immunity',
#  'vaccinated covidvaccination',
#  'life would not couid pandemic completed astra seneca vaccination last month also almost seventy bangkok population news seems people dying lockdown boringest not disease gatepost week ago',
#  'right move modi publicity every even couid vaccination certificate not necessary look quite cheap also removed',
#  'conspiracy theory say unauthorized import heroin quantum would directly proportionate consumption country real time consumption without hesitance universal acceptance couid vaccination',
#  'except appear moving forward safely potentially hundred death thousand long couid case coming outbreak hit modelling already indicated higher vaccination rate necessary',
#  'please prioritise couid vaccination cancer patient prevent cancer patient long_term affect amp increased risk couid not vaccinated',
#  'couid vaccination paper checked taken not acceptable indian travel not tell world vaccine taken justifying still not shown india graduation certificate',
#  'obfuscation complex vaccination theory creating another havoc vaccination admittedly cannot eradicate stop transmission make illness milder embankment passenger without couid vaccination certificate make sens',
#  'shall let enter without couid vaccination certificate negative couid report',
#  'long couid result brain damage long_term damage lung heart kidney viral persistence gut maybe brain ongoing decline brain mass want want avoid infection even vaccination',
#  'think worried picture bearded man couid vaccination certificate ukvaccineracism',
#  'couid vaccination bill issue still not resolved tried several time customer care helpless either gave excuse hang call',
#  'youngster youth colombo srilanka not stupid go get jab available vaccine fine please not keep option covidiots vaccination',
#  'end day everyone infected amp couid nineteen selectively select best group human best trait resist exerting biological pressure able resist process mean natural induced vaccination make',
#  'surely stop government coercion child vaccinated unnecessarily show immunity couid past infection vaccination alone not prove immunity',
#  'first year baby life given ten vaccine age twelve might twenty vaccination november couid vaccine another part completely normal child vaccination schedule approved safe',
#  'remain recently around human endemic spite vaccination mutant frequently vaccination alone not treatment deadly virus rather preventive_measures adopted world',
#  'u subject ceo vaccine producer amp bill gate brain mapping amp narco analysis good chance couid wave may prevented vaccination',
#  'undoubtedly couid vaccination india one best implemented programme healthcare history worldwide feeling real time even hindi heart land health care disaster last decade',
#  'stranded faxed country yr full red zone se asian lock faxed infect faxed chance not die chance not go hospital vaccination protects couid still run around get infected not notice auspol',
#  'stranded faxed country yr full red zone se asian lock faxed infect faxed chance not die chance not go hospital vaccination protects couid still run around get infected not notice',
#  'india surpassed vaccination drive far china word ur side much hatred india good administration noone deny fact couid management better many developed nation digest',
# ...
#  'today went maharaja hospital couid vaccination centre uttarpara saying take written permission municipal corp taking vaccine even though enough stock vaccine unfortunate',
#  'true sir honestly response couid apathy taken many u turn plasma therapy treatment home use steroid vaccination etc guess frustrated due activism civil administration health emergency',
#  'wanted join volunteer today saw mac web page even issue key vaccinate whole population right covidvaccination lindungdirilindungsemua vaccineswork vaccinationcovid',
#  'rural_area not enough facility intern couid testing vaccination people want testing not able travel across district urge tnhealthminister look_matter across rural_area',
#  'unites get hot seat not vaccination slot half time vaccination closed due non availability vaccine get like literally get slot seems die third_wave couid',
#  'good every data vaccination presented would agree couid crisis cannot controlled short time far biggest problem testing hesitancy',
#  'everything blurry feeling real photography creativityiscontagiouspassiton lifeiskindablurryrightnow today got first couid vaccination relief',
#  'mam please talk official remove photo vaccination certificate responsible phase couid nineteen came west_bengal',
#  'please sir cannot take anymore close relative died today family_members got couid even vaccination safety talking feel like dictatorship name republic covidsecondwaveinindia nosafeplace',
#  'death recorded occurred people first dose suggests might got infected couid vaccination antibody response low first seven eight day post vaccination',
#  'mind without fear head adequately masked world not divided narrow couid containment zone tireless striving stretch arm towards vaccination heaven freedom father let country awake anon',
#  'sir college student totally exhausted online education system amp online semester sir ruining future couid sir requesting open college wave stable proper sanitation vaccination student',
#  'vaccination certificate also death certificate succumbed couid',
#  'wonder expected latent couid rate say fifty sixty vaccination may better worse lot place wind flatlining',
#  'hahaha pa tu cop kalau vaccine da reg kim find u vaccination la expose couid virus',
#  'basically dish presently working kolkata would like take couid vaccination bhubaneswar since vaccination availability kolkata rare one next slot available eighteen two travelling kolkata procedure',
#  'every organisation something called planning go country supreme leader disbanded planning commission tom timed war couid health minister said end game one planned procurement vaccination',
#  'population creat difficulty implementing country wise vaccination find hospital bed couid affected patient center hand holding state problem age couid affected patient amp casualty comparatively le nation',
#  'mla couid eighteen vaccination vaccination center low reason mla adm request dak government every many death case coimbatore kindly something',
#  'data semua ada pasar advice area need tackle couid ramp ttis speed vaccination kerajaangagal despite data advice concrete action taken long stay silent whole country burn',
#  'couid nineteen virus already community follow sop self lockdown not enough fast vaccination key handle difficult strain',
#  'stalin good move sir gave people lot freedom lockdown however people not cared real cause personally experienced today went couid vaccination bike car',
#  'dear sir attached pic gate three sacred heart school bus nagar luciana single person crowd infected couid infected kindly something maintain outside vaccination center thanks ton',
#  'zero crore allocated budget couid vaccination state government citizen vaccine price budget also false mess cannot fooled crocodile cry modifailedindia vaccineshortage',
#  'allow couid test airport vaccination one entering assay totally ineffective amp inefficient governance selfish',
#  'vaccination started around est may may vaccination rate decrease people unable book slot even people recovered couid april get died may one caring trying sanitation one emphasizes',
#  'today visited one couid vaccination centre barbara moradabad brother vaccination scheduled ten till not single person got vaccinated lot people gathered due late behaviour staff',
#  'part three trying become pregnant not need avoid pregnancy vaccination evidence suggest couid nineteen vaccine affect fertility',
#  'start vaccination not mean people stop following couid protocol wearing_masks maintaining_social distancing must take another vow dalai_bhi kadam_bhi discussion',
#  'keep mandatory couid test arrival assay vaccination also talk chief_secretary amp la delhi also people coming assay vaccination feel',
#  'finally today got vaccine seems like simple injection neither pain kind problem turn covidvaccination vaccinationcovid vaccinessavelives vaccineswork jharkhandfightscorona newsupdate',
#  'people unaware different health issue related vaccine think doctor available every couid vaccination center give clearance vaccination taking dose worst case check list also information',
#  'facing much difficulty booking slot couid vaccination pin_code five second portal showing slot booked responsible',
#  'respected real brainstorming need timely medicine vaccination treatment recent melody campout couid temporarily take control private_hospitals govt control plus havespefic warlike strategy vaccination',
#  'vaccination done fight couid nineteen not afraid vaccine go take vaccine',
#  'people flush assembling getting unite couid nineteen vaccination slot area per given registration not social_distancing ord_wave pandemic jharkhandgovt getting done simply urge cannot providing dos door_door',
#  'number login iv done aroma_set vaccination ten time trying login social_media entire life every time show zero cowinregistration cowinapp arogyasetuapp vaccineregistration bangalore couid',
#  'propertytax every time changing decision not deactivate early tax_payers also unfair refund amout due paid prop prior increase rebate two three percent got couid vaccination',
#  'plus speed vaccination amp meet exceed pick target asap vaccine supply higher registered u vaccinated vaccine market good farther away couid nineteen pandemic',
#  'couid nineteen surge seychelles archipelago matter_concern subject extensive research approximately seventy vaccination done seychelles still surge couid poised grave question world',
#  'bit confused discouraging pal coming hospital due potential exposure couid wanting decongest asking elderly make crowd vaccination hospital',
#  'modi india saved world disaster bringing couid control two month later ravaging india spiralled control health system teetered verge collapse drive tatter',
#  'adventure life right getting vaccinated covidvaccination getvaccinated covidvaccine',
#  'couid vaccine trial animal stopped kept dying revealed texas senate hearing mean vaccination program trial human',
#  'requested mo organise couid vaccination drive place also thanked entire medical fraternity work providing u mo assured next lot vaccine arrive',
#  'thanks clear decline number case delhi one effect lockdown two following couid appropriate_behaviour three rise infected est wave data important four vaccination data may suggest weak ord_wave',
#  'infected couid two week back vaccination february variant infecting people vaccine efficacy low case variant like seasonal flu medicine lung infection vaccination still good bargain',
#  'know south_africa considered pal option majority crew sa denied entry use couid vaccination reason not quarantine lesser hassle sa pak player would acclimatised condition also',
#  'usual mom argue couid vaccination read forwarded message whatsapp said vain ni agenda saudi straight point job mak israel pun cucu vain',
#  'couid vaccination certificate due vaccination feel back pain one know reason',
#  'sad see people getting vaccination place people coming couid test plus look asap location tiara',
#  'not fool around vaccination figure china couid pandemic origin china know figure emanating country not trust worthy people eulogising data country one time considering biological weapon shame',
#  'govt ration scheme disaster mostly give rice data doorstep delivery people afraid go stand queue risky amp catch couid u afraid catching couid vaccination centre cannot afraid getting ad shop three eight',
#  'ith time couple week back face testing station line waiting get inspection done getting couid vaccination easy compared getting car inspected yesterday cued two hour giving car melted',
#  'doctor died due couid doctor vaccinated died may survived vaccination given time forget public come end excuse doctor health worker',
#  'see sol couid herd_immunity way vaccination let_us think spread weak variant couid let people built immunity naturally variant bioengineering way not kill anyone',
#  'lockdown amp vaccination solution curtail couid spread',
#  'serious complaint min amp birth min reporting figure couid case sample testing vaccination highly inconsistent five retweets various source different sanctity data pal warn verify data tweeting ask check',
#  'disparity sir given honor people first reach every corner state govt part distributing anywhich way sundergarh deeply affected much like khuda covidvaccination',
#  'first vaccination two week later got couid sick three five week tested negative app health passport state immune',
#  'selangor couid nineteen task_force said not oppose full lockdown government insists added would pointless without additional measure mass testing faster vaccination faster testing screening process',
#  'wife got first dose vaccination advice everyone get vaccinated priority even uploaded covishieldvaccine vaccinated covidvaccination himachalpradesh vaccinationforall vaccinationdrive',
#  'india couid death alarmingly increasing vaccination time low feeling fatigue amp exhausted heading couid coronavirusindia whereisvaccine coronasecondwave coronavaccination',
#  'delhi govt school grown immensely try get vaccination give reason one well maintained social_distancing two checkout delhi education development three better learn lesson school delhifightscorona education smarta covidvaccination',
#  'provision patent law compulsory licensing india match match demand covidvaccination covidvaccineindia covidvaccines vaccineforall',
#  'circulated tweet wa group authentic coming chairperson apollo hospital people get worried doctors_nurses health worker contract couid even full vaccination come direct contact couid patient unlike u',
#  'yes case number suggest india recovering covidsecondwave still lot contain virus everyday india couid case come le year end maximum vaccination key',
#  'dun taxman mean syamsul questioned could still infected despite completing vaccination course mom advice vaccine work reduce couid infection self gas',
#  'not contribution couid fund pmcaresfund also trust govt free vaccination received government centre declared free people madly_grades vaccinated',
#  'dear please educate people rural_area vaccination many people immediately testing couid nineteen getting vaccinated getting positive result dying fear',
#  'best way protected pandemic early vaccination eighty population vaccinated may expect herd_immunity couid disease',
#  'request kindly help solution reach higher level vaccination vaccineforall bjymcares coronavirusindia covidvaccination cowinapp',
#  'pathetic situation couid vaccination centre shivrajpur kanpur guideline social_distancing management kindly look',
#  'member amar abbas foundation made endeavor educate people importance couid vaccination encouraged get vaccinated amar abbas foundation started campaign aware villager importance vaccination',
#  'delhi govt amp channel pro work spread negativity first reason couid death otherwise everything line number bed number hospital shortage vaccination hot topic think people idiot big',
#  'sir far response survey vaccination hospital data suggests le elderly getting admitted people dying despite vaccination happen getting couid vaccine expected',
#  'manders place worship must remain closed school way catch bull couid horn not try catch tail aggressive vaccination testing remains answer people government must not go slumber',
#  'hope decision maker considering mean thailand reputation foreigner die couid denied vaccination delaying vaccination based nationality not ethical xenophobic decision maker may soon responsible death',
#  'sheila souca english teacher retired presentation convent school living alone lady attendant sudeep cashmere gate carrying couid vaccination face',
#  'sheila souca english teacher retired presentation convent school living alone lady attendant sudeep cashmere gate carrying couid vaccination',
#  'citizen hereby ask politician want modijee resign stage vaccination work amp couid management think seasoned politician allowed sit debate regard',
#  'working youth call center volunteer provide information help citizen couid situation manage couid situation handle emergency case also encourage people vaccination right information cricoid',
#  'igotvaccinated trying several day finally succeeded covidvaccineindia covidvaccination try try till succeed stayhomestaysafe',
#  'police sudeep took senior_citizen couid vaccination unable walk taking care delhipolice',
#  'regular appeal vaccination sent vice_chancellor urging faculty member take jab however professor seem confirmed among fatality hardly anyone received jab couid nineteen vaccine',
#  'given tsunami wave south asia amp adverse public sentiment around shortage couid vaccine would vaccine surplus country risk donating others unlikely possible highest level coordination nice vaccination pandemic un',
#  'vaccination not effective not everyone vaccinated moment vaccinated le severely exposed couid still spreader',
#  'need know couid nineteen vaccine amp dont need know taking couid nineteen vaccine vaccination indiavaccine ranch',
#  'couple informed mistakenly vaccinated eighteen slot see placebo effect eye placebo placeboeffect covidvaccination parody',
#  'whole world peaceful protest palestine malaysia couid case high vaccination roll low crowd gather lose ask cyberbullying je la pro israel idf gang',
#  'nobody say immunity death due couid anywhere world stats around world regarding post vaccination death create panic mass',
#  'appeal inject couid vaccination opposition leader said fake propaganda arrest rahulgandhi datak narendramodi amitshah anuragthakur bop congress renews not',
#  'shortage vaccine fully blamed government people think present wave couid preventable vaccination way forward',
#  'couid penetrates vaccine armour seems chance contacting couid precaution except vaccine le chance getting couid vaccination',
#  'couid penetrates vaccine armour apollo hospital authority conducted survey vaccinated pal amp found three vaccinated twice contacted couid vaccination guarantee agnst couid considering million twentyfour million infection fig zero two',
#  'celebrity status doctor important talk couid diagnostics management vaccination every thing earth couid nineteen many surprise sleeve',
#  'not spread lie term highest world couid case shall vaccination percentage theory',
#  'golden day telangana couid wave lockdown every one become corrupt govt vaccination black_market injection value u get ask item get double price petrol liter great_job',
#  'providing uninterrupted service two nation since onset couid stil neglected must regard vaccine lost hundred financial soldier cannot accommodate anymore life threat demand immediate vaccination banker priority basis',
#  'time eleven zero vaccination not started lot people gathering together violating social_distancing norm lack system management not sure whether taking couid vaccine instead getting infected',
#  'mother earth watching amp death banker eternal world step motherly treatment couid vaccination remembered year repeat implement order issued',
#  ...]

# %%
df['new_text_noun'] = new_text_noun
# Out:
# /var/folders/pk/mh54kmcs083ggkf50q9s_r1c0000gn/T/ipykernel_62963/2006874802.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new_text_noun'] = new_text_noun

# %%
texts = df['new_text_noun']

# %%
texts
# Out:
# 0        soniya mummy hot toh couid magic stick huma ke...
# 1        surprising vaccinated population yr forcefully...
# 2        guidance saint greet ram rahim dear sacha saun...
# 3        bro know case couid detected india fact kerala...
# 4        muslim teacher intellectual boycott couid vacc...
#                                ...
# 20024    right till today mention local train availabil...
# 20025    eat scotch vaccinate little confuse recently s...
# 20026        mean even fifty vaccinated lead herd_immunity
# 20027    good decision even two dose policy jab also we...
# 20028    indian gene yrs comorbiditie seem obese rip ur...
# Name: new_text_noun, Length: 20029, dtype: object

# %%
# Vectorizing documents, obtaining full vocabulary and biterms
# Internally, btm.get_words_freqs uses CountVectorizer from sklearn
# You can pass any of its arguments to btm.get_words_freqs
# For example, you can remove stop words:
stop_words = ['vaccine','people','couid','lot','time','today','vaccination','covidvaccine', 'day','go','one',
             'get', 'not', 'like', 'make', 'take', 'hai', 'ki', 'se', 'ko', 'ka', 'ke', 'hi', 'ho', 'vaccinated',
             'vaccinate', 'vaccinated', 'amp', 'two', 'even', 'thing', 'covishield', 'yesterday', 'pfizer',
             'nineteen', 'crore', 'dose', 'dos', 'booster', 'world', 'health', 'new', 'also', 'app', 'done',
             'second', 'still', 'need', 'three', 'please', 'getting', 'make', 'five', 'six', 'seven', 'eight', 
             'nine', 'ten', 'taken', 'est', 'say', 'given', 'fully', 'made']

# %% [markdown]
# ## 4 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=4, M=20, alpha=50/4, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
#  62%|█████████████████████████▎               | 370/600 [00:26<00:15, 14.40it/s]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy

# %% [markdown]
# ## Calculate documents vs topics probability matrix

# %%
p_zd = model.transform(docs_vec)

# %%
coherence = model.coherence_

# %%
coherence

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)

# %%
# import pickle as pkl
# # Saving
# with open("./sentence-meat-noun-adj-verb-adv/model9.pkl", "wb") as file:
#     pkl.dump(model, file)
    
#change the model name to save depending on the number of topics so if 9 topics then model9.pkl

# %%
# import pickle as pkl
# import tmplot as tmp
# import glob

# # Loading saved models
# models_files = sorted(glob.glob(r'./sentence-dairy-noun-adj-verb-adv/model[3-8].pkl'))
# models = []
# for fn in models_files:
#     file = open(fn, 'rb')
#     models.append(pkl.load(file))
#     file.close()

# # Choosing reference model
# np.random.seed(122334)
# reference_model = np.random.randint(1, 6)

# # Getting close topics
# close_topics, close_kl = tmp.get_closest_topics(
#     models, method="sklb", ref=reference_model)

# # Getting stable topics
# stable_topics, stable_kl = tmp.get_stable_topics(
#     close_topics, close_kl, ref=reference_model, thres=0.7)

# # Stable topics indices list
# print(stable_topics[:, reference_model])

# %%
stable_topics = [0, 1, 2,3]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words

# %% [markdown]
# ## 5 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=5, M=20, alpha=50/5, beta=0.09)
model.fit(biterms, iterations=600)

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy

# %%
p_zd = model.transform(docs_vec)

# %%
coherence = model.coherence_

# %%
coherence

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)

# %%
stable_topics = [0, 1, 2,3,4]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words

# %% [markdown]
# ## 6 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=6, M=20, alpha=50/6, beta=0.09)
model.fit(biterms, iterations=600)

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy

# %%
p_zd = model.transform(docs_vec)

# %%
coherence = model.coherence_

# %%
coherence

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)

# %%
stable_topics = [0, 1, 2,3,4,5]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words

# %% [markdown]
# ## 7 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=7, M=20, alpha=50/7, beta=0.09)
model.fit(biterms, iterations=600)

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy

# %%
p_zd = model.transform(docs_vec)

# %%
coherence = model.coherence_

# %%
coherence

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)

# %%
stable_topics = [0, 1, 2,3,4,5,6]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words

# %% [markdown]
# ## 8 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=8, M=20, alpha=50/8, beta=0.09)
model.fit(biterms, iterations=600)

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy

# %%
p_zd = model.transform(docs_vec)

# %%
coherence = model.coherence_

# %%
coherence

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)

# %%
stable_topics = [0, 1, 2,3,4,5,6,7]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words

# %% [markdown]
# ## 9 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=9, M=20, alpha=50/9, beta=0.09)
model.fit(biterms, iterations=600)

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy

# %%
p_zd = model.transform(docs_vec)

# %%
coherence = model.coherence_

# %%
coherence

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)

# %%
stable_topics = [0, 1, 2,3,4,5,6,7,8]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
