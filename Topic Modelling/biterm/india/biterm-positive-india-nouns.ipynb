# %%
#for windows users:
#pip install bitermplus

#for mac users:
# xcode-select --install
# brew install libomp
# pip3 install bitermplus

# pip install tmplot
# pip install tomotopy

# %%
import bitermplus as btm
import numpy as np
import pandas as pd

import json 
import csv
import nltk
import unicodedata
import re
import sys
from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora, models
from gensim.utils import simple_preprocess
import gensim, spacy
from gensim.models.ldamulticore import LdaMulticore
import re
from gensim.models import Phrases
from gensim.models.phrases import Phraser

# %%
df = pd.read_csv("../pos_neg_india.csv")
df
# Out:
#        Unnamed: 0  index                                               Text  \
# 0               0      0  soniya mummy hoti toh covid me magic stick ghu...
# 1              12     12  is covid ki waja se buht saray logon ne apne p...
# 2              18     18  deaths due covid what is vaccination rate what...
# 3              28     28  vaccination against covid- 19 is necessity tod...
# 4              33     33  very surprising that unvaccinated population &...
# ...           ...    ...                                                ...
# 37618       95179  95179  nature seems have already started working savi...
# 37619       95180  95180  dear , we #india 🇮🇳has helped this #world incl...
# 37620       95184  95184  our sincere request state central govt 🙏🙏. ple...
# 37621       95185  95185  thanks your appreciation valuable feedback abo...
# 37622       95186  95186  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                                 new_text         languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 1      is covid ki waja se buht saray logon ne apne p...           Unknown
# 2      deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 3      vaccination against covid- 19 is necessity tod...           ENGLISH
# 4      very surprising that unvaccinated population &...           ENGLISH
# ...                                                  ...               ...
# 37618  nature seems have already started working savi...           ENGLISH
# 37619  dear , we #india Indiahas helped this #world i...           ENGLISH
# 37620  our sincere request state central govt folded_...           ENGLISH
# 37621  thanks your appreciation valuable feedback abo...           ENGLISH
# 37622  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
#
#                                               translated     new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 1      is covid ki waja se buht saray logon ne apne p...           Unknown
# 2      deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 3      vaccination against covid- 19 is necessity tod...           ENGLISH
# 4      very surprising that unvaccinated population &...           ENGLISH
# ...                                                  ...               ...
# 37618  nature seems have already started working savi...           ENGLISH
# 37619  dear , we #india Indiahas helped this #world i...           ENGLISH
# 37620  our sincere request state central govt folded_...           ENGLISH
# 37621  thanks your appreciation valuable feedback abo...           ENGLISH
# 37622  i can’t wait get my 2nd dose #covidvaccine ove...           ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 1      [('is', 'VBZ'), ('couid', 'JJ'), ('ki', 'NN'),...
# 2      [('deaths', 'NNS'), ('due', 'JJ'), ('couid', '...
# 3      [('vaccination', 'NN'), ('against', 'IN'), ('c...
# 4      [('very', 'RB'), ('surprising', 'JJ'), ('that'...
# ...                                                  ...
# 37618  [('nature', 'NN'), ('seems', 'VBZ'), ('have', ...
# 37619  [('dear', 'IN'), ('we', 'PRP'), ('india', 'VBP...
# 37620  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 37621  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
# 37622  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1      ['couid', 'ki', 'raja', 'se', 'spray', 'logon'...
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['vaccination', 'couid', 'nineteen', 'necessit...
# 4      ['surprising', 'vaccinated', 'population', 'yr...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'india', 'indians', 'help', 'world', ...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 1                         ['hair', 'ply', 'vaccination']
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['necessity', 'today', 'scenario', 'hope', 'pr...
# 4      ['surprising', 'vaccinated', 'population', 'yr...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'help', 'world', 'include', 'kindness...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type  \
# 0                                              ['death']  subjective
# 1                         ['hair', 'ply', 'vaccination']  subjective
# 2      ['death', 'couid', 'vaccination', 'rate', 'har...  subjective
# 3          ['necessity', 'today', 'scenario', 'problem']  subjective
# 4      ['population', 'yrs', 'offline', 'class', 'amp...  subjective
# ...                                                  ...         ...
# 37618  ['nature', 'generation', 'vaccinesaveslive', '...  subjective
# 37619    ['world', 'kindnessmatter', 'vaccinesaveslive']  subjective
# 37620  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 37621  ['thank', 'appreciation', 'feedback', 'vaccine...  subjective
# 37622  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
#
#        sentiment
# 0              0
# 1              2
# 2              2
# 3              2
# 4              0
# ...          ...
# 37618          2
# 37619          2
# 37620          2
# 37621          2
# 37622          2
#
# [37623 rows x 13 columns]

# %%
df.drop(columns = ['Unnamed: 0', 'Text', 'index', 'new_text', 'languages', 'new_languages', 'pos_tagged_words'], inplace = True)
df
# Out:
#                                               translated  \
# 0      soniya mummy hoti toh covid me magic stick ghu...
# 1      is covid ki waja se buht saray logon ne apne p...
# 2      deaths due covid what is vaccination rate what...
# 3      vaccination against covid- 19 is necessity tod...
# 4      very surprising that unvaccinated population &...
# ...                                                  ...
# 37618  nature seems have already started working savi...
# 37619  dear , we #india Indiahas helped this #world i...
# 37620  our sincere request state central govt folded_...
# 37621  thanks your appreciation valuable feedback abo...
# 37622  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1      ['couid', 'ki', 'raja', 'se', 'spray', 'logon'...
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['vaccination', 'couid', 'nineteen', 'necessit...
# 4      ['surprising', 'vaccinated', 'population', 'yr...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'india', 'indians', 'help', 'world', ...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 1                         ['hair', 'ply', 'vaccination']
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['necessity', 'today', 'scenario', 'hope', 'pr...
# 4      ['surprising', 'vaccinated', 'population', 'yr...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'help', 'world', 'include', 'kindness...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type  \
# 0                                              ['death']  subjective
# 1                         ['hair', 'ply', 'vaccination']  subjective
# 2      ['death', 'couid', 'vaccination', 'rate', 'har...  subjective
# 3          ['necessity', 'today', 'scenario', 'problem']  subjective
# 4      ['population', 'yrs', 'offline', 'class', 'amp...  subjective
# ...                                                  ...         ...
# 37618  ['nature', 'generation', 'vaccinesaveslive', '...  subjective
# 37619    ['world', 'kindnessmatter', 'vaccinesaveslive']  subjective
# 37620  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 37621  ['thank', 'appreciation', 'feedback', 'vaccine...  subjective
# 37622  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
#
#        sentiment
# 0              0
# 1              2
# 2              2
# 3              2
# 4              0
# ...          ...
# 37618          2
# 37619          2
# 37620          2
# 37621          2
# 37622          2
#
# [37623 rows x 6 columns]

# %%
df['words_processed_noun'].values[0][0]
# Out:
# '['

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
tokens_words_processed_noun = list(sent_to_words(df['words_processed_noun']))

# %%
from nltk.corpus import stopwords
stop_list = stopwords.words('english')
high_freq_known_words = ['covid','couid', 'pfizer', 'amp', 'people', 'covidvaccine', 'covishield', 'moderna', 'vaccine', 'astrazeneca', 'vaccinate', 'vaccinated', 'vaccination', 'vaccines']

stop_list.extend(high_freq_known_words)

test_words_only1 = ['not', 'vaccine', 'covid', 'and', 'vegan', 'cruelty', 'free', 'i', 'use', 'elf', 'cosmetics', 'every', 'day', 'and', 'i', 'love', 'it']
test_stopremoved = [w for w in test_words_only1 if w not in stop_list or w == 'not']
print(test_stopremoved)
# Out:
# ['not', 'vegan', 'cruelty', 'free', 'use', 'elf', 'cosmetics', 'every', 'day', 'love']

# %%
stop_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'covid',
#  'couid',
#  'pfizer',
#  'amp',
#  'people',
#  'covidvaccine',
#  'covishield',
#  'moderna',
#  'vaccine',
#  'astrazeneca',
#  'vaccinate',
#  'vaccinated',
#  'vaccination',
#  'vaccines']

# %%
df['words_processed_noun'] = tokens_words_processed_noun

# %%
# remove stop words from tokenised_words_only

tokenised_stopremoved = [[w for w in each if w not in stop_list or w == 'not'] for each in tokens_words_processed_noun]
tokenised_stopremoved
# Out:
# [['death'],
#  ['hair', 'ply'],
#  ['death', 'rate', 'harm', 'harm'],
#  ['necessity', 'today', 'scenario', 'problem'],
#  ['population',
#   'yrs',
#   'offline',
#   'class',
#   'examination',
#   'situation',
#   'safety',
#   'class',
#   'examination'],
#  ['way', 'thing', 'millennium', 'peril', 'job', 'process', 'retweet'],
#  ['symptom', 'example', 'country', 'number', 'death', 'population', 'life'],
#  ['follower', 'pledge', 'service', 'humanity'],
#  ['case', 'case', 'testing', 'taboo'],
#  ['intellectual',
#   'education',
#   'leader',
#   'health',
#   'system',
#   'pandemic',
#   'nation',
#   'service'],
#  ['agreement', 'student', 'travel', 'guideline'],
#  ['system',
#   'conversion',
#   'appeasement',
#   'health',
#   'service',
#   'infection',
#   'rate',
#   'death',
#   'rate',
#   'rate',
#   'welfare',
#   'isis'],
#  ['oppression',
#   'yesterday',
#   'appointment',
#   'wife',
#   'today',
#   'worker',
#   'present',
#   'time',
#   'money'],
#  ['effectiveness',
#   'life',
#   'number',
#   'rajasthan',
#   'safetyfirst',
#   'thursdayvibe'],
#  ['campaign'],
#  ['case', 'malaysia', 'booster'],
#  ['age', 'fact', 'child', 'parent'],
#  ['demyelination',
#   'brain',
#   'cord',
#   'precipitating',
#   'factor',
#   'trigger',
#   'infection'],
#  ['spot',
#   'show',
#   'information',
#   'card',
#   'card',
#   'photo',
#   'day',
#   'home',
#   'video',
#   'mobile',
#   'expose'],
#  ['rephrase',
#   'kid',
#   'school',
#   'disease',
#   'time',
#   'kid',
#   'card',
#   'school',
#   'admission'],
#  ['infection',
#   'symptom',
#   'panic',
#   'treat',
#   'fever',
#   'rest',
#   'home',
#   'precaution',
#   'stuff'],
#  ['fact',
#   'surplus',
#   'fund',
#   'crore',
#   'money',
#   'time',
#   'party',
#   'year',
#   'earth'],
#  ['pledge', 'sauna', 'humanity'],
#  ['wife', 'adult', 'ease', 'social_distance', 'mask'],
#  ['year', 'today', 'battle', 'drive', 'virus', 'threat', 'heel'],
#  ['death',
#   'blow',
#   'virus',
#   'purpose',
#   'convert',
#   'mutation',
#   'force',
#   'virus',
#   'human',
#   'harm'],
#  ['exposure', 'point', 'child', 'covidiot'],
#  ['mess',
#   'subsidy',
#   'program',
#   'crore',
#   'citizen',
#   'food',
#   'growth',
#   'rate',
#   'percentage',
#   'digitization',
#   'benefit',
#   'transfer'],
#  ['world', 'country', 'history', 'leave', 'part', 'vote'],
#  ['hospitalization',
#   'booster',
#   'time',
#   'truth',
#   'billion',
#   'pay',
#   'scam',
#   'epic',
#   'proportion'],
#  ['immunization', 'test', 'need', 'avoid'],
#  ['today', 'nurse', 'norm', 'child', 'count', 'detail'],
#  ['graph', 'death', 'today', 'week', 'omicron', 'one', 'cancer', 'death'],
#  ['wolf', 'shielding'],
#  ['litter', 'day', 'dose', 'decrease', 'number', 'case', 'cat'],
#  ['hope', 'injection', 'deal', 'depression', 'teacher', 'biology', 'degree'],
#  ['team', 'roper', 'report', 'arrival', 'certificate'],
#  ['village', 'guitar', 'awareness', 'life', 'car', 'initiative', 'champion'],
#  ['case',
#   'person',
#   'certificate',
#   'document',
#   'digilocker',
#   'photo',
#   'case',
#   'person',
#   'photo',
#   'person'],
#  ['decision',
#   'testing',
#   'admission',
#   'delivery',
#   'surgery',
#   'patient',
#   'percentage',
#   'kudo',
#   'man',
#   'vision',
#   'execution'],
#  ['official', 'figure', 'shame', 'age', 'benefit', 'risk', 'ratio'],
#  [],
#  ['pandemic', 'rate', 'pandemic'],
#  ['immunity'],
#  ['envoy',
#   'textile',
#   'share',
#   'workforce',
#   'factory',
#   'premise',
#   'envoy',
#   'textile',
#   'family_members',
#   'denim'],
#  ['health', 'dot', 'birthday', 'entry', 'entry', 'death', 'health', 'dot'],
#  ['wife', 'child', 'time', 'complication', 'situation', 'protection', 'virus'],
#  ['era', 'disease', 'need', 'patient'],
#  ['window',
#   'air',
#   'window',
#   'ventilation',
#   'air',
#   'mind',
#   'window',
#   'air',
#   'start'],
#  ['dead_bodie',
#   'today',
#   'talk',
#   'genocide',
#   'riot',
#   'appeasement',
#   'policy',
#   'death',
#   'dead_bodie',
#   'hypocrite'],
#  ['way', 'vote'],
#  ['population', 'job', 'management', 'vote', 'person'],
#  ['virus', 'evade', 'commitment'],
#  ['agency', 'restrain', 'scare', 'situation', 'thing'],
#  ['letter',
#   'consent',
#   'parent',
#   'child',
#   'school',
#   'parent',
#   'child',
#   'hoping',
#   'appearance',
#   'school'],
#  ['blend', 'management', 'budget', 'allocation', 'state', 'heart'],
#  ['comment', 'comment'],
#  [],
#  ['border', 'sop', 'program', 'majority', 'nation', 'politician', 'gain'],
#  ['highway',
#   'video',
#   'infra',
#   'project',
#   'defence',
#   'expenditure',
#   'development',
#   'project',
#   'project',
#   'debt',
#   'side',
#   'coin'],
#  ['hope', 'effect', 'risk', 'death', 'reason', 'step', 'regimen'],
#  ['part',
#   'news',
#   'hope',
#   'booster',
#   'age',
#   'group',
#   'year',
#   'fall',
#   'case',
#   'positivity_rate',
#   'manner',
#   'time',
#   'month',
#   'cycle'],
#  ['situation'],
#  ['commitment',
#   'satyamevajayate',
#   'one',
#   'health',
#   'care',
#   'bank',
#   'pension',
#   'name',
#   'none',
#   'resignation'],
#  ['status', 'time', 'shield', 'virus', 'policy', 'debate'],
#  ['omicron',
#   'expert',
#   'coronaviru',
#   'trait',
#   'idiot',
#   'human',
#   'reason',
#   'breakout',
#   'step',
#   'environment',
#   'difficulty'],
#  ['precaution', 'letter', 'inspiration', 'volunteer', 'devotee', 'camp'],
#  ['movement', 'menace', 'office'],
#  ['picture', 'success', 'shit'],
#  ['lockdown', 'country', 'restriction', 'responsibility'],
#  [],
#  ['kind',
#   'variant',
#   'result',
#   'nose',
#   'mask',
#   'virus',
#   'police',
#   'fear',
#   'news',
#   'disease'],
#  ['child', 'marriage', 'caravan'],
#  ['surge',
#   'case',
#   'help',
#   'corona',
#   'virus',
#   'testing',
#   'root',
#   'school',
#   'markup'],
#  ['duty', 'lage', 'staff', 'month', 'race', 'race', 'nursing', 'payment'],
#  ['mask', 'argument', 'person', 'difference', 'treatment', 'protocol'],
#  ['month', 'cycle', 'sanity'],
#  ['behaviour',
#   'slum',
#   'task',
#   'session',
#   'interaction',
#   'community',
#   'disseminate',
#   'information',
#   'message',
#   'usage',
#   'mask',
#   'hand',
#   'washing',
#   'importance'],
#  ['outcome',
#   'gas',
#   'exp',
#   'worry',
#   'exp',
#   'exp',
#   'fate',
#   'experimenter',
#   'exp'],
#  ['follow', 'time'],
#  ['woman', 'country'],
#  ['law', 'justice', 'politician'],
#  ['pledge'],
#  ['virus', 'likelihood', 'virus', 'autoimmunity', 'virus', 'priority'],
#  ['uncle', 'management', 'management'],
#  ['crystal', 'part', 'problem', 'solution', 'mandate'],
#  ['worker', 'coverage', 'hope'],
#  ['response', 'million', 'dose', 'expiry', 'use'],
#  ['idea', 'immunity', 'effect'],
#  ['help', 'democracy', 'drive', 'spread', 'fire', 'democracy', 'force'],
#  ['old', 'enthusiasm', 'child', 'face', 'world', 'hospital'],
#  ['wave', 'make_sure'],
#  [],
#  ['battle', 'discrimination', 'line', 'train', 'ration', 'countryman', 'kudo'],
#  ['race', 'sake', 'doctor', 'injection'],
#  ['kid',
#   'politic',
#   'road',
#   'hospital',
#   'year',
#   'fund',
#   'plant',
#   'criticise',
#   'man',
#   'world',
#   'drive'],
#  ['friend', 'family', 'flu', 'case', 'way'],
#  ['pic', 'issue', 'government'],
#  ['awareness', 'car', 'initiative', 'teenager'],
#  ['message',
#   'infection',
#   'departure',
#   'decision',
#   'decision',
#   'change',
#   'life'],
#  ['leave', 'year', 'company', 'safety', 'job', 'colleague', 'fall'],
#  ['child', 'protection', 'mis', 'condition', 'deserve', 'pickin'],
#  ['vital', 'importance', 'welfare', 'work'],
#  ['way', 'corona', 'keeping', 'act', 'babaramrahim'],
#  ['lot', 'effort', 'responsibility', 'request', 'thank', 'thank'],
#  ['work',
#   'derasachasauda',
#   'volunteer',
#   'camp',
#   'world',
#   'thank',
#   'doctor',
#   'teaching'],
#  ['government',
#   'exemption',
#   'sentiment',
#   'nick',
#   'kyrgio',
#   'fundraising',
#   'crisis'],
#  ['effort',
#   'job',
#   'government',
#   'sad',
#   'wave',
#   'government',
#   'datum',
#   'casualty'],
#  ['chief_minister',
#   'highlight',
#   'achievement',
#   'government',
#   'president',
#   'photo'],
#  ['space', 'debate', 'provaxxer', 'point', 'view', 'boostershot'],
#  ['cost',
#   'food',
#   'program',
#   'world',
#   'pandemic',
#   'cost',
#   'program',
#   'record',
#   'time',
#   'opposition',
#   'spreading',
#   'rumour',
#   'worker'],
#  ['observation',
#   'fatigue',
#   'rate',
#   'sense',
#   'security',
#   'acquaintance',
#   'hustle',
#   'culture'],
#  [],
#  ['beer', 'night', 'country', 'country'],
#  ['leader',
#   'finger',
#   'wave',
#   'centre',
#   'victory',
#   'realise',
#   'leadership',
#   'silence',
#   'time'],
#  ['initiative', 'pledge', 'missionhumanity', 'freeservice'],
#  ['program',
#   'country',
#   'world',
#   'alcohol',
#   'drug',
#   'responsibility',
#   'alcohol'],
#  [],
#  ['citizen', 'country'],
#  ['show', 'catch', 'one', 'rate', 'rate'],
#  [],
#  ['week', 'advertisement', 'sensitization', 'hoping', 'immunity'],
#  ['inspiration', 'organization', 'camp', 'epidemic'],
#  ['hopelessness',
#   'round',
#   'change',
#   'narrative',
#   'reporting',
#   'style',
#   'fruit'],
#  ['duty', 'child'],
#  ['end', 'microbe', 'case', 'day', 'thank', 'drive', 'authority'],
#  ['time', 'today', 'importance', 'welfare', 'work'],
#  ['criterion', 'fight', 'sop', 'adherence', 'masking', 'distancing', 'crowd'],
#  ['doctor'],
#  ['wave', 'friend', 'relative'],
#  ['post',
#   'allergy',
#   'low',
#   'report',
#   'doctor',
#   'individual',
#   'condition',
#   'allergy',
#   'medication',
#   'doctor'],
#  ['disease', 'loss', 'polio', 'student', 'biology'],
#  ['milder', 'family', 'doctor', 'story', 'surge', 'patient'],
#  ['coverage', 'manipulator', 'money', 'stock'],
#  ['restriction', 'idea', 'country', 'country', 'economy', 'development'],
#  ['program', 'fight', 'pandemic', 'congratulation'],
#  ['cell',
#   'immunity',
#   'infection',
#   'protection',
#   'conclusion',
#   'memory',
#   'role',
#   'timeline',
#   'infection',
#   'antibody'],
#  ['living', 'wage', 'life', 'dignity', 'minimum', 'wage'],
#  ['sop', 'virus', 'likelihood', 'virus', 'autoimmunity', 'help'],
#  ['death', 'effect'],
#  ['harm', 'child', 'shot'],
#  ['care', 'care'],
#  ['protection', 'reason'],
#  ['weapon', 'fight', 'program', 'part', 'emergency', 'service'],
#  ['message', 'family', 'mistake'],
#  ['teacher', 'duty', 'teacher', 'teacher', 'duty', 'teacher', 'body', 'work'],
#  ['time',
#   'end',
#   'restriction',
#   'mandate',
#   'business',
#   'maharashtrian',
#   'state',
#   'blanket',
#   'relief',
#   'city',
#   'rule'],
#  ['case',
#   'increase',
#   'trust',
#   'hospital',
#   'admission',
#   'rate',
#   'ventilatory',
#   'support',
#   'rate',
#   'death',
#   'toll',
#   'surge',
#   'case',
#   'coverage',
#   'care',
#   'soup',
#   'case',
#   'blame'],
#  ['population', 'worry', 'success', 'programme'],
#  ['risk', 'benefit', 'analysis', 'child', 'hazard', 'million', 'child'],
#  ['infection', 'disease', 'week'],
#  ['impact', 'survivor'],
#  ['inflation',
#   'era',
#   'polio',
#   'spite',
#   'party',
#   'today',
#   'sector',
#   'pal',
#   'job'],
#  ['terror', 'child', 'child', 'ink', 'think', 'kid', 'chest', 'cold', 'kid'],
#  ['perception',
#   'survey',
#   'solution',
#   'pandemic',
#   'insight',
#   'research',
#   'attitude',
#   'knowl'],
#  ['perception', 'pal', 'survey'],
#  ['precaution', 'symptom', 'body', 'avoid', 'side_effect'],
#  ['work', 'aspect', 'person', 'passenger', 'bus', 'virus', 'home', 'child'],
#  ['intolerance',
#   'question',
#   'photograph',
#   'certificate',
#   'logic',
#   'photo',
#   'death',
#   'certificate',
#   'logic'],
#  ['warning',
#   'country',
#   'rate',
#   'scrap',
#   'restriction',
#   'touch',
#   'relevance',
#   'restriction',
#   'rate'],
#  [],
#  ['symptom', 'visit', 'day', 'life'],
#  ['family', 'alhamdulillah', 'symptom', 'brother', 'month'],
#  ['faith', 'pop'],
#  ['lakhs', 'student', 'year', 'one', 'mode', 'patience'],
#  ['number', 'booster', 'thing', 'crowd', 'mask', 'distance'],
#  ['patient',
#   'effect',
#   'flu',
#   'sinus',
#   'issue',
#   'virus',
#   'effect',
#   'naudzubillah'],
#  ['occasion'],
#  ['pickin', 'charge', 'smuggle'],
#  ['self', 'saint', 'welfare', 'work', 'spread', 'awareness'],
#  ['help', 'protection', 'spread', 'corona', 'inspiration', 'volunteer'],
#  ['disease', 'syndrome', 'family', 'camp', 'state', 'guidance'],
#  ['build', 'immunity', 'initiative', 'camp', 'awareness', 'inspiration'],
#  ['body',
#   'organization',
#   'initiative',
#   'volunteer',
#   'mask',
#   'volunteer',
#   'dose'],
#  ['time', 'today', 'importance', 'welfare', 'work'],
#  ['idea',
#   'mask',
#   'product',
#   'programme',
#   'food',
#   'production',
#   'int',
#   'nonsense'],
#  ['smallpox', 'child', 'child', 'vote'],
#  ['person', 'dose', 'risk', 'fine', 'facility', 'movement', 'risk'],
#  ['budget', 'nation', 'government'],
#  ['rate', 'lockdown', 'impact', 'rate', 'world'],
#  ['number', 'case', 'safety', 'police', 'doctor', 'booster'],
#  ['line', 'mask'],
#  ['drive', 'district', 'hope', 'weekend', 'pandemic'],
#  ['family', 'location', 'protester', 'thousand', 'protest'],
#  ['certificate',
#   'traveller',
#   'roper',
#   'passenger',
#   'hour',
#   'station',
#   'action',
#   'spread',
#   'spot',
#   'gathering',
#   'longtime'],
#  ['woman', 'election'],
#  [],
#  ['blast', 'sum'],
#  ['pundit', 'evidence', 'effectiveness', 'boostershot', 'deny'],
#  ['student',
#   'friend',
#   'ord',
#   'time',
#   'death',
#   'bed',
#   'mercy',
#   'month',
#   'institution',
#   'control',
#   'student'],
#  ['treatment', 'work', 'think'],
#  ['drive',
#   'rate',
#   'man',
#   'woman',
#   'access',
#   'health',
#   'information',
#   'view_article'],
#  ['family',
#   'infection',
#   'home',
#   'day',
#   'hospital',
#   'expense',
#   'stress',
#   'medicine',
#   'heart'],
#  ['hurdle',
#   'progress',
#   'lead',
#   'disability',
#   'death',
#   'risk',
#   'risk',
#   'infection',
#   'fact'],
#  ['import', 'status', 'use', 'mom', 'apple', 'wallet'],
#  ['pune',
#   'staff',
#   'center',
#   'fakecovidcenter',
#   'staff',
#   'pune',
#   'trend',
#   'app'],
#  ['booster', 'boosterdose'],
#  ['condition', 'center', 'baramulla', 'patient', 'condition', 'centre'],
#  ['infection', 'immunity', 'researcher'],
#  ['time', 'booster', 'company', 'concentration', 'money', 'health'],
#  ['virus', 'country', 'schedule', 'country'],
#  ['sister',
#   'son',
#   'booster',
#   'week',
#   'corona',
#   'day',
#   'mind',
#   'omicron',
#   'wear_mask'],
#  ['seeing'],
#  ['use',
#   'market',
#   'office',
#   'situation',
#   'school',
#   'asap',
#   'symptom',
#   'one',
#   'day',
#   'suggestion'],
#  ['way', 'use', 'word', 'help', 'testing', 'pandemic'],
#  ['nature', 'prevent', 'duration', 'severity'],
#  ['test', 'hour', 'positivity', 'ratio'],
#  ['way', 'death', 'rate', 'booster', 'dose', 'reduce'],
#  ['schools_college',
#   'case',
#   'district',
#   'solution',
#   'school',
#   'student',
#   'life',
#   'study',
#   'exam',
#   'haryanaschool'],
#  ['death', 'relative', 'asthma', 'time', 'danger', 'condition'],
#  ['case', 'race', 'death', 'rate'],
#  ['pain', 'numbness', 'leg', 'arm', 'blood', 'clot'],
#  ['wife', 'message', 'today', 'yesterday', 'name'],
#  ['way', 'confusion'],
#  ['marti', 'queue', 'turn', 'surprise', 'screen', 'centre'],
#  ['today'],
#  [],
#  ['city',
#   'ascertain',
#   'disease',
#   'student',
#   'disease',
#   'datum',
#   'correlation',
#   'level',
#   'infection',
#   'rate',
#   'city'],
#  ['zoom', 'want', 'classroom', 'step', 'step', 'campus', 'divide'],
#  ['news', 'damage', 'expert', 'response', 'falsehood', 'message', 'source'],
#  ['infection', 'blood', 'catch', 'virus', 'nose', 'nasopharynx'],
#  ['radar',
#   'number',
#   'lot',
#   'thing',
#   'testing',
#   'message',
#   'radar',
#   'number',
#   'prevent',
#   'number'],
#  ['price', 'pay', 'sop', 'idiot', 'minister'],
#  ['dna'],
#  ['stop', 'venue', 'world'],
#  ['precaution', 'convince', 'rule', 'team', 'video', 'helmet'],
#  ['school',
#   'college',
#   'stadium',
#   'academy',
#   'restriction',
#   'norm',
#   'sport',
#   'depth',
#   'damage',
#   'talent',
#   'ply'],
#  ['home',
#   'infection',
#   'dose',
#   'family',
#   'self',
#   'test',
#   'day',
#   'cough',
#   'tiredness'],
#  ['rate'],
#  ['question',
#   'use',
#   'booster',
#   'place',
#   'pain',
#   'chest',
#   'heart',
#   'place',
#   'belive',
#   'immunity'],
#  ['test',
#   'day',
#   'day',
#   'guarantee',
#   'medicine',
#   'virus',
#   'omicron',
#   'side_effect',
#   'person',
#   'business',
#   'pharmaceutical'],
#  ['approach', 'population', 'restriction', 'infection', 'protection'],
#  ['state',
#   'statement',
#   'centre',
#   'plea',
#   'guideline',
#   'envisage',
#   'consent',
#   'individual'],
#  ['case', 'concern', 'group', 'year'],
#  ['place', 'rule', 'website', 'connection'],
#  ['risk', 'child', 'show', 'presentation', 'case', 'rate', 'child', 'age'],
#  ['age',
#   'child',
#   'host',
#   'advice',
#   'believe',
#   'child',
#   'part',
#   'infant',
#   'schedule',
#   'year'],
#  ['citizen', 'fear', 'initiative', 'help', 'worker'],
#  ['circumstance',
#   'country',
#   'datum',
#   'draft',
#   'guideline',
#   'management',
#   'guidance',
#   'document',
#   'data',
#   'time',
#   'datum'],
#  ['city', 'solution', 'pill', 'world', 'country', 'nincompoop'],
#  ['sign', 'guard', 'thank', 'government', 'drive'],
#  ['way', 'reluctance', 'incompetence', 'life', 'risk'],
#  ['propaganda', 'work'],
#  ['body', 'body', 'time', 'force', 'life', 'danger'],
#  ['year', 'country', 'drive'],
#  ['way', 'success', 'payment', 'citizenry', 'pay', 'taxis'],
#  ['fact', 'protocol', 'ride', 'time', 'island'],
#  ['child', 'protection', 'end', 'omicron'],
#  ['needle'],
#  ['achievement',
#   'year',
#   'completion',
#   'effort',
#   'task',
#   'administration',
#   'crore',
#   'capacity',
#   'advancement'],
#  ['power', 'certificate', 'test', 'report', 'covidbooster'],
#  ['congratulation'],
#  ['thing',
#   'debacle',
#   'tournament',
#   'policy',
#   'player',
#   'exemption',
#   'health',
#   'risk',
#   'player',
#   'health',
#   'risk'],
#  ['success', 'village'],
#  ['threat', 'lake', 'patient', 'earmark', 'condition'],
#  ['congratulation',
#   'effort',
#   'country',
#   'let_us',
#   'intervention',
#   'contain',
#   'case',
#   'omicron'],
#  ['attention', 'situation', 'drive', 'drive', 'nhmassam', 'lool'],
#  ['video',
#   'detail',
#   'motivation',
#   'program',
#   'training',
#   'emergency',
#   'initiative',
#   'bag',
#   'part'],
#  ['kind', 'video', 'news', 'thank', 'day'],
#  ['day'],
#  ['idiot', 'polio'],
#  ['positivity',
#   'ratio',
#   'percent',
#   'week',
#   'thing',
#   'fatality',
#   'ratio',
#   'patient',
#   'care',
#   'mean'],
#  ['day'],
#  ['status', 'risk', 'assessment', 'status', 'date'],
#  ['control'],
#  ['campus', 'today', 'trainee', 'authority', 'dedication'],
#  ['medicine', 'relief'],
#  ['colony', 'elder', 'locality', 'centre'],
#  ['face', 'mask'],
#  ['request', 'clarity', 'guideline', 'child'],
#  ['corona', 'government', 'corona'],
#  ['life', 'path', 'success', 'success', 'point', 'time', 'life'],
#  ['precaution', 'service'],
#  ['mover', 'relocation', 'worry', 'packer', 'mover', 'dose', 'safemoving'],
#  ['event', 'player', 'player', 'antivaccination', 'rant'],
#  ['precaution', 'dose', 'kudo', 'today', 'mean'],
#  ['time', 'support', 'welfare', 'work', 'welfare', 'work'],
#  ['food',
#   'restriction',
#   'resist',
#   'etc',
#   'time',
#   'forefather',
#   'life',
#   'message'],
#  ['food', 'allergy', 'caution'],
#  ['person', 'suggestion', 'bhagat', 'mistake', 'demand', 'apology'],
#  ['flu', 'booster', 'expert'],
#  [],
#  ['evidence',
#   'infection',
#   'measure',
#   'transmission',
#   'majority',
#   'population',
#   'building',
#   'antibody',
#   'virus',
#   'role',
#   'reduction'],
#  ['road', 'water', 'talk', 'push', 'today', 'settlement', 'life', 'saver'],
#  ['tooo',
#   'check',
#   'testing',
#   'facility',
#   'symptom',
#   'member',
#   'spread',
#   'testing'],
#  ['case', 'status', 'line', 'caseload', 'folk'],
#  ['coin', 'registration', 'certificate', 'registration'],
#  ['country',
#   'rate',
#   'month_ago',
#   'beginning',
#   'campaign',
#   'year',
#   'virus',
#   'job',
#   'hospitalization'],
#  ['number',
#   'certificate',
#   'contact',
#   'list',
#   'type',
#   'certificate',
#   'government',
#   'way'],
#  ['expert',
#   'result',
#   'election',
#   'cost',
#   'life',
#   'staff',
#   'electorate',
#   'violation',
#   'guideline',
#   'situation'],
#  ['infrastructure',
#   'development',
#   'education',
#   'policy',
#   'terror',
#   'attack',
#   'city',
#   'eye',
#   'treatment'],
#  ['review', 'booster', 'staff', 'workplace'],
#  ['body'],
#  ['sample', 'bushland', 'municipality', 'omicron'],
#  ['approach', 'person', 'help', 'note'],
#  ['effect', 'menstruation', 'thread', 'day', 'day'],
#  ['wave', 'decision', 'centre', 'park'],
#  ['truth', 'prospect', 'party', 'city', 'word', 'art'],
#  ['example', 'hat', 'confidence', 'parent', 'science', 'child', 'science'],
#  ['article',
#   'discrimination',
#   'person',
#   'healthcare',
#   'system',
#   'end',
#   'need',
#   'person',
#   'access'],
#  ['reduce',
#   'risk',
#   'hospitalization',
#   'death',
#   'quality',
#   'ventilation',
#   'room',
#   'infection',
#   'line',
#   'defence'],
#  ['disease', 'spread', 'indoor', 'line', 'defence'],
#  ['faith', 'win'],
#  ['syringe'],
#  ['follow', 'masking', 'washing_hand', 'crowd', 'disease'],
#  ['roll',
#   'time',
#   'team',
#   'era',
#   'relief',
#   'camp',
#   'team',
#   'action',
#   'drive',
#   'place'],
#  ['treatment',
#   'patient',
#   'pandemic',
#   'patient',
#   'root',
#   'outbreak',
#   'way',
#   'rack',
#   'brain',
#   'rush'],
#  ['respect', 'rule', 'country', 'fighting', 'part'],
#  ['line', 'line', 'time', 'part'],
#  ['son',
#   'school',
#   'one',
#   'community',
#   'control',
#   'screen',
#   'time',
#   'son',
#   'exposure',
#   'sugar',
#   'stereotype'],
#  ['care',
#   'guess',
#   'system',
#   'doctor',
#   'clue',
#   'work',
#   'jar',
#   'water',
#   'wave',
#   'work',
#   'mask',
#   'test',
#   'report'],
#  ['student'],
#  ['fight', 'line', 'defence', 'fight'],
#  ['government',
#   'slam',
#   'price',
#   'medicine',
#   'pandemic',
#   'slab',
#   'medicine',
#   'time',
#   'bend',
#   'time',
#   'humanity'],
#  ['panic',
#   'precaution',
#   'thank',
#   'herd_immunity',
#   'criticality',
#   'mask',
#   'wave'],
#  ['pit',
#   'center',
#   'world',
#   'rest',
#   'world',
#   'surveillance',
#   'priority',
#   'list',
#   'pit',
#   'gov',
#   'voice'],
#  ['congratulation'],
#  ['dose'],
#  ['declare', 'period', 'child', 'arrange', 'child', 'school'],
#  ['exemption'],
#  ['omicron', 'mask', 'ventilation', 'space'],
#  ['school', 'child', 'state', 'thing', 'school', 'month', 'arrange', 'child'],
#  ['case', 'increase', 'wear', 'mask', 'choice', 'move'],
#  ['line', 'lage', 'infection', 'hospital', 'sector'],
#  ['child', 'child'],
#  ['magnet', 'wash', 'time'],
#  ['congratulation', 'kid', 'year', 'program', 'safety', 'number'],
#  ['survival', 'gathering', 'mask', 'self'],
#  ['person', 'fight'],
#  ['infection',
#   'solution',
#   'juncture',
#   'mutation',
#   'mutation',
#   'stopspreading',
#   'research'],
#  ['today',
#   'protocol',
#   'wearing_masks',
#   'sanitizer',
#   'certificate',
#   'guideline'],
#  ['part',
#   'car',
#   'saving',
#   'life',
#   'human',
#   'information',
#   'medicine',
#   'formula'],
#  ['omicron', 'spread', 'lockdown', 'world', 'restriction', 'lockdown'],
#  ['respect', 'entry', 'cell', 'entry', 'point', 'mask', 'measure', 'stay'],
#  ['pit',
#   'editorial',
#   'op',
#   'talk',
#   'century',
#   'resource',
#   'state',
#   'capacity'],
#  ['video', 'super', 'sum'],
#  ['video', 'super', 'sum'],
#  ['folk', 'ease', 'time', 'waste', 'time', 'money'],
#  [],
#  ['death', 'request', 'government', 'cancelvoterid'],
#  ['hope', 'help', 'body', 'sense', 'odd', 'war'],
#  ['message', 'government', 'way', 'state', 'government', 'crore'],
#  ['weapon', 'believe'],
#  ['newspaper', 'work', 'panic', 'business', 'action', 'news'],
#  ['hospitalization', 'death', 'difference', 'life', 'detour', 'virus'],
#  ['teen',
#   'day',
#   'abit',
#   'period',
#   'factor',
#   'day',
#   'death',
#   'result',
#   'policy',
#   'change'],
#  ['check',
#   'train',
#   'check',
#   'certificate',
#   'detail',
#   'track',
#   'habet',
#   'entry',
#   'exit',
#   'sense'],
#  ['jharkhand', 'door', 'jharkhand', 'governance'],
#  ['world', 'fact', 'nation', 'protection', 'person'],
#  ['situation', 'protocol', 'experience', 'precaution', 'control', 'issue'],
#  ['name', 'death', 'research', 'fear', 'care'],
#  ['reason', 'behavior', 'reduce', 'transmission'],
#  ['lot', 'player', 'donkey', 'ruble', 'coincidence'],
#  ['hotel', 'tonight', 'seeing', 'certificate', 'seeing', 'passport', 'guest'],
#  ['program', 'action', 'expire', 'use', 'hope', 'authority', 'action'],
#  ['population', 'country'],
#  ['state', 'roper', 'increase', 'awareness', 'loot'],
#  ['recommendation',
#   'mask',
#   'effectiveness',
#   'year',
#   'surprise',
#   'expert',
#   'treatment'],
#  ['challenge', 'caution', 'wind', 'covidtesting', 'besame'],
#  ['wrath', 'threat', 'church', 'belief', 'humankind', 'nonsense'],
#  ['gird', 'walk', 'hair', 'sake'],
#  ['time', 'shoulder', 'affair'],
#  ['month',
#   'elimination',
#   'way',
#   'elimination',
#   'virus',
#   'disease',
#   'disability'],
#  ['difference', 'time', 'population', 'position', 'body'],
#  ['body',
#   'notice',
#   'change',
#   'system',
#   'interest',
#   'result',
#   'leadership',
#   'team',
#   'way'],
#  ['evening',
#   'today',
#   'dose',
#   'body',
#   'temperature',
#   'thermometer',
#   'shower',
#   'coin'],
#  ['person', 'week', 'week', 'death', 'vaccinedeath'],
#  ['day', 'fact', 'player'],
#  ['lock',
#   'virus',
#   'decease',
#   'check',
#   'kit',
#   'queue',
#   'good',
#   'mind',
#   'strength',
#   'arise'],
#  ['visit', 'indore', 'family', 'circle', 'risk', 'regulation'],
#  ['country', 'craftsman', 'staff', 'difficulty', 'spirit', 'patience'],
#  ['country', 'containment', 'struggle', 'policy', 'rate'],
#  ['understanding', 'sort', 'narrative', 'convenience', 'shame', 'fellow'],
#  ['brand', 'licensing', 'domain', 'form', 'variant', 'hospital'],
#  ['hotel',
#   'record',
#   'son',
#   'credit',
#   'card',
#   'business',
#   'care',
#   'charge',
#   'money'],
#  ['transit',
#   'traveler',
#   'travel',
#   'symptom',
#   'guideline',
#   'norm',
#   'certificate',
#   'produce',
#   'border',
#   'district'],
#  ['person', 'contracting', 'president', 'man', 'reason', 'compulsory'],
#  ['world', 'football', 'match', 'player', 'time'],
#  ['year', 'certificate', 'congratulation'],
#  ['trash', 'disposal', 'syrinx', 'fall'],
#  ['government', 'rule', 'work'],
#  ['number', 'day', 'way', 'cowinportal'],
#  ['hear', 'omicron', 'mask'],
#  ['challenge', 'drive'],
#  ['argument', 'sum', 'word', 'way'],
#  ['time', 'target', 'area', 'official', 'professional', 'home', 'number'],
#  ['government', 'campaign', 'birthday', 'certificate', 'passed_away'],
#  ['extent', 'certificate', 'billboard', 'face', 'trust', 'role', 'play'],
#  ['country', 'service', 'answer', 'bea'],
#  [],
#  ['verification', 'counter', 'today', 'administration', 'operator'],
#  ['buti', 'result', 'certificate', 'reason', 'cut'],
#  ['child',
#   'adult',
#   'hesitation',
#   'child',
#   'adult',
#   'time',
#   'hesitation',
#   'join',
#   'fight'],
#  ['shocking', 'nonsense', 'action', 'factory', 'syrinx', 'wake'],
#  ['wedding', 'pic', 'availability', 'ticket'],
#  [],
#  ['patient', 'day', 'issue', 'way', 'population', 'manner'],
#  ['time', 'time', 'week', 'medtwitter'],
#  ['man', 'attender', 'par', 'one', 'armor'],
#  ['report', 'citizen'],
#  ['report'],
#  ['let_us', 'report', 'law', 'safety', 'aircraft'],
#  ['case', 'citizen', 'responsibility', 'government', 'delay'],
#  ['recommendation', 'country', 'recurrence', 'disease', 'inform', 'resort'],
#  ['news'],
#  ['today',
#   'reliance',
#   'customer',
#   'experience',
#   'temperature',
#   'face',
#   'mask',
#   'picture',
#   'space',
#   'protocol'],
#  ['need', 'brain', 'physiotherapy'],
#  ['drive', 'milestone', 'momentum', 'strengthen', 'fight', 'protocol'],
#  ['man', 'blame', 'government', 'thing', 'day', 'rush'],
#  ['antibody',
#   'batch',
#   'population',
#   'side',
#   'affect',
#   'post',
#   'nasal',
#   'medicine',
#   'health',
#   'care',
#   'infra',
#   'regulating',
#   'treatment',
#   'cost',
#   'hospital'],
#  ['attention',
#   'protocol',
#   'concern',
#   'country',
#   'request',
#   'support',
#   'plan',
#   'spread',
#   'awareness',
#   'importance'],
#  ['government',
#   'foot',
#   'decision',
#   'booster',
#   'child',
#   'omicron',
#   'vengeance'],
#  ['job', 'officer', 'thing', 'convince', 'medtwitter'],
#  ['lead', 'programme', 'country', 'principle', 'family'],
#  [],
#  ['situation', 'term'],
#  ['hope',
#   'test',
#   'illness',
#   'progress',
#   'teaching',
#   'yr',
#   'duty',
#   'gratitude'],
#  ['spot',
#   'marathon',
#   'event',
#   'event',
#   'noise',
#   'space',
#   'meter',
#   'distance',
#   'case'],
#  ['team', 'village', 'foot', 'distance'],
#  ['core', 'height', 'country', 'man'],
#  ['year', 'dose', 'time', 'help', 'illness'],
#  ['news', 'life', 'mean', 'generation', 'omnicronvariant'],
#  ['today'],
#  ['hospital',
#   'opportunity',
#   'head',
#   'centre',
#   'month',
#   'healthcare',
#   'city',
#   'healthcare',
#   'infrastructure'],
#  ['courtesy', 'export', 'manufacturer', 'cycle', 'strain', 'orion'],
#  ['conspiracy', 'face', 'certificate', 'child', 'plot', 'muslim'],
#  ['case', 'adult', 'term', 'correlation', 'causation'],
#  ['percentage', 'paper', 'skull', 'certificate', 'dose', 'sample'],
#  ['sale'],
#  ['one', 'attitude', 'chalk', 'awareness', 'fine'],
#  ['country', 'border', 'stay', 'herd_immunity', 'solution'],
#  ['shot', 'year', 'travel', 'pass', 'option'],
#  ['wearing_mask'],
#  ['tool', 'end', 'hesitancy', 'world', 'variant', 'nation', 'helping'],
#  ['desire', 'mind', 'theater', 'eat', 'shit', 'covidvariant', 'covidiot'],
#  ['danger', 'hesitancy', 'concern', 'health', 'management', 'threatening'],
#  ['progress', 'country', 'way'],
#  ['government',
#   'telangana',
#   'development',
#   'front',
#   'outbreak',
#   'world',
#   'instruction',
#   'authority',
#   'mask',
#   'hygiene'],
#  ['program', 'world'],
#  ['virus', 'thing', 'war'],
#  ['line',
#   'alarm',
#   'science',
#   'literature',
#   'alarm',
#   'strain',
#   'name',
#   'detail'],
#  ['drive', 'responsibility'],
#  ['stupidity', 'multiverse'],
#  ['logic', 'severity', 'matter'],
#  ['virologist', 'norm', 'mask'],
#  ['situation', 'light', 'focus', 'containment', 'dose', 'coverage'],
#  ['threat', 'time', 'security', 'countryman', 'figure', 'man'],
#  ['fun', 'gas', 'weekend'],
#  ['way', 'fight', 'menace'],
#  ['campaign',
#   'acquisition',
#   'campaign',
#   'farm',
#   'bill',
#   'campaign',
#   'success',
#   'victim',
#   'modi',
#   'word'],
#  ['show', 'proof', 'status', 'way', 'hope', 'way'],
#  ['infection',
#   'protection',
#   'variant',
#   'body',
#   'recognise',
#   'protein',
#   'surface',
#   'virus',
#   'virus',
#   'mutate'],
#  ['phone', 'request', 'type', 'issue', 'share'],
#  ['child',
#   'point',
#   'proportion',
#   'complication',
#   'obesity',
#   'use',
#   'lack',
#   'interaction',
#   'adult',
#   'schoolsreopen'],
#  ['lot', 'factor', 'type'],
#  ['leader'],
#  ['number', 'idiot'],
#  ['trial',
#   'key',
#   'kid',
#   'high_risk',
#   'response',
#   'kid',
#   'activity',
#   'interaction',
#   'school',
#   'programme'],
#  ['thing', 'mirror', 'bill', 'intrusion', 'shortage', 'law', 'farmland'],
#  ['responsibility', 'responsibility', 'humanright'],
#  ['year', 'world', 'world', 'family'],
#  ['gas',
#   'price',
#   'pipeline',
#   'distribution',
#   'good',
#   'supply',
#   'demand',
#   'price',
#   'issue'],
#  ['teacher',
#   'issue',
#   'teacher',
#   'government',
#   'school',
#   'choice',
#   'matter',
#   'school'],
#  ['teacher',
#   'issue',
#   'teacher',
#   'government',
#   'school',
#   'choice',
#   'matter',
#   'school'],
#  ['weapon', 'fight'],
#  ['population', 'percentage', 'faith', 'belief', 'way', 'goat'],
#  [],
#  ['childhood', 'schedule', 'booster', 'mask'],
#  ['world', 'bat'],
#  ['treatment', 'sufferer', 'relief', 'ability', 'reservoir', 'body'],
#  ['thread', 'communicator', 'thread', 'pandemic'],
#  ['schedule', 'risk', 'knicker', 'twist', 'reason'],
#  ['surprise',
#   'visit',
#   'center',
#   'good',
#   'situation',
#   'doctor',
#   'staff',
#   'work'],
#  ['word', 'appreciation', 'process', 'today', 'experience', 'hospital'],
#  ['sector', 'twentynine', 'appointment', 'tomorrow', 'thank', 'advance'],
#  ['fact',
#   'period',
#   'room',
#   'hospital',
#   'doctor',
#   'ration',
#   'drive',
#   'slum',
#   'experience',
#   'cost'],
#  ['ramp', 'booster', 'elder', 'mindset', 'cloud'],
#  ['world', 'year'],
#  ['article', 'topic'],
#  ['coverage', 'lot', 'criticism', 'occasion', 'confidence', 'regard'],
#  ['opinion', 'help', 'opinion', 'infection'],
#  ['propaganda',
#   'liberal',
#   'fear',
#   'leader',
#   'inspire',
#   'area',
#   'defence',
#   'living',
#   'example',
#   'observer'],
#  ['booster', 'adviser', 'prevent', 'pandemic'],
#  ['fight'],
#  ['word', 'answer'],
#  ['status', 'tawakalna', 'app', 'case'],
#  ['problem',
#   'thank',
#   'health',
#   'infra',
#   'facility',
#   'house',
#   'production',
#   'arrangement',
#   'cost'],
#  ['status', 'booster', 'vaccineequity'],
#  ['friend',
#   'relapse',
#   'time',
#   'joke',
#   'precaution',
#   'hand',
#   'distancing',
#   'ply'],
#  ['level', 'immunity', 'spread', 'virus', 'week', 'cave'],
#  ['animal',
#   'citizen',
#   'air',
#   'quality',
#   'case',
#   'complication',
#   'appeal',
#   'government',
#   'cracker',
#   'behaviour'],
#  ['time', 'student', 'career', 'university', 'sinopharm'],
#  ['research', 'work', 'rumour', 'country'],
#  ['money',
#   'fund',
#   'shortfall',
#   'revenue',
#   'evasion',
#   'man',
#   'business',
#   'man',
#   'bank'],
#  ['soldier', 'statesman', 'soldier', 'sandal', 'record', 'time'],
#  ['nightlife', 'bar', 'percent', 'rate'],
#  ['arm'],
#  ['step',
#   'bank',
#   'account',
#   'subsidy',
#   'demonetisation',
#   'part',
#   'payment',
#   'sign',
#   'tea',
#   'stall',
#   'platform'],
#  ['sense', 'eradication', 'smallpox', 'polio', 'policy', 'making'],
#  ['pay',
#   'roll',
#   'distribution',
#   'wealth',
#   'retrospect',
#   'bond',
#   'oil',
#   'company',
#   'oil',
#   'company',
#   'money',
#   'money'],
#  ['opposition'],
#  [],
#  ['rule',
#   'certificate',
#   'railway_station',
#   'harrassing',
#   'treatment',
#   'public'],
#  ['country', 'service', 'certificate', 'line', 'time'],
#  ['virus', 'lie', 'science', 'transmission', 'rate', 'level', 'rate'],
#  ['day', 'ticket', 'request'],
#  ['death', 'mindset', 'part', 'package'],
#  ['dep', 'integrity', 'issue', 'dep', 'job', 'proof'],
#  ['tar',
#   'number',
#   'case',
#   'break',
#   'case',
#   'hospital',
#   'datum',
#   'follow',
#   'protocol'],
#  ['update',
#   'today',
#   'syringe',
#   'injection',
#   'hour',
#   'arm',
#   'shivering',
#   'farm',
#   'needle'],
#  ['case', 'situation', 'place', 'lockdown', 'family_member'],
#  ['home', 'festival', 'follow', 'sop', 'life'],
#  ['man', 'love', 'show', 'man', 'man', 'wall', 'brain', 'analogy'],
#  ['commentary', 'parent', 'sibling'],
#  ['life',
#   'value',
#   'humanity',
#   'trolling',
#   'punishment',
#   'injustice',
#   'sport',
#   'sport',
#   'propaganda',
#   'service'],
#  ['tool', 'battle', 'priority', 'help'],
#  [],
#  ['bus', 'certificate', 'wonder', 'oil', 'travel', 'train'],
#  ['opportunity', 'unmet', 'commitment'],
#  ['case'],
#  ['pandemic'],
#  ['school', 'decision', 'faith', 'child', 'illness', 'time', 'fever'],
#  ['praise', 'modi', 'effort', 'prostitute', 'way', 'mother'],
#  ['regime', 'breath', 'hospital', 'bed', 'funeral', 'success', 'control'],
#  ['time', 'state', 'one', 'number'],
#  ['antibody',
#   'infection',
#   'infection',
#   'antibody',
#   'severity',
#   'infection',
#   'effect',
#   'level',
#   'exposure',
#   'time'],
#  ['duty', 'duty', 'choke', 'government', 'help'],
#  ['appointment'],
#  ['work', 'inflation', 'polarisation', 'fuel', 'inflation', 'burden', 'luck'],
#  ['need'],
#  ['society', 'instruction', 'class', 'control'],
#  ['force', 'coercion', 'rate'],
#  ['mom', 'man', 'mask', 'covidiot'],
#  ['damage', 'repair'],
#  ['center', 'hospital', 'bug', 'care', 'hospital', 'pandemic'],
#  ['person',
#   'test',
#   'certify',
#   'person',
#   'symptom',
#   'person',
#   'immunity',
#   'way',
#   'immunity',
#   'belief'],
#  ['time',
#   'clinic',
#   'nursing',
#   'home',
#   'casualty',
#   'blood',
#   'bank',
#   'clinic',
#   'place',
#   'hesitancy',
#   'effort',
#   'centre'],
#  ['population',
#   'face',
#   'mask',
#   'protection',
#   'blunder',
#   'government',
#   'ngo',
#   'effort',
#   'disaster'],
#  ['drive', 'world'],
#  ['number',
#   'type',
#   'certificate',
#   'whatsapp',
#   'certificate',
#   'certificate',
#   'way'],
#  ['leader', 'man', 'lead', 'country', 'quarter', 'level', 'month', 'crore'],
#  ['country',
#   'baseball',
#   'winner',
#   'runner',
#   'country',
#   'population',
#   'winner',
#   'runner'],
#  ['number',
#   'type',
#   'certificate',
#   'whatsapp',
#   'government',
#   'certificate',
#   'way'],
#  ['congratulation', 'country', 'achievement', 'country'],
#  ['joke', 'difference', 'government', 'documentary', 'case'],
#  ['success', 'drive', 'hole'],
#  ['job', 'certificate'],
#  ['programme', 'lakh', 'death'],
#  ['drive'],
#  ['exercise',
#   'regard',
#   'peoplenorthe',
#   'state',
#   'government',
#   'importance',
#   'performance',
#   'opposition',
#   'party'],
#  ['health',
#   'official',
#   'health',
#   'worker',
#   'government',
#   'success',
#   'crore',
#   'congratulation',
#   'government',
#   'thank'],
#  ['milestone',
#   'challenge',
#   'population',
#   'fear',
#   'pseudo',
#   'liberalism',
#   'time'],
#  ['prevention',
#   'side',
#   'conspiracy',
#   'theory',
#   'research',
#   'explanation',
#   'decrease',
#   'number',
#   'case'],
#  ['mass', 'funeral', 'body', 'momentum', 'event'],
#  ['drive', 'world'],
#  ['initiative',
#   'number',
#   'type',
#   'certificate',
#   'whatsapp',
#   'government',
#   'certificate',
#   'way'],
#  ['drive', 'virus'],
#  ['drive', 'virus'],
#  ['time', 'history', 'hindrance', 'corner', 'case', 'government'],
#  ['number', 'type', 'certificate', 'whatsapp', 'way'],
#  ['enforcement', 'drive', 'interest', 'economy', 'trade', 'business', 'well'],
#  ['certificate',
#   'whatsapp',
#   'number',
#   'type',
#   'certificate',
#   'whatsapp',
#   'government'],
#  ['duty', 'holiday', 'stay', 'road'],
#  ['reason', 'petroleum', 'product', 'price'],
#  ['cancer',
#   'contracting',
#   'combination',
#   'immunity',
#   'comorbitie',
#   'battle',
#   'life',
#   'role',
#   'masse'],
#  [],
#  [],
#  ['death', 'rate', 'crematorium', 'statistic'],
#  ['today', 'duty', 'asap', 'order', 'contain_spread'],
#  ['expenditure', 'ration', 'year', 'idea'],
#  ['death', 'time', 'time', 'challenge'],
#  ['complaint'],
#  ['issue',
#   'risk',
#   'child',
#   'health',
#   'willingness',
#   'risk',
#   'health',
#   'community',
#   'consideration',
#   'vaccinemandate'],
#  ['child', 'ruin', 'rest', 'life', 'year', 'infection'],
#  ['needle',
#   'life',
#   'syringe',
#   'world',
#   'inform',
#   'family',
#   'friend',
#   'ishantrivedi'],
#  ['opposition', 'fight', 'petrol', 'diesel', 'pay'],
#  ['way', 'photo'],
#  ['case',
#   'oil',
#   'control',
#   'corona',
#   'virus',
#   'air',
#   'property',
#   'corona',
#   'virus',
#   'virus',
#   'air'],
#  ['risk', 'news', 'death', 'count', 'season'],
#  ['protection'],
#  ['citizen', 'defeat', 'corona'],
#  ['travel',
#   'prophylactic',
#   'transmission',
#   'virus',
#   'herd_immunity',
#   'effect'],
#  ['occasion', 'protocol', 'dose', 'corona'],
#  ['mumbaikar', 'mumbaikar', 'student', 'person'],
#  ['fact', 'check', 'economy', 'crore', 'bias', 'credibility'],
#  ['season', 'care', 'family', 'awareness', 'pune'],
#  ['welfare',
#   'program',
#   'time',
#   'money',
#   'state',
#   'government',
#   'initiative',
#   'reduce',
#   'contribution',
#   'program'],
#  ['denominator', 'incidence', 'myocarditis', 'death', 'number', 'death'],
#  ['india', 'hospital', 'report', 'allegation', 'money', 'business'],
#  ['adult', 'side_effect', 'dead_bodie', 'food', 'goodbye'],
#  ['concern', 'fool', 'marketing', 'hide', 'reality', 'energy'],
#  [],
#  ['hurdle',
#   'section',
#   'population',
#   'pessimism',
#   'world',
#   'strength',
#   'fight',
#   'pandemic',
#   'vaccinating'],
#  ['son', 'today', 'centre', 'minute', 'staff'],
#  ['news',
#   'charge',
#   'certificate',
#   'fee',
#   'decision',
#   'charge',
#   'certificate',
#   'stall'],
#  ['infection',
#   'infection',
#   'cell',
#   'depletion',
#   'time',
#   'repeat',
#   'infection',
#   'damage'],
#  ['immunity', 'infection', 'evidence', 'contracting', 'stimulating'],
#  ['understand', 'consequence', 'age', 'factor', 'mortality'],
#  ['question',
#   'product',
#   'biotechnology',
#   'story',
#   'one',
#   'farm',
#   'technology',
#   'vetopower',
#   'farmer'],
#  ['bus', 'shot', 'summer', 'service', 'shot', 'reason', 'bureaucratic'],
#  ['rate', 'case', 'answer', 'plan', 'endemic', 'dontbesoblurcan'],
#  ['home', 'drug', 'molnupiravir', 'line', 'defence'],
#  ['population',
#   'number',
#   'number',
#   'coverage',
#   'excrement',
#   'sum',
#   'case',
#   'efficacy',
#   'fact'],
#  ['basis',
#   'death',
#   'aim',
#   'prog',
#   'immunity',
#   'population',
#   'fact',
#   'allergy'],
#  ['kid', 'state', 'miss', 'post', 'pick', 'inotrope', 'case'],
#  ['idea', 'feedback'],
#  ['certificate', 'mumbai', 'trust', 'certificate', 'site'],
#  ['adult', 'condition', 'travel', 'brother', 'risk', 'family'],
#  ['business', 'variant', 'restriction', 'world', 'life', 'thank', 'president'],
#  ['production', 'report', 'certificate', 'pal'],
#  ['factor', 'risk', 'patient', 'risk', 'infection', 'individual'],
#  ['status', 'self', 'test', 'result', 'desk', 'response', 'advance'],
#  ['proportion', 'internet', 'decision', 'version'],
#  ['live',
#   'period',
#   'family',
#   'month',
#   'health',
#   'virus',
#   'contract',
#   'refuse'],
#  [],
#  ['example',
#   'business',
#   'citizen',
#   'private_sector',
#   'business',
#   'business',
#   'welfare',
#   'citizen',
#   'business',
#   'businessman',
#   'profit'],
#  ['step', 'level', 'dining', 'cinema', 'hall', 'step', 'car'],
#  ['update'],
#  [],
#  ['government', 'epidemic', 'camp', 'corner'],
#  ['today', 'message', 'phone', 'number', 'person', 'phone', 'number'],
#  ['policy',
#   'population',
#   'use',
#   'population',
#   'ad',
#   'rate',
#   'world',
#   'datum',
#   'level'],
#  ['season', 'icer', 'carpet', 'time', 'percentage', 'antibody'],
#  ['decision',
#   'syrinx',
#   'synergize',
#   'state',
#   'derail',
#   'programme',
#   'state',
#   'appeal',
#   'decision'],
#  ['method', 'mass'],
#  ['part',
#   'problem',
#   'city',
#   'area',
#   'tourist',
#   'destination',
#   'record',
#   'number',
#   'visitor',
#   'summer',
#   'checking',
#   'enforcement',
#   'sop'],
#  ['study', 'clot', 'infection', 'failure', 'lot', 'news'],
#  ['trouble', 'clot', 'infection', 'clot'],
#  ['campus',
#   'mother',
#   'child',
#   'care',
#   'refusing',
#   'child',
#   'reason',
#   'hospital'],
#  ['country', 'respect', 'handling', 'rate', 'supply', 'status', 'hospital'],
#  ['management'],
#  ['drive', 'woman', 'today', 'situation', 'ground'],
#  ['managing', 'failure', 'protocol', 'mask', 'use', 'stage'],
#  ['word',
#   'force',
#   'student',
#   'school',
#   'education',
#   'parent',
#   'student',
#   'student'],
#  ['passport', 'order', 'restaurant', 'version'],
#  ['morning', 'today', 'passport', 'travel', 'finger'],
#  ['rate', 'good', 'surge', 'case', 'citizen'],
#  ['access', 'transgender', 'community', 'honour'],
#  ['credit', 'drive'],
#  ['friend', 'colleague', 'non', 'cold', 'symptom', 'immunity'],
#  ['story', 'government', 'support'],
#  [],
#  ['life',
#   'pandemic',
#   'month',
#   'population',
#   'news',
#   'lockdown',
#   'disease',
#   'gatepost',
#   'week'],
#  ['matter',
#   'speech',
#   'terrorism',
#   'influence',
#   'country',
#   'sea',
#   'water',
#   'hat',
#   'priority',
#   'world'],
#  ['move', 'modi', 'publicity', 'certificate', 'look'],
#  ['age'],
#  ['case', 'rate', 'time', 'work', 'office'],
#  ['case', 'freedom'],
#  ['conspiracy',
#   'theory',
#   'import',
#   'heroin',
#   'consumption',
#   'country',
#   'time',
#   'consumption'],
#  ['hundred', 'death', 'thousand', 'case', 'outbreak', 'rate'],
#  ['cancer', 'patient', 'cancer', 'patient', 'risk'],
#  ['thank', 'drive', 'inmate', 'family', 'syringe'],
#  ['paper', 'world', 'graduation', 'certificate'],
#  ['theory',
#   'havoc',
#   'transmission',
#   'illness',
#   'milder',
#   'embankment',
#   'passenger',
#   'certificate',
#   'sense'],
#  ['humanity', 'agenda', 'nation', 'shear', 'country', 'product'],
#  ['evidence',
#   'child',
#   'rate',
#   'repeat',
#   'infection',
#   'brain',
#   'damage',
#   'evidence',
#   'show'],
#  ['country', 'broadcast', 'legitimacy'],
#  ['certificate', 'report'],
#  ['result',
#   'brain',
#   'damage',
#   'damage',
#   'lung',
#   'heart',
#   'decline',
#   'brain',
#   'mass',
#   'want',
#   'infection'],
#  ['drive', 'manage', 'set', 'back', 'use', 'stage'],
#  ['family', 'contract', 'virus'],
#  ['picture', 'man'],
#  ['thing', 'friend', 'friend'],
#  ['effort', 'community', 'power', 'thank', 'persona', 'yariroad'],
#  ['recovery', 'pandemic', 'refugee', 'process', 'bangladesh'],
#  ['bill', 'issue', 'time', 'customer', 'care', 'helpless', 'excuse', 'call'],
#  ['youth', 'option', 'covidiot'],
#  ['day', 'group', 'trait', 'pressure', 'resist', 'process'],
#  ['government', 'coercion', 'child', 'immunity', 'infection', 'immunity'],
#  ['research', 'schedule', 'step', 'doctor', 'child', 'disease'],
#  ['year', 'baby', 'life', 'age', 'part', 'child', 'schedule'],
#  ['spite', 'mutant', 'treatment', 'virus', 'world'],
#  ['producer', 'mapping', 'chance', 'wave'],
#  ['make_sure'],
#  ['programme',
#   'healthcare',
#   'history',
#   'time',
#   'heart',
#   'care',
#   'disaster',
#   'decade'],
#  ['country', 'faxed', 'chance', 'chance', 'hospital', 'notice'],
#  ['country', 'faxed', 'chance', 'chance', 'hospital', 'notice'],
#  ['word', 'side', 'noone', 'fact', 'management', 'nation'],
#  ['bed', 'mother', 'hospital', 'society', 'follow'],
#  ['case', 'case', 'deathsvnumber', 'case', 'percentage', 'boss'],
#  ['day', 'hand', 'leader', 'path', 'bow', 'location'],
#  ['day', 'fooling'],
#  ['trend', 'line', 'datum', 'pattern'],
#  ['evening', 'view', 'speed', 'speed', 'country', 'epidemic'],
#  ['ord', 'take'],
#  ['attack', 'defence', 'killer', 'virus', 'chance', 'mask'],
#  ['man', 'nation', 'effect', 'power', 'party'],
#  ['profession',
#   'frontlinehealth',
#   'milestone',
#   'regard',
#   'awareness',
#   'effectiveness'],
#  [],
#  ['lahore', 'check', 'certificate', 'travel'],
#  ['time', 'government'],
#  ['impact', 'term', 'slowdown', 'birthday', 'boy'],
#  ['news',
#   'volunteer',
#   'side',
#   'yesterday',
#   'job',
#   'reason',
#   'person',
#   'year',
#   'service'],
#  ['government',
#   'effort',
#   'success',
#   'economy',
#   'base',
#   'effect',
#   'export',
#   'supply',
#   'chain',
#   'disruption',
#   'inflation',
#   'demand',
#   'head',
#   'line',
#   'management',
#   'management',
#   'body'],
#  ['day', 'celebrity', 'target', 'government', 'celebrity'],
#  ['medium',
#   'house',
#   'drive',
#   'worldrecord',
#   'number',
#   'lap',
#   'naysayer',
#   'newindia'],
#  ['health',
#   'officer',
#   'officer',
#   'bone',
#   'activity',
#   'community',
#   'health',
#   'officer'],
#  ['friend',
#   'assess',
#   'citizen',
#   'world',
#   'use',
#   'humanity',
#   'terrorism',
#   'terrorism',
#   'arranger',
#   'supporter'],
#  ['scam'],
#  ['person', 'guidance'],
#  ['customer', 'citizen'],
#  ['urge', 'part', 'responsibility', 'person', 'vaccinatenmc'],
#  ['yesterday', 'state', 'record', 'system', 'certificate', 'initiative'],
#  ['papilloma', 'virus', 'cancer', 'basis'],
#  ['minister', 'polio', 'smallpox', 'country', 'way'],
#  ['leader',
#   'pandemic',
#   'spread',
#   'population',
#   'country',
#   'health',
#   'care',
#   'system',
#   'span',
#   'pace'],
#  ['mission', 'drive'],
#  ['world', 'trust', 'care', 'mean', 'action', 'process'],
#  ['today', 'play', 'part', 'distance', 'peace'],
#  ['cost',
#   'checking',
#   'slot',
#   'family',
#   'hyderabad',
#   'place',
#   'cost',
#   'fulfill',
#   'coin'],
#  ['duty',
#   'bump',
#   'priority_group',
#   'transgender',
#   'name',
#   'case',
#   'help',
#   'group',
#   'shot',
#   'assist'],
#  ['tomorrow',
#   'camp',
#   'district',
#   'centre',
#   'awareness',
#   'friend',
#   'family',
#   'udalguricare'],
#  ['care', 'pledge', 'weartocare', 'love'],
#  ['opportunity',
#   'share',
#   'experience',
#   'pandemic',
#   'heck',
#   'campaign',
#   'integration',
#   'drive'],
#  ['option', 'scientist', 'data', 'nickiminaj'],
#  ['celebrity',
#   'awareness',
#   'misinformation',
#   'success',
#   'fame',
#   'use',
#   'help',
#   'celebrity'],
#  ['pill',
#   'day',
#   'stop',
#   'lie',
#   'smallpox',
#   'thing',
#   'chance',
#   'delta',
#   'shame'],
#  ['unite'],
#  ['scam', 'world', 'charger'],
#  ['paper', 'claim', 'risk', 'myocarditis', 'case'],
#  ['state', 'arrange', 'school', 'process', 'student', 'way'],
#  [],
#  ['probability', 'body', 'shield', 'virus', 'fitness', 'priority'],
#  ['put', 'life', 'danger', 'wave', 'rally', 'country'],
#  ['condition', 'spatial'],
#  ['dengue', 'manpower', 'control', 'measure', 'number', 'era', 'stat'],
#  ['task'],
#  ['number', 'sum', 'response', 'number', 'list', 'call', 'use'],
#  ['jabbed', 'risk', 'infection', 'risk', 'risk', 'evidence'],
#  ['center', 'running', 'block'],
#  ['world', 'health', 'safety', 'measure', 'human', 'way', 'typhoid', 'way'],
#  ['person', 'death', 'hospitalization'],
#  ['midnight', 'lockdown', 'auspol', 'siem', 'day', 'rise', 'case'],
#  ['none',
#   'food',
#   'supplement',
#   'report',
#   'product',
#   'clinicaltrial',
#   'approval'],
#  ['event', 'datum', 'gathering', 'rate'],
#  ['thing', 'appeal', 'friend', 'fan', 'staystrong'],
#  ['zone', 'screen', 'surgeon', 'need', 'administration'],
#  ['fear', 'wife', 'kid'],
#  ['statement', 'country', 'fee', 'devotee', 'thank'],
#  ['number',
#   'case',
#   'safety',
#   'safety',
#   'corona',
#   'corona',
#   'distance',
#   'foot'],
#  ['number',
#   'drive',
#   'person',
#   'dose',
#   'ground',
#   'health',
#   'staff',
#   'support',
#   'life',
#   'man',
#   'man'],
#  ['chance',
#   'infection',
#   'infertility',
#   'severity',
#   'symptom',
#   'experience',
#   'wife',
#   'symptom',
#   'vaccineswork'],
#  ['guarantee', 'person', 'bullet'],
#  ['charge', 'act', 'ticketless'],
#  ['delivery',
#   'location',
#   'income',
#   'tracking',
#   'item',
#   'health',
#   'worker',
#   'priority',
#   'material',
#   'cotton',
#   'pie',
#   'day',
#   'duty'],
#  ['number',
#   'case',
#   'safety',
#   'safety',
#   'corona',
#   'corona',
#   'distance',
#   'foot'],
#  ['gratitude', 'staff', 'volunteer', 'programme'],
#  ['enforcement',
#   'force',
#   'case',
#   'lot',
#   'facility',
#   'facility',
#   'ev',
#   'facility',
#   'time',
#   'money'],
#  ['case',
#   'presentation',
#   'response',
#   'treatment',
#   'case',
#   'number',
#   'ailment',
#   'time',
#   'report',
# ...
#   'death'],
#  ['struggle', 'article', 'cause', 'situation', 'supply', 'rate'],
#  [],
#  ['home', 'toddler', 'parent', 'praise', 'trouble', 'love', 'star'],
#  ['type', 'pay', 'struggle', 'queue', 'class', 'hype', 'money'],
#  ['country', 'delta', 'wave', 'action', 'testing'],
#  ['rate', 'community', 'urge', 'safety', 'protocol'],
#  ['style',
#   'credit',
#   'modi',
#   'mess',
#   'state',
#   'cabinet',
#   'war',
#   'state',
#   'country',
#   'leadership',
#   'promise',
#   'vision'],
#  ['roper', 'everytime', 'point', 'test', 'state', 'money', 'business', 'loop'],
#  ['bribe', 'link', 'state', 'sin'],
#  ['city',
#   'migrate',
#   'labour',
#   'state',
#   'corner',
#   'state',
#   'rush',
#   'centre',
#   'action'],
#  ['naomi', 'country', 'product', 'input', 'body', 'common_man', 'obligation'],
#  ['licence', 'thing'],
#  ['rate', 'medium', 'news', 'country', 'living', 'world', 'outbreak'],
#  ['medium',
#   'image',
#   'death',
#   'pain',
#   'country',
#   'term',
#   'case',
#   'pin',
#   'silence'],
#  ['post', 'case', 'self', 'illness', 'credit', 'thing'],
#  ['site', 'wave', 'country', 'fear', 'fighting', 'pandemic'],
#  ['trust',
#   'confidence',
#   'part',
#   'solution',
#   'solution',
#   'health',
#   'precaution',
#   'sop',
#   'safety',
#   'measure',
#   'regulation',
#   'world',
#   'tourism',
#   'recover'],
#  ['sin',
#   'silence',
#   'protest',
#   'coward',
#   'man',
#   'wealth',
#   'leader',
#   'case',
#   'death'],
#  ['autism', 'indiavaccine'],
#  ['crowd', 'police', 'force'],
#  ['care',
#   'pal',
#   'protocol',
#   'thing',
#   'event',
#   'celebration',
#   'chavithi',
#   'scripture',
#   'practice',
#   'age',
#   'respect'],
#  ['school',
#   'fruit',
#   'market',
#   'pakistani',
#   'hand',
#   'shake',
#   'fear',
#   'death',
#   'university',
#   'college',
#   'person',
#   'shame',
#   'ncos'],
#  ['rhoda', 'gain', 'protocol', 'manage', 'crowd', 'image'],
#  ['increase',
#   'case',
#   'match',
#   'projection',
#   'peak',
#   'number',
#   'infection',
#   'control',
#   'asap'],
#  ['kind', 'intervention', 'behalf', 'radio', 'base'],
#  ['win'],
#  ['side', 'stage', 'demand', 'lack', 'resource', 'availability', 'number'],
#  [],
#  ['infection', 'dose'],
#  ['death', 'mercy', 'death'],
#  ['pandemic', 'restriction', 'opposition'],
#  ['mound', 'arrest'],
#  ['medicine', 'medicine', 'immunity'],
#  ['group', 'one', 'one', 'one', 'one', 'group'],
#  ['thing', 'case', 'case', 'number', 'reason', 'increase', 'group'],
#  ['night'],
#  ['crore', 'naysayer', 'record', 'congratulation'],
#  ['shirt', 'thing', 'team', 'name', 'name', 'thing'],
#  ['shirt', 'thing', 'team', 'name', 'name', 'thing'],
#  ['situation', 'officer', 'preference', 'acquaintance'],
#  ['congratulation', 'virus', 'colony', 'make_sure'],
#  ['infection',
#   'post',
#   'complication',
#   'diabetes',
#   'heart',
#   'disease',
#   'kidney',
#   'severity'],
#  ['story', 'certificate', 'prove', 'race'],
#  ['effort', 'world', 'response', 'commitment', 'combat', 'pandemic'],
#  ['test'],
#  ['thing', 'park', 'bar', 'club', 'goal', 'bullshit', 'admit'],
#  ['nasal', 'liberty', 'pandemic', 'publichealth', 'globalhealth'],
#  ['center', 'security', 'team', 'employee', 'type'],
#  ['news',
#   'info',
#   'youtube',
#   'com',
#   'thang',
#   'hour',
#   'tube',
#   'short',
#   'thank',
#   'tube'],
#  ['month', 'case', 'apartment', 'app', 'time', 'curb', 'kill', 'bug', 'mask'],
#  ['constituency',
#   'statement',
#   'strandedaussie',
#   'trade',
#   'risk',
#   'fear',
#   'winter',
#   'lockdown',
#   'major_citie',
#   'region'],
#  ['homeopathy', 'prevention', 'program', 'failure', 'situation'],
#  ['help', 'slowing', 'spread', 'measure'],
#  ['protection', 'immunity', 'disease'],
#  ['treatment', 'work', 'year', 'leader', 'world', 'gun'],
#  ['school', 'responsibility', 'case'],
#  ['vision', 'leadership', 'death', 'srilanka'],
#  ['step', 'excuse'],
#  ['virus', 'government', 'state', 'facility', 'rule', 'country', 'number'],
#  ['action', 'hospital', 'name'],
#  ['name', 'hour', 'strict_action'],
#  ['centre', 'line', 'reason'],
#  [],
#  ['day',
#   'effort',
#   'health',
#   'worker',
#   'government',
#   'achievement',
#   'relaxing',
#   'living',
#   'pattern',
#   'country',
#   'wave',
#   'alert'],
#  ['campaign', 'credit', 'credit', 'success', 'initiating', 'campaign'],
#  ['booster', 'company', 'payment', 'help', 'restriction', 'country'],
#  ['core', 'wish', 'virus'],
#  ['family', 'follow', 'sop'],
#  ['time', 'observation', 'room', 'message', 'certificate', 'day'],
#  ['town', 'fear', 'panic', 'rush', 'center', 'reason'],
#  ['police', 'violence', 'accident', 'rate', 'officer', 'reactionary'],
#  ['story', 'role', 'drive', 'show', 'administration', 'corona', 'virus'],
#  ['government',
#   'idea',
#   'development',
#   'country',
#   'policy',
#   'home',
#   'deliver',
#   'system',
#   'management',
#   'arrangement',
#   'time',
#   'table',
#   'country',
#   'world'],
#  ['number', 'pace', 'outcome', 'wave', 'care', 'goi', 'sale'],
#  ['system',
#   'area',
#   'time',
#   'arrangement',
#   'guideline',
#   'shortage',
#   'count',
#   'arrangement'],
#  ['message', 'domain', 'strategy', 'fool', 'program', 'hospital', 'quoting'],
#  ['politic', 'atmosphere', 'fear', 'topic'],
#  ['department', 'arush', 'method', 'mass', 'arenot', 'system'],
#  ['belive',
#   'trump',
#   'cut',
#   'power',
#   'tech',
#   'power',
#   'priority',
#   'arush',
#   'way'],
#  ['protocol', 'slot', 'management', 'lack', 'administration', 'reason'],
#  ['case', 'virus', 'case', 'college', 'woman', 'student', 'staff', 'thank'],
#  ['surge',
#   'infection',
#   'spring',
#   'campaign',
#   'model',
#   'distancing',
#   'rule',
#   'mask',
#   'mandate',
#   'result'],
#  ['degree',
#   'holder',
#   'doctor',
#   'use',
#   'mask',
#   'world',
#   'health',
#   'scam',
#   'lockdown',
#   'work',
#   'corruption'],
#  ['entry', 'visitor', 'state', 'certificate', 'stop', 'eatable'],
#  ['certificate', 'matter', 'attire', 'photo', 'certificate', 'holder'],
#  ['awareness', 'community'],
#  ['pandemic', 'bit', 'variant', 'booster', 'shot', 'source'],
#  ['pettiness',
#   'scrutiny',
#   'certificate',
#   'foolishness',
#   'ism',
#   'level',
#   'practice',
#   'follow',
#   'convenience'],
#  ['fight'],
#  ['mask',
#   'infection',
#   'protection',
#   'dust',
#   'pollution',
#   'brainer',
#   'benefit',
#   'illness'],
#  ['taliban', 'mask', 'ally', 'case', 'thing', 'fishy', 'thing'],
#  ['certificate',
#   'airport',
#   'hassle',
#   'certificate',
#   'shirt',
#   'friend',
#   'trust'],
#  ['childhood', 'schedule', 'age'],
#  ['month', 'friend', 'associate', 'parent', 'wave', 'lot'],
#  ['mask', 'keeping', 'business', 'school', 'saving', 'life'],
#  ['fever', 'time', 'coronavaccine'],
#  [],
#  ['duty',
#   'workplace',
#   'mile',
#   'heartening',
#   'determination',
#   'mother',
#   'twentynine'],
#  ['line', 'management'],
#  ['centre', 'situation'],
#  ['mother', 'profile', 'button', 'status', 'mother', 'appointment'],
#  ['situation',
#   'picture',
#   'sister',
#   'chakra',
#   'brother',
#   'message',
#   'protection',
#   'message',
#   'country',
#   'importance'],
#  ['day', 'emergency', 'medication', 'time', 'recover', 'day'],
#  ['sundaythought'],
#  ['condition', 'lakhanpur', 'test', 'certification', 'matter', 'condition'],
#  ['test'],
#  ['friend',
#   'state',
#   'rate',
#   'drop',
#   'hospital',
#   'admission',
#   'ventilation',
#   'support'],
#  ['pandemic',
#   'extinction',
#   'level',
#   'life',
#   'threatening',
#   'course',
#   'time',
#   'wave',
#   'markup'],
#  ['immunity', 'infection', 'cold'],
#  ['way', 'protocol', 'idea'],
#  ['chance',
#   'play',
#   'path',
#   'regime',
#   'claim',
#   'victory',
#   'rate',
#   'remain',
#   'lawn'],
#  ['rule',
#   'name',
#   'mall',
#   'staff',
#   'customer',
#   'mall',
#   'rest',
#   'mall',
#   'safety',
#   'staff',
#   'mall',
#   'name',
#   'blind',
#   'eye'],
#  ['unemployment',
#   'price',
#   'inflation',
#   'policy',
#   'laughing',
#   'debate',
#   'issue'],
#  ['hospital', 'photo', 'copy', 'center'],
#  ['follow', 'schedule', 'way', 'prevent', 'disease', 'safety', 'norm'],
#  ['kid', 'decision', 'pandemic', 'state', 'student', 'teacher', 'parent'],
#  ['srilanka', 'rate', 'nation', 'world', 'deltavariant'],
#  ['case', 'rate', 'effect', 'year', 'case', 'today', 'care'],
#  ['fact', 'death', 'speed', 'shutdown', 'death'],
#  ['terkawal', 'responsibility'],
#  ['arrangement', 'staff', 'crowd', 'paper', 'reality'],
#  ['waiting', 'slot', 'colleague'],
#  ['way', 'gain', 'obtain', 'retain', 'love'],
#  ['mall',
#   'rule',
#   'mall',
#   'staff',
#   'customer',
#   'care',
#   'rule',
#   'name',
#   'treatment'],
#  ['choice', 'avail', 'service', 'risk', 'safety', 'humanright'],
#  ['rule',
#   'staff',
#   'customer',
#   'half',
#   'mall',
#   'staff',
#   'entry',
#   'name',
#   'eye'],
#  ['staff', 'care', 'protocol', 'mask', 'mall', 'social'],
#  ['mall', 'staff', 'dose', 'follow', 'protocol'],
#  ['number', 'infection', 'child', 'risk'],
#  ['share', 'appreciation', 'management', 'drive', 'family'],
#  ['effectiveness', 'none', 'colleague', 'none', 'family', 'half'],
#  ['bed',
#   'hospital',
#   'coronavir',
#   'increase',
#   'disease',
#   'infection',
#   'spread',
#   'safety',
#   'norm'],
#  ['guitar', 'leadership', 'dhanyavad'],
#  ['effect', 'case', 'fatality', 'earth', 'mask', 'time', 'thing'],
#  ['time', 'state', 'look', 'result'],
#  ['worry', 'level', 'photo', 'certificate'],
#  ['test', 'virus'],
#  ['process', 'day', 'day', 'place', 'process'],
#  ['issue', 'issue', 'job', 'issue', 'taliban'],
#  ['certificate', 'mana', 'baku'],
#  ['thirdwavebeda', 'mask'],
#  ['rush', 'security', 'local'],
#  ['ice',
#   'sicker',
#   'patient',
#   'demand',
#   'bed',
#   'time',
#   'icu',
#   'capacity',
#   'bed',
#   'method'],
#  [],
#  ['one', 'sense', 'security'],
#  ['impure',
#   'quality',
#   'water',
#   'pipeline',
#   'damage',
#   'sewerage',
#   'water',
#   'drinking',
#   'water',
#   'use',
#   'prevent'],
#  ['credit',
#   'orphan',
#   'responsibility',
#   'construction',
#   'land',
#   'allotment',
#   'entitlement',
#   'pond',
#   'land',
#   'record',
#   'record',
#   'room'],
#  ['person', 'son', 'nation', 'kid'],
#  ['center',
#   'system',
#   'work',
#   'team',
#   'one',
#   'care',
#   'system',
#   'independence',
#   'day',
#   'expecting',
#   'disappointment'],
#  ['bullet',
#   'proof',
#   'shoot',
#   'wear',
#   'fire',
#   'proof',
#   'thing',
#   'injunction',
#   'death',
#   'use'],
#  ['today', 'time', 'rule', 'time', 'food'],
#  ['ivermectine', 'ambulance', 'case', 'mercy'],
#  ['child', 'wall', 'painting', 'use', 'structure', 'innovation'],
#  ['cough', 'moth', 'jabbed', 'cough', 'day'],
#  [],
#  ['health', 'concern', 'win', 'battle', 'prevent', 'protect', 'thing'],
#  ['message', 'unite', 'fight', 'epidemic', 'precaution'],
#  ['differance', 'lockdown', 'hotspot', 'pop', 'city'],
#  ['dose', 'lot', 'bit', 'body', 'ache', 'couple', 'day'],
#  ['image',
#   'announce',
#   'government',
#   'hospital',
#   'image',
#   'certificate',
#   'document'],
#  ['pharma', 'money', 'government', 'dna', 'body'],
#  ['variant'],
#  ['education', 'way', 'spread'],
#  ['mettle', 'drive', 'citizen', 'gossaigaon', 'fight'],
#  ['procedure', 'country', 'thing', 'fillip'],
#  ['day', 'well', 'fever', 'pain', 'sense', 'smell', 'rasa', 'sense'],
#  ['precaution', 'guideline', 'slot', 'time', 'priority'],
#  ['mask',
#   'deception',
#   'expert',
#   'fact',
#   'silence',
#   'hiding',
#   'fact',
#   'crime',
#   'virus',
#   'man',
#   'virus',
#   'action'],
#  ['success', 'part', 'ton', 'money', 'ad', 'project'],
#  ['deny',
#   'bed',
#   'pal',
#   'birth',
#   'availability',
#   'bed',
#   'pregnancy',
#   'seroprevalence',
#   'way'],
#  ['control'],
#  ['service', 'part', 'hospital', 'radar', 'phase', 'karachiwork'],
#  ['condition', 'district', 'board', 'class', 'bench', 'school', 'center'],
#  ['visit', 'chair', 'wonder', 'hesitancy', 'indiavaccine'],
#  ['caregiver', 'patient', 'minister'],
#  ['expat', 'foreigner', 'payment'],
#  ['fact',
#   'opposition',
#   'citizen',
#   'parliament',
#   'session',
#   'farmer',
#   'situation',
#   'assess'],
#  ['threat', 'adult', 'kid', 'thing', 'school', 'relaxation', 'relaxation'],
#  ['paralyse',
#   'health',
#   'service',
#   'economy',
#   'job',
#   'shop',
#   'stock',
#   'market',
#   'question',
#   'end'],
#  ['time', 'fetch', 'certificate', 'issue', 'day'],
#  ['procedure', 'lahore'],
#  ['solution'],
#  ['doctor', 'case', 'day', 'exposure', 'chance'],
#  ['saint', 'hospital', 'guideline', 'bill'],
#  ['message',
#   'certificate',
#   'importance',
#   'interest',
#   'document',
#   'parliament'],
#  ['fraud', 'certificate', 'fraud', 'activity', 'probe'],
#  ['inconvenience',
#   'issuance',
#   'certificate',
#   'nada',
#   'office',
#   'country',
#   'registration',
#   'operation'],
#  ['card', 'swimming'],
#  ['job', 'dhamma'],
#  ['coin', 'process', 'problem', 'increase', 'number', 'paper'],
#  ['certificate', 'code', 'work', 'notte'],
#  ['policy',
#   'humanity',
#   'compassion',
#   'science',
#   'reaffirm',
#   'bangladesh',
#   'leader',
#   'nation',
#   'combat',
#   'xenophobic',
#   'refugee'],
#  ['shortage', 'government', 'reason', 'control', 'patient', 'government'],
#  ['degree',
#   'holder',
#   'doctor',
#   'mask',
#   'world',
#   'health',
#   'scam',
#   'lockdown',
#   'work',
#   'corruption'],
#  ['issue',
#   'waste',
#   'time',
#   'convince',
#   'care',
#   'example',
#   'awareness',
#   'importance'],
#  ['scene',
#   'centre',
#   'mismanagement',
#   'follow',
#   'protocol',
#   'authority',
#   'health',
#   'worker',
#   'peace',
#   'harmony'],
#  ['element', 'fight', 'pic', 'week', 'government'],
#  ['slot', 'office'],
#  ['month',
#   'show',
#   'world',
#   'app',
#   'show',
#   'schedule',
#   'railway',
#   'reservation'],
#  ['service', 'certificate', 'second'],
#  ['activist', 'wheeler', 'awareness', 'masse', 'face', 'mask'],
#  ['initiative',
#   'minute',
#   'certificate',
#   'certificate',
#   'certificate',
#   'information',
#   'thank'],
#  ['initiative',
#   'minute',
#   'certificate',
#   'certificate',
#   'certificate',
#   'thank'],
#  ['afternoon', 'expat', 'campaign'],
#  ['flight', 'week'],
#  ['bumper',
#   'oil',
#   'demand',
#   'lockdown',
#   'market',
#   'campaign',
#   'measure',
#   'momentum'],
#  ['value', 'rate', 'wherearevaccine'],
#  ['fight', 'state', 'government', 'responsibility', 'second'],
#  ['government', 'price', 'type', 'adv'],
#  ['sake', 'body', 'pain', 'death', 'family_member', 'day', 'pain'],
#  ['situation',
#   'drive',
#   'confusion',
#   'mind',
#   'action',
#   'empowering',
#   'capacity',
#   'work',
#   'possess',
#   'capacity',
#   'mind',
#   'rest'],
#  ['urge', 'turn_come', 'rule', 'mask', 'distancing'],
#  ['harm', 'antibody', 'effectiveness', 'heat'],
#  ['favour', 'video', 'cry'],
#  ['fact', 'district', 'percent', 'entry'],
#  ['pick'],
#  ['organiser', 'image', 'medal', 'athlete', 'image', 'certificate'],
#  ['care', 'result', 'situation'],
#  ['politic', 'livelihood', 'life', 'chicken', 'change', 'look', 'country'],
#  ['priority', 'safety', 'safety', 'loved_one'],
#  ['matter',
#   'status',
#   'country',
#   'defeat',
#   'country',
#   'level',
#   'vaccineequity',
#   'help',
#   'covidnotover'],
#  ['centre', 'authority', 'management', 'number'],
#  ['centre', 'state', 'health', 'centre', 'guideline', 'picture'],
#  ['celebration', 'death', 'week', 'optic', 'raffle', 'drive'],
#  ['government', 'figure', 'achievement', 'crore', 'dose'],
#  ['patsak', 'fight', 'thing'],
#  ['proud_moment', 'figure', 'achievement', 'crore', 'dose'],
#  ['politician', 'protocol', 'oath', 'rule', 'pal', 'increase', 'government'],
#  ['solution', 'effort', 'jab'],
#  ['order', 'hospital', 'meeting', 'owner', 'help', 'avail', 'service'],
#  ['contribution', 'count', 'organisation', 'ventilator'],
#  ['certificate', 'par', 'doctor'],
#  ['queue',
#   'inviting',
#   'administration',
#   'police',
#   'yard',
#   'distance',
#   'colony'],
#  ['mask'],
#  ['villager', 'road', 'hospital', 'night', 'tomorrow'],
#  ['area', 'service', 'government', 'guideline', 'service', 'justification'],
#  ['measure', 'bengaluru', 'spread', 'term'],
#  ['salwar',
#   'consultant',
#   'clinic',
#   'basement',
#   'building',
#   'tamam',
#   'office',
#   'staff',
#   'building',
#   'parking',
#   'staff',
#   'security',
#   'staff'],
#  ['perspective', 'situation'],
#  ['way', 'citizen', 'threat', 'society'],
#  ['way', 'karnataka', 'appointment'],
#  ['advice', 'doctor', 'rumour', 'cove', 'myth', 'research', 'virus'],
#  ['certificate', 'office', 'hour', 'template', 'app', 'help'],
#  ['hope', 'today', 'cucukmysin'],
#  ['policeman', 'mask', 'safety', 'precaution', 'wave'],
#  ['reason',
#   'appointment',
#   'complaint',
#   'helpline',
#   'coin',
#   'response',
#   'safeguard',
#   'staff'],
#  ['today', 'way', 'virus', 'loved_one'],
#  ['thane', 'coin'],
#  ['cash', 'practice', 'time', 'heart', 'coimbatore', 'vendor', 'money'],
#  ['center', 'bihar', 'mask'],
#  ['worker', 'family', 'today', 'family', 'case', 'week'],
#  ...]

# %%
df['words_processed_noun'].values[0][0]
# Out:
# 'death'

# %%
df['tokenised_stopremoved'] = tokenised_stopremoved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37623 entries, 0 to 37622
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   translated                         37623 non-null  object
#  1   words_processed_all                37623 non-null  object
#  2   words_processed_noun_adj_verb_adv  37623 non-null  object
#  3   words_processed_noun               37623 non-null  object
#  4   text_type                          37623 non-null  object
#  5   sentiment                          37623 non-null  int64
#  6   tokenised_stopremoved              37623 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 2.0+ MB

# %%
df['sentiment'].value_counts()
# Out:
# 0    20029
# 2    17594
# Name: sentiment, dtype: int64

# %%
positive_df = df[df['sentiment'] == 2]

# %%
positive_df
# Out:
#                                               translated  \
# 1      is covid ki waja se buht saray logon ne apne p...
# 2      deaths due covid what is vaccination rate what...
# 3      vaccination against covid- 19 is necessity tod...
# 5      dr. deserved #1 minister's award his exception...
# 6      yeah i still do not get why, symptoms are much...
# ...                                                  ...
# 37618  nature seems have already started working savi...
# 37619  dear , we #india Indiahas helped this #world i...
# 37620  our sincere request state central govt folded_...
# 37621  thanks your appreciation valuable feedback abo...
# 37622  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                      words_processed_all  \
# 1      ['couid', 'ki', 'raja', 'se', 'spray', 'logon'...
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['vaccination', 'couid', 'nineteen', 'necessit...
# 5      ['deserved', 'one', 'minister', 'award', 'exce...
# 6      ['yeah', 'still', 'not', 'get', 'symptom', 'mu...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'india', 'indians', 'help', 'world', ...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 1                         ['hair', 'ply', 'vaccination']
# 2      ['death', 'due', 'couid', 'vaccination', 'rate...
# 3      ['necessity', 'today', 'scenario', 'hope', 'pr...
# 5      ['deserved', 'way', 'manage', 'thing', 'millen...
# 6      ['still', 'symptom', 'much', 'less', 'severe',...
# ...                                                  ...
# 37618  ['nature', 'seem', 'already', 'start', 'work',...
# 37619  ['dear', 'help', 'world', 'include', 'kindness...
# 37620  ['sincere', 'request', 'state', 'central', 'go...
# 37621  ['thank', 'appreciation', 'valuable', 'feedbac...
# 37622  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type  \
# 1                               [hair, ply, vaccination]  subjective
# 2          [death, couid, vaccination, rate, harm, harm]  subjective
# 3                  [necessity, today, scenario, problem]  subjective
# 5      [way, thing, millennium, peril, couid, job, va...  subjective
# 6      [symptom, vaccination, example, country, numbe...  subjective
# ...                                                  ...         ...
# 37618             [nature, generation, life, strengthen]  subjective
# 37619                            [world, kindnessmatter]  subjective
# 37620                      [request, state, govt, share]  subjective
# 37621                    [thank, appreciation, feedback]  subjective
# 37622  [dose, covidvaccine, amp, amp, follow, vaccine...  subjective
#
#        sentiment                              tokenised_stopremoved
# 1              2                                        [hair, ply]
# 2              2                          [death, rate, harm, harm]
# 3              2              [necessity, today, scenario, problem]
# 5              2  [way, thing, millennium, peril, job, process, ...
# 6              2  [symptom, example, country, number, death, pop...
# ...          ...                                                ...
# 37618          2             [nature, generation, life, strengthen]
# 37619          2                            [world, kindnessmatter]
# 37620          2                      [request, state, govt, share]
# 37621          2                    [thank, appreciation, feedback]
# 37622          2                               [dose, follow, folk]
#
# [17594 rows x 7 columns]

# %%
texts = positive_df['words_processed_noun']

# %%
new_text_noun = []

for row in texts:
    # print(type(row))
    new_row = " ".join(row)
    new_text_noun.append(new_row)

# %%
new_text_noun
# Out:
# ['hair ply vaccination',
#  'death couid vaccination rate harm harm',
#  'necessity today scenario problem',
#  'way thing millennium peril couid job vaccination process retweet',
#  'symptom vaccination example country number death population couid life',
#  'agreement couid student travel guideline',
#  'campaign',
#  'case malaysia vaccination booster',
#  'age fact vaccinate child parent',
#  'wife couid adult ease people social_distance mask vaccination',
#  'year today battle couid vaccination drive virus threat heel',
#  'mess subsidy program crore citizen food growth rate percentage couid digitization benefit transfer',
#  'world country history leave vaccination couid part vote',
#  'couid vaccine immunization test need avoid vaccination',
#  'today nurse couid norm people child count amp vaccination detail',
#  'wolf shielding vaccination couid',
#  'vaccine people couid litter day people dose vaccination decrease number case cat',
#  'team roper report arrival vaccination certificate',
#  'village guitar couid vaccine awareness life car initiative champion',
#  'people vaccination official figure shame age benefit risk ratio',
#  'couid pandemic vaccination rate pandemic vaccination',
#  'immunity couid vaccination',
#  'envoy textile share workforce factory premise envoy textile family_members vaccination denim',
#  'era disease need couid patient',
#  'window air window ventilation air amp mind window air start',
#  'population job couid management vaccination vote person other vaccine',
#  'agency restrain scare situation thing vaccination couid',
#  'blend couid management budget allocation state heart',
#  '',
#  'border people sop vaccination program majority nation politician couid gain',
#  'highway video infra project defence expenditure development project couid vaccination project debt side coin',
#  'part news amp vaccination hope booster age group year fall case amp positivity_rate manner time month cycle',
#  'commitment satyamevajayate one health care couid vaccination bank pension name none resignation',
#  'couid omicron expert coronaviru trait vaccination amp idiot human reason breakout amp step environment difficulty',
#  'precaution vaccination letter inspiration volunteer devotee vaccination camp',
#  'movement couid vaccination menace office',
#  '',
#  'couid vaccination child marriage caravan',
#  'surge couid case vaccination help corona virus testing root school couid markup',
#  'couid vaccination duty lage staff month race race nursing payment',
#  'behaviour slum task session interaction community disseminate information message usage mask hand washing importance',
#  'other follow couid time vaccination',
#  'pledge couid vaccination',
#  'amp vaccination virus likelihood virus autoimmunity couid virus priority',
#  'uncle vaccine management couid management',
#  'worker vaccination coverage hope couid',
#  'old enthusiasm child face world hospital',
#  'wave couid make_sure vaccination',
#  '',
#  'battle couid discrimination line train ration countryman amp vaccination kudo',
#  'race sake doctor injection',
#  'couid vaccination awareness car initiative vaccinate teenager',
#  'child protection mis condition vaccination deserve pickin',
#  'vital people importance welfare work',
#  'lot effort couid vaccination responsibility vaccinate request thank thank',
#  'work derasachasauda volunteer couid vaccination camp world thank doctor teaching',
#  'vaccination effort job government sad couid amp wave government datum couid casualty',
#  'people chief_minister highlight achievement government president photo',
#  'cost food program world people pandemic cost vaccination program record time opposition spreading rumour worker',
#  'observation couid fatigue vaccination rate sense security acquaintance couid amp hustle culture',
#  'couid',
#  'beer night country couid vaccination country',
#  'amp leader finger wave couid centre victory couid vaccination realise leadership silence time',
#  'initiative pledge couid vaccination missionhumanity freeservice',
#  'couid program country world vaccination alcohol drug responsibility alcohol',
#  'couid',
#  'couid citizen vaccination country',
#  'couid amp couid vaccination',
#  'week advertisement sensitization hoping immunity',
#  'inspiration organization vaccination camp epidemic couid amp people',
#  'duty child',
#  'end microbe couid case day thank vaccination drive authority people',
#  'criterion fight couid sop adherence masking distancing crowd',
#  'doctor',
#  'vaccination program fight couid pandemic congratulation',
#  'cell immunity infection vaccination protection couid conclusion memory role timeline infection antibody',
#  'couid living wage vaccination life dignity minimum wage amp',
#  'sop amp vaccination virus likelihood virus autoimmunity couid help',
#  'couid death effect vaccination',
#  'people care vaccine care people',
#  'amp weapon fight vaccination program part emergency service',
#  'teacher couid duty teacher teacher couid duty teacher body work',
#  'time end couid restriction vaccination mandate people business maharashtrian state blanket relief city rule',
#  'couid case increase trust hospital admission rate ventilatory support rate amp death toll surge case vaccination coverage care soup vaccine case blame',
#  'population couid vaccination couid worry success programme',
#  'inflation era polio spite party today sector pal job',
#  'terror child child ink think kid vaccination chest cold kid couid',
#  'vaccination perception survey vaccine solution couid pandemic insight research attitude knowl',
#  'precaution vaccine symptom couid body avoid side_effect vaccination couid',
#  '',
#  'symptom visit day life',
#  'family alhamdulillah vaccination symptom brother couid month vaccination',
#  'couid lakhs student vaccination year one mode patience',
#  'vaccination couid vaccination occasion',
#  'pickin charge vaccination smuggle',
#  'self amp couid saint welfare work spread awareness',
#  'help protection couid vaccination other spread corona inspiration volunteer other',
#  'vaccination build immunity initiative vaccination camp awareness couid vaccination inspiration',
#  'body organization initiative volunteer mask amp volunteer dose couid',
#  'time today couid vaccination people importance amp welfare work',
#  'couid idea mask product vaccination programme food production int nonsense',
#  'budget nation couid government vaccination',
#  'vaccination drive district hope weekend pandemic',
#  'treatment couid work think vaccination',
#  'family couid infection vaccination home day hospital expense stress medicine heart',
#  'pune staff center fakecovidcenter staff pune trend app',
#  'condition couid vaccination center baramulla patient condition centre',
#  'infection vaccination immunity researcher',
#  'couid virus country vaccination schedule country',
#  'sister son vaccine booster week corona day vaccination mind couid omicron wear_mask',
#  'seeing couid vaccination',
#  'test hour people couid positivity ratio',
#  'couid case race vaccination death rate',
#  'people vaccination way couid confusion',
#  'today couid covishield',
#  'couid amp couid vaccination',
#  'news people vaccination damage expert amp response falsehood amp message source',
#  'radar number lot thing couid vaccination testing message radar number prevent number',
#  'couid stop venue world',
#  'couid vaccination precaution convince rule team vaccination video helmet',
#  'home couid infection dose vaccination family self couid test day cough tiredness',
#  'test day day guarantee medicine couid virus omicron side_effect person business pharmaceutical',
#  'approach couid population vaccination restriction infection vaccination protection',
#  'couid case concern group year',
#  'age child host vaccination advice believe child couid vaccine part infant vaccination schedule year',
#  'citizen vaccination fear couid initiative vaccine help worker',
#  'sign people guard couid people thank government vaccination drive',
#  'way reluctance incompetence life risk',
#  'couid vaccine year country vaccination drive',
#  'way success couid payment citizenry pay taxis',
#  'child protection end couid vaccine omicron',
#  'needle vaccination',
#  'achievement year completion vaccination couid effort task administration crore capacity advancement',
#  'power vaccine certificate couid test report covidbooster covidvaccine',
#  'congratulation couid',
#  'success village',
#  'threat couid lake patient couid earmark condition',
#  'congratulation vaccination effort country let_us intervention contain case omicron',
#  'attention situation covidvaccine vaccination drive couid drive nhmassam lool',
#  'video detail motivation program training emergency vaccination initiative bag part',
#  'vaccination kind video news thank day',
#  'vaccination couid vaccination day',
#  'vaccination couid vaccination day',
#  'campus today trainee authority dedication couid',
#  'colony elder vaccination locality centre vaccination',
#  'face mask vaccination couid',
#  'request clarity guideline vaccination child couid',
#  'life path success success point time life couid vaccination',
#  'precaution vaccination service',
#  'mover vaccination relocation couid worry packer mover dose vaccination safemoving',
#  'couid event couid vaccination player player antivaccination rant',
#  'precaution dose kudo today vaccination mean couid',
#  'evidence infection couid amp vaccination measure transmission majority population building antibody virus role reduction',
#  'tooo couid check testing facility vaccination amp couid symptom member spread testing couid',
#  'vaccination coin registration couid vaccine couid certificate registration',
#  'country couid rate month_ago beginning vaccination campaign year virus job hospitalization',
#  'number certificate contact list type certificate government way',
#  'review booster staff workplace',
#  'body',
#  'sample vaccination bushland municipality couid omicron',
#  'approach person help note',
#  'amp effect menstruation thread day day',
#  'truth prospect party vaccination city word vaccine art',
#  'example hat confidence parent science child science',
#  'article discrimination person healthcare system end need person access couid vaccination',
#  'couid disease spread indoor vaccination line defence',
#  'faith win',
#  'syringe couid vaccination',
#  'follow masking washing_hand crowd amp vaccination disease couid',
#  'roll time team era relief vaccination camp team action drive place',
#  'respect rule country vaccination fighting couid part',
#  'line line time part vaccination',
#  'care guess couid system doctor clue work jar water wave vaccination work mask test report',
#  'fight vaccination line defence fight',
#  'panic precaution thank vaccination herd_immunity criticality mask wave',
#  'pit vaccination center couid world amp rest world vaccination surveillance priority list pit gov voice',
#  'couid vaccination congratulation vaccination',
#  'dose',
#  'declare period child arrange vaccination child school',
#  'omicron vaccination mask ventilation space couid',
#  'school child state thing school month arrange vaccination child',
#  'amp couid vaccination child child',
#  'magnet couid vaccination wash time',
#  'congratulation kid year vaccination program safety couid number couid other',
#  'survival gathering mask self',
#  'respect entry cell entry point mask measure vaccination stay',
#  'video vaccination couid super sum',
#  'video vaccination couid super sum',
#  'people death other request government vaccination cancelvoterid',
#  'hope help body sense odd war couid',
#  'weapon vaccination couid believe',
#  'jharkhand amp door couid jharkhand governance',
#  'vaccination world fact nation protection person',
#  'couid name death research fear people care vaccination couid',
#  'reason behavior covidvaccine reduce transmission',
#  'vaccination program action vaccine expire use hope authority action',
#  'challenge caution wind couid covidtesting vaccination besame',
#  'gird walk hair sake',
#  'difference time vaccination population position body couid',
#  'body notice change system interest result leadership team way couid vaccination',
#  'evening today couid vaccination dose body temperature thermometer shower coin',
#  'lock vaccination virus decease check kit queue good people mind strength arise',
#  'hotel record son credit card business care charge money',
#  'transit traveler travel symptom guideline couid norm vaccination certificate produce border district',
#  'person contracting couid president man couid reason vaccination compulsory',
#  'year certificate congratulation couid',
#  'trash disposal syrinx couid vaccination fall',
#  'number day way cowinportal',
#  'hear vaccination omicron mask',
#  'challenge vaccination drive couid',
#  'time vaccination target area official amp professional people home number people vaccine',
#  'government campaign birthday vaccine certificate passed_away',
#  'couid extent certificate billboard face amp trust role play',
#  'country service couid answer vaccination bea',
#  'couid vaccination',
#  'child adult hesitation couid vaccination child vaccine adult time hesitation join fight',
#  'wedding pic people availability couid vaccination ticket',
#  'man attender par one armor',
#  'couid vaccination report citizen',
#  'couid vaccination report',
#  'case vaccination citizen couid responsibility government vaccination delay',
#  'vaccination couid vaccination news',
#  'today reliance customer experience temperature face mask picture space couid protocol',
#  'couid vaccination need brain physiotherapy',
#  'drive milestone momentum strengthen fight couid couid protocol',
#  'antibody batch population side affect amp post couid nasal vaccine medicine health care infra regulating treatment cost hospital',
#  'attention couid protocol concern country request support plan vaccinate spread awareness importance vaccination',
#  'people vaccination',
#  'situation couid amp term',
#  'vaccination spot marathon event event noise space vaccination meter distance couid case',
#  'team village foot distance',
#  'core couid vaccination height country man',
#  'year couid dose time help illness couid',
#  'news life mean couid generation omnicronvariant',
#  'hospital opportunity head vaccination centre month amp healthcare city healthcare infrastructure',
#  'one attitude people couid chalk awareness fine',
#  'country border couid stay vaccination herd_immunity solution',
#  'vaccination couid wearing_mask',
#  'tool end vaccination hesitancy world variant nation helping',
#  'desire mind theater eat shit covidvariant couid covidiot vaccination',
#  'progress country way couid vaccination',
#  'vaccination program couid world',
#  'virus thing vaccination couid couid war',
#  'couid vaccination drive responsibility vaccination',
#  'vaccination logic people couid severity matter',
#  'virologist couid norm vaccination mask',
#  'vaccination couid fun gas weekend',
#  'way fight couid menace',
#  'campaign acquisition campaign farm bill campaign vaccination success couid victim modi amp word',
#  'show proof vaccination couid status way hope way',
#  'phone vaccine request type issue share',
#  'lot people couid vaccination vaccination factor type people',
#  'leader couid',
#  'trial key kid high_risk response couid vaccination kid activity interaction school programme',
#  'thing mirror bill intrusion shortage law farmland',
#  'vaccination year couid vaccination world vaccine world family',
#  'couid weapon fight vaccination',
#  'population percentage faith belief way vaccination goat',
#  'vaccination',
#  'treatment couid sufferer relief vaccination ability reservoir body',
#  'thread vaccine communicator thread vaccinate pandemic vaccine',
#  'surprise visit couid vaccination center good situation doctor staff people work',
#  'word appreciation process today experience hospital',
#  'vaccination sector twentynine appointment tomorrow thank advance',
#  'fact couid period room hospital doctor ration vaccination drive slum experience cost',
#  'ramp booster elder mindset cloud couid',
#  'world year other couid vaccination',
#  'article topic',
#  'coverage vaccination lot criticism occasion confidence regard',
#  'opinion help opinion vaccination vaccination couid infection',
#  'people fight couid',
#  'couid vaccination status tawakalna app case',
#  'problem thank health infra facility house production couid vaccine amp arrangement cost vaccination',
#  'couid friend relapse vaccination time couid joke precaution hand distancing ply',
#  'animal citizen air quality amp couid case complication appeal government cracker vaccination behaviour',
#  'soldier statesman soldier couid sandal vaccination record time',
#  'sense eradication smallpox polio policy making',
#  'couid vaccination opposition amp',
#  'vaccination vaccine',
#  'country service couid vaccination certificate people line time',
#  'day ticket vaccination request',
#  'update today syringe injection hour arm shivering farm needle',
#  'home festival follow sop couid couid vaccination amp life',
#  'tool battle couid priority help',
#  'amp vaccinate vaccination',
#  'vaccination couid pandemic',
#  'couid duty vaccination duty choke government help',
#  'appointment',
#  'need couid vaccination',
#  'mom covidvaccine man vaccine mask covidiot',
#  'vaccination damage repair',
#  'couid vaccination center people hospital bug care hospital pandemic',
#  'person couid amp test certify person couid symptom person immunity way immunity belief vaccination',
#  'population face mask protection blunder government ngo effort people couid disaster',
#  'drive world',
#  'number type certificate whatsapp certificate certificate way',
#  'number type certificate whatsapp government certificate way',
#  'congratulation country achievement country vaccination',
#  'vaccine joke difference government documentary case couid vaccination',
#  'success drive hole',
#  'drive',
#  'health official health worker government success vaccination couid crore people vaccine congratulation government thank',
#  'couid milestone challenge population fear pseudo liberalism time',
#  'prevention side conspiracy theory research vaccine explanation decrease number couid case vaccination',
#  'drive world',
#  'initiative number type certificate whatsapp government certificate way',
#  'drive couid virus',
#  'drive couid virus',
#  'time history hindrance amp corner couid case government',
#  'number type certificate whatsapp way',
#  'amp enforcement couid vaccination drive amp interest economy trade business well amp',
#  'couid vaccination certificate whatsapp number type certificate whatsapp government',
#  'vaccination duty holiday stay road',
#  'reason petroleum product price couid',
#  '',
#  'couid death time couid vaccination time challenge',
#  'child couid ruin rest life year infection couid vaccination',
#  'needle life syringe couid vaccine world inform family friend ishantrivedi',
#  'opposition fight petrol diesel vaccination pay couid',
#  'vaccination way couid photo',
#  'risk couid vaccination news death count season',
#  'couid vaccination protection',
#  'vaccination citizen couid defeat corona',
#  'people occasion couid protocol dose corona vaccine',
#  'mumbaikar couid vaccination mumbaikar vaccine student person',
#  'season couid couid vaccination care family awareness pune',
#  'denominator incidence myocarditis death number vaccination couid death',
#  '',
#  'hurdle section population pessimism world strength fight pandemic vaccinating',
#  'son couid today vaccination centre minute staff',
#  'news charge couid certificate fee decision charge certificate stall',
#  'couid immunity infection vaccination evidence contracting vaccination stimulating couid',
#  'vaccination bus shot summer service shot reason bureaucratic',
#  'basis death aim couid vaccination prog immunity vaccinate population fact people vaccination allergy',
#  'couid vaccination idea feedback',
#  'adult vaccination condition travel brother risk family other',
#  'couid vaccination business variant restriction world life thank president',
#  'status couid self test result desk response vaccination advance',
#  'vaccine live period family vaccine month health vaccination couid virus contract refuse',
#  '',
#  'example business citizen couid vaccination private_sector business business welfare citizen business businessman profit',
#  '',
#  'government epidemic couid camp corner',
#  'today message phone number vaccination person phone number couid vaccination',
#  'season icer carpet couid time percentage vaccination antibody',
#  'method couid mass vaccination',
#  'part problem city area tourist destination record number visitor summer checking vaccination enforcement couid sop',
#  'managing couid failure couid protocol mask use stage',
#  'morning today couid vaccination passport travel finger',
#  'rate good surge couid case couid citizen',
#  'access couid vaccine transgender community honour',
#  'credit vaccination drive',
#  'story couid government support',
#  'matter speech terrorism influence country sea water hat priority world',
#  'age',
#  'case vaccination rate time work office',
#  'people case people freedom vaccination',
#  'thank drive inmate vaccination family syringe',
#  'humanity amp vaccination agenda nation shear country couid product vaccine',
#  'evidence child rate repeat infection couid brain damage vaccine evidence show vaccination',
#  'country couid broadcast vaccination legitimacy other',
#  'vaccination drive manage couid set back use stage',
#  'family contract couid virus',
#  'thing friend vaccine vaccine friend vaccination',
#  'effort community vaccination vaccination people power thank persona yariroad',
#  'recovery couid pandemic refugee vaccination process bangladesh',
#  'research vaccination schedule step doctor child disease couid',
#  'make_sure couid',
#  'amp day hand leader path bow location',
#  'vaccine day fooling people',
#  'ord vaccination couid take',
#  'vaccine attack defence killer couid virus chance mask',
#  'man nation effect vaccination amp power party',
#  'people profession frontlinehealth milestone regard awareness effectiveness',
#  'people',
#  'lahore check vaccination certificate travel',
#  'impact term couid slowdown vaccination birthday boy',
#  'news volunteer couid vaccination side yesterday people job reason amp person year service',
#  'health officer officer bone vaccination couid activity community health officer',
#  'friend assess amp citizen world use humanity terrorism terrorism arranger amp supporter',
#  'person couid guidance',
#  'customer citizen',
#  'yesterday couid state record system couid certificate initiative amp',
#  'papilloma virus vaccination amp cancer basis',
#  'minister polio smallpox country way vaccination',
#  'leader couid pandemic spread population country health care system vaccine span vaccination pace',
#  'mission couid drive',
#  'world trust care mean action vaccination process covidvaccine',
#  'today couid play part vaccination distance peace',
#  'vaccination cost checking slot family hyderabad place vaccination cost fulfill coin',
#  'duty bump vaccination priority_group transgender name case help group shot assist',
#  'tomorrow couid vaccination camp district centre awareness vaccination friend family udalguricare',
#  'care couid pledge weartocare love',
#  'opportunity share experience couid pandemic heck campaign integration vaccination drive',
#  'unite',
#  '',
#  'vaccination probability couid body shield virus vaccination fitness priority',
#  'task',
#  'couid vaccination center running block',
#  'midnight vaccination lockdown auspol siem day rise couid case',
#  'event datum gathering vaccination rate',
#  'couid thing appeal friend fan vaccination staystrong',
#  'number couid case safety safety other corona corona distance foot',
#  'number drive person dose ground health staff support life man man',
#  'number couid case safety safety other corona corona distance foot',
#  'couid vaccine gratitude staff volunteer vaccination programme',
#  'couid vaccination',
#  'home toddler parent praise trouble love star',
#  'vaccination rate community couid urge safety protocol',
#  'vaccination city migrate labour state corner state rush vaccination centre action',
#  'people naomi country couid vaccination product input body common_man obligation',
#  'licence couid vaccination thing',
#  'couid trust confidence couid vaccination part solution solution health precaution sop safety measure regulation world tourism recover',
#  'autism vaccine indiavaccine',
#  'care pal vaccination couid protocol thing event celebration chavithi people scripture practice age respect',
#  'rhoda gain couid protocol manage crowd image',
#  'increase case match projection peak vaccination number infection control asap',
#  'kind intervention behalf vaccination people radio base',
#  'covidvaccine win covishield',
#  '',
#  'couid pandemic restriction opposition',
#  'couid medicine medicine immunity vaccination',
#  'night',
#  'crore naysayer record congratulation',
#  'shirt thing couid vaccination team name name thing',
#  'shirt thing couid vaccination team name name thing',
#  'congratulation couid virus colony make_sure vaccination',
#  'vaccine vaccination effort amp world response commitment combat pandemic',
#  'couid test vaccination',
#  'couid vaccination center security team employee type people',
#  'news couid vaccination info youtube com thang hour tube short thank tube',
#  'month case apartment app people vaccination time curb kill bug mask',
#  'homeopathy prevention couid vaccination program failure situation',
#  'vaccination help slowing spread couid vaccination measure couid',
#  'vision leadership couid death vaccination srilanka',
#  'step couid vaccination couid vaccination excuse',
#  'couid vaccination',
#  'day effort health worker government achievement relaxing living pattern country couid wave alert',
#  'campaign couid credit credit success initiating campaign',
#  'core wish virus',
#  'family follow couid sop vaccination',
#  'story role drive couid show administration corona virus',
#  'couid number vaccination pace outcome wave care goi sale',
#  'system area time arrangement couid guideline shortage vaccination count arrangement',
#  'department arush method couid mass vaccination arenot system',
#  'belive trump cut power tech power priority arush way couid',
#  'couid case virus case college woman vaccination student staff thank',
#  'couid surge infection spring vaccination campaign model distancing rule mask mandate result',
#  'degree holder doctor vaccine amp use mask world health scam couid lockdown vaccination work corruption',
#  'awareness couid amp vaccination community',
#  'pettiness scrutiny certificate foolishness ism level practice follow convenience',
#  'fight',
#  'certificate couid vaccination airport hassle couid certificate shirt friend trust',
#  'couid vaccine childhood vaccination schedule vaccine age',
#  '',
#  'vaccination line vaccination management',
#  'sundaythought',
#  'friend state couid vaccination rate drop hospital admission ventilation support vaccine',
#  'couid rule name mall staff vaccination customer mall rest mall safety staff mall name blind eye',
#  'vaccinate follow vaccination schedule way prevent disease couid safety norm',
#  'srilanka vaccination rate nation vaccine world couid covidvaccine deltavariant',
#  'case vaccination rate effect year couid case today care',
#  'terkawal responsibility',
#  'waiting couid vaccine slot vaccination couid vaccine colleague',
#  'way gain obtain retain people love',
#  'mall couid rule mall people vaccination staff customer care rule name treatment',
#  'couid rule staff customer vaccination half mall staff entry name eye',
#  'people vaccination staff care couid protocol mask mall social',
#  'mall staff dose vaccination follow protocol',
#  'number people vaccination infection couid child risk',
#  'share appreciation management couid vaccination drive family vaccination',
#  'effectiveness vaccination couid vaccination none colleague none family half couid',
#  'guitar leadership couid dhanyavad vaccine',
#  'vaccination effect case fatality earth people mask time thing',
#  'time state look result',
#  'vaccination couid test virus',
#  'process day day place vaccination process',
#  'issue people issue job issue vaccination taliban',
#  'thirdwavebeda vaccination mask',
#  'rush couid security local',
#  'people vaccination',
#  'couid one vaccination sense security',
#  'person couid vaccination son nation vaccination kid',
#  'center vaccination system work team one care system independence day expecting disappointment',
#  'today time vaccination people couid rule people time food vaccine',
#  'child couid vaccination wall painting use structure innovation',
#  'couid vaccination',
#  'health concern win battle couid prevent protect thing vaccination people vaccine',
#  'message unite fight epidemic precaution',
#  'vaccination differance lockdown couid hotspot pop city',
#  'pharma money government vaccination couid dna body',
#  'mettle vaccination drive citizen gossaigaon fight couid',
#  'procedure country thing amp fillip',
#  'day couid well fever pain sense smell vaccination rasa sense',
#  'success part ton money ad project vaccine couid vaccination',
#  'service part hospital people radar phase karachiwork',
#  'condition district board class bench school center',
#  'visit chair wonder hesitancy vaccination indiavaccine covidvaccine couid',
#  'caregiver patient minister',
#  'threat adult kid couid thing school relaxation vaccination relaxation',
#  'couid vaccination procedure lahore',
#  'solution',
#  'doctor case day vaccine couid exposure vaccination couid chance',
#  'couid vaccination card swimming vaccination',
#  'job dhamma',
#  'coin process problem increase number paper',
#  'certificate code work notte',
#  'couid vaccination policy humanity compassion science reaffirm bangladesh leader nation combat xenophobic refugee',
#  'degree holder doctor mask amp vaccine world health scam couid lockdown vaccination work corruption',
#  'issue couid waste time convince care example amp awareness importance vaccination',
#  'scene centre mismanagement people follow protocol authority health worker peace harmony vaccination',
#  'element fight couid vaccination pic vaccination week people government',
#  'vaccine month vaccination show world app show schedule railway reservation',
#  'service couid vaccination certificate second',
#  'activist wheeler awareness masse face mask couid vaccination',
#  'initiative minute certificate couid certificate certificate information thank',
#  'initiative minute certificate couid certificate certificate thank',
#  'couid vaccine afternoon expat vaccination campaign',
#  'flight vaccination week',
#  'bumper oil demand couid lockdown market vaccination campaign measure momentum',
#  'fight couid state government responsibility second',
#  'couid situation vaccination drive confusion amp mind action empowering capacity work possess capacity mind rest',
#  'couid urge turn_come rule vaccination mask amp distancing',
#  'favour couid video cry',
#  'vaccine vaccination pick',
#  'organiser image medal athlete image couid vaccination certificate',
#  'priority safety safety loved_one',
#  'matter vaccination status country defeat couid country level vaccineequity help covidnotover',
#  'celebration death week optic people raffle couid vaccination drive',
#  'government couid vaccination figure achievement crore dose',
#  'patsak couid vaccine people vaccination fight couid thing vaccine',
#  'proud_moment couid vaccination figure achievement crore dose',
#  'order hospital vaccination meeting owner help amp vaccination people avail service',
#  'contribution count organisation couid vaccination ventilator',
#  'certificate par doctor',
#  'mask',
#  'area couid vaccination service government guideline vaccination service people justification',
#  'measure bengaluru spread couid term vaccination',
#  'salwar consultant clinic basement building tamam office staff building parking staff security staff',
#  'perspective couid situation vaccination',
#  'certificate office hour template app help',
#  'hope today cucukmysin',
#  'policeman mask safety precaution couid wave',
#  'reason vaccination appointment complaint couid helpline coin response safeguard staff',
#  'today vaccination couid vaccine way virus loved_one',
#  'cash practice time heart coimbatore vendor money',
#  'center bihar mask vaccine',
#  'amp worker family today family couid case week',
#  'symptom couid case vaccination cat lah tag sub assess couid case',
#  'staff request security people vaccination use vaccination',
#  'percent couid month majority world year end',
#  'people government number couid case solution vaccination rate soup government',
#  'couid vaccination awareness watch love react comment share',
#  'couid vaccination people clock',
#  'inhabitant couid vaccination person',
#  'couid control couid breakthechain follow vaccination air pollution pledge energy energy fuel',
#  'one couid vaccination test carrier other',
#  'idea thing couid vaccination appointment country appointment tool service stuff',
#  'couid vaccination vaccination day wealth vaccination wealth lifetime income family support',
#  'guard hospital amp staff complaint supervisor',
#  'concern constituency view couid wave pace sir',
#  'citizen fight couid vaccination step journey defeat couid delay asap',
#  'mass people bangladesh necessity fight couid delta condition',
#  'program priority vaccination medium telephone call email reduction population revenue recovery',
#  'meter distancing sop',
#  'use couid vaccination',
#  'contribution count organisation couid help vaccination',
#  'chance effect need doctor life world',
#  'parent week vaccination',
#  'story',
#  'couid today lot thank',
#  'shield mood fight couid vaccination',
#  'couid vaccination center staff people vaccination staff',
#  'couid call office hospitality amp team boss',
#  'couid vaccination village achievement kudo panchayat villain amp desire celebrate event life',
#  'rush decrease hospital masse team',
#  'dose vaccination symptom bull',
#  'arrangement couid vaccination view school arrangement',
#  '',
#  'today couid vaccination part world',
#  'worker couid vaccination today environment humanity politician',
#  'today couid vaccination part world vaccine distribution world',
#  'government health leader government enemy',
#  'wave importance mask vaccination couid',
#  'vaccination bagging help month slot',
#  'vaccination',
#  'drive constituency police staff couid guideline',
#  'victory other movement',
#  'job government couid case vaccination',
#  'condition phase couid centre sister staff information min queue mob guider',
#  'case roper report look roper check infection vaccination',
#  'job vaccination program amp crew shot motivation',
#  'couid vaccine vaccination vaccine weapon couid virus awareness vaccination wearamask other',
#  'candidate vaccination ply vaccination prevention couid',
#  'child childhood vaccination nutrition loss parent loss amp death life amp livelihood',
#  'escape datum entry vaccination vaccination',
#  'person couid vaccine vaccination',
#  'couid vaccination certificate month status advance',
#  'vaccination certificate day',
#  'example malign couid vaccination plan official derail scapegoat railway reform indeginisation technology world class station',
#  'order amp vaccine freedom amp choice',
#  'support meat awareness couid amp vaccination day people village vaccination',
#  'journalist purpose vaccination vaccine amp leprosy standard couid vaccine',
#  'strategy tourism sandbox couid hotspot vaccination communication',
#  'greeting talk ape care loved_one vaccination vaccine effort virus couid',
#  'today part couid effort prayer protector',
#  'person vaccination rate dog couid cat amp fun symptom couid sense',
#  'fever couid dawn morning ghost dose vaccination care matter',
#  'thought celebrity pic vaccination stress importance couid vaccine celebrity million',
#  'couid vaccine percentage people couid vaccination virus other distance hand',
#  'name couid vaccination',
#  'man goodbye vaccination',
#  'request process vaccination centre infection scout',
#  'afternoon friend couid vaccination family_member',
#  'production couid vaccination badge card difference waste',
#  'couid warning follow sop school school nursery class vaccination twentynine virus',
#  'couid youngroyal',
#  'opportunity video couid vaccination',
#  'behavior serampore image mati government staff face system',
#  'vaccination safety thing submit amp couid protocol recommendation',
#  'tomorrow vaccination protect couid atleast milder disease',
#  'doubt family couid family',
#  'hour queue appointment one couid management',
#  'respect pick truck refrigerator truck power home vaccination charge day',
#  'coronaindia momma',
#  'girl couid vaccination lifeinlockdown',
#  'program minute service',
#  'couid registration charge center receipt hand staff rude',
#  'amp reason vaccine step fight couid case issue doctor',
#  'sight syringe covidvaccine',
#  'other vaccination couid',
#  'plan couid vaccination request action',
#  'colleague today vaccination kami cellar medium duty fight',
#  'choice self preservation evidence save lead',
#  'system kiss time ncos',
#  'people shot worker vaccination appointment',
#  'program vaccine subscribe idea couid modi',
#  '',
#  'couid vaccination certificate digilocker action thank',
#  'social_distance center line video',
#  'couid vaccination vaccine approval guideline barrier movement person seamless business',
#  'help patient symptom day fever side_effect butcher principle',
#  'drive system crowding vaccination center',
#  'look hospital slot vaccination',
#  'virus progress vaccination staysail igotmyshot',
#  'couid strategy mode one vaccination minus',
#  'couid vaccination campaign info thimphu other happiness house',
#  'today village effort',
#  'today registration end butter job',
#  'condition condition couid shame system couid couid spreader welcome drive couid third_wave',
#  'medicine syringe',
#  'thank couid vaccine vaccination program completing',
#  'dose jump star thank herdimmunity',
#  'health secretary flu bit vaccination need move couid machine',
#  'team couid vaccination center hospital dose request area income',
#  'student link passport couid certificate vaccination sort functionality',
#  'part embassy staff citizen amount delta infection today vaccination couid think onshoreaussie strandedaussie',
#  'covisheld thank',
#  'crore covidvaccine world progress fight couid vaccination visit',
#  'country term management vaccination rate test',
#  'word partnership community',
#  'office mam error couid vaccination office doc sir schedule day',
#  'mask hand time time vaccination key couid',
#  'student citizen health people shield vaccination today sir student college',
#  'praise world couid center',
#  'sense covidiot rollout vaccination self restraint amp adherence couid hour severity',
#  'congratulation vaccination wastage vaccine',
#  'effort relief part team amp show',
#  'couid vaccination world momentum immunity year',
#  'district bihar sister awareness couid',
#  'message apology notice today centre vaccination protesting ink',
#  'schedule couid vaccination stock help maximum',
#  'hour midday tomorrow',
#  'yesterday people couid vaccination inorder curb well vaccination shortage supply thing',
#  'year way vaccination centre couid vaccine country',
#  'response',
#  'vaccine vaccination management system rat test registration vaccination management system',
#  'vaccination driver sport person traveler couid arrangement people',
#  'vacation couid vaccination wave',
#  'vaccine supporter',
#  'sop certificate mask',
#  'amp vaccination',
#  'rumor vaccination start bring expert fact evening',
#  'couid vaccination action leg vaccine thing',
#  'appeal request prison jail meet family couid lockdown year family vaccination',
#  'appeal request prison jail couid lockdown family family vaccination',
#  'country fight couid state virus test amp amp ofcourse endorsement',
#  'vaccination',
#  'couid coalition health center condition symptom people',
#  'couid kolkata symptom people center coalition vaccination condition country amp family',
#  'vaccination number scam vaccination scam',
#  'question leader disaster fund disaster',
#  'week day maharashtrian couid ord phase twentynine raise lockdown',
#  'vaccination vaccination sir place patient difficulty',
#  'number people vaccination one couid test time lab money citizen test',
#  'protection vaccination couid people vaccination couid',
#  'healthminister panel situation panel appointment queue',
#  'protocol condition government center couid protocol',
#  'centre impediment couid lending support',
#  'alert rest vit couid bit vit',
#  'parent child school completion couid vaccination',
#  'today protection couid vaccine countryman cost',
#  'pain separation house mask corona family earmark',
#  'covidindia',
#  'page week twist amp conclusion weekend amp register couid vaccination victory amp defeat',
#  'behalf bihar hospital',
#  'turn couid vaccination today power teleportation firework hand seconddose',
#  'vaccination enemy friend fight enemy couid virus variant',
#  'swab center vaccination dengan trigger anxiety staff staff',
#  'grandaughter child couid mask vaccine vaccination business school hospital mandate people',
#  'vaccination couid behaviour',
#  'couid vaccination ship sir company sir',
#  'opinion job moratorium protection relief business couid nation vaccination drive government',
#  'pta',
#  'resident effort vaccination arrangement applause',
#  'racing people sop regulation day case manav racing support vaccination time',
#  'couid vaccination implement',
#  'vaccine vaccine state authority announcement vaccine promise',
#  'corona couid coronavaccine covidantibodie',
#  'couid guideline people yesterday night dear lookup registration suffering type problem',
#  'couid vaccination center',
#  'vaccination attend activity life request vaccination fight',
#  'staff student oversea study parent consent thank',
#  'method',
#  'lambdavariant microbe human mass way mutation',
#  'death world vaccination',
#  'mother vaccination vaccination couid',
#  'civilization world family pandemic people truth philosophy technology platform couid vaccination platform call coin source',
#  '',
#  'trace vaccinate area prioritise vaccination community couid',
#  'election campaign response vaccination program sacrifice space certificate',
#  'thank vaccination couid vaccination thank vaccination blood clotting complication care skill care avoid couid vaccine blood vessel',
#  '',
#  'safety citizen vaccination couid protocol vaccination centre hope action issue location grain market',
#  'survival business couid vaccination pha',
#  'couid breakthrough',
#  'couid need vaccination',
#  'experience digi vaccination center people people queue token people couid protocol shame managing team',
#  'program morning centre vaccine teacher people come centre day couid',
#  'other couid',
#  'month lock lock home solution couid vaccination vaccination need camp company syedsaddiq',
#  'activity service role mass awareness couid vaccination',
#  'time duty disaster order achievement worker amp industry vaccination drive organizer',
#  'couid covidvaccine',
#  'tweet show vaccination couid',
#  'vaccination center people couid protocol protocol team lot rush gathering people protocol',
#  'spread word comment share',
#  'purpose radar verification vaccination daughter radar number',
#  'people vaccination amp boost immunity volunteer arrangement vaccination camp teaching vaccination',
#  'pain fatigue process vaccination',
#  'doctor epidemic urge couid',
#  'importance doctor dignity beacon time doctorslife',
#  'vaccine streaming today rest twitchstreamer visit channel amp support share link stay_safe care twitch couid',
#  'comparison immunity infection vaccination virus vaccine vaccineswork vaccinesforall',
#  'marketing couid vaccination politic couid vaccination paid_slot slot vaccination corruption',
#  'subsidy electricity education healthcare hum vaccination care donate badman',
#  'team encouragement word',
#  'people certificate bit difference',
#  'people certificate bit difference',
#  'figure people vaccination circulation social_media',
#  'sense initiate arrange vaccination drive',
#  'vaccine tugboat health team goa effort vaccination couid vaccine today amp effort',
#  'inoculation vaccination couid',
#  'couid smile vaccination campaign woman selling clothe street',
#  'safety responsibility vaccination program protect combat couid',
#  'quarantine day',
#  'reality vaccination centre center people virus vaccination drive failure',
#  'vaccination centre thank team',
#  'complacency enemy couid sop distance amp earmark vaccination',
#  'couid vaccine today thank minister service time centre work vaccination',
#  'world people person nonsense doctor couid patient antibody vaccination',
#  'family relative mask couid vaccine support center government guideline country',
#  'day violation couid vaccination center video tagore',
#  'pakistani couid vaccination difficulty labor action address issue',
#  'state couid vaccination center step intention vaccination',
#  'sleep sleep feeling vaccine couid sleep drive direction',
#  'sane hog parselity',
#  'couid vaccination win couid situation sanitation hand',
#  'syringe virus couid',
#  'day place administration country election name location programme baruch gujaratis',
#  'government couid guideline vaccination program request facility problem style',
#  'staff member lot control couid sensitization couid precaution measure facilitation vaccination support activity',
#  'bac thing show day vaccination solution wave couid mutant variant immunity mitigation suffering advantage miss',
#  'chain couid transmission self behavior answer contain strain corona vaccination people couid behavior couid surge',
#  'couid vaccination programme',
#  'session chance thing vaccination',
#  'type vaccine half vaccine infection vaccination',
#  'society housemaid staff amp guard couid noid arrange staff',
#  'body health duty mind',
#  'video syringe man officer vaccination duty explanation action',
#  'guideline mind post couid vaccination vaccinate fight pandemic inthistogether',
#  'couid drive',
#  'vaccination process couid norm manner',
#  'couid worker vaccination thank response',
#  'couid factor city frustration vaccination rollout opening australia',
#  'people vaccination couid vaccination telangana citizen',
#  'employee couid vaccination drive employee hyundaicare',
#  'time vaccination news_channel content',
#  'part day fight couid pandemic vaccination',
#  'couid vaccination call support time result',
#  'page ad hindustan_time today couid',
#  'way spread couid urge vaccine insurance pandemic visit detail insurance pandemic couid',
#  'venting couid folk vaccination jabbed peace mind roll process',
#  'leadership protection couid daughter name share',
#  'bhangamandir village barcholla consistency people distance vaccination',
#  'death rate moment vaccination rate country help',
#  'interest couid vaccination registration sum appointment patience understanding',
#  'health lecture group employee mass drive premise convincing fan fraud',
#  'program vaccine staff training number sense',
#  'slot thank lot drive angel passport appointment job minute',
#  'vaccine people recovery post vaccination',
#  'couid virus world wave individual protection amp precaution virus hand wash use hand sanitizer feet',
#  'district conduct health check up conversation couid vaccination awareness medicine charge professional',
#  'child vaccine side',
#  'people vaccination urge atom couid patient day day',
#  'music precaution shame sword report vaccination',
#  'journalist couid vaccination drive start decade trial amp error month walk_in worker nurse',
#  'respect curb spread virus solution virus mutation vaccination people couid precaution amp work',
#  'work',
#  'lot couid vaccine atleast shade seat location hour vaccination situation college',
#  'vaccination vaccine medication mutation couid delay vaccination population mutation herdimmunity',
#  'couid measure vaccination school',
#  'step front shop norm',
#  'vaccination couid awareness government work amp respect achievement achievement waste photopolitic',
#  'drive record other county country',
#  'warrior vaccination drive',
#  'couid vaccination government duty couid vaccine',
#  'vaccination vaccination',
#  'vaccination length queue health official vaccination center spot',
#  '',
#  'pace speed supply problem vaccine great_job vaccine',
#  'vaccination ration booking thing help thing era',
#  'condition tahsildar step avoid condition amp conduct vaccination management',
#  'respect place world shehnaazgill comment cryptocurrency covidvaccine',
#  'thank fraternity doctor couid day vaccination safety efficacy',
#  'vaccination number today momentum deal vaccineforall',
#  'manta_biwa chief_minister assay day night vaccination people couid',
#  'reason couid precaution precaution time',
#  'thank lakh couid',
#  'today vaccine virus seconddose',
#  'fear thank solution speed',
#  'flop today apollo info',
#  'vaccine coronavaccine',
#  'case tool battle couid priority help',
#  'vaccination vaccination fight',
#  'couid vaccinesyringe vaccination fight care bouquet',
#  'couid vaccination amp life citizen country',
#  'couid vaccination vaccination nation',
#  'registration slot time rush couid rule bihar vaccination',
#  'couid vaccination vaccination nation situation control follow instruction',
#  'vaccine side_effect secretary',
#  'couid vaccination',
#  'arrangement mission mode',
#  'stay_safe establishment certificate shop',
#  '',
#  'ad use fact ad vaccination',
#  'thank member field team battle couid party',
#  'doubt city gain gaye',
#  'country turn vaccine favouritism hat vaccineforall',
#  'antibody staff people vaccination centre covishield',
#  'guard vaccination handhygine',
#  'goa vaccine government health officer foreigner',
#  'min service couid mass',
#  'proposal kind consideration growth advantage benefit individual certificate regard',
#  'coronavaccine pain define',
#  'today salute job problem seating arrangement vaccination norm thank doctor staff',
#  'arrangement minute',
#  'arrangement facility staff instruction amp couid vaccination centre',
#  'message prediction round vaccination protocol markup',
#  'staff vaccination coronavirus',
#  'whatsapp grip vaccination paper radio news couid',
#  'vaccination people official centre',
#  'assure hint tinder',
#  'spoon vaccination individual',
#  'nce bogdan',
#  'gotthedose nce bogdan',
#  'couid case vaccination investment',
#  'dosage vaccinate prevention covidshield prevention',
#  'ratio sehr ratio forehead mask',
#  'citizenship guideline opposer',
#  'book vaccine slot family book slot people day help detail',
#  'couid vaccination express couid pandemic',
#  'amp temperature check vaccination bangalore hospital vaccination',
#  'office day wtcfinal dehradun',
#  'couid vaccination pratapgarh loved_one',
#  'vaccine arrangement ncos concern authority opportunity vaccination',
#  'volunteer stone safeguard villager amp support vaccination volunteer dozen village',
#  'crowding wave',
#  '',
#  'vaccination today thank thing',
#  'couid vaccination staff vaccine',
#  'home',
#  'country order vaccine vaccination solution couid nineteen confidence scientist place contain couid country',
#  'news way news couid stage vaccination herd_immunity expression trust latter',
#  'crowding outing villa pal truth responsibility',
#  'vaccination',
#  'team love work',
#  'covidsheild',
#  'school distribution ration amp couid vaccination thank team support help coordinator',
#  'gratitude appreciation work vaccine drive',
#  'vaccination team video reaction home service',
#  'dose rumour country',
#  '',
#  'vaccination drive',
#  'today amp other',
#  'couid testing amp lunch member hand amp team doctor advice amp dismiss fear',
#  'money royal palace vaccination statement transaction',
#  'information masse injection treatment postvaccination',
#  'vaccine need hour fight corona myth fear vaccine darbhangadiarie',
#  'shiba coin address',
#  'line people awareness science hesitation vaccine fight',
#  'action businessman',
#  'oil price brent price end price oil demand couid vaccination activity',
#  'conspiracy theory covidvaccine',
#  'life organism feeling calf serum centre',
#  'couid grandparent granpa vaccination thing question month vaccination',
#  'vaccination follow couid safety safety family',
#  'picture pap campus vaccination seriousness system people corona',
#  'life nation vaccinateindia',
#  'couid vaccination',
#  'today step thank vaccination process',
#  'year mission safe wage',
#  'thousand people fool rumor way',
#  'positivity vaccination drive couid wave',
#  'vaccine',
#  'recession institutes student lion majority country control pandemic',
#  'year type solution couid vaccination niece solution couid vaccination child limitless',
#  'kudo process vaccination',
#  'today couid virus',
#  'vaccination experience people vaccination couid protection kit distribution work utter_grade thank',
#  'centre',
#  'room body cleanliness',
#  'pandemic prevention plan amp awareness',
#  'today radio program guest speaker couid patient hospital vaccination awareness various_aspect station website',
#  'couple week couid vaccination facility park minute service',
#  'reason couid vaccine help couid vaccine vaccine part organism body',
#  'vaccination couid warrior worker people job couid pandemic thank',
#  'firm answer cure vaccination prevention vaccination thing stage trial test mode humankind guineapig',
#  'today precaution time virus vaccination shield couid urge awareness couid vaccine',
#  'people village scanner presence couid disease vaccination amp mask',
#  'couid vaccine couid world mood couid vaccine fight couid vaccination amp awareness programme amp couid',
#  'couid country distance thank team drive',
#  'couid vaccination bosco school panic community centre dear vaccineforall',
#  'scenario nepal',
#  'couid vaccination centre request people tourist area day tourism',
#  'couid vaccination today vaccination process pioneer office police line department',
#  'couid part effort couid livre technology vaccination employee dependent phase kid trivandrum',
#  'part duty couid vaccination couid case visit duty icu duty risk allowance warrior',
#  'vaccination process hospitality staff covishield',
#  'care attention syringe couid',
#  'couid action',
#  'couid vaccine today syringe vaccination amrutafadnavis socialactivist',
#  'time week drive speed insensitivity world reaction',
#  'respect asano hospital couid vaccination people discrimination vaccination',
#  'question vaccination couid ask',
#  'amp experience vaccination thank arrangement amp vaccination procedure couid',
#  'panchsheel couid vaccination panchsheel guideline people managing',
#  'thank health depth amp couid vaccination facility angel stadium cab amp',
#  'today couid mask management process',
#  'vaccination center couid distribution center',
#  'couid vaccine vaccination virus vaccine vaccinationdone',
#  'credit government couid vaccination drive',
#  'seeing vaccination village valley plantation amp couid vaccination time state service amp community participation',
#  'son year wife son child dew head prime_minister child year age',
#  'interaction mo district awareness couid vaccination mass vaccination way couid death',
#  'today covishild amp experience vaccination thank arrangement amp vaccination procedure couid',
#  'community today part vaccination process community couid',
#  'vaccination drive drive possibility couid infection business space drive',
#  'holiness grace bihar panna couid vaccination efficacy people holiness kind regard',
#  'result people care vaccination distribution',
#  'decision couid vaccination mayawati',
#  'people cause option vaccination amp adherence',
#  'couid vaccination slot',
#  'mask bow couid third_wave',
#  'couid pandemic facemask vaccination superstition staysail',
#  'vaccination centre test people number problem',
#  'race',
#  'mask people harbour awareness couid importance vaccination',
#  '',
#  'model team mask vaccination drive team action',
#  'covishield vaccination amp fight couid',
#  'pay salary announce vaccination relief work couid relief drive announce employee scheme',
#  'part couid convey masse amp vaccination hesitancy virus join campaign vaccine hesitancy',
#  'role comunity health worker village doctor people baby vaccination malnutrition couid work sum problem hand',
#  'couid opposition leader effort vaccineforall vaccinateindia',
#  'point inject document talk allow photo body injection point appointment needle symptom officer',
#  'failure thing management responsibility modi responsibility vaccination work people',
#  'couid vaccination conform vaccine reference number',
#  'battle thank uncertainty vaccination',
#  'couid situation vaccination duty stategovts caution relaxation rule pandemic citizen advisory norm rope body mutation',
#  'policy vaccination couid responsibility issue leader problem work leader',
#  '',
#  'arrangement couid village dist block',
#  'sindhgovt vaccination',
#  'vaccination today announcement battle couid doctor victory job politician',
#  'protocol fight couid vaccination vaccine',
#  'vision couid vaccination procedure person state politic',
#  'effort eradication amp vaccination',
#  'bit fight couid vaccination camp turn safety takeprecaution',
#  'vaccine law citizen vaccine family member arrange',
#  ...]

# %%
positive_df['new_text_noun'] = new_text_noun
# Out:
# /var/folders/lg/w8d05wzd48q3m5_s46qt2fxc0000gn/T/ipykernel_86643/1604708766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   positive_df['new_text_noun'] = new_text_noun

# %%
texts = positive_df['new_text_noun']

# %%
texts
# Out:
# 1                                     hair ply vaccination
# 2                   death couid vaccination rate harm harm
# 3                         necessity today scenario problem
# 5        way thing millennium peril couid job vaccinati...
# 6        symptom vaccination example country number dea...
#                                ...
# 37618                    nature generation life strengthen
# 37619                                 world kindnessmatter
# 37620                             request state govt share
# 37621                          thank appreciation feedback
# 37622        dose covidvaccine amp amp follow vaccine folk
# Name: new_text_noun, Length: 17594, dtype: object

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

high_freq_known_words = ['covid','couid', 'pfizer', 'amp', 'people', 'covidvaccine', 'covishield', 'moderna', 'vaccine', 'astrazeneca', 'vaccinate', 'vaccinated', 'vaccination', 'vaccines']

stop_words.extend(high_freq_known_words)

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=4, M=20, alpha=50/4, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [00:12<00:00, 49.60it/s]

# %%
stable_topics = [0, 1, 2, 3]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#         topic0      topic1   topic2    topic3
# 0      student     country     mask     thank
# 1       school         day   family     today
# 2        child        time    virus      dose
# 3      country       world      day     staff
# 4   government  population     time    center
# 5        staff  government     dose       day
# 6         life        year    today      time
# 7         time        case     home    family
# 8        state       state   friend  hospital
# 9        price       virus   corona      team
# 10        year     citizen  symptom      help
# 11      health        work     case     drive

# %% [markdown]
# ## 5 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=5, M=20, alpha=50/5, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [00:11<00:00, 53.44it/s]

# %%
stable_topics = [0, 1, 2, 3, 4]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#         topic0      topic1    topic2      topic3    topic4
# 0      student     country     virus     country     today
# 1       school       world      mask       state     thank
# 2          day       thank       day        time      dose
# 3        child       today      time         day     staff
# 4       travel        time      dose  government    center
# 5         time      health      case       world       day
# 6         home         day    family        help      time
# 7       family        year   symptom  population    family
# 8      country  government    corona       price  hospital
# 9   quarantine        work     today        govt      team
# 10        test     citizen      hand  production      slot
# 11       staff      family  distance      nation      help

# %% [markdown]
# ## 6 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=6, M=20, alpha=50/6, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [00:10<00:00, 57.41it/s]

# %%
stable_topics = [0, 1, 2, 3, 4, 5]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#        topic0      topic1    topic2    topic3       topic4      topic5
# 0         day     country     virus     today       number     student
# 1   injection       world      mask     thank          day       staff
# 2     symptom        time      time      dose         time         day
# 3        time  government      case     staff         post      school
# 4      friend         day       day    center         love        time
# 5      family       state    family       day         news     country
# 6       fever      nation      dose      time  certificate      travel
# 7        pain  population    corona    family        thing        test
# 8      needle      health      hand  hospital         team  government
# 9        year     citizen  distance      team        radar        home
# 10       love        work     today     drive      support       child
# 11      today        year      year       job        share        help

# %% [markdown]
# ## 7 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=7, M=20, alpha=50/7, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [00:14<00:00, 41.55it/s]

# %%
stable_topics = [0, 1, 2, 3, 4, 5, 6]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0      topic1      topic2     topic3    topic4    topic5  \
# 0   student     country         day        day      mask     thank
# 1    school       world        time     family     virus     today
# 2     child        time        case       love    corona      dose
# 3       kid  government        dose       time     today     staff
# 4      year       state       virus     friend    family    center
# 5      life      nation     country  injection      hand       day
# 6      home      health        year      today  distance      time
# 7      exam       thank      number    symptom      time    family
# 8      time     citizen  population       hour      dose  hospital
# 9    family        work      person     needle    safety      slot
# 10   parent         day        week       pain     fight      team
# 11  teacher        help       death      fever    follow      help
#
#          topic6
# 0           day
# 1        travel
# 2         staff
# 3          time
# 4    quarantine
# 5       country
# 6          test
# 7          case
# 8        person
# 9          home
# 10     traveler
# 11  certificate

# %% [markdown]
# ## 8 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=8, M=20, alpha=50/8, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|██████████| 600/600 [00:14<00:00, 42.65it/s]

# %%
stable_topics = [0, 1, 2, 3, 4, 5, 6, 7]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0      topic1      topic2     topic3      topic4      topic5  \
# 0   student       price     country        day       today        mask
# 1     child  government       world    symptom       thank       virus
# 2    school     company        time       case        dose      corona
# 3      year       state         day       dose      family    distance
# 4       kid  production      health       time         day        hand
# 5      life        life  government       week        time        time
# 6      exam        cost  population  injection      friend      follow
# 7    parent     country      nation      death        team      safety
# 8   teacher       world       thank     person       staff      family
# 9      time       money     citizen    patient      parent        dose
# 10    month        help        year   immunity     process        home
# 11   family      profit        work      virus  experience  precaution
#
#          topic6      topic7
# 0         staff         day
# 1        center      travel
# 2      hospital  quarantine
# 3          help     country
# 4          time        time
# 5           day        test
# 6          dose        home
# 7         thank      family
# 8   certificate    traveler
# 9    government        case
# 10          sir     citizen
# 11        today        team
