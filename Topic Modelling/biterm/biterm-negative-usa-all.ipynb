# %%
#for windows users:
#pip install bitermplus

#for mac users:
#xcode-select --install
#brew install libomp
#pip3 install bitermplus

# pip install tmplot
# pip install tomotopy

# %%
# pip install -U scikit-learn

# %%
import bitermplus as btm
import numpy as np
import pandas as pd

# %%
# Importing data
df = pd.read_csv(
    '../pos_neg_usa.csv')

# %%
df
# Out:
#         Unnamed: 0   index                                               Text  \
# 0                0       0  want find way end racism try force people inje...
# 1                1       1  this child almost died tetanus, spent months h...
# 2                2       2  juste se rappeler m. leblanc la pression que l...
# 3                3       3  you would expect cases rise significantly, cou...
# 4                4       4  depends whether vaccination status is embedded...
# ...            ...     ...                                                ...
# 315598      404255  404255  pretty remarkable achievement. thank you all v...
# 315599      404258  404258  oh that explains similar - seemingly out nowhe...
# 315600      404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 315601      404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 315602      404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 315598  pretty remarkable achievement. thank you all v...   ENGLISH
# 315599  oh that explains similar - seemingly out nowhe...   ENGLISH
# 315600  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 315601  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 315602  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 315598  pretty remarkable achievement. thank you all v...
# 315599  oh that explains similar - seemingly out nowhe...
# 315600  do it others.... flexed_bicepsparty_poppersyri...
# 315601  yay raising_handslight_skin_tone congrats dr. ...
# 315602  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 315598  [('pretty', 'RB'), ('remarkable', 'JJ'), ('ach...
# 315599  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
# 315600  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 315601  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 315602  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explains', 'similar', 'seemingly', 'nowhere'...
# 315600                    ['others', 'vaccinesaveslives']
# 315601  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 315598  ['pretty', 'remarkable', 'achievement', 'thank...
# 315599  ['explain', 'similar', 'seemingly', 'nowhere',...
# 315600                      ['other', 'vaccinesaveslive']
# 315601  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 315602  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 315598  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 315599  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 315600                      ['other', 'vaccinesaveslive']  subjective
# 315601  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 315602  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 315598          2
# 315599          0
# 315600          2
# 315601          2
# 315602          2
#
# [315603 rows x 12 columns]

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df = df[df['sentiment']==0]

# %%
df.head()
# Out:
#     index                                               Text  \
# 1       1  this child almost died tetanus, spent months h...
# 2       2  juste se rappeler m. leblanc la pression que l...
# 9       9  does it hurt your head actually use your brain...
# 10     10  world-wide mass vaccination leading world-wide...
# 19     22  oh i see. so what your saying is that alberta ...
#
#                                              new_text languages  \
# 1   this child almost died tetanus, spent months h...   ENGLISH
# 2   juste se rappeler m. leblanc la pression que l...    FRENCH
# 9   does it hurt your head actually use your brain...   ENGLISH
# 10  world-wide mass vaccination leading world-wide...   ENGLISH
# 19  oh i see. so what your saying is that alberta ...   ENGLISH
#
#                            new_text_after_translation  \
# 1   this child almost died tetanus, spent months h...
# 2   just remember mr. leblanc the pressure that th...
# 9   does it hurt your head actually use your brain...
# 10  world-wide mass vaccination leading world-wide...
# 19  oh i see. so what your saying is that alberta ...
#
#                                      pos_tagged_words  \
# 1   [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2   [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 9   [('does', 'VBZ'), ('it', 'PRP'), ('hurt', 'VB'...
# 10  [('world', 'NN'), ('wide', 'JJ'), ('mass', 'NN...
# 19  [('oh', 'NN'), ('i', 'NN'), ('see', 'VBP'), ('...
#
#                                   words_processed_all  \
# 1   ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2   ['remember', 'leblanc', 'pressure', 'provincia...
# 9   ['hurt', 'head', 'actually', 'use', 'brain', '...
# 10  ['world', 'wide', 'mass', 'vaccination', 'lead...
# 19  ['see', 'saying', 'alberta', 'business', 'requ...
#
#                     words_processed_noun_adj_verb_adv  \
# 1   ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2   ['remember', 'leblanc', 'pressure', 'provincia...
# 9   ['head', 'actually', 'use', 'brain', 'seem', '...
# 10  ['wide', 'mass', 'vaccination', 'lead', 'world...
# 19  ['say', 'business', 'require', 'proof', 'vacci...
#
#                                  words_processed_noun   text_type  sentiment
# 1   ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective          0
# 2   ['leblanc', 'pressure', 'business', 'world', '...  subjective          0
# 9   ['head', 'brain', 'place', 'vaccination', 'rat...  subjective          0
# 10  ['vaccination', 'world', 'passport', 'goal', '...  subjective          0
# 19  ['business', 'proof', 'vaccination', 'governme...  subjective          0

# %%
df.reset_index(inplace=True)

# %%
df.drop(['index'], axis=1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#        level_0                                               Text  \
# 0            1  this child almost died tetanus, spent months h...
# 1            2  juste se rappeler m. leblanc la pression que l...
# 2            9  does it hurt your head actually use your brain...
# 3           10  world-wide mass vaccination leading world-wide...
# 4           19  oh i see. so what your saying is that alberta ...
# ...        ...                                                ...
# 92818   315583    half my friends sick af. all vaccinated. sheesh
# 92819   315584  merry christmas 🎄 i hope things improve both m...
# 92820   315587  no me refería este positivo 😅😅#positivo #covid...
# 92821   315592  acute #stroke #covid pneumonia #novax #coronav...
# 92822   315599  oh that explains similar - seemingly out nowhe...
#
#                                                 new_text languages  \
# 0      this child almost died tetanus, spent months h...   ENGLISH
# 1      juste se rappeler m. leblanc la pression que l...    FRENCH
# 2      does it hurt your head actually use your brain...   ENGLISH
# 3      world-wide mass vaccination leading world-wide...   ENGLISH
# 4      oh i see. so what your saying is that alberta ...   ENGLISH
# ...                                                  ...       ...
# 92818    half my friends sick af. all vaccinated. sheesh   ENGLISH
# 92819  merry christmas Christmas_tree i hope things i...   ENGLISH
# 92820  no me refería este positivo grinning_face_with...   Unknown
# 92821  acute #stroke #covid pneumonia #novax #coronav...   ENGLISH
# 92822  oh that explains similar - seemingly out nowhe...   ENGLISH
#
#                               new_text_after_translation  \
# 0      this child almost died tetanus, spent months h...
# 1      just remember mr. leblanc the pressure that th...
# 2      does it hurt your head actually use your brain...
# 3      world-wide mass vaccination leading world-wide...
# 4      oh i see. so what your saying is that alberta ...
# ...                                                  ...
# 92818    half my friends sick af. all vaccinated. sheesh
# 92819  merry christmas Christmas_tree i hope things i...
# 92820  no me refería este positivo grinning_face_with...
# 92821  acute #stroke #covid pneumonia #novax #coronav...
# 92822  oh that explains similar - seemingly out nowhe...
#
#                                         pos_tagged_words  \
# 0      [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 1      [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 2      [('does', 'VBZ'), ('it', 'PRP'), ('hurt', 'VB'...
# 3      [('world', 'NN'), ('wide', 'JJ'), ('mass', 'NN...
# 4      [('oh', 'NN'), ('i', 'NN'), ('see', 'VBP'), ('...
# ...                                                  ...
# 92818  [('half', 'NN'), ('my', 'PRP$'), ('friends', '...
# 92819  [('merry', 'NN'), ('christmas', 'NN'), ('i', '...
# 92820  [('no', 'DT'), ('me', 'PRP'), ('refer', 'VBP')...
# 92821  [('acute', 'JJ'), ('stroke', 'VBD'), ('couid',...
# 92822  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
#
#                                      words_processed_all  \
# 0      ['child', 'almost', 'died', 'tetanus', 'spent'...
# 1      ['remember', 'leblanc', 'pressure', 'provincia...
# 2      ['hurt', 'head', 'actually', 'use', 'brain', '...
# 3      ['world', 'wide', 'mass', 'vaccination', 'lead...
# 4      ['see', 'saying', 'alberta', 'business', 'requ...
# ...                                                  ...
# 92818  ['half', 'friend', 'sick', 'vaccinated', 'shee...
# 92819  ['merry_christmas', 'hope', 'thing', 'improve'...
# 92820  ['refer', 'este', 'positive', 'positive', 'cov...
# 92821  ['acute', 'stroke', 'couid', 'pneumonia', 'nov...
# 92822  ['explains', 'similar', 'seemingly', 'nowhere'...
#
#                        words_processed_noun_adj_verb_adv  \
# 0      ['child', 'almost', 'die', 'tetanus', 'spend',...
# 1      ['remember', 'leblanc', 'pressure', 'provincia...
# 2      ['head', 'actually', 'use', 'brain', 'seem', '...
# 3      ['wide', 'mass', 'vaccination', 'lead', 'world...
# 4      ['say', 'business', 'require', 'proof', 'vacci...
# ...                                                  ...
# 92818  ['half', 'friend', 'sick', 'vaccinate', 'sheesh']
# 92819  ['hope', 'thing', 'improve', 'son', 'triple', ...
# 92820  ['refer', 'positive', 'positive', 'covidtestin...
# 92821  ['acute', 'vaccinate', 'vaccinesaveslive', 'va...
# 92822  ['explain', 'similar', 'seemingly', 'nowhere',...
#
#                                     words_processed_noun   text_type  \
# 0      ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 1      ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 2      ['head', 'brain', 'place', 'vaccination', 'rat...  subjective
# 3      ['vaccination', 'world', 'passport', 'goal', '...  subjective
# 4      ['business', 'proof', 'vaccination', 'governme...  subjective
# ...                                                  ...         ...
# 92818                                         ['friend']  subjective
# 92819  ['thing', 'son', 'friend', 'amp', 'daughter', ...  subjective
# 92820               ['covidtesting', 'vaccinesaveslive']  subjective
# 92821    ['vaccinesaveslive', 'vaccine', 'deltavariant']  subjective
# 92822  ['message', 'background', 'folk', 'vaccinesave...  subjective
#
#        sentiment
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 92818          0
# 92819          0
# 92820          0
# 92821          0
# 92822          0
#
# [92823 rows x 11 columns]

# %%
texts = df['words_processed_all']

# %%
texts
# Out:
# 0        ['child', 'almost', 'died', 'tetanus', 'spent'...
# 1        ['remember', 'leblanc', 'pressure', 'provincia...
# 2        ['hurt', 'head', 'actually', 'use', 'brain', '...
# 3        ['world', 'wide', 'mass', 'vaccination', 'lead...
# 4        ['see', 'saying', 'alberta', 'business', 'requ...
#                                ...
# 92818    ['half', 'friend', 'sick', 'vaccinated', 'shee...
# 92819    ['merry_christmas', 'hope', 'thing', 'improve'...
# 92820    ['refer', 'este', 'positive', 'positive', 'cov...
# 92821    ['acute', 'stroke', 'couid', 'pneumonia', 'nov...
# 92822    ['explains', 'similar', 'seemingly', 'nowhere'...
# Name: words_processed_all, Length: 92823, dtype: object

# %%
new_text_noun = []

for row in texts:
    new_row = row.strip("][").replace("'","").split(", ")
    new_row = " ".join(new_row)
    new_text_noun.append(new_row)

# %%
new_text_noun
# Out:
# ['child almost died tetanus spent month hospital cost around parent still refused vaccination pre pandemic',
#  'remember leblanc pressure provincial business world asked able open border air traffic provincial govt ac included block tourist not pas vaccination hotel restaurant',
#  'hurt head actually use brain seem incredibly brainwashed place highest vaccination rate world highest case_counts everyone disagrees compliance totalitarian dictatorship must called name',
#  'world wide mass vaccination leading world wide digital passport goal populationcontrol',
#  'see saying alberta business required ask proof vaccination rely alberta government rely province',
#  'jesus_christ vaccination not forced carry pregnancy term',
#  'reaction vaccine according cac anaphylaxis couid nineteen vaccination extremely_rare occurred five people per one million vaccinated united_states five vaccination',
#  'bad right body belongs not wear better fight fight compulsory vaccination required business employer government',
#  'conclusion definitely cannot draw mask mandate work since death rate much lower state probably primarily due higher vaccination rate',
#  'couid positive died amazed spun couid death push vaccination agenda',
#  'linked republican controlled state tend state without mask mandate far worse democratic controlled state course also state lower vaccination rate hard draw strong conclusion',
#  'close neighbor pig got one lowest couid vaccination rate world',
#  'conservative anti abortion anti vaccination people thought prayer forget prayer',
#  'classic simpson paradox death among elderly people nearly vaccinated lower vaccination rate total number fatality would much higher',
#  'case gone state highest vaccination rate january ate bullshit obvious fake news site spoon insulting intelligence',
#  'lot people speaking like pro choice abortion pro choice relating vaccine disagree abortion remove choice human ending human life forced coerced vaccination remove choice forcing human risk permanent_damage',
#  'tell vaccinated people died couid unfortunately not true vaccination indeed prevent dire result couid infection pretty well established',
#  'three eric_adams also repeatedly renewed key executive order requires anyone age five show proof full vaccination participate indoor_activities anyone eighteen older proof id along proof vaccination required',
#  'make sad also angry discouraged vaccination',
#  'stake applicant not forcible vaccination rather consequence one choice remain vaccinated',
#  'trading player injured claim injury report like firing non vaccinated claiming vaccination rate',
#  'really get vaccination lesson symptom immediate long_term still get unlikely serious cause long_term damage ifs keep',
#  'strange people claiming want u stop living fear causing lot fear mask vaccination ever caused u held_hostage',
#  'vaccination rate quite low twelve age_range thought needed benefit risk unmasked indoor instruction glad allows unmasked outdoor activity fab socal weather make easy get fresh air',
#  'tend let slide injure doc notice awhile since quit using horse serum good vaccination',
#  'got unease part pas adult make choice suffer consequence deal yet low vaccination rate five_eleven least twelve_seventeen fifty',
#  'especially vehicle towed u not allowed cross_border get wait u requires proof vaccination cross u',
#  'governor control lockdown started long biden biden opened thing vaccination program not sure tracking right trump spent far biden fed failed increase rate presidency',
#  'genuinely curious find clip quote trump telling base anyone anything remotely anti vaccine everything said seen extremely pro vaccination maybe source could cite',
#  'treatment not vaccine obviously not natural_immunity definition know original response said right know vaccination occurs prior illness not illness right',
#  'absolutely since live ohio county one lowest vaccination rate',
#  'mandatory mumps measles rubella vaccination fake outrage particular vaccine',
#  'ugh suck school marin mass vaccination day support dog pretty much every school_district twenty_minutes',
#  'im saying stopping vaccination ending inquiry arbitrary european_union allows titer negative test pas system',
#  'councilman vaccinated said people champ vaccination rate continuing lag district leader help return_normal especially given tweet deleted restaurant',
#  'saying memory_cells remember thing term thing like spike_proteins depends disease vaccination example hepatitis vaccine mainly based surface protein',
#  'hope ontario drop proof vaccination soon cause bring way much unnecessary conflict worker especially wanna change type vacation proof dime',
#  'tyrannical biden_administration want mandatory vaccination protestors canada crushed beneath grinding wheel federal authority',
#  'since couid hospitalization denmark also ticking upwards despite highest booster vaccination rate far europe please take look hospitalization chart world data',
#  'school age vaccination not going well one kid school right around wif wrong parent',
#  'besides fact even mandate canada mean entering country needed follow show proof vaccination negative_test quarantine point leave country without proof',
#  'ice hockey harlem supporting end key vaccination program elected house make sure become famous capitol hill voice matter godblessamerica nomad',
#  'last answer apparently not keeping vaccination stimulates robust gas containing vaccine spike_antigen eight week postvaccination case',
#  'meanwhile government using kid shield unneccessary vaccination face mask school',
#  'since ninety vaccination rate super majority people supporting federal government pandemic plan dummy refer conspiracy_theories get vaccinated',
#  'downplaying pre show vaccination misinformation show zero new nowspinning nowstreaming two hear subgenius radio end time joerogan antivaxxers full detail',
#  'not biden giving crack_pipes long show proof vaccination saw yesterday thought fake literal hell',
#  'stunning yet want treat another flu know zero plus american died last month last three year died flu complication want find rather done vaccination',
#  'talk khalistani issue open threat tiring katra jabbar kalsa etc police australian state mostly pro group democracy australia enforced vaccination kid even leave country',
#  'exception vaccination one worst ac since beginning death patient ambulance icing incompetence quickly sir investigation household imposed management unacceptable',
#  'since latest flip_flop rather sudden question two airline still requesting proof vaccination international destination still requiring proof vaccination',
#  'mitigation mean vaccination',
#  'feel like people pissed employer vaccination mandate thought politically dangerous',
#  'know see boy shower eighty vaccination rate lot science',
#  'nothing see comrade singh told u directly presser today political alignment vaccination issue explain everyday couid cabal real mybodymychoice fall deaf ear',
#  'thankyoukyrie standing firm vaccination belief driving james sixer three',
#  'thought people herpes infection many recurrence vaccination make possible connection cac estimated zero new genital herpes infection united_states single year',
#  'safer aspirin tylenol travel cross state border without showing vaccination card business want serve hire right comparison makes_sense',
#  'fact_checkers say cac changed_definition vaccination increase_transparency probably first time history definition changed reason gave cac right change meaning word',
#  'sure vaccinated never get couid never transmit people safer vaccinated tested negative within hour funny current vaccination policy science',
#  'totally disagree patrick propaganda exercise make recalcitrant feel guilty however vaccination rate quebec highest world not getting guilt ridden business',
#  'realize lift mask mandate next week vaccinated people allowed ask proof vaccination',
#  'united_states right protect border trucker paid dearly likely amp republican_party usa u saying one cross_border without vaccination like rule fuck care find really behind',
#  'regime spokespeople mom keep referring anti vaccination sentiment protest totally clueless trying create false narrative protest reflect anti mandate sentiment must know since ninety trucker vaccinated',
#  'vaccination record false get idea question importance vaccine like typhoid not one know even among called anti several',
#  'ontario superior court freeze fund raised givesendgo platform truckers_protesting vaccination',
#  'not anti_baxters trying keep safe untested high vaccine injury vaccination majority u yell staff member walk take business elsewhere stop assuming something chosen not understand',
#  'whaf anyone anywhere go onto twitter feed blame whatever want couid vaccination proof diagnosis fact exactly wrong many people believe anything long fit narrative',
#  'army leaf vaccination center quebec not busy',
#  'caricature misrepresent thing however accustomed u much finesse subtlety issue vaccination passport nothing vaccination political measure well',
#  'get couid spread couid nearly often get really sick die couid insurance_company valid reason categorize vaccination status else',
#  'maryland reported lowest couid infection rate country today mask work',
#  'quack outlier every profession not understanding need virologist understand tremendous benefit vaccination population statistic individual not understanding want',
#  'doctor outraged doctor honestly discussing sided effect etc saying would stop people vaccinating mostly doctor insisting kid need vaccination using language anti vaccination crusader',
#  'article state confirmed died_anaphylaxis due couid nineteen vaccination',
#  'study suggest vaccination might halve risk long couid effect brother long couid competitive amateur bicycle barely ride succumbing exhaustion',
#  'probably cheaper effective bribe people get vaccinated least u state lowest vaccination rate weirdly never heard suggest mandate discussion maybe read tweet closely enough mention',
#  'tendentious histrionics hearing along australian government bad actor armageddon argument whether able use trumped excuse avoid vaccination requirement',
#  'age bracket vaccination rate case rate graph continues fascinating',
#  'vaccination status not determine intelligence',
#  'vaccination center nurse retired special permit unfit work hospital not let see',
#  'proof vaccination proof felony',
#  'way miss point evidence show mass vaccination never eradicate couid',
#  'cac changing_definition vaccination eye',
#  'drop vaccine conspiracy violating person vaccination shot',
#  'respect medical evidence show mandatory vaccination case unjustifiable',
#  'end feb clock get dust early march check google sunday march thirteen end march',
#  'allowed say argument vaccination child vaccine passport mention think vaccination effort made short begin see nuance plus',
#  'look accurate couid case hospitalization rate plunging',
#  'not vaccination stop spreading stop getting couid protecting idea posted also bad lifestyle choice passed kid impact',
#  'not taking credit vaccine taking credit getting vaccination arm american remember',
#  'vaccination rate high ontario end game liberal',
#  'sorry reading last tweet time see understood death rate vaccination rate not much lower serbia vaccination rate fifty',
#  'appears la heath department recently changed mandate rule business require vaccination mandate not',
#  'pair high local vaccination rate amp low daily case hospitalization risk even vulnerable people low atm new variant emerges another outbreak mask otherwise tribal badge not backed science ie cac',
#  'fact check calling redefinition vaccination exact copy cac website misinformation due missing context ap include foil email show cac panic need redefine',
#  'issue concerned ego rather accuracy data name single virus animal reservoir ever eliminated vaccination provide source claim beyond say ism',
#  'said people discriminate vaccination status really hate fascist terrorist hate group posing freedom_fighter',
#  'not really anti van since holocaust_museum require proof vaccination think coincidental education holocaust canceled',
#  'end day vaccination going keep people hospital get head stop thinking budget vote wrong handling lost plot resign bothered tired go rest',
#  'chicken want see vaccination death rate political party',
#  'ear half ago podcast praising vaccination world renowned funny change people pov look',
#  'not compare vaccination rape fuck wrong',
#  'trucker_protests dumb crossing state international_borders absolutely required proof vaccination pandemic management',
#  'let get straight forced vaccination flu seven survival_rate wearing cloth_masks theater segregation hate social_credit system miss anything',
#  'willing_bet hiv vaccination passport not distant_future',
#  'national cynical network present vaccination misinformation show today put vaccine song root history insanity antivaxrs un released mask war joerogan subgenius radio detail',
#  'really think asking much look around world restriction lockdown mandate dropped everywhere highest vaccination rate trying squeeze blood stone look israel please',
#  'robert_malone higher number vaccination higher rate infection worrisome suggests aspect omicron may enhanced something associated vaccination share video make go',
#  'fair think particular case kyrie vaccination issue made harden disgruntled makes_sense would bother',
#  'flu number really high lower people taking flu vaccination seriously',
#  'vaccinated person leave country open accepting pre couid lot people never vaccination never fight like goal mandate vaccinate people not persecute',
#  'depends well proof vaccination checked managed',
#  'george canadian canada largest country world population million not exactly densely_populated country ninety vaccination rate yet continue maniac mandate amp lockdown liberal logic amp science',
#  'pandemic screwed plan ottawa liberal apostle charter right multiculturalism impose compulsory vaccination law order conservative support anti sanitary trucker blockade detriment economy',
#  'proof vaccination',
#  'not canadian canada largest country world population million not exactly densely_populated country ninety vaccination rate yet continue maniac mandate amp lockdown liberal logic amp science',
#  'also warned u great mistake done massive vaccination',
#  'similar subjected someone statistic myocarditis vaccination none ever bothered look statistic myocarditis couid significantly higher cognitive bias',
#  'even though vaccination program well underway u business face uncertain rocky path ahead mean business hesitant invest permanent recruitment',
#  'tremendous progress vaccination status high yet couid highest ever done shit virus stay nothing',
#  'point much outreach close vaccination gap committed work believe continuing effort offer multiple preventive strategy better reduce death disability many country done',
#  'vaccinated responsible hospitalization delta data death per vaccinated sixteen three vaccinated zero nine data boosted probably one omicron kill finding gap vaccine coverage vaccination key china olympics case reported beijing eight',
#  'not everyone israel jewish occupied territory far lower rate vaccination',
#  'victorian premier daniel_andrews said could different vaccination rule visitor state',
#  'people avoid vaccination lesswrong',
#  'guess spanish flu ended not one vaccination sadly respectfully death immune_system able fight personal hygiene proper health',
#  'habit mentally replacing word vaccinated baptized almost every contemporary discussion around vaccination makes_sense applying one weird trick credit',
#  'vaccination need achieved mandate go away wish u ninety still mandate would lot pissed people think protest quite mild given country claimed ninety vaccination status',
#  'continue post sourced fact myocarditis rate teenager dose two tired people trying wrongly frame sourced accurate information shared myocarditis not typical immune_response vaccination wrong',
#  'unfortunate thing far people need vaccinated misinformation not gonna happen united_states lowest vaccination rate wealthy nation misinformation handled beginning',
#  'congrats region five winner promoting pediatric primary prevention challenge competition helped increase pediatric well visit vaccination rate',
#  'phrase large majority attendee gotten jab academy requires employee get shot attendee nominated attended two award show leading ceremony require vaccination',
#  'well already legitimately tell new booster needed vaccination pas canceled sorry',
#  'going show proof vaccination go place even get id vote',
#  'vaccination immunization got trying keep',
#  'new definition anaphylaxis vaccination vaccination used mean render immunity mean stimulates_immune system watered goal post moving immunization amateur hack',
#  'liberal weaponizing vaccination attempt divide canadian refusal follow science root cause',
#  'kyrie still gon snap reporter ask vaccination status like matter',
#  'kind galaxy brain american mentality kept national vaccination rate toilet',
#  'governor_hocus reassess statewide protocol first week march based latest metric positive case hospital admission vaccination rate maskmandate asksavanity funny',
#  'anti mandate conservative successful anti vaccination campaign end result poor uneducated greatly harmed disease preventable elite vaccinated protected',
#  'know vaccination status mean client talk much',
#  'lie persuade general public not mask vaccination mandate driven either clueless liar chose',
#  'many death people natural_immunity virtually none people talking cac published study show natural_immunity prevents hospitalization_death better vaccination',
#  'going understand joel_lightbound compulsory vaccination',
#  'cincinnati hospital mum worker vaccination rate deadline nears u mandate via',
#  'lol yes vaccination requirement military service one get shot get not escape blood_clot stroke heart_attack get avoid getting killed war biden starting two country part world',
#  'know else changed percentage population immunity vaccination prior infection',
#  'lifted mask mandate state regardless vaccination status not even bout play coming vega sick',
#  'think instead knowing teacher vaccination status would like list medication mainly one want child masked forever',
#  'ignorant selfish hole blocking border amp causing good hard working people grief amp loss vehicle impounded fined jailed shunned decent society know mean poor want vaccination crowd',
#  'world series favorite team ousted national sport news cycle matter hour baron_rodgers vaccination status love baseball come',
#  'believe snowflake van still see past nose would wish harm people disagree vaccination thought liberal democrat stood body choice guess fit narrative',
#  'track infection rate not vaccination rate',
#  'considering amount tweet relating nba trade deadline kyrie_irving vaccination status think whomever told something',
#  'megarbane tank bottom doctor announced evening pajama non van risked death even omicron vaccination give immunity look mirror',
#  'protester think speaking country one highest vaccination rate earth canada trucker_protests couid nineteen vaccine mandate prompting_ford go auto_maker cut back production',
#  'nothing particular interest happened today mediafreeamerica minneapolis_paul end vaccination test order bar eatery via',
#  'government worker thirty year never required vaccination asked medical information',
#  'compulsively hoard every id ever issued print download twenty copy proof vaccination literally trapped forever eye',
#  'wrong proof vaccination everyone border trucker given exemption ended u canada put call trucker called terrorist currently occupying ottawa not trucker white_supremacist',
#  'couid nineteen vaccination recommended people pregnant_breastfeeding trying get pregnant might become pregnant future learn',
#  'propaganda right changed_definition vaccination increase_transparency say fact_checkers think think stupid',
#  'not vaccination mandate represent government taking life ultimately mean government control life get point',
#  'people still refusing vaccination',
#  'forgive ignorance circus involved last heard vaccination status',
#  'classic attempt tea shift blame taking child vaccination make sure clearly communicate child age help ensure correct formulation used unlike medicine pfizer vaccine dosage not vary according child weight',
#  'think true paris region france may still require proof vaccination',
#  'correction newton boston article sad vaccination rate suburban town yet everyone still afraid take mask child suffering following science',
#  'make sad see flag associated overseas well canada high vaccination rate not vast_majority u feel',
#  'precautionary approach since march went outdoor patio several occasion post vaccination wave however decision not go restaurant compelling doubt action informed data evidence amp caution',
#  'reduces variant not contrary mass vaccination specific spike_protein induces mutation',
#  'yesterday premier_moe said proof vaccination policy created two classes_citizens first time saskatchewan history four year ago day white jury acquitted gerald stanley killing molten bolshie premier wake justiceforcolten',
#  'look country single_payer health care system rather warped hybrid system vaccination rate prevention important trying blame socially responsible medicine',
#  'never said would create herd_immunity said would prevent collapse hospital system excess death area vaccination high proven true watch straw_man argument',
#  'excellent news saskatchewan business_owners customer business still require proof vaccination employee customer without fear legal_action spoil cannoli',
#  'given vaccination status indicator whether not couid incompetent dishonest joined conservative party teen left fool like reason said high hope disappointing',
#  'different alteration coming general population try cut number post vaccination heart_inflammation case via',
#  'two look like planned obsolescence deliberate shortening item functional life force people keep buying reached vaccination industry pharma industry make money pimping vaccine forcing government society',
#  'important say thread others establishes vaccination far strongest weapon couid pandemic not vaccinated real sense vaccinated people face major risk',
#  'bow think spike_proteins closed profuse state vaccination bad checkout live replicating virus covered spike breaking cell replicating hundreds_thousands time body',
#  'vaccination status started political litmus test turned test',
#  'thing government interfering medical field first forced vaccination segregation punishment comply government suppose work people country formed people not pawn',
#  'biggest load crap indoor mask wearing end feb fifteen vaccinated word even make sense vaccination not stop transmission fact',
#  'party claim govt overreach problem full bully mode morning telling municipality school university etc failing increase vaccination rate keeping hospital full unbelievable hypocrisy',
#  'wanted spend last twelve burger fry forgot vaccination card awful day',
#  'heard new_york mask mandate indoor arena lifted mean know law following path soon meaning kyrie amp vaccinated people allowed work without vaccination requirement eye',
#  'get past picture death rising vaccination campaign might even',
#  'also kind not true still transmit regardless vaccination status idea vaccination status idea vaccinated spreading mutating false',
#  'people avoid vaccination',
#  'extremely fascinating read insurer ofamerica adding premium load group life insurance employer based low vaccination area',
#  'get second vaccination shot said dying',
#  'call bullshit true end vaccination mandate',
#  'alabama last couid vaccination rate state fifty',
#  'yeah heard referred decoupling effect due easily omicron spread load people protected vaccination natural_immunity sheer size spread causing omicron find vulnerable people anyway',
#  'one option scientific created immune get sick recover vaccination get absolute immune stop strain rna virus canada trudeau essence different concept',
#  'ninety vaccinated steep increase death think anything wrong picture death rising vaccination',
#  'govt mask amp vaccination mandate not tyranny think may entitled snowflake snowflake snowflake karen truckerconvoy economic extortion terrorism increase inflationary supply_chain problem waste gas amp pollutes get silly value markup',
#  'nurse hilariously state vaccination requirement mask mandate healthier lower infection rate number lie decision punishes u healthcare_workers another amount year couid',
#  'missouri low vaccination rate low masking rate ensure keep high death rate',
#  'prior omicron increased rate vaccination paralleled increased infection rate behavioral effect limo guessing death know three middle aged people died within day vaccination non historical cardio event',
#  'showing wave vaccination disappears horizon abruptly spat shoved pier foot half crewed firetheucp',
#  'yes virus opportunity evolve every time person infected mask inhibit transmission probability infection thereby mitigating likelihood mutation vaccination effective method keeping population page',
#  'truth not vaccination',
#  'worry vaccination rate formally adopt bari wei couid position official state policy',
#  'vaccination',
#  'not talking individual level place high vaccination booster rate recent big wave fewer infection place meet either criterion ab wane reasonable expect cycle continue',
#  'hate headline partisan graph state line criterion persuasive state oldest population vermont maine lowest death rate couid mostly due high vaccination rate',
#  'know people come go mixed vaccination status spiked almost ask hospitalization across canada couple weeks_ago magical thinking work',
#  'vaccine far effective mask mandate evidence seems pretty clear hospital much overwhelmed death per much higher area lower vaccination rate mask mandate gonna put republican back charge',
#  'people looking bigger bigger especially since capacity vaccination tolerance reached',
#  'realize time people go hospital not early stage anymore right med provide early treatment effective far vaccination',
#  'think vaccination harm_reduction existing',
#  'wait people still listen apoorva blocked like eight month ago calling shitty take vaccination',
#  'well president much case biden team build execute vaccination program opened economy right sense president little control economy',
#  'precisely response attack power struck people disguised compulsory vaccination punitive vaccination pas shame experimental apartheid not responsible damage said vaccine',
#  'talking vaccination part lol',
#  'communicating intelligently includes knowing not talk ask current example asking people vaccination status would top list something none business ask else would add list',
#  'year old three chance death couid infection forty year old zero one death couid infection vaccination person yield reduction likelihood death person average worker chill risk low',
#  'except seen huge drop couid related death mass vaccination started instead see forty increase excess_deaths',
#  'new anthrax talking point van administered sitting supposedly prof pharma knew something wrong vaccine causing people fall die except seated not requirement vaccination',
#  'fact majority death outbreak remain care home mean happening environment near vaccination mean blame vaccinated also highlight virus endemic everywhere broad measure longer make sense',
#  'worry case like rebecca first people disabled community could lose child vaccination mandatory keeping know not happened father case',
#  'stop compulsory vaccination priest protest end',
#  'funny affect concerned anyone lost job ridiculous mandate restriction not referring due vaccination people wake',
#  'not wrong melanie although percentage quite bit estimation rate ontario vaccination rate ninety increase unlikely not even necessary time move',
#  'understand number impressive probably vaccination rate number remains impressive disease minus around including say big_deal',
#  'important consider impact workforce without high vaccination rate current challenge due burnout sick leaf would dramatically worse high vaccination rate loss small anti science hows little impact',
#  'doubt think asking vaccination status violates hippy',
#  'well yes omicron cause hospitalization death country highest vaccination rate',
#  'comparison stealing car like opposing coercion force vaccination',
#  'vaccination status nothing people vaccinated getting sick vaccinated',
#  'hammy seems history universal virus vaccination said virus eliminated guess coincidence',
#  'equate vaccination tuberculosis infected blanket scooping child sending body bag instead medicine poor little go movie',
#  'two help case understand one person refusing vaccination justifies ten hundred people dying privilege along individual yes said privilege sense communal responsibility duty one another',
#  'racist racism vaccine vaccination vaccinated misinformation disinformation riot rioter looting illegal immigrant immigration open border criminal activity law order domestic_terrorist terrorism made america america first mail ballot ballot validation',
#  'definition updated appropriate merrily webster updated definition december definition vaccination not changed couid vaccine definition vaccination previously updated fact',
#  'vaccination mandate overturning democracy favor populist politics part sowing division among perfectly nice human bean dismantling pillar democracy law representation knowledge not falling',
#  'saw opened email early january stating upload vaccination',
#  'actual government work elected stir pot twitter want oscar require vaccination one isolated event choosing accept negative test cry wanting everyday',
#  'low vaccination rate kid nightmare school change mask mandate going make worse lack care decision would stunning already seen',
#  'exactly nobody rounded anybody put car taking place held forced take vaccination simply want face consequence decision making see get',
#  'disgusting vaccinated vaccination mandate immediately trudeauhasgottogo trudeaumustresign',
#  'parent feel like without contact_tracing school losing major head child might exposed someone county low vaccination rate high positivity optional mask',
#  'point used empathy stranger signed vaccination appointment last spring',
#  'almost like lakers virtually movable asset could get reasonable upgrade roster',
#  'hilarious described accepting thought prayer proof vaccination friend told lol',
#  'number show vaccinated people died mostly elderly much higher vaccination rate rest population looking absolute number different sized group need look fraction population instead',
#  'worry vaccination hula hai log decrease hojayenge koi kama nazi angela',
#  'trucker answer wall working not protesting need vaccination mask truckers_protesting cause lose money disrespect interrupt supply_chain',
#  'kyrie finna walk vaccination clinic like',
#  'lol read beyond headline included article protection highest among vaccination prior couid fact reality actually exact_opposite statement',
#  'sound familiar stopped keeping track long blocking border_crossing u blocking downtown_ottawa demand government resign vaccination mandate',
#  'tell approve novavax vaccine vaccination rate increase',
#  'heard vaccination mandate banned montana net send irving one nba franchise',
#  'high vac rate seventy absolutely not helped country israel great example almost vaccination rate exploding case',
#  'worker country trek vaccinated also couid month ago vaccination not something government force onto population vaccination not prevent infection transmission party leader treading dangerous water',
#  'afraid antivaxxers overemphasize import vaccine side_effect say article widely cited antivaxxers evidence vaccination',
#  'two anti van nurse amityville accused forging thousand vaccination card exchange scary',
#  'one making claim event four six_months vaccination given need provide evidence example exists go back history want polio mar trap vaccine wait',
#  'weird hippy screamed man held sign stating establishment one seventy begging government keep masking rule vaccination passport lockdown',
#  'time nba playoff start vaccination requirement',
#  'said right moment benefit omicron seeming mildness country high vaccination rate percent entire population fully vaccinated percent received additional shot denmark',
#  'happened following cac guideline cave gonna happen rate climb cali good vaccination rate not failed state',
#  'lifetime went death sentence manageable condition might even vaccination soon amazing testament science',
#  'even gotten original vaccination yet not want not allowed make medical decision',
#  'anti vaccination anti couid vaccination',
#  'choosing good policy choice making wedge anything conservative politicized issue knee jerk criticizing every choice every step naturally trudeau chose vaccination conservative chose opposite',
#  'vaccine dot incompetence allowed isolated couid infection spread epidemic proportion requiring trump shutdown led trump recession biden american_rescue plan ended trump epidemic amp recession organizing vaccination program',
#  'watched vice story trying make feel guilty making fun people denied couid refused vaccination later died',
#  'watching coverage insanity anti vaccination trucker_protests threat trucker_protest super_bowl would annoy one privilege class amp wealthy people people could afford ticket range ticket price one',
#  'recently found someone know someone work healthcare falsified vaccination record',
#  'scared mask vaccination help protect scared wear_mask',
#  'like way manipulating narrative vaccine passport useless not positive reinforcement creating division punishment look trend vaccination center people begin doubt scare',
#  'using stick milk vaccination long people still getting vaccinated belief mighty pressure unless vaccination number drop significantly not gonna touch mandate lifting ten poll',
#  'never seen vaccine forced wear_mask maintain social_distance even fully vaccinated never heard vaccine spread virus even vaccination',
#  'cripes paying say shit told five weeks_ago decrease couid gonna happen like spike vaccination rate really changed gonna naturally immune',
#  'apparently vast_majority agree vaccination',
#  'toyota plant running blockade caused supply_chain issue japan eighty vaccination rate without government ask anyone get vaccination mask everywhere without government ask contact_tracing etc',
#  'state anything vaccination status hospital many people tested_positive ontario general statistic',
#  'trudeau not force vaccination huge attack bodily integrity state business imposing compulsory medical treatment punishing people refuse',
#  'army leaf vaccination center quebec not busy',
#  'vaccination turned one jab three possibly four jab concerned force take imagine trump mandating not talking couid vaccination speaking hypothetically',
#  'inventor technology concerned mass vaccination forced take medium not report one bad thing vaccination concerned omitting fact force take',
#  'not published research impact vaccination risk look forward seeing',
#  'still using rep sport game daughter really looking_forward getting yelled weekend ask proof vaccination',
#  'show suck worst show joke coverage protest canada compared coverage bum protest joke take couid vaccination nonsense shove',
#  'better not shit yr taking get couid nineteen vaccination know fast talking commercial',
#  'cac changed_definition vaccination increase_transparency fact_checkers say bull nope trying include inhibitor vaccine exists word reason',
#  'also matter vaccination efficacy compared average vaccinated person include many vaccinated people prior infection least partially top infection protection vaccinated',
#  'urge nation lift travel_bans not mandate proof vaccination entry death blow served ifs mass_formation psychosis break',
#  'vaccination key anti_baxters get hold everyone else hostage still opening country remains policy language make basically sense really clear would mean changing',
#  'globe mail vaccination fi not issue chairman_ceo alain_beard said tuesday driver still say keep canada able poli alberta',
#  'read apparently protest really vaccination maybe nothing one case ought incredibly shitty family case embarrassingly romanticized nonsense',
#  'vaccination vaccination vaccination vaccination like drunk freakin parrot want vaccination not playing anymore yes justin castreau tool',
#  'spike_protein modified vaccine le pathogenic produce orders_magnitude le spike_protein vaccination infection',
#  'meanwhile people dying developing severe morbidity couid read link couid type one diabetes kid evidence today indicates risk benefit favoring vaccination clear',
#  'hahahahaha wonder happened suddenly curve outbreak nope people happened tired bullshit keep minneapolis_paul immediately lift mandate requiring proof vaccination negative_test',
#  'conservative party cheerleader economic terrorism gripping canada started protest vaccination mandate even help terrorist fundraising',
#  'conclusion vaccine effective serious form pas tool coercion force people vaccinated kind compulsory vaccination disguise since politician not even courage impose',
#  'find death rate smallpox diphtheria prior mandatory vaccination child',
#  'yes evidence vaccination lessens risk',
#  'wish vaccination rate canadian level',
#  'changed misinterpretation vaccine effective not effect reporting case vaccination status',
#  'condition called vaccination regret',
#  'vaccine side_effect occur past week post vaccination observed previous vaccine vaccine testing ifr couid zero zero four vaccine death rate remotely similar expect',
#  'think meaning vaccination yeah wack job puff',
#  'received death threat promoting vaccination desire turn temperature convoy protestors dangerous right_wing extremist holding canada hostage gone long law_enforcement need put stop',
#  'portugal highest rate vaccination world couid everywhere vaccine not stopping spread preventing serious_illness justification mandate',
#  'death hospitalization icu age course largely preventable vaccination',
#  'infection hospitalization death much dependent vaccination status',
#  'boy another dumb as lack better term doesnt understand vaccine stri fun stupid part tho vacation stop though grossly misinformed four word correct misleading',
#  'vaccine hesitancy hardened despite still climbing couid nineteen death_toll robert lian argues universal coronavirus vaccine developed essential test efficacy cost vaccine payment raise vaccination rate',
#  'mask precaution forced vaccination human_right violation neither require government stoll state emergency',
#  'among lowest vaccination rate trust science',
#  'yeah no mask show vaccine proof mandate long even no mandate required full vaccination saw clutch sport article literally clickbait thinking no mandate key one write tiny_bit end bout',
#  'still vaccination requirement occupation condition attached restriction lifted fact condition attached like leaving back door return tighter regulation',
#  'except precisely vaccination helped avoid many hospital stay intensive_care death',
#  'contrast state clear anti mask people everything leverage couid exhaustion let er_rip anti van people trying burning childhood vaccination regime public education acceptable collateral_damage',
#  'army leaf vaccination center not busy',
#  'cac changed_definition vaccine thanks fact_checkers know would without cac changed_definition vaccination increase_transparency fact_checkers say',
#  'thinking checked vaccination card lou concert',
#  'one highest vaccination rate country apples_oranges dude',
#  'really frustrating thing state go rescinding mandate literally week away last segment population kid yo able receive vaccination afford wait another month two least sake',
#  'california twice many death since population_density fifty higher yes californian protected death mask amp vaccination ca might also lower risk rule variable explored stemeducation',
#  'fixing kyrie vaccination status brooklyn need kid simmons well newly added depth carry',
#  'measure favorable outcome not vaccination rate mask obedience assume insane',
#  'not discriminated discrimination definition based something cannot change skin_color sexuality gender etc not fact not wish receive vaccination',
#  'reasonable disagree whether greater threat civilization vaccination ordered state many country already versus erosion sense community includes taking small personal risk protect benefit vulnerable',
#  'live state low vaccination rate amp still second highest level death since began even seem like right conversation yet sane world',
#  'chart clearly show austria outcome significantly better sweden omicron spike per_capita number show country surprising considering vaccination rate swe aut',
#  'province country democratic state many place much worse vaccination rate',
#  'interview major news channel india trucker_protest vaccination mandate ottawa',
#  'ending mask mandate suddenly without warning invite chaos campus students_faculty understandably fear attending person class mask mandate student vaccination mandate community transmission rate still high',
#  'raoul never asked compulsory vaccination chickenpox wanted promote lot vaccine',
#  'vaccination not way prevent chinese virus fact prevent virus eliminates death role face crisis faci friend wanting government funding face mask work either cell',
#  'responsible american take basic couid precaution understandably fed coronavirus vaccination wakeup',
#  'fact matter regardless vaccination status couid infect mutate anyone best worry health wellness background noise year people livelihood threatened regardless',
#  'city van mandate made permanent motivate vaccination temp mandate clearly tactical goal accomplished',
#  'partake anything today modern world grow food make clothing never vaccination life never visited hospital dentist',
#  'japan vaccination mandate',
#  'agree place requiring proof vaccination folk useful information',
#  'cac feasibly sit pal patiently explain vaccine wane efficacy virus reproduce quickly respond adaptive vaccination effort mask useful tight confined space not competing min headline space',
#  'lol nothing big_pharma would want population slowly dying sequela let rip refused cheaper path vaccination non pharma mitigation',
#  'real world evidence vaccination slowing surge infection surge happened regardless vaccination rate vaccine available anyone want protection applying restriction based vaccination rate science based',
#  'thee not oscar person attendance not contingent_upon couid vaccination',
#  'net get replenish draft pick lost trading harden think probably reverse vaccination rule sooner later',
#  'one vaccination affect infection rate two vaccination child affect infection rate vaccination make possible survive get delta vaccinated child suffering business corporation',
#  'people table probably proof vaccination ridiculous',
#  'progressive spilled billie gifford amp co amp others supporting government backed coercion people using product could advocated vaccination without losing credibility guess know progressive really',
#  'ink folk keep saying big three brooklyn big one five half kid injury half kyrie vaccination half simmons really know problem philly def trade',
#  'vaccination mandate gone stop brooklyn making noise blame kyrie',
#  'common collective done something reasonable suggest others follow_suit simply ground promised full reopening upon mass vaccination clearly not case either',
#  'feeling simmons possibly perfect complement kid irving net one vaccination away contender',
#  'recognize ploy power museum require vaccination',
#  'well change_definition vaccination transparent even though called conspiracy_theorist saying past year',
#  'pok pushing mandatory vaccination cab pok anti_var standwiththecoaches',
#  'sure reciprocal agreement usa would happen truck cross_border south without proof vaccination american trucker could cross_border',
#  'let hope democrat city providence employee not compliant vaccination policy march subject suspension ri rhodeisland tripoli rhodyreport',
#  'shit sherlock high vaccination rate case vaccinated however hospitalization death overwhelmingly vaccinated work',
#  'careless take vaccination long_term study low dolt bro',
#  'anyone else think represents vaccination rate think strong correlation political map',
#  'term handling couid well could lot worse keeping restriction going even past vaccination campaign couid death even worse conservative senior refuse get vaccinated bonkers fucking bonkers',
#  'two point harden simmons deal one simmons never playing fact trade zero asset someone like harden massive win two guess certain mandate lifted reasonable chance vaccination requirement',
#  'applies dramatically exaggerated outright fabricated benefit vaccine minimizing risk point compulsory vaccination ordered state long run far greater threat civilization virus',
#  'voting killed many people congressman side seem understand analogy work better one follows actual logic mandating people show vaccination card eat not id gun touch blah_blah',
#  'anti goofy fuck socialist bloc country among one producing vaccine world distributing highest vaccination rate not reason people oppose ignore nazi rally goofy',
#  'kendrick perkins assumption everybody want brooklyn kyrie anti vaccination antic mean put past lol',
#  'laura need reach past post information clearly underinformed kathy_hocus allowed maintain mask mandate see fit still required mass transit hospital business want along vaccination',
#  'boston denver among city ditching proof vaccination requirement couid case fall publicly flip_flopping shit keep getting divisive even gon required people lost job friend opportunity etc',
#  'vaccination rate higher county primary care physician suggesting doctor unique position trust patient encourage vaccination',
#  'mixed feeling using motif polymer vaccination even though brilliant move seems give amazing power ad',
#  'takeaway would argue prioritized vaccine long ago get one get rate vaccination kid nearly universal need whatever stop spread',
#  'anti van freedom timbitterrorists terrorizing ottawa travel abroad without couid jab news_flash since international agreement meant passport guarantee vaccination ignorant realize ottawaoccupied',
#  'protest began behalf trucker angry mandatory vaccination requirement cross_border driver become international phenomenon bergen said protest would think mandate people spoken world',
#  'possibility endless everything interaction vaccination different meaning',
#  'may not know exactly everyone infected test site ask vaccination status hospital know patient positive vaccinated plenty data see testing positive end hospital couid',
#  'net might win one two game next four week kyrie vaccination status injury simmons ramp',
#  'death yesterday feb vaccine available given vaccination rate sixty almost half state unfettered interstate travel believe pandemic done dusted not good strategy',
#  'mask mandate lift regardless vaccination status fuckin dumb',
#  'happening',
#  'every often look republican legislation amp wonder small government look like freedom law amp order without gun control mean pro life anti mask vaccination',
#  'net checked vaccination status player',
#  'rolling back maskmandates wise hospitalization death infection still high child lower vaccination rate still extremely vulnerable parent teacher want mandate removed responsibility vaccinate child',
#  'not saying allowing state coordinate approach couid testing amp vaccination individual basis bad idea anyth wait exactly saying ifs wrong u like medicaid',
#  'unfortunately area low vaccination rate precisely ditch mask first',
# ...
#  'not low couid high vaccination rate',
#  'fucking joke ottawa cop unique conspiracy vaccination police_officer united_states died couid ninety death vaccinated wear bulletproof vest get vaccinated',
#  'vaccination snuffed small_pox pharmacist amp tell straight drug company make much drug therapy vaccine seen facebook vaccine big_pharma plot make',
#  'offer solution suggest ninety vaccination rate lockdown ad minimum homeschooling ad minimum',
#  'va forcing veteran vaccinated order seen travesty madness must end look eye thank risk sacrifice breath force vaccination absolutely criminal',
#  'make really giddy happy really hope graham cancer return post vaccination huge leap scientific medicine prove successful',
#  'mean position already clear thing changed lifted trucker exemption border vaccination mandate mention canadian_truckers not get u border without valid proof vaccination',
#  'wif real giving minute based vaccination status justin_trudeau master',
#  'higher vaccination rate busier hospital genetic predisposition sars_cov two spike_protein active inactive synthetic vaccine spur production spike_proteins guess happens mandate peanut_butter',
#  'not really vaccination mandate represent government taking life',
#  'bull shit went get free crack_pipe said need show proof vaccination',
#  'vaccinated people dying mostly made frail people older could not get vaccination jab could kill many comorbidities data broken way',
#  'meanwhile remaining route vaccination many country broke program said need fresh cash injection three seventh pfizer vaccine revenue support global rollout year',
#  'mean vaccination mean wear_mask',
#  'breakthrough rarer primary infection israel prof anything high vaccination rate make death rarer seen u data well skip tedious ad hominem feeling charitable',
#  'hospital report ninety couid patient not vaccinated red trump supporting area lowest vaccination rate sure democrat fault',
#  'information per vary giornalisti opinionisti televirologhi politics cac changed_definition vaccination increase_transparency fact_checkers say',
#  'nominee vaccinated sit as home make proof vaccination mandatory',
#  'vaccination not stop transmission science clear',
#  'long game vaccination never happen liberal plan gas chamber crucifix comply liberal caucus afraid stand emperor trudeau country finished weak politician stand nothing speak',
#  'one thing shit leader saying increasing vaccination number show support current policy many forced vaccinate else lose_jobs segregation originated',
#  'recommends not routine unless country achieve eighty vaccination rate specifically people worse outcome getting adult not rite passage since vaccine approved chickenpox rate gone ninety',
#  'work yes cure would like see transfer rate doug co arapahoe adam hard make sense given economic difference vaccination rate density mask preventative measure kill anyone',
#  'corruption become evident funding whan gof hiding long lockdown demeaning early treatment coercing vaccination masking kid closing school nearly two year pushing failed drug remdesivir censorship',
#  'vaccination cause increase infection compare country high rate much infection',
#  'per capital death much lower america vaccination rate much higher canadian right',
#  'joke especially stage shortage doctor vaccination rate nothing stop spread gov moving backward province like alberta saskatchewan moving_forward',
#  'fifty vaccination rate among five_eleven year old first unmask anyone explain number work able',
#  'like influenza occasionally nasty mutant make horrible season adopt universally free vaccination program maybe annual vaccine optional surely want virulent mutant emerges right',
#  'ignores fact many people vaccinated flu vaccine protective effect omicron sometimes even negative effect vaccination nothing concludes must vaccinated fact useless',
#  'keep clip lawyer child pose absolutely threat show utter incompetence five_eleven yr_olds low rate vaccination despite lie increase risk kid blame get bent threat arse',
#  'u vaccination card get anywhere future',
#  'not testing positive not whether get really sick die list country highest couid death per_capita one eastern europe low rate vaccination',
#  'couid obviously far less_lethal often lot people view threat even though death_toll pre omicron pretty substantial people think risk argue right refute vaccination',
#  'conflating vaccination mandate policy even related evidence mandate lead higher vaccination rate',
#  'easing mask mandate vaccination rate particularly high especially rural area',
#  'exactly sexually explicit material used class taught cut',
#  'growing body case law issue child vaccination separated parent',
#  'well met lol',
#  'high vaccination rate lockdown helped u low death rate comparison country hospital full vaccinated loser antivaxxers threatening healthcare_workers pig getvaccinatednow istandwithtrudeau',
#  'prediction dry sell fake vaccination certificate',
#  'nobody ever said vaccine foolproof never claimed still catch spite vaccination not majority case nearly severe',
#  'also wrong polio early polio vaccination people actually get couple month later',
#  'yes long county low vaccination rate currently hovering range continue mask socially distance etc',
#  'guess see want mandatory vaccination vaccine passport good many u',
#  'let pack van dos maga think turn magnetized puppet send country access preventing vaccination done coddling republican think jab might turn gay whatever latest conspiracy_theory',
#  'vaccination rate couid would still spread not eliminated hope people realize animalreservoirs',
#  'full vaccination protects omicron hospitalization_death',
#  'might want look death rate race matter vaccination rate say majority death not white conservative men democrat killing loyal supporter fighting mask funding improve school ventilation',
#  'point british_columbia biggest restriction civilized world one highest vaccination rate country proved need like',
#  'someone got worried quietly changed_definition vaccination several month ago blue fact_checkers propagandist rushing defend cac motif switcheroo',
#  'nope idiot upset believe vaccination form tyranny',
#  'looked death happened considered virus vaccination rate anti_virals acute therapy changed',
#  'total revenue nearly half ouch lot couid nineteen fatality gun owner maybe nra promote vaccination going forward',
#  'pas compulsory vaccination anyway denounces matron abject electoral manipulation',
#  'also mask people use news equivalent cloth_masks stop virus nearly well enough vaccination rate not nearly enough target rate set initial wave never updated variant',
#  'organizes refusing vaccination would keep hospital reduce icu load event likely struck_lightning fear hospital full healthcare_workers getting burned fear',
#  'nightmare fully committed forced vaccination',
#  'near capacity design surgery recovery whatnot not capacity people think facebook good source vaccination information perhaps forgotten care ten thousand elective surgery canceled due couid',
#  'need higher vaccination rate true given infection',
#  'known side_effect vaccination essentially polio renamed',
#  'even vaccination gong show mistake every turn wonder much longer get communist_party vaccine xi politics largely unserious affair full unserious people covered unserious medium',
#  'kenny fast track removal health restriction threat couid remains premier special kind political pressure forced court anti vaccination segment base caucus',
#  'apparently boil afraid virus vaccination',
#  'nothing prevent spread also got high vaccination rate think fared scaled per_capita u rate infection serious disease course variable say',
#  'none u want get couid even though vaccination status factor mean quite low risk hospitalization_death not possible bad simply difficult outcome bow want transmit others higher risk',
#  'people still care people still vigilant generally follow stupid advice everything right number way cite nothing distinguish partially fully vaccinated kind vaccination rna',
#  'struck attempt divert attention away low provincial vaccination rate repeatedly suggested high canada rate relation country slipped right past part failed leadership saskpoli jackleg cannoli',
#  'vaccination rate changed understand science medicine stop pretending',
#  'even advice already gotten tell enjoy passionate helping others knowledge finding vaccination status either way change',
#  'madison hawthorn even worse hill die vaccination traitor trash freedom lover refused put ventilator',
#  'anti vaccination protester march civic via',
#  'mandate may well let government force vaccination see turn giving government power violate charter_rights recipe anarchy civil_war extremely dangerous needed stopped six_months ago',
#  'government control mask mandate vaccination mandate taught school parent control childrens life',
#  'result defining word vaccination confusion amp distrust allowed word used vaccine relevant efficacy claiming transparency amp clarity speaks incompetence',
#  'almost blue_states higher vaccination rate following science mama tried politicize',
#  'suggesting charter violated indefinitely vaccination never happen',
#  'majority people know got lied dont confuse vaccination rate yes jab please vote',
#  'unlike got caught french laundry case rapidly rose time gavin see opportunity look innocent outright ending mandate since case actually lower hospitalization not case crucial metric consider post vaccination pandemic',
#  'shingle awful everyone chicken_pox risk reducing risk vaccination reasonable route preventing chicken_pox bullshit vaccination usual best way avoid altogether get vaccinated',
#  'even get academy museum without vaccination card',
#  'told friend google restaurant phone number ask require proof vaccination way know expected upon arrival restaurant singled oppose social_media',
#  'cap gap bad wrong tweet',
#  'covidiot edmonton_exploring proof vaccination program alberta_canceled',
#  'futurans without like person without vaccination not going go well met amp obviously love bender rumored pay dispute cash hulu one biggest reason success paid',
#  'allow people regardless vaccination status participate freely society',
#  'mitigation many layer mask test paid leave continue push vaccination',
#  'correct talking vaccination alone previous infection alone per cac',
#  'um well maybe look available data death mass vaccination u death rate mass vaccination death vaccination ninety',
#  'fine afterward xmas year half u tested_positive likely omicron people got sick enough stay bed feeling like shit barely symptom attribute full vaccination booster possibly previous antibody',
#  'perspective science vaccination might recommended question question general population child specifically required need ask legislator',
#  'yeah man got man got done pretty well course miss rat family piece crap club bum smack got keep moving',
#  'mom politician press release misleading headline seven vaccinated died seventeen vaccinated died noted eight booster start telling truth instead trying cover fact vaccination make difference novaccinemandates',
#  'kinda funny marin_county one highest vaccination rate nation predicted ten year ago',
#  'cac changed_definition vaccination increase_transparency fact_checkers say merrily webster dictionary say something need change_definition something different lost argument myers',
#  'addition individual collective sacrifice elected leader also authorized numerous multi trillion spending bill organized unprecedentedly rapid vaccination rollout lock u room nothing',
#  'cannot prevent every death not good policy people die disease couid not special goal not zero couid death people not stand society like vaccination prevents death overwhelmingly period',
#  'coronavirus crisis edmonton_exploring proof vaccination program alberta_canceled ctu',
#  'gotta go walgreens wisdom rothman wait maybe pulling fish seeeeeeeeeeeeeee',
#  'new case vaccine status right mirror vaccination rate closer closer time number cannot right not testing limited think number accurate',
#  'totally agree waiting see result mass vaccination poorly tested treatment think going long_term like thalidomide short_term not much',
#  'risk also exists vaccination risk myocarditis_pericarditis confirmed many time',
#  'vaccine make improvement original patent robert_malone inventor improvement existing patent allows commercialization patent old trick spike_protein level plasma vaccination three',
#  'great burn dude think absolutely relevant people live school_district massive vaccination rate push narrative place sub twenty rate',
#  'seems like false dichotomy personally think van passport space outlived efficacy ending masking school seems premature however transmissibility changed twelve pop low rate vaccination trying save',
#  'seriously getting information vaccination mitigates virus severity increase survival rate cac website website etc not know get information vaccine made impervious couid',
#  'dude realized much need rothman video thanks liking content bro',
#  'not allowed heaven forbid discus may lead talk word vagina vaccination',
#  'cac told associated press changed_definition vaccination removing word immunity focus stimulation body immune_response gee vaccinated couid immune_response vaccinated thatjoke covidlogic',
#  'need change_definition vaccination prior vaccine definition changed technology not considered vaccine previously put umbrella vaccine',
#  'apparently committed suicide vaccination moot point',
#  'surreal excerpt wednesday maischberg talkshow far left sara wagenknecht defending liberal perspective vaccination front liberal gerhardt baum',
#  'spread masked person people need masked stop spread vaccination nothing spreading virus keep getting possibly sick hospitalized even fully valued still small pop hospitalized',
#  'big blue spike outbreak happening receding vaccination rate change people stop mingling could graph actually prove mitigation work',
#  'best defense never mask sanitize vaccination clearly another doctor name not one take true interest profession health true meaning',
#  'starting conclusion vaccine mandate work called circular reasoning regardless risk efficacy vaccine evidence mandate increase vaccination rate',
#  'donaldjtrump right_wing medium unrelenting attack vaccination win election basic biology many trump voter get long suffer brain injury lose_jobs mybodymychoice freedomconvoy',
#  'wonder vaccination rate controlled age anything graph presented',
#  'onset autoimmune phenomenon couid nineteen vaccination reported increasingly e immune thrombotic thrombocytopenia autoimmune liver disease villain_barry syndrome iga neuropathy rheumatoid_arthritis amp systemic lupus erythematous',
#  'impossible vaccination rate country especially usa regarding limit far people willing go public generally support government action mask mandate example not le',
#  'except knocking door demanding see vaccination info',
#  'actual protest coming trucker demanding lift vaccination mandate cross_border extremist backing making noise overthrow gown misled radical protest legitimate',
#  'case plummeting new_york state high vaccination rate hospital not full like north_dakota mississippi red state low vaccination rate',
#  'strictest restriction longest period time one highest vaccination rate world cancer booming currently saying canadian wrong want live life',
#  'nigga taking pill man made shit_processed scared take vaccination shot shit make sense yo gotti',
#  'interesting new case rate mirroring vaccination rate call bullshit percent new case right abcovid',
#  'interesting new case rate mirroring vaccination rate call bullshit percent new case right',
#  'federal law applied differently pandemic federal precedent give state right mitigate spread virus includes requiring vaccination rejecting accommodation basis public health know wa law',
#  'must receive well stocked envelope big_pharma push vaccination clear',
#  ...]

# %%
df['new_text_noun'] = new_text_noun
# Out:
# /var/folders/pk/mh54kmcs083ggkf50q9s_r1c0000gn/T/ipykernel_63195/2006874802.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new_text_noun'] = new_text_noun

# %%
texts = df['new_text_noun']

# %%
texts
# Out:
# 0        child almost died tetanus spent month hospital...
# 1        remember leblanc pressure provincial business ...
# 2        hurt head actually use brain seem incredibly b...
# 3        world wide mass vaccination leading world wide...
# 4        see saying alberta business required ask proof...
#                                ...
# 92818                   half friend sick vaccinated sheesh
# 92819    merry_christmas hope thing improve son amp gir...
# 92820    refer este positive positive covidtesting vacc...
# 92821    acute stroke couid pneumonia nova coronavirus ...
# 92822    explains similar seemingly nowhere message scr...
# Name: new_text_noun, Length: 92823, dtype: object

# %%
# Vectorizing documents, obtaining full vocabulary and biterms
# Internally, btm.get_words_freqs uses CountVectorizer from sklearn
# You can pass any of its arguments to btm.get_words_freqs
# For example, you can remove stop words:
stop_words = ['use','a','no','yes','haha']

# %% [markdown]
# ## 4 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=4, M=20, alpha=50/4, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|█████████████████████████████████████████| 600/600 [04:49<00:00,  2.07it/s]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy
# Out:
# 4.405512762079771

# %% [markdown]
# ## Calculate documents vs topics probability matrix

# %%
p_zd = model.transform(docs_vec)
# Out:
# 100%|█████████████████████████████████| 92823/92823 [00:00<00:00, 154561.00it/s]

# %%
coherence = model.coherence_

# %%
coherence
# Out:
# array([-506.37965841, -537.87589157, -498.92274051, -476.19846882])

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
# import pickle as pkl
# # Saving
# with open("./sentence-meat-noun-adj-verb-adv/model9.pkl", "wb") as file:
#     pkl.dump(model, file)
    
#change the model name to save depending on the number of topics so if 9 topics then model9.pkl

# %%
# import pickle as pkl
# import tmplot as tmp
# import glob

# # Loading saved models
# models_files = sorted(glob.glob(r'./sentence-dairy-noun-adj-verb-adv/model[3-8].pkl'))
# models = []
# for fn in models_files:
#     file = open(fn, 'rb')
#     models.append(pkl.load(file))
#     file.close()

# # Choosing reference model
# np.random.seed(122334)
# reference_model = np.random.randint(1, 6)

# # Getting close topics
# close_topics, close_kl = tmp.get_closest_topics(
#     models, method="sklb", ref=reference_model)

# # Getting stable topics
# stable_topics, stable_kl = tmp.get_stable_topics(
#     close_topics, close_kl, ref=reference_model, thres=0.7)

# # Stable topics indices list
# print(stable_topics[:, reference_model])

# %%
stable_topics = [0, 1, 2,3]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#         topic0       topic1      topic2      topic3
# 0          get      vaccine  vaccinated     vaccine
# 1       pfizer       pfizer      people         not
# 2       modern          not   vaccinate        anti
# 3         shot       modern         not  vaccinated
# 4          not  vaccination         get      people
# 5      booster          one       couid         get
# 6          one          amp     vaccine   vaccinate
# 7      vaccine   government       death         say
# 8          two        would         die         van
# 9   vaccinated          two         one     mandate
# 10         day          say        rate        mask
# 11          go       people    hospital        want

# %% [markdown]
# ## 5 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=5, M=20, alpha=50/5, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|█████████████████████████████████████████| 600/600 [05:33<00:00,  1.80it/s]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy
# Out:
# 4.24090520839173

# %%
p_zd = model.transform(docs_vec)
# Out:
# 100%|█████████████████████████████████| 92823/92823 [00:00<00:00, 134794.91it/s]

# %%
coherence = model.coherence_

# %%
coherence
# Out:
# array([-506.44610656, -482.20703701, -547.43276818, -507.07403767,
#        -503.41155398])

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
stable_topics = [0, 1, 2,3,4]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#         topic0      topic1       topic2       topic3       topic4
# 0          get     vaccine      vaccine   vaccinated   vaccinated
# 1       pfizer        anti       pfizer       people          not
# 2       modern      people          not    vaccinate  vaccination
# 3         shot         not       modern          not      mandate
# 4      booster         get          one        couid       people
# 5          one  vaccinated          amp          get      vaccine
# 6          two   vaccinate  vaccination      vaccine          get
# 7          not         say          say        death      trucker
# 8          day       couid       people          die         mask
# 9      vaccine         van         know          one   government
# 10  vaccinated          go   government         rate          one
# 11          go        like         take  vaccination         anti

# %% [markdown]
# ## 6 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=6, M=20, alpha=50/6, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|█████████████████████████████████████████| 600/600 [05:39<00:00,  1.77it/s]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy
# Out:
# 4.156356787344828

# %%
p_zd = model.transform(docs_vec)
# Out:
# 100%|█████████████████████████████████| 92823/92823 [00:00<00:00, 136588.11it/s]

# %%
coherence = model.coherence_

# %%
coherence
# Out:
# array([-536.62673277, -489.68037151, -600.2463234 , -514.09514166,
#        -475.75954321, -563.97002259])

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
stable_topics = [0, 1, 2,3,4,5]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0   topic1      topic2       topic3      topic4       topic5
# 0       get     anti     vaccine   vaccinated  vaccinated   vaccinated
# 1    pfizer  vaccine      pfizer      vaccine      people          not
# 2    modern      not         not        couid         get  vaccination
# 3      shot   people      modern       people   vaccinate      mandate
# 4   booster      van         one          not         not       people
# 5       one      get         amp        death       couid      vaccine
# 6       two      say         get    vaccinate     vaccine          get
# 7       day     like        take  vaccination         die         mask
# 8   vaccine  anthrax  government         rate    hospital      trucker
# 9       not  science         say          one          go   government
# 10     like      amp       trump         risk        mask          one
# 11    shoot     make      people          get        sick         want

# %% [markdown]
# ## 7 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=7, M=20, alpha=50/7, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|█████████████████████████████████████████| 600/600 [26:29<00:00,  2.65s/it]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy
# Out:
# 4.096403485911485

# %%
p_zd = model.transform(docs_vec)
# Out:
# 100%|█████████████████████████████████| 92823/92823 [00:00<00:00, 110142.20it/s]

# %%
coherence = model.coherence_

# %%
coherence
# Out:
# array([-580.49784205, -510.00476709, -512.37940007, -538.22199843,
#        -530.16364614, -480.41719761, -529.33172039])

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
stable_topics = [0, 1, 2,3,4,5,6]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#         topic0      topic1       topic2       topic3   topic4      topic5  \
# 0       pfizer     vaccine   vaccinated   vaccinated      get  vaccinated
# 1      vaccine         not      vaccine          not   pfizer      people
# 2       modern        anti        couid  vaccination   modern   vaccinate
# 3          not      people        death          get     shot         get
# 4          one         get       people       people  booster         not
# 5          amp         say          not      mandate      two       couid
# 6   government  vaccinated         rate      vaccine      one         die
# 7        trump         van  vaccination         mask      day     vaccine
# 8        money        know    vaccinate          one  vaccine    hospital
# 9         take       couid          one        would      not          go
# 10     company        like         risk      trucker    shoot        mask
# 11        make        make         case   government     like        sick
#
#          topic6
# 0          anti
# 1       vaccine
# 2           van
# 3     vaccinate
# 4           amp
# 5       mandate
# 6        people
# 7           not
# 8       anthrax
# 9   vaccination
# 10        trump
# 11         mask

# %% [markdown]
# ## 8 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=8, M=20, alpha=50/8, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|█████████████████████████████████████████| 600/600 [06:45<00:00,  1.48it/s]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy
# Out:
# 4.062523882767383

# %%
p_zd = model.transform(docs_vec)
# Out:
# 100%|█████████████████████████████████| 92823/92823 [00:00<00:00, 124487.20it/s]

# %%
coherence = model.coherence_

# %%
coherence
# Out:
# array([-543.86629238, -564.04209063, -571.28167384, -537.90997983,
#        -496.41043828, -475.75954321, -547.84169734, -490.02796671])

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
stable_topics = [0, 1, 2,3,4,5,6,7]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0       topic1      topic2       topic3       topic4      topic5  \
# 0       get   vaccinated      pfizer      vaccine   vaccinated  vaccinated
# 1    modern          not     vaccine          not    vaccinate      people
# 2    pfizer          get      modern       pfizer        death         get
# 3      shot       people         not       people        couid   vaccinate
# 4   booster       pfizer       trump          get       people         not
# 5       two          one         one        couid         rate       couid
# 6       one         like       money  vaccination  vaccination     vaccine
# 7       day         know         amp         know          not         die
# 8   vaccine      getting  government          one      vaccine    hospital
# 9     shoot  vaccination         say          amp          one          go
# 10      not        would     million    effective         case        mask
# 11    first          got     country          say         risk        sick
#
#          topic6     topic7
# 0    vaccinated       anti
# 1           not    vaccine
# 2   vaccination        not
# 3       mandate     people
# 4       vaccine        van
# 5          mask        get
# 6       trucker        say
# 7        people    anthrax
# 8    government       like
# 9           get        amp
# 10         anti  vaccinate
# 11      protest    science

# %% [markdown]
# ## 9 topics

# %%
# TRY DIFFERENT NUM TOPICS
# keep beta = 0.09, try different beta if results arent great
# iterations = 600 seems decent

X, vocabulary, vocab_dict = btm.get_words_freqs(texts, stop_words=stop_words)
docs_vec = btm.get_vectorized_docs(texts, vocabulary)
biterms = btm.get_biterms(docs_vec)

# Initializing and running model
model = btm.BTM(
    X, vocabulary, seed=12321, T=9, M=20, alpha=50/9, beta=0.09)
model.fit(biterms, iterations=600)
# Out:
# 100%|█████████████████████████████████████████| 600/600 [07:40<00:00,  1.30it/s]

# %%
entropy = btm.entropy(model.matrix_topics_words_)

# %%
entropy
# Out:
# 4.049320508669942

# %%
p_zd = model.transform(docs_vec)
# Out:
# 100%|█████████████████████████████████| 92823/92823 [00:00<00:00, 109298.67it/s]

# %%
coherence = model.coherence_

# %%
coherence
# Out:
# array([-545.55721935, -569.18874388, -479.67962128, -526.31467188,
#        -562.27512536, -501.27748701, -552.71548324, -560.8016495 ,
#        -481.44827593])

# %%
import tmplot as tmp

# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
stable_topics = [0, 1, 2,3,4,5,6,7,8]
top_words = btm.get_top_topic_words(
    model,
    words_num=12,
    topics_idx=stable_topics)

# %%
top_words
# Out:
#      topic0      topic1      topic2       topic3       topic4       topic5  \
# 0       get      pfizer  vaccinated      vaccine   vaccinated   vaccinated
# 1    modern     vaccine      people          not          not    vaccinate
# 2    pfizer      modern         get       pfizer          get       people
# 3      shot         not         not        couid       people        death
# 4   booster       trump     vaccine  vaccination       pfizer        couid
# 5       two         one   vaccinate          amp          one         rate
# 6   vaccine       money       couid       people         like  vaccination
# 7       one  government         die          one         know          not
# 8       day         amp        mask         know        would      vaccine
# 9     shoot         say          go          get      getting          one
# 10      not     country         say       modern  vaccination         risk
# 11    first     million       still    effective          got         case
#
#         topic6       topic7   topic8
# 0   vaccinated   vaccinated     anti
# 1    vaccinate          not  vaccine
# 2        couid  vaccination      van
# 3     hospital      mandate      not
# 4       people      vaccine   people
# 5          get         mask      say
# 6          die      trucker  anthrax
# 7          not       people      amp
# 8        child   government     like
# 9          amp          get      get
# 10     patient         anti  science
# 11          go      protest    couid
