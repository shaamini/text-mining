# %%
import pandas as pd

# %%
anti_vaccination = pd.read_csv("../data/India/vaccination/anti-vaccination.csv")
anti_vaccination.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
anti_vaccination
# Out:
#                                                  Text
# 0   Only 15% of Africa has received at least one d...
# 1   @washingtonpost Anti-Mandate is not Anti-Vacci...
# 2   @LOCAKD @operskapevacica @pmouratoglou Aussie ...
# 3   Meet RLD HATE MONGERS squad member Kulwant Sin...
# 4   I’m pro vaccination, but anti vaccination mand...
# 5   I’m pro vaccination, but anti vaccination mand...
# 6   I’m pro vaccination, but anti vaccination mandate
# 7   @joshuafarn99 @tiotheo01 @ian_woodhall @MYFree...
# 8   anti vaccination camp \r\nPlease note https://...
# 9   @BBCWorld But the fact is that it is who Novak...
# 10  Valid point as the authorities don’t want to s...
# 11  Great look supporting an antivaxxer who either...
# 12  @LisaMarieBoothe Sane people know Biden is hum...
# 13  @PRSundar64 Australian police probe viral vide...
# 14  Australian police probe viral video of cop VIO...
# 15  @writewing11 @sweetspottrader There is no logi...
# ...

# %%
anti_vaccine = pd.read_csv("../data/India/vaccination/anti-vaccine.csv")
anti_vaccine.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
anti_vaccine
# Out:
#                                                    Text
# 0     Why covering anti-evolution laws has me worrie...
# 1     What You Need To Know About The Anti-vaccine C...
# 2     We found a cure for cancer,  all you have to d...
# 3     New Zealand police move in to break up anti-CO...
# 4     COVID-19: New Zealand police make arrests as a...
# ...                                                 ...
# 1295  Facebook Bans Anti-Vaccine "Conspiracy Theorie...
# 1296  And yet Anti-Vaxxers are taking to social medi...
# 1297  @richardcalhoun Most people are not anti vacci...
# 1298  @501Awani Amik DNA dia boleh buat vaccine anti...
# 1299  Let me rephrase ... \r\n\r\nShould Anti Nashno...
#
# [1300 rows x 1 columns]

# %%
antivaxxer = pd.read_csv("../data/India/vaccination/antivaxxer.csv")
antivaxxer.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
antivaxxer
# Out:
#                                                   Text
# 0    Well I do agree with the "So Help Me God" part...
# 1    @TheLastFabeo @Pernetinha1 Por mim era só eles...
# 2    #NewsUpdates \r\n\r\nParis #Police say they wi...
# 3    @Boujee4201 @Decadence_3 @VerifyThis If you ar...
# 4    "Just in case you don't know. Dr Montagnier ha...
# ..                                                 ...
# 112  Antivaxxer: Pandemik Covid-19 adalah satu peni...
# 113  Antivaxxer Malaysia di luar negara bila tahu v...
# 114  @raja_1980 He is an antivaxxer. The risk of va...
# 115  Majority Indians have natural immunity. Vaccin...
# 116  earth flat, antivaxxer etc etc https://t.co/mW...
#
# [117 rows x 1 columns]

# %%
boostershot = pd.read_csv("../data/India/vaccination/booster-shot.csv")
boostershot.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
boostershot
# Out:
#                                                    Text
# 0     @PretamSharan If the Ro/Rt is 1.6 as predicted...
# 1     i totally forgot i got my booster shot today, ...
# 2     2nd booster shot mwende kesho😂 https://t.co/3d...
# 3     ‘There may be need for yet again another dose’...
# 4     I still do say, that I am still going to do my...
# ...                                                 ...
# 2117  #BioNTech/Pfizer warned that they had no evide...
# 2118  Cheers to another shot of strength booster. 🧘🏻‍♀️
# 2119  Moderna and Pfizer vaccines require two doses....
# 2120  #MBUMomswhoblog \r\nBoosting immunity in child...
# 2121  @blogchatter A-2) 4-6 yrs is the ideal age for...
#
# [2122 rows x 1 columns]

# %%
effectivevaccine = pd.read_csv("../data/India/vaccination/effective-vaccine.csv")
effectivevaccine.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
effectivevaccine
# Out:
#                                                   Text
# 0    #COVID19 vaccines are very effective in modify...
# 1    Inhaled Covid Vaccine Developed Effective Agai...
# 2    That's where @PeterHotez and his amazing Paten...
# 3    Inhaled Covid Vaccine Developed Effective Agai...
# 4    @mukulneetika @timesofindia The only question ...
# ..                                                 ...
# 761  Effective communication strategies &amp; appro...
# 762  @SerumInstIndia  Congratulation to Serum insti...
# 763  @NamasteIndia_in @rahulkanwal Also tell me one...
# 764  Moderna Says it's vaccine is 100% effective ag...
# 765  @KyaUkhaadLega Moderna vaccine claimed 100% ef...
#
# [766 rows x 1 columns]

# %%
immunocompromised = pd.read_csv("../data/India/vaccination/immunocompromised.csv")
immunocompromised.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
immunocompromised
# Out:
#                                                   Text
# 0    @EFFFalcon A) what about immunocompromised peo...
# 1    So many students have been immunocompromised, ...
# 2    @HeerJeet The same way doctors have managed th...
# 3    #CNBCNews - Immunocompromised, disabled and el...
# 4    COVID prognosis for India: Immunocompromised w...
# ..                                                 ...
# 131  @DrSidMukherjee Safe for immunocompromised pat...
# 132  However, if this variant B.1.1.7, evolved to e...
# 133  Thats not how it works.We need to achieve herd...
# 134  Necrotising fasciitis of left upper limb in an...
# 135  Profoundly Immunosuppressed patients especiall...
#
# [136 rows x 1 columns]

# %%
mandatedvaccine = pd.read_csv("../data/India/vaccination/mandated-vaccine.csv")
mandatedvaccine.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
mandatedvaccine
# Out:
#                                                  Text
# 0   @noonienoodie @John_outWest I was waiting for ...
# 1   Is this what you want to be mandated? Shouldn'...
# 2   @JustinTrudeau @fordnation Well undoing the ma...
# 3   @AriMelber @MichaelSteele \r\nThe idea of unma...
# 4   @UnivofDelhi has not mandated the covid vaccin...
# 5   Alberta Will End Mandated Vaccine Passports at...
# 6   Great business idea for lawyers-\r\nSince loca...
# 7   Who are the protesters?\r\n\r\nThis all starte...
# 8   Lessons learnt-\r\n1. Look after your health\r...
# 9   I never made this point, in fact i am against ...
# 10  @Kawanatanga1 @NZedAUS You said they were mand...
# 11  Costa Rica mandated Covid-19 vaccines for chil...
# 12  Costa Rica mandated Covid-19 vaccines for chil...
# 13  Costa Rica mandated Covid-19 vaccines for chil...
# 14  @ninanotready Pfff nope its mandated to fly an...
# 15  @sardesairajdeep @Milan_reports Could it be be...
# ...

# %%
nevervaccine = pd.read_csv("../data/India/vaccination/never-vaccine.csv")
nevervaccine.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
nevervaccine
# Out:
#                                                  Text
# 0   @ronInBendigo They will never admit they got i...
# 1   @KingCapaIot @Pete_Chi_Fan Never watched a gam...
# 2   These corrupt vaccine makers put HIV in their ...
# 3   @Coachrizzo2 @SecretS80760045 @Tombaan66 The p...
# 4   When WHO requested everyone to stay wherever t...
# ..                                                ...
# 95  @DGHisham So the fastest forced experimental v...
# 96  So the fastest forced experimental vaccines in...
# 97  Finding the root cause of pandemics is key\r\n...
# 98  ‘2. Saya bertanggungjawab ke atas risiko Yang ...
# 99  @sunmor2901 He also told Pfizer Moderna vaccin...
#
# [100 rows x 1 columns]

# %%
trustvaccine = pd.read_csv("../data/India/vaccination/trust-vaccine.csv")
trustvaccine.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
trustvaccine
# Out:
#                                                  Text
# 0   If Kyrie takes the vaccine today NBA Twitter w...
# 1   @Iyervval Totally. Forget all of that. Remembe...
# 2   #BigPharma needs to get its house in order. #V...
# 3   69% of adolescents aged 15-18 yrs have been ad...
# 4   #vaccinated today 💉😊\r\n1st dose complete👌💯\r\...
# 5   @NityJayaraman Sir, should we still trust Unio...
# 6   I can’t recall a precedent when an organisatio...
# 7   #news #medicine #pharmaceuticals - Covid vacci...
# 8   @stefunny76 @Tbdbtdbtdbt @aaronptutt @RealCand...
# 9   bila ade flow badan bertanggungjawab yang addr...
# 10  if we want to live in Endamic, we should start...
# 11  We need to continue the good work we are doing...
# 12  Lessons learnt-\r\n1. Look after your health\r...
# 13  Malawi Liverpool Wellcome is conducting a fiel...
# 14  @FaheemYounus If I don't trust either #vaccine...
# 15  @narendramodi Akhilesh called it BJP's vaccine...
# ...

# %%
unvaccinated = pd.read_csv("../data/India/vaccination/unvaccinated.csv")
unvaccinated.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
unvaccinated
# Out:
#                                                   Text
# 0    New York City Set to Fire Up to 3,000 Unvaccin...
# 1    @RickSantini2 @KayleeDMcGhee https://t.co/ZZVs...
# 2    New York Set to Fire Up to 3,000 Unvaccinated ...
# 3    @kathymi71147962 @cwmacko @vintage831 I also a...
# 4    @POTUS I’m moving to china if u don’t tax the ...
# ..                                                 ...
# 965  Corona vaccine arrival.Will not be uncontrover...
# 966  Wear a mask even after getting COVID-19 or the...
# 967  @ZubyMusic Welcome to the fascism. My unvaccin...
# 968  @DharRenuka Who would want to die unvaccinated. 🤔
# 969  More than 60 million destitute people could go...
#
# [970 rows x 1 columns]

# %%
vaccinated = pd.read_csv("../data/India/vaccination/vaccinated.csv")
vaccinated.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
vaccinated
# Out:
#                                                     Text
# 0      Hi everyone I just wanna ask \n2 covid doses =...
# 1      @Eunique_ny He should get vaccinated too that ...
# 2      💉 About sixteen million (77%) Sri Lankans have...
# 3      Covid-19: 1.8 lakh of those vaccinated in Mumb...
# 4      Re-Up: 78% Fully Vaccinated In Odisha Vs 95% I...
# ...                                                  ...
# 40114  @kushal_mehra @centerofright It means even if ...
# 40115  @B2015Malar @PotholeWarriors @PTI_News @INCInd...
# 40116  Is the govt telling us that vaccination agains...
# 40117  So does Mr. Health Secretary mean here only th...
# 40118  Central Govt has clarified that everyone doesn...
#
# [40119 rows x 1 columns]

# %%
vaccinesaveslives = pd.read_csv("../data/India/vaccination/vaccinesaveslives.csv")
vaccinesaveslives.drop(columns = ["Datetime", "Tweet Id", "Username"], inplace = True)
vaccinesaveslives
# Out:
#                                                  Text
# 0   கோயம்புத்தூர் மாநகராட்சி பகுதியில் கொரோனா தடுப...
# 1   நாளை மீண்டும் திருப்பூர் மாநகராட்சி முழுவதும் ...
# 2   ❗जिले के पांकी प्रखंड अंतर्गत  19-21 नवम्बर तक...
# 3   ❗जिले के हरिहरगंज तथा पिपरा प्रखंड अंतर्गत  19...
# 4   ❗जिले के सीएचसी विश्रामपुर अंतर्गत  19-21 नवम्...
# ..                                                ...
# 91  I can’t wait to get my 2nd dose of the #CovidV...
# 92  Thanks for your appreciation and valuable feed...
# 93  Getting my #CovidVaccine jab (3rd batch) today...
# 94  @Mohanlal @narendramodi @drharshvardhan @vijay...
# 95  That's why it's important to be vaccinated. We...
#
# [96 rows x 1 columns]

# %%
frames = [anti_vaccination, anti_vaccine, antivaxxer, boostershot, effectivevaccine, immunocompromised, mandatedvaccine, nevervaccine, trustvaccine, unvaccinated, vaccinated, vaccinesaveslives]

result = pd.concat(frames)

# %%
result
# Out:
#                                                  Text
# 0   Only 15% of Africa has received at least one d...
# 1   @washingtonpost Anti-Mandate is not Anti-Vacci...
# 2   @LOCAKD @operskapevacica @pmouratoglou Aussie ...
# 3   Meet RLD HATE MONGERS squad member Kulwant Sin...
# 4   I’m pro vaccination, but anti vaccination mand...
# ..                                                ...
# 91  I can’t wait to get my 2nd dose of the #CovidV...
# 92  Thanks for your appreciation and valuable feed...
# 93  Getting my #CovidVaccine jab (3rd batch) today...
# 94  @Mohanlal @narendramodi @drharshvardhan @vijay...
# 95  That's why it's important to be vaccinated. We...
#
# [45833 rows x 1 columns]

# %%
tweet_text_list = result['Text'].tolist()

tweet_text_list
# Out:
# ['Only 15% of Africa has received at least one dose of the Covid vaccine. Despite all anti-vaccination protests, U.S. and Canada together stand at 77%. #VaccineInequality',
#  '@washingtonpost Anti-Mandate is not Anti-Vaccination.\r\n\r\nThis tweet is misleading. #Reported',
#  "@LOCAKD @operskapevacica @pmouratoglou Aussie government confirmed Novak had valid exemption.They deported him for anti-vaccination sentiment. \r\nI didn’t expect Rafa to boycott AO. But\r\nRafa could say something kind like Nick Kyrgios did, or not say anything. After all Novak donated Rafa's fundraising on covid crisis.",
#  'Meet RLD HATE MONGERS squad member Kulwant Singh :\r\n\r\nPro Election Violence\r\nHates Hindu customs &amp; traditions\r\nHates Science\r\nHates Lata Mangeshkar\r\nAnti Vaccination\r\nPro Casteist Separation\r\n\r\nAnd other typical leftist &amp; separatist mindset views.\r\n\r\nMany like him are brainwashing youth! https://t.co/wsRHX2amJh https://t.co/Ws0GP63Tph',
# ...

# %%
import numpy as np
import re

# %%
stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from", "vaccine", "covid", "vaccines","vaccinated","vaccination", "amp", "will"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
cleaned_tweets = [clean_tweet(tw) for tw in tweet_text_list]
cleaned_tweets
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_51104/4011379638.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['only 15 africa has received at least one dose despite all anti protests u s canada together stand at 77',
#  'anti mandate is not anti this tweet is misleading',
#  'aussie government confirmed novak had valid exemption they deported him anti sentiment i didn t expect rafa boycott ao but rafa could say something kind like nick kyrgios did or not say anything after all novak donated rafas fundraising crisis',
# ...

# %%
print(len(cleaned_tweets))
# Out:
# 45833

# %%
cleaned_list = list( dict.fromkeys(cleaned_tweets) )
print(len(cleaned_list))
# Out:
# 40471

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in cleaned_list:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
