# %%
import pandas as pd

# %%
anti_vaccination = pd.read_csv("../data/USA/usa_anti_vaccination.csv")
anti_vaccination.drop(columns = "Unnamed: 0", inplace = True)
anti_vaccination
# Out:
#                                                    Text
# 0     So.... Conservative Anti-Abortion Anti-Vaccina...
# 1     @saletan @theabstoddard As you might know, the...
# 2     The "regime spokespeople" (MSM) keep referring...
# 3     @maureviv The doctors who were outraged that o...
# 4     Manchin voted for Sen. Mike Lee’s anti-vaccina...
# ...                                                 ...
# 1001  @coats1234 She posted something anti vaccinati...
# 1002  I’ve never been anti vaccination but something...
# 1003  @JohnVetsResist1 I will tell you being in the ...
# 1004  Regarding the anti-vaccination millions in the...
# 1005  This is very good. Especially President Bush s...
#
# [1006 rows x 1 columns]

# %%
anti_vaccine = pd.read_csv("../data/USA/usa_anti_vaccine.csv")
anti_vaccine.drop(columns = "Unnamed: 0", inplace = True)
anti_vaccine
# Out:
#                                                     Text
# 0      Why covering anti-evolution laws has me worrie...
# 1      Federal Conservatives call on anti-vaccine man...
# 2      The DHS has issued a warning to law enforcemen...
# 3      @DGam98 @JonnyC24401853 I'm not anti Vax, anti...
# 4      The DHS has issued a warning to law enforcemen...
# ...                                                  ...
# 16112  For any vegans who follow me... vegan ≠ anti v...
# 16113  Sorry sis but can you say - TUSKEGEE EXPERIMEN...
# 16114  @DrMCecconi Ignore the anti-vaxxers like you i...
# 16115  @TheRickWilson @Lori78986851 Prior to getting ...
# 16116  #MSNBC  #thebeat I am an elder w/multiple\n he...
#
# [16117 rows x 1 columns]

# %%
antivax = pd.read_csv("../data/USA/usa_antivax.csv")
antivax.drop(columns = "Unnamed: 0", inplace = True)
antivax
# Out:
#                                                     Text
# 0      @broc_lee11 @NBCNews You need to pay closer at...
# 1      @canadianaco You don’t speak for me. Happy to ...
# 2      @DGam98 @JonnyC24401853 I'm not anti Vax, anti...
# 3      @AnitaM86 People act like this anti vax moveme...
# 4      @FeehanRichard @Mike_G_YYC #Kenney_UCP_Republi...
# ...                                                  ...
# 12249  @ankleorthopod Spend some time on nutrition Tw...
# 12250  For any vegans who follow me... vegan ≠ anti v...
# 12251  @melanielynngrif @drsimonegold Fine, I am not ...
# 12252  This is DISGUSTING behavior. I don’t care if y...
# 12253  I can’t believe how many people are anti vax.....
#
# [12254 rows x 1 columns]

# %%
antivaxxer = pd.read_csv("../data/USA/usa_antivaxxer.csv")
antivaxxer.drop(columns = "Unnamed: 0", inplace = True)
antivaxxer
# Out:
#                                                    Text
# 0     @GOP Republicans are financing the Canadian tr...
# 1     I’ll wear a mask until the last antivaxxer has...
# 2     Imagine how far Brooklyn could have gone if Ky...
# 3     @JeyFNRow All I wanna know of hes an antivaxxe...
# 4     Scratch an antivaxxer &amp; y’all always find ...
# ...                                                 ...
# 2455  @SydesJokes Colin I guess you would consider m...
# 2456  Letitia Wright is a whole antivaxxer and the c...
# 2457  why oh why did I pick a fight with an antivaxx...
# 2458  The antivaxxer cries of martyrdom are gonna be...
# 2459  Did I just share a news article on Facebook th...
#
# [2460 rows x 1 columns]

# %%
boostershot = pd.read_csv("../data/USA/usa_booster_shot.csv")
boostershot.drop(columns = "Unnamed: 0", inplace = True)
boostershot
# Out:
#                                                     Text
# 0      @peabodypress @hall_loraine @CCryptonaire Go g...
# 1      @AP Do not understand why @CDCgov and @US_FDA ...
# 2      No matter how you slice it*, 4/5 of Canadians ...
# 3      Need your first shot?  A booster?  Come to Rub...
# 4      This booster shot got me more fucked up than a...
# ...                                                  ...
# 24576  -allowing you to expand more fully and move fo...
# 24577  @RepSwalwell @realDonaldTrump Mr. Swalwell, pa...
# 24578  @Heathhooperstar @CarrieDDahl Yes i had chicke...
# 24579  @becca74721600 The 15 and the 22 of this month...
# 24580  @NewDay @drsanjaygupta \nIf there is a concern...
#
# [24581 rows x 1 columns]

# %%
effectivevaccine = pd.read_csv("../data/USA/usa_effective_vaccine.csv")
effectivevaccine.drop(columns = "Unnamed: 0", inplace = True)
effectivevaccine
# Out:
#                                                     Text
# 0      @DailySignal @RandPaul By my calculations mid ...
# 1      @SenatorLankford Why are you pushing natural i...
# 2      @IgorForHire @RepThomasMassie Sure. But then y...
# 3      i’m pro vaxx and double vaxxed myself, but to ...
# 4      @frozen_Tundra12 @michaelkramerSB @kuhnj30 No ...
# ...                                                  ...
# 13373  @RChilderhose @vankayak @cathmckenna @erinotoo...
# 13374  If we get a safe and effective vaccine, I’d li...
# 13375  Excited to learn more about the path to approv...
# 13376  Morderna 100% effective Vaccine for COVID-19 C...
# 13377  Yes indeed,  but Morderna Vaccine is 100% effe...
#
# [13378 rows x 1 columns]

# %%
immunocompromised = pd.read_csv("../data/USA/usa_immunocompromised.csv")
immunocompromised.drop(columns = "Unnamed: 0", inplace = True)
immunocompromised
# Out:
#                                                    Text
# 0     “Not everyone is equally burdened by the pande...
# 1     @soopajx it's the idea that catching the virus...
# 2     Wear you masks, live your life. If you are imm...
# 3     With everyone going madkless. I have to say I'...
# 4     @joncoopertweets Yes. \nI never wore a mask to...
# ...                                                 ...
# 8716  ok not to be dramatic but as an immunocompromi...
# 8717  @emily_fri And what fraction of “? PCP — GGO i...
# 8718  We’ve tried on both our accounts, mine is new,...
# 8719  Dear @AirbnbHelp, For some reason we can’t boo...
# 8720  @thekoreanvegan I DO support them being BARRED...
#
# [8721 rows x 1 columns]

# %%
mandatedvaccine = pd.read_csv("../data/USA/usa_mandated_vaccine.csv")
mandatedvaccine.drop(columns = "Unnamed: 0", inplace = True)
mandatedvaccine
# Out:
#                                                    Text
# 0     @DGam98 @JonnyC24401853 I'm not anti Vax, anti...
# 1     @DelanoSquires But we all were mandated to be ...
# 2     @ShannonSkalos Literally no other developed co...
# 3     @jeff_nidiffer @MSNBC @AliVelshi Vaccines have...
# 4     @gavin1581 @koinosuke @PremierScottMoe Sure it...
# ...                                                 ...
# 3148  I really hope there’s no “my body, my choice” ...
# 3149  @AsteadWesley I notice that UK/African friends...
# 3150  @AgentScully64 @BTtoronto Children do not need...
# 3151  @amyhsin @elizashapiro @NYCMayor @nytimes @NYG...
# 3152  Vaccines are only MANDATORY for children who w...
#
# [3153 rows x 1 columns]

# %%
nevervaccine = pd.read_csv("../data/USA/usa_never_vaccine.csv")
nevervaccine.drop(columns = "Unnamed: 0", inplace = True)
nevervaccine
# Out:
#                                                    Text
# 0     @ChrisSchloemer @drewmckevitt And you injected...
# 1     And so what?!?  \n\nThat 20% of the population...
# 2     @tottwriter @patrushkaz @chrischirp @ashishkjh...
# 3     @QueenoftheUnde6 @bim_pure @GRHutchinson @CamM...
# 4     @6to12elbow The pro masks forever. The pro vac...
# ...                                                 ...
# 6282  @CoachDGraves7 Never will get  Vaccine, its tr...
# 6283  @WhatWeat @COHoney88 Trump never said he made ...
# 6284  @prchovanec I’ve had over 20 (maybe 30?) close...
# 6285  not y’all scared of the COVID vaccine...we’ll ...
# 6286  @Bret_Sears @erinotoole @JustinTrudeau @theJag...
#
# [6287 rows x 1 columns]

# %%
trustvaccine = pd.read_csv("../data/USA/usa_trust_vaccine.csv")
trustvaccine.drop(columns = "Unnamed: 0", inplace = True)
trustvaccine
# Out:
#                                                    Text
# 0     @Decadence_3 @VerifyThis When this all started...
# 1     @2closetocall @anderson_spence The mainstream ...
# 2     Who can trust Irving?  You can’t trust him to ...
# 3     MaximeBernier: “Candice Bergen has ended days ...
# 4     “Candice Bergen has ended days of support for ...
# ...                                                 ...
# 7438  Joy Reid: Black People May Not Trust Vaccine D...
# 7439  I AIN’T BLACK AND I STILL DO NOT TRUST THOSE L...
# 7440  Didn't you say you wouldn't trust a vaccine de...
# 7441  @PressSec @realDonaldTrump Yes and Kamala told...
# 7442  If Clinton was elected rather than Trump, and ...
#
# [7443 rows x 1 columns]

# %%
unvaccinated = pd.read_csv("../data/USA/usa_unvaccinated.csv")
unvaccinated.drop(columns = "Unnamed: 0", inplace = True)
unvaccinated
# Out:
#                                                     Text
# 0      @ericowensdc @RadioFreeTom @FuzzyDanSo @bobsal...
# 1      @BrianTorri @RadioFreeTom @FuzzyDanSo @bobsalp...
# 2      @AP Because some ignorant selfish people don’t...
# 3      @ERoosevelt9 @lionsdenmother1 @joncoopertweets...
# 4      @Noahpinion Some schools, some offices, certai...
# ...                                                  ...
# 67703  @DrTomFrieden @CDCgov Even thinking of keeping...
# 67704  @CNN @GovRonDeSantis @jaytrumbull @SenatorGain...
# 67705  @Dexter131 @RobynUrback @erinotoole You do you...
# 67706                  @Dr_Of_Style Ma Tuck unvaccinated
# 67707  Oh joy. While locked down unvaccinated we can ...
#
# [67708 rows x 1 columns]

# %%
vaccinated = pd.read_csv("../data/USA/usa_vaccinated.csv")
vaccinated.drop(columns = "Unnamed: 0", inplace = True)
vaccinated
# Out:
#                                                      Text
# 0       @Julirose @apple_shamp0o @Aviendha69 @Snowden ...
# 1       @R11RT @TheoMoudakis @TorontoStar I guess as a...
# 2       @WAPFLondon @CDCgov Individual responsibility ...
# 3       @CheyenneGames @jhaletweets @TheJohnDiMaggio M...
# 4                           @terr3tme Granny must pleased
# ...                                                   ...
# 99996   @DSORennie @DenisMacShane David, New York City...
# 99997   @djhomicide Half my friends sick af. All vacci...
# 99998   @TraceyM0802 Merry Christmas! 🎄 I hope things ...
# 99999   Vaccinated North Miami Councilman Alix Desulme...
# 100000  @rick_pittman How does wearing a mask or getti...
#
# [100001 rows x 1 columns]

# %%
vaccinesaveslives = pd.read_csv("../data/USA/usa_vaccinesaveslives.csv")
vaccinesaveslives.drop(columns = "Unnamed: 0", inplace = True)
vaccinesaveslives
# Out:
#                                                  Text
# 0   @Vincentvega56 @rainglock @JForma @DefiantLs @...
# 1   No me refería a este positivo 😅😅#Positivo #Cov...
# 2   #MaskUp #vaccinesaveslives https://t.co/BRsY3J...
# 3   Still wearing a mask. Still testing regularly....
# 4   This note from the analysis is important to ma...
# 5   #VaccineMandates #VaccinEquity #vaccineinjured...
# 6   #bravekids #vaccinesaveslives https://t.co/ea5...
# 7   Fun fact: the "generally useless as a measurem...
# 8   90%!!!!!! Keep getting vaxed #vaccinesaveslive...
# 9   Keep going Rhody!! We’ve got this!! #VaccineSa...
# 10         #vaccinesaveslives https://t.co/pO3Dx1jhNs
# 11  Your daily reminder to get your fucking vaccin...
# 12  Thank you @drcynthiagyamfi ! #VaccineSavesLive...
# 13  @TimHannan And we ALL want that mental giant t...
# 14  @AvrahamCooperMD Horrible. Seeing it so many t...
# 15  Acute #stroke #covid pneumonia #novax #coronav...
# ...

# %%
frames = [anti_vaccination, anti_vaccine, antivax, antivaxxer, boostershot, effectivevaccine, immunocompromised, mandatedvaccine, nevervaccine, trustvaccine, unvaccinated, vaccinated, vaccinesaveslives]

result = pd.concat(frames)

# %%
result
# Out:
#                                                  Text
# 0   So.... Conservative Anti-Abortion Anti-Vaccina...
# 1   @saletan @theabstoddard As you might know, the...
# 2   The "regime spokespeople" (MSM) keep referring...
# 3   @maureviv The doctors who were outraged that o...
# 4   Manchin voted for Sen. Mike Lee’s anti-vaccina...
# ..                                                ...
# 30  Do it for others.... 💪🎉💉🤙 #vaccinesaveslives h...
# 31  Got my first Pfizer shot today. Feeling well!\...
# 32  #FauciOuchie #2 #vaccinated #vaccinesaveslives...
# 33  @RyanBJackson1 Yay! 🙌🏻 Congrats Dr. J! Being f...
# 34  We all have to do our part to end this pandemi...
#
# [263144 rows x 1 columns]

# %%
tweet_text_list = result['Text'].tolist()

tweet_text_list
# Out:
# ["So.... Conservative Anti-Abortion Anti-Vaccination people.... thoughts?\n\nAnd prayers, can't forget the prayers... https://t.co/gPydNIjV9T",
#  '@saletan @theabstoddard As you might know, the less you know about a topic, the more you believe in it e.g. anti-vaccination Republican supporters!',
#  'The "regime spokespeople" (MSM) keep referring to the "anti-vaccination sentiment" of the protests. Are they totally clueless or just trying to create a false narrative? The protests reflect an ANTI-MANDATE sentiment. They must know this since 90% of truckers are vaccinated. https://t.co/lpyiBL61Yk',
#  '@maureviv The doctors who were outraged that other doctors were honestly discussing sided effects etc. and saying it would stop people vaccinating… are mostly the same doctors insisting kids don’t need vaccinations, and using the language of the anti vaccination crusaders.',
# ...

# %%
import numpy as np
import re

# %%
stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from", "curfew", "curfews", "vaccine", "covid", "vaccines","vaccinated","vaccination", "weekend", "lockdown", "day", "night", "amp", "pm", "am", "will"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
cleaned_tweets = [clean_tweet(tw) for tw in tweet_text_list]
cleaned_tweets
# Out:
# /var/folders/pk/mh54kmcs083ggkf50q9s_r1c0000gn/T/ipykernel_62063/2485735798.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['so conservative anti abortion anti people thoughts prayers cant forget prayers',
#  'as you might know less you know about topic more you believe it e g anti republican supporters',
#  'regime spokespeople msm keep referring anti sentiment protests are they totally clueless or just trying create false narrative protests reflect anti mandate sentiment they must know this since 90 truckers are',
# ...

# %%
print(len(cleaned_tweets))
# Out:
# 263144

# %%
cleaned_list = list( dict.fromkeys(cleaned_tweets) )
print(len(cleaned_list))
# Out:
# 239087

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in cleaned_list:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
