# %%
import pandas as pd

# %%
moderna = pd.read_csv("../data/USA/vaccine types/usa_moderna.csv")
moderna.drop(columns = "Unnamed: 0", inplace = True)
moderna
# Out:
#                                                     Text
# 0      Truth --- #Malone \n\nBaillie Gifford &amp; Co...
# 1      @pcrritesgood @6eustacia @JesseKellyDC I lost ...
# 2      Need your first shot?  A booster?  Come to Rub...
# 3      @NoorAli60402024 @kit10219512 @blane1122 We ha...
# 4      @JoyceWhiteVance Weekday does immunize mean he...
# ...                                                  ...
# 56332  @ABC Here is a short video about the Moderna C...
# 56333  @ABC @ABCNewsLive Here is a short video about ...
# 56334  @CNN Here is a short video about the Moderna C...
# 56335  @CNN Here is a short video about the Moderna C...
# 56336  @ABTudorQueen According to the CDC there are  ...
#
# [56337 rows x 1 columns]

# %%
pfizer = pd.read_csv("../data/USA/vaccine types/usa_pfizer.csv")
pfizer.drop(columns = "Unnamed: 0", inplace = True)
pfizer
# Out:
#                                                     Text
# 0      @sluchetti @massimogara @borghi_claudio Evito ...
# 1      I wonder how many in our leadership in the US ...
# 2      @MeetDogBlack1 @joncoopertweets What's in the ...
# 3      @Writingwithabi1 @TPaine1988 @CookDayNight @th...
# 4      Pfizer made an unreal $36.8 BILLION from its C...
# ...                                                  ...
# 96061  Why would his financial advisors make such spe...
# 96062  @PressSec @realDonaldTrump He can only take cr...
# 96063  @NickiZvik @GavinNewsom I think Pfizer and Mod...
# 96064  @ABTudorQueen According to the CDC there are  ...
# 96065       Habemus vacunas!!! Next month thanks @pfizer
#
# [96066 rows x 1 columns]

# %%
janssen = pd.read_csv("../data/USA/vaccine types/usa_janssen.csv")
janssen.drop(columns = "Unnamed: 0", inplace = True)
janssen
# Out:
#                                                    Text
# 0     One of my favourite things to do in this job i...
# 1     Happy to support a local small business with m...
# 2        @AlexCVassar @CAStateLibrary What a dream job!
# 3     @JuiceboxCA brand-centricity is the antithesis...
# 4                         Woah. https://t.co/9RQf0d9aw7
# ...                                                 ...
# 5089  Good milestone for Janssen’s vaccine candidate...
# 5090  Research teams at University of Kentucky, Bapt...
# 5091  📣🆕#️⃣SesiónMensual Diciembre\n@coleurolgto 🇲🇽 ...
# 5092  @PattyArquette @donwinslow Correct! I am a vol...
# 5093  @ABTudorQueen According to the CDC there are  ...
#
# [5094 rows x 1 columns]

# %%
frames = [janssen, pfizer, moderna]

result = pd.concat(frames)

# %%
result
# Out:
#                                                     Text
# 0      One of my favourite things to do in this job i...
# 1      Happy to support a local small business with m...
# 2         @AlexCVassar @CAStateLibrary What a dream job!
# 3      @JuiceboxCA brand-centricity is the antithesis...
# 4                          Woah. https://t.co/9RQf0d9aw7
# ...                                                  ...
# 56332  @ABC Here is a short video about the Moderna C...
# 56333  @ABC @ABCNewsLive Here is a short video about ...
# 56334  @CNN Here is a short video about the Moderna C...
# 56335  @CNN Here is a short video about the Moderna C...
# 56336  @ABTudorQueen According to the CDC there are  ...
#
# [157497 rows x 1 columns]

# %%
tweet_text_list = result['Text'].tolist()

tweet_text_list
# Out:
# ['One of my favourite things to do in this job is to pick up the phone and call a client to tell them that their PR has been approved',
#  'Happy to support a local small business with my prize from winning the trivia at the @TVRSCIA AGM last week! https://t.co/AB5vE5PtWI',
#  '@AlexCVassar @CAStateLibrary What a dream job!',
#  '@JuiceboxCA brand-centricity is the antithesis of marketing.  I’m consistently surprised how frequently it happens',
#  'Woah. https://t.co/9RQf0d9aw7',
#  '@HalSparks My HS crush. 🥰😍',
#  "One of my very favorites.\nThat white haired woman over Harrison Ford's shoulder?\nThat's David Janssen's mother. https://t.co/mCwtwHgukG",
#  'European Commissions Role In Policy Making European Commissions Role In Policy Making. \nJanssen, Wimmer, and Delijoo (2015) https://t.co/FGtLP9KDWJ',
#  'Te quiero mucho Janssen de la femenil que sí anota goles https://t.co/heV5fkkYAq',
#  'https://t.co/aQHOF6Gk0z',
#  'Macho en Spetter https://t.co/z1lOcgtf7p',
# ...

# %%
unique_list = list( dict.fromkeys(tweet_text_list) )
print(len(unique_list))
# Out:
# 142406

# %%
import numpy as np
import re

# %%
stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from",  "vaccine", "covid", "pfizer", "moderna", "janssen", "vaccines","vaccinated","vaccination", "day", "night", "amp", "pm", "am", "will"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
cleaned_tweets = [clean_tweet(tw) for tw in unique_list]
cleaned_tweets
# Out:
# <ipython-input-10-8ad76bbae69d>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['one my favourite things do this job is pick up phone call client tell them that their pr has been approved',
#  'happy support local small business with my prize winning trivia at agm last week',
#  'what dream job',
#  'brand centricity is antithesis marketing i m consistently surprised how frequently it happens',
#  'woah',
#  'my hs crush',
#  'one my very favorites that white haired woman over harrison fords shoulder thats david janssens mother',
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in cleaned_tweets:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
