# %%
import pandas as pd

# %%
nz = pd.read_csv("../data/New Zealand/nz_vaccine_pass.csv")
nz.drop(columns = "Unnamed: 0", inplace = True)
nz
# Out:
#                                                   Text
# 0    Would be fascinating to know what % are actual...
# 1    @Farq_Doff I bet the thing they're really worr...
# 2    @ArendtRead Yeah. Around 2000 people the first...
# 3    @SciBuff82 Its a tragic story. Beyond terrible...
# 4    @samanthamaiden @JoshFrydenberg i have only se...
# ..                                                 ...
# 422  "Pfizer and BioNTech say their vaccine is '95%...
# 423  @iammarkcarnegie I’m so pro vaccine it hurts b...
# 424  Covid-19 fun facts:\n§ Kids catch and pass on ...
# 425  Me [in a state of panic]: “What happens if I’v...
# 426  #Vaccines currently in Phase II of the clinica...
#
# [427 rows x 1 columns]

# %%
tweet_text_list = nz['Text'].tolist()

tweet_text_list
# Out:
# ['Would be fascinating to know what % are actually impacted by a vaccine mandate vs inconvenienced by it not having a vaccine pass.',
#  "@Farq_Doff I bet the thing they're really worried about is that you're more infectious and have more serious implications than Omicron. And once we pass on this dangerous disease of questioning the narrative Jacinda and Co will realise there's no vaccine available...",
#  "@ArendtRead Yeah. Around 2000 people the first day in Wellington (probably another thousand or so in the South Island because they didn't realise you can't get on the ferry without ID and a Vaccine pass or negative Covid test). Numbers now dwindled to a couple of hundred people?",
#  '@SciBuff82 Its a tragic story. Beyond terrible...had a friend today whose 8yo daughter wanted the vax to play sport etc. 13 minutes after the jab, went grey, passed out. All the medical crew refused to recognise it was vaccine related. \n..\nShe seems ok now thankfully. \n\nThe future though?',
# ...

# %%
import numpy as np
import re

# %%
stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from",  "lockdown", "level", "new zealand", "will"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
cleaned_tweets = [clean_tweet(tw) for tw in tweet_text_list]
cleaned_tweets
# Out:
# <ipython-input-6-773a689e3166>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['would be fascinating know what are actually impacted by vaccine mandate vs inconvenienced by it not having vaccine pass',
#  'i bet thing theyre really worried about is that youre more infectious have more serious implications than omicron once we pass this dangerous disease questioning narrative jacinda co realise theres no vaccine available',
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in cleaned_tweets:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
cpf = pd.read_csv("../data/New Zealand/nz_covid19_protection_framework.csv")
cpf.drop(columns = "Unnamed: 0", inplace = True)
cpf
# Out:
#                                                  Text
# 0   GlobalPlatform’s new #SecureElement protection...
# 1   Really good read on the IAB's Transparency and...
# 2   @Kenmorrey92 Agreed children do need protectio...
# 3   #ICYMI A widely used framework for implementin...
# 4   We thought about whether equal protection focu...
# 5   Belgian Data Protection Authority fined IAB EU...
# 6   Due to the recent move to the COVID-19 Protect...
# 7   Secure work-from-anywhere can be a reality wit...
# 8   Secure work-from-anywhere can be a reality wit...
# 9   Axient’s cybersecurity professionals perform c...
# 10  Secure work-from-anywhere can be a reality wit...
# 11  Secure work-from-anywhere can be a reality wit...
# 12  Secure work-from-anywhere can be a reality wit...
# 13  Secure work-from-anywhere can be a reality wit...
# 14  Secure work-from-anywhere can be a reality wit...
# 15  Secure work-from-anywhere can be a reality wit...
# ...

# %%
ir = pd.read_csv("../data/New Zealand/nz_interest_rate.csv")
ir.drop(columns = "Unnamed: 0", inplace = True)
ir
# Out:
#                                                   Text
# 0    Price\n\nCost within reach for most investors\...
# 1    @CollieYimby I could probably get an unsecured...
# 2    @CBlaine72 @SeanMcCoyPhotog Can you refinance ...
# 3    @akin_gbe_leo When people do not think or spea...
# 4    @BofA_News Me: Can you lower my CC interest ra...
# ..                                                 ...
# 189  Did you know a higher FICO score can result in...
# 190  @SenSanders With what money? Will I be refunde...
# 191  @erin18_ @CobraShelby86 @DrunkBrianF Not stick...
# 192  @scatteredmom @Mommyisweird Recently divorced ...
# 193  @Hannah_Nichole7 I would check the interest ra...
#
# [194 rows x 1 columns]
