# %%
import pandas as pd

# %%
wld_delhi = pd.read_csv("../data/India/weekend lockdown/Delhi_Lockdown_Weekend.csv")
wld_delhi.drop(columns = ["Datetime", "Username", "Tweet Id"], inplace = True)
wld_delhi
# Out:
#                                                    Text
# 0     Lifting weekend lockdown right decision at rig...
# 1     Jammu &amp; Kashmir Government’s decision to l...
# 2     Lifting weekend lockdown right decision at rig...
# 3     Jammu and Kashmir Covid-19 guidelines: No week...
# 4     JAMMU: Jammu &amp; Kashmir Government's decisi...
# ...                                                 ...
# 1563  This past weekend I decided to take quick acti...
# 1564  A 3 day complete country wide Lockdown is need...
# 1565  Quarantine activities!\nSkate everyday.\n\n#in...
# 1566  Hindi lang pang Biyernes, pang Weekend din.. M...
# 1567  #Quarantine #QuarantineLife #lockdown #Corona ...
#
# [1568 rows x 1 columns]

# %%
wld_mumbai = pd.read_csv("../data/India/weekend lockdown/Mumbai_Lockdown_Weekend.csv")
wld_mumbai.drop(columns = ["Datetime", "Username", "Tweet Id"], inplace = True)
wld_mumbai
# Out:
#                                                  Text
# 0   After First and Second lockdown, Weekend lockd...
# 1   Covid: No weekend lockdown in J&amp;K; night c...
# 2   New Tumblr post: "Jammu and Kashmir Covid-19 g...
# 3   #VeeramaeVaagaiSoodum ends it domestic opening...
# 4   JK Govt Lifts Weekend Lockdown, Coaching Centr...
# 5   Omicron variant LIVE Updates: No weekend lockd...
# 6   JK Govt Lifts Weekend Lockdown, Coaching Centr...
# 7   #COVID19: Jammu &amp; Kashmir State Executive ...
# 8   COVID-19: J&amp;K govt relaxes night curfew ti...
# 9   Covid-19: No Weekend Lockdown in J&amp;K; Nigh...
# 10  Covid: No weekend lockdown in J&amp;K; night c...
# 11  Omicron variant LIVE Updates: No weekend lockd...
# 12  Omicron variant LIVE Updates: No weekend lockd...
# 13  Jammu and Kashmir Covid-19 guidelines: No week...
# 14  As Covid cases decline, govt lifts weekend loc...
# 15  #JammuKashmir State Executive Committee ends  ...
# ...

# %%
wld_punjab = pd.read_csv("../data/India/weekend lockdown/Punjab_Lockdown_Weekend.csv")
wld_punjab.drop(columns = ["Datetime", "Username", "Tweet Id"], inplace = True)
wld_punjab
# Out:
#                                                    Text
# 0                  Weekend lock down lifted at kerala 🤩
# 1     Lifting weekend lockdown right decision at rig...
# 2     Jammu &amp; Kashmir Government’s decision to l...
# 3     Lifting weekend lockdown right decision at rig...
# 4     Jammu and Kashmir Covid-19 guidelines: No week...
# ...                                                 ...
# 1482  What #moms feel as they step into the #weekend...
# 1483  Best part of #Lockdown21 is , Wife is not maki...
# 1484  #lockdown #COVID19Pandemic #StayHomeSaveLives ...
# 1485  G&amp;T time! No limes... #lockdown #weekend @...
# 1486  Coming live in Instagram this weekend!!timings...
#
# [1487 rows x 1 columns]

# %%
wld_tn = pd.read_csv("../data/India/weekend lockdown/TamilNadu_Lockdown_Weekend.csv")
wld_tn.drop(columns = ["Datetime", "Username", "Tweet Id"], inplace = True)
wld_tn
# Out:
#                                                    Text
# 0                  Weekend lock down lifted at kerala 🤩
# 1     (3 piece thread) \n\nThis weekend we chiseled ...
# 2     So #Aaraattu is ready for a mass weekend 💥\n\n...
# 3     So #Aaraattu is ready for a mass weekend 💥\n\n...
# 4     China Imposes Lockdown on 3.5MN after 100 Covi...
# ...                                                 ...
# 1580  Weekend - lockdown diri sendiri dari apapun it...
# 1581  Sambil2 lepak weekend lockdown ni, jom layan a...
# 1582  @narendramodi @mygovindia Hello Sir,\n I have ...
# 1583  Be calm, stay home, binge-watch Kdramas, and d...
# 1584  Since our family has declared a "lock down" fo...
#
# [1585 rows x 1 columns]

# %%
frames = [wld_delhi, wld_mumbai, wld_punjab, wld_tn]

result = pd.concat(frames)

# %%
result
# Out:
#                                                    Text
# 0     Lifting weekend lockdown right decision at rig...
# 1     Jammu &amp; Kashmir Government’s decision to l...
# 2     Lifting weekend lockdown right decision at rig...
# 3     Jammu and Kashmir Covid-19 guidelines: No week...
# 4     JAMMU: Jammu &amp; Kashmir Government's decisi...
# ...                                                 ...
# 1580  Weekend - lockdown diri sendiri dari apapun it...
# 1581  Sambil2 lepak weekend lockdown ni, jom layan a...
# 1582  @narendramodi @mygovindia Hello Sir,\n I have ...
# 1583  Be calm, stay home, binge-watch Kdramas, and d...
# 1584  Since our family has declared a "lock down" fo...
#
# [4671 rows x 1 columns]

# %%
tweet_text_list = result['Text'].tolist()

tweet_text_list
# Out:
# ['Lifting weekend lockdown right decision at right time: CCI https://t.co/4ZV44DAWqn',
#  'Jammu &amp; Kashmir Government’s decision to lift weekend lockdown has came at a right time as the business community of Jammu was already going through crisis due to prevailing pandemic situation.\n\nThis was stated by Arun Gupta, president, Chamber of\n\nhttps://t.co/YcuGWjfmU3 https://t.co/ffhx5b8Rvg',
#  'Lifting weekend lockdown right decision at right time: CCI\n\nhttps://t.co/jlFOGFWtdb https://t.co/ddPFetmJKS',
#  'Jammu and Kashmir Covid-19 guidelines: No weekend lockdown, night curfew relaxed by one hour, check here | India News https://t.co/exwHtv2ma0',
#  "JAMMU: Jammu &amp; Kashmir Government's decision to lift weekend lockdown has came at a right time as the business community of Jammu was already going through crisis due to prevailing pandemic situation.\n\nRead more at: https://t.co/NjnjLeYQ6A https://t.co/EWLlxaNPFT",
# ...

# %%
import numpy as np
import re

# %%
stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from", "curfew", "curfews", "weekend", "lockdown", "day", "night", "amp", "pm", "am", "will"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
cleaned_tweets = [clean_tweet(tw) for tw in tweet_text_list]
cleaned_tweets
# Out:
# <ipython-input-13-343fb61971f4>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['lifting right decision at right time cci',
#  'jammu kashmir government s decision lift has came at right time as business community jammu was already going through crisis due prevailing pandemic situation this was stated by arun gupta president chamber',
#  'lifting right decision at right time cci',
#  'jammu kashmir covid 19 guidelines no relaxed by one hour check here india news',
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in cleaned_tweets:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
