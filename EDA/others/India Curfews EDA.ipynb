# %%
import pandas as pd

# %%
curfews_delhi = pd.read_csv("../data/India/curfews/Delhi_Lockdown_Curfew.csv")

# %%
curfews_delhi.drop(columns = ["Datetime", "Username", "Tweet Id"], inplace = True)

# %%
curfews_delhi
# Out:
#                                                     Text
# 0      Mother whose son was killed by illegal migrant...
# 1      @UpYogiVikas Curfew lga h 11 to 5 😐 subah khul...
# 2      Gujarat relaxes Covid-induced night curfew in ...
# 3      Covid-19: Tripura government imposes night cur...
# 4      Gujarat: Night Curfew Shortened in Eight Citie...
# ...                                                  ...
# 9996   Shops, groceries &amp; pharmacies in Quarantin...
# 9997   @imZahran Ha ha. From gliders, A380s to super ...
# 9998   @nazly @DawnPDSi I’m using Prima to make dumpl...
# 9999   "Macron announces nightly curfew in major Fren...
# 10000  A curfew banning people from leaving home at n...
#
# [10001 rows x 1 columns]

# %%
curfew_delhi = pd.read_csv("../data/India/curfews/Delhi_Lockdown_Curfews.csv")
curfew_delhi.drop(columns = ["Datetime", "Username", "Tweet Id"], inplace = True)
curfew_delhi
# Out:
#                                                   Text
# 0              @ANI Night curfews were a joke anyways🤣
# 1    Be it riots in Kosi Kalan or Muzaffarnagar, Sa...
# 2    Internet shutdowns and curfews cannot stop thi...
# 3    @ARanganathan72 @richaanirudh I never saw a ka...
# 4    From beating internet shutdowns to curfews, @f...
# ..                                                 ...
# 677  O Sanghis,\nThis ‘Free Kashmir’doesn’t necessa...
# 678  @AnupamPKher This ‘Free Kashmir’doesn’t necess...
# 679  @rajuparulekar Exactly, It means freedom from ...
# 680  Curfews "restrictions "atrocities " blockade "...
# 681  (2/3) saffron terrorism. Shame on you @myogiad...
#
# [682 rows x 1 columns]

# %%
curfews_mumbai = pd.read_csv("../data/India/curfews/Mumbai_Lockdown_Curfew.csv")
curfews_mumbai.drop(columns = ["Datetime", "Username", "Tweet Id", "Unnamed: 0"], inplace = True)
curfews_mumbai
# Out:
#                                                    Text
# 0     @UpYogiVikas Curfew lga h 11 to 5 😐 subah khul...
# 1     Covid-19: Tripura government imposes night cur...
# 2     Night Curfew no crowd\nIn night so night curfe...
# 3     Gujarat: Night Curfew Shortened in Eight Citie...
# 4     Gujarat Covid-19 update: Night curfew reduced ...
# ...                                                 ...
# 5875  They may have imposed the CAA on us today. But...
# 5876  Author @Vineet_Bajpai talking at @VESIMLitFest...
# 5877  @syedmohammedd My Question why Govt imposed\nS...
# 5878  @khimaanshu Come on frd, don't U know what doe...
# 5879  @hydcitypolice @TelanganaDGP is there a curfew...
#
# [5880 rows x 1 columns]

# %%
curfew_mumbai = pd.read_csv("../data/India/curfews/Mumbai_Lockdown_Curfews.csv")
curfew_mumbai.drop(columns = ["Datetime", "Username", "Tweet Id", "Unnamed: 0"], inplace = True)
curfew_mumbai
# Out:
#                                                   Text
# 0              @ANI Night curfews were a joke anyways🤣
# 1    As per Team, #BheemlaNayakOnFeb25th only if Ni...
# 2    Be it riots in Kosi Kalan or Muzaffarnagar, Sa...
# 3    Be it riots in #KosiKalan or Muzaffarnagar, Sa...
# 4    Be it riots in Kosi Kalan or Muzaffarnagar, Sa...
# ..                                                 ...
# 124  Rationed supplies arriving in vans, curfews, b...
# 125  Someone teach him about Marshall McLuhan pleas...
# 126  @AnupamPKher This ‘Free Kashmir’doesn’t necess...
# 127  @rajuparulekar Exactly, It means freedom from ...
# 128  (2/3) saffron terrorism. Shame on you @myogiad...
#
# [129 rows x 1 columns]

# %%
curfews_punjab = pd.read_csv("../data/India/curfews/Punjab_Lockdown_Curfew.csv")
curfews_punjab.drop(columns = ["Datetime", "Username", "Tweet Id", "Unnamed: 0"], inplace = True)
curfews_punjab
# Out:
#                                                     Text
# 0      Gujarat: Night Curfew Shortened in Eight Citie...
# 1      11 Feb marked a great day of Islamic revolutio...
# 2      Gujarat: Night Curfew Shortened in Eight Citie...
# 3      Gujarat: Night Curfew Shortened in Eight Citie...
# 4      Pre BJP govt, in UP I gave every exam in curfe...
# ...                                                  ...
# 10996  @CPBlr no curfew,no mask, no rules followed at...
# 10997  #Odisha Weekend shutdown in these 10 districts...
# 10998  Night Curfew relaxed in Odisha; 9 PM to 5 AM t...
# 10999  .@SecyChief Asit Tripathy says schools &amp; c...
# 11000  Night curfew will be from 9 pm to 5 am instead...
#
# [11001 rows x 1 columns]

# %%
curfew_punjab = pd.read_csv("../data/India/curfews/Punjab_Lockdown_Curfews.csv")
curfew_punjab.drop(columns = ["Datetime", "Username", "Tweet Id", "Unnamed: 0"], inplace = True)
curfew_punjab
# Out:
#                                                   Text
# 0    Be it riots in Kosi Kalan or Muzaffarnagar, Sa...
# 1    Be it riots in Kosi Kalan or Muzaffarnagar, Sa...
# 2    From beating internet shutdowns to curfews, @f...
# 3    #Covid_19 played huge role in ruining the #Val...
# 4    From beating internet shutdowns to curfews, @f...
# ..                                                 ...
# 717  O Sanghis,\nThis ‘Free Kashmir’doesn’t necessa...
# 718  @AnupamPKher This ‘Free Kashmir’doesn’t necess...
# 719  @rajuparulekar Exactly, It means freedom from ...
# 720  Curfews "restrictions "atrocities " blockade "...
# 721  (2/3) saffron terrorism. Shame on you @myogiad...
#
# [722 rows x 1 columns]

# %%
curfews_tamil = pd.read_csv("../data/India/curfews/TamilNadu_Lockdown_Curfew.csv")
curfews_tamil.drop(columns = ["Datetime", "Username", "Tweet Id", "Unnamed: 0"], inplace = True)
curfews_tamil
# Out:
#                                                     Text
# 0      Gujarat: Night Curfew Shortened in Eight Citie...
# 1      Gujarat: Night Curfew Shortened in Eight Citie...
# 2      Night Curfew no crowd\nIn night so night curfe...
# 3      Gujarat: Night Curfew Shortened in Eight Citie...
# 4      Dad bought himself a bottle of rum for the nig...
# ...                                                  ...
# 10996  @suraj_yadav2005 @Sunitayadav1143 @SunitaYadav...
# 10997  Request @ProshuncTOI @anjayaaTOI to please ver...
# 10998  No reason for island-wide #curfew yet! #lka #S...
# 10999  @HinaRohtaki @iepunjab Weekend curfew is a big...
# 11000  A fearless Lady Constable #SunitaYadav Slams t...
#
# [11001 rows x 1 columns]

# %%
curfew_tamil = pd.read_csv("../data/India/curfews/TamilNadu_Lockdown_Curfews.csv")
curfew_tamil.drop(columns = ["Datetime", "Username", "Tweet Id", "Unnamed: 0"], inplace = True)
curfew_tamil
# Out:
#                                                   Text
# 0    @AskAnshul Because, if its anti nationals dema...
# 1    Welcome move by #tamilnadu government removing...
# 2    Maybe it time for a few curfews before we gott...
# 3    Pls be informed that curfews have been imposed...
# 4    @AkeshChandrasi6 @shivajr11 I'm not talking ab...
# ..                                                 ...
# 385  O Sanghis,\nThis ‘Free Kashmir’doesn’t necessa...
# 386  @AnupamPKher This ‘Free Kashmir’doesn’t necess...
# 387  @rajuparulekar Exactly, It means freedom from ...
# 388  Curfews "restrictions "atrocities " blockade "...
# 389  (2/3) saffron terrorism. Shame on you @myogiad...
#
# [390 rows x 1 columns]

# %%
frames = [curfews_delhi, curfews_mumbai, curfews_punjab, curfews_tamil,curfew_delhi, curfew_mumbai, curfew_punjab, curfew_tamil]

result = pd.concat(frames)

# %%
result
# Out:
#                                                   Text
# 0    Mother whose son was killed by illegal migrant...
# 1    @UpYogiVikas Curfew lga h 11 to 5 😐 subah khul...
# 2    Gujarat relaxes Covid-induced night curfew in ...
# 3    Covid-19: Tripura government imposes night cur...
# 4    Gujarat: Night Curfew Shortened in Eight Citie...
# ..                                                 ...
# 385  O Sanghis,\nThis ‘Free Kashmir’doesn’t necessa...
# 386  @AnupamPKher This ‘Free Kashmir’doesn’t necess...
# 387  @rajuparulekar Exactly, It means freedom from ...
# 388  Curfews "restrictions "atrocities " blockade "...
# 389  (2/3) saffron terrorism. Shame on you @myogiad...
#
# [39806 rows x 1 columns]

# %%
tweet_text_list = result['Text'].tolist()

tweet_text_list
# Out:
# ['Mother whose son was killed by illegal migrant blasts Biden over ‘disgusting’ home curfew program https://t.co/ul9qdgJqWm #SmartNews',
#  '@UpYogiVikas Curfew lga h 11 to 5 😐 subah khulenge ab',
#  'Gujarat relaxes Covid-induced night curfew in 8 major cities. Details here #gujaratcovid #gujaratnightcurfew #gujaratnightcurfew8cities https://t.co/1PYdHUrxxT\nhttps://t.co/wP7b1hTYEZ',
#  'Covid-19: Tripura government imposes night curfew from February 11 The state government has introduced fresh guidelines which said that people (up to 50 percent capacity) are allowed in closed spaces #Latest News by #BusinessStandard https://t.co/1XK8bepgV7',
#  'Gujarat: Night Curfew Shortened in Eight Cities, Lifted in Other\xa0Towns https://t.co/S6XrmBy4Fl',
# ...

# %%
import numpy as np
import re

# %%
stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from", "curfew", "curfews", "weekend", "lockdown", "day", "night", "amp", "pm", "am", "will"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
cleaned_tweets = [clean_tweet(tw) for tw in tweet_text_list]
cleaned_tweets
# Out:
# <ipython-input-51-343fb61971f4>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['mother whose son was killed by illegal migrant blasts biden over disgusting home program',
#  'lga h 11 5 subah khulenge ab',
#  'gujarat relaxes covid induced 8 major cities details here',
#  'covid 19 tripura government imposes february 11 state government has introduced fresh guidelines which said that people up 50 percent capacity are allowed closed spaces news by',
#  'gujarat shortened eight cities lifted other towns',
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in cleaned_tweets:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
