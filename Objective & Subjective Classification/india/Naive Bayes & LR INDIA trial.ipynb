# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("labelled_data_objective_subjective_india.csv")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             1             1
# 1             2             2
# 2             3             3
# 3             4             4
# 4             5             5
# ..          ...           ...
# 995        1458          1458
# 996        1459          1459
# 997        1462          1462
# 998        1463          1463
# 999        1464          1464
#
#                                                   Text  \
# 0    #pickids : about 20,000 children perlis eligib...
# 1    previous covid-19 infection – but not vaccinat...
# 2    india’s covid-19 vaccination coverage crosses ...
# 3    i got call office principal commissioner cgst ...
# 4    i have booked flight 13 feb, 2022 toronto new ...
# ..                                                 ...
# 995  they should allow businesses with reduced capa...
# 996  patiala covid vaccination schedule 12 january🔴...
# 997  hi team, i am trying get covid vaccination cer...
# 998  #dimapur | 11jan 2022: covid-19 vaccination at...
# 999  namaste sir covid 19 precaution dose vaccinati...
#
#                                               new_text languages  \
# 0    #pickids : about 20,000 children perlis eligib...   ENGLISH
# 1    previous covid-19 infection – but not vaccinat...   ENGLISH
# 2    india’s covid-19 vaccination coverage crosses ...   ENGLISH
# 3    i got call office principal commissioner cgst ...   ENGLISH
# 4    i have booked flight 13 feb, 2022 toronto new ...   ENGLISH
# ..                                                 ...       ...
# 995  they should allow businesses with reduced capa...   ENGLISH
# 996  patiala covid vaccination schedule 12 januaryr...   ENGLISH
# 997  hi team, i am trying get covid vaccination cer...   ENGLISH
# 998  #dimapur | 11jan 2022: covid-19 vaccination at...   ENGLISH
# 999  namaste sir covid 19 precaution dose vaccinati...   ENGLISH
#
#                                             translated new_languages  \
# 0    #pickids : about 20,000 children perlis eligib...       ENGLISH
# 1    previous covid-19 infection – but not vaccinat...       ENGLISH
# 2    india’s covid-19 vaccination coverage crosses ...       ENGLISH
# 3    i got call office principal commissioner cgst ...       ENGLISH
# 4    i have booked flight 13 feb, 2022 toronto new ...       ENGLISH
# ..                                                 ...           ...
# 995  they should allow businesses with reduced capa...       ENGLISH
# 996  patiala covid vaccination schedule 12 januaryr...       ENGLISH
# 997  hi team, i am trying get covid vaccination cer...       ENGLISH
# 998  #dimapur | 11jan 2022: covid-19 vaccination at...       ENGLISH
# 999  namaste sir covid 19 precaution dose vaccinati...       ENGLISH
#
#                                       pos_tagged_words  \
# 0    [('pickins', 'NNS'), ('about', 'IN'), ('twenty...
# 1    [('previous', 'JJ'), ('couid', 'NN'), ('ninete...
# 2    [('india', 'NN'), ('i', 'NN'), ('i', 'VBP'), (...
# 3    [('i', 'NN'), ('got', 'VBD'), ('call', 'JJ'), ...
# 4    [('i', 'NNS'), ('have', 'VBP'), ('booked', 'VB...
# ..                                                 ...
# 995  [('they', 'PRP'), ('should', 'MD'), ('allow', ...
# 996  [('patiala', 'NN'), ('couid', 'NN'), ('vaccina...
# 997  [('hi', 'NN'), ('team', 'NN'), ('i', 'NN'), ('...
# 998  [('diaper', 'NN'), ('jan', 'NN'), ('couid', 'N...
# 999  [('namaste', 'NN'), ('sir', 'NN'), ('couid', '...
#
#                                    words_processed_all  \
# 0    ['pickins', 'twenty', 'zero', 'child', 'peril'...
# 1    ['previous', 'couid', 'nineteen', 'infection',...
# 2    ['india', 'couid', 'nineteen', 'vaccination', ...
# 3    ['got', 'call', 'office', 'principal', 'commis...
# 4    ['booked', 'flight', 'thirteen', 'feb', 'toron...
# ..                                                 ...
# 995  ['allow', 'business', 'reduced', 'capacity', '...
# 996  ['patiala', 'couid', 'vaccination', 'schedule'...
# 997  ['hi', 'team', 'trying', 'get', 'couid', 'vacc...
# 998  ['diaper', 'jan', 'couid', 'nineteen', 'vaccin...
# 999  ['namaste', 'sir', 'couid', 'nineteen', 'preca...
#
#                      words_processed_noun_adj_verb_adv  \
# 0    ['child', 'peril', 'eligible', 'couid', 'vacci...
# 1    ['previous', 'couid', 'infection', 'vaccinatio...
# 2                              ['vaccination', 'mark']
# 3    ['get', 'call', 'office', 'ascertain', 'status...
# 4    ['book', 'departure', 'time', 'let', 'know', '...
# ..                                                 ...
# 995  ['allow', 'business', 'reduce', 'capacity', 'a...
# 996                    ['schedule', 'patiala_politic']
# 997  ['team', 'try', 'couid', 'vaccination', 'certi...
# 998  ['vaccination', 'join', 'charitable', 'clinic'...
# 999  ['precaution', 'dose', 'vaccination', 'service...
#
#                                   words_processed_noun  subjectivity  \
# 0           ['child', 'peril', 'couid', 'vaccination']      0.000000
# 1    ['couid', 'infection', 'vaccination', 'perform...      0.166667
# 2                                      ['vaccination']      0.000000
# 3    ['office', 'status', 'couid', 'vaccination', '...      0.000000
# 4    ['departure', 'time', 'guideline', 'today', 'c...      0.727273
# ..                                                 ...           ...
# 995  ['business', 'capacity', 'couid', 'guideline',...      0.000000
# 996                    ['schedule', 'patiala_politic']      0.000000
# 997  ['team', 'couid', 'vaccination', 'certificate'...      0.000000
# 998  ['vaccination', 'clinic', 'number', 'school', ...      0.525000
# 999           ['precaution', 'vaccination', 'service']      0.000000
#
#       text_type
# 0     objective
# 1     objective
# 2     objective
# 3     objective
# 4     objective
# ..          ...
# 995  subjective
# 996   objective
# 997   objective
# 998   objective
# 999  subjective
#
# [1000 rows x 13 columns]

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)
df
# Out:
#                                                   Text  \
# 0    #pickids : about 20,000 children perlis eligib...
# 1    previous covid-19 infection – but not vaccinat...
# 2    india’s covid-19 vaccination coverage crosses ...
# 3    i got call office principal commissioner cgst ...
# 4    i have booked flight 13 feb, 2022 toronto new ...
# ..                                                 ...
# 995  they should allow businesses with reduced capa...
# 996  patiala covid vaccination schedule 12 january🔴...
# 997  hi team, i am trying get covid vaccination cer...
# 998  #dimapur | 11jan 2022: covid-19 vaccination at...
# 999  namaste sir covid 19 precaution dose vaccinati...
#
#                                               new_text languages  \
# 0    #pickids : about 20,000 children perlis eligib...   ENGLISH
# 1    previous covid-19 infection – but not vaccinat...   ENGLISH
# 2    india’s covid-19 vaccination coverage crosses ...   ENGLISH
# 3    i got call office principal commissioner cgst ...   ENGLISH
# 4    i have booked flight 13 feb, 2022 toronto new ...   ENGLISH
# ..                                                 ...       ...
# 995  they should allow businesses with reduced capa...   ENGLISH
# 996  patiala covid vaccination schedule 12 januaryr...   ENGLISH
# 997  hi team, i am trying get covid vaccination cer...   ENGLISH
# 998  #dimapur | 11jan 2022: covid-19 vaccination at...   ENGLISH
# 999  namaste sir covid 19 precaution dose vaccinati...   ENGLISH
#
#                                             translated new_languages  \
# 0    #pickids : about 20,000 children perlis eligib...       ENGLISH
# 1    previous covid-19 infection – but not vaccinat...       ENGLISH
# 2    india’s covid-19 vaccination coverage crosses ...       ENGLISH
# 3    i got call office principal commissioner cgst ...       ENGLISH
# 4    i have booked flight 13 feb, 2022 toronto new ...       ENGLISH
# ..                                                 ...           ...
# 995  they should allow businesses with reduced capa...       ENGLISH
# 996  patiala covid vaccination schedule 12 januaryr...       ENGLISH
# 997  hi team, i am trying get covid vaccination cer...       ENGLISH
# 998  #dimapur | 11jan 2022: covid-19 vaccination at...       ENGLISH
# 999  namaste sir covid 19 precaution dose vaccinati...       ENGLISH
#
#                                       pos_tagged_words  \
# 0    [('pickins', 'NNS'), ('about', 'IN'), ('twenty...
# 1    [('previous', 'JJ'), ('couid', 'NN'), ('ninete...
# 2    [('india', 'NN'), ('i', 'NN'), ('i', 'VBP'), (...
# 3    [('i', 'NN'), ('got', 'VBD'), ('call', 'JJ'), ...
# 4    [('i', 'NNS'), ('have', 'VBP'), ('booked', 'VB...
# ..                                                 ...
# 995  [('they', 'PRP'), ('should', 'MD'), ('allow', ...
# 996  [('patiala', 'NN'), ('couid', 'NN'), ('vaccina...
# 997  [('hi', 'NN'), ('team', 'NN'), ('i', 'NN'), ('...
# 998  [('diaper', 'NN'), ('jan', 'NN'), ('couid', 'N...
# 999  [('namaste', 'NN'), ('sir', 'NN'), ('couid', '...
#
#                                    words_processed_all  \
# 0    ['pickins', 'twenty', 'zero', 'child', 'peril'...
# 1    ['previous', 'couid', 'nineteen', 'infection',...
# 2    ['india', 'couid', 'nineteen', 'vaccination', ...
# 3    ['got', 'call', 'office', 'principal', 'commis...
# 4    ['booked', 'flight', 'thirteen', 'feb', 'toron...
# ..                                                 ...
# 995  ['allow', 'business', 'reduced', 'capacity', '...
# 996  ['patiala', 'couid', 'vaccination', 'schedule'...
# 997  ['hi', 'team', 'trying', 'get', 'couid', 'vacc...
# 998  ['diaper', 'jan', 'couid', 'nineteen', 'vaccin...
# 999  ['namaste', 'sir', 'couid', 'nineteen', 'preca...
#
#                      words_processed_noun_adj_verb_adv  \
# 0    ['child', 'peril', 'eligible', 'couid', 'vacci...
# 1    ['previous', 'couid', 'infection', 'vaccinatio...
# 2                              ['vaccination', 'mark']
# 3    ['get', 'call', 'office', 'ascertain', 'status...
# 4    ['book', 'departure', 'time', 'let', 'know', '...
# ..                                                 ...
# 995  ['allow', 'business', 'reduce', 'capacity', 'a...
# 996                    ['schedule', 'patiala_politic']
# 997  ['team', 'try', 'couid', 'vaccination', 'certi...
# 998  ['vaccination', 'join', 'charitable', 'clinic'...
# 999  ['precaution', 'dose', 'vaccination', 'service...
#
#                                   words_processed_noun  subjectivity  \
# 0           ['child', 'peril', 'couid', 'vaccination']      0.000000
# 1    ['couid', 'infection', 'vaccination', 'perform...      0.166667
# 2                                      ['vaccination']      0.000000
# 3    ['office', 'status', 'couid', 'vaccination', '...      0.000000
# 4    ['departure', 'time', 'guideline', 'today', 'c...      0.727273
# ..                                                 ...           ...
# 995  ['business', 'capacity', 'couid', 'guideline',...      0.000000
# 996                    ['schedule', 'patiala_politic']      0.000000
# 997  ['team', 'couid', 'vaccination', 'certificate'...      0.000000
# 998  ['vaccination', 'clinic', 'number', 'school', ...      0.525000
# 999           ['precaution', 'vaccination', 'service']      0.000000
#
#       text_type
# 0     objective
# 1     objective
# 2     objective
# 3     objective
# 4     objective
# ..          ...
# 995  subjective
# 996   objective
# 997   objective
# 998   objective
# 999  subjective
#
# [1000 rows x 11 columns]

# %%
df["text_type"].value_counts()
# Out:
# objective     669
# subjective    331
# Name: text_type, dtype: int64

# %% [markdown]
# # Classification

# %%
X = df.translated
y = df.text_type

# %%
# # In the first step we will split the data in training and remaining dataset
# X_train, X_rem, y_train, y_rem = train_test_split(X,y, train_size=0.8, random_state=1)

# # Now since we want the valid and test size to be equal (10% each of overall data). 
# # we have to define valid_size=0.5 (that is 50% of remaining data)
# test_size = 0.5
# X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=0.5, random_state=1)

# %%
# print(X_train.shape), print(y_train.shape)
# print(X_valid.shape), print(y_valid.shape)
# print(X_test.shape), print(y_test.shape)

# %%
#split into training and testing datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size = 0.2)
print(X_train.shape)
print(X_test.shape)
# Out:
# (800,)
# (200,)

# %%
# instantiate the vectorizer
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

# %%
# learn training data vocabulary, then create document-term matrix
X_train_data = v.fit_transform(X_train)
X_train_data
# Out:
# <800x4106 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17637 stored elements in Compressed Sparse Row format>

# %%
# transform testing data (using fitted vocabulary) into a document-term matrix
X_test_data = v.transform(X_test)

# %%
#store token names into the variables Xt_tokens and Xtf_tokens
Xt_tokens =  v.get_feature_names()
# Out:
# /Users/janviaswani/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
Xt_tokens = v.get_feature_names()
Xt_count = np.sum(X_train_data.toarray(), axis =0)
print(Xt_count)
# Out:
# [9 4 1 ... 1 1 1]

# %%
#so there's 2155 unique words in the training dataset
print(Xt_count.shape)
# Out:
# (4106,)

# %%
#show the most common words in the dataset 
df_token = pd.DataFrame({'word':Xt_tokens, 'count':Xt_count})
df_token.sort_values(by='count', ascending=False)
# Out:
#              word  count
# 3880  vaccination    836
# 1070        covid    808
# 85             19    376
# 2044           is    297
# 1961        india    175
# ...           ...    ...
# 1016     contains      1
# 1014   contagious      1
# 2455       morena      1
# 2456     moreover      1
# 4105          𝘆𝗼𝘂      1
#
# [4106 rows x 2 columns]

# %%
# create separate DataFrames for fact and nonfact
subj = df[df.text_type=='subjective']
obj = df[df.text_type=='objective']

# %%
# learn the vocabulary of ALL messages and save it
v.fit(df.translated)
# put the names of all features (tokens) into a variable
all_tokens = v.get_feature_names()
# Out:
# /Users/janviaswani/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# create document-term matrices for fact and nonfact

subj_doc = v.transform(subj['translated'])
obj_doc = v.transform(obj['translated'])

# %%
# count how many times each token appears across all fact messages

subj_count = np.sum(subj_doc.toarray(), axis=0)

# %%
# count how many times each token appears across all opinion messages
obj_count = np.sum(obj_doc.toarray(), axis=0)

# %%
#produce list that counts number of times a token appears in a factual or nonfactual sentence (for unfiltered dataframe)
tokens= pd.DataFrame({'token':all_tokens, 'subjective': subj_count, 'objective': obj_count})
tokens
# Out:
#       token  subjective  objective
# 0        00           0         10
# 1       000           0          6
# 2     00001           0          1
# 3       005           0          1
# 4       008           0          1
# ...     ...         ...        ...
# 4608     𝗶𝗻           1          0
# 4609     𝗷𝗶           1          0
# 4610    𝘀𝗲𝗲           1          0
# 4611     𝘄𝗲           1          0
# 4612    𝘆𝗼𝘂           1          0
#
# [4613 rows x 3 columns]

# %%
## Above shows that if the token is numeric, more likely it is objective

# %% [markdown]
# ## Naive Bayes Classifier method 1
#
# https://github.com/cpatri/Fact-vs-Opinion-Articles/blob/master/CSCI%20183%20Project.ipynb

# %%
# train a Naive Bayes model using X_train_data and Xf_train_data
from sklearn.naive_bayes import MultinomialNB

naive_bayes = MultinomialNB()

naive_bayes.fit(X_train_data, y_train)
# Out:
# MultinomialNB()

# %%
# make class predictions  
y_pred_class = naive_bayes.predict(X_test_data)

# %%
# calculate accuracy of class predictions from the one-time cross validation
# compute the accuracy scores
from sklearn import metrics
NB = metrics.accuracy_score(y_test, y_pred_class)
print(NB)
# Out:
# 0.85

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_class)
print(cm)
# Out:
# [[120  16]
#  [ 14  50]]

# %%
y_pred_class
# Out:
# array(['objective', 'subjective', 'objective', 'subjective', 'objective',
#        'objective', 'subjective', 'objective', 'objective', 'subjective',
#        'subjective', 'subjective', 'objective', 'objective', 'subjective',
#        'objective', 'objective', 'objective', 'objective', 'objective',
#        'objective', 'subjective', 'objective', 'subjective', 'subjective',
#        'objective', 'objective', 'objective', 'objective', 'objective',
#        'subjective', 'objective', 'subjective', 'subjective',
#        'subjective', 'objective', 'objective', 'subjective', 'objective',
#        'subjective', 'objective', 'objective', 'subjective', 'objective',
#        'objective', 'objective', 'objective', 'objective', 'subjective',
#        'subjective', 'objective', 'subjective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'subjective', 'objective',
#        'subjective', 'objective', 'objective', 'objective', 'subjective',
#        'subjective', 'subjective', 'objective', 'subjective', 'objective',
#        'subjective', 'objective', 'objective', 'subjective', 'objective',
#        'objective', 'objective', 'objective', 'objective', 'objective',
#        'objective', 'objective', 'subjective', 'objective', 'objective',
#        'subjective', 'objective', 'objective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'objective', 'subjective',
#        'subjective', 'objective', 'subjective', 'subjective', 'objective',
#        'objective', 'objective', 'objective', 'objective', 'objective',
#        'subjective', 'objective', 'subjective', 'objective', 'objective',
#        'objective', 'subjective', 'subjective', 'objective', 'objective',
#        'objective', 'objective', 'subjective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'subjective', 'objective',
#        'subjective', 'objective', 'subjective', 'objective', 'subjective',
#        'objective', 'objective', 'objective', 'objective', 'objective',
#        'subjective', 'subjective', 'objective', 'objective', 'objective',
#        'objective', 'objective', 'subjective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'subjective', 'subjective',
#        'subjective', 'objective', 'objective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'subjective', 'subjective',
#        'objective', 'objective', 'objective', 'objective', 'objective',
#        'subjective', 'subjective', 'subjective', 'subjective',
#        'subjective', 'objective', 'subjective', 'subjective', 'objective',
#        'objective', 'subjective', 'objective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'objective', 'subjective',
#        'subjective', 'objective', 'objective', 'subjective', 'subjective',
#        'subjective', 'objective', 'subjective', 'objective', 'objective',
#        'objective', 'objective', 'objective', 'subjective', 'objective',
#        'objective', 'objective'], dtype='<U10')

# %% [markdown]
# ## Naive Bayes Classifier method 2 (Only works with tokens)
#
# week5 lab

# %%
X_train
# Out:
# 731    #getvaccinated &amp; help yourself protection ...
# 716    #vaccinemandate here's data. israel with highe...
# 640    #covid19: #gujarat administered 10,838 second ...
# 804    day two covid care week #cc i will talk about ...
# 737    world is shaken-covid. no idea how get mask. b...
#                              ...
# 767    wish compliment staff chc bhangel, noida profe...
# 72     is not this oppression people yesterday i have...
# 908    elite mfs living metro cities think shutting e...
# 235    india’s covid vaccination coverage crosses 170...
# 37     bro you know where was case covid detected ind...
# Name: translated, Length: 700, dtype: object

# %%
y_train
# Out:
# 731    subjective
# 716     objective
# 640     objective
# 804     objective
# 737    subjective
#           ...
# 767    subjective
# 72     subjective
# 908    subjective
# 235     objective
# 37     subjective
# Name: text_type, Length: 700, dtype: object

# %%
x_train1 = pd.DataFrame(X_train)
x_train1
# Out:
#                                             translated
# 731  #getvaccinated &amp; help yourself protection ...
# 716  #vaccinemandate here's data. israel with highe...
# 640  #covid19: #gujarat administered 10,838 second ...
# 804  day two covid care week #cc i will talk about ...
# 737  world is shaken-covid. no idea how get mask. b...
# ..                                                 ...
# 767  wish compliment staff chc bhangel, noida profe...
# 72   is not this oppression people yesterday i have...
# 908  elite mfs living metro cities think shutting e...
# 235  india’s covid vaccination coverage crosses 170...
# 37   bro you know where was case covid detected ind...
#
# [700 rows x 1 columns]

# %%
y_train1 = pd.DataFrame(y_train)
y_train1
# Out:
#       text_type
# 731  subjective
# 716   objective
# 640   objective
# 804   objective
# 737  subjective
# ..          ...
# 767  subjective
# 72   subjective
# 908  subjective
# 235   objective
# 37   subjective
#
# [700 rows x 1 columns]

# %%
y_train1.value_counts()
# Out:
# text_type
# objective     463
# subjective    237
# dtype: int64

# %%
index_subj_train = []
index_obj_train = []
for i in range(len(y_train1)):
    each = y_train1.iloc[i]
    text_type = each["text_type"]
    name = each.name
    if text_type == "subj":
        index_subj_train.append(name)
    else:
        index_obj_train.append(name)

# %%
import ast
subj_docs_train = []
obj_docs_train = []
for i in range(len(x_train1)):
    each = x_train1.iloc[i]
    words = ast.literal_eval(each["translated"])
    name = each.name
    if name in index_subj_train:
        subj_docs_train.append(words)
    else:
        obj_docs_train.append(words)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/janviaswani/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-59-4c67b9f092dd>", line 6, in <module>
#     words = ast.literal_eval(each["translated"])
#
#   File "/Users/janviaswani/opt/anaconda3/lib/python3.8/ast.py", line 59, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "/Users/janviaswani/opt/anaconda3/lib/python3.8/ast.py", line 47, in parse
#     return compile(source, filename, mode, flags,
#
#   File "<unknown>", line 1
#     #getvaccinated &amp; help yourself protection against covid 19. vaccination helps you &amp; others protect getting vaccinated spread corona. with inspiration saint ji volunteers are getting vaccinated aware others too.
#                                                                                                                                                                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
X_test
# Out:
# 201    ['dailywrap', 'february', 'nine', 'nice', 'org...
# 29     ['multi', 'lingual', 'poster', 'created', 'cit...
# 102    ['student', 'centre', 'even', 'asked', 'couid'...
# 407    ['athens', 'couid', 'nineteen', 'vaccination',...
# 186    ['state', 'couid', 'nineteen', 'vaccination', ...
#                              ...
# 73     ['big', 'u', 'move', 'u', 'navy', 'personnel',...
# 347    ['may', 'sound', 'incredible', 'freedom_convoy...
# 272    ['india', 'surpassed', 'crore', 'vaccinated', ...
# 363    ['covidsafe', 'used', 'couid', 'result', 'vacc...
# 132    ['attendee', 'not', 'required', 'provide', 'co...
# Name: words_processed_all, Length: 124, dtype: object

# %%
y_test
# Out:
# 201       fact
# 29        fact
# 102    opinion
# 407       fact
# 186       fact
#         ...
# 73        fact
# 347    opinion
# 272       fact
# 363    opinion
# 132       fact
# Name: text_type, Length: 124, dtype: object

# %%
all_docs_test = []
for each in X_test:
    words = ast.literal_eval(each)
    all_docs_test.append(words)

# %%
all_docs_test
# Out:
# [['dailywrap',
#   'february',
#   'nine',
#   'nice',
#   'organises',
#   'ord',
#   'edition',
#   'seminar',
#   'series',
#   'igniting',
#   'young',
#   'mind',
#   'rejuvenating',
#   'river',
#   'india',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds',
#   'crore'],
#  ['multi',
#   'lingual',
#   'poster',
#   'created',
#   'citizen',
#   'sixty',
#   'year',
#   'urging',
#   'go',
#   'couid',
#   'vaccination',
#   'fearlessly',
#   'pushed',
#   'digital',
#   'platform',
#   'ashok',
#   'join',
#   'executive',
#   'director',
#   'micro',
#   'lab',
#   'limited',
#   'executive',
#   'director',
#   'micro',
#   'lab',
#   'limited',
#   'day'],
#  ['student',
#   'centre',
#   'even',
#   'asked',
#   'couid',
#   'neither',
#   'ive',
#   'vaccination',
#   'guess',
#   'condition',
#   'rest',
#   'centre',
#   'isolation',
#   'room',
#   'centre'],
#  ['athens',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'certificate',
#   'zero',
#   'people',
#   'greece',
#   'not',
#   'take',
#   'booster',
#   'shot',
#   'became',
#   'invalid',
#   'government',
#   'announced',
#   'according',
#   'current',
#   'regulation',
#   'greece',
#   'vaccination',
#   'certificate',
#   'valid',
#   'seven',
#   'month',
#   'day',
#   'se'],
#  ['state', 'couid', 'nineteen', 'vaccination', 'update', 'february'],
#  ['couid',
#   'pune',
#   'mask',
#   'amp',
#   'maintain_cab',
#   'amp',
#   'vaccination',
#   'maskuppune',
#   'new',
#   'case',
#   'sparrow',
#   'active',
#   'active_cases',
#   'hosp',
#   'seven',
#   'twentyfive',
#   'sparrow',
#   'discharged',
#   'sparrow',
#   'sparrow',
#   'ventilator',
#   'sparrow',
#   'testing',
#   'sparrow',
#   'eight',
#   'sparrow'],
#  ['lithuania',
#   'announced',
#   'ready',
#   'welcome',
#   'traveller',
#   'back',
#   'tourist',
#   'european',
#   'union',
#   'amp',
#   'european',
#   'economic',
#   'area',
#   'need',
#   'show',
#   'proof',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'europeanunion',
#   'travelupsates',
#   'thedopenews'],
#  ['india',
#   'couid',
#   'vaccination',
#   'coverage_crosses',
#   'crore',
#   'lakh',
#   'mark'],
#  ['mess',
#   'talking',
#   'universal',
#   'free',
#   'cost',
#   'vaccination',
#   'universal',
#   'food',
#   'subsidy',
#   'program',
#   'eighty',
#   'crore',
#   'citizen',
#   'indian',
#   'given',
#   'free',
#   'food',
#   'growth',
#   'rate',
#   'eight',
#   'percentage',
#   'despite',
#   'couid',
#   'pandemic',
#   'digitization',
#   'india',
#   'direct',
#   'benefit',
#   'transfer'],
#  ['si',
#   'sri',
#   'ambedkar',
#   'along',
#   'patrol',
#   'car',
#   'conducted',
#   'awareness',
#   'programme',
#   'couid',
#   'vaccination',
#   'couid',
#   'safety',
#   'precaution',
#   'keg',
#   'lane',
#   'gudimalkapur'],
#  ['mediate',
#   'partnered',
#   'multiple',
#   'hospital',
#   'conduct',
#   'couid',
#   'vaccination',
#   'hyderabad',
#   'place',
#   'currently',
#   'providing',
#   'two',
#   'vaccination',
#   'one',
#   'covishield',
#   'another',
#   'one',
#   'coaxing'],
#  ['way',
#   'india',
#   'moving',
#   'today',
#   'drawing',
#   'attention',
#   'world',
#   'many',
#   'country',
#   'asked',
#   'medicine',
#   'india',
#   'corona',
#   'said',
#   'prime_minister',
#   'mahendra_modi',
#   'narendramodi',
#   'covidvaccination'],
#  ['possible',
#   'side_effect',
#   'parent',
#   'look',
#   'child',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'pickins',
#   'lindungdirilindungsemua'],
#  ['couid', 'vaccination', 'camp', 'held', 'district', 'yoga', 'ten', 'two'],
#  ['athenahealth',
#   'say',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'required',
#   'limited',
#   'number',
#   'employee',
#   'ofhealth'],
#  ['reviewed',
#   'status',
#   'progress',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'district',
#   'today'],
#  ['gujarati',
#   'achieves',
#   'big',
#   'number',
#   'corona',
#   'vaccination',
#   'set',
#   'record',
#   'giving',
#   'million',
#   'dos',
#   'gujarati',
#   'covidvaccination',
#   'achievement'],
#  ['oscar',
#   'attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof'],
#  ['malaysia',
#   'couid',
#   'nine',
#   'two',
#   'confirmed',
#   'two',
#   'imp',
#   'discharged',
#   'two',
#   'icu',
#   'ventilator',
#   'vaccination',
#   'est',
#   'dose',
#   'ten',
#   'dose',
#   'five',
#   'one',
#   'booster',
#   'twelve'],
#  ['got',
#   'booster',
#   'continuous',
#   'effort',
#   'battle',
#   'couid',
#   'si',
#   'frontline_workers',
#   'taken',
#   'one',
#   'step',
#   'ahead',
#   'got',
#   'booster',
#   'shot',
#   'make',
#   'nation',
#   'safe',
#   'corona',
#   'free',
#   'humareheroes',
#   'boosterdoses',
#   'sisfrontline',
#   'subgroup',
#   'couid',
#   'vaccination'],
#  ['gujarati',
#   'administered',
#   'one',
#   'lakh',
#   'second',
#   'dos',
#   'fifteen',
#   'eighteen',
#   'year',
#   'age_group',
#   'taking',
#   'total',
#   'ten',
#   'lakh',
#   'gujarati',
#   'administered',
#   'booster',
#   'dos',
#   'senior_citizen',
#   'taking',
#   'total',
#   'sixteen',
#   'lakh',
#   'gujaratcoronaupdate',
#   'covidvaccination'],
#  ['national',
#   'border',
#   'reopening',
#   'immigration',
#   'department',
#   'director',
#   'general',
#   'datum',
#   'seri',
#   'khairul',
#   'aimee',
#   'dad',
#   'malaysia',
#   'among',
#   'country',
#   'highest',
#   'percentage',
#   'completed',
#   'vaccination',
#   'world',
#   'adult_population'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'drive',
#   'around',
#   'crore',
#   'couid',
#   'vaccine',
#   'dos',
#   'administered',
#   'india',
#   'say',
#   'govt'],
#  ['middayentertainment',
#   'attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof',
#   'vaccination'],
#  ['booked',
#   'flight',
#   'thirteen',
#   'feb',
#   'toronto',
#   'new',
#   'delhi',
#   'departure',
#   'time',
#   'est',
#   'please',
#   'let',
#   'know',
#   'per',
#   'new',
#   'guideline',
#   'come',
#   'today',
#   'couid',
#   'nineteen',
#   'test',
#   'still',
#   'necessary',
#   'upload',
#   'vaccination',
#   'certificate',
#   'travel'],
#  ['vaccination',
#   'rourke',
#   'eleven',
#   'sixteen',
#   'feb',
#   'slot',
#   'open',
#   'ten',
#   'feb',
#   'nine',
#   'onwards',
#   'coin_portal',
#   'app',
#   'vaccination',
#   'age',
#   'fifteen',
#   'eighteen',
#   'eighteen',
#   'sixty',
#   'booster',
#   'dose',
#   'booster',
#   'dose',
#   'slot',
#   'available',
#   'nine',
#   'month',
#   'dose',
#   'vaccination',
#   'follow',
#   'couid',
#   'protocol',
#   'stay_safe'],
#  ['photostory',
#   'list',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'center',
#   'coimbatore',
#   'today',
#   'ten',
#   'two'],
#  ['srinagar',
#   'thankful',
#   'people',
#   'srinagar',
#   'adhering',
#   'cab',
#   'third_wave',
#   'highest',
#   'couid',
#   'case',
#   'reported',
#   'single',
#   'day',
#   'expected',
#   'case',
#   'sec',
#   'take',
#   'call',
#   'reopening',
#   'school',
#   'soon',
#   'parent',
#   'ensure',
#   'vaccination',
#   'child'],
#  ['couid',
#   'nineteen',
#   'take',
#   'booster',
#   'dose',
#   'abudhabi',
#   'authority',
#   'urge',
#   'resident',
#   'abu_dhabi',
#   'public',
#   'health',
#   'centre',
#   'clarifies',
#   'vaccination',
#   'schedule',
#   'different',
#   'group'],
#  ['keeping_mind',
#   'recent',
#   'surge',
#   'couid',
#   'nineteen',
#   'case',
#   'make_sure',
#   'properly',
#   'following',
#   'sop',
#   'got',
#   'vaccination',
#   'done',
#   'safe',
#   'help',
#   'u',
#   'win',
#   'fight',
#   'menace',
#   'corona',
#   'virus',
#   'testing',
#   'conducted',
#   'root',
#   'milling',
#   'school',
#   'one',
#   'eight',
#   'couid',
#   'markup'],
#  ['muslim',
#   'teacher',
#   'intellectual',
#   'boycott',
#   'couid',
#   'vaccination',
#   'education',
#   'top',
#   'leader',
#   'visiting',
#   'u',
#   'health',
#   'health',
#   'system',
#   'flood',
#   'couid',
#   'pandemic',
#   'nation',
#   'seen',
#   'delivering',
#   'social',
#   'service',
#   'harmonious',
#   'act'],
#  ['total',
#   'number',
#   'active',
#   'couid',
#   'nineteen',
#   'case',
#   'punjab',
#   'feb',
#   'ten',
#   'five',
#   'total',
#   'vaccination',
#   'first',
#   'second',
#   'dose',
#   'punjab',
#   'day',
#   'feb',
#   'ten',
#   'two',
#   'pub'],
#  ['couid',
#   'nineteen',
#   'status',
#   'india',
#   'vaccination',
#   'testing',
#   'active_cases',
#   'ten',
#   'february',
#   'indiafightscorona'],
#  ['suddenly',
#   'semua',
#   'org',
#   'penal',
#   'myocarditis',
#   'seek',
#   'relate',
#   'vaccination',
#   'myocarditis',
#   'tau',
#   'kalau',
#   'kne',
#   'couid',
#   'li',
#   'la',
#   'keen',
#   'severe',
#   'myocarditis',
#   'myocarditis',
#   'tu',
#   'prevalence',
#   'higher',
#   'age',
#   'twelve',
#   'bukan',
#   'kayak',
#   'get',
#   'ur',
#   'fact',
#   'right',
#   'vaccinate',
#   'ur',
#   'young',
#   'innocent',
#   'child',
#   'good',
#   'parent'],
#  ['health',
#   'bulletin',
#   'couid',
#   'nineteen',
#   'eight',
#   'two',
#   'today',
#   'vaccination',
#   'two',
#   'total',
#   'vaccination',
#   'eighteen',
#   'haryanafightscorona',
#   'indiafightscorona',
#   'staysail',
#   'covidappropriatebehaviour',
#   'together',
#   'win',
#   'battle',
#   'couid',
#   'nineteen'],
#  ['swami',
#   'raided',
#   'said',
#   'today',
#   'couid',
#   'vaccination',
#   'not',
#   'forced',
#   'upon',
#   'made',
#   'compulsory',
#   'result',
#   'effect',
#   'yet',
#   'established',
#   'plus',
#   'exercise',
#   'restraint',
#   'promotion',
#   'larger',
#   'interest',
#   'public'],
#  ['oscar',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'not',
#   'required',
#   'person',
#   'attendee'],
#  ['nineteen',
#   'ninety',
#   'new',
#   'case',
#   'today',
#   'expected',
#   'omicron',
#   'new',
#   'case',
#   'sharp_rise',
#   'booster',
#   'campaign',
#   'amp',
#   'child',
#   'vaccination',
#   'needed_proven',
#   'successful_reducing',
#   'severity',
#   'couid',
#   'nineteen',
#   'boost_elderly',
#   'vaccinate',
#   'children_pickbooster',
#   'pickins'],
#  ['daily', 'couid', 'vaccination', 'report', 'sundargarh', 'nine', 'february'],
#  ['oscar',
#   'attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof',
#   'oscar',
#   'reportedly',
#   'return',
#   'traditional',
#   'setting',
#   'dolby',
#   'theatre',
#   'hollywood',
#   'boulevard',
#   'upcoming',
#   'ceremony',
#   'march',
#   'latest',
#   'news_businessstandard'],
#  ['sinovac',
#   'vaccine',
#   'recipient',
#   'senior_citizen',
#   'must',
#   'receive',
#   'booster',
#   'dose',
#   'march',
#   'one',
#   'maintain',
#   'complete',
#   'vaccination',
#   'status'],
#  ['debate',
#   'bacillus',
#   'cassette',
#   'grin',
#   'vaccination',
#   'couid',
#   'nineteen',
#   'worth',
#   'performing',
#   'clinical_trial'],
#  ['thing',
#   'keep',
#   'mind',
#   'nation',
#   'recovers',
#   'earmark',
#   'vaccination',
#   'socialdistancing',
#   'industry',
#   'safeindia'],
#  ['total',
#   'number',
#   'active',
#   'couid',
#   'nineteen',
#   'case',
#   'punjab',
#   'feb',
#   'eight',
#   'seven',
#   'total',
#   'vaccination',
#   'first',
#   'second',
#   'dose',
#   'punjab',
#   'day',
#   'feb',
#   'eight',
#   'two',
#   'sixteen',
#   'pub'],
#  ['nashi',
#   'district',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'eight',
#   'two',
#   'total',
#   'dos',
#   'twentyfive',
#   'area',
#   'wise',
#   'status',
#   'one',
#   'day',
#   'eighteen',
#   'yr',
#   'est',
#   'dose',
#   'dose',
#   'fifteen',
#   'yr',
#   'est',
#   'dose',
#   'dose',
#   'twentyfour'],
#  ['besides',
#   'uploading',
#   'negative',
#   'per',
#   'report',
#   'taken',
#   'prior',
#   'journey',
#   'option',
#   'upload',
#   'certificate',
#   'completing',
#   'full',
#   'primary',
#   'vaccination',
#   'schedule',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'provided',
#   'country',
#   'reciprocal',
#   'basis',
#   'ministry',
#   'health'],
#  ['mischief',
#   'vaccine',
#   'center',
#   'working',
#   'hour',
#   'kuwait',
#   'moh',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'address'],
#  ['went',
#   'school',
#   'submit',
#   'admission',
#   'form',
#   'new',
#   'academic',
#   'year',
#   'four',
#   'yr_old',
#   'form',
#   'without',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'certificate',
#   'parent',
#   'not',
#   'accepted',
#   'karachi'],
#  ['vaccination',
#   'done',
#   'ten',
#   'target',
#   'set',
#   'delhi',
#   'know',
#   'many',
#   'people',
#   'not',
#   'yet',
#   'taken',
#   'second',
#   'dose',
#   'delhicovid',
#   'covidvaccination'],
#  ['authority',
#   'must',
#   'follow',
#   'centre',
#   'policy',
#   'aadhaar',
#   'not',
#   'mandatory',
#   'couid',
#   'vaccination',
#   'supreme_court',
#   'lively'],
#  ['government',
#   'make',
#   'aadhaar_card',
#   'not',
#   'mandatory',
#   'coin_portal',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'read',
#   'apacinnovations'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'seven',
#   'two',
#   'number',
#   'people',
#   'received',
#   'first',
#   'dose',
#   'eleven',
#   'atoll',
#   'eleven',
#   'number',
#   'people',
#   'received',
#   'second',
#   'dose',
#   'atoll',
#   'number',
#   'people',
#   'received',
#   'booster',
#   'dose',
#   'atoll',
#   'three'],
#  ['also',
#   'look',
#   'highway',
#   'posted',
#   'video',
#   'earlier',
#   'various',
#   'infra',
#   'project',
#   'defence',
#   'expenditure',
#   'development',
#   'project',
#   'aim',
#   'etc',
#   'consider',
#   'india',
#   'worst',
#   'hit',
#   'couid',
#   'ran',
#   'world_largest',
#   'free',
#   'vaccination',
#   'drive',
#   'not',
#   'stop',
#   'project',
#   'despite',
#   'rising',
#   'debt',
#   'side',
#   'coin'],
#  ['athenahealth',
#   'say',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'required',
#   'limited',
#   'number',
#   'employee'],
#  ['quarantine',
#   'period',
#   'couid',
#   'nineteen',
#   'patient',
#   'close',
#   'contact',
#   'positive',
#   'couid',
#   'nineteen',
#   'case',
#   'according',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'eight',
#   'february',
#   'kitajagakita',
#   'kitamestimenang',
#   'menangbersama',
#   'coronavirus',
#   'algeria'],
#  ['top',
#   'sri_lankan',
#   'referee',
#   'face',
#   'trouble',
#   'bia',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'card'],
#  ['twentyfive',
#   'population',
#   'awesome',
#   'job',
#   'couid',
#   'management',
#   'vaccination',
#   'not',
#   'vote',
#   'person',
#   'not',
#   'vaccinated',
#   'wanted',
#   'others',
#   'not',
#   'take',
#   'vaccine'],
#  ['relief',
#   'thousand',
#   'new',
#   'case',
#   'corona',
#   'surfaced',
#   'country',
#   'twentyfour_hours',
#   'recoveryrate',
#   'nutcase',
#   'coronavirus',
#   'coronainindia',
#   'covidvaccination'],
#  ['dehradun',
#   'airport',
#   'today',
#   'organised',
#   'couid',
#   'nineteen',
#   'foster',
#   'loose',
#   'vaccination',
#   'drive',
#   'medical',
#   'inspection',
#   'room',
#   'dehradun',
#   'airport',
#   'stakeholder'],
#  ['couid',
#   'nineteen',
#   'status',
#   'india',
#   'vaccination',
#   'testing',
#   'active_cases',
#   'nine',
#   'february',
#   'indiafightscorona'],
#  ['india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds'],
#  ['navi_mumbai',
#   'municipal_corporation',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'campaign',
#   'date',
#   'ten',
#   'two',
#   'session',
#   'planning',
#   'maskupnavimumbai',
#   'nomasknoentry',
#   'cove',
#   'indiafightscorona'],
#  ['next',
#   'couid',
#   'variant',
#   'omicron',
#   'expert',
#   'explain',
#   'coronavirus',
#   'evolve',
#   'trait',
#   'vaccination'],
#  ['five',
#   'powerful',
#   'couid',
#   'vaccine',
#   'except',
#   'ensure',
#   'immunization',
#   'still',
#   'syringe',
#   'booster',
#   'dose',
#   'fully',
#   'vaccinated',
#   'still',
#   'need',
#   'get',
#   'negative',
#   'test',
#   'fully',
#   'vaccinated',
#   'need',
#   'wear_mask',
#   'amp',
#   'avoid',
#   'socializing',
#   'vaccination'],
#  ['loved',
#   'vaccination',
#   'achieved',
#   'new',
#   'milestone',
#   'country',
#   'one',
#   'crore',
#   'child',
#   'age_group',
#   'fifteen',
#   'eighteen',
#   'got',
#   'dos',
#   'vaccine',
#   'covidvaccination',
#   'kidsvaccination',
#   'omicronvariant'],
#  ['india',
#   'vaccination',
#   'coverage_crossed',
#   'crore',
#   'lakh',
#   'today',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'till',
#   'seven',
#   'today',
#   'one',
#   'crore',
#   'lakh',
#   'precaution',
#   'dos',
#   'identified',
#   'category',
#   'beneficiary',
#   'couid',
#   'vaccination',
#   'administered',
#   'far'],
#  ['unlockindia',
#   'breakingnews',
#   'newsupdate',
#   'ministry',
#   'health',
#   'revise',
#   'guideline',
#   'international',
#   'arrival',
#   'today',
#   'feb',
#   'come',
#   'effect',
#   'feb',
#   'read',
#   'detailed',
#   'travel',
#   'guideline',
#   'traveler',
#   'couid',
#   'vaccination',
#   'travelupdates',
#   'traveltoindia'],
#  ['galati',
#   'high',
#   'court',
#   'issue',
#   'notice',
#   'pil',
#   'challenging',
#   'nagaland',
#   'govt',
#   'order',
#   'mandating',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'student',
#   'fifteen',
#   'year',
#   'age'],
#  ['hi',
#   'clarify',
#   'whether',
#   'tweet',
#   'mean',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'not',
#   'required',
#   'perform',
#   'ummah'],
#  ['look',
#   'government',
#   'fool',
#   'robs',
#   'spectacle',
#   'vaccination',
#   'privacy',
#   'myth',
#   'fully',
#   'vaccinated',
#   'last',
#   'yr',
#   'today',
#   'got',
#   'top',
#   'message',
#   'couid',
#   'vaccination',
#   'registration',
#   'three',
#   'minute',
#   'automatically',
#   'message',
#   'first',
#   'dose',
#   'come',
#   'check',
#   'app'],
#  ['total',
#   'twentyfive',
#   'people',
#   'arrested',
#   'nationwide',
#   'connection',
#   'cheating',
#   'case',
#   'involving',
#   'sale',
#   'fake',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'certificate'],
#  ['study',
#   'show',
#   'couid',
#   'vaccination',
#   'pregnancy',
#   'produce',
#   'persistent',
#   'antibody',
#   'infant',
#   'covidvaccination'],
#  ['prayer',
#   'trust',
#   'organised',
#   'near',
#   'home',
#   'couid',
#   'vaccination',
#   'drive',
#   'today',
#   'ith',
#   'february',
#   'new',
#   'mahavirnagar',
#   'coaxing',
#   'available',
#   'everyone',
#   'fifteen',
#   'yr',
#   'age',
#   'many',
#   'teenager',
#   'took',
#   'benefit',
#   'vaccination',
#   'drive',
#   'heading',
#   'back',
#   'school',
#   'offline',
#   'class'],
#  ['visited',
#   'couid',
#   'vaccinated',
#   'centre',
#   'kangpokpi',
#   'district',
#   'delighted',
#   'see',
#   'many',
#   'student',
#   'eighteen',
#   'yr',
#   'turned',
#   'vaccination',
#   'believe',
#   'administrative',
#   'couid',
#   'unit',
#   'kangpokpi',
#   'district',
#   'target',
#   'maximum',
#   'vaccination',
#   'taking',
#   'est',
#   'amp',
#   'precaution',
#   'dos'],
#  ['child',
#   'age_group',
#   'fifteen',
#   'eighteen',
#   'year',
#   'inoculated',
#   'dose',
#   'couid',
#   'vaccination',
#   'designated',
#   'couid',
#   'vaccination',
#   'centre'],
#  ['doctor',
#   'say',
#   'low',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'rate',
#   'child',
#   'mean',
#   'soon',
#   'drop',
#   'mask',
#   'mandate'],
#  ['child',
#   'vaccination',
#   'progress',
#   'available',
#   'register',
#   'child',
#   'vaccination',
#   'deserve',
#   'protected',
#   'couid',
#   'nineteen',
#   'pickins'],
#  ['get',
#   'vaccinated',
#   'take',
#   'pledge',
#   'get',
#   'vaccinated',
#   'encourage_others',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'get',
#   'inoculated',
#   'derasachasauda',
#   'babaramrahim'],
#  ['one',
#   'crore',
#   'youth',
#   'fifteen',
#   'eighteen',
#   'age_group',
#   'fully',
#   'vaccinated',
#   'union',
#   'health',
#   'minister',
#   'covidvaccination'],
#  ['fourth',
#   'dose',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'conceivable',
#   'protect',
#   'omicron_variant',
#   'covidvaccination',
#   'anthonyfauci',
#   'omicronsymptoms',
#   'uspandemicadvisoranthonyfauci'],
#  ['coronaupdate',
#   'coronavirus',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'work',
#   'progress',
#   'review'],
#  ['update',
#   'india',
#   'record',
#   'fresh',
#   'couid',
#   'nineteen',
#   'case',
#   'coronavirusupdates',
#   'activecases',
#   'deathtoll',
#   'recovery',
#   'covidvaccination'],
#  ['third',
#   'batch',
#   'discus',
#   'communication',
#   'advocacy',
#   'strategy',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'rosaline',
#   'communication',
#   'officer',
#   'john',
#   'snow',
#   'india',
#   'join',
#   'u',
#   'february',
#   'guest',
#   'speaker'],
#  ['pal',
#   'advise',
#   'precaution',
#   'couid',
#   'vaccination',
#   'dose',
#   'already',
#   'taken',
#   'two',
#   'pfizer',
#   'dos',
#   'usa',
#   'feb',
#   'twenty',
#   'essential',
#   'citizen',
#   'seventy'],
#  ['still',
#   'need',
#   'hospitalization',
#   'vaccination',
#   'amp',
#   'endless',
#   'booster',
#   'doze',
#   'time',
#   'face',
#   'harsh',
#   'truth',
#   'billion',
#   'conned',
#   'amp',
#   'made',
#   'pay',
#   'compromising',
#   'immune_system',
#   'couid',
#   'amp',
#   'many',
#   'variant',
#   'vaccine',
#   'global',
#   'scam',
#   'epic',
#   'proportion'],
#  ['seventeen',
#   'new',
#   'case',
#   'today',
#   'expected',
#   'omicron',
#   'new',
#   'case',
#   'sharp_rise',
#   'booster',
#   'campaign',
#   'amp',
#   'child',
#   'vaccination',
#   'needed_proven',
#   'successful_reducing',
#   'severity',
#   'couid',
#   'nineteen',
#   'boost_elderly',
#   'vaccinate',
#   'children_pickbooster',
#   'pickins'],
#  ['couid',
#   'nineteen',
#   'update',
#   'vaccine',
#   'dos',
#   'administered',
#   'far',
#   'nationwide',
#   'vaccination',
#   'drive',
#   'india',
#   'active_caseload',
#   'currently_stands',
#   'eight',
#   'active_cases',
#   'stand',
#   'two',
#   'eleven',
#   'recovery_rate',
#   'currently',
#   'seventy'],
#  ['guidance',
#   'saint',
#   'greet',
#   'ram',
#   'rahim',
#   'dear',
#   'sacha',
#   'sauna',
#   'follower',
#   'took',
#   'pledge',
#   'get',
#   'vaccinated',
#   'encourage_others',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'get',
#   'inoculated',
#   'selfless',
#   'service',
#   'humanity'],
#  ['today',
#   'nisam',
#   'muhammad',
#   'khalil',
#   'additional',
#   'assistant',
#   'commissioner',
#   'one',
#   'khat',
#   'visited',
#   'civil',
#   'dispensary',
#   'jungle',
#   'hell',
#   'checked',
#   'staff',
#   'attendance',
#   'couid',
#   'vaccination'],
#  ['tempura',
#   'govt',
#   'launch',
#   'spacial',
#   'couid',
#   'vaccination',
#   'drive',
#   'expectant',
#   'mother'],
#  ['far',
#   'one',
#   'seventy',
#   'people',
#   'india',
#   'vaccinated',
#   'corona',
#   'winner',
#   'india',
#   'covidvaccination'],
#  ['malaysia',
#   'plan',
#   'mic',
#   'concerned',
#   'omicron',
#   'wave',
#   'urge',
#   'one',
#   'accelerate',
#   'non',
#   'mandatory',
#   'vaccination',
#   'child',
#   'two',
#   'amplify',
#   'local',
#   'couid',
#   'nineteen',
#   'genomic',
#   'surveillance',
#   'three',
#   'increase',
#   'availability',
#   'antiviral',
#   'drug'],
#  ['number',
#   'corona',
#   'vaccine',
#   'injected',
#   'india',
#   'crossed',
#   'crore',
#   'india',
#   'covidvaccination'],
#  ['letter',
#   'consent',
#   'sent',
#   'parent',
#   'child',
#   'vaccinated',
#   'school',
#   'parent',
#   'declined',
#   'amp',
#   'not',
#   'want',
#   'child',
#   'vaccinated',
#   'couid',
#   'hoping',
#   'make',
#   'appearance',
#   'encourage',
#   'uptake',
#   'vaccination',
#   'school'],
#  ['total',
#   'number',
#   'active',
#   'couid',
#   'nineteen',
#   'case',
#   'aryan',
#   'feb',
#   'ten',
#   'seven',
#   'total',
#   'vaccination',
#   'aryan',
#   'feb',
#   'ten',
#   'first',
#   'dose',
#   'seventy',
#   'second',
#   'dose',
#   'five',
#   'total',
#   'cumulative',
#   'figure',
#   'four',
#   'one',
#   'date',
#   'try'],
#  ['couid',
#   'vaccination',
#   'voluntarily',
#   'not',
#   'compulsory',
#   'join',
#   'campaign',
#   'mybodymydecision'],
#  ['vaccine',
#   'geneva',
#   'also',
#   'developed',
#   'omicron',
#   'paul',
#   'covidvaccination'],
#  ['case',
#   'one',
#   'person',
#   'couid',
#   'vaccination',
#   'certificate',
#   'shown',
#   'issued',
#   'document',
#   'digilocker',
#   'contains',
#   'photo',
#   'however',
#   'not',
#   'case',
#   'another',
#   'vaccinated',
#   'person',
#   'enable',
#   'photo',
#   'another',
#   'vaccinated',
#   'person'],
#  ['one',
#   'crore',
#   'adolescent',
#   'fifteen',
#   'eighteen',
#   'year',
#   'group',
#   'fully',
#   'vaccinated',
#   'couid',
#   'nineteen',
#   'mandaviya',
#   'vaccination'],
#  ['gujarati',
#   'twentyfour_hours',
#   'vaccinated',
#   'person',
#   'first',
#   'dose',
#   'one',
#   'lakh',
#   'second',
#   'five',
#   'sixteen',
#   'crore',
#   'administered',
#   'first',
#   'four',
#   'crore',
#   'second',
#   'dose',
#   'couid',
#   'vaccine',
#   'gujaratcoronaupdate',
#   'covidvaccination'],
#  ['obsessed',
#   'dead_body',
#   'today',
#   'talk',
#   'sikh',
#   'genocide',
#   'sponsored',
#   'riot',
#   'started',
#   'appeasement',
#   'policy',
#   'amp',
#   'couid',
#   'death',
#   'amp',
#   'dead_body',
#   'ganga',
#   'basically',
#   'hindu',
#   'died',
#   'couid',
#   'inc',
#   'doubting',
#   'vaccination',
#   'hypocrite'],
#  ['day',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'report',
#   'india',
#   'live',
#   'india',
#   'omicron',
#   'couid'],
#  ['couid',
#   'pune',
#   'mask',
#   'amp',
#   'maintain_cab',
#   'amp',
#   'vaccination',
#   'maskuppune',
#   'new',
#   'case',
#   'sparrow',
#   'active',
#   'active_cases',
#   'hosp',
#   'sparrow',
#   'discharged',
#   'sparrow',
#   'ventilator',
#   'testing',
#   'five'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'day',
#   'india',
#   'cumulative',
#   'vaccination',
#   'coverage',
#   'reach',
#   'nearly',
#   'crore',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'today',
#   'till',
#   'seven',
#   'couid',
#   'vaccination'],
#  ['vaccination', 'february', 'nine', 'maharashtrian', 'session', 'cumulative'],
#  ['racket',
#   'gujarati',
#   'ten',
#   'crore',
#   'couid',
#   'vaccination',
#   'celebrated',
#   'ddo'],
#  ['zero',
#   'kid',
#   'pore',
#   'receive',
#   'couid',
#   'nineteen',
#   'jab',
#   'two',
#   'vaccination',
#   'centre',
#   'close',
#   'via',
#   'wah',
#   'pandemic'],
#  ['tempura',
#   'government',
#   'launch',
#   'special',
#   'covidvaccination',
#   'drive',
#   'expectant',
#   'mother',
#   'cover',
#   'left',
#   'population',
#   'not',
#   'receive',
#   'dos',
#   'corona',
#   'vaccine'],
#  ['modi',
#   'minister',
#   'center',
#   'whereas',
#   'yogi',
#   'minister',
#   'state',
#   'not',
#   'make',
#   'blend',
#   'prime_minister',
#   'done',
#   'best',
#   'vaccination',
#   'couid',
#   'management',
#   'budget',
#   'allocation',
#   'state',
#   'done',
#   'due',
#   'molten',
#   'heart',
#   'pro'],
#  ['hopping', 'not', 'become', 'like', 'someday', 'couid', 'vaccination'],
#  ['police',
#   'twentyfive',
#   'nabbed',
#   'nationwide',
#   'sale',
#   'fake',
#   'couid',
#   'vaccination',
#   'cert'],
#  ['coronavirusupdates',
#   'five',
#   'crore',
#   'teenager',
#   'got',
#   'first',
#   'dose',
#   'corona',
#   'vaccine',
#   'lakh',
#   'pregnant_women',
#   'also',
#   'got',
#   'vaccinated',
#   'vaccination',
#   'couid'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'day',
#   'india',
#   'cumulative',
#   'vaccination',
#   'coverage_crosses',
#   'crore',
#   'one',
#   'crore',
#   'youngster',
#   'fifteen',
#   'eighteen',
#   'year',
#   'age_group',
#   'fully',
#   'vaccinated',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'today',
#   'till',
#   'seven',
#   'vaccination'],
#  ['jan',
#   'visa',
#   'sansthan',
#   'working',
#   'along',
#   'government',
#   'authority',
#   'promoting',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'among',
#   'public',
#   'drive',
#   'gram_panchayat',
#   'machhalishahar',
#   'daksha',
#   'block',
#   'jaipur',
#   'district'],
#  ['promoting',
#   'vaccination',
#   'couid',
#   'appropriate',
#   'behaviour',
#   'slum',
#   'key',
#   'task',
#   'session',
#   'interaction',
#   'community',
#   'disseminates',
#   'key',
#   'information',
#   'message',
#   'involving',
#   'usage',
#   'mask',
#   'periodic',
#   'hand',
#   'washing',
#   'importance',
#   'social_distancing'],
#  ['please',
#   'completed',
#   'vaccination',
#   'requirement',
#   'go',
#   'ummah',
#   'later',
#   'discovered',
#   'number',
#   'people',
#   'went',
#   'ummah',
#   'came',
#   'back',
#   'couid',
#   'nineteen',
#   'not',
#   'vaccinated',
#   'action',
#   'taken',
#   'enabled'],
#  ['couid', 'nineteen', 'influenza', 'confection', 'importance', 'vaccination'],
#  ['banegaswasthindia',
#   'february',
#   'ten',
#   'india',
#   'administered',
#   'crore',
#   'vaccine',
#   'shot',
#   'look',
#   'coronavirus',
#   'vaccination',
#   'number',
#   'log',
#   'covidvaccination'],
#  ['ninth',
#   'free',
#   'couid',
#   'vaccination',
#   'camp_organised',
#   'punjabi',
#   'university',
#   'feb',
#   'ten',
#   'ten',
#   'zero',
#   'two',
#   'zero',
#   'interested',
#   'kindly',
#   'fill_form',
#   'available',
#   'health',
#   'centre',
#   'feb',
#   'eight',
#   'amp',
#   'nine',
#   'ten',
#   'one',
#   'three',
#   'zero'],
#  ['big',
#   'u',
#   'move',
#   'u',
#   'navy',
#   'personnel',
#   'fired',
#   'not',
#   'getting',
#   'vaccinated',
#   'unitedstates',
#   'fired',
#   'covidvaccination'],
#  ['may',
#   'sound',
#   'incredible',
#   'freedom_convoy',
#   'movement',
#   'trucker',
#   'canada',
#   'protesting',
#   'couid',
#   'vaccination',
#   'supported',
#   'u',
#   'president',
#   'trump',
#   'continues',
#   'global',
#   'menace',
#   'even',
#   'office'],
#  ['india',
#   'surpassed',
#   'crore',
#   'vaccinated',
#   'people',
#   'first',
#   'dose',
#   'verge',
#   'india',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'drive'],
#  ['covidsafe',
#   'used',
#   'couid',
#   'result',
#   'vaccination',
#   'status',
#   'quarantine',
#   'status',
#   'maybe',
#   'worthwhile',
#   'add'],
#  ['attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof']]

# %%
# def CreateCorpusFromDataFrame(corpusfolder, df):
#     for index, r in df.iterrows():
#     # print (r['text'])
#     # print (str(index) + '.txt')
#         text = r['translated']
#         fname = str(index)+'.txt'
#         corpusfile = open(corpusfolder+'/'+fname, "w", encoding="utf-8")
#         corpusfile.write(str(text))
#         corpusfile.close()

# CreateCorpusFromDataFrame('corpus/test/fact', fact)

# %%
#Prepare the corpus

# import nltk
# from nltk.corpus import PlaintextCorpusReader

# fact = PlaintextCorpusReader('corpus/fact', '.+\.txt')
# opinion = PlaintextCorpusReader('corpus/opinion', '.+\.txt')

# fact_docs1 = [fact.words(fid) for fid in fact.fileids()]
# opinion_docs1 = [opinion.words(fid) for fid in opinion.fileids()]

print(opinion_docs_train[0][0:20])
print(fact_docs_train[0][0:20])
# Out:
# ['health', 'news', 'corona', 'vaccination', 'producing', 'antibody', 'immunity', 'natural', 'couid', 'nineteen', 'infection', 'people', 'dog']
# ['stay_safe', 'couid', 'proper', 'precaution', 'vaccination', 'compulsory', 'babaramrahim', 'also', 'inspired', 'letter', 'getvaccinated', 'following', 'inspiration', 'volunteer', 'getting', 'devotee', 'also', 'organising', 'free', 'vaccination']

# %%
# Combine the categories of the corpus
all_docs_train = opinion_docs_train + fact_docs_train
num_fact_docs = len(fact_docs_train)
num_opinion_docs = len(opinion_docs_train)
print (num_opinion_docs)
print(num_fact_docs)
# Out:
# 89
# 200

# %%
all_docs_train[89:]
# Out:
# [['stay_safe',
#   'couid',
#   'proper',
#   'precaution',
#   'vaccination',
#   'compulsory',
#   'babaramrahim',
#   'also',
#   'inspired',
#   'letter',
#   'getvaccinated',
#   'following',
#   'inspiration',
#   'volunteer',
#   'getting',
#   'devotee',
#   'also',
#   'organising',
#   'free',
#   'vaccination',
#   'camp'],
#  ['couid', 'nineteen', 'vaccination', 'update', 'day'],
#  ['five',
#   'crore',
#   'total',
#   'eligible',
#   'beneficiary',
#   'fifteen',
#   'eighteen',
#   'age_group',
#   'received',
#   'first',
#   'dose',
#   'vaccine',
#   'couid',
#   'nineteen',
#   'india',
#   'couid',
#   'covidvaccine',
#   'vaccine',
#   'vaccination'],
#  ['one',
#   'abolition',
#   'article',
#   'two',
#   'surgical',
#   'strike',
#   'pak',
#   'favourite',
#   'country',
#   'three',
#   'ram',
#   'mandar',
#   'four',
#   'couid',
#   'vaccination',
#   'five',
#   'caa',
#   'arc',
#   'congress',
#   'must',
#   'etc',
#   'etc',
#   'etc',
#   'etc'],
#  ['ten',
#   'two',
#   'india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds'],
#  ['children_aged',
#   'sixteen',
#   'receive',
#   'booster',
#   'dose',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'month',
#   'taking',
#   'second',
#   'health',
#   'ministry',
#   'said',
#   'people',
#   'aged',
#   'forty',
#   'take',
#   'booster',
#   'vaccination',
#   'center',
#   'without',
#   'prior',
#   'appointment',
#   'aged',
#   'forty',
#   'still',
#   'need',
#   'appointment'],
#  ['crore',
#   'lakh',
#   'dos',
#   'couid',
#   'vaccine',
#   'administered',
#   'far',
#   'nationwide',
#   'vaccination',
#   'drive',
#   'largestvaccinedrive',
#   'daily_positivity',
#   'rate',
#   'four',
#   'per_cent',
#   'weekly',
#   'positivity_rate',
#   'per_cent'],
#  ['tonga', 'first', 'couid', 'outbreak', 'erupts', 'vaccination', 'surge'],
#  ['couid',
#   'vaccination',
#   'news',
#   'update',
#   'thirty',
#   'million',
#   'dos',
#   'vaccine',
#   'used',
#   'fight',
#   'corona',
#   'latest',
#   'news',
#   'update',
#   'couid',
#   'vaccination',
#   'delhi'],
#  ['oscar',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'not',
#   'required',
#   'person',
#   'attendee',
#   'exclusive'],
#  ['couid',
#   'nineteen',
#   'stats',
#   'india',
#   'ith',
#   'feb',
#   'eleven',
#   'zero',
#   'ist',
#   'active_cases',
#   'twelve',
#   'death',
#   'total',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'done',
#   'one',
#   'seventy',
#   'covidstatistics',
#   'covidcases',
#   'covidcasesinindia',
#   'omicron',
#   'omicronvariant'],
#  ['karnataka', 'achieves', 'ninety', 'double', 'dose', 'vaccination'],
#  ['year',
#   'people',
#   'travel',
#   'jane',
#   'vaccination',
#   'booklet',
#   'dengue',
#   'fever',
#   'yellow',
#   'fever',
#   'etc',
#   'vaccine',
#   'recommended',
#   'compulsory',
#   'certain',
#   'country',
#   'particularly',
#   'tropical',
#   'one',
#   'mine',
#   'also',
#   'put',
#   'couid',
#   'vaccine'],
#  ['health',
#   'benefit',
#   'super',
#   'specialist',
#   'wing',
#   'vaccination',
#   'efficient',
#   'fight',
#   'couid'],
#  ['oscar', 'attendee', 'required', 'show', 'proof', 'couid', 'vaccination'],
#  ['corona',
#   'pandemic',
#   'thousand',
#   'new',
#   'case',
#   'one',
#   'death',
#   'daily_positivity',
#   'rate',
#   'four',
#   'percent',
#   'india',
#   'coronavirus',
#   'couid',
#   'vaccination',
#   'corona'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'nine',
#   'two',
#   'number',
#   'people',
#   'received',
#   'first',
#   'dose',
#   'thirteen',
#   'atoll',
#   'eight',
#   'number',
#   'people',
#   'received',
#   'second',
#   'dose',
#   'atoll',
#   'fifteen',
#   'number',
#   'people',
#   'received',
#   'booster',
#   'dose',
#   'atoll'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'drive',
#   'underway',
#   'center',
#   'capital',
#   'wednesday'],
#  ['india',
#   'couid',
#   'tally',
#   'drop',
#   'ask',
#   'case',
#   'day',
#   'new',
#   'delhi',
#   'india',
#   'report',
#   'fresh',
#   'couid',
#   'case',
#   'one',
#   'recovery',
#   'one',
#   'death',
#   'last_twentyfour',
#   'hour',
#   'active_cases',
#   'seven',
#   'ninety',
#   'one',
#   'death_toll',
#   'five',
#   'daily_positivity',
#   'rate',
#   'four',
#   'total',
#   'vaccination',
#   'one',
#   'nineteen'],
#  ['international',
#   'traveler',
#   'vaccinated',
#   'two',
#   'dos',
#   'corona',
#   'vaccine',
#   'seven',
#   'day',
#   'isolation',
#   'central',
#   'government',
#   'winner',
#   'covidvaccination',
#   'centralgovt',
#   'quarantine'],
#  ['kasa',
#   'oriental',
#   'head',
#   'health',
#   'division',
#   'satisfied',
#   'enthusiasm',
#   'observed',
#   'vaccination',
#   'couid',
#   'nineteen',
#   'via'],
#  ['inspects', 'couid', 'vaccination', 'centre'],
#  ['fifteen',
#   'africa',
#   'received',
#   'least',
#   'one',
#   'dose',
#   'couid',
#   'vaccine',
#   'despite',
#   'anti',
#   'vaccination',
#   'protest',
#   'u',
#   'canada',
#   'together',
#   'stand',
#   'vaccineinequality'],
#  ['information',
#   'given',
#   'general_public',
#   'cultural',
#   'program',
#   'chiming',
#   'carnal',
#   'khinvsar',
#   'village',
#   'nagar',
#   'district',
#   'today',
#   'mobile',
#   'exhibition',
#   'vehicle',
#   'run',
#   'make',
#   'general_public',
#   'aware',
#   'corona',
#   'vaccination',
#   'covidvaccination'],
#  ['pickins',
#   'twenty',
#   'zero',
#   'child',
#   'peril',
#   'eligible',
#   'couid',
#   'nineteen',
#   'vaccination'],
#  ['lakh',
#   'couid',
#   'vaccine',
#   'dos',
#   'administrated',
#   'pregnant_women',
#   'till',
#   'feb',
#   'two',
#   'govt',
#   'february',
#   'two',
#   'seventy',
#   'percent',
#   'total',
#   'vaccine',
#   'dos',
#   'administered',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'centre',
#   'located',
#   'rural',
#   'news_economictimes'],
#  ['total',
#   'number',
#   'active',
#   'couid',
#   'nineteen',
#   'case',
#   'aryan',
#   'feb',
#   'eight',
#   'ten',
#   'total',
#   'vaccination',
#   'aryan',
#   'feb',
#   'eight',
#   'first',
#   'dose',
#   'one',
#   'second',
#   'dose',
#   'total',
#   'cumulative',
#   'figure',
#   'three',
#   'sixty',
#   'date',
#   'try'],
#  ['couid',
#   'vaccination',
#   'drive',
#   'children_aged',
#   'fifteen',
#   'eighteen',
#   'year',
#   'eligible',
#   'vaccine',
#   'get',
#   'registration',
#   'via',
#   'co_win',
#   'app',
#   'today',
#   'second',
#   'dose',
#   'coaxing',
#   'given',
#   'day'],
#  ['oscar',
#   'ceremony',
#   'attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof',
#   'covidvaccination'],
#  ['outreach',
#   'couid',
#   'vaccination',
#   'session',
#   'team',
#   'chander',
#   'nagar',
#   'east',
#   'district',
#   'largestvaccinedrive'],
#  ['list',
#   'vaccination',
#   'centre',
#   'ranch',
#   'district',
#   'february',
#   'thursday',
#   'highlighted',
#   'entry',
#   'special',
#   'couid',
#   'vaccination',
#   'camp',
#   'adolescent',
#   'aged',
#   'fifteen',
#   'eighteen',
#   'year'],
#  ['couid',
#   'nineteen',
#   'new_york',
#   'state',
#   'end',
#   'mask',
#   'mandate',
#   'proof',
#   'vaccination',
#   'requirement'],
#  ['question',
#   'regarding',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'eligible',
#   'population',
#   'eighteen',
#   'india',
#   'ith',
#   'feb',
#   'honorable',
#   'health',
#   'minister',
#   'said',
#   'india',
#   'completed',
#   'five',
#   'first',
#   'dose',
#   'eighteen',
#   'mean',
#   'eligible',
#   'population',
#   'crore'],
#  ['said',
#   'field',
#   'unit',
#   'punjab',
#   'continuously',
#   'sending',
#   'picture',
#   'couid',
#   'vaccination',
#   'campaign',
#   'different',
#   'district',
#   'closely',
#   'working',
#   'state',
#   'health',
#   'department',
#   'covidvaccination',
#   'nhmpunjab',
#   'usaidmomentum',
#   'si'],
#  ['evening',
#   'meeting',
#   'regarding',
#   'couid',
#   'vaccination',
#   'chaired',
#   'deputy_commissioner',
#   'abbottabad'],
#  ['couid',
#   'vaccination',
#   'pregnancy',
#   'resulted',
#   'lasting',
#   'antibody',
#   'level',
#   'infant',
#   'compared',
#   'baby',
#   'born',
#   'vaccinated',
#   'couid',
#   'infected',
#   'mother',
#   'showed',
#   'study',
#   'ommcomnews'],
#  ['gujarati',
#   'twentyfour_hours',
#   'vaccinated',
#   'person',
#   'first',
#   'dose',
#   'two',
#   'second',
#   'five',
#   'fifteen',
#   'crore',
#   'administered',
#   'first',
#   'four',
#   'crore',
#   'second',
#   'dose',
#   'couid',
#   'vaccine',
#   'gujaratcoronaupdate',
#   'covidvaccination'],
#  ['working',
#   'fast',
#   'towards',
#   'achieving',
#   'per_cent',
#   'covidvaccination',
#   'country',
#   'say',
#   'raja_sasha'],
#  ['number',
#   'case',
#   'state',
#   'saw',
#   'slight',
#   'decline',
#   'four',
#   'case',
#   'reported',
#   'total',
#   'number',
#   'couid',
#   'nineteen',
#   'case',
#   'tamilnadu',
#   'reached',
#   'twenty',
#   'coronavirusupdates',
#   'coronavirus',
#   'corona',
#   'vaccination'],
#  ['couid', 'vaccination', 'drive', 'child', 'slowing', 'chandigarh'],
#  ['first',
#   'dose',
#   'couid',
#   'vaccination',
#   'coverage',
#   'among',
#   'youngster',
#   'crossed',
#   'five',
#   'crore',
#   'indicating',
#   'five',
#   'adolescent',
#   'fifteen',
#   'seventeen',
#   'year',
#   'partially',
#   'immunized'],
#  ['delhi',
#   'university',
#   'start',
#   'physical',
#   'class',
#   'ug',
#   'pig',
#   'course',
#   'feb',
#   'seventeen',
#   'onwards',
#   'college',
#   'affiliated',
#   'du',
#   'also',
#   'directed',
#   'encourage',
#   'covidvaccination',
#   'student',
#   'faculty',
#   'left',
#   'behind',
#   'immunization',
#   'drive',
#   'delhiuniversity'],
#  ['update',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'availability',
#   'state',
#   'u',
#   'nineteen',
#   'crore',
#   'vaccine',
#   'dos',
#   'provided',
#   'state',
#   'u',
#   'twelve',
#   'two',
#   'crore_balance',
#   'utilized',
#   'vaccine',
#   'dos',
#   'still',
#   'available',
#   'state',
#   'u',
#   'vaccination'],
#  ['besides',
#   'uploading',
#   'negative',
#   'taken',
#   'prior',
#   'journey',
#   'option',
#   'upload',
#   'certificate',
#   'completing',
#   'full',
#   'primary',
#   'vaccination',
#   'schedule',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'provided',
#   'country',
#   'reciprocal',
#   'basis',
#   'ministryofhealth'],
#  ['india',
#   'couid',
#   'vaccination',
#   'coverage',
#   'reached',
#   'around',
#   'crore',
#   'lakh',
#   'dos',
#   'administered',
#   'till',
#   'seven',
#   'today',
#   'ministry',
#   'health',
#   'covidvaccination'],
#  ['effectiveness',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'nine',
#   'month',
#   'post',
#   'vaccination',
#   'population',
#   'sweden'],
#  ['besides',
#   'uploading',
#   'negative',
#   'per',
#   'report',
#   'taken',
#   'prior',
#   'journey',
#   'option',
#   'upload',
#   'certificate',
#   'completing',
#   'full',
#   'primary',
#   'vaccination',
#   'schedule',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'provided',
#   'country',
#   'reciprocal',
#   'basis'],
#  ['delhi',
#   'high',
#   'court',
#   'agrees',
#   'hear',
#   'teacher',
#   'plea_seeking',
#   'exemption',
#   'couid',
#   'vaccination',
#   'petition',
#   'stated',
#   'exemption',
#   'granted',
#   'considering',
#   'auto',
#   'immune',
#   'disease',
#   'however',
#   'unilaterally',
#   'withdrawn',
#   'later',
#   'prohibiting',
#   'taking',
#   'even',
#   'online',
#   'class'],
#  ['covidvaccination',
#   'update',
#   'crore',
#   'vaccine',
#   'administered',
#   'nationwide',
#   'couid',
#   'vaccination',
#   'lakh',
#   'vaccinated',
#   'last_twentyfour',
#   'hour',
#   'weekly',
#   'active_cases',
#   'rate',
#   'link',
#   'largestvaccinedrive'],
#  ['five',
#   'crore',
#   'adolescent',
#   'fifteen',
#   'seventeen',
#   'year',
#   'age_group',
#   'india',
#   'covered',
#   'first',
#   'dose',
#   'couid',
#   'vaccine',
#   'country',
#   'report',
#   'syringe',
#   'read',
#   'vaccination',
#   'coronavirus'],
#  ['state', 'couid', 'nineteen', 'vaccination', 'update', 'february'],
#  ['oscar',
#   'ceremony',
#   'attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof'],
#  ['u',
#   'plan',
#   'roll',
#   'couid',
#   'nineteen',
#   'shot',
#   'child',
#   'five',
#   'year',
#   'february',
#   'stay',
#   'tuned',
#   'space',
#   'live_updates',
#   'link',
#   'coronavirus',
#   'vaccination'],
#  ['list',
#   'vaccination',
#   'centre',
#   'ranch',
#   'district',
#   'february',
#   'friday',
#   'highlighted',
#   'entry',
#   'special',
#   'couid',
#   'vaccination',
#   'camp',
#   'adolescent',
#   'aged',
#   'fifteen',
#   'eighteen',
#   'year'],
#  ['coronavirus',
#   'vaccination',
#   'india',
#   'update',
#   'five',
#   'crore',
#   'youngster',
#   'received',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'first',
#   'dose',
#   'adolescent',
#   'received',
#   'first',
#   'dose',
#   'vaccine',
#   'government',
#   'informed',
#   'raja_sasha'],
#  ['covidvaccination',
#   'drive',
#   'children_aged',
#   'fifteen',
#   'eighteen',
#   'chandigarh',
#   'slowed',
#   'considerably',
#   'kid',
#   'received',
#   'first',
#   'second',
#   'dose',
#   'past',
#   'week',
#   'average',
#   'report'],
#  ['isolation',
#   'period',
#   'couid',
#   'nineteen',
#   'case',
#   'amp',
#   'quarantine',
#   'period',
#   'close',
#   'contact',
#   'according',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'eight',
#   'february',
#   'isolation',
#   'period',
#   'couid',
#   'nineteen',
#   'case',
#   'amp',
#   'quarantine',
#   'period',
#   'close',
#   'contact',
#   'according',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'eight',
#   'february'],
#  ['roper',
#   'testing',
#   'airport',
#   'not',
#   'mandatory',
#   'international',
#   'traveler',
#   'vaccinated',
#   'two',
#   'dose',
#   'corona',
#   'vaccine',
#   'central',
#   'government',
#   'winner',
#   'roper',
#   'covidvaccination',
#   'centralgovt',
#   'quarantine'],
#  ['shri',
#   'aditya',
#   'neg',
#   'flag',
#   'couid',
#   'awareness',
#   'mobile',
#   'van',
#   'cut',
#   'school',
#   'today',
#   'van',
#   'shall',
#   'flash',
#   'message',
#   'regarding',
#   'covidvaccination',
#   'appropriatebehaviour',
#   'eight',
#   'eleven',
#   'february',
#   'shimla'],
#  ['couid',
#   'vaccination',
#   'centre',
#   'list',
#   'ten',
#   'two',
#   'two',
#   'two',
#   'vaccinationdrive',
#   'covidvaccine',
#   'kmcfightsagainstcorona'],
#  ['download', 'couid', 'vaccination', 'card', 'est', 'dose'],
#  ['leader', 'go', 'country', 'take', 'couid', 'vaccination'],
#  ['one',
#   'crore',
#   'adolescent',
#   'fifteen',
#   'eighteen',
#   'yr',
#   'group',
#   'fully',
#   'vaccinated',
#   'couid',
#   'nineteen',
#   'masuka_mandaviya',
#   'administration',
#   'lakh',
#   'vaccine',
#   'dos',
#   'span',
#   'twentyfour_hours',
#   'india',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage',
#   'news_economictimes'],
#  ['loved',
#   'vaccination',
#   'campaign',
#   'country',
#   'tuesday',
#   'day',
#   'lakh',
#   'vaccine',
#   'administered',
#   'total',
#   'vaccination',
#   'crore',
#   'vaccination',
#   'couid'],
#  ['couid',
#   'vaccination',
#   'update',
#   'vaccination',
#   'figure',
#   'india',
#   'crossed',
#   'crore',
#   'lakh',
#   'people',
#   'took',
#   'vaccine',
#   'twentyfour_hours'],
#  ['hit',
#   'back',
#   'pharmaceutical',
#   'company',
#   'disputed',
#   'claim',
#   'pfizer_biotech',
#   'booster',
#   'dose',
#   'would',
#   'offer',
#   'greater',
#   'protection',
#   'couid',
#   'nineteen',
#   'infection',
#   'especially',
#   'sinovac',
#   'primary',
#   'vaccination',
#   'recipient'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'response',
#   'project',
#   'support',
#   'health',
#   'department',
#   'conducting',
#   'community',
#   'based',
#   'mobile',
#   'vaccination',
#   'male',
#   'amp',
#   'female',
#   'different',
#   'area',
#   'district',
#   'chachi',
#   'period',
#   'two',
#   'month',
#   'individual',
#   'received',
#   'couid',
#   'vaccination'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'day',
#   'india',
#   'cumulative',
#   'vaccination',
#   'coverage',
#   'reach',
#   'nearly',
#   'crore',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'today',
#   'till',
#   'seven'],
#  ['gi',
#   'representation',
#   'scenario',
#   'india',
#   'ith',
#   'feb',
#   'prepared',
#   'total',
#   'vaccination',
#   'one',
#   'seventy',
#   'active_cases',
#   'last_twentyfour',
#   'seventy',
#   'coronavirusupdates',
#   'coronavirus',
#   'maharashtrian',
#   'omicron',
#   'omicronvarient'],
#  ['biggest',
#   'u',
#   'move',
#   'nine',
#   'worker',
#   'exempted',
#   'couid',
#   'vaccination',
#   'rule',
#   'religious',
#   'ground',
#   'airforce',
#   'personnel',
#   'covidvaccination',
#   'rule',
#   'exemption'],
#  ['vaccination',
#   'picking',
#   'several',
#   'measure',
#   'taken',
#   'health',
#   'department',
#   'private_hospitals',
#   'witnessing',
#   'le',
#   'number',
#   'people',
#   'getting',
#   'vaccinated',
#   'site',
#   'coronavirus',
#   'covidvaccine',
#   'covidvaccination',
#   'ingot'],
#  ['india',
#   'covidvaccination',
#   'coverage',
#   'reached',
#   'crore',
#   'lakh',
#   'dos',
#   'administered',
#   'till',
#   'seven',
#   'today',
#   'health',
#   'ministry'],
#  ['today',
#   'nisam',
#   'muhammad',
#   'khalil',
#   'additional',
#   'assistant',
#   'commissioner',
#   'one',
#   'khat',
#   'visited',
#   'civil',
#   'dispensary',
#   'jungle',
#   'hell',
#   'checked',
#   'staff',
#   'attendance',
#   'couid',
#   'vaccination'],
#  ['covidvaccination',
#   'pregnancy',
#   'resulted',
#   'lasting',
#   'antibody',
#   'level',
#   'infant',
#   'compared',
#   'baby',
#   'born',
#   'vaccinated',
#   'couid',
#   'infected',
#   'mother',
#   'showed',
#   'study'],
#  ['india',
#   'loved',
#   'vaccination',
#   'coverage',
#   'reached',
#   'crore',
#   'lakh',
#   'dos',
#   'administered',
#   'till',
#   'seven',
#   'today',
#   'ministry',
#   'health',
#   'covidvaccination'],
#  ['two',
#   'three',
#   'airline',
#   'allow',
#   'boarding',
#   'passenger',
#   'filled',
#   'information',
#   'self',
#   'declaration',
#   'form',
#   'air',
#   'sumida',
#   'portal',
#   'uploaded',
#   'negative',
#   'per',
#   'test',
#   'report',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'certificate'],
#  ['couid',
#   'nineteen',
#   'stats',
#   'india',
#   'feb',
#   'eleven',
#   'zero',
#   'active_cases',
#   'death',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'done',
#   'one',
#   'twentyfour',
#   'covidstatistics',
#   'covidcases',
#   'covidcasesinindia',
#   'omicron',
#   'omicronvariant'],
#  ['oscar', 'celebs', 'require', 'provide', 'proof', 'couid', 'vaccination'],
#  ['information',
#   'given',
#   'general_public',
#   'cultural',
#   'program',
#   'various',
#   'village',
#   'altar',
#   'nagar',
#   'district',
#   'today',
#   'mobile',
#   'exhibition',
#   'vehicle',
#   'run',
#   'make',
#   'general_public',
#   'aware',
#   'corona',
#   'vaccination',
#   'covidvaccination'],
#  ['group',
#   'trucker',
#   'canada',
#   'protest',
#   'mandatory',
#   'couid',
#   'vaccination',
#   'name',
#   'freedom',
#   'choice',
#   'vocal',
#   'minority',
#   'fanatical',
#   'holding',
#   'country',
#   'ransom'],
#  ['performed',
#   'duty',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'session',
#   'shimla',
#   'dated',
#   'nine',
#   'two',
#   'total',
#   'number',
#   'beneficiary',
#   'session',
#   'number',
#   'age_group',
#   'eighteen',
#   'amp',
#   'ad'],
#  ['india', 'couid', 'vaccination', 'coverage_crosses', 'crore_mark'],
#  ['one',
#   'student',
#   'able',
#   'return',
#   'campus',
#   'stage',
#   'beginning',
#   'march',
#   'one',
#   'defence',
#   'minister',
#   'hishammuddin',
#   'hussein',
#   'say',
#   'complete',
#   'incomplete',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'allowed',
#   'campus'],
#  ['record',
#   'two',
#   'dos',
#   'vaccine',
#   'one',
#   'crore',
#   'people',
#   'age',
#   'fifteen',
#   'eighteen',
#   'covidvaccination',
#   'india'],
#  ['ministry',
#   'health',
#   'arranging',
#   'mobile',
#   'medical',
#   'team',
#   'bring',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'people',
#   'community',
#   'order',
#   'increase',
#   'cambodia',
#   'vaccination',
#   'rate',
#   'accelerate',
#   'administration',
#   'booster',
#   'shot'],
#  ['use',
#   'india',
#   'travel',
#   'couid',
#   'nineteen',
#   'per',
#   'negative',
#   'report',
#   'still',
#   'must',
#   'mandatory',
#   'quarantine',
#   'arrival',
#   'vaccination',
#   'certificate',
#   'not',
#   'sufficient',
#   'travel',
#   'use',
#   'india',
#   'embassy',
#   'say',
#   'use',
#   'roper',
#   'travel',
#   'quarantine'],
#  ['new_york',
#   'roll',
#   'back',
#   'mask',
#   'mandate',
#   'florida',
#   'surgeon',
#   'general',
#   'not',
#   'reveal',
#   'vaccination',
#   'status',
#   'live',
#   'couid',
#   'nineteen',
#   'update'],
#  ['couid',
#   'vaccination',
#   'tribal',
#   'school',
#   'girl',
#   'chapati',
#   'gumba',
#   'jharkhand',
#   'tika',
#   'express',
#   'gumba',
#   'team',
#   'health',
#   'department',
#   'careindia',
#   'foundation',
#   'covidvaccination',
#   'careindia'],
#  ['couid',
#   'vaccination',
#   'started',
#   'today',
#   'various',
#   'school',
#   'district',
#   'child',
#   'age',
#   'fifteen',
#   'fourteen',
#   'direction',
#   'department',
#   'health',
#   'dish',
#   'total',
#   'student',
#   'vaccinated',
#   'first',
#   'day',
#   'district',
#   'chief',
#   'hospital',
#   'buddhist',
#   'covidvaccination',
#   'coronaupdate'],
#  ['envoy',
#   'textile',
#   'limited',
#   'proud',
#   'share',
#   'whole',
#   'workforce',
#   'fully',
#   'vaccinated',
#   'factory',
#   'premise',
#   'couid',
#   'nineteen',
#   'envoy',
#   'textile',
#   'limited',
#   'always',
#   'care',
#   'family_members',
#   'envoytextiles',
#   'vaccination',
#   'denim',
#   'bangladesh'],
#  ['india',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'nine',
#   'feb',
#   'nine',
#   'fifteen',
#   'view',
#   'largestvaccinedrive',
#   'largestvaccinationdrive',
#   'indiafightscorona'],
#  ['couid',
#   'nineteen',
#   'update',
#   'vaccine',
#   'dos',
#   'administered',
#   'far',
#   'nationwide',
#   'vaccination',
#   'drive',
#   'active_cases',
#   'stand',
#   'one',
#   'recovery_rate',
#   'currently',
#   'read'],
#  ['cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'last_twentyfour',
#   'hour',
#   'read'],
#  ['couid',
#   'nineteen',
#   'prevention',
#   'vaccination',
#   'programme',
#   'continues',
#   'region',
#   'amp',
#   'state'],
#  ['india',
#   'couid',
#   'vaccination',
#   'coverage_crosses',
#   'mark',
#   'nineteen',
#   'vaccine',
#   'dos',
#   'administered',
#   'est',
#   'dose',
#   'four',
#   'vaccine',
#   'dos',
#   'given',
#   'dos',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'today'],
#  ['effectiveness',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'nine',
#   'month',
#   'post',
#   'vaccination',
#   'population',
#   'sweden'],
#  ['one',
#   'crore',
#   'adolescent',
#   'fifteen',
#   'eighteen',
#   'year',
#   'age_group',
#   'nationwide',
#   'fully',
#   'vaccinated',
#   'novel',
#   'coronavirus',
#   'infection',
#   'union',
#   'health',
#   'minister',
#   'said',
#   'covidvaccine',
#   'covidvaccination',
#   'vaccination',
#   'mansukhmandaviya'],
#  ['oscar',
#   'ceremony',
#   'not',
#   'require',
#   'couid',
#   'vaccination',
#   'proof',
#   'person',
#   'attendee',
#   'couid',
#   'oscarceremony',
#   'theacademy',
#   'vaccine'],
#  ['breakthrough',
#   'couid',
#   'power',
#   'immune_response',
#   'variant',
#   'including',
#   'omicron',
#   'sars_cov',
#   'two',
#   'infection',
#   'vaccination',
#   'trigger',
#   'antibody',
#   'level',
#   'similar',
#   'people',
#   'whose',
#   'infection',
#   'preceded',
#   'vaccination'],
#  ['couid',
#   'india',
#   'update',
#   'case',
#   'one',
#   'recovery',
#   'one',
#   'death',
#   'last_twentyfour',
#   'hour',
#   'active_cases',
#   'eight',
#   'two',
#   'eleven',
#   'death_toll',
#   'five',
#   'five',
#   'daily_positivity',
#   'rate',
#   'four',
#   'total',
#   'vaccination',
#   'one',
#   'seventy',
#   'health',
#   'ministry'],
#  ['couid',
#   'nineteen',
#   'saskatchewan',
#   'proof',
#   'vaccination',
#   'negative',
#   'test',
#   'requirement',
#   'ending',
#   'monday',
#   'full'],
#  ['information',
#   'given',
#   'general_public',
#   'cultural',
#   'program',
#   'tatarpur',
#   'chandauli',
#   'jindoli',
#   'village',
#   'altar',
#   'district',
#   'today',
#   'mobile',
#   'exhibition',
#   'vehicle',
#   'run',
#   'make',
#   'general_public',
#   'aware',
#   'corona',
#   'vaccination',
#   'covidvaccination'],
#  ['corona',
#   'virus',
#   'update',
#   'decline',
#   'corona',
#   'case',
#   'country',
#   'continues',
#   'new',
#   'case',
#   'twentyfour_hours',
#   'recoveryrate',
#   'nutcase',
#   'coronavirus',
#   'coronainindia',
#   'covidvaccination'],
#  ['big',
#   'int',
#   'traveller',
#   'coming',
#   'india',
#   'feb',
#   'fourteen',
#   'upload',
#   'negative',
#   'couid',
#   'nineteen',
#   'per',
#   'report',
#   'test',
#   'within',
#   'prior',
#   'undertaking',
#   'journey',
#   'certificate',
#   'completing',
#   'full',
#   'primary',
#   'vaccination',
#   'schedule',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'country',
#   'like',
#   'usa',
#   'canada',
#   'etc'],
#  ['update',
#   'india',
#   'record',
#   'fresh',
#   'couid',
#   'nineteen',
#   'case',
#   'single',
#   'day',
#   'coronavirusupdates',
#   'activecases',
#   'recovery',
#   'positivityrate',
#   'deathtoll',
#   'covidvaccination'],
#  ['couid',
#   'vaccination',
#   'centre',
#   'list',
#   'ten',
#   'two',
#   'one',
#   'two',
#   'vaccinationdrive',
#   'covidvaccine',
#   'kmcfightsagainstcorona'],
#  ['majority',
#   'parent',
#   'agree',
#   'couid',
#   'vaccination',
#   'kid',
#   'aged',
#   'five',
#   'eleven',
#   'health',
#   'ministry'],
#  ['three',
#   'allow',
#   'operation',
#   'public',
#   'hall',
#   'capacity',
#   'seventy',
#   'venue',
#   'proof',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'four',
#   'allow',
#   'holding',
#   'local',
#   'international',
#   'conference',
#   'exhibition',
#   'capacity',
#   'not',
#   'seventy'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'update',
#   'eight',
#   'two',
#   'number',
#   'people',
#   'received',
#   'first',
#   'dose',
#   'nine',
#   'atoll',
#   'sixteen',
#   'number',
#   'people',
#   'received',
#   'second',
#   'dose',
#   'atoll',
#   'seventeen',
#   'number',
#   'people',
#   'received',
#   'booster',
#   'dose',
#   'atoll',
#   'two'],
#  ['disruption',
#   'basic',
#   'health',
#   'service',
#   'vaccination',
#   'programme',
#   'treatment',
#   'disease',
#   'like',
#   'aid',
#   'reported',
#   'country',
#   'worldhealthorganization',
#   'survey',
#   'impact',
#   'couid',
#   'nineteen',
#   'pandemic',
#   'showed',
#   'monday'],
#  ['got',
#   'second',
#   'dose',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'saigon',
#   'municipal',
#   'maternity',
#   'home',
#   'today',
#   'thank',
#   'vaccination'],
#  ['eight',
#   'two',
#   'received',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'booster',
#   'dose',
#   'pfizer',
#   'relax',
#   'vaccination',
#   'centre',
#   'friendly',
#   'asked',
#   'sign',
#   'consent',
#   'form',
#   'whole',
#   'process',
#   'took',
#   'ten',
#   'minute'],
#  ['citizen',
#   'without',
#   'id',
#   'proof',
#   'lucknow',
#   'eligible',
#   'couid',
#   'nineteen',
#   'vaccination'],
#  ['india',
#   'covidvaccination',
#   'coverage_crossed',
#   'crore',
#   'lakh',
#   'mark',
#   'crore',
#   'nineteen',
#   'lakh',
#   'vaccine',
#   'dos',
#   'administered',
#   'first',
#   'dose',
#   'crore',
#   'four',
#   'lakh',
#   'vaccine',
#   'dos',
#   'given',
#   'second',
#   'dos',
#   'lakh',
#   'thousand',
#   'vaccine',
#   'dos',
#   'administered',
#   'yesterday'],
#  ['adult_population',
#   'received',
#   'first',
#   'dose',
#   'couid',
#   'vaccine',
#   'eligible',
#   'cohort',
#   'received',
#   'shot',
#   'health',
#   'ministry',
#   'couid',
#   'india',
#   'vaccination'],
#  ['successful',
#   'launch',
#   'two',
#   'batch',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'confidence',
#   'amp',
#   'advocacy',
#   'program',
#   'nom',
#   'nagaland',
#   'excited',
#   'announce',
#   'launch',
#   'third',
#   'batch',
#   'february',
#   'train',
#   'asha',
#   'arm',
#   'allteachalllearn',
#   'vaccinehesitancy'],
#  ['moving',
#   'tuesday',
#   'five',
#   'crore',
#   'children_aged',
#   'fifteen',
#   'eighteen',
#   'year',
#   'got',
#   'first',
#   'dose',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'learn',
#   'covidvaccine',
#   'vaccination',
#   'vaccine',
#   'corona',
#   'coronavirus',
#   'pandemic',
#   'unscrews'],
#  ['india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds',
#   'newsonline',
#   'omicron',
#   'indian',
#   'various',
#   'cumulative',
#   'vaccination',
#   'coverage_exceeds'],
#  ['one',
#   'crore',
#   'people',
#   'vaccinated',
#   'corona',
#   'india',
#   'far',
#   'winner',
#   'india',
#   'covidvaccination'],
#  ['sixty',
#   'per_cent',
#   'parent',
#   'children_aged',
#   'five',
#   'eleven',
#   'agree',
#   'couid',
#   'vaccination',
#   'survey'],
#  ['everyone',
#   'getting',
#   'vaccinated',
#   'couid',
#   'vaccination',
#   'situation',
#   'prothomalo',
#   'covidvaccine'],
#  ['couid', 'vaccination', 'center', 'eleven', 'two'],
#  ['india',
#   'report',
#   'fresh',
#   'couid',
#   'nineteen',
#   'case',
#   'one',
#   'recovery',
#   'one',
#   'death',
#   'last_twentyfour',
#   'hour',
#   'active_cases',
#   'eight',
#   'two',
#   'eleven',
#   'death_toll',
#   'five',
#   'five',
#   'daily_positivity',
#   'rate',
#   'four',
#   'total',
#   'vaccination',
#   'one',
#   'seventy',
#   'rahemanzildaily',
#   'india',
#   'healthministry',
#   'newsupdates'],
#  ['india',
#   'surpassed',
#   'crore',
#   'vaccinated',
#   'people',
#   'first',
#   'dose',
#   'verge',
#   'india',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'drive'],
#  ['gujarati',
#   'twentyfour_hours',
#   'vaccinated',
#   'person',
#   'first',
#   'dose',
#   'second',
#   'five',
#   'sixteen',
#   'crore',
#   'administered',
#   'first',
#   'four',
#   'seven',
#   'crore',
#   'second',
#   'dose',
#   'couid',
#   'vaccine',
#   'gujaratcoronaupdate',
#   'covidvaccination'],
#  ['get',
#   'vaccinated',
#   'without',
#   'delay',
#   'protect',
#   'couid',
#   'nineteen',
#   'happy',
#   'inform',
#   'coaxing',
#   'vaccination',
#   'available',
#   'precautionary',
#   'dose',
#   'booster',
#   'dose',
#   'child',
#   'fifteen',
#   'year',
#   'first',
#   'second',
#   'dose',
#   'contact',
#   'vaccine'],
#  ['troop',
#   'lekhapani',
#   'amp',
#   'rupa',
#   'battalion',
#   'redshielddivision',
#   'conducted',
#   'medical',
#   'camp',
#   'changing',
#   'district',
#   'arunachal',
#   'benefiting',
#   'local',
#   'also',
#   'given',
#   'couid',
#   'vaccination',
#   'football',
#   'match',
#   'also',
#   'organised',
#   'local',
#   'tinsukia',
#   'assay'],
#  ['india',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage',
#   'reach',
#   'nearly',
#   'crore',
#   'administration',
#   'lakh',
#   'dos',
#   'till',
#   'seven',
#   'today',
#   'union',
#   'health',
#   'ministry'],
#  ['press_conference',
#   'excellency',
#   'minister',
#   'health',
#   'intensification',
#   'communication',
#   'amp',
#   'awareness',
#   'campaign',
#   'favor',
#   'vaccination',
#   'couid',
#   'nineteen',
#   'dry'],
#  ['vaccination',
#   'drive',
#   'around',
#   'crore',
#   'couid',
#   'vaccine',
#   'dos',
#   'administered',
#   'india',
#   'say',
#   'govt'],
#  ['dated',
#   'eight',
#   'two',
#   'evening',
#   'meeting',
#   'regarding',
#   'extended',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'campaign',
#   'held',
#   'chairmanship',
#   'worthy',
#   'orakzai',
#   'officer',
#   'dist_admin',
#   'health',
#   'team',
#   'rep',
#   'line',
#   'depth',
#   'participated',
#   'meeting'],
#  ['india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage',
#   'reach',
#   'crore'],
#  ['total',
#   'number',
#   'active',
#   'couid',
#   'nineteen',
#   'case',
#   'punjab',
#   'feb',
#   'nine',
#   'total',
#   'vaccination',
#   'first',
#   'second',
#   'dose',
#   'punjab',
#   'day',
#   'feb',
#   'nine',
#   'two',
#   'pub'],
#  ['people',
#   'age',
#   'forty',
#   'get',
#   'booster',
#   'dose',
#   'vaccine',
#   'without',
#   'prior',
#   'appointment',
#   'vaccination',
#   'center',
#   'ministry',
#   'health',
#   'announced',
#   'thursday',
#   'people',
#   'aged',
#   'sixteen',
#   'older',
#   'receive',
#   'boostershot',
#   'least',
#   'month',
#   'getting',
#   'dose',
#   'added'],
#  ['seventeen',
#   'new',
#   'case',
#   'today',
#   'expected',
#   'omicron',
#   'case',
#   'sharp_rise',
#   'booster',
#   'campaign',
#   'amp',
#   'child',
#   'vaccination',
#   'needed_proven',
#   'successful_reducing',
#   'severity',
#   'couid',
#   'nineteen',
#   'boost_elderly',
#   'vaccinate',
#   'children_pickbooster',
#   'pickins'],
#  ['couid',
#   'nineteen',
#   'vaccinationsyringe',
#   'est',
#   'dose',
#   'done',
#   'two',
#   'february',
#   'vaccinated',
#   'boosterdose',
#   'pakistan',
#   'pakistan'],
#  ['couid',
#   'nineteen',
#   'update',
#   'vaccine',
#   'dos',
#   'administered',
#   'far',
#   'nationwide',
#   'vaccination',
#   'drive',
#   'india',
#   'active_caseload',
#   'currently_stands',
#   'seven',
#   'ninety',
#   'active_cases',
#   'stand',
#   'one'],
#  ['list',
#   'vaccination',
#   'centre',
#   'ranch',
#   'district',
#   'ith',
#   'february',
#   'wednesday',
#   'highlighted',
#   'entry',
#   'special',
#   'couid',
#   'vaccination',
#   'camp',
#   'adolescent',
#   'aged',
#   'fifteen',
#   'eighteen',
#   'year'],
#  ['india', 'couid', 'nineteen', 'vaccination', 'coverage_crosses', 'mark'],
#  ['covidvaccination',
#   'update',
#   'crore',
#   'vaccinated',
#   'far',
#   'nationwide',
#   'couid',
#   'vaccination',
#   'rate',
#   'weekly',
#   'active_cases',
#   'lakh',
#   'vaccinated',
#   'last_twentyfour',
#   'hour',
#   'largestvaccinedrive'],
#  ['seventeen',
#   'new',
#   'case',
#   'today',
#   'expected',
#   'omicron',
#   'new',
#   'case',
#   'sharp_rise',
#   'booster',
#   'campaign',
#   'amp',
#   'child',
#   'vaccination',
#   'needed_proven',
#   'successful_reducing',
#   'severity',
#   'couid',
#   'nineteen',
#   'boost_elderly',
#   'vaccinate',
#   'children_pickbooster',
#   'pickins'],
#  ['banegaswasthindia',
#   'february',
#   'nine',
#   'india',
#   'administered',
#   'crore',
#   'vaccine',
#   'shot',
#   'look',
#   'coronavirus',
#   'vaccination',
#   'number',
#   'log',
#   'covidvaccination',
#   'omicron'],
#  ['patient',
#   'refuse',
#   'couid',
#   'vaccination',
#   'denied',
#   'transplantation',
#   'eligibility',
#   'cardiology'],
#  ['today',
#   'visited',
#   'vidyapeeth',
#   'block',
#   'manduadih',
#   'son',
#   'vaccination',
#   'nurse',
#   'without',
#   'adhering',
#   'couid',
#   'norm',
#   'crowded',
#   'people',
#   'one',
#   'nook',
#   'injecting',
#   'child',
#   'make',
#   'count',
#   'not',
#   'vaccinate',
#   'also',
#   'pretended',
#   'amp',
#   'argued',
#   'u',
#   'ask',
#   'vaccination',
#   'detail',
#   'governmenthopitals',
#   'mo'],
#  ['oscar',
#   'ceremony',
#   'attendee',
#   'not',
#   'required',
#   'provide',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'proof',
#   'read',
#   'story',
#   'covidvaccination'],
#  ['covidvaccination',
#   'total',
#   'vaccination',
#   'coverage',
#   'corona',
#   'vaccine',
#   'country',
#   'increased',
#   'one',
#   'seventy',
#   'union',
#   'health',
#   'ministry',
#   'vaccination',
#   'unionhealthministry',
#   'india'],
#  ['double',
#   'vaccinated',
#   'individual',
#   'not',
#   'require',
#   'per',
#   'test',
#   'entering',
#   'meghalaya',
#   'conrad',
#   'sang',
#   'new',
#   'rule',
#   'come',
#   'effect',
#   'february',
#   'eleven',
#   'shilling',
#   'meghalaya',
#   'northeastindia',
#   'covidvaccination'],
#  ['mobile',
#   'health',
#   'unit',
#   'arranged',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'drive',
#   'eight',
#   'village',
#   'three',
#   'school',
#   'tribal',
#   'beneficiary',
#   'registered',
#   'mobile',
#   'vaccination',
#   'unit',
#   'till_date',
#   'unit',
#   'registered',
#   'vaccination',
#   'rural',
#   'sector',
#   'covidvacccine',
#   'deepakfoundation'],
#  ['vaccination',
#   'camp',
#   'organised',
#   'different',
#   'village',
#   'prevent',
#   'couid'],
#  ['ten',
#   'beneficiary',
#   'received',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'including',
#   'one',
#   'pregnant',
#   'woman',
#   'presence',
#   'national',
#   'observer',
#   'mow',
#   'mawkhanu',
#   'diengpasoh',
#   'door_door',
#   'mobilisation',
#   'drive',
#   'conducted',
#   'presence',
#   'national',
#   'team',
#   'observer',
#   'tarot',
#   'diengpasoh'],
#  ['union',
#   'health',
#   'family_welfare',
#   'minister_masuka',
#   'mandala',
#   'said',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'helped',
#   'reduce',
#   'mortality',
#   'hospital',
#   'admission',
#   'covidvaccination'],
#  ['million',
#   'dos',
#   'given',
#   'national',
#   'vaccination',
#   'crore',
#   'nineteen',
#   'lakh',
#   'first',
#   'dose',
#   'crore',
#   'four',
#   'lakh',
#   'second',
#   'dose',
#   'given',
#   'lakh',
#   'thousand',
#   'vaccine',
#   'given',
#   'last_twentyfour',
#   'hour',
#   'covidvaccination'],
#  ['nine',
#   'two',
#   'india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds'],
#  ['university',
#   'johannesburg',
#   'herc',
#   'couid',
#   'nineteen',
#   'democracy',
#   'survey',
#   'show',
#   'decline',
#   'vaccine',
#   'hesitancy',
#   'highlight',
#   'inequality',
#   'vaccination',
#   'coverage'],
#  ['low',
#   'vaccination',
#   'rate',
#   'lead',
#   'rise',
#   'middle',
#   'east',
#   'couid',
#   'nineteen',
#   'infection'],
#  ['data',
#   'available',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'punjab',
#   'collective',
#   'data',
#   'not',
#   'reflect',
#   'state',
#   'province',
#   'many',
#   'vaccine',
#   'administrated',
#   'sind',
#   'balochistan',
#   'khyberpakhumkwa'],
#  ['active',
#   'couid',
#   'nineteen',
#   'case',
#   'country',
#   'decline',
#   'seven',
#   'ninety',
#   'couid',
#   'healthministry',
#   'omicron',
#   'pandemic',
#   'vaccination'],
#  ['corona',
#   'pandemic',
#   'thousand',
#   'new',
#   'case',
#   'one',
#   'death',
#   'india',
#   'coronavirus',
#   'couid',
#   'corona',
#   'vaccination',
#   'vaccinationdrive'],
#  ['schedule',
#   'child',
#   'couid',
#   'nineteen',
#   'second',
#   'dose',
#   'vaccination',
#   'appointment',
#   'children_aged',
#   'five',
#   'eleven',
#   'year',
#   'take',
#   'second',
#   'dose',
#   'vaccination',
#   'twentynine',
#   'day',
#   'receiving',
#   'first',
#   'dose',
#   'learn',
#   'schedule',
#   'appointment'],
#  ['relaxation',
#   'restriction',
#   'international',
#   'traveler',
#   'winner',
#   'covidvaccination',
#   'centralgovt',
#   'quarantine',
#   'foreigner',
#   'roper',
#   'india'],
#  ['highlight',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'sixty',
#   'zero',
#   'malaysian',
#   'child',
#   'given',
#   'first',
#   'dose',
#   'feb',
#   'nine',
#   'bernard'],
#  ['population',
#   'adult',
#   'covered',
#   'covidvaccination',
#   'dream',
#   'achieve',
#   'india',
#   'done',
#   'fully',
#   'paul'],
#  ['passenger',
#   'aged',
#   'fifteen',
#   'require',
#   'full',
#   'vaccination',
#   'couid',
#   'nineteen',
#   'order',
#   'undertake',
#   'inbound',
#   'flight',
#   'pakistan'],
#  ['couid',
#   'vaccination',
#   'compulsory',
#   'ass',
#   'board',
#   'exam',
#   'forced',
#   'student',
#   'get',
#   'vaccinate',
#   'exam',
#   'via',
#   'daily',
#   'india',
#   'one',
#   'education',
#   'portal'],
#  ['update',
#   'couid',
#   'nineteen',
#   'vaccine',
#   'availability',
#   'state',
#   'u',
#   'nearly',
#   'crore',
#   'vaccine',
#   'dos',
#   'provided',
#   'state',
#   'u',
#   'twelve',
#   'eleven',
#   'crore_balance',
#   'utilized',
#   'vaccine',
#   'dos',
#   'still',
#   'available',
#   'state',
#   'u',
#   'vaccination'],
#  ['deputy',
#   'health',
#   'minister',
#   'said',
#   'government',
#   'view',
#   'vaccination',
#   'children_aged',
#   'five',
#   'eleven',
#   'vital',
#   'protect',
#   'risk',
#   'couid',
#   'nineteen',
#   'infection',
#   'malaysia',
#   'news',
#   'vaccination',
#   'moh',
#   'immunisation',
#   'pav',
#   'pickins'],
#  ['health',
#   'bulletin',
#   'couid',
#   'nineteen',
#   'ten',
#   'two',
#   'today',
#   'vaccination',
#   'two',
#   'total',
#   'vaccination',
#   'eighteen',
#   'haryanafightscorona',
#   'indiafightscorona',
#   'staysail',
#   'covidappropriatebehaviour',
#   'together',
#   'win',
#   'battle',
#   'couid',
#   'nineteen'],
#  ['today',
#   'vaccination',
#   'update',
#   'latest',
#   'covidvaccination',
#   'equation',
#   'wednesday',
#   'february',
#   'nine'],
#  ['got',
#   'call',
#   'office',
#   'principal',
#   'commissioner',
#   'cost',
#   'lucknow',
#   'ascertained',
#   'status',
#   'couid',
#   'vaccination',
#   'dos',
#   'dos',
#   'booster',
#   'taken',
#   'thanks',
#   'regard',
#   'commissioner',
#   'cost',
#   'lucknow'],
#  ['besides',
#   'uploading',
#   'negative',
#   'per',
#   'report',
#   'taken',
#   'prior',
#   'journey',
#   'option',
#   'upload',
#   'certificate',
#   'completing',
#   'full',
#   'primary',
#   'vaccination',
#   'schedule',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'provided',
#   'country',
#   'reciprocal',
#   'basis',
#   'list',
#   'country'],
#  ['india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'campaign',
#   'cross',
#   'crore_mark',
#   'masuka_mandaviya',
#   'download_toi',
#   'app'],
#  ['couid',
#   'vaccination',
#   'physically',
#   'disabled',
#   'old',
#   'man',
#   'home',
#   'har_gear',
#   'datak',
#   'campaign',
#   'tika',
#   'express',
#   'team',
#   'later',
#   'health',
#   'department',
#   'careindia',
#   'foundation',
#   'jharkhand',
#   'harghardastak',
#   'careindia',
#   'covidvaccination'],
#  ['last',
#   'major',
#   'phase',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'roll',
#   'child',
#   'five'],
#  ['gujarati',
#   'administered',
#   'second',
#   'dos',
#   'fifteen',
#   'eighteen',
#   'year',
#   'age_group',
#   'taking',
#   'total',
#   'ten',
#   'lakh',
#   'gujarati',
#   'administered',
#   'booster',
#   'dos',
#   'senior_citizen',
#   'taking',
#   'total',
#   'sixteen',
#   'lakh',
#   'gujaratcoronaupdate',
#   'covidvaccination'],
#  ['mwscovidrahat',
#   'couid',
#   'vaccination',
#   'facilitation',
#   'program',
#   'prayagraj',
#   'collaboration',
#   'local',
#   'health',
#   'authority'],
#  ['previous',
#   'couid',
#   'nineteen',
#   'infection',
#   'not',
#   'vaccination',
#   'improves',
#   'performance',
#   'antibody'],
#  ['isolation',
#   'period',
#   'couid',
#   'nineteen',
#   'case',
#   'quarantine',
#   'period',
#   'close',
#   'contact',
#   'according',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'status',
#   'effective',
#   'eight',
#   'february'],
#  ['fifty',
#   'fifteen',
#   'eighteen',
#   'age_group',
#   'given',
#   'first',
#   'couid',
#   'vaccine',
#   'dose',
#   'mandaviya',
#   'vaccination',
#   'drive',
#   'aged',
#   'fifteen',
#   'eighteen',
#   'year',
#   'commenced',
#   'january',
#   'three',
#   'year',
#   'latest',
#   'news_businessstandard'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'cac',
#   'govt',
#   'boy',
#   'senior',
#   'secondary',
#   'school',
#   'loni',
#   'road',
#   'north',
#   'east',
#   'district',
#   'largestvaccinedrive'],
#  ['estimation',
#   'couid',
#   'nineteen',
#   'case',
#   'prevented',
#   'vaccination',
#   'averted',
#   'amp',
#   'reduction',
#   'case',
#   'due',
#   'vaccination',
#   'primary',
#   'total',
#   'case',
#   'averted',
#   'occurred',
#   'delta',
#   'became',
#   'dominant',
#   'strain',
#   'sars_cov',
#   'two',
#   'circulating',
#   'california'],
#  ['organized',
#   'couid',
#   'vaccination',
#   'camp',
#   'age',
#   'fifteen',
#   'student',
#   'along',
#   'support',
#   'mom',
#   'bac',
#   'ward'],
#  ['total',
#   'number',
#   'active',
#   'couid',
#   'nineteen',
#   'case',
#   'aryan',
#   'feb',
#   'nine',
#   'eight',
#   'total',
#   'vaccination',
#   'aryan',
#   'feb',
#   'nine',
#   'first',
#   'dose',
#   'second',
#   'dose',
#   'four',
#   'total',
#   'cumulative',
#   'figure',
#   'four',
#   'zero',
#   'date',
#   'try'],
#  ['international',
#   'traveller',
#   'coming',
#   'india',
#   'submit',
#   'complete',
#   'factual',
#   'information',
#   'self',
#   'declaration',
#   'form',
#   'online',
#   'air',
#   'sumida',
#   'portal',
#   'internationaltravellers',
#   'airsuvidhaportal',
#   'vaccination',
#   'couid',
#   'rtpcrreport'],
#  ['vaccination',
#   'couid',
#   'nineteen',
#   'rapid',
#   'azerbaijan',
#   'plea',
#   'world',
#   'health',
#   'organization',
#   'representative',
#   'azerbaijan',
#   'hande',
#   'harmonic'],
#  ['need',
#   'fourth',
#   'couid',
#   'nineteen',
#   'booster',
#   'dose',
#   'top',
#   'u',
#   'scientist',
#   'anthony_faci',
#   'say',
#   'boostershot',
#   'covidvaccination'],
#  ['sample',
#   'tamilnadu',
#   'carried',
#   'sars_cov',
#   'two',
#   'antibody',
#   'show',
#   'ith',
#   'phase',
#   'serosurvey',
#   'result',
#   'prior',
#   'couid',
#   'infection',
#   'delta',
#   'wave',
#   'vaccination',
#   'rate',
#   'made',
#   'ord',
#   'omicron',
#   'wave',
#   'look',
#   'mild',
#   'not',
#   'created',
#   'much',
#   'impact',
#   'term',
#   'hospitalization',
#   'tamilnadu'],
#  ['couid',
#   'nineteen',
#   'vaccination',
#   'held',
#   'per',
#   'schedule',
#   'nine',
#   'feb'],
#  ['india',
#   'cumulative',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'coverage_exceeds'],
#  ['minister',
#   'economy',
#   'finance',
#   'aun',
#   'pornmoniroth',
#   'pegged',
#   'cambodia',
#   'economic',
#   'growth',
#   'five',
#   'per_cent',
#   'reflecting',
#   'national',
#   'progress',
#   'towards',
#   'herd_immunity',
#   'couid',
#   'nineteen',
#   'underpinned',
#   'vaccination',
#   'rate',
#   'rank',
#   'among',
#   'best',
#   'globally',
#   'motivated'],
#  ['case',
#   'missed',
#   'expert',
#   'urged',
#   'government',
#   'expedite',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'student',
#   'reopen',
#   'school',
#   'sake',
#   'child',
#   'future',
#   'want',
#   'read',
#   'click_link',
#   'schoolsreopen',
#   'vaccination'],
#  ['couid',
#   'nineteen',
#   'awareness',
#   'mass',
#   'vaccination',
#   'drive',
#   'car',
#   'initiative',
#   'pel',
#   'pic',
#   'foundation',
#   'trust',
#   'old',
#   'age',
#   'people',
#   'definitely',
#   'abled',
#   'person',
#   'betel',
#   'chhindwara'],
#  ['get',
#   'vaccinated',
#   'without',
#   'delay',
#   'protect',
#   'couid',
#   'nineteen',
#   'happy',
#   'inform',
#   'coaxing',
#   'vaccination',
#   'available',
#   'precautionary',
#   'dose',
#   'booster',
#   'dose',
#   'child',
#   'fifteen',
#   'year',
#   'first',
#   'second',
#   'dose',
#   'contact',
#   'vaccine'],
#  ['cop',
#   'nab',
#   'twentyfive',
#   'nationwide',
#   'sale',
#   'fake',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'cert'],
#  ['effect',
#   'couid',
#   'nineteen',
#   'vaccination',
#   'fertility',
#   'credihealth',
#   'blog'],
#  ['gi',
#   'representation',
#   'scenario',
#   'india',
#   'feb',
#   'prepared',
#   'total',
#   'vaccination',
#   'one',
#   'nineteen',
#   'active_cases',
#   'last_twentyfour',
#   'coronavirusupdates',
#   'coronavirus',
#   'maharashtrian',
#   'omicron',
#   'omicronvarient'],
#  ['new_york',
#   'illinois',
#   'poised',
#   'roll',
#   'back',
#   'mask',
#   'mandate',
#   'florida',
#   'surgeon',
#   'general',
#   'not',
#   'reveal',
#   'vaccination',
#   'status',
#   'live',
#   'couid',
#   'nineteen',
#   'update'],
#  ['central',
#   'govt',
#   'informed',
#   'submitting',
#   'radar_card',
#   'not',
#   'mandatory',
#   'coin_portal',
#   'couid',
#   'nineteen',
#   'vaccination'],
#  ['india',
#   'crossed',
#   'yet',
#   'another_milestone',
#   'couid',
#   'vaccination',
#   'drive',
#   'total',
#   'vaccination',
#   'crossing',
#   'crore_mark',
#   'today',
#   'union',
#   'health',
#   'ministry',
#   'termed',
#   'yet',
#   'another',
#   'achievement',
#   'fight'],
#  ['lord',
#   'macaulay',
#   'education',
#   'system',
#   'promotes',
#   'religious',
#   'conversion',
#   'appeasement',
#   'health',
#   'service',
#   'many',
#   'people',
#   'still',
#   'couid',
#   'positive',
#   'infection',
#   'rate',
#   'high',
#   'death',
#   'rate',
#   'high',
#   'vaccination',
#   'rate',
#   'social',
#   'welfare',
#   'promotes',
#   'people',
#   'join',
#   'isi'],
#  ['largestvaccinedrive',
#   'national',
#   'couid',
#   'la',
#   'vaccination',
#   'program',
#   'ith',
#   'february',
#   'total',
#   'dos',
#   'administered',
#   'woman',
#   'approximates',
#   'estimated',
#   'proportion',
#   'woman',
#   'country',
#   'population',
#   'fast']]

# %%
#Create dictionary
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(all_docs_train)
print(dictionary)
# Out:
# Dictionary(1718 unique tokens: ['antibody', 'corona', 'couid', 'dog', 'health']...)

# %%
# Convert all documents to TF Vectors
all_tf_vectors = [dictionary.doc2bow(doc) for doc in all_docs_train]

# %%
#Label the trained data. Since the folder name is the label, I use the same labels.

all_data_as_dict = [{id:1 for (id, tf_value) in vec} for vec in all_tf_vectors]
print(type(all_data_as_dict))

opinion_data = [(d, 'opinion') for d in all_data_as_dict[0:num_opinion_docs]]
fact_data = [(d, 'fact') for d in all_data_as_dict[num_opinion_docs:]]
all_labeled_data = opinion_data + fact_data
# Out:
# <class 'list'>

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader

# %%
#Generate the trained classifier
classifier = nltk.NaiveBayesClassifier.train(all_labeled_data)

# %%
test_doc = all_data_as_dict[35] #35 is opinion article. Until 89 are all opinion
print(classifier.classify(test_doc))
# Out:
# opinion

# %%
# # Read the files in validate folder and preparing the validation corpus

# fact_validation = PlaintextCorpusReader('SGNewsForClassification/Validate/Crime', '.+\.txt')
# opinion_validation = PlaintextCorpusReader('SGNewsForClassification/Validate/Sports', '.+\.txt')

# # Tokenization
# crime_valid_docs1 = [crime_validation.words(fid) for fid in crime_validation.fileids()]
# sports_valid_docs1 = [sports_validation.words(fid) for fid in sports_validation.fileids()]

# # Combine the two sets of documents for easy processing.
# all_valid_docs = crime_valid_docs1 + sports_valid_docs1

# # This number will be used to separate the two sets of documents later.
# num_crime_valid_docs = len(crime_valid_docs1)

# # Text pre-processing, including stop word removal, stemming, etc.
# all_valid_docs2 = [[w.lower() for w in doc] for doc in all_valid_docs]
# all_valid_docs3 = [[w for w in doc if re.search('^[a-z]+$',w)] for doc in all_valid_docs2]
# all_valid_docs4 = [[w for w in doc if w not in stop_list] for doc in all_valid_docs3]
# all_valid_docs5 = [[stemmer.stem(w) for w in doc] for doc in all_valid_docs4]

# # Note that we're using the dictionary created earlier.
# all_valid_tf_vectors = [dictionary.doc2bow(doc) for doc in all_valid_docs5]

# # Convert documents into dict representation.
# all_valid_data_as_dict = [{id:1 for (id, tf_value) in vec} for vec in all_valid_tf_vectors]

# # Separate the two sets of documents and add labels.
# crime_valid_data_with_labels = [(d, 'Crime') for d in all_valid_data_as_dict[0:num_crime_valid_docs]]
# sports_valid_data_with_labels = [(d, 'Sports') for d in all_valid_data_as_dict[num_crime_valid_docs:]]

# # Combine the labeled documents.
# all_valid_data_with_labels = crime_valid_data_with_labels + sports_valid_data_with_labels

# %%
# # Write your code below:

# test_corpus = PlaintextCorpusReader('SGNewsForClassification/Test', '.+\.txt')
# fids = test_corpus.fileids()

# # Tokenization
# test_docs1 = [test_corpus.words(fid) for fid in fids]

# # Text pre-processing, including stop word removal, stemming, etc.
# test_docs2 = [[w.lower() for w in doc] for doc in test_docs1]
# test_docs3 = [[w for w in doc if re.search('^[a-z]+$',w)] for doc in test_docs2]
# test_docs4 = [[w for w in doc if w not in stop_list] for doc in test_docs3]
# test_docs5 = [[stemmer.stem(w) for w in doc] for doc in test_docs4]

# Note that we're using the dictionary created earlier to create TF vectors
test_tf_vectors = [dictionary.doc2bow(doc) for doc in all_docs_test]

# Convert documents into dict representation. This is document-label representation
test_data_as_dict = [{id:1 for (id, tf_value) in vec} for vec in test_tf_vectors]

#For each file, classify and print the label.
for i in range(len(all_docs_test)):
    print(i, '-->', classifier.classify(test_data_as_dict[i]))
# Out:
# 0 --> fact
# 1 --> fact
# 2 --> opinion
# 3 --> opinion
# 4 --> fact
# 5 --> fact
# 6 --> fact
# 7 --> fact
# 8 --> opinion
# 9 --> opinion
# 10 --> fact
# 11 --> opinion
# 12 --> opinion
# 13 --> fact
# 14 --> fact
# 15 --> fact
# 16 --> fact
# 17 --> fact
# 18 --> fact
# 19 --> opinion
# 20 --> fact
# 21 --> opinion
# 22 --> fact
# 23 --> fact
# 24 --> opinion
# 25 --> fact
# 26 --> fact
# 27 --> opinion
# 28 --> fact
# 29 --> opinion
# 30 --> opinion
# 31 --> fact
# 32 --> fact
# 33 --> opinion
# 34 --> fact
# 35 --> opinion
# 36 --> fact
# 37 --> opinion
# 38 --> fact
# 39 --> fact
# 40 --> fact
# 41 --> opinion
# 42 --> opinion
# 43 --> fact
# 44 --> fact
# 45 --> fact
# 46 --> fact
# 47 --> fact
# 48 --> opinion
# 49 --> opinion
# 50 --> fact
# 51 --> fact
# 52 --> opinion
# 53 --> fact
# 54 --> fact
# 55 --> opinion
# 56 --> opinion
# 57 --> fact
# 58 --> opinion
# 59 --> fact
# 60 --> fact
# 61 --> fact
# 62 --> opinion
# 63 --> opinion
# 64 --> fact
# 65 --> fact
# 66 --> fact
# 67 --> fact
# 68 --> fact
# 69 --> opinion
# 70 --> fact
# 71 --> opinion
# 72 --> opinion
# 73 --> opinion
# 74 --> fact
# 75 --> opinion
# 76 --> opinion
# 77 --> opinion
# 78 --> fact
# 79 --> fact
# 80 --> opinion
# 81 --> fact
# 82 --> fact
# 83 --> fact
# 84 --> opinion
# 85 --> opinion
# 86 --> fact
# 87 --> opinion
# 88 --> fact
# 89 --> fact
# 90 --> fact
# 91 --> fact
# 92 --> fact
# 93 --> opinion
# 94 --> fact
# 95 --> fact
# 96 --> opinion
# 97 --> opinion
# 98 --> fact
# 99 --> fact
# 100 --> opinion
# 101 --> fact
# 102 --> fact
# 103 --> fact
# 104 --> fact
# 105 --> fact
# 106 --> opinion
# 107 --> fact
# 108 --> opinion
# 109 --> opinion
# 110 --> opinion
# 111 --> fact
# 112 --> fact
# 113 --> fact
# 114 --> opinion
# 115 --> opinion
# 116 --> opinion
# 117 --> fact
# 118 --> fact
# 119 --> fact
# 120 --> opinion
# 121 --> fact
# 122 --> fact
# 123 --> fact

# %%
y_test
# Out:
# 201       fact
# 29        fact
# 102    opinion
# 407       fact
# 186       fact
#         ...
# 73        fact
# 347    opinion
# 272       fact
# 363    opinion
# 132       fact
# Name: text_type, Length: 124, dtype: object

# %%
import nltk
import random
from nltk.corpus import CategorizedPlaintextCorpusReader

# %%
#Create the list of documents with the categories. 
#Below code combines all the files and stores randomly.
documents = []
for i in range(len(x_train1)):
    each_x = x_train1.iloc[i]
    x_words = ast.literal_eval(each_x["words_processed_all"])
    
    each_y = y_train1.iloc[i]
    y_category = each_y["text_type"]
    
    word_category = (x_words, y_category)
    documents.append(word_category)
random.shuffle(documents)

# %%
#The below code is for the feature set definition. We are using only top 2000 words as our features 
all_words = []
for each in x_train1["words_processed_all"]:
    words = ast.literal_eval(each)
    for each2 in words:
        all_words.append(each2)
        
all_words = nltk.FreqDist(w for w in all_words)

word_features = list(all_words)[100:2000]

# %%
word_features
# Out:
# ['children_aged',
#  'without',
#  'prior',
#  'appointment',
#  'nationwide',
#  'largestvaccinedrive',
#  'oscar',
#  'person',
#  'ith',
#  'travel',
#  'protect',
#  'patient',
#  'hour',
#  'vaccinate',
#  'information',
#  'team',
#  'minister',
#  'department',
#  'high',
#  'seventeen',
#  'student',
#  'available',
#  'negative',
#  'taken',
#  'primary',
#  'schedule',
#  'read',
#  'age',
#  'national',
#  'news',
#  'even',
#  'taking',
#  'study',
#  'malaysia',
#  'age_group',
#  'must',
#  'coverage_exceeds',
#  'per_cent',
#  'attendee',
#  'mask',
#  'disease',
#  'zero',
#  'done',
#  'atoll',
#  'fresh',
#  'international',
#  'government',
#  'pickins',
#  'general_public',
#  'village',
#  'till',
#  'list',
#  'punjab',
#  'air',
#  'full',
#  'bop',
#  'kid',
#  'fully',
#  'home',
#  'free',
#  'care',
#  'open',
#  'beneficiary',
#  'sixteen',
#  'center',
#  'daily_positivity',
#  'required',
#  'infected',
#  'twelve',
#  'ninety',
#  'van',
#  'via',
#  'anti',
#  'govt',
#  'aryan',
#  'try',
#  'entry',
#  'awareness',
#  'gujarati',
#  'twentyfour_hours',
#  'reached',
#  'provided',
#  'well',
#  'service',
#  'shot',
#  'contact',
#  'roper',
#  'worker',
#  'risk',
#  'situation',
#  'union',
#  'exp',
#  'post',
#  'including',
#  'forty',
#  'used',
#  'latest',
#  'delhi',
#  'variant',
#  'show',
#  'thousand',
#  'recovery',
#  'isolation',
#  'winner',
#  'expected',
#  'sharp_rise',
#  'needed_proven',
#  'successful_reducing',
#  'severity',
#  'boost_elderly',
#  'children_pickbooster',
#  'canada',
#  'exhibition',
#  'active',
#  'figure',
#  'woman',
#  'much',
#  'severe',
#  'back',
#  'ceremony',
#  'provide',
#  'reason',
#  'mandate',
#  'regarding',
#  'unit',
#  'good',
#  'pregnancy',
#  'level',
#  'decline',
#  'coronavirusupdates',
#  'class',
#  'journey',
#  'upload',
#  'completing',
#  'whole',
#  'roll',
#  'everyone',
#  'effective',
#  'mandatory',
#  'card',
#  'est',
#  'fake',
#  'wife',
#  'present',
#  'reach',
#  'administration',
#  'hope',
#  'use',
#  'various',
#  'would',
#  'scenario',
#  'rule',
#  'test',
#  'require',
#  'careindia',
#  'local',
#  'world',
#  'cost',
#  'last',
#  'live',
#  'compulsory',
#  'border',
#  'march',
#  'support',
#  'majority',
#  'nation',
#  'weekly',
#  'fight',
#  'human',
#  'result',
#  'covered',
#  'fever',
#  'benefit',
#  'percent',
#  'end',
#  'wednesday',
#  'thursday',
#  'death_toll',
#  'traveler',
#  'central',
#  'centralgovt',
#  'despite',
#  'stand',
#  'cultural',
#  'nagar',
#  'vehicle',
#  'run',
#  'aware',
#  'current',
#  'individual',
#  'sixty',
#  'coaxing',
#  'symptom',
#  'impact',
#  'cambodia',
#  'herd_immunity',
#  'bring',
#  'already',
#  'session',
#  'east',
#  'ranch',
#  'highlighted',
#  'special',
#  'around',
#  'new_york',
#  'different',
#  'meeting',
#  'infant',
#  'baby',
#  'mother',
#  'showed',
#  'gujaratcoronaupdate',
#  'tamilnadu',
#  'crossed',
#  'start',
#  'behind',
#  'coming',
#  'besides',
#  'uploading',
#  'option',
#  'reciprocal',
#  'basis',
#  'exemption',
#  'way',
#  'close',
#  'according',
#  'testing',
#  'vaccinationdrive',
#  'yesterday',
#  'going',
#  'group',
#  'loved',
#  'may',
#  'effect',
#  'programme',
#  'held',
#  'protection',
#  'community',
#  'nearly',
#  'commissioner',
#  'visited',
#  'problem',
#  'allow',
#  'form',
#  'portal',
#  'mom',
#  'medical',
#  'window',
#  'coverage_crosses',
#  'crore_mark',
#  'reveal',
#  'foundation',
#  'cannot',
#  'see',
#  'enough',
#  'admission',
#  'mark',
#  'sars_cov',
#  'agree',
#  'organised',
#  'happy',
#  'rare',
#  'survey',
#  'lucknow',
#  'pakistan',
#  'look',
#  'wave',
#  'yet',
#  'immunity',
#  'come',
#  'top',
#  'gave',
#  'africa',
#  'memory',
#  'created',
#  'nothing',
#  'commitment',
#  'achieve',
#  'name',
#  'modi',
#  'seems',
#  'stay_safe',
#  'precaution',
#  'following',
#  'sop',
#  'politician',
#  'stop',
#  'personal',
#  'ram',
#  'receive',
#  'positivity_rate',
#  'surge',
#  'thirty',
#  'million',
#  'fear',
#  'stats',
#  'covidstatistics',
#  'covidcases',
#  'covidcasesinindia',
#  'omicronvariant',
#  'keep',
#  'safe',
#  'follow',
#  'double',
#  'super',
#  'within',
#  'equation',
#  'ask',
#  'least',
#  'protest',
#  'together',
#  'lockdown',
#  'restriction',
#  'twenty',
#  'peril',
#  'right',
#  'administrated',
#  'rural',
#  'news_economictimes',
#  'date',
#  'ration',
#  'better',
#  'app',
#  'normal',
#  'ago',
#  'battle',
#  'achieving',
#  'immune',
#  'forced',
#  'outreach',
#  'vulnerable',
#  'drug',
#  'requirement',
#  'question',
#  'completed',
#  'mean',
#  'field',
#  'sending',
#  'picture',
#  'working',
#  'evening',
#  'resulted',
#  'lasting',
#  'compared',
#  'born',
#  'fast',
#  'towards',
#  'raja_sasha',
#  'saw',
#  'reported',
#  'chandigarh',
#  'among',
#  'youngster',
#  'university',
#  'course',
#  'college',
#  'left',
#  'availability',
#  'crore_balance',
#  'utilized',
#  'stuck',
#  'cat',
#  'work',
#  'boosterdose',
#  'effectiveness',
#  'sweden',
#  'usa',
#  'important',
#  'major',
#  'part',
#  'vote',
#  'teacher',
#  'later',
#  'online',
#  'link',
#  'informed',
#  'week',
#  'shimla',
#  'kmcfightsagainstcorona',
#  'go',
#  'dot',
#  'responsible',
#  'kindly',
#  'oppression',
#  'money',
#  'proud',
#  'soon',
#  'harghardastak',
#  'yr',
#  'masuka_mandaviya',
#  'tuesday',
#  'step',
#  'took',
#  'based',
#  'thing',
#  'next',
#  'recipient',
#  'gi',
#  'representation',
#  'prepared',
#  'maharashtrian',
#  'omicronvarient',
#  'bro',
#  'fact',
#  'kerala',
#  'feel',
#  'expert',
#  'biggest',
#  'religious',
#  'additional',
#  'passenger',
#  'self',
#  'declaration',
#  'sumida',
#  'found',
#  'adult',
#  'side_effect',
#  'complication',
#  'due',
#  'altar',
#  'freedom',
#  'holding',
#  'clear',
#  'let',
#  'dated',
#  'eliminate',
#  'priority',
#  'generates',
#  'spike',
#  'finding',
#  'another',
#  'campus',
#  'complete',
#  'record',
#  'order',
#  'arrival',
#  'twentyfive',
#  'sale',
#  'cert',
#  'florida',
#  'surgeon',
#  'general',
#  'tribal',
#  'gumba',
#  'jharkhand',
#  'tika',
#  'express',
#  'cycle',
#  'fourteen',
#  'hospital',
#  'envoy',
#  'textile',
#  'limited',
#  'view',
#  'indiafightscorona',
#  'pfizer',
#  'remove',
#  'died',
#  'daily',
#  'continues',
#  'man',
#  'treatment',
#  'basic',
#  'avoid',
#  'trigger',
#  'monday',
#  'traveller',
#  'ireland',
#  'needed',
#  'rest',
#  'single',
#  'comment',
#  'parent',
#  'capacity',
#  'ernakulam',
#  'pointed',
#  'every',
#  'thank',
#  'process',
#  'citizen',
#  'id',
#  'launch',
#  'batch',
#  'confidence',
#  'learn',
#  'indian',
#  'real',
#  'healthministry',
#  'delay',
#  'inform',
#  'precautionary',
#  'definitely',
#  'conducted',
#  'line',
#  'boostershot',
#  'reduce',
#  'blind',
#  'meghalaya',
#  'registered',
#  'prevent',
#  'pregnant',
#  'presence',
#  'observer',
#  'mow',
#  'diengpasoh',
#  'higher',
#  'almost',
#  'dead',
#  'causing',
#  'highlight',
#  'data',
#  'twentynine',
#  'receiving',
#  'hospitalization',
#  'official',
#  'offline',
#  'examination',
#  'exam',
#  'education',
#  'positive',
#  'ord',
#  'pic',
#  'aim',
#  'cross',
#  'performance',
#  'senpai',
#  'old',
#  'phase',
#  'want',
#  'term',
#  'averted',
#  'delta',
#  'best',
#  'azerbaijan',
#  'motivated',
#  'mutual',
#  'agreement',
#  'promotes',
#  'producing',
#  'natural',
#  'dog',
#  'metric',
#  'calculate',
#  'probably',
#  'crisis',
#  'caribbean',
#  'island',
#  'west',
#  'loosing',
#  'forgetting',
#  'might',
#  'couple',
#  'remember',
#  'satyamevajayate',
#  'bank',
#  'pension',
#  'stopped',
#  'none',
#  'demanding',
#  'resignation',
#  'except',
#  'proper',
#  'babaramrahim',
#  'inspired',
#  'letter',
#  'getvaccinated',
#  'inspiration',
#  'volunteer',
#  'devotee',
#  'organising',
#  'followed',
#  'diligently',
#  'large',
#  'using',
#  'political',
#  'gain',
#  'abolition',
#  'article',
#  'surgical',
#  'strike',
#  'pak',
#  'favourite',
#  'mandar',
#  'caa',
#  'arc',
#  'congress',
#  'tonga',
#  'outbreak',
#  'erupts',
#  'precautionary_measures',
#  'avert',
#  'wearing',
#  'exclusive',
#  'common',
#  'facing',
#  'kind',
#  'ultimate',
#  'nose',
#  'police',
#  'attack',
#  'ist',
#  'others',
#  'appropriate_behavior',
#  'tickettosuraksha',
#  'karnataka',
#  'achieves',
#  'jane',
#  'booklet',
#  'dengue',
#  'yellow',
#  'recommended',
#  'certain',
#  'particularly',
#  'tropical',
#  'mine',
#  'put',
#  'specialist',
#  'wing',
#  'efficient',
#  'imply',
#  'era',
#  'treated',
#  'oneself',
#  'apparently',
#  'approved',
#  'dci',
#  'nasal_spray',
#  'treating',
#  'launched',
#  'thirteen',
#  'underway',
#  'capital',
#  'tally',
#  'drop',
#  'kasa',
#  'oriental',
#  'head',
#  'division',
#  'satisfied',
#  'enthusiasm',
#  'observed',
#  'inspects',
#  'vaccineinequality',
#  'chiming',
#  'carnal',
#  'khinvsar',
#  'answer',
#  'simple',
#  'solution',
#  'european',
#  'lifted',
#  'focused',
#  'responsibility',
#  'preventive_measures',
#  'highest',
#  'recorded',
#  'worrisome',
#  'please',
#  'pregnant_women',
#  'located',
#  'kyun',
#  'marino',
#  'tak',
#  'poor',
#  'ka',
#  'bandobast',
#  'kira',
#  'handled',
#  'developed',
#  'registration',
#  'co_win',
#  'yeah',
#  'example',
#  'lower',
#  'life',
#  'cent',
#  'ensured',
#  'prayed',
#  'sawant',
#  'third_wave',
#  'amit',
#  'shah',
#  'intensified',
#  'embarking',
#  'aimed',
#  'ultimately',
#  'threat',
#  'heel',
#  'really',
#  'exists',
#  'exposure',
#  'point',
#  'covidiot',
#  'chander',
#  'reaching',
#  'momentum',
#  'routine_immunization',
#  'transformation',
#  'equity',
#  'addict',
#  'addiction',
#  'bathing',
#  'spreading',
#  'busting',
#  'myth',
#  'honorable',
#  'continuously',
#  'closely',
#  'nhmpunjab',
#  'usaidmomentum',
#  'si',
#  'infertility',
#  'develop',
#  'small',
#  'actual',
#  'chaired',
#  'deputy_commissioner',
#  'abbottabad',
#  'ommcomnews',
#  'slight',
#  'slowing',
#  'indicating',
#  'partially',
#  'immunized',
#  'physical',
#  'ug',
#  'pig',
#  'onwards',
#  'affiliated',
#  'du',
#  'directed',
#  'encourage',
#  'faculty',
#  'immunization',
#  'delhiuniversity',
#  'wad',
#  'trend',
#  'increasing',
#  'usually',
#  'warded',
#  'co',
#  'morbid',
#  'nasal',
#  'prong',
#  'room',
#  'luckily',
#  'vaccineswork',
#  'ministryofhealth',
#  'powerful',
#  'iron',
#  'history',
#  'never',
#  'forget',
#  'leave',
#  'played',
#  'court',
#  'agrees',
#  'hear',
#  'plea_seeking',
#  'petition',
#  'stated',
#  'granted',
#  'considering',
#  'auto',
#  'however',
#  'unilaterally',
#  'withdrawn',
#  'prohibiting',
#  'syringe',
#  'pledge',
#  'encourage_others',
#  'inoculated',
#  'dear',
#  'sacha',
#  'sauna',
#  'selfless',
#  'humanity',
#  'saint',
#  'greet',
#  'rahim',
#  'plan',
#  'stay',
#  'tuned',
#  'space',
#  'live_updates',
#  'infodemic',
#  'draw',
#  'hence',
#  'disinformation',
#  'friday',
#  'slowed',
#  'considerably',
#  'past',
#  'average',
#  'airport',
#  'shri',
#  'aditya',
#  'neg',
#  'flag',
#  'cut',
#  'shall',
#  'flash',
#  'message',
#  'appropriatebehaviour',
#  'download',
#  'leader',
#  'promote',
#  'birthday',
#  'anybody',
#  'reply',
#  'happen',
#  'wasted',
#  'loved_one',
#  'uranus',
#  'extreme',
#  'ensure',
#  'salute',
#  'determination',
#  'target',
#  'span',
#  'anything',
#  'mandated',
#  'upon',
#  'believed',
#  'shield',
#  'since',
#  'evolved',
#  'policy',
#  'kindergarten',
#  'debate',
#  'damaging',
#  'immediate',
#  'drastically',
#  'reduced',
#  'regimen',
#  'request',
#  'location',
#  'mahadevapura',
#  'assembly',
#  'constituency',
#  'agency',
#  'restrain',
#  'creating',
#  'scare',
#  'hypothetical',
#  'continue',
#  'masking',
#  'likely',
#  'infectious',
#  'hit',
#  'pharmaceutical',
#  'company',
#  'disputed',
#  'claim',
#  'pfizer_biotech',
#  'offer',
#  'greater',
#  'especially',
#  'sinovac',
#  'response',
#  'project',
#  'conducting',
#  'male',
#  'female',
#  'area',
#  'chachi',
#  'detected',
#  'failed',
#  'boasting',
#  'heard',
#  'taboo',
#  'explain',
#  'evolve',
#  'trait',
#  'unless',
#  'idiot',
#  'breakout',
#  'save',
#  'environment',
#  'difficulty',
#  'waiting',
#  'move',
#  'exempted',
#  'ground',
#  'airforce',
#  'personnel',
#  'picking',
#  'several',
#  'measure',
#  'private_hospitals',
#  'witnessing',
#  'site',
#  'ingot',
#  'nisam',
#  'muhammad',
#  'khalil',
#  'assistant',
#  'khat',
#  'civil',
#  'dispensary',
#  'jungle',
#  'hell',
#  'checked',
#  'staff',
#  'attendance',
#  'ummm',
#  'wonder',
#  'find',
#  'bothered',
#  'investigate',
#  'heart',
#  'airline',
#  'boarding',
#  'filled',
#  'uploaded',
#  'buddy',
#  'family',
#  'myanmar',
#  'fighting',
#  'ease',
#  'social_distance',
#  'wash_hands',
#  'twentyfour',
#  'celebs',
#  'provision',
#  'compensation',
#  'arise',
#  'inoculation',
#  'entirely',
#  'voluntary',
#  'unscarred',
#  'loksabha',
#  'notovaccinemandates',
#  'shadow',
#  'map',
#  'stress',
#  'importance',
#  'flu',
#  'trucker',
#  'choice',
#  'vocal',
#  'minority',
#  'fanatical',
#  'ransom',
#  'openwindows',
#  'growtrees',
#  'constructwindowstogetventillation',
#  'distributefreemaskindia',
#  'ventilation',
#  'mind',
#  'give',
#  'performed',
#  'duty',
#  'ad',
#  'generated',
#  'gradually',
#  'wane',
#  'rollout',
#  'jab',
#  'alone',
#  'quicker',
#  'likelihood',
#  'developing',
#  'persistent',
#  'autoimmunity',
#  'long',
#  'akiko',
#  'lwasaki',
#  'yale',
#  'eliminating',
#  'kim',
#  'expecting',
#  'boosted',
#  'able',
#  'return',
#  'stage',
#  'beginning',
#  'defence',
#  'hishammuddin',
#  'hussein',
#  'incomplete',
#  'allowed',
#  'arranging',
#  'increase',
#  'accelerate',
#  'sufficient',
#  'embassy',
#  'arrested',
#  'girl',
#  'chapati',
#  'watching',
#  'mustafa',
#  'youtube',
#  'fuck',
#  'excruciating',
#  'sanity',
#  'started',
#  'direction',
#  'dish',
#  'chief',
#  ...]

# %%
#The below code is the function, feature extractor
def document_features(document): 
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features
#print(document_features(sgnews.words('crime/Crime_9067.txt')))

#We can reuse the previous classifier and test. But we didn't train it with the feature set. So 
#We now divide the train set into test and train set. We can use different combinations. Call classifier
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

#Print the accuray and the most informative features
print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(5)

#What this tells you is the ratio of occurences in Sports to Crime, or visa versa, 
#for every word. So here, we can see that the term "police" appears 12.3 more times 
#as often in Crime articles as it does in Sports articles.

print(classifier.labels())
# Out:
# 0.74
# Most Informative Features
#           contains(even) = True           opinio : fact   =      7.6 : 1.0
#          contains(study) = True           opinio : fact   =      5.9 : 1.0
#      contains(admission) = True           opinio : fact   =      4.2 : 1.0
#           contains(anti) = True           opinio : fact   =      4.2 : 1.0
#        contains(benefit) = True           opinio : fact   =      4.2 : 1.0
# ['opinion', 'fact']

# %%
#Precision and Recall

test_result = []
gold_result = []

for i in range(len(test_set)):
    test_result.append(classifier.classify(test_set[i][0]))
    gold_result.append(test_set[i][1])
    
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix   

print('\nClasification report:\n', classification_report(gold_result, test_result))
print('\nConfussion matrix:\n',confusion_matrix(gold_result, test_result)  )
# Out:
# Clasification report:
#                precision    recall  f1-score   support
#
#         fact       0.73      0.94      0.82        64
#      opinion       0.78      0.39      0.52        36
#
#     accuracy                           0.74       100
#    macro avg       0.75      0.66      0.67       100
# weighted avg       0.75      0.74      0.71       100
#
#
# Confussion matrix:
#  [[60  4]
#  [22 14]]

# %%
from gensim.models.fasttext import FastText
import time

# parameters to train fast text
embedding_size = 300 #Dimensionality of the word vectors.
window_size = 5 #The maximum distance between the current and predicted word within a sentence. Captures context
min_word = 5 #The model ignores all words with total frequency lower than this.
down_sampling = 1e-2  #The threshold for configuring which higher-frequency words are randomly downsampled

# This is to track processing time
start_time = time.time()

ft_model = FastText(all_docs_train,
                      vector_size=embedding_size,
                      window=window_size,
                      min_count=min_word,
                      sample=down_sampling,
                      sg=0, # put 1 if you want to use skip-gram, look into the documentation for other variables
                      epochs=100)

print("Embedding Completed! Time taken: %s seconds\n" % (time.time() - start_time))

print(ft_model)
# Out:
# Embedding Completed! Time taken: 9.946325063705444 seconds
#
# FastText(vocab=192, vector_size=300, alpha=0.025)

# %%
#The below code is a minor modification of the feature selector and a repeat of the above code
import numpy as np

def embedded_document_features(document): 
    document_words = set(document)
    features = {}
    for word in document_words:
        #word=word.lower()
        #if word in dictionary:
            features['contains({})'.format(word)] = np.mean(ft_model.wv[word]) # the average vector value
    return features

featuresets = [(embedded_document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(5)
# Out:
# 0.74
# Most Informative Features
#           contains(like) = -0.00093230885 opinio : fact   =      9.3 : 1.0
#       contains(antibody) = -0.0039680195  opinio : fact   =      7.6 : 1.0
#           contains(even) = -0.0008405318  opinio : fact   =      7.6 : 1.0
#          contains(virus) = -0.0049005453  opinio : fact   =      7.6 : 1.0
#           contains(dose) = 0.011883234      fact : opinio =      7.2 : 1.0

# %%
# Compare the results with the previous results and see if there are any difference.
# Most of the codes can be further simplified if we are using functions
# Note that the we also did not do any pre-processing steps

test_result = []
gold_result = []

for i in range(len(test_set)):
    test_result.append(classifier.classify(test_set[i][0]))
    gold_result.append(test_set[i][1])

print('\nClasification report:\n', classification_report(gold_result, test_result))
print('\nConfussion matrix:\n',confusion_matrix(gold_result, test_result)  )
# Out:
# Clasification report:
#                precision    recall  f1-score   support
#
#         fact       0.84      0.73      0.78        64
#      opinion       0.61      0.75      0.67        36
#
#     accuracy                           0.74       100
#    macro avg       0.73      0.74      0.73       100
# weighted avg       0.76      0.74      0.74       100
#
#
# Confussion matrix:
#  [[47 17]
#  [ 9 27]]

# %% [markdown]
# ## Logistic regression
#
# https://github.com/Idilismiguzel/NLP-with-Python/blob/master/Text-Classification.ipynb

# %%
import matplotlib.pyplot as plt
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
from sklearn.linear_model import LogisticRegression
import sklearn.model_selection
import sklearn.preprocessing as preproc
from sklearn.feature_extraction import text
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
bow_converter = CountVectorizer(tokenizer=lambda doc: doc, lowercase=False)
x = bow_converter.fit_transform(df['translated'])

words = bow_converter.get_feature_names()
len(words)
# Out:
# 97

# %%
# bigram_converter = CountVectorizer(tokenizer=lambda doc: doc, ngram_range=[2,2], lowercase=False) 
# x2 = bigram_converter.fit_transform(df['Text_Cleaned'])
# bigrams = bigram_converter.get_feature_names()
# len(bigrams)

# %%
# bigrams[-10:]

# %%
# trigram_converter = CountVectorizer(tokenizer=lambda doc: doc, ngram_range=[3,3], lowercase=False) 
# x3 = trigram_converter.fit_transform(df['Text_Cleaned'])
# trigrams = trigram_converter.get_feature_names()
# len(trigrams)

# %%
# trigrams[:10]

# %%
# print(len(words), len(bigrams), len(trigrams))
# Out:
# 1881 4570 5052

# %%
training_data, test_data = sklearn.model_selection.train_test_split(df, train_size = 0.8, random_state=1)

# %%
print(training_data.shape)
print(test_data.shape)
# Out:
# (800, 11)
# (200, 11)

# %%
bow_transform = CountVectorizer(tokenizer=lambda doc: doc, ngram_range=[3,3], lowercase=False)

# %%
X_tr_bow = bow_transform.fit_transform(training_data['translated'])

# %%
len(bow_transform.vocabulary_)
# Out:
# 7880

# %%
X_tr_bow.shape
# Out:
# (800, 7880)

# %%
X_te_bow = bow_transform.transform(test_data['translated'])

# %%
y_tr = training_data['text_type']
y_te = test_data['text_type']

# %%
tfidf_transform = text.TfidfTransformer(norm=None)
X_tr_tfidf = tfidf_transform.fit_transform(X_tr_bow)

# %%
X_te_tfidf = tfidf_transform.transform(X_te_bow)

# %%
def simple_logistic_classify(X_tr, y_tr, X_test, y_test, description, _C=1.0):
    model = LogisticRegression(C=_C).fit(X_tr, y_tr)
    score = model.score(X_test, y_test)
    print('Test Score with', description, 'features', score)
    return model

# %%
model_bow = simple_logistic_classify(X_tr_bow, y_tr, X_te_bow, y_te, 'bow')
model_tfidf = simple_logistic_classify(X_tr_tfidf, y_tr, X_te_tfidf, y_te, 'tf-idf')
# Out:
# Test Score with bow features 0.825
# Test Score with tf-idf features 0.84

# %%
param_grid_ = {'C': [1e-5, 1e-3, 1e-1, 1e0, 1e1, 1e2]}
bow_search = sklearn.model_selection.GridSearchCV(LogisticRegression(), cv=5, param_grid=param_grid_)
tfidf_search = sklearn.model_selection.GridSearchCV(LogisticRegression(), cv=5,
                                   param_grid=param_grid_)

# %%
bow_search.fit(X_tr_bow, y_tr)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1e-05, 0.001, 0.1, 1.0, 10.0, 100.0]})

# %%
bow_search.best_score_
# Out:
# 0.83375

# %%
tfidf_search.fit(X_tr_tfidf, y_tr)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1e-05, 0.001, 0.1, 1.0, 10.0, 100.0]})

# %%
tfidf_search.best_score_
# Out:
# 0.83625

# %%
bow_search.best_params_
# Out:
# {'C': 0.1}

# %%
tfidf_search.best_params_
# Out:
# {'C': 0.1}

# %%
bow_search.cv_results_
# Out:
# {'mean_fit_time': array([0.02933922, 0.04254413, 0.07970285, 0.13548002, 0.15217886,
#         0.1370688 ]),
#  'std_fit_time': array([0.00499061, 0.01627317, 0.00251828, 0.01236248, 0.02165408,
#         0.00640233]),
#  'mean_score_time': array([0.00067787, 0.00077205, 0.00067039, 0.00075345, 0.00079889,
#         0.00067754]),
#  'std_score_time': array([1.81791714e-04, 1.75057007e-04, 1.06469356e-04, 6.02516157e-05,
#         1.23284069e-04, 1.46013455e-04]),
#  'param_C': masked_array(data=[1e-05, 0.001, 0.1, 1.0, 10.0, 100.0],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1e-05},
#   {'C': 0.001},
#   {'C': 0.1},
#   {'C': 1.0},
#   {'C': 10.0},
#   {'C': 100.0}],
#  'split0_test_score': array([0.66875, 0.7875 , 0.85625, 0.84375, 0.8375 , 0.83125]),
#  'split1_test_score': array([0.66875, 0.76875, 0.84375, 0.8375 , 0.84375, 0.84375]),
#  'split2_test_score': array([0.66875, 0.74375, 0.7875 , 0.775  , 0.775  , 0.76875]),
#  'split3_test_score': array([0.6625, 0.75  , 0.85  , 0.85  , 0.8375, 0.8375]),
#  'split4_test_score': array([0.6625 , 0.75   , 0.83125, 0.8125 , 0.79375, 0.8    ]),
#  'mean_test_score': array([0.66625, 0.76   , 0.83375, 0.82375, 0.8175 , 0.81625]),
#  'std_test_score': array([0.00306186, 0.01610512, 0.0245586 , 0.0275    , 0.02778264,
#         0.02811805]),
#  'rank_test_score': array([6, 5, 1, 2, 3, 4], dtype=int32)}

# %%
results_file = open('tfidf_gridcv_results.pkl', 'wb')
pickle.dump(bow_search, results_file, -1)
pickle.dump(tfidf_search, results_file, -1)
results_file.close()

# %%
pkl_file = open('tfidf_gridcv_results.pkl', 'rb')
bow_search = pickle.load(pkl_file)
tfidf_search = pickle.load(pkl_file)
pkl_file.close()

# %%
search_results = pd.DataFrame.from_dict({'bow': bow_search.cv_results_['mean_test_score'],
                               'tfidf': tfidf_search.cv_results_['mean_test_score']})
search_results
# Out:
#        bow    tfidf
# 0  0.66625  0.66625
# 1  0.76000  0.82875
# 2  0.83375  0.83625
# 3  0.82375  0.83125
# 4  0.81750  0.82750
# 5  0.81625  0.82375

# %%
# %matplotlib inline
ax = sns.boxplot(data=search_results, width=0.4)
ax.set_ylabel('Accuracy', size=14)
ax.tick_params(labelsize=14)
plt.savefig('tfidf_gridcv_results.png')

# %%
model_bow = simple_logistic_classify(X_tr_bow, y_tr, X_te_bow, y_te, 'bow', 
                              _C=bow_search.best_params_['C'])
model_tfidf = simple_logistic_classify(X_tr_tfidf, y_tr, X_te_tfidf, y_te, 'tf-idf', 
                              _C=tfidf_search.best_params_['C'])
# Out:
# Test Score with bow features 0.83
# Test Score with tf-idf features 0.84
