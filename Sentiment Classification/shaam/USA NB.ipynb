# %% [markdown]
# ### Read opinion labelled data

# %%
import pandas as pd
import numpy as np

# %%
usa_opinion = pd.read_csv("labelled_data_usa_LR.csv")
usa_opinion = usa_opinion.rename(columns={'Unnamed: 0': 'index'})
usa_opinion
# Out:
#          index                                               Text  \
# 0            0  want find way end racism try force people inje...
# 1            1  this child almost died tetanus, spent months h...
# 2            2  juste se rappeler m. leblanc la pression que l...
# 3            3  you would expect cases rise significantly, cou...
# 4            4  depends whether vaccination status is embedded...
# ...        ...                                                ...
# 404259  404259  if you are eligible, please pre- register covi...
# 404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 404261  404261  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 404259  if you are eligible, please pre- register covi...   ENGLISH
# 404260  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 404261  #fauciouchie #2 #vaccinated #vaccinesaveslives...   ENGLISH
# 404262  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 404263  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404259  if you are eligible, please pre- register covi...
# 404260  do it others.... flexed_bicepsparty_poppersyri...
# 404261  #fauciouchie #2 #vaccinated #vaccinesaveslives...
# 404262  yay raising_handslight_skin_tone congrats dr. ...
# 404263  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 404259  [('if', 'IN'), ('you', 'PRP'), ('are', 'VBP'),...
# 404260  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 404261  [('fauciouchie', 'RB'), ('two', 'CD'), ('vacci...
# 404262  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 404263  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 404259  ['eligible', 'please', 'pre', 'register', 'cou...
# 404260                    ['others', 'vaccinesaveslives']
# 404261  ['fauciouchie', 'two', 'vaccinated', 'vaccines...
# 404262  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 404259  ['eligible', 'pre', 'register', 'couid', 'vacc...
# 404260                      ['other', 'vaccinesaveslive']
# 404261  ['vaccinated', 'vaccinesaveslive', 'getyourshot']
# 404262  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 404259  ['couid', 'vaccination', 'appointment', 'vacci...   objective
# 404260                      ['other', 'vaccinesaveslive']  subjective
# 404261                ['vaccinesaveslive', 'getyourshot']   objective
# 404262  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 404263  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
# [404264 rows x 10 columns]

# %%
usa_opinion['text_type'].value_counts()
# Out:
# subjective    320122
# objective      84142
# Name: text_type, dtype: int64

# %%
usa_opinion = usa_opinion[usa_opinion.text_type == 'subjective']

# %%
usa_opinion
# Out:
#          index                                               Text  \
# 0            0  want find way end racism try force people inje...
# 1            1  this child almost died tetanus, spent months h...
# 2            2  juste se rappeler m. leblanc la pression que l...
# 3            3  you would expect cases rise significantly, cou...
# 4            4  depends whether vaccination status is embedded...
# ...        ...                                                ...
# 404255  404255  pretty remarkable achievement. thank you all v...
# 404258  404258  oh that explains similar - seemingly out nowhe...
# 404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 404255  pretty remarkable achievement. thank you all v...   ENGLISH
# 404258  oh that explains similar - seemingly out nowhe...   ENGLISH
# 404260  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 404262  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 404263  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404255  pretty remarkable achievement. thank you all v...
# 404258  oh that explains similar - seemingly out nowhe...
# 404260  do it others.... flexed_bicepsparty_poppersyri...
# 404262  yay raising_handslight_skin_tone congrats dr. ...
# 404263  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 404255  [('pretty', 'RB'), ('remarkable', 'JJ'), ('ach...
# 404258  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
# 404260  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 404262  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 404263  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 404255  ['pretty', 'remarkable', 'achievement', 'thank...
# 404258  ['explains', 'similar', 'seemingly', 'nowhere'...
# 404260                    ['others', 'vaccinesaveslives']
# 404262  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 404255  ['pretty', 'remarkable', 'achievement', 'thank...
# 404258  ['explain', 'similar', 'seemingly', 'nowhere',...
# 404260                      ['other', 'vaccinesaveslive']
# 404262  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 404255  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 404258  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 404260                      ['other', 'vaccinesaveslive']  subjective
# 404262  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 404263  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
# [320122 rows x 10 columns]

# %% [markdown]
# ### Read data (Labelled)

# %%
labelled_df = pd.read_csv("usa-labelled.csv")
# labelled_df.drop(['Unnamed: 0'], axis=1, inplace=True)
labelled_df
# Out:
#                                                    Text  \
# 0     cher i got my second pfizer vaccine shot may 1...
# 1              Ô£ø√º√≠√¢dp'ed by pfizer april Ô£ø√º√≤√•
# 2                 Ô£ø√º√´√ßÔ£ø√º√®¬∫ double shot pfizer
# 3     couple things. my wife has ra. takes plaquenil...
# 4              great, me too back april. pfizer 2 shots
# ...                                                 ...
# 1494  we‚Äö√Ñ√¥re at north high school today until 5...
# 1495  y‚Äö√Ñ√¥all please get vaccinated. . . . . * d...
# 1496  disappointed you are blame only unvaccinated c...
# 1497  be fair, cdc et al have always said pfizer or ...
# 1498  if it has been 21 days since your first pfizer...
#
#                                                new_text languages  \
# 0     cher i got my second pfizer vaccine shot may 1...   ENGLISH
# 1            syringedp'ed by pfizer april relieved_face   ENGLISH
# 2     thumbs_upmedium-light_skin_tone double shot pf...   ENGLISH
# 3     couple things. my wife has ra. takes plaquenil...   ENGLISH
# 4              great, me too back april. pfizer 2 shots   ENGLISH
# ...                                                 ...       ...
# 1494  we‚Äö√Ñ√¥re at north high school today until 5...   ENGLISH
# 1495  y‚Äö√Ñ√¥all please get vaccinated. . . . . * d...   ENGLISH
# 1496  disappointed you are blame only unvaccinated c...   ENGLISH
# 1497  be fair, cdc et al have always said pfizer or ...   ENGLISH
# 1498  if it has been 21 days since your first pfizer...   ENGLISH
#
#                              new_text_after_translation  \
# 0     cher i got my second pfizer vaccine shot may 1...
# 1            syringedp'ed by pfizer april relieved_face
# 2     thumbs_upmedium-light_skin_tone double shot pf...
# 3     couple things. my wife has ra. takes plaquenil...
# 4              great, me too back april. pfizer 2 shots
# ...                                                 ...
# 1494  we‚Äö√Ñ√¥re at north high school today until 5...
# 1495  y‚Äö√Ñ√¥all please get vaccinated. . . . . * d...
# 1496  disappointed you are blame only unvaccinated c...
# 1497  be fair, cdc et al have always said pfizer or ...
# 1498  if it has been 21 days since your first pfizer...
#
#                                        pos_tagged_words  \
# 0     [('cher', 'NN'), ('i', 'NN'), ('got', 'VBD'), ...
# 1     [('syringe', 'NN'), ('ed', 'NN'), ('by', 'IN')...
# 2     [('double', 'RB'), ('shot', 'JJ'), ('pfizer', ...
# 3     [('couple', 'NN'), ('things', 'NNS'), ('my', '...
# 4     [('great', 'JJ'), ('me', 'PRP'), ('too', 'RB')...
# ...                                                 ...
# 1494  [('we', 'PRP'), ('i', 'VBP'), ('re', 'VBP'), (...
# 1495  [('y', 'NN'), ('i', 'NN'), ('all', 'DT'), ('pl...
# 1496  [('disappointed', 'VBN'), ('you', 'PRP'), ('ar...
# 1497  [('be', 'VB'), ('fair', 'JJ'), ('cac', 'JJ'), ...
# 1498  [('if', 'IN'), ('it', 'PRP'), ('has', 'VBZ'), ...
#
#                                     words_processed_all  \
# 0     ['cher', 'get', 'second', 'pfizer', 'vaccine',...
# 1                  ['syringe', 'ed', 'pfizer', 'april']
# 2                          ['double', 'shot', 'pfizer']
# 3     ['couple', 'thing', 'wife', 'ra', 'take', 'pla...
# 4     ['great', 'back', 'april', 'pfizer', 'two', 's...
# ...                                                 ...
# 1494  ['north', 'high_school', 'today', 'come', 'get...
# 1495  ['please', 'get', 'vaccinated', 'disclaimer', ...
# 1496  ['disappointed', 'blame', 'vaccinated', 'crowd...
# 1497  ['fair', 'cac', 'et_al', 'always', 'say', 'pfi...
# 1498  ['twentynine', 'day', 'since', 'first', 'pfize...
#
#                       words_processed_noun_adj_verb_adv  \
# 0     ['cher', 'get', 'second', 'pfizer', 'vaccine',...
# 1                                           ['syringe']
# 2                          ['double', 'shot', 'pfizer']
# 3     ['couple', 'thing', 'wife', 'take', 'plaquenil...
# 4                           ['great', 'pfizer', 'shot']
# ...                                                 ...
# 1494  ['north', 'today', 'come', 'get', 'free', 'pfi...
# 1495  ['get', 'vaccinated', 'disclaimer', 'pfizer', ...
# 1496  ['disappointed', 'blame', 'vaccinated', 'crowd...
# 1497  ['fair', 'cac', 'et_al', 'always', 'say', 'pfi...
# 1498  ['twentynine', 'day', 'first', 'pfizer', 'shoo...
#
#                                    words_processed_noun  \
# 0     ['cher', 'pfizer', 'vaccine', 'cher', 'guess',...
# 1                                           ['syringe']
# 2                                    ['shot', 'pfizer']
# 3     ['couple', 'thing', 'wife', 'plaquenil', 'prob...
# 4                                    ['pfizer', 'shot']
# ...                                                 ...
# 1494  ['north', 'today', 'pfizer', 'vaccine', 'year'...
# 1495                  ['disclaimer', 'pfizer', 'stock']
# 1496     ['blame', 'delta', 'covid', 'case', 'vaccine']
# 1497  ['cac', 'et_al', 'pfizer', 'vaccination', 'cha...
# 1498  ['twentynine', 'day', 'pfizer', 'day', 'shot',...
#
#                                                  scores  compound sentiment
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 3     {'neg': 0.056, 'neu': 0.887, 'pos': 0.057, 'co...    0.0150   neutral
# 4     {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'comp...    0.6249  positive
# ...                                                 ...       ...       ...
# 1494  {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'comp...    0.5106  positive
# 1495  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'comp...    0.3182  positive
# 1496  {'neg': 0.174, 'neu': 0.727, 'pos': 0.099, 'co...   -0.4753  negative
# 1497  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...    0.5106  positive
# 1498  {'neg': 0.052, 'neu': 0.948, 'pos': 0.0, 'comp...   -0.2732  positive
#
# [1499 rows x 11 columns]

# %%
def sentiment2target(sentiment):
    return {
        'negative': 0,
        'neutral': 1,
        'positive' : 2
    }[sentiment]
targets = labelled_df.sentiment.apply(sentiment2target)

# %%
labelled_df['sentiment'] =targets

# %%
labelled_df
# Out:
#                                                    Text  \
# 0     cher i got my second pfizer vaccine shot may 1...
# 1              Ô£ø√º√≠√¢dp'ed by pfizer april Ô£ø√º√≤√•
# 2                 Ô£ø√º√´√ßÔ£ø√º√®¬∫ double shot pfizer
# 3     couple things. my wife has ra. takes plaquenil...
# 4              great, me too back april. pfizer 2 shots
# ...                                                 ...
# 1494  we‚Äö√Ñ√¥re at north high school today until 5...
# 1495  y‚Äö√Ñ√¥all please get vaccinated. . . . . * d...
# 1496  disappointed you are blame only unvaccinated c...
# 1497  be fair, cdc et al have always said pfizer or ...
# 1498  if it has been 21 days since your first pfizer...
#
#                                                new_text languages  \
# 0     cher i got my second pfizer vaccine shot may 1...   ENGLISH
# 1            syringedp'ed by pfizer april relieved_face   ENGLISH
# 2     thumbs_upmedium-light_skin_tone double shot pf...   ENGLISH
# 3     couple things. my wife has ra. takes plaquenil...   ENGLISH
# 4              great, me too back april. pfizer 2 shots   ENGLISH
# ...                                                 ...       ...
# 1494  we‚Äö√Ñ√¥re at north high school today until 5...   ENGLISH
# 1495  y‚Äö√Ñ√¥all please get vaccinated. . . . . * d...   ENGLISH
# 1496  disappointed you are blame only unvaccinated c...   ENGLISH
# 1497  be fair, cdc et al have always said pfizer or ...   ENGLISH
# 1498  if it has been 21 days since your first pfizer...   ENGLISH
#
#                              new_text_after_translation  \
# 0     cher i got my second pfizer vaccine shot may 1...
# 1            syringedp'ed by pfizer april relieved_face
# 2     thumbs_upmedium-light_skin_tone double shot pf...
# 3     couple things. my wife has ra. takes plaquenil...
# 4              great, me too back april. pfizer 2 shots
# ...                                                 ...
# 1494  we‚Äö√Ñ√¥re at north high school today until 5...
# 1495  y‚Äö√Ñ√¥all please get vaccinated. . . . . * d...
# 1496  disappointed you are blame only unvaccinated c...
# 1497  be fair, cdc et al have always said pfizer or ...
# 1498  if it has been 21 days since your first pfizer...
#
#                                        pos_tagged_words  \
# 0     [('cher', 'NN'), ('i', 'NN'), ('got', 'VBD'), ...
# 1     [('syringe', 'NN'), ('ed', 'NN'), ('by', 'IN')...
# 2     [('double', 'RB'), ('shot', 'JJ'), ('pfizer', ...
# 3     [('couple', 'NN'), ('things', 'NNS'), ('my', '...
# 4     [('great', 'JJ'), ('me', 'PRP'), ('too', 'RB')...
# ...                                                 ...
# 1494  [('we', 'PRP'), ('i', 'VBP'), ('re', 'VBP'), (...
# 1495  [('y', 'NN'), ('i', 'NN'), ('all', 'DT'), ('pl...
# 1496  [('disappointed', 'VBN'), ('you', 'PRP'), ('ar...
# 1497  [('be', 'VB'), ('fair', 'JJ'), ('cac', 'JJ'), ...
# 1498  [('if', 'IN'), ('it', 'PRP'), ('has', 'VBZ'), ...
#
#                                     words_processed_all  \
# 0     ['cher', 'get', 'second', 'pfizer', 'vaccine',...
# 1                  ['syringe', 'ed', 'pfizer', 'april']
# 2                          ['double', 'shot', 'pfizer']
# 3     ['couple', 'thing', 'wife', 'ra', 'take', 'pla...
# 4     ['great', 'back', 'april', 'pfizer', 'two', 's...
# ...                                                 ...
# 1494  ['north', 'high_school', 'today', 'come', 'get...
# 1495  ['please', 'get', 'vaccinated', 'disclaimer', ...
# 1496  ['disappointed', 'blame', 'vaccinated', 'crowd...
# 1497  ['fair', 'cac', 'et_al', 'always', 'say', 'pfi...
# 1498  ['twentynine', 'day', 'since', 'first', 'pfize...
#
#                       words_processed_noun_adj_verb_adv  \
# 0     ['cher', 'get', 'second', 'pfizer', 'vaccine',...
# 1                                           ['syringe']
# 2                          ['double', 'shot', 'pfizer']
# 3     ['couple', 'thing', 'wife', 'take', 'plaquenil...
# 4                           ['great', 'pfizer', 'shot']
# ...                                                 ...
# 1494  ['north', 'today', 'come', 'get', 'free', 'pfi...
# 1495  ['get', 'vaccinated', 'disclaimer', 'pfizer', ...
# 1496  ['disappointed', 'blame', 'vaccinated', 'crowd...
# 1497  ['fair', 'cac', 'et_al', 'always', 'say', 'pfi...
# 1498  ['twentynine', 'day', 'first', 'pfizer', 'shoo...
#
#                                    words_processed_noun  \
# 0     ['cher', 'pfizer', 'vaccine', 'cher', 'guess',...
# 1                                           ['syringe']
# 2                                    ['shot', 'pfizer']
# 3     ['couple', 'thing', 'wife', 'plaquenil', 'prob...
# 4                                    ['pfizer', 'shot']
# ...                                                 ...
# 1494  ['north', 'today', 'pfizer', 'vaccine', 'year'...
# 1495                  ['disclaimer', 'pfizer', 'stock']
# 1496     ['blame', 'delta', 'covid', 'case', 'vaccine']
# 1497  ['cac', 'et_al', 'pfizer', 'vaccination', 'cha...
# 1498  ['twentynine', 'day', 'pfizer', 'day', 'shot',...
#
#                                                  scores  compound  sentiment
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000          1
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000          1
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000          1
# 3     {'neg': 0.056, 'neu': 0.887, 'pos': 0.057, 'co...    0.0150          1
# 4     {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'comp...    0.6249          2
# ...                                                 ...       ...        ...
# 1494  {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'comp...    0.5106          2
# 1495  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'comp...    0.3182          2
# 1496  {'neg': 0.174, 'neu': 0.727, 'pos': 0.099, 'co...   -0.4753          0
# 1497  {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'comp...    0.5106          2
# 1498  {'neg': 0.052, 'neu': 0.948, 'pos': 0.0, 'comp...   -0.2732          2
#
# [1499 rows x 11 columns]

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
X_whole_data = cv.fit_transform(usa_opinion['new_text_after_translation'].values.astype('U'))

# %%
from sklearn.model_selection import train_test_split
# X=text_counts
X = cv.transform(labelled_df.new_text_after_translation)
y=labelled_df.sentiment
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=19)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1049, 103522)
# (450, 103522)

# %%
from sklearn.naive_bayes import ComplementNB
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from math import *
cnb = ComplementNB()
cnb.fit(X_train, y_train)
cross_cnb = cross_val_score(cnb, X, y,n_jobs = -1)
print("Cross Validation score = ",cross_cnb)                
print ("Train accuracy ={:.2f}%".format(cnb.score(X_train,y_train)*100))
print ("Test accuracy ={:.2f}%".format(cnb.score(X_test,y_test)*100))
train_acc_cnb=cnb.score(X_train,y_train)
test_acc_cnb=cnb.score(X_test,y_test)
# Out:
# Cross Validation score =  [0.5        0.48333333 0.43666667 0.52666667 0.44481605]
# Train accuracy =81.12%
# Test accuracy =48.44%

# %%
#plotting the best parameters
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
data_cnb = [train_acc_cnb,test_acc_cnb]
labels = ['Train Accuracy','Test Accuracy']
plt.xticks(range(len(data_cnb)), labels)
plt.ylabel('Accuracy')
plt.title('Accuracy plot with best parameters')
plt.bar(range(len(data_cnb)), data_cnb,color=['blue','darkorange']) 
Train_acc = mpatches.Patch(color='blue', label='Train_acc')
Test_acc = mpatches.Patch(color='darkorange', label='Test_acc')
plt.legend(handles=[Train_acc, Test_acc],loc='best')
plt.gcf().set_size_inches(8, 8)
plt.show()

# %%
 from sklearn.metrics import *
#Predict test data set
y_pred_cnb =cnb.predict(X_test)

#This is the confusion matrix :
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_cnb))
# Out:
# [[ 41   1  93]
#  [ 20   6 100]
#  [ 17   1 171]]

# %%
#Checking performance our model with classification report
print(classification_report(y_test, y_pred_cnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.30      0.38       135
#            1       0.75      0.05      0.09       126
#            2       0.47      0.90      0.62       189
#
#     accuracy                           0.48       450
#    macro avg       0.58      0.42      0.36       450
# weighted avg       0.56      0.48      0.40       450

# %%
from sklearn.metrics import *

print("F1 score ={:.2f}%".format(f1_score(y_test, y_pred_cnb, average="macro")*100))
f1_cnb=f1_score(y_test, y_pred_cnb, average="macro")
print("Precision score ={:.2f}%".format(precision_score(y_test, y_pred_cnb, average="macro")*100))
precision_cnb=precision_score(y_test, y_pred_cnb, average="macro")
print("Recall score ={:.2f}%".format(recall_score(y_test, y_pred_cnb, average="macro")*100))  
recall_cnb=recall_score(y_test, y_pred_cnb, average="macro")
# Out:
# F1 score =36.43%
# Precision score =58.18%
# Recall score =41.87%

# %% [markdown]
# ## Implement on entire dataset

# %%
predictions = cnb.predict(X_whole_data)

# %%
usa_opinion["sentiment"] = predictions
usa_opinion
# Out:
# /var/folders/d0/5_1bb8ld291843m4x7vj7vnw0000gn/T/ipykernel_19906/2669235059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_opinion["sentiment"] = predictions
#          index                                               Text  \
# 0            0  want find way end racism try force people inje...
# 1            1  this child almost died tetanus, spent months h...
# 2            2  juste se rappeler m. leblanc la pression que l...
# 3            3  you would expect cases rise significantly, cou...
# 4            4  depends whether vaccination status is embedded...
# ...        ...                                                ...
# 404255  404255  pretty remarkable achievement. thank you all v...
# 404258  404258  oh that explains similar - seemingly out nowhe...
# 404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 404255  pretty remarkable achievement. thank you all v...   ENGLISH
# 404258  oh that explains similar - seemingly out nowhe...   ENGLISH
# 404260  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 404262  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 404263  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404255  pretty remarkable achievement. thank you all v...
# 404258  oh that explains similar - seemingly out nowhe...
# 404260  do it others.... flexed_bicepsparty_poppersyri...
# 404262  yay raising_handslight_skin_tone congrats dr. ...
# 404263  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 404255  [('pretty', 'RB'), ('remarkable', 'JJ'), ('ach...
# 404258  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
# 404260  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 404262  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 404263  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 404255  ['pretty', 'remarkable', 'achievement', 'thank...
# 404258  ['explains', 'similar', 'seemingly', 'nowhere'...
# 404260                    ['others', 'vaccinesaveslives']
# 404262  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 404255  ['pretty', 'remarkable', 'achievement', 'thank...
# 404258  ['explain', 'similar', 'seemingly', 'nowhere',...
# 404260                      ['other', 'vaccinesaveslive']
# 404262  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 404255  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 404258  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 404260                      ['other', 'vaccinesaveslive']  subjective
# 404262  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 404263  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 404255          2
# 404258          0
# 404260          2
# 404262          2
# 404263          2
#
# [320122 rows x 11 columns]

# %%
usa_opinion["sentiment"].value_counts()
# Out:
# 2    222780
# 0     92823
# 1      4519
# Name: sentiment, dtype: int64

# %%
usa_opinion.to_csv("sentiment_labelled_usa_NNB.csv")

# %%
whole_df = usa_opinion[usa_opinion.sentiment != 1]

# %%
whole_df
# Out:
#          index                                               Text  \
# 0            0  want find way end racism try force people inje...
# 1            1  this child almost died tetanus, spent months h...
# 2            2  juste se rappeler m. leblanc la pression que l...
# 3            3  you would expect cases rise significantly, cou...
# 4            4  depends whether vaccination status is embedded...
# ...        ...                                                ...
# 404255  404255  pretty remarkable achievement. thank you all v...
# 404258  404258  oh that explains similar - seemingly out nowhe...
# 404260  404260           do it others.... 💪🎉💉🤙 #vaccinesaveslives
# 404262  404262  yay 🙌🏻 congrats dr. j being fully vaccinated i...
# 404263  404263  we all have do our part end this pandemic— get...
#
#                                                  new_text languages  \
# 0       want find way end racism try force people inje...   ENGLISH
# 1       this child almost died tetanus, spent months h...   ENGLISH
# 2       juste se rappeler m. leblanc la pression que l...    FRENCH
# 3       you would expect cases rise significantly, cou...   ENGLISH
# 4       depends whether vaccination status is embedded...   ENGLISH
# ...                                                   ...       ...
# 404255  pretty remarkable achievement. thank you all v...   ENGLISH
# 404258  oh that explains similar - seemingly out nowhe...   ENGLISH
# 404260  do it others.... flexed_bicepsparty_poppersyri...   ENGLISH
# 404262  yay raising_handslight_skin_tone congrats dr. ...   ENGLISH
# 404263  we all have do our part end this pandemic— get...   ENGLISH
#
#                                new_text_after_translation  \
# 0       want find way end racism try force people inje...
# 1       this child almost died tetanus, spent months h...
# 2       just remember mr. leblanc the pressure that th...
# 3       you would expect cases rise significantly, cou...
# 4       depends whether vaccination status is embedded...
# ...                                                   ...
# 404255  pretty remarkable achievement. thank you all v...
# 404258  oh that explains similar - seemingly out nowhe...
# 404260  do it others.... flexed_bicepsparty_poppersyri...
# 404262  yay raising_handslight_skin_tone congrats dr. ...
# 404263  we all have do our part end this pandemic— get...
#
#                                          pos_tagged_words  \
# 0       [('want', 'JJ'), ('find', 'VB'), ('way', 'NN')...
# 1       [('this', 'DT'), ('child', 'NN'), ('almost', '...
# 2       [('just', 'RB'), ('remember', 'VB'), ('my', 'P...
# 3       [('you', 'PRP'), ('would', 'MD'), ('expect', '...
# 4       [('depends', 'VBZ'), ('whether', 'IN'), ('vacc...
# ...                                                   ...
# 404255  [('pretty', 'RB'), ('remarkable', 'JJ'), ('ach...
# 404258  [('oh', 'UH'), ('that', 'DT'), ('explains', 'V...
# 404260  [('do', 'VB'), ('it', 'PRP'), ('others', 'NNS'...
# 404262  [('yay', 'NN'), ('congrats', 'NNS'), ('do', 'V...
# 404263  [('we', 'PRP'), ('all', 'DT'), ('have', 'VBP')...
#
#                                       words_processed_all  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'died', 'tetanus', 'spent'...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depends', 'whether', 'vaccination', 'status'...
# ...                                                   ...
# 404255  ['pretty', 'remarkable', 'achievement', 'thank...
# 404258  ['explains', 'similar', 'seemingly', 'nowhere'...
# 404260                    ['others', 'vaccinesaveslives']
# 404262  ['yay', 'congrats', 'fully', 'vaccinated', 'be...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                         words_processed_noun_adj_verb_adv  \
# 0       ['want', 'find', 'way', 'end', 'racism', 'try'...
# 1       ['child', 'almost', 'die', 'tetanus', 'spend',...
# 2       ['remember', 'leblanc', 'pressure', 'provincia...
# 3       ['would', 'expect', 'case', 'rise', 'significa...
# 4       ['depend', 'vaccination', 'status', 'embed', '...
# ...                                                   ...
# 404255  ['pretty', 'remarkable', 'achievement', 'thank...
# 404258  ['explain', 'similar', 'seemingly', 'nowhere',...
# 404260                      ['other', 'vaccinesaveslive']
# 404262  ['congrat', 'fully', 'vaccinate', 'good', 'fee...
# 404263  ['part', 'end', 'pandemic', 'get', 'vaccine', ...
#
#                                      words_processed_noun   text_type  \
# 0       ['way', 'end', 'racism', 'force', 'people', 'b...  subjective
# 1       ['child', 'tetanus', 'month', 'hospital', 'cos...  subjective
# 2       ['leblanc', 'pressure', 'business', 'world', '...  subjective
# 3       ['case', 'vaccination', 'rate', 'play', 'space...  subjective
# 4       ['vaccination', 'status', 'code', 'link', 'con...  subjective
# ...                                                   ...         ...
# 404255  ['achievement', 'volunteer', 'shotsshotsshot',...  subjective
# 404258  ['message', 'background', 'folk', 'vaccinesave...  subjective
# 404260                      ['other', 'vaccinesaveslive']  subjective
# 404262  ['congrat', 'feeling', 'safetyfirst', 'vaccine...  subjective
# 404263  ['part', 'end', 'vaccine', 'help', 'other', 'v...  subjective
#
#         sentiment
# 0               2
# 1               0
# 2               0
# 3               2
# 4               2
# ...           ...
# 404255          2
# 404258          0
# 404260          2
# 404262          2
# 404263          2
#
# [315603 rows x 11 columns]

# %%
whole_df["sentiment"].value_counts()
# Out:
# 2    222780
# 0     92823
# Name: sentiment, dtype: int64

# %%
whole_df.to_csv("pos_neg_usa.csv")
