# %%
import nltk
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("700_USA_Labelled.csv")
df
# Out:
#                                                   Text  \
# 0    this was response post praising pfizer vaccine...
# 1    les van poner pfizer pinches morrillos cagason...
# 2    after may 2nd pfizer vax 6 days id be glad go ...
# 3    cher i got my second pfizer vaccine shot may 1...
# 4                                    eso es con pfizer
# ..                                                 ...
# 695  yes. steve bannon rumble had great show with i...
# 696  vaccine debate- i personally had pfizer. my fa...
# 697                                        makes sense
# 698  podrías ayudar un playense que quiere ponerse...
# 699         pfizer biontech vacc is german development
#
#                                       pos_tagged_words  \
# 0    [('this', 'DT'), ('was', 'VBD'), ('response', ...
# 1    [('they', 'PRP'), ('re', 'VBP'), ('going', 'VB...
# 2    [('after', 'IN'), ('may', 'MD'), ('and', 'CC')...
# 3    [('cher', 'NN'), ('i', 'NN'), ('got', 'VBD'), ...
# 4    [('that', 'IN'), ('i', 'NN'), ('with', 'IN'), ...
# ..                                                 ...
# 695  [('yes', 'NNS'), ('steve', 'VBP'), ('cannon', ...
# 696  [('vaccine', 'JJ'), ('debate', 'NN'), ('i', 'N...
# 697                [('makes', 'VBZ'), ('sense', 'NN')]
# 698  [('could', 'MD'), ('you', 'PRP'), ('help', 'VB...
# 699  [('pfizer', 'NN'), ('biotech', 'NN'), ('vac', ...
#
#                                             words_list  \
# 0    ['response', 'post', 'praise', 'pfizer', 'vacc...
# 1    ['go', 'put', 'pfizer', 'fuck', 'lucky', 'shit...
# 2    ['may', 'pfizer', 'van', 'day', 'I', 'd', 'gla...
# 3    ['cher', 'get', 'second', 'pfizer', 'vaccine',...
# 4                                           ['pfizer']
# ..                                                 ...
# 695  ['yes', 'steve', 'cannon', 'rumble', 'great', ...
# 696  ['vaccine', 'debate', 'personally', 'pfizer', ...
# 697                                    ['makes_sense']
# 698  ['could', 'help', 'player', 'want', 'get', 'pf...
# 699  ['pfizer', 'biotech', 'vac', 'german', 'develo...
#
#                                               new_text  \
# 0    response post praise pfizer vaccine april gop ...
# 1    go put pfizer fuck lucky shithead go get vacci...
# 2    may pfizer van day I d glad go help work probl...
# 3    cher get second pfizer vaccine shoot may est f...
# 4                                               pfizer
# ..                                                 ...
# 695  yes steve cannon rumble great show inventor ex...
# 696  vaccine debate personally pfizer family receiv...
# 697                                        makes_sense
# 698    could help player want get pfizer proof_address
# 699              pfizer biotech vac german development
#
#                                                 scores  compound  \
# 0    {'neg': 0.072, 'neu': 0.785, 'pos': 0.143, 'co...    0.4767
# 1    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 2    {'neg': 0.146, 'neu': 0.685, 'pos': 0.17, 'com...    0.2023
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# ..                                                 ...       ...
# 695  {'neg': 0.209, 'neu': 0.698, 'pos': 0.093, 'co...   -0.8159
# 696  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'comp...    0.7351
# 697  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 698  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 699  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
#
#     sentiment_vader
# 0          negative
# 1          negative
# 2          positive
# 3           neutral
# 4           neutral
# ..              ...
# 695        negative
# 696        positive
# 697         neutral
# 698         neutral
# 699         neutral
#
# [700 rows x 7 columns]

# %%
df.drop(['Text','pos_tagged_words','words_list','scores','compound'], axis=1, inplace=True)
df.head(10)
# Out:
#                                             new_text sentiment_vader
# 0  response post praise pfizer vaccine april gop ...        negative
# 1  go put pfizer fuck lucky shithead go get vacci...        negative
# 2  may pfizer van day I d glad go help work probl...        positive
# 3  cher get second pfizer vaccine shoot may est f...         neutral
# 4                                             pfizer         neutral
# 5                            syringe ed pfizer april         neutral
# 6                                        dose pfizer         neutral
# 7                                 double shot pfizer         neutral
# 8                         renault already two pfizer         neutral
# 9  couple thing wife ra take plaquenil plus never...         neutral

# %%
df
# Out:
#                                               new_text sentiment_vader
# 0    response post praise pfizer vaccine april gop ...        negative
# 1    go put pfizer fuck lucky shithead go get vacci...        negative
# 2    may pfizer van day I d glad go help work probl...        positive
# 3    cher get second pfizer vaccine shoot may est f...         neutral
# 4                                               pfizer         neutral
# ..                                                 ...             ...
# 695  yes steve cannon rumble great show inventor ex...        negative
# 696  vaccine debate personally pfizer family receiv...        positive
# 697                                        makes_sense         neutral
# 698    could help player want get pfizer proof_address         neutral
# 699              pfizer biotech vac german development         neutral
#
# [700 rows x 2 columns]

# %%
def sentiment2target(sentiment):
    return {
        'negative': 0,
        'neutral': 1,
        'positive' : 2
    }[sentiment]
targets = df.sentiment_vader.apply(sentiment2target)

# %%
df['sentiment'] =targets
df
# Out:
#                                               new_text sentiment_vader  \
# 0    response post praise pfizer vaccine april gop ...        negative
# 1    go put pfizer fuck lucky shithead go get vacci...        negative
# 2    may pfizer van day I d glad go help work probl...        positive
# 3    cher get second pfizer vaccine shoot may est f...         neutral
# 4                                               pfizer         neutral
# ..                                                 ...             ...
# 695  yes steve cannon rumble great show inventor ex...        negative
# 696  vaccine debate personally pfizer family receiv...        positive
# 697                                        makes_sense         neutral
# 698    could help player want get pfizer proof_address         neutral
# 699              pfizer biotech vac german development         neutral
#
#      sentiment
# 0            0
# 1            0
# 2            2
# 3            1
# 4            1
# ..         ...
# 695          0
# 696          2
# 697          1
# 698          1
# 699          1
#
# [700 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X=df['new_text']
y=df['sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=19)

# %%
X_test
# Out:
# 555    first dose pfizer monterey nuevo leon city mou...
# 560    get dose pfizer third trimester baby bear happ...
# 219    we need booster every year assure pfizer massi...
# 252                    right second dose pfizer sure hit
# 337    not stop tremble hahahahahahahaha first dose p...
#                              ...
# 318                                 high_risk say pfizer
# 186              god need pfizer hic matter drink bottle
# 401    know take shot pfizer modern fully effective w...
# 398    finally quarantine time get dose one two three...
# 108    side_effect besides stiff arm either jab first...
# Name: new_text, Length: 210, dtype: object

# %%
X_train
# Out:
# 110                                        modern pfizer
# 37                                    second dose pfizer
# 538    hear anecdote awful side_effect covid vaccine ...
# 501    lubbock health_department partner dialog isd o...
# 173            fully vaccinated pfizer longboat colorado
#                              ...
# 308    lol not vaccine work stop mutation enough peop...
# 19     think go get headache like covid never develop...
# 354    pfizer amp react covid nineteen breakthrough_i...
# 622    meee brother cage want money earn would alread...
# 605    go look pfizer trial result fact not conspirac...
# Name: new_text, Length: 490, dtype: object

# %%
y_train
# Out:
# 110    1
# 37     1
# 538    0
# 501    1
# 173    1
#       ..
# 308    2
# 19     0
# 354    0
# 622    1
# 605    2
# Name: sentiment, Length: 490, dtype: int64

# %%
y_test
# Out:
# 555    1
# 560    2
# 219    0
# 252    1
# 337    0
#       ..
# 318    1
# 186    2
# 401    2
# 398    2
# 108    1
# Name: sentiment, Length: 210, dtype: int64

# %%
tweets = df['new_text']

# %%
def build_freqs(tweets, ys):
    """Build frequencies.
    Input:
        tweets: a list of tweets
        ys: an m x 1 array with the sentiment label of each tweet
            (either 0 or 1)
    Output:
        freqs: a dictionary mapping each (word, sentiment) pair to its
        frequency
    """
    # Convert np array to list since zip needs an iterable.
    # The squeeze is necessary or the list ends up with one element.
    # Also note that this is just a NOP if ys is already a list.
    yslist = np.squeeze(ys).tolist()

    # Start with an empty dictionary and populate it by looping over all tweets
    # and over all processed words in each tweet.
    freqs = {}
    for y, tweet in zip(yslist, tweets):
        for a_tweet in tweets:
            for word in a_tweet:
                pair = (word, y)
                if pair in freqs:
                    freqs[pair] += 1
                else:
                    freqs[pair] = 1

    return freqs

# %%
freqs = build_freqs(X_train, y_train)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d0/5_1bb8ld291843m4x7vj7vnw0000gn/T/ipykernel_7680/3849627704.py in <module>
# ----> 1 freqs = build_freqs(X_train, y_train)
#       2
#       3 # check the output
#       4 print("type(freqs) = " + str(type(freqs)))
#       5 print("len(freqs) = " + str(len(freqs.keys())))
#
# /var/folders/d0/5_1bb8ld291843m4x7vj7vnw0000gn/T/ipykernel_7680/4179724652.py in build_freqs(tweets, ys)
#      19     for y, tweet in zip(yslist, tweets):
#      20         for a_tweet in tweets:
# ---> 21             for word in a_tweet:
#      22                 pair = (word, y)
#      23                 if pair in freqs:
#
# TypeError: 'float' object is not iterable

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
    h = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        # get z, the dot product of x and theta
        z = np.dot(x,theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = -1./m * (np.dot(y.transpose(), np.log(h)) + np.dot((1-y).transpose(),np.log(1-h)))

        # update the weights theta
        theta = theta - (alpha/m) * np.dot(x.transpose(),(h-y))
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = tweet
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word, 1.0),0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word, 0.0),0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(X_train[0], freqs)
print(tmp1)
# Out:
# [[1.0000000e+00 2.8675296e+07 2.8973997e+07]]

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1.000000e+00 3.128736e+06 3.161327e+06]]

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(X_train), 3))
for i in range(len(X_train)):
    X[i, :]= extract_features(X_train[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/d0/5_1bb8ld291843m4x7vj7vnw0000gn/T/ipykernel_3047/937338346.py in <module>
#       2 X = np.zeros((len(X_train), 3))
#       3 for i in range(len(X_train)):
# ----> 4     X[i, :]= extract_features(X_train[i], freqs)
#       5
#       6 # training labels corresponding to X
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 1
