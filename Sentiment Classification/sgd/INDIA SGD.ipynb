# %% [markdown]
# ### Read opinion labelled data

# %%
import pandas as pd
import numpy as np

# %%
india_opinion = pd.read_csv("labelled_data_india_NB.csv")
india_opinion = india_opinion.rename(columns={'Unnamed: 0': 'index'})
india_opinion = india_opinion.drop(columns=['Unnamed: 0.1'])
india_opinion
# Out:
#        index                                               Text  \
# 0          0  soniya mummy hoti toh covid me magic stick ghu...
# 1          1  #pickids : about 20,000 children perlis eligib...
# 2          2  previous covid-19 infection – but not vaccinat...
# 3          3  india’s covid-19 vaccination coverage crosses ...
# 4          4  i got call office principal commissioner cgst ...
# ...      ...                                                ...
# 95183  95183  mask up 😷 india 🇮🇳 come forward vaccination ti...
# 95184  95184  our sincere request state central govt 🙏🙏. ple...
# 95185  95185  thanks your appreciation valuable feedback abo...
# 95186  95186  i can’t wait get my 2nd dose #covidvaccine ove...
# 95187  95187  thanks your appreciation valuable feedback abo...
#
#                                                 new_text         languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 1      #pickids : about 20,000 children perlis eligib...           ENGLISH
# 2      previous covid-19 infection – but not vaccinat...           ENGLISH
# 3      india’s covid-19 vaccination coverage crosses ...           ENGLISH
# 4      i got call office principal commissioner cgst ...           ENGLISH
# ...                                                  ...               ...
# 95183  mask up face_with_medical_mask india India com...  ENGLISH, Unknown
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95185  thanks your appreciation valuable feedback abo...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
# 95187  thanks your appreciation valuable feedback abo...           ENGLISH
#
#                                               translated new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...       Unknown
# 1      #pickids : about 20,000 children perlis eligib...       ENGLISH
# 2      previous covid-19 infection – but not vaccinat...       ENGLISH
# 3      india’s covid-19 vaccination coverage crosses ...       ENGLISH
# 4      i got call office principal commissioner cgst ...       ENGLISH
# ...                                                  ...           ...
# 95183  mask up face_with_medical_mask india India com...       ENGLISH
# 95184  our sincere request state central govt folded_...       ENGLISH
# 95185  thanks your appreciation valuable feedback abo...       ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...       ENGLISH
# 95187  thanks your appreciation valuable feedback abo...       ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 1      [('pickins', 'NNS'), ('about', 'IN'), ('twenty...
# 2      [('previous', 'JJ'), ('couid', 'NN'), ('ninete...
# 3      [('india', 'NN'), ('i', 'NN'), ('i', 'VBP'), (...
# 4      [('i', 'NN'), ('got', 'VBD'), ('call', 'JJ'), ...
# ...                                                  ...
# 95183  [('mask', 'VB'), ('up', 'RP'), ('india', 'JJ')...
# 95184  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 95185  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
# 95186  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
# 95187  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1      ['pickins', 'twenty', 'zero', 'child', 'peril'...
# 2      ['previous', 'couid', 'nineteen', 'infection',...
# 3      ['india', 'couid', 'nineteen', 'vaccination', ...
# 4      ['got', 'call', 'office', 'principal', 'commis...
# ...                                                  ...
# 95183  ['mask', 'india', 'india', 'come_forward', 'va...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
# 95187  ['thank', 'appreciation', 'valuable', 'feedbac...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 1      ['child', 'peril', 'eligible', 'couid', 'vacci...
# 2      ['previous', 'couid', 'infection', 'vaccinatio...
# 3                                ['vaccination', 'mark']
# 4      ['get', 'call', 'office', 'ascertain', 'status...
# ...                                                  ...
# 95183  ['come_forward', 'vaccination', 'tika_tsar', '...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
# 95187  ['thank', 'appreciation', 'valuable', 'feedbac...
#
#                                     words_processed_noun   text_type
# 0                                              ['death']  subjective
# 1             ['child', 'peril', 'couid', 'vaccination']   objective
# 2      ['couid', 'infection', 'vaccination', 'perform...   objective
# 3                                        ['vaccination']   objective
# 4      ['office', 'status', 'couid', 'vaccination', '...   objective
# ...                                                  ...         ...
# 95183  ['vaccination', 'syringemicrobe', 'television'...   objective
# 95184  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 95185  ['thank', 'appreciation', 'feedback', 'vaccine...  subjective
# 95186  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
# 95187  ['thank', 'appreciation', 'feedback', 'vaccina...   objective
#
# [95188 rows x 11 columns]

# %%
india_opinion['text_type'].value_counts()
# Out:
# objective     51725
# subjective    43463
# Name: text_type, dtype: int64

# %%
india_opinion = india_opinion[india_opinion.text_type == 'subjective']

# %%
india_opinion
# Out:
#        index                                               Text  \
# 0          0  soniya mummy hoti toh covid me magic stick ghu...
# 11        11  خود کو اور اپنے پیاروں کو کورونا وبا سے بچانے ...
# 12        12  is covid ki waja se buht saray logon ne apne p...
# 18        18  deaths due covid what is vaccination rate what...
# 28        28  vaccination against covid- 19 is necessity tod...
# ...      ...                                                ...
# 95179  95179  nature seems have already started working savi...
# 95180  95180  dear , we #india 🇮🇳has helped this #world incl...
# 95184  95184  our sincere request state central govt 🙏🙏. ple...
# 95185  95185  thanks your appreciation valuable feedback abo...
# 95186  95186  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                                 new_text         languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 11     خود کو اور اپنے پیاروں کو کورونا وبا سے بچانے ...     URDU, Unknown
# 12     is covid ki waja se buht saray logon ne apne p...           Unknown
# 18     deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 28     vaccination against covid- 19 is necessity tod...           ENGLISH
# ...                                                  ...               ...
# 95179  nature seems have already started working savi...           ENGLISH
# 95180  dear , we #india Indiahas helped this #world i...           ENGLISH
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95185  thanks your appreciation valuable feedback abo...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
#
#                                               translated     new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 11     Vaccinate to protect yourself and your loved o...           ENGLISH
# 12     is covid ki waja se buht saray logon ne apne p...           Unknown
# 18     deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 28     vaccination against covid- 19 is necessity tod...           ENGLISH
# ...                                                  ...               ...
# 95179  nature seems have already started working savi...           ENGLISH
# 95180  dear , we #india Indiahas helped this #world i...           ENGLISH
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95185  thanks your appreciation valuable feedback abo...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...           ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 11     [('vaccinate', 'NN'), ('to', 'TO'), ('protect'...
# 12     [('is', 'VBZ'), ('couid', 'JJ'), ('ki', 'NN'),...
# 18     [('deaths', 'NNS'), ('due', 'JJ'), ('couid', '...
# 28     [('vaccination', 'NN'), ('against', 'IN'), ('c...
# ...                                                  ...
# 95179  [('nature', 'NN'), ('seems', 'VBZ'), ('have', ...
# 95180  [('dear', 'IN'), ('we', 'PRP'), ('india', 'VBP...
# 95184  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 95185  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
# 95186  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 11     ['vaccinate', 'protect', 'loved_one', 'coronav...
# 12     ['couid', 'ki', 'raja', 'se', 'spray', 'logon'...
# 18     ['death', 'due', 'couid', 'vaccination', 'rate...
# 28     ['vaccination', 'couid', 'nineteen', 'necessit...
# ...                                                  ...
# 95179  ['nature', 'seem', 'already', 'start', 'work',...
# 95180  ['dear', 'india', 'indians', 'help', 'world', ...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 11                        ['uranus', 'covidvaccination']
# 12                        ['hair', 'ply', 'vaccination']
# 18     ['death', 'due', 'couid', 'vaccination', 'rate...
# 28     ['necessity', 'today', 'scenario', 'hope', 'pr...
# ...                                                  ...
# 95179  ['nature', 'seem', 'already', 'start', 'work',...
# 95180  ['dear', 'help', 'world', 'include', 'kindness...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type
# 0                                              ['death']  subjective
# 11                                  ['covidvaccination']  subjective
# 12                        ['hair', 'ply', 'vaccination']  subjective
# 18     ['death', 'couid', 'vaccination', 'rate', 'har...  subjective
# 28         ['necessity', 'today', 'scenario', 'problem']  subjective
# ...                                                  ...         ...
# 95179  ['nature', 'generation', 'vaccinesaveslive', '...  subjective
# 95180    ['world', 'kindnessmatter', 'vaccinesaveslive']  subjective
# 95184  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 95185  ['thank', 'appreciation', 'feedback', 'vaccine...  subjective
# 95186  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
#
# [43463 rows x 11 columns]

# %% [markdown]
# ### Read data (Labelled)

# %%
labelled_df = pd.read_csv("../../1k_sample_labelled_india.csv")
# labelled_df.drop(['Unnamed: 0'], axis=1, inplace=True)
labelled_df
# Out:
#      index                                               Text  \
# 0    57000  kalau aku jadi anti vaccine ni salahkan keraja...
# 1    57003  "no vax passports": anti-vaccine protesters ga...
# 2    57010  good, sir also make sure that other persons yo...
# 3    57014  some anti-vaxers my circle influence believe t...
# 4    57044  myself, my lovely wife &amp; respectful parent...
# ..     ...                                                ...
# 994  75434  amazing staff &amp; supporting .thanks all got...
# 995  75444  it has been great honor &amp; pleasure have va...
# 996  75691  great know, i am now fully #vaccinated with 2n...
# 997  75783  thank you #republic_of_india i have vaccinated...
# 998  75835  thanks visionary leadership hon'ble pmo india,...
#
#                                       pos_tagged_words new_languages  \
# 0    [('if', 'IN'), ('i', 'JJ'), ('become', 'VBP'),...       ENGLISH
# 1    [('no', 'DT'), ('van', 'NN'), ('passports', 'V...       ENGLISH
# 2    [('good', 'JJ'), ('sir', 'NN'), ('also', 'RB')...       ENGLISH
# 3    [('some', 'DT'), ('anti', 'JJ'), ('cars', 'NNS...       ENGLISH
# 4    [('myself', 'PRP'), ('my', 'PRP$'), ('lovely',...       ENGLISH
# ..                                                 ...           ...
# 994  [('amazing', 'JJ'), ('staff', 'NN'), ('amp', '...       ENGLISH
# 995  [('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'...       ENGLISH
# 996  [('great', 'JJ'), ('know', 'VBP'), ('i', 'JJ')...       ENGLISH
# 997  [('thank', 'IN'), ('you', 'PRP'), ('i', 'VBP')...       ENGLISH
# 998  [('thanks', 'NNS'), ('visionary', 'JJ'), ('lea...       ENGLISH
#
#                                             words_list  \
# 0    ['become', 'anti', 'vaccine', 'blame', 'malays...
# 1    ['van', 'passports', 'anti', 'vaccine', 'prote...
# 2    ['good', 'sir', 'also', 'make_sure', 'person',...
# 3    ['anti', 'cars', 'circle', 'influence', 'belie...
# 4    ['lovely', 'wife', 'amp', 'respectful', 'paren...
# ..                                                 ...
# 994  ['amazing', 'staff', 'amp', 'support', 'thank'...
# 995  ['great', 'honor', 'amp', 'pleasure', 'vaccina...
# 996  ['great', 'know', 'fully', 'vaccinate', 'dose'...
# 997  ['thank', 'vaccinated', 'today', 'public', 'th...
# 998  ['thanks', 'visionary', 'leadership', 'hon_ble...
#
#                                               new_text  \
# 0    become anti vaccine blame malaysian government...
# 1    van passports anti vaccine protester gather sp...
# 2    good sir also make_sure person fraternity part...
# 3    anti cars circle influence believe second wave...
# 4    lovely wife amp respectful parent complete tak...
# ..                                                 ...
# 994  amazing staff amp support thank get vaccinate ...
# 995  great honor amp pleasure vaccinated people kin...
# 996  great know fully vaccinate dose also heartfelt...
# 997  thank vaccinated today public thank article th...
# 998  thanks visionary leadership hon_ble pro india ...
#
#                                                 scores  compound  \
# 0    {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'comp...   -0.3182
# 1    {'neg': 0.339, 'neu': 0.661, 'pos': 0.0, 'comp...   -0.4767
# 2    {'neg': 0.084, 'neu': 0.727, 'pos': 0.189, 'co...    0.4404
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4    {'neg': 0.075, 'neu': 0.424, 'pos': 0.501, 'co...    0.9801
# ..                                                 ...       ...
# 994  {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'comp...    0.8625
# 995  {'neg': 0.0, 'neu': 0.542, 'pos': 0.458, 'comp...    0.9001
# 996  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...    0.8885
# 997  {'neg': 0.0, 'neu': 0.561, 'pos': 0.439, 'comp...    0.8885
# 998  {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'comp...    0.7650
#
#     sentiment_vader
# 0          negative
# 1          negative
# 2          positive
# 3           neutral
# 4          positive
# ..              ...
# 994        positive
# 995        positive
# 996        positive
# 997        positive
# 998        positive
#
# [999 rows x 9 columns]

# %%
def sentiment2target(sentiment):
    return {
        'negative': 0,
        'neutral': 1,
        'positive' : 2
    }[sentiment]
targets = labelled_df.sentiment_vader.apply(sentiment2target)

# %%
labelled_df['sentiment_vader'] =targets

# %%
labelled_df
# Out:
#      index                                               Text  \
# 0    57000  kalau aku jadi anti vaccine ni salahkan keraja...
# 1    57003  "no vax passports": anti-vaccine protesters ga...
# 2    57010  good, sir also make sure that other persons yo...
# 3    57014  some anti-vaxers my circle influence believe t...
# 4    57044  myself, my lovely wife &amp; respectful parent...
# ..     ...                                                ...
# 994  75434  amazing staff &amp; supporting .thanks all got...
# 995  75444  it has been great honor &amp; pleasure have va...
# 996  75691  great know, i am now fully #vaccinated with 2n...
# 997  75783  thank you #republic_of_india i have vaccinated...
# 998  75835  thanks visionary leadership hon'ble pmo india,...
#
#                                       pos_tagged_words new_languages  \
# 0    [('if', 'IN'), ('i', 'JJ'), ('become', 'VBP'),...       ENGLISH
# 1    [('no', 'DT'), ('van', 'NN'), ('passports', 'V...       ENGLISH
# 2    [('good', 'JJ'), ('sir', 'NN'), ('also', 'RB')...       ENGLISH
# 3    [('some', 'DT'), ('anti', 'JJ'), ('cars', 'NNS...       ENGLISH
# 4    [('myself', 'PRP'), ('my', 'PRP$'), ('lovely',...       ENGLISH
# ..                                                 ...           ...
# 994  [('amazing', 'JJ'), ('staff', 'NN'), ('amp', '...       ENGLISH
# 995  [('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'...       ENGLISH
# 996  [('great', 'JJ'), ('know', 'VBP'), ('i', 'JJ')...       ENGLISH
# 997  [('thank', 'IN'), ('you', 'PRP'), ('i', 'VBP')...       ENGLISH
# 998  [('thanks', 'NNS'), ('visionary', 'JJ'), ('lea...       ENGLISH
#
#                                             words_list  \
# 0    ['become', 'anti', 'vaccine', 'blame', 'malays...
# 1    ['van', 'passports', 'anti', 'vaccine', 'prote...
# 2    ['good', 'sir', 'also', 'make_sure', 'person',...
# 3    ['anti', 'cars', 'circle', 'influence', 'belie...
# 4    ['lovely', 'wife', 'amp', 'respectful', 'paren...
# ..                                                 ...
# 994  ['amazing', 'staff', 'amp', 'support', 'thank'...
# 995  ['great', 'honor', 'amp', 'pleasure', 'vaccina...
# 996  ['great', 'know', 'fully', 'vaccinate', 'dose'...
# 997  ['thank', 'vaccinated', 'today', 'public', 'th...
# 998  ['thanks', 'visionary', 'leadership', 'hon_ble...
#
#                                               new_text  \
# 0    become anti vaccine blame malaysian government...
# 1    van passports anti vaccine protester gather sp...
# 2    good sir also make_sure person fraternity part...
# 3    anti cars circle influence believe second wave...
# 4    lovely wife amp respectful parent complete tak...
# ..                                                 ...
# 994  amazing staff amp support thank get vaccinate ...
# 995  great honor amp pleasure vaccinated people kin...
# 996  great know fully vaccinate dose also heartfelt...
# 997  thank vaccinated today public thank article th...
# 998  thanks visionary leadership hon_ble pro india ...
#
#                                                 scores  compound  \
# 0    {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'comp...   -0.3182
# 1    {'neg': 0.339, 'neu': 0.661, 'pos': 0.0, 'comp...   -0.4767
# 2    {'neg': 0.084, 'neu': 0.727, 'pos': 0.189, 'co...    0.4404
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4    {'neg': 0.075, 'neu': 0.424, 'pos': 0.501, 'co...    0.9801
# ..                                                 ...       ...
# 994  {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'comp...    0.8625
# 995  {'neg': 0.0, 'neu': 0.542, 'pos': 0.458, 'comp...    0.9001
# 996  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...    0.8885
# 997  {'neg': 0.0, 'neu': 0.561, 'pos': 0.439, 'comp...    0.8885
# 998  {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'comp...    0.7650
#
#      sentiment_vader
# 0                  0
# 1                  0
# 2                  2
# 3                  1
# 4                  2
# ..               ...
# 994                2
# 995                2
# 996                2
# 997                2
# 998                2
#
# [999 rows x 9 columns]

# %% [markdown]
# ## SGD

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
X_whole_data = cv.fit_transform(india_opinion['new_text'].values.astype('U'))

# %%
from sklearn.model_selection import train_test_split
# X=text_counts
X = cv.transform(labelled_df.new_text)
y=labelled_df.sentiment_vader
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=19)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (699, 51890)
# (300, 51890)

# %%
import scipy.sparse as sp
train_count = sp.csr_matrix(X_train)

# %%
X_train = sp.hstack([train_count])
X_train
# Out:
# <699x51890 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6821 stored elements in Compressed Sparse Row format>

# %%
test_count = sp.csr_matrix(X_test)
X_test = sp.hstack([test_count])

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
n_classes = 3

clf = SGDClassifier(alpha=1e-3, random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import *
#Checking performance our model with classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.64      0.72        85
#            1       0.70      0.96      0.81       111
#            2       0.88      0.70      0.78       104
#
#     accuracy                           0.78       300
#    macro avg       0.80      0.77      0.77       300
# weighted avg       0.80      0.78      0.78       300

# %%
from sklearn.metrics import *
from sklearn.metrics import *
# from sklearn.metrics import confusion_matrix
n_classes = 3

cm = confusion_matrix(y_test, y_pred, labels=range(n_classes))

print(f'Number of samples to classify: {len(X_test.toarray())}\n')

print("Accuracy score ={:.2f}%".format(accuracy_score(y_test, y_pred)*100))
print("F1 score ={:.2f}%".format(f1_score(y_test, y_pred, average="macro")*100))
print("Precision score ={:.2f}%".format(precision_score(y_test, y_pred, average="macro")*100))
print("Recall score ={:.2f}%".format(recall_score(y_test, y_pred, average="macro")*100))
# Out:
# Number of samples to classify: 300
#
# Accuracy score =78.00%
# F1 score =77.15%
# Precision score =80.47%
# Recall score =76.71%

# %%
import pickle
with open('india_sgd.model', "wb") as f:
 pickle.dump(clf, f)
 f.close()

# %%
#Load the save classifier 
model_saved = open("india_sgd.model", "rb") #binary read
clf = pickle.load(model_saved)
model_saved.close()

# %% [markdown]
# ## Implement on entire dataset

# %%
predictions = clf.predict(X_whole_data)

# %%
india_opinion["sentiment"] = predictions
india_opinion
# Out:
# /var/folders/d0/5_1bb8ld291843m4x7vj7vnw0000gn/T/ipykernel_44880/2469898815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_opinion["sentiment"] = predictions
#        index                                               Text  \
# 0          0  soniya mummy hoti toh covid me magic stick ghu...
# 11        11  خود کو اور اپنے پیاروں کو کورونا وبا سے بچانے ...
# 12        12  is covid ki waja se buht saray logon ne apne p...
# 18        18  deaths due covid what is vaccination rate what...
# 28        28  vaccination against covid- 19 is necessity tod...
# ...      ...                                                ...
# 95179  95179  nature seems have already started working savi...
# 95180  95180  dear , we #india 🇮🇳has helped this #world incl...
# 95184  95184  our sincere request state central govt 🙏🙏. ple...
# 95185  95185  thanks your appreciation valuable feedback abo...
# 95186  95186  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                                 new_text         languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 11     خود کو اور اپنے پیاروں کو کورونا وبا سے بچانے ...     URDU, Unknown
# 12     is covid ki waja se buht saray logon ne apne p...           Unknown
# 18     deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 28     vaccination against covid- 19 is necessity tod...           ENGLISH
# ...                                                  ...               ...
# 95179  nature seems have already started working savi...           ENGLISH
# 95180  dear , we #india Indiahas helped this #world i...           ENGLISH
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95185  thanks your appreciation valuable feedback abo...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
#
#                                               translated     new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 11     Vaccinate to protect yourself and your loved o...           ENGLISH
# 12     is covid ki waja se buht saray logon ne apne p...           Unknown
# 18     deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 28     vaccination against covid- 19 is necessity tod...           ENGLISH
# ...                                                  ...               ...
# 95179  nature seems have already started working savi...           ENGLISH
# 95180  dear , we #india Indiahas helped this #world i...           ENGLISH
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95185  thanks your appreciation valuable feedback abo...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...           ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 11     [('vaccinate', 'NN'), ('to', 'TO'), ('protect'...
# 12     [('is', 'VBZ'), ('couid', 'JJ'), ('ki', 'NN'),...
# 18     [('deaths', 'NNS'), ('due', 'JJ'), ('couid', '...
# 28     [('vaccination', 'NN'), ('against', 'IN'), ('c...
# ...                                                  ...
# 95179  [('nature', 'NN'), ('seems', 'VBZ'), ('have', ...
# 95180  [('dear', 'IN'), ('we', 'PRP'), ('india', 'VBP...
# 95184  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 95185  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
# 95186  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 11     ['vaccinate', 'protect', 'loved_one', 'coronav...
# 12     ['couid', 'ki', 'raja', 'se', 'spray', 'logon'...
# 18     ['death', 'due', 'couid', 'vaccination', 'rate...
# 28     ['vaccination', 'couid', 'nineteen', 'necessit...
# ...                                                  ...
# 95179  ['nature', 'seem', 'already', 'start', 'work',...
# 95180  ['dear', 'india', 'indians', 'help', 'world', ...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 11                        ['uranus', 'covidvaccination']
# 12                        ['hair', 'ply', 'vaccination']
# 18     ['death', 'due', 'couid', 'vaccination', 'rate...
# 28     ['necessity', 'today', 'scenario', 'hope', 'pr...
# ...                                                  ...
# 95179  ['nature', 'seem', 'already', 'start', 'work',...
# 95180  ['dear', 'help', 'world', 'include', 'kindness...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type  \
# 0                                              ['death']  subjective
# 11                                  ['covidvaccination']  subjective
# 12                        ['hair', 'ply', 'vaccination']  subjective
# 18     ['death', 'couid', 'vaccination', 'rate', 'har...  subjective
# 28         ['necessity', 'today', 'scenario', 'problem']  subjective
# ...                                                  ...         ...
# 95179  ['nature', 'generation', 'vaccinesaveslive', '...  subjective
# 95180    ['world', 'kindnessmatter', 'vaccinesaveslive']  subjective
# 95184  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 95185  ['thank', 'appreciation', 'feedback', 'vaccine...  subjective
# 95186  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
#
#        sentiment
# 0              1
# 11             1
# 12             1
# 18             2
# 28             2
# ...          ...
# 95179          2
# 95180          1
# 95184          2
# 95185          1
# 95186          2
#
# [43463 rows x 12 columns]

# %%
india_opinion["sentiment"].value_counts()
# Out:
# 1    20488
# 0    12242
# 2    10733
# Name: sentiment, dtype: int64

# %%
india_opinion.to_csv("sentiment_labelled_india_NB.csv")

# %%
whole_df = india_opinion[india_opinion.sentiment != 1]

# %%
whole_df
# Out:
#        index                                               Text  \
# 18        18  deaths due covid what is vaccination rate what...
# 28        28  vaccination against covid- 19 is necessity tod...
# 38        38  dr. deserved #1 minister's award his exception...
# 54        54  yeah i still don't get why, symptoms are much ...
# 68        68  bro you know where was case covid detected ind...
# ...      ...                                                ...
# 95176  95176  it’s time you do your part this fight against ...
# 95177  95177  indian gene with 66yrs no comorbidities ,he is...
# 95179  95179  nature seems have already started working savi...
# 95184  95184  our sincere request state central govt 🙏🙏. ple...
# 95186  95186  i can’t wait get my 2nd dose #covidvaccine ove...
#
#                                                 new_text         languages  \
# 18     deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 28     vaccination against covid- 19 is necessity tod...           ENGLISH
# 38     dr. deserved #1 minister's award his exception...           ENGLISH
# 54     yeah i still don't get why, symptoms are much ...           ENGLISH
# 68     bro you know where was case covid detected ind...           ENGLISH
# ...                                                  ...               ...
# 95176  it’s time you do your part this fight against ...  ENGLISH, Unknown
# 95177  indian gene with 66yrs no comorbidities ,he is...           ENGLISH
# 95179  nature seems have already started working savi...           ENGLISH
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
#
#                                               translated     new_languages  \
# 18     deaths due covid what is vaccination rate what...  ENGLISH, Unknown
# 28     vaccination against covid- 19 is necessity tod...           ENGLISH
# 38     dr. deserved #1 minister's award his exception...           ENGLISH
# 54     yeah i still do not get why, symptoms are much...           ENGLISH
# 68     bro you know where was case covid detected ind...           ENGLISH
# ...                                                  ...               ...
# 95176  it’s time you do your part this fight against ...           ENGLISH
# 95177  indian gene with 66yrs no comorbidities ,he is...           ENGLISH
# 95179  nature seems have already started working savi...           ENGLISH
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...           ENGLISH
#
#                                         pos_tagged_words  \
# 18     [('deaths', 'NNS'), ('due', 'JJ'), ('couid', '...
# 28     [('vaccination', 'NN'), ('against', 'IN'), ('c...
# 38     [('do', 'VBP'), ('deserved', 'VBD'), ('one', '...
# 54     [('yeah', 'NN'), ('i', 'NN'), ('still', 'RB'),...
# 68     [('bro', 'NN'), ('you', 'PRP'), ('know', 'VBP'...
# ...                                                  ...
# 95176  [('it', 'PRP'), ('i', 'VBZ'), ('i', 'JJ'), ('t...
# 95177  [('indian', 'JJ'), ('gene', 'NN'), ('with', 'I...
# 95179  [('nature', 'NN'), ('seems', 'VBZ'), ('have', ...
# 95184  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 95186  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
#
#                                      words_processed_all  \
# 18     ['death', 'due', 'couid', 'vaccination', 'rate...
# 28     ['vaccination', 'couid', 'nineteen', 'necessit...
# 38     ['deserved', 'one', 'minister', 'award', 'exce...
# 54     ['yeah', 'still', 'not', 'get', 'symptom', 'mu...
# 68     ['bro', 'know', 'case', 'couid', 'detected', '...
# ...                                                  ...
# 95176  ['time', 'part', 'fight', 'couid', 'reward', '...
# 95177  ['indian', 'gene', 'yrs', 'comorbiditie', 'see...
# 95179  ['nature', 'seem', 'already', 'start', 'work',...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                        words_processed_noun_adj_verb_adv  \
# 18     ['death', 'due', 'couid', 'vaccination', 'rate...
# 28     ['necessity', 'today', 'scenario', 'hope', 'pr...
# 38     ['deserved', 'way', 'manage', 'thing', 'millen...
# 54     ['still', 'symptom', 'much', 'less', 'severe',...
# 68     ['case', 'detect', 'fail', 'bring', 'case', 'b...
# ...                                                  ...
# 95176  ['time', 'part', 'fight', 'couid', 'reward', '...
# 95177  ['gene', 'comorbiditie', 'seem', 'say', 'vacci...
# 95179  ['nature', 'seem', 'already', 'start', 'work',...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
#
#                                     words_processed_noun   text_type  \
# 18     ['death', 'couid', 'vaccination', 'rate', 'har...  subjective
# 28         ['necessity', 'today', 'scenario', 'problem']  subjective
# 38     ['way', 'thing', 'millennium', 'peril', 'couid...  subjective
# 54     ['symptom', 'vaccination', 'example', 'country...  subjective
# 68     ['case', 'case', 'testing', 'people', 'vaccina...  subjective
# ...                                                  ...         ...
# 95176  ['time', 'part', 'fight', 'reward', 'action', ...  subjective
# 95177  ['gene', 'comorbiditie', 'vaccine', 'reason', ...  subjective
# 95179  ['nature', 'generation', 'vaccinesaveslive', '...  subjective
# 95184  ['request', 'state', 'govt', 'share', 'vaccine...  subjective
# 95186  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...  subjective
#
#        sentiment
# 18             2
# 28             2
# 38             2
# 54             0
# 68             0
# ...          ...
# 95176          2
# 95177          0
# 95179          2
# 95184          2
# 95186          2
#
# [22975 rows x 12 columns]

# %%
whole_df["sentiment"].value_counts()
# Out:
# 0    12242
# 2    10733
# Name: sentiment, dtype: int64

# %%
whole_df.to_csv("pos_neg_india_SGD.csv")
