# %%
import pandas as pd            
data = pd.read_csv('../../1k_sample_labelled_india.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             999 non-null    int64
#  1   Text              999 non-null    object
#  2   pos_tagged_words  999 non-null    object
#  3   new_languages     999 non-null    object
#  4   words_list        999 non-null    object
#  5   new_text          999 non-null    object
#  6   scores            999 non-null    object
#  7   compound          999 non-null    float64
#  8   sentiment_vader   999 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 70.4+ KB

# %%
# Label Encoding...

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(data.sentiment_vader)
data['categorical_label'] = le.transform(data.sentiment_vader)
data.head()
# Out:
#    index                                               Text  \
# 0  57000  kalau aku jadi anti vaccine ni salahkan keraja...
# 1  57003  "no vax passports": anti-vaccine protesters ga...
# 2  57010  good, sir also make sure that other persons yo...
# 3  57014  some anti-vaxers my circle influence believe t...
# 4  57044  myself, my lovely wife &amp; respectful parent...
#
#                                     pos_tagged_words new_languages  \
# 0  [('if', 'IN'), ('i', 'JJ'), ('become', 'VBP'),...       ENGLISH
# 1  [('no', 'DT'), ('van', 'NN'), ('passports', 'V...       ENGLISH
# 2  [('good', 'JJ'), ('sir', 'NN'), ('also', 'RB')...       ENGLISH
# 3  [('some', 'DT'), ('anti', 'JJ'), ('cars', 'NNS...       ENGLISH
# 4  [('myself', 'PRP'), ('my', 'PRP$'), ('lovely',...       ENGLISH
#
#                                           words_list  \
# 0  ['become', 'anti', 'vaccine', 'blame', 'malays...
# 1  ['van', 'passports', 'anti', 'vaccine', 'prote...
# 2  ['good', 'sir', 'also', 'make_sure', 'person',...
# 3  ['anti', 'cars', 'circle', 'influence', 'belie...
# 4  ['lovely', 'wife', 'amp', 'respectful', 'paren...
#
#                                             new_text  \
# 0  become anti vaccine blame malaysian government...
# 1  van passports anti vaccine protester gather sp...
# 2  good sir also make_sure person fraternity part...
# 3  anti cars circle influence believe second wave...
# 4  lovely wife amp respectful parent complete tak...
#
#                                               scores  compound  \
# 0  {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'comp...   -0.3182
# 1  {'neg': 0.339, 'neu': 0.661, 'pos': 0.0, 'comp...   -0.4767
# 2  {'neg': 0.084, 'neu': 0.727, 'pos': 0.189, 'co...    0.4404
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4  {'neg': 0.075, 'neu': 0.424, 'pos': 0.501, 'co...    0.9801
#
#   sentiment_vader  categorical_label
# 0        negative                  0
# 1        negative                  0
# 2        positive                  2
# 3         neutral                  1
# 4        positive                  2

# %%
import pandas as pd            
original_df = pd.read_csv('./india-v1-preprocessed-overall.csv')
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95188 entries, 0 to 95187
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         95188 non-null  int64
#  1   Text                               95188 non-null  object
#  2   new_text                           95188 non-null  object
#  3   languages                          95188 non-null  object
#  4   translated                         95188 non-null  object
#  5   new_languages                      95188 non-null  object
#  6   pos_tagged_words                   95188 non-null  object
#  7   words_processed_all                95188 non-null  object
#  8   words_processed_noun_adj_verb_adv  95188 non-null  object
#  9   words_processed_noun               95188 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 7.3+ MB

# %%
original_df
# Out:
#        Unnamed: 0                                               Text  \
# 0               0  soniya mummy hoti toh covid me magic stick ghu...
# 1               1  #pickids : about 20,000 children perlis eligib...
# 2               2  previous covid-19 infection – but not vaccinat...
# 3               3  india’s covid-19 vaccination coverage crosses ...
# 4               4  i got call office principal commissioner cgst ...
# ...           ...                                                ...
# 95183       95183  mask up 😷 india 🇮🇳 come forward vaccination ti...
# 95184       95184  our sincere request state central govt 🙏🙏. ple...
# 95185       95185  thanks your appreciation valuable feedback abo...
# 95186       95186  i can’t wait get my 2nd dose #covidvaccine ove...
# 95187       95187  thanks your appreciation valuable feedback abo...
#
#                                                 new_text         languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...           Unknown
# 1      #pickids : about 20,000 children perlis eligib...           ENGLISH
# 2      previous covid-19 infection – but not vaccinat...           ENGLISH
# 3      india’s covid-19 vaccination coverage crosses ...           ENGLISH
# 4      i got call office principal commissioner cgst ...           ENGLISH
# ...                                                  ...               ...
# 95183  mask up face_with_medical_mask india India com...  ENGLISH, Unknown
# 95184  our sincere request state central govt folded_...           ENGLISH
# 95185  thanks your appreciation valuable feedback abo...           ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...  Unknown, ENGLISH
# 95187  thanks your appreciation valuable feedback abo...           ENGLISH
#
#                                               translated new_languages  \
# 0      soniya mummy hoti toh covid me magic stick ghu...       Unknown
# 1      #pickids : about 20,000 children perlis eligib...       ENGLISH
# 2      previous covid-19 infection – but not vaccinat...       ENGLISH
# 3      india’s covid-19 vaccination coverage crosses ...       ENGLISH
# 4      i got call office principal commissioner cgst ...       ENGLISH
# ...                                                  ...           ...
# 95183  mask up face_with_medical_mask india India com...       ENGLISH
# 95184  our sincere request state central govt folded_...       ENGLISH
# 95185  thanks your appreciation valuable feedback abo...       ENGLISH
# 95186  i can’t wait get my 2nd dose #covidvaccine ove...       ENGLISH
# 95187  thanks your appreciation valuable feedback abo...       ENGLISH
#
#                                         pos_tagged_words  \
# 0      [('soniya', 'JJ'), ('mummy', 'NN'), ('hot', 'J...
# 1      [('pickins', 'NNS'), ('about', 'IN'), ('twenty...
# 2      [('previous', 'JJ'), ('couid', 'NN'), ('ninete...
# 3      [('india', 'NN'), ('i', 'NN'), ('i', 'VBP'), (...
# 4      [('i', 'NN'), ('got', 'VBD'), ('call', 'JJ'), ...
# ...                                                  ...
# 95183  [('mask', 'VB'), ('up', 'RP'), ('india', 'JJ')...
# 95184  [('our', 'PRP$'), ('sincere', 'JJ'), ('request...
# 95185  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
# 95186  [('i', 'NN'), ('can', 'MD'), ('i', 'VB'), ('i'...
# 95187  [('thanks', 'NNS'), ('your', 'PRP$'), ('apprec...
#
#                                      words_processed_all  \
# 0      ['soniya', 'mummy', 'hot', 'toh', 'couid', 'ma...
# 1      ['pickins', 'twenty', 'zero', 'child', 'peril'...
# 2      ['previous', 'couid', 'nineteen', 'infection',...
# 3      ['india', 'couid', 'nineteen', 'vaccination', ...
# 4      ['got', 'call', 'office', 'principal', 'commis...
# ...                                                  ...
# 95183  ['mask', 'india', 'india', 'come_forward', 'va...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
# 95187  ['thank', 'appreciation', 'valuable', 'feedbac...
#
#                        words_processed_noun_adj_verb_adv  \
# 0                                              ['death']
# 1      ['child', 'peril', 'eligible', 'couid', 'vacci...
# 2      ['previous', 'couid', 'infection', 'vaccinatio...
# 3                                ['vaccination', 'mark']
# 4      ['get', 'call', 'office', 'ascertain', 'status...
# ...                                                  ...
# 95183  ['come_forward', 'vaccination', 'tika_tsar', '...
# 95184  ['sincere', 'request', 'state', 'central', 'go...
# 95185  ['thank', 'appreciation', 'valuable', 'feedbac...
# 95186  ['wait', 'get', 'dose', 'covidvaccine', 'amp',...
# 95187  ['thank', 'appreciation', 'valuable', 'feedbac...
#
#                                     words_processed_noun
# 0                                              ['death']
# 1             ['child', 'peril', 'couid', 'vaccination']
# 2      ['couid', 'infection', 'vaccination', 'perform...
# 3                                        ['vaccination']
# 4      ['office', 'status', 'couid', 'vaccination', '...
# ...                                                  ...
# 95183  ['vaccination', 'syringemicrobe', 'television'...
# 95184  ['request', 'state', 'govt', 'share', 'vaccine...
# 95185  ['thank', 'appreciation', 'feedback', 'vaccine...
# 95186  ['dose', 'covidvaccine', 'amp', 'amp', 'follow...
# 95187  ['thank', 'appreciation', 'feedback', 'vaccina...
#
# [95188 rows x 10 columns]

# %%
data_merged = pd.merge(data, original_df[['translated','words_processed_all', 'words_processed_noun_adj_verb_adv', 'words_processed_noun']], left_on='index',right_index=True)
data_merged
# Out:
#      index                                               Text  \
# 0    57000  kalau aku jadi anti vaccine ni salahkan keraja...
# 1    57003  "no vax passports": anti-vaccine protesters ga...
# 2    57010  good, sir also make sure that other persons yo...
# 3    57014  some anti-vaxers my circle influence believe t...
# 4    57044  myself, my lovely wife &amp; respectful parent...
# ..     ...                                                ...
# 994  75434  amazing staff &amp; supporting .thanks all got...
# 995  75444  it has been great honor &amp; pleasure have va...
# 996  75691  great know, i am now fully #vaccinated with 2n...
# 997  75783  thank you #republic_of_india i have vaccinated...
# 998  75835  thanks visionary leadership hon'ble pmo india,...
#
#                                       pos_tagged_words new_languages  \
# 0    [('if', 'IN'), ('i', 'JJ'), ('become', 'VBP'),...       ENGLISH
# 1    [('no', 'DT'), ('van', 'NN'), ('passports', 'V...       ENGLISH
# 2    [('good', 'JJ'), ('sir', 'NN'), ('also', 'RB')...       ENGLISH
# 3    [('some', 'DT'), ('anti', 'JJ'), ('cars', 'NNS...       ENGLISH
# 4    [('myself', 'PRP'), ('my', 'PRP$'), ('lovely',...       ENGLISH
# ..                                                 ...           ...
# 994  [('amazing', 'JJ'), ('staff', 'NN'), ('amp', '...       ENGLISH
# 995  [('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'...       ENGLISH
# 996  [('great', 'JJ'), ('know', 'VBP'), ('i', 'JJ')...       ENGLISH
# 997  [('thank', 'IN'), ('you', 'PRP'), ('i', 'VBP')...       ENGLISH
# 998  [('thanks', 'NNS'), ('visionary', 'JJ'), ('lea...       ENGLISH
#
#                                             words_list  \
# 0    ['become', 'anti', 'vaccine', 'blame', 'malays...
# 1    ['van', 'passports', 'anti', 'vaccine', 'prote...
# 2    ['good', 'sir', 'also', 'make_sure', 'person',...
# 3    ['anti', 'cars', 'circle', 'influence', 'belie...
# 4    ['lovely', 'wife', 'amp', 'respectful', 'paren...
# ..                                                 ...
# 994  ['amazing', 'staff', 'amp', 'support', 'thank'...
# 995  ['great', 'honor', 'amp', 'pleasure', 'vaccina...
# 996  ['great', 'know', 'fully', 'vaccinate', 'dose'...
# 997  ['thank', 'vaccinated', 'today', 'public', 'th...
# 998  ['thanks', 'visionary', 'leadership', 'hon_ble...
#
#                                               new_text  \
# 0    become anti vaccine blame malaysian government...
# 1    van passports anti vaccine protester gather sp...
# 2    good sir also make_sure person fraternity part...
# 3    anti cars circle influence believe second wave...
# 4    lovely wife amp respectful parent complete tak...
# ..                                                 ...
# 994  amazing staff amp support thank get vaccinate ...
# 995  great honor amp pleasure vaccinated people kin...
# 996  great know fully vaccinate dose also heartfelt...
# 997  thank vaccinated today public thank article th...
# 998  thanks visionary leadership hon_ble pro india ...
#
#                                                 scores  compound  \
# 0    {'neg': 0.095, 'neu': 0.905, 'pos': 0.0, 'comp...   -0.3182
# 1    {'neg': 0.339, 'neu': 0.661, 'pos': 0.0, 'comp...   -0.4767
# 2    {'neg': 0.084, 'neu': 0.727, 'pos': 0.189, 'co...    0.4404
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4    {'neg': 0.075, 'neu': 0.424, 'pos': 0.501, 'co...    0.9801
# ..                                                 ...       ...
# 994  {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'comp...    0.8625
# 995  {'neg': 0.0, 'neu': 0.542, 'pos': 0.458, 'comp...    0.9001
# 996  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...    0.8885
# 997  {'neg': 0.0, 'neu': 0.561, 'pos': 0.439, 'comp...    0.8885
# 998  {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'comp...    0.7650
#
#     sentiment_vader  categorical_label  \
# 0          negative                  0
# 1          negative                  0
# 2          positive                  2
# 3           neutral                  1
# 4          positive                  2
# ..              ...                ...
# 994        positive                  2
# 995        positive                  2
# 996        positive                  2
# 997        positive                  2
# 998        positive                  2
#
#                                             translated  \
# 0    If I become anti -vaccine, blame the Malaysian...
# 1    "no vax passports": anti-vaccine protesters ga...
# 2    good, sir also make sure that other persons yo...
# 3    some anti-vaxers my circle influence believe t...
# 4    myself, my lovely wife &amp; respectful parent...
# ..                                                 ...
# 994  amazing staff &amp; supporting .thanks all got...
# 995  it has been great honor &amp; pleasure have va...
# 996  great know, i am now fully #vaccinated with 2n...
# 997  thank you #republic_of_india i have vaccinated...
# 998  thanks visionary leadership hon'ble pmo india,...
#
#                                    words_processed_all  \
# 0    ['become', 'anti', 'vaccine', 'blame', 'malays...
# 1    ['van', 'passports', 'anti', 'vaccine', 'prote...
# 2    ['good', 'sir', 'also', 'make_sure', 'person',...
# 3    ['anti', 'cars', 'circle', 'influence', 'belie...
# 4    ['lovely', 'wife', 'amp', 'respectful', 'paren...
# ..                                                 ...
# 994  ['amazing', 'staff', 'amp', 'support', 'thank'...
# 995  ['great', 'honor', 'amp', 'pleasure', 'vaccina...
# 996  ['great', 'know', 'fully', 'vaccinate', 'dose'...
# 997  ['thank', 'vaccinated', 'today', 'public', 'th...
# 998  ['thanks', 'visionary', 'leadership', 'hon_ble...
#
#                      words_processed_noun_adj_verb_adv  \
# 0    ['become', 'anti', 'malaysian', 'government', ...
# 1    ['vaccine', 'protester', 'gather', 'broadway',...
# 2    ['good', 'also', 'make_sure', 'person', 'frate...
# 3    ['anti', 'influence', 'believe', 'second', 'wa...
# 4    ['lovely', 'wife', 'amp', 'respectful', 'paren...
# ..                                                 ...
# 994  ['amazing', 'staff', 'amp', 'support', 'thank'...
# 995  ['great', 'honor', 'amp', 'pleasure', 'vaccina...
# 996  ['great', 'know', 'fully', 'vaccinate', 'dose'...
# 997  ['thank', 'vaccinated', 'today', 'public', 'th...
# 998  ['visionary', 'leadership', 'hon_ble', 'nation...
#
#                                   words_processed_noun
# 0                            ['government', 'vaccine']
# 1                             ['vaccine', 'protester']
# 2    ['person', 'fraternity', 'part', 'vaccine', 'n...
# 3    ['influence', 'wave', 'vaccine', 'vaccination'...
# 4    ['wife', 'amp', 'parent', 'dose', 'vaccine', '...
# ..                                                 ...
# 994                  ['staff', 'amp', 'thank', 'asap']
# 995  ['honor', 'amp', 'pleasure', 'people', 'kingdo...
# 996                     ['dose', 'thank', 'scientist']
# 997  ['today', 'public', 'article', 'indianmedicala...
# 998  ['leadership', 'nation', 'country', 'number', ...
#
# [999 rows x 14 columns]

# %%
# Tweet text preprocessing...

import json
import collections
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import re
from nltk.tokenize import TweetTokenizer
def text_preprocess(text, tknzr):
    FLAGS = re.MULTILINE | re.DOTALL
    # Different regex parts for smiley faces
    eyes = r"[8:=;]"
    nose = r"['`-]?"
    # function so code less repetitive
    def re_sub(pattern, repl):
        return re.sub(pattern, repl, text, flags=FLAGS)
    text = re_sub(r"https?://S+b|www.(w+.)+S*", "")
    text = re_sub(r"/"," / ")
    text = re_sub(r"@w+", "")
    text = re_sub(r"{}{}[)dD]+|[)dD]+{}{}".format(eyes, nose, nose, eyes), "")
    text = re_sub(r"{}{}p+".format(eyes, nose), "")
    # text = re_sub(r"{}{}(+|)+{}{}".format(eyes, nose, nose, eyes), "")
    text = re_sub(r"{}{}[/|l*]".format(eyes, nose), "")
    text = re_sub(r"<3","")
    text = re_sub(r"[-+]?[.d]*[d]+[:,.d]*", "")
    text = re_sub(r"([!?.]){2,}", r"1 ")
    text = re_sub(r"b(S*?)(.)2{2,}b", r"12 ")
    text = re_sub(r"[A-Za-z]+[@#$%^&*()]+[A-Za-z]*","abuse")
    tokens = tknzr.tokenize(text.lower())
    return tokens #" ".join(tokens)

tknzr=TweetTokenizer(reduce_len=True, preserve_case=False, strip_handles=False)

# %%
X = []
Y = []

for idx in data.index:
    X.append(text_preprocess(data_merged['translated'][idx], tknzr))
    Y.append(data_merged['categorical_label'][idx])

# Train-Test splitting
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=19)
labels = ['Negative','Neutral', 'Positive']  # For further use...

# %%
#if error shows up, open mac terminal and type "open $TMPDIR"
#find tfhub_modules folder and del sub folder (the one with long string of nums and chars)
#rerun

import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# Loading USE encoder
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" 
use_model = hub.load(module_url)
print ("module %s loaded" % module_url)

def get_use_vector(doc):
  tmp = use_model(doc)
  return np.mean(tmp, axis=0)

# Convert text data into vector
train_vectors = []
for doc in X_train:
    try:
      train_vectors.append(get_use_vector(doc))
    except Exception:
      print('error...')
test_vectors = []
for doc in X_test:
    try:
      test_vectors.append(get_use_vector(doc))
    except Exception:
      print('error...')
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
# We calculate the following metrics to evaluate the model.

from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# This utility function will be used to evaluate the other models also.
def show_performance_data(Y_test, Y_pred, model_name):
  print(classification_report(Y_test, Y_pred, target_names=labels))
  tmp_result = classification_report(Y_test, Y_pred, target_names=labels, output_dict=True)
  cm1 = confusion_matrix(Y_test, Y_pred)
  df_cm = pd.DataFrame(cm1, index = [i for i in labels], columns = [i for i in labels])
  plt.figure(figsize = (7,5))
  sn.heatmap(df_cm, annot=True,cmap='gist_earth_r', fmt='g')
  plt.savefig('confusion_mrtx_'+model_name+'.png',bbox_inches = 'tight')
  return tmp_result

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(train_vectors, Y_train)
Y_pred = neigh.predict(test_vectors)
result_knn = show_performance_data(Y_test, Y_pred, 'knn')
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.46      0.91      0.61        55
#      Neutral       0.90      0.37      0.53        75
#     Positive       0.80      0.69      0.74        70
#
#     accuracy                           0.63       200
#    macro avg       0.72      0.66      0.63       200
# weighted avg       0.74      0.63      0.62       200
